# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime

# %%
#full cities
#Italy:
#Rome,Venice,Florence,Siena,Piacenza,Ferrara,Vicenza,Napoli,Noto,Catania,Urbino,Verona,Siracusa
#Amalfi,Ravello
#Russia
#St Petersburg
#France
#Provins,Dijon,Lyon,Bordeaux,Strasbourg
#Spain
#Toledo, Cuenca, Burgos, Leon, Caceres, Alcala de Henares,Segovia,Santiago de Compostela
#Avila, Salamanca, Astorga
#Germany
#Luebeck,Bamberg,Regensburg,Baden-Baden,Stralsund,Freiberg 
#Switzerland
#Bern, La Chaux-de-Fonds
#Austria
#Salzburg,Vienna,Baden,Graz
#Belgium
#Bruges
#Luxembourg: Luxembourg
#Poland
#Warsaw,Krakow,Torun
#Hungary
#Budapest,Tokaj
#Czech
#Prague,Cesky Krumlov,Kutna Hora,Telc
#Slovakia
#Bardejov,Levoca,Spisske Pohradie, Banska Stiavnica,Vlcolinec
#Croatia
#Trogir,Split
#UK
#Bath,Edinburgh
#Latvia
#Riga
#Lithuania
#Vilnius
#Portugal
#Sintra,Guimaraes,Elvas,Evora,Porto
#South Korea
#Yangdong Village

#Sweden
#Visby,Karlskrona, Oland

# %%
#this dataframe will contain the following based on pictures taken from 2006 to today
#introduce removed flag
#read Dresden into removed category, keep Liverpool
#change groupings though or do it in different periodsxsß

#['Date', 'Place', 'UNESCO World Heritage Site','Secondary Site','Country','PictureCount','Secondary Picture Count',"Cultural Site","Natural Site","Site Removed","Co-Travellers"]

#originally planned to set index to date, but considering we have two sites per data that is not possible
data_list=[]
#1996
data_list.append([datetime.datetime(1996, 3, 2),"Hartmannswiller","Funerary and memory sites of the First World War",'','France',3,0,1,0,0,["Hannsjoerg","Artur","Heidrun",'Anne-Kathrin','Jan-Marc']])
data_list.append([datetime.datetime(1996, 5, 15),"Beatenberg","Jungfrau-Aletsch","","Switzerland",3,0,0,0,0,["Artur","Anne-Kathrin"]])
data_list.append([datetime.datetime(1996, 8, 26),"London","Palace of Westminster and Westminster Abbey including Saint Margaret’s Church","","United Kingdom",1,0,1,0,0,["Hannsjoerg","Artur","Heidrun",'Anne-Kathrin','Jan-Marc']])
data_list.append([datetime.datetime(1996, 8, 28),"London","Tower of London","","United Kingdom",4,0,1,0,0,["Hannsjoerg","Artur","Heidrun",'Anne-Kathrin','Jan-Marc']])
data_list.append([datetime.datetime(1996, 8, 28),"London","Palace of Westminster and Westminster Abbey including Saint Margaret’s Church","","United Kingdom",13,0,1,0,0,["Artur"]])
data_list.append([datetime.datetime(1996, 8, 29),"London","Maritime Greenwich","","United Kingdom",6,0,1,0,0,["Hannsjoerg","Artur","Heidrun",'Anne-Kathrin','Jan-Marc']])
data_list.append([datetime.datetime(1996, 10, 27),"Speyer","Speyer Cathedral","","Germany",16,0,1,0,0,["Hannsjoerg","Artur","Heidrun",'Anne-Kathrin','Jan-Marc']])
data_list.append([datetime.datetime(1996, 10, 28),"Bingen","Upper Middle Rhine Valley","","Germany",1,0,1,0,0,["Hannsjoerg","Artur","Heidrun",'Anne-Kathrin','Jan-Marc']])
#1997
data_list.append([datetime.datetime(1997, 8, 24),"Rome","Rome","","Vatican",6,0,1,0,0,["Hannsjoerg","Artur","Heidrun",'Anne-Kathrin','Jan-Marc']])
data_list.append([datetime.datetime(1997, 8, 24),"Rome","Rome","","Italy",8,0,1,0,0,["Hannsjoerg","Artur","Heidrun",'Anne-Kathrin','Jan-Marc']])
data_list.append([datetime.datetime(1997, 8, 25),"Rome","Rome","","Italy",13,0,1,0,0,["Hannsjoerg","Artur","Heidrun",'Anne-Kathrin','Jan-Marc']])
data_list.append([datetime.datetime(1997, 8, 26),"Rome","Rome","","Italy",11,0,1,0,0,["Hannsjoerg","Artur","Heidrun",'Anne-Kathrin','Jan-Marc']])
data_list.append([datetime.datetime(1997, 8, 27),"Rome","Vatican City","","Vatican",19,0,1,0,0,["Hannsjoerg","Artur","Heidrun",'Anne-Kathrin','Jan-Marc']])
data_list.append([datetime.datetime(1997, 8, 27),"Rome","Rome","","Italy",4,0,1,0,0,["Hannsjoerg","Artur","Heidrun",'Anne-Kathrin','Jan-Marc']])
data_list.append([datetime.datetime(1997, 8, 28),"Rome","Rome","","Vatican",6,0,1,0,0,["Hannsjoerg","Artur","Heidrun",'Anne-Kathrin','Jan-Marc']])
data_list.append([datetime.datetime(1997, 8, 28),"Rome","Rome","","Italy",8,0,1,0,0,["Hannsjoerg","Artur","Heidrun",'Anne-Kathrin','Jan-Marc']])
data_list.append([datetime.datetime(1997, 8, 30),"Rome","Rome","","Italy",3,0,1,0,0,["Hannsjoerg","Artur","Heidrun",'Anne-Kathrin','Jan-Marc']])
data_list.append([datetime.datetime(1997, 8, 31),"Rome","Vatican City","","Vatican",7,0,1,0,0,["Hannsjoerg","Artur","Heidrun",'Anne-Kathrin','Jan-Marc']])
data_list.append([datetime.datetime(1997, 8, 31),"Rome","Rome","","Italy",4,0,1,0,0,["Hannsjoerg","Artur","Heidrun",'Anne-Kathrin','Jan-Marc']])
data_list.append([datetime.datetime(1997, 9, 1),"Rome","Rome","","Italy",4,0,1,0,0,["Hannsjoerg","Artur","Heidrun",'Anne-Kathrin','Jan-Marc']])
#1998
data_list.append([datetime.datetime(1999, 6, 14),"Speyer","Speyer Cathedral","","Germany",16,0,1,0,0,['school']])
data_list.append([datetime.datetime(1999, 6, 18),"Cologne","Cologne Cathedral","","Germany",28,0,1,0,0,['school']])
data_list.append([datetime.datetime(1998, 8, 22),"Paris","Paris, Banks of the Seine","","France",4,0,1,0,0,["Hannsjoerg","Artur","Heidrun",'Anne-Kathrin','Jan-Marc']])
data_list.append([datetime.datetime(1998, 8, 23),"Paris","Paris, Banks of the Seine","","France",20,0,1,0,0,["Hannsjoerg","Artur","Heidrun",'Anne-Kathrin','Jan-Marc']])
data_list.append([datetime.datetime(1998, 8, 24),"Paris","Paris, Banks of the Seine","","France",9,0,1,0,0,["Hannsjoerg","Artur","Heidrun",'Anne-Kathrin','Jan-Marc']])
data_list.append([datetime.datetime(1998, 8, 25),"Versailles","Palace and Park of Versailles","","France",6,0,1,0,0,["Hannsjoerg","Artur","Heidrun",'Anne-Kathrin','Jan-Marc']])
data_list.append([datetime.datetime(1998, 8, 27),"Paris","Routes of Santiago de Compostela in France","","France",1,0,1,0,0,["Hannsjoerg","Artur","Heidrun",'Anne-Kathrin','Jan-Marc']])

#1999
data_list.append([datetime.datetime(1999, 8, 27),"Athens","Athens Acropolis","","Greece",1,0,1,0,0,["Hannsjoerg","Artur","Heidrun",'Anne-Kathrin','Jan-Marc']])
data_list.append([datetime.datetime(1999, 8, 28),"Athens","Athens Acropolis","","Greece",12,0,1,0,0,["Hannsjoerg","Artur","Heidrun",'Anne-Kathrin','Jan-Marc']])
data_list.append([datetime.datetime(1999, 8, 29),"Mykines","Mykene","","Greece",9,0,1,0,0,["Hannsjoerg","Artur","Heidrun",'Anne-Kathrin','Jan-Marc']])
data_list.append([datetime.datetime(1999, 8, 29),"Tripolis","Sanctuary of Asklepios at Epidaurus","","Greece",5,0,1,0,0,["Hannsjoerg","Artur","Heidrun",'Anne-Kathrin','Jan-Marc']])
data_list.append([datetime.datetime(1999, 8, 30),"Olympia","Olympia","","Greece",6,0,1,0,0,["Hannsjoerg","Artur","Heidrun",'Anne-Kathrin','Jan-Marc']])
data_list.append([datetime.datetime(1999, 9, 1),"Delphi","Delphi","","Greece",15,0,1,0,0,["Hannsjoerg","Artur","Heidrun",'Anne-Kathrin','Jan-Marc']])
data_list.append([datetime.datetime(1999, 9, 2),"Athens","Athens Acropolis","","Greece",4,0,1,0,0,["Hannsjoerg","Artur","Heidrun",'Anne-Kathrin','Jan-Marc']])
#2000
data_list.append([datetime.datetime(2000, 8, 26),"Bursa","Bursa and Cumalikizik: the Birth of the Ottoman Empire","","Turkey",13,0,1,0,0,["Hannsjoerg","Artur","Heidrun",'Anne-Kathrin']])
data_list.append([datetime.datetime(2000, 8, 27),"Istanbul","Istanbul","","Turkey",48,0,1,0,0,["Hannsjoerg","Artur","Heidrun",'Anne-Kathrin']])
data_list.append([datetime.datetime(2000, 8, 28),"Istanbul","Istanbul","","Turkey",29,0,1,0,0,["Hannsjoerg","Artur","Heidrun",'Anne-Kathrin']])
data_list.append([datetime.datetime(2000, 8, 29),"Troy","Troy","","Turkey",7,0,1,0,0,["Hannsjoerg","Artur","Heidrun",'Anne-Kathrin']])
data_list.append([datetime.datetime(2000, 8, 30),"Bergama","Pergamon and its Multi-Layered Cultural Landscape","","Turkey",6,0,1,0,0,["Hannsjoerg","Artur","Heidrun",'Anne-Kathrin']])
data_list.append([datetime.datetime(2000, 8, 30),"Selcuk","Ephesus","","Turkey",14,0,1,0,0,["Hannsjoerg","Artur","Heidrun",'Anne-Kathrin']])
data_list.append([datetime.datetime(2000, 8, 31),"Denizli","Hierapolis-Pamukkale","","Turkey",11,0,1,1,0,["Hannsjoerg","Artur","Heidrun",'Anne-Kathrin']])
#2001
data_list.append([datetime.datetime(2001, 5, 15),"Barcelona","Works of Antoni Gaudi","","Spain",31,0,1,0,0,['school']])
data_list.append([datetime.datetime(2001, 5, 19),"Vers-Pont-du-Gard", "Pont-du-Gard","",'France',2,0,1,0,0,['school']])
data_list.append([datetime.datetime(2001, 6, 9),"Berlin","Museumsinsel","","Germany",1,0,1,0,0,["Hannsjoerg","Artur","Heidrun",'Anne-Kathrin']])
data_list.append([datetime.datetime(2001, 6, 11),'Potsdam',"Palaces and Parks of Potsdam and Berlin","","Germany",3,0,1,0,0,["Hannsjoerg","Artur","Heidrun",'Anne-Kathrin']])
data_list.append([datetime.datetime(2001, 8, 23),"Granada", "Alhambra, Generalife and Albayzin", "","Spain",2 ,0,1,0,0,["Hannsjoerg","Artur","Heidrun",'Anne-Kathrin']])
data_list.append([datetime.datetime(2001, 8, 24),"Granada", "Alhambra, Generalife and Albayzin", "","Spain",21 ,0,1,0,0,["Hannsjoerg","Artur","Heidrun",'Anne-Kathrin']])
data_list.append([datetime.datetime(2001, 8, 24),"Cordoba", "Cordoba", "","Spain",5 ,0,1,0,0,["Hannsjoerg","Artur","Heidrun",'Anne-Kathrin']])
data_list.append([datetime.datetime(2001, 8, 25),"Cordoba", "Cordoba", "","Spain",34 ,0,1,0,0,["Hannsjoerg","Artur","Heidrun",'Anne-Kathrin']])
data_list.append([datetime.datetime(2001, 3, 26),"Sevilla", "Cathedral, Alcazar and Archivo de Indias in Seville", "","Spain",30 ,0,1,0,0,["Hannsjoerg","Artur","Heidrun",'Anne-Kathrin']])
#2002
data_list.append([datetime.datetime(2002, 5, 26),"San Gimignano", "San Gimignano", "","Italy",3 ,0,1,0,0,["Hannsjoerg","Artur","Heidrun",'Anne-Kathrin']])
data_list.append([datetime.datetime(2002, 5, 26),"Siena", "Siena", "","Italy",17 ,0,1,0,0,["Hannsjoerg","Artur","Heidrun",'Anne-Kathrin']])
data_list.append([datetime.datetime(2002, 5, 27),"Florence", "Florence", "Medici Villas and Gardens","Italy",30 ,3,1,0,0,["Hannsjoerg","Artur","Heidrun",'Anne-Kathrin']])
data_list.append([datetime.datetime(2002, 5, 28),"Pisa","Piazza del Duomo, Pisa","","Italy",27,0,1,0,0,["Hannsjoerg","Artur","Heidrun",'Anne-Kathrin']])
data_list.append([datetime.datetime(2002, 8, 21),"Marrakesh","Marrakesh","","Morocco",12,0,1,0,0,["Hannsjoerg","Artur","Heidrun",'Anne-Kathrin']]) 
data_list.append([datetime.datetime(2002, 8, 23),"Fez","Fez","","Morocco",10,0,1,0,0,["Hannsjoerg","Artur","Heidrun",'Anne-Kathrin']]) 
data_list.append([datetime.datetime(2002, 8, 24),"Fez","Fez","","Morocco",19,0,1,0,0,["Hannsjoerg","Artur","Heidrun",'Anne-Kathrin']]) 
data_list.append([datetime.datetime(2002, 8, 24),"Meknes","Meknes","","Morocco",6,0,1,0,0,["Hannsjoerg","Artur","Heidrun",'Anne-Kathrin']]) 
data_list.append([datetime.datetime(2002, 8, 24),"Fertassa","Volubilis","","Morocco",11,0,1,0,0,["Hannsjoerg","Artur","Heidrun",'Anne-Kathrin']]) 
data_list.append([datetime.datetime(2002, 8, 25),"Rabat","Rabat, Modern Capital and Historic City: a Shared Heritage","","Morocco",10,0,1,0,0,["Hannsjoerg","Artur","Heidrun",'Anne-Kathrin']]) 
#2003
data_list.append([datetime.datetime(2003, 7, 8),"Selcuk","Ephesus","","Turkey",19,0,1,0,0,['Gianrico','Sigi','Böni']])
#2004
data_list.append([datetime.datetime(2004, 7, 7),"Tunis","Tunis","","Tunisia",12,0,1,0,0,['Gianrico','Sigi']])
data_list.append([datetime.datetime(2004, 7, 7),"Carthage","Carthage","","Tunisia",4,0,1,0,0,['Gianrico','Sigi']])
data_list.append([datetime.datetime(2004, 10, 17),"London","Tower of London","","United Kingdom",8,0,1,0,0,['Gianrico','Sigi','Anne']])
#2005
data_list.append([datetime.datetime(2005, 3, 21),"Saqqara","Memphis and its Necropolis – the Pyramid Fields from Giza to Dahshur","","Egypt",13,0,1,0,0,['Artur','Heidrun','Hannsjoerg']])
data_list.append([datetime.datetime(2005, 3, 21),"Giza","Memphis and its Necropolis – the Pyramid Fields from Giza to Dahshur","","Egypt",20,0,1,0,0,['Artur','Heidrun','Hannsjoerg']])
data_list.append([datetime.datetime(2005, 3, 22),"Karnak","Ancient Thebes with its Necropolis","","Egypt",6,0,1,0,0,['Artur','Heidrun','Hannsjoerg']])
data_list.append([datetime.datetime(2005, 3, 22),"Luxor","Ancient Thebes with its Necropolis","","Egypt",9,0,1,0,0,['Artur','Heidrun','Hannsjoerg']])
data_list.append([datetime.datetime(2005, 3, 23),"Luxor","Ancient Thebes with its Necropolis","","Egypt",17,0,1,0,0,['Artur','Heidrun','Hannsjoerg']])
data_list.append([datetime.datetime(2005, 3, 25),"Aswan","Nubian Monuments from Abu Simbel to Philae","","Egypt",7,0,1,0,0,['Artur','Heidrun','Hannsjoerg']])
data_list.append([datetime.datetime(2005, 3, 27),"Cairo","Cairo","","Egypt",18,0,1,0,0,['Artur','Heidrun','Hannsjoerg']])
data_list.append([datetime.datetime(2005, 8, 30),"Belem","Monastery of the Hieronymites and Tower of Belem","","Portugal",2,0,1,0,0,['Artur','Heidrun','Hannsjoerg','Anne-Kathrin']])
#2006
data_list.append([datetime.datetime(2006, 7, 11),"London","Palace of Westminster and Westminster Abbey including Saint Margaret’s Church","","United Kingdom",4,0,1,0,0,["Hannsjoerg","Artur","Heidrun"]])
data_list.append([datetime.datetime(2006, 7, 12),"London","Palace of Westminster and Westminster Abbey including Saint Margaret’s Church","","United Kingdom",20,0,1,0,0,["Hannsjoerg","Artur","Heidrun"]])
data_list.append([datetime.datetime(2006, 7, 13),"London","Tower of London","","United Kingdom",4,0,1,0,0,["Hannsjoerg","Artur","Heidrun"]])
data_list.append([datetime.datetime(2006, 7, 14),"London","Maritime Greenwich","","United Kingdom",6,0,1,0,0,["Hannsjoerg","Artur","Heidrun"]])
#NONE in 2007
#2008
data_list.append([datetime.datetime(2008, 1, 2),"Dresden","Dresden","","Germany",34,0,1,0,1,["Anne-Kathrin","Hannsjoerg","Artur","Heidrun"]])
data_list.append([datetime.datetime(2008, 1, 4),"Dresden","Dresden","","Germany",118,0,1,0,1,["Anne-Kathrin","Hannsjoerg","Artur","Heidrun"]])
data_list.append([datetime.datetime(2008, 1, 13),"St Gallen","Abbey of St Gall","","Switzerland",32,0,1,0,0,[]]) 
data_list.append([datetime.datetime(2008, 5, 4),"Bern","Bern","","Switzerland",32,0,1,0,0,["Zhiling"]]) 
data_list.append([datetime.datetime(2008, 7, 29),"Philadelphia","Independence Hall","","USA",4,0,1,0,0,[]])
data_list.append([datetime.datetime(2008, 9, 4),"El Escorial","El Escorial Monastery","","Spain",19,0,1,0,0,["Hannsjoerg","Artur","Heidrun"]])
#???
data_list.append([datetime.datetime(2008, 9, 4),"Madrid", "Paseo del Prado and Buen Retiro", "","Spain",17 ,0,1,0,0,['Hannsjoerg','Artur','Heidrun']])
data_list.append([datetime.datetime(2008, 9, 5),"Segovia","Segovia","","Spain",107,0,1,0,0,['Heidrun']])
#???
data_list.append([datetime.datetime(2008, 9, 5),"Madrid", "Paseo del Prado and Buen Retiro", "","Spain",2 ,0,1,0,0,['Hannsjoerg','Artur','Heidrun']])
#???
data_list.append([datetime.datetime(2008, 9, 6),"Madrid", "Paseo del Prado and Buen Retiro", "","Spain",40 ,0,1,0,0,['Hannsjoerg','Artur','Heidrun']])
data_list.append([datetime.datetime(2008, 10, 5),"Lauterbrunnen","Jungfrau-Aletsch","","Switzerland",24,0,0,1,0,["Anne","Sigi"]])
data_list.append([datetime.datetime(2008, 10, 5),"Grindelwald","Jungfrau-Aletsch","","Switzerland",5,0,0,1,0,["Anne","Sigi"]])
data_list.append([datetime.datetime(2008, 10, 5),"Fieschertal","Jungfrau-Aletsch","","Switzerland",67,0,0,1,0,["Anne","Sigi"]])
#2009
data_list.append([datetime.datetime(2009, 1, 3),"Reichenau","Reichenau","","Germany",36,0,1,0,0,["Hannsjoerg","Artur","Heidrun"]]) 
data_list.append([datetime.datetime(2009, 4, 29),"Toledo","Toledo","","Spain",71,0,1,0,0,[]]) 
#???
data_list.append([datetime.datetime(2009, 4, 29),"Madrid", "Paseo del Prado and Buen Retiro", "","Spain",16 ,0,1,0,0,[]])
data_list.append([datetime.datetime(2009, 7, 7),"New York City","Statue of Liberty","","USA",37,0,1,0,0,[]])
data_list.append([datetime.datetime(2009, 8, 30),"Stechelberg","Jungfrau-Aletsch","","Switzerland",42,0,0,1,0,[]])
data_list.append([datetime.datetime(2009, 11, 26),"Bern","Bern","","Switzerland",42,0,1,0,0,[]])
data_list.append([datetime.datetime(2009, 12, 20),"Speyer","Speyer Cathedral","","Germany",35,0,1,0,0,["Anne-Kathrin"]])
#2010
data_list.append([datetime.datetime(2010, 1, 21),"Bellinzona","Castles of Bellinzona","","Switzerland",48,0,0,1,0,["all the physicists"]])
data_list.append([datetime.datetime(2010, 4, 5),"Steingaden","Wieskirche","","Germany",29,0,1,0,0,["Hannsjoerg"]])
data_list.append([datetime.datetime(2010, 5, 23),"Rosenlaui","Jungfrau-Aletsch","","Switzerland",70,0,0,1,0,['Anne-Kathrin',"Hannsjoerg","Artur","Heidrun"]])
data_list.append([datetime.datetime(2010, 6, 27),"Fiesch","Jungfrau-Aletsch","","Switzerland",81,0,0,1,0,[]])
data_list.append([datetime.datetime(2010, 6, 27),"Riederalp","Jungfrau-Aletsch","","Switzerland",15,0,0,1,0,[]])
data_list.append([datetime.datetime(2010, 7, 21),"Paris","Paris, Banks of the Seine","","France",147,0,1,0,0,[]])
data_list.append([datetime.datetime(2010, 7, 22),"Paris","Paris, Banks of the Seine","","France",4,0,1,0,0,[]])
data_list.append([datetime.datetime(2010, 7, 23),"Paris","Paris, Banks of the Seine","","France",35,0,1,0,0,[]])
data_list.append([datetime.datetime(2010, 7, 23),"Paris","Routes of Santiago de Compostela in France","","France",2,0,1,0,0,[]])
data_list.append([datetime.datetime(2010, 7, 24),"Paris","Paris, Banks of the Seine","","France",3,0,1,0,0,[]])
data_list.append([datetime.datetime(2010, 7, 25),"Versailles","Palace and Park of Versailles","","France",249,0,1,0,0,[]])
data_list.append([datetime.datetime(2010, 7, 26),"Paris","Paris, Banks of the Seine","","France",13,0,1,0,0,[]])
data_list.append([datetime.datetime(2010, 7, 28),"Paris","Paris, Banks of the Seine","","France",1,0,1,0,0,[]])
data_list.append([datetime.datetime(2010, 7, 29),"Chartres","Chartres Cathedral","","France",85,0,1,0,0,[]])
data_list.append([datetime.datetime(2010, 7, 30),"Fontainebleau","Palace and Park of Fontainebleau",'',"France",83,0,1,0,0,['Artur','Heidrun']])
data_list.append([datetime.datetime(2010, 7, 30),"Paris","Paris, Banks of the Seine","","France",43,0,1,0,0,['Artur','Heidrun']])
data_list.append([datetime.datetime(2010, 8, 1),"Paris","Paris, Banks of the Seine","","France",145,0,1,0,0,['Artur','Heidrun']])
data_list.append([datetime.datetime(2010, 8, 2),"Paris","Paris, Banks of the Seine","","France",160,0,1,0,0,['Artur','Heidrun']])
data_list.append([datetime.datetime(2010, 8, 3),"Reims","Cathedral of Notre-Dame, Former Abbey of Saint-Remi and Palace of Tau","","France",128,0,1,0,0,['Artur','Heidrun']])
data_list.append([datetime.datetime(2010, 8, 4),"Paris","Paris, Banks of the Seine","","France",26,0,1,0,0,['Artur','Heidrun']])
data_list.append([datetime.datetime(2010, 8, 8),"Grindelwald","Jungfrau-Aletsch","","Switzerland",242,0,0,1,0,[]])
data_list.append([datetime.datetime(2010, 8, 29),"Zermatt","Jungfrau-Aletsch","","Switzerland",3,0,0,1,0,[]])
data_list.append([datetime.datetime(2010, 9, 4),"Saas-Fee","Jungfrau-Aletsch","","Switzerland",16,0,0,1,0,[]])
data_list.append([datetime.datetime(2010, 11, 27),"Bern","Bern","","Switzerland",242,0,1,0,0,['Hannsjoerg']])
#2011
data_list.append([datetime.datetime(2011, 1, 23),"Milan","Santa Maria delle Grazie with The Last Supper","","Italy",3,0,1,0,0,['Hannsjoerg']])
data_list.append([datetime.datetime(2011, 4, 3),"Lauterbrunnen","Jungfrau-Aletsch","","Switzerland",108,0,0,1,0,[]])
data_list.append([datetime.datetime(2011, 4, 3),"Grindelwald","Jungfrau-Aletsch","","Switzerland",25,0,0,1,0,[]])
data_list.append([datetime.datetime(2011, 4, 3),"Fieschertal","Jungfrau-Aletsch","","Switzerland",90,0,0,1,0,[]])
data_list.append([datetime.datetime(2011, 5, 22),"Lyon","Lyon","","France",130,0,1,0,0,['Hannsjoerg',"Heidrun",'Artur']])
data_list.append([datetime.datetime(2011, 5, 29),"Grindelwald","Jungfrau-Aletsch","","Switzerland",198,0,0,1,0,['Hannsjoerg']])
data_list.append([datetime.datetime(2011, 5, 29),"Lauterbrunnen","Jungfrau-Aletsch","","Switzerland",87,0,0,1,0,['Hannsjoerg']])
data_list.append([datetime.datetime(2011, 7, 3),"Fiescher","Jungfrau-Aletsch","","Switzerland",75,0,0,1,0,['Hannsjoerg']])
data_list.append([datetime.datetime(2011, 7, 3),"Fieschertal","Jungfrau-Aletsch","","Switzerland",66,0,0,1,0,['Hannsjoerg']])
data_list.append([datetime.datetime(2011, 9, 29),"Wuerzburg","Wuerzburg Residence","","Germany",20,0,1,0,0,['Artur',"Heidrun"]])
data_list.append([datetime.datetime(2011, 9, 29),"Bamberg","Bamberg","","Germany",16,0,1,0,0,['Artur',"Heidrun"]])
data_list.append([datetime.datetime(2011, 9, 30),"Bamberg","Bamberg","","Germany",140,0,1,0,0,['Artur',"Heidrun"]])
data_list.append([datetime.datetime(2011, 10, 1),"Wuerzburg","Wuerzburg Residence","","Germany",25,0,1,0,0,['Artur',"Heidrun"]])
data_list.append([datetime.datetime(2011, 12, 27),"Vienna","Vienna","","Austria",60,0,1,0,0,['Artur',"Heidrun",'Hannsjoerg']])
data_list.append([datetime.datetime(2011, 12, 27),"Vienna","Gardens and Palace of Schoenbrunn","","Austria",41,0,1,0,0,['Artur',"Heidrun",'Hannsjoerg']])
data_list.append([datetime.datetime(2011, 12, 28),"Vienna","Vienna","","Austria",99,0,1,0,0,['Artur',"Heidrun",'Hannsjoerg']])
data_list.append([datetime.datetime(2011, 12, 29),"Vienna","Vienna","","Austria",166,0,1,0,0,['Artur',"Heidrun",'Hannsjoerg']])
data_list.append([datetime.datetime(2011, 12, 30),"Vienna","Vienna","","Austria",149,0,1,0,0,['Artur',"Heidrun",'Hannsjoerg']])
#2012 #Canon EOS 600D
data_list.append([datetime.datetime(2012, 5, 11),'Prague',"Prague","","Czech Republic",122,0,1,0,0,['Artur',"Heidrun"]])
data_list.append([datetime.datetime(2012, 5, 12),'Prague',"Prague","","Czech Republic",251,0,1,0,0,['Artur',"Heidrun"]])
data_list.append([datetime.datetime(2012, 5, 13),'Prague',"Prague","","Czech Republic",147,0,1,0,0,['Artur',"Heidrun"]])
data_list.append([datetime.datetime(2012, 5, 31),'Chenonceau',"Loire Valley between Sully-sur-Loire and Chalonnes","","France",64,0,1,0,0,['Artur',"Heidrun"]])
data_list.append([datetime.datetime(2012, 5, 31),'Blois',"Loire Valley between Sully-sur-Loire and Chalonnes","","France",5,0,1,0,0,['Artur',"Heidrun",'Hannsjoerg']])
data_list.append([datetime.datetime(2012, 6, 1),'Blois',"Loire Valley between Sully-sur-Loire and Chalonnes","","France",114,0,1,0,0,['Artur',"Heidrun",'Hannsjoerg']])
data_list.append([datetime.datetime(2012, 6, 1),'Amboise',"Loire Valley between Sully-sur-Loire and Chalonnes","","France",50,0,1,0,0,['Artur',"Heidrun",'Hannsjoerg']])
data_list.append([datetime.datetime(2012, 6, 1),'Chaumont-sur-Loire',"Loire Valley between Sully-sur-Loire and Chalonnes","","France",39,0,1,0,0,['Artur',"Heidrun",'Hannsjoerg']])
data_list.append([datetime.datetime(2012, 6, 2),'Chambord',"Loire Valley between Sully-sur-Loire and Chalonnes","","France",89,0,1,0,0,['Artur',"Heidrun",'Hannsjoerg']])
data_list.append([datetime.datetime(2012, 6, 2),'Orleans',"Loire Valley between Sully-sur-Loire and Chalonnes","","France",46,0,1,0,0,['Artur',"Heidrun",'Hannsjoerg']])
data_list.append([datetime.datetime(2012, 6, 3),'Vezelay',"Vezelay, Church and Hill","Routes of Santiago de Compostela in France","France",50,0,1,0,0,['Artur',"Heidrun",'Hannsjoerg']])
data_list.append([datetime.datetime(2012, 7, 24),"Switzerland","Jungfrau-Aletsch","","Switzerland",52,0,0,1,0,[]])
data_list.append([datetime.datetime(2012, 7, 26),'Potsdam',"Palaces and Parks of Potsdam and Berlin","","Germany",11,0,1,0,0,[]])
data_list.append([datetime.datetime(2012, 7, 27),'Berlin',"Palaces and Parks of Potsdam and Berlin","","Germany",67,0,1,0,0,[]])
data_list.append([datetime.datetime(2012, 7, 27),'Potsdam',"Palaces and Parks of Potsdam and Berlin","","Germany",75,0,1,0,0,[]])
data_list.append([datetime.datetime(2012, 7, 28),'Potsdam',"Palaces and Parks of Potsdam and Berlin","","Germany",107,0,1,0,0,['Gianrico']])
data_list.append([datetime.datetime(2012, 7, 9),"Berlin","Museumsinsel","","Germany",72,0,1,0,0,[]])
data_list.append([datetime.datetime(2012, 8, 18),"Lauterbrunnen","Jungfrau-Aletsch","","Switzerland",52,0,0,1,0,['Indara']])
data_list.append([datetime.datetime(2012, 8, 18),"Grindelwald","Jungfrau-Aletsch","","Switzerland",42,0,0,1,0,['Indara']])
data_list.append([datetime.datetime(2012, 8, 18),"Fieschertal","Jungfrau-Aletsch","","Switzerland",49,0,0,1,0,['Indara']])
data_list.append([datetime.datetime(2012, 8, 2),"Interlaken","Jungfrau-Aletsch","","Switzerland",52,0,0,1,0,['Indara','Brant','Jacob']])
data_list.append([datetime.datetime(2012, 8, 26),"Unteruhldingen","Prehistoric Pile Dwellings around the Alps","","Switzerland",14,0,1,0,0,['Artur',"Heidrun",'Hannsjoerg']])
data_list.append([datetime.datetime(2012, 8, 30),"Belem","Monastery of the Hieronymites and Tower of Belem","","Portugal",3,0,1,0,0,[]])
data_list.append([datetime.datetime(2012, 8, 31),"Mafra","Palace of Mafra","","Portugal",68,0,1,0,0,[]])
data_list.append([datetime.datetime(2012, 8, 31),"Sintra","Cultural Landscape of Sintra","","Portugal",117,0,1,0,0,[]])
data_list.append([datetime.datetime(2012, 9, 1),"Sintra","Cultural Landscape of Sintra","","Portugal",73,0,1,0,0,[]])
data_list.append([datetime.datetime(2012, 9, 2),"Belem","Monastery of the Hieronymites and Tower of Belem","","Portugal",27,0,1,0,0,['David Saltzberg']])
data_list.append([datetime.datetime(2012, 9, 6),"Tomar","Convent of Christ in Tomar","","Portugal",96,0,1,0,0,[]])
data_list.append([datetime.datetime(2012, 9, 8),"Porto","Historic Centre of Oporto, Luiz I Bridge and Monastery of Serra do Pilar","","Portugal",86,0,1,0,0,[]])
data_list.append([datetime.datetime(2012, 9, 6),"Coimbra","University of Coimbra – Alta and Sofia","","Portugal",89,0,1,0,0,[]])
data_list.append([datetime.datetime(2012, 9, 16),"Gutannen","Jungfrau-Aletsch","","Switzerland",25,0,0,1,0,[]])
data_list.append([datetime.datetime(2012, 9, 29),"Krakow","Krakow","","Poland",169,0,1,0,0,['Eric']])
data_list.append([datetime.datetime(2012, 9, 29),"Warsaw","Warsaw","","Poland",122,0,1,0,0,['Eric']])
#2013
data_list.append([datetime.datetime(2013, 1, 3),"Amsterdam","Seventeenth-Century Canal Ring Area","","Netherlands",41,0,1,0,0,[]])
data_list.append([datetime.datetime(2013, 1, 5),"Amsterdam","Seventeenth-Century Canal Ring Area","","Netherlands",18,0,1,0,0,[]])
data_list.append([datetime.datetime(2013, 1, 6),"Amsterdam","Seventeenth-Century Canal Ring Area","","Netherlands",12,0,1,0,0,[]])
data_list.append([datetime.datetime(2013, 3, 22),"Versailles","Palace and Park of Versailles","","France",190,0,1,0,0,['Andrew']])
data_list.append([datetime.datetime(2013, 3, 22),"Paris","Paris, Banks of the Seine","","France",86,0,1,0,0,['Andrew']])
data_list.append([datetime.datetime(2013, 3, 23),"Paris","Paris, Banks of the Seine","","France",145,0,1,0,0,['Andrew']])
data_list.append([datetime.datetime(2013, 3, 23),"Paris","Routes of Santiago de Compostela in France","","France",1,0,1,0,0,['Andrew']])
data_list.append([datetime.datetime(2013, 3, 24),"Fontainebleau","Palace and Park of Fontainebleau",'',"France",125,0,1,0,0,['Andrew']])
data_list.append([datetime.datetime(2013, 3, 24),"Paris","Paris, Banks of the Seine","","France",25,0,1,0,0,['Andrew']])
data_list.append([datetime.datetime(2013, 3, 25),"Paris","Paris, Banks of the Seine","","France",31,0,1,0,0,['Andrew']])
data_list.append([datetime.datetime(2013, 4, 3),"Rome","Rome","","Italy",77,0,1,0,0,['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 4),"Rome","Rome","","Italy",233,0,1,0,0,['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 4),"Rome","Vatican City","","Vatican",269,0,1,0,0,['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 5),"Rome","Rome","","Italy",40,0,1,0,0,['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 5),"Rome","Rome","","Vatican",185,0,1,0,0,['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 5),"Rome","Via Appia. Regina Viarum","","",68,0,1,0,0,['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 6),"Rome","Rome","","Italy",160,0,1,0,0,['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 6),"Rome","Rome","","Vatican",8,0,1,0,0,['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 7),"Rome","Rome","","Italy",90,0,1,0,0,['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 8),"Rome","Rome","","Italy",249,0,1,0,0,['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 9),"Tivoli", "Villa Adriana", "","Italy",66 ,0,1,0,0,['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 9),"Tivoli", "Villa d'Este", "","Italy",98 ,0,1,0,0,['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 9),"Rome","Rome","","Italy",69,0,1,0,0,['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 10),"Rome","Rome","","Italy",48,0,1,0,0,['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 11),"Rome","Rome","","Italy",66,0,1,0,0,['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 14),"Grandvaux","Lavaux","","Switzerland",13,0,1,0,0,['Hannsjoerg']])
data_list.append([datetime.datetime(2013, 5, 25),"Lyon","Lyon","","France",165,0,1,0,0,['Hannsjoerg','Artur','Heidrun']])
data_list.append([datetime.datetime(2013, 7, 7),"Milan","Santa Maria delle Grazie with The Last Supper","","Italy",5,0,1,0,0,['Andrew','Nick']])
data_list.append([datetime.datetime(2013, 7, 15),"Drottningholm","Royal Domain of Drottningholm","","Sweden",52,0,1,0,0,[]])
data_list.append([datetime.datetime(2013, 7, 15),"Helsingor","Kronborg","","Denmark",91,0,1,0,0,[]])
data_list.append([datetime.datetime(2013, 9, 5),"Venice","Venice and its Lagoon","","Italy",84,0,1,0,0,[]])
data_list.append([datetime.datetime(2013, 9, 6),"Venice","Venice and its Lagoon","","Italy",339,0,1,0,0,[]])
data_list.append([datetime.datetime(2013, 9, 7),"Venice","Venice and its Lagoon","","Italy",179,0,1,0,0,[]])
data_list.append([datetime.datetime(2013, 9, 8),"Venice","Venice and its Lagoon","","Italy",205,0,1,0,0,[]])
data_list.append([datetime.datetime(2013, 11, 8),"Compiegne","Routes of Santiago de Compostela in France","","France",6,0,1,0,0,['Eric','Chris Lee','Chris Clarke']])
data_list.append([datetime.datetime(2013, 11, 8),"Paris","Paris, Banks of the Seine","","France",59,0,1,0,0,['Eric','Chris Lee','Chris Clarke']])
data_list.append([datetime.datetime(2013, 11, 9),"Paris","Paris, Banks of the Seine","","France",23,0,1,0,0,['Eric']])
data_list.append([datetime.datetime(2013, 11, 10),"Paris","Paris, Banks of the Seine","","France",64,0,1,0,0,['Eric','Chris Lee','Chris Clarke']])
data_list.append([datetime.datetime(2013, 11, 10),"Paris","Routes of Santiago de Compostela in France","","France",2,0,1,0,0,['Eric','Chris Lee','Chris Clarke']])
data_list.append([datetime.datetime(2013, 12, 27),"Strassbourg", "Strassbourg", "","France",102 ,0,1,0,0,['Hannsjoerg','Artur','Heidrun']])
#2014
data_list.append([datetime.datetime(2014, 4, 19),"Steingaden","Wieskirche","","Germany",2,0,1,0,0,['Eric','Indara']])
data_list.append([datetime.datetime(2014, 8, 18),"Grindelwald","Jungfrau-Aletsch","","Switzerland",74,0,0,1,0,['Chris Martin']])
data_list.append([datetime.datetime(2014, 7, 24),"London", "Kew Gardens", "","United Kingdom",113 ,0,1,0,0,['Artur',"Heidrun",'Hannsjoerg','Anne-Kathrin']])
data_list.append([datetime.datetime(2014, 7, 29),"London", "Tower of London", "","United Kingdom",59 ,0,1,0,0,['Heidrun']])
data_list.append([datetime.datetime(2014, 7, 30),"Woodstock", "Blenheim Palace", "","United Kingdom",141 ,0,1,0,0,['Artur',"Heidrun",'Hannsjoerg']])
data_list.append([datetime.datetime(2014, 7, 31),"London", "Palace of Westminster and Westminster Abbey including Saint Margaret’s Church", "","United Kingdom",114 ,0,1,0,0,['Artur',"Heidrun",'Hannsjoerg']])
data_list.append([datetime.datetime(2014, 8, 1),"Canterbury", "Canterbury Cathedral, St Augustine's Abbey, and St Martin's Church", "","United Kingdom",90 ,0,1,0,0,['Artur',"Heidrun",'Hannsjoerg']])
data_list.append([datetime.datetime(2014, 8, 2),"Amesbury", "Stonehenge, Avebury and Associated Sites", "","United Kingdom",22 ,0,1,0,0,['Artur',"Heidrun",'Hannsjoerg']])
data_list.append([datetime.datetime(2014, 8, 2),"Bath", "Bath", "The Great Spa Towns of Europe","United Kingdom",73 ,73,1,0,0,['Artur',"Heidrun",'Hannsjoerg']])
data_list.append([datetime.datetime(2012, 8, 22),"Switzerland","Jungfrau-Aletsch","","Switzerland",7,0,0,1,0,[]])
data_list.append([datetime.datetime(2014, 8, 22),"Vienna","Vienna","","Austria",216,0,1,0,0,[]])
data_list.append([datetime.datetime(2014, 8, 23),"Neusiedl am See","Fertoe - Neusiedlersee Cultural Landscape","","Austria",1,0,1,0,0,[]])
data_list.append([datetime.datetime(2014, 8, 23),"Fertoed","Fertoe - Neusiedlersee Cultural Landscape","","Hungary",102,0,1,0,0,[]])
data_list.append([datetime.datetime(2014, 8, 23),"Vienna","Vienna","","Austria",21,0,1,0,0,[]])
data_list.append([datetime.datetime(2014, 8, 25),"Vienna","Vienna","","Austria",13,0,1,0,0,['Lessya','Viola','Dooyeon']])
data_list.append([datetime.datetime(2014, 8, 26),"Vienna","Vienna","","Austria",16,0,1,0,0,[]])
data_list.append([datetime.datetime(2014, 8, 27),"Vienna","Vienna","","Austria",66,0,1,0,0,[]])
data_list.append([datetime.datetime(2014, 8, 28),"Vienna","Gardens and Palace of Schoenbrunn","","Austria",151,0,1,0,0,[]])
data_list.append([datetime.datetime(2014, 8, 28),"Vienna","Vienna","","Austria",84,0,1,0,0,[]])
data_list.append([datetime.datetime(2014, 8, 29),"Vienna","Vienna","","Austria",149,0,1,0,0,[]])
data_list.append([datetime.datetime(2014, 8, 30),"Budapest","Budapest, including the Banks of the Danube, the Buda Castle Quarter and Andrassy Avenue","","Hungary",194,0,1,0,0,[]])
data_list.append([datetime.datetime(2014, 8, 31),"Budapest","Budapest, including the Banks of the Danube, the Buda Castle Quarter and Andrassy Avenue","","Hungary",132,0,1,0,0,[]])
data_list.append([datetime.datetime(2014, 9, 6),"Florence", "Florence", "Medici Villas and Gardens","Italy",245 ,221,1,0,0,[]])
data_list.append([datetime.datetime(2014, 9, 6),"Bologna", "Porticoes of Bologna", "","Italy",5,0,1,0,0,[]])
data_list.append([datetime.datetime(2014, 9, 7),"Pisa","Piazza del Duomo, Pisa","","Italy",104,0,1,0,0,[]])
data_list.append([datetime.datetime(2014, 9, 7),"Florence", "Florence", "","Italy",155 ,0,1,0,0,[]])
data_list.append([datetime.datetime(2014, 9, 8),"Bologna", "Porticoes of Bologna", "","Italy",8,0,1,0,0,[]])
data_list.append([datetime.datetime(2014, 9, 9),"Bologna", "Porticoes of Bologna", "","Italy",4,0,1,0,0,[]])
data_list.append([datetime.datetime(2014, 9, 10),"Bologna", "Porticoes of Bologna", "","Italy",91,0,1,0,0,[]])
data_list.append([datetime.datetime(2014, 9, 11),"Bologna", "Porticoes of Bologna", "","Italy",49,0,1,0,0,[]])
data_list.append([datetime.datetime(2014, 9, 12),"Florence", "Florence", "","Italy",187 ,0,1,0,0,[]])
data_list.append([datetime.datetime(2014, 9, 13),"Florence", "Florence", "","Italy",193 ,0,1,0,0,[]])
data_list.append([datetime.datetime(2014, 9, 13),"Siena", "Siena", "","Italy",151 ,0,1,0,0,[]])
data_list.append([datetime.datetime(2014, 9, 14),"Florence", "Medici Villas and Gardens","","Italy",88 ,0,1,0,0,[]])
data_list.append([datetime.datetime(2014, 9, 14),"Florence", "Florence", "","Italy",138 ,0,1,0,0,[]])
data_list.append([datetime.datetime(2014, 9, 21),"Paris","Paris, Banks of the Seine","","France",64,0,1,0,0,[]])
data_list.append([datetime.datetime(2014, 10, 24),"Istanbul","Istanbul","","Turkey",67,0,1,0,0,['Chris Martin']])
data_list.append([datetime.datetime(2014, 10, 25),"Istanbul","Istanbul","","Turkey",262,0,1,0,0,['Chris Martin']])
data_list.append([datetime.datetime(2014, 10, 26),"Istanbul","Istanbul","","Turkey",17,0,1,0,0,['Chris Martin']])
data_list.append([datetime.datetime(2014, 12, 13),"London", "Palace of Westminster and Westminster Abbey including Saint Margaret’s Church", "","United Kingdom",17 ,0,1,0,0,['Manuel']])
data_list.append([datetime.datetime(2014, 12, 13),"London", "Tower of London", "","United Kingdom",3 ,0,1,0,0,['Manuel']])
#2015
#???
data_list.append([datetime.datetime(2015, 3, 28),"Madrid", "Paseo del Prado and Buen Retiro", "","Spain",25 ,0,1,0,0,['Manuel']])
data_list.append([datetime.datetime(2015, 3, 29),"Sevilla", "Cathedral, Alcazar and Archivo de Indias in Seville", "","Spain",89 ,0,1,0,0,['Manuel']])
data_list.append([datetime.datetime(2015, 3, 30),"Granada", "Alhambra, Generalife and Albayzin", "","Spain",166 ,0,1,0,0,['Manuel']])
data_list.append([datetime.datetime(2015, 3, 31),"Cordoba", "Medina Azahara", "","Spain",43 ,0,1,0,0,['Manuel']])
data_list.append([datetime.datetime(2015, 3, 31),"Cordoba", "Cordoba", "","Spain",85 ,0,1,0,0,['Manuel']])
data_list.append([datetime.datetime(2015, 4, 1),"Segovia","Segovia","","Spain",118,0,1,0,0,['Manuel']])
data_list.append([datetime.datetime(2015, 4, 2),"Toledo","Toledo","","Spain",146,0,1,0,0,['Manuel']])
data_list.append([datetime.datetime(2015, 4, 3),"El Escorial","El Escorial Monastery","","Spain",54,0,1,0,0,['Manuel']])
data_list.append([datetime.datetime(2015, 4, 4),"Cordoba", "Cordoba", "","Spain",113 ,0,1,0,0,['Manuel']])
data_list.append([datetime.datetime(2015, 4, 4),"Sevilla", "Cathedral, Alcazar and Archivo de Indias in Seville", "","Spain",89 ,0,1,0,0,['Manuel']])
data_list.append([datetime.datetime(2015, 4, 5),"Aranjuez", "Aranjuez Cultural Landscape", "","Spain",66 ,0,1,0,0,['Eric']])
data_list.append([datetime.datetime(2015, 5, 15),"Pompei","Pompei, Herculaneum and Torre Annunziata","","Italy",85,0,1,0,0,['AJ','Stephan']])
data_list.append([datetime.datetime(2015, 5, 15),"Torre Annunziata","Pompei, Herculaneum and Torre Annunziata","","Italy",34,0,1,0,0,['AJ','Stephan']])
data_list.append([datetime.datetime(2015, 5, 15),"Naples","Naples","","Italy",54,0,1,0,0,['AJ','Stephan']])
data_list.append([datetime.datetime(2015, 5, 16),"Ercolano","Pompei, Herculaneum and Torre Annunziata","","Italy",31,0,1,0,0,['AJ','Stephan']])
data_list.append([datetime.datetime(2015, 5, 16),"Naples","Naples","","Italy",15,0,1,0,0,['AJ','Stephan']])
data_list.append([datetime.datetime(2015, 5, 17),"Caserta","Reggia di Caserta","","Italy",196,0,1,0,0,['AJ','Stephan']])
data_list.append([datetime.datetime(2015, 5, 17),"Naples","Naples","","Italy",79,0,1,0,0,['AJ','Stephan']])
data_list.append([datetime.datetime(2015, 5, 18),"Naples","Naples","","Italy",212,0,1,0,0,['AJ','Stephan']])
data_list.append([datetime.datetime(2015, 7, 18),"Versailles","Palace and Park of Versailles","","France",355,0,1,0,0,['Riju']])
data_list.append([datetime.datetime(2015, 7, 19),"Mont-Saint-Michel","Mont-Saint-Michel and its Bay","Routes of Santiago de Compostela in France","France",80,80,1,0,0,[]])
#????
data_list.append([datetime.datetime(2015, 8, 23),"Nizza", "Nice, capital of Riviera tourism","","France",40,0,1,0,0,[]])
data_list.append([datetime.datetime(2015, 8, 28),"Peterhof", "Petersburg and Related Groups of Monuments","","Russia",1,0,1,0,0,[]])
data_list.append([datetime.datetime(2015, 8, 28),"Strelna", "Petersburg and Related Groups of Monuments","","Russia",1,0,1,0,0,[]])
data_list.append([datetime.datetime(2015, 8, 28),"St Petersburg", "Petersburg and Related Groups of Monuments","","Russia",102,0,1,0,0,[]])
data_list.append([datetime.datetime(2015, 8, 29),"St Petersburg", "Petersburg and Related Groups of Monuments","","Russia",59,0,1,0,0,[]])
data_list.append([datetime.datetime(2015, 8, 29),"Lomonosow", "Petersburg and Related Groups of Monuments","","Russia",44,0,1,0,0,[]])
data_list.append([datetime.datetime(2015, 8, 30),"St Petersburg", "Petersburg and Related Groups of Monuments","","Russia",2,0,1,0,0,[]])
data_list.append([datetime.datetime(2015, 8, 30),"Pawlovsk", "Petersburg and Related Groups of Monuments","","Russia",81,0,1,0,0,[]])
data_list.append([datetime.datetime(2015, 8, 30),"Gatchina", "Petersburg and Related Groups of Monuments","","Russia",69,0,1,0,0,[]])
data_list.append([datetime.datetime(2015, 8, 31),"St Petersburg", "Petersburg and Related Groups of Monuments","","Russia",1,0,1,0,0,['Manuel']])
data_list.append([datetime.datetime(2015, 8, 31),"St Petersburg", "Petersburg and Related Groups of Monuments","","Russia",2,0,1,0,0,['Manuel']])
data_list.append([datetime.datetime(2015, 9, 2),"Moscow", "Kremlin and Red Square","","Russia",133,0,1,0,0,['Manuel']])
data_list.append([datetime.datetime(2015, 9, 3),"St Petersburg", "Petersburg and Related Groups of Monuments","","Russia",7,0,1,0,0,[]])
data_list.append([datetime.datetime(2015, 9, 3),"Peterhof", "Petersburg and Related Groups of Monuments","","Russia",96,0,1,0,0,[]])
data_list.append([datetime.datetime(2015, 9, 4),"St Petersburg", "Petersburg and Related Groups of Monuments","","Russia",11,0,1,0,0,['Manuel','Nathan','Hannah']])
data_list.append([datetime.datetime(2015, 9, 5),"St Petersburg", "Petersburg and Related Groups of Monuments","","Russia",32,0,1,0,0,['Manuel','Nathan','Hannah']])
data_list.append([datetime.datetime(2015, 9, 6),"St Petersburg", "Petersburg and Related Groups of Monuments","","Russia",21,0,1,0,0,['Manuel','Nathan','Hannah']])
data_list.append([datetime.datetime(2015, 9, 6),"Puschkin", "Petersburg and Related Groups of Monuments","","Russia",259,0,1,0,0,['Manuel']])
data_list.append([datetime.datetime(2015, 9, 7),"St Petersburg", "Petersburg and Related Groups of Monuments","","Russia",94,0,1,0,0,['Manuel']])
data_list.append([datetime.datetime(2015, 9, 8),"St Petersburg", "Petersburg and Related Groups of Monuments","","Russia",200,0,1,0,0,['Manuel']])
data_list.append([datetime.datetime(2015, 9, 9),"St Petersburg", "Petersburg and Related Groups of Monuments","","Russia",129,0,1,0,0,[]])
data_list.append([datetime.datetime(2015, 9, 10),"Peterhof", "Petersburg and Related Groups of Monuments","","Russia",162,0,1,0,0,[]])
data_list.append([datetime.datetime(2015, 9, 9),"Strelna", "Petersburg and Related Groups of Monuments","","Russia",44,0,1,0,0,[]])
data_list.append([datetime.datetime(2015, 9, 19),"Paris","Paris, Banks of the Seine","","France",131,0,1,0,0,[]])
data_list.append([datetime.datetime(2015, 9, 20),"Paris","Paris, Banks of the Seine","","France",27,0,1,0,0,[]])
data_list.append([datetime.datetime(2015, 9, 20),"Paris","Routes of Santiago de Compostela in France","","France",1,0,1,0,0,[]])
data_list.append([datetime.datetime(2015, 10, 8),"Melk","Wachau Cultural Landscape","","Austria",70,0,1,0,0,['Eric','Siyi']])
data_list.append([datetime.datetime(2015, 10, 8),"Furth bei Goettweig","Wachau Cultural Landscape","","Austria",56,0,1,0,0,['Eric','Siyi']])
data_list.append([datetime.datetime(2015, 10, 9),"Salzburg","Salzburg","","Austria",97,0,1,0,0,['Eric','Siyi']])
data_list.append([datetime.datetime(2015, 11, 8),'Potsdam',"Palaces and Parks of Potsdam and Berlin","","Germany",143,0,1,0,0,['Heidrun','Artur']])
data_list.append([datetime.datetime(2015, 11, 8),'Hamburg',"Speicherstadt","","Germany",3,0,1,0,0,['Heidrun','Artur','Anne-Kathrin']])
data_list.append([datetime.datetime(2015, 11, 10),'Berlin',"Museumsinsel","","Germany",2,0,1,0,0,['Heidrun','Artur','Anne-Kathrin']])
data_list.append([datetime.datetime(2015, 11, 11),'Luebeck',"Luebeck","","Germany",62,0,1,0,0,[]])
data_list.append([datetime.datetime(2015, 11, 11),'Schwerin',"Schwerin Residence Ensemble","","Germany",86,0,1,0,0,[]])
data_list.append([datetime.datetime(2015, 11, 13),'Weimar',"Classical Weimar","","Germany",94,0,1,0,0,[]])
#2016
#until here flight jungfrau done
data_list.append([datetime.datetime(2016, 3, 16),"Catania","Mount Etna","","Italy",2,0,0,1,0,['Artur','Heidrun']])
data_list.append([datetime.datetime(2016, 3, 17),"Piazza Armeria","Villa Romana del Casale","","Italy",55,0,1,0,0,['Artur','Heidrun']])
data_list.append([datetime.datetime(2016, 3, 17),"Cefalu","Arab-Norman Palermo and the Cathedral Churches of Cefalu and Monreale","","Italy",32,0,1,0,0,['Artur','Heidrun']])
data_list.append([datetime.datetime(2016, 3, 17),"Monreale","Arab-Norman Palermo and the Cathedral Churches of Cefalu and Monreale","","Italy",122,0,1,0,0,['Artur','Heidrun']])
data_list.append([datetime.datetime(2016, 3, 17),"Palermo","Arab-Norman Palermo and the Cathedral Churches of Cefalu and Monreale","","Italy",5,0,1,0,0,['Artur','Heidrun']])
data_list.append([datetime.datetime(2016, 3, 18),"Palermo","Arab-Norman Palermo and the Cathedral Churches of Cefalu and Monreale","","Italy",227,0,1,0,0,['Artur','Heidrun']])
data_list.append([datetime.datetime(2016, 3, 21),"Agrigento","Archaeological Area of Agrigento","","Italy",128,0,1,0,0,['Artur','Heidrun']])
data_list.append([datetime.datetime(2016, 3, 22),"Noto","Late Baroque Towns of the Val di Noto","","Italy",91,0,1,0,0,['Artur','Heidrun']])
data_list.append([datetime.datetime(2016, 3, 22),"Syracuse","Syracuse and the Rocky Necropolis of Pantalica","","Italy",18,0,1,0,0,['Artur','Heidrun']])
data_list.append([datetime.datetime(2016, 3, 23),"Syracuse","Syracuse and the Rocky Necropolis of Pantalica","","Italy",80,0,1,0,0,['Artur','Heidrun']])
data_list.append([datetime.datetime(2016, 3, 23),"Catania","Late Baroque Towns of the Val di Noto","","Italy",66,0,1,0,0,['Artur','Heidrun']])
data_list.append([datetime.datetime(2016, 3, 24),"Nicolisi","Mount Etna","",'Italy',77,0,0,1,0,['Artur','Heidrun']])
data_list.append([datetime.datetime(2016, 3, 24),"Catania","Late Baroque Towns of the Val di Noto","","Italy",26,0,1,0,0,['Artur']])
data_list.append([datetime.datetime(2016, 3, 25),"Catania","Late Baroque Towns of the Val di Noto","","Italy",39,0,1,0,0,['Artur']])
data_list.append([datetime.datetime(2016, 3, 26),"Barcelona","Works of Antoni Gaudi","","Spain",152,0,1,0,0,['Riju']])
data_list.append([datetime.datetime(2016, 3, 27),"Barcelona","Palau de la Musica Catalana and Hospital de Sant Pau","","Spain",40,0,1,0,0,['Riju']])
data_list.append([datetime.datetime(2016, 3, 27),"Barcelona","Works of Antoni Gaudi","","Spain",54,0,1,0,0,['Riju']])
data_list.append([datetime.datetime(2016, 3, 28),"Zaragoza","Mudejar Architecture of Aragon","","Spain",91,0,1,0,0,['Riju']])
data_list.append([datetime.datetime(2016, 3, 29),"Barcelona","Works of Antoni Gaudi","","Spain",68,0,1,0,0,['Riju']])
data_list.append([datetime.datetime(2016, 3, 29),"Barcelona","Palau de la Musica Catalana and Hospital de Sant Pau","","Spain",54,0,1,0,0,['Riju']])
data_list.append([datetime.datetime(2016, 5, 5),"Venaria Reale","Residences of the Royal House of Savoy","","Italy",120,0,1,0,0,[]])
data_list.append([datetime.datetime(2016, 5, 5),"Torino","Residences of the Royal House of Savoy","","Italy",160,0,1,0,0,[]])
data_list.append([datetime.datetime(2016, 5, 6),"Racconigi","Residences of the Royal House of Savoy","","Italy",63,0,1,0,0,[]])
data_list.append([datetime.datetime(2016, 5, 6),"Aglie","Residences of the Royal House of Savoy","","Italy",74,0,1,0,0,[]])
data_list.append([datetime.datetime(2016, 5, 7),"Torino","Residences of the Royal House of Savoy","","Italy",130,0,1,0,0,[]])
data_list.append([datetime.datetime(2016, 5, 7),"Nichelino","Residences of the Royal House of Savoy","","Italy",80,0,1,0,0,[]])
data_list.append([datetime.datetime(2016, 5, 8),"Torino","Residences of the Royal House of Savoy","","Italy",1,0,1,0,0,[]])
data_list.append([datetime.datetime(2016, 5, 8),"Torino","Residences of the Royal House of Savoy","","Italy",1,0,1,0,0,[]])
data_list.append([datetime.datetime(2016, 5, 14),"Genoa","Genoa: Le Strade Nuove and the system of the Palazzi dei Rolli","","Italy",176,0,1,0,0,['Amin']])
data_list.append([datetime.datetime(2016, 5, 15),"Genoa","Genoa: Le Strade Nuove and the system of the Palazzi dei Rolli","","Italy",113,0,1,0,0,['Amin']])
data_list.append([datetime.datetime(2016, 5, 16),"Riomaggiore","Cinque Terre","","Italy",25,0,1,0,0,['Amin']])
data_list.append([datetime.datetime(2016, 5, 16),"Manarola","Cinque Terre","","Italy",23,0,1,0,0,['Amin']])
data_list.append([datetime.datetime(2016, 5, 16),"Corniglia","Cinque Terre","","Italy",14,0,1,0,0,['Amin']])
data_list.append([datetime.datetime(2016, 5, 16),"Monterosso al Mare","Cinque Terre","","Italy",32,0,1,0,0,['Amin']])
data_list.append([datetime.datetime(2016, 5, 16),"Vernazza","Cinque Terre","","Italy",11,0,1,0,0,['Amin']])
data_list.append([datetime.datetime(2016, 5, 29),"Punte Viesgo","Cave of Altamira and Paleolithic Cave Art of Northern Spain","","Spain",15,0,1,0,0,[]])
data_list.append([datetime.datetime(2016, 5, 30),"Burgos","Routes of Santiago de Compostela: Camino Frances and Routes of Northern Spain","","Spain",36,0,1,0,0,[]])
data_list.append([datetime.datetime(2016, 5, 30),"Burgos","Burgos Cathedral","Routes of Santiago de Compostela: Camino Frances and Routes of Northern Spain","Spain",161,161,1,0,0,[]])
data_list.append([datetime.datetime(2016, 6, 3),"Bilbao","Routes of Santiago de Compostela: Camino Frances and Routes of Northern Spain","","Spain",36,0,1,0,0,[]])
data_list.append([datetime.datetime(2016, 6, 11),"Lauterbrunnen","Jungfrau-Aletsch","","Switzerland",3,0,0,1,0,['Andrew']])
data_list.append([datetime.datetime(2016, 6, 11),"Stechelberg","Jungfrau-Aletsch","","Switzerland",34,0,0,1,0,['Andrew']])
data_list.append([datetime.datetime(2016, 6, 11),"Bern","Bern","","Switzerland",40,0,1,0,0,['Andrew']])
data_list.append([datetime.datetime(2016, 6, 25),"Ravenna","Early Christian Monuments of Ravenna","","Italy",114,0,1,0,0,['Keyvan']])
data_list.append([datetime.datetime(2016, 6, 25),"Classe","Early Christian Monuments of Ravenna","","Italy",19,0,1,0,0,['']])
#???
data_list.append([datetime.datetime(2016, 6, 26),"Padua","Padova Urbs picta","","Italy",160,0,1,0,0,[]])
data_list.append([datetime.datetime(2016, 6, 26),"Padua","Orto Botanico of Padua","","Italy",1,0,1,0,0,[]])
data_list.append([datetime.datetime(2016, 7, 1),"Bordeaux","Bordeaux, Port of the Moon",'',"France",22,0,1,0,0,['Artur','Heidrun','Anne-Kathrin']])
data_list.append([datetime.datetime(2016, 7, 2),"Bordeaux","Bordeaux, Port of the Moon","Routes of Santiago de Compostela in France","France",102,45,1,0,0,['Artur','Heidrun','Anne-Kathrin']])
data_list.append([datetime.datetime(2016, 7, 17),"Riederalp","Jungfrau-Aletsch","","Switzerland",21,0,0,1,0,['Artur, Heidrun']])
data_list.append([datetime.datetime(2016, 7, 17),"Fiesch","Jungfrau-Aletsch","","Switzerland",27,0,0,1,0,['Artur, Heidrun']])
data_list.append([datetime.datetime(2016, 7, 17),"Fieschertal","Jungfrau-Aletsch","","Switzerland",27,0,0,1,0,['Artur, Heidrun']])
data_list.append([datetime.datetime(2016, 7, 22),"Brussels","Grand-Place, Brussels","","Belgium",8,0,1,0,0,[]])
data_list.append([datetime.datetime(2016, 7, 23),"Brussels","Grand-Place, Brussels","","Belgium",26,0,1,0,0,[]])
data_list.append([datetime.datetime(2016, 7, 23),"Brussels","Stoclet House","","Belgium",3,0,1,0,0,[]])
data_list.append([datetime.datetime(2016, 7, 23),"Aachen","Aachen Cathedral","","Germany",36,0,1,0,0,[]])
data_list.append([datetime.datetime(2016, 7, 24),"Brussels","Grand-Place, Brussels","","Belgium",16,0,1,0,0,[]])
data_list.append([datetime.datetime(2016, 7, 22),"Brussels","Major Town Houses of the Architect Victor Horta","","Belgium",2,0,1,0,0,[]])
data_list.append([datetime.datetime(2016, 8, 16),"Grand Canyon Village", "Grand Canyon National Park","","USA",184,0,0,1,0,['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2016, 8, 17),"Grand Canyon Village", "Grand Canyon National Park","","USA",88,0,0,1,0,['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2016, 8, 18),"Grand Canyon Village", "Grand Canyon National Park","","USA",17,0,0,1,0,['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2016, 8, 19),"Cortez", "Mesa Verde National Park","","USA",33,0,1,0,0,['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2016, 8, 20),"Cortez", "Mesa Verde National Park","","USA",67,0,1,0,0,['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2016, 10, 8),"Santiago de Compostela","Santiago de Compostela (Old Town)","Routes of Santiago de Compostela: Camino Frances and Routes of Northern Spain","Spain",137,137,1,0,0,[]])
data_list.append([datetime.datetime(2016, 10, 14),"Cologne","Cologne Cathedral","","Germany",15,0,1,0,0,[]])
data_list.append([datetime.datetime(2016, 10, 15),"Cologne","Cologne Cathedral","","Germany",107,0,1,0,0,[]])
data_list.append([datetime.datetime(2016, 10, 15),"Cologne","Cologne Cathedral","","Germany",11,0,1,0,0,[]])
data_list.append([datetime.datetime(2016, 10, 15),"Bruehl","Castles of Augustusburg and Falkenlust at Bruehl","","Germany",49,0,1,0,0,[]])
data_list.append([datetime.datetime(2016, 11, 26),"Milan","Santa Maria delle Grazie with The Last Supper","","Italy",32,0,1,0,0,['Riju']])
data_list.append([datetime.datetime(2016, 11, 26),"Mantua","Mantua and Sabbioneta","","Italy",122,0,1,0,0,['Riju']])
data_list.append([datetime.datetime(2016, 11, 27),"Mantua","Mantua and Sabbioneta","","Italy",140,0,1,0,0,['Riju']])
data_list.append([datetime.datetime(2016, 11, 27),"Verona","Verona","","Italy",102,0,1,0,0,['Riju']])
data_list.append([datetime.datetime(2016, 12, 8),"Hiraizumi","Hiraizumi – Temples, Gardens and Archaeological Sites Representing the Buddhist Pure Land","","Japan",45,0,1,0,0,[]])
data_list.append([datetime.datetime(2016, 12, 10),"Japan","Fujisan, sacred place and source of artistic inspiration","","Japan",1,1,0,0,0,[]])
data_list.append([datetime.datetime(2016, 12, 10),"Nikko","Shrines and Temples of Nikko","","Japan",142,0,1,0,0,[]])
data_list.append([datetime.datetime(2016, 12, 11),"Kyoto","Historic Monuments of Ancient Kyoto (Kyoto, Uji and Otsu Cities)","","Japan",71,0,1,0,0,[]])
data_list.append([datetime.datetime(2016, 12, 12),"Kyoto","Historic Monuments of Ancient Kyoto (Kyoto, Uji and Otsu Cities)","","Japan",167,0,1,0,0,[]])
data_list.append([datetime.datetime(2016, 12, 13),"Nara","Historic Monuments of Ancient Nara","","Japan",74,0,1,0,0,[]])
data_list.append([datetime.datetime(2016, 12, 13),"Ikagara","Buddhist Monuments in the Horyu-ji Area","","Japan",20,0,1,0,0,[]])
data_list.append([datetime.datetime(2016, 12, 14),"Hiroshima","Hiroshima Peace Memorial (Genbaku Dome)","","Japan",16,0,1,0,0,[]])
data_list.append([datetime.datetime(2016, 12, 14),"Himeji","Himeji-jo","","Japan",95,0,1,0,0,[]])
data_list.append([datetime.datetime(2016, 12, 15),"Hatsukaichi","Itsukushima Shinto Shrine","","Japan",48,0,1,0,0,[]])
data_list.append([datetime.datetime(2016, 12, 16),"Uji","Historic Monuments of Ancient Kyoto (Kyoto, Uji and Otsu Cities)","","Japan",15,0,1,0,0,[]])
data_list.append([datetime.datetime(2016, 12, 16),"Kyoto","Historic Monuments of Ancient Kyoto (Kyoto, Uji and Otsu Cities)","","Japan",14,0,1,0,0,[]])
data_list.append([datetime.datetime(2016, 12, 16),"Tokyo","Corbusier","","Japan",17,0,1,0,0,[]])
data_list.append([datetime.datetime(2016, 12, 17),"Japan","Fujisan, sacred place and source of artistic inspiration","","Japan",6,1,0,0,0,[]])
#2017
data_list.append([datetime.datetime(2017, 1, 4),"Bushmills", "Giant's Causeway and Causeway Coast", "","United Kingdom",56 ,0,0,1,0,['Chris Martin']])
data_list.append([datetime.datetime(2017, 1, 14),"Carcassonne", "Canal du Midi", "","France",5 ,0,1,0,0,[]])
data_list.append([datetime.datetime(2017, 1, 14),"Carcassonne", "Cite de Carcassonne", "","France",101 ,0,1,0,0,[]])
data_list.append([datetime.datetime(2017, 1, 14),"Avignon", "Papal Palace, Episcopal Ensemble and Avignon Bridge", "","France",11 ,0,1,0,0,[]])
data_list.append([datetime.datetime(2017, 1, 15),"Avignon", "Papal Palace, Episcopal Ensemble and Avignon Bridge", "","France",167 ,0,1,0,0,[]])
data_list.append([datetime.datetime(2017, 2, 11),"Brussels","Grand-Place, Brussels","","Belgium",3,0,1,0,0,['Riju']])
data_list.append([datetime.datetime(2017, 2, 11),"Bruges","Bruges","Belfries of Belgium and France","Belgium",94,5,1,0,0,[]])
data_list.append([datetime.datetime(2017, 2, 11),"Ghent","Belfries of Belgium and France","","Belgium",6,0,1,0,0,['Riju']])
data_list.append([datetime.datetime(2017, 2, 12),"Ghent","Belfries of Belgium and France","","Belgium",2,0,1,0,0,['Riju']])
data_list.append([datetime.datetime(2017, 2, 12),"Antwerp","Belfries of Belgium and France","","Belgium",71,0,1,0,0,['Riju']])
data_list.append([datetime.datetime(2017, 3, 25),"Assisi","Assisi","","Italy",193,0,1,0,0,[]])
data_list.append([datetime.datetime(2017, 3, 26),"Assisi","Assisi","","Italy",15,0,1,0,0,[]])
data_list.append([datetime.datetime(2017, 3, 26),"Florence","Florence","","Italy",5,0,1,0,0,[]])
data_list.append([datetime.datetime(2017, 4, 15),"Kiev","Saint-Sophia Cathedral and Kyiv-Pechersk Lavra","","Ukraine",137,0,1,0,0,[]])
data_list.append([datetime.datetime(2017, 4, 30),"Speyer","Speyer Cathedral","","Germany",73,0,1,0,0,[]])
data_list.append([datetime.datetime(2017, 5, 1),"Kassel","Bergpark Wilhelmshoehe","","Germany",164,0,1,0,0,[]])
data_list.append([datetime.datetime(2017, 5, 25),"Salamanca","Salamanca","","Spain",259,0,1,0,0,[]])
data_list.append([datetime.datetime(2017, 5, 26),"Valencia","Llotja de la Seda","","Spain",23,0,1,0,0,[]])
data_list.append([datetime.datetime(2017, 5, 27),"Leon","Routes of Santiago de Compostela: Camino Frances and Routes of Northern Spain","","Spain",111,0,1,0,0,[]])
data_list.append([datetime.datetime(2017, 5, 27),"Oviedo","Monuments of Oviedo and the Kingdom of the Asturias","Routes of Santiago de Compostela: Camino Frances and Routes of Northern Spain","Spain",25,19,1,0,0,[]])
data_list.append([datetime.datetime(2017, 5, 27),"Oviedo","Routes of Santiago de Compostela: Camino Frances and Routes of Northern Spain","","Spain",73,0,1,0,0,[]])
data_list.append([datetime.datetime(2017, 5, 28),"Avila","Old Town of Avila with its Extra-Muros Churches","","Spain",170,0,1,0,0,[]])
data_list.append([datetime.datetime(2017, 6, 3),"Athens","Athens Acropolis","","Greece",16,0,1,0,0,['Riju','Amin','MaryAnn']])
data_list.append([datetime.datetime(2017, 6, 4),"Athens","Athens Acropolis","","Greece",50,0,1,0,0,['Riju','Amin','MaryAnn']])
data_list.append([datetime.datetime(2017, 6, 5),"Delphi","Delphi","","Greece",76,0,1,0,0,['Riju','Amin']])
data_list.append([datetime.datetime(2017, 6, 6),"Athens","Athens Acropolis","","Greece",1,0,1,0,0,['Riju','Amin','MaryAnn']])
data_list.append([datetime.datetime(2017, 6, 9),"Iceland","Vatnajoekuell","","Iceland",1,0,0,1,0,[]])
data_list.append([datetime.datetime(2017, 6, 9),"USA","Yellowstone National Park","","USA",3,0,0,1,0,['Artur','Heidrun','Hannsjoerg']])
data_list.append([datetime.datetime(2017, 6, 12),"West Yellowstone","Yellowstone National Park","","USA",42,0,0,1,0,['Artur','Heidrun','Hannsjoerg']])
data_list.append([datetime.datetime(2017, 6, 13),"Madison","Yellowstone National Park","","USA",13,0,0,1,0,['Artur','Heidrun','Hannsjoerg']])
data_list.append([datetime.datetime(2017, 6, 13),"Norris","Yellowstone National Park","","USA",35,0,0,1,0,['Artur','Heidrun','Hannsjoerg']])
data_list.append([datetime.datetime(2017, 6, 13),"Gardiner","Yellowstone National Park","","USA",71,0,0,1,0,['Artur','Heidrun','Hannsjoerg']])
data_list.append([datetime.datetime(2017, 6, 14),"West Yellowstone","Yellowstone National Park","","USA",8,0,0,1,0,['Artur','Heidrun','Hannsjoerg']])
data_list.append([datetime.datetime(2017, 6, 14),"Norris","Yellowstone National Park","","USA",1,0,0,1,0,['Artur','Heidrun','Hannsjoerg']])
data_list.append([datetime.datetime(2017, 6, 14),"Canyon Village","Yellowstone National Park","","USA",81,0,0,1,0,['Artur','Heidrun','Hannsjoerg']])
data_list.append([datetime.datetime(2017, 6, 14),"Roosevelt","Yellowstone National Park","","USA",18,0,0,1,0,['Artur','Heidrun','Hannsjoerg']])
data_list.append([datetime.datetime(2017, 6, 14),"West Yellowstone","Yellowstone National Park","","USA",3,0,0,1,0,['Artur','Heidrun','Hannsjoerg']])
data_list.append([datetime.datetime(2017, 6, 15),"Lake Village","Yellowstone National Park","","USA",55,0,0,1,0,['Artur','Heidrun','Hannsjoerg']])
data_list.append([datetime.datetime(2017, 6, 15),"Grant Village","Yellowstone National Park","","USA",31,0,0,1,0,['Artur','Heidrun','Hannsjoerg']])
data_list.append([datetime.datetime(2017, 6, 15),"West Yellowstone","Yellowstone National Park","","USA",50,0,0,1,0,['Artur','Heidrun','Hannsjoerg']])
data_list.append([datetime.datetime(2017, 7, 6),"Venice","Venice and its Lagoon","","Italy",33,0,1,0,0,['Indara','Mia']])
data_list.append([datetime.datetime(2017, 7, 7),"Venice","Venice and its Lagoon","","Italy",8,0,1,0,0,[]])
data_list.append([datetime.datetime(2017, 7, 8),"Venice","Venice and its Lagoon","","Italy",222,0,1,0,0,['Indara','Reyer','Riju']])
data_list.append([datetime.datetime(2017, 7, 9),"Venice","Venice and its Lagoon","","Italy",38,0,1,0,0,[]])
data_list.append([datetime.datetime(2017, 7, 10),"Venice","Venice and its Lagoon","","Italy",217,0,1,0,0,['Indara','Katy','Riju','Reyer']])
data_list.append([datetime.datetime(2017, 7, 11),"Venice","Venice and its Lagoon","","Italy",21,0,1,0,0,['Indara','Mia','Rachel Bartek','Didar','Riju','Reyer']])
data_list.append([datetime.datetime(2017, 7, 12),"Vicenza","City of Vicenza and the Palladian Villas of the Veneto","","Italy",141,0,1,0,0,[]])
data_list.append([datetime.datetime(2017, 7, 13),"Ferrara","Ferrara, City of the Renaissance, and its Po Delta","","Italy",176,0,1,0,0,[]])
data_list.append([datetime.datetime(2017, 7, 13),"Padua","Orto Botanico of Padua","","Italy",24,0,1,0,0,[]])
#???
data_list.append([datetime.datetime(2016, 7, 14),"Padua","Padova Urbs picta","","Italy",37,0,1,0,0,[]])
data_list.append([datetime.datetime(2017, 7, 14),"Skocjan","Skocjan Caves","","Slovenia",83,0,0,1,0,['Reyer']])
data_list.append([datetime.datetime(2017, 7, 14),"Porec","Euphrasien Basilica","","Croatia",61,0,1,0,0,['Reyer']])
data_list.append([datetime.datetime(2017, 7, 15),"Aquileia","Archaeological Area and the Patriarchal Basilica of Aquileia","","Italy",42,0,1,0,0,['Reyer']])
data_list.append([datetime.datetime(2017, 7, 15),"Cividale del Friuli","Longobards in Italy","","Italy",48,0,1,0,0,['Reyer']])
data_list.append([datetime.datetime(2017, 8, 27),"Trogir","Trogir","","Croatia",61,0,1,0,0,[]])
data_list.append([datetime.datetime(2017, 8, 27),"Split","Historical Complex of Split with the Palace of Diocletian","","Croatia",195,0,1,0,0,[]])
data_list.append([datetime.datetime(2017, 9, 6),"Rome","Rome","","Italy",23,0,1,0,0,['Riju']])
data_list.append([datetime.datetime(2017, 9, 6),"Rome","Rome","","Vatican",1,0,1,0,0,['Riju']])
data_list.append([datetime.datetime(2017, 9, 7),"Rome","Rome","","Italy",171,0,1,0,0,['Riju']])
data_list.append([datetime.datetime(2017, 9, 7),"Rome","Vatican City","","Vatican",286,0,1,0,0,['Riju']])
data_list.append([datetime.datetime(2017, 9, 8),"Rome","Rome","","Italy",376,0,1,0,0,['Riju','Amin']])
data_list.append([datetime.datetime(2017, 9, 8),"Rome","Rome","","Vatican",119,0,1,0,0,['Riju','Amin']])
data_list.append([datetime.datetime(2017, 9, 9),"Rome","Rome","","Italy",346,0,1,0,0,['Riju','Amin']])
data_list.append([datetime.datetime(2017, 9, 9),"Rome","Rome","","Vatican",1,0,1,0,0,['Riju','Amin']])
data_list.append([datetime.datetime(2017, 9, 9),"Rome","Vatican City","","Vatican",10,0,1,0,0,['Riju','Amin']])
data_list.append([datetime.datetime(2017, 9, 10),"Rome","Rome","","Italy",233,0,1,0,0,['Riju','Amin']])
data_list.append([datetime.datetime(2017, 9, 16),"London","Palace of Westminster and Westminster Abbey including Saint Margaret’s Church","","United Kingdom",111,0,1,0,0,['Riju']])
data_list.append([datetime.datetime(2017, 9, 17),"London","Tower of London","","United Kingdom",9,0,1,0,0,['Riju']])
data_list.append([datetime.datetime(2017, 9, 30),"Graz","Graz","","Austria",149,0,1,0,0,[]])
data_list.append([datetime.datetime(2017, 10, 1),"Graz","Graz","","Austria",62,0,1,0,0,[]])
data_list.append([datetime.datetime(2017, 10, 6),"Tallinn","Tallinn","","Estonia",23,0,1,0,0,['Riju','Reyer','Rachel']])
data_list.append([datetime.datetime(2017, 10, 7),"Tallinn","Tallinn","","Estonia",3,0,1,0,0,['Riju','Reyer','Rachel']])
data_list.append([datetime.datetime(2017, 10, 7),"Helsinki","Suomenlinna","","Finland",37,0,1,0,0,['Riju','Reyer','Rachel']])
data_list.append([datetime.datetime(2017, 10, 8),"Tallinn","Tallinn","","Estonia",86,0,1,0,0,['Riju','Reyer','Rachel']])
data_list.append([datetime.datetime(2017, 11, 4),"St Gallen","Abbey of St Gall","","Switzerland",71,0,1,0,0,[]]) 
data_list.append([datetime.datetime(2017, 11, 4),"Reichenau","Reichenau","","Germany",48,0,1,0,0,[]]) 
data_list.append([datetime.datetime(2017, 11, 10),"Marrakesh","Marrakesh","","Morocco",136,0,1,0,0,['Riju','Tony','Cameron']]) 
data_list.append([datetime.datetime(2017, 11, 11),"Marrakesh","Marrakesh","","Morocco",136,0,1,0,0,['Riju','Tony','Cameron']])
data_list.append([datetime.datetime(2017, 11, 11),"Ait-Ben-Haddou","Ait-Ben-Haddou","","Morocco",40,0,1,0,0,['Riju','Tony','Cameron']])
data_list.append([datetime.datetime(2017, 11, 12),"Marrakesh","Marrakesh","","Morocco",129,0,1,0,0,['Riju','Tony','Cameron']])
data_list.append([datetime.datetime(2017, 11, 13),"Marrakesh","Marrakesh","","Morocco",9,0,1,0,0,['Riju','Tony','Cameron']])
data_list.append([datetime.datetime(2017, 11, 19),"Marmagne","Fontenay Abbey","","France",50,0,1,0,0,['Andrew']])
data_list.append([datetime.datetime(2017, 11, 19),"Arc-et-Senans","From the Great Saltworks of Salins-les-Bains to the Royal Saltworks of Arc-et-Senans, the Production of Open-pan Salt","","France",12,0,1,0,0,['Andrew']])
data_list.append([datetime.datetime(2017, 11, 19),"Besancon","Fortifications of Vauban","","France",12,0,1,0,0,['Andrew']])
data_list.append([datetime.datetime(2017, 12, 9),"Lyon","Lyon","","France",42,0,1,0,0,['Riju','Tony','Cameron','Rachel','Paul','Juliana']])
#2018
data_list.append([datetime.datetime(2018, 1, 2),"Suzhou", "The Grand Canal", "","China",1 ,0,1,0,0,[]])
data_list.append([datetime.datetime(2018, 1, 2),"Hangzhou", "West Lake of Hangzhou", "","China",148 ,0,1,0,0,[]])
data_list.append([datetime.datetime(2018, 1, 3),"Suzhou", "Classical Gardens of Suzhou", "","China",116 ,0,1,0,0,[]])
data_list.append([datetime.datetime(2018, 1, 5),"Nanjing", "Imperial Tombs of the Ming and Qing Dynasties", "","China",52 ,0,1,0,0,['Siyi','Zhicheng']])
data_list.append([datetime.datetime(2018, 1, 7),"Beijing", "Imperial Palaces of the Ming and Qing Dynasties in Beijing and Shenyang", "Beijing Central Axis: A Building Ensemble Exhibiting the Ideal Order of the Chinese Capital","China",299 ,0,1,0,0,['Serena']])
data_list.append([datetime.datetime(2018, 1, 7),"Beijing", "Beijing Central Axis: A Building Ensemble Exhibiting the Ideal Order of the Chinese Capital", "","China",80 ,0,1,0,0,['Serena']])
data_list.append([datetime.datetime(2018, 1, 7),"Beijing", "Beijing Central Axis: A Building Ensemble Exhibiting the Ideal Order of the Chinese Capital", "","China",1 ,0,1,0,0,[]])
data_list.append([datetime.datetime(2018, 1, 8),"Juyongguan", "The Great Wall", "","China",7 ,0,1,0,0,[]])
data_list.append([datetime.datetime(2018, 1, 8),"Badaling", "The Great Wall", "","China",80 ,0,1,0,0,[]])
data_list.append([datetime.datetime(2018, 1, 8),"Beijing", "Beijing Central Axis: A Building Ensemble Exhibiting the Ideal Order of the Chinese Capital", "","China",14 ,0,1,0,0,[]])
data_list.append([datetime.datetime(2018, 1, 9),"Beijing", "Temple of Heaven in Beijing", "Beijing Central Axis: A Building Ensemble Exhibiting the Ideal Order of the Chinese Capital","China",119 ,0,1,0,0,[]])
data_list.append([datetime.datetime(2018, 1, 9),"Beijing", "Summer Palace in Beijing", "","China",177 ,0,1,0,0,[]])
data_list.append([datetime.datetime(2018, 1, 10),"Beijing", "The Grand Canal", "","China",3 ,0,1,0,0,[]])
data_list.append([datetime.datetime(2018, 1, 11),"Luoyang", "Longmen Grottoes", "Silk Roads: the Routes Network of Chang'an-Tianshan Corridor","China",105 ,105,1,0,0,[]])
data_list.append([datetime.datetime(2018, 1, 11),"Beijing", "Beijing Central Axis: A Building Ensemble Exhibiting the Ideal Order of the Chinese Capital", "","China",25 ,0,1,0,0,[]])
data_list.append([datetime.datetime(2018, 1, 12),"Xi'an", "Mausoleum of the First Qin Emperor", "","China",81 ,0,1,0,0,[]])
data_list.append([datetime.datetime(2018, 1, 12),"Xi'an", "Silk Roads: the Routes Network of Chang'an-Tianshan Corridor", "","China",55 ,0,1,0,0,[]])
data_list.append([datetime.datetime(2018, 1, 2),"Macao", "Macao", "","China",76 ,0,1,0,0,[]])
data_list.append([datetime.datetime(2018, 3, 3),"Albi", "Episcopal City of Albi", "","France",122 ,0,1,0,0,[]])
data_list.append([datetime.datetime(2018, 3, 3),"Toulouse","Routes of Santiago de Compostela in France","","France",60,0,1,0,0,[]])
data_list.append([datetime.datetime(2018, 3, 3),"Toulouse","Canal du Midi","","France",2,0,1,0,0,[]])
data_list.append([datetime.datetime(2018, 3, 4),"Toulouse","Canal du Midi","","France",4,0,1,0,0,[]])
data_list.append([datetime.datetime(2018, 3, 4),"Toulouse","Routes of Santiago de Compostela in France","","France",4,0,1,0,0,[]])
data_list.append([datetime.datetime(2018, 3, 10),"Amsterdam","Seventeenth-Century Canal Ring Area","","Netherlands",6,0,1,0,0,['Mohamed']])
data_list.append([datetime.datetime(2018, 3, 11),"Brussels","Grand-Place, Brussels","","Belgium",71,0,1,0,0,['Mohamed']])
data_list.append([datetime.datetime(2018, 3, 30),"Thingvellir National Park","Thingvellir National Park","","Iceland",33,0,1,0,0,['Rachel','Riju','Reyer']])
data_list.append([datetime.datetime(2018, 4, 15),"Roskilde","Roskilde Cathedral","","Denmark",115,0,1,0,0,['Rachel','Riju','Reyer']])
data_list.append([datetime.datetime(2018, 4, 28),"Reims","Cathedral of Notre-Dame, Former Abbey of Saint-Remi and Palace of Tau","","France",139,0,1,0,0,['Christine','Reyer']])
data_list.append([datetime.datetime(2018, 4, 28),"Reims","Champagne Hillsides, Houses and Cellars","","France",40,0,1,0,0,['Christine','Reyer']])
data_list.append([datetime.datetime(2018, 4, 29),"Versailles","Palace and Park of Versailles","","France",242,0,1,0,0,['Christine','Reyer']])
data_list.append([datetime.datetime(2018, 4, 29),"Paris","Routes of Santiago de Compostela in France","","France",2,0,1,0,0,['Christine','Reyer']])
data_list.append([datetime.datetime(2018, 4, 29),"Paris","Paris, Banks of the Seine","","France",89,0,1,0,0,['Christine','Reyer']])
data_list.append([datetime.datetime(2018, 5, 1),"Amiens","Amiens Cathedral","","France",111,0,1,0,0,['Reyer']])
data_list.append([datetime.datetime(2018, 5, 1),"Amiens","Belfries of Belgium and France","","France",1,0,1,0,0,['Reyer']])
data_list.append([datetime.datetime(2018, 5, 1),"Chartres","Chartres Cathedral","","France",108,0,1,0,0,['Reyer']])
data_list.append([datetime.datetime(2018, 5, 19),"Brescia","Longobards in Italy","","Italy",145,0,1,0,0,['Amin']])
data_list.append([datetime.datetime(2018, 5, 20),"Bergamo","Venetian Works of Defence between the 16th and 17th Centuries","","Italy",137,0,1,0,0,['Amin']])
data_list.append([datetime.datetime(2018, 5, 21),"San Marino","San Marino","","San Marino",77,0,1,0,0,['Amin']])
data_list.append([datetime.datetime(2018, 5, 26),"Tarragona","Archaeological Ensemble of Tarraco","","Spain",46,0,1,0,0,[]])
data_list.append([datetime.datetime(2018, 5, 26),"Barcelona","Works of Antoni Gaudi","","Spain",52,0,1,0,0,['Rachel']])
data_list.append([datetime.datetime(2018, 5, 26),"Barcelona","Palau de la Musica Catalana and Hospital de Sant Pau","","Spain",1,0,1,0,0,['Rachel']])
data_list.append([datetime.datetime(2018, 5, 27),"Barcelona","Works of Antoni Gaudi","","Spain",47,0,1,0,0,[]])
data_list.append([datetime.datetime(2018, 6, 3),"Edinburgh","Edinburgh","","United Kingdom",101,0,1,0,0,[]])
data_list.append([datetime.datetime(2018, 6, 3),"Queensferry","Forth Bridge","","United Kingdom",14,0,1,0,0,['Artur','Heidrun']])
data_list.append([datetime.datetime(2018, 6, 3),"North Queensferry","Forth Bridge","","United Kingdom",2,0,1,0,0,['Artur','Heidrun']])
data_list.append([datetime.datetime(2018, 6, 4),"Fallkirk","Frontiers of the Roman Empire","","United Kingdom",9,0,1,0,0,['Artur','Heidrun']])
data_list.append([datetime.datetime(2018, 6, 5),"Durham","Durham Castle and Cathedral","","United Kingdom",59,0,1,0,0,['Artur','Heidrun']])
data_list.append([datetime.datetime(2018, 6, 6),"Ripon","Studley Royal Park including the Ruins of Fountains Abbey","","United Kingdom",98,0,1,0,0,['Artur','Heidrun']])
data_list.append([datetime.datetime(2018, 6, 8),"Conwy","Castles and Town Walls of King Edward in Gwynedd","","United Kingdom",69,0,1,0,0,['Artur','Heidrun']])
data_list.append([datetime.datetime(2018, 6, 8),"Caernarfon","Castles and Town Walls of King Edward in Gwynedd","","United Kingdom",55,0,1,0,0,['Artur','Heidrun']])
data_list.append([datetime.datetime(2018, 6, 9),"Liverpool","Liverpool – Maritime Mercantile City","","United Kingdom",39,0,1,0,1,['Artur','Heidrun']])
data_list.append([datetime.datetime(2018, 7, 3),"Seoul","Changdeokgung Palace","","South Korea",109,0,1,0,0,['Eva','Ulrike']])
data_list.append([datetime.datetime(2018, 7, 4),"Seoul","Jongmyo Shrine","","South Korea",20,0,1,0,0,[]])
data_list.append([datetime.datetime(2018, 7, 4),"Seoul","Royal Tombs of the Joseon Dynasty","","South Korea",23,0,1,0,0,[]])
data_list.append([datetime.datetime(2018, 7, 12),"Suwom","Hwaseong Fortress","","South Korea",66,0,1,0,0,[]])
data_list.append([datetime.datetime(2018, 7, 12),"Gwangju","Namhansanseong","","South Korea",38,0,1,0,0,[]])
data_list.append([datetime.datetime(2018, 7, 13),"Gyeongju","Seokguram Grotto and Bulguksa Temple","","South Korea",45,0,1,0,0,['Stephanie','Steffen']])
data_list.append([datetime.datetime(2018, 7, 13),"Gyeongju","Historic Villages of Korea: Hahoe and Yangdong","","South Korea",21,0,1,0,0,['Stephanie','Steffen']])
data_list.append([datetime.datetime(2018, 7, 13),"Gyeongju","Gyeongju Historic Areas","","South Korea",20,0,1,0,0,['Stephanie','Steffen']])
data_list.append([datetime.datetime(2018, 7, 28),"Kandersteg","Jungfrau-Aletsch","","Switzerland",57,0,0,1,0,['Riju']])
data_list.append([datetime.datetime(2018, 7, 28),"Frutigen","Jungfrau-Aletsch","","Switzerland",5,0,0,1,0,['Riju']])
data_list.append([datetime.datetime(2018, 7, 28),"Bern","Bern","","Switzerland",48,0,1,0,0,['Riju']])
data_list.append([datetime.datetime(2018, 7, 28),"Kerzers","Jungfrau-Aletsch","","Switzerland",2,0,0,1,0,['Riju']])
data_list.append([datetime.datetime(2018, 7, 28),"Neuchatel","Jungfrau-Aletsch","","Switzerland",2,0,0,1,0,['Riju']])
data_list.append([datetime.datetime(2018, 8, 5),"Grisons","Rhaetian Railways","","Switzerland",4,0,0,1,0,[]])
data_list.append([datetime.datetime(2018, 9, 2),"Steingaden","Wieskirche","","Germany",17,0,1,0,0,['Reyer','Chris Brainerd']])
data_list.append([datetime.datetime(2018, 9, 2),"Regensburg","Regensburg","","Germany",52,0,1,0,0,['Reyer','Chris Brainerd']])
data_list.append([datetime.datetime(2018, 9, 3),"Bamberg","Bamberg","","Germany",68,0,1,0,0,['Reyer','Chris Brainerd']])
data_list.append([datetime.datetime(2018, 9, 4),"Wuerzburg","Wuerzburg Residence","","Germany",34,0,1,0,0,['Reyer','Chris Brainerd']])
data_list.append([datetime.datetime(2018, 9, 4),"Bayreuth","Margravial Opera House Bayreuth","","Germany",24,0,1,0,0,['Reyer','Chris Brainerd']])
data_list.append([datetime.datetime(2018, 9, 5),"Eisenach","Wartburg","","Germany",77,0,1,0,0,['Reyer','Chris Brainerd']])
data_list.append([datetime.datetime(2018, 9, 5),"Schoenstedt","Ancient and Primeval Beech Forests of the Carpathians and Other Regions of Europe","","Germany",18,0,0,1,0,['Reyer','Chris Brainerd']])
data_list.append([datetime.datetime(2018, 9, 5),"Naumburg","Naumburg Cathedral","","Germany",51,0,1,0,0,['Reyer','Chris Brainerd']])
data_list.append([datetime.datetime(2018, 9, 6),"Dessau-Rosslau","Bauhaus and its Sites in Weimar, Dessau and Bernau","","Germany",24,0,1,0,0,['Reyer','Chris Brainerd']])
data_list.append([datetime.datetime(2018, 9, 6),"Dessau-Rosslau","Garden Kingdom of Dessau-Wörlitz","","Germany",50,0,1,0,0,['Reyer','Chris Brainerd']])
data_list.append([datetime.datetime(2018, 9, 6),"Oranienbaum-Woerlitz","Garden Kingdom of Dessau-Wörlitz","","Germany",184,0,1,0,0,['Reyer','Chris Brainerd']])
data_list.append([datetime.datetime(2018, 9, 7),"Wittenberg","Luther Memorials","","Germany",36,0,1,0,0,['Reyer','Chris Brainerd']])
data_list.append([datetime.datetime(2018, 9, 7),"Quedlinburg","Quedlinburg","","Germany",50,0,1,0,0,['Reyer','Chris Brainerd']])
data_list.append([datetime.datetime(2018, 9, 8),"Potsdam","Palaces and Parks of Potsdam and Berlin","","Germany",350,0,1,0,0,['Reyer','Chris Brainerd','Riju']])
data_list.append([datetime.datetime(2018, 9, 9),"Berlin","Museumsinsel","","Germany",139,0,1,0,0,['Reyer','Chris Brainerd','Riju']])
data_list.append([datetime.datetime(2018, 9, 22),"Antwerp", "Belfries of Belgium and France", "","Belgium",2 ,0,1,0,0,[]])
data_list.append([datetime.datetime(2018, 9, 22),"Antwerp", "Plantin Moretus", "","Belgium",33 ,0,1,0,0,[]])
data_list.append([datetime.datetime(2018, 9, 22),"Mechelen", "Belfries of Belgium and France", "","Belgium",33 ,0,1,0,0,[]])
data_list.append([datetime.datetime(2018, 9, 23),"Leuven", "Flemish Beguinages", "","Belgium",2 ,0,1,0,0,['Rachel']])
data_list.append([datetime.datetime(2018, 9, 23),"Leuven", "Belfries of Belgium and France", "","Belgium",31 ,0,1,0,0,['Rachel']])
data_list.append([datetime.datetime(2018, 11, 17),"Arles", "Arles, Roman and Romanesque Monuments", "Routes of Santiago de Compostela in France","France",151 ,18,1,0,0,['Santona']])
data_list.append([datetime.datetime(2018, 11, 18),"Nimes", "The Maison Carree of Nimes", "","France",2 ,0,1,0,0,['Santona']])
data_list.append([datetime.datetime(2018, 11, 19),"Nimes", "The Maison Carree of Nimes", "","France",5 ,0,1,0,0,['Santona']])
data_list.append([datetime.datetime(2018, 11, 19),"Orange", "Theatre and Triumphal Arch of Orange", "","France",38 ,0,1,0,0,['Santona']])
data_list.append([datetime.datetime(2018, 12, 8),"Beaune", "Climats, Terroirs of Burgundy", "","France",61 ,0,1,0,0,['Santona','Yao Yao','Graham','Chris Brainerd']])
data_list.append([datetime.datetime(2018, 12, 8),"Dijon", "Climats, Terroirs of Burgundy", "","France",87 ,0,1,0,0,['Santona','Yao Yao','Graham','Chris Brainerd']])
data_list.append([datetime.datetime(2018, 12, 8),"Vougeot", "Climats, Terroirs of Burgundy", "","France",54 ,0,1,0,0,['Santona','Yao Yao','Graham','Chris Brainerd']])
data_list.append([datetime.datetime(2018, 12, 29),"Maulbronn", "Maulbronn Monastery", "","Germany",92 ,0,1,0,0,['Artur','Heidrun']])
data_list.append([datetime.datetime(2018, 12, 29),"Voelklingen", "Voelklingen Ironworks", "","Germany",95 ,0,1,0,0,['Artur','Heidrun']])
data_list.append([datetime.datetime(2018, 12, 29),"Lorsch", "Abbey of Lorsch", "","Germany",30 ,0,1,0,0,['Artur','Heidrun']])
#2019
data_list.append([datetime.datetime(2019, 1, 13),"Domodossola", "Sacri Monti of Piedmont and Lombardy", "","Italy",140 ,0,1,0,0,[]])
data_list.append([datetime.datetime(2019, 1, 13),"Orta San Giulia", "Sacri Monti of Piedmont and Lombardy", "","Italy",156 ,0,1,0,0,[]])
data_list.append([datetime.datetime(2019, 3, 11),"Matera","Sassi of Matera","","Italy",104,0,1,0,0,['Artur','Heidrun']])
data_list.append([datetime.datetime(2019, 3, 12),"Andria","Castel del Monte","","Italy",45,0,1,0,0,['Artur','Heidrun']])
data_list.append([datetime.datetime(2019, 3, 14),"Alberobello","Trulli of Alberobello","","Italy",39,0,1,0,0,['Artur','Heidrun']])
data_list.append([datetime.datetime(2019, 3, 15),"Naples","Naples","","Italy",308,0,1,0,0,['Artur','Heidrun']])
data_list.append([datetime.datetime(2019, 3, 16),"Caserta","Reggia di Caserta","","Italy",200,0,1,0,0,['Artur','Heidrun']])
data_list.append([datetime.datetime(2019, 3, 16),"Benevento","Longobards in Italy","Via Appia. Regina Viarum","Italy",34,0,1,0,0,['Artur','Heidrun']])
data_list.append([datetime.datetime(2019, 3, 16),"Benevento","Via Appia. Regina Viarum","","Italy",65,0,1,0,0,['Artur','Heidrun']])
data_list.append([datetime.datetime(2019, 3, 17),"Ercolano","Pompei, Herculaneum and Torre Annunziata","","Italy",127,0,1,0,0,['Artur','Heidrun']])
data_list.append([datetime.datetime(2019, 3, 17),"Naples","Naples","","Italy",250,0,1,0,0,['Artur','Heidrun']])
data_list.append([datetime.datetime(2019, 3, 18),"Paestum","Cilento and Vallo di Diano National Park with the Archeological Sites of Paestum and Velia, and the Certosa di Padula","","Italy",66,0,1,0,0,['Artur','Heidrun']])
data_list.append([datetime.datetime(2019, 3, 18),"Naples","Naples","","Italy",228,0,1,0,0,['Artur','Heidrun']])
data_list.append([datetime.datetime(2019, 3, 19),"Pompei","Pompei, Herculaneum and Torre Annunziata","","Italy",169,0,1,0,0,['Artur','Heidrun']])
data_list.append([datetime.datetime(2019, 3, 19),"Torre Annunziata","Pompei, Herculaneum and Torre Annunziata","","Italy",73,0,1,0,0,['Artur','Heidrun']])
data_list.append([datetime.datetime(2019, 3, 19),"Naples","Naples","","Italy",73,0,1,0,0,['Artur','Heidrun']])
data_list.append([datetime.datetime(2019, 3, 20),"Positano","Amalfi Coast","","Italy",79,0,1,0,0,['Artur','Heidrun']])
data_list.append([datetime.datetime(2019, 3, 20),"Praiano","Amalfi Coast","","Italy",3,0,1,0,0,['Artur','Heidrun']])
data_list.append([datetime.datetime(2019, 3, 20),"Furore","Amalfi Coast","","Italy",2,0,1,0,0,['Artur','Heidrun']])
data_list.append([datetime.datetime(2019, 3, 20),"Conca dei Marini","Amalfi Coast","","Italy",3,0,1,0,0,['Artur','Heidrun']])
data_list.append([datetime.datetime(2019, 3, 20),"Amalfi","Amalfi Coast","","Italy",145,0,1,0,0,['Artur','Heidrun']])
data_list.append([datetime.datetime(2019, 3, 20),"Atrani","Amalfi Coast","","Italy",3,0,1,0,0,['Artur','Heidrun']])
data_list.append([datetime.datetime(2019, 3, 20),"Ravello","Amalfi Coast","","Italy",3,0,1,0,0,['Artur','Heidrun']])
data_list.append([datetime.datetime(2019, 3, 20),"Marmorata","Amalfi Coast","","Italy",1,0,1,0,0,['Artur','Heidrun']])
data_list.append([datetime.datetime(2019, 3, 20),"Minori","Amalfi Coast","","Italy",3,0,1,0,0,['Artur','Heidrun']])
data_list.append([datetime.datetime(2019, 3, 20),"Maiori","Amalfi Coast","","Italy",10,0,1,0,0,['Artur','Heidrun']])
data_list.append([datetime.datetime(2019, 3, 20),"Erchie","Amalfi Coast","","Italy",4,0,1,0,0,['Artur','Heidrun']])
data_list.append([datetime.datetime(2019, 3, 20),"Cetara","Amalfi Coast","","Italy",9,0,1,0,0,['Artur','Heidrun']])
data_list.append([datetime.datetime(2019, 3, 20),"Vietri Sul Mare","Amalfi Coast","","Italy",4,0,1,0,0,['Artur','Heidrun']])
data_list.append([datetime.datetime(2019, 3, 21),"Naples","Naples","","Italy",60,0,1,0,0,['Artur','Heidrun']])
data_list.append([datetime.datetime(2019, 4, 6),"Murten","Prehistoric Pile Dwellings around the Alps","","Switzerland",2,0,1,0,0,['Artur','Heidrun']])
data_list.append([datetime.datetime(2019, 4, 14),"London","Maritime Greenwich","","United Kingdom",106,0,1,0,0,[]])
data_list.append([datetime.datetime(2019, 4, 18),"Paris","Routes of Santiago de Compostela in France","","France",1,0,1,0,0,['Riju','Chris Brainerd']])
data_list.append([datetime.datetime(2019, 4, 19),"St Savin","Abbey Church of St Savin","","France",105,0,1,0,0,['Riju','Chris Brainerd']])
data_list.append([datetime.datetime(2019, 4, 19),"Poitiers","Routes of Santiago de Compostela in France","","France",29,0,1,0,0,['Riju','Chris Brainerd']])
data_list.append([datetime.datetime(2019, 4, 19),"Paris","Paris, Banks of the Seine","","France",13,0,1,0,0,['Riju','Chris Brainerd']])
data_list.append([datetime.datetime(2019, 4, 20),"Provins","Provins",'',"France",60,0,1,0,0,['Riju','Chris Brainerd']])
data_list.append([datetime.datetime(2019, 4, 20),"Fontainebleau","Palace and Park of Fontainebleau",'',"France",250,0,1,0,0,['Riju','Chris Brainerd']])
data_list.append([datetime.datetime(2019, 4, 20),"Paris","Routes of Santiago de Compostela in France","","France",2,0,1,0,0,['Riju','Chris Brainerd']])
data_list.append([datetime.datetime(2019, 4, 20),"Paris","Paris, Banks of the Seine","","France",83,0,1,0,0,['Riju','Chris Brainerd']])
data_list.append([datetime.datetime(2019, 4, 21),"Bourges","Bourges Cathedral","Routes of Santiago de Compostela in France","France",195,195,1,0,0,[]])
data_list.append([datetime.datetime(2019, 4, 22),"Le Havre","Le Havre","","France",62,0,1,0,0,['Riju','Chris Brainerd']])
data_list.append([datetime.datetime(2019, 5, 31),"Hoexter","Corvey Monastery","","Germany",104,0,1,0,0,['Grace']])
data_list.append([datetime.datetime(2019, 5, 31),"Alfeld","Fagus Factory","","Germany",14,0,1,0,0,['Grace']])
data_list.append([datetime.datetime(2019, 5, 31),"Hildesheim","St Mary's Cathedral and St Michael's Church at Hildesheim","","Germany",124,0,1,0,0,['Grace']])
data_list.append([datetime.datetime(2019, 6, 1),"Bremen","City Hall Bremen","","Germany",77,0,1,0,0,['Grace']])
data_list.append([datetime.datetime(2019, 6, 1),"Norddeich","Wadden Sea","","Germany",47,0,0,1,0,['Grace']])
data_list.append([datetime.datetime(2019, 6, 2),"Goslar","Goslar and Rammelsberg","","Germany",105,0,1,0,0,['Grace']])
data_list.append([datetime.datetime(2019, 6, 23),"Cully","Lavaux","","Switzerland",9,0,1,0,0,['Artur','Heidrun','Christian','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(2019, 6, 23),"Riex","Lavaux","","Switzerland",15,0,1,0,0,['Artur','Heidrun','Christian','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(2019, 6, 23),"Bourg-en-Lavaux","Lavaux","","Switzerland",19,0,1,0,0,['Artur','Heidrun','Christian','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(2019, 6, 23),"Chexbres","Lavaux","","Switzerland",5,0,1,0,0,['Artur','Heidrun','Christian','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(2019, 7, 28),"Fiesch","Jungfrau-Aletsch","","Switzerland",18,0,0,1,0,['Ulrike','Francesca','Ivan','Jose','Chris Brainerd']])
data_list.append([datetime.datetime(2019, 7, 28),"Fieschertal","Jungfrau-Aletsch","","Switzerland",87,0,0,1,0,['Ulrike','Francesca','Ivan','Jose','Chris Brainerd']])
data_list.append([datetime.datetime(2019, 9, 15),"Blatten","Jungfrau-Aletsch","","Switzerland",277,0,0,1,0,['Janina']])
data_list.append([datetime.datetime(2019, 9, 21),"Paris","Paris, Banks of the Seine","","France",277,0,1,0,0,['Nhi','Michael','Vivan','Sam']])
data_list.append([datetime.datetime(2019, 9, 22),"Paris","Routes of Santiago de Compostela in France","","France",1,0,1,0,0,['Nhi','Michael','Vivan','Sam']])
data_list.append([datetime.datetime(2019, 9, 22),"Paris","Paris, Banks of the Seine","","France",186,0,1,0,0,['Nhi','Michael','Vivan','Sam']])
data_list.append([datetime.datetime(2019, 10, 6),"Corseaux","Corbusier","","Switzerland",7,0,1,0,0,['Xuan','Andrew','Will']])
data_list.append([datetime.datetime(2019, 10, 6),"Rivaz","Lavaux","","Switzerland",19,0,1,0,0,['Xuan','Andrew','Will']])
data_list.append([datetime.datetime(2019, 12, 29),"Dresden","Dresden Elbe Valley","","Germany",16,0,1,0,1,['Artur']])
data_list.append([datetime.datetime(2019, 12, 30),"Dresden","Dresden Elbe Valley","","Germany",179,0,1,0,1,['Artur']])
data_list.append([datetime.datetime(2019, 12, 31),"Dresden","Dresden Elbe Valley","","Germany",377,0,1,0,1,['Artur']])
#2020
data_list.append([datetime.datetime(2020, 1, 1),"Dresden","Dresden Elbe Valley","","Germany",6,0,1,0,1,['Artur']])
data_list.append([datetime.datetime(2020, 1, 1),"Bad Muskau","Muskauer Park","","Germany",22,0,1,0,0,['Artur']])
data_list.append([datetime.datetime(2020, 1, 1),"Leknica","Muskauer Park","","Poland",25,0,1,0,0,['Artur']])
data_list.append([datetime.datetime(2020, 1, 1),"Swidwinica","Churches of Peace in Slesia","","Poland",59,0,1,0,0,['Artur']])
data_list.append([datetime.datetime(2020, 1, 2),"Wieliczka","Wieliczka and Bochnia Royal Salt Mines","","Poland",97,0,1,0,0,['Artur']])
data_list.append([datetime.datetime(2020, 1, 2),"Krakow","Krakow","","Poland",175,0,1,0,0,['Artur']])
data_list.append([datetime.datetime(2020, 1, 3),"Wroclaw","Centennial Hall","","Poland",12,0,1,0,0,['Artur']])  
data_list.append([datetime.datetime(2020, 2, 8),"St Gallen","Abbey of St Gall","","Switzerland",44,0,1,0,0,['Sam','Vivan','Grace','Dylan']]) 
data_list.append([datetime.datetime(2020, 2, 8),"Reichenau","Reichenau","","Germany",79,0,1,0,0,['Sam','Vivan','Grace','Dylan']]) 
data_list.append([datetime.datetime(2020, 2, 20),"Rome", "Rome", "","Vatican",62 ,0,1,0,0,[]])
data_list.append([datetime.datetime(2020, 2, 20),"Rome", "Rome", "","Italy",130 ,0,1,0,0,[]])
data_list.append([datetime.datetime(2020, 2, 21),"Urbino", "Urbino", "","Italy",147 ,0,1,0,0,[]])
data_list.append([datetime.datetime(2020, 2, 23),"Rome", "Rome", "","Vatican",6 ,0,1,0,0,[]])
data_list.append([datetime.datetime(2020, 2, 23),"Rome", "Rome", "","Italy",14 ,0,1,0,0,[]])
data_list.append([datetime.datetime(2020, 2, 24),"Pienza", "Pienza", "","Italy",59 ,0,1,0,0,[]])
data_list.append([datetime.datetime(2020, 2, 24),"Pienza", "Val d'Orcia", "","Italy",46 ,0,1,0,0,[]])
data_list.append([datetime.datetime(2020, 2, 25),"Siena", "Siena", "","Italy",298 ,0,1,0,0,[]])
data_list.append([datetime.datetime(2020, 2, 25),"San Gimignano", "San Gimignano", "","Italy",137 ,0,1,0,0,[]])
data_list.append([datetime.datetime(2020, 2, 26),"Florence", "Florence", "Medici Villas and Gardens","Italy",768 ,202,1,0,0,[]])
data_list.append([datetime.datetime(2020, 2, 27),"Rome","Via Appia. Regina Viarum","","Italy",67,0,1,0,0,['Bryan']])
data_list.append([datetime.datetime(2020, 2, 27),"Rome", "Rome", "","Vatican",128 ,0,1,0,0,['Bryan']])
data_list.append([datetime.datetime(2020, 2, 27),"Rome", "Rome", "","Italy",10 ,0,1,0,0,['Bryan']])
data_list.append([datetime.datetime(2020, 2, 27),"Rome", "Vatican City", "","Vatican",3 ,0,1,0,0,['Bryan']])
data_list.append([datetime.datetime(2020, 2, 28),"Rome", "Vatican City", "","Vatican",362 ,0,1,0,0,['Bryan']])
data_list.append([datetime.datetime(2020, 2, 28),"Rome", "Rome", "","Italy",180 ,0,1,0,0,['Bryan']])
data_list.append([datetime.datetime(2020, 2, 29),"Rome", "Rome", "","Italy",535 ,0,1,0,0,['Bryan']])
data_list.append([datetime.datetime(2020, 3, 1),"Tivoli", "Villa d'Este", "","Italy",164 ,0,1,0,0,['Bryan']])
data_list.append([datetime.datetime(2020, 3, 1),"Tivoli", "Villa Adriana", "","Italy",94 ,0,1,0,0,['Bryan']])
data_list.append([datetime.datetime(2020, 3, 2),"Rome", "Rome", "","Vatican",73 ,0,1,0,0,['Bryan']])
data_list.append([datetime.datetime(2020, 3, 2),"Rome", "Rome", "","Italy",145 ,0,1,0,0,['Bryan']])
data_list.append([datetime.datetime(2020, 6, 20),"Strassbourg", "Strassbourg", "","France",114 ,0,1,0,0,['Artur']])
data_list.append([datetime.datetime(2020, 6, 20),"Baden-Baden", "The Great Spa Towns of Europe", "","Germany",11 ,0,1,0,0,['Artur',"Anne-Kathrin",'Christian',"Mathilda"]])
data_list.append([datetime.datetime(2020, 8, 1),"Belalp", "Jungfrau-Aletsch", "","Switzerland",51 ,0,0,1,0,['Sam']])
data_list.append([datetime.datetime(2020, 8, 1),"Domodossola", "Sacri Monti of Piedmont and Lombardy", "","Italy",15 ,0,1,0,0,['Sam']])
data_list.append([datetime.datetime(2020, 8, 9),"Lauterbrunnen", "Jungfrau-Aletsch", "","Switzerland",14 ,0,0,1,0,['Artem']])
data_list.append([datetime.datetime(2020, 8, 9),"Grindelwald", "Jungfrau-Aletsch", "","Switzerland",10 ,0,0,1,0,['Artem']])
data_list.append([datetime.datetime(2020, 8, 9),"Fieschertal", "Jungfrau-Aletsch", "","Switzerland",226 ,0,0,1,0,['Sasha','Juno','Artem']])
data_list.append([datetime.datetime(2020, 8, 10),"Fieschertal", "Jungfrau-Aletsch", "","Switzerland",75 ,0,0,1,0,['Sasha','Juno','Artem']])
data_list.append([datetime.datetime(2020,11, 22),"Hoechenschwand", "Jungfrau-Aletsch", "","Switzerland",14 ,0,0,1,0,['Artur']])

# %%
#2021
data_list.append([datetime.datetime(2021, 2, 4),"Reichenau","Reichenau","","Germany",21,0,1,0,0,["Artur"]]) 
data_list.append([datetime.datetime(2021, 5, 4),"Vienna","Vienna","","Austria",116,0,1,0,0,[]])
data_list.append([datetime.datetime(2021, 5, 4),"Vienna","Vienna","","Austria",34,0,1,0,0,['Bob']])
data_list.append([datetime.datetime(2021, 5, 6),"Vienna","Vienna","","Austria",244,0,1,0,0,[]])
data_list.append([datetime.datetime(2021, 5, 7),"Vienna","Gardens and Palace of Schoenbrunn","","Austria",140,0,1,0,0,[]])
data_list.append([datetime.datetime(2021, 5, 6),"Vienna","Vienna","","Austria",65,0,1,0,0,[]])
data_list.append([datetime.datetime(2021, 5, 8),"Vienna","Vienna","","Austria",150,0,1,0,0,[]])
data_list.append([datetime.datetime(2021, 5, 9),"Vienna","Vienna","","Austria",121,0,1,0,0,[]])
data_list.append([datetime.datetime(2021, 5, 10),"Vienna","Vienna","","Austria",111,0,1,0,0,[]])
data_list.append([datetime.datetime(2021, 5, 11),"Vienna","Vienna","","Austria",139,0,1,0,0,[]])
data_list.append([datetime.datetime(2021, 5, 11),"Vienna","Gardens and Palace of Schoenbrunn","","Austria",67,0,1,0,0,[]])
data_list.append([datetime.datetime(2021, 5, 12),"Vienna","Vienna","","Austria",117,0,1,0,0,[]])
data_list.append([datetime.datetime(2021, 5, 13),"Vienna","Vienna","","Austria",45,0,1,0,0,[]])
data_list.append([datetime.datetime(2021, 5, 13),"Vienna","Gardens and Palace of Schoenbrunn","","Austria",35,0,1,0,0,[]])
data_list.append([datetime.datetime(2021, 5, 15),"Vienna","Gardens and Palace of Schoenbrunn","","Austria",49,0,1,0,0,[]])
data_list.append([datetime.datetime(2021, 5, 16),"Vienna","Gardens and Palace of Schoenbrunn","","Austria",102,0,1,0,0,[]])
data_list.append([datetime.datetime(2021, 5, 22),"Salzburg","Salzburg","","Austria",343,0,1,0,0,[]])
data_list.append([datetime.datetime(2021, 5, 23),"Vienna","Vienna","","Austria",117,0,1,0,0,[]])
data_list.append([datetime.datetime(2021, 5, 24),"Hallstatt","Hallstatt-Dachstein/Salzkammergut","","Austria",219,0,1,0,0,[]])
data_list.append([datetime.datetime(2021, 5, 24),"Obertraun","Hallstatt-Dachstein/Salzkammergut","","Austria",26,0,1,0,0,[]])
data_list.append([datetime.datetime(2021, 5, 28),"Vienna","Vienna","","Austria",10,0,1,0,0,[]])
data_list.append([datetime.datetime(2021, 5, 28),"Vienna","Vienna","","Austria",92,0,1,0,0,['Bob']])
data_list.append([datetime.datetime(2021, 5, 29),"Vienna","Vienna","","Austria",60,0,1,0,0,[]])
data_list.append([datetime.datetime(2021, 6, 3),"Semmering","Semmering Railway","","Austria",2,0,1,0,0,[]])
data_list.append([datetime.datetime(2021, 6, 3),"Breitenstein","Semmering Railway","","Austria",1,0,1,0,0,[]])
data_list.append([datetime.datetime(2021, 6, 6),"Vienna","Gardens and Palace of Schoenbrunn","","Austria",24,0,1,0,0,[]])
data_list.append([datetime.datetime(2021, 6, 6),"Vienna","Vienna","","Austria",3,0,1,0,0,[]])
data_list.append([datetime.datetime(2021, 6, 19),"Melk","Wachau Cultural Landscape","","Austria",2,0,1,0,0,[]])
data_list.append([datetime.datetime(2021, 6, 19),"Grimsing","Wachau Cultural Landscape","","Austria",5,0,1,0,0,[]])
data_list.append([datetime.datetime(2021, 6, 19),"Schallemmersdorf","Wachau Cultural Landscape","","Austria",1,0,1,0,0,[]])
data_list.append([datetime.datetime(2021, 6, 19),"Emmersdorf an der Donau","Wachau Cultural Landscape","","Austria",10,0,1,0,0,[]])
data_list.append([datetime.datetime(2021, 6, 19),"Aggsbach Markt","Wachau Cultural Landscape","","Austria",1,0,1,0,0,[]])
data_list.append([datetime.datetime(2021, 6, 19),"Willendorf in der Wachau","Wachau Cultural Landscape","","Austria",1,0,1,0,0,[]])
data_list.append([datetime.datetime(2021, 6, 19),"Schwallenbach","Wachau Cultural Landscape","","Austria",1,0,1,0,0,[]])
data_list.append([datetime.datetime(2021, 6, 19),"Spitz an der Donau","Wachau Cultural Landscape","","Austria",29,0,1,0,0,[]])
data_list.append([datetime.datetime(2021, 6, 19),"Weissenkirchen in der Wachau","Wachau Cultural Landscape","","Austria",4,0,1,0,0,[]])
data_list.append([datetime.datetime(2021, 6, 19),"Duernstein","Wachau Cultural Landscape","","Austria",131,0,1,0,0,[]])
data_list.append([datetime.datetime(2021, 6, 19),"Oberloiben","Wachau Cultural Landscape","","Austria",1,0,1,0,0,[]])
data_list.append([datetime.datetime(2021, 6, 19),"Unterloiben","Wachau Cultural Landscape","","Austria",1,0,1,0,0,[]])
data_list.append([datetime.datetime(2021, 6, 19),"Krems an der Donau","Wachau Cultural Landscape","","Austria",51,0,1,0,0,[]])
data_list.append([datetime.datetime(2021, 6, 19),"Thunau am Kamp","Wachau Cultural Landscape","","Austria",2,0,1,0,0,[]])
data_list.append([datetime.datetime(2021, 6, 20),"Baden bei Wien", "The Great Spa Towns of Europe", "","Austria",61 ,0,1,0,0,[]])
data_list.append([datetime.datetime(2021, 6, 22),"Vienna","Vienna","","Austria",6,0,1,0,0,[]])
data_list.append([datetime.datetime(2021, 6, 25),"Vienna","Vienna","","Austria",6,0,1,0,0,[]])
data_list.append([datetime.datetime(2021, 7, 2),"Vienna","Vienna","","Austria",80,0,1,0,0,[]])
data_list.append([datetime.datetime(2021, 7, 3),"Bad Goisern","Hallstatt-Dachstein/Salzkammergut","","Austria",5,0,1,0,0,[]])
data_list.append([datetime.datetime(2021, 7, 3),"Obertraun","Hallstatt-Dachstein/Salzkammergut","","Austria",200,0,1,0,0,[]])
data_list.append([datetime.datetime(2021, 7, 4),"Vienna","Vienna","","Austria",42,0,1,0,0,[]])
data_list.append([datetime.datetime(2021, 7, 4),"Vienna","Frontiers of the Roman Empire – The Danube Limes","","Austria",7,0,1,0,0,[]])
data_list.append([datetime.datetime(2021, 7, 9),"Vienna","Vienna","","Austria",4,0,1,0,0,[]])
data_list.append([datetime.datetime(2021, 7, 18),"Vienna","Vienna","","Austria",43,0,1,0,0,[]])
data_list.append([datetime.datetime(2021, 7, 31),"Vienna","Vienna","","Austria",63,0,1,0,0,[]])
data_list.append([datetime.datetime(2021, 8, 1),"Petronell-Carnuntum","Frontiers of the Roman Empire – The Danube Limes","","Austria",19,0,1,0,0,[]])
data_list.append([datetime.datetime(2021, 8, 1),"Bad Deutsch-Altenburg","Frontiers of the Roman Empire – The Danube Limes","","Austria",6,0,1,0,0,[]])
data_list.append([datetime.datetime(2021, 8, 5),"Vienna","Vienna","","Austria",7,0,1,0,0,["Namrata","xyz"]])
data_list.append([datetime.datetime(2021, 8, 7),"St Margarethen im Burgenland","Fertoe - Neusiedlersee Cultural Landscape","","Austria",33,0,1,0,0,[]])
data_list.append([datetime.datetime(2021, 8, 7),"Rust am See","Fertoe - Neusiedlersee Cultural Landscape","","Austria",30,0,1,0,0,[]])
data_list.append([datetime.datetime(2021, 8, 14),"Furth bei Goettweig","Wachau Cultural Landscape","","Austria",76,0,1,0,0,[]])
data_list.append([datetime.datetime(2021, 8, 19),"Vienna","Vienna","","Austria",13,0,1,0,0,[]])
data_list.append([datetime.datetime(2021, 8, 21),"Semmering","Semmering Railway","","Austria",25,0,1,0,0,[]])
data_list.append([datetime.datetime(2021, 8, 21),"Breitenstein","Semmering Railway","","Austria",23,0,1,0,0,[]])
data_list.append([datetime.datetime(2021, 8, 21),"Payerbach","Semmering Railway","","Austria",3,0,1,0,0,[]])
data_list.append([datetime.datetime(2021, 8, 27),'Prague',"Prague","","Czech Republic",10,0,1,0,0,[]])
data_list.append([datetime.datetime(2021, 8, 28),'Prague',"Prague","","Czech Republic",361,0,1,0,0,[]])
data_list.append([datetime.datetime(2021, 8, 29),'Prague',"Prague","","Czech Republic",253,0,1,0,0,[]])
data_list.append([datetime.datetime(2021, 9, 3),"Bamberg","Bamberg","","Germany",61,0,1,0,0,["Hannsjoerg"]])
data_list.append([datetime.datetime(2021, 9, 4),"Wuerzburg","Wuerzburg Residence","","Germany",5,0,1,0,0,['Artur',"Hannsjoerg","Marion","Julius","Jan-Marc",'Felicitas','Julius']])
data_list.append([datetime.datetime(2021, 9, 4),"Wuerzburg","Wuerzburg Residence","","Germany",22,0,1,0,0,['Artur',"Hannsjoerg","Marion","Julius","Jan-Marc",'Felicitas','Julius','Christian',"Anne-Kathrin","Mathilda"]])
data_list.append([datetime.datetime(2021, 9, 5),"Regensburg","Regensburg","Frontiers of the Roman Empire – The Danube Limes","Germany",118,3,1,0,0,[""]])
data_list.append([datetime.datetime(2021, 9, 23),"Vienna","Vienna","","Austria",14,0,1,0,0,["Michael",'Vivan']])
data_list.append([datetime.datetime(2021, 9, 24),"Vienna","Vienna","","Austria",4,0,1,0,0,["Michael",'Vivan']])
data_list.append([datetime.datetime(2021, 9, 25),"Salzburg","Salzburg","","Austria",37,0,1,0,0,["Michael",'Vivan']])
data_list.append([datetime.datetime(2021, 9, 26),"Vienna","Vienna","","Austria",96,0,1,0,0,['Vivan']])
data_list.append([datetime.datetime(2021, 9, 26),"Vienna","Vienna","","Austria",67,0,1,0,0,["Michael",'Vivan']])
data_list.append([datetime.datetime(2021, 10, 2),"Vienna","Vienna","","Austria",162,0,1,0,0,[]])
data_list.append([datetime.datetime(2021, 10, 8),"Vienna","Vienna","","Austria",1,0,1,0,0,['Angelika']])
data_list.append([datetime.datetime(2021, 10, 9),"Vienna","Gardens and Palace of Schoenbrunn","","Austria",34,0,1,0,0,[]])
data_list.append([datetime.datetime(2021, 10, 23),"Trier","Roman Monuments, Cathedral of St Peter and Church of Our Lady","","Germany",5,0,1,0,0,[]])
data_list.append([datetime.datetime(2021, 10, 24),"Luxemburg","City of Luxembourg: its Old Quarters and Fortifications","","Luxemburg",53,0,1,0,0,[]])
data_list.append([datetime.datetime(2021, 10, 24),"Trier","Roman Monuments, Cathedral of St Peter and Church of Our Lady","","Germany",179,0,1,0,0,[]])
data_list.append([datetime.datetime(2021, 10, 25),"Nancy","Place Stanislas, Place de la Carriere and Place d'Alliance","","France",42,0,1,0,0,[]])
data_list.append([datetime.datetime(2021, 10, 26),"Paris","Paris, Banks of the Seine","","France",242,0,1,0,0,[]])
data_list.append([datetime.datetime(2021, 10, 27),"Paris","Paris, Banks of the Seine","","France",329,0,1,0,0,[]])
data_list.append([datetime.datetime(2021, 10, 27),"Paris","Routes of Santiago de Compostela in France","","France",3,0,1,0,0,[]])
data_list.append([datetime.datetime(2021, 10, 28),"Tournai","Belfries of Belgium and France","","Belgium",5,0,1,0,0,[]])
data_list.append([datetime.datetime(2021, 10, 28),"Tournai","Tournai Cathedral","","Belgium",58,0,1,0,0,[]])
data_list.append([datetime.datetime(2021, 10, 28),"Lille","Belfries of Belgium and France","","France",7,0,1,0,0,[]])
data_list.append([datetime.datetime(2021, 10, 28),"Oignies","Nord-Pas de Calais Mining Basin","","France",37,0,1,0,0,[]])
data_list.append([datetime.datetime(2021, 10, 28),"Arras","Belfries of Belgium and France","","France",9,0,1,0,0,[]])
data_list.append([datetime.datetime(2021, 10, 28),"Arras","Fortifications of Vauban","","France",31,0,1,0,0,[]])
data_list.append([datetime.datetime(2021, 10, 29),"Aachen","Aachen Cathedral","","Germany",114,0,1,0,0,[]])
data_list.append([datetime.datetime(2021, 10, 29),"Cologne","Cologne Cathedral","","Germany",202,0,1,0,0,[]])
data_list.append([datetime.datetime(2021, 10, 29),"Cologne","Frontiers of the Roman Empire - The Lower German Limes","","Germany",1,0,1,0,0,[]])
data_list.append([datetime.datetime(2021, 10, 30),"Speyer","Speyer Cathedral","","Germany",70,0,1,0,0,[]])
data_list.append([datetime.datetime(2021, 10, 30),"Speyer","ShUM Sites of Speyer, Worms and Mainz","","Germany",19,0,1,0,0,[]])
data_list.append([datetime.datetime(2021, 10, 30),"Darmstadt","Mathildenhoehe","","Germany",47,0,1,0,0,[]])
data_list.append([datetime.datetime(2021, 10, 31),"Kaub","Upper Middle Rhine Valley","","Germany",10,0,1,0,0,[]])
data_list.append([datetime.datetime(2021, 10, 31),"Sankt Goarshausen","Upper Middle Rhine Valley","","Germany",7,0,1,0,0,[]])
data_list.append([datetime.datetime(2021, 10, 31),"Kesters","Upper Middle Rhine Valley","","Germany",1,0,1,0,0,[]])
data_list.append([datetime.datetime(2021, 10, 31),"Kamp-Bornhofen","Upper Middle Rhine Valley","","Germany",1,0,1,0,0,[]])
data_list.append([datetime.datetime(2021, 10, 31),"Braubach","Upper Middle Rhine Valley","","Germany",85,0,1,0,0,[]])
data_list.append([datetime.datetime(2021, 10, 31),"Lahnstein","Upper Middle Rhine Valley","","Germany",1,0,1,0,0,[]])
data_list.append([datetime.datetime(2021, 10, 31),"Koblenz","Upper Middle Rhine Valley","","Germany",1,0,1,0,0,[]])
data_list.append([datetime.datetime(2021, 10, 31),"Essen","Zollverein Coal Mine Industrial Complex in Essen","","Germany",32,0,1,0,0,[]])
data_list.append([datetime.datetime(2021, 11, 1),"Vienna","Gardens and Palace of Schoenbrunn","","Austria",41,0,1,0,0,[]])
data_list.append([datetime.datetime(2021, 12, 12),"Vienna","Vienna","","Austria",31,0,1,0,0,[]])

# %%
#2022
data_list.append([datetime.datetime(2022, 1, 30),"Vienna","Vienna","","Austria",67,0,1,0,0,[]])
data_list.append([datetime.datetime(2022, 2, 13),"Vienna","Vienna","","Austria",34,0,1,0,0,[]])
data_list.append([datetime.datetime(2022, 2, 18),"Vienna","Vienna","","Austria",63,0,1,0,0,[]])
data_list.append([datetime.datetime(2022, 2, 18),"Vienna","Gardens and Palace of Schoenbrunn","","Austria",6,0,1,0,0,[]])
data_list.append([datetime.datetime(2022, 2, 19),"Vienna","Vienna","","Austria",41,0,1,0,0,[]])
data_list.append([datetime.datetime(2022, 3, 19),"Madrid", "Paseo del Prado and Buen Retiro", "","Spain",96,0,1,0,0,[]])
data_list.append([datetime.datetime(2022, 3, 21),"Granada", "Alhambra, Generalife and Albayzin", "","Spain",29 ,0,1,0,0,[]])
data_list.append([datetime.datetime(2022, 3, 22),"Granada", "Alhambra, Generalife and Albayzin", "","Spain",252 ,0,1,0,0,[]])
data_list.append([datetime.datetime(2022, 3, 23),"Ubeda", "Renaissance Monumental Ensembles of Ubeda and Baeza", "","Spain",96 ,0,1,0,0,[]])
data_list.append([datetime.datetime(2022, 3, 24),"Cordoba", "Cordoba", "","Spain",221 ,0,1,0,0,[]])
data_list.append([datetime.datetime(2022, 3, 24),"Cordoba", "Medina Azahara", "","Spain",82,0,1,0,0,[]])
data_list.append([datetime.datetime(2022, 3, 25),"Sevilla", "Cathedral, Alcazar and Archivo de Indias in Seville", "","Spain",418 ,0,1,0,0,[]])
data_list.append([datetime.datetime(2022, 3, 26),"Caceres", "Old Town of Caceres", "","Spain",150,0,1,0,0,[]])
data_list.append([datetime.datetime(2022, 3, 27),"Merida", "Archaeological Ensemble of Merida", "","Spain",189,0,1,0,0,[]])
data_list.append([datetime.datetime(2022, 3, 28),"Cuenca", "Historic Walled Town of Cuenca", "","Spain",178,0,1,0,0,[]])
data_list.append([datetime.datetime(2022, 3, 28),"Madrid", "Paseo del Prado and Buen Retiro", "","Spain",22,0,1,0,0,[]])
data_list.append([datetime.datetime(2022, 3, 29),"Madrid", "Paseo del Prado and Buen Retiro", "","Spain",5,0,1,0,0,[]])
data_list.append([datetime.datetime(2022, 3, 29),"Alcala de Henares", "University and Historic Precinct of Alcala de Henares", "","Spain",65,0,1,0,0,[]])
data_list.append([datetime.datetime(2022, 3, 30),"Toledo","Toledo","","Spain",554,0,1,0,0,[]]) 
data_list.append([datetime.datetime(2022, 3, 31),"Leon","Routes of Santiago de Compostela: Camino Frances and Routes of Northern Spain","","Spain",167,0,1,0,0,[]])
data_list.append([datetime.datetime(2022, 3, 31),"Astorga","Routes of Santiago de Compostela: Camino Frances and Routes of Northern Spain","","Spain",134,0,1,0,0,[]])
data_list.append([datetime.datetime(2022, 4, 1),"Segovia","Segovia","","Spain",206,0,1,0,0,['']])
data_list.append([datetime.datetime(2022, 4, 1),"Madrid", "Paseo del Prado and Buen Retiro", "","Spain",29,0,1,0,0,[]])
data_list.append([datetime.datetime(2022, 4, 2),"Aranjuez", "Aranjuez Cultural Landscape", "","Spain",65 ,0,1,0,0,[]])
data_list.append([datetime.datetime(2022, 4, 2),"El Escorial","El Escorial Monastery","","Spain",124,0,1,0,0,[]])
data_list.append([datetime.datetime(2022, 4, 3),"Madrid", "Paseo del Prado and Buen Retiro", "","Spain",70,0,1,0,0,[]])
data_list.append([datetime.datetime(2022, 4, 8),"Vienna","Vienna","","Austria",14,0,1,0,0,[]])
data_list.append([datetime.datetime(2022, 4, 17),"Vienna","Vienna","","Austria",12,0,1,0,0,[]])
data_list.append([datetime.datetime(2022, 4, 24),"Vienna","Vienna","","Austria",13,0,1,0,0,[]])
data_list.append([datetime.datetime(2022, 5, 3),"Vienna","Gardens and Palace of Schoenbrunn","","Austria",9,0,1,0,0,[]])
data_list.append([datetime.datetime(2022, 5, 15),"Pannonhalma","Millenary Benedictine Abbey of Pannonhalma and its Natural Environment","","Hungary",98,0,1,0,0,[]])
data_list.append([datetime.datetime(2022, 5, 20),"Vienna","Vienna","","Austria",9,0,1,0,0,[]])
data_list.append([datetime.datetime(2022, 5, 21),"Vienna","Vienna","","Austria",1,0,1,0,0,['Rachel','Chris Martin']])
data_list.append([datetime.datetime(2022, 5, 21),"Vienna","Gardens and Palace of Schoenbrunn","","Austria",6,0,1,0,0,['Rachel','Chris Martin']])
data_list.append([datetime.datetime(2022, 5, 22),"Vienna","Vienna","","Austria",8,0,1,0,0,['Rachel','Chris Martin']])
data_list.append([datetime.datetime(2022, 5, 23),"Vienna","Vienna","","Austria",47,0,1,0,0,[]])
data_list.append([datetime.datetime(2022, 5, 24),"Vienna","Vienna","","Austria",2,0,1,0,0,['Chris Martin']])
data_list.append([datetime.datetime(2022, 5, 25),"Budapest","Budapest, including the Banks of the Danube, the Buda Castle Quarter and Andrassy Avenue","","Hungary",152,0,1,0,0,['Chris Martin']])
data_list.append([datetime.datetime(2022, 5, 26),"Budapest","Budapest, including the Banks of the Danube, the Buda Castle Quarter and Andrassy Avenue","","Hungary",72,0,1,0,0,['Chris Martin']])
data_list.append([datetime.datetime(2022, 6, 3),"Vienna","Vienna","","Austria",2,0,1,0,0,["Artur"]])
data_list.append([datetime.datetime(2022, 6, 4),"Vienna","Vienna","","Austria",3,0,1,0,0,["Artur"]])
data_list.append([datetime.datetime(2022, 6, 5),"Budapest","Budapest, including the Banks of the Danube, the Buda Castle Quarter and Andrassy Avenue","","Hungary",117,0,1,0,0,['Artur']])
data_list.append([datetime.datetime(2022, 6, 6),"Vienna","Vienna","","Austria",1,0,1,0,0,["Artur"]])
data_list.append([datetime.datetime(2022, 6, 11),"Augsburg",'The Water Management System of Augsburg',"","Germany",27,0,1,0,0,[]])
data_list.append([datetime.datetime(2022, 6, 16),"Stralsund","Historic Centres of Stralsund and Wismar","","Germany",108,0,1,0,0,[]])
data_list.append([datetime.datetime(2022, 6, 17),"Freiberg","Erzgebirge/Krusnohori Mining region","","Germany",99,0,1,0,0,[]])
data_list.append([datetime.datetime(2022, 6, 19),"Berlin","Museumsinsel","","Germany",25,0,1,0,0,[]])
data_list.append([datetime.datetime(2022, 6, 18),'Potsdam',"Palaces and Parks of Potsdam and Berlin","","Germany",285,0,1,0,0,["Hannsjoerg"]])
data_list.append([datetime.datetime(2022, 6, 19),"Berlin","Berlin Modernism Housing Estates","","Germany",14,0,1,0,0,[]])
data_list.append([datetime.datetime(2022, 6, 25),"Vienna","Vienna","","Austria",25,0,1,0,0,[]])
data_list.append([datetime.datetime(2022, 6, 27),"Vienna","Vienna","","Austria",4,0,1,0,0,["Monica"]])
data_list.append([datetime.datetime(2022, 6, 28),"Vienna","Vienna","","Austria",1,0,1,0,0,["Monica"]])
data_list.append([datetime.datetime(2022, 7, 10),"Cesky Krumlov","Cesky Krumlov","","Czech Republic",125,0,1,0,0,[]])
data_list.append([datetime.datetime(2022, 7, 16),"Kromeriz","Gardens and Castle at Kromeriz","","Czech Republic",92,0,1,0,0,[]])
data_list.append([datetime.datetime(2022, 7, 16),"Olomouc","Holy Trinity Column of Olomouc","","Czech Republic",25,0,1,0,0,[]])
data_list.append([datetime.datetime(2022, 7, 29),"Modena","Cathedral, Torre Civica and Piazza Grande, Modena","","Italy",100,0,1,0,0,[]])
data_list.append([datetime.datetime(2022, 7, 30),"Milan","Santa Maria delle Grazie with The Last Supper","","Italy",80,0,1,0,0,['Riju']])
data_list.append([datetime.datetime(2022, 8, 1),"Naples","Naples","","Italy",13,0,1,0,0,['Riju']])
data_list.append([datetime.datetime(2022, 8, 2),"Castaglione","Amalfi Coast","","Italy",3,0,1,0,0,[]])
data_list.append([datetime.datetime(2022, 8, 2),"Atrani","Amalfi Coast","","Italy",2,0,1,0,0,[]])
data_list.append([datetime.datetime(2022, 8, 2),"Ravello","Amalfi Coast","","Italy",147,0,1,0,0,['Riju']])
data_list.append([datetime.datetime(2022, 8, 2),"Amalfi","Amalfi Coast","","Italy",48,0,1,0,0,['Riju']])
data_list.append([datetime.datetime(2022, 8, 2),"Positano","Amalfi Coast","","Italy",5,0,1,0,0,['Riju']])
data_list.append([datetime.datetime(2022, 8, 3),"Pompei","Pompei, Herculaneum and Torre Annunziata","","Italy",97,0,1,0,0,['Riju']])
data_list.append([datetime.datetime(2022, 8, 3),"Naples","Naples","","Italy",88,0,1,0,0,['Riju']])
data_list.append([datetime.datetime(2022, 8, 4),"Pisa","Piazza del Duomo, Pisa","","Italy",264,0,1,0,0,[]])
data_list.append([datetime.datetime(2022, 8, 4),"Siena", "Siena", "","Italy",179 ,0,1,0,0,[]])
data_list.append([datetime.datetime(2022, 8, 4),"Florence", "Florence", "","Italy",64 ,0,1,0,0,[]])
data_list.append([datetime.datetime(2022, 8, 5),"Florence", "Florence", "","Italy",273 ,0,1,0,0,[]])
data_list.append([datetime.datetime(2022, 8, 5),"Bologna", "Porticoes of Bologna", "","Italy",140,0,1,0,0,[]])
data_list.append([datetime.datetime(2022, 8, 5),"Venice","Venice and its Lagoon","","Italy",26,0,1,0,0,[]])
data_list.append([datetime.datetime(2022, 8, 6),"Venice","Venice and its Lagoon","","Italy",584,0,1,0,0,[]])
data_list.append([datetime.datetime(2022, 8, 13),"Kutna Hora","Kutna Hora: Historical Town Centre with the Church of St Barbara and the Cathedral of Our Lady at Sedlec","","Czech Republic",143,0,1,0,0,[]])
data_list.append([datetime.datetime(2021, 8, 13),'Prague',"Prague","","Czech Republic",24,0,1,0,0,[]])
data_list.append([datetime.datetime(2021, 8, 14),'Prague',"Prague","","Czech Republic",136,0,1,0,0,[]])
data_list.append([datetime.datetime(2022, 8, 15),"Lednice","Lednice-Valtice Cultural Landscape","","Czech Republic",222,0,1,0,0,[]])
data_list.append([datetime.datetime(2022, 8, 21),"Zdar nad Sazavou","Pilgrimage Church of St John of Nepomuk at Zelena Hora","","Czech Republic",36,0,1,0,0,[]])
data_list.append([datetime.datetime(2022, 8, 21),"Brno","Tugendhat Villa in Brno","","Czech Republic",60,0,1,0,0,[]])
data_list.append([datetime.datetime(2022, 8, 26),"Riga","Historic Centre of Riga","","Latvia",133,0,1,0,0,["Artur"]])
data_list.append([datetime.datetime(2022, 8, 27),"Vilnius","Vilnius Historic Centre","","Lithuania",161,0,1,0,0,["Artur"]])
data_list.append([datetime.datetime(2022, 8, 28),"Riga","Historic Centre of Riga","","Latvia",96,0,1,0,0,["Artur"]])
data_list.append([datetime.datetime(2022, 9, 3),"Valtice","Lednice-Valtice Cultural Landscape","","Czech Republic",156,0,1,0,0,[]])
data_list.append([datetime.datetime(2022, 9, 4),"Trebic","Jewish Quarter and St Procopius' Basilica in Trebic","","Czech Republic",103,0,1,0,0,[]])
data_list.append([datetime.datetime(2022, 9, 10),"Litomysl","Litomysl Castle","","Czech Republic",135,0,1,0,0,[]])
data_list.append([datetime.datetime(2022, 9, 25),"Vienna","Vienna","","Austria",39,0,1,0,0,[]])
data_list.append([datetime.datetime(2022, 9, 30),"Vienna","Vienna","","Austria",14,0,1,0,0,[]])
data_list.append([datetime.datetime(2022, 10, 1),"Vienna","Gardens and Palace of Schoenbrunn","","Austria",99,0,1,0,0,[]])
data_list.append([datetime.datetime(2022, 10, 26),"Vienna","Vienna","","Austria",75,0,1,0,0,[]])
data_list.append([datetime.datetime(2022, 10, 29),"Graz","Graz","","Austria",30,0,1,0,0,[]])
data_list.append([datetime.datetime(2022, 11, 3),"Warsaw","Warsaw","","Poland",178,0,1,0,0,[]])
data_list.append([datetime.datetime(2022, 11, 4),"Torun","Medieval Town of Torun","","Poland",178,0,1,0,0,[]])
data_list.append([datetime.datetime(2022, 11, 5),"Malbork","Castle of the Teutonic Order in Malbork","","Poland",253,0,1,0,0,[]])
data_list.append([datetime.datetime(2022, 11, 13),"Vienna","Vienna","","Austria",19,0,1,0,0,[]])
data_list.append([datetime.datetime(2022, 11, 27),"Vienna","Vienna","","Austria",7,0,1,0,0,[]])
data_list.append([datetime.datetime(2022, 12, 2),"Cologne","Cologne Cathedral","","Germany",175,0,1,0,0,['Artur']])
data_list.append([datetime.datetime(2022, 12, 10),"Vienna","Vienna","","Austria",6,0,1,0,0,[]])
data_list.append([datetime.datetime(2022, 12, 14),"Vienna","Vienna","","Austria",39,0,1,0,0,[]])
data_list.append([datetime.datetime(2022, 12, 17),"Vienna","Vienna","","Austria",66,0,1,0,0,[]])
data_list.append([datetime.datetime(2022, 12, 26),"Blaubeuren","Caves and Ice Age Art in the Swabian Jura","","Germany",17,0,1,0,0,['Artur']])
data_list.append([datetime.datetime(2022, 12, 27),"Bern","Bern","","Switzerland",74,0,1,0,0,['Artur']])
data_list.append([datetime.datetime(2022, 12, 28),"Muestair","Benedictine Convent of St John at Muestair","","Switzerland",32,0,1,0,0,['Artur']])
data_list.append([datetime.datetime(2022, 12, 28),"Berguen","Rhaetian Railways","","Switzerland",5,0,0,1,0,['Artur']])
data_list.append([datetime.datetime(2022, 12, 29),"Neuf-Brisach","Fortifications of Vauban","","France",30,0,1,0,0,['Artur']])

# %%
data_list.append([datetime.datetime(2023, 1, 7),"Vienna","Vienna","","Austria",44,0,1,0,0,[]])
data_list.append([datetime.datetime(2023, 1, 14),"Vienna","Vienna","","Austria",122,0,1,0,0,[]])
data_list.append([datetime.datetime(2023, 1, 22),"Vienna","Vienna","","Austria",12,0,1,0,0,[]])
data_list.append([datetime.datetime(2023, 1, 22),"Vienna","Gardens and Palace of Schoenbrunn","","Austria",53,0,1,0,0,[]])
data_list.append([datetime.datetime(2023, 2, 24),"Vienna","Vienna","","Austria",9,0,1,0,0,['Janina','Kevin']])
data_list.append([datetime.datetime(2023, 2, 24),"Vienna","Frontiers of the Roman Empire – The Danube Limes","Vienna","Austria",1,1,1,0,0,['Janina','Kevin']])
data_list.append([datetime.datetime(2023, 2, 26),"Vienna","Gardens and Palace of Schoenbrunn","","Austria",12,0,1,0,0,['Janina','Kevin']])
data_list.append([datetime.datetime(2023, 2, 26),"Vienna","Vienna","","Austria",2,0,1,0,0,['Janina','Kevin']])
data_list.append([datetime.datetime(2023, 3, 4),"Belem","Monastery of the Hieronymites and Tower of Belem","","Portugal",125,0,1,0,0,[]])
data_list.append([datetime.datetime(2023, 3, 7),"Sintra","Cultural Landscape of Sintra","","Portugal",194,0,1,0,0,[]])
data_list.append([datetime.datetime(2023, 3, 8),"Tomar","Convent of Christ in Tomar","","Portugal",128,0,1,0,0,[]])
data_list.append([datetime.datetime(2023, 3, 9),"Mafra","Palace of Mafra","","Portugal",86,0,1,0,0,[]])
data_list.append([datetime.datetime(2023, 3, 9),"Sintra","Cultural Landscape of Sintra","","Portugal",167,0,1,0,0,[]])
data_list.append([datetime.datetime(2023, 3, 10),"Porto","Historic Centre of Oporto, Luiz I Bridge and Monastery of Serra do Pilar","","Portugal",197,0,1,0,0,['Artur']])
data_list.append([datetime.datetime(2023, 3, 10),"Vila Nova de Gaia","Historic Centre of Oporto, Luiz I Bridge and Monastery of Serra do Pilar","","Portugal",15,0,1,0,0,['Artur']])
data_list.append([datetime.datetime(2023, 3, 11),"Braga","Sanctuary of Bom Jesus do Monte in Braga","","Portugal",79,0,1,0,0,['Artur']])
data_list.append([datetime.datetime(2023, 3, 11),"Porto","Historic Centre of Oporto, Luiz I Bridge and Monastery of Serra do Pilar","","Portugal",11,0,1,0,0,['Artur']])
data_list.append([datetime.datetime(2023, 3, 12),"Porto","Historic Centre of Oporto, Luiz I Bridge and Monastery of Serra do Pilar","","Portugal",45,0,1,0,0,['Artur']])
data_list.append([datetime.datetime(2023, 3, 12),"Guimaraes","Historic Centre of Guimaraes","","Portugal",105,0,1,0,0,['Artur']])
data_list.append([datetime.datetime(2023, 3, 12),"Vila Nova de Gaia","Historic Centre of Oporto, Luiz I Bridge and Monastery of Serra do Pilar","","Portugal",12,0,1,0,0,['Artur']])
data_list.append([datetime.datetime(2023, 3, 13),"Santiago de Compostela","Santiago de Compostela (Old Town)","Routes of Santiago de Compostela: Camino Frances and Routes of Northern Spain","Spain",235,137,1,0,0,['Artur']])
data_list.append([datetime.datetime(2023, 3, 14),"Coimbra","University of Coimbra – Alta and Sofia","","Portugal",271,0,1,0,0,[]])
data_list.append([datetime.datetime(2023, 3, 16),"Batalha","Monastery of Batalha","","Portugal",90,0,1,0,0,[]])
data_list.append([datetime.datetime(2023, 3, 16),"Alcobaca","Monastery of Alcobaca","","Portugal",113,0,1,0,0,[]])
data_list.append([datetime.datetime(2023, 3, 17),"Evora","Historic Centre of Evora","","Portugal",240,0,1,0,0,[]])
data_list.append([datetime.datetime(2023, 3, 17),"Elvas","Garrison Border Town of Elvas and its Fortifications","","Portugal",87,0,1,0,0,[]])
data_list.append([datetime.datetime(2023, 4, 10),"Vienna","Gardens and Palace of Schoenbrunn","","Austria",27,0,1,0,0,[]])
data_list.append([datetime.datetime(2023, 4, 10),"Vienna","Vienna","","Austria",5,0,1,0,0,[]])
data_list.append([datetime.datetime(2023, 4, 29),"Krakow","Krakow","","Poland",434,0,1,0,0,[]])
data_list.append([datetime.datetime(2023, 4, 30),"Tarnowskie Gory","Tarnowskie Gory Lead-Silver-Zinc Mine and its Underground Water Management System","","Poland",39,0,1,0,0,[]])
data_list.append([datetime.datetime(2023, 4, 30),"Oswiecim","Auschwitz Birkenau German Nazi Concentration and Extermination Camp (1940-1945)","","Poland",31,0,1,0,0,[]])
data_list.append([datetime.datetime(2023, 4, 30),"Brzezinka","Auschwitz Birkenau German Nazi Concentration and Extermination Camp (1940-1945)","","Poland",12,0,1,0,0,[]])
data_list.append([datetime.datetime(2023, 5, 1),"Kalwaria Zebrzydowska","Kalwaria Zebrzydowska: the Mannerist Architectural and Park Landscape Complex and Pilgrimage Park","","Poland",44,0,1,0,0,[]])
data_list.append([datetime.datetime(2023, 5, 1),"Brody","Kalwaria Zebrzydowska: the Mannerist Architectural and Park Landscape Complex and Pilgrimage Park","","Poland",29,0,1,0,0,[]])
data_list.append([datetime.datetime(2023, 5, 1),"Bugaj","Kalwaria Zebrzydowska: the Mannerist Architectural and Park Landscape Complex and Pilgrimage Park","","Poland",22,0,1,0,0,[]])
data_list.append([datetime.datetime(2023, 6, 3),"Aengelsberg","Engelsberg Ironworks","","Sweden",39,0,1,0,0,[]])
data_list.append([datetime.datetime(2023, 6, 3),"Stockholm", "Skogskyrkogarden","","Sweden",28,0,1,0,0,[]])
data_list.append([datetime.datetime(2023, 6, 5),"Falun", "Mining Area of the Great Copper Mountain in Falun","","Sweden",70,0,1,0,0,[]])
data_list.append([datetime.datetime(2023, 6, 6),"Drottningholm","Royal Domain of Drottningholm","","Sweden",182,0,1,0,0,[]])
data_list.append([datetime.datetime(2023, 6, 8),"Vienna","Gardens and Palace of Schoenbrunn","","Austria",34,0,1,0,0,[]])
data_list.append([datetime.datetime(2023, 6, 24),"Sofia","Boyana Church","","Bulgaria",3,0,1,0,0,[]])
data_list.append([datetime.datetime(2023, 6, 24),"Rilski Manastir","Rila Monastery","","Bulgaria",118,0,1,0,0,[]])
data_list.append([datetime.datetime(2023, 6, 25),"Frauenkirchen","Fertoe - Neusiedlersee Cultural Landscape","","Austria",2,0,1,0,0,[]])
data_list.append([datetime.datetime(2023, 6, 25),"Podersdorf am See","Fertoe - Neusiedlersee Cultural Landscape","","Austria",4,0,1,0,0,[]])
data_list.append([datetime.datetime(2023, 6, 25),"Purbach am Neusiedler See","Fertoe - Neusiedlersee Cultural Landscape","","Austria",4,0,1,0,0,[]])
data_list.append([datetime.datetime(2023, 7, 22),"Lyngby","The par force hunting landscape in North Zealand","","Denmark",42,0,1,0,0,[]])
data_list.append([datetime.datetime(2023, 7, 22),"Klampenborg","The par force hunting landscape in North Zealand","","Denmark",5,0,1,0,0,[]])
data_list.append([datetime.datetime(2023, 7, 22),"Roedvig","Stevns Klint","","Denmark",36,0,0,0,0,[]])
data_list.append([datetime.datetime(2023, 7, 22),"Hoejerup","Stevns Klint","","Denmark",9,0,0,0,0,[]])
data_list.append([datetime.datetime(2023, 7, 23),"Helsingor","Kronborg","","Denmark",82,0,1,0,0,[]])
data_list.append([datetime.datetime(2023, 8, 12),'Weimar',"Classical Weimar","","Germany",99,0,1,0,0,[]])
data_list.append([datetime.datetime(2023, 8, 12),"Weimar","Bauhaus and its Sites in Weimar, Dessau and Bernau","","Germany",14,0,1,0,0,[]])
data_list.append([datetime.datetime(2023, 8, 12),"Erfurt","Jewish-Medieval Heritage of Erfurt","","Germany",1,0,1,0,0,[]])
data_list.append([datetime.datetime(2023, 8, 12),"Naumburg","Naumburg Cathedral","","Germany",98,0,1,0,0,[]])
data_list.append([datetime.datetime(2023, 8, 13),"Niederheimbach","Upper Middle Rhine Valley","","Germany",1,0,1,0,0,[]])
data_list.append([datetime.datetime(2023, 8, 13),"Bruehl","Castles of Augustusburg and Falkenlust at Bruehl","","Germany",219,0,1,0,0,[]])
data_list.append([datetime.datetime(2023, 8, 13),"Boppard","Upper Middle Rhine Valley","","Germany",41,0,1,0,0,[]])
data_list.append([datetime.datetime(2023, 8, 13),"St Goar","Upper Middle Rhine Valley","","Germany",82,0,1,0,0,[]])
data_list.append([datetime.datetime(2023, 8, 13),"Oberwesel","Upper Middle Rhine Valley","","Germany",1,0,1,0,0,[]])
data_list.append([datetime.datetime(2023, 8, 13),"Bacharach","Upper Middle Rhine Valley","","Germany",30,0,1,0,0,[]])     
data_list.append([datetime.datetime(2023, 8, 14),"Messel","Messel Pit Fossil Site","","Germany",28,0,0,0,0,[]])
data_list.append([datetime.datetime(2023, 8, 14),"Bad Ems", "The Great Spa Towns of Europe", "","Germany",47 ,0,1,0,0,[]])
data_list.append([datetime.datetime(2023, 8, 14),"Bad Ems","Frontiers of the Roman Empire","","Germany",2,0,1,0,0,[]])
data_list.append([datetime.datetime(2023, 8, 15),"Kassel","Bergpark Wilhelmshoehe","","Germany",55,0,1,0,0,[]])
data_list.append([datetime.datetime(2023, 8, 15),"Wuerzburg","Wuerzburg Residence","","Germany",164,0,1,0,0,[]])
data_list.append([datetime.datetime(2023, 8, 25),'Banska Stiavnica',"Historic Town of Banska Stiavnica and the Technical Monuments in its Vicinity","","Slovakia",43,0,1,0,0,['Artur']])
data_list.append([datetime.datetime(2023, 8, 26),'Banska Stiavnica',"Historic Town of Banska Stiavnica and the Technical Monuments in its Vicinity","","Slovakia",20,0,1,0,0,['Artur']])
data_list.append([datetime.datetime(2023, 8, 26),'Banska Stiavnica',"Historic Town of Banska Stiavnica and the Technical Monuments in its Vicinity","","Slovakia",43,0,1,0,0,[]])
data_list.append([datetime.datetime(2023, 8, 26),'Banska Bela',"Historic Town of Banska Stiavnica and the Technical Monuments in its Vicinity","","Slovakia",1,0,1,0,0,[]])
data_list.append([datetime.datetime(2023, 8, 26),'Hronsek',"Wooden Churches of the Slovak part of the Carpathian Mountain Area","","Slovakia",18,0,1,0,0,['Artur']])
data_list.append([datetime.datetime(2023, 8, 26),'Vlkolinec',"Vlkolinec","","Slovakia",19,0,1,0,0,['Artur']])
data_list.append([datetime.datetime(2023, 8, 26),"Spisska Kapitula","Levoca, Spissky Hrad and the Associated Cultural Monuments","","Slovakia",8,0,1,0,0,['Artur']])  
data_list.append([datetime.datetime(2023, 8, 27),"Spisska Kapitula","Levoca, Spissky Hrad and the Associated Cultural Monuments","","Slovakia",10,0,1,0,0,['Artur']]) 
data_list.append([datetime.datetime(2023, 8, 27),'Bardejov',"Bardejov Town Conservation Reserve","","Slovakia",42,0,1,0,0,['Artur']])
data_list.append([datetime.datetime(2023, 8, 27),"Kwiaton",'Wooden Tserkvas of the Carpathian Region in Poland and Ukraine',"","Poland",3,0,1,0,0,['Artur']])
data_list.append([datetime.datetime(2023, 8, 27),"Brunary",'Wooden Tserkvas of the Carpathian Region in Poland and Ukraine',"","Poland",8,0,1,0,0,['Artur']])
data_list.append([datetime.datetime(2023, 8, 27),'Sekowa',"Wooden Churches of Southern Malopolska","","Poland",10,0,1,0,0,['Artur']])
data_list.append([datetime.datetime(2023, 8, 27),"Owczary",'Wooden Tserkvas of the Carpathian Region in Poland and Ukraine',"","Poland",14,0,1,0,0,['Artur']])
data_list.append([datetime.datetime(2023, 8, 27),'Binarowa',"Wooden Churches of Southern Malopolska","","Poland",18,0,1,0,0,['Artur']])
data_list.append([datetime.datetime(2023, 8, 27),'Hervartov',"Wooden Churches of the Slovak part of the Carpathian Mountain Area","","Slovakia",2,0,1,0,0,['Artur']])
data_list.append([datetime.datetime(2023, 8, 27),"Spisske Podhradie","Levoca, Spissky Hrad and the Associated Cultural Monuments","","Slovakia",5,0,1,0,0,['Artur']])
data_list.append([datetime.datetime(2023, 8, 28),"Spisske Podhradie","Levoca, Spissky Hrad and the Associated Cultural Monuments","","Slovakia",1,0,1,0,0,['Artur']])
data_list.append([datetime.datetime(2023, 8, 28),"Spisska Kapitula","Levoca, Spissky Hrad and the Associated Cultural Monuments","","Slovakia",45,0,1,0,0,['Artur']]) 
data_list.append([datetime.datetime(2023, 8, 28),"Zehra","Levoca, Spissky Hrad and the Associated Cultural Monuments","","Slovakia",63,0,1,0,0,['Artur']]) 
data_list.append([datetime.datetime(2023, 8, 28),"Levoca","Levoca, Spissky Hrad and the Associated Cultural Monuments","","Slovakia",35,0,1,0,0,['Artur']]) 
data_list.append([datetime.datetime(2023, 8, 29),'Jasov',"Caves of Aggtelek Karst and Slovak Karst","","Slovakia",84,0,0,0,0,['Artur']]) 
data_list.append([datetime.datetime(2023, 8, 29),'Ochtina',"Caves of Aggtelek Karst and Slovak Karst","","Slovakia",60,0,0,0,0,['Artur']]) 
data_list.append([datetime.datetime(2023, 8, 29),'Dobsina',"Caves of Aggtelek Karst and Slovak Karst","","Slovakia",40,0,0,0,0,[]]) 
data_list.append([datetime.datetime(2023, 8, 30),'Kecovo',"Caves of Aggtelek Karst and Slovak Karst","","Slovakia",105,0,0,0,0,['Artur']]) 
data_list.append([datetime.datetime(2023, 8, 30),'Aggtelek',"Caves of Aggtelek Karst and Slovak Karst","","Hungary",240,0,0,0,0,['Artur']]) 
data_list.append([datetime.datetime(2023, 8, 30),'Tokaj',"Tokaj Wine Region Historic Cultural Landscape","","Hungary",7,0,1,0,0,['Artur']]) 
data_list.append([datetime.datetime(2023, 8, 31),'Hortobagy',"Hortobagy National Park - the Puszta","","Hungary",7,0,0,0,0,['Artur']]) 
data_list.append([datetime.datetime(2023, 8, 31),'Nagyhegyes',"Hortobagy National Park - the Puszta","","Hungary",3,0,0,0,0,['Artur']]) 
data_list.append([datetime.datetime(2023, 8, 31),'Tokaj',"Tokaj Wine Region Historic Cultural Landscape","","Hungary",39,0,1,0,0,['Artur']]) 
data_list.append([datetime.datetime(2023, 9, 2),'Pecs',"Early Christian Necropolis of Pecs (Sopianae)","","Hungary",25,0,1,0,0,['Artur']]) 
data_list.append([datetime.datetime(2023, 9, 3),"Graz","Graz","","Austria",74,0,1,0,0,['Artur']])
data_list.append([datetime.datetime(2023, 9, 3),"Schladming","Hallstatt-Dachstein/Salzkammergut","","Austria",1,0,1,0,0,['Artur']])
data_list.append([datetime.datetime(2023, 9, 4),"Schladming","Hallstatt-Dachstein/Salzkammergut","","Austria",1,0,1,0,0,['Artur']])
data_list.append([datetime.datetime(2023, 9, 4),"Ramsau am Dachstein","Hallstatt-Dachstein/Salzkammergut","","Austria",5,0,1,0,0,['Artur']])
data_list.append([datetime.datetime(2023, 9, 4),"Obertraun","Hallstatt-Dachstein/Salzkammergut","","Austria",42,0,1,0,0,['Artur']])
data_list.append([datetime.datetime(2023, 9, 4),"Obertraun","Hallstatt-Dachstein/Salzkammergut","","Austria",30,0,1,0,0,[]])
data_list.append([datetime.datetime(2023, 9, 4),"Salzburg","Salzburg","","Austria",1,0,1,0,0,[]])
data_list.append([datetime.datetime(2023, 9, 8),"Vienna","Vienna","","Austria",44,0,1,0,0,['Grace']])
data_list.append([datetime.datetime(2023, 9, 9),"Telc","Historic Centre of Telc","","Czech Republic",155,0,1,0,0,['Grace']])
data_list.append([datetime.datetime(2023, 9, 30),"Vienna","Vienna","","Austria",15,0,1,0,0,['Bing']])
data_list.append([datetime.datetime(2023, 10, 15),"Vienna","Vienna","","Austria",48,0,1,0,0,[]])
data_list.append([datetime.datetime(2023, 10, 26),"Visby","Hanseatic Town of Visby","","Sweden",176,0,1,0,0,[]])
data_list.append([datetime.datetime(2023, 10, 27),"Visby","Hanseatic Town of Visby","","Sweden",82,0,1,0,0,[]])
data_list.append([datetime.datetime(2023, 10, 30),"Karlskrona","Naval Port of Karlskrona","","Sweden",123,0,1,0,0,[]])
data_list.append([datetime.datetime(2023, 10, 31),"Moerbylanga","Agricultural Landscape of Southern Oeland","","Sweden",16,0,1,0,0,[]])
data_list.append([datetime.datetime(2023, 11, 18),"Vienna","Vienna","","Austria",9,0,1,0,0,[]])
data_list.append([datetime.datetime(2023, 12, 8),"La Chaux-de-Fonds","La Chaux-de-Fonds/Le Locle, Watchmaking Town Planning","","Switzerland",43,0,1,0,0,[]])
data_list.append([datetime.datetime(2023, 12, 9),"Lyon","Lyon","","France",239,0,1,0,0,['Bing','Sasha']])
data_list.append([datetime.datetime(2023, 12, 17),"Vienna","Vienna","","Austria",59,0,1,0,0,[]])
data_list.append([datetime.datetime(2023, 12, 26),"Reichenau","Reichenau","","Germany",46,0,1,0,0,["Hannsjoerg","Artur","Jennet"]]) 
data_list.append([datetime.datetime(2023, 12, 30),"Bayreuth","Margravial Opera House Bayreuth","","Germany",25,0,1,0,0,['Artur','Hannsjoerg','Jennetee']])

# %%
data_list.append([datetime.datetime(2024, 1, 1),'Prague',"Prague","","Czech Republic",144,0,1,0,0,[]])
data_list.append([datetime.datetime(2024, 1, 26),"Padua","Padova Urbs picta","","Italy",334,0,1,0,0,[]])
data_list.append([datetime.datetime(2024, 1, 27),"Verona","Verona","","Italy",476,0,1,0,0,[]])
data_list.append([datetime.datetime(2024, 1, 28),"Tiers","The Dolomites","","Italy",1,0,0,0,0,[]])
data_list.append([datetime.datetime(2024, 2, 17),"Ferrara","Ferrara, City of the Renaissance, and its Po Delta","","Italy",317,0,1,0,0,[]])
data_list.append([datetime.datetime(2024, 2, 18),"Vicenza","City of Vicenza and the Palladian Villas of the Veneto","","Italy",337,0,1,0,0,[]])
data_list.append([datetime.datetime(2024, 2, 18),"Caldogno","City of Vicenza and the Palladian Villas of the Veneto","","Italy",57,0,1,0,0,[]])
data_list.append([datetime.datetime(2024, 2, 19),"Ravenna","Early Christian Monuments of Ravenna","","Italy",219,0,1,0,0,[]])
data_list.append([datetime.datetime(2024, 2, 19),"Classe","Early Christian Monuments of Ravenna","","Italy",31,0,1,0,0,['']])
data_list.append([datetime.datetime(2024, 2, 20),"Venice","Venice and its Lagoon","","Italy",287,0,1,0,0,[]])
data_list.append([datetime.datetime(2024, 3, 10),"Vienna","Vienna","","Austria",18,0,1,0,0,[]])
data_list.append([datetime.datetime(2024, 3, 22),"Vienna","Vienna","","Austria",64,0,1,0,0,[]])
data_list.append([datetime.datetime(2024, 3, 22),"Vienna","Gardens and Palace of Schoenbrunn","","Austria",117,0,1,0,0,[]])
data_list.append([datetime.datetime(2024, 3, 31),"Thessaloniki","Paleochristian and Byzantine Monuments of Thessalonika","","Greece",75,0,1,0,0,['Artur']])
data_list.append([datetime.datetime(2024, 4, 1),"Thessaloniki","Paleochristian and Byzantine Monuments of Thessalonika","","Greece",1,0,1,0,0,['Artur']])
data_list.append([datetime.datetime(2024, 4, 1),"Krenides","Archaeological Site of Philippi","","Greece",75,0,1,0,0,['Artur']])
data_list.append([datetime.datetime(2024, 4, 2),"Vergina","Archaeological Site of Aigai","","Greece",60,0,1,0,0,['Artur']])
data_list.append([datetime.datetime(2024, 4, 2),"Palitatsia","Archaeological Site of Aigai","","Greece",16,0,1,0,0,['Artur']])
data_list.append([datetime.datetime(2024, 4, 4),"Ohrid","Natural and Cultural Heritage of the Ohrid region","","North Macedonia",103,0,1,1,0,['Artur']])
data_list.append([datetime.datetime(2024, 4, 4),"Ohrid","Natural and Cultural Heritage of the Ohrid region","","North Macedonia",25,0,1,1,0,[]])
data_list.append([datetime.datetime(2024, 4, 6),"Thessaloniki","Paleochristian and Byzantine Monuments of Thessalonika","","Greece",52,0,1,0,0,[]])
data_list.append([datetime.datetime(2024, 4, 6),"Thessaloniki","Paleochristian and Byzantine Monuments of Thessalonika","","Greece",67,0,1,0,0,['Artur']])
data_list.append([datetime.datetime(2024, 4, 7),"Kalambaka","Meteora","","Greece",83,0,1,1,0,['Artur']])
data_list.append([datetime.datetime(2024, 4, 7),"Kalambaka","Meteora","","Greece",149,0,1,1,0,[]])
data_list.append([datetime.datetime(2024, 4, 8),"Kalambaka","Meteora","","Greece",19,0,1,1,0,['Artur']])
data_list.append([datetime.datetime(2024, 4, 8),"Kalambaka","Meteora","","Greece",2,0,1,1,0,[]])
data_list.append([datetime.datetime(2024, 4, 8),"Kastraki","Meteora","","Greece",34,0,1,1,0,['Artur']])
data_list.append([datetime.datetime(2024, 4, 9),"Thessaloniki","Paleochristian and Byzantine Monuments of Thessalonika","","Greece",7,0,1,0,0,[]])
data_list.append([datetime.datetime(2024, 4, 9),"Thessaloniki","Paleochristian and Byzantine Monuments of Thessalonika","","Greece",57,0,1,0,0,['Artur']])
data_list.append([datetime.datetime(2024, 4, 9),"Vienna","Vienna","","Austria",6,0,1,0,0,[]])
data_list.append([datetime.datetime(2024, 4, 27),"Vienna","Vienna","","Austria",16,0,1,0,0,[]])
data_list.append([datetime.datetime(2024, 5, 1),"Durham","Durham Castle and Cathedral","","United Kingdom",111,0,1,0,0,[]])
data_list.append([datetime.datetime(2024, 5, 1),"Saltaire","Saltaire","","United Kingdom",29,0,1,0,0,[]])
data_list.append([datetime.datetime(2024, 5, 2),"London","Tower of London","","United Kingdom",33,0,1,0,0,[]])
data_list.append([datetime.datetime(2024, 5, 2),"London","Palace of Westminster and Westminster Abbey including Saint Margaret’s Church","","United Kingdom",162,0,1,0,0,[]])
data_list.append([datetime.datetime(2024, 5, 2),"Canterbury", "Canterbury Cathedral, St Augustine's Abbey, and St Martin's Church", "","United Kingdom",201,0,1,0,0,[]])
data_list.append([datetime.datetime(2024, 5, 3),"Stavely", "The English Lake District", "","United Kingdom",1,0,0,1,0,[]])
data_list.append([datetime.datetime(2024, 5, 3),"Windermere", "The English Lake District", "","United Kingdom",30,0,0,1,0,[]])
data_list.append([datetime.datetime(2024, 5, 3),"Ambleside", "The English Lake District", "","United Kingdom",33,0,0,1,0,[]])
data_list.append([datetime.datetime(2024, 5, 3),"Rydal", "The English Lake District", "","United Kingdom",57,0,0,1,0,[]])
data_list.append([datetime.datetime(2024, 5, 3),"Grasmere", "The English Lake District", "","United Kingdom",38,0,0,1,0,[]])
data_list.append([datetime.datetime(2024, 5, 4),"West Lulworth", "Dorset and East Devon Coast", "","United Kingdom",57,0,0,1,0,[]])
data_list.append([datetime.datetime(2024, 5, 9),"Idrija", "Heritage of Mercury. Almaden and Idrija", "","Slovenia",110,0,1,0,0,[]])
data_list.append([datetime.datetime(2024, 5, 9),"Ljubljana", "The works of Joze Plecnik in Ljubljana", "","Slovenia",10,0,1,0,0,[]])
data_list.append([datetime.datetime(2024, 5, 11),"Skocjan","Skocjan Caves","","Slovenia",98,0,0,1,0,[]])
data_list.append([datetime.datetime(2024, 5, 12),"Ljubljana", "The works of Joze Plecnik in Ljubljana", "","Slovenia",43,0,1,0,0,[]])
data_list.append([datetime.datetime(2024, 5, 18),"Valletta","City of Valletta", "", "Malta",8,0,1,0,0,['Artur']])
data_list.append([datetime.datetime(2024, 5, 19),"Qrendi","Megalithic Temples of Malta", "", "Malta",50,0,1,0,0,['Artur']])
data_list.append([datetime.datetime(2024, 5, 19),"Tarxien","Megalithic Temples of Malta", "", "Malta",36,0,1,0,0,['Artur']])
data_list.append([datetime.datetime(2024, 5, 19),"Paola","Megalithic Temples of Malta", "", "Malta",3,0,1,0,0,['Artur']])
data_list.append([datetime.datetime(2024, 5, 19),"Paola","Hal Saflieni Hypogeum","","Malta",0,0,1,0,0,['Artur']])
data_list.append([datetime.datetime(2024, 5, 20),"Valletta","City of Valletta", "", "Malta",381,0,1,0,0,['Artur']])
data_list.append([datetime.datetime(2024, 5, 20),"Valletta","City of Valletta", "", "Malta",71,0,1,0,0,['Artur']])
data_list.append([datetime.datetime(2024, 5, 31),"Fertoed","Fertoe - Neusiedlersee Cultural Landscape","","Hungary",118,0,1,0,0,[]])
data_list.append([datetime.datetime(2024, 6, 22),"Krems an der Donau","Wachau Cultural Landscape","","Austria",51,0,1,0,0,[]])
data_list.append([datetime.datetime(2024, 6, 22),"Stein an der Donau","Wachau Cultural Landscape","","Austria",1,0,1,0,0,[]])
data_list.append([datetime.datetime(2024, 6, 22),"Traismauer","Frontiers of the Roman Empire – The Danube Limes","","Austria",5,0,1,0,0,[]])
data_list.append([datetime.datetime(2024, 6, 23),"Krems an der Donau","Wachau Cultural Landscape","","Austria",135,0,1,0,0,[]])
data_list.append([datetime.datetime(2024, 6, 29),"Spitz an der Donau","Wachau Cultural Landscape","","Austria",69,0,1,0,0,[]])
data_list.append([datetime.datetime(2024, 6, 29),"Oberarnsdorf","Wachau Cultural Landscape","","Austria",8,0,1,0,0,[]])
data_list.append([datetime.datetime(2024, 6, 29),"Aggstein","Wachau Cultural Landscape","","Austria",49,0,1,0,0,[]])
data_list.append([datetime.datetime(2024, 6, 29),"St Lorenz","Frontiers of the Roman Empire – The Danube Limes","Wachau Cultural Landscape","Austria",1,0,1,0,0,[]])
data_list.append([datetime.datetime(2024, 6, 29),"St Lorenz","Wachau Cultural Landscape","","Austria",10,0,1,0,0,[]])
data_list.append([datetime.datetime(2024, 6, 29),"Weissenkirchen in der Wachau","Wachau Cultural Landscape","","Austria",25,0,1,0,0,[]])
data_list.append([datetime.datetime(2024, 6, 29),"Stein an der Donau","Wachau Cultural Landscape","","Austria",20,0,1,0,0,[]])
data_list.append([datetime.datetime(2024, 6, 29),"Mautern an der Donau","Frontiers of the Roman Empire – The Danube Limes","Wachau Cultural Landscape","Austria",4,0,1,0,0,[]])
data_list.append([datetime.datetime(2024, 6, 29),"Mautern an der Donau","Wachau Cultural Landscape","","Austria",5,0,1,0,0,[]])
data_list.append([datetime.datetime(2024, 7, 13),"Zeiselmauer","Frontiers of the Roman Empire – The Danube Limes","","Austria",7,0,1,0,0,[]])
data_list.append([datetime.datetime(2024, 7, 13),"Tulln","Frontiers of the Roman Empire – The Danube Limes","","Austria",1,0,1,0,0,[]])
data_list.append([datetime.datetime(2024, 7, 20),"Salzburg","Salzburg","","Austria",1,0,1,0,0,[]])
data_list.append([datetime.datetime(2024, 8, 2),"Salzburg","Salzburg","","Austria",1,0,1,0,0,[]])
data_list.append([datetime.datetime(2024, 8, 3),"Orange", "Theatre and Triumphal Arch of Orange", "","France",19,0,1,0,0,['Artur']])
data_list.append([datetime.datetime(2024, 8, 4),"Avignon", "Papal Palace, Episcopal Ensemble and Avignon Bridge", "","France",108,0,1,0,0,['Artur']])
data_list.append([datetime.datetime(2024, 8, 4),"Arles", "Arles, Roman and Romanesque Monuments", "Routes of Santiago de Compostela in France","France",113,20,1,0,0,['Artur']])
data_list.append([datetime.datetime(2024, 8, 4),"Vers-Pont-du-Gard", "Pont-du-Gard","",'France',9,0,1,0,0,['Artur']])
data_list.append([datetime.datetime(2024, 8, 4),"Orange", "Theatre and Triumphal Arch of Orange", "","France",19,0,1,0,0,['Artur']])
data_list.append([datetime.datetime(2024, 8, 5),"Vallon-Pont-d'Arc", "Decorated Cave of Pont d’Arc, known as Grotte Chauvet-Pont d’Arc, Ardeche", "","France",4,0,1,0,0,['Artur']])
data_list.append([datetime.datetime(2024, 8, 5),"Hures-la-Parade", "The Causses and the Cevennes, Mediterranean agro-pastoral Cultural Landscape", "","France",88,0,1,0,0,['Artur']])
data_list.append([datetime.datetime(2024, 8, 5),"Meyrueis", "The Causses and the Cevennes, Mediterranean agro-pastoral Cultural Landscape", "","France",100,0,1,0,0,['Artur']])
data_list.append([datetime.datetime(2024, 8, 6),"Meyrueis", "The Causses and the Cevennes, Mediterranean agro-pastoral Cultural Landscape", "","France",5,0,1,0,0,['Artur']])
data_list.append([datetime.datetime(2024, 8, 6),"St-Sauveur-Camprieu", "The Causses and the Cevennes, Mediterranean agro-pastoral Cultural Landscape", "","France",73,0,1,0,0,['Artur']])
data_list.append([datetime.datetime(2024, 8, 6),'St-Andre-de-Vezines', "The Causses and the Cevennes, Mediterranean agro-pastoral Cultural Landscape", "","France",2,0,1,0,0,['Artur']])
data_list.append([datetime.datetime(2024, 8, 6),"Albi", "Episcopal City of Albi", "","France",75 ,0,1,0,0,['Artur']])
data_list.append([datetime.datetime(2024, 8, 6),"Toulouse","Canal du Midi","","France",2,0,1,0,0,['Artur']])
data_list.append([datetime.datetime(2024, 8, 6),"Toulouse","Routes of Santiago de Compostela in France","","France",30,0,1,0,0,['Artur']])
data_list.append([datetime.datetime(2024, 8, 7),"Carcassonne", "Cite de Carcassonne", "","France",114 ,0,1,0,0,['Artur']])
data_list.append([datetime.datetime(2024, 8, 8),"Escaldes–Engordany", "Madriu-Perafita-Claror Valley", "","Andorra",2,0,1,0,0,[]])
data_list.append([datetime.datetime(2024, 8, 8),"Escaldes–Engordany", "Madriu-Perafita-Claror Valley", "","Andorra",54,0,1,0,0,['Artur']])
data_list.append([datetime.datetime(2024, 8, 9),"St Lizier", "Routes of Santiago de Compostela in France", "","France",62,0,1,0,0,['Artur']])
data_list.append([datetime.datetime(2024, 8, 10),"Gavarnie", "Routes of Santiago de Compostela in France", "","France",5,0,1,0,0,['Artur']])
data_list.append([datetime.datetime(2024, 8, 10),"Gavarnie", "Pyrenees - Mont Perdu", "","France",67,0,1,0,0,['Artur']])
data_list.append([datetime.datetime(2024, 8, 10),"Bordeaux","Bordeaux, Port of the Moon","Routes of Santiago de Compostela in France","France",73,42,1,0,0,['Artur']])
data_list.append([datetime.datetime(2024, 8, 10),"Bordeaux","Bordeaux, Port of the Moon","Routes of Santiago de Compostela in France","France",53,39,1,0,0,[]])
data_list.append([datetime.datetime(2024, 8, 11),"Le Verdon-sur-Mer", "Cordouan Lighthouse", "","France",63,0,1,0,0,['Artur']])
data_list.append([datetime.datetime(2024, 8, 11),"St Emilion", "Jurisdiction of Saint-Emilion", "","France",44,0,1,0,0,['Artur']])
data_list.append([datetime.datetime(2024, 8, 12),"St Emilion", "Jurisdiction of Saint-Emilion", "","France",48,0,1,0,0,['Artur']])
data_list.append([datetime.datetime(2024, 8, 12),"La Sauve", "Routes of Santiago de Compostela in France", "","France",48,0,1,0,0,['Artur']])
data_list.append([datetime.datetime(2024, 8, 12),"St-Avit-Senieur", "Routes of Santiago de Compostela in France", "","France",22,0,1,0,0,['Artur']])
data_list.append([datetime.datetime(2024, 8, 12),"Cadouin", "Routes of Santiago de Compostela in France", "","France",39,0,1,0,0,['Artur']])
data_list.append([datetime.datetime(2024, 8, 12),"Perigueux", "Routes of Santiago de Compostela in France", "","France",35,0,1,0,0,['Artur']])
data_list.append([datetime.datetime(2024, 8, 13),'Les Eyzies',"Prehistoric Sites and Decorated Caves of the Vezere Valley","","France",69,0,1,0,0,['Artur']])
data_list.append([datetime.datetime(2024, 8, 13),'Tours',"Loire Valley between Sully-sur-Loire and Chalonnes","","France",112,0,1,0,0,['Artur']])
data_list.append([datetime.datetime(2024, 8, 14),'Chambord',"Loire Valley between Sully-sur-Loire and Chalonnes","","France",102,0,1,0,0,['Artur']])
data_list.append([datetime.datetime(2024, 8, 14),"Chartres","Chartres Cathedral","","France",155,0,1,0,0,['Artur']])
data_list.append([datetime.datetime(2024, 8, 15),"Mont-Saint-Michel","Mont-Saint-Michel and its Bay","Routes of Santiago de Compostela in France","France",123,123,1,0,0,['Artur']])
data_list.append([datetime.datetime(2024, 8, 16),"Amiens","Amiens Cathedral","","France",131,0,1,0,0,['Artur']])
data_list.append([datetime.datetime(2024, 8, 16),"Amiens","Belfries of Belgium and France","","France",3,0,1,0,0,['Artur']])
data_list.append([datetime.datetime(2024, 8, 17),"Reims","Cathedral of Notre-Dame, Former Abbey of Saint-Remi and Palace of Tau","","France",209,0,1,0,0,['Artur']])
data_list.append([datetime.datetime(2024, 8, 17),"Reims","Champagne Hillsides, Houses and Cellars","","France",44,0,1,0,0,['Artur']])
data_list.append([datetime.datetime(2024, 8, 18),"Paris","Paris, Banks of the Seine","","France",226,0,1,0,0,["Artur"]])
data_list.append([datetime.datetime(2024, 8, 18),"Paris","Routes of Santiago de Compostela in France","","France",16,0,1,0,0,['Artur']])
data_list.append([datetime.datetime(2024, 8, 19),"Chalons-en-Champagne", "Routes of Santiago de Compostela in France", "","France",38,0,1,0,0,['Artur']])
data_list.append([datetime.datetime(2024, 8, 19),'Vezelay',"Vezelay, Church and Hill","Routes of Santiago de Compostela in France","France",98,0,1,0,0,['Artur']])
data_list.append([datetime.datetime(2024, 8, 19),"Marmagne","Fontenay Abbey","","France",38,0,1,0,0,['Artur']])
data_list.append([datetime.datetime(2024, 8, 19),"Dijon", "Climats, Terroirs of Burgundy", "","France",14,0,1,0,0,['Artur']])
data_list.append([datetime.datetime(2024, 8, 20),"Dijon", "Climats, Terroirs of Burgundy", "","France",69,0,1,0,0,['Artur']])
data_list.append([datetime.datetime(2024, 8, 20),"Besancon", "Fortifications of Vauban", "","France",24,0,1,0,0,['Artur']])
data_list.append([datetime.datetime(2024, 8, 21),"St Gallen","Abbey of St Gall","","Switzerland",84,0,1,0,0,['Artur']]) 
data_list.append([datetime.datetime(2024, 8, 30),"Amesbury", "Stonehenge, Avebury and Associated Sites", "","United Kingdom",37 ,0,1,0,0,[]])
data_list.append([datetime.datetime(2024, 8, 30),"Bath", "Bath", "The Great Spa Towns of Europe","United Kingdom",77,77,1,0,0,['Artur']])
data_list.append([datetime.datetime(2024, 8, 30),"Bath", "Bath", "The Great Spa Towns of Europe","United Kingdom",10,10,1,0,0,[]])
data_list.append([datetime.datetime(2024, 8, 31),"Woodstock", "Blenheim Palace", "","United Kingdom",95 ,0,1,0,0,['Artur']])
data_list.append([datetime.datetime(2024, 9, 1),"London", "Kew Gardens", "","United Kingdom",75 ,0,1,0,0,['Artur']])
data_list.append([datetime.datetime(2024, 9, 13),"Weesp", "Dutch Water Defence Lines", "","Netherlands",20 ,0,1,0,0,[]])
data_list.append([datetime.datetime(2024, 9, 13),"Muiden", "Dutch Water Defence Lines", "","Netherlands",58 ,0,1,0,0,[]])
data_list.append([datetime.datetime(2024, 9, 13),"Utrecht", "Dutch Water Defence Lines", "","Netherlands",2 ,0,1,0,0,[]])
data_list.append([datetime.datetime(2024, 9, 13),"Utrecht", "Rietveld Schroeder House", "","Netherlands",33 ,0,1,0,0,[]])
data_list.append([datetime.datetime(2024, 9, 14),"Rotterdam", "Van Nellefabriek", "","Netherlands",44 ,0,1,0,0,[]])
data_list.append([datetime.datetime(2024, 9, 15),"Amsterdam","Seventeenth-Century Canal Ring Area","","Netherlands",180,0,1,0,0,[]])
data_list.append([datetime.datetime(2024, 9, 16),"Kinderdijk","Mill Network at Kinderdijk-Elshout","","Netherlands",90,0,1,0,0,[]])

# %%
df = pd.DataFrame(data_list,columns=['Date', 'Place', 'UNESCO World Heritage Site','Secondary Site','Country','Picture Count','Secondary Picture Count',"Cultural Site","Natural Site","Site Removed","Co-Travellers"])
df.to_csv("../data/data_UNESCO_World_Heritage_VisitInfo.csv")

# %%
df=pd.read_csv("../data/data_UNESCO_World_Heritage_VisitInfo.csv",index_col=0)
df.sort_values(by=["Co-Travellers","Date"]).tail(40)
# Out:
#             Date                         Place  \
# 1035  2024-05-02                    Canterbury
# 1036  2024-05-03                       Stavely
# 1037  2024-05-03                    Windermere
# 1038  2024-05-03                     Ambleside
# 1039  2024-05-03                         Rydal
# 1040  2024-05-03                      Grasmere
# 1041  2024-05-04                 West Lulworth
# 1042  2024-05-09                        Idrija
# 1043  2024-05-09                     Ljubljana
# 1044  2024-05-11                       Skocjan
# 1045  2024-05-12                     Ljubljana
# 1053  2024-05-31                       Fertoed
# 1054  2024-06-22            Krems an der Donau
# 1055  2024-06-22            Stein an der Donau
# 1056  2024-06-22                    Traismauer
# 1057  2024-06-23            Krems an der Donau
# 1058  2024-06-29            Spitz an der Donau
# 1059  2024-06-29                  Oberarnsdorf
# 1060  2024-06-29                      Aggstein
# ...

# %%
df['UNESCO World Heritage Site'].nunique()
# Out:
# 357

# %%
df['Date']=pd.to_datetime(df['Date'])
df['Year']=df['Date'].dt.year
df["firstDateVisited"]=df.groupby('UNESCO World Heritage Site')['Date'].transform(lambda x:x.min())

# %%
#main style, secondary style, third style
#main culture, secondary, third
#main natural reason, second third
#total people list

data_style_list=[]
data_style_list.append(["Ibiza City","gothic","baroque","fortification",["Hannsjoerg","Artur","Heidrun",'Anne-Kathrin','Jan-Marc']])
data_style_list.append(["Trier","roman","romanesque","gothic",["Hannsjoerg","Artur","Heidrun",'Anne-Kathrin','Jan-Marc']])
data_style_list.append(["Luxembourg City","fortification","baroque","classicist",["Hannsjoerg","Artur","Heidrun",'Anne-Kathrin','Jan-Marc']])
#1996
data_style_list.append(["Palace of Westminster and Westminster Abbey including Saint Margaret’s Church","gothic","neo-gothic","",["Hannsjoerg","Artur","Heidrun",'Anne-Kathrin','Jan-Marc']])
data_style_list.append(["Tower of London","romanesque","","",["Hannsjoerg","Artur","Heidrun",'Anne-Kathrin','Jan-Marc','Anne',"Sigi","Gianrico"]])
data_style_list.append(["Maritime Greenwich","baroque","renaissance","",["Hannsjoerg","Artur","Heidrun",'Anne-Kathrin','Jan-Marc']])
data_style_list.append(["Speyer Cathedral","romanesque","","",["Hannsjoerg","Artur","Heidrun",'Anne-Kathrin','Jan-Marc']])
data_style_list.append(["Upper Middle Rhine Valley","romanesque","gothic","river canyon",["Hannsjoerg","Artur","Heidrun",'Anne-Kathrin','Jan-Marc']])
#1997
data_style_list.append(["Rome","roman","baroque","renaissance",["Hannsjoerg","Artur","Heidrun",'Anne-Kathrin','Jan-Marc',"Amin","Riju","Bryan"]])
data_style_list.append(["Vatican City","renaissance","baroque","",["Hannsjoerg","Artur","Heidrun",'Anne-Kathrin','Jan-Marc']])
data_style_list.append(["Cologne Cathedral","gothic","neo-gothic","",['']])
data_style_list.append(["Paris, Banks of the Seine","gothic","baroque","industrial",["Hannsjoerg","Artur","Heidrun",'Anne-Kathrin','Jan-Marc',"Andrew","Eric","Chris L","Chris C","Chris B","Riju","Reyer","Christine","Nhi","Vivan","Sam","Michael"]])
data_style_list.append(["Palace and Park of Versailles","baroque","rococo","classicist",["Hannsjoerg","Artur","Heidrun",'Anne-Kathrin','Jan-Marc',"Andrew","Riju","Reyer","Christine"]])
#1999
data_style_list.append(["Athens Acropolis","greek","","",["Hannsjoerg","Artur","Heidrun",'Anne-Kathrin','Jan-Marc',"Riju","Amin","MaryAnn"]])
data_style_list.append(["Mykene","minoic","","",["Hannsjoerg","Artur","Heidrun",'Anne-Kathrin','Jan-Marc']])
data_style_list.append(["Sanctuary of Asklepios at Epidaurus",'greek',"","",["Hannsjoerg","Artur","Heidrun",'Anne-Kathrin','Jan-Marc']])
data_style_list.append(["Olympia","greek",'','',["Hannsjoerg","Artur","Heidrun",'Anne-Kathrin','Jan-Marc']])
data_style_list.append(["Delphi","greek","","",["Hannsjoerg","Artur","Heidrun",'Anne-Kathrin','Jan-Marc','Amin',"Riju"]])
#2000
data_style_list.append(["Bursa and Cumalikizik: the Birth of the Ottoman Empire","islamic","",'',["Hannsjoerg","Artur","Heidrun",'Anne-Kathrin']])
data_style_list.append(["Istanbul","islamic","byzantine","baroque",["Hannsjoerg","Artur","Heidrun",'Anne-Kathrin','Chris M']])
data_style_list.append(["Troy","bronze age","greek","",["Hannsjoerg","Artur","Heidrun",'Anne-Kathrin']])
data_style_list.append(["Pergamon and its Multi-Layered Cultural Landscape","greek","roman","byzantine",["Hannsjoerg","Artur","Heidrun",'Anne-Kathrin']])
data_style_list.append(["Ephesus","roman","byzantine","",["Hannsjoerg","Artur","Heidrun",'Anne-Kathrin','Boeni','Sigi',"Gianrico"]])
data_style_list.append(["Hierapolis-Pamukkale","sinter terrace","roman",'',["Hannsjoerg","Artur","Heidrun",'Anne-Kathrin']])
#2001
data_style_list.append(["Works of Antoni Gaudi","modernist",'','',['Riju',"Rachel"]])
data_style_list.append(["Pont-du-Gard","roman",'','',[]])
data_style_list.append(["Berlin Museumsinsel",'classicist','','',["Hannsjoerg","Artur","Heidrun",'Anne-Kathrin','Riju','Reyer',"Chris B"]])
data_style_list.append(["Palaces and Parks of Potsdam and Berlin","rococo",'classicist','',["Hannsjoerg","Artur","Heidrun",'Anne-Kathrin',"Riju","Reyer"]])
data_style_list.append(["Alhambra, Generalife and Albayzin", "islamic",'renaissance','',["Hannsjoerg","Artur","Heidrun",'Anne-Kathrin']])
data_style_list.append(["Cordoba", "islamic",'renaissance','',["Hannsjoerg","Artur","Heidrun",'Anne-Kathrin',"Manuel"]])
data_style_list.append(["Cathedral, Alcazar and Archivo de Indias in Seville", "gothic",'islamic',"renaissance",["Hannsjoerg","Artur","Heidrun",'Anne-Kathrin','Manuel']])
#2002
data_style_list.append(["San Gimignano", "gothic",'romanesque','',["Hannsjoerg","Artur","Heidrun",'Anne-Kathrin']])
data_style_list.append(["Siena", "gothic","","",["Hannsjoerg","Artur","Heidrun",'Anne-Kathrin']])
data_style_list.append(["Florence", "renaissance",'gothic','baroque',["Hannsjoerg","Artur","Heidrun",'Anne-Kathrin']])
data_style_list.append(["Piazza del Duomo, Pisa","romanesque","","",["Hannsjoerg","Artur","Heidrun",'Anne-Kathrin']])
data_style_list.append(["Marrakesh","islamic",'','',["Hannsjoerg","Artur","Heidrun",'Anne-Kathrin',"Riju","Cameron","Tony"]]) 
data_style_list.append(["Fez","islamic",'','',["Hannsjoerg","Artur","Heidrun",'Anne-Kathrin']])
data_style_list.append(["Meknes","islamic","","",["Hannsjoerg","Artur","Heidrun",'Anne-Kathrin']]) 
data_style_list.append(["Volubilis","roman",'','',["Hannsjoerg","Artur","Heidrun",'Anne-Kathrin']]) 
data_style_list.append(["Rabat, Modern Capital and Historic City: a Shared Heritage","islamic","modern",'',["Hannsjoerg","Artur","Heidrun",'Anne-Kathrin']]) 
#2003
#2004
data_style_list.append(["Tunis","islamic","","",['Gianrico','Sigi']])
data_style_list.append(["Carthage","roman","",'',['Gianrico','Sigi']])
#2005
data_style_list.append(["Memphis and its Necropolis – the Pyramid Fields from Giza to Dahshur","egypt","",'',['Artur','Heidrun','Hannsjoerg']])
data_style_list.append(["Ancient Thebes with its Necropolis","egypt","",'',['Artur','Heidrun','Hannsjoerg']])
data_style_list.append(["Nubian Monuments from Abu Simbel to Philae","egypt",'','',['Artur','Heidrun','Hannsjoerg']])
data_style_list.append(["Cairo","islamic",'','',['Artur','Heidrun','Hannsjoerg']])
data_style_list.append(["Belem","renaissance","","",['Artur','Heidrun','Hannsjoerg','Anne-Kathrin','David']])
#2008
data_style_list.append(["Dresden Elbe Valley","baroque","rococo","neo-renaissance",["Anne-Kathrin","Hannsjoerg","Artur","Heidrun"]])
data_style_list.append(["Abbey of St Gall","rococo","",'',["Artur","Heidrun","Anne-Kathrin","Hannsjoerg","Vivan","Sam","Grace","Dylan"]]) 
data_style_list.append(["Bern","gothic","renaissance","baroque",["Zhiling","Andrew","Riju"]]) 
data_style_list.append(["Independence Hall","classicist","","",[]])
data_style_list.append(["El Escorial Monastery","renaissance","baroque",'',["Hannsjoerg","Artur","Heidrun","Manuel"]])
data_style_list.append(["Paseo del Prado and Buen Retiro", "classicist","revival style","modernist",['Hannsjoerg','Artur','Heidrun',"Manuel"]])
data_style_list.append(["Segovia","gothic","roman","",['Heidrun',"Manuel"]])
data_style_list.append(["Jungfrau-Aletsch","glaciers","waterfalls","canyons",["Anne","Sigi","Indara","Hannsjoerg",'Artur',"Heidrun","Anne-Kathrin","Jan-Marc","Andrew","Riju","Tema","Sasha","Juno","Jose","Francesca","Chris B","Ivan","Ulrike","Sam"]])
#2009
data_style_list.append(["Reichenau","romanesque","","",["Hannsjoerg","Artur","Heidrun","Anne-Kathrin","Jan-Marc","Sam","Grace","Dylan","Vivan"]]) 
data_style_list.append(["Toledo","gothic","baroque","islamic","Manuel"]) 
data_style_list.append(["Statue of Liberty","statue","",'',[]])
data_style_list.append(["Castles of Bellinzona","romanesque","",'',[""]])
data_style_list.append(["Wieskirche","rococo","",'',["Hannsjoerg","Heidrun","Artur","Anne-Kathrin","Jan-Marc","Indara","Eric","Chris B","Reyer"]])
data_style_list.append(["Chartres Cathedral","gothic","",'',["Reyer",'Artur']])
data_style_list.append(["Palace and Park of Fontainebleau",'renaissance',"classicist",'baroque',['Artur','Heidrun',"Andrew","Riju","Chris B"]])
#2011
data_style_list.append(["Santa Maria delle Grazie with The Last Supper","renaissance","gothic","",['Hannsjoerg',"Andrew","Nick","Riju"]])
data_style_list.append(["Lyon","gothic","roman",'neo-byzantine',['Hannsjoerg',"Heidrun",'Artur',"Andrew",'Sasha','Bing']])
data_style_list.append(["Wuerzburg Residence","rococo","baroque",'',['Artur',"Heidrun","Chris B","Reyer"]])
data_style_list.append(["Bamberg","romanesque","baroque","renaissance",['Artur',"Heidrun","Chris B","Reyer"]])
data_style_list.append(["Vienna","baroque","gothic","revival",['Artur',"Heidrun",'Hannsjoerg',"Bob",'Riju','Grace','Rachel',
                            "Chris M",'Kevin','Janina','Grace','Sam','Sophie','Michael','Bing']])
data_style_list.append(["Gardens and Palace of Schoenbrunn","baroque","rococo","revival",['Artur',"Heidrun",'Hannsjoerg',
                                'Riju','Grace','Rachel',"Chris M",'Kevin','Janina','Grace','Sam','Sophie','Bing']])

#2012 #Canon EOS 600D
data_style_list.append(["Prague","gothic","baroque","revival",['Artur',"Heidrun"]])
data_style_list.append(["Loire Valley between Sully-sur-Loire and Chalonnes","renaissance","baroque",'gothic',['Artur',"Heidrun",'Hannsjoerg']])
data_style_list.append(['Vezelay',"romanesque","","",['Artur',"Heidrun",'Hannsjoerg']])
data_style_list.append(["Prehistoric Pile Dwellings around the Alps","bronze age","","",['Artur',"Heidrun",'Hannsjoerg']])
data_style_list.append(["Palace of Mafra","baroque","","",[]])
data_style_list.append(["Cultural Landscape of Sintra","revival","gothic","",["Artur",'Heidrun',"Hannsjoerg","Anne-Kathrin"]])
data_style_list.append(["Convent of Christ in Tomar","renaissance","gothic","",[]])
data_style_list.append(["Porto","baroque","gothic",'revival',['Artur']])
data_style_list.append(["University of Coimbra – Alta and Sofia","baroque","gothic","",[]])
data_style_list.append(["Krakow","gothic",'renaissance',"",['Eric','Artur']])
data_style_list.append(["Warsaw","baroque","gothic",'',['Eric']])

#2013
data_style_list.append(["Seventeenth-Century Canal Ring Area","renaissance","baroque","",["Artur","Heidrun","Hannsjoerg","Mohammed"]])
data_style_list.append(["Routes of Santiago de Compostela in France","gothic","romanesque","modernist",['Andrew',"Riju","Chris B","Santona","Eric",'Chris L',"Chris C","Reyer","Christine",'Nhi',"Vivan",'Sam',"Michael","Jan-Marc","Heidrun","Artur","Anne-Kathrin","Hannsjoerg"]])
data_style_list.append(["Villa d'Este", "renaissance","",'',['Heidrun',"Bryan"]])
data_style_list.append(["Villa Adriana", "roman","",'',['Heidrun',"Bryan"]])
data_style_list.append(["Lavaux","vineyards","cultural","",['Hannsjoerg',"Heidrun","Artur","Anne-Kathrin","Christian","Andrew","Xuan","Will"]])
data_style_list.append(["Royal Domain of Drottningholm","baroque","",'',[]])
data_style_list.append(["Kronborg",'renaissance',"","",[]])
data_style_list.append(["Venice and its Lagoon","renaissance","baroque",'byzantine',['Riju',"Reyer","Indara"]])
data_style_list.append(["Strassbourg", "gothic", "baroque","revival",['Hannsjoerg','Artur','Heidrun']])
#2014
data_style_list.append(["Kew Gardens","botanical garden",'','',['Artur',"Heidrun",'Hannsjoerg','Anne-Kathrin']])
data_style_list.append(["Blenheim Palace", "baroque","",'',['Artur',"Heidrun",'Hannsjoerg']])
data_style_list.append(["Canterbury Cathedral, St Augustine's Abbey, and St Martin's Church", "gothic","","",['Artur',"Heidrun",'Hannsjoerg']])
data_style_list.append(["Stonehenge, Avebury and Associated Sites", "prehistoric","",'',['Artur',"Heidrun",'Hannsjoerg']])
data_style_list.append(["Bath", "gothic",'classicist','roman',['Artur',"Heidrun",'Hannsjoerg']])
data_style_list.append(["Fertoe - Neusiedlersee Cultural Landscape","lake","baroque","",[]])
data_style_list.append(["Budapest, including the Banks of the Danube, the Buda Castle Quarter and Andrassy Avenue","neo-baroque","neo-gothic",'modernism',['Artur','Chris M']])
data_style_list.append(["Medici Villas and Gardens","renaissance",'',"",['Artur','Heidrun','Hannsjoerg','Anne-Kathrin']])
data_style_list.append(["Porticoes of Bologna", "renaissance","baroque",'romanesque',[]])
data_style_list.append(["Medina Azahara", "islamic",'','',['Manuel']])
data_style_list.append(["Aranjuez Cultural Landscape", "baroque","",'',['Eric']])
data_style_list.append(["Pompei, Herculaneum and Torre Annunziata","roman","",'',['AJ','Stephan',"Artur","Heidrun"]])
data_style_list.append(["Naples","baroque","renaissance",'gothic',['AJ','Stephan',"Artur","Heidrun"]])
data_style_list.append(["Reggia di Caserta","classicist","","",['AJ','Stephan',"Artur","Heidrun"]])
data_style_list.append(["Mont-Saint-Michel and its Bay","gothic","romanesque","",['Artur']])
data_style_list.append(["Nice, capital of Riviera tourism","baroque","revival","classicist",[]])
data_style_list.append(["Petersburg and Related Groups of Monuments","baroque","classicist","revival",["Manuel"]])
data_style_list.append(["Kremlin and Red Square","byzantine","baroque","gothic",['Manuel']])
data_style_list.append(["Routes of Santiago de Compostela: Camino Frances and Routes of Northern Spain","gothic","romanesque","",[]])
data_style_list.append(["Wachau Cultural Landscape","baroque","gothic","",['Eric','Siyi']])
data_style_list.append(["Salzburg","baroque","gothic","",['Eric','Siyi','Vivan','Michael']])
data_style_list.append(["Hamburg Speicherstadt","industrial","","",['Heidrun','Artur','Anne-Kathrin']])
data_style_list.append(["Luebeck","gothic","","",[]])
data_style_list.append(["Classical Weimar","classicist","rococo","baroque",['Artur','Hannsjoerg','Anne-Kathrin','Heidrun','Jan-Marc']])

#2016
data_style_list.append(["Mount Etna","volcano","mountain","cave",['Artur','Heidrun']])
data_style_list.append(["Villa Romana del Casale","roman","","",['Artur','Heidrun']])
data_style_list.append(["Arab-Norman Palermo and the Cathedral Churches of Cefalu and Monreale","romanesque","byzantine","",['Artur','Heidrun']])
data_style_list.append(["Archaeological Area of Agrigento","greek","","",['Artur','Heidrun']])
data_style_list.append(["Late Baroque Towns of the Val di Noto","baroque","","",['Artur','Heidrun']])
data_style_list.append(["Syracuse and the Rocky Necropolis of Pantalica","greek","roman","necropolis & stone quarry",['Artur','Heidrun']])
data_style_list.append(["Palau de la Musica Catalana and Hospital de Sant Pau","modernist","","",['Riju']])
data_style_list.append(["Mudejar Architecture of Aragon","gothic","mujedar","",['Riju']])
data_style_list.append(["Residences of the Royal House of Savoy","baroque","rococo","",[]])
data_style_list.append(["Genoa: Le Strade Nuove and the system of the Palazzi dei Rolli","baroque","","",['Amin']])
data_style_list.append(["Cinque Terre","coast","cliffs","village",['Amin']])
data_style_list.append(["Cave of Altamira and Paleolithic Cave Art of Northern Spain","cave paintings","pre-historic","",[]])
data_style_list.append(["Burgos Cathedral","gothic","","",[]])
data_style_list.append(["Early Christian Monuments of Ravenna","early christian","byzantine","",['Keyvan']])
data_style_list.append(["Padova Urbs picta","gothic","","",[]])
data_style_list.append(["Orto Botanico of Padua","garden","park","",[]])
data_style_list.append(["Bordeaux, Port of the Moon","classicist","baroque","gothic",['Artur','Heidrun','Anne-Kathrin']])
data_style_list.append(["Grand-Place, Brussels","gothic","renaissance","baroque",[]])
data_style_list.append(["Stoclet House","modernist","","",[]])
data_style_list.append(["Aachen Cathedral","karolingian","gothic","",[]])
data_style_list.append(["Major Town Houses of the Architect Victor Horta","modernist","","",[]])
data_style_list.append(["Grand Canyon National Park","canyon","desert wildlife","",['Artur','Hannsjoerg','Heidrun']])
data_style_list.append(["Mesa Verde National Park","native american","canyon","",['Artur','Hannsjoerg','Heidrun']])
data_style_list.append(["Santiago de Compostela (Old Town)","romanesque","baroque","",[]])
data_style_list.append(["Castles of Augustusburg and Falkenlust at Bruehl","rococo",'baroque','',[]])
data_style_list.append(["Mantua and Sabbioneta","renaissance",'baroque','',['Riju']])
data_style_list.append(["Verona",'romanesque','roman','gothic',['Riju']])
data_style_list.append(["Hiraizumi – Temples, Gardens and Archaeological Sites Representing the Buddhist Pure Land","east asian",'japanese',"temple",[]])
data_style_list.append(["Shrines and Temples of Nikko","east asian",'japanese',"temple",[]])
data_style_list.append(["Historic Monuments of Ancient Kyoto (Kyoto, Uji and Otsu Cities)","east asian",'japanese',"temple",[]])
data_style_list.append(["Historic Monuments of Ancient Nara","east asian",'japanese',"temple",[]])
data_style_list.append(["Buddhist Monuments in the Horyu-ji Area","east asian",'japanese',"temple",[]])
data_style_list.append(["Hiroshima Peace Memorial (Genbaku Dome)","anti atomb-bomb",'anti-war','revival',[]])
data_style_list.append(["Himeji-jo","east asian",'japanese',"castle",[]])
data_style_list.append(["Itsukushima Shinto Shrine","east asian",'japanese',"temple",[]])
data_style_list.append(["Corbusier","brutalist",'','',['Reyer','Xuan','Andrew','Will']])
#2017
data_style_list.append(["Giant's Causeway and Causeway Coast", "basalt columns","coast","volcano",['Chris Martin']])
data_style_list.append(["Canal du Midi", "canal",'waterway','',['Artur']])
data_style_list.append(["Cite de Carcassonne", "romanesque",'gothic','',['Artur']])
data_style_list.append(["Papal Palace, Episcopal Ensemble and Avignon Bridge", "gothic",'','',['Artur']])
data_style_list.append(["Bruges",'gothic','renaissance','revival',[]])
data_style_list.append(["Belfries of Belgium and France","gothic",'baroque','revival',['Riju','Artur','Reyer']])
data_style_list.append(["Assisi","gothic","baroque","",[]])
data_style_list.append(["Saint-Sophia Cathedral and Kyiv-Pechersk Lavra","byzantine",'baroque','',[]])
data_style_list.append(["Bergpark Wilhelmshoehe","landscape garden",'classicist','revival',[]])
data_style_list.append(["Salamanca","renaissance","gothic",'baroque',[]])
data_style_list.append(["Llotja de la Seda","gothic","",'',[]])
data_style_list.append(["Monuments of Oviedo and the Kingdom of the Asturias","romanesque","",'',[]])
data_style_list.append(["Old Town of Avila with its Extra-Muros Churches","roman",'gothic','romanesque',[]])
data_style_list.append(["Vatnajoekuell","glacier","volcano",'',[]])
data_style_list.append(["Yellowstone National Park","volcano","waterfalls",'canyon',['Artur','Heidrun','Hannsjoerg']])
data_style_list.append(["City of Vicenza and the Palladian Villas of the Veneto","renaissance","",'',[]])
data_style_list.append(["Ferrara, City of the Renaissance, and its Po Delta","renaissance","river delta",'gothic',[]])
data_style_list.append(["Skocjan Caves","cave","river canyon","",['Reyer']])
data_style_list.append(["Euphrasien Basilica","byzantine",'early christian','romanesque',['Reyer']])
data_style_list.append(["Archaeological Area and the Patriarchal Basilica of Aquileia","early christian",'roman','romanesque',['Reyer']])
data_style_list.append(["Longobards in Italy","romanesque",'early christian','',['Reyer']])
data_style_list.append(["Trogir","romanesque","gothic",'',[]])
data_style_list.append(["Historical Complex of Split with the Palace of Diocletian","roman","",'',[]])
data_style_list.append(["Graz","gothic",'baroque','',['Artur']])
data_style_list.append(["Suomenlinna","fortification","",'',['Riju','Reyer','Rachel']])
data_style_list.append(["Tallinn","gothic",'','',['Riju','Reyer','Rachel']])
data_style_list.append(["Ait-Ben-Haddou","fortification","desert fortress","",['Riju','Tony','Cameron']])
data_style_list.append(["Fontenay Abbey","romanesque",'','',['Andrew','Artur']])
data_style_list.append(["From the Great Saltworks of Salins-les-Bains to the Royal Saltworks of Arc-et-Senans, the Production of Open-pan Salt","baroque",'',"",['Andrew']])
data_style_list.append(["Fortifications of Vauban","fortification","baroque",'',['Andrew','Artur']])
data_style_list.append(["City of Luxembourg: its Old Quarters and Fortifications","fortification","baroque",'',['Artur','Heidrun','Anne-Kathrin','Hannsjoerg','Jan-Marc']])
data_style_list.append(["The Grand Canal", "canal","waterway",'',[]])
data_style_list.append(["West Lake of Hangzhou", "east asian","chinese",'lake',[]])
data_style_list.append(["Classical Gardens of Suzhou", "east asian","chinese","garden",[]])
data_style_list.append(["Imperial Tombs of the Ming and Qing Dynasties", "east asian","chinese",'tomb',['Siyi','Zhicheng']])
data_style_list.append(["The Great Wall", "east asian","chinese",'fortification',[]])
data_style_list.append(["Temple of Heaven in Beijing", "east asian","chinese",'',[]])
data_style_list.append(["Summer Palace in Beijing","east asian","chinese",'',[]])
data_style_list.append(["Longmen Grottoes", "east asian","chinese",'',[]])
data_style_list.append(["Mausoleum of the First Qin Emperor", "east asian","chinese",'tomb',[]])
data_style_list.append(["Silk Roads: the Routes Network of Chang'an-Tianshan Corridor","east asian","chinese",'',[]])
data_style_list.append(["Macao", "classicist", "colonist architecture","",[]])
data_style_list.append(["Episcopal City of Albi", "gothic",'','',['Artur']])
data_style_list.append(["Thingvellir National Park","old parliament","rock","",['Rachel','Riju','Reyer']])
data_style_list.append(["Roskilde Cathedral","gothic","","",['Rachel','Riju','Reyer']])
data_style_list.append(["Cathedral of Notre-Dame, Former Abbey of Saint-Remi and Palace of Tau","gothic",'','',['Christine','Reyer']])
data_style_list.append(["Champagne Hillsides, Houses and Cellars","cellars","vine making",'',['Christine','Reyer']])
data_style_list.append(["Amiens Cathedral","gothic","","",['Reyer','Artur']])
data_style_list.append(["Venetian Works of Defence between the 16th and 17th Centuries","fortification","baroque",'',['Amin']])
data_style_list.append(["San Marino","fortification","gothic","",['Amin']])
data_style_list.append(["Archaeological Ensemble of Tarraco","roman","",'',[]])
data_style_list.append(["Edinburgh","gothic",'baroque','',[]])
data_style_list.append(["Forth Bridge","industrial","bridge",'railway',['Artur','Heidrun']])
data_style_list.append(["Frontiers of the Roman Empire","roman","fortification",'',['Artur','Heidrun']])
data_style_list.append(["Durham Castle and Cathedral","romanesque","","",['Artur','Heidrun']])
data_style_list.append(["Studley Royal Park including the Ruins of Fountains Abbey","gothic","baroque",'',['Artur','Heidrun']])
data_style_list.append(["Castles and Town Walls of King Edward in Gwynedd","romanesque","",'',['Artur','Heidrun']])
data_style_list.append(["Liverpool – Maritime Mercantile City","revival","",'',['Artur','Heidrun']])
data_style_list.append(["Changdeokgung Palace","east asian","korean",'',['Eva','Ulrike']])
data_style_list.append(["Jongmyo Shrine","east asian","korean",'',[]])
data_style_list.append(["Royal Tombs of the Joseon Dynasty","east asian","korean",'tomb',[]])
data_style_list.append(["Hwaseong Fortress","east asian","korean",'fortificaion',[]])
data_style_list.append(["Namhansanseong","east asian","korean",'fortification',[]])
data_style_list.append(["Seokguram Grotto and Bulguksa Temple","east asian","korean",'temple',['Stephanie','Steffen']])
data_style_list.append(["Historic Villages of Korea: Hahoe and Yangdong",'village architecture',"east asian","korean",['Stephanie','Steffen']])
data_style_list.append(["Gyeongju Historic Areas","tomb","","",['Stephanie','Steffen']])
data_style_list.append(["Regensburg","gothic",'baroque',"",['Reyer','Chris Brainerd']])
data_style_list.append(["Margravial Opera House Bayreuth","baroque","",'',['Reyer','Chris Brainerd','Artur','Hannsjoerg','Jennet']])
data_style_list.append(["Wartburg","romanesque","",'',['Reyer','Chris Brainerd']])
data_style_list.append(["Ancient and Primeval Beech Forests of the Carpathians and Other Regions of Europe","forest","",'',['Reyer','Chris Brainerd']])
data_style_list.append(["Naumburg Cathedral","romanesque",'gothic','',['Reyer','Chris Brainerd']])
data_style_list.append(["Bauhaus and its Sites in Weimar, Dessau and Bernau","industrial","",'',['Reyer','Chris Brainerd']])
data_style_list.append(["Garden Kingdom of Dessau-Wörlitz","landscape garden","classcist",'baroque',['Reyer','Chris Brainerd']])
data_style_list.append(["Luther Memorials","reformation",'','',['Reyer','Chris Brainerd']])
data_style_list.append(["Quedlinburg","romanesque","gothic",'',['Reyer','Chris Brainerd']])
data_style_list.append(["Flemish Beguinages", "village architecture","",'',['Rachel']])
data_style_list.append(["Arles, Roman and Romanesque Monuments", "roman","romanesque",'',['Santona','Artur']])
data_style_list.append(["Theatre and Triumphal Arch of Orange", "roman","",'',['Santona','Artur']])
data_style_list.append(["Climats, Terroirs of Burgundy", "gothic","vineyards",'',['Santona','Yao Yao','Graham','Chris Brainerd','Artur']])
data_style_list.append(["Maulbronn Monastery", "gothic","",'',['Artur','Heidrun']])
data_style_list.append(["Voelklingen Ironworks", "industrial","iron works",'',['Artur','Heidrun']])
data_style_list.append(["Abbey of Lorsch", "karolingian","",'',['Artur','Heidrun']])
#2019
data_style_list.append(["Sacri Monti of Piedmont and Lombardy", "classicist","baroque","",[]])
data_style_list.append(["Sassi of Matera","romanesque","gothic",'',['Artur','Heidrun']])
data_style_list.append(["Castel del Monte","romanesque","",'',['Artur','Heidrun']])
data_style_list.append(["Trulli of Alberobello","village architecture","traditional",'',['Artur','Heidrun']])
data_style_list.append(["Cilento and Vallo di Diano National Park with the Archeological Sites of Paestum and Velia, and the Certosa di Padula","greek","gothic","mountains",['Artur','Heidrun']])
data_style_list.append(["Amalfi Coast","coast","cliffs","romanesque",['Artur','Heidrun']])
data_style_list.append(["Abbey Church of St Savin","romanesque","","",['Riju','Chris Brainerd']])
data_style_list.append(["Provins","romanesque",'gothic',"",['Riju','Chris Brainerd']])
data_style_list.append(["Bourges Cathedral","gothic","",'',[]])
data_style_list.append(["Le Havre","brutalist","",'',['Riju','Chris Brainerd']])
data_style_list.append(["Corvey Monastery","carolingian","baroque",'',['Grace']])
data_style_list.append(["Fagus Factory","industrial","","",['Grace']])
data_style_list.append(["St Mary's Cathedral and St Michael's Church at Hildesheim","romanesque","",'',['Grace']])
data_style_list.append(["City Hall Bremen","renaissance","","",['Grace']])
data_style_list.append(["Wadden Sea","tidal sea","sea","",['Grace']])
data_style_list.append(["Goslar and Rammelsberg","mine","gothic",'romanesque',['Grace']])
#2020
data_style_list.append(["Muskauer Park","landscape garden","",'',['Artur']])
data_style_list.append(["Churches of Peace in Slesia","baroque","","",['Artur']])
data_style_list.append(["Wieliczka and Bochnia Royal Salt Mines","mine","","",['Artur']])
data_style_list.append(["Centennial Hall","industrial",'',"",['Artur']])  
data_style_list.append(["Urbino", "renaissance", "","",[]])
data_style_list.append(["Pienza", "renaissance",'','',[]])
data_style_list.append(["Val d'Orcia", "vineyards","fields","",[]])
#2021
data_style_list.append(["The Great Spa Towns of Europe", "classicist",'revival',"",['Artur',"Anne-Kathrin",'Christian',"Mathilda"]])
data_style_list.append(["Hallstatt-Dachstein/Salzkammergut","mine","mountain lake",'caves',['Artur']])
data_style_list.append(["Semmering Railway","railway",'industrial',"",[]])
data_style_list.append(["Trier","roman","romanesque",'gothic',['Artur','Anne-Kathrin','Heidrun','Jan-Marc','Hannsjoerg']])
data_style_list.append(["Place Stanislas, Place de la Carriere and Place d'Alliance",'baroque',"classicist","",[]])
data_style_list.append(["Tournai Cathedral",'romanesque',"gothic","",[]])
data_style_list.append(["Nord-Pas de Calais Mining Basin","industrial","","",[]])
data_style_list.append(["ShUM Sites of Speyer, Worms and Mainz","romanesque",'gothic','',[]])
data_style_list.append(["Mathildenhoehe","modernist",'','',[]])
data_style_list.append(["Zollverein Coal Mine Industrial Complex in Essen","industrial","","",[]])
#2022
data_style_list.append(["Millenary Benedictine Abbey of Pannonhalma and its Natural Environment","classicist","baroque","neo-gothic",[]])
data_style_list.append(["Renaissance Monumental Ensembles of Ubeda and Baeza","renaissance","","",[]])
data_style_list.append(["Old Town of Caceres","gothic","renaissance","islamic",[]])
data_style_list.append(["Archaeological Ensemble of Merida","roman","islamic","romanesque",[]])
data_style_list.append(["Historic Walled Town of Cuenca","gothic","","",[]])
data_style_list.append(["University and Historic Precinct of Alcala de Henares","renaissance","baroque","",[]])
data_style_list.append(["Historic Centres of Stralsund and Wismar","gothic","","",[]])
data_style_list.append(["Berlin Modernism Housing Estates",'modern',"","",[]])
data_style_list.append(["Erzgebirge/Krusnohori Mining Region",'mine',"gothic","",[]])
data_style_list.append(["Cesky Krumlov",'baroque',"renaissance","",[]])
data_style_list.append(["Gardens and Castle at Kromeriz","baroque","","",[]])
data_style_list.append(["Holy Trinity Column of Olomouc","baroque","","",[]])
data_style_list.append(["Cathedral, Torre Civica and Piazza Grande, Modena","romanesque","","",[]])
data_style_list.append(["Kutna Hora: Historical Town Centre with the Church of St Barbara and the Cathedral of Our Lady at Sedlec","gothic","mine","",[]])
data_style_list.append(["Lednice-Valtice Cultural Landscape","neo-gothic",'landscape garden','baroque',[]])
data_style_list.append(["Pilgrimage Church of St John of Nepomuk at Zelena Hora","baroque","gothic","",[]])
data_style_list.append(["Tugendhat Villa in Brno","modern","","",[]])
data_style_list.append(["Historic Centre of Riga","modernist","gothic","",['Artur']])
data_style_list.append(["Vilnius Historic Centre","baroque","classicist","renaissance",['Artur']])
data_style_list.append(["Jewish Quarter and St Procopius' Basilica in Trebic","romanesque","gothic","",[]])
data_style_list.append(["Litomysl Castle","renaissance","classicist","",[]])
data_style_list.append(["Medieval Town of Torun","gothic","","",[]])
data_style_list.append(["Castle of the Teutonic Order in Malbork","gothic","",'',[]])
data_style_list.append(["Caves and Ice Age Art in the Swabian Jura","cave","","",[]])
data_style_list.append(["Benedictine Convent of St John at Muestair","karolingian","romanesque","",[]])
#2023
data_style_list.append(["Sanctuary of Bom Jesus do Monte in Braga","baroque","classicist","",['Artur']])
data_style_list.append(["Historic Centre of Guimaraes","gothic","baroque","",['Artur']])
data_style_list.append(["Monastery of Batalha","gothic","","",[]])
data_style_list.append(["Monastery of Alcobaca","gothic","","",[]])
data_style_list.append(["Historic Centre of Evora","renaissance","gothic","baroque",[]])
data_style_list.append(["Garrison Border Town of Elvas and its Fortifications","fortification","baroque",'',[]])
data_style_list.append(["Tarnowskie Gory Lead-Silver-Zinc Mine and its Underground Water Management System","mine","","",[]])
data_style_list.append(["Auschwitz Birkenau German Nazi Concentration and Extermination Camp (1940-1945)","historical place","",'',[]])
data_style_list.append(["Kalwaria Zebrzydowska: the Mannerist Architectural and Park Landscape Complex and Pilgrimage Park","Baroques","",'',[]])
data_style_list.append(["Engelsberg Ironworks","industrial","","",[]])   
data_style_list.append(["Skogskyrkogarden","cemetery","","",[]]) 
data_style_list.append(["Mining Area of the Great Copper Mountain in Falun","mine","","",[]])
data_style_list.append(["Boyana Church","byzantine","","",[]]) 
data_style_list.append(["Rila Monastery","neo-byzanine","","",[]]) 
data_style_list.append(["The par force hunting landscape in North Zealand","hunting ground","","",[]]) 
data_style_list.append(["Stevns Klint","cliff","coast","fossile",[]]) 
data_style_list.append(["Messel Pit Fossil Site","fossile","volcano","",[]]) 
data_style_list.append(["Historic Town of Banska Stiavnica and the Technical Monuments in its Vicinity","mine","baroque","",['Artur']])
data_style_list.append(["Wooden Churches of the Slovak part of the Carpathian Mountain Area","baroque","",'',['Artur']])
data_style_list.append(["Vlkolinec","village architecture","",'',['Artur']])
data_style_list.append(["Levoca, Spissky Hrad and the Associated Cultural Monuments","gothic","renaissance",'',['Artur']])   
data_style_list.append(["Bardejov Town Conservation Reserve","renaissance","gothic",'baroque',['Artur']])      
data_style_list.append(["Wooden Churches of Southern Malopolsk","baroque","renaissance",'gothic',['Artur']])  
data_style_list.append(["Wooden Tserkvas of the Carpathian Region in Poland and Ukraine","russian renaissance","renaissance",'baroque',['Artur']])  
data_style_list.append(["Caves of Aggtelek Karst and Slovak Karst",'cave','','',['Artur']])  
data_style_list.append(["Tokaj Wine Region Historic Cultural Landscape",'vineyards','cultural','',['Artur']])  
data_style_list.append(["Hortobagy National Park - the Puszta",'grassland','wetlands','',['Artur']])  
data_style_list.append(["Early Christian Necropolis of Pecs (Sopianae)",'early christian','mausoleum','',['Artur']]) 
data_style_list.append(["Historic Centre of Telc",'renaissance','gothic','baroque',['Grace']])  
data_style_list.append(["Jewish-Medieval Heritage of Erfurt","romanesque",'gothic','',[]])
data_style_list.append(["Maison Carree of Nimes","roman",'','',['Santona']])
data_style_list.append(["Hanseatic Town of Visby","gothic",'romanesque','',[]])
data_style_list.append(["Agricultural Landscape of Southern Oeland","grassland",'agricultural setting','',[]])
data_style_list.append(["Naval Port of Karlskrona","baroque",'','',[]]) 
data_style_list.append(["La Chaux-de-Fonds/Le Locle, Watchmaking Town Planning","industrial",'','',[]]) 
#2024
data_style_list.append(["The Dolomites",'mountain','','',[]])  
data_style_list.append(["Paleochristian and Byzantine Monuments of Thessalonika",'byzantine','early christian','',['Artur']]) 
data_style_list.append(["Archaeological Site of Philippi",'greek','early christian','',['Artur']]) 
data_style_list.append(["Archaeological Site of Aigai",'greek','byzantine','',['Artur']]) 
data_style_list.append(["Natural and Cultural Heritage of the Ohrid region",'byzantine','lake','',['Artur']]) 
data_style_list.append(["Meteora",'rock formation','byzantine','',['Artur']]) 
data_style_list.append(["Saltaire","industrial","","",[]])  
data_style_list.append(["Hal Saflieni Hypogeum", "prehistoric","",'',['Artur']])
data_style_list.append(["The English Lake District", "lake","",'',[]])
data_style_list.append(["Dorset and East Devon Coast","cliff","coast","fossile",[]])
data_style_list.append(['Heritage of Mercury. Almaden and Idrija',"mine","","",[]])
data_style_list.append(["The works of Joze Plecnik in Ljubljana","modern","classicist","",[]])
data_style_list.append(["City of Valletta","baroque","","",['Artur']])
data_style_list.append(["Megalithic Temples of Malta","prehistoric","","",['Artur']])
data_style_list.append(["Cordouan Lighthouse","baroque","","",['Artur']])
data_style_list.append(["Jurisdiction of Saint-Emilion",'vineyards','cultural',"",['Artur']])
data_style_list.append(["Madriu-Perafita-Claror Valley",'mountain','',"",['Artur']])
data_style_list.append(["Prehistoric Sites and Decorated Caves of the Vezere Valley","prehistoric","cave","",['Artur']])
data_style_list.append(["The Causses and the Cevennes, Mediterranean agro-pastoral Cultural Landscape","agricultural setting",'caves','gorges',[]])
data_style_list.append(["Decorated Cave of Pont d’Arc, known as Grotte Chauvet-Pont d’Arc, Ardeche","prehistoric","cave","",['Artur']])
data_style_list.append(["Pyrenees - Mont Perdu","mountain","","",['Artur']])
data_style_list.append(["Dutch Water Defence Lines","fortification","","",[]])
data_style_list.append(["Rietveld Schroeder House","modern","","",[]])
data_style_list.append(["Van Nellefabriek","modern","industrial","",[]])
data_style_list.append(["Mill Network at Kinderdijk-Elshout","windmills","","",[]])


df_style = pd.DataFrame(data_style_list,columns=['UNESCO World Heritage Site','main style/reason','2nd main style/reason','3rd main style/reason',"Co-Travellers"])
df_style["Number of Co-Travellers"]=df_style["Co-Travellers"].str.len()
df_style.to_csv("data/picture_data_UNESCO_World_Heritage_StyleInfo.csv")

# %%
df_style.sort_values(by="Number of Co-Travellers",ascending=False).head(20)
# Out:
#                     UNESCO World Heritage Site main style/reason  \
# 54                            Jungfrau-Aletsch          glaciers
# 80  Routes of Santiago de Compostela in France            gothic
# 11                   Paris, Banks of the Seine            gothic
# 66                                      Vienna           baroque
# 67           Gardens and Palace of Schoenbrunn           baroque
# 59                                  Wieskirche            rococo
# 12               Palace and Park of Versailles           baroque
# 55                                   Reichenau        romanesque
# 4                              Tower of London        romanesque
# 13                            Athens Acropolis             greek
# 48                            Abbey of St Gall            rococo
# 83                                      Lavaux         vineyards
# 8                                         Rome             roman
# ...

# %%
df_style.groupby(["main style/reason"]).agg(
    sites_per_reason=("UNESCO World Heritage Site","count")
).sort_values(by=["sites_per_reason"],ascending=False).reset_index()
# Out:
#        main style/reason  sites_per_reason
# 0                 gothic                53
# 1                baroque                35
# 2             romanesque                31
# 3            renaissance                27
# 4             east asian                22
# ..                   ...               ...
# 61      historical place                 1
# 62        hunting ground                 1
# 63  agricultural setting                 1
# 64                minoic                 1
# 65             windmills                 1
#
# [66 rows x 2 columns]

# %%
df[(df['Date'].dt.year>2009)].groupby(pd.Grouper(key="Date", freq="1M")).sum()["Picture Count"].plot(
    title="monthly count of UNESCO world heritage pictures",figsize=(15,5),
    ylabel="picture count",ylim=(0,3500))
# Out:
# /var/folders/8d/gvjspwlj4hq61gsmkn1p_h480000gn/T/ipykernel_8760/1795875464.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df[(df['Date'].dt.year>2009)].groupby(pd.Grouper(key="Date", freq="1M")).sum()["Picture Count"].plot(
# <AxesSubplot: title={'center': 'monthly count of UNESCO world heritage pictures'}, xlabel='Date', ylabel='picture count'>

# %%
df.groupby(pd.Grouper(key="Date", freq="1M")).sum()["Picture Count"].plot(
    title="monthly count of UNESCO world heritage pictures",figsize=(15,5),
    ylabel="picture count",ylim=(0,3500))
# Out:
# /var/folders/8d/gvjspwlj4hq61gsmkn1p_h480000gn/T/ipykernel_8760/3540095234.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(pd.Grouper(key="Date", freq="1M")).sum()["Picture Count"].plot(
# <AxesSubplot: title={'center': 'monthly count of UNESCO world heritage pictures'}, xlabel='Date', ylabel='picture count'>

# %%
df_stat_per_year=df.groupby(["Year","UNESCO World Heritage Site"]).agg(
    Country=('Country',lambda x:x.mode()),
    PictureCount=('Picture Count','sum'),
).sort_values(by=['Year','PictureCount'],ascending=False).reset_index()
df_stat_per_year["rank_in_year"]=df_stat_per_year.groupby(["Year"])['PictureCount'].rank(ascending=False)
df_stat_per_year["rank_in_year_inv"]=df_stat_per_year.groupby(["Year"])['PictureCount'].rank()
df_stat_per_year.head(50)
# Out:
#     Year                         UNESCO World Heritage Site          Country  \
# 0   2024                                             Verona            Italy
# 1   2024                                   City of Valletta            Malta
# 2   2024  City of Vicenza and the Palladian Villas of th...            Italy
# 3   2024                          Wachau Cultural Landscape          Austria
# 4   2024                                  Padova Urbs picta            Italy
# 5   2024  Ferrara, City of the Renaissance, and its Po D...            Italy
# 6   2024         Routes of Santiago de Compostela in France           France
# 7   2024                                            Meteora           Greece
# 8   2024                              Venice and its Lagoon            Italy
# 9   2024  The Causses and the Cevennes, Mediterranean ag...           France
# 10  2024  Paleochristian and Byzantine Monuments of Thes...           Greece
# ...

# %%
df_stat_per_year.loc[(df_stat_per_year['PictureCount']<10)].head(50)
# Out:
#      Year                         UNESCO World Heritage Site         Country  \
# 63   2024                                       Pont-du-Gard          France
# 64   2024  Decorated Cave of Pont d’Arc, known as Grotte ...          France
# 65   2024                     Belfries of Belgium and France          France
# 66   2024                                      Canal du Midi          France
# 67   2024                                           Salzburg         Austria
# 68   2024                                      The Dolomites           Italy
# 69   2024                              Hal Saflieni Hypogeum           Malta
# 128  2023                                      Boyana Church        Bulgaria
# 129  2023                      Frontiers of the Roman Empire         Germany
# 130  2023   Frontiers of the Roman Empire – The Danube Limes         Austria
# 131  2023                 Jewish-Medieval Heritage of Erfurt         Germany
# ...

# %%
df_stat_per_year.loc[(df_stat_per_year['rank_in_year']<4)].head(55)
# Out:
#      Year                         UNESCO World Heritage Site         Country  \
# 0    2024                                             Verona           Italy
# 1    2024                                   City of Valletta           Malta
# 2    2024  City of Vicenza and the Palladian Villas of th...           Italy
# 70   2023           Caves of Aggtelek Karst and Slovak Karst        Slovakia
# 71   2023                                             Krakow          Poland
# 72   2023                                             Vienna         Austria
# 133  2022                                             Vienna         Austria
# 134  2022                              Venice and its Lagoon           Italy
# 135  2022                                             Toledo           Spain
# 189  2021                                             Vienna         Austria
# 190  2021                                             Prague  Czech Republic
# ...

# %%
df.groupby(pd.Grouper(key="Date", freq="1M")).nunique()["UNESCO World Heritage Site"]
# Out:
# Date
# 1996-03-31     1
# 1996-04-30     0
# 1996-05-31     1
# 1996-06-30     0
# 1996-07-31     0
#               ..
# 2024-05-31    14
# 2024-06-30     2
# 2024-07-31     2
# 2024-08-31    33
# 2024-09-30     6
# Freq: M, Name: UNESCO World Heritage Site, Length: 343, dtype: int64

# %%
df.groupby(pd.Grouper(key="Date", freq="2W")).nunique()["UNESCO World Heritage Site"].plot(
    title="weekly count of UNESCO world heritage sites visited",figsize=(15,5),
    ylabel="unesco site count",ylim=(0,18))
# Out:
# <AxesSubplot: title={'center': 'weekly count of UNESCO world heritage sites visited'}, xlabel='Date', ylabel='unesco site count'>

# %%
df.groupby(pd.Grouper(key="Date", freq="1M")).nunique()["UNESCO World Heritage Site"].plot(
    title="monthly count of UNESCO world heritage sites visited",figsize=(15,5),
    ylabel="unesco site count",ylim=(0,25))
# Out:
# <AxesSubplot: title={'center': 'monthly count of UNESCO world heritage sites visited'}, xlabel='Date', ylabel='unesco site count'>

# %%
df.groupby(pd.Grouper(key="Date", freq="1Y")).nunique()["UNESCO World Heritage Site"].plot(
    title="yearly count of UNESCO world heritage sites visited",figsize=(15,5),
    ylabel="unesco site count",ylim=(0,80))
# Out:
# <AxesSubplot: title={'center': 'yearly count of UNESCO world heritage sites visited'}, xlabel='Date', ylabel='unesco site count'>

# %%
df.loc[(df['Date'].dt.year>2009)].groupby(pd.Grouper(key="Date", freq="1D")).nunique()["UNESCO World Heritage Site"].plot(
    title="daily count of UNESCO world heritage sites visited",figsize=(15,5),
    ylabel="unesco site count",ylim=(0,6))
# Out:
# <AxesSubplot: title={'center': 'daily count of UNESCO world heritage sites visited'}, xlabel='Date', ylabel='unesco site count'>

# %%
df.loc[(df['Date'].dt.year>2009)].groupby(pd.Grouper(key="Date", freq="1W")).nunique()["UNESCO World Heritage Site"].plot(
    title="weekly count of UNESCO world heritage sites visited",figsize=(15,5),
    ylabel="unesco site count",ylim=(0,17))
# Out:
# <AxesSubplot: title={'center': 'weekly count of UNESCO world heritage sites visited'}, xlabel='Date', ylabel='unesco site count'>

# %%
df.loc[(df['Date'].dt.year>2009)].groupby(pd.Grouper(key="Date", freq="1M")).nunique()["UNESCO World Heritage Site"].plot(
    title="monthly count of UNESCO world heritage sites visited",figsize=(15,5),
    ylabel="unesco site count",ylim=(0,25))
# Out:
# <AxesSubplot: title={'center': 'monthly count of UNESCO world heritage sites visited'}, xlabel='Date', ylabel='unesco site count'>

# %%
df.loc[(df['Date'].dt.year>2009)].groupby(pd.Grouper(key="Date", freq="2W")).sum()["Picture Count"].plot(
    title="bi-weekly count of UNESCO world heritage pictures",figsize=(15,5),
    ylabel="picture count",ylim=(0,3500))
# Out:
# /var/folders/8d/gvjspwlj4hq61gsmkn1p_h480000gn/T/ipykernel_8760/350529086.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.loc[(df['Date'].dt.year>2009)].groupby(pd.Grouper(key="Date", freq="2W")).sum()["Picture Count"].plot(
# <AxesSubplot: title={'center': 'bi-weekly count of UNESCO world heritage pictures'}, xlabel='Date', ylabel='picture count'>

# %%
df[(df['Date'].dt.year>2009)].groupby(pd.Grouper(key="Date", freq="1W")).sum()["Picture Count"].plot(
    title="weekly count of UNESCO world heritage pictures",figsize=(15,5),
    ylabel="picture count",ylim=(0,3000))
# Out:
# /var/folders/8d/gvjspwlj4hq61gsmkn1p_h480000gn/T/ipykernel_8760/2531498290.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df[(df['Date'].dt.year>2009)].groupby(pd.Grouper(key="Date", freq="1W")).sum()["Picture Count"].plot(
# <AxesSubplot: title={'center': 'weekly count of UNESCO world heritage pictures'}, xlabel='Date', ylabel='picture count'>

# %%
df.groupby(pd.Grouper(key="Date", freq="1W")).sum()["Picture Count"].plot(
    title="weekly count of UNESCO world heritage pictures",figsize=(15,5),
    ylabel="picture count",ylim=(0,3000))
# Out:
# /var/folders/8d/gvjspwlj4hq61gsmkn1p_h480000gn/T/ipykernel_8760/2991017334.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(pd.Grouper(key="Date", freq="1W")).sum()["Picture Count"].plot(
# <AxesSubplot: title={'center': 'weekly count of UNESCO world heritage pictures'}, xlabel='Date', ylabel='picture count'>

# %%
#df.drop(columns=['Cultural Site','Natural Site']).groupby(["Place"]).agg().sort_values(by="Picture Count", ascending=False).head(20).reset_index()

# %%
df_mostpics_per_country = df.groupby(["Country","UNESCO World Heritage Site"]).sum().reset_index()
#df_mostpics_per_country=df_mostpics_per_country[["UNESCO World Heritage Site","Country","Picture Count"]].rename(columns={"Country": "MajorCountryPictures","Picture Count": "Most Picture Per Country"})
df_mostpics_per_country
# Out:
# /var/folders/8d/gvjspwlj4hq61gsmkn1p_h480000gn/T/ipykernel_8760/1601794712.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_mostpics_per_country = df.groupby(["Country","UNESCO World Heritage Site"]).sum().reset_index()
#             Country                         UNESCO World Heritage Site  \
# 0           Andorra                      Madriu-Perafita-Claror Valley
# 1           Austria          Fertoe - Neusiedlersee Cultural Landscape
# 2           Austria   Frontiers of the Roman Empire – The Danube Limes
# 3           Austria                  Gardens and Palace of Schoenbrunn
# 4           Austria                                               Graz
# ..              ...                                                ...
# ...

# %%
#df[(df["UNESCO World Heritage Site"]=="Jungfrau-Aletsch") | (df["UNESCO World Heritage Site"]=="Yellowstone National Park")].groupby(["Place","UNESCO World Heritage Site"]).sum()

# %%
df_print=df.groupby(["Country"]).agg(
    site_unique=("UNESCO World Heritage Site",'unique')).reset_index()
df_print.loc[(df_print["Country"]=='Czech Republic'),'site_unique'].iloc[0]
# Out:
# array(['Prague', 'Cesky Krumlov', 'Gardens and Castle at Kromeriz',
#        'Holy Trinity Column of Olomouc',
#        'Kutna Hora: Historical Town Centre with the Church of St Barbara and the Cathedral of Our Lady at Sedlec',
#        'Lednice-Valtice Cultural Landscape',
#        'Pilgrimage Church of St John of Nepomuk at Zelena Hora',
#        'Tugendhat Villa in Brno',
#        "Jewish Quarter and St Procopius' Basilica in Trebic",
#        'Litomysl Castle', 'Historic Centre of Telc'], dtype=object)

# %%
df_mostpics_per_country = df.groupby(["Country","UNESCO World Heritage Site"]).sum().reset_index().sort_values(
                        by=["UNESCO World Heritage Site","Picture Count"],ascending=False
                        ).groupby(["UNESCO World Heritage Site"]).first().reset_index()
df_mostpics_per_country=df_mostpics_per_country[["UNESCO World Heritage Site","Country","Picture Count"]].rename(
    columns={"Country": "CountryMostPictures","Picture Count": "Most Picture Per Country"})
df_mostpics_per_country
# Out:
# /var/folders/8d/gvjspwlj4hq61gsmkn1p_h480000gn/T/ipykernel_8760/88789282.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_mostpics_per_country = df.groupby(["Country","UNESCO World Heritage Site"]).sum().reset_index().sort_values(
#                             UNESCO World Heritage Site CountryMostPictures  \
# 0                                     Aachen Cathedral             Germany
# 1                             Abbey Church of St Savin              France
# 2                                      Abbey of Lorsch             Germany
# 3                                     Abbey of St Gall         Switzerland
# 4            Agricultural Landscape of Southern Oeland              Sweden
# ..                                                 ...                 ...
# ...

# %%
df_mostpics_per_place = df.groupby(["Place","UNESCO World Heritage Site"]).sum().reset_index().sort_values(
                        by=["UNESCO World Heritage Site","Picture Count"],ascending=False
                        ).groupby(["UNESCO World Heritage Site"]).first().reset_index()
df_mostpics_per_place=df_mostpics_per_place[["UNESCO World Heritage Site","Place","Picture Count"]].rename(
    columns={"Place": "PlaceMostPictures","Picture Count": "Most Picture Per Place"})
df_mostpics_per_place
# Out:
# /var/folders/8d/gvjspwlj4hq61gsmkn1p_h480000gn/T/ipykernel_8760/1966926577.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_mostpics_per_place = df.groupby(["Place","UNESCO World Heritage Site"]).sum().reset_index().sort_values(
#                             UNESCO World Heritage Site PlaceMostPictures  \
# 0                                     Aachen Cathedral            Aachen
# 1                             Abbey Church of St Savin          St Savin
# 2                                      Abbey of Lorsch            Lorsch
# 3                                     Abbey of St Gall         St Gallen
# 4            Agricultural Landscape of Southern Oeland       Moerbylanga
# ..                                                 ...               ...
# ...

# %%
df_siteinfo=df.groupby(["UNESCO World Heritage Site"]).agg(TotalPictures=("Picture Count",'sum'),
                                              TotalSecondaryPictures=("Secondary Picture Count",'sum'),
                                              CulturalSite=("Cultural Site",'mean'),
                                              NaturalSite=("Natural Site",'mean'),
                                              NumCountries=("Country",'nunique'),
                                              CountryMostVisits=("Country",lambda x:x.value_counts().index[0]),
                                              PlaceMostVisits=("Place",lambda x:x.value_counts().index[0]),
                                              DaysVisited=("Date",'nunique'),
                                              PlacesVisited=("Place",'nunique'),  
                                              FirstDateVisited=("Date",'min'),
                                              LastDateVisited=("Date",'max'),
                                              YearsVisited=('Year','nunique')
                                              ).reset_index().sort_values(by="TotalPictures", ascending=False).reset_index(drop=True)
df_siteinfo.head(60)
# Out:
#                            UNESCO World Heritage Site  TotalPictures  \
# 0                                              Vienna           4187
# 1                                                Rome           3845
# 2                           Paris, Banks of the Seine           2710
# 3                                    Jungfrau-Aletsch           2520
# 4                               Venice and its Lagoon           2243
# 5                                            Florence           2058
# 6                                              Prague           1448
# 7          Petersburg and Related Groups of Monuments           1417
# 8                                              Naples           1380
# 9                   Gardens and Palace of Schoenbrunn           1047
# 10                      Palace and Park of Versailles           1042
# 11            Palaces and Parks of Potsdam and Berlin           1041
# 12                                       Vatican City            956
# ...

# %%
df_siteinfo.loc[(df_siteinfo["UNESCO World Heritage Site"].str.contains("Loire",na=False)),'UNESCO World Heritage Site'].unique()
# Out:
# array(['Loire Valley between Sully-sur-Loire and Chalonnes'], dtype=object)

# %%
df_siteinfo_sec=df.groupby(['Secondary Site']).agg(TotalPicturesFromSecondary=("Secondary Picture Count",'sum'),
                                              SecondaryPlaceMostVisits=("Place",lambda x:x.value_counts().index[0]),
                                              SecondaryDaysVisited=("Date",'nunique'),
                                              SecondaryPlacesVisited=("Place",'nunique'),  
                                              ).reset_index().sort_values(by="TotalPicturesFromSecondary", ascending=False)
df_siteinfo_sec
# Out:
#                                        Secondary Site  \
# 4          Routes of Santiago de Compostela in France
# 5   Routes of Santiago de Compostela: Camino Franc...
# 3                           Medici Villas and Gardens
# 7                       The Great Spa Towns of Europe
# 6   Silk Roads: the Routes Network of Chang'an-Tia...
# 1                      Belfries of Belgium and France
# 2    Frontiers of the Roman Empire – The Danube Limes
# 9                                              Vienna
# 0   Beijing Central Axis: A Building Ensemble Exhi...
# 8                            Via Appia. Regina Viarum
# 10                          Wachau Cultural Landscape
#
#     TotalPicturesFromSecondary SecondaryPlaceMostVisits  SecondaryDaysVisited  \
# 4                          562                 Bordeaux                     9
# 5                          454   Santiago de Compostela                     4
# 3                          426                 Florence                     3
# ...

# %%
df_siteinfo.loc[(df_siteinfo['CountryMostVisits']=='Ukraine')]
# Out:
#                          UNESCO World Heritage Site  TotalPictures  \
# 141  Saint-Sophia Cathedral and Kyiv-Pechersk Lavra            137
#
#      TotalSecondaryPictures  CulturalSite  NaturalSite  NumCountries  \
# 141                       0           1.0          0.0             1
#
#     CountryMostVisits PlaceMostVisits  DaysVisited  PlacesVisited  \
# 141           Ukraine            Kiev            1              1
#
#     FirstDateVisited LastDateVisited  YearsVisited
# 141       2017-04-15      2017-04-15             1

# %%
df_siteinfo['UNESCO World Heritage Site'].unique()
# Out:
# array(['Vienna', 'Rome', 'Paris, Banks of the Seine', 'Jungfrau-Aletsch',
#        'Venice and its Lagoon', 'Florence', 'Prague',
#        'Petersburg and Related Groups of Monuments', 'Naples',
#        'Gardens and Palace of Schoenbrunn',
#        'Palace and Park of Versailles',
#        'Palaces and Parks of Potsdam and Berlin', 'Vatican City',
#        'Wachau Cultural Landscape', 'Krakow', 'Toledo',
#        'Budapest, including the Banks of the Danube, the Buda Castle Quarter and Andrassy Avenue',
#        'Siena', 'Residences of the Royal House of Savoy',
#        'Cathedral, Alcazar and Archivo de Indias in Seville',
#        'Loire Valley between Sully-sur-Loire and Chalonnes',
#        'Pompei, Herculaneum and Torre Annunziata', 'Verona',
#        'Dresden Elbe Valley', 'Lyon',
#        'Routes of Santiago de Compostela: Camino Frances and Routes of Northern Spain',
#        'Cultural Landscape of Sintra', 'Cologne Cathedral',
# ...

# %%
df_siteinfo.loc[(df_siteinfo['UNESCO World Heritage Site'].str.contains("Malbork"))]
# Out:
#                  UNESCO World Heritage Site  TotalPictures  \
# 83  Castle of the Teutonic Order in Malbork            253
#
#     TotalSecondaryPictures  CulturalSite  NaturalSite  NumCountries  \
# 83                       0           1.0          0.0             1
#
#    CountryMostVisits PlaceMostVisits  DaysVisited  PlacesVisited  \
# 83            Poland         Malbork            1              1
#
#    FirstDateVisited LastDateVisited  YearsVisited
# 83       2022-11-05      2022-11-05             1

# %%
df_siteinfo_full=df_siteinfo.merge(df_mostpics_per_country,on="UNESCO World Heritage Site").merge(
    df_mostpics_per_place,on="UNESCO World Heritage Site")
df_siteinfo_full
# Out:
#                             UNESCO World Heritage Site  TotalPictures  \
# 0                                               Vienna           4187
# 1                                                 Rome           3845
# 2                            Paris, Banks of the Seine           2710
# 3                                     Jungfrau-Aletsch           2520
# 4                                Venice and its Lagoon           2243
# ..                                                 ...            ...
# 352                                      Vatnajoekuell              1
# 353  Frontiers of the Roman Empire - The Lower Germ...              1
# 354                 Jewish-Medieval Heritage of Erfurt              1
# 355                                      The Dolomites              1
# 356                              Hal Saflieni Hypogeum              0
#
#      TotalSecondaryPictures  CulturalSite  NaturalSite  NumCountries  \
# ...

# %%
df_siteinfo_full=df_siteinfo_full.merge(df_siteinfo_sec,left_on="UNESCO World Heritage Site",
                                       right_on="Secondary Site",how="left")
df_siteinfo_full[['TotalPicturesFromSecondary','SecondaryDaysVisited']]=df_siteinfo_full[['TotalPicturesFromSecondary','SecondaryDaysVisited']].fillna(0)

# %%
df.loc[
    
    #(
    #(df['UNESCO World Heritage Site'].str.contains("Routes"))
    #           & (df['UNESCO World Heritage Site'].str.contains("in France"))) |
    (
    (df['Secondary Site'].str.contains("Routes"))
               & (df['Secondary Site'].str.contains("in France"))),"Date"].dt.date
# Out:
# 148     2012-06-03
# 272     2015-07-19
# 355     2016-07-02
# 563     2018-11-17
# 613     2019-04-21
# 1073    2024-08-04
# 1091    2024-08-10
# 1092    2024-08-10
# 1104    2024-08-15
# 1112    2024-08-19
# Name: Date, dtype: object

# %%
df_siteinfo_full.loc[(df_siteinfo_full["CountryMostVisits"]=="Greece")]
# Out:
#                             UNESCO World Heritage Site  TotalPictures  \
# 67                                             Meteora            287
# 79   Paleochristian and Byzantine Monuments of Thes...            259
# 195                                             Delphi             91
# 204                                   Athens Acropolis             84
# 214                       Archaeological Site of Aigai             76
# 217                    Archaeological Site of Philippi             75
# 332                                             Mykene              9
# 340                                            Olympia              6
# 341                Sanctuary of Asklepios at Epidaurus              5
#
#      TotalSecondaryPictures  CulturalSite  NaturalSite  NumCountries  \
# 67                        0           1.0          1.0             1
# 79                        0           1.0          0.0             1
# ...

# %%
df_siteinfo_full.loc[df_siteinfo_full['UNESCO World Heritage Site'].str.contains("Bologna")]
# Out:
#    UNESCO World Heritage Site  TotalPictures  TotalSecondaryPictures  \
# 62       Porticoes of Bologna            297                       0
#
#     CulturalSite  NaturalSite  NumCountries CountryMostVisits PlaceMostVisits  \
# 62           1.0          0.0             1             Italy         Bologna
#
#     DaysVisited  PlacesVisited  ... YearsVisited CountryMostPictures  \
# 62            6              1  ...            2               Italy
#
#     Most Picture Per Country PlaceMostPictures  Most Picture Per Place  \
# 62                       297           Bologna                     297
#
#    Secondary Site  TotalPicturesFromSecondary SecondaryPlaceMostVisits  \
# 62            NaN                         0.0                      NaN
#
#     SecondaryDaysVisited SecondaryPlacesVisited
# 62                   0.0                    NaN
#
# [1 rows x 22 columns]

# %%
df_siteinfo_full.loc[(df_siteinfo_full["UNESCO World Heritage Site"]=="Routes of Santiago de Compostela in France")]
# Out:
#                     UNESCO World Heritage Site  TotalPictures  \
# 46  Routes of Santiago de Compostela in France            410
#
#     TotalSecondaryPictures  CulturalSite  NaturalSite  NumCountries  \
# 46                       0           1.0          0.0             1
#
#    CountryMostVisits PlaceMostVisits  DaysVisited  PlacesVisited  ...  \
# 46            France           Paris           20             11  ...
#
#    YearsVisited CountryMostPictures  Most Picture Per Country  \
# 46            8              France                       410
#
#    PlaceMostPictures  Most Picture Per Place  \
# 46          Toulouse                      94
#
#                                 Secondary Site  TotalPicturesFromSecondary  \
# 46  Routes of Santiago de Compostela in France                       562.0
#
#    SecondaryPlaceMostVisits  SecondaryDaysVisited SecondaryPlacesVisited
# 46                 Bordeaux                   9.0                    5.0
#
# [1 rows x 22 columns]

# %%
df_siteinfo_full.loc[(df_siteinfo_full["UNESCO World Heritage Site"]=="Routes of Santiago de Compostela in France")
                     | (df_siteinfo_full['Secondary Site']=="Routes of Santiago de Compostela in France")]
# Out:
#                     UNESCO World Heritage Site  TotalPictures  \
# 46  Routes of Santiago de Compostela in France            410
#
#     TotalSecondaryPictures  CulturalSite  NaturalSite  NumCountries  \
# 46                       0           1.0          0.0             1
#
#    CountryMostVisits PlaceMostVisits  DaysVisited  PlacesVisited  ...  \
# 46            France           Paris           20             11  ...
#
#    YearsVisited CountryMostPictures  Most Picture Per Country  \
# 46            8              France                       410
#
#    PlaceMostPictures  Most Picture Per Place  \
# 46          Toulouse                      94
#
#                                 Secondary Site  TotalPicturesFromSecondary  \
# 46  Routes of Santiago de Compostela in France                       562.0
#
#    SecondaryPlaceMostVisits  SecondaryDaysVisited SecondaryPlacesVisited
# 46                 Bordeaux                   9.0                    5.0
#
# [1 rows x 22 columns]

# %%
df_siteinfo_full.sort_values(by=["DaysVisited"],ascending=False,ignore_index=True).head(30)
# Out:
#                            UNESCO World Heritage Site  TotalPictures  \
# 0                                              Vienna           4187
# 1                           Paris, Banks of the Seine           2710
# 2                                                Rome           3845
# 3                                    Jungfrau-Aletsch           2520
# 4          Routes of Santiago de Compostela in France            410
# 5                   Gardens and Palace of Schoenbrunn           1047
# 6                               Venice and its Lagoon           2243
# 7          Petersburg and Related Groups of Monuments           1417
# 8                                              Naples           1380
# 9                                            Florence           2058
# 10                    Paseo del Prado and Buen Retiro            322
# 11                                             Prague           1448
# 12  Palace of Westminster and Westminster Abbey in...            442
# ...

# %%
df_first_year_stat=df[(df["Date"].dt.year==df['firstDateVisited'].dt.year)].groupby(df["Date"].dt.year).agg(
    PhotosInFirstSiteVisit=("Picture Count",'sum'),
    DaysFirstSiteVisit=('Date','nunique'),
    FirstSiteVisitPerYear=("UNESCO World Heritage Site",'nunique')
    ).reset_index()
df_first_year_stat
# Out:
#     Date  PhotosInFirstSiteVisit  DaysFirstSiteVisit  FirstSiteVisitPerYear
# 0   1996                      47                   7                      7
# 1   1997                      93                   8                      2
# 2   1998                      40                   5                      3
# 3   1999                      80                   7                      6
# 4   2000                     128                   6                      6
# 5   2001                     129                   8                      7
# 6   2002                     145                   7                      9
# 7   2004                      16                   1                      2
# 8   2005                      92                   6                      5
# 9   2008                     405                   8                      7
# 10  2009                     144                   3                      3
# ...

# %%
df_stat_per_year_country=df.groupby([df["Date"].dt.year,'Country']).agg(
    SitePerYearCountry=("UNESCO World Heritage Site",'nunique'),
    #SitePerYearCountryUnique=("UNESCO World Heritage Site",'unique'),
    Photos=("Picture Count",'sum'),
    Days=('Date','nunique')
).reset_index()
df_stat_per_year_country=df_stat_per_year_country.rename({"Date":'Year'},axis=1)
df_stat_per_year_country.sort_values(by=['Year','Photos'],ascending=False, ignore_index=True).head(50)
# Out:
#     Year          Country  SitePerYearCountry  Photos  Days
# 0   2024           France                  27    2791    17
# 1   2024            Italy                   7    2059     7
# 2   2024   United Kingdom                  11    1046     7
# 3   2024           Greece                   4     697     7
# 4   2024          Austria                   5     614    10
# 5   2024            Malta                   3     549     3
# 6   2024      Netherlands                   5     427     4
# 7   2024         Slovenia                   3     261     3
# 8   2024   Czech Republic                   1     144     1
# 9   2024  North Macedonia                   1     128     1
# 10  2024          Hungary                   1     118     1
# 11  2024      Switzerland                   1      84     1
# 12  2024          Andorra                   1      56     1
# 13  2023         Portugal                  12    1965    10
# 14  2023          Germany                  13     953     6
# ...

# %%
df_stat_per_year_country.sort_values(by=['Photos'],ascending=False, ignore_index=True).head(50)
# Out:
#     Year         Country  SitePerYearCountry  Photos  Days
# 0   2021         Austria                   9    3911    43
# 1   2022           Spain                  15    3152    15
# 2   2020           Italy                  11    2809    12
# 3   2024          France                  27    2791    17
# 4   2016           Italy                  15    2718    20
# 5   2019           Italy                  11    2406    11
# 6   2017           Italy                   9    2332    16
# 7   2022           Italy                  10    2113     8
# 8   2024           Italy                   7    2059     7
# 9   2013           Italy                   5    2008    14
# 10  2023        Portugal                  12    1965    10
# 11  2015          Russia                   2    1550    13
# 12  2018           China                  13    1439     9
# 13  2014           Italy                   5    1418     9
# 14  2018         Germany                  17    1391     9
# ...

# %%
df_stat_per_year_country.sort_values(by=['SitePerYearCountry','Photos'],ascending=False, ignore_index=True).head(50)
# Out:
#     Year         Country  SitePerYearCountry  Photos  Days
# 0   2024          France                  27    2791    17
# 1   2018         Germany                  17    1391     9
# 2   2022           Spain                  15    3152    15
# 3   2016           Italy                  15    2718    20
# 4   2018          France                  14    1322     9
# 5   2018           China                  13    1439     9
# 6   2021         Germany                  13    1002     9
# 7   2023         Germany                  13     953     6
# 8   2023        Portugal                  12    1965    10
# 9   2020           Italy                  11    2809    12
# 10  2019           Italy                  11    2406    11
# 11  2024  United Kingdom                  11    1046     7
# 12  2022           Italy                  10    2113     8
# 13  2016           Japan                  10     731     9
# 14  2021         Austria                   9    3911    43
# ...

# %%
df_stat_per_year=df.groupby(df["Date"].dt.year).agg(
    SitePerYear=("UNESCO World Heritage Site",'nunique'),
    Photos=("Picture Count",'sum'),
    Days=('Date','nunique')
).reset_index()
df_stat_per_year=df_stat_per_year.merge(df_first_year_stat,how="left",on="Date")
df_stat_per_year['FirstSiteVisitPerYear']=pd.to_numeric(df_stat_per_year['FirstSiteVisitPerYear'].fillna(0),downcast='integer')
df_stat_per_year['PhotosInFirstSiteVisit']=pd.to_numeric(df_stat_per_year['PhotosInFirstSiteVisit'].fillna(0),downcast='integer')
df_stat_per_year['DaysFirstSiteVisit']=pd.to_numeric(df_stat_per_year['DaysFirstSiteVisit'].fillna(0),downcast='integer')
df_stat_per_year=df_stat_per_year.rename({"Date":'Year'},axis=1)
df_stat_per_year
# Out:
#     Year  SitePerYear  Photos  Days  PhotosInFirstSiteVisit  \
# 0   1996            7      47     7                      47
# 1   1997            2      93     8                      93
# 2   1998            3      40     5                      40
# 3   1999            7      96     8                      80
# 4   2000            6     128     6                     128
# 5   2001            7     129     8                     129
# 6   2002            9     145     7                     145
# 7   2003            1      19     1                       0
# 8   2004            3      24     2                      16
# 9   2005            5      92     6                      92
# 10  2006            3      34     4                       0
# 11  2008            8     501     9                     405
# 12  2009            7     279     6                     144
# 13  2010           10    1870    21                     373
# 14  2011            7    1498    12                     849
# ...

# %%
df_stat_per_year.plot(x="Year",y='Photos')
# Out:
# <AxesSubplot: xlabel='Year'>

# %%
df_stat_per_year.plot(x="Year",y='SitePerYear')
# Out:
# <AxesSubplot: xlabel='Year'>

# %%
df_stat_per_year.plot(x="Year",y='FirstSiteVisitPerYear')
# Out:
# <AxesSubplot: xlabel='Year'>

# %%
df_stat_per_year.plot(x="Year",y='Photos')
# Out:
# <AxesSubplot: xlabel='Year'>

# %%
df_stat_per_year.plot(x="Year",y='PhotosInFirstSiteVisit')
# Out:
# <AxesSubplot: xlabel='Year'>

# %%
df_siteinfo_full.sort_values(by=['TotalPictures'],ascending=False,ignore_index=True).head(50)
# Out:
#                            UNESCO World Heritage Site  TotalPictures  \
# 0                                              Vienna           4187
# 1                                                Rome           3845
# 2                           Paris, Banks of the Seine           2710
# 3                                    Jungfrau-Aletsch           2520
# 4                               Venice and its Lagoon           2243
# 5                                            Florence           2058
# 6                                              Prague           1448
# 7          Petersburg and Related Groups of Monuments           1417
# 8                                              Naples           1380
# 9                   Gardens and Palace of Schoenbrunn           1047
# 10                      Palace and Park of Versailles           1042
# 11            Palaces and Parks of Potsdam and Berlin           1041
# 12                                       Vatican City            956
# ...

# %%
df_siteinfo_full.loc[(df_siteinfo_full['CountryMostVisits']=='Slovenia')].sort_values(by=['TotalPictures'],
                    ascending=False,ignore_index=True).head(50)
# Out:
#                 UNESCO World Heritage Site  TotalPictures  \
# 0                            Skocjan Caves            181
# 1  Heritage of Mercury. Almaden and Idrija            110
# 2   The works of Joze Plecnik in Ljubljana             53
#
#    TotalSecondaryPictures  CulturalSite  NaturalSite  NumCountries  \
# 0                       0           0.0          1.0             1
# 1                       0           1.0          0.0             1
# 2                       0           1.0          0.0             1
#
#   CountryMostVisits PlaceMostVisits  DaysVisited  PlacesVisited  ...  \
# 0          Slovenia         Skocjan            2              1  ...
# 1          Slovenia          Idrija            1              1  ...
# 2          Slovenia       Ljubljana            2              1  ...
#
#   YearsVisited CountryMostPictures  Most Picture Per Country  \
# 0            2            Slovenia                       181
# ...

# %%
df_siteinfo_full.loc[(df_siteinfo_full['CountryMostVisits']=='Italy')].sort_values(by=['TotalPictures'],
                    ascending=False,ignore_index=True).head(50)
# Out:
#                            UNESCO World Heritage Site  TotalPictures  \
# 0                                                Rome           3845
# 1                               Venice and its Lagoon           2243
# 2                                            Florence           2058
# 3                                              Naples           1380
# 4                                               Siena            645
# 5              Residences of the Royal House of Savoy            629
# 6            Pompei, Herculaneum and Torre Annunziata            616
# 7                                              Verona            578
# 8   City of Vicenza and the Palladian Villas of th...            535
# 9                                   Padova Urbs picta            531
# 10  Ferrara, City of the Renaissance, and its Po D...            493
# 11                                       Amalfi Coast            474
# 12                                  Reggia di Caserta            396
# ...

# %%
df_siteinfo_full.loc[(df_siteinfo_full['CountryMostVisits']=='Germany')].sort_values(by=['TotalPictures'],
                    ascending=False,ignore_index=True).head(50)
# Out:
#                            UNESCO World Heritage Site  TotalPictures  \
# 0             Palaces and Parks of Potsdam and Berlin           1041
# 1                                 Dresden Elbe Valley            578
# 2                                   Cologne Cathedral            538
# 3                                             Bamberg            285
# 4                                 Wuerzburg Residence            270
# 5    Castles of Augustusburg and Falkenlust at Bruehl            268
# 6                           Upper Middle Rhine Valley            262
# 7                                        Museumsinsel            239
# 8                    Garden Kingdom of Dessau-Wörlitz            234
# 9                                           Reichenau            230
# 10                             Bergpark Wilhelmshoehe            219
# 11                                   Speyer Cathedral            210
# 12                                   Classical Weimar            193
# ...

# %%
df_siteinfo_full.loc[(df_siteinfo_full['CountryMostVisits']=='Italy')].sort_values(by=['TotalPictures'],
                    ascending=False,ignore_index=True).head(50)
# Out:
#                            UNESCO World Heritage Site  TotalPictures  \
# 0                                                Rome           3845
# 1                               Venice and its Lagoon           2243
# 2                                            Florence           2058
# 3                                              Naples           1380
# 4                                               Siena            645
# 5              Residences of the Royal House of Savoy            629
# 6            Pompei, Herculaneum and Torre Annunziata            616
# 7                                              Verona            578
# 8   City of Vicenza and the Palladian Villas of th...            535
# 9                                   Padova Urbs picta            531
# 10  Ferrara, City of the Renaissance, and its Po D...            493
# 11                                       Amalfi Coast            474
# 12                                  Reggia di Caserta            396
# ...

# %%
df_siteinfo_full.loc[(df_siteinfo_full['CountryMostVisits']=='China')].sort_values(by=['TotalPictures'],
                    ascending=False,ignore_index=True).head(50)
# Out:
#                            UNESCO World Heritage Site  TotalPictures  \
# 0   Imperial Palaces of the Ming and Qing Dynastie...            299
# 1                            Summer Palace in Beijing            177
# 2                               West Lake of Hangzhou            148
# 3   Beijing Central Axis: A Building Ensemble Exhi...            120
# 4                         Temple of Heaven in Beijing            119
# 5                         Classical Gardens of Suzhou            116
# 6                                    Longmen Grottoes            105
# 7                                      The Great Wall             87
# 8                  Mausoleum of the First Qin Emperor             81
# 9                                               Macao             76
# 10  Silk Roads: the Routes Network of Chang'an-Tia...             55
# 11      Imperial Tombs of the Ming and Qing Dynasties             52
# 12                                    The Grand Canal              4
#
# ...

# %%
df_siteinfo_full.loc[(df_siteinfo_full['CountryMostVisits']=='United Kingdom')].sort_values(by=['TotalPictures'],
                    ascending=False,ignore_index=True).head(50)
# Out:
#                            UNESCO World Heritage Site  TotalPictures  \
# 0   Palace of Westminster and Westminster Abbey in...            442
# 1   Canterbury Cathedral, St Augustine's Abbey, an...            291
# 2                                     Blenheim Palace            236
# 3                                         Kew Gardens            188
# 4                         Durham Castle and Cathedral            170
# 5                                                Bath            160
# 6                           The English Lake District            159
# 7    Castles and Town Walls of King Edward in Gwynedd            124
# 8                                     Tower of London            120
# 9                                  Maritime Greenwich            118
# 10                                          Edinburgh            101
# 11  Studley Royal Park including the Ruins of Foun...             98
# 12           Stonehenge, Avebury and Associated Sites             59
# ...

# %%
df_siteinfo_full.loc[(df_siteinfo_full['CountryMostVisits']=='Netherlands')].sort_values(by=['TotalPictures'],
                    ascending=False,ignore_index=True).head(50)
# Out:
#             UNESCO World Heritage Site  TotalPictures  TotalSecondaryPictures  \
# 0  Seventeenth-Century Canal Ring Area            257                       0
# 1   Mill Network at Kinderdijk-Elshout             90                       0
# 2            Dutch Water Defence Lines             80                       0
# 3                     Van Nellefabriek             44                       0
# 4             Rietveld Schroeder House             33                       0
#
#    CulturalSite  NaturalSite  NumCountries CountryMostVisits PlaceMostVisits  \
# 0           1.0          0.0             1       Netherlands       Amsterdam
# 1           1.0          0.0             1       Netherlands      Kinderdijk
# 2           1.0          0.0             1       Netherlands           Weesp
# 3           1.0          0.0             1       Netherlands       Rotterdam
# 4           1.0          0.0             1       Netherlands         Utrecht
#
# ...

# %%
df_siteinfo_full.loc[(df_siteinfo_full['CountryMostVisits']=='France')].sort_values(by=['TotalPictures'],
                    ascending=False,ignore_index=True).head(50)
# Out:
#                            UNESCO World Heritage Site  TotalPictures  \
# 0                           Paris, Banks of the Seine           2710
# 1                       Palace and Park of Versailles           1042
# 2   Loire Valley between Sully-sur-Loire and Chalo...            621
# 3                                                Lyon            576
# 4   Cathedral of Notre-Dame, Former Abbey of Saint...            476
# 5                    Palace and Park of Fontainebleau            458
# 6          Routes of Santiago de Compostela in France            410
# 7                                  Chartres Cathedral            348
# 8   Papal Palace, Episcopal Ensemble and Avignon B...            286
# 9                       Climats, Terroirs of Burgundy            285
# 10  The Causses and the Cevennes, Mediterranean ag...            268
# 11              Arles, Roman and Romanesque Monuments            264
# 12                         Bordeaux, Port of the Moon            250
# ...

# %%
df_siteinfo_full.loc[(df_siteinfo_full['UNESCO World Heritage Site'].str.contains('Frontiers'))]
# Out:
#                             UNESCO World Heritage Site  TotalPictures  \
# 245   Frontiers of the Roman Empire – The Danube Limes             51
# 328                      Frontiers of the Roman Empire             11
# 353  Frontiers of the Roman Empire - The Lower Germ...              1
#
#      TotalSecondaryPictures  CulturalSite  NaturalSite  NumCountries  \
# 245                       1           1.0          0.0             1
# 328                       0           1.0          0.0             2
# 353                       0           1.0          0.0             1
#
#     CountryMostVisits PlaceMostVisits  DaysVisited  PlacesVisited  ...  \
# 245           Austria          Vienna            6              8  ...
# 328    United Kingdom        Fallkirk            2              2  ...
# 353           Germany         Cologne            1              1  ...
#
#     YearsVisited CountryMostPictures  Most Picture Per Country  \
# ...

# %%
df_siteinfo_full.sort_values(by=["PlacesVisited",'TotalPictures'],ascending=False,ignore_index=True).head(30)
# Out:
#                            UNESCO World Heritage Site  TotalPictures  \
# 0                                    Jungfrau-Aletsch           2520
# 1                           Wachau Cultural Landscape            815
# 2                                        Amalfi Coast            474
# 3                           Upper Middle Rhine Valley            262
# 4          Routes of Santiago de Compostela in France            410
# 5                           Yellowstone National Park            411
# 6                      Belfries of Belgium and France            170
# 7    Frontiers of the Roman Empire – The Danube Limes             51
# 8          Petersburg and Related Groups of Monuments           1417
# 9   Loire Valley between Sully-sur-Loire and Chalo...            621
# 10          Fertoe - Neusiedlersee Cultural Landscape            294
# 11                                             Lavaux             80
# 12             Residences of the Royal House of Savoy            629
# ...

# %%
df_country_totals=df.groupby(["Country"]).agg(PicturesTaken=('Picture Count','sum'),
                            DaysVisited=('Date','nunique')
                           ,UNESCOWorldHeritageSites=('UNESCO World Heritage Site','nunique') 
                           ,PlacesVisited=('Place','nunique')
).sort_values(by="PicturesTaken", ascending=False).reset_index()
df_country_totals
# Out:
#             Country  PicturesTaken  DaysVisited  UNESCOWorldHeritageSites  \
# 0             Italy          18986          115                        46
# 1            France          10462           86                        41
# 2           Austria           7613          112                        10
# 3           Germany           7002           69                        51
# 4             Spain           6427           48                        26
# 5       Switzerland           3464           43                        10
# 6    Czech Republic           2700           18                        11
# 7          Portugal           2526           17                        12
# 8    United Kingdom           2472           32                        19
# 9            Poland           1932           11                        13
# 10          Vatican           1551           16                         2
# 11           Russia           1550           13                         2
# ...

# %%
df_siteinfo_full.nunique()
# Out:
# UNESCO World Heritage Site    357
# TotalPictures                 227
# TotalSecondaryPictures         15
# CulturalSite                    2
# NaturalSite                     3
# NumCountries                    2
# CountryMostVisits              41
# PlaceMostVisits               325
# DaysVisited                    19
# PlacesVisited                  14
# FirstDateVisited              283
# LastDateVisited               273
# YearsVisited                    9
# CountryMostPictures            41
# Most Picture Per Country      226
# PlaceMostPictures             327
# Most Picture Per Place        220
# Secondary Site                 11
# TotalPicturesFromSecondary      9
# SecondaryPlaceMostVisits       11
# SecondaryDaysVisited            6
# SecondaryPlacesVisited          4
# dtype: int64

# %%
df_siteinfo_full.sum()
# Out:
# /var/folders/8d/gvjspwlj4hq61gsmkn1p_h480000gn/T/ipykernel_8760/3909192596.py:1: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_siteinfo_full.sum()
# UNESCO World Heritage Site    ViennaRomeParis, Banks of the SeineJungfrau-Al...
# TotalPictures                                                             78538
# TotalSecondaryPictures                                                     1718
# CulturalSite                                                              338.0
# NaturalSite                                                           15.977273
# NumCountries                                                                365
# CountryMostVisits             AustriaItalyFranceSwitzerlandItalyItalyCzech R...
# ...

# %%
df_country_totals.sum()
# Out:
# Country                     ItalyFranceAustriaGermanySpainSwitzerlandCzech...
# PicturesTaken                                                           78470
# DaysVisited                                                               725
# UNESCOWorldHeritageSites                                                  365
# PlacesVisited                                                             511
# dtype: object

# %%
df_place_totals=df.groupby(["UNESCO World Heritage Site"]).agg(PicturesPerSite=('Picture Count','sum'),
                            DaysVisited=('Date','nunique'),
                            PlacesVisited=('Place','nunique')
                           ,MaxPicturesPerPlace=('Place','max') 
).sort_values(by="PicturesPerSite", ascending=False).reset_index().head(50)

# %%
df_place_totals=df.groupby(["Place"]).agg(PicturesTaken=('Picture Count','sum'),
                            DaysVisited=('Date','nunique')
                           ,UNESCOWorldHeritageSites=('UNESCO World Heritage Site','nunique') 
).sort_values(by="PicturesTaken", ascending=False).reset_index().head(50)

# %%
df_place_totals.sum()
# Out:
# Place                       ViennaRomeParisVeniceFlorencePragueNaplesVersa...
# PicturesTaken                                                           43207
# DaysVisited                                                               391
# UNESCOWorldHeritageSites                                                   72
# dtype: object

# %%
df_siteinfo_full.sort_values(by=["Most Picture Per Place"],ascending=False,ignore_index=True)
# Out:
#                             UNESCO World Heritage Site  TotalPictures  \
# 0                                               Vienna           4187
# 1                                                 Rome           3845
# 2                            Paris, Banks of the Seine           2710
# 3                                Venice and its Lagoon           2243
# 4                                             Florence           2058
# ..                                                 ...            ...
# 352                                      Vatnajoekuell              1
# 353  Frontiers of the Roman Empire - The Lower Germ...              1
# 354                 Jewish-Medieval Heritage of Erfurt              1
# 355                                      The Dolomites              1
# 356                              Hal Saflieni Hypogeum              0
#
#      TotalSecondaryPictures  CulturalSite  NaturalSite  NumCountries  \
# ...

# %%
df_siteinfo_full.sort_values(by=["Most Picture Per Place"],ascending=False,ignore_index=True).head(50)
# Out:
#                            UNESCO World Heritage Site  TotalPictures  \
# 0                                              Vienna           4187
# 1                                                Rome           3845
# 2                           Paris, Banks of the Seine           2710
# 3                               Venice and its Lagoon           2243
# 4                                            Florence           2058
# 5                                              Prague           1448
# 6                                              Naples           1380
# 7                   Gardens and Palace of Schoenbrunn           1047
# 8                       Palace and Park of Versailles           1042
# 9             Palaces and Parks of Potsdam and Berlin           1041
# 10                                       Vatican City            956
# 11                                             Krakow            778
# 12                                             Toledo            771
# ...

# %%
df[df['Co-Travellers'].str.contains('Heidrun')]["UNESCO World Heritage Site"].nunique()
# Out:
# 97

# %%
df[df['Co-Travellers'].str.contains('Heidrun')].groupby("UNESCO World Heritage Site").sum().reset_index().sort_values(by="Picture Count",ascending=False,ignore_index=True)
# Out:
# /var/folders/8d/gvjspwlj4hq61gsmkn1p_h480000gn/T/ipykernel_8760/1592941629.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df[df['Co-Travellers'].str.contains('Heidrun')].groupby("UNESCO World Heritage Site").sum().reset_index().sort_values(by="Picture Count",ascending=False,ignore_index=True)
#                           UNESCO World Heritage Site  Picture Count  \
# 0                                               Rome           1292
# 1                                             Naples            919
# 2                                             Prague            520
# 3                                             Vienna            474
# 4                          Yellowstone National Park            411
# ..                                               ...            ...
# ...

# %%
df[df['Co-Travellers'].str.contains('Grace')].groupby("UNESCO World Heritage Site").sum().reset_index().sort_values(by="Picture Count",ascending=False,ignore_index=True)
# Out:
# /var/folders/8d/gvjspwlj4hq61gsmkn1p_h480000gn/T/ipykernel_8760/2459381609.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df[df['Co-Travellers'].str.contains('Grace')].groupby("UNESCO World Heritage Site").sum().reset_index().sort_values(by="Picture Count",ascending=False,ignore_index=True)
#                           UNESCO World Heritage Site  Picture Count  \
# 0                            Historic Centre of Telc            155
# 1  St Mary's Cathedral and St Michael's Church at...            124
# 2                             Goslar and Rammelsberg            105
# 3                                   Corvey Monastery            104
# 4                                          Reichenau             79
# 5                                   City Hall Bremen             77
# ...

# %%
df[df['Co-Travellers'].str.contains('Vivan')].groupby("UNESCO World Heritage Site").sum().reset_index().sort_values(by="Picture Count",ascending=False,ignore_index=True)
# Out:
# /var/folders/8d/gvjspwlj4hq61gsmkn1p_h480000gn/T/ipykernel_8760/29378327.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df[df['Co-Travellers'].str.contains('Vivan')].groupby("UNESCO World Heritage Site").sum().reset_index().sort_values(by="Picture Count",ascending=False,ignore_index=True)
#                    UNESCO World Heritage Site  Picture Count  \
# 0                   Paris, Banks of the Seine            463
# 1                                      Vienna            181
# 2                                   Reichenau             79
# 3                            Abbey of St Gall             44
# 4                                    Salzburg             37
# 5  Routes of Santiago de Compostela in France              1
#
# ...

# %%
df[df['Co-Travellers'].str.contains('Michael')].groupby("UNESCO World Heritage Site").sum().reset_index().sort_values(by="Picture Count",ascending=False,ignore_index=True)
# Out:
# /var/folders/8d/gvjspwlj4hq61gsmkn1p_h480000gn/T/ipykernel_8760/100071543.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df[df['Co-Travellers'].str.contains('Michael')].groupby("UNESCO World Heritage Site").sum().reset_index().sort_values(by="Picture Count",ascending=False,ignore_index=True)
#                    UNESCO World Heritage Site  Picture Count  \
# 0                   Paris, Banks of the Seine            463
# 1                                      Vienna             85
# 2                                    Salzburg             37
# 3  Routes of Santiago de Compostela in France              1
#
#    Secondary Picture Count  Cultural Site  Natural Site  Site Removed  Year
# 0                        0              2             0             0  4038
# ...

# %%
df[df['Co-Travellers'].str.contains('Artur')].groupby("UNESCO World Heritage Site").sum().reset_index().sort_values(by="Picture Count",ascending=False,ignore_index=True)
# Out:
# /var/folders/8d/gvjspwlj4hq61gsmkn1p_h480000gn/T/ipykernel_8760/3392827616.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df[df['Co-Travellers'].str.contains('Artur')].groupby("UNESCO World Heritage Site").sum().reset_index().sort_values(by="Picture Count",ascending=False,ignore_index=True)
#                             UNESCO World Heritage Site  Picture Count  \
# 0                                               Naples            919
# 1                            Paris, Banks of the Seine            633
# 2    Loire Valley between Sully-sur-Loire and Chalo...            621
# 3                                  Dresden Elbe Valley            578
# 4                                               Prague            520
# ..                                                 ...            ...
# ...

# %%
df[df['Co-Travellers'].str.contains('Artur')].groupby("UNESCO World Heritage Site").sum().reset_index().sort_values(by="Picture Count",ascending=False,ignore_index=True).head(50)
# Out:
# /var/folders/8d/gvjspwlj4hq61gsmkn1p_h480000gn/T/ipykernel_8760/2590033770.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df[df['Co-Travellers'].str.contains('Artur')].groupby("UNESCO World Heritage Site").sum().reset_index().sort_values(by="Picture Count",ascending=False,ignore_index=True).head(50)
#                            UNESCO World Heritage Site  Picture Count  \
# 0                                              Naples            919
# 1                           Paris, Banks of the Seine            633
# 2   Loire Valley between Sully-sur-Loire and Chalo...            621
# 3                                 Dresden Elbe Valley            578
# 4                                              Prague            520
# ...

# %%
df[df['Co-Travellers'].str.contains('Hannsjoerg')].groupby("UNESCO World Heritage Site").sum().reset_index().sort_values(by="Picture Count",ascending=False,ignore_index=True)
# Out:
# /var/folders/8d/gvjspwlj4hq61gsmkn1p_h480000gn/T/ipykernel_8760/4161994731.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df[df['Co-Travellers'].str.contains('Hannsjoerg')].groupby("UNESCO World Heritage Site").sum().reset_index().sort_values(by="Picture Count",ascending=False,ignore_index=True)
#                            UNESCO World Heritage Site  Picture Count  \
# 0                                    Jungfrau-Aletsch            496
# 1                                              Vienna            474
# 2                           Yellowstone National Park            411
# 3   Loire Valley between Sully-sur-Loire and Chalo...            343
# 4                                                Lyon            295
# ..                                                ...            ...
# ...

# %%
df[df['Co-Travellers'].str.contains('Hannsjoerg')].groupby(pd.Grouper(key="Date", freq="1W")).sum()["Picture Count"].plot(title="weekly count of UNESCO world heritage pictures",ylabel="picture count",ylim=(0,600))
# Out:
# /var/folders/8d/gvjspwlj4hq61gsmkn1p_h480000gn/T/ipykernel_8760/3745833341.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df[df['Co-Travellers'].str.contains('Hannsjoerg')].groupby(pd.Grouper(key="Date", freq="1W")).sum()["Picture Count"].plot(title="weekly count of UNESCO world heritage pictures",ylabel="picture count",ylim=(0,600))
# <AxesSubplot: title={'center': 'weekly count of UNESCO world heritage pictures'}, xlabel='Date', ylabel='picture count'>

# %%
df[df['Co-Travellers'].str.contains('Janina')].groupby(pd.Grouper(key="Date", freq="1W")).sum()["Picture Count"].plot(title="weekly count of UNESCO world heritage pictures",ylabel="picture count",ylim=(0,150))
# Out:
# /var/folders/8d/gvjspwlj4hq61gsmkn1p_h480000gn/T/ipykernel_8760/3991261483.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df[df['Co-Travellers'].str.contains('Janina')].groupby(pd.Grouper(key="Date", freq="1W")).sum()["Picture Count"].plot(title="weekly count of UNESCO world heritage pictures",ylabel="picture count",ylim=(0,150))
# <AxesSubplot: title={'center': 'weekly count of UNESCO world heritage pictures'}, xlabel='Date', ylabel='picture count'>

# %%
df[df['Co-Travellers'].str.contains('Grace')].groupby(pd.Grouper(key="Date", freq="1W")).sum()["Picture Count"].plot(title="weekly count of UNESCO world heritage pictures",ylabel="picture count",ylim=(0,400))
# Out:
# /var/folders/8d/gvjspwlj4hq61gsmkn1p_h480000gn/T/ipykernel_8760/2583849131.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df[df['Co-Travellers'].str.contains('Grace')].groupby(pd.Grouper(key="Date", freq="1W")).sum()["Picture Count"].plot(title="weekly count of UNESCO world heritage pictures",ylabel="picture count",ylim=(0,400))
# <AxesSubplot: title={'center': 'weekly count of UNESCO world heritage pictures'}, xlabel='Date', ylabel='picture count'>

# %%
df[df['Co-Travellers'].str.contains('Artur')].groupby(pd.Grouper(key="Date", freq="1W")).sum()["Picture Count"].plot(title="weekly count of UNESCO world heritage pictures",ylabel="picture count",ylim=(0,1300))
# Out:
# /var/folders/8d/gvjspwlj4hq61gsmkn1p_h480000gn/T/ipykernel_8760/3068904610.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df[df['Co-Travellers'].str.contains('Artur')].groupby(pd.Grouper(key="Date", freq="1W")).sum()["Picture Count"].plot(title="weekly count of UNESCO world heritage pictures",ylabel="picture count",ylim=(0,1300))
# <AxesSubplot: title={'center': 'weekly count of UNESCO world heritage pictures'}, xlabel='Date', ylabel='picture count'>

# %%
df[df['Co-Travellers'].str.contains('Anne-Kathrin')]
# Out:
#           Date            Place  \
# 0   1996-03-02  Hartmannswiller
# 1   1996-05-15       Beatenberg
# 2   1996-08-26           London
# 3   1996-08-28           London
# 5   1996-08-29           London
# ..         ...              ...
# 622 2019-06-23             Riex
# 623 2019-06-23  Bourg-en-Lavaux
# 624 2019-06-23         Chexbres
# 667 2020-06-20      Baden-Baden
# 742 2021-09-04        Wuerzburg
#
#                             UNESCO World Heritage Site Secondary Site  \
# 0     Funerary and memory sites of the First World War            NaN
# 1                                     Jungfrau-Aletsch            NaN
# 2    Palace of Westminster and Westminster Abbey in...            NaN
# 3                                      Tower of London            NaN
# 5                                   Maritime Greenwich            NaN
# ..                                                 ...            ...
# 622                                             Lavaux            NaN
# ...

# %%
df[df['Co-Travellers'].str.contains('Anne-Kathrin')].groupby(pd.Grouper(key="Date", freq="1W")).sum()["Picture Count"].plot(title="weekly count of UNESCO world heritage pictures",ylabel="picture count",ylim=(0,175))
# Out:
# /var/folders/8d/gvjspwlj4hq61gsmkn1p_h480000gn/T/ipykernel_8760/3484599336.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df[df['Co-Travellers'].str.contains('Anne-Kathrin')].groupby(pd.Grouper(key="Date", freq="1W")).sum()["Picture Count"].plot(title="weekly count of UNESCO world heritage pictures",ylabel="picture count",ylim=(0,175))
# <AxesSubplot: title={'center': 'weekly count of UNESCO world heritage pictures'}, xlabel='Date', ylabel='picture count'>

# %%
df[df['Co-Travellers'].str.contains('Anne-Kathrin')].groupby("UNESCO World Heritage Site").sum().reset_index().sort_values(by="Picture Count",ascending=False,ignore_index=True)
# Out:
# /var/folders/8d/gvjspwlj4hq61gsmkn1p_h480000gn/T/ipykernel_8760/2785321219.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df[df['Co-Travellers'].str.contains('Anne-Kathrin')].groupby("UNESCO World Heritage Site").sum().reset_index().sort_values(by="Picture Count",ascending=False,ignore_index=True)
#                            UNESCO World Heritage Site  Picture Count  \
# 0                                             Dresden            152
# 1                          Bordeaux, Port of the Moon            124
# 2                                         Kew Gardens            113
# 3                                            Istanbul             77
# 4                                    Jungfrau-Aletsch             73
# 5                                                Rome             67
# ...

# %%
df[df['Co-Travellers'].str.contains('Jan-Marc')].groupby("UNESCO World Heritage Site").sum().reset_index().sort_values(by="Picture Count",ascending=False,ignore_index=True)
# Out:
# /var/folders/8d/gvjspwlj4hq61gsmkn1p_h480000gn/T/ipykernel_8760/2235796882.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df[df['Co-Travellers'].str.contains('Jan-Marc')].groupby("UNESCO World Heritage Site").sum().reset_index().sort_values(by="Picture Count",ascending=False,ignore_index=True)
#                            UNESCO World Heritage Site  Picture Count  \
# 0                                                Rome             67
# 1                           Paris, Banks of the Seine             33
# 2                                 Wuerzburg Residence             27
# 3                                        Vatican City             26
# 4                                    Athens Acropolis             17
# 5                                    Speyer Cathedral             16
# ...

# %%
df[df['Co-Travellers'].str.contains('Heidrun')].groupby(pd.Grouper(key="Date", freq="1W")).sum()["Picture Count"].plot(title="weekly count of UNESCO world heritage pictures",ylabel="picture count",ylim=(0,1200))
# Out:
# /var/folders/8d/gvjspwlj4hq61gsmkn1p_h480000gn/T/ipykernel_8760/1163030640.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df[df['Co-Travellers'].str.contains('Heidrun')].groupby(pd.Grouper(key="Date", freq="1W")).sum()["Picture Count"].plot(title="weekly count of UNESCO world heritage pictures",ylabel="picture count",ylim=(0,1200))
# <AxesSubplot: title={'center': 'weekly count of UNESCO world heritage pictures'}, xlabel='Date', ylabel='picture count'>

# %%
df_country_totals=df[df['Co-Travellers'].str.contains('Amin')].groupby(["Country"]).agg(PicturesTaken=('Picture Count','sum'),
                            DaysVisited=('Date','nunique')
                           ,UNESCOWorldHeritageSites=('UNESCO World Heritage Site','nunique') 
                           ,PlacesVisited=('Place','nunique')
).sort_values(by="PicturesTaken", ascending=False).reset_index()
df_country_totals
# Out:
#       Country  PicturesTaken  DaysVisited  UNESCOWorldHeritageSites  \
# 0       Italy           1631            8                         5
# 1      Greece            143            4                         2
# 2     Vatican            130            2                         2
# 3  San Marino             77            1                         1
#
#    PlacesVisited
# 0              9
# 1              2
# 2              1
# 3              1

# %%
df[df['Co-Travellers'].str.contains('Tony')].groupby("UNESCO World Heritage Site").sum().reset_index().sort_values(by="Picture Count",ascending=False,ignore_index=True)
# Out:
# /var/folders/8d/gvjspwlj4hq61gsmkn1p_h480000gn/T/ipykernel_8760/2858634196.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df[df['Co-Travellers'].str.contains('Tony')].groupby("UNESCO World Heritage Site").sum().reset_index().sort_values(by="Picture Count",ascending=False,ignore_index=True)
#   UNESCO World Heritage Site  Picture Count  Secondary Picture Count  \
# 0                  Marrakesh            410                        0
# 1                       Lyon             42                        0
# 2             Ait-Ben-Haddou             40                        0
#
#    Cultural Site  Natural Site  Site Removed  Year
# 0              4             0             0  8068
# 1              1             0             0  2017
# 2              1             0             0  2017

# %%
df[df['Co-Travellers'].str.contains('Vivan')].groupby("UNESCO World Heritage Site").sum().reset_index().sort_values(by="Picture Count",ascending=False,ignore_index=True)
# Out:
# /var/folders/8d/gvjspwlj4hq61gsmkn1p_h480000gn/T/ipykernel_8760/29378327.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df[df['Co-Travellers'].str.contains('Vivan')].groupby("UNESCO World Heritage Site").sum().reset_index().sort_values(by="Picture Count",ascending=False,ignore_index=True)
#                    UNESCO World Heritage Site  Picture Count  \
# 0                   Paris, Banks of the Seine            463
# 1                                      Vienna            181
# 2                                   Reichenau             79
# 3                            Abbey of St Gall             44
# 4                                    Salzburg             37
# 5  Routes of Santiago de Compostela in France              1
#
# ...

# %%
df[df['Co-Travellers'].str.contains('Amin')].groupby("UNESCO World Heritage Site").sum().reset_index().sort_values(by="Picture Count",ascending=False,ignore_index=True)
# Out:
# /var/folders/8d/gvjspwlj4hq61gsmkn1p_h480000gn/T/ipykernel_8760/4063235578.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df[df['Co-Travellers'].str.contains('Amin')].groupby("UNESCO World Heritage Site").sum().reset_index().sort_values(by="Picture Count",ascending=False,ignore_index=True)
#                           UNESCO World Heritage Site  Picture Count  \
# 0                                               Rome           1075
# 1  Genoa: Le Strade Nuove and the system of the P...            289
# 2                                Longobards in Italy            145
# 3  Venetian Works of Defence between the 16th and...            137
# 4                                       Cinque Terre            105
# 5                                         San Marino             77
# ...

# %%
df[df['Co-Travellers'].str.contains('Riju')].groupby("UNESCO World Heritage Site").sum().reset_index().sort_values(by="Picture Count",ascending=False,ignore_index=True)
# Out:
# /var/folders/8d/gvjspwlj4hq61gsmkn1p_h480000gn/T/ipykernel_8760/270217552.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df[df['Co-Travellers'].str.contains('Riju')].groupby("UNESCO World Heritage Site").sum().reset_index().sort_values(by="Picture Count",ascending=False,ignore_index=True)
#                            UNESCO World Heritage Site  Picture Count  \
# 0                                                Rome           1270
# 1                               Venice and its Lagoon            460
# 2                                           Marrakesh            410
# 3                       Palace and Park of Versailles            355
# 4             Palaces and Parks of Potsdam and Berlin            350
# 5                                        Vatican City            296
# ...

# %%
df[df['Co-Travellers'].str.contains('Riju')].groupby(pd.Grouper(key="Date", freq="1W")).sum()["Picture Count"].plot(title="weekly count of UNESCO world heritage pictures",ylabel="picture count",ylim=(0,1800),
                                                                                                                      xlim=(datetime.datetime(year=2015,month=5,day=1),datetime.datetime(year=2022,month=10,day=1))
                                                                                                                    )
# Out:
# /var/folders/8d/gvjspwlj4hq61gsmkn1p_h480000gn/T/ipykernel_8760/789186259.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df[df['Co-Travellers'].str.contains('Riju')].groupby(pd.Grouper(key="Date", freq="1W")).sum()["Picture Count"].plot(title="weekly count of UNESCO world heritage pictures",ylabel="picture count",ylim=(0,1800),
# <AxesSubplot: title={'center': 'weekly count of UNESCO world heritage pictures'}, xlabel='Date', ylabel='picture count'>

# %%
df[df['Co-Travellers'].str.contains('Andrew')].groupby(pd.Grouper(key="Date", freq="1W")).sum()["Picture Count"].plot(title="weekly count of UNESCO world heritage pictures",ylabel="picture count",ylim=(0,800),
                                                                                                                      xlim=(datetime.datetime(year=2013,month=1,day=1),datetime.datetime(year=2020,month=1,day=1)))
# Out:
# /var/folders/8d/gvjspwlj4hq61gsmkn1p_h480000gn/T/ipykernel_8760/2801041642.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df[df['Co-Travellers'].str.contains('Andrew')].groupby(pd.Grouper(key="Date", freq="1W")).sum()["Picture Count"].plot(title="weekly count of UNESCO world heritage pictures",ylabel="picture count",ylim=(0,800),
# <AxesSubplot: title={'center': 'weekly count of UNESCO world heritage pictures'}, xlabel='Date', ylabel='picture count'>

# %%
df[df['Co-Travellers'].str.contains('Manuel')].groupby(pd.Grouper(key="Date", freq="1W")).sum()["Picture Count"].plot(title="weekly count of UNESCO world heritage pictures",ylabel="picture count",ylim=(0,1300))
# Out:
# /var/folders/8d/gvjspwlj4hq61gsmkn1p_h480000gn/T/ipykernel_8760/919931489.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df[df['Co-Travellers'].str.contains('Manuel')].groupby(pd.Grouper(key="Date", freq="1W")).sum()["Picture Count"].plot(title="weekly count of UNESCO world heritage pictures",ylabel="picture count",ylim=(0,1300))
# <AxesSubplot: title={'center': 'weekly count of UNESCO world heritage pictures'}, xlabel='Date', ylabel='picture count'>

# %%
df[df['Co-Travellers'].str.contains('Reyer')].groupby(pd.Grouper(key="Date", freq="1W")).sum()["Picture Count"].plot(title="weekly count of UNESCO world heritage pictures",ylabel="picture count",ylim=(0,1300))
# Out:
# /var/folders/8d/gvjspwlj4hq61gsmkn1p_h480000gn/T/ipykernel_8760/4100375599.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df[df['Co-Travellers'].str.contains('Reyer')].groupby(pd.Grouper(key="Date", freq="1W")).sum()["Picture Count"].plot(title="weekly count of UNESCO world heritage pictures",ylabel="picture count",ylim=(0,1300))
# <AxesSubplot: title={'center': 'weekly count of UNESCO world heritage pictures'}, xlabel='Date', ylabel='picture count'>

# %%
df[df['Co-Travellers'].str.contains('Rachel')].groupby(pd.Grouper(key="Date", freq="1W")).sum()["Picture Count"].plot(title="weekly count of UNESCO world heritage pictures",ylabel="picture count",ylim=(0,200))
# Out:
# /var/folders/8d/gvjspwlj4hq61gsmkn1p_h480000gn/T/ipykernel_8760/3969879581.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df[df['Co-Travellers'].str.contains('Rachel')].groupby(pd.Grouper(key="Date", freq="1W")).sum()["Picture Count"].plot(title="weekly count of UNESCO world heritage pictures",ylabel="picture count",ylim=(0,200))
# <AxesSubplot: title={'center': 'weekly count of UNESCO world heritage pictures'}, xlabel='Date', ylabel='picture count'>

# %%
df[df['Co-Travellers'].str.contains('Eric')].groupby(pd.Grouper(key="Date", freq="1W")).sum()["Picture Count"].plot(title="weekly count of UNESCO world heritage pictures",ylabel="picture count",ylim=(0,1300))
# Out:
# /var/folders/8d/gvjspwlj4hq61gsmkn1p_h480000gn/T/ipykernel_8760/1187963477.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df[df['Co-Travellers'].str.contains('Eric')].groupby(pd.Grouper(key="Date", freq="1W")).sum()["Picture Count"].plot(title="weekly count of UNESCO world heritage pictures",ylabel="picture count",ylim=(0,1300))
# <AxesSubplot: title={'center': 'weekly count of UNESCO world heritage pictures'}, xlabel='Date', ylabel='picture count'>

# %%
df[df['Co-Travellers'].str.contains('Chris B')].groupby(pd.Grouper(key="Date", freq="1W")).sum()["Picture Count"].plot(title="weekly count of UNESCO world heritage pictures",ylabel="picture count",ylim=(0,1300))
# Out:
# /var/folders/8d/gvjspwlj4hq61gsmkn1p_h480000gn/T/ipykernel_8760/3726560252.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df[df['Co-Travellers'].str.contains('Chris B')].groupby(pd.Grouper(key="Date", freq="1W")).sum()["Picture Count"].plot(title="weekly count of UNESCO world heritage pictures",ylabel="picture count",ylim=(0,1300))
# <AxesSubplot: title={'center': 'weekly count of UNESCO world heritage pictures'}, xlabel='Date', ylabel='picture count'>

# %%
df[df['Co-Travellers'].str.contains('Amin')].groupby(pd.Grouper(key="Date", freq="1W")).sum()["Picture Count"].plot(title="weekly count of UNESCO world heritage pictures",ylabel="picture count",ylim=(0,1300))
# Out:
# /var/folders/8d/gvjspwlj4hq61gsmkn1p_h480000gn/T/ipykernel_8760/1459436836.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df[df['Co-Travellers'].str.contains('Amin')].groupby(pd.Grouper(key="Date", freq="1W")).sum()["Picture Count"].plot(title="weekly count of UNESCO world heritage pictures",ylabel="picture count",ylim=(0,1300))
# <AxesSubplot: title={'center': 'weekly count of UNESCO world heritage pictures'}, xlabel='Date', ylabel='picture count'>

# %%
df[df['Co-Travellers'].str.contains('Grace')].groupby(pd.Grouper(key="Date", freq="1W")).sum()["Picture Count"].plot(title="weekly count of UNESCO world heritage pictures",ylabel="picture count",ylim=(0,200))
# Out:
# /var/folders/8d/gvjspwlj4hq61gsmkn1p_h480000gn/T/ipykernel_8760/284903112.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df[df['Co-Travellers'].str.contains('Grace')].groupby(pd.Grouper(key="Date", freq="1W")).sum()["Picture Count"].plot(title="weekly count of UNESCO world heritage pictures",ylabel="picture count",ylim=(0,200))
# <AxesSubplot: title={'center': 'weekly count of UNESCO world heritage pictures'}, xlabel='Date', ylabel='picture count'>

# %%
df[df['Co-Travellers'].str.contains('Anne-Kathrin')]["UNESCO World Heritage Site"].nunique()
# Out:
# 45

# %%
df[df['Co-Travellers'].str.contains('Artur')]["UNESCO World Heritage Site"].nunique()
# Out:
# 158

# %%
df.nunique()
# Out:
# Date                          692
# Place                         510
# UNESCO World Heritage Site    357
# Secondary Site                 11
# Country                        41
# Picture Count                 242
# Secondary Picture Count        21
# Cultural Site                   2
# Natural Site                    2
# Site Removed                    2
# Co-Travellers                  94
# Year                           28
# firstDateVisited              283
# dtype: int64

# %%
import re
#re.sub(r'\W+', '', your_string)

cotravellers=set()

#if I consider unique() just alone, then it would split everything directly into 

for expr in df['Co-Travellers'].unique():
    word_V1=expr.split(", ")
    for w in word_V1:
        name=re.sub(r'\W+', '', w)
        if name!="":
            cotravellers.add(name)
len(cotravellers)
# Out:
# 87

# %%
cotravellers
# Out:
# {'AJ',
#  'Amin',
#  'Andrew',
#  'Angelika',
#  'Anne',
#  'AnneKathrin',
#  'Artem',
#  'Artur',
#  'Bing',
#  'Bob',
#  'Brant',
#  'Bryan',
#  'Böni',
#  'Cameron',
#  'ChrisBrainerd',
#  'ChrisClarke',
#  'ChrisLee',
#  'ChrisMartin',
#  'Christian',
#  'Christine',
#  'DavidSaltzberg',
#  'Didar',
#  'Dooyeon',
#  'Dylan',
#  'Eric',
#  'Eva',
#  'Felicitas',
#  'Francesca',
#  'Gianrico',
#  'Grace',
#  'Graham',
#  'Hannah',
#  'Hannsjoerg',
#  'Heidrun',
#  'Indara',
#  'Ivan',
#  'Jacob',
#  'JanMarc',
#  'Janina',
#  'Jennet',
#  'Jennetee',
#  'Jose',
#  'Juliana',
#  'Julius',
#  'Juno',
#  'Katy',
#  'Kevin',
#  'Keyvan',
#  'Lessya',
#  'Manuel',
#  'Marion',
#  'MaryAnn',
#  'Mathilda',
#  'Mia',
#  'Michael',
#  'Mohamed',
#  'Monica',
#  'Namrata',
#  'Nathan',
#  'Nhi',
#  'Nick',
#  'Paul',
#  'Rachel',
#  'RachelBartek',
#  'Reyer',
#  'Riju',
#  'Sam',
#  'Santona',
#  'Sasha',
#  'Serena',
#  'Sigi',
#  'Siyi',
#  'Steffen',
#  'Stephan',
#  'Stephanie',
# ...

# %%
df[df["UNESCO World Heritage Site"].str.contains('Vienna')].sum()
# Out:
# /var/folders/8d/gvjspwlj4hq61gsmkn1p_h480000gn/T/ipykernel_8760/10600161.py:1: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df[df["UNESCO World Heritage Site"].str.contains('Vienna')].sum()
# Place                         ViennaViennaViennaViennaViennaViennaViennaVien...
# UNESCO World Heritage Site    ViennaViennaViennaViennaViennaViennaViennaVien...
# Secondary Site                                                                0
# Country                       AustriaAustriaAustriaAustriaAustriaAustriaAust...
# Picture Count                                                              4187
# Secondary Picture Count                                                       0
# Cultural Site                                                                83
# ...

# %%
df_siteinfo_full.loc[df_siteinfo_full["UNESCO World Heritage Site"]=="Sea"]
# Out:
# Empty DataFrame
# Columns: [UNESCO World Heritage Site, TotalPictures, TotalSecondaryPictures, CulturalSite, NaturalSite, NumCountries, CountryMostVisits, PlaceMostVisits, DaysVisited, PlacesVisited, FirstDateVisited, LastDateVisited, YearsVisited, CountryMostPictures, Most Picture Per Country, PlaceMostPictures, Most Picture Per Place, Secondary Site, TotalPicturesFromSecondary, SecondaryPlaceMostVisits, SecondaryDaysVisited, SecondaryPlacesVisited]
# Index: []
#
# [0 rows x 22 columns]

# %%
df_siteinfo_full.loc[df_siteinfo_full["Secondary Site"]=="Routes of Santiago de Compostela in France"]
# Out:
#                     UNESCO World Heritage Site  TotalPictures  \
# 46  Routes of Santiago de Compostela in France            410
#
#     TotalSecondaryPictures  CulturalSite  NaturalSite  NumCountries  \
# 46                       0           1.0          0.0             1
#
#    CountryMostVisits PlaceMostVisits  DaysVisited  PlacesVisited  ...  \
# 46            France           Paris           20             11  ...
#
#    YearsVisited CountryMostPictures  Most Picture Per Country  \
# 46            8              France                       410
#
#    PlaceMostPictures  Most Picture Per Place  \
# 46          Toulouse                      94
#
#                                 Secondary Site  TotalPicturesFromSecondary  \
# 46  Routes of Santiago de Compostela in France                       562.0
#
#    SecondaryPlaceMostVisits  SecondaryDaysVisited SecondaryPlacesVisited
# 46                 Bordeaux                   9.0                    5.0
#
# [1 rows x 22 columns]

# %%
df_siteinfo_full.loc[df_siteinfo_full["Secondary Site"]=="Routes of Santiago de Compostela: Camino Frances and Routes of Northern Spain"]
# Out:
#                            UNESCO World Heritage Site  TotalPictures  \
# 25  Routes of Santiago de Compostela: Camino Franc...            557
#
#     TotalSecondaryPictures  CulturalSite  NaturalSite  NumCountries  \
# 25                       0           1.0          0.0             1
#
#    CountryMostVisits PlaceMostVisits  DaysVisited  PlacesVisited  ...  \
# 25             Spain            Leon            4              5  ...
#
#    YearsVisited CountryMostPictures  Most Picture Per Country  \
# 25            3               Spain                       557
#
#    PlaceMostPictures  Most Picture Per Place  \
# 25              Leon                     278
#
#                                        Secondary Site  \
# 25  Routes of Santiago de Compostela: Camino Franc...
#
#     TotalPicturesFromSecondary SecondaryPlaceMostVisits  SecondaryDaysVisited  \
# 25                       454.0   Santiago de Compostela                   4.0
#
#    SecondaryPlacesVisited
# ...

# %%
df_siteinfo_full.loc[(df_siteinfo_full["UNESCO World Heritage Site"]=="Routes of Santiago de Compostela: Camino Frances and Routes of Northern Spain")]
# Out:
#                            UNESCO World Heritage Site  TotalPictures  \
# 25  Routes of Santiago de Compostela: Camino Franc...            557
#
#     TotalSecondaryPictures  CulturalSite  NaturalSite  NumCountries  \
# 25                       0           1.0          0.0             1
#
#    CountryMostVisits PlaceMostVisits  DaysVisited  PlacesVisited  ...  \
# 25             Spain            Leon            4              5  ...
#
#    YearsVisited CountryMostPictures  Most Picture Per Country  \
# 25            3               Spain                       557
#
#    PlaceMostPictures  Most Picture Per Place  \
# 25              Leon                     278
#
#                                        Secondary Site  \
# 25  Routes of Santiago de Compostela: Camino Franc...
#
#     TotalPicturesFromSecondary SecondaryPlaceMostVisits  SecondaryDaysVisited  \
# 25                       454.0   Santiago de Compostela                   4.0
#
#    SecondaryPlacesVisited
# ...
