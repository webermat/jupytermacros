# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime

#originally planned to set index to date, but considering we have two sites per data that is not possible
data_list=[]
#2006
data_list.append([datetime.datetime(2006, 7, 11),"London","Westminster","","United Kingdom",4,0,1,0])
data_list.append([datetime.datetime(2006, 7, 12),"London","Westminster","","United Kingdom",20,0,1,0])
data_list.append([datetime.datetime(2006, 7, 13),"London","Tower of London","","United Kingdom",4,0,1,0])
data_list.append([datetime.datetime(2006, 7, 14),"London","Maritime Greenwich","","United Kingdom",6,0,1,0])
#NONE in 2007
#2008
data_list.append([datetime.datetime(2008, 1, 2),"Dresden","Dresden","","Germany",34,0,1,0])
data_list.append([datetime.datetime(2008, 1, 4),"Dresden","Dresden","","Germany",118,0,1,0])
data_list.append([datetime.datetime(2008, 1, 13),"St Gallen","Abbey of St Gall","","Switzerland",32,0,1,0]) 
data_list.append([datetime.datetime(2008, 5, 4),"Bern","Bern","","Switzerland",32,0,1,0]) 
data_list.append([datetime.datetime(2008, 7, 29),"Philadelphia","Independence Hall","","USA",4,0,1,0])
data_list.append([datetime.datetime(2008, 9, 4),"El Escorial","El Escorial Monastery","","Spain",19,0,1,0])
data_list.append([datetime.datetime(2008, 9, 5),"Segovia","Segovia","","Spain",107,0,1,0])
data_list.append([datetime.datetime(2008, 10, 5),"Lauterbrunnen","Jungfrau-Aletsch","","Switzerland",24,0,0,1])
data_list.append([datetime.datetime(2008, 10, 5),"Grindelwald","Jungfrau-Aletsch","","Switzerland",5,0,0,1])
data_list.append([datetime.datetime(2008, 10, 5),"Fieschertal","Jungfrau-Aletsch","","Switzerland",67,0,0,1])
#2009
data_list.append([datetime.datetime(2009, 1, 3),"Reichenau","Reichenau","","Germany",36,0,1,0]) 
data_list.append([datetime.datetime(2009, 1, 3),"Toledo","Toledo","","Spain",71,0,1,0]) 
data_list.append([datetime.datetime(2009, 7, 7),"New York City","Statue of Liberty","","USA",37,0,1,0])
data_list.append([datetime.datetime(2009, 8, 30),"Stechelberg","Jungfrau-Aletsch","","Switzerland",42,0,0,1])
data_list.append([datetime.datetime(2009, 11, 26),"Bern","Bern","","Switzerland",42,0,1,0])
data_list.append([datetime.datetime(2009, 12, 20),"Speyer","Speyer Cathedral","","Germany",35,0,1,0])
#2010
data_list.append([datetime.datetime(2010, 1, 21),"Bellinzona","Castles of Bellinzona","","Switzerland",48,0,0,1])
data_list.append([datetime.datetime(2010, 4, 5),"Steingaden","Wieskirche","","Germany",29,0,1,0])
data_list.append([datetime.datetime(2010, 5, 23),"Rosenlaui","Jungfrau-Aletsch","","Switzerland",70,0,0,1])
data_list.append([datetime.datetime(2010, 6, 27),"Fiesch","Jungfrau-Aletsch","","Switzerland",81,0,0,1])
data_list.append([datetime.datetime(2010, 6, 27),"Riederalp","Jungfrau-Aletsch","","Switzerland",15,0,0,1])
data_list.append([datetime.datetime(2010, 7, 21),"Paris","Paris, Banks of the Seine","","France",147,0,1,0])
data_list.append([datetime.datetime(2010, 7, 22),"Paris","Paris, Banks of the Seine","","France",4,0,1,0])
data_list.append([datetime.datetime(2010, 7, 23),"Paris","Paris, Banks of the Seine","","France",35,0,1,0])
data_list.append([datetime.datetime(2010, 7, 23),"Paris","Routes of Santiago de Compostela","","France",2,0,1,0])
data_list.append([datetime.datetime(2010, 7, 24),"Paris","Paris, Banks of the Seine","","France",3,0,1,0])
data_list.append([datetime.datetime(2010, 7, 25),"Versailles","Palace and Park of Versailles","","France",249,0,1,0])
data_list.append([datetime.datetime(2010, 7, 26),"Paris","Paris, Banks of the Seine","","France",13,0,1,0])
data_list.append([datetime.datetime(2010, 7, 28),"Paris","Paris, Banks of the Seine","","France",1,0,1,0])
data_list.append([datetime.datetime(2010, 7, 29),"Chartres","Chartres Cathedral","","France",85,0,1,0])
data_list.append([datetime.datetime(2010, 7, 30),"Fontainebleau","Palace and Park of Fontainebleau",'',"France",83,0,1,0])
data_list.append([datetime.datetime(2010, 7, 30),"Paris","Paris, Banks of the Seine","","France",43,0,1,0])
data_list.append([datetime.datetime(2010, 8, 1),"Paris","Paris, Banks of the Seine","","France",145,0,1,0])
data_list.append([datetime.datetime(2010, 8, 2),"Paris","Paris, Banks of the Seine","","France",160,0,1,0])
data_list.append([datetime.datetime(2010, 8, 3),"Reims","Cathedral of Notre-Dame, Former Abbey of Saint-Remi and Palace of Tau","","France",128,0,1,0])
data_list.append([datetime.datetime(2010, 8, 4),"Paris","Paris, Banks of the Seine","","France",26,0,1,0])
data_list.append([datetime.datetime(2010, 8, 8),"Grindelwald","Jungfrau-Aletsch","","Switzerland",242,0,0,1])
data_list.append([datetime.datetime(2010, 11, 27),"Bern","Bern","","Switzerland",242,0,1,0])
#2011
data_list.append([datetime.datetime(2011, 1, 23),"Milan","Santa Maria delle Grazie with The Last Supper","","Italy",3,0,1,0])
data_list.append([datetime.datetime(2011, 4, 3),"Lauterbrunnen","Jungfrau-Aletsch","","Switzerland",108,0,0,1])
data_list.append([datetime.datetime(2011, 4, 3),"Grindelwald","Jungfrau-Aletsch","","Switzerland",25,0,0,1])
data_list.append([datetime.datetime(2011, 4, 3),"Fieschertal","Jungfrau-Aletsch","","Switzerland",90,0,0,1])
data_list.append([datetime.datetime(2011, 5, 22),"Lyon","Lyon","","France",130,0,1,0])
data_list.append([datetime.datetime(2011, 5, 29),"Grindelwald","Jungfrau-Aletsch","","Switzerland",198,0,0,1])
data_list.append([datetime.datetime(2011, 5, 29),"Lauterbrunnen","Jungfrau-Aletsch","","Switzerland",87,0,0,1])
data_list.append([datetime.datetime(2011, 7, 3),"Fiescher","Jungfrau-Aletsch","","Switzerland",75,0,0,1])
data_list.append([datetime.datetime(2011, 7, 3),"Fieschertal","Jungfrau-Aletsch","","Switzerland",66,0,0,1])
data_list.append([datetime.datetime(2011, 9, 29),"Wuerzburg","Wuerzburg Residence","","Germany",20,0,1,0])
data_list.append([datetime.datetime(2011, 9, 29),"Bamberg","Bamberg","","Germany",16,0,1,0])
data_list.append([datetime.datetime(2011, 9, 30),"Bamberg","Bamberg","","Germany",140,0,1,0])
data_list.append([datetime.datetime(2011, 10, 1),"Wuerzburg","Wuerzburg Residence","","Germany",25,0,1,0])
data_list.append([datetime.datetime(2011, 12, 27),"Vienna","Wien","","Austria",60,0,1,0])
data_list.append([datetime.datetime(2011, 12, 27),"Vienna","Gardens and Palace of Schoenbrunn","","Austria",41,0,1,0])
data_list.append([datetime.datetime(2011, 12, 28),"Vienna","Wien","","Austria",99,0,1,0])
data_list.append([datetime.datetime(2011, 12, 29),"Vienna","Wien","","Austria",166,0,1,0])
data_list.append([datetime.datetime(2011, 12, 30),"Vienna","Wien","","Austria",149,0,1,0])
#2012 #Canon EOS 600D
data_list.append([datetime.datetime(2012, 5, 11),'Prague',"Prague","","Czech Republic",122,0,1,0])
data_list.append([datetime.datetime(2012, 5, 12),'Prague',"Prague","","Czech Republic",251,0,1,0])
data_list.append([datetime.datetime(2012, 5, 13),'Prague',"Prague","","Czech Republic",147,0,1,0])
data_list.append([datetime.datetime(2012, 6, 1),'Blois'," Loire Valley between Sully-sur-Loire and Chalonnes","","France",114,0,1,0])
data_list.append([datetime.datetime(2012, 6, 1),'Amboise'," Loire Valley between Sully-sur-Loire and Chalonnes","","France",50,0,1,0])
data_list.append([datetime.datetime(2012, 6, 1),'Chaumont-sur-Loire'," Loire Valley between Sully-sur-Loire and Chalonnes","","France",39,0,1,0])
data_list.append([datetime.datetime(2012, 6, 2),'Chambord'," Loire Valley between Sully-sur-Loire and Chalonnes","","France",89,0,1,0])
data_list.append([datetime.datetime(2012, 6, 3),'Vezelay',"Vezelay, Church and Hill","","France",50,0,1,0])
data_list.append([datetime.datetime(2012, 6, 3),'Vezelay',"Vezelay, Church and Hill","","France",50,0,1,0])
data_list.append([datetime.datetime(2012, 7, 26),'Potsdam',"Palaces and Parks of Potsdam and Berlin","","Germany",205,0,1,0])
data_list.append([datetime.datetime(2012, 7, 27),'Berlin',"Palaces and Parks of Potsdam and Berlin","","Germany",67,0,1,0])
data_list.append([datetime.datetime(2012, 7, 27),'Potsdam',"Palaces and Parks of Potsdam and Berlin","","Germany",75,0,1,0])
data_list.append([datetime.datetime(2012, 7, 28),'Potsdam',"Palaces and Parks of Potsdam and Berlin","","Germany",107,0,1,0])
data_list.append([datetime.datetime(2012, 7, 9),"Berlin","Museumsinsel","","Germany",72,0,1,0])
data_list.append([datetime.datetime(2012, 8, 18),"Lauterbrunnen","Jungfrau-Aletsch","","Switzerland",52,0,0,1])
data_list.append([datetime.datetime(2012, 8, 18),"Grindelwald","Jungfrau-Aletsch","","Switzerland",42,0,0,1])
data_list.append([datetime.datetime(2012, 8, 18),"Fieschertal","Jungfrau-Aletsch","","Switzerland",49,0,0,1])
data_list.append([datetime.datetime(2012, 8, 2),"Interlaken","Jungfrau-Aletsch","","Switzerland",52,0,0,1])
data_list.append([datetime.datetime(2019, 8, 26),"Unteruhldingen","Prehistoric Pile Dwellings around the Alps","","Switzerland",14,0,1,0])
data_list.append([datetime.datetime(2012, 8, 30),"Belem","Monastery of the Hieronymites and Tower of Belem","","Portugal",3,0,1,0])
data_list.append([datetime.datetime(2012, 8, 31),"Mafra","Palace of Mafra","","Portugal",68,0,1,0])
data_list.append([datetime.datetime(2012, 8, 31),"Sintra","Cultural Landscape of Sintra","","Portugal",117,0,1,0])
data_list.append([datetime.datetime(2012, 9, 1),"Sintra","Cultural Landscape of Sintra","","Portugal",73,0,1,0])
data_list.append([datetime.datetime(2012, 9, 2),"Belem","Monastery of the Hieronymites and Tower of Belem","","Portugal",27,0,1,0])
data_list.append([datetime.datetime(2012, 9, 6),"Tomar","Convent of Christ in Tomar","","Portugal",96,0,1,0])
data_list.append([datetime.datetime(2012, 9, 8),"Porto","Porto","","Portugal",86,0,1,0])
data_list.append([datetime.datetime(2012, 9, 6),"Coimbra","University of Coimbra – Alta and Sofia","","Portugal",89,0,1,0])
data_list.append([datetime.datetime(2012, 9, 16),"Gutannen","Jungfrau-Aletsch","","Switzerland",25,0,0,1])
data_list.append([datetime.datetime(2012, 9, 29),"Krakow","Krakow","","Poland",169,0,1,0])
data_list.append([datetime.datetime(2012, 9, 29),"Warsaw","Warsaw","","Poland",122,0,1,0])
#2013
data_list.append([datetime.datetime(2013, 1, 3),"Amsterdam","Seventeenth-Century Canal Ring Area","","Netherlands",41,0,1,0])
data_list.append([datetime.datetime(2013, 1, 5),"Amsterdam","Seventeenth-Century Canal Ring Area","","Netherlands",18,0,1,0])
data_list.append([datetime.datetime(2013, 3, 22),"Versailles","Palace and Park of Versailles","","France",190,0,1,0])
data_list.append([datetime.datetime(2013, 3, 22),"Paris","Paris, Banks of the Seine","","France",86,0,1,0])
data_list.append([datetime.datetime(2013, 3, 23),"Paris","Paris, Banks of the Seine","","France",145,0,1,0])
data_list.append([datetime.datetime(2013, 3, 23),"Paris","Routes of Santiago de Compostela","","France",1,0,1,0])
data_list.append([datetime.datetime(2013, 3, 24),"Fontainebleau","Palace and Park of Fontainebleau",'',"France",125,0,1,0])
data_list.append([datetime.datetime(2013, 3, 24),"Paris","Paris, Banks of the Seine","","France",25,0,1,0])
data_list.append([datetime.datetime(2013, 3, 25),"Paris","Paris, Banks of the Seine","","France",31,0,1,0])
data_list.append([datetime.datetime(2013, 4, 3),"Rome","Rome","","Italy",77,0,1,0])
data_list.append([datetime.datetime(2013, 4, 4),"Rome","Rome","","Italy",233,0,1,0])
data_list.append([datetime.datetime(2013, 4, 4),"Rome","Vatican City","","Vatican",269,0,1,0])
data_list.append([datetime.datetime(2013, 4, 5),"Rome","Rome","","Italy",40,0,1,0])
data_list.append([datetime.datetime(2013, 4, 5),"Rome","Rome","","Vatican",185,0,1,0])
data_list.append([datetime.datetime(2013, 4, 6),"Rome","Rome","","Italy",160,0,1,0])
data_list.append([datetime.datetime(2013, 4, 6),"Rome","Rome","","Vatican",8,0,1,0])
data_list.append([datetime.datetime(2013, 4, 7),"Rome","Rome","","Italy",90,0,1,0])
data_list.append([datetime.datetime(2013, 4, 8),"Rome","Rome","","Italy",249,0,1,0])
data_list.append([datetime.datetime(2013, 4, 9),"Tivoli", "Villa Adriana", "","Italy",66 ,0,1,0])
data_list.append([datetime.datetime(2013, 4, 9),"Tivoli", "Villa d'Este", "","Italy",98 ,0,1,0])
data_list.append([datetime.datetime(2013, 4, 9),"Rome","Rome","","Italy",69,0,1,0])
data_list.append([datetime.datetime(2013, 4, 10),"Rome","Rome","","Italy",48,0,1,0])
data_list.append([datetime.datetime(2013, 4, 11),"Rome","Rome","","Italy",66,0,1,0])
data_list.append([datetime.datetime(2013, 4, 14),"Grandvaux","Lavaux","","Switzerland",13,0,1,0])
data_list.append([datetime.datetime(2013, 5, 25),"Lyon","Lyon","","France",165,0,1,0])
data_list.append([datetime.datetime(2013, 7, 7),"Milan","Santa Maria delle Grazie with The Last Supper","","Italy",5,0,1,0])
data_list.append([datetime.datetime(2013, 7, 15),"Drottningholm","Royal Domain of Drottningholm","","Sweden",52,0,1,0])
data_list.append([datetime.datetime(2013, 7, 15),"Helsingor","Kronborg","","Denmark",91,0,1,0])
data_list.append([datetime.datetime(2013, 9, 5),"Venice","Venice and its Lagoon","","Italy",84,0,1,0])
data_list.append([datetime.datetime(2013, 9, 6),"Venice","Venice and its Lagoon","","Italy",339,0,1,0])
data_list.append([datetime.datetime(2013, 9, 7),"Venice","Venice and its Lagoon","","Italy",179,0,1,0])
data_list.append([datetime.datetime(2013, 9, 8),"Venice","Venice and its Lagoon","","Italy",205,0,1,0])
data_list.append([datetime.datetime(2013, 11, 8),"Compiegne","Routes of Santiago de Compostela","","France",6,0,1,0])
data_list.append([datetime.datetime(2013, 11, 8),"Paris","Paris, Banks of the Seine","","France",59,0,1,0])
data_list.append([datetime.datetime(2013, 11, 9),"Paris","Paris, Banks of the Seine","","France",23,0,1,0])
data_list.append([datetime.datetime(2013, 11, 10),"Paris","Paris, Banks of the Seine","","France",64,0,1,0])
data_list.append([datetime.datetime(2013, 11, 10),"Compiegne","Routes of Santiago de Compostela","","France",2,0,1,0])
data_list.append([datetime.datetime(2013, 12, 27),"Strassbourg", "Strassbourg", "","France",102 ,0,1,0])
#2014
data_list.append([datetime.datetime(2014, 4, 19),"Steingaden","Wieskirche","","Germany",2,0,1,0])
data_list.append([datetime.datetime(2014, 8, 18),"Grindelwald","Jungfrau-Aletsch","","Switzerland",74,0,0,1])
data_list.append([datetime.datetime(2014, 7, 24),"London", "Kew Gardens", "","United Kingdom",113 ,0,1,0])
data_list.append([datetime.datetime(2014, 7, 29),"London", "Tower of London", "","United Kingdom",59 ,0,1,0])
data_list.append([datetime.datetime(2014, 7, 30),"Woodstock", "Blenheim Palace", "","United Kingdom",141 ,0,1,0])
data_list.append([datetime.datetime(2014, 7, 31),"London", "Westminster", "","United Kingdom",114 ,0,1,0])
data_list.append([datetime.datetime(2014, 8, 1),"Canterbury", "Canterbury Castle", "","United Kingdom",90 ,0,1,0])
data_list.append([datetime.datetime(2014, 8, 2),"Amesbury", "Stonehenge, Avebury and Associated Sites", "","United Kingdom",22 ,0,1,0])
data_list.append([datetime.datetime(2014, 8, 2),"Bath", "Bath", "","United Kingdom",73 ,0,1,0])
data_list.append([datetime.datetime(2014, 8, 22),"Vienna","Wien","","Austria",216,0,1,0])
data_list.append([datetime.datetime(2014, 8, 23),"Neusiedl am See","Fertoe - Neusiedlersee Cultural Landscape","","Austria",1,0,1,0])
data_list.append([datetime.datetime(2014, 8, 23),"Fertoed","Fertoe - Neusiedlersee Cultural Landscape","","Hungary",102,0,1,0])
data_list.append([datetime.datetime(2014, 8, 23),"Vienna","Vienna","","Austria",21,0,1,0])
data_list.append([datetime.datetime(2014, 8, 25),"Vienna","Vienna","","Austria",13,0,1,0])
data_list.append([datetime.datetime(2014, 8, 26),"Vienna","Vienna","","Austria",16,0,1,0])
data_list.append([datetime.datetime(2014, 8, 27),"Vienna","Vienna","","Austria",66,0,1,0])
data_list.append([datetime.datetime(2014, 8, 28),"Vienna","Gardens and Palace of Schoenbrunn","","Austria",151,0,1,0])
data_list.append([datetime.datetime(2014, 8, 28),"Vienna","Vienna","","Austria",84,0,1,0])
data_list.append([datetime.datetime(2014, 8, 29),"Vienna","Vienna","","Austria",149,0,1,0])
data_list.append([datetime.datetime(2014, 8, 30),"Budapest","Budapest, including the Banks of the Danube, the Buda Castle Quarter and Andrassy Avenue","","Hungary",194,0,1,0])
data_list.append([datetime.datetime(2014, 8, 31),"Budapest","Budapest, including the Banks of the Danube, the Buda Castle Quarter and Andrassy Avenue","","Hungary",132,0,1,0])
data_list.append([datetime.datetime(2014, 9, 6),"Florence", "Florence", "Medici Villas and Gardens","Italy",245 ,221,1,0])
data_list.append([datetime.datetime(2014, 9, 7),"Pisa","Piazza del Duomo, Pisa","","Italy",104,0,1,0])
data_list.append([datetime.datetime(2014, 9, 7),"Florence", "Florence", "","Italy",155 ,0,1,0])
data_list.append([datetime.datetime(2014, 9, 12),"Florence", "Florence", "","Italy",187 ,0,1,0])
data_list.append([datetime.datetime(2014, 9, 13),"Florence", "Florence", "","Italy",193 ,0,1,0])
data_list.append([datetime.datetime(2014, 9, 13),"Siena", "Siena", "","Italy",151 ,0,1,0])
data_list.append([datetime.datetime(2014, 9, 14),"Florence", "Medici Villas and Gardens","","Italy",88 ,0,1,0])
data_list.append([datetime.datetime(2014, 9, 14),"Florence", "Florence", "","Italy",138 ,0,1,0])
data_list.append([datetime.datetime(2014, 9, 21),"Paris","Paris, Banks of the Seine","","France",64,0,1,0])
data_list.append([datetime.datetime(2014, 10, 24),"Istanbul","Istanbul","","Turkey",67,0,1,0])
data_list.append([datetime.datetime(2014, 10, 25),"Istanbul","Istanbul","","Turkey",262,0,1,0])
data_list.append([datetime.datetime(2014, 10, 26),"Istanbul","Istanbul","","Turkey",17,0,1,0])
data_list.append([datetime.datetime(2014, 12, 13),"London", "Westminster", "","United Kingdom",17 ,0,1,0])
data_list.append([datetime.datetime(2014, 12, 13),"London", "Tower of London", "","United Kingdom",3 ,0,1,0])
#2015
data_list.append([datetime.datetime(2015, 3, 29),"Sevilla", "Cathedral, Alcazar and Archivo de Indias in Seville", "","Spain",89 ,0,1,0])
data_list.append([datetime.datetime(2015, 3, 30),"Granada", "Alhambra, Generalife and Albayzin", "","Spain",166 ,0,1,0])
data_list.append([datetime.datetime(2015, 3, 31),"Cordoba", "Medina Azahara", "","Spain",43 ,0,1,0])
data_list.append([datetime.datetime(2015, 3, 31),"Cordoba", "Cordoba", "","Spain",85 ,0,1,0])
data_list.append([datetime.datetime(2015, 4, 1),"Segovia","Segovia","","Spain",118,0,1,0])
data_list.append([datetime.datetime(2015, 4, 2),"Toledo","Toledo","","Spain",146,0,1,0])
data_list.append([datetime.datetime(2015, 4, 3),"El Escorial","El Escorial Monastery","","Spain",54,0,1,0])
data_list.append([datetime.datetime(2015, 4, 4),"Cordoba", "Cordoba", "","Spain",113 ,0,1,0])
data_list.append([datetime.datetime(2015, 4, 4),"Sevilla", "Cathedral, Alcazar and Archivo de Indias in Seville", "","Spain",89 ,0,1,0])
data_list.append([datetime.datetime(2015, 4, 5),"Aranjuez", "Aranjuez Cultural Landscape", "","Spain",66 ,0,1,0])
data_list.append([datetime.datetime(2015, 5, 15),"Pompei","Pompei, Herculaneum and Torre Annunziata","","Italy",85,0,1,0])
data_list.append([datetime.datetime(2015, 5, 15),"Torre Annunziata","Pompei, Herculaneum and Torre Annunziata","","Italy",34,0,1,0])
data_list.append([datetime.datetime(2015, 5, 15),"Naples","Naples","","Italy",54,0,1,0])
data_list.append([datetime.datetime(2015, 5, 16),"Ercolano","Pompei, Herculaneum and Torre Annunziata","","Italy",31,0,1,0])
data_list.append([datetime.datetime(2015, 5, 16),"Naples","Naples","","Italy",15,0,1,0])
data_list.append([datetime.datetime(2015, 5, 17),"Caserta","Reggia di Caserta","","Italy",196,0,1,0])
data_list.append([datetime.datetime(2015, 5, 17),"Naples","Naples","","Italy",79,0,1,0])
data_list.append([datetime.datetime(2015, 5, 18),"Naples","Naples","","Italy",212,0,1,0])
data_list.append([datetime.datetime(2015, 7, 18),"Versailles","Palace and Park of Versailles","","France",355,0,1,0])
data_list.append([datetime.datetime(2015, 7, 19),"Mont-Saint-Michel","Mont-Saint-Michel and its Bay","","France",80,0,1,0])
data_list.append([datetime.datetime(2015, 8, 28),"Peterhof", "Petersburg and Related Groups of Monuments","","Russia",1,0,1,0])
data_list.append([datetime.datetime(2015, 8, 28),"Strelna", "Petersburg and Related Groups of Monuments","","Russia",1,0,1,0])
data_list.append([datetime.datetime(2015, 8, 28),"St Petersburg", "Petersburg and Related Groups of Monuments","","Russia",102,0,1,0])
data_list.append([datetime.datetime(2015, 8, 29),"St Petersburg", "Petersburg and Related Groups of Monuments","","Russia",59,0,1,0])
data_list.append([datetime.datetime(2015, 8, 29),"Lomonosow", "Petersburg and Related Groups of Monuments","","Russia",44,0,1,0])
data_list.append([datetime.datetime(2015, 8, 30),"St Petersburg", "Petersburg and Related Groups of Monuments","","Russia",2,0,1,0])
data_list.append([datetime.datetime(2015, 8, 30),"Pawlovsk", "Petersburg and Related Groups of Monuments","","Russia",81,0,1,0])
data_list.append([datetime.datetime(2015, 8, 30),"Gatchina", "Petersburg and Related Groups of Monuments","","Russia",69,0,1,0])
data_list.append([datetime.datetime(2015, 8, 31),"St Petersburg", "Petersburg and Related Groups of Monuments","","Russia",2,0,1,0])
data_list.append([datetime.datetime(2015, 9, 2),"Moscow", "Kremlin and Red Square","","Russia",133,0,1,0])
data_list.append([datetime.datetime(2015, 9, 3),"St Petersburg", "Petersburg and Related Groups of Monuments","","Russia",7,0,1,0])
data_list.append([datetime.datetime(2015, 9, 3),"Peterhof", "Petersburg and Related Groups of Monuments","","Russia",96,0,1,0])
data_list.append([datetime.datetime(2015, 9, 4),"St Petersburg", "Petersburg and Related Groups of Monuments","","Russia",11,0,1,0])
data_list.append([datetime.datetime(2015, 9, 5),"St Petersburg", "Petersburg and Related Groups of Monuments","","Russia",32,0,1,0])
data_list.append([datetime.datetime(2015, 9, 6),"St Petersburg", "Petersburg and Related Groups of Monuments","","Russia",21,0,1,0])
data_list.append([datetime.datetime(2015, 9, 6),"Puschkin", "Petersburg and Related Groups of Monuments","","Russia",259,0,1,0])
data_list.append([datetime.datetime(2015, 9, 7),"St Petersburg", "Petersburg and Related Groups of Monuments","","Russia",94,0,1,0])
data_list.append([datetime.datetime(2015, 9, 8),"St Petersburg", "Petersburg and Related Groups of Monuments","","Russia",200,0,1,0])
data_list.append([datetime.datetime(2015, 9, 9),"St Petersburg", "Petersburg and Related Groups of Monuments","","Russia",129,0,1,0])
data_list.append([datetime.datetime(2015, 9, 10),"Peterhof", "Petersburg and Related Groups of Monuments","","Russia",162,0,1,0])
data_list.append([datetime.datetime(2015, 9, 9),"Strelna", "Petersburg and Related Groups of Monuments","","Russia",44,0,1,0])
data_list.append([datetime.datetime(2015, 9, 19),"Paris","Paris, Banks of the Seine","","France",131,0,1,0])
data_list.append([datetime.datetime(2015, 9, 20),"Paris","Paris, Banks of the Seine","","France",27,0,1,0])
data_list.append([datetime.datetime(2015, 9, 20),"Paris","Routes of Santiago de Compostela","","France",1,0,1,0])
data_list.append([datetime.datetime(2015, 10, 8),"Melk","Wachau Cultural Landscape","","Austria",70,0,1,0])
data_list.append([datetime.datetime(2015, 10, 8),"Goettweig","Wachau Cultural Landscape","","Austria",56,0,1,0])
data_list.append([datetime.datetime(2015, 10, 9),"Salzburg","Salzburg","","Austria",97,0,1,0])
data_list.append([datetime.datetime(2015, 11, 8),'Potsdam',"Palaces and Parks of Potsdam and Berlin","","Germany",143,0,1,0])
data_list.append([datetime.datetime(2015, 11, 8),'Hamburg',"Speicherstadt","","Germany",3,0,1,0])
data_list.append([datetime.datetime(2015, 11, 10),'Berlin',"Museumsinsel","","Germany",2,0,1,0])
data_list.append([datetime.datetime(2015, 11, 11),'Luebeck',"Luebeck","","Germany",62,0,1,0])
data_list.append([datetime.datetime(2015, 11, 13),'Weimar',"Classical Weimar","","Germany",94,0,1,0])
#2016





#2017
data_list.append([datetime.datetime(2017, 1, 4),"Bushmills", "Giant's Causeway and Causeway Coast", "","United Kingdom",56 ,0,0,1])
data_list.append([datetime.datetime(2017, 1, 14),"Carcassonne", "Canal du Midi", "","France",5 ,0,1,0])
data_list.append([datetime.datetime(2017, 1, 14),"Carcassonne", "Cite de Carcassonne", "","France",101 ,0,1,0])
data_list.append([datetime.datetime(2017, 1, 14),"Avignon", "Papal Palace, Episcopal Ensemble and Avignon Bridge", "","France",11 ,0,1,0])
data_list.append([datetime.datetime(2017, 1, 15),"Avignon", "Papal Palace, Episcopal Ensemble and Avignon Bridge", "","France",167 ,0,1,0])
data_list.append([datetime.datetime(2017, 2, 11),"Brussels","Grand-Place, Brussels","","Belgium",3,0,1,0])
data_list.append([datetime.datetime(2017, 2, 11),"Bruges","Bruges","Belfries of Belgium and France","Belgium",94,5,1,0])
data_list.append([datetime.datetime(2017, 2, 11),"Ghent","Belfries of Belgium and France","","Belgium",6,0,1,0])
data_list.append([datetime.datetime(2017, 2, 12),"Ghent","Belfries of Belgium and France","","Belgium",2,0,1,0])
data_list.append([datetime.datetime(2017, 2, 12),"Antwerp","Belfries of Belgium and France","","Belgium",71,0,1,0])
data_list.append([datetime.datetime(2017, 3, 25),"Assisi","Assisi","","Italy",193,0,1,0])
data_list.append([datetime.datetime(2017, 3, 26),"Assisi","Assisi","","Italy",15,0,1,0])
data_list.append([datetime.datetime(2017, 3, 26),"Florence","Florence","","Italy",5,0,1,0])
data_list.append([datetime.datetime(2017, 4, 15),"Kiev","Saint-Sophia Cathedral and Kyiv-Pechersk Lavra","","Ukraine",137,0,1,0])
data_list.append([datetime.datetime(2017, 4, 30),"Speyer","Speyer Cathedral","","Germany",73,0,1,0])
data_list.append([datetime.datetime(2017, 5, 1),"Kassel","Bergpark Wilhelmshoehe","","Germany",164,0,1,0])
data_list.append([datetime.datetime(2017, 5, 25),"Salamanca","Salamanca","","Spain",259,0,1,0])
data_list.append([datetime.datetime(2017, 5, 26),"Valencia","Llotja de la Seda","","Spain",23,0,1,0])
data_list.append([datetime.datetime(2017, 5, 27),"Leon","Routes of Santiago de Compostela","","Spain",111,0,1,0])
data_list.append([datetime.datetime(2017, 5, 27),"Oviedo","Monuments of Oviedo and the Kingdom of the Asturias","Routes of Santiago de Compostela","Spain",25,19,1,0])
data_list.append([datetime.datetime(2017, 5, 27),"Oviedo","Routes of Santiago de Compostela","","Spain",73,0,1,0])
data_list.append([datetime.datetime(2017, 5, 28),"Avila","Old Town of Avila with its Extra-Muros Churches","","Spain",170,0,1,0])
data_list.append([datetime.datetime(2017, 6, 3),"Athens","Athens Acropolis","","Greece",16,0,1,0])
data_list.append([datetime.datetime(2017, 6, 4),"Athens","Athens Acropolis","","Greece",50,0,1,0])
data_list.append([datetime.datetime(2017, 6, 5),"Delphi","Delphi","","Greece",76,0,1,0])
data_list.append([datetime.datetime(2017, 6, 6),"Athens","Athens Acropolis","","Greece",1,0,1,0])
data_list.append([datetime.datetime(2017, 6, 9),"Iceland","Vatnajoekuell","","Iceland",1,0,0,1])
data_list.append([datetime.datetime(2017, 6, 9),"USA","Yellowstone","","USA",3,0,0,1])
data_list.append([datetime.datetime(2017, 6, 12),"West Yellowstone","Yellowstone National Park","","USA",42,0,0,1])
data_list.append([datetime.datetime(2017, 6, 13),"Madison","Yellowstone National Park","","USA",13,0,0,1])
data_list.append([datetime.datetime(2017, 6, 13),"Norris","Yellowstone National Park","","USA",35,0,0,1])
data_list.append([datetime.datetime(2017, 6, 13),"Gardiner","Yellowstone National Park","","USA",71,0,0,1])
data_list.append([datetime.datetime(2017, 6, 14),"West Yellowstone","Yellowstone National Park","","USA",8,0,0,1])
data_list.append([datetime.datetime(2017, 6, 14),"Norris","Yellowstone National Park","","USA",1,0,0,1])
data_list.append([datetime.datetime(2017, 6, 14),"Canyon Village","Yellowstone National Park","","USA",81,0,0,1])
data_list.append([datetime.datetime(2017, 6, 14),"Roosevelt","Yellowstone National Park","","USA",18,0,0,1])
data_list.append([datetime.datetime(2017, 6, 14),"West Yellowstone","Yellowstone National Park","","USA",3,0,0,1])
data_list.append([datetime.datetime(2017, 6, 15),"Lake Village","Yellowstone National Park","","USA",55,0,0,1])
data_list.append([datetime.datetime(2017, 6, 15),"Grant Village","Yellowstone National Park","","USA",31,0,0,1])
data_list.append([datetime.datetime(2017, 6, 15),"West Yellowstone","Yellowstone National Park","","USA",50,0,0,1])
data_list.append([datetime.datetime(2017, 7, 6),"Venice","Venice and its Lagoon","","Italy",33,0,1,0])
data_list.append([datetime.datetime(2017, 7, 7),"Venice","Venice and its Lagoon","","Italy",8,0,1,0])
data_list.append([datetime.datetime(2017, 7, 8),"Venice","Venice and its Lagoon","","Italy",222,0,1,0])
data_list.append([datetime.datetime(2017, 7, 9),"Venice","Venice and its Lagoon","","Italy",38,0,1,0])
data_list.append([datetime.datetime(2017, 7, 10),"Venice","Venice and its Lagoon","","Italy",217,0,1,0])
data_list.append([datetime.datetime(2017, 7, 11),"Venice","Venice and its Lagoon","","Italy",21,0,1,0])
data_list.append([datetime.datetime(2017, 7, 12),"Vicenza","City of Vicenza and the Palladian Villas of the Veneto","","Italy",141,0,1,0])
data_list.append([datetime.datetime(2017, 7, 13),"Ferrara","Ferrara, City of the Renaissance, and its Po Delta","","Italy",176,0,1,0])
data_list.append([datetime.datetime(2017, 7, 13),"Padua","Orto Botanico of Padua","","Italy",24,0,1,0])
data_list.append([datetime.datetime(2017, 7, 14),"Skocjan","Skocjan Caves","","Slovenia",83,0,0,1])
data_list.append([datetime.datetime(2017, 7, 14),"Porec","Skocjan Caves","","Croatia",61,0,1,0])
data_list.append([datetime.datetime(2017, 7, 15),"Aquileia","Archaeological Area and the Patriarchal Basilica of Aquileia","","Italy",42,0,1,0])
data_list.append([datetime.datetime(2017, 7, 15),"Cividale del Friuli","Longobards in Italy","","Italy",48,0,1,0])
data_list.append([datetime.datetime(2017, 8, 27),"Trogir","Trogir","","Croatia",61,0,1,0])
data_list.append([datetime.datetime(2017, 8, 27),"Split","Historical Complex of Split with the Palace of Diocletian","","Croatia",195,0,1,0])
data_list.append([datetime.datetime(2017, 9, 6),"Rome","Rome","","Italy",23,0,1,0])
data_list.append([datetime.datetime(2017, 9, 6),"Rome","Rome","","Vatican",1,0,1,0])
data_list.append([datetime.datetime(2017, 9, 7),"Rome","Rome","","Italy",171,0,1,0])
data_list.append([datetime.datetime(2017, 9, 7),"Rome","Vatican City","","Vatican",286,0,1,0])
data_list.append([datetime.datetime(2017, 9, 8),"Rome","Rome","","Italy",376,0,1,0])
data_list.append([datetime.datetime(2017, 9, 8),"Rome","Rome","","Vatican",119,0,1,0])
data_list.append([datetime.datetime(2017, 9, 9),"Rome","Rome","","Italy",346,0,1,0])
data_list.append([datetime.datetime(2017, 9, 9),"Rome","Rome","","Vatican",11,0,1,0])
data_list.append([datetime.datetime(2017, 9, 10),"Rome","Rome","","Italy",233,0,1,0])
data_list.append([datetime.datetime(2017, 9, 16),"London","Westminster","","United Kingdom",111,0,1,0])
data_list.append([datetime.datetime(2017, 9, 17),"London","Tower of London","","United Kingdom",9,0,1,0])
data_list.append([datetime.datetime(2017, 9, 30),"Graz","Graz","","Austria",149,0,1,0])
data_list.append([datetime.datetime(2017, 10, 1),"Graz","Graz","","Austria",62,0,1,0])
data_list.append([datetime.datetime(2017, 10, 6),"Tallinn","Tallinn","","Estonia",23,0,1,0])
data_list.append([datetime.datetime(2017, 10, 7),"Tallinn","Tallinn","","Estonia",3,0,1,0])
data_list.append([datetime.datetime(2017, 10, 7),"Helsinki","Suomenlinna","","Finland",37,0,1,0])
data_list.append([datetime.datetime(2017, 10, 8),"Tallinn","Tallinn","","Estonia",86,0,1,0])
data_list.append([datetime.datetime(2017, 11, 4),"St Gallen","Abbey of St Gall","","Switzerland",71,0,1,0]) 
data_list.append([datetime.datetime(2017, 11, 4),"Reichenau","Reichenau","","Germany",48,0,1,0]) 
data_list.append([datetime.datetime(2017, 11, 10),"Marrakesh","Marrakesh","","Morocco",136,0,1,0]) 
data_list.append([datetime.datetime(2017, 11, 11),"Marrakesh","Marrakesh","","Morocco",136,0,1,0])
data_list.append([datetime.datetime(2017, 11, 11),"Ait-Ben-Haddou","Ait-Ben-Haddou","","Morocco",40,0,1,0])
data_list.append([datetime.datetime(2017, 11, 12),"Marrakesh","Marrakesh","","Morocco",129,0,1,0])
data_list.append([datetime.datetime(2017, 11, 13),"Marrakesh","Marrakesh","","Morocco",9,0,1,0])
data_list.append([datetime.datetime(2017, 11, 19),"Marmagne","Fontenay Abbey","","France",50,0,1,0])
data_list.append([datetime.datetime(2017, 11, 19),"Arc-et-Senans","From the Great Saltworks of Salins-les-Bains to the Royal Saltworks of Arc-et-Senans, the Production of Open-pan Salt","","France",12,0,1,0])
data_list.append([datetime.datetime(2017, 11, 19),"Besancon","Fortifications of Vauban","","France",12,0,1,0])
data_list.append([datetime.datetime(2017, 12, 9),"Lyon","Lyon","","France",42,0,1,0])
#2018
data_list.append([datetime.datetime(2018, 1, 2),"Suzhou", "The Grand Canal", "","China",1 ,0,1,0])
data_list.append([datetime.datetime(2018, 1, 2),"Hangzhou", "West Lake of Hangzhou", "","China",148 ,0,1,0])
data_list.append([datetime.datetime(2018, 1, 3),"Suzhou", "Classical Gardens of Suzhou", "","China",116 ,0,1,0])
data_list.append([datetime.datetime(2018, 1, 5),"Nanjing", "Imperial Tombs of the Ming and Qing Dynasties", "","China",52 ,0,1,0])
data_list.append([datetime.datetime(2018, 1, 7),"Beijing", "Imperial Palaces of the Ming and Qing Dynasties in Beijing and Shenyang", "","China",299 ,0,1,0])
data_list.append([datetime.datetime(2018, 1, 8),"Juyongguan", "The Great Wall", "","China",7 ,0,1,0])
data_list.append([datetime.datetime(2018, 1, 8),"Badaling", "The Great Wall", "","China",80 ,0,1,0])
data_list.append([datetime.datetime(2018, 1, 9),"Beijing", "Temple of Heaven in Beijing", "","China",119 ,0,1,0])
data_list.append([datetime.datetime(2018, 1, 9),"Beijing", "Summer Palace in Beijing", "","China",177 ,0,1,0])
data_list.append([datetime.datetime(2018, 1, 10),"Beijing", "The Grand Canal", "","China",3 ,0,1,0])
data_list.append([datetime.datetime(2018, 1, 11),"Luoyang", "Longmen Grottoes", "Silk Roads: the Routes Network of Chang'an-Tianshan Corridor","China",105 ,105,1,0])
data_list.append([datetime.datetime(2018, 1, 12),"Xi'an", "Mausoleum of the First Qin Emperor", "","China",81 ,0,1,0])
data_list.append([datetime.datetime(2018, 1, 12),"Xi'an", "Silk Roads: the Routes Network of Chang'an-Tianshan Corridor", "","China",55 ,0,1,0])
data_list.append([datetime.datetime(2018, 1, 2),"Macao", "Macao", "","China",76 ,0,1,0])
data_list.append([datetime.datetime(2018, 3, 3),"Albi", "Episcopal City of Albi", "","France",122 ,0,1,0])
data_list.append([datetime.datetime(2018, 3, 3),"Toulouse","Routes of Santiago de Compostela","","France",60,0,1,0])
data_list.append([datetime.datetime(2018, 3, 3),"Toulouse","Canal du Midi","","France",2,0,1,0])
data_list.append([datetime.datetime(2018, 3, 4),"Toulouse","Canal du Midi","","France",4,0,1,0])
data_list.append([datetime.datetime(2018, 3, 4),"Toulouse","Routes of Santiago de Compostela","","France",4,0,1,0])
data_list.append([datetime.datetime(2018, 3, 10),"Amsterdam","Seventeenth-Century Canal Ring Area","","Netherlands",6,0,1,0])
data_list.append([datetime.datetime(2018, 3, 11),"Brussels","Grand-Place, Brussels","","Belgium",71,0,1,0])
data_list.append([datetime.datetime(2018, 3, 30),"Thingvellir National Park","Thingvellir National Park","","Iceland",33,0,1,0])
data_list.append([datetime.datetime(2018, 4, 15),"Roskilde","Roskilde Cathedral","","Denmark",115,0,1,0])
data_list.append([datetime.datetime(2018, 4, 28),"Reims","Cathedral of Notre-Dame, Former Abbey of Saint-Remi and Palace of Tau","","France",139,0,1,0])
data_list.append([datetime.datetime(2018, 4, 28),"Reims","Champagne Hillsides, Houses and Cellars","","France",40,0,1,0])
data_list.append([datetime.datetime(2018, 4, 29),"Versailles","Palace and Park of Versailles","","France",242,0,1,0])
data_list.append([datetime.datetime(2018, 4, 29),"Paris","Routes of Santiago de Compostela","","France",2,0,1,0])
data_list.append([datetime.datetime(2018, 4, 29),"Paris","Paris, Banks of the Seine","","France",89,0,1,0])
data_list.append([datetime.datetime(2018, 5, 1),"Amiens","Amiens Cathedral","","France",111,0,1,0])
data_list.append([datetime.datetime(2018, 5, 1),"Chartres","Chartres Cathedral","","France",108,0,1,0])
data_list.append([datetime.datetime(2018, 5, 19),"Brescia","Longobards in Italy","","Italy",145,0,1,0])
data_list.append([datetime.datetime(2018, 5, 20),"Bergamo","Venetian Works of Defence between the 16th and 17th Centuries","","Italy",137,0,1,0])
data_list.append([datetime.datetime(2018, 5, 21),"San Marino","San Marino","","San Marino",77,0,1,0])
data_list.append([datetime.datetime(2018, 5, 26),"Tarragona","Archaeological Ensemble of Tarraco","","Spain",46,0,1,0])
data_list.append([datetime.datetime(2018, 5, 26),"Barcelona","Works of Antoni Gaudi","","Spain",52,0,1,0])
data_list.append([datetime.datetime(2018, 5, 26),"Barcelona","Palau de la Música Catalana and Hospital de Sant Pau","","Spain",1,0,1,0])
data_list.append([datetime.datetime(2018, 5, 27),"Barcelona","Works of Antoni Gaudi","","Spain",47,0,1,0])
data_list.append([datetime.datetime(2018, 6, 3),"Edinburgh","Edinburgh","","United Kingdom",101,0,1,0])
data_list.append([datetime.datetime(2018, 6, 3),"Queensferry","Forth Bridge","","United Kingdom",14,0,1,0])
data_list.append([datetime.datetime(2018, 6, 3),"North Queensferry","Forth Bridge","","United Kingdom",2,0,1,0])
data_list.append([datetime.datetime(2018, 6, 4),"Fallkirk","Frontiers of the Roman Empire","","United Kingdom",9,0,1,0])
data_list.append([datetime.datetime(2018, 6, 5),"Durham","Durham Castle and Cathedral","","United Kingdom",59,0,1,0])
data_list.append([datetime.datetime(2018, 6, 6),"Ripon","Studley Royal Park including the Ruins of Fountains Abbey","","United Kingdom",98,0,1,0])
data_list.append([datetime.datetime(2018, 6, 8),"Conwy","Castles and Town Walls of King Edward in Gwynedd","","United Kingdom",69,0,1,0])
data_list.append([datetime.datetime(2018, 6, 8),"Caernarfon","Castles and Town Walls of King Edward in Gwynedd","","United Kingdom",55,0,1,0])
data_list.append([datetime.datetime(2018, 6, 9),"Liverpool","Liverpool – Maritime Mercantile City","","United Kingdom",39,0,1,0])
data_list.append([datetime.datetime(2018, 7, 3),"Seoul","Changdeokgung Palace","","South Korea",109,0,1,0])
data_list.append([datetime.datetime(2018, 7, 4),"Seoul","Jongmyo Shrine","","South Korea",20,0,1,0])
data_list.append([datetime.datetime(2018, 7, 4),"Seoul","Royal Tombs of the Joseon Dynasty","","South Korea",23,0,1,0])
data_list.append([datetime.datetime(2018, 7, 12),"Suwom","Hwaseong Fortress","","South Korea",66,0,1,0])
data_list.append([datetime.datetime(2018, 7, 12),"Gwangju","Namhansanseong","","South Korea",38,0,1,0])
data_list.append([datetime.datetime(2018, 7, 13),"Gyeongju","Seokguram Grotto and Bulguksa Temple","","South Korea",45,0,1,0])
data_list.append([datetime.datetime(2018, 7, 13),"Gyeongju","Historic Villages of Korea: Hahoe and Yangdong","","South Korea",21,0,1,0])
data_list.append([datetime.datetime(2018, 7, 13),"Gyeongju","Gyeongju Historic Areas","","South Korea",20,0,1,0])
data_list.append([datetime.datetime(2019, 7, 28),"Kandersteg","Jungfrau-Aletsch","","Switzerland",57,0,0,1])
data_list.append([datetime.datetime(2019, 7, 28),"Frutigen","Jungfrau-Aletsch","","Switzerland",5,0,0,1])
data_list.append([datetime.datetime(2019, 7, 28),"Bern","Bern","","Switzerland",48,0,1,0])
data_list.append([datetime.datetime(2019, 7, 28),"Kerzers","Jungfrau-Aletsch","","Switzerland",2,0,0,1])
data_list.append([datetime.datetime(2019, 7, 28),"Neuchatel","Jungfrau-Aletsch","","Switzerland",2,0,0,1])
data_list.append([datetime.datetime(2019, 9, 2),"Steingaden","Wieskirche","","Germany",17,0,1,0])
data_list.append([datetime.datetime(2019, 9, 2),"Regensburg","Regensburg","","Germany",52,0,1,0])
data_list.append([datetime.datetime(2019, 9, 3),"Bamberg","Bamberg","","Germany",68,0,1,0])
data_list.append([datetime.datetime(2019, 9, 4),"Wuerzburg","Wuerzburg Residence","","Germany",34,0,1,0])
data_list.append([datetime.datetime(2019, 9, 4),"Bayreuth","Margravial Opera House Bayreuth","","Germany",24,0,1,0])
data_list.append([datetime.datetime(2019, 9, 5),"Eisenach","Wartburg","","Germany",77,0,1,0])
data_list.append([datetime.datetime(2019, 9, 5),"Schoenstedt","Ancient and Primeval Beech Forests of the Carpathians and Other Regions of Europe","","Germany",18,0,0,1])
data_list.append([datetime.datetime(2019, 9, 5),"Naumburg","Naumburg Cathedral","","Germany",51,0,1,0])
data_list.append([datetime.datetime(2019, 9, 6),"Dessau-Rosslau","Bauhaus and its Sites in Weimar, Dessau and Bernau","","Germany",24,0,1,0])
data_list.append([datetime.datetime(2019, 9, 6),"Dessau-Rosslau","Garden Kingdom of Dessau-Wörlitz","","Germany",50,0,1,0])
data_list.append([datetime.datetime(2019, 9, 6),"Oranienbaum-Woerlitz","Garden Kingdom of Dessau-Wörlitz","","Germany",184,0,1,0])
data_list.append([datetime.datetime(2019, 9, 7),"Wittenberg","Luther Memorials","","Germany",36,0,1,0])
data_list.append([datetime.datetime(2019, 9, 7),"Quedlinburg","Quedlinburg","","Germany",50,0,1,0])
data_list.append([datetime.datetime(2019, 9, 8),"Potsdam","Palaces and Parks of Potsdam and Berlin","","Germany",350,0,1,0])
data_list.append([datetime.datetime(2019, 9, 9),"Berlin","Museumsinsel","","Germany",139,0,1,0])
data_list.append([datetime.datetime(2018, 9, 22),"Antwerp", "Belfries of Belgium and France", "","Belgium",2 ,0,1,0])
data_list.append([datetime.datetime(2018, 9, 22),"Antwerp", "Plantin Moretus", "","Belgium",33 ,0,1,0])
data_list.append([datetime.datetime(2018, 9, 22),"Mechelen", "Belfries of Belgium and France", "","Belgium",33 ,0,1,0])
data_list.append([datetime.datetime(2018, 9, 23),"Leuven", "Flemish Beguinages", "","Belgium",2 ,0,1,0])
data_list.append([datetime.datetime(2018, 9, 23),"Leuven", "Belfries of Belgium and France", "","Belgium",31 ,0,1,0])
data_list.append([datetime.datetime(2018, 11, 17),"Arles", "Arles, Roman and Romanesque Monuments", "Routes of Santiago de Compostela","France",151 ,18,1,0])
data_list.append([datetime.datetime(2018, 11, 19),"Orange", "Theatre and Triumphal Arch of Orange", "","France",38 ,0,1,0])
data_list.append([datetime.datetime(2018, 12, 8),"Beaune", "Climats, Terroirs of Burgundy", "","France",61 ,0,1,0])
data_list.append([datetime.datetime(2018, 12, 8),"Dijon", "Climats, Terroirs of Burgundy", "","France",87 ,0,1,0])
data_list.append([datetime.datetime(2018, 12, 8),"Vougeot", "Climats, Terroirs of Burgundy", "","France",54 ,0,1,0])
data_list.append([datetime.datetime(2018, 12, 29),"Maulbronn", "Maulbronn Monastery", "","Germany",92 ,0,1,0])
data_list.append([datetime.datetime(2018, 12, 29),"Voelklingen", "Voelklingen Ironworks", "","Germany",95 ,0,1,0])
data_list.append([datetime.datetime(2018, 12, 29),"Lorsch", "Abbey of Lorsch", "","Germany",30 ,0,1,0])
#2019
data_list.append([datetime.datetime(2019, 1, 13),"Domodossola", "Sacri Monti of Piedmont and Lombardy", "","Italy",140 ,0,1,0])
data_list.append([datetime.datetime(2019, 1, 13),"Orta San Giulia", "Sacri Monti of Piedmont and Lombardy", "","Italy",156 ,0,1,0])
data_list.append([datetime.datetime(2019, 3, 11),"Matera","Sassi of Matera","","Italy",104,0,1,0])
data_list.append([datetime.datetime(2019, 3, 12),"Andria","Castel del Monte","","Italy",45,0,1,0])
data_list.append([datetime.datetime(2019, 3, 14),"Alberobello","Trulli of Alberobello","","Italy",39,0,1,0])
data_list.append([datetime.datetime(2019, 3, 15),"Naples","Naples","","Italy",308,0,1,0])
data_list.append([datetime.datetime(2019, 3, 16),"Caserta","Reggia di Caserta","","Italy",200,0,1,0])
data_list.append([datetime.datetime(2019, 3, 16),"Benevento","Longobards in Italy","","Italy",34,0,1,0])
data_list.append([datetime.datetime(2019, 3, 17),"Ercolano","Pompei, Herculaneum and Torre Annunziata","","Italy",127,0,1,0])
data_list.append([datetime.datetime(2019, 3, 17),"Naples","Naples","","Italy",250,0,1,0])
data_list.append([datetime.datetime(2019, 3, 18),"Paestum","Cilento and Vallo di Diano National Park with the Archeological Sites of Paestum and Velia, and the Certosa di Padula","","Italy",66,0,1,0])
data_list.append([datetime.datetime(2019, 3, 18),"Naples","Naples","","Italy",228,0,1,0])
data_list.append([datetime.datetime(2019, 3, 19),"Pompei","Pompei, Herculaneum and Torre Annunziata","","Italy",169,0,1,0])
data_list.append([datetime.datetime(2019, 3, 19),"Torre Annunziata","Pompei, Herculaneum and Torre Annunziata","","Italy",73,0,1,0])
data_list.append([datetime.datetime(2019, 3, 19),"Naples","Naples","","Italy",73,0,1,0])
data_list.append([datetime.datetime(2019, 3, 20),"Positano","Amalfi Coast","","Italy",79,0,1,0])
data_list.append([datetime.datetime(2019, 3, 20),"Praiano","Amalfi Coast","","Italy",3,0,1,0])
data_list.append([datetime.datetime(2019, 3, 20),"Furore","Amalfi Coast","","Italy",2,0,1,0])
data_list.append([datetime.datetime(2019, 3, 20),"Conca dei Marini","Amalfi Coast","","Italy",3,0,1,0])
data_list.append([datetime.datetime(2019, 3, 20),"Amalfi","Amalfi Coast","","Italy",145,0,1,0])
data_list.append([datetime.datetime(2019, 3, 20),"Atrani","Amalfi Coast","","Italy",3,0,1,0])
data_list.append([datetime.datetime(2019, 3, 20),"Ravello","Amalfi Coast","","Italy",3,0,1,0])
data_list.append([datetime.datetime(2019, 3, 20),"Marmorata","Amalfi Coast","","Italy",1,0,1,0])
data_list.append([datetime.datetime(2019, 3, 20),"Minori","Amalfi Coast","","Italy",3,0,1,0])
data_list.append([datetime.datetime(2019, 3, 20),"Maiori","Amalfi Coast","","Italy",10,0,1,0])
data_list.append([datetime.datetime(2019, 3, 20),"Erchie","Amalfi Coast","","Italy",4,0,1,0])
data_list.append([datetime.datetime(2019, 3, 20),"Cetara","Amalfi Coast","","Italy",9,0,1,0])
data_list.append([datetime.datetime(2019, 3, 20),"Vietri Sul Mare","Amalfi Coast","","Italy",4,0,1,0])
data_list.append([datetime.datetime(2019, 3, 21),"Naples","Naples","","Italy",60,0,1,0])
data_list.append([datetime.datetime(2019, 4, 6),"Murten","Prehistoric Pile Dwellings around the Alps","","Switzerland",2,0,1,0])
data_list.append([datetime.datetime(2019, 4, 14),"London","Maritime Greenwich","","United Kingdom",106,0,1,0])
data_list.append([datetime.datetime(2019, 4, 18),"Paris","Routes of Santiago de Compostela","","France",1,0,1,0])
data_list.append([datetime.datetime(2019, 4, 19),"St Savin","Abbey Church of St Savin","","France",105,0,1,0])
data_list.append([datetime.datetime(2019, 4, 19),"Poitiers","Routes of Santiago de Compostela","","France",29,0,1,0])
data_list.append([datetime.datetime(2019, 4, 19),"Paris","Paris, Banks of the Seine","","France",13,0,1,0])
data_list.append([datetime.datetime(2019, 4, 20),"Provins","Provins",'',"France",60,0,1,0])
data_list.append([datetime.datetime(2019, 4, 20),"Fontainebleau","Palace and Park of Fontainebleau",'',"France",250,0,1,0])
data_list.append([datetime.datetime(2019, 4, 20),"Paris","Routes of Santiago de Compostela","","France",2,0,1,0])
data_list.append([datetime.datetime(2019, 4, 20),"Paris","Paris, Banks of the Seine","","France",83,0,1,0])
data_list.append([datetime.datetime(2019, 4, 21),"Bourges","Bourges Cathedral","Routes of Santiago de Compostela","France",195,195,1,0])
data_list.append([datetime.datetime(2019, 4, 22),"Le Havre","Le Havre","","France",62,0,1,0])
data_list.append([datetime.datetime(2019, 5, 31),"Hoexter","Corvey Monastery","","Germany",104,0,1,0])
data_list.append([datetime.datetime(2019, 5, 31),"Alfeld","Fagus Factory","","Germany",14,0,1,0])
data_list.append([datetime.datetime(2019, 5, 31),"Hildesheim","St Mary's Cathedral and St Michael's Church at Hildesheim","","Germany",124,0,1,0])
data_list.append([datetime.datetime(2019, 6, 1),"Bremen","City Hall Bremen","","Germany",77,0,1,0])
data_list.append([datetime.datetime(2019, 6, 1),"Norddeich","Wadden Sea","","Germany",47,0,0,1])
data_list.append([datetime.datetime(2019, 6, 2),"Goslar","Goslar and Rammelsberg","","Germany",105,0,1,0])
data_list.append([datetime.datetime(2019, 6, 23),"Cully","Lavaux","","Switzerland",9,0,1,0])
data_list.append([datetime.datetime(2019, 6, 23),"Riex","Lavaux","","Switzerland",15,0,1,0])
data_list.append([datetime.datetime(2019, 6, 23),"Bourg-en-Lavaux","Lavaux","","Switzerland",19,0,1,0])
data_list.append([datetime.datetime(2019, 6, 23),"Chexbres","Lavaux","","Switzerland",5,0,1,0])
data_list.append([datetime.datetime(2019, 7, 28),"Fiesch","Jungfrau-Aletsch","","Switzerland",18,0,0,1])
data_list.append([datetime.datetime(2019, 7, 28),"Fieschertal","Jungfrau-Aletsch","","Switzerland",87,0,0,1])
data_list.append([datetime.datetime(2019, 9, 15),"Blatten","Jungfrau-Aletsch","","Switzerland",277,0,0,1])
data_list.append([datetime.datetime(2019, 9, 21),"Paris","Paris, Banks of the Seine","","France",277,0,1,0])
data_list.append([datetime.datetime(2019, 9, 22),"Paris","Routes of Santiago de Compostela","","France",1,0,1,0])
data_list.append([datetime.datetime(2019, 9, 22),"Paris","Paris, Banks of the Seine","","France",186,0,1,0])
data_list.append([datetime.datetime(2019, 10, 6),"Corseaux","Corbusier","","Switzerland",7,0,1,0])
data_list.append([datetime.datetime(2019, 10, 6),"Rivaz","Lavaux","","Switzerland",19,0,1,0])
#2020
data_list.append([datetime.datetime(2020, 1, 1),"Bad Muskau","Muskauer Park","","Germany",22,0,1,0])
data_list.append([datetime.datetime(2020, 1, 1),"Leknica","Muskauer Park","","Poland",25,0,1,0])
data_list.append([datetime.datetime(2020, 1, 1),"Swidwinica","Churches of Peace in Slesia","","Poland",59,0,1,0])
data_list.append([datetime.datetime(2020, 1, 2),"Wieliczka","Wieliczka and Bochnia Royal Salt Mines","","Poland",97,0,1,0])
data_list.append([datetime.datetime(2020, 1, 2),"Krakow","Krakow","","Poland",175,0,1,0])
data_list.append([datetime.datetime(2020, 1, 3),"Wroclaw","Centennial Hall","","Poland",12,0,1,0])  
data_list.append([datetime.datetime(2020, 2, 8),"St Gallen","Abbey of St Gall","","Switzerland",44,0,1,0]) 
data_list.append([datetime.datetime(2020, 2, 8),"Reichenau","Reichenau","","Germany",79,0,1,0]) 
data_list.append([datetime.datetime(2020, 2, 20),"Rome", "Rome", "","Vatican",62 ,0,1,0])
data_list.append([datetime.datetime(2020, 2, 20),"Rome", "Rome", "","Italy",130 ,0,1,0])
data_list.append([datetime.datetime(2020, 2, 21),"Urbino", "Urbino", "","Italy",147 ,0,1,0])
data_list.append([datetime.datetime(2020, 2, 23),"Rome", "Rome", "","Vatican",6 ,0,1,0])
data_list.append([datetime.datetime(2020, 2, 23),"Rome", "Rome", "","Italy",14 ,0,1,0])
data_list.append([datetime.datetime(2020, 2, 24),"Pienza", "Pienza", "","Italy",59 ,0,1,0])
data_list.append([datetime.datetime(2020, 2, 24),"Pienza", "Val d'Orcia", "","Italy",46 ,0,1,0])
data_list.append([datetime.datetime(2020, 2, 25),"Siena", "Siena", "","Italy",298 ,0,1,0])
data_list.append([datetime.datetime(2020, 2, 25),"San Gimignano", "San Gimignano", "","Italy",137 ,0,1,0])
data_list.append([datetime.datetime(2020, 2, 26),"Florence", "Florence", "Medici Villas and Gardens","Italy",768 ,202,1,0])
data_list.append([datetime.datetime(2020, 2, 27),"Rome", "Rome", "","Vatican",128 ,0,1,0])
data_list.append([datetime.datetime(2020, 2, 27),"Rome", "Rome", "","Italy",10 ,0,1,0])
data_list.append([datetime.datetime(2020, 2, 27),"Rome", "Vatican City", "","Vatican",3 ,0,1,0])
data_list.append([datetime.datetime(2020, 2, 28),"Rome", "Vatican City", "","Vatican",362 ,0,1,0])
data_list.append([datetime.datetime(2020, 2, 28),"Rome", "Rome", "","Italy",180 ,0,1,0])
data_list.append([datetime.datetime(2020, 2, 29),"Rome", "Rome", "","Italy",535 ,0,1,0])
data_list.append([datetime.datetime(2020, 3, 1),"Tivoli", "Villa d'Este", "","Italy",164 ,0,1,0])
data_list.append([datetime.datetime(2020, 3, 1),"Tivoli", "Villa Adriana", "","Italy",94 ,0,1,0])
data_list.append([datetime.datetime(2020, 3, 2),"Rome", "Rome", "","Vatican",73 ,0,1,0])
data_list.append([datetime.datetime(2020, 3, 2),"Rome", "Rome", "","Italy",145 ,0,1,0])
data_list.append([datetime.datetime(2020, 6, 20),"Strassbourg", "Strassbourg", "","France",114 ,0,1,0])
data_list.append([datetime.datetime(2020, 8, 1),"Belalp", "Jungfrau-Aletsch", "","Switzerland",151 ,0,0,1])
data_list.append([datetime.datetime(2020, 8, 1),"Domodossola", "Sacri Monti of Piedmont and Lombardy", "","Italy",15 ,0,1,0])
data_list.append([datetime.datetime(2020, 8, 9),"Lauterbrunnen", "Jungfrau-Aletsch", "","Switzerland",14 ,0,0,1])
data_list.append([datetime.datetime(2020, 8, 9),"Grindelwald", "Jungfrau-Aletsch", "","Switzerland",10 ,0,0,1])
data_list.append([datetime.datetime(2020, 8, 9),"Fieschertal", "Jungfrau-Aletsch", "","Switzerland",226 ,0,0,1])
data_list.append([datetime.datetime(2020, 8, 10),"Fieschertal", "Jungfrau-Aletsch", "","Switzerland",75 ,0,0,1])

df = pd.DataFrame(data_list,columns=['Date', 'Place', 'UNESCO World Heritage Site','Secondary Site','Country','PictureCount','Secondary Picture Count',"Cultural Site","Natural Site"])
df.groupby(pd.Grouper(key="Date", freq="1W")).sum()["PictureCount"].plot()

# %%
df.groupby(["Place"]).sum().sort_values(by="PictureCount", ascending=False).head(20)
# Out:
#                PictureCount  Secondary Picture Count  Cultural Site  \
# Place
# Rome                   4708                        0             33
# Paris                  1890                        0             32
# Florence               1779                      423              8
# Venice                 1346                        0             10
# Naples                 1279                        0              9
# Vienna                 1231                        0             13
# Versailles             1036                        0              4
# Potsdam                 880                        0              5
# Fieschertal             660                        0              0
# St Petersburg           659                        0             11
# Beijing                 598                        0              4
# Grindelwald             596                        0              0
# London                  566                        0             12
# ...

# %%
df.groupby(["UNESCO World Heritage Site"]).sum().sort_values(by="PictureCount", ascending=False).head(20)
# Out:
#                                             PictureCount  \
# UNESCO World Heritage Site
# Rome                                                3788
# Jungfrau-Aletsch                                    2413
# Paris, Banks of the Seine                           1880
# Florence                                            1691
# Petersburg and Related Groups of Monuments          1416
# Venice and its Lagoon                               1346
# Naples                                              1279
# Palace and Park of Versailles                       1036
# Palaces and Parks of Potsdam and Berlin              947
# Vatican City                                         920
# Wien                                                 690
# Prague                                               520
# Pompei, Herculaneum and Torre Annunziata             519
# Palace and Park of Fontainebleau                     458
# Siena                                                449
# ...

# %%
df.groupby(["Country"]).sum().sort_values(by="PictureCount", ascending=False)
# Out:
#                 PictureCount  Secondary Picture Count  Cultural Site  \
# Country
# Italy                  11675                      423             98
# France                  6420                      213             81
# Germany                 3533                        0             47
# Switzerland             3075                        0             16
# Spain                   1973                       19             23
# Austria                 1666                        0             19
# Russia                  1549                        0             21
# Vatican                 1513                        0             13
# United Kingdom          1394                        0             25
# China                   1319                      105             14
# Poland                   659                        0              7
# Portugal                 559                        0              8
# ...
