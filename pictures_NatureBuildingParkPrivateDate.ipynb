# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import datetime as datetime

# %%
#columns:
#date,place,country,type of photo, photo count, people travelling on that trip
#photo types: 0 city photo/buildings, 1 predominantly nature (not major on animals), 2 mixed (e.g. lake and village, or sea and city), 
#3 park, 4 private event aka focus on people, 5 animals/zoo, 6 flowers outside of park 7 else

data_list=[]

# %%
#FEUERWERK ETC ALSO MISSING

#photo types: 0 city photo/buildings, 1 predominantly nature (not major on animals), 2 mixed (e.g. lake and village, or sea and city), 
#3 park, 4 private event aka focus on people, 5 animals/zoo, 6 flowers outside of park 7 else

data_list.append([datetime.datetime(2019, 1, 13),"Domodossola","Italy",0,154,[]])
data_list.append([datetime.datetime(2019, 1, 13),"Domodossola","Italy",1,2,[]])
data_list.append([datetime.datetime(2019, 1, 13),"Domodossola","Italy",2,3,[]])
data_list.append([datetime.datetime(2019, 1, 13),"Orta San Giulia","Italy",0,159,[]])
data_list.append([datetime.datetime(2019, 1, 13),"Orta San Giulia","Italy",1,4,[]])
data_list.append([datetime.datetime(2019, 1, 13),"Orta San Giulia","Italy",2,10,[]])
data_list.append([datetime.datetime(2019, 1, 19),"Lauchringen","Germany",1,1,[]])
data_list.append([datetime.datetime(2019, 1, 19),"Lauchringen","Germany",4,1,["Christian",'Anne-Kathrin',"Ursula"]])
data_list.append([datetime.datetime(2019, 2, 21),"St Cergue","Switzerland",4,6,["CLIC group"]])
data_list.append([datetime.datetime(2019, 2, 21),"St Cergue","Switzerland",2,2,["CLIC group"]])
data_list.append([datetime.datetime(2019, 2, 21),"St Cergue","Switzerland",0,4,["CLIC group"]])
data_list.append([datetime.datetime(2019, 2, 21),"St Cergue","Switzerland",1,6,["CLIC group"]])
data_list.append([datetime.datetime(2019, 2, 24),"Chamonix","France",4,5,["Christine",'Grace',"Riju"]])
data_list.append([datetime.datetime(2019, 2, 24),"Chamonix","France",2,7,["Christine",'Grace',"Riju"]])
data_list.append([datetime.datetime(2019, 2, 24),"Chamonix","France",1,129,["Christine",'Grace',"Riju"]])
data_list.append([datetime.datetime(2019, 3, 2),"Zuerich","Switzerland",2,11,[]])
data_list.append([datetime.datetime(2019, 3, 2),"Zuerich","Switzerland",0,177,[]])
data_list.append([datetime.datetime(2019, 3, 4),"Meyrin","Switzerland",0,24,[]])








data_list.append([datetime.datetime(2019, 4, 6),"Murten","Switzerland",0,35,["Artur",'Heidrun']])
data_list.append([datetime.datetime(2019, 4, 6),"Murten","Switzerland",1,1,["Artur",'Heidrun']])
data_list.append([datetime.datetime(2019, 4, 6),"Murten","Switzerland",2,3,["Artur",'Heidrun']])
data_list.append([datetime.datetime(2019, 4, 6),"Murten","Switzerland",4,1,["Artur",'Heidrun']])
data_list.append([datetime.datetime(2019, 4, 6),"Avenches","Switzerland",0,18,["Artur",'Heidrun']])
data_list.append([datetime.datetime(2019, 4, 6),"Avenches","Switzerland",1,1,["Artur",'Heidrun']])
data_list.append([datetime.datetime(2019, 4, 6),"Puidoux","Switzerland",1,1,[]])
data_list.append([datetime.datetime(2019, 4, 6),"Bourg-en-Lavaux","Switzerland",1,1,[]])
data_list.append([datetime.datetime(2019, 4, 6),"Riex","Switzerland",2,1,[]])
data_list.append([datetime.datetime(2019, 4, 6),"Chenaux","Switzerland",2,2,[]])
data_list.append([datetime.datetime(2019, 4, 6),"Grandvaux","Switzerland",2,2,[]])
data_list.append([datetime.datetime(2019, 4, 6),"Vilette","Switzerland",2,2,[]])
data_list.append([datetime.datetime(2019, 4, 8),"Genf","Switzerland",0,1,[]])
data_list.append([datetime.datetime(2019, 4, 8),"Genf","Switzerland",4,7,[]])
data_list.append([datetime.datetime(2019, 4, 13),"London","United Kingdom",0,10,[]])
data_list.append([datetime.datetime(2019, 4, 13),"Cambridge","United Kingdom",0,101,[]])
data_list.append([datetime.datetime(2019, 4, 13),"Cambridge","United Kingdom",2,2,[]])
data_list.append([datetime.datetime(2019, 4, 13),"Peterborough","United Kingdom",0,67,[]])
data_list.append([datetime.datetime(2019, 4, 13),"Ely","United Kingdom",0,77,[]])
data_list.append([datetime.datetime(2019, 4, 14),"London","United Kingdom",0,242,[]])
data_list.append([datetime.datetime(2019, 4, 14),"London","United Kingdom",2,7,[]])
data_list.append([datetime.datetime(2019, 4, 14),"London","United Kingdom",3,3,[]])
data_list.append([datetime.datetime(2019, 4, 14),"London","United Kingdom",1,5,[]])
data_list.append([datetime.datetime(2019, 4, 14),"Oxford","United Kingdom",0,7,[]])
data_list.append([datetime.datetime(2019, 4, 15),"Oxford","United Kingdom",0,5,[]])
data_list.append([datetime.datetime(2019, 4, 16),"Oxford","United Kingdom",0,26,[]])
data_list.append([datetime.datetime(2019, 4, 16),"Oxford","United Kingdom",6,4,[]])
data_list.append([datetime.datetime(2019, 4, 17),"Oxford","United Kingdom",0,32,[]])
data_list.append([datetime.datetime(2019, 4, 18),"Paris","France",0,1,["Riju","Chris B"]])
data_list.append([datetime.datetime(2019, 4, 19),"St Savin","France",0,105,["Riju","Chris B"]])
data_list.append([datetime.datetime(2019, 4, 19),"St Savin","France",1,2,["Riju","Chris B"]])
data_list.append([datetime.datetime(2019, 4, 19),"St Savin","France",2,5,["Riju","Chris B"]])
data_list.append([datetime.datetime(2019, 4, 19),"Chauvigny","France",0,2,["Riju","Chris B"]])
data_list.append([datetime.datetime(2019, 4, 19),"Poitiers","France",0,128,["Riju","Chris B"]])
data_list.append([datetime.datetime(2019, 4, 19),"Paris","France",0,26,["Riju","Chris B"]])
data_list.append([datetime.datetime(2019, 4, 20),"Provins","France",1,1,["Riju","Chris B"]])
data_list.append([datetime.datetime(2019, 4, 20),"Provins","France",6,1,["Riju","Chris B"]])
data_list.append([datetime.datetime(2019, 4, 20),"Provins","France",0,1,["Riju","Chris B"]])
data_list.append([datetime.datetime(2019, 4, 20),"Fontainebleau","France",0,230,["Riju","Chris B"]])
data_list.append([datetime.datetime(2019, 4, 20),"Fontainebleau","France",3,20,["Riju","Chris B"]])
data_list.append([datetime.datetime(2019, 4, 20),"Paris","France",0,85,["Riju","Chris B"]])
data_list.append([datetime.datetime(2019, 4, 21),"Paris","France",0,7,["Riju","Chris B"]])
data_list.append([datetime.datetime(2019, 4, 21),"Bourges","France",0,347,["Riju","Chris B"]])
data_list.append([datetime.datetime(2019, 4, 22),"Paris","France",0,10,["Riju","Chris B"]])
data_list.append([datetime.datetime(2019, 4, 22),"Le Havre","France",0,71,["Riju","Chris B"]])
data_list.append([datetime.datetime(2020, 5, 26),"Bourg-en-Lavaux","Switzerland",2,8,['Riju']])
data_list.append([datetime.datetime(2020, 5, 26),"Balzers","Liechtenstein",0,1,['Riju']])
data_list.append([datetime.datetime(2020, 5, 26),"Balzers","Liechtenstein",2,2,['Riju']])
data_list.append([datetime.datetime(2020, 5, 26),"Sevelen","Switzerland",2,1,['Riju']])
data_list.append([datetime.datetime(2020, 5, 26),"Vaduz","Liechtenstein",0,37,['Riju']])
data_list.append([datetime.datetime(2020, 5, 26),"Vaduz","Liechtenstein",2,4,['Riju']])
data_list.append([datetime.datetime(2020, 5, 26),"Vaduz","Liechtenstein",1,3,['Riju']])
data_list.append([datetime.datetime(2020, 5, 26),"Vaduz","Liechtenstein",6,1,['Riju']])
data_list.append([datetime.datetime(2020, 5, 26),"Vaduz","Liechtenstein",3,3,['Riju']])
data_list.append([datetime.datetime(2020, 5, 26),"Vaduz","Liechtenstein",4,2,['Riju']])
data_list.append([datetime.datetime(2020, 5, 26),"Zuerich","Switzerland",4,1,['Riju']])
data_list.append([datetime.datetime(2020, 5, 26),"Zuerich","Switzerland",0,2,['Riju']])
data_list.append([datetime.datetime(2020, 5, 30),"Frankfurt","Germany",0,4,['Grace']])
data_list.append([datetime.datetime(2020, 5, 30),"Hannover","Germany",0,28,['Grace']])
data_list.append([datetime.datetime(2020, 5, 30),"Hannover","Germany",2,1,['Grace']])
data_list.append([datetime.datetime(2020, 5, 30),"Bremen","Germany",0,1,['Grace']])
data_list.append([datetime.datetime(2020, 5, 30),"Oldenburg","Germany",0,58,['Grace']])
data_list.append([datetime.datetime(2020, 5, 30),"Oldenburg","Germany",4,1,['Grace']])
data_list.append([datetime.datetime(2020, 5, 30),"Oldenburg","Germany",2,1,['Grace']])
data_list.append([datetime.datetime(2020, 5, 31),"Hoexter","Germany",0,106,['Grace']])
data_list.append([datetime.datetime(2020, 5, 31),"Alfeld","Germany",0,13,['Grace']])
data_list.append([datetime.datetime(2020, 5, 31),"Alfeld","Germany",4,1,['Grace']])
data_list.append([datetime.datetime(2020, 5, 31),"Hildesheim","Germany",0,130,['Grace']])
data_list.append([datetime.datetime(2020, 5, 31),"Braunschweig","Germany",0,25,['Grace']])
data_list.append([datetime.datetime(2020, 5, 31),"Hannover","Germany",0,1,['Grace']])
data_list.append([datetime.datetime(2020, 6, 1),"Bremen","Germany",0,164,['Grace']])
data_list.append([datetime.datetime(2020, 6, 1),"Bremen","Germany",1,1,['Grace']])
data_list.append([datetime.datetime(2020, 6, 1),"Bremen","Germany",4,3,['Grace']])
data_list.append([datetime.datetime(2020, 6, 1),"Norddeich","Germany",0,23,['Grace']])
data_list.append([datetime.datetime(2020, 6, 1),"Norddeich","Germany",1,14,['Grace']])
data_list.append([datetime.datetime(2020, 6, 1),"Norddeich","Germany",4,3,['Grace']])
data_list.append([datetime.datetime(2020, 6, 1),"Norddeich","Germany",2,13,['Grace']])
data_list.append([datetime.datetime(2020, 6, 1),"Hannover","Germany",1,1,['Grace']])
data_list.append([datetime.datetime(2020, 6, 2),"Goslar","Germany",0,107,['Grace']])
data_list.append([datetime.datetime(2020, 6, 2),"Goslar","Germany",4,1,['Grace']])
data_list.append([datetime.datetime(2020, 6, 2),"Hannover","Germany",0,97,['Grace']])
data_list.append([datetime.datetime(2020, 6, 2),"Hannover","Germany",4,5,['Grace']])
data_list.append([datetime.datetime(2020, 6, 2),"Hannover","Germany",3,81,['Grace']])
data_list.append([datetime.datetime(2020, 6, 3),"Hannover","Germany",0,3,['Grace']])
data_list.append([datetime.datetime(2020, 6, 3),"Deutschland","Germany",2,11,['Grace']])
data_list.append([datetime.datetime(2020, 6, 3),"Deutschland","Germany",0,3,['Grace']])
data_list.append([datetime.datetime(2020, 6, 3),"Hoeri","Switzerland",2,2,['Grace']])
data_list.append([datetime.datetime(2020, 6, 3),"Kloten","Switzerland",0,1,['Grace']])
data_list.append([datetime.datetime(2020, 6, 16),"Luzern","Switzerland",1,2,['Riju','Chris B','Rachel']])
data_list.append([datetime.datetime(2020, 6, 16),"Luzern","Switzerland",0,58,['Riju','Chris B','Rachel']])
data_list.append([datetime.datetime(2020, 6, 16),"Luzern","Switzerland",2,17,['Riju','Chris B','Rachel']])
data_list.append([datetime.datetime(2020, 6, 16),"Schweiz","Switzerland",2,33,['Riju','Chris B','Rachel']])
data_list.append([datetime.datetime(2020, 6, 16),"Schweiz","Switzerland",1,45,['Riju','Chris B','Rachel']])
data_list.append([datetime.datetime(2020, 6, 16),"Schweiz","Switzerland",0,4,['Riju','Chris B','Rachel']])
data_list.append([datetime.datetime(2020, 6, 16),"Schweiz","Switzerland",5,1,['Riju','Chris B','Rachel']])
data_list.append([datetime.datetime(2020, 6, 16),"Schweiz","Switzerland",4,1,['Riju','Chris B','Rachel']])
data_list.append([datetime.datetime(2020, 6, 22),"Vallorbe","Switzerland",1,119,['Christian','Anne-Kathrin']])
data_list.append([datetime.datetime(2020, 6, 22),"Vallorbe","Switzerland",0,2,['Christian','Anne-Kathrin']])
data_list.append([datetime.datetime(2020, 6, 22),"Genf","Switzerland",2,2,[]])
data_list.append([datetime.datetime(2020, 6, 22),"Genf","Switzerland",0,2,[]])
data_list.append([datetime.datetime(2020, 6, 22),"Genf","Switzerland",4,4,['Andres','Jose',"Indara",'Ivan']])
data_list.append([datetime.datetime(2020, 6, 23),"Genf","Switzerland",4,5,['Andres','Jose',"Indara",'Ivan']])
data_list.append([datetime.datetime(2020, 6, 23),"Cully","Switzerland",4,1,['Christian','Anne-Kathrin','Hannsjoerg','Heidrun','Artur']])
data_list.append([datetime.datetime(2020, 6, 23),"Cully","Switzerland",2,9,['Christian','Anne-Kathrin','Hannsjoerg','Heidrun','Artur']])
data_list.append([datetime.datetime(2020, 6, 23),"Cully","Switzerland",1,2,['Christian','Anne-Kathrin','Hannsjoerg','Heidrun','Artur']])
data_list.append([datetime.datetime(2020, 6, 23),"Riex","Switzerland",1,8,['Christian','Anne-Kathrin','Hannsjoerg','Heidrun','Artur']])
data_list.append([datetime.datetime(2020, 6, 23),"Riex","Switzerland",2,9,['Christian','Anne-Kathrin','Hannsjoerg','Heidrun','Artur']])
data_list.append([datetime.datetime(2020, 6, 23),"Bourg-en-Lavaux","Switzerland",1,9,['Christian','Anne-Kathrin','Hannsjoerg','Heidrun','Artur']])
data_list.append([datetime.datetime(2020, 6, 23),"Bourg-en-Labaux","Switzerland",2,11,['Christian','Anne-Kathrin','Hannsjoerg','Heidrun','Artur']])
data_list.append([datetime.datetime(2020, 6, 23),"Bourg-en-Labaux","Switzerland",4,3,['Christian','Anne-Kathrin','Hannsjoerg','Heidrun','Artur']])
data_list.append([datetime.datetime(2020, 6, 23),"Bourg-en-Lavaux","Switzerland",1,4,['Christian','Anne-Kathrin','Hannsjoerg','Heidrun','Artur']])
data_list.append([datetime.datetime(2020, 6, 23),"Bourg-en-Labaux","Switzerland",2,4,['Christian','Anne-Kathrin','Hannsjoerg','Heidrun','Artur']])
data_list.append([datetime.datetime(2020, 7, 5),"Meyrin","Switzerland",4,1,['CERNies']])
data_list.append([datetime.datetime(2020, 7, 8),"Cessy","France",0,7,['Jens',"Matthias",'Andres']])
data_list.append([datetime.datetime(2020, 7, 8),"Cessy","France",4,5,['Jens',"Matthias",'Andres']])
data_list.append([datetime.datetime(2020, 7, 28),"Fieschertal","Switzerland",4,12,["Ulrike","Francesca",'Chris B',"Ivan",'Jose']])
data_list.append([datetime.datetime(2020, 7, 28),"Fieschertal","Switzerland",1,77,["Ulrike","Francesca",'Chris B',"Ivan",'Jose']])
data_list.append([datetime.datetime(2020, 7, 28),"Fiesch","Switzerland",1,19,["Ulrike","Francesca",'Chris B',"Ivan",'Jose']])
data_list.append([datetime.datetime(2020, 8, 17),"Lauchringen","Germany",4,12,["Heidrun","Artur","Julius","Franziska","Lena",'Katharina',"Marion","Felicitas","Jan-Marc"]])
data_list.append([datetime.datetime(2019, 8, 25),"Embd","Switzerland",1,1,["Andres","Janina","Chris B","Grace","Sam","Christine"]])
data_list.append([datetime.datetime(2019, 8, 25),"St Niklaus","Switzerland",1,5,["Andres","Janina","Chris B","Grace","Sam","Christine"]])
data_list.append([datetime.datetime(2019, 8, 25),"Randa","Switzerland",1,13,["Andres","Janina","Chris B","Grace","Sam","Christine","David Y"]])
data_list.append([datetime.datetime(2019, 8, 25),"Taesch","Switzerland",1,2,["Andres","Janina","Chris B","Grace","Sam","Christine","David Y"]])
data_list.append([datetime.datetime(2019, 8, 25),"Zermatt","Switzerland",1,58,["Andres","Janina","Chris B","Grace","Sam","Christine","David Y"]])
data_list.append([datetime.datetime(2019, 8, 25),"Zermatt","Switzerland",2,2,["Andres","Janina","Chris B","Grace","Sam","Christine","David Y"]])
data_list.append([datetime.datetime(2019, 8, 25),"Zermatt","Switzerland",4,3,["Andres","Janina","Chris B","Grace","Sam","Christine","David Y"]])
data_list.append([datetime.datetime(2019, 8, 27),"Meyrin","Switzerland",4,2,["CLIC Group"]])
data_list.append([datetime.datetime(2019, 8, 27),"Echenevex","France",3,1,["CLIC Group"]])
data_list.append([datetime.datetime(2019, 8, 31),"Chamonix","France",1,3,["Sasha","Yaroslava","Chris B","Andres"]])
data_list.append([datetime.datetime(2019, 8, 31),"Courmayeur","Italy",1,5,["Sasha","Yaroslava","Chris B","Andres"]])
data_list.append([datetime.datetime(2019, 8, 31),"Aosta","Italy",0,26,["Sasha","Yaroslava","Chris B","Andres"]])
data_list.append([datetime.datetime(2019, 8, 31),"Lillaz","Italy",4,11,["Sasha","Yaroslava","Chris B","Andres"]])
data_list.append([datetime.datetime(2019, 8, 31),"Lillaz","Italy",1,46,["Sasha","Yaroslava","Chris B","Andres"]])
data_list.append([datetime.datetime(2019, 8, 31),"Cogne","Italy",1,3,["Sasha","Yaroslava","Chris B","Andres"]])
data_list.append([datetime.datetime(2019, 8, 31),"La Thuile","Italy",4,7,["Sasha","Yaroslava","Chris B","Andres"]])
data_list.append([datetime.datetime(2019, 8, 31),"La Tuile","Italy",1,35,["Sasha","Yaroslava","Chris B","Andres"]])
data_list.append([datetime.datetime(2019, 9, 15),"Blatten","Switzerland",4,3,["Janina"]])
data_list.append([datetime.datetime(2019, 9, 15),"Blatten","Switzerland",1,156,["Janina"]])
data_list.append([datetime.datetime(2019, 9, 20),"Paris","France",0,3,["Vivan","Nhi","Sam"]])
data_list.append([datetime.datetime(2019, 9, 21),"Paris","France",4,12,["Vivan","Nhi","Sam","Michael"]])
data_list.append([datetime.datetime(2019, 9, 21),"Paris","France",0,347,["Vivan","Nhi","Sam","Michael"]])
data_list.append([datetime.datetime(2019, 9, 22),"Paris","France",4,12,["Vivan","Nhi","Sam","Michael"]])
data_list.append([datetime.datetime(2019, 9, 22),"Paris","France",0,347,["Vivan","Nhi","Sam","Michael"]])
data_list.append([datetime.datetime(2019, 9, 22),"Paris","France",3,18,["Vivan","Nhi","Sam","Michael"]])
data_list.append([datetime.datetime(2019, 9, 22),"Paris","France",4,4,["Vivan","Nhi","Sam","Michael"]])
data_list.append([datetime.datetime(2019, 9, 22),"Paris","France",0,302,["Vivan","Nhi","Sam","Michael"]])
data_list.append([datetime.datetime(2019, 9, 22),"Frankreich","France",1,2,["Vivan","Nhi","Sam","Michael"]])
data_list.append([datetime.datetime(2019, 9, 26),"Genf","Switzerland",3,1,["Ulrike",'Erica']])
data_list.append([datetime.datetime(2019, 9, 26),"Genf","Switzerland",2,14,["Ulrike","Erica"]])
data_list.append([datetime.datetime(2019, 10, 6),"Gruyeres","Switzerland",0,6,["Andrew",'Xuan','Will']])
data_list.append([datetime.datetime(2019, 10, 6),"Gruyeres","Switzerland",4,2,["Andrew",'Xuan','Will']])
data_list.append([datetime.datetime(2019, 10, 6),"Broc","Switzerland",0,1,["Andrew",'Xuan','Will']])
data_list.append([datetime.datetime(2019, 10, 6),"Corseaux","Switzerland",2,2,["Andrew",'Xuan','Will']])
data_list.append([datetime.datetime(2019, 10, 6),"Corseaux","Switzerland",0,7,["Andrew",'Xuan','Will']])
data_list.append([datetime.datetime(2019, 10, 6),"St-Saphorin","Switzerland",2,1,["Andrew",'Xuan','Will']])
data_list.append([datetime.datetime(2019, 10, 6),"Rivaz","Switzerland",0,1,["Andrew",'Xuan','Will']])
data_list.append([datetime.datetime(2019, 10, 6),"Rivaz","Switzerland",1,14,["Andrew",'Xuan','Will']])
data_list.append([datetime.datetime(2019, 10, 6),"Rivaz","Switzerland",2,4,["Andrew",'Xuan','Will']])
data_list.append([datetime.datetime(2019, 10, 10),"St-Genis-Pouilly","France",4,3,["Ulrike",'Rickard',"Mateus","Eva","Erica",'Aidan']])
data_list.append([datetime.datetime(2019, 10, 10),"St-Genis-Pouilly","France",0,4,["Ulrike",'Rickard',"Mateus","Eva","Erica",'Aidan']])
data_list.append([datetime.datetime(2019, 10, 10),"Genf","Switzerland",0,1,["Sam"]])
data_list.append([datetime.datetime(2019, 10, 13),"Lovagny","France",0,2,["Andrew"]])
data_list.append([datetime.datetime(2019, 10, 13),"Lovagny","France",1,77,["Andrew"]])
data_list.append([datetime.datetime(2019, 10, 13),"Bellegarde-sur-Valserine","France",0,2,["Andrew"]])
data_list.append([datetime.datetime(2019, 10, 13),"Bellegarde-sur-Valserine","France",2,8,["Andrew"]])
data_list.append([datetime.datetime(2019, 10, 13),"Bellegarde-sur-Valserine","France",1,29,["Andrew"]])
data_list.append([datetime.datetime(2019, 10, 20),"Genf","Switzerland",3,2,[]])
data_list.append([datetime.datetime(2019, 10, 20),"Genf","Switzerland",0,16,[]])
data_list.append([datetime.datetime(2019, 10, 26),"Grimentz","Switzerland",0,3,["Sasha",'Tema',"Juno","Elga"]])
data_list.append([datetime.datetime(2019, 10, 26),"Grimentz","Switzerland",1,100,["Sasha",'Tema',"Juno","Elga"]])
data_list.append([datetime.datetime(2019, 10, 26),"Grimentz","Switzerland",2,4,["Sasha",'Tema',"Juno","Elga"]])
data_list.append([datetime.datetime(2019, 10, 26),"Montreux","Switzerland",1,5,["Sasha",'Tema',"Juno","Elga"]])
data_list.append([datetime.datetime(2019, 10, 26),"Montreux","Switzerland",2,1,["Sasha",'Tema',"Juno","Elga"]])
data_list.append([datetime.datetime(2019, 10, 27),"Boudry","Switzerland",0,2,["Vivan",'Dylan',"Christine","Grace","Sam","Will"]])
data_list.append([datetime.datetime(2019, 10, 27),"Boudry","Switzerland",2,6,["Vivan",'Dylan',"Christine","Grace","Sam","Will"]])
data_list.append([datetime.datetime(2019, 10, 27),"Boudry","Switzerland",1,115,["Vivan",'Dylan',"Christine","Grace","Sam","Will"]])
data_list.append([datetime.datetime(2019, 10, 27),"Boudry","Switzerland",4,11,["Vivan",'Dylan',"Christine","Grace","Sam","Will"]])
data_list.append([datetime.datetime(2019, 10, 27),"Boudry","Switzerland",5,2,["Vivan",'Dylan',"Christine","Grace","Sam","Will"]])
data_list.append([datetime.datetime(2019, 10, 27),"Neuchatel","Switzerland",1,7,["Vivan",'Dylan',"Christine","Grace","Sam","Will"]])
data_list.append([datetime.datetime(2019, 11, 11),"Meyrin","Switzerland",4,1,["CERNies"]])
data_list.append([datetime.datetime(2019, 11, 17),"Lauchringen","Germany",4,7,["Anne-Kathrin","Christian",'Mathilda']])
data_list.append([datetime.datetime(2019, 11, 17),"Waldshut","Germany",4,3,["Heidrun","Anne-Kathrin","Christian",'Mathilda']])
data_list.append([datetime.datetime(2019, 11, 17),"Waldshut","Germany",0,1,["Anne-Kathrin","Christian",'Mathilda']])
data_list.append([datetime.datetime(2019, 12, 17),"Genf","Switzerland",2,2,[]])
data_list.append([datetime.datetime(2019, 12, 17),"Genf","Switzerland",0,1,[]])
data_list.append([datetime.datetime(2019, 12, 20),"Lauchringen","Germany",4,1,[]])
data_list.append([datetime.datetime(2019, 12, 20),"Lauchringen","Germany",0,6,[]])
data_list.append([datetime.datetime(2019, 12, 25),"Lauchringen","Germany",4,7,[]])
data_list.append([datetime.datetime(2019, 12, 29),"Nufringen","Germany",1,1,["Artur"]])
data_list.append([datetime.datetime(2019, 12, 29),"Leipzig","Germany",0,116,["Artur"]])
data_list.append([datetime.datetime(2019, 12, 29),"Dresden","Germany",0,16,["Artur"]])
data_list.append([datetime.datetime(2019, 12, 30),"Dresden","Germany",0,181,["Artur"]])
data_list.append([datetime.datetime(2019, 12, 30),"Lohmen","Germany",2,115,["Artur"]])
data_list.append([datetime.datetime(2019, 12, 30),"Lohmen","Germany",1,60,["Artur"]])
data_list.append([datetime.datetime(2019, 12, 30),"Lohmen","Germany",4,1,["Artur"]])
data_list.append([datetime.datetime(2019, 12, 31),"Dresden","Germany",0,382,["Artur"]])
#photo types: 0 city photo/buildings, 1 predominantly nature (not major on animals), 2 mixed (e.g. lake and village, or sea and city), 
#3 park, 4 private event aka focus on people, 5 animals/zoo, 6 flowers outside of park 7 else

# %%
#photo types: 0 city photo/buildings, 1 predominantly nature (not major on animals), 2 mixed (e.g. lake and village, or sea and city), 
#3 park, 4 private event aka focus on people, 5 animals/zoo, 6 flowers outside of park 7 else

data_list.append([datetime.datetime(2020, 1, 1),"Dresden","Germany",0,3,["Artur"]])
data_list.append([datetime.datetime(2020, 1, 1),"Bad Muskau","Germany",3,22,["Artur"]])
data_list.append([datetime.datetime(2020, 1, 1),"Leknica","Poland",3,25,["Artur"]])
data_list.append([datetime.datetime(2020, 1, 1),"Swidnica","Poland",0,73,["Artur"]])
data_list.append([datetime.datetime(2020, 1, 1),"Wroclaw","Poland",0,19,["Artur"]])
data_list.append([datetime.datetime(2020, 1, 2),"Wroclaw","Poland",0,1,["Artur"]])
data_list.append([datetime.datetime(2020, 1, 2),"Wieliczka","Poland",0,97,["Artur"]])
data_list.append([datetime.datetime(2020, 1, 2),"Krakau","Poland",0,179,["Artur"]])
data_list.append([datetime.datetime(2020, 1, 3),"Wroclaw","Poland",0,280,["Artur"]])
data_list.append([datetime.datetime(2020, 1, 3),"Wroclaw","Poland",2,9,["Artur"]])
data_list.append([datetime.datetime(2020, 1, 4),"Walbrzych","Poland",4,1,["Artur"]])
data_list.append([datetime.datetime(2020, 1, 4),"Walbrzych","Poland",3,2,["Artur"]])
data_list.append([datetime.datetime(2020, 1, 4),"Walbrzych","Poland",0,86,["Artur"]])
data_list.append([datetime.datetime(2020, 1, 5),"Wonsees","Germany",0,4,["Artur"]])
data_list.append([datetime.datetime(2020, 1, 5),"Wonsees","Germany",3,56,["Artur"]])
data_list.append([datetime.datetime(2020, 1, 5),"Wonsees","Germany",1,2,["Artur"]])
data_list.append([datetime.datetime(2020, 1, 5),"Wonsees","Germany",4,1,["Artur"]])
data_list.append([datetime.datetime(2020, 1, 5),"Lauchringen","Germany",0,1,[]])
data_list.append([datetime.datetime(2020, 1, 11),"Meyrin","Switzerland",1,3,[]])
data_list.append([datetime.datetime(2020, 1, 11),"Les Planches-en-Montagne","France",2,5,["Sasha",'Juno']])
data_list.append([datetime.datetime(2020, 1, 11),"Les Planches-en-Montagne","France",1,26,["Sasha",'Juno']])
data_list.append([datetime.datetime(2020, 1, 11),"Bourg-de-Sirod","France",0,54,["Sasha",'Juno']])
data_list.append([datetime.datetime(2020, 1, 11),"Bourg-de-Sirod","France",2,2,["Sasha",'Juno']])
data_list.append([datetime.datetime(2020, 1, 11),"Bourg-de-Sirod","France",1,26,["Sasha",'Juno']])
data_list.append([datetime.datetime(2020, 1, 11),"Bourg-en-Bresse","France",0,120,["Sasha",'Juno']])

data_list.append([datetime.datetime(2020, 2, 20),"Genf","Switzerland",0,1,[]])
data_list.append([datetime.datetime(2020, 2, 20),"Frankreich","France",1,6,[]])
data_list.append([datetime.datetime(2020, 2, 20),"Italien","Italy",1,3,[]])
data_list.append([datetime.datetime(2020, 2, 20),"Fiumicino","Italy",2,1,[]])
data_list.append([datetime.datetime(2020, 2, 20),"Fiumicino","Italy",0,1,[]])
data_list.append([datetime.datetime(2020, 2, 20),"Rom","Italy",0,192,[]])
data_list.append([datetime.datetime(2020, 2, 20),"Orvieto","Italy",0,148,[]])
data_list.append([datetime.datetime(2020, 2, 20),"Orvieto","Italy",1,2,[]])
data_list.append([datetime.datetime(2020, 2, 20),"Orvieto","Italy",2,6,[]])
data_list.append([datetime.datetime(2020, 2, 21),"Ancona","Italy",0,1,[]])
data_list.append([datetime.datetime(2020, 2, 21),"Urbino","Italy",0,147,[]])
data_list.append([datetime.datetime(2020, 2, 21),"Urbino","Italy",1,1,[]])
data_list.append([datetime.datetime(2020, 2, 21),"Urbino","Italy",2,1,[]])
data_list.append([datetime.datetime(2020, 2, 21),"Pesaro","Italy",0,10,[]])
data_list.append([datetime.datetime(2020, 2, 21),"Pesaro","Italy",1,2,[]])
data_list.append([datetime.datetime(2020, 2, 21),"Pesaro","Italy",2,4,[]])
data_list.append([datetime.datetime(2020, 2, 22),"Castel Gandolfo","Italy",0,76,[]])
data_list.append([datetime.datetime(2020, 2, 22),"Castel Gandolfo","Italy",1,6,[]])
data_list.append([datetime.datetime(2020, 2, 22),"Castel Gandolfo","Italy",3,77,[]])
data_list.append([datetime.datetime(2020, 2, 22),"Castel Gandolfo","Italy",2,2,[]])
data_list.append([datetime.datetime(2020, 2, 22),"Ciampino","Italy",0,2,[]])
data_list.append([datetime.datetime(2020, 2, 22),"Anagni","Italy",0,124,[]])
data_list.append([datetime.datetime(2020, 2, 22),"Anagni","Italy",2,1,[]])
data_list.append([datetime.datetime(2020, 2, 22),"Anagni","Italy",1,1,[]])
data_list.append([datetime.datetime(2020, 2, 23),"Terni","Italy",0,17,[]])
data_list.append([datetime.datetime(2020, 2, 23),"Marmore","Italy",1,129,[]])
data_list.append([datetime.datetime(2020, 2, 23),"Marmore","Italy",2,8,[]])
data_list.append([datetime.datetime(2020, 2, 23),"Rom","Italy",0,119,[]])
data_list.append([datetime.datetime(2020, 2, 24),"Orte","Italy",7,2,[]])
data_list.append([datetime.datetime(2020, 2, 24),"Mugnano","Italy",0,1,[]])
data_list.append([datetime.datetime(2020, 2, 24),"Baschi","Italy",0,1,[]])
data_list.append([datetime.datetime(2020, 2, 24),"Orvieto","Italy",0,2,[]])
data_list.append([datetime.datetime(2020, 2, 24),"Montepulciano","Italy",0,3,[]])
data_list.append([datetime.datetime(2020, 2, 24),"Montepulciano","Italy",2,2,[]])
data_list.append([datetime.datetime(2020, 2, 24),"Pienza","Italy",0,54,[]])
data_list.append([datetime.datetime(2020, 2, 24),"Pienza","Italy",1,44,[]])
data_list.append([datetime.datetime(2020, 2, 24),"Pienza","Italy",3,4,[]])
data_list.append([datetime.datetime(2020, 2, 24),"Pienza","Italy",2,5,[]])
data_list.append([datetime.datetime(2020, 2, 25),"Siena","Italy",0,298,[]])
data_list.append([datetime.datetime(2020, 2, 25),"Colle di Val d'Elsa","Italy",0,1,[]])
data_list.append([datetime.datetime(2020, 2, 25),"San Gimignano","Italy",0,134,[]])
data_list.append([datetime.datetime(2020, 2, 25),"San Gimignano","Italy",1,4,[]])
data_list.append([datetime.datetime(2020, 2, 25),"San Gimignano","Italy",2,6,[]])
data_list.append([datetime.datetime(2020, 2, 26),"Florenz","Italy",0,733,[]])
data_list.append([datetime.datetime(2020, 2, 26),"Florenz","Italy",3,35,[]])
data_list.append([datetime.datetime(2020, 2, 27),"Rom","Italy",0,278,["Bryan"]])
data_list.append([datetime.datetime(2020, 2, 27),"Rom","Italy",2,2,["Bryan"]])
data_list.append([datetime.datetime(2020, 2, 27),"Rom","Italy",3,5,["Bryan"]])
data_list.append([datetime.datetime(2020, 2, 28),"Rom","Italy",0,603,["Bryan"]])
data_list.append([datetime.datetime(2020, 2, 28),"Rom","Italy",3,7,["Bryan"]])
data_list.append([datetime.datetime(2020, 2, 29),"Rom","Italy",0,529,["Bryan"]])
data_list.append([datetime.datetime(2020, 2, 29),"Rom","Italy",3,6,["Bryan"]])
data_list.append([datetime.datetime(2020, 3, 1),"Tivoli","Italy",0,158,["Bryan"]])
data_list.append([datetime.datetime(2020, 3, 1),"Tivoli","Italy",1,38,["Bryan"]])
data_list.append([datetime.datetime(2020, 3, 1),"Tivoli","Italy",2,7,["Bryan"]])
data_list.append([datetime.datetime(2020, 3, 1),"Tivoli","Italy",3,108,["Bryan"]])
data_list.append([datetime.datetime(2020, 3, 1),"Tivoli","Italy",4,3,["Bryan"]])
data_list.append([datetime.datetime(2020, 3, 1),"Rom","Italy",0,7,["Bryan"]])
data_list.append([datetime.datetime(2020, 3, 2),"Rom","Italy",0,218,["Bryan"]])
data_list.append([datetime.datetime(2020, 5, 17),"Rossiniere","Switzerland",2,4,["Juno"]])
data_list.append([datetime.datetime(2020, 5, 17),"Rossiniere","Switzerland",1,10,["Juno"]])
data_list.append([datetime.datetime(2020, 5, 17),"Chateau d'Oex","Switzerland",2,13,["Juno"]])
data_list.append([datetime.datetime(2020, 5, 17),"Chateau d'Oex","Switzerland",1,28,["Juno"]])
data_list.append([datetime.datetime(2020, 5, 17),"Rougemont","Switzerland",2,4,["Juno"]])
data_list.append([datetime.datetime(2020, 5, 17),"Rougemont","Switzerland",1,4,["Juno"]])
data_list.append([datetime.datetime(2020, 5, 17),"Montbovon","Switzerland",2,2,["Juno"]])
data_list.append([datetime.datetime(2020, 5, 17),"Montbovon","Switzerland",1,4,["Juno"]])
data_list.append([datetime.datetime(2020, 5, 17),"Schweiz","Switzerland",1,4,["Juno"]])
data_list.append([datetime.datetime(2020, 5, 17),"Montreux","Switzerland",2,3,["Juno"]])


data_list.append([datetime.datetime(2020, 7, 4),"Labalme","France",1,75,["Sasha","Tema"]])
data_list.append([datetime.datetime(2020, 7, 4),"La Balme-les-Grottes","France",1,108,["Sasha","Tema"]])
data_list.append([datetime.datetime(2020, 7, 4),"La Balme-les-Grottes","France",2,4,["Sasha","Tema"]])
data_list.append([datetime.datetime(2020, 7, 4),"La Balme-les-Grottes","France",4,4,["Sasha","Tema"]])
data_list.append([datetime.datetime(2020, 7, 4),"Belmont-Luthezieu","France",1,15,["Sasha"]])
data_list.append([datetime.datetime(2020, 7, 4),"Ceveyrieu","France",1,3,["Sasha"]])
data_list.append([datetime.datetime(2020, 7, 4),"Vieu","France",4,1,["Sasha"]])
data_list.append([datetime.datetime(2020, 7, 4),"Vieu","France",1,15,["Sasha"]])
data_list.append([datetime.datetime(2020, 7, 4),"Champagne-en-Valromey","France",1,19,["Sasha"]])
data_list.append([datetime.datetime(2020, 7, 4),"Surjoux","France",1,8,["Sasha"]])

data_list.append([datetime.datetime(2020, 7, 18),"Chamonix","France",1,134,["Sasha","Juno","Tema",'Andriy']])
data_list.append([datetime.datetime(2020, 7, 18),"Chamonix","France",4,17,["Sasha","Juno","Tema",'Andriy']])

data_list.append([datetime.datetime(2020, 8, 9),"Lauterbrunnen","Switzerland",1,13,["Sasha","Juno","Tema"]])
data_list.append([datetime.datetime(2020, 8, 9),"Grindelwald","Switzerland",1,10,["Sasha","Juno","Tema"]])
data_list.append([datetime.datetime(2020, 8, 9),"Fieschertal","Switzerland",4,24,["Sasha","Juno","Tema"]])
data_list.append([datetime.datetime(2020, 8, 9),"Fieschertal","Switzerland",2,2,["Sasha","Juno","Tema"]])
data_list.append([datetime.datetime(2020, 8, 9),"Fieschertal","Switzerland",1,200,["Sasha","Juno","Tema"]])
data_list.append([datetime.datetime(2020, 8, 10),"Fieschertal","Switzerland",4,3,["Sasha","Juno","Tema"]])
data_list.append([datetime.datetime(2020, 8, 10),"Fieschertal","Switzerland",2,4,["Sasha","Juno","Tema"]])
data_list.append([datetime.datetime(2020, 8, 10),"Fieschertal","Switzerland",1,70,["Sasha","Juno","Tema"]])
data_list.append([datetime.datetime(2020, 8, 10),"Fiesch","Switzerland",1,1,["Sasha","Juno","Tema"]])


data_list.append([datetime.datetime(2020, 8, 29),"Brugg","Switzerland",0,13,['Artur']])
data_list.append([datetime.datetime(2020, 8, 29),"Brugg","Switzerland",2,3,['Artur']])
data_list.append([datetime.datetime(2020, 8, 31),"Zuerich","Switzerland",0,2,[]])
data_list.append([datetime.datetime(2020, 9, 1),"Lauchringen","Germany",0,2,[]])
data_list.append([datetime.datetime(2020, 9, 1),"Waldshut","Germany",2,1,[]])
data_list.append([datetime.datetime(2020, 9, 4),"Lauchringen","Germany",2,1,[]])
data_list.append([datetime.datetime(2020, 9, 5),"Altenburg","Germany",2,2,["Artur"]])
data_list.append([datetime.datetime(2020, 9, 5),"Altenburg","Germany",1,1,["Artur"]])
data_list.append([datetime.datetime(2020, 9, 5),"Rheinau","Switzerland",2,5,["Artur"]])
data_list.append([datetime.datetime(2020, 9, 5),"Rheinau","Switzerland",1,1,["Artur"]])
data_list.append([datetime.datetime(2020, 9, 5),"Rheinau","Switzerland",0,15,["Artur"]])
data_list.append([datetime.datetime(2020, 9, 5),"Nohl","Switzerland",2,3,["Artur"]])
data_list.append([datetime.datetime(2020, 9, 5),"Laufen","Switzerland",0,10,["Artur"]])
data_list.append([datetime.datetime(2020, 9, 5),"Laufen","Switzerland",2,2,["Artur"]])
data_list.append([datetime.datetime(2020, 9, 5),"Laufen","Switzerland",1,32,["Artur"]])
data_list.append([datetime.datetime(2020, 9, 5),"Neuhausen am Rheinfall","Switzerland",1,33,["Artur"]])
data_list.append([datetime.datetime(2020, 9, 5),"Neuhausen am Rheinfall","Switzerland",2,8,["Artur"]])
data_list.append([datetime.datetime(2020, 9, 5),"Neuhausen am Rheinfall","Switzerland",0,3,["Artur"]])
data_list.append([datetime.datetime(2020, 9, 6),"Bechtersbohl","Germany",0,12,["Artur",'Jan-Marc','Franziska','Julius','Felicitas']])
data_list.append([datetime.datetime(2020, 9, 6),"Bechtersbohl","Germany",1,4,["Artur",'Jan-Marc','Franziska','Julius','Felicitas']])
data_list.append([datetime.datetime(2020, 9, 6),"Bechtersbohl","Germany",4,1,["Artur",'Jan-Marc','Franziska','Julius','Felicitas']])
data_list.append([datetime.datetime(2020, 9, 6),"Lauchringen","Germany",4,1,["Artur",'Jan-Marc','Franziska','Julius','Felicitas']])
data_list.append([datetime.datetime(2020, 9, 13),"Lauchringen","Germany",0,1,[]])
data_list.append([datetime.datetime(2020, 9, 14),"Lauchringen","Germany",1,2,[]])
data_list.append([datetime.datetime(2020, 9, 14),"Baden","Switzerland",0,3,[]])
data_list.append([datetime.datetime(2020, 9, 14),"Zuerich","Switzerland",0,1,[]])
data_list.append([datetime.datetime(2020, 9, 14),"Waldshut","Germany",1,6,[]])
data_list.append([datetime.datetime(2020, 9, 20),"Wangen","Germany",0,2,["Artur"]])
data_list.append([datetime.datetime(2020, 9, 20),"Wangen","Germany",2,4,["Artur"]])
data_list.append([datetime.datetime(2020, 9, 20),"Wangen","Germany",1,2,["Artur"]])
data_list.append([datetime.datetime(2020, 9, 20),"Oehningen","Germany",0,9,["Artur"]])
data_list.append([datetime.datetime(2020, 9, 20),"Oehningen","Germany",4,2,["Artur"]])
data_list.append([datetime.datetime(2020, 9, 20),"Oehningen","Germany",1,13,["Artur"]])
data_list.append([datetime.datetime(2020, 9, 20),"Oehningen","Germany",1,13,["Artur"]])
data_list.append([datetime.datetime(2020, 9, 20),"Kattenhorn","Germany",0,2,["Artur"]])
data_list.append([datetime.datetime(2020, 9, 20),"Kattenhorn","Germany",1,23,["Artur"]])
data_list.append([datetime.datetime(2020, 9, 21),"Lauchringen","Germany",1,2,[]])
data_list.append([datetime.datetime(2020, 9, 25),"Lauchringen","Germany",0,3,[]])
data_list.append([datetime.datetime(2020, 9, 27),"Lauchringen","Germany",1,13,['Artur']])
data_list.append([datetime.datetime(2020, 10, 3),"Lauchringen","Germany",0,1,['Artur']])
data_list.append([datetime.datetime(2020, 10, 3),"Lauchringen","Germany",2,3,['Artur']])
data_list.append([datetime.datetime(2020, 10, 3),"Lauchringen","Germany",1,28,['Artur']])
data_list.append([datetime.datetime(2020, 10, 3),"Tiengen","Germany",1,3,['Artur']])
data_list.append([datetime.datetime(2020, 10, 3),"Tiengen","Germany",0,1,['Artur']])
data_list.append([datetime.datetime(2020, 10, 4),"Salem","Germany",0,98,["Artur"]])
data_list.append([datetime.datetime(2020, 10, 4),"Bermatingen","Germany",0,8,["Artur"]])
data_list.append([datetime.datetime(2020, 10, 4),"Ueberlingen","Germany",0,98,["Artur"]])
data_list.append([datetime.datetime(2020, 10, 4),"Ueberlingen","Germany",1,2,["Artur"]])
data_list.append([datetime.datetime(2020, 10, 9),"Baden","Switzerland",0,28,[]])
data_list.append([datetime.datetime(2020, 10, 10),"Lauchringen","Germany",1,27,[]])
data_list.append([datetime.datetime(2020, 10, 11),"Zug","Switzerland",1,65,["Namrata"]])
data_list.append([datetime.datetime(2020, 10, 11),"Baar","Switzerland",2,4,["Namrata"]])
data_list.append([datetime.datetime(2020, 10, 11),"Baar","Switzerland",0,6,["Namrata"]])
data_list.append([datetime.datetime(2020, 10, 11),"Baar","Switzerland",4,5,["Namrata"]])
data_list.append([datetime.datetime(2020, 10, 12),"Zuerich","Switzerland",0,2,[]])
data_list.append([datetime.datetime(2020, 10, 12),"Waldshut","Germany",0,1,[]])
data_list.append([datetime.datetime(2020, 10, 18),"Lauchringen","Germany",0,1,[]])
data_list.append([datetime.datetime(2020, 10, 18),"Lauchringen","Germany",2,1,[]])
data_list.append([datetime.datetime(2020, 10, 18),"Lauchringen","Germany",1,6,[]])
data_list.append([datetime.datetime(2020, 10, 25),"Tiengen","Germany",2,10,["Artur"]])
data_list.append([datetime.datetime(2020, 10, 25),"Tiengen","Germany",1,26,["Artur"]])
data_list.append([datetime.datetime(2020, 10, 27),"Lauchringen","Germany",1,3,[]])
data_list.append([datetime.datetime(2020, 10, 28),"Lauchringen","Germany",1,4,[]])
data_list.append([datetime.datetime(2020, 10, 30),"Lauchringen","Germany",2,1,[]])
data_list.append([datetime.datetime(2020, 10, 30),"Lauchringen","Germany",1,6,[]])
data_list.append([datetime.datetime(2020, 10, 31),"Lauchringen","Germany",0,1,["Artur"]])
data_list.append([datetime.datetime(2020, 10, 31),"Lauchringen","Germany",1,26,["Artur"]])
data_list.append([datetime.datetime(2020, 11, 6),"Lauchringen","Germany",1,10,[]])
data_list.append([datetime.datetime(2020, 11, 6),"Lauchringen","Germany",0,3,[]])
data_list.append([datetime.datetime(2020, 11, 7),"Hoechenschwand","Germany",1,24,["Artur"]])
data_list.append([datetime.datetime(2020, 11, 9),"Lauchringen","Germany",2,2,[]])
data_list.append([datetime.datetime(2020, 11, 9),"Lauchringen","Germany",0,4,[]])
data_list.append([datetime.datetime(2020, 11, 9),"Lauchringen","Germany",1,12,[]])
data_list.append([datetime.datetime(2020, 11, 10),"Lauchringen","Germany",2,1,[]])
data_list.append([datetime.datetime(2020, 11, 10),"Lauchringen","Germany",1,8,[]])
data_list.append([datetime.datetime(2020, 11, 10),"Lauchringen","Germany",0,1,[]])
data_list.append([datetime.datetime(2020, 11, 13),"Lauchringen","Germany",1,5,[]])
data_list.append([datetime.datetime(2020, 11, 14),"Tiengen","Germany",1,16,[]])
data_list.append([datetime.datetime(2020, 11, 14),"Tiengen","Germany",0,12,[]])
data_list.append([datetime.datetime(2020, 11, 14),"Tiengen","Germany",2,2,[]])
data_list.append([datetime.datetime(2020, 11, 14),"Lauchringen","Germany",4,1,[]])
data_list.append([datetime.datetime(2020, 11, 14),"Lauchringen","Germany",1,16,[]])
data_list.append([datetime.datetime(2020, 11, 14),"Lauchringen","Germany",2,1,[]])
data_list.append([datetime.datetime(2020, 11, 14),"Tiengen","Germany",1,1,[]])
data_list.append([datetime.datetime(2020, 11, 14),"Tiengen","Germany",0,1,[]])
data_list.append([datetime.datetime(2020, 11, 18),"Lauchringen","Germany",1,6,[]])
data_list.append([datetime.datetime(2020, 11, 22),"St Blasien","Germany",1,30,["Artur"]])
data_list.append([datetime.datetime(2020, 11, 22),"Todtmoos","Germany",1,30,["Artur"]])
data_list.append([datetime.datetime(2020, 11, 22),"Todtmoos","Germany",2,4,["Artur"]])
data_list.append([datetime.datetime(2020, 11, 22),"Hoechenschwand","Germany",1,27,["Artur"]])
data_list.append([datetime.datetime(2020, 12, 1),"Lauchringen","Germany",1,27,[]])
data_list.append([datetime.datetime(2020, 12, 1),"Lauchringen","Germany",0,2,[]])
data_list.append([datetime.datetime(2020, 12, 3),"Lauchringen","Germany",2,2,[]])
data_list.append([datetime.datetime(2020, 12, 3),"Lauchringen","Germany",1,5,[]])
data_list.append([datetime.datetime(2020, 12, 11),"Lauchringen","Germany",0,1,[]])
data_list.append([datetime.datetime(2020, 12, 20),"Lauchringen","Germany",1,1,[]])
data_list.append([datetime.datetime(2020, 12, 22),"Lauchringen","Germany",4,3,["Artur","Felicitas","Julius","Franziska"]])
data_list.append([datetime.datetime(2020, 12, 22),"Lauchringen","Germany",1,1,["Artur","Felicitas","Julius","Franziska"]])
data_list.append([datetime.datetime(2020, 12, 24),"Lauchringen","Germany",4,4,["Jan-Marc","Artur","Felicitas","Julius","Franziska"]])
data_list.append([datetime.datetime(2020, 12, 26),"Lauchringen","Germany",1,1,[]])
data_list.append([datetime.datetime(2020, 12, 28),"Lauchringen","Germany",1,1,[]])

#photo types: 0 city photo/buildings, 1 predominantly nature (not major on animals), 2 mixed (e.g. lake and village, or sea and city), 
#3 park, 4 private event aka focus on people, 5 animals/zoo, 6 flowers outside of park 7 else

# %%
#photo types: 0 city photo/buildings, 1 predominantly nature (not major on animals), 2 mixed (e.g. lake and village, or sea and city), 
#3 park, 4 private event aka focus on people, 5 animals/zoo, 6 flowers outside of park 7 else



data_list.append([datetime.datetime(2021, 1, 5),"Lauchringen","Germany",1,11,[]])
data_list.append([datetime.datetime(2021, 1, 6),"Lauchringen","Germany",2,4,[]])
data_list.append([datetime.datetime(2021, 1, 6),"Lauchringen","Germany",0,3,[]])
data_list.append([datetime.datetime(2021, 1, 10),"Bad Saeckingen","Germany",0,42,["Artur"]])
data_list.append([datetime.datetime(2021, 1, 10),"Bad Saeckingen","Germany",2,6,["Artur"]])
data_list.append([datetime.datetime(2021, 1, 10),"Laufenburg","Germany",0,11,["Artur"]])
data_list.append([datetime.datetime(2021, 1, 10),"Laufenburg","Germany",2,9,["Artur"]])
data_list.append([datetime.datetime(2021, 1, 10),"Laufenburg","Germany",1,1,["Artur"]])
data_list.append([datetime.datetime(2021, 1, 11),"Lauchringen","Germany",0,1,[]])
data_list.append([datetime.datetime(2021, 1, 11),"Lauchringen","Germany",2,1,[]])
data_list.append([datetime.datetime(2021, 1, 12),"Lauchringen","Germany",2,1,[]])
data_list.append([datetime.datetime(2021, 1, 14),"Lauchringen","Germany",2,3,[]])
data_list.append([datetime.datetime(2021, 1, 15),"Lauchringen","Germany",0,2,[]])
data_list.append([datetime.datetime(2021, 1, 15),"Lauchringen","Germany",1,15,[]])
data_list.append([datetime.datetime(2021, 1, 15),"Lauchringen","Germany",2,9,[]])
data_list.append([datetime.datetime(2021, 1, 16),"Lauchringen","Germany",2,2,[]])
data_list.append([datetime.datetime(2021, 1, 16),"Lauchringen","Germany",1,38,[]])
data_list.append([datetime.datetime(2021, 1, 17),"Lauchringen","Germany",2,3,[]])
data_list.append([datetime.datetime(2021, 1, 17),"Lauchringen","Germany",1,3,[]])
data_list.append([datetime.datetime(2021, 1, 19),"Lauchringen","Germany",2,1,[]])
data_list.append([datetime.datetime(2021, 1, 19),"Lauchringen","Germany",0,2,[]])
data_list.append([datetime.datetime(2021, 1, 20),"Lauchringen","Germany",1,4,[]])
data_list.append([datetime.datetime(2021, 1, 22),"Tiengen","Germany",0,3,[]])
data_list.append([datetime.datetime(2021, 1, 22),"Lauchringen","Germany",1,1,[]])
data_list.append([datetime.datetime(2021, 1, 22),"Tiengen","Germany",1,30,[]])
data_list.append([datetime.datetime(2021, 1, 26),"Lauchringen","Germany",1,4,[]])
data_list.append([datetime.datetime(2021, 1, 27),"Lauchringen","Germany",1,1,[]])
data_list.append([datetime.datetime(2021, 1, 29),"Lauchringen","Germany",1,1,[]])
data_list.append([datetime.datetime(2021, 1, 29),"Tiengen","Germany",2,2,[]])
data_list.append([datetime.datetime(2021, 1, 29),"Tiengen","Germany",1,36,[]])
data_list.append([datetime.datetime(2021, 1, 30),"Lauchringen","Germany",1,9,[]])
data_list.append([datetime.datetime(2021, 1, 30),"Tiengen","Germany",1,8,[]])
data_list.append([datetime.datetime(2021, 1, 31),"Tiengen","Germany",1,4,[]])
data_list.append([datetime.datetime(2021, 1, 31),"Ettikon","Germany",1,12,["Artur"]])
data_list.append([datetime.datetime(2021, 1, 31),"Ettikon","Germany",0,1,['Artur']])
data_list.append([datetime.datetime(2021, 1, 31),"Ettikon","Germany",4,1,['Artur']])
data_list.append([datetime.datetime(2021, 2, 4),"Aach","Germany",1,10,['Artur']])
data_list.append([datetime.datetime(2021, 2, 4),"Reichenau","Germany",0,21,['Artur']])
data_list.append([datetime.datetime(2021, 2, 5),"Lauchringen","Germany",1,4,['Artur']])
data_list.append([datetime.datetime(2021, 2, 5),"Lauchringen","Germany",0,4,['Artur']])
data_list.append([datetime.datetime(2021, 2, 5),"Lauchringen","Germany",2,9,['Artur']])
data_list.append([datetime.datetime(2021, 2, 6),"Uhldingen-Muehlhofen","Germany",1,1,['Artur']])
data_list.append([datetime.datetime(2021, 2, 6),"Uhldingen-Muehlhofen","Germany",0,16,['Artur']])
data_list.append([datetime.datetime(2021, 2, 6),"Lindau","Germany",1,4,['Artur']])
data_list.append([datetime.datetime(2021, 2, 6),"Lindau","Germany",0,42,['Artur']])
data_list.append([datetime.datetime(2021, 2, 6),"Lindau","Germany",2,3,['Artur']])
data_list.append([datetime.datetime(2021, 2, 6),"Weingarten","Germany",0,39,['Artur']])
data_list.append([datetime.datetime(2021, 2, 6),"Weingarten","Germany",4,1,['Artur']])
data_list.append([datetime.datetime(2021, 2, 6),"Friedrichshafen","Germany",0,4,['Artur']])
data_list.append([datetime.datetime(2021, 2, 6),"Meersburg","Germany",0,28,['Artur']])
data_list.append([datetime.datetime(2021, 2, 6),"Meersburg","Germany",2,3,['Artur']])
data_list.append([datetime.datetime(2021, 2, 7),"Lauchringen","Germany",0,8,["Artur"]])
data_list.append([datetime.datetime(2021, 2, 7),"Lauchringen","Germany",1,6,["Artur"]])
data_list.append([datetime.datetime(2021, 2, 7),"Lauchringen","Germany",2,1,["Artur"]])
data_list.append([datetime.datetime(2021, 2, 7),"Tiengen","Germany",0,8,["Artur"]])
data_list.append([datetime.datetime(2021, 2, 7),"Tiengen","Germany",1,12,["Artur"]])
data_list.append([datetime.datetime(2021, 2, 7),"Tiengen","Germany",2,2,["Artur"]])
data_list.append([datetime.datetime(2021, 2, 9),"Lauchringen","Germany",1,5,[]])
data_list.append([datetime.datetime(2021, 2, 9),"Lauchringen","Germany",2,2,[]])
data_list.append([datetime.datetime(2021, 2, 11),"Lauchringen","Germany",1,2,[]])
data_list.append([datetime.datetime(2021, 2, 11),"Detzeln","Germany",1,14,[]])
data_list.append([datetime.datetime(2021, 2, 12),"Lauchringen","Germany",0,4,[]])
data_list.append([datetime.datetime(2021, 2, 12),"Lauchringen","Germany",1,1,[]])
data_list.append([datetime.datetime(2021, 2, 12),"Lauchringen","Germany",2,3,[]])
data_list.append([datetime.datetime(2021, 2, 13),"Lauchringen","Germany",1,12,[]])
data_list.append([datetime.datetime(2021, 2, 14),"Indlekofen","Germany",1,31,[]])
data_list.append([datetime.datetime(2021, 2, 15),"Lauchringen","Germany",0,1,[]])
data_list.append([datetime.datetime(2021, 2, 15),"Lauchringen","Germany",1,7,[]])
data_list.append([datetime.datetime(2021, 2, 15),"Tiengen","Germany",1,6,[]])
data_list.append([datetime.datetime(2021, 2, 16),"Lauchringen","Germany",1,4,[]])
data_list.append([datetime.datetime(2021, 2, 16),"Lauchringen","Germany",2,2,[]])
data_list.append([datetime.datetime(2021, 2, 19),"Grafenhausen","Germany",1,24,["Artur"]])
data_list.append([datetime.datetime(2021, 2, 21),"Beuron","Germany",0,19,["Artur"]])
data_list.append([datetime.datetime(2021, 2, 21),"Beuron","Germany",1,55,["Artur"]])
data_list.append([datetime.datetime(2021, 2, 21),"Beuron","Germany",2,12,["Artur"]])
data_list.append([datetime.datetime(2021, 2, 21),"Beuron","Germany",4,1,["Artur"]])
data_list.append([datetime.datetime(2021, 2, 21),"Sigmaringen","Germany",2,2,["Artur"]])
data_list.append([datetime.datetime(2021, 2, 21),"Sigmaringen","Germany",0,13,["Artur"]])
data_list.append([datetime.datetime(2021, 2, 22),"Reinheim","Germany",2,8,["Artur"]])
data_list.append([datetime.datetime(2021, 2, 22),"Reinheim","Germany",1,5,["Artur"]])
data_list.append([datetime.datetime(2021, 2, 23),"Bonndorf","Germany",1,5,["Artur"]])
data_list.append([datetime.datetime(2021, 2, 23),"Bonndorf","Germany",0,9,["Artur"]])
data_list.append([datetime.datetime(2021, 2, 23),"Detzeln","Germany",1,3,["Artur"]])
data_list.append([datetime.datetime(2021, 2, 24),"Waldshut","Germany",0,4,[]])
data_list.append([datetime.datetime(2021, 2, 25),"Lauchringen","Germany",2,3,["Artur"]])
data_list.append([datetime.datetime(2021, 2, 25),"Lauchringen","Germany",0,3,["Artur"]])
data_list.append([datetime.datetime(2021, 2, 25),"Lauchringen","Germany",1,3,["Artur"]])
data_list.append([datetime.datetime(2021, 2, 25),"Kadelburg","Germany",1,3,["Artur"]])
data_list.append([datetime.datetime(2021, 2, 26),"Lauchringen","Germany",0,1,[]])
data_list.append([datetime.datetime(2021, 2, 26),"Lauchringen","Germany",1,1,[]])
data_list.append([datetime.datetime(2021, 2, 26),"Menzenschwand","Germany",1,32,["Artur"]])
data_list.append([datetime.datetime(2021, 2, 26),"Menzenschwand","Germany",2,2,["Artur"]])
data_list.append([datetime.datetime(2021, 2, 26),"Todtnau","Germany",2,1,["Artur"]])
data_list.append([datetime.datetime(2021, 2, 26),"Todtnau","Germany",4,1,["Artur"]])
data_list.append([datetime.datetime(2021, 2, 26),"Todtnau","Germany",1,46,["Artur"]])
data_list.append([datetime.datetime(2021, 2, 27),"Breitnau","Germany",0,5,["Artur"]])
data_list.append([datetime.datetime(2021, 2, 27),"Breitnau","Germany",1,41,["Artur"]])
data_list.append([datetime.datetime(2021, 2, 27),"Breitnau","Germany",2,4,["Artur"]])
data_list.append([datetime.datetime(2021, 2, 27),"Breitnau","Germany",4,1,["Artur"]])
data_list.append([datetime.datetime(2021, 2, 27),"Freiburg","Germany",0,47,["Artur"]])
data_list.append([datetime.datetime(2021, 2, 27),"St Peter","Germany",0,20,["Artur"]])
data_list.append([datetime.datetime(2021, 2, 27),"St Peter","Germany",2,1,["Artur"]])
data_list.append([datetime.datetime(2021, 2, 27),"St Maergen","Germany",0,9,["Artur"]])
data_list.append([datetime.datetime(2021, 2, 27),"St Maergen","Germany",1,1,["Artur"]])
data_list.append([datetime.datetime(2021, 2, 27),"St Maergen","Germany",2,2,["Artur"]])
data_list.append([datetime.datetime(2021, 2, 27),"Titisee","Germany",0,2,["Artur"]])
data_list.append([datetime.datetime(2021, 2, 27),"Titisee","Germany",1,3,["Artur"]])
data_list.append([datetime.datetime(2021, 2, 27),"Titisee","Germany",2,4,["Artur"]])
data_list.append([datetime.datetime(2021, 2, 27),"Lenzkirch","Germany",1,4,["Artur"]])
data_list.append([datetime.datetime(2021, 2, 27),"Lenzkirch","Germany",2,1,["Artur"]])
data_list.append([datetime.datetime(2021, 2, 27),"Schluchsee","Germany",0,2,["Artur"]])
data_list.append([datetime.datetime(2021, 2, 27),"Schluchsee","Germany",2,3,["Artur"]])
data_list.append([datetime.datetime(2021, 2, 28),"Rickenbach","Germany",0,12,["Artur"]])
data_list.append([datetime.datetime(2021, 2, 28),"Rickenbach","Germany",1,21,["Artur"]])
data_list.append([datetime.datetime(2021, 2, 28),"Rickenbach","Germany",2,1,["Artur"]])
data_list.append([datetime.datetime(2021, 2, 28),"Murg","Germany",1,6,["Artur"]])
data_list.append([datetime.datetime(2021, 2, 28),"Murg","Germany",2,1,["Artur"]])



data_list.append([datetime.datetime(2021, 4, 28),"Ainring","Germany",1,1,[]])
data_list.append([datetime.datetime(2021, 4, 28),"Wien","Austria",0,2,[]])
data_list.append([datetime.datetime(2021, 4, 29),"Wien","Austria",0,2,[]])
data_list.append([datetime.datetime(2021, 5, 4),"Wien","Austria",0,152,[]])
data_list.append([datetime.datetime(2021, 5, 5),"Wien","Austria",5,1,[]])
data_list.append([datetime.datetime(2021, 5, 5),"Wien","Austria",2,4,[]])
data_list.append([datetime.datetime(2021, 5, 6),"Wien","Austria",0,244,[]])
data_list.append([datetime.datetime(2021, 5, 7),"Wien","Austria",0,167,[]])
data_list.append([datetime.datetime(2021, 5, 7),"Wien","Austria",3,37,[]])
data_list.append([datetime.datetime(2021, 5, 8),"Wien","Austria",0,133,[]])
data_list.append([datetime.datetime(2021, 5, 8),"Wien","Austria",3,18,[]])
data_list.append([datetime.datetime(2021, 5, 8),"Wien","Austria",6,2,[]])
data_list.append([datetime.datetime(2021, 5, 9),"Wien","Austria",0,115,[]])
data_list.append([datetime.datetime(2021, 5, 9),"Wien","Austria",1,68,[]])
data_list.append([datetime.datetime(2021, 5, 9),"Wien","Austria",3,6,[]])
data_list.append([datetime.datetime(2021, 5, 10),"Wien","Austria",0,108,[]])
data_list.append([datetime.datetime(2021, 5, 10),"Wien","Austria",3,13,[]])
data_list.append([datetime.datetime(2021, 5, 10),"Wien","Austria",2,1,[]])
data_list.append([datetime.datetime(2021, 5, 11),"Wien","Austria",0,141,[]])
data_list.append([datetime.datetime(2021, 5, 11),"Wien","Austria",3,65,[]])
data_list.append([datetime.datetime(2021, 5, 12),"Wien","Austria",0,115,[]])
data_list.append([datetime.datetime(2021, 5, 12),"Wien","Austria",3,9,[]])
data_list.append([datetime.datetime(2021, 5, 13),"Wien","Austria",0,118,[]])
data_list.append([datetime.datetime(2021, 5, 14),"Wien","Austria",2,5,[]])
data_list.append([datetime.datetime(2021, 5, 14),"Wien","Austria",0,16,[]])
data_list.append([datetime.datetime(2021, 5, 14),"Engelhartstetten","Austria",1,1,[]])
data_list.append([datetime.datetime(2021, 5, 14),"Engelhartstetten","Austria",2,2,[]])
data_list.append([datetime.datetime(2021, 5, 14),"Engelhartstetten","Austria",0,55,[]])
data_list.append([datetime.datetime(2021, 5, 14),"Engelhartstetten","Austria",3,51,[]])
data_list.append([datetime.datetime(2021, 5, 14),"Wien","Austria",0,21,[]])
data_list.append([datetime.datetime(2021, 5, 14),"Wien","Austria",3,29,[]])
data_list.append([datetime.datetime(2021, 5, 14),"Wien","Austria",2,2,[]])
data_list.append([datetime.datetime(2021, 5, 14),"Wien","Austria",6,2,[]])
data_list.append([datetime.datetime(2021, 5, 15),"Wien","Austria",3,2,[]])
data_list.append([datetime.datetime(2021, 5, 15),"Wien","Austria",5,100,[]])
data_list.append([datetime.datetime(2021, 5, 22),"Salzburg","Austria",3,105,[]])
data_list.append([datetime.datetime(2021, 5, 22),"Salzburg","Austria",0,345,[]])
data_list.append([datetime.datetime(2021, 5, 22),"Salzburg","Austria",2,1,[]])
data_list.append([datetime.datetime(2021, 5, 22),"Salzburg","Austria",1,4,[]])
data_list.append([datetime.datetime(2021, 5, 22),"Golling an der Salzach","Austria",2,6,[]])
data_list.append([datetime.datetime(2021, 5, 22),"Golling an der Salzach","Austria",1,47,[]])
data_list.append([datetime.datetime(2021, 5, 22),"Elsbethen","Austria",1,1,[]])
data_list.append([datetime.datetime(2021, 5, 23),"Wien","Austria",0,117,[]])
data_list.append([datetime.datetime(2021, 5, 24),"Wels","Austria",0,1,[]])
data_list.append([datetime.datetime(2021, 5, 24),"Altmuenster","Austria",1,1,[]])
data_list.append([datetime.datetime(2021, 5, 24),"Traunkirchen","Austria",1,4,[]])
data_list.append([datetime.datetime(2021, 5, 24),"Ebensee","Austria",1,1,[]])
data_list.append([datetime.datetime(2021, 5, 24),"Lahnstein","Austria",1,1,[]])
data_list.append([datetime.datetime(2021, 5, 24),"Steeg","Austria",2,2,[]])
data_list.append([datetime.datetime(2021, 5, 24),"Steeg","Austria",1,3,[]])
data_list.append([datetime.datetime(2021, 5, 24),"Hallstatt","Austria",2,12,[]])
data_list.append([datetime.datetime(2021, 5, 24),"Hallstatt","Austria",1,120,[]])
data_list.append([datetime.datetime(2021, 5, 24),"Hallstatt","Austria",0,109,[]])
data_list.append([datetime.datetime(2021, 5, 24),"Attnang-Puchheim","Austria",0,1,[]])
data_list.append([datetime.datetime(2021, 5, 28),"Wien","Austria",0,102,["Bob"]])
data_list.append([datetime.datetime(2021, 5, 29),"Wien","Austria",0,60,[]])
data_list.append([datetime.datetime(2021, 5, 30),"Klosterneuburg","Austria",0,265,[]])
data_list.append([datetime.datetime(2021, 5, 30),"Wien","Austria",0,7,[]])
data_list.append([datetime.datetime(2021, 6, 3),"Semmering","Austria",0,2,[]])
data_list.append([datetime.datetime(2021, 6, 3),"Breitenstein","Austria",0,2,[]])
data_list.append([datetime.datetime(2021, 6, 3),"Althofen","Austria",0,3,[]])
data_list.append([datetime.datetime(2021, 6, 3),"Launsdorf","Austria",0,68,[]])
data_list.append([datetime.datetime(2021, 6, 3),"Launsdorf","Austria",1,7,[]])
data_list.append([datetime.datetime(2021, 6, 3),"Neumarkt in der Steiermark","Austria",2,1,[]])
data_list.append([datetime.datetime(2021, 6, 5),"Wien","Austria",0,28,[]])
data_list.append([datetime.datetime(2021, 6, 5),"Wien","Austria",3,4,[]])
data_list.append([datetime.datetime(2021, 6, 5),"Wien","Austria",1,29,[]])
data_list.append([datetime.datetime(2021, 6, 5),"Wien","Austria",0,73,[]])
data_list.append([datetime.datetime(2021, 6, 6),"Wien","Austria",2,1,[]])
data_list.append([datetime.datetime(2021, 6, 6),"Wien","Austria",3,37,[]])
data_list.append([datetime.datetime(2021, 6, 12),"Lilienfeld","Austria",0,68,[]])
data_list.append([datetime.datetime(2021, 6, 12),"Lilienfeld","Austria",3,1,[]])
data_list.append([datetime.datetime(2021, 6, 12),"Lilienfeld","Austria",2,3,[]])
data_list.append([datetime.datetime(2021, 6, 12),"Herzogenburg","Austria",0,73,[]])
data_list.append([datetime.datetime(2021, 6, 12),"St Poelten","Austria",0,51,[]])
data_list.append([datetime.datetime(2021, 6, 13),"Muggendorf","Austria",2,8,[]])
data_list.append([datetime.datetime(2021, 6, 13),"Muggendorf","Austria",5,1,[]])
data_list.append([datetime.datetime(2021, 6, 13),"Muggendorf","Austria",1,72,[]])
data_list.append([datetime.datetime(2021, 6, 13),"Furth an der Triesting","Austria",2,2,[]])
data_list.append([datetime.datetime(2021, 6, 13),"Furth an der Triesting","Austria",1,52,[]])
data_list.append([datetime.datetime(2021, 6, 13),"Pernitz","Austria",1,1,[]])
data_list.append([datetime.datetime(2021, 6, 13),"Pernitz","Austria",2,1,[]])
data_list.append([datetime.datetime(2021, 6, 13),"Wiener Neustadt","Austria",0,51,[]])
data_list.append([datetime.datetime(2021, 6, 19),"Melk","Austria",0,2,[]])
data_list.append([datetime.datetime(2021, 6, 19),"Grimsing","Austria",1,3,[]])
data_list.append([datetime.datetime(2021, 6, 19),"Grimsing","Austria",2,2,[]])
data_list.append([datetime.datetime(2021, 6, 19),"Emmersdorf an der Donau","Austria",2,1,[]])
data_list.append([datetime.datetime(2021, 6, 19),"Emmersdorf an der Donau","Austria",0,9,[]])
data_list.append([datetime.datetime(2021, 6, 19),"Aggsbach Markt","Austria",1,1,[]])
data_list.append([datetime.datetime(2021, 6, 19),"Willendorf in der Wachau","Austria",2,1,[]])
data_list.append([datetime.datetime(2021, 6, 19),"Schwallenbach","Austria",0,1,[]])
data_list.append([datetime.datetime(2021, 6, 19),"Spitz an der Donau","Austria",2,15,[]])
data_list.append([datetime.datetime(2021, 6, 19),"Spitz an der Donau","Austria",0,5,[]])
data_list.append([datetime.datetime(2021, 6, 19),"Spitz an der Donau","Austria",1,9,[]])
data_list.append([datetime.datetime(2021, 6, 19),"Weissenkirchen in der Wachau","Austria",2,2,[]])
data_list.append([datetime.datetime(2021, 6, 19),"Duernstein","Austria",1,13,[]])
data_list.append([datetime.datetime(2021, 6, 19),"Duernstein","Austria",2,15,[]])
data_list.append([datetime.datetime(2021, 6, 19),"Duernstein","Austria",0,104,[]])
data_list.append([datetime.datetime(2021, 6, 19),"Weissenkirchen in der Wachau","Austria",1,2,[]])
data_list.append([datetime.datetime(2021, 6, 19),"Unterloiben","Austria",2,1,[]])
data_list.append([datetime.datetime(2021, 6, 19),"Oberloiben","Austria",0,1,[]])
data_list.append([datetime.datetime(2021, 6, 19),"Krems an der Donau","Austria",0,52,[]])
data_list.append([datetime.datetime(2021, 6, 19),"Krems an der Donau","Austria",1,1,[]])
data_list.append([datetime.datetime(2021, 6, 19),"Thunau am Kamp","Austria",2,2,[]])
data_list.append([datetime.datetime(2021, 6, 20),"Baden bei Wien","Austria",2,1,[]])
data_list.append([datetime.datetime(2021, 6, 20),"Baden bei Wien","Austria",3,6,[]])
data_list.append([datetime.datetime(2021, 6, 20),"Baden bei Wien","Austria",0,52,[]])
data_list.append([datetime.datetime(2021, 6, 20),"Heiligenkreuz im Wienerwald","Austria",0,98,[]])
data_list.append([datetime.datetime(2021, 6, 20),"Heiligenkreuz im Wienerwald","Austria",2,7,[]])
data_list.append([datetime.datetime(2021, 6, 22),"Wien","Austria",0,6,[]])
data_list.append([datetime.datetime(2021, 6, 25),"Wien","Austria",0,29,[]])
data_list.append([datetime.datetime(2021, 6, 26),"Seitenstetten","Austria",0,64,[]])
data_list.append([datetime.datetime(2021, 6, 26),"Seitenstetten","Austria",2,1,[]])
data_list.append([datetime.datetime(2021, 6, 26),"Seitenstetten","Austria",3,17,[]])
data_list.append([datetime.datetime(2021, 6, 26),"St Florian bei Linz","Austria",0,164,[]])
data_list.append([datetime.datetime(2021, 6, 26),"St Florian bei Linz","Austria",2,1,[]])
data_list.append([datetime.datetime(2021, 6, 26),"Hohenbrunn","Austria",0,3,[]])
data_list.append([datetime.datetime(2021, 6, 26),"Linz","Austria",0,19,[]])
data_list.append([datetime.datetime(2021, 6, 27),"Wien","Austria",1,2,[]])
data_list.append([datetime.datetime(2021, 6, 27),"Wien","Austria",2,2,[]])
data_list.append([datetime.datetime(2021, 7, 2),"Wien","Austria",6,11,[]])
data_list.append([datetime.datetime(2021, 7, 2),"Wien","Austria",5,26,[]])
data_list.append([datetime.datetime(2021, 7, 2),"Wien","Austria",0,45,[]])
data_list.append([datetime.datetime(2021, 7, 3),"Bad Goisern","Austria",1,5,[]])
data_list.append([datetime.datetime(2021, 7, 3),"Obertraun","Austria",1,188,[]])
data_list.append([datetime.datetime(2021, 7, 3),"Obertraun","Austria",2,12,[]])
data_list.append([datetime.datetime(2021, 7, 3),"Ebensee","Austria",1,1,[]])
data_list.append([datetime.datetime(2021, 7, 3),"Traunkirchen","Austria",1,1,[]])
data_list.append([datetime.datetime(2021, 7, 3),"Altmuenster","Austria",2,1,[]])

data_list.append([datetime.datetime(2021, 7, 10),"Wien","Austria",0,1,[]])
data_list.append([datetime.datetime(2021, 7, 10),"Salzburg","Austria",1,1,[]])
data_list.append([datetime.datetime(2021, 7, 10),"Werfen","Austria",0,1,[]])
data_list.append([datetime.datetime(2021, 7, 10),"Taxenbach","Austria",2,2,[]])
data_list.append([datetime.datetime(2021, 7, 10),"Taxenbach","Austria",0,1,[]])
data_list.append([datetime.datetime(2021, 7, 10),"Taxenbach","Austria",1,93,[]])
data_list.append([datetime.datetime(2021, 7, 10),"Lend","Austria",1,1,[]])
data_list.append([datetime.datetime(2021, 7, 10),"Schwarzach im Pongau","Austria",1,1,[]])
data_list.append([datetime.datetime(2021, 7, 10),"Schwarzach im Pongau","Austria",2,1,[]])
data_list.append([datetime.datetime(2021, 7, 10),"Schwarzach im Pongau","Austria",0,1,[]])
data_list.append([datetime.datetime(2021, 7, 10),"Sankt Veit im Pongau","Austria",0,1,[]])
data_list.append([datetime.datetime(2021, 7, 10),"Sankt Veit im Pongau","Austria",2,1,[]])
data_list.append([datetime.datetime(2021, 7, 10),"Sankt Veit im Pongau","Austria",1,2,[]])
data_list.append([datetime.datetime(2021, 7, 10),"Sankt Johann im Pongau","Austria",1,99,[]])
data_list.append([datetime.datetime(2021, 7, 10),"Sankt Johann im Pongau","Austria",0,3,[]])
data_list.append([datetime.datetime(2021, 7, 10),"Bischofshofen","Austria",1,13,[]])
data_list.append([datetime.datetime(2021, 7, 10),"Bischofshofen","Austria",2,3,[]])
data_list.append([datetime.datetime(2021, 7, 10),"Bischofshofen","Austria",0,7,[]])
data_list.append([datetime.datetime(2021, 7, 10),"Golling an der Salzach","Austria",1,1,[]])

data_list.append([datetime.datetime(2021, 9, 18),"Annaberg bei Mariazell","Austria",1,35,[]])
data_list.append([datetime.datetime(2021, 9, 18),"Annaberg bei Mariazell","Austria",2,1,[]])
data_list.append([datetime.datetime(2021, 9, 18),"Annaberg bei Mariazell","Austria",0,1,[]])
data_list.append([datetime.datetime(2021, 9, 18),"Mitterbach am Erlaufsee","Austria",0,1,[]])
data_list.append([datetime.datetime(2021, 9, 18),"Mitterbach am Erlaufsee","Austria",1,145,[]])
data_list.append([datetime.datetime(2021, 9, 18),"Mariazell","Austria",0,39,[]])
data_list.append([datetime.datetime(2021, 9, 18),"Mariazell","Austria",2,1,[]])
data_list.append([datetime.datetime(2021, 9, 18),"Mariazell","Austria",2,2,[]])

#photo types: 0 city photo/buildings, 1 predominantly nature (not major on animals), 2 mixed (e.g. lake and village, or sea and city), 
#3 park, 4 private event aka focus on people, 5 animals/zoo, 6 flowers outside of park 7 else

# %%
df = pd.DataFrame(data_list,columns=["Date", 'Place', 'Country','Photo Type','Picture Count',"Co-Travellers"])
df["Number of Co-Travellers"]=df["Co-Travellers"].str.len()
df.to_csv("data/picture_data_pictureMotiveStyle.csv")

# %%
df.groupby(["Place","Photo Type"]).agg(picturecount_type_place=("Picture Count","sum")).reset_index().sort_values(by="picturecount_type_place",ascending=False).head(40)
# Out:
#                        Place  Photo Type  picturecount_type_place
# 331                      Rom           0                     1946
# 456                     Wien           0                     1802
# 298                    Paris           0                     1128
# 136                  Florenz           0                      733
# 112                  Dresden           0                      582
# 131              Fieschertal           1                      347
# 67                   Bourges           0                      347
# 339                 Salzburg           0                      345
# 198              Lauchringen           1                      343
# 468                  Wroclaw           0                      300
# 367                    Siena           0                      298
# 89                  Chamonix           1                      266
# 185           Klosterneuburg           0                      265
# ...

# %%
df.groupby(["Country","Photo Type"]).agg(picturecount_type_place=("Picture Count","sum")).reset_index().sort_values(by="picturecount_type_place",ascending=False).head(40)
# Out:
#            Country  Photo Type  picturecount_type_place
# 17           Italy           0                     4196
# 0          Austria           0                     3525
# 6           France           0                     2201
# 12         Germany           0                     2123
# 34     Switzerland           1                     1249
# 13         Germany           1                     1062
# 1          Austria           1                     1029
# 29          Poland           0                      735
# 7           France           1                      678
# 39  United Kingdom           0                      567
# 33     Switzerland           0                      450
# 3          Austria           3                      400
# 18           Italy           1                      325
# 14         Germany           2                      287
# 20           Italy           3                      242
# 35     Switzerland           2                      212
# ...
