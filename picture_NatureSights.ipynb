# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
data_list=[]
#Nature Type:
#0 other 
#1 glacier
#2 waterfall
#3 canyon/Schlucht
#4 mountain peak

#5 lake
#6 mountain range
#7 river/creek (bach)
#8 cave

#9 natural arch/bridge/window
#10 Coastal Cliff
#11 beach
#12 desert

#13 special forest/trees
#14 desert/ Sand dunes
#15 Auen/wetlands
#16 volcano

#17 geyser
#18 lava cave
#19 rock formation 
#20 sea cave

#21 grotto
#22 natural rock/cinter teracces
#23 basalt/rock columns
#24 archipelago
#25 island/islets
#26 spring
#27 valley
#28 Fjord
#29 vineyard/fields
#30 natural flower scapes etc (not including parks)
#31 tidal sea
#32 bay

#category specific to nature type

#for mountains
#0 alpin
#1 mittelgebirge
#2 Rumpfgebirge

#volcano
#0 shield volcano/shield lake crater
#1 caldera
#2 maar

#caves
#0 flowstone
#1 flowstone with river
#2 flowstone with lake
#3 no flowstone but lake, also pure underground lake
#4 no flowstone but river, also pure river cave
#5 grotto and cave no flowstones
#6 ice cave

#'natural sight', 'Place', 'Country','UNESCO World Heritage Site','NationalPark/NaturPark',"category type"'category",Picture Count',
#'Nature Type Count" 'people visited with'
data_list.append(["Stockholm Archipelago","Stockholm","Sweden","","",0,66,24, "Archipelago", ['Yanyan']])
data_list.append(["Mojave Desert","","USA","","",0,  9,12, "Desert", ['Heidrun','Artur']])
data_list.append(["Taklamakan","","China","","",0,  5,12, "Desert", ['']])
data_list.append(["Gumfluh","Chateau d'Oex","Switzerland","","",0,  11,4, "Mountain Peak", ['Juno']])
data_list.append(["Cascade du Ramacle","Chateau d'Oex","Switzerland","","",0,  5,2, "Waterfall", ['Juno']])
data_list.append(["Sarine","Chateau d'Oex","Switzerland","","",0,  10,7, "River", ['Juno']])
data_list.append(["Rheinfall","Neuhausen am Rheinfall","Switzerland","","",0,  165,2, "Waterfall", ["Artur","Heidrun","Anne-Kathrin","Jan-Marc","Hannsjoerg"]])
data_list.append(["Thuner See","Interlaken","Switzerland","","",0,  27,5, "Lake", ["Artur","Heidrun","Anne-Kathrin","Jan-Marc","Hannsjoerg"]])
data_list.append(["Berner Alpen","Interlaken","Switzerland","Jungfrau Region","",0,  28,6, "Mountain Range", ["Artur","Heidrun","Anne-Kathrin","Jan-Marc","Hannsjoerg",'Tema','Sasha','Juno','Anne','Sigi','Indara','Chris M']])
data_list.append(["Toba Kakar Range","","Pakistan","","",0,  5,6, "Mountain Range", []])
data_list.append(["Karakorum","","Pakistan","","",0,  36,6, "Mountain Range", []])
data_list.append(["Batura Glacier","","Pakistan","","",0,  7,1, "Glacier", []])
data_list.append(["Pasu Glacier","","Pakistan","","",0,  6,1, "Glacier", []])
data_list.append(["Eiger","Grindelwald","Switzerland","Jungfrauregion","",0,67,4, "Mountain Peak", ["Artur","Heidrun","Anne-Kathrin","Jan-Marc","Hannsjoerg",'Tema','Sasha','Juno','Anne','Sigi','Indara','Chris M']])
data_list.append(["Moench","Grindelwald","Switzerland","Jungfrauregion","",0,82,4, "Mountain Peak", ["Artur","Heidrun","Anne-Kathrin","Jan-Marc","Hannsjoerg",'Tema','Sasha','Juno','Anne','Sigi','Indara','Chris M']])
data_list.append(["Jungfrau","Grindelwald","Switzerland","Jungfrauregion","",0,88,4, "Mountain Peak", ["Artur","Heidrun","Anne-Kathrin","Jan-Marc","Hannsjoerg",'Tema','Sasha','Juno','Anne','Sigi','Indara','Chris M']])
data_list.append(["Gross Fiescherhorn","Grindelwald","Switzerland","Jungfrauregion","",0, 35,4, "Mountain Peak", ["Indara",'Hannsjoerg','Chris M']])
data_list.append(["Untere Grindelwaldgletscherschlucht","Grindelwald","Switzerland","Jungfrauregion","",0, 37,3, "Canyon", []])
data_list.append(["Obere Grindelwaldgletscherschlucht","Grindelwald","Switzerland","Jungfrauregion","",0, 29,3, "Canyon", []])
data_list.append(["Pamukkale","Pamukkale","Turkey","Pamukkale","",0, 8,22, "Natural Terrace", ["Artur","Heidrun","Anne-Kathrin","Hannsjoerg"]])
data_list.append(["Aletschgletscher","Fieschertal","Switzerland","Jungfrauregion","",0,301,1, "Glacier", ["Artur","Heidrun","Anne","Hannsjoerg",'Francesca','Ulrike','Ivan','Chris B','Jose','Tema','Juno','Sigi','Sasha','Sam']])
data_list.append(["Silberhorn","Lauterbrunnen","Switzerland","Jungfrauregion","",0, 32,1, "Glacier", ["Anne","Hannsjoerg",'Tema','Indara','Sigi']])
data_list.append(["Silberhorngletscher","Lauterbrunnen","Switzerland","Jungfrauregion","",0,32,1, "Glacier", ["Anne","Hannsjoerg",'Tema','Sigi','Indara']])
data_list.append(["Hochfirn","Lauterbrunnen","Switzerland","Jungfrauregion","",0, 6,1, "Glacier", ["Anne","Hannsjoerg",'Tema','Sigi','Indara']])
data_list.append(["Giessengletscher","Lauterbrunnen","Switzerland","Jungfrauregion","",0,57,1, "Glacier", ["Anne","Hannsjoerg",'Tema','Sigi','Indara']])
data_list.append(["Guggigletscher","Lauterbrunnen","Switzerland","Jungfrauregion","",0, 43,1, "Glacier", ["Anne","Hannsjoerg",'Tema','Sigi','Indara']])
data_list.append(["Hengsterengletscher","Grindelwald","Switzerland","Jungfrauregion","",0, 6,1, "Glacier", ["Hannsjoerg",'Indara']])
data_list.append(["Chielouwenengletscher","Lauterbrunnen","Switzerland","Jungfrauregion","",0, 58,1, "Glacier", ["Anne","Hannsjoerg",'Tema','Sigi','Indara']])
data_list.append(["Grindelwald-Fieschergletscher & Unterer Grindelwaldgletscher","Grindelwald","Switzerland","Jungfrauregion","",0, 170,1, "Glacier", ['Artur','Heidrun',"Anne","Hannsjoerg",'Sigi','Indara','Chris M','Anne-Kathrin','Jan-Marc','Heidrun','Artur']])
data_list.append(["Eismeer","Grindelwald","Switzerland","Jungfrauregion","",0, 20,1, "Glacier", ["Anne","Hannsjoerg",'Tema','Sigi','Indara']])
data_list.append(["Oberer Grindelwaldgletscher","Grindelwald","Switzerland","Jungfrauregion","",0,101,1, "Glacier", ["Anne","Hannsjoerg",'Tema','Sigi','Indara','Chris M','Anne-Kathrin','Jan-Marc','Artur','Heidrun']])
data_list.append(["Challifirn","Grindelwald","Switzerland","Jungfrauregion","",0, 9,1, "Glacier", ["Anne","Hannsjoerg",'Tema','Sigi','Indara','Chris M']])
data_list.append(["Schreckhorn","Grindelwald","Switzerland","Jungfrauregion","",0, 34,4, "Mountain Peak", ["Indara","Anne",'Hannsjoerg','Tema','Sigi']])
data_list.append(["Finsteraarhorn","Grindelwald","Switzerland","Jungfrauregion","",0, 23,4, "Mountain Peak", ["Indara",'Hannsjoerg','Chris M']])
data_list.append(["Lauteraarhorn","Grindelwald","Switzerland","Jungfrauregion","",0, 11,4, "Mountain Peak", ["Indara","Anne",'Hannsjoerg','Tema','Sigi']])
data_list.append(["Aletschhorn","Fiesch","Switzerland","Jungfrauregion","",0,41,4, "Mountain Peak", ["Artur","Heidrun","Anne","Hannsjoerg",'Francesca','Ulrike','Ivan','Chris B','Jose','Tema','Juno','Sigi','Sasha','Sam']])
data_list.append(["Mittelaletschgletscher","Fiescher","Switzerland","Jungfrauregion","",0, 25,1, "Glacier", ["Artur",'Heidrun','Hannsjoerg']])
data_list.append(["Oberaletschgletscher","Fiesch","Switzerland","Jungfrauregion","",0,35,1, "Glacier", ["Sam","Artur","Heidrun"]])
data_list.append(["Driestgletscher","Fiesch","Switzerland","Jungfrauregion","",0,4,1, "Glacier", []])
data_list.append(["Fieschergletscher","Fiesch","Switzerland","Jungfrauregion","",0, 52,1, "Glacier", ["Artur","Heidrun","Hannsjoerg",'Francesca','Ulrike','Ivan','Chris B','Jose','Tema','Juno','Sasha']])
data_list.append(["Oberaarrothorn","Fiesch","Switzerland","Jungfrauregion","",0, 14,4, "Mountain Peak", ["Artur","Heidrun","Hannsjoerg",'Francesca','Ulrike','Ivan','Chris B','Jose','Tema','Juno','Sasha']])
data_list.append(["Grosses Wannenhorn","Fiesch","Switzerland","Jungfrauregion","",0, 5,4, "Mountain Peak", ["Artur","Heidrun","Hannsjoerg",'Francesca','Ulrike','Ivan','Chris B','Jose','Tema','Juno','Sasha']])
data_list.append(["Balfringletscher","Visp","Switzerland","","",0,11,1, "Glacier", ["Artur","Heidrun","Hannsjoerg",'Francesca','Ulrike','Ivan','Chris B','Jose','Tema','Juno','Sasha']])
data_list.append(["Oberrothorn","Fiesch","Switzerland","Jungfrauregion","",0, 10,4, "Mountain Peak", ["Artur","Heidrun","Hannsjoerg",'Francesca','Ulrike','Ivan','Chris B','Jose','Tema','Juno','Sasha']])
data_list.append(["Trugberg","Fieschertal","Switzerland","Jungfrauregion","",0, 21,4, "Mountain Peak", ["Artur","Heidrun","Anne","Hannsjoerg",'Francesca','Ulrike','Ivan','Chris B','Jose','Tema','Juno','Sigi','Sasha']])
data_list.append(["Sphinx","Fieschertal","Switzerland","Jungfrauregion","",0, 13,4, "Mountain Peak", ["Artur","Heidrun","Anne","Hannsjoerg",'Francesca','Ulrike','Ivan','Chris B','Jose','Tema','Juno','Sigi','Sasha']])
data_list.append(["Jungfraufirn","Fieschertal","Switzerland","Jungfrauregion","",0, 197,1, "Glacier", ["Artur","Heidrun","Anne","Hannsjoerg",'Francesca','Ulrike','Ivan','Chris B','Jose','Tema','Juno','Sigi','Sasha']])
data_list.append(["Ewigschneefeld","Fieschertal","Switzerland","Jungfrauregion","",0, 83,1, "Glacier", ["Artur","Heidrun","Anne","Hannsjoerg",'Francesca','Ulrike','Ivan','Chris B','Jose','Tema','Juno','Sigi','Sasha']])
data_list.append(["Aleschfirn","Fieschertal","Switzerland","Jungfrauregion","",0, 23,1, "Glacier", ['Tema','Juno',"Sasha"]])
data_list.append(["Grueneggfirn","Fieschertal","Switzerland","Jungfrauregion","",0, 10,1, "Glacier", ['Tema','Juno',"Sasha"]])
data_list.append(["Eigergletscher","Fieschertal","Switzerland","Jungfrauregion","",0, 65,1, "Glacier", ["Artur","Heidrun","Anne","Hannsjoerg",'Tema','Sigi']])
data_list.append(["Breithorn (Lauterbrunnen)","Lauterbrunnen","Switzerland","Jungfrauregion","",0, 29,4, "Mountain Peak", ["Anne","Hannsjoerg",'Andrew','Tema','Sigi']])
data_list.append(["Lauterbrunner Tal","Lauterbrunnen","Switzerland","","",0, 20,37, "Valley", ["Anne","Hannsjoerg",'Andrew','Tema','Sigi']])
data_list.append(["Gutzgletscher","Grindelwald","Switzerland","Jungfrauregion","",0, 24,1, "Glacier", ["Hannsjoerg",'Indara','Chris M']])
data_list.append(["Wetterhorn","Grindelwald","Switzerland","Jungfrauregion","",0, 38,4, "Mountain Peak", ["Hannsjoerg",'Indara','Chris M']])
data_list.append(["Rosenlauigletscher","Rosenlaui","Switzerland","Jungfrauregion","",0, 5,1, "Glacier", ["Artur","Heidrun","Anne-Kathrin","Hannsjoerg"]])
data_list.append(["Uratgletscher","Engelberg","Switzerland","","",0,7,1, "Glacier", []])
data_list.append(["Titlisgletscher","Engelberg","Switzerland","","",0,73,1, "Glacier", []])
data_list.append(["Kleintitlis","Engelberg","Switzerland","","",0, 2,4, "Mountain Peak", []])
data_list.append(["Titlis","Engelberg","Switzerland","","",0, 2,4, "Mountain Peak", []])
data_list.append(["Sustenhorn","Engelberg","Switzerland","","",0, 1,4, "Mountain Peak", []])
data_list.append(["Mittler Tierberg","Gadmen","Switzerland","","",0, 12,4, "Mountain Peak", ["Artur","Heidrun",'Hannsjoerg']])
data_list.append(["Triftsee","Gadmen","Switzerland","","",0, 4,5, "Lake", ["Artur","Heidrun",'Hannsjoerg']])
data_list.append(["Steinsee","Gadmen","Switzerland","","",0, 7,5, "Lake", ["Artur","Heidrun",'Hannsjoerg']])
data_list.append(["Triftstoeckli","Gadmen","Switzerland","","",0, 5,4, "Mountain Peak", ["Artur","Heidrun",'Hannsjoerg']])
data_list.append(["Triftgletscher (Gadmen)","Gadmen","Switzerland","","",0,38,1, "Glacier", ["Artur","Heidrun",'Hannsjoerg']])
data_list.append(["Steingletscher","Susten","Switzerland","","",0, 56,1, "Glacier", ["Artur","Heidrun","Hannsjoerg"]])
data_list.append(["Steinlimigletscher","Susten","Switzerland","","",0, 5,1, "Glacier", ["Artur","Heidrun","Hannsjoerg"]])
data_list.append(["Obertalgletscher","Susten","Switzerland","","",0, 2,1, "Glacier", ["Artur","Heidrun","Hannsjoerg"]])
data_list.append(["Fuenffingerstoecke","Susten","Switzerland","","",0, 5,4, "Mountain Peak", ["Andrew","Hannsjoerg"]])
data_list.append(["Wendengletscher","Engelberg","Switzerland","","",0,21,1, "Glacier", []])
data_list.append(["Firnalpelifirn","Engelberg","Switzerland","","",0,3,1, "Glacier", []])
data_list.append(["Truebsee","Engelberg","Switzerland","","",0, 7,5, "Lake", []])
data_list.append(["Maennlichen","Grindelwald","Switzerland","","",0,7,4, "Mountain Peak", ["Hannsjoerg",'Indara','Chris M']])
data_list.append(["Bachalpsee","Grindelwald","Switzerland","","",0, 12,5, "Lake", ["Hannsjoerg"]])
data_list.append(["Staubbachfall","Lauterbrunnen","Switzerland","","",0, 9,2, "Waterfall", ["Anne","Hannsjoerg",'Andrew','Tema','Sigi']])
data_list.append(["Lavaux","Grandvaux","Switzerland","Lavaux","",0, 54,29, "Vineyards/Fields", ["Hannsjoerg",'Andrew','Xuan',"Will","Artur","Heidrun",'Anne-Kathrin','Christian']])
data_list.append(["Genfer See","Genf","Switzerland","","",0, 98,5, "Lake", ["Hannsjoerg",'Andrew','Xuan',"Will","Artur","Heidrun",'Anne-Kathrin','Christian']])
data_list.append(["Rhein","Schaffhausen","Switzerland","","",0, 53,7, "River", ["Artur"]])
data_list.append(["Salzach","Taxenbach","Austria","","",0, 7,7, "River", []])
data_list.append(["Buergerwald","Tiengen","Switzerland","","",0, 19,13, "Forest", ["Artur",'Heidrun','Anne-Kathrin','Hannsjoerg','Jan-Marc']])
data_list.append(["Bernina Massif","Diavolezza","Switzerland","","",0, 9,6, "Mountain Range", []])
data_list.append(["Morteratschgletscher","Diavolezza","Switzerland","","",0, 31,1, "Glacier", []])
data_list.append(["Persgletscher","Diavolezza","Switzerland","","",0, 36,1, "Glacier", []])
data_list.append(["Lac Blanc","Chamonix","France","","",0, 11,5, "Lake", ["David","Andrew",'Nick','Eve','Pieter','Cameron','Chris S']])
data_list.append(["Mer de Glace","Chamonix","France","","",0, 176,1, "Glacier", ["Artur",'Heidrun','Hannsjoerg','Sasha','Juno','Tema','Andrej']])
data_list.append(["Aiguille du Tacul","Chamonix","France","","",0, 8,4, "Mountain Peak", ['Sasha',"Juno",'Tema','Andrej']])
data_list.append(["Glacier de Nantillons","Chamonix","France","","",0,15,1, "Glacier", ["Artur",'Heidrun','Hannsjoerg','Sasha','Juno','Tema','Andrej']])
data_list.append(["Aiguille du Plan","Chamonix","France","","",0, 21,4, "Mountain Peak", ["Artur",'Heidrun','Hannsjoerg','James','Indara','Grace','Riju','Christine']])
data_list.append(["Glacier du Plan","Chamonix","France","","",0, 21,1, "Glacier", ["Artur",'Heidrun','Hannsjoerg','James','Indara','Grace','Riju','Christine']])
data_list.append(["Glacier d'Envers du Plan","Chamonix","France","","",0,14,1, "Glacier", []])
data_list.append(["Glacier de la Charpoua","Chamonix","France","","",0, 5,1, "Glacier", []])
data_list.append(["Glacier Rond","Chamonix","France","","",0, 9,1, "Glacier", ["Artur",'Heidrun','Hannsjoerg','James','Indara','Grace','Riju','Christine',"Manuel"]])
data_list.append(["Glacier de Bossons","Chamonix","France","","",0,357,1, "Glacier", ["Artur",'Heidrun','Hannsjoerg','Sasha','Juno','Tema',"Manuel",'Andrej','Indara','Riju','Grace',"Christine","James","Andreas"]])
data_list.append(["Glacier du Taconnaz","Chamonix","France","","",0,47,1, "Glacier", ["Manuel","Artur",'Heidrun','Hannsjoerg','Andreas']])
data_list.append(["Glacier de Talefre","Chamonix","France","","",0,37,1, "Glacier", ["Artur",'Heidrun','Hannsjoerg','Indara','Riju','Grace',"Christine","James"]])
data_list.append(["Glacier de Geant","Chamonix","France","","",0,100,1, "Glacier", ["Artur",'Heidrun','Hannsjoerg','Indara','Riju','Grace',"Christine","James"]])
data_list.append(["Dent du Geant","Chamonix","France","","",0,7,4, "Mountain Peak", ["Artur",'Heidrun','Hannsjoerg','Indara','Riju','Grace',"Christine","James"]])
data_list.append(["Vallee Blanche","Chamonix","France","","",0,70,1, "Glacier", ["Artur",'Heidrun','Hannsjoerg','Indara','Riju','Grace',"Christine","James"]])
data_list.append(["Grands Jorasses","Chamonix","France","","",0,27,4, "Mountain Peak", ["Artur",'Heidrun','Hannsjoerg','Sasha','Juno','Tema','Mikhail']])
data_list.append(["Gh del Rutor","La Thuile","Italy","","",0,2,1, "Glacier", ["Artur",'Heidrun','Hannsjoerg','Indara','Riju','Grace',"Christine","James"]])
data_list.append(["Glacier de Periades","Chamonix","France","","",0,28,1, "Glacier", ["Artur",'Heidrun','Hannsjoerg','Sasha','Juno','Tema','Andrej','Indara','Riju','Grace',"Christine","James"]])
data_list.append(["Glacier de Pelerins","Chamonix","France","","",0,55,1, "Glacier", ["Artur",'Heidrun','Hannsjoerg','Sasha','Juno','Tema','Andrej','Indara','Riju','Grace',"Christine","James"]])
data_list.append(["Glacier de Grands Montets","Argentiere","France","","",0,14,1, "Glacier", ['Jacob','Brant','Dan','Jesse']])
data_list.append(["Glacier des Rognons","Argentiere","France","","",0,21,1, "Glacier", ['Jacob','Brant','Dan','Jesse']])
data_list.append(["Glacier des Lognon","Argentiere","France","","",0,11,1, "Glacier", ['Jacob','Brant','Dan','Jesse']])
data_list.append(["Glacier de la Pendant","Argentiere","France","","",0, 7,1, "Glacier", ['Jacob','Brant','Dan','Jesse']])
data_list.append(["Gh di Toula","Chamonix","France","","",0,10,1, "Glacier", ['Jacob','Brant','Dan','Jesse']])
data_list.append(["Mont Brevent","Chamonix","France","","",0, 11,4, "Mountain Peak", ["Artur",'Heidrun','Hannsjoerg','Sasha','Juno','Tema','Andrej','Indara','Riju','Grace',"Christine","James"]])
data_list.append(["Prarion","Chamonix","France","","",0, 1,4, "Mountain Peak", ["Artur",'Heidrun','Hannsjoerg','Indara','Riju','Grace',"Christine","James"]])
data_list.append(["Aiguille du Midi","Chamonix","France","","",0,89,4, "Mountain Peak", ["Artur",'Heidrun','Hannsjoerg','Indara','Riju','Grace',"Christine","James"]])
data_list.append(["Mont Blanc","Chamonix","France","","",0,108,4, "Mountain Peak", ["Artur",'Heidrun','Hannsjoerg','Sasha','Juno','Tema','Andrej','Indara','Riju','Grace',"Christine","James",'Andrew','Nick','David','Eve','Chris S','Cameron','Pieter',"Manuel","Jesse",'Brant',"Dan",'Jacob']])
data_list.append(["Mont Blanc du Tacul","Chamonix","France","","",0,11,4, "Mountain Peak", ["Artur",'Heidrun','Hannsjoerg','Indara','Riju','Grace',"Christine","James"]])
data_list.append(["Aiguille du Chardonnet","Chamonix","France","","",0, 19,4, "Mountain Peak", ["Pieter","Jonas","Line","Dan",'Brant','Jesse','Jacob']])
data_list.append(["Glacier du Chardonnet","Chamonix","France","","",0,8,4, "Mountain Peak", ["Dan",'Brant','Jesse','Jacob']])
data_list.append(["Glacier du Tour","Chamonix","France","","",0, 49,4, "Mountain Peak", ["Pieter","Jonas","Line"]])
data_list.append(["Domes de Miage","passy","France","","",0, 2,4, "Mountain Peak", ["Pieter","Jonas","Line"]])
data_list.append(["Dome du Gouter","Chamonix","France","","",0,39,4, "Mountain Peak", ["Artur",'Heidrun','Hannsjoerg','Sasha','Juno','Tema','Andrej','Indara','Riju','Grace',"Christine","James",'Manuel']])
data_list.append(["Les Drus","Chamonix","France","","",0,22,4, "Mountain Peak", ["Artur",'Heidrun','Hannsjoerg','Sasha','Juno','Tema','Andrej']])
data_list.append(["Glacier de Bionnassay","Saint-Gervais-les-Bains","France","","",0, 35,1, "Glacier", ['Pieter','Jonas','Grace','Riju','Grace S','Chris S']])
data_list.append(["Aiguille de Bionnassay","Saint-Gervais-les-Bains","France","","",0, 19,4, "Mountain Peak", ['Pieter','Jonas','Grace','Riju','Grace S','Chris S']])
data_list.append(["Mont Maudit","Chamonix","France","","",0,19,4, "Mountain Peak", ["Artur",'Heidrun','Hannsjoerg','Indara','Riju','Grace',"Christine","James","Manuel"]])
data_list.append(["Aiguille de Blaitiere","Chamonix","France","","",0,18,4, "Mountain Peak", ["Artur",'Heidrun','Hannsjoerg','Indara','Riju','Grace',"Christine","James"]])
data_list.append(["Glacier de Blaitiere","Chamonix","France","","",0,12,1, "Glacier", ["Artur",'Heidrun','Hannsjoerg','Indara','Riju','Grace',"Christine","James"]])
data_list.append(["Glacier d'Envers de Blaitiere","Chamonix","France","","",0,3,1, "Glacier", []])
data_list.append(["Aiguille de l'M","Chamonix","France","","",0,10,4, "Mountain Peak", ["Artur",'Heidrun','Hannsjoerg','Sasha','Juno','Tema','Andrej']])
data_list.append(["Grands Charmoz","Chamonix","France","","",0, 21,4, "Mountain Peak", ["Artur",'Heidrun','Hannsjoerg','Sasha','Juno','Tema','Andrej']])
data_list.append(["Glacier de Leschaux","Chamonix","France","","",0,21,1, "Glacier", ["Artur",'Heidrun','Hannsjoerg','Sasha','Juno','Tema','Andrej']])
data_list.append(["Glacier de Nant Blanc","Chamonix","France","","",0,34,1, "Glacier", ["Artur",'Heidrun','Hannsjoerg','Sasha','Juno','Tema','Andrej']])
data_list.append(["Glacier d'Argentiere","Chamonix","France","","",0,74,1, "Glacier", ["Dan","Brant",'Jacob',"Jesse"]])
data_list.append(["Aiguille d'Argentiere","Chamonix","France","","",0,6,4, "Mountain Peak", ["Dan","Brant",'Jacob',"Jesse"]])
data_list.append(["Jura","Geneva","Switzerland","","",0, 22,6, "Mountain Range", ["Juno",'Sasha',"Rosana","Jacob","Jesse","Hannsjoerg"]])
data_list.append(["Mole","Geneva","France","","",0, 11,4, "Mountain Peak", ["David",'Rosana',"Andrew","Pieter"]])
data_list.append(["Saleve","Geneva","France","","",0,15,4, "Mountain Peak", ["Heidrun",'Artur',"Hannsjoerg"]])
data_list.append(["Aiguille Verte","Chamonix","France","","",0,26,4, "Mountain Peak", ['Benjamin','Viola','Wieland','Juerg','Ann-Karin','Pascal','Jacob','Brant','Dan','Jesse']])
data_list.append(["Seerenbach","Betlis","Switzerland","","",0, 11,7, "River", ["Juno"]])
data_list.append(["Rhone","Geneva","Switzerland","","",0, 42,7, "River", ['Bing',"Francesca","Sam","Indara",'Andres','Grace',"Riju"]])

# %%
#### so tiresome try tomorrow or during the weak 2007 zermatt not even in
data_list.append(["Matterhorn","Zermatt","Switzerland","","",0,140,4, "Mountain Peak", ['Hannsjoerg','Artur',"Heidrun",'Riju','Eric','Manuel','Stani','Andres','Chris B','David Y','Janina','Grace','Sam',"Christine"]])
data_list.append(["Matterhorngletscher","Zermatt","Switzerland","","",0, 16,1, "Gletscher", ["Manuel",'Stani','Eric']])
data_list.append(["Weingartengletscher","Zermatt","Switzerland","","",0, 7,1, "Gletscher", ['Eric',"Heidrun",'Artur',"Hannsjoerg"]])
data_list.append(["Kingletscher","Zermatt","Switzerland","","",0, 8,1, "Gletscher", ['Eric',"Heidrun",'Artur',"Hannsjoerg"]])
data_list.append(["Kleinmatterhorn","Zermatt","Switzerland","","",0,31,4, "Mountain Peak", ['Eric',"Heidrun",'Artur',"Hannsjoerg"]])
data_list.append(["Dom","Zermatt","Switzerland","","",0, 20,4, "Mountain Peak", ['Eric',"Heidrun",'Artur',"Hannsjoerg"]])
data_list.append(["Taeschhorn","Zermatt","Switzerland","","",0,25,4, "Mountain Peak", ['Eric',"Heidrun",'Artur',"Hannsjoerg"]])
data_list.append(["Mischabelgruppe","Zermatt","Switzerland","","",0,21,4, "Mountain Peak", ["Andrew","Hannsjoerg"]])
data_list.append(["Weisshorn","Zermatt","Switzerland","","",0,43,4, "Mountain Peak", ['Eric',"Heidrun",'Artur',"Hannsjoerg","Riju","Christine","Janina","Chris B","Sam","Andres","David Y","Grace"]])
data_list.append(["Dent Blanche","Zermatt","Switzerland","","",0,19,4, "Mountain Peak", ['Eric',"Heidrun",'Artur',"Hannsjoerg","Riju","Christine","Janina","Chris B","Sam","Andres","David Y","Grace"]])
data_list.append(["Obergabelhorn","Zermatt","Switzerland","","",0, 18,4, "Mountain Peak", ['Eric',"Heidrun",'Artur',"Hannsjoerg","Riju","Christine","Janina","Chris B","Sam","Andres","David Y","Grace"]])
data_list.append(["Strahlhorn","Zermatt","Switzerland","","",0,26,4, "Mountain Peak", ['Eric',"Heidrun",'Artur',"Hannsjoerg","Riju","Christine","Janina","Chris B","Sam","Andres","David Y","Grace"]])
data_list.append(["Rimpfischhorn","Zermatt","Switzerland","","",0,19,4, "Mountain Peak", ['Eric',"Heidrun",'Artur',"Hannsjoerg","Riju","Christine","Janina","Chris B","Sam","Andres","David Y","Grace"]])
data_list.append(["Zinalrothorn","Zermatt","Switzerland","","",0, 24,4, "Mountain Peak", ['Eric',"Heidrun",'Artur',"Hannsjoerg","Riju","Christine","Janina","Chris B","Sam","Andres","David Y","Grace"]])
data_list.append(["Rothorngletscher","Zermatt","Switzerland","","",0,12,1, "Glacier", ['Eric',"Heidrun",'Artur',"Hannsjoerg","Riju","Christine","Janina","Chris B","Sam","Andres","David Y","Grace"]])
data_list.append(["Hohlichtgletscher","Zermatt","Switzerland","","",0,10,1, "Glacier", ['Eric',"Heidrun",'Artur',"Hannsjoerg","Riju","Christine","Janina","Chris B","Sam","Andres","David Y","Grace"]])
data_list.append(["Hohwaenggletscher","Zermatt","Switzerland","","",0,13,1, "Glacier", ['Eric',"Heidrun",'Artur',"Hannsjoerg","Riju","Christine","Janina","Chris B","Sam","Andres","David Y","Grace"]])
data_list.append(["Gabelhorngletscher","Zermatt","Switzerland","","",0,23,1, "Glacier", ['Eric',"Heidrun",'Artur',"Hannsjoerg","Riju","Christine","Janina","Chris B","Sam","Andres","David Y","Grace"]])
data_list.append(["Stockjigletscher","Zermatt","Switzerland","","",0,27,1, "Glacier", ['Eric',"Heidrun",'Artur',"Hannsjoerg","Riju","Christine","Manuel","Stani","Grace","Janina","Chris B","Sam","Andres","David Y"]])
data_list.append(["Tiefmattengletscher","Zermatt","Switzerland","","",0,8,1, "Glacier", ['Eric',"Heidrun",'Artur',"Hannsjoerg","Riju","Christine","Manuel","Stani","Grace","Janina","Chris B","Sam","Andres","David Y"]])
data_list.append(["Zmuttgletscher","Zermatt","Switzerland","","",0, 10,1, "Glacier", ['Eric',"Manuel","Stani"]])
data_list.append(["Riffelsee","Zermatt","Switzerland","","",0, 14,5, "Lake", ["Riju","Hannsjoerg"]])
data_list.append(["Riffelhorn","Zermatt","Switzerland","","",0, 3,4, "Mountain Peak", ["Riju","Hannsjoerg"]])
data_list.append(["Schaligletscher","Zermatt","Switzerland","","",0, 12,1, "Glacier", ['Eric',"Heidrun",'Artur']])
data_list.append(["Alphubel","Saas-Fee","Switzerland","","",0,21,4, "Mountain Peak", ["Andrew","Hannsjoerg"]])
data_list.append(["Allalin","Saas-Fee","Switzerland","","",0,29,4, "Mountain Peak", ["Andrew","Hannsjoerg"]])
data_list.append(["Lagginhorn","Saas-Fee","Switzerland","","",0,16,4, "Mountain Peak", ["Andrew","Hannsjoerg"]])
data_list.append(["Weissmies","Saas-Grund","Switzerland","","",0,13,4, "Mountain Peak", []])
data_list.append(["Mattmark-Stausee","Saas-Almagell","Switzerland","","",0, 6,5, "Lake", ['Hannsjoerg']])
data_list.append(["Seewjinengletscher","Saas-Allmagell","Switzerland","","",0, 2,1, "Glacier", ['Hannsjoerg']])
data_list.append(["Schwarzberggletscher","Saas-Allmagell","Switzerland","","",0, 13,1, "Glacier", ['Hannsjoerg']])
data_list.append(["Allalingletscher","Saas-Allmagell","Switzerland","","",0,51,1, "Glacier", ['Hannsjoerg']])
data_list.append(["Chessjengletscher","Saas-Fee","Switzerland","","",0,5,1, "Glacier", ['Hannsjoerg']])
data_list.append(["Hohlaubgletscher (Saas Fee)","Saas-Fee","Switzerland","","",0,23,1, "Glacier", ['Hannsjoerg']])
data_list.append(["Triftgletscher (Saas)","Saas-Grund","Switzerland","","",0,29,1, "Glacier", []])
data_list.append(["Fletschhorn","Saas-Fee","Switzerland","","",0,20,4, "Mountain Peak", ["Andrew","Hannsjoerg"]])
data_list.append(["Fletschhorngletscher","Saas-Fee","Switzerland","","",0,10,4, "Mountain Peak", ["Andrew","Hannsjoerg"]])
data_list.append(["Gruebuggletscher","Saas-Fee","Switzerland","","",0,10,4, "Mountain Peak", ["Andrew","Hannsjoerg"]])
data_list.append(["Feegletscher","Saas-Fee","Switzerland","","",0,222,1, "Glacier", ["Andrew","Hannsjoerg"]])
data_list.append(["Bidergletscher","Saas-Fee","Switzerland","","",0,6,1, "Glacier", []])
data_list.append(["Hohbalmgletscher","Saas-Fee","Switzerland","","",0,15,1, "Glacier", ["Andrew","Hannsjoerg"]])
data_list.append(["Hohlaubgletscher (Saas-Grund)","Saas-Grund","Switzerland","","",0,9,1, "Glacier", []])
data_list.append(["Alphubelgletscher","Zermatt","Switzerland","","",0, 6,1, "Glacier", ['Eric',"Heidrun",'Artur']])
data_list.append(["Mellichgletscher","Zermatt","Switzerland","","",0,8,1, "Glacier", ['Eric',"Heidrun",'Artur']])
data_list.append(["Langfluehgletscher","Zermatt","Switzerland","","",0, 2,1, "Glacier", ['Eric',"Heidrun",'Artur']])
data_list.append(["Stellisee","Zermatt","Switzerland","","",0, 9,5, "Lake", ["Christine","Janina","Chris B","Sam","Andres","Grace"]])
data_list.append(["Grindjisee","Zermatt","Switzerland","","",0, 4,5, "Lake", ["Christine","Janina","Chris B","Sam","Andres","Grace"]])
data_list.append(["Glacier d'Otemma","","Switzerland","","",0, 3,1, "Glacier", []])
data_list.append(["Wildstrubelgletscher","Leukerbad","Switzerland","","",0, 3,1, "Glacier", ['Hannsjoerg']])
data_list.append(["Breithorn (Blatten)","Blatten","Switzerland","Jungfrauregion","",0,5,1, "Mountain Peak", ['Janina']])
data_list.append(["Bietschorn","Zermatt","Switzerland","Jungfrauregion","",0,11,1, "Mountain Peak", ['Janina']])
data_list.append(["Liskamm","Zermatt","Switzerland","","",0,25,4, "Mountain Peak", ["Eric","Riju","Hannsjoerg"]])
data_list.append(["Breithorn","Zermatt","Switzerland","","",0,57,4, "Mountain Peak", ["Eric","Hannsjoerg",'Artur',"Heidrun"]])
data_list.append(["Castor & Pollux","Zermatt","Switzerland","","",0,15,4, "Mountain Peak", ["Eric","Riju","Hannsjoerg"]])
data_list.append(["Zwillingsgletscher","Zermatt","Switzerland","","",0,14,1, "Glacier", ["Eric","Riju","Hannsjoerg"]])
data_list.append(["Gornergletscher","Zermatt","Switzerland","","",0,65,1, "Glacier", ["Eric","Riju","Hannsjoerg"]])
data_list.append(["Grenzgletscher","Zermatt","Switzerland","","",0,58,1, "Glacier", ["Eric","Riju","Hannsjoerg"]])
data_list.append(["Furgggletscher","Zermatt","Switzerland","","",0,56,1, "Glacier", ["Eric","Manuel","Heidrun","Artur","Stani"]])
data_list.append(["Arbengletscher","Zermatt","Switzerland","","",0,13,1, "Glacier", ["Eric","Manuel","Heidrun","Artur","Stani"]])
data_list.append(["Furggghorn","Zermatt","Switzerland","","",0,22,4, "Mountain Peak", ["Eric","Manuel","Heidrun","Artur","Stani"]])
data_list.append(["Findelgletscher","Zermatt","Switzerland","","",0,26,1, "Glacier", ["Hannsjoerg","Christine","Janina","Chris B","Sam","Andres","Grace"]])
data_list.append(["Adlergletscher","Zermatt","Switzerland","","",0,19,1, "Glacier", ["Hannsjoerg","Christine","Janina","Chris B","Sam","Andres","Grace"]])
data_list.append(["Triftgletscher (Zermatt)","Zermatt","Switzerland","","",0,21,1, "Glacier", ["Riju","Hannsjoerg","Christine","Janina","Chris B","Sam","Andres","Grace"]])
data_list.append(["Kleinmatterhorngletscher","Zermatt","Switzerland","","",0,71,1, "Glacier", ["Eric","Heidrun",'Artur','Hannsjoerg']])
data_list.append(["Dent d'Herens","Zermatt","Switzerland","","",0,16,4, "Mountain Peak", ["Eric","Heidrun","Artur"]])
data_list.append(["Gh di Monte Tabel","Zermatt","Switzerland","","",0, 6,1, "Mountain Peak", ["Eric","Heidrun","Artur"]])
data_list.append(["Plateau Rosa","Zermatt","Switzerland","","",0,31,1, "Glacier", ["Eric","Heidrun",'Artur']])
data_list.append(["Plateau Breithorn","Zermatt","Switzerland","","",0,42,1, "Glacier", ["Eric","Heidrun",'Artur']])
data_list.append(["Theodulhorn","Zermatt","Switzerland","","",0,15,4, "Mountain Peak", ["Eric","Heidrun",'Artur','Hannsjoerg']])
data_list.append(["Oberer Theodulgletscher","Zermatt","Switzerland","","",0,70,1, "Glacier", ["Eric","Heidrun",'Artur','Hannsjoerg']])
data_list.append(["Unterer Thedulgletscher","Zermatt","Switzerland","","",0,94,1, "Glacier", ["Eric","Heidrun",'Artur','Hannsjoerg']])
data_list.append(["Monte Rosa Gletscher","Zermatt","Switzerland","","",0,20,1, "Glacier", ["Eric",'Hannsjoerg','Riju']])
data_list.append(["Monte Rosa","Zermatt","Switzerland","","",0,69,4, "Mountain Peak", ["Eric",'Hannsjoerg','Riju']])
data_list.append(["Schwaerzegletscher","Zermatt","Switzerland","","",0,25,1, "Glacier", ["Eric",'Hannsjoerg','Riju']])
data_list.append(["Rossbodegletscher","Fiesch","Switzerland","","",0,3,1, "Glacier", ["Eric",'Hannsjoerg','Riju']])
data_list.append(["Triftjigletscher (Stockhorn)","Zermatt","Switzerland","","",0, 8,1, "Glacier", ["Hannsjoerg","Christine","Janina","Chris B","Sam","Andres","Grace"]])
data_list.append(["Triftjigletscher (Breithorn)","Zermatt","Switzerland","","",0,16,1, "Glacier", ["Eric",'Hannsjoerg','Riju','Artur','Heidrun']])
data_list.append(["Breithorngletscher","Zermatt","Switzerland","","",0,17,1, "Glacier", ["Eric",'Hannsjoerg','Riju']])
data_list.append(["Bisgletscher","Zermatt","Switzerland","","",0, 31,1, "Glacier", ["Heidrun",'Artur',"Hannsjoerg","Christine","Janina","Chris B","Sam","Andres","Grace","Riju",'Eric',"David Y"]])
data_list.append(["Bruneggletscher","Zermatt","Switzerland","","",0, 5,1, "Glacier", ["Eric"]])
data_list.append(["Gornerschlucht","Zermatt","Switzerland","","",0,8,3, "Canyon", []])
data_list.append(["Gran Paradiso","Zermatt","Italy","","",0,12,4, "Mountain Peak", ["Eric",'Artur','Heidrun']])
data_list.append(["Gh Tribolazione","Zermatt","Italy","","",0,5,1, "Glacier", []])
data_list.append(["Grand Combin","Zermatt","Switzerland","","",0,31,4, "Mountain Peak", ["Eric",'Artur','Heidrun']])
data_list.append(["Glacier du Petit Combin","Verbier","Switzerland","","",0, 7,1, "Glacier", []])
data_list.append(["Glacier du Petit Montfort","Verbier","Switzerland","","",0, 7,1, "Glacier", []])
data_list.append(["Glacier des Ecoulaies","Hermence","Switzerland","","",0, 1,1, "Glacier", []])
data_list.append(["Grand Dessert","Verbier","Switzerland","","",0, 7,1, "Glacier", []])
data_list.append(["Glacier de Cheillon","Hermence","Switzerland","","",0, 7,1, "Glacier", []])
data_list.append(["Glacier des Follats","Verbier","Switzerland","","",0, 3,1, "Glacier", []])
data_list.append(["Glacier d'Orny'","Verbier","Switzerland","","",0, 1,1, "Glacier", []])
data_list.append(["Glacier de Tortin","Verbier","Switzerland","","",0, 10,1, "Glacier", []])
data_list.append(["Grotte de Fees","St Maurice","Switzerland","","",4, 18,8, "Cave", []])
data_list.append(["Lac Souterrain","St Leonhard","Switzerland","","",3, 47,8, "Cave", []])
data_list.append(["Grotte de l'Observatoire","Monaco","Monaco","","",0, 47,8, "Cave", []])
data_list.append(["Wutachschlucht","Wutach","Germany","","",0, 25,3, "Canyon", ["Artur","Heidrun","Anne-Kathrin",'Jan-Marc',"Hannsjoerg"]])
data_list.append(["Aareschlucht","Meiringen","Switzerland","","",0, 108,3, "Canyon", ["Hannsjoerg"]])
data_list.append(["Reichenbachfall","Meiringen","Switzerland","","",0, 25,2, "Waterfall", ["Hannsjoerg"]])
data_list.append(["Truemmelbacher Wasserfaelle","Stechelberg","Switzerland","Jungfrauregion","",0, 66,2, "Waterfall", ["Artur","Heidrun","Anne-Kathrin","Jan-Marc","Hannsjoerg","Andrew"]])
data_list.append(["Lago Maggiore","Ascona","Switzerland","","",0, 54,5, "Lake", []])
data_list.append(["Reichenbach","Rosenlaui","Switzerland","","",0, 4,7, "River", ["Artur","Heidrun","Anne-Kathrin","Hannsjoerg"]])
data_list.append(["Aare","Bern","Switzerland","","",0, 3,7, "River", []])
data_list.append(["Brienzer See","Bern","Switzerland","","",0, 25,5, "Lake", ['Hannsjoerg']])
data_list.append(["Giessbachfall","Bern","Switzerland","","",0, 49,2, "Waterfall", ["Hannsjoerg"]])
data_list.append(["Bluemlisalp","Kandersteg","Switzerland","Jungfrauregion","",0, 31,4, "Mountain Peak", ['Riju']])
data_list.append(["Bluemlisalpgletscher","Kandersteg","Switzerland","Jungfrauregion","",0, 9,1, "Glacier", ['Riju']])
data_list.append(["Oeschinensee","Kandersteg","Switzerland","Jungfrauregion","",0, 9,5, "Lake", ["Riju"]])
data_list.append(["Rosenlauischlucht","Rosenlaui","Switzerland","Jungfrauregion","",0, 50,3, "Canyon", ["Artur","Heidrun","Hannsjoerg"]])
data_list.append(["Bodensee","Reichenau","Germany","","",0,  23,5, "Lake", ["Artur","Heidrun","Anne-Kathrin","Jan-Marc","Hannsjoerg",'Vivan',"Dylan",'Sam','Grace']])
data_list.append(["Titisee","Titisee","Germany","","",0,  5,5, "Lake", ["Artur","Heidrun","Anne-Kathrin","Jan-Marc","Hannsjoerg",'Vivan',"Dylan",'Sam','Grace']])
data_list.append(["Windgfaellweiher","Lenzkirch","Germany","","",0,  5,5, "Lake", ["Artur","Heidrun","Anne-Kathrin","Jan-Marc","Hannsjoerg",'Vivan',"Dylan",'Sam','Grace']])
data_list.append(["Schluchsee","Schluchsee","Germany","","",0,  3,5, "Lake", ["Artur","Heidrun","Anne-Kathrin","Jan-Marc","Hannsjoerg",'Vivan',"Dylan",'Sam','Grace']])
data_list.append(["Donauauen","Wien","Austria","","Nationalpark Donauauen",0,  111,15, "Wetlands", []])
data_list.append(["Gollinger Wasserfall","Golling an der Salzach","Austria","","",0,  41,2, "Waterfall", []])
data_list.append(["Muehlbachfall","Hallstatt","Austria","Hallstatt Salzkammergut","",0,  19,2, "Waterfall", []])
data_list.append(["Waldbachstrub","Hallstatt","Austria","Hallstatt Salzkammergut","",0,  13,2, "Waterfall", []])
data_list.append(["Hallstaetter See","Hallstatt","Austria","Hallstatt Salzkammergut","",0,  65,5, "Lake", []])
data_list.append(["Myrafaelle","Muggendorf","Austria","","",0,  60,2, "Waterfall", []])
data_list.append(["Steinwandklamm","Furth an der Triesting","Austria","","",0,  48,3, "Canyon", []])
data_list.append(["Koppenbruellerhoehle","Obertraun","Austria","Hallstatt Salzkammergut","",4,  19,8, "Cave", []])
data_list.append(["Mammuthoehle","Obertraun","Austria","Hallstatt Salzkammergut","",5,  42,8, "Cave", []])
data_list.append(["Rieseneishoehle","Obertraun","Austria","Hallstatt Salzkammergut","",6,  58,8, "Cave", []])
data_list.append(["Hallstaetter Gletscher","Obertraun","Austria","Hallstatt Salzkammergut","",0,  8,1, "Glacier", []])
data_list.append(["Knoppenwinkelsee","Obertraun","Austria","Hallstatt Salzkammergut","",0, 8,5, "Lake", []])
data_list.append(["Neusiedler See","Rust am See","Austria","Neusiedler See","",0, 8,5, "Lake", []])
data_list.append(["Kitzlochklamm","Taxenbach","Austria","","",0,  84,3, "Canyon", []])
data_list.append(["Liechtensteinklamm","St Johann im Pongau","Austria","","",0,  100,3, "Canyon", []])
data_list.append(["Gainfeldwasserfall","Bischofshofen","Austria","","",0,  4,2, "Waterfall", []])
data_list.append(["Gasteiner Wasserfall","Bad Gastein","Austria","","",0,  67,2, "Waterfall", []])
data_list.append(["Durlassboden","Gerlos","Austria","","Hohe Tauern Nationalpark",0,  5,5, "Lake", ["Sam","Grace","Janina"]])
data_list.append(["Krimmler Wasserfall","Bad Gastein","Austria","","",0,  49,2, "Waterfall", ["Sam","Grace","Janina"]])
data_list.append(["Kamp","Rosenburg","Switzerland","","",0, 8,7, "River", []])
data_list.append(["Donau","Wien","Switzerland","","",0, 42,7, "River", []])
data_list.append(["Cliffs with Boca do Inferno","Cascais","Portugal","","",0, 41,10, "Coastal Cliff", []])
data_list.append(["Seven Sisters","Seaford","United Kingdom","","",0, 27,10, "Coastal Cliff", ['Heidrun','Hannsjoerg','Artur','Anne-Kathrin']])
data_list.append(["Cuckmere","Seaford","United Kingdom","","",0, 7,7, "River", ['Heidrun','Hannsjoerg','Artur','Anne-Kathrin']])
data_list.append(["Alum Bay & The Needles","Totland","United Kingdom","","",0, 102,10, "Coastal Cliff", ['Heidrun']])
data_list.append(["Carrick-a-Rede Coastline","Ballycastle","United Kingdom","","",0, 38,10, "Coastal Cliff", ['Chris M']])
data_list.append(["Giant's Causeway","Bushmills","United Kingdom","Giant's Causeway","",0, 42,23, "Basalt Columns", ['Chris M']])
data_list.append(["Scala dei Turchi","Realmonte","Italy","","",0, 27,10, "Coastal Cliff", ['Artur','Heidrun']])
data_list.append(["Port Noffer","Bushmills","United Kingdom","","",0, 7,10, "Coastal Cliff", ['Chris M']])
data_list.append(["Lac des Brenets","Les Brenets","Switzerland","","",0, 37,3, "Canyon", ['Sarah','Riju']])
data_list.append(["Creux du Van","Montalchez","Switzerland","","",0, 12,3, "Canyon", ['Bing','Manuel']])
data_list.append(["Jaunbachschlucht","Broc","Switzerland","","",0, 50,3, "Canyon", ['Heidrun','Artur']])
data_list.append(["Doubs","Villars-le-Lac","Switzerland","","",0, 35,7, "River", ['Sarah','Riju']])
data_list.append(["Saut de Doubs","Les Brenets","Switzerland","","",0, 25,2, "Waterfall", ['Sarah','Riju']])
data_list.append(["Lac Neuchatel","Neuchatel","Switzerland","","",0, 12,5, "Lake", ['Sarah','Riju']])
data_list.append(["Oldenhorn","Les-Diablerets","Switzerland","","",0, 7,4, "Mountain Peak", []])
data_list.append(["Glacier de Tsanfleuron","Les-Diablerets","Switzerland","","",0, 36,1, "Glacier", []])
data_list.append(["Glacier du Scex Rouge","Les-Diablerets","Switzerland","","",0, 7,1, "Glacier", []])
data_list.append(["Glacier de Prapio","Les-Diablerets","Switzerland","","",0, 4,1, "Glacier", []])
data_list.append(["Glacier de Corbassiere","Les-Diablerets","Switzerland","","",0, 18,1, "Glacier", []])
data_list.append(["Glacier de Diablerets","Les-Diablerets","Switzerland","","",0, 3,1, "Glacier", []])
data_list.append(["Diablerets","Les-Diablerets","Switzerland","","",0, 3,4, "Mountain Peak", []])

# %%
data_list.append(["Norris Geysers","West Yellowstone","USA","Yellowstone National Park","Yellowstone National Park",0, 34,17, "Geyser", ['Artur','Heidrun','Hannsjoerg']])
data_list.append(["Upper Geysers (with Old Faithful)","West Yellowstone","USA","Yellowstone National Park","Yellowstone National Park",0, 33,17, "Geyser", ['Artur','Heidrun','Hannsjoerg']])
data_list.append(["Lower Geysers","West Yellowstone","USA","Yellowstone National Park","Yellowstone National Park",0, 7,17, "Geyser", ['Artur','Heidrun','Hannsjoerg']])
data_list.append(["West Thumb Geysers","Lake Village","USA","Yellowstone National Park","Yellowstone National Park",0, 31,17, "Geyser", ['Artur','Heidrun','Hannsjoerg']])
data_list.append(["Madison River","West Yellowstone","USA","Yellowstone National Park","Yellowstone National Park",0, 6,7, "River", ['Artur','Heidrun','Hannsjoerg']])
data_list.append(["Yellowstone River","Canyon Village","USA","Yellowstone National Park","Yellowstone National Park",0, 24,7, "River", ['Artur','Heidrun','Hannsjoerg']])
data_list.append(["Yellowstone Lake","Canyon Village","USA","Yellowstone National Park","Yellowstone National Park",0, 5,5, "Lake", ['Artur','Heidrun','Hannsjoerg']])
data_list.append(["Mammoth Hot Springs","Gardiner","USA","Yellowstone National Park","Yellowstone National Park",0, 60,22, "Natural Terrace", ['Artur','Heidrun','Hannsjoerg']])
data_list.append(["Yellowstone Canyon","Canyon Village","USA","Yellowstone National Park","Yellowstone National Park",0, 43,3, "Canyon", ['Artur','Heidrun','Hannsjoerg']])
data_list.append(["Yellowstone Upper Falls","Canyon Village","USA","Yellowstone National Park","Yellowstone National Park",0, 6,2, "Waterfall", ['Artur','Heidrun','Hannsjoerg']])
data_list.append(["Yellowstone Lower Falls","Canyon Village","USA","Yellowstone National Park","Yellowstone National Park",0, 10,2, "Waterfall", ['Artur','Heidrun','Hannsjoerg']])
data_list.append(["Mesa Falls","Ashton","USA","","",0, 15,2, "Waterfall", ['Artur','Heidrun','Hannsjoerg']])
data_list.append(["Mud Volcano","West Yellowstone","USA","Yellowstone National Park","Yellowstone National Park",0, 30,16, "Volcano", ['Artur','Heidrun','Hannsjoerg']])
data_list.append(["Shoshone Falls","Twin Falls","USA","","",0, 21,2, "Waterfall", ['Artur','Heidrun','Hannsjoerg']])
data_list.append(["Snake River Canyon","Twin Falls","USA","","",0, 24,3, "Canyon", ['Artur','Heidrun','Hannsjoerg']])
data_list.append(["Bruneau Dunes","Bruneau","USA","","Bruenau Dunes State Park",0, 20,14, "Sand Dune", ['Artur','Heidrun','Hannsjoerg']])
data_list.append(["Craters of the Moon","Arco","USA","","Craters of the Moon National Monument",0, 102,16, "Volcano", ['Artur','Heidrun','Hannsjoerg']])
data_list.append(["Firehole Canyon","West Yellowstone","USA","Yellowstone National Park","Yellowstone National Park",0, 12,3, "Canyon", ['Artur','Heidrun','Hannsjoerg']])
data_list.append(["Yellowstone Caldera","West Yellowstone","USA","Yellowstone National Park","Yellowstone National Park",1, 47,16, "Volcano", ['Artur','Heidrun','Hannsjoerg']])
data_list.append(["Grand Teton Mountain Range","Jackson","USA","","Grand Teton National Park",1, 55,6, "Mountain Range", ['Artur','Heidrun','Hannsjoerg']])
data_list.append(["Snake River","Jackson","USA","","Grand Teton National Park",0, 10,7, "River", ['Artur','Heidrun','Hannsjoerg']])
data_list.append(["Jenny Lake","Jackson","USA","","Yellowstone National Park",0, 9,5, "Lake", ['Artur','Heidrun','Hannsjoerg']])
data_list.append(["Hidden Falls","Jackson","USA","","",0, 11,2, "Waterfall", ['Artur','Heidrun','Hannsjoerg']])
data_list.append(["Vatnajoekuell","","Iceland","Vatnajoekuell","",0, 1,1, "Glacier", []])
data_list.append(["Langjoekuell","","Iceland","Vatnajoekuell","",0, 8,1, "Glacier", []])
data_list.append(["Eriksjoekuell","","Iceland","Vatnajoekuell","",0, 4,1, "Glacier", []])
data_list.append(["Groenland Eisschild","Greenland","Denmark","","",0, 28,1, "Glacier", []])
data_list.append(["Great Salt Lake","Utah","USA","","",0, 23,5, "Lake", ["Artur","Heidrun","Hannsjoerg"]])
data_list.append(["Wiggenberg","Lauchringen","Germany","","",0, 25,13, "Forest", ['Artur','Heidrun','Hannsjoerg','Anne-Kathrin','Jan-Marc']])
data_list.append(["Vitibuck","Tiengen","Germany","","",0, 35,13, "Forest", ['Artur','Heidrun','Hannsjoerg','Anne-Kathrin','Jan-Marc']])
data_list.append(["Reiherwald","Lauchringen","Germany","","",0, 15,13, "Forest", ['Artur','Heidrun','Hannsjoerg','Anne-Kathrin','Jan-Marc']])
data_list.append(["Steinaschlucht","Lauchringen","Germany","","",0, 90,3, "Canyon", ["Artur"]])
data_list.append(["Kotbach","Lauchringen","Germany","","",0, 5,7, "River", ["Franziksa",'Julius','Felicitas','Artur','Heidrun','Hannsjoerg','Anne-Kathrin','Jan-Marc']])
data_list.append(["Wutach","Lauchringen","Germany","","",0, 93,7, "River", ["Franziksa",'Julius','Felicitas','Artur','Heidrun','Hannsjoerg','Anne-Kathrin','Jan-Marc']])
data_list.append(["Steina","Tiengen","Germany","","",0, 47,7, "River", ['Artur','Heidrun','Hannsjoerg','Anne-Kathrin','Jan-Marc']])
data_list.append(["Lauffen (Lauchringen)","Lauchringen","Germany","","",0, 82,2, "Waterfall", ['Artur','Heidrun','Hannsjoerg','Anne-Kathrin','Jan-Marc']])
data_list.append(["Aachtopf","Aach","Germany","","",0, 7,26, "Spring", ['Artur','Heidrun','Hannsjoerg','Anne-Kathrin','Jan-Marc']])
data_list.append(["Haselbachfall","Indlekofen","Germany","","",0, 5,2, "Waterfall", ["Artur"]])
data_list.append(["Schluechtsee","Grafenhausen","Germany","","",0, 5,5, "Lake", ['Artur','Heidrun','Hannsjoerg','Anne-Kathrin','Jan-Marc']])
data_list.append(["Schluecht","Tiengen","Germany","","",0, 7,7, "River", ['Artur','Heidrun','Hannsjoerg','Anne-Kathrin','Jan-Marc']])
data_list.append(["Oberer Donaudurchbruch","Beuron","Germany","","",0, 71,3, "Canyon", ["Artur","Heidrun"]])
data_list.append(["Menzenschwander Wasserfaelle","Menzenschwand","Germany","","",0, 28,2, "Waterfall", ["Artur"]])
data_list.append(["Todtnauer Wasserfall","Todtnau","Germany","","",0, 42,2, "Waterfall", ["Artur"]])
data_list.append(["Ravennaschlucht","Breitnau","Germany","","",0, 72,3, "Canyon", ["Artur",'Heidrun',"Hannsjoerg"]])
data_list.append(["Hoellbach Wasserfaelle","Goerwihl","Germany","","",0, 24,2, "Waterfall", ["Artur"]])
data_list.append(["Muehlbachschlucht","Tengen","Germany","","",0, 21,3, "Canyon", ["Artur"]])
data_list.append(["Triberger Wasserfaelle","Triberg","Germany","","",0, 34,2, "Waterfall", ["Artur"]])
data_list.append(["Schleifenbach Wasserfaelle","Blumberg","Germany","","",0, 12,2, "Waterfall", ["Artur"]])
data_list.append(["Dampfkessel","Grimmelshofen","Germany","","",0, 14,2, "Waterfall", ["Artur"]])
data_list.append(["Kaiserstuhl","Bickensohl","Germany","","",0, 24,29, "Vineyards", ["Artur"]])
data_list.append(["Grotte du Cerdon","Labalme","France","","",0, 74,8, "Cave", ["Sasha","Tema"]])
data_list.append(["Grottes de La Balme","La Balme-les-Grottes","France","","",2, 109,8, "Cave", ["Sasha","Tema"]])
data_list.append(["Gorges de Thurignin","Belmont-Luthezieu","France","","",0, 15,3, "Canyon", ['Sasha']])
data_list.append(["Gorge du Durnand","Bovernier","Switzerland","","",0, 92,3, "Canyon", ['Hannsjoerg']])
data_list.append(["Source de Groin","Vieu","France","","",0, 12,26, "Spring", ['Sasha']])
data_list.append(["Puits des Tines","Champagne-en-Valromey","France","","",0, 3,2, "Waterfall", ['Sasha']])
data_list.append(["Pain de Sucre","Champagne-en-Valromey","France","","",0, 7,2, "Waterfall", ['Sasha']])
data_list.append(["Pain de Sucre","Surjoux","France","","",0, 5,2, "Waterfall", ['Sasha']])
data_list.append(["Vesuv","Octaviano","Italy","","",0, 26,16, "Volcano", ["AJ","Stephan",'Riju']])
data_list.append(["Somma","Octaviano","Italy","","",0, 3,16, "Volcano", ["AJ","Stephan"]])
data_list.append(["Solfatara","Pozzuoli","Italy","","",0, 33,16, "Volcano", ["AJ","Stephan"]])
data_list.append(["Aetna","Nicolosi","Italy","Mount Etna","",0, 51,16, "Volcano", ["Artur","Heidrun"]])
data_list.append(["Fujisan","Fuji","Japan","Fujisan","",0, 3,16, "Volcano", []])
data_list.append(["Schlucht von Matera","Matera","Italy","Matera","",0, 8,3, "Canyon", ['Heidrun','Artur']])
data_list.append(["Grotte di Castellana","Castellana Grotte","Italy","","",0, 56,8, "Cave", ['Heidrun','Artur']])
data_list.append(["Amalfi Kueste","Amalfi","Italy","Amalfi Coast","",0, 76,10, "Coastal Cliff", ['Heidrun','Artur','Riju']])
data_list.append(["Cinque Terre","Manarola","Italy","Cinque Terre","",0, 73,10, "Coastal Cliff", ['Amin']])
data_list.append(["Monte Nuovo","Lucrino","Italy","","",0, 4,16, "Volcano", ["Artur"]])
data_list.append(["Monte Gauro","Pozzuoli","Italy","","",0, 4,16, "Volcano", ["Artur","Heidrun"]])
data_list.append(["Lago di Orta","Orta San Giulio","Italy","","",0, 8,5, "Lake", []])
data_list.append(["Grotte de Fees","Vallorbe","Switzerland","","",1,11,8, "Cave", ['Heidrun','Artur','Hannsjoerg']])
data_list.append(["Grottes de Vallorbe","Vallorbe","Switzerland","","",1,153,8, "Cave", ['Heidrun','Artur','Hannsjoerg','Christian',"Anne-Kathrin"]])
data_list.append(["Groges de Langouette","La Planches-en-Montagne","France","","",0, 30,3, "Canyon", ['Sasha','Juno']])
data_list.append(["Pertes de l'Ain","Bourg-de-Sirod","France","","",0, 55,3, "Canyon", ['Sasha','Juno']])
data_list.append(["Gorges du Fier","Lovagny","France","","",0, 42,3, "Canyon", ['Andrew']])
data_list.append(["Mer de Rochers","Lovagny","France","","",0, 33,3, "Canyon", ['Andrew']])
data_list.append(["Pertes de la Valserine","Bellegarde-sur-Valserine","France","","",0, 24,3, "Canyon", ['Sasha','Juno']])
data_list.append(["Gorge de l'Areuse","Boudry","France","","",0, 102,3, "Canyon", ['Christine',"Sam",'Dylan','Vivan','Will','Grace']])
data_list.append(["Weinberge","Boudry","France","","",0, 7,29, "Vineyards", ['Christine',"Sam",'Dylan','Vivan','Will','Grace']])
data_list.append(["Schwarzenbachfall","Baar","Switzerland","","",0, 8,2, "Waterfall", ['Namrata']])
data_list.append(["Schwarzwald","Hoechenschwand","Germany","","",0, 29,13, "Forest", ['Artur']])
data_list.append(["Todtmooser Wasserfall","Hoechenschwand","Germany","","",0, 27,2, "Waterfall", ['Artur']])
data_list.append(["Hoellgrotten","Baar","Switzerland","","",1, 42,8, "Cave", ['Namrata']])
data_list.append(["Klingenbachschlucht","Oehningen","Germany","","",0, 12,3, "Canyon", ['Artur']])
data_list.append(["Hoewenegg","Immendingen","Germany","","",0, 10,16, "Volcano", ["Artur"]])
data_list.append(["Hohenkraehen","Hilzingen","Germany","","",0, 5,16, "Volcano", ["Artur"]])
data_list.append(["Lago Albano","Castel Gandolfo","Italy","","",0, 3,16, "Volcano", []])
data_list.append(["Hintertuxer Wasserfall","Hintertux","Austria","","",0, 31,2, "Waterfall", [""]])
data_list.append(["Hintertuxer Gletscher","Hintertux","Austria","","",0, 49,1, "Glacier", ["Heidrun"]])
data_list.append(["Schwarzbrunnerkees","Hintertux","Austria","","",0, 6,1, "Glacier", ["Heidrun"]])
data_list.append(["Schwarzsteinkees","Hintertux","Austria","","",0, 4,1, "Glacier", ["Heidrun"]])
data_list.append(["Schlegeiskees","Hintertux","Austria","","",0, 4,1, "Glacier", ["Heidrun"]])
data_list.append(["Cascata della Marmore","Marmore","Italy","","",0, 113,2, "Waterfall", [""]])
data_list.append(["Val d'Orcia","Pienza","Italy","Val d'Orcia","",0, 44,29, "Fields", [""]])
data_list.append(["Wattenmeer","Norddeich","Germany","Wadden Sea of the Northern Sea","",0, 27,31, "Tidal Sea", ["Grace"]])
data_list.append(["Vierwaldstaedter See","Luzern","Switzerland","","",0, 44,5, "Lake", ["Hannsjoerg","Heidrun",'Artur','Anne-Kathrin','Rachel','Riju','Chris B']])
data_list.append(["Zuerichsee","","Switzerland","","",0, 2,5, "Lake", []])
data_list.append(["Zuger See","","Switzerland","","",0, 6,5, "Lake", ["Rachel","Riju",'Chris B','Namrata']])
data_list.append(["Rigi","Kuessnacht","Switzerland","","",0, 8,4, "Mountain Peak", ["Rachel","Riju",'Chris B']])
data_list.append(["Lauerzer See","Schwyz","Switzerland","","",0, 2,5, "Lake", ["Rachel","Riju",'Chris B']])
data_list.append(["Wasserfall","Lillaz","Italy","","",0, 35,2, "Waterfall", ["Sasha",'Andres','Chris B','Yaroslava']])
data_list.append(["Cascate del Rutor","La Thuile","Italy","","",0, 19,2, "Waterfall", ["Sasha",'Andres','Chris B','Yaroslava']])
data_list.append(["Langgletscher","Blatten","Switzerland","Jungfrauregion","",0, 47,1, "Glacier", ['Janina']])
data_list.append(["Loibinbachgletscher","Blatten","Switzerland","Jungfrauregion","",0, 3,1, "Glacier", ['Janina']])
data_list.append(["Jegigletscher","Blatten","Switzerland","Jungfrauregion","",0, 23,1, "Glacier", ['Janina']])
data_list.append(["Talgletscher","Blatten","Switzerland","Jungfrauregion","",0, 2,1, "Glacier", ['Janina']])
data_list.append(["Dischliggletscher","Blatten","Switzerland","Jungfrauregion","",0, 6,1, "Glacier", ['Janina']])
data_list.append(["Lonza","Blatten","Switzerland","Jungfrauregion","",0, 19,7, "River", ['Janina']])
data_list.append(["Lac de Moiry","Moiry","Switzerland","","",0, 6,5, "Lake", ["Tema","Elga",'Juno','Sasha']])
data_list.append(["Lac de Chateaupre","Moiry","Switzerland","","",0, 7,5, "Lake", ["Tema","Elga",'Juno','Sasha']])
data_list.append(["Glacier de Moiry","Moiry","Switzerland","","",0,44,1, "Glacier", ["Tema","Elga",'Juno','Sasha']])
data_list.append(["Elbsandsteingebirge","Lohmen","Germany","","",0,37,19, "Rock Formations", ['Artur']])
data_list.append(["Elbe","Lohmen","Germany","","",0,4,7, "River", ['Artur']])
data_list.append(["West Lake","Hangzhou","China","West Lake","",0, 30,5, "Lake", []])
data_list.append(["Purple Mountain","Nanjing","China","","",0, 9,13, "Forest", []])
data_list.append(["Reykjavik Bay","Reykjavik","Iceland","","",0, 21,32, "Bay", ['Riju','Rachel','Reyer']])
data_list.append(["Seljalandsfoss","","Iceland","","",0, 18,2, "Waterfall", ['Riju','Rachel','Reyer']])
data_list.append(["Skogafoss","Vik i Myrdal","Iceland","","",0, 11,2, "Waterfall", ['Riju','Rachel','Reyer']])
data_list.append(["Black Sand Beach","Vik i Myrdal","Iceland","","",0, 24,11, "Beach", ['Riju','Rachel','Reyer']])
data_list.append(["El Sardinero","Santander","Spain","","",0, 10,11, "Beach", []])
data_list.append(["Lido Azzuro","Lido di Ostia","Italy","","",0, 10,12, "Beach", ['Heidrun']])
data_list.append(["Villa Gregoriana","Tivoli","Italy","","",0, 66,2, "Waterfall", ["Heidrun","Bryan"]])
data_list.append(["El Castillo and Las Modenas Caves","Puente Viesdo","Spain","Cave Art of Cantabria","",0, 16,8, "Caves", []])
data_list.append(["Erdmannshoehle","Haslach","Germany","","",0, 25,8, "Caves", ["Artur",'Hannsjoerg','Heidrun','Anne-Kathrin','Jan-Marc']])
data_list.append(["Solheimajoekull","Vik i Myrdal","Iceland","","",0, 106,1, "Glacier", ['Riju','Rachel','Reyer']])
data_list.append(["Hafnarfjoerthur Lavahoehle","","Iceland","","",0, 35,18, "Lava Cave", ['Riju','Rachel','Reyer']])
data_list.append(["Grotta dei tre Livelli","Niccolosi","Italy","Mount Etna","",0, 8,18, "Lava Cave", ['Artur','Heidrun']])
data_list.append(["Thingvellir Nationalpark","","Iceland","","",0, 44,0, "Continental Divide", ['Riju','Rachel','Reyer']])
data_list.append(["Geyser & Strokkur area","","Iceland","","",0, 33,17, "Geyser", ['Riju','Rachel','Reyer']])
data_list.append(["Donaudurchbruch","Kehlheim","Germany","","",0, 66,3, "Canyon", ['Reyer','Chris B']])
data_list.append(["Poellatschlucht","Schwangau","Germany","","",0, 8,3, "Canyon", ['Reyer','Chris B','Hannsjoerg','Indara','Eric']])
data_list.append(["Lechklamm","Schwangau","Germany","","",0, 11,3, "Canyon", ['Indara','Eric','Hannsjoerg']])
data_list.append(["Partnachklamm","Schwangau","Germany","","",0, 39,3, "Canyon", ['Indara','Eric']])
data_list.append(["Nationalpark Hainich","Schoenstedt","Germany","Beech Forrests","Nationalpark Hainich",0, 16,13, "Forrest", ['Reyer','Chris B']])
data_list.append(["Pissevache","Vernayaz","Switzerland","","",0, 41,2, "Waterfall", ['Hannsjoerg','Heidrun','Artur']])
data_list.append(["Churfirsten","Quinten","Switzerland","","",0, 30,6, "Mountain Range", ['Juno']])
data_list.append(["Alpstein","Wasserauen","Switzerland","","",0, 133,6, "Mountain Range", ['Juno']])
data_list.append(["Saentis","Wasserauen","Switzerland","","",0, 14,4, "Mountain Peak", ['Juno']])
data_list.append(["Seealpsee","Wasserauen","Switzerland","","",0, 22,5, "Lake", ['Juno']])
data_list.append(["Ringquelle","Betlis","Switzerland","","",0, 6,2, "Waterfall", ['Juno']])
data_list.append(["Wildkirchlihoehle","Wasserauen","Switzerland","","",5, 7,8, "Cave", ['Juno']])
data_list.append(["Walensee","Quinten","Switzerland","","",0, 47,5, "Lake", ['Juno']])
data_list.append(["Rosegggletscher","Pontresina","Switzerland","Jungfrauregion","",0, 3,1, "Glacier", []])
data_list.append(["Gaerstenhoerner","Gutannen","Switzerland","","",0, 2,4, "Mountain Peak", []])
data_list.append(["Alpligletscher","Pontresina","Switzerland","","",0, 6,1, "Glacier", []])
data_list.append(["Sidelengletscher","Realp","Switzerland","","",0, 2,1, "Glacier", []])
data_list.append(["Galengletscher","Realp","Switzerland","","",0, 9,1, "Glacier", []])
data_list.append(["Sidelenhorn","Realp","Switzerland","","",0, 2,4, "Mountain Peak", []])
data_list.append(["Galenstock","Realp","Switzerland","","",0, 9,4, "Mountain Peak", []])
data_list.append(["Muttgletscher","Realp","Switzerland","","",0, 3,1, "Glacier", []])
data_list.append(["Raeterichsbodensee","Gutannen","Switzerland","","",0, 7,5, "Lake", []])
data_list.append(["Grimselsee","Gutannen","Switzerland","","",0, 5,5, "Lake", []])
data_list.append(["Triebtensee","Gutannen","Switzerland","","",0, 2,5, "Lake", []])
data_list.append(["Totensee","Gutannen","Switzerland","","",0, 7,5, "Lake", []])
data_list.append(["Rhonegletscher","Oberwald","Switzerland","","",0, 53,1, "Glacier", []])
data_list.append(["Minstigergletscher","Oberwald","Switzerland","Jungfrauregion","",0, 2,1, "Glacier", []])
data_list.append(["Lauteraargletscher","Gutannen","Switzerland","Jungfrauregion","",0, 9,1, "Glacier", []])
data_list.append(["Unteraargletscher","Gutannen","Switzerland","Jungfrauregion","",0, 9,1, "Glacier", []])
data_list.append(["Oberaargletscher","Gutannen","Switzerland","Jungfrauregion","",0, 8,1, "Glacier", []])
data_list.append(["Finsteraargletscher","Gutannen","Switzerland","Jungfrauregion","",0, 3,1, "Glacier", []])

# %%
data_list.append(["Lake Mead","Boulder","USA","","",0, 4,5, "Lake", ['Heidrun','Artur','Hannsjoerg']])
data_list.append(["Grand Canyon","Grand Canyon Village","USA","Grand Canyon","",0, 265,3, "Canyon", ['Heidrun','Artur','Hannsjoerg']])
data_list.append(["Little Colorado River Gorge","Cameron","USA","","",0, 16,3, "Canyon", ['Heidrun','Artur','Hannsjoerg']])
data_list.append(["Horseshoe Bend","Page","USA","","",0, 12,3, "Canyon", ['Heidrun','Artur','Hannsjoerg']])
data_list.append(["Upper Antelope Canyon","Page","USA","","",0, 101,3, "Canyon", ['Heidrun','Artur','Hannsjoerg']])
data_list.append(["Monument Valley","Oljato Monument Valley","USA","","",0, 138,19, "Rock Formations", ['Heidrun','Artur','Hannsjoerg']])
data_list.append(["Goosenecks State Park","Mexican Hat","USA","","",0, 10,3, "Canyon", ['Heidrun','Artur','Hannsjoerg']])
data_list.append(["Mesa Verde National Park","Cortez","USA","Mesa Verde National Park","",0, 25,3, "Canyon", ['Heidrun','Artur','Hannsjoerg']])
data_list.append(["Arches National Park","Moab","USA","","Arches National Park",0, 119,9, "Arches", ['Heidrun','Artur','Hannsjoerg']])
data_list.append(["Colorado River Canyon","Moab","USA","","",0, 4,3, "Canyon", ['Heidrun','Artur','Hannsjoerg']])
data_list.append(["Eagle Canyon","San Rafael","USA","","",0, 9,3, "Canyon", ['Heidrun','Artur','Hannsjoerg']])
data_list.append(["Red Canyon","Garfield","USA","","",0, 7,3, "Canyon", ['Heidrun','Artur','Hannsjoerg']])
data_list.append(["Bryce Canyon","Bryce Canyon City","USA","","Bryce Canyon National Park",0, 159,3, "Canyon", ['Heidrun','Artur','Hannsjoerg']])
data_list.append(["Zion Canyon","Springdale","USA","","Zion Canyon National Park",0, 136,3, "Canyon", ['Heidrun','Artur','Hannsjoerg']])
data_list.append(["Canyonlands National Park","","USA","","Canyonlands National Park",0, 6,3, "Canyon", ['Heidrun','Artur']])
data_list.append(["Lassinggraben","Annaberg bei Mariazell","Austria","","Naturpark Oetscher-Tormaeuer",0, 31,3, "Canyon", []])
data_list.append(["Oetschergraeben","Mitterbach am Erlaufsee","Austria","","Naturpark Oetscher-Tormaeuer",0, 135,3, "Canyon", []])
data_list.append(["Erlaufstausee","Mitterbach am Erlaufsee","Austria","","",0, 4,5, "Lake", []])
data_list.append(["Gorge du Trient","Vernayaz","Switzerland","","",0, 22,3, "Canyon", ["Hannsjoerg"]])
data_list.append(["Feldberg","Feldberg","Germany","","",0, 17,3, "Mountain Peak", ["Hannsjoerg","Heidrun",'Artur']])
data_list.append(["Feldsee","Feldberg","Germany","","",0, 10,5, "Lake", ["Hannsjoerg","Heidrun",'Artur']])
data_list.append(["Cueva del Nerja","Maro","Spain","","",0,  76,8, "Cave", []])
data_list.append(["Palvoelgy Cave","Budapest","Hungary","","",0,  71,8, "Cave", ['Chris M']])
data_list.append(["Szemlohegy Cave","Budapest","Hungary","","",0,  58,8, "Cave", ['Chris M']])
data_list.append(["Faraglioni","Capri","Italy","","",0, 7,16, "Coastal Cliff", ['Riju']])
data_list.append(["Gesaeuse","Admont","Austria","Nationalpark Gesaeuse","",0, 74,3, "Canyon", []])
data_list.append(["Hartelsbachgraben","Admont","Austria","Nationalpark Gesaeuse","",0, 44,3, "Canyon", []])
data_list.append(["Johnsbachschlucht","Admont","Austria","Nationalpark Gesaeuse","",0, 6,3, "Canyon", []])


#1995-2021 all in

df = pd.DataFrame(data_list,columns=['Natural Site', 'Place', 'Country','UNESCO World Heritage Site','National/Nature/State Park',"finer type category",'Picture Count','Nature Type',"Nature Type Name","Co-Travellers"])

df["Number of Co-Travellers"]=df["Co-Travellers"].str.len()


df.to_csv("data/picture_data_natural_places.csv")

# %%
df.sort_values(by="Picture Count",ascending=False).reset_index(drop=True).head(50)
# Out:
#                                          Natural Site  \
# 0                                  Glacier de Bossons
# 1                                    Aletschgletscher
# 2                                        Grand Canyon
# 3                                        Feegletscher
# 4                                        Jungfraufirn
# 5                                        Mer de Glace
# 6   Grindelwald-Fieschergletscher & Unterer Grinde...
# 7                                           Rheinfall
# 8                                        Bryce Canyon
# 9                                 Grottes de Vallorbe
# 10                                         Matterhorn
# 11                                    Monument Valley
# 12                                        Zion Canyon
# 13                                    Oetschergraeben
# 14                                           Alpstein
# 15                               Arches National Park
# ...

# %%
print(len(df),len(df.loc[df["Number of Co-Travellers"]==0])/len(df))
df.sort_values (by="Number of Co-Travellers",ascending=False).head(25)
# Out:
# 479 0.22129436325678498
#             Natural Site        Place      Country UNESCO World Heritage Site  \
# 111           Mont Blanc     Chamonix       France
# 35           Aletschhorn       Fiesch  Switzerland             Jungfrauregion
# 137           Matterhorn      Zermatt  Switzerland
# 93    Glacier de Bossons     Chamonix       France
# 20      Aletschgletscher  Fieschertal  Switzerland             Jungfrauregion
# 156  Tiefmattengletscher      Zermatt  Switzerland
# 155     Stockjigletscher      Zermatt  Switzerland
# 47        Ewigschneefeld  Fieschertal  Switzerland             Jungfrauregion
# 46          Jungfraufirn  Fieschertal  Switzerland             Jungfrauregion
# 117       Dome du Gouter     Chamonix       France
# 44              Trugberg  Fieschertal  Switzerland             Jungfrauregion
# 45                Sphinx  Fieschertal  Switzerland             Jungfrauregion
# 145            Weisshorn      Zermatt  Switzerland
# ...
