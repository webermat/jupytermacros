# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime

# %%
#night stay, for train/car rides the night stayed before
#for flight in airport city of flight 

#originally planned to set index to date, but considering we have two sites per data that is not possible
data_list=[]

#TripDestinationCloser
#-1 if Destination and Origin are the same, 1 if Destination is closer, 0 if Origin is closer
#FlightFlag 0 both of them reached without flight 1 if flight from Origin, 2 if flight to Destination

#1983
#data_list.append([datetime.datetime(1983, 7, 24),"Loerrach","Germany","Lauchringen",0,1,['Artur',"Heidrun","Jan-Marc"]])
#data_list.append([datetime.datetime(1983, 7, 30),"Schaffhausen","Switzerland","Lauchringen",0,1,['Artur',"Heidrun","Jan-Marc"]])
#data_list.append([datetime.datetime(1983, 7, 31),"Rigi","Switzerland","Lauchringen",0,1,['Artur',"Heidrun","Jan-Marc"]])
#data_list.append([datetime.datetime(1983, 8, 3),"Basel","Switzerland","Lauchringen",0,1,['Artur',"Heidrun","Jan-Marc"]])
#data_list.append([datetime.datetime(1983, 8, 16),"Rust","Germany","Lauchringen",0,1,['Artur',"Heidrun","Jan-Marc"]])
#data_list.append([datetime.datetime(1983, 9, 28),"Schluchsee","Germany","Lauchringen",0,1,['Artur',"Heidrun","Jan-Marc"]])
#1984
#data_list.append([datetime.datetime(1984, 8, 18),"Koblenz","Switzerland","Lauchringen",0,1,['Artur',"Heidrun","Jan-Marc",'Anne-Kathrin']])
#data_list.append([datetime.datetime(1984, 8, 21),"Basel","Switzerland","Lauchringen",0,1,['Artur',"Heidrun","Jan-Marc",'Anne-Kathrin']])
#data_list.append([datetime.datetime(1984, 8, 29),"Bechtersbohl","Germany","Lauchringen",0,1,['Artur',"Heidrun","Jan-Marc",'Anne-Kathrin']])
#1985
#data_list.append([datetime.datetime(1985, 5, 26),"Zurich","Switzerland","Lauchringen",0,1,['Artur',"Heidrun","Jan-Marc",'Anne-Kathrin']])
#data_list.append([datetime.datetime(1985, 5, 26),"Konstanz","Germany,"Lauchringen",0,1,['Artur',"Heidrun","Jan-Marc",'Anne-Kathrin']])
#data_list.append([datetime.datetime(1985, 8, 17),"Basel","Switzerland,"Lauchringen",0,1,['Artur',"Heidrun","Jan-Marc",'Anne-Kathrin']])
#1986
#data_list.append([datetime.datetime(1986, 7, 27),"Titisee","Germany,"Lauchringen",0,1,['Artur',"Heidrun","Jan-Marc",'Anne-Kathrin']])
#data_list.append([datetime.datetime(1986, 10, 4),"Grafenhausen","Germany,"Lauchringen",0,1,['Artur','Hannsjoerg',"Heidrun","Jan-Marc",'Anne-Kathrin']])
#1987
#data_list.append([datetime.datetime(1987, 1, 6),"Dielsdorf","Switzerland,"Lauchringen",0,1,['Artur','Hannsjoerg',"Heidrun","Jan-Marc",'Anne-Kathrin']])
#data_list.append([datetime.datetime(1987, 3, 7),"Zurzach","Switzerland,"Lauchringen",0,1,['Artur','Hannsjoerg',"Heidrun","Jan-Marc",'Anne-Kathrin']])
#data_list.append([datetime.datetime(1987, 3, 15),"Schaffhausen","Switzerland,"Lauchringen",0,1,['Artur','Hannsjoerg',"Heidrun","Jan-Marc",'Anne-Kathrin']])
#data_list.append([datetime.datetime(1987, 8, 17),"Basel","Switzerland,"Lauchringen",0,1,['Artur','Hannsjoerg',"Heidrun","Jan-Marc",'Anne-Kathrin']])
#data_list.append([datetime.datetime(1987, 8, 29),"Grafenhausen","Switzerland,"Lauchringen",0,1,['Artur','Hannsjoerg',"Heidrun","Jan-Marc",'Anne-Kathrin']])
#data_list.append([datetime.datetime(1987, 8, 30),"Loeffingen","Switzerland,"Lauchringen",0,1,['Artur','Hannsjoerg',"Heidrun","Jan-Marc",'Anne-Kathrin']])

#data_list.append([datetime.datetime(1987, 10, 26),"Bad Ragaz","Switzerland,"Flumserberg",0,0,['Artur','Hannsjoerg',"Heidrun","Jan-Marc",'Anne-Kathrin']])
#data_list.append([datetime.datetime(1987, 10, 28),"Sargans","Switzerland,"Flumserberg",0,0,['Artur','Hannsjoerg',"Heidrun","Jan-Marc",'Anne-Kathrin']])
#data_list.append([datetime.datetime(1987, 10, 29),"Marienfeld","Switzerland,"Flumserberg",0,0,['Artur','Hannsjoerg',"Heidrun","Jan-Marc",'Anne-Kathrin']])

#data_list.append([datetime.datetime(1988, 7, 5),"Reichenau","Germany,"Horn",0,0,['Artur','Hannsjoerg',"Heidrun","Jan-Marc",'Anne-Kathrin']])
#data_list.append([datetime.datetime(1988, 7, 9),"Aach","Germany,"Horn",0,0,['Artur','Hannsjoerg',"Heidrun","Jan-Marc",'Anne-Kathrin']])
#data_list.append([datetime.datetime(1988, 7, 12),"Mainau","Germany,"Horn",0,0,['Artur','Hannsjoerg',"Heidrun","Jan-Marc",'Anne-Kathrin']])


#data_list.append([datetime.datetime(1989, 5, 16),"Habkern","Switzerland,"Beatenberg",0,0,['Artur','Hannsjoerg',"Heidrun","Jan-Marc",'Anne-Kathrin']])
#data_list.append([datetime.datetime(1989, 6, 25),"Meersburg","Germany,"Horn",0,0,['Artur','Hannsjoerg',"Heidrun","Jan-Marc",'Anne-Kathrin']])
#data_list.append([datetime.datetime(1989, 8, 14),"Basel","Switzerland,"Lauchringen",0,1,['Artur','Hannsjoerg',"Heidrun","Jan-Marc",'Anne-Kathrin']])
#data_list.append([datetime.datetime(1989, 10, 31),"Lindau","Germany,"Missen Willams",0,0,['Artur','Hannsjoerg',"Heidrun","Jan-Marc",'Anne-Kathrin']])
#data_list.append([datetime.datetime(1989, 11, 2),"Oberstdorf","Germany,"Missen Willams",0,0,['Artur','Hannsjoerg',"Heidrun","Jan-Marc",'Anne-Kathrin']])

#data_list.append([datetime.datetime(1990, 7, 6),"Basel","Switzerland,"Lauchringen",0,1,['Artur','Hannsjoerg',"Heidrun","Jan-Marc",'Anne-Kathrin']])
#data_list.append([datetime.datetime(1990, 8, 7),"Einsiedeln","Switzerland,"Lauchringen",0,1,['Artur','Hannsjoerg',"Heidrun","Jan-Marc",'Anne-Kathrin']])


#data_list.append([datetime.datetime(1991, 8, 5),"Mainau","Germany,"Ueberlingen",0,1,['Artur','Hannsjoerg',"Heidrun","Jan-Marc",'Anne-Kathrin']])
#data_list.append([datetime.datetime(1991, 8, 16),"Zuerich","Switzerland,"Lauchringen",0,1,['Artur','Hannsjoerg',"Heidrun","Jan-Marc",'Anne-Kathrin']])

#data_list.append([datetime.datetime(1992, 3, 24),"Schluechtsee","Germany,"Lauchringen",0,1,['Artur','Hannsjoerg',"Heidrun","Jan-Marc",'Anne-Kathrin']])
#data_list.append([datetime.datetime(1992, 4, 28),"Klingnau","Switzerland,"Lauchringen",0,1,['Artur','Hannsjoerg',"Heidrun","Jan-Marc",'Anne-Kathrin']])
#data_list.append([datetime.datetime(1992, 6, 11),"Grafenhausen","Germany,"Lauchringen",0,1,['Artur','Hannsjoerg',"Heidrun","Jan-Marc",'Anne-Kathrin']])

#data_list.append([datetime.datetime(1992, 7, 8),"Strohn","Germany,"Daun",0,0,['Artur','Hannsjoerg',"Heidrun","Jan-Marc",'Anne-Kathrin']])
#data_list.append([datetime.datetime(1992, 7, 10),"Aachen","Germany,"Daun",0,0,['Artur','Hannsjoerg',"Heidrun","Jan-Marc",'Anne-Kathrin']])
#data_list.append([datetime.datetime(1992, 7, 13),"Manderscheid","Germany,"Daun",0,0,['Artur','Hannsjoerg',"Heidrun","Jan-Marc",'Anne-Kathrin']])
#data_list.append([datetime.datetime(1992, 7, 14),"Kasselburg","Germany,"Daun",0,0,['Artur','Hannsjoerg',"Heidrun","Jan-Marc",'Anne-Kathrin']])


#data_list.append([datetime.datetime(1993, 10, 31),"Ehrwald","Austria,"Telfs",0,0,['Artur','Hannsjoerg',"Heidrun","Jan-Marc",'Anne-Kathrin']])
#data_list.append([datetime.datetime(1993, 11, 2),"Innsbruck","Austria,"Telfs",0,0,['Artur','Hannsjoerg',"Heidrun","Jan-Marc",'Anne-Kathrin']])
#data_list.append([datetime.datetime(1993, 11, 4),"Schwaz","Austria,"Telfs",0,0,['Artur','Hannsjoerg',"Heidrun","Jan-Marc",'Anne-Kathrin']])

# %%
#1996
data_list.append([datetime.datetime(1996, 4, 10),"Birnau","Germany","Lauchringen","Lauchringen",2,1,-1,0,'Birnau 96',['Artur',"Hannsjoerg","Heidrun","Jan-Marc","Anne-Kathrin"]])
data_list.append([datetime.datetime(1996, 4, 14),"Unteruhldingen","Germany","Lauchringen","Lauchringen",4,1,-1,0,'Pfahlbauten 96',['Artur',"Hannsjoerg","Heidrun","Jan-Marc","Anne-Kathrin"]])
data_list.append([datetime.datetime(1996, 5, 8),"Hartmannswiller","France","Lauchringen","Lauchringen",3,1,-1,0,'Hartmannswiller 96',['Artur',"Hannsjoerg","Heidrun","Jan-Marc","Anne-Kathrin"]])
#Beatenberg
data_list.append([datetime.datetime(1996, 5, 10),"Thun","Switzerland","Lauchringen","Beatenberg",4,0,1,0,'Beatenberg 96',['Artur',"Jan-Marc","Anne-Kathrin"]])
data_list.append([datetime.datetime(1996, 5, 10),"Hilterfingen","Switzerland","Lauchringen","Beatenberg",1,0,-1,0,'Beatenberg 96',['Artur',"Jan-Marc","Anne-Kathrin"]])
data_list.append([datetime.datetime(1996, 5, 10),"Oberhofen","Switzerland","Lauchringen","Beatenberg",2,0,-1,0,'Beatenberg 96',['Artur',"Jan-Marc","Anne-Kathrin"]])
data_list.append([datetime.datetime(1996, 5, 10),"Beatenberg","Switzerland","Lauchringen","Beatenberg",13,0,-1,0,'Beatenberg 96',['Artur',"Jan-Marc","Anne-Kathrin"]])
data_list.append([datetime.datetime(1996, 5, 11),"Ballenberg","Switzerland","Beatenberg","Lauchringen",8,0,0,0,'Beatenberg 96',['Artur',"Jan-Marc","Anne-Kathrin"]])
##
#London
data_list.append([datetime.datetime(1996, 8, 24),"London","United Kingdom",'Lauchringen','London',2,0,1,1,'London 96',['Artur',"Hannsjoerg","Heidrun","Jan-Marc","Anne-Kathrin"]])
data_list.append([datetime.datetime(1996, 8, 25),"London","United Kingdom",'London','London',6,0,-1,0,'London 96',['Artur',"Hannsjoerg","Heidrun","Jan-Marc","Anne-Kathrin"]])
data_list.append([datetime.datetime(1996, 8, 26),"London","United Kingdom",'London','London',9,0,-1,0,'London 96',['Artur',"Hannsjoerg","Heidrun","Jan-Marc","Anne-Kathrin"]])
data_list.append([datetime.datetime(1996, 8, 27),"London","United Kingdom",'London','London',5,0,-1,0,'London 96',['Artur',"Hannsjoerg","Heidrun","Jan-Marc","Anne-Kathrin"]])
data_list.append([datetime.datetime(1996, 8, 28),"London","United Kingdom",'London','London',25,0,-1,0,'London 96',['Artur',"Hannsjoerg","Heidrun","Jan-Marc","Anne-Kathrin"]])
data_list.append([datetime.datetime(1996, 8, 29),"London","United Kingdom",'London','London',7,0,-1,0,'London 96',['Artur',"Hannsjoerg","Heidrun","Jan-Marc","Anne-Kathrin"]])
data_list.append([datetime.datetime(1996, 8, 30),"London","United Kingdom",'London','London',8,0,-1,0,'London 96',['Artur',"Hannsjoerg","Heidrun","Jan-Marc","Anne-Kathrin"]])
##
data_list.append([datetime.datetime(1996, 6, 14),"Singen","Germany","Lauchringen","Lauchringen",9,1,-1,0,'Singen 96',['Artur',"Hannsjoerg","Heidrun","Jan-Marc","Anne-Kathrin"]])
data_list.append([datetime.datetime(1996, 7, 28),"Waldshut","Germany","Lauchringen","Lauchringen",4,1,-1,0,'Waldshut 96',['Artur',"Hannsjoerg","Heidrun","Jan-Marc","Anne-Kathrin"]])
##Stromberg
data_list.append([datetime.datetime(1996, 10, 27),"Speyer","Germany","Lauchringen",'Stromberg',16,0,1,0,'Stromberg 96',['Artur',"Hannsjoerg","Heidrun","Jan-Marc","Anne-Kathrin"]])
data_list.append([datetime.datetime(1996, 10, 27),"Stromberg","Germany","Lauchringen",'Stromberg',8,0,1,0,'Stromberg 96',['Artur',"Hannsjoerg","Heidrun","Jan-Marc","Anne-Kathrin"]])
data_list.append([datetime.datetime(1996, 10, 28),"Bingen","Germany","Stromberg",'Stromberg',2,0,-1,0,'Stromberg 96',['Artur',"Hannsjoerg","Heidrun","Jan-Marc","Anne-Kathrin"]])
data_list.append([datetime.datetime(1996, 10, 29),"Heidelberg","Germany","Stromberg",'Stromberg',16,0,-1,0,'Stromberg 96',['Artur',"Hannsjoerg","Heidrun","Jan-Marc","Anne-Kathrin"]])
data_list.append([datetime.datetime(1996, 10, 30),"Worms","Germany","Stromberg",'Stromberg',9,0,-1,0,'Stromberg 96',['Artur',"Hannsjoerg","Heidrun","Jan-Marc","Anne-Kathrin"]])
data_list.append([datetime.datetime(1996, 10, 31),"Mainz","Germany","Stromberg",'Stromberg',14,0,-1,0,'Stromberg 96',['Artur',"Hannsjoerg","Heidrun","Jan-Marc","Anne-Kathrin"]])

#1997
data_list.append([datetime.datetime(1997, 4, 14),"Bechtersbohl","Germany","Lauchringen","Lauchringen",2,1,-1,0,'Kuessaburg 97',['Artur',"Hannsjoerg","Heidrun","Jan-Marc","Anne-Kathrin"]])
##munich
data_list.append([datetime.datetime(1997, 5, 22),"Muenchen","Germany","Lauchringen","Muenchen",30,0,1,0,"Muenchen 97",['Artur',"Hannsjoerg","Heidrun","Jan-Marc","Anne-Kathrin"]])
data_list.append([datetime.datetime(1997, 5, 23),"Muenchen","Germany","Muenchen","Muenchen",12,0,-1,0,"Muenchen 97",['Artur',"Hannsjoerg","Heidrun","Jan-Marc","Anne-Kathrin"]])
data_list.append([datetime.datetime(1997, 5, 24),"Muenchen","Germany","Muenchen","Muenchen",7,0,-1,0,"Muenchen 97",['Artur',"Hannsjoerg","Heidrun","Jan-Marc","Anne-Kathrin"]])
data_list.append([datetime.datetime(1997, 5, 25),"Dachau","Germany","Muenchen","Lauchringen",4,0,0,0,"Muenchen 97",['Artur',"Hannsjoerg","Heidrun","Jan-Marc","Anne-Kathrin"]])
##Rome
data_list.append([datetime.datetime(1997, 8, 24),"Rome","Italy","Rome","Rome",8,0,-1,0,"Rome 97",['Artur',"Hannsjoerg","Heidrun","Jan-Marc","Anne-Kathrin"]])
data_list.append([datetime.datetime(1997, 8, 24),"Rome","Vatican","Rome","Rome",6,0,-1,0,"Rome 97",['Artur',"Hannsjoerg","Heidrun","Jan-Marc","Anne-Kathrin"]])
data_list.append([datetime.datetime(1997, 8, 25),"Rome","Italy","Rome","Rome",12,0,-1,0,"Rome 97",['Artur',"Hannsjoerg","Heidrun","Jan-Marc","Anne-Kathrin"]])
data_list.append([datetime.datetime(1997, 8, 25),"Rome","Vatican","Rome","Rome",1,0,-1,0,"Rome 97",['Artur',"Hannsjoerg","Heidrun","Jan-Marc","Anne-Kathrin"]])
data_list.append([datetime.datetime(1997, 8, 26),"Rome","Italy","Rome","Rome",11,0,-1,0,"Rome 97",['Artur',"Hannsjoerg","Heidrun","Jan-Marc","Anne-Kathrin"]])
data_list.append([datetime.datetime(1997, 8, 27),"Rome","Vatican","Rome","Rome",19,0,-1,0,"Rome 97",['Artur',"Hannsjoerg","Heidrun","Jan-Marc","Anne-Kathrin"]])
data_list.append([datetime.datetime(1997, 8, 27),"Rome","Italy","Rome","Rome",4,0,-1,0,"Rome 97",['Artur',"Hannsjoerg","Heidrun","Jan-Marc","Anne-Kathrin"]])
data_list.append([datetime.datetime(1997, 8, 28),"Rome","Vatican","Rome","Rome",6,0,-1,0,"Rome 97",['Artur',"Hannsjoerg","Heidrun","Jan-Marc","Anne-Kathrin"]])
data_list.append([datetime.datetime(1997, 8, 28),"Rome","Italy","Rome","Rome",8,0,-1,0,"Rome 97",['Artur',"Hannsjoerg","Heidrun","Jan-Marc","Anne-Kathrin"]])
data_list.append([datetime.datetime(1997, 8, 29),"Ostia","Italy","Rome","Rome",7,0,-1,0,"Rome 97",['Artur',"Hannsjoerg","Heidrun","Jan-Marc","Anne-Kathrin"]])
data_list.append([datetime.datetime(1997, 8, 30),"Rome","Italy","Rome","Rome",3,0,-1,0,"Rome 97",['Artur',"Hannsjoerg","Heidrun","Jan-Marc","Anne-Kathrin"]])
data_list.append([datetime.datetime(1997, 8, 31),"Rome","Vatican","Rome","Rome",7,0,-1,0,"Rome 97",['Artur',"Hannsjoerg","Heidrun","Jan-Marc","Anne-Kathrin"]])
data_list.append([datetime.datetime(1997, 8, 31),"Rome","Italy","Rome","Rome",4,0,-1,0,"Rome 97",['Artur',"Hannsjoerg","Heidrun","Jan-Marc","Anne-Kathrin"]])
data_list.append([datetime.datetime(1997, 9, 1),"Rome","Italy","Rome",'Lauchringen',4,0,0,2,"Rome 97",['Artur',"Hannsjoerg","Heidrun","Jan-Marc","Anne-Kathrin"]])
##
data_list.append([datetime.datetime(1997, 10, 11),"Saint Pierre de Chandieu","France","Lauchringen",'Saint Pierre de Chandieu',2,0,1,0,'Saint Pierre de Chandieu 97',['Artur',"Jan-Marc","Anne-Kathrin"]])
data_list.append([datetime.datetime(1997, 10, 12),"Saint Pierre de Chandieu","France","Saint Pierre de Chandieu","Saint Pierre de Chandieu",2,0,-1,0,'Saint Pierre de Chandieu 97',['Artur',"Jan-Marc","Anne-Kathrin"]])
data_list.append([datetime.datetime(1997, 11, 25),"Habsburg","Switzerland","Lauchringen","Lauchringen",3,1,-1,0,"Habsburg and Lenzburg 97",['Artur',"Heidrun"]])
data_list.append([datetime.datetime(1997, 11, 25),"Lenzburg","Switzerland","Lauchringen","Lauchringen",4,1,-1,0,"Habsburg and Lenzburg 97",['Artur',"Heidrun"]])
#1998
#Ulm
data_list.append([datetime.datetime(1998, 4, 17),"Ulm","Germany","Lauchringen","Ulm",28,0,1,0,'Ulm 98',['Artur',"Heidrun","Hannsjoerg","Anne-Kathrin"]])
data_list.append([datetime.datetime(1998, 4, 18),"Blaubeuren","Germany","Ulm","Ulm",6,0,-1,0,'Ulm 98',['Artur',"Heidrun","Hannsjoerg","Anne-Kathrin"]])
data_list.append([datetime.datetime(1998, 4, 18),"Ulm","Germany","Ulm","Ulm",14,0,-1,0,'Ulm 98',['Artur',"Heidrun","Hannsjoerg","Anne-Kathrin"]])
data_list.append([datetime.datetime(1998, 4, 19),"Sonnenbuehl","Germany","Ulm",'Lauchringen',3,0,0,0,'Ulm 98',['Artur',"Heidrun","Hannsjoerg","Anne-Kathrin"]])
#Paris
data_list.append([datetime.datetime(1998, 8, 22),"Paris","France","Paris",'Paris',4,0,-1,0,'Paris 98',['Artur',"Hannsjoerg","Heidrun","Jan-Marc","Anne-Kathrin"]])
data_list.append([datetime.datetime(1998, 8, 23),"Paris","France","Paris",'Paris',22,0,-1,0,'Paris 98',['Artur',"Hannsjoerg","Heidrun","Jan-Marc","Anne-Kathrin"]])
data_list.append([datetime.datetime(1998, 8, 24),"Paris","France","Paris",'Paris',9,0,-1,0,'Paris 98',['Artur',"Hannsjoerg","Heidrun","Jan-Marc","Anne-Kathrin"]])
data_list.append([datetime.datetime(1998, 8, 25),"Versailles","France","Paris",'Paris',6,0,-1,0,'Paris 98',['Artur',"Hannsjoerg","Heidrun","Jan-Marc","Anne-Kathrin"]])
data_list.append([datetime.datetime(1998, 8, 26),"Saint Denis","France","Paris",'Paris',5,0,-1,0,'Paris 98',['Artur',"Hannsjoerg","Heidrun","Jan-Marc","Anne-Kathrin"]])
data_list.append([datetime.datetime(1998, 8, 27),"Paris","France","Paris",'Paris',3,0,-1,0,'Paris 98',['Artur',"Hannsjoerg","Heidrun","Jan-Marc","Anne-Kathrin"]])
data_list.append([datetime.datetime(1998, 8, 28),"Paris","France","Paris",'Lauchringen',3,0,0,2,'Paris 98',['Artur',"Hannsjoerg","Heidrun","Jan-Marc","Anne-Kathrin"]])

#1999
#bonn
data_list.append([datetime.datetime(1999, 6, 14),"Speyer","Germany","Lauchringen",'Bad Honnef',6,0,1,0,'Bonn 99',['school']])
data_list.append([datetime.datetime(1999, 6, 14),"Bonn","Germany","Lauchringen",'Bad Honnef',1,0,1,0,'Bonn 99',['school']])
data_list.append([datetime.datetime(1999, 6, 15),"Bonn","Germany",'Bad Honnef','Bad Honnef',1,0,-1,0,'Bonn 99',['school']])
data_list.append([datetime.datetime(1999, 6, 16),"Bonn","Germany",'Bad Honnef','Bad Honnef',2,0,-1,0,'Bonn 99',['school']])
data_list.append([datetime.datetime(1999, 6, 17),"Bonn","Germany",'Bad Honnef','Bad Honnef',1,0,-1,0,'Bonn 99',['school']])
data_list.append([datetime.datetime(1999, 6, 18),"Cologne","Germany",'Bad Honnef','Lauchringen',37,0,0,0,'Bonn 99',['school']])
#greece
data_list.append([datetime.datetime(1999, 8, 27),"Athens","Greece","Athens","Athens",10,0,-1,0,'Greece 99',['Artur',"Hannsjoerg","Heidrun","Jan-Marc","Anne-Kathrin"]])
data_list.append([datetime.datetime(1999, 8, 28),"Athens","Greece","Athens","Athens",26,0,-1,0,'Greece 99',['Artur',"Hannsjoerg","Heidrun","Jan-Marc","Anne-Kathrin"]])
data_list.append([datetime.datetime(1999, 8, 29),"Korinth","Greece","Athens",'Nauplia',2,0,0,0,'Greece 99',['Artur',"Hannsjoerg","Heidrun","Jan-Marc","Anne-Kathrin"]])
data_list.append([datetime.datetime(1999, 8, 29),"Mykene","Greece","Athens",'Nauplia',11,0,1,0,'Greece 99',['Artur',"Hannsjoerg","Heidrun","Jan-Marc","Anne-Kathrin"]])
data_list.append([datetime.datetime(1999, 8, 29),"Epidauros","Greece","Athens",'Nauplia',5,0,1,0,'Greece 99',['Artur',"Hannsjoerg","Heidrun","Jan-Marc","Anne-Kathrin"]])
data_list.append([datetime.datetime(1999, 8, 29),"Nauplia","Greece","Athens",'Nauplia',3,0,1,0,'Greece 99',['Artur',"Hannsjoerg","Heidrun","Jan-Marc","Anne-Kathrin"]])
data_list.append([datetime.datetime(1999, 8, 30),"Olympia","Greece","Nauplia",'Olympia',6,0,1,0,'Greece 99',['Artur',"Hannsjoerg","Heidrun","Jan-Marc","Anne-Kathrin"]])
data_list.append([datetime.datetime(1999, 8, 31),"Kalavrita","Greece","Olympia","Delphi",1,0,0,0,'Greece 99',['Artur',"Hannsjoerg","Heidrun","Jan-Marc","Anne-Kathrin"]])
data_list.append([datetime.datetime(1999, 9, 1),"Delphi","Greece","Delphi","Athens",15,0,0,0,'Greece 99',['Artur',"Hannsjoerg","Heidrun","Jan-Marc","Anne-Kathrin"]])
data_list.append([datetime.datetime(1999, 9, 2),"Athens","Greece","Athens","Athens",36,0,-1,0,'Greece 99',['Artur',"Hannsjoerg","Heidrun","Jan-Marc","Anne-Kathrin"]])
data_list.append([datetime.datetime(1999, 9, 4),"Eretria","Greece","Eretria","Eretria",1,0,-1,0,'Greece 99',['Artur',"Hannsjoerg","Heidrun","Jan-Marc","Anne-Kathrin"]])
data_list.append([datetime.datetime(1999, 9, 7),"Eretria","Greece","Eretria","Eretria",1,0,-1,0,'Greece 99',['Artur',"Hannsjoerg","Heidrun","Jan-Marc","Anne-Kathrin"]])
#nurburgring
data_list.append([datetime.datetime(1999, 9, 26),"Adenau","Germany","Frankfurt",'Lauchringen',12,0,-1,0,'Nuerburgring 99',['Artur',"Hannsjoerg","Heidrun","Jan-Marc","Anne-Kathrin"]])

# %%
#2000
##munich
data_list.append([datetime.datetime(2000, 5, 17),"Munich","Germany","Lauchringen","Munich",6,0,1,0,'Muenchen 00',["Hochrhein Seminar"]])
data_list.append([datetime.datetime(2000, 5, 18),"Munich","Germany","Munich","Munich",11,0,-1,0,'Muenchen 00',["Vera"]])
data_list.append([datetime.datetime(2000, 5, 19),"Munich","Germany","Munich","Munich",12,0,-1,0,'Muenchen 00',["Christine S"]])
data_list.append([datetime.datetime(2000, 5, 20),"Munich","Germany","Munich","Munich",6,0,-1,0,'Muenchen 00',["Hochrhein Seminar"]])
data_list.append([datetime.datetime(2000, 5, 21),"Munich","Germany","Lauchringen",'Lauchringen',4,0,0,0,'Muenchen 00',["Hochrhein Seminar"]])
##EXPO
data_list.append([datetime.datetime(2000, 6, 9),"Hannover","Germany","Lauchringen","Hannover",9,0,1,0,"Expo 2000",["Heidrun",'Artur','Hannsjoerg','Anne-Kathrin']])
data_list.append([datetime.datetime(2000, 6, 10),"Hannover","Germany","Hannover","Hannover",39,0,-1,0,"Expo 2000",["Heidrun",'Artur','Hannsjoerg','Anne-Kathrin']])
data_list.append([datetime.datetime(2000, 6, 11),"Hannover","Germany","Hannover","Hannover",15,0,-1,0,"Expo 2000",["Heidrun",'Artur','Hannsjoerg','Anne-Kathrin']])
##Turkey
data_list.append([datetime.datetime(2000, 8, 25),"Antalya","Turkey",'Lauchringen',"Antalya",7,0,1,1,"Turkey 2000",["Heidrun",'Artur','Hannsjoerg','Anne-Kathrin']])
data_list.append([datetime.datetime(2000, 8, 26),"Bursa","Turkey","Antalya","Bursa",13,0,1,0,"Turkey 2000",["Heidrun",'Artur','Hannsjoerg','Anne-Kathrin']])
data_list.append([datetime.datetime(2000, 8, 27),"Istanbul","Turkey","Bursa","Istanbul",48,0,1,0,"Turkey 2000",["Heidrun",'Artur','Hannsjoerg','Anne-Kathrin']])
data_list.append([datetime.datetime(2000, 8, 28),"Istanbul","Turkey","Istanbul","Istanbul",46,0,-1,0,"Turkey 2000",["Heidrun",'Artur','Hannsjoerg','Anne-Kathrin']])
data_list.append([datetime.datetime(2000, 8, 29),"Troy","Turkey","Istanbul","Canakkale",8,0,1,0,"Turkey 2000",["Heidrun",'Artur','Hannsjoerg','Anne-Kathrin']])
data_list.append([datetime.datetime(2000, 8, 30),"Pergamon","Turkey","Canakkale","Selcuk",9,0,1,0,"Turkey 2000",["Heidrun",'Artur','Hannsjoerg','Anne-Kathrin']])
data_list.append([datetime.datetime(2000, 8, 30),"Ephesus","Turkey","Canakkale","Selcuk",12,0,1,0,"Turkey 2000",["Heidrun",'Artur','Hannsjoerg','Anne-Kathrin']])
data_list.append([datetime.datetime(2000, 8, 30),"Selcuk","Turkey","Canakkale","Selcuk",1,0,1,0,"Turkey 2000",["Heidrun",'Artur','Hannsjoerg','Anne-Kathrin']])
data_list.append([datetime.datetime(2000, 8, 31),"Pamukkale","Turkey","Selcuk","Antalya",11,0,0,0,"Turkey 2000",["Heidrun",'Artur','Hannsjoerg','Anne-Kathrin']])
data_list.append([datetime.datetime(2000, 8, 31),"Antalya","Turkey","Selcuk","Antalya",1,0,1,0,"Turkey 2000",["Heidrun",'Artur','Hannsjoerg','Anne-Kathrin']])
data_list.append([datetime.datetime(2000, 9, 5),"Kemer","Turkey","Kemer","Kemer",3,0,-1,0,"Turkey 2000",["Heidrun",'Artur','Hannsjoerg','Anne-Kathrin']])
data_list.append([datetime.datetime(2000, 10, 8),"Neuhausen am Rheinfall","Switzerland","Lauchringen","Lauchringen",3,1,-1,0,"Rheinfall 2000",["Heidrun",'Artur','Hannsjoerg','Anne-Kathrin']])
data_list.append([datetime.datetime(2000, 11, 14),"Tiengen","Germany","Lauchringen","Lauchringen",1,1,-1,0,"Freiburg 2000",['School Concert']])
data_list.append([datetime.datetime(2000, 11, 14),"Freiburg","Germany","Lauchringen","Lauchringen",4,1,-1,0,"Freiburg 2000",['School Concert']])
#2001
#barcelona
data_list.append([datetime.datetime(2001, 5, 13),"Figueres","Spain","Lauchringen","Barcelona",6,0,1,0,"Barcelona 2001",["KGT"]])
data_list.append([datetime.datetime(2001, 5, 14),"Barcelona","Spain","Barcelona","Barcelona",14,0,-1,0,"Barcelona 2001",["KGT"]])
data_list.append([datetime.datetime(2001, 5, 15),"Barcelona","Spain","Barcelona","Barcelona",58,0,-1,0,"Barcelona 2001",["KGT"]])
data_list.append([datetime.datetime(2001, 5, 16),"Monistrol de Montserrat","Spain","Barcelona","Barcelona",17,0,-1,0,"Barcelona 2001",["KGT"]])
data_list.append([datetime.datetime(2001, 5, 17),"Barcelona","Spain","Barcelona","Barcelona",1,0,-1,0,"Barcelona 2001",["KGT"]])
data_list.append([datetime.datetime(2001, 5, 18),"Barcelona","Spain","Barcelona","Barcelona",14,0,-1,0,"Barcelona 2001",["KGT"]])
data_list.append([datetime.datetime(2001, 5, 19),"Vers-Pont-du-Gard","France","Barcelona",'Lauchringen',4,0,0,0,"Barcelona 2001",["KGT"]])
##Berlin
data_list.append([datetime.datetime(2001, 6, 7),"Berlin","Germany","Lauchringen","Berlin",7,0,1,0,'Berlin 2001',["Heidrun",'Anne-Kathrin','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2001, 6, 8),"Berlin","Germany","Berlin","Berlin",6,0,-1,0,'Berlin 2001',["Heidrun",'Anne-Kathrin','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2001, 6, 9),"Berlin","Germany","Berlin","Berlin",15,0,-1,0,'Berlin 2001',["Heidrun",'Anne-Kathrin','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2001, 6, 10),"Berlin","Germany","Berlin","Berlin",8,0,-1,0,'Berlin 2001',["Heidrun",'Anne-Kathrin','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2001, 6, 11),"Potsdam","Germany","Berlin","Berlin",3,0,-1,0,'Berlin 2001',["Heidrun",'Anne-Kathrin','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2001, 6, 11),"Berlin","Germany","Berlin","Berlin",1,0,-1,0,'Berlin 2001',["Heidrun",'Anne-Kathrin','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2001, 6, 12),"Berlin","Germany","Berlin",'Lauchringen',3,0,0,0,'Berlin 2001',["Heidrun",'Anne-Kathrin','Artur','Hannsjoerg']])
#Andalusia
data_list.append([datetime.datetime(2001, 8, 23),"Nerja","Spain","Malaga","Granada",7,0,0,0,'Andalusia 2001',["Heidrun",'Anne-Kathrin','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2001, 8, 23),"Granada","Spain","Malaga","Granada",2,0,1,0,'Andalusia 2001',["Heidrun",'Anne-Kathrin','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2001, 8, 24),"Granada","Spain","Granada","Cordoba",22,0,0,0,'Andalusia 2001',["Heidrun",'Anne-Kathrin','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2001, 8, 24),"Cordoba","Spain","Granada","Cordoba",5,0,1,0,'Andalusia 2001',["Heidrun",'Anne-Kathrin','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2001, 8, 25),"Cordoba","Spain","Cordoba","Sevilla",34,0,0,0,'Andalusia 2001',["Heidrun",'Anne-Kathrin','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2001, 8, 25),"Sevilla","Spain","Cordoba","Sevilla",2,0,1,0,'Andalusia 2001',["Heidrun",'Anne-Kathrin','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2001, 8, 26),"Sevilla","Spain","Sevilla","Sevilla",38,0,-1,0,'Andalusia 2001',["Heidrun",'Anne-Kathrin','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2001, 8, 27),"Cadiz","Spain","Sevilla","Arcos de la Frontera",4,0,1,0,'Andalusia 2001',["Heidrun",'Anne-Kathrin','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2001, 8, 27),"Jerez de la Frontera","Spain","Sevilla","Arcos de la Frontera",3,0,1,0,'Andalusia 2001',["Heidrun",'Anne-Kathrin','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2001, 8, 27),"Arcos de la Frontera","Spain","Sevilla","Arcos de la Frontera",3,0,1,0,'Andalusia 2001',["Heidrun",'Anne-Kathrin','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2001, 8, 28),"Ronda","Spain","Arcos de la Frontera",'Malaga',6,0,0,0,'Andalusia 2001',["Heidrun",'Anne-Kathrin','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2001, 8, 30),"Marbella","Spain","Marbella","Marbella",2,0,-1,0,'Andalusia 2001',["Heidrun",'Anne-Kathrin','Artur','Hannsjoerg']])

# %%
#2002
#toscana
data_list.append([datetime.datetime(2002, 5, 26),"San Gimignano","Italy","Montaione","Montaione",3,0,-1,0,'Toscana 2002',["Heidrun",'Anne-Kathrin','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2002, 5, 27),"Siena","Italy","Montaione","Montaione",17,0,-1,0,'Toscana 2002',["Heidrun",'Anne-Kathrin','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2002, 5, 28),"Florence","Italy","Montaione","Montaione",30,0,-1,0,'Toscana 2002',["Heidrun",'Anne-Kathrin','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2002, 5, 29),"Pisa","Italy","Montaione","Montaione",27,0,-1,0,'Toscana 2002',["Heidrun",'Anne-Kathrin','Artur','Hannsjoerg']])
#marocco
data_list.append([datetime.datetime(2002, 8, 20),"Agadir","Morocco",'Lauchringen',"Agadir",1,0,1,1,'Morocco 2002',["Heidrun",'Anne-Kathrin','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2002, 8, 21),"Marrakech","Morocco","Agadir",'Marrakech',12,0,1,0,'Morocco 2002',["Heidrun",'Anne-Kathrin','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2002, 8, 24),"Fez","Morocco","Fez","Fez",19,0,-1,0,'Morocco 2002',["Heidrun",'Anne-Kathrin','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2002, 8, 24),"Meknes","Morocco","Fez","Volubilis",6,0,1,0,'Morocco 2002',["Heidrun",'Anne-Kathrin','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2002, 8, 24),"Moulay Idris","Morocco","Fez","Volubilis",1,0,1,0,'Morocco 2002',["Heidrun",'Anne-Kathrin','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2002, 8, 24),"Volubilis","Morocco","Fez","Volubilis",11,0,1,0,'Morocco 2002',["Heidrun",'Anne-Kathrin','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2002, 8, 25),"Moulay Idris","Morocco","Volubilis","Casablanca",1,0,0,0,'Morocco 2002',["Heidrun",'Anne-Kathrin','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2002, 8, 25),"Rabat","Morocco","Volubilis","Casablanca",10,0,1,0,'Morocco 2002',["Heidrun",'Anne-Kathrin','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2002, 8, 25),"Casablanca","Morocco","Volubilis","Casablanca",7,0,1,0,'Morocco 2002',["Heidrun",'Anne-Kathrin','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2002, 8, 26),"Casablanca","Morocco","Casablanca",'Essaouira',1,0,0,0,'Morocco 2002',["Heidrun",'Anne-Kathrin','Artur','Hannsjoerg']])
#2003
data_list.append([datetime.datetime(2003, 7, 5),"Bodrum","Turkey","Bodrum","Bodrum",1,0,-1,0,'Bodrum 2003',["Boeni",'Sigi','Gianrico']])
data_list.append([datetime.datetime(2003, 7, 6),"Bodrum","Turkey","Bodrum","Bodrum",2,0,-1,0,'Bodrum 2003',["Boeni",'Sigi','Gianrico']])
data_list.append([datetime.datetime(2003, 7, 7),"Ephesus","Turkey","Bodrum","Bodrum",19,0,-1,0,'Bodrum 2003',["Boeni",'Sigi','Gianrico']])
data_list.append([datetime.datetime(2003, 7, 9),"Bodrum","Turkey","Bodrum","Bodrum",14,0,-1,0,'Bodrum 2003',["Boeni",'Sigi','Gianrico']])
data_list.append([datetime.datetime(2003, 7, 10),"Bodrum","Turkey","Bodrum","Bodrum",14,0,-1,0,'Bodrum 2003',["Boeni",'Sigi','Gianrico']])
data_list.append([datetime.datetime(2003, 7, 11),"Bodrum","Turkey","Bodrum","Bodrum",7,0,-1,0,'Bodrum 2003',["Boeni",'Sigi','Gianrico']])
data_list.append([datetime.datetime(2003, 7, 11),"Stuttgart","Germany","Bodrum",'Lauchringen',3,0,1,2,'Bodrum 2003',["Boeni",'Sigi','Gianrico']])
#2004
data_list.append([datetime.datetime(2004, 7, 2),"Monastir","Tunisia","Monastir","Monastir",4,0,-1,0,'Tunisia 2004',['Sigi','Gianrico']])
data_list.append([datetime.datetime(2004, 7, 5),"Monastir","Tunisia","Monastir","Monastir",5,0,-1,0,'Tunisia 2004',['Sigi','Gianrico']])
data_list.append([datetime.datetime(2004, 7, 6),"Monastir","Tunisia","Monastir","Monastir",18,0,-1,0,'Tunisia 2004',['Sigi','Gianrico']])
data_list.append([datetime.datetime(2004, 7, 7),"Tunis","Tunisia","Monastir","Monastir",12,0,-1,0,'Tunisia 2004',['Sigi','Gianrico']])
data_list.append([datetime.datetime(2004, 7, 7),"Carthage","Tunisia","Monastir","Monastir",5,0,-1,0,'Tunisia 2004',['Sigi','Gianrico']])
data_list.append([datetime.datetime(2004, 7, 8),"Monastir","Tunisia","Monastir","Monastir",12,0,-1,0,'Tunisia 2004',['Sigi','Gianrico']])
data_list.append([datetime.datetime(2004, 7, 9),"Monastir","Tunisia","Monastir",'Lauchringen',4,0,0,2,'Tunisia 2004',['Sigi','Gianrico']])
#London
data_list.append([datetime.datetime(2004, 10, 16),"London","United Kingdom",'Lauchringen',"London",4,0,1,1,'London 2004',['Sigi','Gianrico','Anne F']])
data_list.append([datetime.datetime(2004, 10, 17),"London","United Kingdom","London","London",10,0,-1,0,'London 2004',['Sigi','Gianrico','Anne F']])
data_list.append([datetime.datetime(2004, 10, 18),"London","United Kingdom","London","London",6,0,-1,0,'London 2004',['Sigi','Gianrico','Anne F']])
data_list.append([datetime.datetime(2004, 10, 19),"London","United Kingdom","London",'Lauchringen',2,0,0,2,'London 2004',['Sigi','Gianrico','Anne F']])
##
data_list.append([datetime.datetime(2004, 10, 23),"Frankfurt","Germany","Lauchringen",'Lauchringen',31,1,-1,0,"Frankfurt 2004",[]])
#2005
#Diavolezza
data_list.append([datetime.datetime(2005, 2, 8),"Pontresina","Switzerland","Pontresina","Pontresina",11,0,-1,0,"Diavolezza 2005",["ETH Astro Crew"]])
data_list.append([datetime.datetime(2005, 2, 9),"Pontresina","Switzerland","Pontresina","Pontresina",7,0,-1,0,"Diavolezza 2005",["ETH Astro Crew"]])
data_list.append([datetime.datetime(2005, 2, 10),"Pontresina","Switzerland","Pontresina","Pontresina",3,0,-1,0,"Diavolezza 2005",["ETH Astro Crew"]])
data_list.append([datetime.datetime(2005, 2, 11),"Pontresina","Switzerland","Pontresina","Pontresina",6,0,-1,0,"Diavolezza 2005",["ETH Astro Crew"]])
data_list.append([datetime.datetime(2005, 2, 12),"Pontresina","Switzerland","Pontresina",'Lauchringen',2,0,0,0,"Diavolezza 2005",["ETH Astro Crew"]])
#egypt
data_list.append([datetime.datetime(2005, 3, 20),"Cairo","Egypt",'Lauchringen',"Cairo",3,0,1,1,"Egypt 2005",["Artur",'Heidrun','Hannsjoerg']])
data_list.append([datetime.datetime(2005, 3, 21),"Saqqara","Egypt","Cairo","Cairo",13,0,-1,0,"Egypt 2005",["Artur",'Heidrun','Hannsjoerg']])
data_list.append([datetime.datetime(2005, 3, 21),"Gizeh","Egypt","Cairo","Cairo",20,0,-1,0,"Egypt 2005",["Artur",'Heidrun','Hannsjoerg']])
data_list.append([datetime.datetime(2005, 3, 21),"Cairo","Egypt","Cairo","Cairo",1,0,-1,0,"Egypt 2005",["Artur",'Heidrun','Hannsjoerg']])
data_list.append([datetime.datetime(2005, 3, 22),"Karnak","Egypt","Cairo","Luxor",7,0,1,1,"Egypt 2005",["Artur",'Heidrun','Hannsjoerg']])
data_list.append([datetime.datetime(2005, 3, 22),"Luxor","Egypt","Cairo","Luxor",9,0,-1,0,"Egypt 2005",["Artur",'Heidrun','Hannsjoerg']])
data_list.append([datetime.datetime(2005, 3, 23),"Luxor","Egypt","Luxor","Edfu",17,0,0,0,"Egypt 2005",["Artur",'Heidrun','Hannsjoerg']])
data_list.append([datetime.datetime(2005, 3, 23),"Esna","Egypt","Luxor","Edfu",1,0,1,0,"Egypt 2005",["Artur",'Heidrun','Hannsjoerg']])
data_list.append([datetime.datetime(2005, 3, 24),"Edfu","Egypt","Edfu","Kom Ombo",14,0,0,0,"Egypt 2005",["Artur",'Heidrun','Hannsjoerg']])
data_list.append([datetime.datetime(2005, 3, 24),"Kom Ombo","Egypt","Edfu","Kom Ombo",7,0,1,0,"Egypt 2005",["Artur",'Heidrun','Hannsjoerg']])
data_list.append([datetime.datetime(2005, 3, 25),"Philae","Egypt","Kom Ombo","Aswan",7,0,1,0,"Egypt 2005",["Artur",'Heidrun','Hannsjoerg']])
data_list.append([datetime.datetime(2005, 3, 26),"Aswan","Egypt","Aswan","Cairo",5,0,0,2,"Egypt 2005",["Artur",'Heidrun','Hannsjoerg']])
data_list.append([datetime.datetime(2005, 3, 27),"Cairo","Egypt","Cairo",'Lauchringen',18,0,0,2,"Egypt 2005",["Artur",'Heidrun','Hannsjoerg']])
#lisbon
data_list.append([datetime.datetime(2005, 8, 29),"Lisbon","Portugal","Lisbon","Lisbon",6,0,-1,0,"Lisbon 2005",["Artur",'Anne-Kathrin','Heidrun','Hannsjoerg']])
data_list.append([datetime.datetime(2005, 8, 30),"Belem","Portugal","Lisbon","Lisbon",7,0,-1,0,"Lisbon 2005",["Artur",'Anne-Kathrin','Heidrun','Hannsjoerg']])
data_list.append([datetime.datetime(2005, 8, 30),"Lisbon","Portugal","Lisbon","Lisbon",2,0,-1,0,"Lisbon 2005",["Artur",'Anne-Kathrin','Heidrun','Hannsjoerg']])
data_list.append([datetime.datetime(2005, 8, 31),"Lisbon","Portugal","Lisbon","Lisbon",4,0,-1,0,"Lisbon 2005",["Artur",'Anne-Kathrin','Heidrun','Hannsjoerg']])
data_list.append([datetime.datetime(2005, 9, 1),"Queluz","Portugal","Lisbon","Lisbon",3,0,-1,0,"Lisbon 2005",["Artur",'Anne-Kathrin','Heidrun','Hannsjoerg']])
data_list.append([datetime.datetime(2005, 9, 2),"Lisbon","Portugal","Lisbon","Lisbon",6,0,-1,0,"Lisbon 2005",["Artur",'Anne-Kathrin','Heidrun','Hannsjoerg']])
data_list.append([datetime.datetime(2005, 9, 3),"Lisbon","Portugal","Lisbon","Lisbon",1,0,-1,0,"Lisbon 2005",["Artur",'Anne-Kathrin','Heidrun','Hannsjoerg']])

# %%
#-1 if Destination and Origin are the same, 1 if Destination is closer, 0 if Origin is closer
#FlightFlag 0 both of them reached without flight 1 if flight from Origin, 2 if flight to Destination

#2006
data_list.append([datetime.datetime(2006, 6, 26),"Bechtersbohl","Germany","Lauchringen","Lauchringen",8,1,-1,0,'Kuessaburg 2006',['Artur','Hannsjoerg']])
#London
data_list.append([datetime.datetime(2006, 7, 11),"Basel","Switzerland","Lauchringen","London",1,0,1,1,'London 2006',['Artur','Heidrun','Hannsjoerg']])
data_list.append([datetime.datetime(2006, 7, 11),"London","United Kingdom",'Lauchringen',"London",23,0,-1,0,'London 2006',['Artur','Heidrun','Hannsjoerg']])
data_list.append([datetime.datetime(2006, 7, 12),"Windsor","United Kingdom","London","London",17,0,-1,0,'London 2006',['Artur','Heidrun','Hannsjoerg']])
data_list.append([datetime.datetime(2006, 7, 12),"London","United Kingdom","London","London",24,0,-1,0,'London 2006',['Artur','Heidrun','Hannsjoerg']])
data_list.append([datetime.datetime(2006, 7, 13),"London","United Kingdom","London","London",10,0,-1,0,'London 2006',['Artur','Heidrun','Hannsjoerg']])
data_list.append([datetime.datetime(2006, 7, 14),"London","United Kingdom","London","London",17,0,-1,0,'London 2006',['Artur','Heidrun','Hannsjoerg']])
data_list.append([datetime.datetime(2006, 7, 15),"London","United Kingdom","London","London",8,0,-1,0,'London 2006',['Artur','Heidrun','Hannsjoerg']])
data_list.append([datetime.datetime(2006, 7, 16),"London","United Kingdom","London","London",5,0,-1,0,'London 2006',['Artur','Heidrun','Hannsjoerg']])
data_list.append([datetime.datetime(2006, 7, 17),"London","United Kingdom","London","London",24,0,-1,0,'London 2006',['Artur','Heidrun','Hannsjoerg']])
data_list.append([datetime.datetime(2006, 7, 18),"London","United Kingdom","London",'Lauchringen',1,0,0,2,'London 2006',['Artur','Heidrun','Hannsjoerg']])
##
data_list.append([datetime.datetime(2006, 10, 6),"Zurich","Germany","Lauchringen","Lauchringen",28,1,-1,0,'Zuerich I 2006',['Anne F','Sigi','Gianrico']])
data_list.append([datetime.datetime(2006, 10, 8),"Goerwihl","Germany","Lauchringen","Lauchringen",6,1,-1,0,'Gorwihl I 2006',['Artur',"Jan-Marc"]])
data_list.append([datetime.datetime(2006, 10, 19),"Zurich","Germany","Lauchringen","Lauchringen",28,1,-1,0,'Zurich II 2006',['Hannsjoerg']])
data_list.append([datetime.datetime(2006, 10, 28),"Genf","Switzerland","Meyrin","Meyrin",15,1,-1,0,'Genf I 2006',['Hannsjoerg','Heidrun','Artur']])
data_list.append([datetime.datetime(2006, 10, 29),"Genf","Switzerland","Meyrin","Meyrin",25,1,-1,0,'Genf II 2006',[]])
data_list.append([datetime.datetime(2006, 11, 4),"Genf","Switzerland","Meyrin","Meyrin",8,1,-1,0,'Genf III 2006',[]])
data_list.append([datetime.datetime(2006, 11, 25),"Les Houches","France","Meyrin","Meyrin",1,1,-1,0,'Chamonix 2006',['Hannsjoerg','Artur','Heidrun']])
data_list.append([datetime.datetime(2006, 11, 25),"Chamonix","France","Meyrin","Meyrin",39,1,-1,0,'Chamonix 2006',['Hannsjoerg','Artur','Heidrun']])
data_list.append([datetime.datetime(2006, 11, 30),"Genf","Switzerland","Meyrin","Meyrin",2,1,-1,0,'Genf IV 2006',[]])
data_list.append([datetime.datetime(2006, 12, 1),"Genf","Switzerland","Meyrin","Meyrin",4,1,-1,0,'Genf V 2006',[]])
data_list.append([datetime.datetime(2006, 12, 3),"Genf","Switzerland","Meyrin","Meyrin",44,1,-1,0,'Genf VI 2006',[]])
data_list.append([datetime.datetime(2006, 12, 9),"Genf","Switzerland","Meyrin","Meyrin",12,1,-1,0,'Genf VII 2006',[]])
data_list.append([datetime.datetime(2006, 12, 10),"Genf","Switzerland","Meyrin","Meyrin",41,1,-1,0,'Genf VIII 2006',[]])
data_list.append([datetime.datetime(2006, 12, 16),"Genf","Switzerland","Meyrin","Meyrin",11,1,-1,0,'Genf IX 2006',[]])

# %%
#2007
data_list.append([datetime.datetime(2007, 1, 13),"Genf","Switzerland","Meyrin","Meyrin",21,1,-1,0,'Genf I 2007',[]])
data_list.append([datetime.datetime(2007, 1, 20),"Genf","Switzerland","Meyrin","Meyrin",40,1,-1,0,'Genf II 2007',[]])
data_list.append([datetime.datetime(2007, 1, 27),"Genf","Switzerland","Meyrin","Meyrin",26,1,-1,0,'Genf III 2007',['Zhiling']])
data_list.append([datetime.datetime(2007, 1, 28),"Genf","Switzerland","Meyrin","Meyrin",21,1,-1,0,'Genf IV 2007',['Zhiling']])
data_list.append([datetime.datetime(2007, 2, 4),"Genf","Switzerland","Meyrin","Meyrin",57,1,-1,0,'Genf V 2007',['Zhiling']])
data_list.append([datetime.datetime(2007, 2, 11),"Genf","Switzerland","Meyrin","Meyrin",22,1,-1,0,'Genf VI 2007',[]])
data_list.append([datetime.datetime(2007, 2, 13),"Cessy","France","Meyrin","Meyrin",34,1,-1,0,"CMS 2007",['Filip']])
data_list.append([datetime.datetime(2007, 2, 17),"Genf","Switzerland","Meyrin","Meyrin",33,1,-1,0,'Genf VII 2007',[]])
data_list.append([datetime.datetime(2007, 2, 18),"Genf","Switzerland","Meyrin","Meyrin",48,1,-1,0,'Genf VIII 2007',[]])
data_list.append([datetime.datetime(2007, 2, 24),"Genf","Switzerland","Meyrin","Meyrin",8,1,-1,0,'Genf IX 2007',[]])
data_list.append([datetime.datetime(2007, 3, 4),"Genf","Switzerland","Meyrin","Meyrin",4,1,-1,0,'Genf X 2007',[]])
data_list.append([datetime.datetime(2007, 3, 21),"Zurich","Switzerland","Lauchringen","Lauchringen",65,1,-1,0,'Zurich I 2007',[]])
data_list.append([datetime.datetime(2007, 4, 17),"Genf","Switzerland","Lauchringen",'Genf',2,1,-1,0,'Genf XI 2007',['Heidrun','Artur']])
data_list.append([datetime.datetime(2007, 4, 22),"Singen","Germany","Lauchringen","Lauchringen",4,1,-1,0,'Birnau & Meersburg 2007',['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2007, 4, 22),"Birnau","Germany","Lauchringen","Lauchringen",8,1,-1,0,'Birnau & Meersburg 2007',['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2007, 4, 22),"Meersburg","Germany","Lauchringen","Lauchringen",19,1,-1,0,'Birnau & Meersburg 2007',['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2007, 4, 9),"Lausanne","Switzerland","Genf",'Genf',27,1,-1,0,'Lausanne 2007',[]])
data_list.append([datetime.datetime(2007, 4, 14),"Einsiedeln","Switzerland","Lauchringen","Lauchringen",13,1,-1,0,'Schwyz 2007',['Artur','Heidrun','Hannsjoerg']])
data_list.append([datetime.datetime(2007, 4, 14),"Schwyz","Switzerland","Lauchringen","Lauchringen",18,1,-1,0,'Schwyz 2007',['Artur','Heidrun','Hannsjoerg']])
data_list.append([datetime.datetime(2007, 5, 4),"Zurich","Switzerland","Lauchringen","Lauchringen",15,1,-1,0,'Zurich II 2007',['Diploma Ceremmony']])
data_list.append([datetime.datetime(2007, 9, 9),"Lausanne","Switzerland","Genf","Genf",93,1,-1,0,'Lausanne and Montreux 2007',[]])
data_list.append([datetime.datetime(2007, 9, 9),"Villeneuve","Switzerland","Genf","Genf",6,1,-1,0,'Lausanne and Montreux 2007',[]])
data_list.append([datetime.datetime(2007, 9, 9),"Veytaux","Switzerland","Genf","Genf",53,1,-1,0,'Lausanne and Montreux 2007',[]])
data_list.append([datetime.datetime(2007, 9, 9),"Montreux","Switzerland","Genf","Genf",1,1,-1,0,'Lausanne and Montreux 2007',[]])
data_list.append([datetime.datetime(2007, 11, 9),"Aarau","Switzerland","Genf","Genf",1,0,-1,0,'Aarau 2007',[]])
data_list.append([datetime.datetime(2007, 12, 16),"Sion","Switzerland","Genf","Genf",1,1,-1,0,'Zermatt 2007',[]])
data_list.append([datetime.datetime(2007, 12, 16),"Sankt Niklaus","Switzerland","Genf","Genf",1,1,-1,0,'Zermatt 2007',[]])
data_list.append([datetime.datetime(2007, 12, 16),"Randa","Switzerland","Genf","Genf",1,1,-1,0,'Zermatt 2007',[]])
data_list.append([datetime.datetime(2007, 12, 16),"Zermatt","Switzerland","Genf","Genf",120,1,-1,0,'Zermatt 2007',[]])

# %%
#2008
#Dresden
data_list.append([datetime.datetime(2008, 1, 2),"Dresden","Germany","Lauchringen","Dresden",37,0,1,0,'Dresden 2008',['Artur',"Hannsjoerg","Heidrun","Anne-Kathrin"]])
data_list.append([datetime.datetime(2008, 1, 3),"Meissen","Germany","Dresden","Dresden",64,0,-1,0,'Dresden 2008',['Artur',"Hannsjoerg","Heidrun","Anne-Kathrin"]])
data_list.append([datetime.datetime(2008, 1, 3),"Moritzburg","Germany","Dresden","Dresden",6,0,-1,0,'Dresden 2008',['Artur',"Hannsjoerg","Heidrun","Anne-Kathrin"]])
data_list.append([datetime.datetime(2008, 1, 3),"Dresden","Germany","Dresden","Dresden",3,0,-1,0,'Dresden 2008',['Artur',"Hannsjoerg","Heidrun","Anne-Kathrin"]])
data_list.append([datetime.datetime(2008, 1, 4),"Dresden","Germany","Dresden",'Lauchringen',118,0,0,0,'Dresden 2008',['Artur',"Hannsjoerg","Heidrun","Anne-Kathrin"]])
#naefels
data_list.append([datetime.datetime(2008, 1, 13),"Naefels","Switzerland","Naefels","Naefels",3,0,-1,0,'CHIPP 2008',[]])
data_list.append([datetime.datetime(2008, 1, 17),"Naefels","Switzerland","Naefels","Naefels",6,0,-1,0,'CHIPP 2008',[]])
data_list.append([datetime.datetime(2008, 1, 17),"Sankt Gallen","Switzerland","Naefels","Naefels",32,0,-1,0,'CHIPP 2008',[]])
##
data_list.append([datetime.datetime(2008, 3, 5),"Neuchatel","Switzerland","Genf","Genf",6,1,-1,0,"Switzerland I 2008",["Zhiling"]])
data_list.append([datetime.datetime(2008, 3, 5),"Solothurn","Switzerland","Genf","Genf",36,1,-1,0,"Switzerland I 2008",["Zhiling"]])
data_list.append([datetime.datetime(2008, 3, 5),"Bern","Switzerland","Genf","Genf",32,1,-1,0,"Switzerland I 2008",["Zhiling"]])
data_list.append([datetime.datetime(2008, 3, 5),"Sion","Switzerland","Genf","Genf",33,1,-1,0,"Switzerland I 2008",["Zhiling"]])
data_list.append([datetime.datetime(2008, 3, 5),"Lausanne","Switzerland","Genf","Genf",16,1,-1,0,"Switzerland I 2008",["Zhiling"]])
data_list.append([datetime.datetime(2008, 3, 14),"Lausanne","Switzerland","Genf","Genf",3,1,-1,0,"Switzerland II 2008",['Wieland','Sofie',"Kostas",'Filip','Joanna','Fabian','Pedja']])
data_list.append([datetime.datetime(2008, 4, 5),"Cessy","France","Genf","Genf",16,0,-1,0,'CMS 2008',['Artur',"Hannsjoerg","Heidrun"]])
data_list.append([datetime.datetime(2008, 7, 19),"Annecy","France","Genf","Genf",20,1,-1,0,'Annecy 2008',['Artur',"Hannsjoerg","Heidrun"]])
#philadelphia
data_list.append([datetime.datetime(2008, 7, 28),"Frankfurt","Germany","Genf","Philadelphia",1,0,0,1,'Philadelphia ICHEP 2008',[]])
data_list.append([datetime.datetime(2008, 7, 28),"Philadelphia","USA","Philadelphia","Philadelphia",2,0,-1,0,'Philadelphia ICHEP 2008',[]])
data_list.append([datetime.datetime(2008, 7, 29),"Philadelphia","USA","Philadelphia","Philadelphia",78,0,-1,0,'Philadelphia ICHEP 2008',[]])
data_list.append([datetime.datetime(2008, 7, 30),"Philadelphia","USA","Philadelphia","Philadelphia",11,0,-1,0,'Philadelphia ICHEP 2008',[]])
data_list.append([datetime.datetime(2008, 8, 2),"Philadelphia","USA","Philadelphia","Philadelphia",3,0,-1,0,'Philadelphia ICHEP 2008',[]])
data_list.append([datetime.datetime(2008, 8, 4),"Philadelphia","USA","Philadelphia","Philadelphia",52,0,-1,0,'Philadelphia ICHEP 2008',[]])
data_list.append([datetime.datetime(2008, 8, 5),"Philadelphia","USA","Philadelphia","Philadelphia",8,0,-1,0,'Philadelphia ICHEP 2008',[]])
data_list.append([datetime.datetime(2008, 8, 6),"Philadelphia","USA","Philadelphia","Philadelphia",7,0,-1,0,'Philadelphia ICHEP 2008',[]])
data_list.append([datetime.datetime(2008, 8, 7),"Frankfurt","Germany","Philadelphia","Genf",25,0,1,2,'Philadelphia ICHEP 2008',[]])
##
data_list.append([datetime.datetime(2008, 8, 5),"Lauchringen","Germany","Lauchringen","Lauchringen",6,1,-1,0,'Lauchringen I 2008',['Heidrun','Artur','Hannsjoerg','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(2008, 8, 6),"Lauchringen","Germany","Lauchringen",'Genf',1,1,1,0,'Lauchringen I 2008',['Heidrun','Artur','Hannsjoerg','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(2008, 8, 16),"Tiengen","Germany","Lauchringen","Lauchringen",59,1,-1,0,'Lauchringen II 2008',['Anne-Kathrin','Hannsjoerg']])
##Madrid
data_list.append([datetime.datetime(2008, 9, 2),"Madrid","Spain",'Genf',"Madrid",2,0,1,1,'Madrid 2008',['Artur',"Hannsjoerg","Heidrun"]])
data_list.append([datetime.datetime(2008, 9, 3),"Madrid","Spain","Madrid","Madrid",19,0,-1,0,'Madrid 2008',['Artur',"Hannsjoerg","Heidrun"]])
data_list.append([datetime.datetime(2008, 9, 4),"Madrid","Spain","Madrid","Madrid",105,0,-1,0,'Madrid 2008',['Artur',"Hannsjoerg","Heidrun"]])
data_list.append([datetime.datetime(2008, 9, 5),"Madrid","Spain","Madrid","Madrid",18,0,-1,0,'Madrid 2008',['Artur',"Hannsjoerg","Heidrun"]])
data_list.append([datetime.datetime(2008, 9, 5),"El Escorial","Spain","Madrid","Madrid",23,0,-1,0,'Madrid 2008',['Artur',"Hannsjoerg","Heidrun"]])
data_list.append([datetime.datetime(2008, 9, 6),"Madrid","Spain","Madrid","Madrid",7,0,-1,0,'Madrid 2008',['Artur',"Hannsjoerg","Heidrun"]])
data_list.append([datetime.datetime(2008, 9, 6),"Segovia","Spain","Madrid","Madrid",112,0,-1,0,'Madrid 2008',["Heidrun"]])
data_list.append([datetime.datetime(2008, 9, 7),"Madrid","Spain","Madrid","Madrid",54,0,-1,0,'Madrid 2008',['Artur',"Hannsjoerg","Heidrun"]])
data_list.append([datetime.datetime(2008, 9, 8),"Madrid","Spain","Madrid","Madrid",50,0,-1,0,'Madrid 2008',['Artur',"Hannsjoerg","Heidrun"]])
data_list.append([datetime.datetime(2008, 9, 9),"Madrid","Spain","Madrid",'Genf',24,0,0,2,'Madrid 2008',['Artur',"Hannsjoerg","Heidrun"]])
##
data_list.append([datetime.datetime(2008, 10, 6),"Lauterbrunnen","Switzerland","Genf","Genf",29,1,-1,0,'Jungfraujoch 2008',['Anne F','Sigi']])
data_list.append([datetime.datetime(2008, 10, 6),"Grindelwald","Switzerland","Genf","Genf",12,1,-1,0,'Jungfraujoch 2008',['Anne F','Sigi']])
data_list.append([datetime.datetime(2008, 10, 6),"Fieschertal","Switzerland","Genf","Genf",67,1,-1,0,'Jungfraujoch 2008',['Anne F','Sigi']])
data_list.append([datetime.datetime(2008, 11, 28),"Fieschertal","Switzerland","Genf","Genf",10,1,-1,0,'Jungfraujoch 2008',[]])
##Nuernberg
data_list.append([datetime.datetime(2008, 11, 29),"Nuernberg","Germany","Lauchringen","Nuernberg",73,0,1,0,'Nuernberg 2008',['Artur',"Hannsjoerg","Heidrun"]])
data_list.append([datetime.datetime(2008, 11, 30),"Nuernberg","Germany","Nuernberg","Nuernberg",108,0,-1,0,'Nuernberg 2008',['Artur',"Hannsjoerg","Heidrun"]])
data_list.append([datetime.datetime(2008, 12, 1),"Nuernberg","Germany","Nuernberg","Lauchringen",24,0,0,0,'Nuernberg 2008',['Artur',"Hannsjoerg","Heidrun"]])
##
data_list.append([datetime.datetime(2008, 12, 2),"Sankt Blasien","Germany","Lauchringen","Lauchringen",28,1,-1,0,'Lauchringen III 2008',['Artur',"Hannsjoerg","Heidrun"]])
data_list.append([datetime.datetime(2008, 12, 19),"Meyrin","Switzerland","Genf","Lauchringen",3,1,0,0,'Meyrin 2008',[]])
data_list.append([datetime.datetime(2008, 12, 19),"Aargau","Switzerland","Genf","Lauchringen",2,1,1,0,'Meyrin 2008',[]])

# %%
#2009
data_list.append([datetime.datetime(2009, 1, 1),"Lauchringen","Germany","Lauchringen","Lauchringen",6,1,-1,0,'Lauchringen I 2009',['Artur',"Hannsjoerg","Heidrun"]])
data_list.append([datetime.datetime(2009, 1, 3),"Lauchringen","Germany","Lauchringen","Lauchringen",1,1,-1,0,'Lauchringen I 2009',['Artur',"Hannsjoerg","Heidrun"]])
data_list.append([datetime.datetime(2009, 1, 3),"Konstanz","Germany","Lauchringen","Lauchringen",84,1,-1,0,'Konstanz and Reichenau 2009',['Artur',"Hannsjoerg","Heidrun"]])
data_list.append([datetime.datetime(2009, 1, 3),"Reichenau","Germany","Lauchringen","Lauchringen",36,1,-1,0,'Konstanz and Reichenau 2009',['Artur',"Hannsjoerg","Heidrun"]])
data_list.append([datetime.datetime(2009, 1, 16),"Tiengen","Germany","Lauchringen","Lauchringen",33,1,-1,0,'Lauchringen II 2009',['Anne-Kathrin',"Hannsjoerg"]])
data_list.append([datetime.datetime(2009, 1, 16),"Lauchringen","Germany","Lauchringen","Lauchringen",2,1,-1,0,'Lauchringen II 2009',['Artur','Heidrun',"Hannsjoerg"]])
data_list.append([datetime.datetime(2009, 1, 21),"Zurich","Switzerland","Genf",'Lauchringen',13,1,0,0,'Zurich I 2009',[]])
data_list.append([datetime.datetime(2009, 2, 1),"Lausanne","Switzerland","Genf","Genf",39,1,-1,0,'Lausanne and Nyon 2009',[]])
data_list.append([datetime.datetime(2009, 2, 1),"Morges","Switzerland","Genf","Genf",8,1,-1,0,'Lausanne and Nyon 2009',[]])
data_list.append([datetime.datetime(2009, 2, 1),"Nyon","Switzerland","Genf","Genf",29,1,-1,0,'Lausanne and Nyon 2009',[]])
data_list.append([datetime.datetime(2009, 2, 21),"Lausanne","Switzerland","Genf","Genf",3,1,-1,0,'Lausanne Fondue 2009',['ETH Crew']])
data_list.append([datetime.datetime(2009, 3, 21),"Basel","Switzerland","Genf","Genf",49,1,-1,0,'Basel and Fribourg 2009',[]])
data_list.append([datetime.datetime(2009, 3, 21),"Fribourg","Switzerland","Genf","Genf",86,1,-1,0,'Basel and Fribourg 2009',[]])
data_list.append([datetime.datetime(2009, 3, 21),"Saint Maurice","Switzerland","Genf","Genf",3,1,-1,0,'Basel and Fribourg 2009',[]])
data_list.append([datetime.datetime(2009, 3, 21),"Neuhausen am Rheinfall","Switzerland","Lauchringen","Lauchringen",108,1,-1,0,'Rheinfall and Rheinau 2009',["Artur"]])
data_list.append([datetime.datetime(2009, 3, 21),"Laufen","Switzerland","Lauchringen","Lauchringen",16,1,-1,0,'Rheinfall and Rheinau 2009',["Artur"]])
data_list.append([datetime.datetime(2009, 3, 21),"Rheinau","Switzerland","Lauchringen","Lauchringen",8,1,-1,0,'Rheinfall and Rheinau 2009',["Artur"]])
#Madrid
data_list.append([datetime.datetime(2009, 4, 25),"Madrid","Spain",'Genf',"Madrid",47,0,1,1,'Madrid DIS 2009',[]])
data_list.append([datetime.datetime(2009, 4, 26),"Madrid","Spain","Madrid","Madrid",6,0,-1,0,'Madrid DIS 2009',[]])
data_list.append([datetime.datetime(2009, 4, 27),"Madrid","Spain","Madrid","Madrid",4,0,-1,0,'Madrid DIS 2009',[]])
data_list.append([datetime.datetime(2009, 4, 28),"Madrid","Spain","Madrid","Madrid",22,0,-1,0,'Madrid DIS 2009',[]])
data_list.append([datetime.datetime(2009, 4, 29),"Getafe","Spain","Madrid","Madrid",19,0,-1,0,'Madrid DIS 2009',[]])
data_list.append([datetime.datetime(2009, 4, 29),"Madrid","Spain","Madrid","Madrid",26,0,-1,0,'Madrid DIS 2009',[]])
data_list.append([datetime.datetime(2009, 4, 29),"Toledo","Spain","Madrid","Madrid",74,0,-1,0,'Madrid DIS 2009',[]])
data_list.append([datetime.datetime(2009, 4, 30),"Madrid","Spain","Madrid","Madrid",14,0,-1,0,'Madrid DIS 2009',[]])
##
data_list.append([datetime.datetime(2009, 5, 16),"Lauchringen","Germany","Lauchringen","Lauchringen",111,1,-1,0,'Lauchringen II 2009',["Artur",'Heidrun','Anne-Kathrin','Hannsjoerg','Marion','Franziska','Jan-Marc']])
data_list.append([datetime.datetime(2009, 5, 16),"Breitenfeld","Germany","Lauchringen","Lauchringen",58,1,-1,0,'Lauchringen II 2009',["Artur",'Heidrun','Anne-Kathrin','Hannsjoerg','Marion','Franziska','Jan-Marc']])
data_list.append([datetime.datetime(2009, 5, 31),"Coppet","Switzerland","Genf","Genf",6,1,-1,0,'Coppet 2009',[]])
data_list.append([datetime.datetime(2009, 6, 6),"Bechtersbohl","Germany","Lauchringen","Lauchringen",50,1,-1,0,'Kuessaburg 2009',["Artur"]])
#CTEQ NYC
data_list.append([datetime.datetime(2009, 6, 23),"Paris","France","Genf",'Madison',3,0,0,1,'USA CTEQ 2009',[]])
data_list.append([datetime.datetime(2009, 6, 23),"Hebron","USA","Genf",'Madison',2,0,1,1,'USA CTEQ 2009',[]])
data_list.append([datetime.datetime(2009, 6, 24),"Madison","USA","Madison","Madison",39,0,-1,0,'USA CTEQ 2009',[]])
data_list.append([datetime.datetime(2009, 6, 25),"Madison","USA","Madison","Madison",21,0,-1,0,'USA CTEQ 2009',[]])
data_list.append([datetime.datetime(2009, 6, 26),"Madison","USA","Madison","Madison",7,0,-1,0,'USA CTEQ 2009',[]])
data_list.append([datetime.datetime(2009, 6, 27),"Madison","USA","Madison","Madison",3,0,-1,0,'USA CTEQ 2009',[]])
data_list.append([datetime.datetime(2009, 6, 28),"Chicago","USA","Madison","Madison",295,0,-1,0,'USA CTEQ 2009',[]])
data_list.append([datetime.datetime(2009, 7, 1),"Madison","USA","Madison","Madison",2,0,-1,0,'USA CTEQ 2009',[]])
data_list.append([datetime.datetime(2009, 7, 2),"Madison","USA","Madison","Madison",3,0,-1,0,'USA CTEQ 2009',[]])
data_list.append([datetime.datetime(2009, 7, 3),"Madison","USA","Madison","New York City",1,0,0,1,'USA CTEQ 2009',[]])
data_list.append([datetime.datetime(2009, 7, 3),"New York City","USA","Madison","New York City",105,0,1,1,'USA CTEQ 2009',[]])
data_list.append([datetime.datetime(2009, 7, 4),"New York City","USA","New York City","New York City",211,0,-1,0,'USA CTEQ 2009',[]])
data_list.append([datetime.datetime(2009, 7, 4),"New York City","USA","New York City","New York City",48,0,-1,0,'USA CTEQ 2009',['Kendal']])
data_list.append([datetime.datetime(2009, 7, 5),"New York City","USA","New York City","New York City",244,0,-1,0,'USA CTEQ 2009',[]])
data_list.append([datetime.datetime(2009, 7, 6),"New York City","USA","New York City","New York City",101,0,-1,0,'USA CTEQ 2009',[]])
data_list.append([datetime.datetime(2009, 7, 7),"New York City","USA","New York City","New York City",158,0,-1,0,'USA CTEQ 2009',[]])
data_list.append([datetime.datetime(2009, 7, 7),"Jersey City","USA","New York City","New York City",17,0,-1,0,'USA CTEQ 2009',[]])
data_list.append([datetime.datetime(2009, 7, 7),"New York City","USA","New York City","New York City",9,0,-1,0,'USA CTEQ 2009',['Kendal']])
data_list.append([datetime.datetime(2009, 7, 8),"New York City","USA","New York City",'Genf',18,0,0,2,'USA CTEQ 2009',[]])
##
data_list.append([datetime.datetime(2009, 7, 26),"Saint Maurice","Switzerland","Genf","Genf",23,1,-1,0,'Valais 2009',[]])
data_list.append([datetime.datetime(2009, 7, 26),"Sion","Switzerland","Genf","Genf",47,1,-1,0,'Valais 2009',[]])
data_list.append([datetime.datetime(2009, 7, 26),"Saint Leonhard","Switzerland","Genf","Genf",47,1,-1,0,'Valais 2009',[]])
data_list.append([datetime.datetime(2009, 7, 26),"Brig","Switzerland","Genf","Genf",25,1,-1,0,'Valais 2009',[]])
data_list.append([datetime.datetime(2009, 8, 13),"Zurich","Switzerland","Genf","Genf",8,0,-1,0,'Zurich II 2009',[]])
data_list.append([datetime.datetime(2009, 8, 15),"Schaffhausen","Switzerland","Lauchringen",'Lauchringen',7,1,-1,0,'Schaffhausen 2009',["Jan-Marc",'Hannsjoerg','Franziska','Anne-Kathrin']])
data_list.append([datetime.datetime(2009, 8, 16),"Wutach","Germany","Lauchringen","Lauchringen",33,1,-1,0,'Wutachschlucht 2009',["Artur",'Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2009, 8, 23),"Zermatt","Switzerland","Genf","Genf",142,1,-1,0,'Zermatt 2009',[]])
data_list.append([datetime.datetime(2009, 8, 23),"Randa","Switzerland","Genf","Genf",3,1,-1,0,'Zermatt 2009',[]])
data_list.append([datetime.datetime(2009, 8, 30),"Brienz","Switzerland","Genf","Genf",3,1,-1,0,'Aareschlucht and Truemmelbachfaelle 2009',[]])
data_list.append([datetime.datetime(2009, 8, 30),"Meiringen","Switzerland","Genf","Genf",62,1,-1,0,'Aareschlucht and Truemmelbachfaelle 2009',[]])
data_list.append([datetime.datetime(2009, 8, 30),"Lauterbrunnen","Switzerland","Genf","Genf",10,1,-1,0,'Aareschlucht and Truemmelbachfaelle 2009',[]])
data_list.append([datetime.datetime(2009, 8, 30),"Stechelberg","Switzerland","Genf","Genf",42,1,-1,0,'Aareschlucht and Truemmelbachfaelle 2009',[]])
data_list.append([datetime.datetime(2009, 8, 30),"Thun","Switzerland","Genf","Genf",15,1,-1,0,'Aareschlucht and Truemmelbachfaelle 2009',[]])
## SPS Innsbruck
data_list.append([datetime.datetime(2009, 9, 1),"Sargans","Switzerland","Genf","Innsbruck",90,1,1,0,'SPS and OEPG 2009',[]])
data_list.append([datetime.datetime(2009, 9, 1),"Innsbruck","Austria","Genf","Innsbruck",90,0,1,0,'SPS and OEPG 2009',[]])
data_list.append([datetime.datetime(2009, 9, 3),"Innsbruck","Austria","Innsbruck","Innsbruck",7,0,-1,0,'SPS and OEPG 2009',[]])
data_list.append([datetime.datetime(2009, 9, 4),"Innsbruck","Austria","Innsbruck","Innsbruck",26,0,-1,0,'SPS and OEPG 2009',[]])
data_list.append([datetime.datetime(2009, 9, 5),"Innsbruck","Austria","Innsbruck","Genf",127,0,0,0,'SPS and OEPG 2009',[]])
data_list.append([datetime.datetime(2009, 9, 5),"Telfs","Austria","Innsbruck","Genf",8,0,0,0,'SPS and OEPG 2009',[]])
data_list.append([datetime.datetime(2009, 9, 5),"Feldkirch","Austria","Innsbruck","Genf",9,0,0,0,'SPS and OEPG 2009',[]])
##
data_list.append([datetime.datetime(2009, 11, 26),"Bern","Switzerland","Genf","Genf",47,1,-1,0,'Bern 2009',[]])
##Karlsruhe
data_list.append([datetime.datetime(2009, 12, 18),"Karlsruhe","Germany","Lauchringen",'Karlsruhe',34,0,1,0,'Karlsruhe 2009',["Anne-Kathrin"]])
data_list.append([datetime.datetime(2009, 12, 19),"Mainz","Germany","Karlsruhe",'Karlsruhe',29,0,-1,0,'Karlsruhe 2009',["Anne-Kathrin"]])
data_list.append([datetime.datetime(2009, 12, 19),"Frankfurt","Germany","Karlsruhe",'Karlsruhe',62,0,-1,0,'Karlsruhe 2009',["Anne-Kathrin"]])
data_list.append([datetime.datetime(2009, 12, 20),"Speyer","Germany","Karlsruhe",'Karlsruhe',35,0,-1,0,'Karlsruhe 2009',["Anne-Kathrin"]])
data_list.append([datetime.datetime(2009, 12, 20),"Mannheim","Germany","Karlsruhe",'Karlsruhe',17,0,-1,0,'Karlsruhe 2009',["Anne-Kathrin"]])
data_list.append([datetime.datetime(2009, 12, 20),"Worms","Germany","Karlsruhe",'Karlsruhe',38,0,-1,0,'Karlsruhe 2009',[]])
data_list.append([datetime.datetime(2009, 12, 21),"Heidelberg","Germany","Karlsruhe",'Karlsruhe',102,0,-1,0,'Karlsruhe 2009',[]])

# %%
#2010
data_list.append([datetime.datetime(2010, 1, 6),"Hoechenschwand","Germany","Lauchringen","Lauchringen",5,0,-1,0,'Lauchringen I 2010',["Artur",'Anne-Kathrin']])
#ASCONA
data_list.append([datetime.datetime(2010, 1, 18),"Ascona","Switzerland","Ascona","Ascona",18,0,-1,0,'CHIPP 2010',["CHIPP School 2010"]])
data_list.append([datetime.datetime(2010, 1, 19),"Ascona","Switzerland","Ascona","Ascona",30,0,-1,0,'CHIPP 2010',["CHIPP School 2010"]])
data_list.append([datetime.datetime(2010, 1, 21),"Ascona","Switzerland","Ascona","Ascona",2,0,-1,0,'CHIPP 2010',["CHIPP School 2010"]])
data_list.append([datetime.datetime(2010, 1, 21),"Locarno","Switzerland","Ascona","Ascona",1,0,-1,0,'CHIPP 2010',["CHIPP School 2010"]])
data_list.append([datetime.datetime(2010, 1, 21),"Bellinzona","Switzerland","Ascona","Ascona",67,0,-1,0,'CHIPP 2010',["CHIPP School 2010"]])
data_list.append([datetime.datetime(2010, 1, 24),"Lugano","Switzerland","Ascona","Ascona",21,0,0,0,'CHIPP 2010',[]])
data_list.append([datetime.datetime(2010, 1, 24),"Como","Italy","Ascona",'Genf',40,0,0,0,'CHIPP 2010',[]])
##
data_list.append([datetime.datetime(2010, 2, 5),"Chamonix","France","Genf","Chamonix",48,0,1,0,'Chamonix I 2010',["ETH Ski outing"]])
data_list.append([datetime.datetime(2010, 2, 6),"Chamonix","France","Chamonix","Genf",155,0,0,0,'Chamonix I 2010',["ETH Ski outing"]])
data_list.append([datetime.datetime(2010, 2, 6),"Argentiere","France","Chamonix",'Genf',28,0,0,0,'Chamonix I 2010',["ETH Ski outing"]])
data_list.append([datetime.datetime(2010, 2, 8),"Zurich","Switzerland","Lauchringen","Lauchringen",6,1,-1,0,'Lauchringen II 2010',[]])
data_list.append([datetime.datetime(2010, 3, 25),"Zurich","Switzerland","Lauchringen","Genf",21,1,0,0,'Lauchringen III 2010',[]])
##Bavaria
data_list.append([datetime.datetime(2010, 4, 5),"Schwangau","Germany","Lauchringen","Schwangau",77,0,1,0,'Bavaria 2010',["Hannsjoerg"]])
data_list.append([datetime.datetime(2010, 4, 5),"Steingaden","Germany","Lauchringen","Schwangau",31,0,1,0,'Bavaria 2010',["Hannsjoerg"]])
data_list.append([datetime.datetime(2010, 4, 5),"Fuessen","Germany","Lauchringen","Schwangau",35,0,1,0,'Bavaria 2010',["Hannsjoerg"]])
data_list.append([datetime.datetime(2010, 4, 6),"Ehrwald","Austria","Schwangau","Garmisch-Partenkirchen",2,0,1,0,'Bavaria 2010',["Hannsjoerg"]])
data_list.append([datetime.datetime(2010, 4, 6),"Garmisch-Partenkirchen","Germany","Schwangau","Garmisch-Partenkirchen",112,0,1,0,'Bavaria 2010',["Hannsjoerg"]])
data_list.append([datetime.datetime(2010, 4, 6),"Ettal","Germany","Schwangau","Garmisch-Partenkirchen",73,0,1,0,'Bavaria 2010',["Hannsjoerg"]])
data_list.append([datetime.datetime(2010, 4, 6),"Grainau","Germany","Schwangau","Garmisch-Partenkirchen",14,0,1,0,'Bavaria 2010',["Hannsjoerg"]])
data_list.append([datetime.datetime(2010, 4, 7),"Garmisch-Partenkirchen","Germany","Garmisch-Partenkirchen","Munich",3,0,0,0,'Bavaria 2010',["Hannsjoerg"]])
data_list.append([datetime.datetime(2010, 4, 7),"Munich","Germany","Garmisch-Partenkirchen","Munich",153,0,1,0,'Bavaria 2010',["Hannsjoerg"]])
data_list.append([datetime.datetime(2010, 4, 8),"Munich","Germany","Munich","Munich",161,0,-1,0,'Bavaria 2010',["Hannsjoerg"]])
data_list.append([datetime.datetime(2010, 4, 9),"Augsburg","Germany","Munich",'Lauchringen',47,0,0,0,'Bavaria 2010',["Hannsjoerg"]])
data_list.append([datetime.datetime(2010, 4, 9),"Ulm","Germany","Munich",'Lauchringen',19,0,0,0,'Bavaria 2010',["Hannsjoerg"]])
##
data_list.append([datetime.datetime(2010, 4, 9),"Luzern","Switzerland","Lauchringen",'Genf',36,1,0,0,'Lucerne & Rosenlauischlucht 2010',["Hannsjoerg",'Heidrun','Anne-Kathrin','Artur']])
data_list.append([datetime.datetime(2010, 4, 9),"Rosenlaui","Switzerland","Lauchringen",'Genf',70,1,0,0,'Lucerne & Rosenlauischlucht 2010',["Hannsjoerg",'Heidrun','Anne-Kathrin','Artur']])
data_list.append([datetime.datetime(2010, 6, 27),"Fiesch","Switzerland","Genf",'Genf',87,1,-1,0,'Aletsch glacier 2010',[]])
data_list.append([datetime.datetime(2010, 6, 27),"Riederalp","Switzerland","Genf",'Genf',91,1,-1,0,'Aletsch glacier 2010',[]])
data_list.append([datetime.datetime(2010, 7, 11),"Oberwald","Switzerland","Genf",'Genf',94,1,-1,0,'Rhone glacier 2010',[]])
data_list.append([datetime.datetime(2010, 7, 11),"Realp","Switzerland","Genf",'Genf',2,1,-1,0,'Rhone glacier 2010',[]])
##Paris ICHEP
data_list.append([datetime.datetime(2010, 7, 21),"Paris","France","Genf",'Paris',245,0,1,0,"Paris ICHEP 2010",[]])
data_list.append([datetime.datetime(2010, 7, 22),"Paris","France","Paris",'Paris',5,0,-1,0,"Paris ICHEP 2010",[]])
data_list.append([datetime.datetime(2010, 7, 23),"Paris","France","Paris",'Paris',41,0,-1,0,"Paris ICHEP 2010",[]])
data_list.append([datetime.datetime(2010, 7, 24),"Paris","France","Paris",'Paris',3,0,-1,0,"Paris ICHEP 2010",[]])
data_list.append([datetime.datetime(2010, 7, 25),"Versailles","France","Paris",'Paris',262,0,-1,0,"Paris ICHEP 2010",[]])
data_list.append([datetime.datetime(2010, 7, 26),"Paris","France","Paris",'Paris',31,0,-1,0,"Paris ICHEP 2010",[]])
data_list.append([datetime.datetime(2010, 7, 27),"Paris","France","Paris",'Paris',3,0,-1,0,"Paris ICHEP 2010",[]])
data_list.append([datetime.datetime(2010, 7, 28),"Paris","France","Paris",'Paris',1,0,-1,0,"Paris ICHEP 2010",[]])
data_list.append([datetime.datetime(2010, 7, 29),"Chartres","France","Paris",'Paris',105,0,-1,0,"Paris ICHEP 2010",[]])
data_list.append([datetime.datetime(2010, 7, 30),"Fontainebleau","France","Paris",'Paris',83,0,-1,0,"Paris ICHEP 2010",['Artur','Heidrun']])
data_list.append([datetime.datetime(2010, 7, 30),"Paris","France","Paris",'Paris',69,0,-1,0,"Paris ICHEP 2010",['Artur','Heidrun']])
data_list.append([datetime.datetime(2010, 7, 31),"Vincennes","France","Paris",'Paris',43,0,-1,0,"Paris ICHEP 2010",['Artur','Heidrun']])
data_list.append([datetime.datetime(2010, 7, 31),"Saint Denis","France","Paris",'Paris',78,0,-1,0,"Paris ICHEP 2010",['Artur','Heidrun']])
data_list.append([datetime.datetime(2010, 7, 31),"Paris","France","Paris",'Paris',11,0,-1,0,"Paris ICHEP 2010",['Artur','Heidrun']])
data_list.append([datetime.datetime(2010, 7, 31),"Puteaux","France","Paris",'Paris',24,0,-1,0,"Paris ICHEP 2010",['Artur','Heidrun']])
data_list.append([datetime.datetime(2010, 8, 1),"Paris","France","Paris",'Paris',194,0,-1,0,"Paris ICHEP 2010",['Artur','Heidrun']])
data_list.append([datetime.datetime(2010, 8, 2),"Paris","France","Paris",'Paris',274,0,-1,0,"Paris ICHEP 2010",['Artur','Heidrun']])
data_list.append([datetime.datetime(2010, 8, 3),"Paris","France","Paris",'Paris',2,0,-1,0,"Paris ICHEP 2010",['Artur','Heidrun']])
data_list.append([datetime.datetime(2010, 8, 3),"Reims","France","Paris",'Paris',142,0,-1,0,"Paris ICHEP 2010",['Artur','Heidrun']])
data_list.append([datetime.datetime(2010, 8, 4),"Paris","France","Paris",'Genf',81,0,0,0,"Paris ICHEP 2010",['Artur','Heidrun']])
##
data_list.append([datetime.datetime(2010, 8, 8),"Grindelwald","Switzerland","Genf","Genf",242,1,-1,0,'Grindelwald 2010',[]])
data_list.append([datetime.datetime(2010, 8, 21),"Hasel","Germany","Lauchringen","Lauchringen",25,1,-1,0,'Erdmannshoehle 2010',["Artur",'Hannsjoerg']])
data_list.append([datetime.datetime(2010, 8, 22),"Hechingen","Germany","Lauchringen","Lauchringen",42,1,-1,0,'Hohenzollern and Rottweil 2010',["Artur",'Heidrun','Hannsjoerg']])
data_list.append([datetime.datetime(2010, 8, 22),"Rottweil","Germany","Lauchringen","Lauchringen",25,1,-1,0,'Hohenzollern and Rottweil 2010',["Artur",'Heidrun','Hannsjoerg']])
data_list.append([datetime.datetime(2010, 8, 22),"Donaueschingen","Germany","Lauchringen","Lauchringen",1,1,-1,0,'Hohenzollern and Rottweil 2010',["Artur",'Heidrun','Hannsjoerg']])
data_list.append([datetime.datetime(2010, 8, 27),"Les Brenets","Switzerland","Genf","Genf",64,1,-1,0,'Lac des Brenets 2010',["ETH IPP"]])
data_list.append([datetime.datetime(2010, 8, 27),"Le Locle","Switzerland","Genf","Genf",13,1,-1,0,'Lac des Brenets 2010',["ETH IPP"]])
data_list.append([datetime.datetime(2010, 8, 29),"Sankt Niklaus","Switzerland","Genf","Genf",1,1,-1,0,'Zermatt I 2010',[]])
data_list.append([datetime.datetime(2010, 8, 29),"Randa","Switzerland","Genf","Genf",4,1,-1,0,'Zermatt I 2010',[]])
data_list.append([datetime.datetime(2010, 8, 29),"Zermatt","Switzerland","Genf","Genf",375,1,-1,0,'Zermatt I 2010',[]])
data_list.append([datetime.datetime(2010, 9, 4),"Saas Fee","Switzerland","Genf","Genf",247,1,-1,0,'Saas Fee 2010',[]])
data_list.append([datetime.datetime(2010, 9, 4),"Saas Grund","Switzerland","Genf","Genf",93,1,-1,0,'Saas Fee 2010',[]])
data_list.append([datetime.datetime(2010, 9, 4),"Visp","Switzerland","Genf","Genf",1,1,-1,0,'Saas Fee 2010',[]])
data_list.append([datetime.datetime(2010, 9, 5),"Engelberg","Switzerland","Genf","Genf",185,1,-1,0,'Titlis 2010',[]])
data_list.append([datetime.datetime(2010, 9, 12),"Martigny","Switzerland","Genf","Genf",1,1,-1,0,'Chamonix I and Argentiere 2010',[]])
data_list.append([datetime.datetime(2010, 9, 12),"Tour","France","Genf","Genf",3,1,-1,0,'Chamonix I and Argentiere 2010',[]])
data_list.append([datetime.datetime(2010, 9, 12),"Argentiere","France","Genf","Genf",52,1,-1,0,'Chamonix I and Argentiere 2010',[]])
data_list.append([datetime.datetime(2010, 9, 12),"Chamonix","France","Genf","Genf",322,1,-1,0,'Chamonix I and Argentiere 2010',[]])
data_list.append([datetime.datetime(2010, 10, 2),"Chamonix","France","Genf","Genf",117,1,-1,0,'Chamonix II 2010',["Heidrun",'Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2010, 11, 13),"Hoechenschwand","Germany","Lauchringen","Lauchringen",22,1,-1,0,'Hoechenschwand I and St Blasien 2010',["Heidrun",'Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2010, 11, 13),"Sankt Blasien","Germany","Lauchringen","Lauchringen",17,1,-1,0,'Hoechenschwand I and St Blasien 2010',["Heidrun",'Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2010, 12, 23),"Hoechenschwand","Germany","Lauchringen","Lauchringen",18,1,-1,0,'Hoechenschwand II 2010',["Anne-Kathrin","Heidrun",'Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2010, 11, 27),"Randa","Switzerland","Genf","Genf",10,1,-1,0,'Zermatt II and Bern 2010',["Hannsjoerg"]])
data_list.append([datetime.datetime(2010, 11, 27),"Zermatt","Switzerland","Genf","Genf",7,1,-1,0,'Zermatt II and Bern 2010',["Hannsjoerg"]])
data_list.append([datetime.datetime(2010, 11, 27),"Bern","Switzerland","Genf","Genf",15,1,-1,0,'Zermatt II and Bern 2010',["Hannsjoerg"]])
data_list.append([datetime.datetime(2010, 12, 4),"Zermatt","Switzerland","Genf","Genf",158,1,-1,0,'Zermatt III 2010',["Hannsjoerg"]])

# %%
#2011
data_list.append([datetime.datetime(2011, 1, 15),"Montreux","Switzerland","Genf","Genf",4,1,-1,0,'Chateau Chillon 2011',["Hannsjoerg"]])
data_list.append([datetime.datetime(2011, 1, 15),"Veytaux","Switzerland","Genf","Genf",61,1,-1,0,'Chateau Chillon 2011',["Hannsjoerg"]])
data_list.append([datetime.datetime(2011, 1, 16),"Lausanne","Switzerland","Genf","Genf",22,1,-1,0,'Lausanne and Nyon 2011',["Hannsjoerg"]])
data_list.append([datetime.datetime(2011, 1, 16),"Nyon","Switzerland","Genf","Genf",18,1,-1,0,'Lausanne and Nyon 2011',["Hannsjoerg"]])
data_list.append([datetime.datetime(2011, 1, 23),"Milano","Italy","Genf","Genf",77,1,-1,0,'Milano 2011',["Hannsjoerg"]])
##Les Houches
data_list.append([datetime.datetime(2011, 2, 13),"Flegere","France","Genf","Les Houches",25,0,1,0,'Les Houches 2011',["Andreas"]])
data_list.append([datetime.datetime(2011, 2, 13),"Chamonix","France","Genf","Les Houches",61,0,1,0,'Les Houches 2011',["Andreas"]])
data_list.append([datetime.datetime(2011, 2, 13),"Les Houches","France","Genf","Les Houches",23,0,1,0,'Les Houches 2011',[]])
data_list.append([datetime.datetime(2011, 2, 14),"Les Houches","France","Les Houches","Les Houches",13,0,-1,0,'Les Houches 2011',[]])
data_list.append([datetime.datetime(2011, 2, 17),"Les Houches","France","Les Houches","Les Houches",16,0,-1,0,'Les Houches 2011',[]])
data_list.append([datetime.datetime(2011, 2, 17),"Chamonix","France","Les Houches","Les Houches",61,0,-1,0,'Les Houches 2011',[]])
data_list.append([datetime.datetime(2011, 2, 17),"Argentiere","France","Les Houches","Les Houches",45,0,-1,0,'Les Houches 2011',[]])
data_list.append([datetime.datetime(2011, 2, 18),"Les Houches","France","Les Houches","Genf",2,0,0,0,'Les Houches 2011',[]])
##
data_list.append([datetime.datetime(2011, 4, 3),"Lauterbrunnen","Switzerland","Genf","Genf",109,1,-1,0,'Jungfraujoch 2011',[]])
data_list.append([datetime.datetime(2011, 4, 3),"Grindelwald","Switzerland","Genf","Genf",25,1,-1,0,'Jungfraujoch 2011',[]])
data_list.append([datetime.datetime(2011, 4, 3),"Fieschertal","Switzerland","Genf","Genf",90,1,-1,0,'Jungfraujoch 2011',[]])
data_list.append([datetime.datetime(2011, 4, 22),"Breitnau","Germany","Lauchringen","Lauchringen",39,0,-1,0,'Ravennaschlucht and Freiburg 2011',['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2011, 4, 22),"Freiburg","Germany","Lauchringen","Lauchringen",38,0,-1,0,'Ravennaschlucht and Freiburg 2011',['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2011, 4, 25),"Feldberg","Germany","Lauchringen","Lauchringen",24,0,-1,0,'Feldsee 2011',['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2011, 5, 15),"Martigny","Switzerland","Genf","Genf",4,1,-1,0,'Gorge du Trient and Pissevache 2011',['Hannsjoerg']])
data_list.append([datetime.datetime(2011, 5, 15),"Vernayaz","Switzerland","Genf","Genf",62,1,-1,0,'Gorge du Trient and Pissevache 2011',['Hannsjoerg']])
data_list.append([datetime.datetime(2011, 5, 21),"Vallorbe","Switzerland","Genf","Genf",69,1,-1,0,'Vallorbe 2011',['Hannsjoerg',"Heidrun",'Artur']])
data_list.append([datetime.datetime(2011, 5, 22),"Lyon","Switzerland","Genf","Genf",130,1,-1,0,'Lyon 2011',['Hannsjoerg',"Heidrun",'Artur']])
data_list.append([datetime.datetime(2011, 5, 29),"Grindelwald","Switzerland","Genf","Genf",198,1,-1,0,'Grindelwald 2011',['Hannsjoerg']])
data_list.append([datetime.datetime(2011, 5, 29),"Lauterbrunnen","Switzerland","Genf","Genf",95,1,-1,0,'Grindelwald 2011',['Hannsjoerg']])
data_list.append([datetime.datetime(2011, 6, 3),"Bad Saeckingen","Germany","Lauchringen","Lauchringen",23,1,-1,0,'Zoo Basel and Bad Saeckingen 2011',['Hannsjoerg','Heidrun','Artur']])
data_list.append([datetime.datetime(2011, 6, 3),"Stein","Switzerland","Lauchringen","Lauchringen",2,1,-1,0,'Zoo Basel and Bad Saeckingen 2011',['Hannsjoerg','Heidrun','Artur']])
data_list.append([datetime.datetime(2011, 6, 3),"Leibstadt","Switzerland","Lauchringen","Lauchringen",7,1,-1,0,'Zoo Basel and Bad Saeckingen 2011',['Hannsjoerg','Heidrun','Artur']])
data_list.append([datetime.datetime(2011, 6, 3),"Basel","Switzerland","Lauchringen","Lauchringen",162,1,-1,0,'Zoo Basel and Bad Saeckingen 2011',['Hannsjoerg','Heidrun','Artur']])
data_list.append([datetime.datetime(2011, 6, 4),"Mainau","Germany","Lauchringen","Lauchringen",143,1,-1,0,'Mainau 2011',['Hannsjoerg','Heidrun','Artur']])
data_list.append([datetime.datetime(2011, 6, 19),"Randa","Switzerland","Genf","Genf",5,1,-1,0,'Zermatt 2011',['Hannsjoerg']])
data_list.append([datetime.datetime(2011, 6, 19),"Zermatt","Switzerland","Genf","Genf",243,1,-1,0,'Zermatt 2011',['Hannsjoerg']])
data_list.append([datetime.datetime(2011, 6, 19),"Visp","Switzerland","Genf","Genf",1,1,-1,0,'Zermatt 2011',['Hannsjoerg']])
data_list.append([datetime.datetime(2011, 6, 26),"Gadmen","Switzerland","Genf","Genf",141,1,-1,0,'Trift glacier 2011',['Hannsjoerg','Heidrun','Artur']])
data_list.append([datetime.datetime(2011, 7, 3),"Fiesch","Switzerland","Genf","Genf",95,1,-1,0,'Aletsch glacier 2011',['Hannsjoerg']])
data_list.append([datetime.datetime(2011, 7, 3),"Fieschtal","Switzerland","Genf","Genf",67,1,-1,0,'Aletsch glacier 2011',['Hannsjoerg']])
data_list.append([datetime.datetime(2011, 7, 31),"Saas Almagell","Switzerland","Genf","Genf",92,1,-1,0,'Scharzbergchopf 2011',['Hannsjoerg']])
data_list.append([datetime.datetime(2011, 8, 28),"Ludwigsburg","Germany","Lauchringen","Lauchringen",136,1,-1,0,'Ludwigsburg 2011',['Hannsjoerg','Heidrun','Artur']])
data_list.append([datetime.datetime(2011, 9, 3),"Hintertux","Austria","Lauchringen","Fuegen",126,0,1,0,'Fuegen 2011',['Heidrun']])
data_list.append([datetime.datetime(2011, 9, 4),"Zell am Ziller","Austria","Fuegen","Fuegen",14,0,-1,0,'Fuegen 2011',['Heidrun','Artur','Jan-Marc','Franziska','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(2011, 9, 5),"Innsbruck","Austria","Fuegen","Lauchringen",28,0,0,0,'Fuegen 2011',['Heidrun','Artur','Jan-Marc','Franziska','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(2011, 9, 29),"Wuerzburg","Germany","Lauchringen","Bamberg",145,0,1,0,'Frankonia 2011',['Heidrun','Artur']])
data_list.append([datetime.datetime(2011, 9, 29),"Bamberg","Germany","Lauchringen","Bamberg",16,0,1,0,'Frankonia 2011',['Heidrun','Artur']])
data_list.append([datetime.datetime(2011, 9, 30),"Bamberg","Germany","Bamberg","Bamberg",140,0,-1,0,'Frankonia 2011',['Heidrun','Artur']])
data_list.append([datetime.datetime(2011, 9, 30),"Bad Staffelstein","Germany","Bamberg","Bamberg",67,0,-1,0,'Frankonia 2011',['Heidrun','Artur']])
data_list.append([datetime.datetime(2011, 9, 30),"Banz","Germany","Bamberg","Bamberg",27,0,-1,0,'Frankonia 2011',['Heidrun','Artur']])
data_list.append([datetime.datetime(2011, 9, 30),"Coburg","Germany","Bamberg","Bamberg",18,0,-1,0,'Frankonia 2011',['Heidrun','Artur']])
data_list.append([datetime.datetime(2011, 10, 1),"Pommersfelden","Germany","Bamberg","Lauchringen",25,0,0,0,'Frankonia 2011',['Heidrun','Artur']])
data_list.append([datetime.datetime(2011, 10, 1),"Wuerzburg","Germany","Bamberg","Lauchringen",25,0,0,0,'Frankonia 2011',['Heidrun','Artur']])
data_list.append([datetime.datetime(2011, 10, 16),"Chamonix","France","Genf","Genf",142,1,-1,0,'Chamonix 2011',['Hannsjoerg']])
#Wien
data_list.append([datetime.datetime(2011, 12, 27),"Kloten","Switzerland","Lauchringen",'Vienna',1,1,1,1,"Vienna 2011",['Hannsjoerg','Heidrun','Artur']])
data_list.append([datetime.datetime(2011, 12, 27),"Vienna","Austria","Vienna","Vienna",79,0,-1,0,"Vienna 2011",['Hannsjoerg','Heidrun','Artur']])
data_list.append([datetime.datetime(2011, 12, 28),"Vienna","Austria","Vienna","Vienna",107,0,-1,0,"Vienna 2011",['Hannsjoerg','Heidrun','Artur']])
data_list.append([datetime.datetime(2011, 12, 29),"Vienna","Austria","Vienna","Vienna",166,0,-1,0,"Vienna 2011",['Hannsjoerg','Heidrun','Artur']])
data_list.append([datetime.datetime(2011, 12, 30),"Vienna","Austria","Vienna",'Lauchringen',149,0,0,2,"Vienna 2011",['Hannsjoerg','Heidrun','Artur']])

# %%
#2012
data_list.append([datetime.datetime(2012, 1, 13),"Zuerich","Switzerland","Genf","Genf",9,0,-1,0,'Zurich 2012',["Artur",'Heidrun','Hannsjoerg']])
data_list.append([datetime.datetime(2012, 2, 12),"Newark","USA","Genf","Saint Charles",32,0,1,1,"EDIT 2012",['EDIT 2012']])
data_list.append([datetime.datetime(2012, 2, 12),"Chicago","USA","Saint Charles","Saint Charles",2,0,-1,0,"EDIT 2012",['EDIT 2012']])
data_list.append([datetime.datetime(2012, 2, 13),"Batavia","USA","Saint Charles","Saint Charles",3,0,-1,0,"EDIT 2012",['EDIT 2012']])
data_list.append([datetime.datetime(2012, 2, 14),"Batavia","USA","Saint Charles","Saint Charles",33,0,-1,0,"EDIT 2012",['EDIT 2012']])
data_list.append([datetime.datetime(2012, 2, 15),"Batavia","USA","Saint Charles","Saint Charles",3,0,-1,0,"EDIT 2012",['EDIT 2012']])
data_list.append([datetime.datetime(2012, 2, 17),"Batavia","USA","Saint Charles","Saint Charles",1,0,-1,0,"EDIT 2012",['EDIT 2012']])
data_list.append([datetime.datetime(2012, 2, 19),"Chicago","USA","Saint Charles","Saint Charles",127,0,-1,0,"EDIT 2012",['EDIT 2012']])
data_list.append([datetime.datetime(2012, 2, 26),"Washington DC","USA","Saint Charles","Genf",9,0,0,2,"EDIT 2012",['EDIT 2012']])
#prague
data_list.append([datetime.datetime(2012, 5, 11),"Karlstejn","Czech Republic",'Genf',"Prague",20,0,1,1,"Prague 2012",['Artur','Heidrun']])
data_list.append([datetime.datetime(2012, 5, 11),"Prague","Czech Republic",'Genf',"Prague",122,0,1,1,"Prague 2012",['Artur','Heidrun']])
data_list.append([datetime.datetime(2012, 5, 12),"Prague","Czech Republic","Prague","Prague",251,0,-1,0,"Prague 2012",['Artur','Heidrun']])
data_list.append([datetime.datetime(2012, 5, 13),"Prague","Czech Republic","Prague",'Genf',149,0,0,2,"Prague 2012",['Artur','Heidrun']])
##
data_list.append([datetime.datetime(2012, 5, 27),"Brienz","Switzerland","Genf","Genf",78,1,-1,0,'Lake Brienz and Lake Thun 2012',['Hannsjoerg']])
data_list.append([datetime.datetime(2012, 5, 27),"Spiez","Switzerland","Genf","Genf",3,1,-1,0,'Lake Brienz and Lake Thun 2012',['Hannsjoerg']])
data_list.append([datetime.datetime(2012, 5, 27),"Hilterfingen","Switzerland","Genf","Genf",1,1,-1,0,'Lake Brienz and Lake Thun 2012',['Hannsjoerg']])
data_list.append([datetime.datetime(2012, 5, 27),"Oberhofen","Switzerland","Genf","Genf",2,1,-1,0,'Lake Brienz and Lake Thun 2012',['Hannsjoerg']])
data_list.append([datetime.datetime(2012, 5, 27),"Thun","Switzerland","Genf","Genf",2,1,-1,0,'Lake Brienz and Lake Thun 2012',['Hannsjoerg']])
#Blois
data_list.append([datetime.datetime(2012, 5, 31),"Chenonceaux","France","Genf",'Blois',64,0,1,0,"Blois 2012",['Heidrun','Artur']])
data_list.append([datetime.datetime(2012, 5, 31),"Blois","France","Genf",'Blois',5,0,1,0,"Blois 2012",['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2012, 6, 1),"Blois","France","Blois",'Blois',109,0,-1,0,"Blois 2012",['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2012, 6, 1),"Amboise","France","Blois",'Blois',50,0,-1,0,"Blois 2012",['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2012, 6, 1),"Chaumont-sur-Loire","France","Blois",'Blois',41,0,-1,0,"Blois 2012",['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2012, 6, 2),"Cheverny","France","Blois",'Blois',43,0,-1,0,"Blois 2012",['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2012, 6, 2),"Chambord","France","Blois",'Blois',89,0,-1,0,"Blois 2012",['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2012, 6, 2),"Orleans","France","Blois",'Blois',46,0,-1,0,"Blois 2012",['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2012, 6, 3),"Vezelay","France","Blois",'Genf',50,0,0,0,"Blois 2012",['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2012, 6, 3),"Cluny","France","Blois",'Genf',69,0,0,0,"Blois 2012",['Heidrun','Artur','Hannsjoerg']])
##
data_list.append([datetime.datetime(2012, 6, 17),"Sion","Switzerland","Genf",'Genf',10,1,-1,0,'Sion and Leukerbad I 2012',['Hannsjoerg']])
data_list.append([datetime.datetime(2012, 6, 17),"Leukerbad","Switzerland","Genf",'Genf',3,1,-1,0,'Sion and Leukerbad I 2012',['Hannsjoerg']])
data_list.append([datetime.datetime(2012, 6, 17),"Saas-Fee","Switzerland","Genf",'Genf',27,1,-1,0,'Sion and Leukerbad I 2012',['Hannsjoerg']])
data_list.append([datetime.datetime(2012, 7, 22),"Leuk","Switzerland","Genf",'Genf',27,1,-1,0,'Leukerbad II 2012',['Hannsjoerg']])
data_list.append([datetime.datetime(2012, 7, 22),"Leukerbad","Switzerland","Genf",'Genf',20,1,-1,0,'Leukerbad II 2012',['Hannsjoerg']])
##Berlin
data_list.append([datetime.datetime(2012, 7, 24),"Berlin","Germany",'Genf',"Berlin",2,0,1,1,"Berlin 2012",[]])
data_list.append([datetime.datetime(2012, 7, 25),"Berlin","Germany","Berlin","Berlin",230,0,-1,0,"Berlin 2012",[]])
data_list.append([datetime.datetime(2012, 7, 26),"Potsdam","Germany","Berlin","Berlin",205,0,-1,0,"Berlin 2012",[]])
data_list.append([datetime.datetime(2012, 7, 26),"Berlin","Germany","Berlin","Berlin",1,0,-1,0,"Berlin 2012",[]])
data_list.append([datetime.datetime(2012, 7, 27),"Berlin","Germany","Berlin","Berlin",67,0,-1,0,"Berlin 2012",[]])
data_list.append([datetime.datetime(2012, 7, 27),"Potsdam","Germany","Berlin","Berlin",46,0,-1,0,"Berlin 2012",[]])
data_list.append([datetime.datetime(2012, 7, 28),"Potsdam","Germany","Berlin","Berlin",107,0,-1,0,"Berlin 2012",['Gianrico']])
data_list.append([datetime.datetime(2012, 7, 29),"Berlin","Germany","Berlin","Berlin",170,0,-1,0,"Berlin 2012",['Gianrico']])
data_list.append([datetime.datetime(2012, 7, 30),"Berlin","Germany","Berlin","Berlin",172,0,-1,0,"Berlin 2012",[]])
data_list.append([datetime.datetime(2012, 7, 31),"Berlin","Germany","Berlin",'Genf',98,0,0,2,"Berlin 2012",[]])
##
data_list.append([datetime.datetime(2012, 8, 11),"Argentiere","France","Genf","Genf",84,1,-1,0,'Argentiere 2012',['Jacob','Jesse','Dan','Brant']])
data_list.append([datetime.datetime(2012, 8, 18),"Lauterbrunnen","Switzerland","Genf","Genf",51,1,-1,0,'Jungfraujoch 2012',[]])
data_list.append([datetime.datetime(2012, 8, 18),"Grindelwald","Switzerland","Genf","Genf",43,1,-1,0,'Jungfraujoch 2012',['Indara']])
data_list.append([datetime.datetime(2012, 8, 18),"Fieschertal","Switzerland","Genf","Genf",50,1,-1,0,'Jungfraujoch 2012',['Indara']])
data_list.append([datetime.datetime(2012, 8, 18),"Lauterbrunnen","Switzerland","Genf","Genf",4,1,-1,0,'Jungfraujoch 2012',['Indara']])
data_list.append([datetime.datetime(2012, 8, 18),"Interlaken","Switzerland","Genf","Genf",2,1,-1,0,'Jungfraujoch 2012',['Indara','Brant','Jacob','Kate','Stan']])
data_list.append([datetime.datetime(2012, 8, 26),"Meersburg","Germany","Lauchringen","Genf",44,1,0,0,'Meersburg and Pfahlbauten 2012',['Artur','Heidrun','Hannsjoerg']])
data_list.append([datetime.datetime(2012, 8, 26),"Unteruhldingen","Germany","Lauchringen","Genf",21,1,0,0,'Meersburg and Pfahlbauten 2012',['Artur','Heidrun','Hannsjoerg']])
data_list.append([datetime.datetime(2012, 8, 26),"Birnau","Germany","Lauchringen","Genf",12,1,0,0,'Meersburg and Pfahlbauten 2012',['Artur','Heidrun','Hannsjoerg']])
#Lisbon
data_list.append([datetime.datetime(2012, 8, 30),"Oeiras","Portugal","Genf","Lisbon",1,0,1,1,"Lisbon 2012",[]])
data_list.append([datetime.datetime(2012, 8, 30),"Belem","Portugal","Genf","Lisbon",4,0,1,1,"Lisbon 2012",[]])
data_list.append([datetime.datetime(2012, 8, 30),"Lisbon","Portugal","Genf","Lisbon",102,0,1,1,"Lisbon 2012",[]])
data_list.append([datetime.datetime(2012, 8, 31),"Mafra","Portugal","Lisbon","Lisbon",68,0,-1,0,"Lisbon 2012",[]])
data_list.append([datetime.datetime(2012, 8, 31),"Lisbon","Portugal","Lisbon","Lisbon",1,0,-1,0,"Lisbon 2012",[]])
data_list.append([datetime.datetime(2012, 8, 31),"Queluz","Portugal","Lisbon","Lisbon",64,0,-1,0,"Lisbon 2012",[]])
data_list.append([datetime.datetime(2012, 8, 31),"Sintra","Portugal","Lisbon","Lisbon",118,0,-1,0,"Lisbon 2012",[]])
data_list.append([datetime.datetime(2012, 9, 1),"Lisbon","Portugal","Lisbon","Lisbon",28,0,-1,0,"Lisbon 2012",[]])
data_list.append([datetime.datetime(2012, 9, 1),"Sintra","Portugal","Lisbon","Lisbon",74,0,-1,0,"Lisbon 2012",[]])
data_list.append([datetime.datetime(2012, 9, 2),"Belem","Portugal","Lisbon","Lisbon",100,0,-1,0,"Lisbon 2012",["David S"]])
data_list.append([datetime.datetime(2012, 9, 2),"Lisbon","Portugal","Lisbon","Lisbon",2,0,-1,0,"Lisbon 2012",["David S"]])
data_list.append([datetime.datetime(2012, 9, 5),"Lisbon","Portugal","Lisbon","Lisbon",22,0,-1,0,"Lisbon 2012",[]])
data_list.append([datetime.datetime(2012, 9, 6),"Lisbon","Portugal","Lisbon","Lisbon",31,0,-1,0,"Lisbon 2012",[]])
data_list.append([datetime.datetime(2012, 9, 6),"Tomar","Portugal","Lisbon","Lisbon",101,0,-1,0,"Lisbon 2012",[]])
data_list.append([datetime.datetime(2012, 9, 7),"Cascais","Portugal","Lisbon","Lisbon",58,0,-1,0,"Lisbon 2012",[]])
data_list.append([datetime.datetime(2012, 9, 8),"Lisbon","Portugal","Lisbon","Lisbon",13,0,-1,0,"Lisbon 2012",[]])
data_list.append([datetime.datetime(2012, 9, 8),"Porto","Portugal","Lisbon","Lisbon",86,0,-1,0,"Lisbon 2012",[]])
data_list.append([datetime.datetime(2012, 9, 8),"Coimbra","Portugal","Lisbon","Lisbon",101,0,-1,0,"Lisbon 2012",[]])
data_list.append([datetime.datetime(2012, 9, 9),"Lisbon","Portugal","Lisbon",'Genf',125,0,0,2,"Lisbon 2012",[]])
##
data_list.append([datetime.datetime(2012, 9, 16),"Guttannen","Switzerland","Genf",'Genf',88,1,-1,0,'Sidelhorn hike 2012',[]])
data_list.append([datetime.datetime(2012, 9, 16),"Oberwald","Switzerland","Genf",'Genf',8,1,-1,0,'Sidelhorn hike 2012',[]])
#warsaw
data_list.append([datetime.datetime(2012, 9, 28),"Warsaw","Poland",'Genf',"Warsaw",94,0,1,1,"Warsaw 2012",["Eric"]])
data_list.append([datetime.datetime(2012, 9, 29),"Warsaw","Poland","Warsaw","Warsaw",4,0,-1,0,"Warsaw 2012",["Eric"]])
data_list.append([datetime.datetime(2012, 9, 29),"Krakow","Poland","Warsaw","Warsaw",169,0,-1,0,"Warsaw 2012",["Eric"]])
data_list.append([datetime.datetime(2012, 9, 30),"Warsaw","Poland","Warsaw","Warsaw",247,0,-1,0,"Warsaw 2012",["Eric"]])
data_list.append([datetime.datetime(2012, 10, 1),"Warsaw","Poland","Warsaw",'Genf',45,0,0,2,"Warsaw 2012",["Eric"]])
##

# %%
#2013
#amsterdam
data_list.append([datetime.datetime(2013, 1, 2),"Amsterdam","Netherlands",'Lauchringen',"Amsterdam",126,0,1,1,'Amsterdam 2013',['Artur','Heidrun','Hannsjoerg']])
data_list.append([datetime.datetime(2013, 1, 3),"Apeldoorn","Netherlands","Amsterdam","Amsterdam",79,0,-1,0,'Amsterdam 2013',[]])
data_list.append([datetime.datetime(2013, 1, 3),"Amsterdam","Netherlands","Amsterdam","Amsterdam",45,0,-1,0,'Amsterdam 2013',[]])
data_list.append([datetime.datetime(2013, 1, 4),"Den Haag","Netherlands","Amsterdam","Amsterdam",106,0,-1,0,'Amsterdam 2013',['Artur','Heidrun','Hannsjoerg']])
data_list.append([datetime.datetime(2013, 1, 4),"Amsterdam","Netherlands","Amsterdam","Amsterdam",5,0,-1,0,'Amsterdam 2013',['Artur','Heidrun','Hannsjoerg']])
data_list.append([datetime.datetime(2013, 1, 5),"Soestdijk","Netherlands","Amsterdam","Amsterdam",15,0,-1,0,'Amsterdam 2013',[]])
data_list.append([datetime.datetime(2013, 1, 5),"Amsterdam","Netherlands","Amsterdam","Amsterdam",125,0,-1,0,'Amsterdam 2013',[]])
data_list.append([datetime.datetime(2013, 1, 5),"Amsterdam","Netherlands","Amsterdam",'Lauchringen',53,0,0,2,'Amsterdam 2013',['Artur','Heidrun','Hannsjoerg']])
###
data_list.append([datetime.datetime(2013, 2, 10),"Satigny","Switzerland","Genf","Genf",4,1,-1,0,'Satigny walk 2013',['Hannsjoerg']])
##Paris I
data_list.append([datetime.datetime(2013, 3, 21),"Paris","France","Genf","Paris",3,0,1,0,'Paris I 2013',['Andrew']])
data_list.append([datetime.datetime(2013, 3, 22),"Versailles","France","Paris","Paris",199,0,-1,0,'Paris I 2013',['Andrew']])
data_list.append([datetime.datetime(2013, 3, 22),"Paris","France","Paris","Paris",86,0,-1,0,'Paris I 2013',['Andrew']])
data_list.append([datetime.datetime(2013, 3, 23),"Paris","France","Paris","Paris",211,0,-1,0,'Paris I 2013',['Andrew']])
data_list.append([datetime.datetime(2013, 3, 24),"Fontainebleau","France","Paris","Paris",129,0,-1,0,'Paris I 2013',['Andrew']])
data_list.append([datetime.datetime(2013, 3, 24),"Paris","France","Paris","Paris",26,0,-1,0,'Paris I 2013',['Andrew']])
data_list.append([datetime.datetime(2013, 3, 25),"Paris","France","Paris",'Genf',118,0,0,0,'Paris I 2013',['Andrew']])
data_list.append([datetime.datetime(2013, 3, 25),"Saint Denis","France","Paris",'Genf',36,0,0,0,'Paris I 2013',['Andrew']])
##Rom

data_list.append([datetime.datetime(2013, 4, 3),"Rome","Italy",'Genf',"Rome",78,0,1,1,'Rome 2013',['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 4),"Rome","Italy","Rome","Rome",333,0,-1,0,'Rome 2013',['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 4),"Rome","Vatican","Rome","Rome",269,0,-1,0,'Rome 2013',['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 5),"Rome","Italy","Rome","Rome",108,0,-1,0,'Rome 2013',['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 5),"Rome","Vatican","Rome","Rome",187,0,-1,0,'Rome 2013',['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 6),"Rome","Italy","Rome","Rome",260,0,-1,0,'Rome 2013',['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 5),"Rome","Vatican","Rome","Rome",8,0,-1,0,'Rome 2013',['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 7),"Rome","Italy","Rome","Rome",59,0,-1,0,'Rome 2013',['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 8),"Rome","Italy","Rome","Rome",249,0,-1,0,'Rome 2013',['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 9),"Tivoli","Italy","Rome","Rome",229,0,-1,0,'Rome 2013',['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 9),"Rome","Italy","Rome","Rome",69,0,-1,0,'Rome 2013',['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 10),"Rome","Italy","Rome","Rome",66,0,-1,0,'Rome 2013',['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 10),"Ostia","Italy","Rome","Rome",110,0,-1,0,'Rome 2013',['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 11),"Rome","Italy","Rome",'Genf',106,0,0,2,'Rome 2013',['Heidrun']])
###
data_list.append([datetime.datetime(2013, 4, 14),"Grandvaux","Switzerland","Genf","Genf",22,1,-1,0,'Lavaux 2013',['Hannsjoerg']])
data_list.append([datetime.datetime(2013, 5, 1),"Ayze","France","Genf","Genf",26,1,-1,0,'Le Mole 2013',['Pieter','David S','Andrew','Rosana']])
data_list.append([datetime.datetime(2013, 5, 5),"Hermance","Switzerland","Genf","Genf",6,1,-1,0,'Hermance Walk 2013',['Hannsjoerg']])
data_list.append([datetime.datetime(2013, 5, 25),"Lyon","France","Genf","Genf",165,1,-1,0,'Lyon 2013',['Hannsjoerg','Andrew']])
data_list.append([datetime.datetime(2013, 6, 16),"Thoiry","France","Genf","Genf",32,1,-1,0,'Reculet 2013',['Hannsjoerg','Jacob',"Jesse",'Rosana']])
data_list.append([datetime.datetime(2013, 7, 4),"Flegere","France","Genf","Genf",50,1,-1,0,'Lac des Blanc 2013',['Nick','David S','Eve','Pieter','Cameron','Andrew','Chris S']])
data_list.append([datetime.datetime(2013, 7, 7),"Milano","Italy","Genf","Genf",251,1,-1,0,'Milano 2013',['Nick','Andrew']])
##Sweden
data_list.append([datetime.datetime(2013, 7, 15),"Stockholm","Sweden","Stockholm","Stockholm",164,0,-1,0,'Stockholm and Copenhagen EPS 2013',[]])
data_list.append([datetime.datetime(2013, 7, 16),"Drottningholm","Sweden","Stockholm","Stockholm",54,0,-1,0,'Stockholm and Copenhagen EPS 2013',[]])
data_list.append([datetime.datetime(2013, 7, 16),"Ulriksdal","Sweden","Stockholm","Stockholm",19,0,-1,0,'Stockholm and Copenhagen EPS 2013',[]])
data_list.append([datetime.datetime(2013, 7, 16),"Stockholm","Sweden","Stockholm","Stockholm",56,0,-1,0,'Stockholm and Copenhagen EPS 2013',[]])
data_list.append([datetime.datetime(2013, 7, 17),"Soedertalje","Sweden","Stockholm","Stockholm",1,0,-1,0,'Stockholm and Copenhagen EPS 2013',[]])
data_list.append([datetime.datetime(2013, 7, 17),"Mariefred","Sweden","Stockholm","Stockholm",53,0,-1,0,'Stockholm and Copenhagen EPS 2013',[]])
data_list.append([datetime.datetime(2013, 7, 18),"Stockholm","Sweden","Stockholm","Stockholm",20,0,-1,0,'Stockholm and Copenhagen EPS 2013',["EPS folks"]])
data_list.append([datetime.datetime(2013, 7, 20),"Skokloster","Sweden","Stockholm","Stockholm",36,0,-1,0,'Stockholm and Copenhagen EPS 2013',[]])
data_list.append([datetime.datetime(2013, 7, 20),"Stockholm","Sweden","Stockholm","Stockholm",22,0,-1,0,'Stockholm and Copenhagen EPS 2013',[]])
data_list.append([datetime.datetime(2013, 7, 21),"Rosersberg","Sweden","Stockholm","Stockholm",18,0,-1,0,'Stockholm and Copenhagen EPS 2013',[]])
data_list.append([datetime.datetime(2013, 7, 21),"Solna","Sweden","Stockholm","Stockholm",68,0,-1,0,'Stockholm and Copenhagen EPS 2013',[]])
data_list.append([datetime.datetime(2013, 7, 22),"Stockholm","Sweden","Stockholm","Stockholm",137,0,-1,0,'Stockholm and Copenhagen EPS 2013',['Yanyan']])
data_list.append([datetime.datetime(2013, 7, 23),"Stockholm","Sweden","Stockholm","Stockholm",51,0,-1,0,'Stockholm and Copenhagen EPS 2013',["EPS Dinner"]])
#Denmark
data_list.append([datetime.datetime(2013, 7, 25),"Hillerod","Denmark","Copenhagen","Copenhagen",133,0,-1,0,'Stockholm and Copenhagen EPS 2013',[]])
data_list.append([datetime.datetime(2013, 7, 25),"Copenhagen","Denmark","Copenhagen","Copenhagen",174,0,-1,0,'Stockholm and Copenhagen EPS 2013',[]])
data_list.append([datetime.datetime(2013, 7, 26),"Helsingor","Denmark","Copenhagen","Copenhagen",104,0,-1,0,'Stockholm and Copenhagen EPS 2013',[]])
data_list.append([datetime.datetime(2013, 7, 26),"Fredensborg","Denmark","Copenhagen","Copenhagen",70,0,-1,0,'Stockholm and Copenhagen EPS 2013',[]])
data_list.append([datetime.datetime(2013, 7, 26),"Copenhagen","Denmark","Copenhagen","Copenhagen",22,0,-1,0,'Stockholm and Copenhagen EPS 2013',['Susanne']])
data_list.append([datetime.datetime(2013, 7, 27),"Copenhagen","Denmark","Copenhagen","Copenhagen",303,0,-1,0,'Stockholm and Copenhagen EPS 2013',['Susanne']])
data_list.append([datetime.datetime(2013, 7, 28),"Copenhagen","Denmark","Copenhagen",'Genf',180,0,0,2,'Stockholm and Copenhagen EPS 2013',[]])
##Venice
data_list.append([datetime.datetime(2013, 9, 5),"Venice","Italy",'Genf',"Venice",84,0,1,1,'Venice 2013',[]])
data_list.append([datetime.datetime(2013, 9, 6),"Venice","Italy","Venice","Venice",339,0,-1,0,'Venice 2013',[]])
data_list.append([datetime.datetime(2013, 9, 7),"Venice","Italy","Venice","Venice",179,0,-1,0,'Venice 2013',[]])
data_list.append([datetime.datetime(2013, 9, 8),"Venice","Italy","Venice",'Genf',205,0,0,2,'Venice 2013',[]])
##
data_list.append([datetime.datetime(2013, 9, 14),"Riedern am Wald","Germany","Lauchringen","Lauchringen",36,0,-1,0,'Riedern Wedding 2013',['relatives']])
data_list.append([datetime.datetime(2013, 9, 21),"Chamonix","France","Genf","Genf",122,1,-1,0,'Chamonix 2013',['Indara','James']])
data_list.append([datetime.datetime(2013, 9, 28),"Meyrin","Switzerland","Genf","Genf",5,1,-1,0,'LHC Days 2013',['Hannsjoerg','Heidrun','Anne-Kathrin','Artur']])
data_list.append([datetime.datetime(2013, 9, 28),"Saint-Genis-Pouilly","France","Genf","Genf",14,1,-1,0,'LHC Days 2013',['Hannsjoerg','Heidrun','Anne-Kathrin','Artur']])
data_list.append([datetime.datetime(2013, 9, 28),"Prevessin","France","Genf","Genf",2,1,-1,0,'LHC Days 2013',['Hannsjoerg','Heidrun','Anne-Kathrin','Artur']])
data_list.append([datetime.datetime(2013, 9, 30),"Prevessin","France","Genf","Genf",44,1,-1,0,'Bosons and More 2013',['Hannsjoerg','Sarah','Eric','Tom']])
##Paris II
data_list.append([datetime.datetime(2013, 11, 8),"Paris","France","Paris","Paris",65,0,-1,0,'Paris II 2013',["Chris C",'Chris L',"Eric"]])
data_list.append([datetime.datetime(2013, 11, 8),"Compiegne","France","Paris","Paris",55,0,-1,0,'Paris II 2013',["Chris C",'Chris L',"Eric"]])
data_list.append([datetime.datetime(2013, 11, 8),"Chantilly","France","Paris","Paris",60,0,-1,0,'Paris II 2013',["Chris C",'Chris L',"Eric"]])
data_list.append([datetime.datetime(2013, 11, 9),"Paris","France","Paris","Paris",31,0,-1,0,'Paris II 2013',["Chris C",'Chris L',"Eric"]])
data_list.append([datetime.datetime(2013, 11, 9),"Malmaison","France","Paris","Paris",43,0,-1,0,'Paris II 2013',["Eric"]])
data_list.append([datetime.datetime(2013, 11, 9),"Maisons-Lafitte","France","Paris","Paris",30,0,-1,0,'Paris II 2013',["Eric"]])
data_list.append([datetime.datetime(2013, 11, 9),"Paris","France","Paris","Paris",31,0,-1,0,'Paris II 2013',["Eric"]])
data_list.append([datetime.datetime(2013, 11, 10),"Champs-sur-Marne","France","Paris","Paris",66,0,-1,0,'Paris II 2013',["Chris C",'Chris L',"Eric"]])
data_list.append([datetime.datetime(2013, 11, 10),"Vaux-le-Vicomte","France","Paris","Paris",88,0,-1,0,'Paris II 2013',["Chris C",'Chris L',"Eric"]])
data_list.append([datetime.datetime(2013, 11, 11),"Saint Denis","France","Paris",'Genf',49,0,0,0,'Paris II 2013',["Chris C",'Chris L',"Eric"]])
data_list.append([datetime.datetime(2013, 11, 11),"Paris","France","Paris",'Genf',110,0,0,0,'Paris II 2013',["Chris C",'Chris L',"Eric"]])
##
data_list.append([datetime.datetime(2013, 11, 30),"Prangins","Switzerland","Genf",'Genf',32,1,-1,0,'Prangins 2013',["Hannsjoerg"]])
data_list.append([datetime.datetime(2013, 12, 19),"Meyrin","Switzerland","Genf",'Genf',2,1,-1,0,'ATLAS visit 2013',['Sarah']])
data_list.append([datetime.datetime(2013, 12, 27),"Strasbourg","Germany","Lauchringen","Lauchringen",102,1,-1,0,'Strasbourg 2013',["Hannsjoerg",'Heidrun','Artur']])

# %%
#2014
data_list.append([datetime.datetime(2014, 3, 16),"Genthod","Switzerland","Genf","Genf",8,1,-1,0,'Genthod walk 2014',["Hannsjoerg"]])
#Bayern
data_list.append([datetime.datetime(2014, 4, 18),"Meyrin","Switzerland","Genf","Fuessen",3,0,0,1,'Bavaria 2014',["Eric",'Indara']])
data_list.append([datetime.datetime(2014, 4, 18),"Schwangau","Germany","Genf","Fuessen",89,0,1,1,'Bavaria 2014',["Eric",'Indara']])
data_list.append([datetime.datetime(2014, 4, 18),"Fuessen","Germany","Genf","Fuessen",26,0,1,1,'Bavaria 2014',["Eric",'Indara']])
data_list.append([datetime.datetime(2014, 4, 19),"Kempten","Germany","Fuessen","Rosenheim",91,0,0,0,'Bavaria 2014',["Eric",'Indara']])
data_list.append([datetime.datetime(2014, 4, 19),"Steingaden","Germany","Fuessen","Rosenheim",23,0,0,0,'Bavaria 2014',["Eric",'Indara']])
data_list.append([datetime.datetime(2014, 4, 19),"Ettal","Germany","Fuessen","Rosenheim",118,0,0,0,'Bavaria 2014',["Eric",'Indara']])
data_list.append([datetime.datetime(2014, 4, 19),"Garmisch-Partenkirchen","Germany","Fuessen","Rosenheim",52,0,0,0,'Bavaria 2014',["Eric",'Indara']])
data_list.append([datetime.datetime(2014, 4, 19),"Rosenheim","Germany","Fuessen","Rosenheim",5,0,1,0,'Bavaria 2014',["Eric",'Indara']])
data_list.append([datetime.datetime(2014, 4, 20),"Rosenheim","Germany","Rosenheim","Munich",1,0,0,0,'Bavaria 2014',["Eric",'Indara']])
data_list.append([datetime.datetime(2014, 4, 20),"Prien","Germany","Rosenheim","Munich",9,0,0,0,'Bavaria 2014',["Eric",'Indara']])
data_list.append([datetime.datetime(2014, 4, 20),"Herrenchiemsee","Germany","Rosenheim","Munich",66,0,0,0,'Bavaria 2014',["Eric",'Indara']])
data_list.append([datetime.datetime(2014, 4, 20),"Landshut","Germany","Rosenheim","Munich",28,0,1,0,'Bavaria 2014',["Eric",'Indara']])
data_list.append([datetime.datetime(2014, 4, 20),"Munich","Germany","Rosenheim","Munich",22,0,1,0,'Bavaria 2014',["Eric",'Indara']])
data_list.append([datetime.datetime(2014, 4, 21),"Munich","Germany","Munich","Munich",394,0,-1,0,'Bavaria 2014',["Eric",'Indara']])
data_list.append([datetime.datetime(2014, 4, 22),"Schleissheim","Germany","Munich",'Genf',148,0,0,2,'Bavaria 2014',["Eric"]])
data_list.append([datetime.datetime(2014, 4, 22),"Munich","Germany","Munich",'Genf',24,0,0,2,'Bavaria 2014',["Eric",'Indara']])
##
data_list.append([datetime.datetime(2014, 5, 1),"Neuchatel","Switzerland","Genf",'Genf',45,1,-1,0,'Chateau Neuchatel 2014',["Hannsjoerg"]])
data_list.append([datetime.datetime(2014, 5, 4),"Stresa","Italy","Genf",'Genf',206,1,-1,0,'Borromean Islands 2014',["Hannsjoerg"]])
data_list.append([datetime.datetime(2014, 5, 4),"Baveno","Italy","Genf",'Genf',15,1,-1,0,'Borromean Islands 2014',["Hannsjoerg"]])
data_list.append([datetime.datetime(2014, 5, 4),"Domodossola","Italy","Genf",'Genf',6,1,-1,0,'Borromean Islands 2014',["Hannsjoerg"]])
data_list.append([datetime.datetime(2014, 5, 18),"Donaueschingen","Germany","Lauchringen","Lauchringen",16,1,-1,0,'Beuron & Sigmaringen 2014',["Heidrun",'Artur']])
data_list.append([datetime.datetime(2014, 5, 18),"Sigmaringen","Germany","Lauchringen","Lauchringen",21,1,-1,0,'Beuron & Sigmaringen 2014',["Heidrun",'Artur']])
data_list.append([datetime.datetime(2014, 5, 18),"Beuron","Germany","Lauchringen","Lauchringen",29,1,-1,0,'Beuron & Sigmaringen 2014',["Heidrun",'Artur']])
data_list.append([datetime.datetime(2014, 5, 24),"Russin","Switzerland","Genf","Genf",8,1,-1,0,'Gorge du Durnand 2014',["Hannsjoerg"]])
data_list.append([datetime.datetime(2014, 5, 24),"Bourdigny-Dessous","Switzerland","Genf","Genf",5,1,-1,0,'Gorge du Durnand 2014',["Hannsjoerg"]])
data_list.append([datetime.datetime(2014, 5, 29),"Bovernier","Switzerland","Genf","Genf",94,1,-1,0,'Gorge du Durnand 2014',["Hannsjoerg"]])
data_list.append([datetime.datetime(2014, 5, 29),"Martigny","Switzerland","Genf","Genf",2,1,-1,0,'Gorge du Durnand 2014',["Hannsjoerg"]])
data_list.append([datetime.datetime(2014, 6, 8),"Grindelwald","Switzerland","Genf","Genf",75,1,-1,0,'Grindelwald 2014',["Chris M"]])
data_list.append([datetime.datetime(2014, 6, 22),"Meiringen","Switzerland","Genf","Genf",78,1,-1,0,'Aareschlucht & Schloss Oberhofen 2014',["Hannsjoerg"]])
data_list.append([datetime.datetime(2014, 6, 22),"Spiez","Switzerland","Genf","Genf",3,1,-1,0,'Aareschlucht & Schloss Oberhofen 2014',["Hannsjoerg"]])
data_list.append([datetime.datetime(2014, 6, 22),"Oberhofen","Switzerland","Genf","Genf",79,1,-1,0,'Aareschlucht & Schloss Oberhofen 2014',["Hannsjoerg"]])
data_list.append([datetime.datetime(2014, 6, 22),"Thun","Switzerland","Genf","Genf",3,1,-1,0,'Aareschlucht & Schloss Oberhofen 2014',["Hannsjoerg"]])
data_list.append([datetime.datetime(2014, 6, 25),"Cessy","France","Genf","Genf",28,1,-1,0,'CMS Summer Party 2014',["Manuel",'Aaron','Nate','Jesse','Indara','Pieter','David S','Chris M','Eric','Chris C']])
#London I
data_list.append([datetime.datetime(2014, 7, 24),"London","United Kingdom","Genf","London",45,0,1,1,'London and South England 2014',['Heidrun']])
data_list.append([datetime.datetime(2014, 7, 24),"London","United Kingdom","Genf","London",116,0,1,1,'London and South England 2014',['Heidrun','Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(2014, 7, 25),"Windsor","United Kingdom","London","London",87,0,-1,0,'London and South England 2014',['Heidrun']])
data_list.append([datetime.datetime(2014, 7, 25),"Windsor","United Kingdom","London","London",6,0,-1,0,'London and South England 2014',['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2014, 7, 25),"Hatfield","United Kingdom","London","London",72,0,-1,0,'London and South England 2014',['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2014, 7, 25),"London","United Kingdom","London","London",64,0,-1,0,'London and South England 2014',['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2014, 7, 26),"London","United Kingdom","London","London",2,0,-1,0,'London and South England 2014',['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2014, 7, 26),"Seaford","United Kingdom","London","London",64,0,-1,0,'London and South England 2014',["Anne-Kathrin",'Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2014, 7, 26),"Brighton","United Kingdom","London","London",55,0,-1,0,'London and South England 2014',['Heidrun']])
data_list.append([datetime.datetime(2014, 7, 26),"Seaford","United Kingdom","London","London",28,0,-1,0,'London and South England 2014',["Anne-Kathrin",'Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2014, 7, 26),"London","United Kingdom","London","London",1,0,-1,0,'London and South England 2014',["Anne-Kathrin",'Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2014, 7, 27),"London","United Kingdom","London","London",45,0,-1,0,'London and South England 2014',["Anne-Kathrin",'Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2014, 7, 27),"London","United Kingdom","London","London",5,0,-1,0,'London and South England 2014',['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2014, 7, 27),"London","United Kingdom","London","London",76,0,-1,0,'London and South England 2014',['Heidrun']])
data_list.append([datetime.datetime(2014, 7, 28),"London","United Kingdom","London","London",2,0,-1,0,'London and South England 2014',['Heidrun']])
data_list.append([datetime.datetime(2014, 7, 28),"Portsmouth","United Kingdom","London","London",18,0,-1,0,'London and South England 2014',['Heidrun']])
data_list.append([datetime.datetime(2014, 7, 28),"Ryde","United Kingdom","London","London",4,0,-1,0,'London and South England 2014',['Heidrun']])
data_list.append([datetime.datetime(2014, 7, 28),"East Cowes","United Kingdom","London","London",52,0,-1,0,'London and South England 2014',['Heidrun']])
data_list.append([datetime.datetime(2014, 7, 28),"Totland","United Kingdom","London","London",109,0,-1,0,'London and South England 2014',['Heidrun']])
data_list.append([datetime.datetime(2014, 7, 28),"Yarmouth","United Kingdom","London","London",25,0,-1,0,'London and South England 2014',['Heidrun']])
data_list.append([datetime.datetime(2014, 7, 28),"Lymington","United Kingdom","London","London",4,0,-1,0,'London and South England 2014',['Heidrun']])
data_list.append([datetime.datetime(2014, 7, 29),"London","United Kingdom","London","London",97,0,-1,0,'London and South England 2014',['Heidrun']])
data_list.append([datetime.datetime(2014, 7, 29),"London","United Kingdom","London","London",78,0,-1,0,'London and South England 2014',['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2014, 7, 30),"Oxford","United Kingdom","London","London",31,0,-1,0,'London and South England 2014',['Heidrun']])
data_list.append([datetime.datetime(2014, 7, 30),"Oxford","United Kingdom","London","London",73,0,-1,0,'London and South England 2014',['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2014, 7, 30),"Woodstock","United Kingdom","London","London",142,0,-1,0,'London and South England 2014',['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2014, 7, 31),"London","United Kingdom","London","London",50,0,-1,0,'London and South England 2014',['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2014, 7, 31),"London","United Kingdom","London","London",189,0,-1,0,'London and South England 2014',['Heidrun']])
data_list.append([datetime.datetime(2014, 8, 1),"Rochester","United Kingdom","London","London",79,0,-1,0,'London and South England 2014',['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2014, 8, 1),"Canterbury","United Kingdom","London","London",103,0,-1,0,'London and South England 2014',['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2014, 8, 1),"Dover","United Kingdom","London","London",65,0,-1,0,'London and South England 2014',['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2014, 8, 2),"Amesbury","United Kingdom","London","London",22,0,-1,0,'London and South England 2014',['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2014, 8, 2),"Salisbury","United Kingdom","London","London",61,0,-1,0,'London and South England 2014',['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2014, 8, 2),"Bath","United Kingdom","London","London",75,0,-1,0,'London and South England 2014',['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2014, 8, 3),"London","United Kingdom","London","London",265,0,-1,0,'London and South England 2014',['Heidrun']])
data_list.append([datetime.datetime(2014, 8, 4),"London","United Kingdom","London","Genf",44,0,0,2,'London and South England 2014',['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2014, 8, 4),"London","United Kingdom","London","Genf",71,0,0,2,'London and South England 2014',['Hannsjoerg']])
##Wien & Budapest
data_list.append([datetime.datetime(2014, 8, 22),"Vienna","Austria",'Genf',"Vienna",245,0,1,1,'Vienna and Budapest 2014',[]])
data_list.append([datetime.datetime(2014, 8, 23),"Eisenstadt","Austria","Vienna","Vienna",79,0,-1,0,'Vienna and Budapest 2014',[]])
data_list.append([datetime.datetime(2014, 8, 23),"Neusiedl am See","Austria","Vienna","Vienna",1,0,-1,0,'Vienna and Budapest 2014',[]])
data_list.append([datetime.datetime(2014, 8, 23),"Fertoed","Hungary","Vienna","Vienna",102,0,-1,0,'Vienna and Budapest 2014',[]])
data_list.append([datetime.datetime(2014, 8, 23),"Vienna","Austria","Vienna","Vienna",21,0,-1,0,'Vienna and Budapest 2014',[]])
data_list.append([datetime.datetime(2014, 8, 24),"Bratislava","Slovakia","Vienna","Vienna",170,0,-1,0,'Vienna and Budapest 2014',[]])
data_list.append([datetime.datetime(2014, 8, 24),"Devinska Nova Ves","Slovakia","Vienna","Vienna",8,0,-1,0,'Vienna and Budapest 2014',[]])
data_list.append([datetime.datetime(2014, 8, 24),"Engelhartstetten","Austria","Vienna","Vienna",79,0,-1,0,'Vienna and Budapest 2014',[]])
data_list.append([datetime.datetime(2014, 8, 24),"Vienna","Austria","Vienna","Vienna",5,0,-1,0,'Vienna and Budapest 2014',[]])
data_list.append([datetime.datetime(2014, 8, 25),"Vienna","Austria","Vienna","Vienna",14,0,-1,0,'Vienna and Budapest 2014',[]])
data_list.append([datetime.datetime(2014, 8, 26),"Vienna","Austria","Vienna","Vienna",16,0,-1,0,'Vienna and Budapest 2014',[]])
data_list.append([datetime.datetime(2014, 8, 27),"Vienna","Austria","Vienna","Vienna",66,0,-1,0,'Vienna and Budapest 2014',[]])
data_list.append([datetime.datetime(2014, 8, 28),"Vienna","Austria","Vienna","Vienna",279,0,-1,0,'Vienna and Budapest 2014',[]])
data_list.append([datetime.datetime(2014, 8, 29),"Vienna","Austria","Vienna","Budapest",161,0,0,0,'Vienna and Budapest 2014',[]])
data_list.append([datetime.datetime(2014, 8, 29),"Budapest","Hungary","Vienna","Budapest",3,0,1,0,'Vienna and Budapest 2014',[]])
data_list.append([datetime.datetime(2014, 8, 30),"Budapest","Hungary","Budapest","Budapest",221,0,-1,0,'Vienna and Budapest 2014',[]])
data_list.append([datetime.datetime(2014, 8, 30),"Goedoello","Hungary","Budapest","Budapest",47,0,-1,0,'Vienna and Budapest 2014',[]])
data_list.append([datetime.datetime(2014, 8, 31),"Budapest","Hungary","Budapest",'Genf',173,0,0,2,'Vienna and Budapest 2014',[]])
#Toscana & Bologna
data_list.append([datetime.datetime(2014, 9, 6),"Bologna","Italy",'Genf',"Bologna",8,0,1,0,'Bologna and Toscana 2014',[]])
data_list.append([datetime.datetime(2014, 9, 6),"Florence","Italy",'Genf',"Bologna",245,0,1,0,'Bologna and Toscana 2014',[]])
data_list.append([datetime.datetime(2014, 9, 7),"Pisa","Italy","Bologna","Bologna",156,0,-1,0,'Bologna and Toscana 2014',[]])
data_list.append([datetime.datetime(2014, 9, 7),"Florence","Italy","Bologna","Bologna",155,0,-1,0,'Bologna and Toscana 2014',[]])
data_list.append([datetime.datetime(2014, 9, 8),"Bologna","Italy","Bologna","Bologna",8,0,-1,0,'Bologna and Toscana 2014',[]])
data_list.append([datetime.datetime(2014, 9, 9),"Bologna","Italy","Bologna","Bologna",15,0,-1,0,'Bologna and Toscana 2014',[]])
data_list.append([datetime.datetime(2014, 9, 10),"Bologna","Italy","Bologna","Bologna",115,0,-1,0,'Bologna and Toscana 2014',[]])
data_list.append([datetime.datetime(2014, 9, 11),"Bologna","Italy","Bologna","Bologna",152,0,-1,0,'Bologna and Toscana 2014',[]])
data_list.append([datetime.datetime(2014, 9, 12),"Florence","Italy","Bologna","Florence",187,0,1,0,'Bologna and Toscana 2014',[]])
data_list.append([datetime.datetime(2014, 9, 13),"Florence","Italy","Florence","Florence",193,0,-1,0,'Bologna and Toscana 2014',[]])
data_list.append([datetime.datetime(2014, 9, 13),"Siena","Italy","Florence","Florence",151,0,-1,0,'Bologna and Toscana 2014',[]])
data_list.append([datetime.datetime(2014, 9, 14),"Florence","Italy","Florence",'Genf',261,0,0,0,'Bologna and Toscana 2014',[]])
##aris
data_list.append([datetime.datetime(2014, 9, 20),"Paris","France","Paris",'Paris',290,0,-1,0,'Paris 2014',[]])
data_list.append([datetime.datetime(2014, 9, 21),"Paris","France","Paris",'Genf',390,0,0,0,'Paris 2014',[]])
##
data_list.append([datetime.datetime(2014, 10, 4),"Montalchez","Switzerland","Genf","Genf",15,1,-1,0,'Creux du Van 2014',['Bing','Manuel']])
data_list.append([datetime.datetime(2014, 10, 11),"Lauchringen","Germany","Lauchringen","Lauchringen",13,1,-1,0,'Lauchringen I 2014',['relatives']])
#Istanbul
data_list.append([datetime.datetime(2014, 10, 23),"Istanbul","Turkey",'Genf',"Istanbul",4,0,1,1,'Istanbul 2014',['Chris M']])
data_list.append([datetime.datetime(2014, 10, 24),"Istanbul","Turkey","Istanbul","Istanbul",164,0,-1,0,'Istanbul 2014',['Chris M']])
data_list.append([datetime.datetime(2014, 10, 25),"Istanbul","Turkey","Istanbul","Istanbul",301,0,-1,0,'Istanbul 2014',['Chris M']])
data_list.append([datetime.datetime(2014, 10, 26),"Istanbul","Turkey","Istanbul","Istanbul",184,0,-1,0,'Istanbul 2014',['Chris M']])
##
data_list.append([datetime.datetime(2014, 10, 26),"Saas Fee","Switzerland","Genf","Genf",88,1,-1,0,'Saas Fee hike 2014',['Andrew']])
#London II
data_list.append([datetime.datetime(2014, 12, 13),"London","United Kingdom","London","London",114,0,-1,0,'London 2014',['Manuel']])
data_list.append([datetime.datetime(2014, 12, 14),"London","United Kingdom","London","Genf",67,0,0,2,'London 2014',['Manuel']])
data_list.append([datetime.datetime(2014, 12, 14),"Windsor","United Kingdom","London","Genf",15,0,0,2,'London 2014',['Manuel']])
##

# %%
#2015
data_list.append([datetime.datetime(2015, 1, 11),"Veytaux","Switzerland","Genf","Genf",51,1,-1,0,'Chateau Chillon 2015',['Eric','Siyi']])
data_list.append([datetime.datetime(2015, 1, 11),"Montreux","Switzerland","Genf","Genf",4,1,-1,0,'Chateau Chillon 2015',['Eric','Siyi']])
#MILAN
data_list.append([datetime.datetime(2015, 3, 13),"Milano","Italy","Genf",'Milano',65,0,1,0,'Milano 2015',['Nate','Laser','Kennedy','Can Y',"Devin",'Aaron','Christine M']])
data_list.append([datetime.datetime(2015, 3, 13),"Monza","Italy","Genf",'Milano',57,0,1,0,'Milano 2015',['Nate','Laser','Kennedy','Can Y',"Devin",'Aaron','Christine M']])
data_list.append([datetime.datetime(2015, 3, 14),"Milano","Italy","Milano",'Genf',188,0,0,0,'Milano 2015',['Nate','Kennedy','Can Y',"Devin",'Aaron','Christine M']])
##Spain
data_list.append([datetime.datetime(2015, 3, 28),"Madrid","Spain","Madrid","Cordoba",6,0,0,0,'Spain 2015',[]])
data_list.append([datetime.datetime(2015, 3, 28),"Madrid","Spain","Madrid","Cordoba",27,0,0,0,'Spain 2015',['Manuel']])
data_list.append([datetime.datetime(2015, 3, 29),"Sevilla","Spain","Cordoba","Cordoba",192,0,-1,0,'Spain 2015',['Manuel']])
data_list.append([datetime.datetime(2015, 3, 30),"Granada","Spain","Cordoba","Cordoba",222,0,-1,0,'Spain 2015',['Manuel']])
data_list.append([datetime.datetime(2015, 3, 30),"Cordoba","Spain","Cordoba","Cordoba",1,0,-1,0,'Spain 2015',['Manuel']])
data_list.append([datetime.datetime(2015, 3, 31),"Cordoba","Spain","Cordoba","Madrid",128,0,0,0,'Spain 2015',['Manuel']])
data_list.append([datetime.datetime(2015, 4, 1),"Madrid","Spain","Madrid","Madrid",12,0,-1,0,'Spain 2015',['Manuel']])
data_list.append([datetime.datetime(2015, 4, 1),"Segovia","Spain","Madrid","Madrid",118,0,-1,0,'Spain 2015',['Manuel']])
data_list.append([datetime.datetime(2015, 4, 1),"La Granja","Spain","Madrid","Madrid",80,0,-1,0,'Spain 2015',['Manuel']])
data_list.append([datetime.datetime(2015, 4, 2),"Madrid","Spain","Madrid","Madrid",11,0,-1,0,'Spain 2015',['Manuel']])
data_list.append([datetime.datetime(2015, 4, 2),"Toledo","Spain","Madrid","Madrid",146,0,-1,0,'Spain 2015',['Manuel']])
data_list.append([datetime.datetime(2015, 4, 3),"El Escorial","Spain","Madrid","Madrid",54,0,-1,0,'Spain 2015',['Manuel']])
data_list.append([datetime.datetime(2015, 4, 3),"Madrid","Spain","Madrid","Madrid",26,0,-1,0,'Spain 2015',['Manuel']])
data_list.append([datetime.datetime(2015, 4, 4),"Cordoba","Spain","Madrid","Madrid",113,0,-1,0,'Spain 2015',[]])
data_list.append([datetime.datetime(2015, 4, 4),"Sevilla","Spain","Madrid","Madrid",90,0,-1,0,'Spain 2015',[]])
data_list.append([datetime.datetime(2015, 4, 4),"Madrid","Spain","Madrid","Madrid",6,0,-1,0,'Spain 2015',['Eric']])
data_list.append([datetime.datetime(2015, 4, 5),"Aranjuez","Spain","Madrid","Madrid",66,0,-1,0,'Spain 2015',['Eric']])
data_list.append([datetime.datetime(2015, 4, 5),"El Pardo","Spain","Madrid","Madrid",11,0,-1,0,'Spain 2015',['Eric']])
data_list.append([datetime.datetime(2015, 4, 5),"Madrid","Spain","Madrid","Madrid",47,0,-1,0,'Spain 2015',['Eric']])
data_list.append([datetime.datetime(2015, 4, 6),"Madrid","Spain","Madrid",'Genf',139,0,0,2,'Spain 2015',['Eric']])
##Naples
data_list.append([datetime.datetime(2015, 5, 15),"Pompei","Italy","Naples","Naples",102,0,-1,0,'Naples 2015',['AJ','Stephan S']])
data_list.append([datetime.datetime(2015, 5, 15),"Ottaviano","Italy","Naples","Naples",21,0,-1,0,'Naples 2015',['AJ','Stephan S']])
data_list.append([datetime.datetime(2015, 5, 15),"Torre Annunziata","Italy","Naples","Naples",35,0,-1,0,'Naples 2015',['AJ','Stephan S']])
data_list.append([datetime.datetime(2015, 5, 15),"Torre Annunziata","Italy","Naples","Naples",54,0,-1,0,'Naples 2015',['AJ','Stephan S']])
data_list.append([datetime.datetime(2015, 5, 16),"Pozzuoli","Italy","Naples","Naples",36,0,-1,0,'Naples 2015',['AJ','Stephan S']])
data_list.append([datetime.datetime(2015, 5, 16),"Portici","Italy","Naples","Naples",26,0,-1,0,'Naples 2015',['AJ','Stephan S']])
data_list.append([datetime.datetime(2015, 5, 16),"Ercolano","Italy","Naples","Naples",32,0,-1,0,'Naples 2015',['AJ','Stephan S']])
data_list.append([datetime.datetime(2015, 5, 16),"Castellammare di Stabia","Italy","Naples","Naples",40,0,-1,0,'Naples 2015',['AJ','Stephan S']])
data_list.append([datetime.datetime(2015, 5, 16),"Naples","Italy","Naples","Naples",15,0,-1,0,'Naples 2015',['AJ','Stephan S']])
data_list.append([datetime.datetime(2015, 5, 17),"Caserta","Italy","Naples","Naples",196,0,-1,0,'Naples 2015',['AJ','Stephan S']])
data_list.append([datetime.datetime(2015, 5, 17),"Naples","Italy","Naples","Naples",90,0,-1,0,'Naples 2015',['AJ','Stephan S']])
data_list.append([datetime.datetime(2015, 5, 18),"Naples","Italy","Naples","Naples",170,0,-1,0,'Naples 2015',['AJ','Stephan S']])
data_list.append([datetime.datetime(2015, 5, 18),"Naples","Italy","Naples","Naples",42,0,-1,0,'Naples 2015',['AJ','Stephan S']])
data_list.append([datetime.datetime(2015, 5, 18),"Erding","Germany","Naples","Genf",1,0,1,2,'Naples 2015',['AJ','Stephan S']])
data_list.append([datetime.datetime(2015, 5, 18),"Munich","Germany","Naples","Genf",1,0,1,2,'Naples 2015',['AJ','Stephan S']])
##Los Angels
data_list.append([datetime.datetime(2015, 6, 6),"Lauchringen","Germany","Lauchringen","Lauchringen",16,1,-1,0,'Lauchringen I 2015',['relatives']])
data_list.append([datetime.datetime(2015, 6, 13),"London","United Kingdom","Genf",'Los Angeles',1,0,0,1,'Los Angeles 2015',[]])
data_list.append([datetime.datetime(2015, 6, 15),"Los Angeles","USA","Los Angeles",'Los Angeles',68,0,-1,0,'Los Angeles 2015',['Eric','Cameron']])
data_list.append([datetime.datetime(2015, 6, 15),"Long Beach","USA","Los Angeles",'Los Angeles',43,0,-1,0,'Los Angeles 2015',['Eric','Cameron']])
data_list.append([datetime.datetime(2015, 6, 15),"Los Angeles","USA","Los Angeles",'Los Angeles',4,0,-1,0,'Los Angeles 2015',['Eric','Cameron','Riju','David S']])
data_list.append([datetime.datetime(2015, 6, 16),"Los Angeles","USA","Los Angeles",'Los Angeles',35,0,-1,0,'Los Angeles 2015',['Eric','Cameron']])
data_list.append([datetime.datetime(2015, 6, 16),"Pasadena","USA","Los Angeles",'Los Angeles',1,0,-1,0,'Los Angeles 2015',['Eric','Cameron']])
data_list.append([datetime.datetime(2015, 6, 17),"Los Angeles","USA","Los Angeles",'Los Angeles',25,0,-1,0,'Los Angeles 2015',['Eric','Cameron']])
data_list.append([datetime.datetime(2015, 6, 19),"Pacific Palisades","USA","Los Angeles",'Los Angeles',43,0,-1,0,'Los Angeles 2015',['Eric','Cameron']])
data_list.append([datetime.datetime(2015, 6, 19),"Los Angeles","USA","Los Angeles",'Los Angeles',29,0,-1,0,'Los Angeles 2015',['Eric']])
data_list.append([datetime.datetime(2015, 6, 20),"Los Angeles","USA","Los Angeles",'Genf',10,0,0,2,'Los Angeles 2015',[]])
data_list.append([datetime.datetime(2015, 6, 21),"London","United Kingdom","Los Angeles",'Genf',12,0,1,2,'Los Angeles 2015',[]])
##
data_list.append([datetime.datetime(2015, 7, 4),"Tour","France","Genf","Genf",59,1,-1,0,'Glacier du Tour 2015',["Line",'Jonas','Pieter']])
data_list.append([datetime.datetime(2015, 7, 4),"Passy","France","Genf","Genf",2,1,-1,0,'Glacier du Tour 2015',["Line",'Jonas','Pieter']])
data_list.append([datetime.datetime(2015, 7, 8),"Lyon","France","Lyon","Genf",4,1,1,0,'Lyon JetMET 2015',[]])
data_list.append([datetime.datetime(2015, 7, 11),"Chamonix","France","Genf","Genf",181,1,-1,0,'Chamonix 2015',['Manuel']])
#Paris I
data_list.append([datetime.datetime(2015, 7, 18),"Versailles","France","Paris",'Paris',358,0,-1,0,'Paris I 2015',['Riju']])
data_list.append([datetime.datetime(2015, 7, 19),"Mont-Saint-Michel","France","Paris",'Paris',80,0,-1,0,'Paris I 2015',[]])
##
data_list.append([datetime.datetime(2015, 7, 26),"Sankt Niklaus","Switzerland","Genf","Genf",1,1,-1,0,'Zermatt 2015',['Eric']])
data_list.append([datetime.datetime(2015, 7, 26),"Randa","Switzerland","Genf","Genf",7,1,-1,0,'Zermatt 2015',['Eric']])
data_list.append([datetime.datetime(2015, 7, 26),"Taesch","Switzerland","Genf","Genf",2,1,-1,0,'Zermatt 2015',['Eric']])
data_list.append([datetime.datetime(2015, 7, 26),"Zermatt","Switzerland","Genf","Genf",142,1,-1,0,'Zermatt 2015',['Eric']])
data_list.append([datetime.datetime(2015, 7, 26),"Zermatt","Switzerland","Genf","Genf",46,1,-1,0,'Zermatt 2015',['Eric','Manuel','Stani']])
##Monaco & Nice
data_list.append([datetime.datetime(2015, 8, 21),"Monaco","Monaco","Genf","Beausoleil",1,0,1,1,'Monaco and Nice 2015',[]])
data_list.append([datetime.datetime(2015, 8, 22),"Monaco","Monaco","Beausoleil","Beausoleil",118,0,-1,0,'Monaco and Nice 2015',['AJ','Laser','Evan']])
data_list.append([datetime.datetime(2015, 8, 22),"Monaco","Monaco","Beausoleil","Beausoleil",66,0,-1,0,'Monaco and Nice 2015',[]])
data_list.append([datetime.datetime(2015, 8, 23),"Nice","France","Beausoleil","Genf",40,0,0,2,'Monaco and Nice 2015',[]])
data_list.append([datetime.datetime(2015, 8, 23),"Beaulieu-sur-Mer","France","Beausoleil","Genf",91,0,0,2,'Monaco and Nice 2015',[]])
##
data_list.append([datetime.datetime(2015, 8, 28),"Strelna","Russia",'Genf',"Saint Petersburg",1,0,1,1,'St Petersburg LHCP 2015',[]])
data_list.append([datetime.datetime(2015, 8, 28),"Peterhof","Russia",'Genf',"Saint Petersburg",1,0,1,1,'St Petersburg LHCP 2015',[]])
data_list.append([datetime.datetime(2015, 8, 28),"Saint Petersburg","Russia",'Genf',"Saint Petersburg",102,0,1,1,'St Petersburg LHCP 2015',[]])
data_list.append([datetime.datetime(2015, 8, 29),"Saint Petersburg","Russia","Saint Petersburg","Saint Petersburg",58,0,-1,0,'St Petersburg LHCP 2015',[]])
data_list.append([datetime.datetime(2015, 8, 29),"Lomonosow","Russia","Saint Petersburg","Saint Petersburg",44,0,-1,0,'St Petersburg LHCP 2015',[]])
data_list.append([datetime.datetime(2015, 8, 30),"Saint Petersburg","Russia","Saint Petersburg","Saint Petersburg",1,0,-1,0,'St Petersburg LHCP 2015',[]])
data_list.append([datetime.datetime(2015, 8, 30),"Pawlovsk","Russia","Saint Petersburg","Saint Petersburg",81,0,-1,0,'St Petersburg LHCP 2015',[]])
data_list.append([datetime.datetime(2015, 8, 30),"Gatchina","Russia","Saint Petersburg","Saint Petersburg",69,0,-1,0,'St Petersburg LHCP 2015',[]])
data_list.append([datetime.datetime(2015, 8, 31),"Saint Petersburg","Russia","Saint Petersburg","Saint Petersburg",1,0,-1,0,'St Petersburg LHCP 2015',["Manuel"]])
data_list.append([datetime.datetime(2015, 9, 1),"Saint Petersburg","Russia","Saint Petersburg","Saint Petersburg",2,0,-1,0,'St Petersburg LHCP 2015',['Manuel']])
data_list.append([datetime.datetime(2015, 9, 2),"Moscow","Russia","Saint Petersburg","Saint Petersburg",198,0,-1,0,'St Petersburg LHCP 2015',['Manuel']])
data_list.append([datetime.datetime(2015, 9, 3),"Saint Petersburg","Russia","Saint Petersburg","Saint Petersburg",20,0,-1,0,'St Petersburg LHCP 2015',['LHCP']])
data_list.append([datetime.datetime(2015, 9, 3),"Peterhof","Russia","Saint Petersburg","Saint Petersburg",100,0,-1,0,'St Petersburg LHCP 2015',['LHCP']])
data_list.append([datetime.datetime(2015, 9, 3),"Strelna","Russia","Saint Petersburg","Saint Petersburg",3,0,-1,0,'St Petersburg LHCP 2015',['LHCP']])
data_list.append([datetime.datetime(2015, 9, 4),"Saint Petersburg","Russia","Saint Petersburg","Saint Petersburg",11,0,-1,0,'St Petersburg LHCP 2015',['Manuel']])
data_list.append([datetime.datetime(2015, 9, 5),"Saint Petersburg","Russia","Saint Petersburg","Saint Petersburg",32,0,-1,0,'St Petersburg LHCP 2015',['Manuel']])
data_list.append([datetime.datetime(2015, 9, 6),"Saint Petersburg","Russia","Saint Petersburg","Saint Petersburg",22,0,-1,0,'St Petersburg LHCP 2015',['Manuel']])
data_list.append([datetime.datetime(2015, 9, 6),"Puschkin","Russia","Saint Petersburg","Saint Petersburg",260,0,-1,0,'St Petersburg LHCP 2015',['Manuel']])
data_list.append([datetime.datetime(2015, 9, 7),"Saint Petersburg","Russia","Saint Petersburg","Saint Petersburg",94,0,-1,0,'St Petersburg LHCP 2015',['Manuel']])
data_list.append([datetime.datetime(2015, 9, 8),"Saint Petersburg","Russia","Saint Petersburg","Saint Petersburg",200,0,-1,0,'St Petersburg LHCP 2015',['Manuel']])
data_list.append([datetime.datetime(2015, 9, 9),"Saint Petersburg","Russia","Saint Petersburg","Saint Petersburg",131,0,-1,0,'St Petersburg LHCP 2015',[]])
data_list.append([datetime.datetime(2015, 9, 10),"Peterhof","Russia","Saint Petersburg","Saint Petersburg",162,0,-1,0,'St Petersburg LHCP 2015',[]])
data_list.append([datetime.datetime(2015, 9, 11),"Strelna","Russia","Saint Petersburg","Saint Petersburg",44,0,-1,0,'St Petersburg LHCP 2015',[]])
data_list.append([datetime.datetime(2015, 9, 12),"Saint Petersburg","Russia","Saint Petersburg",'Genf',5,0,0,2,'St Petersburg LHCP 2015',[]])
data_list.append([datetime.datetime(2015, 9, 12),"Kronstadt","Russia","Saint Petersburg",'Genf',1,0,0,2,'St Petersburg LHCP 2015',[]])
data_list.append([datetime.datetime(2015, 9, 12),"Paris","France","Saint Petersburg","Genf",3,0,1,2,'St Petersburg LHCP 2015',[]])
##Paris II
data_list.append([datetime.datetime(2015, 9, 19),"Paris","France","Paris",'Paris',276,0,-1,0,'Paris II 2015',[]])
data_list.append([datetime.datetime(2015, 9, 20),"Paris","France","Paris","Genf",213,0,0,0,'Paris II 2015',[]])
#ISMD2015
data_list.append([datetime.datetime(2015, 10, 3),"Munich","Germany","Garching",'Garching',38,0,-1,0,"Muenchen and Austria 2015",['Eric','Siyi']])
data_list.append([datetime.datetime(2015, 10, 4),"Munich","Germany","Garching","Wildbad Kreuth",54,0,0,0,"Muenchen and Austria 2015",['Eric','Siyi']])
data_list.append([datetime.datetime(2015, 10, 5),"Wildbad Kreuth","Germany","Wildbad Kreuth","Wildbad Kreuth",3,0,-1,0,"Muenchen and Austria 2015",[]])
data_list.append([datetime.datetime(2015, 10, 7),"Tegernsee","Germany","Wildbad Kreuth","Wildbad Kreuth",3,0,-1,0,"Muenchen and Austria 2015",[]])
data_list.append([datetime.datetime(2015, 10, 8),"Wildbad Kreuth","Germany","Wildbad Kreuth","Wildbad Kreuth",3,0,-1,0,"Muenchen and Austria 2015",[]])
data_list.append([datetime.datetime(2015, 10, 10),"Melk","Austria","Poechlarn","Salzburg",70,0,0,0,"Muenchen and Austria 2015",['Eric','Siyi']])
data_list.append([datetime.datetime(2015, 10, 10),"Furth bei Goettweig","Austria","Poechlarn","Salzburg",56,0,0,0,"Muenchen and Austria 2015",['Eric','Siyi']])
data_list.append([datetime.datetime(2015, 10, 10),"Passau","Germany","Poechlarn","Salzburg",36,0,1,0,"Muenchen and Austria 2015",['Eric','Siyi']])
data_list.append([datetime.datetime(2015, 10, 11),"Salzburg","Austria","Salzburg",'Genf',97,0,0,2,"Muenchen and Austria 2015",['Eric','Siyi']])
#Berlin 2015
data_list.append([datetime.datetime(2015, 11, 8),"Berlin","Germany",'Genf',"Berlin",2,0,1,1,'Berlin 2015',[]])
data_list.append([datetime.datetime(2015, 11, 8),"Potsdam","Germany",'Genf',"Berlin",143,0,1,1,'Berlin 2015',['Artur','Heidrun']])
data_list.append([datetime.datetime(2015, 11, 8),"Berlin","Germany",'Genf',"Berlin",3,0,1,1,'Berlin 2015',['Artur','Heidrun','Anne-Kathrin']])
data_list.append([datetime.datetime(2015, 11, 9),"Hamburg","Germany","Berlin","Berlin",136,0,-1,0,'Berlin 2015',['Artur','Heidrun','Anne-Kathrin']])
data_list.append([datetime.datetime(2015, 11, 10),"Berlin","Germany","Berlin","Berlin",40,0,-1,0,'Berlin 2015',['Artur','Heidrun','Anne-Kathrin']])
data_list.append([datetime.datetime(2015, 11, 10),"Berlin","Germany","Berlin","Berlin",30,0,-1,0,'Berlin 2015',['Heidrun']])
data_list.append([datetime.datetime(2015, 11, 11),"Berlin","Germany","Berlin","Berlin",3,0,-1,0,'Berlin 2015',['Heidrun']])
data_list.append([datetime.datetime(2015, 11, 11),"Berlin","Germany","Berlin","Berlin",5,0,-1,0,'Berlin 2015',[]])
data_list.append([datetime.datetime(2015, 11, 11),"Schwerin","Germany","Berlin","Berlin",86,0,-1,0,'Berlin 2015',[]])
data_list.append([datetime.datetime(2015, 11, 11),"Luebeck","Germany","Berlin","Berlin",63,0,-1,0,'Berlin 2015',[]])
data_list.append([datetime.datetime(2015, 11, 12),"Berlin","Germany","Berlin","Berlin",90,0,-1,0,'Berlin 2015',['Artur','Heidrun','Anne-Kathrin']])
data_list.append([datetime.datetime(2015, 11, 13),"Weimar","Germany","Berlin","Berlin",96,0,-1,0,'Berlin 2015',[]])
data_list.append([datetime.datetime(2015, 11, 13),"Erfurt","Germany","Berlin","Berlin",46,0,-1,0,'Berlin 2015',[]])
data_list.append([datetime.datetime(2015, 11, 14),"Jena","Germany","Berlin","Berlin",2,0,-1,0,'Berlin 2015',[]])
data_list.append([datetime.datetime(2015, 11, 14),"Rudolstadt","Germany","Berlin","Berlin",85,0,-1,0,'Berlin 2015',[]])
data_list.append([datetime.datetime(2015, 11, 14),"Gotha","Germany","Berlin","Berlin",81,0,-1,0,'Berlin 2015',[]])
data_list.append([datetime.datetime(2015, 11, 15),"Berlin","Germany","Berlin",'Genf',205,0,0,2,'Berlin 2015',['Artur','Heidrun']])
##

# %%
# 2016
data_list.append([datetime.datetime(2016, 1, 2),"Colmar","France","Lauchringen","Lauchringen",83,1,-1,0,'Colmar 2016',['Artur','Heidrun','Hannsjoerg']])
#Sicily
data_list.append([datetime.datetime(2016, 3, 16),"Catania","Italy","Genf","Piazza Armerina",2,0,1,1,'Sicily 2016',['Artur','Heidrun']])
data_list.append([datetime.datetime(2016, 3, 16),"Piazza Armerina","Italy","Genf","Piazza Armerina",1,0,1,1,'Sicily 2016',['Artur','Heidrun']])
data_list.append([datetime.datetime(2016, 3, 17),"Piazza Armerina","Italy","Piazza Armerina","Palermo",58,0,0,0,'Sicily 2016',['Artur','Heidrun']])
data_list.append([datetime.datetime(2016, 3, 17),"Cefalu","Italy","Piazza Armerina","Palermo",33,0,1,0,'Sicily 2016',['Artur','Heidrun']])
data_list.append([datetime.datetime(2016, 3, 17),"Monreale","Italy","Piazza Armerina","Palermo",123,0,1,0,'Sicily 2016',['Artur','Heidrun']])
data_list.append([datetime.datetime(2016, 3, 17),"Palermo","Italy","Piazza Armerina","Palermo",7,0,1,0,'Sicily 2016',['Artur','Heidrun']])
data_list.append([datetime.datetime(2016, 3, 18),"Palermo","Italy","Palermo","Palermo",316,0,-1,0,'Sicily 2016',['Artur','Heidrun']])
data_list.append([datetime.datetime(2016, 3, 18),"Palermo","Italy","Palermo","Palermo",40,0,-1,0,'Sicily 2016',[]])
data_list.append([datetime.datetime(2016, 3, 19),"Palermo","Italy","Palermo","Castellammare del Golfo",102,0,0,0,'Sicily 2016',['Artur','Heidrun']])
data_list.append([datetime.datetime(2016, 3, 19),"Calatafimi","Italy","Palermo","Castellammare del Golfo",30,0,1,0,'Sicily 2016',['Artur','Heidrun']])
data_list.append([datetime.datetime(2016, 3, 19),"Castellammare del Golfo","Italy","Palermo","Castellammare del Golfo",27,0,1,0,'Sicily 2016',['Artur','Heidrun']])
data_list.append([datetime.datetime(2016, 3, 20),"Selinunt","Italy","Castellammare del Golfo","Agrigent",47,0,1,0,'Sicily 2016',['Artur','Heidrun']])
data_list.append([datetime.datetime(2016, 3, 20),"Realmonte","Italy","Castellammare del Golfo","Agrigent",47,0,1,0,'Sicily 2016',['Artur','Heidrun']])
data_list.append([datetime.datetime(2016, 3, 20),"Agrigent","Italy","Castellammare del Golfo","Agrigent",14,0,1,0,'Sicily 2016',['Artur','Heidrun']])
data_list.append([datetime.datetime(2016, 3, 21),"Agrigent","Italy","Agrigent","Agrigent",140,0,-1,0,'Sicily 2016',['Artur','Heidrun']])
data_list.append([datetime.datetime(2016, 3, 22),"Comiso","Italy","Agrigent","Siracusa",19,0,1,0,'Sicily 2016',['Artur','Heidrun']])
data_list.append([datetime.datetime(2016, 3, 22),"Noto","Italy","Agrigent","Siracusa",91,0,1,0,'Sicily 2016',['Artur','Heidrun']])
data_list.append([datetime.datetime(2016, 3, 22),"Siracusa","Italy","Agrigent","Siracusa",18,0,1,0,'Sicily 2016',['Artur','Heidrun']])
data_list.append([datetime.datetime(2016, 3, 23),"Siracusa","Italy","Siracusa","Catania",92,0,0,0,'Sicily 2016',['Artur','Heidrun']])
data_list.append([datetime.datetime(2016, 3, 23),"Catania","Italy","Siracusa","Catania",66,0,1,0,'Sicily 2016',['Artur','Heidrun']])
data_list.append([datetime.datetime(2016, 3, 24),"Nicolosi","Italy","Catania","Catania",77,0,-1,0,'Sicily 2016',['Artur','Heidrun']])
data_list.append([datetime.datetime(2016, 3, 24),"Catania","Italy","Catania","Catania",26,0,-1,0,'Sicily 2016',['Artur']])
data_list.append([datetime.datetime(2016, 3, 25),"Catania","Italy","Catania",'Genf',40,0,0,1,'Sicily 2016',['Artur']])
#Barcelona
data_list.append([datetime.datetime(2016, 3, 26),"Barcelona","Spain",'Genf',"Barcelona",221,0,1,1,'Barcelona 2016',['Riju']])
data_list.append([datetime.datetime(2016, 3, 26),"Barcelona","Spain",'Genf',"Barcelona",98,0,1,1,'Barcelona 2016',[]])
data_list.append([datetime.datetime(2016, 3, 27),"Barcelona","Spain","Barcelona","Barcelona",202,0,-1,0,'Barcelona 2016',['Riju']])
data_list.append([datetime.datetime(2016, 3, 27),"Barcelona","Spain","Barcelona","Barcelona",114,0,-1,0,'Barcelona 2016',[]])
data_list.append([datetime.datetime(2016, 3, 28),"Zaragoza","Spain","Barcelona","Barcelona",183,0,-1,0,'Barcelona 2016',['Riju']])
data_list.append([datetime.datetime(2016, 3, 28),"Barcelona","Spain","Barcelona","Barcelona",5,0,-1,0,'Barcelona 2016',['Riju']])
data_list.append([datetime.datetime(2016, 3, 29),"Barcelona","Spain","Barcelona",'Genf',74,0,0,2,'Barcelona 2016',['Riju']])
data_list.append([datetime.datetime(2016, 3, 29),"Barcelona","Spain","Barcelona",'Genf',56,0,0,2,'Barcelona 2016',[]])
##
data_list.append([datetime.datetime(2016, 4, 10),"Gruyeres","Switzerland","Genf","Genf",86,1,-1,0,'Gruyeres and Jonbachschlucht 2016',["Artur",'Heidrun']])
data_list.append([datetime.datetime(2016, 4, 10),"Broc","Switzerland","Genf","Genf",61,1,-1,0,'Gruyeres and Jonbachschlucht 2016',["Artur",'Heidrun']])
data_list.append([datetime.datetime(2016, 4, 22),"Prevessin","France","Genf","Genf",4,1,-1,0,'NA64 2016',['Brant']])
data_list.append([datetime.datetime(2016, 4, 23),"Lauchringen","Germany","Lauchringen","Lauchringen",23,1,-1,0,'Lauchringen I 2016',['Heidrun','Franziska','Artur','Jan-Marc','Anne-Kathrin']])
#Torino
data_list.append([datetime.datetime(2016, 5, 5),"Venaria Reale","Italy","Torino","Torino",124,0,-1,0,'Torino 2016',[]])
data_list.append([datetime.datetime(2016, 5, 5),"Torino","Italy","Torino","Torino",193,0,-1,0,'Torino 2016',[]])
data_list.append([datetime.datetime(2016, 5, 6),"Racconigi","Italy","Torino","Torino",69,0,-1,0,'Torino 2016',[]])
data_list.append([datetime.datetime(2016, 5, 6),"Aglie","Italy","Torino","Torino",79,0,-1,0,'Torino 2016',[]])
data_list.append([datetime.datetime(2016, 5, 7),"Torino","Italy","Torino","Torino",221,0,-1,0,'Torino 2016',[]])
data_list.append([datetime.datetime(2016, 5, 7),"Nichelino","Italy","Torino","Torino",80,0,-1,0,'Torino 2016',[]])
data_list.append([datetime.datetime(2016, 5, 8),"Torino","Italy","Torino",'Genf',155,0,0,0,'Torino 2016',[]])
#Genua
data_list.append([datetime.datetime(2016, 5, 14),"Pollein","Italy","Genf","Genua",1,0,0,0,'Genua 2016',['Amin']])
data_list.append([datetime.datetime(2016, 5, 14),"Genua","Italy",'Genf',"Genua",279,0,1,0,'Genua 2016',['Amin']])
data_list.append([datetime.datetime(2016, 5, 15),"Genua","Italy","Genua","Genua",239,0,-1,0,'Genua 2016',['Amin']])
data_list.append([datetime.datetime(2016, 5, 16),"Riomaggiore","Italy","Genua",'Genf',25,0,0,0,'Genua 2016',['Amin']])
data_list.append([datetime.datetime(2016, 5, 16),"Manarola","Italy","Genua",'Genf',23,0,0,0,'Genua 2016',['Amin']])
data_list.append([datetime.datetime(2016, 5, 16),"Corniglia","Italy","Genua",'Genf',15,0,0,0,'Genua 2016',['Amin']])
data_list.append([datetime.datetime(2016, 5, 16),"Monterosso al Mare","Italy","Genua",'Genf',32,0,0,0,'Genua 2016',['Amin']])
data_list.append([datetime.datetime(2016, 5, 16),"Vernazza","Italy","Genua",'Genf',11,0,0,0,'Genua 2016',['Amin']])
data_list.append([datetime.datetime(2016, 5, 16),"Courmayeur","Italy","Genua",'Genf',2,0,1,0,'Genua 2016',['Amin']])
##Santander
data_list.append([datetime.datetime(2016, 5, 28),"Santander","Spain",'Genf',"Santander",24,0,1,1,'Santander 2016',[]])
data_list.append([datetime.datetime(2016, 5, 29),"Santander","Spain","Santander","Santander",69,0,-1,0,'Santander 2016',[]])
data_list.append([datetime.datetime(2016, 5, 29),"Puente Viesgo","Spain","Santander","Santander",21,0,-1,0,'Santander 2016',[]])
data_list.append([datetime.datetime(2016, 5, 30),"Burgos","Spain","Santander","Santander",197,0,-1,0,'Santander 2016',[]])
data_list.append([datetime.datetime(2016, 5, 30),"Santander","Spain","Santander","Santander",40,0,-1,0,'Santander 2016',[]])
data_list.append([datetime.datetime(2016, 5, 31),"Santander","Spain","Santander","Santander",3,0,-1,0,'Santander 2016',[]])
data_list.append([datetime.datetime(2016, 6, 2),"Santander","Spain","Santander","Santander",13,0,-1,0,'Santander 2016',[]])
data_list.append([datetime.datetime(2016, 6, 3),"Santander","Spain","Santander","Bilbao",15,0,0,0,'Santander 2016',[]])
data_list.append([datetime.datetime(2016, 6, 3),"Bilbao","Spain","Santander","Bilbao",106,0,1,0,'Santander 2016',[]])
##

# %%
#2016
data_list.append([datetime.datetime(2016, 6, 11),"Lauterbrunnen","Switzerland","Genf","Genf",9,1,-1,0,'Truemmelbach Falls and Bern 2016',["Andrew"]])
data_list.append([datetime.datetime(2016, 6, 11),"Stechelberg","Switzerland","Genf","Genf",35,1,-1,0,'Truemmelbach Falls and Bern 2016',["Andrew"]])
data_list.append([datetime.datetime(2016, 6, 11),"Bern","Switzerland","Genf","Genf",41,1,-1,0,'Truemmelbach Falls and Bern 2016',["Andrew"]])
#ravenna
data_list.append([datetime.datetime(2016, 6, 25),"Ravenna","Italy","Milano","Ravenna",97,0,1,0,'Ravenna and Padua 2016',["Keyvan"]])
data_list.append([datetime.datetime(2016, 6, 25),"Classe","Italy","Milano","Ravenna",28,0,1,0,'Ravenna and Padua 2016',[]])
data_list.append([datetime.datetime(2016, 6, 25),"Ravenna","Italy","Milano","Ravenna",56,0,1,0,'Ravenna and Padua 2016',[]])
data_list.append([datetime.datetime(2016, 6, 26),"Padua","Italy","Ravenna",'Genf',210,0,0,0,'Ravenna and Padua 2016',[]])
#Bordeaux
data_list.append([datetime.datetime(2016, 7, 1),"Bordeaux","France","Genf","Bordeaux",22,0,1,0,'Bordeaux EM 2016',['Artur','Heidrun','Anne-Kathrin']])
data_list.append([datetime.datetime(2016, 7, 2),"Bordeaux","France","Bordeaux","Bordeaux",156,0,-1,0,'Bordeaux EM 2016',['Artur','Heidrun','Anne-Kathrin']])
##
data_list.append([datetime.datetime(2016, 7, 10),"Saint-Gervais-les-Bains","France","Genf","Genf",47,1,-1,0,"Nid d'Aigle 2016",['Pieter','Jonas','Grace S','Chris S','Riju']])
#zermatt/fiesch
data_list.append([datetime.datetime(2016, 7, 16),"Zermatt","Switzerland","Genf","Fiesch",125,0,1,0,'Fiesch 2016',['Artur','Heidrun']])
data_list.append([datetime.datetime(2016, 7, 17),"Riederalp","Switzerland","Fiesch","Genf",25,0,0,0,'Fiesch 2016',['Artur','Heidrun']])
data_list.append([datetime.datetime(2016, 7, 17),"Fiesch","Switzerland","Fiesch","Genf",37,0,0,0,'Fiesch 2016',['Artur','Heidrun']])
data_list.append([datetime.datetime(2016, 7, 17),"Fieschertal","Switzerland","Fiesch","Genf",27,0,0,0,'Fiesch 2016',['Artur','Heidrun']])
#Brussels
data_list.append([datetime.datetime(2016, 7, 22),"Brussels","Belgium","Genf","Brussels",10,0,1,1,'Brussels 2016',[]])
data_list.append([datetime.datetime(2016, 7, 23),"Brussels","Belgium","Brussels","Brussels",138,0,-1,0,'Brussels 2016',[]])
data_list.append([datetime.datetime(2016, 7, 23),"Aachen","Germany","Brussels","Brussels",69,0,-1,0,'Brussels 2016',[]])
data_list.append([datetime.datetime(2016, 7, 23),"Brussels","Belgium","Brussels","Brussels",152,0,-1,0,'Brussels 2016',[]])
data_list.append([datetime.datetime(2016, 7, 24),"Koekelberg","Belgium","Brussels","Genf",22,0,0,2,'Brussels 2016',[]])
data_list.append([datetime.datetime(2016, 7, 24),"Brussels","Belgium","Brussels","Genf",99,0,0,2,'Brussels 2016',[]])
#USA
data_list.append([datetime.datetime(2016, 8, 13),"Brussels","Belgium","Genf","Aurora",1,0,0,1,'US National Parks and Washington DC 2016',[]])
data_list.append([datetime.datetime(2016, 8, 13),"Chicago","USA",'Genf',"Aurora",33,0,1,1,'US National Parks and Washington DC 2016',['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2016, 8, 14),"Chicago","USA","Aurora","Aurora",152,0,-1,0,'US National Parks and Washington DC 2016',['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2016, 8, 15),"Aurora","USA","Aurora","Tusayan",1,0,0,1,'US National Parks and Washington DC 2016',['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2016, 8, 15),"Boulder City","USA","Aurora","Tusayan",10,0,1,1,'US National Parks and Washington DC 2016',['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2016, 8, 16),"Grand Canyon Village","USA","Tusayan","Tusayan",184,0,-1,0,'US National Parks and Washington DC 2016',['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2016, 8, 16),"Tusayan","USA","Tusayan","Tusayan",1,0,-1,0,'US National Parks and Washington DC 2016',['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2016, 8, 17),"Grand Canyon Village","USA","Tusayan","Tusayan",88,0,-1,0,'US National Parks and Washington DC 2016',['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2016, 8, 18),"Grand Canyon Village","USA","Tusayan","Oljato-Monument Valley",17,0,0,0,'US National Parks and Washington DC 2016',['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2016, 8, 18),"Cameron","USA","Tusayan","Oljato-Monument Valley",16,0,0,0,'US National Parks and Washington DC 2016',['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2016, 8, 18),"Page","USA","Tusayan","Oljato-Monument Valley",117,0,1,0,'US National Parks and Washington DC 2016',['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2016, 8, 18),"Kaibito","USA","Tusayan","Oljato-Monument Valley",2,0,1,0,'US National Parks and Washington DC 2016',['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2016, 8, 19),"Oljato-Monument Valley","USA","Oljato-Monument Valley","Cortez",148,0,1,0,'US National Parks and Washington DC 2016',['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2016, 8, 19),"Halchita","USA","Oljato-Monument Valley","Cortez",3,0,0,0,'US National Parks and Washington DC 2016',['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2016, 8, 19),"Mexican Hat","USA","Oljato-Monument Valley","Cortez",19,0,0,0,'US National Parks and Washington DC 2016',['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2016, 8, 19),"Bluff","USA","Oljato-Monument Valley","Cortez",5,0,0,0,'US National Parks and Washington DC 2016',['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2016, 8, 19),"Aneth","USA","Oljato-Monument Valley","Cortez",3,0,1,0,'US National Parks and Washington DC 2016',['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2016, 8, 19),"Montezuma Creek","USA","Oljato-Monument Valley","Cortez",1,0,1,0,'US National Parks and Washington DC 2016',['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2016, 8, 19),"Ute Mountain Reservation","USA","Oljato-Monument Valley","Cortez",5,0,1,0,'US National Parks and Washington DC 2016',['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2016, 8, 19),"Cortez","USA","Oljato-Monument Valley","Cortez",33,0,0,0,'US National Parks and Washington DC 2016',['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2016, 8, 20),"Cortez","USA","Cortez","Moab",67,0,0,0,'US National Parks and Washington DC 2016',['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2016, 8, 20),"Moab","USA","Cortez","Moab",1,0,1,0,'US National Parks and Washington DC 2016',['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2016, 8, 21),"Moab","USA","Moab","Moab",123,0,-1,0,'US National Parks and Washington DC 2016',['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2016, 8, 22),"Moab","USA","Moab","Bryce Canyon City",5,0,0,0,'US National Parks and Washington DC 2016',['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2016, 8, 22),"San Rafael Swell","USA","Moab","Bryce Canyon City",9,0,0,0,'US National Parks and Washington DC 2016',['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2016, 8, 22),"Emery","USA","Moab","Bryce Canyon City",2,0,0,0,'US National Parks and Washington DC 2016',['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2016, 8, 22),"Garfield","USA","Moab","Bryce Canyon City",7,0,1,0,'US National Parks and Washington DC 2016',['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2016, 8, 22),"Bryce Canyon City","USA","Moab","Bryce Canyon City",78,0,1,0,'US National Parks and Washington DC 2016',['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2016, 8, 23),"Bryce Canyon City","USA","Bryce Canyon City","Springdale",92,0,0,0,'US National Parks and Washington DC 2016',['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2016, 8, 23),"Mount Carmel","USA","Bryce Canyon City","Springdale",27,0,1,0,'US National Parks and Washington DC 2016',['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2016, 8, 23),"Springdale","USA","Bryce Canyon City","Springdale",87,0,1,0,'US National Parks and Washington DC 2016',['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2016, 8, 24),"Springdale","USA","Springdale","Las Vegas",34,0,0,0,'US National Parks and Washington DC 2016',['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2016, 8, 24),"Virgin","USA","Springdale","Las Vegas",2,0,0,0,'US National Parks and Washington DC 2016',['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2016, 8, 24),"Las Vegas","USA","Springdale","Las Vegas",37,0,1,0,'US National Parks and Washington DC 2016',['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2016, 8, 25),"Las Vegas","USA","Las Vegas","Las Vegas",51,0,-1,0,'US National Parks and Washington DC 2016',['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2016, 8, 26),"Las Vegas","USA","Las Vegas","Washington DC",6,0,0,2,'US National Parks and Washington DC 2016',['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2016, 8, 26),"Washington DC","USA","Washington DC","Washington DC",11,0,1,2,'US National Parks and Washington DC 2016',['Artur','Heidrun']])
data_list.append([datetime.datetime(2016, 8, 27),"Washington DC","USA","Washington DC","Washington DC",184,0,-1,0,'US National Parks and Washington DC 2016',['Artur','Heidrun']])
data_list.append([datetime.datetime(2016, 8, 28),"Washington DC","USA","Washington DC","Washington DC",148,0,-1,0,'US National Parks and Washington DC 2016',['Artur','Heidrun']])
data_list.append([datetime.datetime(2016, 8, 28),"Washington DC","USA","Washington DC","Washington DC",8,0,-1,0,'US National Parks and Washington DC 2016',[]])
data_list.append([datetime.datetime(2016, 8, 29),"Washington DC","USA","Washington DC",'Genf',60,0,0,2,'US National Parks and Washington DC 2016',['Luis']])
#

# %%
data_list.append([datetime.datetime(2016, 9, 4),"Waldshut","Germany","Lauchringen","Lauchringen",5,1,-1,0,'Lauchringen II 2016',['Franziska','Felicitas','Jan-Marc','Anne-Kathrin']])
data_list.append([datetime.datetime(2016, 9, 10),"Le Chable","Switzerland","Genf","Genf",2,1,-1,0,'Mont Fort 2016',[]])
data_list.append([datetime.datetime(2016, 9, 10),"Verbier","Switzerland","Genf","Genf",81,1,-1,0,'Mont Fort 2016',[]])
data_list.append([datetime.datetime(2016, 9, 11),"Heremence","Switzerland","Genf","Genf",8,1,-1,0,'Lac des Dix 2016',[]])
#Arlington
data_list.append([datetime.datetime(2016, 9, 13),"Dagenham","United Kingdom","Genf","Arlington",1,0,0,1,'Calice 2016',[]])
data_list.append([datetime.datetime(2016, 9, 13),"Dartford","United Kingdom","Genf","Arlington",1,0,0,1,'Calice 2016',[]])
data_list.append([datetime.datetime(2016, 9, 13),"London","United Kingdom","Genf","Arlington",1,0,0,1,'Calice 2016',[]])
data_list.append([datetime.datetime(2016, 9, 13),"Eton","United Kingdom","Genf","Arlington",1,0,0,1,'Calice 2016',[]])
data_list.append([datetime.datetime(2016, 9, 13),"Windsor","United Kingdom","Genf","Arlington",2,0,0,1,'Calice 2016',[]])
data_list.append([datetime.datetime(2016, 9, 13),"Longford","United Kingdom","Genf","Arlington",1,0,0,1,'Calice 2016',[]])
data_list.append([datetime.datetime(2016, 9, 13),"Sligo","Ireland","Genf","Arlington",2,0,0,1,'Calice 2016',[]])
data_list.append([datetime.datetime(2016, 9, 13),"Little Elm","USA","Genf","Arlington",2,0,1,1,'Calice 2016',[]])
data_list.append([datetime.datetime(2016, 9, 13),"Frisco","USA","Genf","Arlington",2,0,1,1,'Calice 2016',[]])
data_list.append([datetime.datetime(2016, 9, 13),"Lake Dallas","USA","Genf","Arlington",2,0,1,1,'Calice 2016',[]])
data_list.append([datetime.datetime(2016, 9, 13),"Lewisville","USA","Genf","Arlington",2,0,1,1,'Calice 2016',[]])
data_list.append([datetime.datetime(2016, 9, 13),"Fort Worth","USA","Genf","Arlington",2,0,1,1,'Calice 2016',[]])
data_list.append([datetime.datetime(2016, 9, 17),"Dallas","USA","Arlington","Genf",6,0,0,2,'Calice 2016',[]])
##
data_list.append([datetime.datetime(2016, 9, 23),"Lauchringen","Germany","Lauchringen","Lauchringen",2,1,-1,0,'Lauchringen III 2016',['Artur','Heidrun','Franziska','Felicitas','Jan-Marc','Anne-Kathrin']])
#Santiago de Compostela
data_list.append([datetime.datetime(2016, 10,8),"Santiago de Compostela","Spain",'Genf',"Santiago de Compostela",138,0,1,1,"Santiago de Compostela 2016",[]])
data_list.append([datetime.datetime(2016, 10,9),"Santiago de Compostela","Spain","Santiago de Compostela",'Genf',2,0,0,2,"Santiago de Compostela 2016",[]])
#Koeln
data_list.append([datetime.datetime(2016, 10,14),"Cologne","Germany",'Genf',"Cologne",16,0,1,1,'Cologne 2016',[]])
data_list.append([datetime.datetime(2016, 10,15),"Cologne","Germany","Cologne","Cologne",117,0,-1,0,'Cologne 2016',[]])
data_list.append([datetime.datetime(2016, 10,15),"Dusseldorf","Germany","Cologne","Cologne",26,0,-1,0,'Cologne 2016',[]])
data_list.append([datetime.datetime(2016, 10,15),"Friedrichssegen","Germany","Cologne","Cologne",1,0,-1,0,'Cologne 2016',[]])
data_list.append([datetime.datetime(2016, 10,15),"Limburg","Germany","Cologne","Cologne",44,0,-1,0,'Cologne 2016',[]])
data_list.append([datetime.datetime(2016, 10,16),"Cologne","Germany","Cologne","Dusseldorf",23,0,0,0,'Cologne 2016',[]])
data_list.append([datetime.datetime(2016, 10,16),"Bruehl","Germany","Cologne","Dusseldorf",49,0,0,0,'Cologne 2016',[]])
data_list.append([datetime.datetime(2016, 10,16),"Bonn","Germany","Cologne","Dusseldorf",35,0,0,0,'Cologne 2016',[]])
data_list.append([datetime.datetime(2016, 10,16),"Dusseldorf","Germany","Cologne","Dusseldorf",1,0,1,0,'Cologne 2016',[]])
#Mantua
data_list.append([datetime.datetime(2016, 11,26),"Milano","Italy","Milano","Mantua",80,0,0,0,'Milano and Mantua 2016',['Riju']])
data_list.append([datetime.datetime(2016, 11,26),"Mantua","Italy","Milano","Mantua",122,0,1,0,'Milano and Mantua 2016',['Riju']])
data_list.append([datetime.datetime(2016, 11,27),"Mantua","Italy","Mantua",'Genf',140,0,0,0,'Milano and Mantua 2016',['Riju']])
data_list.append([datetime.datetime(2016, 11,27),"Verona","Italy","Mantua",'Genf',102,0,0,0,'Milano and Mantua 2016',['Riju']])
##
data_list.append([datetime.datetime(2016, 12, 4),"Lauchringen","Germany","Lauchringen","Lauchringen",53,1,-1,0,'Lauchringen IV 2016',['Marion','Artur','Heidrun','Franziska','Felicitas','Jan-Marc','Anne-Kathrin','Hannsjoerg']])
##Japan
data_list.append([datetime.datetime(2016, 12,5),"Tokyo","Japan",'Lauchringen',"Tokyo",1,0,1,1,'Japan 2016',[]])
data_list.append([datetime.datetime(2016, 12,6),"Tokyo","Japan","Tokyo","Morioka",2,0,0,0,'Japan 2016',[]])
data_list.append([datetime.datetime(2016, 12,6),"Morioka","Japan","Tokyo","Morioka",3,0,1,0,'Japan 2016',[]])
data_list.append([datetime.datetime(2016, 12,7),"Morioka","Japan","Morioka","Morioka",7,0,-1,0,'Japan 2016',[]])
data_list.append([datetime.datetime(2016, 12,8),"Morioka","Japan","Morioka","Morioka",3,0,-1,0,'Japan 2016',[]])
data_list.append([datetime.datetime(2016, 12,8),"Hiraizumi","Japan","Morioka","Morioka",45,0,-1,0,'Japan 2016',[]])
data_list.append([datetime.datetime(2016, 12,9),"Morioka","Japan","Morioka","Tokyo",2,0,0,0,'Japan 2016',[]])
data_list.append([datetime.datetime(2016, 12,9),"Tokyo","Japan","Morioka","Tokyo",62,0,1,0,'Japan 2016',[]])
data_list.append([datetime.datetime(2016, 12,10),"Nikko","Japan","Tokyo","Tokyo",143,0,-1,0,'Japan 2016',[]])
data_list.append([datetime.datetime(2016, 12,10),"Utsunomiya","Japan","Tokyo","Tokyo",1,0,-1,0,'Japan 2016',[]])
data_list.append([datetime.datetime(2016, 12,10),"Tokyo","Japan","Tokyo","Tokyo",2,0,-1,0,'Japan 2016',[]])
data_list.append([datetime.datetime(2016, 12,11),"Kyoto","Japan","Tokyo","Kyoto",162,0,1,0,'Japan 2016',[]])
data_list.append([datetime.datetime(2016, 12,12),"Kyoto","Japan","Kyoto","Kyoto",169,0,-1,0,'Japan 2016',[]])
data_list.append([datetime.datetime(2016, 12,13),"Nara","Japan","Kyoto","Kyoto",79,0,-1,0,'Japan 2016',[]])
data_list.append([datetime.datetime(2016, 12,13),"Ikaruga","Japan","Kyoto","Kyoto",26,0,-1,0,'Japan 2016',[]])
data_list.append([datetime.datetime(2016, 12,14),"Hiroshima","Japan","Kyoto","Kyoto",36,0,-1,0,'Japan 2016',[]])
data_list.append([datetime.datetime(2016, 12,14),"Fukuyama","Japan","Kyoto","Kyoto",2,0,-1,0,'Japan 2016',[]])
data_list.append([datetime.datetime(2016, 12,14),"Himeji","Japan","Kyoto","Kyoto",106,0,-1,0,'Japan 2016',[]])
data_list.append([datetime.datetime(2016, 12,14),"Kyoto","Japan","Kyoto","Kyoto",2,0,-1,0,'Japan 2016',[]])
data_list.append([datetime.datetime(2016, 12,15),"Kyoto","Japan","Kyoto","Kyoto",3,0,-1,0,'Japan 2016',[]])
data_list.append([datetime.datetime(2016, 12,15),"Hatsukaichi","Japan","Kyoto","Kyoto",52,0,-1,0,'Japan 2016',[]])
data_list.append([datetime.datetime(2016, 12,15),"Osaka","Japan","Kyoto","Kyoto",52,0,-1,0,'Japan 2016',[]])
data_list.append([datetime.datetime(2016, 12,16),"Kyoto","Japan","Kyoto","Tokyo",26,0,0,0,'Japan 2016',[]])
data_list.append([datetime.datetime(2016, 12,16),"Uji","Japan","Kyoto","Tokyo",16,0,0,0,'Japan 2016',[]])
data_list.append([datetime.datetime(2016, 12,16),"Tokyo","Japan","Kyoto","Tokyo",79,0,1,0,'Japan 2016',[]])
data_list.append([datetime.datetime(2016, 12,17),"Tokyo","Japan","Tokyo",'Genf',133,0,0,2,'Japan 2016',[]])
##

# %%
#2017
#Dublin
data_list.append([datetime.datetime(2017, 1, 2),"Dublin","Ireland",'Genf',"Dublin",64,0,1,2,'Dublin and Northern Ireland 2017',["Chris M"]])
data_list.append([datetime.datetime(2017, 1, 3),"Dublin","Ireland","Dublin","Dublin",74,0,-1,0,'Dublin and Northern Ireland 2017',["Chris M"]])
data_list.append([datetime.datetime(2017, 1, 4),"Ballycastle","United Kingdom","Dublin","Dublin",46,0,-1,0,'Dublin and Northern Ireland 2017',["Chris M"]])
data_list.append([datetime.datetime(2017, 1, 4),"Bushmills","United Kingdom","Dublin","Dublin",61,0,-1,0,'Dublin and Northern Ireland 2017',["Chris M"]])
data_list.append([datetime.datetime(2017, 1, 4),"Belfast","United Kingdom","Dublin","Dublin",2,0,-1,0,'Dublin and Northern Ireland 2017',["Chris M"]])
data_list.append([datetime.datetime(2017, 1, 4),"Belfast","United Kingdom","Dublin","Dublin",24,0,-1,0,'Dublin and Northern Ireland 2017',[]])
##Avignon
data_list.append([datetime.datetime(2017, 1, 13),"Avignon","France","Genf","Avignon",1,0,1,0,"Carcassonne & Avignon 2017",[]])
data_list.append([datetime.datetime(2017, 1, 14),"Carcassonne","France","Avignon","Avignon",150,0,-1,0,"Carcassonne & Avignon 2017",[]])
data_list.append([datetime.datetime(2017, 1, 14),"Avignon","France","Avignon","Avignon",17,0,-1,0,"Carcassonne & Avignon 2017",[]])
data_list.append([datetime.datetime(2017, 1, 15),"Avignon","France",'Avignon',"Genf",215,0,0,0,"Carcassonne & Avignon 2017",[]])
data_list.append([datetime.datetime(2017, 1, 15),"Villeneuve-les-Avignon","France","Avignon","Genf",12,0,0,0,"Carcassonne & Avignon 2017",[]])
data_list.append([datetime.datetime(2017, 1, 15),"Lyon","France","Avignon","Genf",3,0,1,0,"Carcassonne & Avignon 2017",[]])
##
data_list.append([datetime.datetime(2017, 1, 19),"Ferney-Voltaire","France","Genf","Genf",19,1,-1,0,'LHCb 2017',['LCD']])
##Belgium
data_list.append([datetime.datetime(2017, 2, 11),"Brussels","Belgium",'Genf',"Brussels",6,0,1,1,'Brussels 2017',["Riju"]])
data_list.append([datetime.datetime(2017, 2, 11),"Bruges","Belgium","Brussels","Ghent",96,0,1,0,'Brussels 2017',[]])
data_list.append([datetime.datetime(2017, 2, 11),"Ghent","Belgium","Brussels","Ghent",103,0,1,0,'Brussels 2017',[]])
data_list.append([datetime.datetime(2017, 2, 11),"Ghent","Belgium","Brussels","Ghent",17,0,1,0,'Brussels 2017',["Riju"]])
data_list.append([datetime.datetime(2017, 2, 12),"Ghent","Belgium","Ghent","Genf",56,0,0,2,'Brussels 2017',["Riju"]])
data_list.append([datetime.datetime(2017, 2, 12),"Antwerp","Belgium","Ghent","Genf",175,0,0,3,'Brussels 2017',["Riju"]])
##
data_list.append([datetime.datetime(2017, 2, 17),"Cessy","France","Genf","Genf",10,1,-1,0,'CMS 2017',['LCD']])
data_list.append([datetime.datetime(2017, 3, 4),"Lauchringen","Germany","Lauchringen","Lauchringen",5,1,-1,0,'Lauchringen I 2017',['Heidrun','Artur','Hannsjoerg','Anne-Kathrin']])
data_list.append([datetime.datetime(2017, 3, 4),"Oberalpfen","Germany","Lauchringen","Lauchringen",5,1,-1,0,'Lauchringen I 2017',['Marion','Felicitas','Jan-Marc','Franziska','Heidrun','Artur','Hannsjoerg','Anne-Kathrin']])
data_list.append([datetime.datetime(2017, 3, 12),"Les Brenets","Switzerland","Genf","Genf",40,1,-1,0,'Lac des Brenets 2017',['Sarah','Riju']])
data_list.append([datetime.datetime(2017, 3, 12),"Villers-le-Lac","France","Genf","Genf",20,1,-1,0,'Lac des Brenets 2017',['Sarah','Riju']])
data_list.append([datetime.datetime(2017, 3, 12),"Le Cerneux-Pequignot","Switzerland","Genf","Genf",2,1,-1,0,'Lac des Brenets 2017',['Sarah','Riju']])
data_list.append([datetime.datetime(2017, 3, 12),"Neuchatel","Switzerland","Genf","Genf",23,1,-1,0,'Lac des Brenets 2017',['Sarah','Riju']])
##Assisi
data_list.append([datetime.datetime(2017, 3, 24),"Milano","Italy","Genf",'Milano',2,0,1,0,'Assisi and Perugia 2017',[]])
data_list.append([datetime.datetime(2017, 3, 25),"Milano","Italy","Milano",'Assisi',2,0,0,0,'Assisi and Perugia 2017',[]])
data_list.append([datetime.datetime(2017, 3, 25),"Assisi","Italy","Milano",'Assisi',194,0,1,0,'Assisi and Perugia 2017',[]])
data_list.append([datetime.datetime(2017, 3, 26),"Assisi","Italy","Assisi",'Genf',16,0,0,0,'Assisi and Perugia 2017',[]])
data_list.append([datetime.datetime(2017, 3, 26),"Perugia","Italy","Assisi",'Genf',107,0,0,0,'Assisi and Perugia 2017',[]])
data_list.append([datetime.datetime(2017, 3, 26),"Florence","Italy","Assisi",'Genf',5,0,0,0,'Assisi and Perugia 2017',[]])
data_list.append([datetime.datetime(2017, 3, 26),"Bologna","Italy","Assisi",'Genf',1,0,0,0,'Assisi and Perugia 2017',[]])
data_list.append([datetime.datetime(2017, 3, 26),"Milano","Italy","Assisi",'Genf',2,0,1,0,'Assisi and Perugia 2017',[]])
##Kiev
data_list.append([datetime.datetime(2017, 4, 14),"Kiev","Ukraine","Kiev",'Genf',2,0,1,1,'Kiev 2017',[]])
data_list.append([datetime.datetime(2017, 4, 15),"Kiev","Ukraine","Kiev","Kiev",278,0,-1,0,'Kiev 2017',[]])
data_list.append([datetime.datetime(2017, 4, 16),"Kiev","Ukraine","Kiev","Kiev",127,0,-1,0,'Kiev 2017',[]])
data_list.append([datetime.datetime(2017, 4, 17),"Boryspil","Ukraine","Kiev",'Genf',3,0,0,2,'Kiev 2017',[]])
##Frankfurt
data_list.append([datetime.datetime(2017, 4, 28),"Frankfurt","Germany",'Genf',"Frankfurt",17,0,1,1,'Frankfurt 2017',[]])
data_list.append([datetime.datetime(2017, 4, 29),"Frankfurt","Germany","Frankfurt","Frankfurt",91,0,-1,0,'Frankfurt 2017',[]])
data_list.append([datetime.datetime(2017, 4, 29),"Aschaffenburg","Germany","Frankfurt","Frankfurt",105,0,-1,0,'Frankfurt 2017',[]])
data_list.append([datetime.datetime(2017, 4, 29),"Wiesbaden","Germany","Frankfurt","Frankfurt",101,0,-1,0,'Frankfurt 2017',[]])
data_list.append([datetime.datetime(2017, 4, 30),"Karlsruhe","Germany","Frankfurt","Frankfurt",1,0,-1,0,'Frankfurt 2017',[]])
data_list.append([datetime.datetime(2017, 4, 30),"Bruchsal","Germany","Frankfurt","Frankfurt",103,0,-1,0,'Frankfurt 2017',[]])
data_list.append([datetime.datetime(2017, 4, 30),"Mannheim","Germany","Frankfurt","Frankfurt",59,0,-1,0,'Frankfurt 2017',[]])
data_list.append([datetime.datetime(2017, 4, 30),"Speyer","Germany","Frankfurt","Frankfurt",81,0,-1,0,'Frankfurt 2017',[]])
data_list.append([datetime.datetime(2017, 4, 30),"Mainz","Germany","Frankfurt","Frankfurt",53,0,-1,0,'Frankfurt 2017',[]])
data_list.append([datetime.datetime(2017, 5, 1),"Frankfurt","Germany","Frankfurt","Frankfurt",1,0,-1,0,'Frankfurt 2017',[]])
data_list.append([datetime.datetime(2017, 5, 1),"Wuerzburg","Germany","Frankfurt","Frankfurt",5,0,-1,0,'Frankfurt 2017',[]])
data_list.append([datetime.datetime(2017, 5, 1),"Kassel","Germany","Frankfurt","Frankfurt",202,0,-1,0,'Frankfurt 2017',[]])
data_list.append([datetime.datetime(2017, 5, 2),"Frankfurt","Germany","Frankfurt","Genf",1,0,0,2,'Frankfurt 2017',[]])
##

# %%
#Madrid
data_list.append([datetime.datetime(2017, 5, 24),"Madrid","Spain","Madrid",'Genf',2,0,1,2,'Madrid 2017',[]])
data_list.append([datetime.datetime(2017, 5, 25),"Salamanca","Spain","Madrid","Madrid",259,0,-1,0,'Madrid 2017',[]])
data_list.append([datetime.datetime(2017, 5, 26),"Valencia","Spain","Madrid","Madrid",286,0,-1,0,'Madrid 2017',[]])
data_list.append([datetime.datetime(2017, 5, 27),"Leon","Spain","Madrid","Madrid",117,0,-1,0,'Madrid 2017',[]])
data_list.append([datetime.datetime(2017, 5, 27),"Oviedo","Spain","Madrid","Madrid",110,0,-1,0,'Madrid 2017',[]])
data_list.append([datetime.datetime(2017, 5, 28),"Avila","Spain","Madrid","Genf",159,0,0,2,'Madrid 2017',[]])
##
data_list.append([datetime.datetime(2017, 6, 1),"Meyrin","Switzerland","Genf","Genf",18,1,-1,0,'CERN Relay Race 2017',["LCD"]])
#Athens
data_list.append([datetime.datetime(2017, 6, 3),"Athens","Greece",'Genf',"Athens",16,0,1,1,'Athens 2017',['Riju','Amin']])
data_list.append([datetime.datetime(2017, 6, 3),"Athens","Greece",'Genf',"Athens",48,0,1,1,'Athens 2017',['Riju','Amin','MaryAnn']])
data_list.append([datetime.datetime(2017, 6, 4),"Athens","Greece","Athens","Athens",122,0,-1,0,'Athens 2017',['Riju','Amin','MaryAnn']])
data_list.append([datetime.datetime(2017, 6, 4),"Athens","Greece","Athens","Athens",63,0,-1,0,'Athens 2017',['Riju','Amin']])
data_list.append([datetime.datetime(2017, 6, 5),"Athens","Greece","Athens","Athens",2,0,-1,0,'Athens 2017',['Riju','Amin']])
data_list.append([datetime.datetime(2017, 6, 5),"Delphi","Greece","Athens","Athens",84,0,-1,0,'Athens 2017',['Riju','Amin']])
data_list.append([datetime.datetime(2017, 6, 6),"Athens","Greece","Athens",'Genf',1,0,0,2,'Athens 2017',['Riju','Amin']])
#USA
data_list.append([datetime.datetime(2017, 6, 9),"Le Mesnil-Amelot","France","Genf","Twin Falls",11,0,0,1,'USA Yellowstone and Grand Teton 2017',['Heidrun','Artur']])
data_list.append([datetime.datetime(2017, 6, 10),"Twin Falls","USA","Twin Falls","Twin Falls",41,0,-1,0,'USA Yellowstone and Grand Teton 2017',['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2017, 6, 10),"Bruneau","USA","Twin Falls","Twin Falls",32,0,-1,0,'USA Yellowstone and Grand Teton 2017',['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2017, 6, 10),"Bliss","USA","Twin Falls","Twin Falls",5,0,-1,0,'USA Yellowstone and Grand Teton 2017',['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2017, 6, 10),"Salmon Springs","USA","Twin Falls","Twin Falls",4,0,-1,0,'USA Yellowstone and Grand Teton 2017',['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2017, 6, 11),"Arco","USA","Twin Falls","Island Park",111,0,0,0,'USA Yellowstone and Grand Teton 2017',['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2017, 6, 12),"West Yellowstone","USA","Island Park","Island Park",43,0,-1,0,'USA Yellowstone and Grand Teton 2017',['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2017, 6, 13),"Madison","USA","Island Park","Island Park",13,0,-1,0,'USA Yellowstone and Grand Teton 2017',['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2017, 6, 13),"Norris","USA","Island Park","Island Park",36,0,-1,0,'USA Yellowstone and Grand Teton 2017',['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2017, 6, 13),"Gardiner","USA","Island Park","Island Park",71,0,-1,0,'USA Yellowstone and Grand Teton 2017',['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2017, 6, 14),"West Yellowstone","USA","Island Park","Island Park",12,0,-1,0,'USA Yellowstone and Grand Teton 2017',['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2017, 6, 14),"Norris","USA","Island Park","Island Park",1,0,-1,0,'USA Yellowstone and Grand Teton 2017',['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2017, 6, 14),"Canyon Village","USA","Island Park","Island Park",81,0,-1,0,'USA Yellowstone and Grand Teton 2017',['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2017, 6, 14),"Roosevelt","USA","Island Park","Island Park",18,0,-1,0,'USA Yellowstone and Grand Teton 2017',['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2017, 6, 14),"Island Park","USA","Island Park","Island Park",2,0,-1,0,'USA Yellowstone and Grand Teton 2017',['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2017, 6, 15),"Lake Village","USA","Island Park","Island Park",57,0,-1,0,'USA Yellowstone and Grand Teton 2017',['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2017, 6, 15),"Grant Village","USA","Island Park","Island Park",31,0,-1,0,'USA Yellowstone and Grand Teton 2017',['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2017, 6, 15),"West Yellowstone","USA","Island Park","Island Park",52,0,-1,0,'USA Yellowstone and Grand Teton 2017',['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2017, 6, 16),"Ashton","USA","Island Park","Island Park",28,0,-1,0,'USA Yellowstone and Grand Teton 2017',['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2017, 6, 17),"Jackson","USA","Island Park","Jackson",20,0,1,0,'USA Yellowstone and Grand Teton 2017',['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2017, 6, 18),"Jackson","USA","Jackson","Jackson",91,0,-1,0,'USA Yellowstone and Grand Teton 2017',['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2017, 6, 19),"Jackson","USA","Jackson","Jackson",69,0,-1,0,'USA Yellowstone and Grand Teton 2017',['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2017, 6, 20),"Afton","USA","Jackson","Salt Lake City",33,0,0,0,'USA Yellowstone and Grand Teton 2017',['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2017, 6, 20),"Salt Lake City","USA","Jackson","Salt Lake City",1,0,-1,0,'USA Yellowstone and Grand Teton 2017',['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2017, 6, 21),"Salt Lake City","USA","Salt Lake City","Salt Lake City",114,0,-1,0,'USA Yellowstone and Grand Teton 2017',['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2017, 6, 22),"Magna","USA","Salt Lake City",'Genf',16,0,0,2,'USA Yellowstone and Grand Teton 2017',['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2017, 6, 22),"Salt Lake City","USA","Salt Lake City",'Genf',56,0,0,2,'USA Yellowstone and Grand Teton 2017',['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2017, 6, 23),"Le Bourget","France","Salt Lake City",'Genf',1,0,1,2,'USA Yellowstone and Grand Teton 2017',['Heidrun','Artur']])
data_list.append([datetime.datetime(2017, 6, 23),"Drancy","France","Salt Lake City",'Genf',2,0,1,2,'USA Yellowstone and Grand Teton 2017',['Heidrun','Artur']])
data_list.append([datetime.datetime(2017, 6, 23),"Bondy","France","Salt Lake City",'Genf',1,0,1,2,'USA Yellowstone and Grand Teton 2017',['Heidrun','Artur']])
data_list.append([datetime.datetime(2017, 6, 23),"Neueilly-Plaisance","France","Salt Lake City",'Genf',1,0,1,2,'USA Yellowstone and Grand Teton 2017',['Heidrun','Artur']])
data_list.append([datetime.datetime(2017, 6, 23),"Perreux-sur-Marne","France","Salt Lake City",'Genf',1,0,1,2,'USA Yellowstone and Grand Teton 2017',['Heidrun','Artur']])
data_list.append([datetime.datetime(2017, 6, 23),"Champigny-sur-Marne","France","Salt Lake City",'Genf',1,0,1,2,'USA Yellowstone and Grand Teton 2017',['Heidrun','Artur']])
data_list.append([datetime.datetime(2017, 6, 23),'Adamville',"France","Salt Lake City",'Genf',1,0,1,2,'USA Yellowstone and Grand Teton 2017',['Heidrun','Artur']])
data_list.append([datetime.datetime(2017, 6, 23),"Bonneuil-sur-Marne","France","Salt Lake City",'Genf',1,0,1,2,'USA Yellowstone and Grand Teton 2017',['Heidrun','Artur']])
##

# %%
#2017
#Venice
data_list.append([datetime.datetime(2017, 7, 5),"Venice","Italy",'Genf',"Venice",1,0,1,1,'Venice EPS 2017',[]])
data_list.append([datetime.datetime(2017, 7, 6),"Venice","Italy","Venice","Venice",33,0,-1,0,'Venice EPS 2017',[]])
data_list.append([datetime.datetime(2017, 7, 7),"Venice","Italy","Venice","Venice",8,0,-1,0,'Venice EPS 2017',[]])
data_list.append([datetime.datetime(2017, 7, 8),"Venice","Italy","Venice","Venice",222,0,-1,0,'Venice EPS 2017',['Riju','Reyer','Indara']])
data_list.append([datetime.datetime(2017, 7, 9),"Venice","Italy","Venice","Venice",38,0,-1,0,'Venice EPS 2017',[]])
data_list.append([datetime.datetime(2017, 7, 9),"Lorero","Italy","Venice","Venice",78,0,-1,0,'Venice EPS 2017',[]])
data_list.append([datetime.datetime(2017, 7, 9),"Ancona","Italy","Venice","Venice",82,0,-1,0,'Venice EPS 2017',[]])
data_list.append([datetime.datetime(2017, 7, 10),"Venice","Italy","Venice","Venice",183,0,-1,0,'Venice EPS 2017',[]])
data_list.append([datetime.datetime(2017, 7, 10),"Venice","Italy","Venice","Venice",34,0,-1,0,'Venice EPS 2017',['Indara']])
data_list.append([datetime.datetime(2017, 7, 11),"Venice","Italy","Venice","Venice",21,0,-1,0,'Venice EPS 2017',['Indara']])
data_list.append([datetime.datetime(2017, 7, 12),"Vicenza","Italy","Venice","Venice",187,0,-1,0,'Venice EPS 2017',[]])
data_list.append([datetime.datetime(2017, 7, 12),"Stra","Italy","Venice","Venice",61,0,-1,0,'Venice EPS 2017',[]])
data_list.append([datetime.datetime(2017, 7, 13),"Ferrara","Italy","Venice","Trieste",176,0,0,0,'Venice EPS 2017',[]])
data_list.append([datetime.datetime(2017, 7, 13),"Padua","Italy","Venice","Trieste",72,0,0,0,'Venice EPS 2017',[]])
data_list.append([datetime.datetime(2017, 7, 14),"Divaca","Slovenia","Trieste","Trieste",85,0,-1,0,'Venice EPS 2017',['Reyer']])
data_list.append([datetime.datetime(2017, 7, 14),"Porec","Croatia","Trieste","Trieste",72,0,-1,0,'Venice EPS 2017',['Reyer']])
data_list.append([datetime.datetime(2017, 7, 14),"Trieste","Italy","Trieste","Trieste",20,0,-1,0,'Venice EPS 2017',['Reyer']])
data_list.append([datetime.datetime(2017, 7, 15),"Aquileia","Italy","Trieste","Trieste",42,0,-1,0,'Venice EPS 2017',['Reyer']])
data_list.append([datetime.datetime(2017, 7, 15),"Cividale del Friuli","Italy","Trieste","Trieste",55,0,-1,0,'Venice EPS 2017',['Reyer']])
data_list.append([datetime.datetime(2017, 7, 15),"Trieste","Italy","Trieste",'Trieste',42,0,-1,0,'Venice EPS 2017',['Reyer']])
data_list.append([datetime.datetime(2017, 7, 16),"Sgonico","Italy","Trieste",'Genf',114,0,0,2,'Venice EPS 2017',['Reyer']])
data_list.append([datetime.datetime(2017, 7, 16),"Trieste","Italy","Trieste",'Genf',17,0,0,2,'Venice EPS 2017',['Reyer']])
##Oslo
data_list.append([datetime.datetime(2017, 7, 21),"Zeventem","Belgium",'Genf',"Oslo",2,0,-1,3,'Oslo 2017',[]])
data_list.append([datetime.datetime(2017, 7, 21),"Gardermoen","Norway","Genf",'Oslo',1,0,1,1,'Oslo 2017',[]])
data_list.append([datetime.datetime(2017, 7, 21),"Oslo","Norway","Oslo",'Oslo',17,0,-1,0,'Oslo 2017',[]])
data_list.append([datetime.datetime(2017, 7, 22),"Oslo","Norway","Oslo",'Oslo',218,0,-1,0,'Oslo 2017',[]])
data_list.append([datetime.datetime(2017, 7, 22),"Oslo","Norway","Oslo",'Oslo',3,0,-1,0,'Oslo 2017',['Messay']])
data_list.append([datetime.datetime(2017, 7, 23),"Oslo","Norway","Oslo",'Oslo',104,0,-1,0,'Oslo 2017',[]])
data_list.append([datetime.datetime(2017, 7, 23),"Gardermoen","Norway","Oslo",'Genf',6,0,0,2,'Oslo 2017',[]])
data_list.append([datetime.datetime(2017, 7, 23),"Kloten","Switzerland","Oslo",'Genf',2,0,1,2,'Oslo 2017',[]])
#Munich
data_list.append([datetime.datetime(2017, 7, 29),"Garching","Germany","Garching","Garching",6,0,-1,0,'Muenchen 2017',['Eric','Siyi']])
data_list.append([datetime.datetime(2017, 7, 29),"Munich","Germany","Garching","Garching",150,0,-1,0,'Muenchen 2017',['Eric','Siyi']])
data_list.append([datetime.datetime(2017, 7, 30),"Munich","Germany","Garching",'Genf',159,0,0,2,'Muenchen 2017',[]])
data_list.append([datetime.datetime(2017, 7, 30),"Erding","Germany","Garching",'Genf',2,0,0,2,'Muenchen 2017',[]])
##
data_list.append([datetime.datetime(2017, 8, 1),"Meyrin","Switzerland","Genf",'Genf',9,1,-1,0,'Swiss National Holiday 2017',['Eva','Ulrike']])
data_list.append([datetime.datetime(2017, 8, 5),"Bechtersbohl","Germany","Lauchringen","Lauchringen",14,1,-1,0,'Kuessaburg 2017',['Christian','Artur','Anne-Kathrin']])
data_list.append([datetime.datetime(2017, 8, 5),"Lauchringen","Germany","Lauchringen","Lauchringen",19,1,-1,0,'Lauchringen II 2017',['Franziska','Jan-Marc','Felicitas','Christian','Artur','Anne-Kathrin','Heidrun']])
data_list.append([datetime.datetime(2017, 8, 26),"Les-Diablerets","Switzerland","Genf","Genf",93,1,-1,0,'Glacier 3000',[]])
#split
data_list.append([datetime.datetime(2017, 8, 27),"Trogir","Croatia","Genf",'Split',61,0,1,1,'Split 2017',[]])
data_list.append([datetime.datetime(2017, 8, 27),"Split","Croatia",'Genf',"Split",234,0,1,1,'Split 2017',[]])
data_list.append([datetime.datetime(2017, 8, 28),"Trogir","Croatia","Split",'Genf',3,0,0,2,'Split 2017',[]])
##
data_list.append([datetime.datetime(2017, 9, 3),"Lauchringen","Germany","Lauchringen",'Lauchringen',19,1,-1,0,'Lauchringen III 2017',['Heidrun','Franziska','Jan-Marc','Felicitas','Christian','Artur','Anne-Kathrin','Marion']])

# %%
#2017
#Rome
data_list.append([datetime.datetime(2017, 9, 6),"Rome","Italy","Genf",'Rome',24,0,1,1,'Rome 2017',['Riju']])
data_list.append([datetime.datetime(2017, 9, 7),"Rome","Italy","Rome",'Rome',259,0,-1,0,'Rome 2017',['Riju']])
data_list.append([datetime.datetime(2017, 9, 7),"Rome","Vatican","Rome",'Rome',289,0,-1,0,'Rome 2017',['Riju']])
data_list.append([datetime.datetime(2017, 9, 8),"Rome","Italy","Rome",'Rome',165,0,-1,0,'Rome 2017',['Riju']])
data_list.append([datetime.datetime(2017, 9, 8),"Rome","Vatican","Rome",'Rome',59,0,-1,0,'Rome 2017',['Riju']])
data_list.append([datetime.datetime(2017, 9, 8),"Rome","Vatican","Rome",'Rome',62,0,-1,0,'Rome 2017',['Riju','Amin']])
data_list.append([datetime.datetime(2017, 9, 8),"Rome","Italy","Rome",'Rome',209,0,-1,0,'Rome 2017',['Riju','Amin']])
data_list.append([datetime.datetime(2017, 9, 9),"Rome","Italy","Rome",'Rome',166,0,-1,0,'Rome 2017',['Amin']])
data_list.append([datetime.datetime(2017, 9, 9),"Rome","Italy","Rome",'Rome',163,0,-1,0,'Rome 2017',[]])
data_list.append([datetime.datetime(2017, 9, 9),"Rome","Vatican","Rome",'Rome',11,0,-1,0,'Rome 2017',['Riju','Amin']])
data_list.append([datetime.datetime(2017, 9, 9),"Rome","Italy","Rome",'Rome',17,0,-1,0,'Rome 2017',['Riju','Amin']])
data_list.append([datetime.datetime(2017, 9, 10),"Rome","Italy","Rome",'Rome',52,0,-1,0,'Rome 2017',['Riju','Amin']])
data_list.append([datetime.datetime(2017, 9, 10),"Rome","Italy","Rome",'Rome',181,0,-1,0,'Rome 2017',[]])
data_list.append([datetime.datetime(2017, 9, 11),"Fiumicino","Italy","Rome",'Genf',1,0,0,2,'Rome 2017',['Riju','Amin']])
data_list.append([datetime.datetime(2017, 9, 11),"Chiavari","Italy","Rome",'Genf',1,0,0,2,'Rome 2017',['Riju','Amin']])
data_list.append([datetime.datetime(2017, 9, 11),"Rapallo","Italy","Rome",'Genf',1,0,0,2,'Rome 2017',['Riju','Amin']])
#London
data_list.append([datetime.datetime(2017, 9, 16),"London","United Kingdom","London","London",189,0,-1,0,'London 2017',['Riju']])
data_list.append([datetime.datetime(2017, 9, 16),"London","United Kingdom","London","London",69,0,-1,0,'London 2017',[]])
data_list.append([datetime.datetime(2017, 9, 17),"London","United Kingdom","London","Genf",280,0,0,2,'London 2017',['Riju']])
##
data_list.append([datetime.datetime(2017, 9, 20),"Zurich","Switzerland","Genf","Genf",57,1,-1,0,'Rolling Stones Concert 2017',['Artur','Heidrun','Angelika','Rickard']])
#Graz
data_list.append([datetime.datetime(2017, 9, 30),"Graz","Austria","Genf",'Graz',154,0,1,1,'Graz 2017',[]])
data_list.append([datetime.datetime(2017, 10, 1),"Graz","Austria","Graz",'Genf',74,0,0,2,'Graz 2017',[]])
data_list.append([datetime.datetime(2017, 10, 1),"Feldkirchen","Austria","Graz",'Genf',4,0,0,2,'Graz 2017',[]])
data_list.append([datetime.datetime(2017, 10, 1),"Kloten","Switzerland","Graz",'Genf',4,0,1,2,'Graz 2017',[]])
#Estonia
data_list.append([datetime.datetime(2017, 10, 6),"Warsaw","Poland","Genf",'Tallinn',8,0,-1,3,'Tallinn and Helsinki 2017',['Riju','Rachel','Reyer']])
data_list.append([datetime.datetime(2017, 10, 6),"Tallinn","Estonia",'Genf',"Tallinn",25,0,1,1,'Tallinn and Helsinki 2017',['Riju','Rachel','Reyer']])
data_list.append([datetime.datetime(2017, 10, 7),"Tallinn","Estonia","Tallinn","Tallinn",4,0,-1,0,'Tallinn and Helsinki 2017',['Riju','Rachel','Reyer']])
data_list.append([datetime.datetime(2017, 10, 7),"Helsinki","Finland","Tallinn","Tallinn",112,0,-1,0,'Tallinn and Helsinki 2017',['Riju','Rachel','Reyer']])
data_list.append([datetime.datetime(2017, 10, 8),"Tallinn","Estonia","Tallinn","Tallinn",139,0,-1,0,'Tallinn and Helsinki 2017',['Riju','Rachel','Reyer']])
data_list.append([datetime.datetime(2017, 10, 9),"Schwechat","Austria","Tallinn",'Genf',5,0,-1,3,'Tallinn and Helsinki 2017',['Riju','Rachel','Reyer']])
data_list.append([datetime.datetime(2017, 10, 9),"Vienna","Austria","Tallinn",'Genf',6,0,-1,3,'Tallinn and Helsinki 2017',['Riju','Rachel','Reyer']])
##
data_list.append([datetime.datetime(2017, 10, 15),"Randa","Switzerland","Genf","Genf",5,1,-1,0,'Zermatt 2017',['Riju']])
data_list.append([datetime.datetime(2017, 10, 15),"Taesch","Switzerland","Genf","Genf",1,1,-1,0,'Zermatt 2017',['Riju']])
data_list.append([datetime.datetime(2017, 10, 15),"Zermatt","Switzerland","Genf","Genf",103,1,-1,0,'Zermatt 2017',['Riju']])

# %%
#2017
data_list.append([datetime.datetime(2017, 10, 15),"Sankt Gallen","Switzerland","Genf","Genf",77,1,-1,0,'St Gallen and Reichenau 2017',[]])
data_list.append([datetime.datetime(2017, 10, 15),"Reichenau","Germany","Genf","Genf",48,1,-1,0,'St Gallen and Reichenau 2017',[]])
data_list.append([datetime.datetime(2017, 10, 15),"Konstanz","Germany","Genf","Genf",34,1,-1,0,'St Gallen and Reichenau 2017',[]])
#Marrakech
data_list.append([datetime.datetime(2017, 11, 10),"Marrakech","Morocco","Genf","Marrakech",138,0,1,1,'Marrakech 2017',['Riju','Cameron','Tony']])
data_list.append([datetime.datetime(2017, 11, 11),"Marrakech","Morocco","Marrakech","Marrakech",4,0,-1,0,'Marrakech 2017',['Riju','Cameron','Tony']])
data_list.append([datetime.datetime(2017, 11, 11),"Tiglatine","Morocco","Marrakech","Marrakech",2,0,-1,0,'Marrakech 2017',['Riju','Cameron','Tony']])
data_list.append([datetime.datetime(2017, 11, 11),"Douar Ait-Imgeur","Morocco","Marrakech","Marrakech",1,0,-1,0,'Marrakech 2017',['Riju','Cameron','Tony']])
data_list.append([datetime.datetime(2017, 11, 11),"Toufliht","Morocco","Marrakech","Marrakech",5,0,-1,0,'Marrakech 2017',['Riju','Cameron','Tony']])
data_list.append([datetime.datetime(2017, 11, 11),"Tizi N'Tichka","Morocco","Marrakech","Marrakech",7,0,-1,0,'Marrakech 2017',['Riju','Cameron','Tony']])
data_list.append([datetime.datetime(2017, 11, 11),"Abadou","Morocco","Marrakech","Marrakech",2,0,-1,0,'Marrakech 2017',['Riju','Cameron','Tony']])
data_list.append([datetime.datetime(2017, 11, 11),"Telouet","Morocco","Marrakech","Marrakech",27,0,-1,0,'Marrakech 2017',['Riju','Cameron','Tony']])
data_list.append([datetime.datetime(2017, 11, 11),"Ounila","Morocco","Marrakech","Marrakech",5,0,-1,0,'Marrakech 2017',['Riju','Cameron','Tony']])
data_list.append([datetime.datetime(2017, 11, 11),"Ait Ben Haddou","Morocco","Marrakech","Marrakech",48,0,-1,0,'Marrakech 2017',['Riju','Cameron','Tony']])
data_list.append([datetime.datetime(2017, 11, 12),"Marrakech","Morocco","Marrakech","Marrakech",129,0,-1,0,'Marrakech 2017',['Riju','Cameron','Tony']])
data_list.append([datetime.datetime(2017, 11, 13),"Marrakech","Morocco","Marrakech","Genf",12,0,0,2,'Marrakech 2017',['Riju','Cameron','Tony']])
data_list.append([datetime.datetime(2017, 11, 13),"Casablanca","Morocco","Marrakech","Genf",6,0,0,2,'Marrakech 2017',['Riju','Cameron','Tony']])
##
data_list.append([datetime.datetime(2017, 11, 18),"Marmagne","France","Genf","Genf",50,1,-1,0,'Fontenay and Arc-et-Senans 2017',['Andrew']])
data_list.append([datetime.datetime(2017, 11, 18),"Arc-et-Senans","France","Genf","Genf",12,1,-1,0,'Fontenay and Arc-et-Senans 2017',['Andrew']])
data_list.append([datetime.datetime(2017, 11, 18),"Besancon","France","Genf","Genf",37,1,-1,0,'Fontenay and Arc-et-Senans 2017',['Andrew']])
data_list.append([datetime.datetime(2017, 12, 1),"Meyrin","Switzerland","Genf","Genf",10,1,-1,0,"Lucie's birthday 2017",['LCD']])
data_list.append([datetime.datetime(2017, 12, 2),"Lauchringen","Germany","Lauchringen","Lauchringen",11,1,-1,0,'Lauchringen IV 2017',['Heidrun','Hannsjoerg','Felicitas','Franziska','Jan-Marc','Artur']])
data_list.append([datetime.datetime(2017, 12, 9),"Lyon","France","Genf","Genf",42,1,-1,0,'Lyon Fete de Lumiere 2017',['Riju','Reyer','Rachel','Tony','Cameron']])
#China
data_list.append([datetime.datetime(2017, 12, 30),"Shanghai","China","Shanghai","Shanghai",18,0,-1,0,"China 2017 and 2018",[]])
data_list.append([datetime.datetime(2017, 12, 31),"Shanghai","China","Shanghai","Shanghai",47,0,-1,0,"China 2017 and 2018",['Siyi']])

# %%
#2018
data_list.append([datetime.datetime(2018, 1, 1),"Shanghai","China","Shanghai","Suzhou",14,0,0,0,"China 2017 and 2018",['Siyi']])
data_list.append([datetime.datetime(2018, 1, 1),"Suzhou","China","Shanghai","Suzhou",7,0,1,0,"China 2017 and 2018",[]])
data_list.append([datetime.datetime(2018, 1, 2),"Suzhou","China","Suzhou","Suzhou",5,0,-1,0,"China 2017 and 2018",[]])
data_list.append([datetime.datetime(2018, 1, 2),"Hangzhou","China","Suzhou","Suzhou",148,0,-1,0,"China 2017 and 2018",[]])
data_list.append([datetime.datetime(2018, 1, 3),"Suzhou","China","Suzhou","Kunshan",133,0,0,0,"China 2017 and 2018",[]])
data_list.append([datetime.datetime(2018, 1, 3),"Luzhi Town","China","Suzhou","Kunshan",29,0,1,0,"China 2017 and 2018",['Siyi']])
data_list.append([datetime.datetime(2018, 1, 3),"Kunshan","China","Suzhou","Kunshan",8,0,1,0,"China 2017 and 2018",['Siyi']])
data_list.append([datetime.datetime(2018, 1, 4),"Nanjing","China","Kunshan","Nanjing",108,0,1,0,"China 2017 and 2018",[]])
data_list.append([datetime.datetime(2018, 1, 4),"Nanjing","China","Kunshan","Nanjing",1,0,1,0,"China 2017 and 2018",['Siyi',"Zhicheng"]])
data_list.append([datetime.datetime(2018, 1, 5),"Nanjing","China","Nanjing","Nanjing",98,0,-1,0,"China 2017 and 2018",['Siyi',"Zhicheng"]])
data_list.append([datetime.datetime(2018, 1, 5),"Nanjing","China","Nanjing","Nanjing",52,0,-1,0,"China 2017 and 2018",[]])
data_list.append([datetime.datetime(2018, 1, 5),"Nanjing","China","Nanjing","Nanjing",52,0,-1,0,"China 2017 and 2018",[]])
data_list.append([datetime.datetime(2018, 1, 6),"Nanjing","China","Nanjing","Beijing",99,0,0,0,"China 2017 and 2018",[]])
data_list.append([datetime.datetime(2018, 1, 6),"Beijing","China","Nanjing","Beijing",1,0,1,0,"China 2017 and 2018",[]])
data_list.append([datetime.datetime(2018, 1, 7),"Beijing","China","Beijing","Beijing",390,0,-1,0,"China 2017 and 2018",[]])
data_list.append([datetime.datetime(2018, 1, 8),"Juyongguan","China","Beijing","Beijing",7,0,-1,0,"China 2017 and 2018",[]])
data_list.append([datetime.datetime(2018, 1, 8),"Badaling","China","Beijing","Beijing",80,0,-1,0,"China 2017 and 2018",[]])
data_list.append([datetime.datetime(2018, 1, 8),"Beijing","China","Beijing","Beijing",68,0,-1,0,"China 2017 and 2018",[]])
data_list.append([datetime.datetime(2018, 1, 9),"Beijing","China","Beijing","Beijing",357,0,-1,0,"China 2017 and 2018",[]])
data_list.append([datetime.datetime(2018, 1, 10),"Beijing","China","Beijing","Beijing",220,0,-1,0,"China 2017 and 2018",[]])
data_list.append([datetime.datetime(2018, 1, 11),"Luoyang","China","Beijing","Xi'an",138,0,1,0,"China 2017 and 2018",[]])
data_list.append([datetime.datetime(2018, 1, 11),"Xi'an","China","Beijing","Xi'an",37,0,1,0,"China 2017 and 2018",[]])
data_list.append([datetime.datetime(2018, 1, 12),"Xi'an","China","Xi'an","Beijing",179,0,0,0,"China 2017 and 2018",[]])
data_list.append([datetime.datetime(2018, 1, 12),"Sanmenxia","China","Xi'an","Beijing",179,0,0,0,"China 2017 and 2018",[]])
data_list.append([datetime.datetime(2018, 1, 13),"Beijing","China","Beijing","Beijing",67,0,-1,0,"China 2017 and 2018",[]])
data_list.append([datetime.datetime(2018, 1, 14),"Beijing","China","Beijing","Hong Kong",9,0,0,2,"China 2017 and 2018",[]])
data_list.append([datetime.datetime(2018, 1, 14),"Hong Kong","China","Beijing","Hong Kong",35,0,1,2,"China 2017 and 2018",[]])
data_list.append([datetime.datetime(2018, 1, 15),"Hong Kong","China","Hong Kong","Hong Kong",139,0,-1,0,"China 2017 and 2018",[]])
data_list.append([datetime.datetime(2018, 1, 16),"Hong Kong","China","Hong Kong","Hong Kong",78,0,-1,0,"China 2017 and 2018",[]])
data_list.append([datetime.datetime(2018, 1, 16),"Macao","China","Hong Kong","Hong Kong",111,0,-1,0,"China 2017 and 2018",[]])
data_list.append([datetime.datetime(2018, 1, 17),"Hong Kong","China","Hong Kong","Hong Kong",55,0,-1,0,"China 2017 and 2018",[]])
data_list.append([datetime.datetime(2018, 1, 20),"Hong Kong","China","Hong Kong","Genf",86,0,0,2,"China 2017 and 2018",[]])
data_list.append([datetime.datetime(2018, 1, 21),"Frankfurt","Germany","Hong Kong",'Genf',1,0,1,2,"China 2017 and 2018",[]])
##
data_list.append([datetime.datetime(2018, 1, 28),"Lausanne","Switzerland","Genf","Genf",45,1,-1,0,'Lausanne 2018',['Hannsjoerg']])
data_list.append([datetime.datetime(2018, 2, 20),"Nyon","Switzerland","Genf","Genf",27,1,-1,0,'Nyon 2018',['Hannsjoerg','Artur','Heidrun']])
##Toulouse
data_list.append([datetime.datetime(2018, 3, 3),"Toulouse","France","Genf","Toulouse",106,0,1,1,'Albi and Toulouse 2018',[]])
data_list.append([datetime.datetime(2018, 3, 3),"Albi","France","Genf","Toulouse",133,0,1,1,'Albi and Toulouse 2018',[]])
data_list.append([datetime.datetime(2018, 3, 4),"Toulouse","France","Toulouse",'Genf',143,0,0,2,'Albi and Toulouse 2018',[]])
##Brussels I
data_list.append([datetime.datetime(2018, 3, 10),"Brussels","Belgium","Brussels","Brussels",2,0,-1,0,'Brussels I and Amsterdam 2018',[]])
data_list.append([datetime.datetime(2018, 3, 10),"Amsterdam","Netherlands","Brussels","Brussels",108,0,-1,0,'Brussels I and Amsterdam 2018',['Mohammed']])
data_list.append([datetime.datetime(2018, 3, 11),"Brussels","Belgium","Brussels",'Genf',159,0,0,2,'Brussels I and Amsterdam 2018',['Mohammed']])
data_list.append([datetime.datetime(2018, 3, 11),"Zaventem","Belgium","Brussels",'Genf',1,0,0,2,'Brussels I and Amsterdam 2018',[]])

# %%
#2018
#ICELAND
data_list.append([datetime.datetime(2018, 3, 28),"Reykjavik","Iceland",'Genf',"Reykjavik",53,0,1,2,"Iceland 2018",['Riju','Rachel','Reyer']])
data_list.append([datetime.datetime(2018, 3, 29),"Iceland","Iceland","Reykjavik","Reykjavik",76,0,-1,0,"Iceland 2018",['Riju','Rachel','Reyer']])
data_list.append([datetime.datetime(2018, 3, 29),"Vik i Myrdal","Iceland","Reykjavik","Reykjavik",161,0,-1,0,"Iceland 2018",['Riju','Rachel','Reyer']])
data_list.append([datetime.datetime(2018, 3, 29),"Reykjavik","Iceland","Reykjavik","Reykjavik",3,0,-1,0,"Iceland 2018",['Riju','Rachel','Reyer']])
data_list.append([datetime.datetime(2018, 3, 30),"Hafnarfjoerthur","Iceland","Reykjavik","Reykjavik",41,0,-1,0,"Iceland 2018",['Riju','Rachel','Reyer']])
data_list.append([datetime.datetime(2018, 3, 30),"Thingvellir","Iceland","Reykjavik","Reykjavik",44,0,-1,0,"Iceland 2018",['Riju','Rachel','Reyer']])
data_list.append([datetime.datetime(2018, 3, 30),"Gulfoss","Iceland","Reykjavik","Reykjavik",29,0,-1,0,"Iceland 2018",['Riju','Rachel','Reyer']])
data_list.append([datetime.datetime(2018, 3, 30),"Haukadalur","Iceland","Reykjavik","Reykjavik",34,0,-1,0,"Iceland 2018",['Riju','Rachel','Reyer']])
data_list.append([datetime.datetime(2018, 3, 31),"Reykjavik","Iceland","Reykjavik","Genf",31,0,0,2,"Iceland 2018",['Riju']])
data_list.append([datetime.datetime(2018, 3, 31),"Keflavik","Iceland","Reykjavik","Genf",3,0,0,2,"Iceland 2018",['Riju','Rachel','Reyer']])
##
data_list.append([datetime.datetime(2018, 4, 7),"Sion","Switzerland","Genf","Genf",52,1,-1,0,'Sion 2018',['Artur','Heidrun']])
data_list.append([datetime.datetime(2018, 4, 7),"Vernayaz","Switzerland","Genf","Genf",6,1,-1,0,'Sion 2018',['Artur','Heidrun']])
#Copenhagen
data_list.append([datetime.datetime(2018, 4, 14),"Freising","Germany","Oberding","Frederiskberg",1,0,0,1,"Copenhagen 2018",[]])
data_list.append([datetime.datetime(2018, 4, 14),"Copenhagen","Denmark","Oberding","Frederiskberg",285,0,1,1,"Copenhagen 2018",['Riju','Rachel','Reyer']])
data_list.append([datetime.datetime(2018, 4, 15),"Copenhagen","Denmark","Frederiskberg",'Genf',1,0,0,2,"Copenhagen 2018",['Riju','Rachel','Reyer']])
data_list.append([datetime.datetime(2018, 4, 15),"Roskilde","Denmark","Frederiskberg",'Genf',125,0,0,2,"Copenhagen 2018",['Riju','Rachel','Reyer']])
data_list.append([datetime.datetime(2018, 4, 15),"Kastrup","Denmark","Frederiskberg",'Genf',1,0,0,2,"Copenhagen 2018",[]])
##France
data_list.append([datetime.datetime(2018, 4, 28),"Reims","France","Paris","Paris",181,0,-1,0,'Paris 2018',['Reyer','Christine M']])
data_list.append([datetime.datetime(2018, 4, 28),"Paris","France","Paris","Paris",2,0,-1,0,'Paris 2018',['Reyer','Christine M']])
data_list.append([datetime.datetime(2018, 4, 29),"Versailles","France","Paris","Paris",242,0,-1,0,'Paris 2018',['Reyer','Christine M']])
data_list.append([datetime.datetime(2018, 4, 29),"Paris","France","Paris","Paris",91,0,-1,0,'Paris 2018',['Reyer','Christine M']])
data_list.append([datetime.datetime(2018, 4, 30),"Bayeux","France","Paris","Paris",48,0,-1,0,'Paris 2018',['Reyer']])
data_list.append([datetime.datetime(2018, 4, 30),"Caen","France","Paris","Paris",46,0,-1,0,'Paris 2018',['Reyer']])
data_list.append([datetime.datetime(2018, 4, 30),"Rouen","France","Paris","Paris",108,0,-1,0,'Paris 2018',['Reyer']])
data_list.append([datetime.datetime(2018, 5, 1),"Paris","France","Paris",'Genf',2,0,0,0,'Paris 2018',['Reyer']])
data_list.append([datetime.datetime(2018, 5, 1),"Amiens","France","Paris",'Genf',120,0,0,0,'Paris 2018',['Reyer']])
data_list.append([datetime.datetime(2018, 5, 1),"Chartres","France","Paris",'Genf',110,0,0,0,'Paris 2018',['Reyer']])
#wedding
data_list.append([datetime.datetime(2018, 5, 11),"Buehl","Germany","Buehl","Buehl",46,0,-1,0,'Buehl 2018',['Heidrun','Artur','Anne-Kathrin','Christian','Hannsjoerg','Franziska','Felicitas','Jan-Marc']])
data_list.append([datetime.datetime(2018, 5, 11),"Baden-Baden","Germany","Buehl","Buehl",131,0,-1,0,'Buehl 2018',['Heidrun','Artur','Anne-Kathrin','Christian','Hannsjoerg','Franziska','Felicitas','Jan-Marc']])
data_list.append([datetime.datetime(2018, 5, 13),"Lauchringen","Germany","Lauchringen",'Genf',10,0,0,0,'Lauchringen I 2018',['Heidrun','Artur','Hannsjoerg','Franziska']])
#Lombardia
data_list.append([datetime.datetime(2018, 5, 19),"Certosa di Pavia","Italy","Milano","Milano",73,0,-1,0,'Milano 2018',['Amin']])
data_list.append([datetime.datetime(2018, 5, 19),"Pavia","Italy","Milano","Milano",93,0,-1,0,'Milano 2018',['Amin']])
data_list.append([datetime.datetime(2018, 5, 19),"Brescia","Italy","Milano","Milano",214,0,-1,0,'Milano 2018',['Amin']])
data_list.append([datetime.datetime(2018, 5, 20),"Bergamo","Italy","Milano","Milano",161,0,-1,0,'Milano 2018',['Amin']])
data_list.append([datetime.datetime(2018, 5, 20),"Cremona","Italy","Milano","Milano",91,0,-1,0,'Milano 2018',['Amin']])
data_list.append([datetime.datetime(2018, 5, 21),"Rimini","Italy","Milano",'Genf',1,0,0,0,'Milano 2018',['Amin']])
data_list.append([datetime.datetime(2018, 5, 21),"San Marino","San Marino","Milano",'Genf',78,0,0,0,'Milano 2018',['Amin']])
data_list.append([datetime.datetime(2018, 5, 21),"Milano","Italy","Milano",'Genf',108,0,0,0,'Milano 2018',['Amin']])
##

# %%
#2018
#Barcelona
data_list.append([datetime.datetime(2018, 5, 25),"Barcelona","Spain",'Genf',"Barcelona",3,0,1,1,'Barcelona 2018',['Rachel']])
data_list.append([datetime.datetime(2018, 5, 26),"Figueres","Spain","Barcelona","Barcelona",144,0,-1,0,'Barcelona 2018',[]])
data_list.append([datetime.datetime(2018, 5, 26),"Tarragona","Spain","Barcelona","Barcelona",113,0,-1,0,'Barcelona 2018',[]])
data_list.append([datetime.datetime(2018, 5, 26),"Barcelona","Spain","Barcelona","Barcelona",118,0,-1,0,'Barcelona 2018',['Rachel']])
data_list.append([datetime.datetime(2018, 5, 27),"Barcelona","Spain","Barcelona",'Castelldefels',215,0,0,0,'Barcelona 2018',[]])
data_list.append([datetime.datetime(2018, 5, 28),"Castelldefels","Spain","Barcelona","Castelldefels",2,0,1,0,'Barcelona 2018',[]])
data_list.append([datetime.datetime(2018, 5, 28),"Crawley","United Kingdom","Castelldefels",'Genf',3,0,-1,3,'Barcelona 2018',[]])
#Scotland & Midlands
data_list.append([datetime.datetime(2018, 6, 3),"Edinburgh","United Kingdom","Edinburgh","Edinburgh",101,0,-1,0,'Great Britain 2018',[]])
data_list.append([datetime.datetime(2018, 6, 3),"Stirling","United Kingdom","Edinburgh","Edinburgh",5,0,-1,0,'Great Britain 2018',[]])
data_list.append([datetime.datetime(2018, 6, 3),"Stirling","United Kingdom","Edinburgh","Edinburgh",41,0,-1,0,'Great Britain 2018',['Artur','Heidrun']])
data_list.append([datetime.datetime(2018, 6, 3),"Linlithgow","United Kingdom","Edinburgh","Edinburgh",9,0,-1,0,'Great Britain 2018',['Artur','Heidrun']])
data_list.append([datetime.datetime(2018, 6, 3),"Stirling","United Kingdom","Edinburgh","Edinburgh",42,0,-1,0,'Great Britain 2018',[]])
data_list.append([datetime.datetime(2018, 6, 3),"Queensferry","United Kingdom","Edinburgh","Edinburgh",24,0,-1,0,'Great Britain 2018',['Artur','Heidrun']])
data_list.append([datetime.datetime(2018, 6, 3),"North Queensferry","United Kingdom","Edinburgh","Edinburgh",4,0,-1,0,'Great Britain 2018',['Artur','Heidrun']])
data_list.append([datetime.datetime(2018, 6, 4),"Glasgow","United Kingdom","Edinburgh","York",68,0,0,0,'Great Britain 2018',['Artur','Heidrun']])
data_list.append([datetime.datetime(2018, 6, 4),"Falkirk","United Kingdom","Edinburgh","York",15,0,0,0,'Great Britain 2018',['Artur','Heidrun']])
data_list.append([datetime.datetime(2018, 6, 4),"York","United Kingdom","Edinburgh","York",47,0,1,0,'Great Britain 2018',['Artur','Heidrun']])
data_list.append([datetime.datetime(2018, 6, 5),"York","United Kingdom","York","York",115,0,-1,0,'Great Britain 2018',['Artur','Heidrun']])
data_list.append([datetime.datetime(2018, 6, 5),"Durham","United Kingdom","York","York",61,0,-1,0,'Great Britain 2018',['Artur','Heidrun']])
data_list.append([datetime.datetime(2018, 6, 6),"York","United Kingdom","York","Manchester",145,0,0,0,'Great Britain 2018',['Artur','Heidrun']])
data_list.append([datetime.datetime(2018, 6, 6),"Knaresborough","United Kingdom","York","Manchester",7,0,0,0,'Great Britain 2018',['Artur','Heidrun']])
data_list.append([datetime.datetime(2018, 6, 6),"Ripon","United Kingdom","York","Manchester",98,0,0,0,'Great Britain 2018',['Artur','Heidrun']])
data_list.append([datetime.datetime(2018, 6, 6),"Kilburn","United Kingdom","York","Manchester",7,0,0,0,'Great Britain 2018',[]])
data_list.append([datetime.datetime(2018, 6, 7),"Bakewell","United Kingdom","Manchester","Manchester",121,0,-1,0,'Great Britain 2018',['Artur','Heidrun']])
data_list.append([datetime.datetime(2018, 6, 7),"Sheffield","United Kingdom","Manchester","Manchester",2,0,-1,0,'Great Britain 2018',['Artur','Heidrun']])
data_list.append([datetime.datetime(2018, 6, 7),"Lincoln","United Kingdom","Manchester","Manchester",120,0,-1,0,'Great Britain 2018',['Artur','Heidrun']])
data_list.append([datetime.datetime(2018, 6, 8),"Manchester","United Kingdom","Manchester","Manchester",3,0,-1,0,'Great Britain 2018',['Artur','Heidrun']])
data_list.append([datetime.datetime(2018, 6, 8),"Conwy","United Kingdom","Manchester","Manchester",70,0,-1,0,'Great Britain 2018',['Artur','Heidrun']])
data_list.append([datetime.datetime(2018, 6, 8),"Caernarfon","United Kingdom","Manchester","Manchester",55,0,-1,0,'Great Britain 2018',['Artur','Heidrun']])
data_list.append([datetime.datetime(2018, 6, 8),"Bangor","United Kingdom","Manchester","Manchester",5,0,-1,0,'Great Britain 2018',[]])
data_list.append([datetime.datetime(2018, 6, 9),"Liverpool","United Kingdom","Manchester","Manchester",112,0,-1,0,'Great Britain 2018',['Artur','Heidrun']])
data_list.append([datetime.datetime(2018, 6, 9),"Chester","United Kingdom","Manchester","Manchester",62,0,-1,0,'Great Britain 2018',[]])
data_list.append([datetime.datetime(2018, 6, 10),"Manchester","United Kingdom","Manchester",'Genf',123,0,0,2,'Great Britain 2018',[]])
#Korea
data_list.append([datetime.datetime(2018, 7, 1),"Dubai","United Arab Emirates","Dubai","Seoul",10,0,-1,3,'South Korea ICHEP 2018',[]])
data_list.append([datetime.datetime(2018, 7, 2),"Incheon","South Korea","Seoul","Seoul",2,0,1,1,'South Korea ICHEP 2018',[]])
data_list.append([datetime.datetime(2018, 7, 3),"Seoul","South Korea","Seoul","Seoul",181,0,-1,0,'South Korea ICHEP 2018',['Eva','Ulrike']])
data_list.append([datetime.datetime(2018, 7, 4),"Seoul","South Korea","Seoul","Seoul",138,0,-1,0,'South Korea ICHEP 2018',[]])
data_list.append([datetime.datetime(2018, 7, 7),"Seoul","South Korea","Seoul","Seoul",41,0,-1,0,'South Korea ICHEP 2018',['Eva','Ulrike','Steffen','Stephanie']])
data_list.append([datetime.datetime(2018, 7, 8),"Paju","South Korea","Seoul","Seoul",50,0,-1,0,'South Korea ICHEP 2018',['Eva','Ulrike','Cameron']])
data_list.append([datetime.datetime(2018, 7, 9),"Seoul","South Korea","Seoul","Seoul",4,0,-1,0,'South Korea ICHEP 2018',[]])
data_list.append([datetime.datetime(2018, 7, 12),"Suwon","South Korea","Seoul","Seoul",72,0,-1,0,'South Korea ICHEP 2018',[]])
data_list.append([datetime.datetime(2018, 7, 12),"Gwangju","South Korea","Seoul","Seoul",40,0,-1,0,'South Korea ICHEP 2018',[]])
data_list.append([datetime.datetime(2018, 7, 12),"Seoul","South Korea","Seoul","Seoul",8,0,-1,0,'South Korea ICHEP 2018',[]])
data_list.append([datetime.datetime(2018, 7, 13),"Gyeongju","South Korea","Seoul",'Busan',91,0,1,0,'South Korea ICHEP 2018',['Steffen','Stephanie']])
data_list.append([datetime.datetime(2018, 7, 13),"Busan","South Korea","Seoul",'Busan',20,0,1,0,'South Korea ICHEP 2018',['Steffen','Stephanie']])
data_list.append([datetime.datetime(2018, 7, 14),"Busan","South Korea","Busan","Seoul",99,0,0,0,'South Korea ICHEP 2018',['Steffen','Stephanie']])
data_list.append([datetime.datetime(2018, 7, 14),"Seoul","South Korea","Busan","Seoul",1,0,-1,0,'South Korea ICHEP 2018',['Steffen','Stephanie']])
data_list.append([datetime.datetime(2018, 7, 15),"Seoul","South Korea","Seoul","Seoul",187,0,-1,0,'South Korea ICHEP 2018',[]])
data_list.append([datetime.datetime(2018, 7, 15),"Incheon","South Korea","Seoul","Dubai",3,0,0,2,'South Korea ICHEP 2018',[]])
data_list.append([datetime.datetime(2018, 7, 16),"Dubai","United Arab Emirates","Dubai",'Genf',24,0,-1,3,'South Korea ICHEP 2018',[]])
##

# %%
#2018
data_list.append([datetime.datetime(2018, 7, 27),"Lauchringen","Germany","Lauchringen","Lauchringen",5,1,-1,0,'Lauchringen II 2018',[]])
data_list.append([datetime.datetime(2018, 7, 29),"Basel","Switzerland","Lauchringen","Genf",1,1,-1,0,'Lauchringen II 2018',[]])
data_list.append([datetime.datetime(2018, 8, 5),"Klosters","Switzerland","Genf","Genf",1,1,-1,0,'Diavolezza and Chur 2018',[]])
data_list.append([datetime.datetime(2018, 8, 5),"Samedan","Switzerland","Genf","Genf",2,1,-1,0,'Diavolezza and Chur 2018',[]])
data_list.append([datetime.datetime(2018, 8, 5),"Pontresina","Switzerland","Genf","Genf",81,1,-1,0,'Diavolezza and Chur 2018',[]])
data_list.append([datetime.datetime(2018, 8, 5),"Tomils","Switzerland","Genf","Genf",2,1,-1,0,'Diavolezza and Chur 2018',[]])
data_list.append([datetime.datetime(2018, 8, 5),"Chur","Switzerland","Genf","Genf",25,1,-1,0,'Diavolezza and Chur 2018',[]])
data_list.append([datetime.datetime(2018, 8, 12),"Leaz","France","Genf","Genf",37,1,-1,0,"Fort l'Ecluse 2018",['Riju']])
data_list.append([datetime.datetime(2018, 8, 18),"Waldshut","Germany","Genf",'Lauchringen',33,1,1,0,'Lauchringen III 2018',['Franziska','Jan-Marc','Felicitas']])
data_list.append([datetime.datetime(2018, 8, 26),"Kandersteg","Switzerland","Genf","Genf",57,1,-1,0,'Oeschinensee and Bern 2018',['Riju']])
data_list.append([datetime.datetime(2018, 8, 26),"Frutigen","Switzerland","Genf","Genf",5,1,-1,0,'Oeschinensee and Bern 2018',['Riju']])
data_list.append([datetime.datetime(2018, 8, 26),"Bern","Switzerland","Genf","Genf",48,1,-1,0,'Oeschinensee and Bern 2018',['Riju']])
data_list.append([datetime.datetime(2018, 8, 26),"Kerzers","Switzerland","Genf","Genf",2,1,-1,0,'Oeschinensee and Bern 2018',['Riju']])
data_list.append([datetime.datetime(2018, 8, 26),"Neuchatel","Switzerland","Genf","Genf",2,1,-1,0,'Oeschinensee and Bern 2018',['Riju']])
data_list.append([datetime.datetime(2018, 8, 28),"Meyrin","Switzerland","Genf",'Genf',5,1,-1,0,'CLIC Days 2018',['CLIC']])
#Germany
data_list.append([datetime.datetime(2018, 8, 31),"Meyrin","Switzerland","Genf","Munich",2,0,1,1,'Germany 2018',['Reyer']])
data_list.append([datetime.datetime(2018, 9, 1),"Munich","Germany","Munich","Fuessen",202,0,0,0,'Germany 2018',['Reyer','Chris B']])
data_list.append([datetime.datetime(2018, 9, 2),"Schwangau","Germany","Fuessen","Regensburg",26,0,0,0,'Germany 2018',['Reyer','Chris B']])
data_list.append([datetime.datetime(2018, 9, 2),"Steingaden","Germany","Fuessen","Regensburg",17,0,0,0,'Germany 2018',['Reyer','Chris B']])
data_list.append([datetime.datetime(2018, 9, 2),"Ettal","Germany","Fuessen","Regensburg",44,0,0,0,'Germany 2018',['Reyer','Chris B']])
data_list.append([datetime.datetime(2018, 9, 2),"Regensburg","Germany","Fuessen","Regensburg",52,0,1,0,'Germany 2018',['Reyer','Chris B']])
data_list.append([datetime.datetime(2018, 9, 3),"Kelheim","Germany","Regensburg","Bamberg",120,0,0,0,'Germany 2018',['Reyer','Chris B']])
data_list.append([datetime.datetime(2018, 9, 3),"Donaustauf","Germany","Regensburg","Bamberg",23,0,0,0,'Germany 2018',['Reyer','Chris B']])
data_list.append([datetime.datetime(2018, 9, 3),"Memmelsdorf","Germany","Regensburg","Bamberg",39,0,1,0,'Germany 2018',['Reyer','Chris B']])
data_list.append([datetime.datetime(2018, 9, 3),"Bamberg","Germany","Regensburg","Bamberg",68,0,1,0,'Germany 2018',['Reyer','Chris B']])
data_list.append([datetime.datetime(2018, 9, 4),"Wuerzburg","Germany","Bamberg","Bayreuth",48,0,0,0,'Germany 2018',['Reyer','Chris B']])
data_list.append([datetime.datetime(2018, 9, 4),"Bayreuth","Germany","Bamberg","Bayreuth",90,0,1,0,'Germany 2018',['Reyer','Chris B']])
data_list.append([datetime.datetime(2018, 9, 5),"Eisenach","Germany","Bayreuth","Dessau-Rosslau",78,0,0,0,'Germany 2018',['Reyer','Chris B']])
data_list.append([datetime.datetime(2018, 9, 5),"Schoenstedt","Germany","Bayreuth","Dessau-Rosslau",18,0,1,0,'Germany 2018',['Reyer','Chris B']])
data_list.append([datetime.datetime(2018, 9, 5),"Naumburg","Germany","Bayreuth","Dessau-Rosslau",51,0,1,0,'Germany 2018',['Reyer','Chris B']])
data_list.append([datetime.datetime(2018, 9, 6),"Dessau-Rosslau","Germany","Dessau-Rosslau","Dessau-Rosslau",81,0,-1,0,'Germany 2018',['Reyer','Chris B']])
data_list.append([datetime.datetime(2018, 9, 6),"Oranienbaum-Woerlitz","Germany","Dessau-Rosslau","Dessau-Rosslau",184,0,-1,0,'Germany 2018',['Reyer','Chris B']])
data_list.append([datetime.datetime(2018, 9, 7),"Wittenberg","Germany","Dessau-Rosslau","Berlin",38,0,0,0,'Germany 2018',['Reyer','Chris B']])
data_list.append([datetime.datetime(2018, 9, 7),"Quedlinburg","Germany","Dessau-Rosslau","Berlin",50,0,0,0,'Germany 2018',['Reyer','Chris B']])
data_list.append([datetime.datetime(2018, 9, 7),"Berlin","Germany","Dessau-Rosslau","Berlin",18,0,1,0,'Germany 2018',['Reyer','Chris B','Riju']])
data_list.append([datetime.datetime(2018, 9, 8),"Potsdam","Germany","Berlin","Berlin",207,0,-1,0,'Germany 2018',['Reyer','Chris B','Riju']])
data_list.append([datetime.datetime(2018, 9, 8),"Potsdam","Germany","Berlin","Berlin",143,0,-1,0,'Germany 2018',['Riju']])
data_list.append([datetime.datetime(2018, 9, 8),"Berlin","Germany","Berlin","Berlin",19,0,-1,0,'Germany 2018',['Reyer','Chris B','Riju']])
data_list.append([datetime.datetime(2018, 9, 9),"Berlin","Germany","Berlin",'Genf',189,0,0,2,'Germany 2018',['Reyer','Chris B','Riju']])
##

# %%
#2018
#Belgium II
data_list.append([datetime.datetime(2018, 9, 22),"Brussels","Belgium","Brussels","Brussels",3,0,-1,0,"Brussels II 2018",[]])
data_list.append([datetime.datetime(2018, 9, 22),"Antwerp","Belgium","Brussels","Brussels",59,0,-1,0,"Brussels II 2018",[]])
data_list.append([datetime.datetime(2018, 9, 22),"Mechelen","Belgium","Brussels","Brussels",35,0,-1,0,"Brussels II 2018",[]])
data_list.append([datetime.datetime(2018, 9, 22),"Brussels","Belgium","Brussels","Brussels",33,0,-1,0,"Brussels II 2018",['Rachel']])
data_list.append([datetime.datetime(2018, 9, 23),"Leuven","Belgium","Brussels","Genf",93,0,0,2,"Brussels II 2018",['Rachel']])
data_list.append([datetime.datetime(2018, 9, 23),"Zaventem","Belgium","Brussels","Genf",2,0,0,2,"Brussels II 2018",['Rachel']])
##
data_list.append([datetime.datetime(2018, 11, 4),"Motiers","Switzerland","Genf","Genf",29,1,-1,0,'Absinthe Museum 2018',['Rachel','Sasha','Kevin N','Grace E','Christine M']])
data_list.append([datetime.datetime(2018, 11, 4),"Couvet","Switzerland","Genf","Genf",1,1,-1,0,'Absinthe Museum 2018',['Rachel','Sasha','Kevin N','Grace E','Christine M']])
#Provence
data_list.append([datetime.datetime(2018, 11, 17),"Arles","France","Genf","Nimes",152,0,1,0,"Provence 2018",['Santona']])
data_list.append([datetime.datetime(2018, 11, 18),"Marseille","France","Nimes","Nimes",201,0,-1,0,"Provence 2018",['Santona']])
data_list.append([datetime.datetime(2018, 11, 18),"Nimes","France","Nimes","Nimes",5,0,-1,0,"Provence 2018",['Santona']])
data_list.append([datetime.datetime(2018, 11, 19),"Nimes","France","Nimes","Genf",67,0,0,0,"Provence 2018",['Santona']])
data_list.append([datetime.datetime(2018, 11, 19),"Orange","France","Nimes","Genf",63,0,0,0,"Provence 2018",['Santona']])
##
data_list.append([datetime.datetime(2018, 11, 25),"Freiburg","Germany","Genf","Genf",99,1,-1,0,'Freiburg and Christmas Market Basel 2018',['Santona','Riju']])
data_list.append([datetime.datetime(2018, 11, 25),"Basel","Germany","Genf","Genf",40,1,-1,0,'Freiburg and Christmas Market Basel 2018',['Santona','Riju']])
data_list.append([datetime.datetime(2018, 12, 1),"Tiengen","Germany","Lauchringen","Lauchringen",1,1,-1,0,'Lauchringen IV 2018',['Anne-Kathrin','Christian']])
data_list.append([datetime.datetime(2018, 12, 1),"Lauchringen","Germany","Lauchringen","Lauchringen",24,1,-1,0,'Lauchringen IV 2018',['Heidrun','Felicitas','Hannsjoerg','Artur','Anne-Kathrin','Christian','Julius','Franziska','Jan-Marc']])
data_list.append([datetime.datetime(2018, 12, 2),"Lauchringen","Germany","Lauchringen","Genf",2,1,-1,0,'Lauchringen IV 2018',['Heidrun','Felicitas','Hannsjoerg','Artur','Anne-Kathrin','Christian','Julius','Franziska','Jan-Marc']])
data_list.append([datetime.datetime(2018, 12, 8),"Beaune","France","Genf","Genf",61,1,-1,0,'Beaune and Dijon 2018',['Santona','Graham','Yao Yao','Chris B']])
data_list.append([datetime.datetime(2018, 12, 8),"Dijon","France","Genf","Genf",87,1,-1,0,'Beaune and Dijon 2018',['Santona','Graham','Yao Yao','Chris B']])
data_list.append([datetime.datetime(2018, 12, 8),"Vougeot","France","Genf","Genf",50,1,-1,0,'Beaune and Dijon 2018',['Santona','Graham','Yao Yao','Chris B']])
##Ladenburg
data_list.append([datetime.datetime(2018, 12, 28),"Maulbronn","Germany","Lauchringen","Ladenburg",92,0,1,0,"Ladenburg 2018",['Artur','Heidrun']])
data_list.append([datetime.datetime(2018, 12, 28),"Ladenburg","Germany","Lauchringen","Ladenburg",24,0,1,0,"Ladenburg 2018",['Artur','Heidrun']])
data_list.append([datetime.datetime(2018, 12, 29),"Voelklingen","Germany","Ladenburg","Ladenburg",95,0,-1,0,"Ladenburg 2018",['Artur','Heidrun']])
data_list.append([datetime.datetime(2018, 12, 29),"Saarbruecken","Germany","Ladenburg","Ladenburg",24,0,-1,0,"Ladenburg 2018",['Artur','Heidrun']])
data_list.append([datetime.datetime(2018, 12, 29),"Lorsch","Germany","Ladenburg","Ladenburg",31,0,-1,0,"Ladenburg 2018",['Artur','Heidrun']])
data_list.append([datetime.datetime(2018, 12, 30),"Mannheim","Germany","Ladenburg",'Lauchringen',73,0,0,0,"Ladenburg 2018",['Artur','Heidrun']])
data_list.append([datetime.datetime(2018, 12, 30),"Rastatt","Germany","Ladenburg",'Lauchringen',114,0,0,0,"Ladenburg 2018",['Artur','Heidrun']])
##

# %%
#2019
data_list.append([datetime.datetime(2019, 1, 13),"Domodossola","Italy","Genf","Genf",159,1,-1,0,'Sacri Monti 2019',[]])
data_list.append([datetime.datetime(2019, 1, 13),"Orta San Giulia","Italy","Genf","Genf",173,1,-1,0,'Sacri Monti 2019',[]])
data_list.append([datetime.datetime(2019, 1, 19),"Lauchringen","Germany","Lauchringen",'Lauchringen',2,1,-1,0,'Lauchringen I 2019',["Heidrun","Anne-Kathrin",'Christian','Heidrun',"Hannsjoerg",'Ursula']])
data_list.append([datetime.datetime(2019, 2, 21),"Saint-Cergue","Switzerland","Genf","Genf",18,1,-1,0,'Snowshoeing 2019',["LCD"]])
data_list.append([datetime.datetime(2019, 2, 24),"Chamonix","France","Genf","Genf",141,1,-1,0,'Chamonix 2019',["Grace C",'Riju',"Christine M"]])
data_list.append([datetime.datetime(2019, 3, 2),"Zurich","Switzerland","Genf","Genf",188,1,-1,0,'Zurich I 2019',[]])
data_list.append([datetime.datetime(2019, 3, 4),"Meyrin","Switzerland","Genf","Genf",24,1,-1,0,'CERN tour 2019',[]])
data_list.append([datetime.datetime(2019, 3, 10),"Brindisi","Italy","Genf","Bari",7,0,1,1,"Bari and Naples 2019",[]])
data_list.append([datetime.datetime(2019, 3, 10),"Bari","Italy","Genf","Bari",157,0,1,1,"Bari and Naples 2019",["Heidrun",'Artur']])
data_list.append([datetime.datetime(2019, 3, 11),"Matera","Italy","Bari","Bari",207,0,-1,0,"Bari and Naples 2019",["Heidrun",'Artur']])
data_list.append([datetime.datetime(2019, 3, 12),"Molfetta","Italy","Bari","Bari",27,0,-1,0,"Bari and Naples 2019",["Heidrun",'Artur']])
data_list.append([datetime.datetime(2019, 3, 12),"Bitonto","Italy","Bari","Bari",92,0,-1,0,"Bari and Naples 2019",["Heidrun",'Artur']])
data_list.append([datetime.datetime(2019, 3, 12),"Andria","Italy","Bari","Bari",46,0,-1,0,"Bari and Naples 2019",["Heidrun",'Artur']])
data_list.append([datetime.datetime(2019, 3, 12),"Trani","Italy","Bari","Bari",29,0,-1,0,"Bari and Naples 2019",["Heidrun",'Artur']])
data_list.append([datetime.datetime(2019, 3, 12),"Bari","Italy","Bari","Bari",1,0,-1,0,"Bari and Naples 2019",["Heidrun",'Artur']])
data_list.append([datetime.datetime(2019, 3, 13),"Lecce","Italy","Bari","Bari",200,0,-1,0,"Bari and Naples 2019",["Heidrun",'Artur']])
data_list.append([datetime.datetime(2019, 3, 13),"Bari","Italy","Bari","Bari",18,0,-1,0,"Bari and Naples 2019",["Heidrun",'Artur']])
data_list.append([datetime.datetime(2019, 3, 14),"Castellana Grotte","Italy","Bari","Bari",58,0,-1,0,"Bari and Naples 2019",["Heidrun",'Artur']])
data_list.append([datetime.datetime(2019, 3, 14),"Alberobello","Italy","Bari","Bari",39,0,-1,0,"Bari and Naples 2019",["Heidrun",'Artur']])
data_list.append([datetime.datetime(2019, 3, 15),"Naples","Italy","Bari","Naples",308,0,1,0,"Bari and Naples 2019",["Heidrun",'Artur']])
data_list.append([datetime.datetime(2019, 3, 16),"Caserta","Italy","Naples","Naples",200,0,-1,0,"Bari and Naples 2019",["Heidrun",'Artur']])
data_list.append([datetime.datetime(2019, 3, 16),"Benevento","Italy","Naples","Naples",133,0,-1,0,"Bari and Naples 2019",["Heidrun",'Artur']])
data_list.append([datetime.datetime(2019, 3, 17),"Ercolano","Italy","Naples","Naples",175,0,-1,0,"Bari and Naples 2019",["Heidrun",'Artur']])
data_list.append([datetime.datetime(2019, 3, 17),"Portici","Italy","Naples","Naples",59,0,-1,0,"Bari and Naples 2019",["Heidrun",'Artur']])
data_list.append([datetime.datetime(2019, 3, 17),"Naples","Italy","Naples","Naples",250,0,-1,0,"Bari and Naples 2019",["Heidrun",'Artur']])
data_list.append([datetime.datetime(2019, 3, 18),"Paestum","Italy","Naples","Naples",66,0,-1,0,"Bari and Naples 2019",["Heidrun",'Artur']])
data_list.append([datetime.datetime(2019, 3, 18),"Naples","Italy","Naples","Naples",238,0,-1,0,"Bari and Naples 2019",["Heidrun",'Artur']])
data_list.append([datetime.datetime(2019, 3, 19),"Pompeii","Italy","Naples","Naples",190,0,-1,0,"Bari and Naples 2019",["Heidrun",'Artur']])
data_list.append([datetime.datetime(2019, 3, 19),"Torre Annunziata","Italy","Naples","Naples",73,0,-1,0,"Bari and Naples 2019",["Heidrun",'Artur']])
data_list.append([datetime.datetime(2019, 3, 19),"Naples","Italy","Naples","Naples",73,0,-1,0,"Bari and Naples 2019",["Heidrun",'Artur']])
data_list.append([datetime.datetime(2019, 3, 20),"Sorrento","Italy","Naples","Naples",1,0,-1,0,"Bari and Naples 2019",["Heidrun",'Artur']])
data_list.append([datetime.datetime(2019, 3, 20),"Colli di Fontanelle","Italy","Naples","Naples",2,0,-1,0,"Bari and Naples 2019",["Heidrun",'Artur']])
data_list.append([datetime.datetime(2019, 3, 20),"Vico Equense","Italy","Naples","Naples",4,0,-1,0,"Bari and Naples 2019",["Heidrun",'Artur']])
data_list.append([datetime.datetime(2019, 3, 20),"Positano","Italy","Naples","Naples",79,0,-1,0,"Bari and Naples 2019",["Heidrun",'Artur']])
data_list.append([datetime.datetime(2019, 3, 20),"Praiano","Italy","Naples","Naples",3,0,-1,0,"Bari and Naples 2019",["Heidrun",'Artur']])
data_list.append([datetime.datetime(2019, 3, 20),"Furore","Italy","Naples","Naples",2,0,-1,0,"Bari and Naples 2019",["Heidrun",'Artur']])
data_list.append([datetime.datetime(2019, 3, 20),"Conca dei Marini","Italy","Naples","Naples",3,0,-1,0,"Bari and Naples 2019",["Heidrun",'Artur']])
data_list.append([datetime.datetime(2019, 3, 20),"Amalfi","Italy","Naples","Naples",145,0,-1,0,"Bari and Naples 2019",["Heidrun",'Artur']])
data_list.append([datetime.datetime(2019, 3, 20),"Atrani","Italy","Naples","Naples",3,0,-1,0,"Bari and Naples 2019",["Heidrun",'Artur']])
data_list.append([datetime.datetime(2019, 3, 20),"Ravello","Italy","Naples","Naples",3,0,-1,0,"Bari and Naples 2019",["Heidrun",'Artur']])
data_list.append([datetime.datetime(2019, 3, 20),"Marmorata","Italy","Naples","Naples",1,0,-1,0,"Bari and Naples 2019",["Heidrun",'Artur']])
data_list.append([datetime.datetime(2019, 3, 20),"Minori","Italy","Naples","Naples",3,0,-1,0,"Bari and Naples 2019",["Heidrun",'Artur']])
data_list.append([datetime.datetime(2019, 3, 20),"Maiori","Italy","Naples","Naples",9,0,-1,0,"Bari and Naples 2019",["Heidrun",'Artur']])
data_list.append([datetime.datetime(2019, 3, 20),"Erchie","Italy","Naples","Naples",4,0,-1,0,"Bari and Naples 2019",["Heidrun",'Artur']])
data_list.append([datetime.datetime(2019, 3, 20),"Cetara","Italy","Naples","Naples",9,0,-1,0,"Bari and Naples 2019",["Heidrun",'Artur']])
data_list.append([datetime.datetime(2019, 3, 20),"Vietri Sul Mare","Italy","Naples","Naples",4,0,-1,0,"Bari and Naples 2019",["Heidrun",'Artur']])
data_list.append([datetime.datetime(2019, 3, 20),"Salerno","Italy","Naples","Naples",69,0,-1,0,"Bari and Naples 2019",["Heidrun",'Artur']])
data_list.append([datetime.datetime(2019, 3, 21),"Pozzuoli","Italy","Naples","Naples",80,0,-1,0,"Bari and Naples 2019",["Heidrun",'Artur']])
data_list.append([datetime.datetime(2019, 3, 21),"Bacoli","Italy","Naples","Naples",2,0,-1,0,"Bari and Naples 2019",["Heidrun",'Artur']])
data_list.append([datetime.datetime(2019, 3, 21),"Baia","Italy","Naples","Naples",64,0,-1,0,"Bari and Naples 2019",["Heidrun",'Artur']])
data_list.append([datetime.datetime(2019, 3, 21),"Naples","Italy","Naples","Naples",60,0,-1,0,"Bari and Naples 2019",["Heidrun",'Artur']])
data_list.append([datetime.datetime(2019, 3, 22),"Naples","Italy","Naples","Genf",3,0,0,2,"Bari and Naples 2019",["Heidrun",'Artur']])
data_list.append([datetime.datetime(2019, 4, 6),"Murten","Switzerland","Genf","Genf",40,1,-1,0,'Murten and Avenches 2019',["Heidrun",'Artur']])
data_list.append([datetime.datetime(2019, 4, 6),"Avenches","Switzerland","Genf","Genf",19,1,-1,0,'Murten and Avenches 2019',["Heidrun",'Artur']])
data_list.append([datetime.datetime(2019, 4, 6),"Puidoux","Switzerland","Genf","Genf",1,1,-1,0,'Murten and Avenches 2019',[]])
data_list.append([datetime.datetime(2019, 4, 6),"Bourg-en-Lavaux","Switzerland","Genf","Genf",1,1,-1,0,'Murten and Avenches 2019',[]])
data_list.append([datetime.datetime(2019, 4, 6),"Riex","Switzerland","Genf","Genf",1,1,-1,0,'Murten and Avenches 2019',[]])
data_list.append([datetime.datetime(2019, 4, 6),"Chenaux","Switzerland","Genf","Genf",2,1,-1,0,'Murten and Avenches 2019',[]])
data_list.append([datetime.datetime(2019, 4, 6),"Grandvaux","Switzerland","Genf","Genf",1,1,-1,0,'Murten and Avenches 2019',[]])
data_list.append([datetime.datetime(2019, 4, 6),"Vilette","Switzerland","Genf","Genf",1,1,-1,0,'Murten and Avenches 2019',[]])
#Oxford London
data_list.append([datetime.datetime(2019, 4, 13),"London","United Kingdom","Genf","London",10,0,1,1,"London and Oxford 2019",[]])
data_list.append([datetime.datetime(2019, 4, 13),"Cambridge","United Kingdom","Genf","London",103,0,1,1,"London and Oxford 2019",[]])
data_list.append([datetime.datetime(2019, 4, 13),"Peterborough","United Kingdom","Genf","London",67,0,1,1,"London and Oxford 2019",[]])
data_list.append([datetime.datetime(2019, 4, 13),"Ely","United Kingdom","Genf","London",77,0,1,1,"London and Oxford 2019",[]])
data_list.append([datetime.datetime(2019, 4, 14),"London","United Kingdom","London","Oxford",257,0,0,0,"London and Oxford 2019",[]])
data_list.append([datetime.datetime(2019, 4, 14),"Oxford","United Kingdom","London","Oxford",7,0,1,0,"London and Oxford 2019",[]])
data_list.append([datetime.datetime(2019, 4, 15),"Oxford","United Kingdom","Oxford","Oxford",5,0,-1,0,"London and Oxford 2019",[]])
data_list.append([datetime.datetime(2019, 4, 16),"Oxford","United Kingdom","Oxford","Oxford",30,0,-1,0,"London and Oxford 2019",[]])
data_list.append([datetime.datetime(2019, 4, 17),"Oxford","United Kingdom","Oxford",'Genf',32,0,0,2,"London and Oxford 2019",[]])
##
#Paris
data_list.append([datetime.datetime(2019, 4, 18),"Paris","France","Genf","Paris",32,0,1,0,"Paris I 2019",['Chris B','Riju']])
data_list.append([datetime.datetime(2019, 4, 19),"Saint Savin","France","Paris","Paris",107,0,-1,0,"Paris I 2019",['Chris B','Riju']])
data_list.append([datetime.datetime(2019, 4, 19),"Saint Germain","France","Paris","Paris",5,0,-1,0,"Paris I 2019",['Chris B','Riju']])
data_list.append([datetime.datetime(2019, 4, 19),"Chauvigny","France","Paris","Paris",2,0,-1,0,"Paris I 2019",['Chris B','Riju']])
data_list.append([datetime.datetime(2019, 4, 19),"Poitiers","France","Paris","Paris",128,0,-1,0,"Paris I 2019",['Chris B','Riju']])
data_list.append([datetime.datetime(2019, 4, 19),"Paris","France","Paris","Paris",26,0,-1,0,"Paris I 2019",['Chris B','Riju']])
data_list.append([datetime.datetime(2019, 4, 20),"Provins","France","Paris","Paris",61,0,-1,0,"Paris I 2019",['Chris B','Riju']])
data_list.append([datetime.datetime(2019, 4, 20),"Fontainebleau","France","Paris","Paris",250,0,-1,0,"Paris I 2019",['Chris B','Riju']])
data_list.append([datetime.datetime(2019, 4, 20),"Paris","France","Paris","Paris",85,0,-1,0,"Paris I 2019",['Chris B','Riju']])
data_list.append([datetime.datetime(2019, 4, 21),"Paris","France","Paris","Paris",7,0,-1,0,"Paris I 2019",['Chris B','Riju']])
data_list.append([datetime.datetime(2019, 4, 21),"Bourges","France","Paris","Paris",347,0,-1,0,"Paris I 2019",[]])
data_list.append([datetime.datetime(2019, 4, 22),"Paris","France","Paris","Genf",10,0,0,0,"Paris I 2019",['Chris B','Riju']])
data_list.append([datetime.datetime(2019, 4, 22),"Le Havre","France","Paris","Genf",71,0,0,0,"Paris I 2019",['Chris B','Riju']])
##
data_list.append([datetime.datetime(2019, 5, 26),"Bourg-en-Lavaux","Switzerland","Genf","Genf",8,1,-1,0,'Vaduz and Zurich II 2019',['Riju']])
data_list.append([datetime.datetime(2019, 5, 26),"Balzers","Liechtenstein","Genf","Genf",3,1,-1,0,'Vaduz and Zurich II 2019',['Riju']])
data_list.append([datetime.datetime(2019, 5, 26),"Vaduz","Liechtenstein","Genf","Genf",50,1,-1,0,'Vaduz and Zurich II 2019',['Riju']])
data_list.append([datetime.datetime(2019, 5, 26),"Sevelen","Switzerland","Genf","Genf",1,1,-1,0,'Vaduz and Zurich II 2019',['Riju']])
data_list.append([datetime.datetime(2019, 5, 26),"Zurich","Switzerland","Genf","Genf",3,1,-1,0,'Vaduz and Zurich II 2019',['Riju']])
#Hannover
data_list.append([datetime.datetime(2019, 5, 30),"Frankfurt","Germany","Genf","Hannover",4,0,1,1,"Hannover 2019",['Grace C']])
data_list.append([datetime.datetime(2019, 5, 30),"Hannover","Germany","Genf","Hannover",29,0,1,1,"Hannover 2019",['Grace C']])
data_list.append([datetime.datetime(2019, 5, 30),"Bremen","Germany","Genf","Hannover",1,0,1,1,"Hannover 2019",['Grace C']])
data_list.append([datetime.datetime(2019, 5, 30),"Oldenburg","Germany","Genf","Hannover",60,0,1,1,"Hannover 2019",['Grace C']])
data_list.append([datetime.datetime(2019, 5, 31),"Hoexter","Germany","Hannover","Hannover",106,0,-1,0,"Hannover 2019",['Grace C']])
data_list.append([datetime.datetime(2019, 5, 31),"Alfeld","Germany","Hannover","Hannover",14,0,-1,0,"Hannover 2019",['Grace C']])
data_list.append([datetime.datetime(2019, 5, 31),"Hildesheim","Germany","Hannover","Hannover",130,0,-1,0,"Hannover 2019",['Grace C']])
data_list.append([datetime.datetime(2019, 5, 31),"Braunschweig","Germany","Hannover","Hannover",25,0,-1,0,"Hannover 2019",['Grace C']])
data_list.append([datetime.datetime(2019, 5, 31),"Hannover","Germany","Hannover","Hannover",1,0,-1,0,"Hannover 2019",['Grace C']])
data_list.append([datetime.datetime(2019, 6, 1),"Bremen","Germany","Hannover","Hannover",168,0,-1,0,"Hannover 2019",['Grace C']])
data_list.append([datetime.datetime(2019, 6, 1),"Norddeich","Germany","Hannover","Hannover",53,0,-1,0,"Hannover 2019",['Grace C']])
data_list.append([datetime.datetime(2019, 6, 2),"Goslar","Germany","Hannover","Hannover",108,0,-1,0,"Hannover 2019",['Grace C']])
data_list.append([datetime.datetime(2019, 6, 2),"Hannover","Germany","Hannover","Hannover",182,0,-1,0,"Hannover 2019",['Grace C']])
data_list.append([datetime.datetime(2019, 6, 3),"Hannover","Germany","Hannover","Genf",3,0,0,2,"Hannover 2019",['Grace C']])
data_list.append([datetime.datetime(2019, 6, 3),"Kloten","Switzerland","Hannover","Genf",1,0,1,2,"Hannover 2019",['Grace C']])

# %%
data_list.append([datetime.datetime(2019, 6, 16),"Lucerne","Switzerland","Genf","Genf",77,1,-1,0,'Lucerne and Rigi 2019',['Chris B',"Riju",'Rachel']])
data_list.append([datetime.datetime(2019, 6, 16),"Vierwaldstaetter See","Switzerland","Genf","Genf",47,1,-1,0,'Lucerne and Rigi 2019',['Chris B',"Riju",'Rachel']])
data_list.append([datetime.datetime(2019, 6, 16),"Rigi","Switzerland","Genf","Genf",37,1,-1,0,'Lucerne and Rigi 2019',['Chris B',"Riju",'Rachel']])
data_list.append([datetime.datetime(2019, 6, 22),"Vallorbe","Switzerland","Genf","Genf",121,1,-1,0,'Vallorbe 2019',['Christian',"Anne-Kathrin"]])
data_list.append([datetime.datetime(2019, 6, 23),"Cully","Switzerland","Genf","Genf",15,1,-1,0,'Lavaux I 2019',['Christian','Anne-Kathrin','Artur',"Heidrun",'Hannsjoerg']])
data_list.append([datetime.datetime(2019, 6, 23),"Riex","Switzerland","Genf","Genf",17,1,-1,0,'Lavaux I 2019',['Christian','Anne-Kathrin','Artur',"Heidrun",'Hannsjoerg']])
data_list.append([datetime.datetime(2019, 6, 23),"Bourg-en-Lavaux","Switzerland","Genf","Genf",23,1,-1,0,'Lavaux I 2019',['Christian','Anne-Kathrin','Artur',"Heidrun",'Hannsjoerg']])
data_list.append([datetime.datetime(2019, 6, 23),"Chexbres","Switzerland","Genf","Genf",8,1,-1,0,'Lavaux I 2019',['Christian','Anne-Kathrin','Artur',"Heidrun",'Hannsjoerg']])
data_list.append([datetime.datetime(2019, 7, 5),"Meyrin","Switzerland","Genf","Genf",1,1,-1,0,'Meyrin I 2019',['US folks']])
data_list.append([datetime.datetime(2019, 7, 8),"Cessy","France","Genf","Genf",12,1,-1,0,'CMS 2019',['Andres','Jens']])
data_list.append([datetime.datetime(2019, 7, 28),"Fieschertal","Switzerland","Genf","Genf",88,1,-1,0,'Aletsch glacier 2019',['Ivan','Jose',"Chris B","Ulrike",'Francesca']])
data_list.append([datetime.datetime(2019, 7, 28),"Fiesch","Switzerland","Genf","Genf",19,1,-1,0,'Aletsch glacier 2019',['Ivan','Jose',"Chris B","Ulrike",'Francesca']])
data_list.append([datetime.datetime(2019, 8, 17),"Lauchringen","Germany","Lauchringen",'Lauchringen',12,1,-1,0,'Lauchringen II 2019',['Heidrun',"Artur","Felicitas",'Julius','Marion','Franziska','Jan-Marc']])
data_list.append([datetime.datetime(2019, 8, 25),"Embd","Switzerland","Genf","Genf",1,1,-1,0,'Zermatt 2019',['Christine M','Andres','Chris B',"Sam",'Grace C','Janina']])
data_list.append([datetime.datetime(2019, 8, 25),"Sankt Niklaus","Switzerland","Genf","Genf",5,1,-1,0,'Zermatt 2019',['Christine M','Andres','Chris B',"Sam",'Grace C','Janina']])
data_list.append([datetime.datetime(2019, 8, 25),"Randa","Switzerland","Genf","Genf",13,1,-1,0,'Zermatt 2019',['Christine M','Andres','Chris B',"Sam",'Grace C','Janina']])
data_list.append([datetime.datetime(2019, 8, 25),"Taesch","Switzerland","Genf","Genf",2,1,-1,0,'Zermatt 2019',['Christine M','Andres','Chris B',"Sam",'Grace C','Janina']])
data_list.append([datetime.datetime(2019, 8, 25),"Zermatt","Switzerland","Genf","Genf",51,1,-1,0,'Zermatt 2019',['Christine M','Andres','Chris B',"Sam",'Grace C','Janina']])
data_list.append([datetime.datetime(2019, 8, 25),"Zermatt","Switzerland","Genf","Genf",12,1,-1,0,'Zermatt 2019',['David Y','Christine M','Andres','Chris B',"Sam",'Grace C','Janina']])
data_list.append([datetime.datetime(2019, 8, 27),"Meyrin","Switzerland","Genf","Genf",2,1,-1,0,'CLIC Days 2019',['CLIC Folks']])
data_list.append([datetime.datetime(2019, 8, 27),"Echenevex","France","Genf","Genf",1,1,-1,0,'CLIC Days 2019',['CLIC Folks']])
data_list.append([datetime.datetime(2019, 8, 31),"Chamonix","France","Genf","Genf",3,1,-1,0,'Aosta Valley 2019',['Sasha',"Andres",'Chris B','Yaroslava']])
data_list.append([datetime.datetime(2019, 8, 31),"Courmayeur","Italy","Genf","Genf",7,1,-1,0,'Aosta Valley 2019',['Sasha',"Andres",'Chris B','Yaroslava']])
data_list.append([datetime.datetime(2019, 8, 31),"Aosta","Italy","Genf","Genf",26,1,-1,0,'Aosta Valley 2019',['Sasha',"Andres",'Chris B','Yaroslava']])
data_list.append([datetime.datetime(2019, 8, 31),"Lillaz","Italy","Genf","Genf",57,1,-1,0,'Aosta Valley 2019',['Sasha',"Andres",'Chris B','Yaroslava']])
data_list.append([datetime.datetime(2019, 8, 31),"Cogne","Italy","Genf","Genf",3,1,-1,0,'Aosta Valley 2019',['Sasha',"Andres",'Chris B','Yaroslava']])
data_list.append([datetime.datetime(2019, 8, 31),"La Thuile","Italy","Genf","Genf",42,1,-1,0,'Aosta Valley 2019',['Sasha',"Andres",'Chris B','Yaroslava']])
data_list.append([datetime.datetime(2019, 9, 15),"Blatten","Switzerland","Genf","Genf",160,1,-1,0,'Lang glacier 2019',['Janinia']])
#paris II
data_list.append([datetime.datetime(2019, 9, 20),"Paris","France","Genf","Paris",3,0,1,0,"Paris II 2019",['Sam','Nhi','Michael','Vivan']])
data_list.append([datetime.datetime(2019, 9, 21),"Paris","France","Genf","Paris",1,0,1,0,"Paris II 2019",['Sam','Nhi','Michael','Vivan']])
data_list.append([datetime.datetime(2019, 9, 21),"Paris","France","Paris","Paris",354,0,-1,0,"Paris II 2019",['Sam','Nhi','Michael','Vivan']])
data_list.append([datetime.datetime(2019, 9, 22),"Paris","France","Paris","Genf",324,0,0,0,"Paris II 2019",['Sam','Nhi','Michael','Vivan']])
##
data_list.append([datetime.datetime(2019, 10, 6),"Gruyeres","Switzerland","Genf","Genf",18,1,-1,0,'Gruyeres and Lavaux 2019',['Xuan',"Will",'Andrew']])
data_list.append([datetime.datetime(2019, 10, 6),"Broc","Switzerland","Genf","Genf",1,1,-1,0,'Gruyeres and Lavaux 2019',['Xuan',"Will",'Andrew']])
data_list.append([datetime.datetime(2019, 10, 6),"Corseaux","Switzerland","Genf","Genf",9,1,-1,0,'Gruyeres and Lavaux 2019',['Xuan',"Will",'Andrew']])
data_list.append([datetime.datetime(2019, 10, 6),"Saint-Saphorin","Switzerland","Genf","Genf",1,1,-1,0,'Gruyeres and Lavaux 2019',['Xuan',"Will",'Andrew']])
data_list.append([datetime.datetime(2019, 10, 6),"Rivaz","Switzerland","Genf","Genf",19,1,-1,0,'Gruyeres and Lavaux 2019',['Xuan',"Will",'Andrew']])
data_list.append([datetime.datetime(2019, 10, 10),"Saint-Genis-Pouilly","France","Genf","Genf",7,1,-1,0,'CERN II 2019',['Eva','Ulrike',"Aidan"]])
data_list.append([datetime.datetime(2019, 10, 13),"Lovagny","France","Genf","Genf",79,1,-1,0,"Gorges du Fier and Pertes de la Valserine 2019",['Andrew']])
data_list.append([datetime.datetime(2019, 10, 13),"Bellegarde-sur-Valserine","France","Genf","Genf",39,1,-1,0,"Gorges du Fier and Pertes de la Valserine 2019",['Andrew']])
data_list.append([datetime.datetime(2019, 10, 26),"Grimentz","Switzerland","Genf","Genf",107,1,-1,0,'Glacier du Moiry 2019',['Sasha',"Elga",'Tema','Juno']])
data_list.append([datetime.datetime(2019, 10, 26),"Montreux","Switzerland","Genf","Genf",6,1,-1,0,'Glacier du Moiry 2019',['Sasha',"Elga",'Tema','Juno']])
data_list.append([datetime.datetime(2019, 10, 27),"Boudry","Switzerland","Genf","Genf",136,1,-1,0,"Gorge de l'Areuse 2019",['Will','Sam','Dylan','Christine M','Vivan','Grace C']])
data_list.append([datetime.datetime(2019, 10, 27),"Neuchatel","Switzerland","Genf","Genf",7,1,-1,0,"Gorge de l'Areuse 2019",['Will','Sam','Dylan','Christine M','Vivan','Grace C']])
data_list.append([datetime.datetime(2019, 11, 17),"Lauchringen","Germany","Lauchringen","Genf",7,1,-1,0,'Lauchringen III 2019',['Heidrun','Artur','Mathilda','Christian','Anne-Kathrin']])
data_list.append([datetime.datetime(2019, 11, 17),"Waldshut","Germany","Lauchringen","Genf",4,1,-1,0,'Lauchringen III 2019',['Heidrun','Artur','Mathilda','Christian','Anne-Kathrin']])
data_list.append([datetime.datetime(2019, 12, 20),"Lauchringen","Germany","Lauchringen","Lauchringen",7,1,-1,0,'Lauchringen IV 2019',['Artur','Mathilda','Christian','Anne-Kathrin']])
data_list.append([datetime.datetime(2019, 12, 25),"Lauchringen","Germany","Lauchringen","Lauchringen",7,1,-1,0,'Lauchringen IV 2019',['Artur','Jan-Marc']])
##Germany Poland trip 19/20
data_list.append([datetime.datetime(2019, 12, 29),"Nufringen","Germany","Lauchringen","Dresden",1,0,0,0,'Saxony & Silesia 2019 and 2020',['Artur']])
data_list.append([datetime.datetime(2019, 12, 29),"Leipzig","Germany","Lauchringen","Dresden",116,0,1,0,'Saxony & Silesia 2019 and 2020',['Artur']])
data_list.append([datetime.datetime(2019, 12, 29),"Dresden","Germany","Lauchringen","Dresden",16,0,-1,0,'Saxony & Silesia 2019 and 2020',['Artur']])
data_list.append([datetime.datetime(2019, 12, 30),"Dresden","Germany","Dresden","Dresden",181,0,-1,0,'Saxony & Silesia 2019 and 2020',['Artur']])
data_list.append([datetime.datetime(2019, 12, 30),"Lohmen","Germany","Dresden","Dresden",76,0,-1,0,'Saxony & Silesia 2019 and 2020',['Artur']])
data_list.append([datetime.datetime(2019, 12, 31),"Dresden","Germany","Dresden","Dresden",382,0,-1,0,'Saxony & Silesia 2019 and 2020',['Artur']])

# %%
##Germany Poland trip 19/20
data_list.append([datetime.datetime(2020, 1, 1),"Dresden","Germany","Dresden","Wroclaw",3,0,0,0,'Saxony & Silesia 2019 and 2020',['Artur']])
data_list.append([datetime.datetime(2020, 1, 1),"Bad Muskau","Germany","Dresden","Wroclaw",22,0,0,0,'Saxony & Silesia 2019 and 2020',['Artur']])
data_list.append([datetime.datetime(2020, 1, 1),"Leknica","Poland","Dresden","Wroclaw",25,0,0,0,'Saxony & Silesia 2019 and 2020',['Artur']])
data_list.append([datetime.datetime(2020, 1, 1),"Swidnica","Poland","Dresden","Wroclaw",73,0,1,0,'Saxony & Silesia 2019 and 2020',['Artur']])
data_list.append([datetime.datetime(2020, 1, 1),"Wroclaw","Poland","Dresden","Wroclaw",19,0,1,0,'Saxony & Silesia 2019 and 2020',['Artur']])
data_list.append([datetime.datetime(2020, 1, 2),"Wroclaw","Poland","Wroclaw","Wroclaw",2,0,-1,0,'Saxony & Silesia 2019 and 2020',['Artur']])
data_list.append([datetime.datetime(2020, 1, 2),"Wieliczka","Poland","Wroclaw","Wroclaw",97,0,-1,0,'Saxony & Silesia 2019 and 2020',['Artur']])
data_list.append([datetime.datetime(2020, 1, 2),"Krakow","Poland","Wroclaw","Wroclaw",179,0,-1,0,'Saxony & Silesia 2019 and 2020',['Artur']])
data_list.append([datetime.datetime(2020, 1, 3),"Wroclaw","Poland","Wroclaw","Wroclaw",289,0,-1,0,'Saxony & Silesia 2019 and 2020',['Artur']])
data_list.append([datetime.datetime(2020, 1, 4),"Walbrzych","Poland","Wroclaw","Bayreuth",89,0,0,0,'Saxony & Silesia 2019 and 2020',['Artur']])
data_list.append([datetime.datetime(2020, 1, 5),"Wonsees","Germany","Bayreuth",'Lauchringen',63,0,0,0,'Saxony & Silesia 2019 and 2020',['Artur']])
data_list.append([datetime.datetime(2020, 1, 5),"Lauchringen","Germany","Bayreuth",'Lauchringen',1,0,1,0,'Saxony & Silesia 2019 and 2020',['Artur']])
##
data_list.append([datetime.datetime(2020, 1, 11),"Meyrin","Switzerland","Genf","Genf",3,1,-1,0,'French Waterfalls and Monastery of Brou 2020',['Sasha','Juno']])
data_list.append([datetime.datetime(2020, 1, 11),"Les Planches-en-Montagne","France","Genf","Genf",31,1,-1,0,'French Waterfalls and Monastery of Brou 2020',['Sasha','Juno']])
data_list.append([datetime.datetime(2020, 1, 11),"Bourg-de-Sirod","France","Genf","Genf",57,1,-1,0,'French Waterfalls and Monastery of Brou 2020',['Sasha','Juno']])
data_list.append([datetime.datetime(2020, 1, 11),"Bourg-en-Bresse","France","Genf","Genf",120,1,-1,0,'French Waterfalls and Monastery of Brou 2020',['Sasha','Juno']])
data_list.append([datetime.datetime(2020, 1, 18),"Lauchringen","Germany","Lauchringen",'Lauchringen',4,0,-1,0,'Lauchringen I 2020',['Christian','Mathilda','Felicitas','Franziska','Jan-Marc','Anne-Kathrin','Julius']])
data_list.append([datetime.datetime(2020, 2, 8),"Sankt Gallen","Switzerland","Genf","Genf",45,1,-1,0,'St Gallen & Reichenau 2020',['Sam','Vivan','Grace C','Dylan']])
data_list.append([datetime.datetime(2020, 2, 8),"Reichenau","Germany","Genf","Genf",97,1,-1,0,'St Gallen & Reichenau 2020',['Sam','Vivan','Grace C','Dylan']])
data_list.append([datetime.datetime(2020, 2, 8),"Konstanz","Germany","Genf","Genf",47,1,-1,0,'St Gallen & Reichenau 2020',['Sam','Vivan','Grace C','Dylan']])
##Rom
data_list.append([datetime.datetime(2020, 2, 20),"Fiumicino","Italy","Genf","Rome",2,0,1,1,'Rome and Italy 2020',[]])
data_list.append([datetime.datetime(2020, 2, 20),"Rome","Vatican","Genf","Rome",63,0,1,1,'Rome and Italy 2020',[]])
data_list.append([datetime.datetime(2020, 2, 20),"Rome","Italy","Genf","Rome",129,0,1,1,'Rome and Italy 2020',[]])
data_list.append([datetime.datetime(2020, 2, 20),"Orvieto","Italy","Genf","Rome",156,0,1,1,'Rome and Italy 2020',[]])
data_list.append([datetime.datetime(2020, 2, 21),"Ancona","Italy","Rome","Rome",1,0,-1,0,'Rome and Italy 2020',[]])
data_list.append([datetime.datetime(2020, 2, 21),"Urbino","Italy","Rome","Rome",150,0,-1,0,'Rome and Italy 2020',[]])
data_list.append([datetime.datetime(2020, 2, 21),"Pesaro","Italy","Rome","Rome",16,0,-1,0,'Rome and Italy 2020',[]])
data_list.append([datetime.datetime(2020, 2, 22),"Castel Gandolfo","Vatican","Rome","Rome",138,0,-1,0,'Rome and Italy 2020',[]])
data_list.append([datetime.datetime(2020, 2, 22),"Castel Gandolfo","Italy","Rome","Rome",23,0,-1,0,'Rome and Italy 2020',[]])
data_list.append([datetime.datetime(2020, 2, 22),"Ciampino","Italy","Rome","Rome",2,0,-1,0,'Rome and Italy 2020',[]])
data_list.append([datetime.datetime(2020, 2, 22),"Anagni","Italy","Rome","Rome",126,0,-1,0,'Rome and Italy 2020',[]])
data_list.append([datetime.datetime(2020, 2, 23),"Terni","Italy","Rome","Rome",17,0,-1,0,'Rome and Italy 2020',[]])
data_list.append([datetime.datetime(2020, 2, 23),"Marmore","Italy","Rome","Rome",137,0,-1,0,'Rome and Italy 2020',[]])
data_list.append([datetime.datetime(2020, 2, 23),"Rome","Italy","Rome","Rome",110,0,-1,0,'Rome and Italy 2020',[]])
data_list.append([datetime.datetime(2020, 2, 23),"Rome","Vatican","Rome","Rome",9,0,-1,0,'Rome and Italy 2020',[]])
data_list.append([datetime.datetime(2020, 2, 24),"Orte","Italy","Rome","Rome",2,0,-1,0,'Rome and Italy 2020',[]])
data_list.append([datetime.datetime(2020, 2, 24),"Mugano","Italy","Rome","Rome",1,0,-1,0,'Rome and Italy 2020',[]])
data_list.append([datetime.datetime(2020, 2, 24),"Baschi","Italy","Rome","Rome",1,0,-1,0,'Rome and Italy 2020',[]])
data_list.append([datetime.datetime(2020, 2, 24),"Orvieto","Italy","Rome","Rome",2,0,-1,0,'Rome and Italy 2020',[]])
data_list.append([datetime.datetime(2020, 2, 24),"Montepulciano","Italy","Rome","Rome",5,0,-1,0,'Rome and Italy 2020',[]])
data_list.append([datetime.datetime(2020, 2, 24),"Pienza","Italy","Rome","Rome",109,0,-1,0,'Rome and Italy 2020',[]])
data_list.append([datetime.datetime(2020, 2, 25),"Siena","Italy","Rome","Rome",298,0,-1,0,'Rome and Italy 2020',[]])
data_list.append([datetime.datetime(2020, 2, 25),"Colle di Val d'Elsa","Italy","Rome","Rome",1,0,-1,0,'Rome and Italy 2020',[]])
data_list.append([datetime.datetime(2020, 2, 25),"San Gimignano","Italy","Rome","Rome",144,0,-1,0,'Rome and Italy 2020',[]])
data_list.append([datetime.datetime(2020, 2, 26),"Florence","Italy","Rome","Rome",768,0,-1,0,'Rome and Italy 2020',[]])
data_list.append([datetime.datetime(2020, 2, 27),"Rome","Italy","Rome","Rome",154,0,-1,0,'Rome and Italy 2020',["Bryan"]])
data_list.append([datetime.datetime(2020, 2, 27),"Rome","Vatican","Rome","Rome",131,0,-1,0,'Rome and Italy 2020',["Bryan"]])
data_list.append([datetime.datetime(2020, 2, 28),"Rome","Italy","Rome","Rome",246,0,-1,0,'Rome and Italy 2020',["Bryan"]])
data_list.append([datetime.datetime(2020, 2, 28),"Rome","Vatican","Rome","Rome",364,0,-1,0,'Rome and Italy 2020',["Bryan"]])
data_list.append([datetime.datetime(2020, 2, 29),"Rome","Italy","Rome","Rome",535,0,-1,0,'Rome and Italy 2020',["Bryan"]])
data_list.append([datetime.datetime(2020, 3, 1),"Tivoli","Italy","Rome","Rome",315,0,-1,0,'Rome and Italy 2020',["Bryan"]])
data_list.append([datetime.datetime(2020, 3, 1),"Rome","Italy","Rome","Rome",7,0,-1,0,'Rome and Italy 2020',["Bryan"]])
data_list.append([datetime.datetime(2020, 3, 2),"Rome","Italy","Rome","Genf",147,0,0,2,'Rome and Italy 2020',["Bryan"]])
data_list.append([datetime.datetime(2020, 3, 2),"Rome","Vatican","Rome","Genf",71,0,0,2,'Rome and Italy 2020',["Bryan"]])
##

# %%
data_list.append([datetime.datetime(2020, 5, 17),"Rossiniere","Switzerland","Genf","Genf",14,1,-1,0,'Goldenpass hike 2020',["Juno"]])
data_list.append([datetime.datetime(2020, 5, 17),"Chateau d'Oex","Switzerland","Genf","Genf",42,1,-1,0,'Goldenpass hike 2020',["Juno"]])
data_list.append([datetime.datetime(2020, 5, 17),"Rougemont","Switzerland","Genf","Genf",8,1,-1,0,'Goldenpass hike 2020',["Juno"]])
data_list.append([datetime.datetime(2020, 5, 17),"Montnovon","Switzerland","Genf","Genf",3,1,-1,0,'Goldenpass hike 2020',["Juno"]])
data_list.append([datetime.datetime(2020, 5, 17),"Montreux","Switzerland","Genf","Genf",3,1,-1,0,'Goldenpass hike 2020',["Juno"]])
##ebenalp
data_list.append([datetime.datetime(2020, 5, 31),"Wasserauen","Switzerland","Genf","Wasserauen",162,0,1,0,"Alpstein 2020",["Juno"]])
data_list.append([datetime.datetime(2020, 6, 1),"Wasserauen","Switzerland","Wasserauen","Murg",130,0,0,0,"Alpstein 2020",["Juno"]])
data_list.append([datetime.datetime(2020, 6, 1),"Waldstatt","Switzerland","Wasserauen","Murg",1,0,0,0,"Alpstein 2020",["Juno"]])
data_list.append([datetime.datetime(2020, 6, 1),"Murg","Switzerland","Wasserauen","Murg",31,0,1,0,"Alpstein 2020",["Juno"]])
data_list.append([datetime.datetime(2020, 6, 2),"Murg","Switzerland","Murg",'Genf',8,0,0,0,"Alpstein 2020",["Juno"]])
data_list.append([datetime.datetime(2020, 6, 2),"Quinten","Switzerland","Murg",'Genf',33,0,0,0,"Alpstein 2020",["Juno"]])
data_list.append([datetime.datetime(2020, 6, 2),"Betlis","Switzerland","Murg",'Genf',38,0,0,0,"Alpstein 2020",["Juno"]])
data_list.append([datetime.datetime(2020, 6, 2),"Weesen","Switzerland","Murg",'Genf',7,0,0,0,"Alpstein 2020",["Juno"]])
data_list.append([datetime.datetime(2020, 6, 2),"Schaenis","Switzerland","Murg",'Genf',2,0,0,0,"Alpstein 2020",["Juno"]])
##
data_list.append([datetime.datetime(2020, 6, 18),"Lauchringen","Germany","Genf","Lauchringen",4,1,1,0,'Lauchringen II 2020',["Artur"]])
data_list.append([datetime.datetime(2020, 6, 19),"Lauchringen","Germany","Lauchringen","Lauchringen",1,1,-1,0,'Lauchringen II 2020',["Artur"]])
data_list.append([datetime.datetime(2020, 6, 20),"Strasbourg","France","Lauchringen","Lauchringen",114,1,-1,0,'Strasbourg and Baden-Baden 2020',["Artur"]])
data_list.append([datetime.datetime(2020, 6, 20),"Baden-Baden","Germany","Lauchringen","Lauchringen",20,1,-1,0,'Strasbourg and Baden-Baden 2020',["Artur",'Mathilda','Anne-Kathrin','Christian']])
data_list.append([datetime.datetime(2020, 6, 21),"Untermettingen","Germany","Lauchringen","Genf",1,1,0,0,'Lauchringen II 2020',["Artur",'Felicitas','Julius','Jan-Marc','Franziska']])
##
data_list.append([datetime.datetime(2020, 7, 4),"Labalme","France","Genf","Genf",75,1,-1,0,'Caves and Waterfalls in France 2020',['Tema','Sasha']])
data_list.append([datetime.datetime(2020, 7, 4),"La Balme-les-Grottes","France","Genf","Genf",114,1,-1,0,'Caves and Waterfalls in France 2020',['Tema','Sasha']])
data_list.append([datetime.datetime(2020, 7, 4),"Belmont-Luthezieu","France","Genf","Genf",15,1,-1,0,'Caves and Waterfalls in France 2020',['Sasha']])
data_list.append([datetime.datetime(2020, 7, 4),"Cerveyrieu","France","Genf","Genf",3,1,-1,0,'Caves and Waterfalls in France 2020',['Sasha']])
data_list.append([datetime.datetime(2020, 7, 4),"Vieu","France","Genf","Genf",16,1,-1,0,'Caves and Waterfalls in France 2020',['Sasha']])
data_list.append([datetime.datetime(2020, 7, 4),"Champagne-en-Valromey","France","Genf","Genf",19,1,-1,0,'Caves and Waterfalls in France 2020',['Sasha']])
data_list.append([datetime.datetime(2020, 7, 4),"Surjoux","France","Genf","Genf",8,1,-1,0,'Caves and Waterfalls in France 2020',['Sasha']])
data_list.append([datetime.datetime(2020, 7, 5),"Saint-Cergue","Switzerland","Genf",'Genf',18,1,-1,0,'St-Cergue Roman Road hike 2020',['Sam','Grace C','Dylan','Janina','Kevin']])
data_list.append([datetime.datetime(2020, 7, 5),"Trelex","Switzerland","Genf","Genf",24,1,-1,0,'St-Cergue Roman Road hike 2020',['Sam','Grace C','Dylan','Janina','Kevin']])
data_list.append([datetime.datetime(2020, 7, 18),"Chamonix","France","Genf","Genf",151,1,-1,0,'Mer de Glace 2020',['Sasha','Andrey','Tema','Juno']])
data_list.append([datetime.datetime(2020, 7, 25),"Lauchringen","Germany","Lauchringen",'Lauchringen',4,1,-1,0,'Lauchringen III 2020',['Felicitas','Jan-Marc','Artur','Julius','Franziska','Jan-Marc','Mathilda','Anne-Kathrin','Christian']])
data_list.append([datetime.datetime(2020, 7, 29),"Meyrin","Switzerland","Genf","Genf",11,1,-1,0,'CERN Tour 2020',[]])
data_list.append([datetime.datetime(2020, 8, 1),"Leuck","Switzerland","Genf","Genf",1,1,-1,0,'Belalp and Domodossola 2020',['Sam']])
data_list.append([datetime.datetime(2020, 8, 1),"Belalp","Switzerland","Genf","Genf",69,1,-1,0,'Belalp and Domodossola 2020',['Sam']])
data_list.append([datetime.datetime(2020, 8, 1),"Domodossola","Italy","Genf","Genf",15,1,-1,0,'Belalp and Domodossola 2020',['Sam']])
##Aletsch
data_list.append([datetime.datetime(2020, 8, 9),"Lauterbrunnen","Switzerland","Genf","Genf",14,0,1,0,'Aletsch glacier hike 2020',['Tema']])
data_list.append([datetime.datetime(2020, 8, 9),"Grindelwald","Switzerland","Genf","Genf",10,0,1,0,'Aletsch glacier hike 2020',['Tema']])
data_list.append([datetime.datetime(2020, 8, 9),"Fieschertal","Switzerland","Genf","Genf",16,0,1,0,'Aletsch glacier hike 2020',['Tema']])
data_list.append([datetime.datetime(2020, 8, 9),"Fieschertal","Switzerland","Genf","Genf",210,0,1,0,'Aletsch glacier hike 2020',['Tema','Juno','Sasha']])
data_list.append([datetime.datetime(2020, 8, 10),"Fieschertal","Switzerland","Fieschertal","Genf",77,0,0,0,'Aletsch glacier hike 2020',['Tema','Juno','Sasha']])
data_list.append([datetime.datetime(2020, 8, 10),"Fiesch","Switzerland","Fieschertal","Genf",1,0,0,0,'Aletsch glacier hike 2020',['Tema','Juno','Sasha']])
##
data_list.append([datetime.datetime(2020, 8, 17),"Lauchringen","Germany","Lauchringen","Genf",3,1,0,0,'Lauchringen IV 2020',['Felicitas','Jan-Marc','Artur','Julius','Franziska','Jan-Marc','Marion']])
data_list.append([datetime.datetime(2020, 8, 22),"Lullin","France","Genf","Genf",36,1,-1,0,'Mont Forchat 2020',['Sasha']])
data_list.append([datetime.datetime(2020, 8, 29),"Brugg","Switzerland","Lauchringen","Lauchringen",16,1,-1,0,'Brugg 2020',['Artur']])
data_list.append([datetime.datetime(2020, 9, 5),"Altenburg","Germany","Lauchringen","Lauchringen",3,1,-1,0,'Rheinau and Rheinfall 2020',['Artur']])
data_list.append([datetime.datetime(2020, 9, 5),"Rheinau","Switzerland","Lauchringen","Lauchringen",22,1,-1,0,'Rheinau and Rheinfall 2020',['Artur']])
data_list.append([datetime.datetime(2020, 9, 5),"Nohl","Switzerland","Lauchringen","Lauchringen",3,1,-1,0,'Rheinau and Rheinfall 2020',['Artur']])
data_list.append([datetime.datetime(2020, 9, 5),"Laufen","Switzerland","Lauchringen","Lauchringen",44,1,-1,0,'Rheinau and Rheinfall 2020',['Artur']])
data_list.append([datetime.datetime(2020, 9, 5),"Neuhausen am Rheinfall","Switzerland","Lauchringen","Lauchringen",44,1,-1,0,'Rheinau and Rheinfall 2020',['Artur']])
data_list.append([datetime.datetime(2020, 9, 6),"Bechtersbohl","Germany","Lauchringen","Lauchringen",19,1,-1,0,'Kuessaburg 2020',['Artur','Felicitas','Julius','Jan-Marc','Franziska']])
data_list.append([datetime.datetime(2020, 9, 14),"Baden","Germany","Lauchringen","Lauchringen",3,1,-1,0,'Waldshut 2020',[]])
data_list.append([datetime.datetime(2020, 9, 14),"Zurich","Germany","Lauchringen","Lauchringen",1,1,-1,0,'Waldshut 2020',[]])
data_list.append([datetime.datetime(2020, 9, 14),"Waldshut","Germany","Lauchringen","Lauchringen",6,1,-1,0,'Waldshut 2020',[]])
data_list.append([datetime.datetime(2020, 9, 20),"Wangen","Germany","Lauchringen","Lauchringen",8,1,-1,0,'Hoeri hike 2020',[]])
data_list.append([datetime.datetime(2020, 9, 20),"Oehningen","Germany","Lauchringen","Lauchringen",24,1,-1,0,'Hoeri hike 2020',[]])
data_list.append([datetime.datetime(2020, 9, 20),"Kattenhorn","Germany","Lauchringen","Lauchringen",3,1,-1,0,'Hoeri hike 2020',[]])
data_list.append([datetime.datetime(2020, 9, 25),"Waldshut","Germany","Lauchringen","Lauchringen",3,1,-1,0,'Hoeri hike 2020',[]])
data_list.append([datetime.datetime(2020, 10, 4),"Salem","Germany","Lauchringen","Lauchringen",98,1,-1,0,'Salem and Ueberlingen 2020',['Artur']])
data_list.append([datetime.datetime(2020, 10, 4),"Bermatingen","Germany","Lauchringen","Lauchringen",8,1,-1,0,'Salem and Ueberlingen 2020',['Artur']])
data_list.append([datetime.datetime(2020, 10, 4),"Ueberlingen","Germany","Lauchringen","Lauchringen",25,1,-1,0,'Salem and Ueberlingen 2020',['Artur']])
data_list.append([datetime.datetime(2020, 10, 9),"Baden","Switzerland","Lauchringen","Lauchringen",28,1,-1,0,'Baden 2020',['Propulsion']])
data_list.append([datetime.datetime(2020, 10, 11),"Zug","Switzerland","Lauchringen","Lauchringen",1,1,-1,0,'Hoellgrotten 2020',['Namrata']])
data_list.append([datetime.datetime(2020, 10, 11),"Baar","Switzerland","Lauchringen","Lauchringen",80,1,-1,0,'Hoellgrotten 2020',['Namrata']])
data_list.append([datetime.datetime(2020, 10, 12),"Waldshut","Germany","Lauchringen","Lauchringen",1,1,-1,0,'Zurich I 2020',[]])
data_list.append([datetime.datetime(2020, 10, 12),"Zurich","Germany","Lauchringen","Lauchringen",2,1,-1,0,'Zurich I 2020',[]])
data_list.append([datetime.datetime(2020, 10, 25),"Tiengen","Germany","Lauchringen","Lauchringen",36,1,-1,0,'Vitibuck 2020',['Artur']])
data_list.append([datetime.datetime(2020, 11, 7),"Hoechenschwand","Germany","Lauchringen","Lauchringen",24,1,-1,0,'Hoechenschwand hike 2020',['Artur']])
data_list.append([datetime.datetime(2020, 11, 8),"Waldshut","Germany","Lauchringen","Lauchringen",30,1,-1,0,'Tiengen and Waldshut 2020',['Artur']])
data_list.append([datetime.datetime(2020, 11, 8),"Tiengen","Germany","Lauchringen","Lauchringen",25,1,-1,0,'Tiengen and Waldshut 2020',['Artur']])
data_list.append([datetime.datetime(2020, 11, 14),"Tiengen","Germany","Lauchringen","Lauchringen",31,1,-1,0,'Buergerwald hike 2020',['Artur']])
data_list.append([datetime.datetime(2020, 11, 22),"Sankt Blasien","Germany","Lauchringen","Lauchringen",30,1,-1,0,'Todtmoos Waterfall & Dom St Blasien 2020',['Artur']])
data_list.append([datetime.datetime(2020, 11, 22),"Todtmoos","Germany","Lauchringen","Lauchringen",34,1,-1,0,'Todtmoos Waterfall & Dom St Blasien 2020',['Artur']])
data_list.append([datetime.datetime(2020, 11, 22),"Hoechenschwand","Germany","Lauchringen","Lauchringen",27,1,-1,0,'Todtmoos Waterfall & Dom St Blasien 2020',['Artur']])

# %%
#2021
data_list.append([datetime.datetime(2021, 1, 11),"Bad Saeckingen","Germany","Lauchringen","Lauchringen",48,1,-1,0,'Bad Saeckingen and Laufenburg 2021',["Artur"]])
data_list.append([datetime.datetime(2021, 1, 11),"Laufenburg","Germany","Lauchringen","Lauchringen",21,1,-1,0,'Bad Saeckingen and Laufenburg 2021',["Artur"]])
data_list.append([datetime.datetime(2021, 2, 4),"Aach","Germany","Lauchringen","Lauchringen",10,1,-1,0,'Aachtopf and Reichenau 2021',["Artur"]])
data_list.append([datetime.datetime(2021, 2, 4),"Reichenau","Germany","Lauchringen","Lauchringen",21,1,-1,0,'Aachtopf and Reichenau 2021',["Artur"]])
data_list.append([datetime.datetime(2021, 2, 6),"Birnau","Germany","Lauchringen","Lauchringen",17,1,-1,0,'Bodensee 2021',["Artur"]])
data_list.append([datetime.datetime(2021, 2, 6),"Lindau","Germany","Lauchringen","Lauchringen",49,1,-1,0,'Bodensee 2021',["Artur"]])
data_list.append([datetime.datetime(2021, 2, 6),"Weingarten","Germany","Lauchringen","Lauchringen",40,1,-1,0,'Bodensee 2021',["Artur"]])
data_list.append([datetime.datetime(2021, 2, 6),"Friedrichshafen","Germany","Lauchringen","Lauchringen",4,1,-1,0,'Bodensee 2021',["Artur"]])
data_list.append([datetime.datetime(2021, 2, 6),"Meersburg","Germany","Lauchringen","Lauchringen",28,1,-1,0,'Bodensee 2021',["Artur"]])
data_list.append([datetime.datetime(2021, 2, 14),"Indlekofen","Germany","Lauchringen","Lauchringen",31,1,-1,0,'Haselbachfall 2021',["Artur"]])
data_list.append([datetime.datetime(2021, 2, 19),"Grafenhausen","Germany","Lauchringen","Lauchringen",17,1,-1,0,'Schluechtsee 2021',["Artur"]])
data_list.append([datetime.datetime(2021, 2, 21),"Beuron","Germany","Lauchringen","Lauchringen",87,1,-1,0,'Donaudurchbruch 2021',["Artur"]])
data_list.append([datetime.datetime(2021, 2, 21),"Sigmaringen","Germany","Lauchringen","Lauchringen",15,1,-1,0,'Donaudurchbruch 2021',["Artur"]])
data_list.append([datetime.datetime(2021, 2, 22),"Reinheim","Germany","Lauchringen","Lauchringen",6,1,-1,0,'Rhein Kadelburg 2021',["Artur"]])
data_list.append([datetime.datetime(2021, 2, 22),"Kadelburg","Germany","Lauchringen","Lauchringen",7,1,-1,0,'Rhein Kadelburg 2021',["Artur"]])
data_list.append([datetime.datetime(2021, 2, 23),"Bonndorf","Germany","Lauchringen","Lauchringen",15,1,-1,0,'Roggenbacher Schloesser 2021',["Artur"]])
data_list.append([datetime.datetime(2021, 2, 23),"Detzeln","Germany","Lauchringen","Lauchringen",3,1,-1,0,'Roggenbacher Schloesser 2021',["Artur"]])
data_list.append([datetime.datetime(2021, 2, 24),"Menzenschwand","Germany","Lauchringen","Lauchringen",33,1,-1,0,'Menzenschwander and Todtnauer Waterfalls 2021',["Artur"]])
data_list.append([datetime.datetime(2021, 2, 24),"Todtnau","Germany","Lauchringen","Lauchringen",47,1,-1,0,'Menzenschwander and Todtnauer Waterfalls 2021',["Artur"]])
data_list.append([datetime.datetime(2021, 2, 27),"Breitnau","Germany","Lauchringen","Lauchringen",47,1,-1,0,'Ravennaschlucht and Freiburg 2021',["Artur"]])
data_list.append([datetime.datetime(2021, 2, 27),"Freiburg","Germany","Lauchringen","Lauchringen",47,1,-1,0,'Ravennaschlucht and Freiburg 2021',["Artur"]])
data_list.append([datetime.datetime(2021, 2, 24),"Sankt Peter","Germany","Lauchringen","Lauchringen",21,1,-1,0,'Ravennaschlucht and Freiburg 2021',["Artur"]])
data_list.append([datetime.datetime(2021, 2, 24),"Sankt Maergen","Germany","Lauchringen","Lauchringen",12,1,-1,0,'Ravennaschlucht and Freiburg 2021',["Artur"]])
data_list.append([datetime.datetime(2021, 2, 24),"Titisee","Germany","Lauchringen","Lauchringen",9,1,-1,0,'Ravennaschlucht and Freiburg 2021',["Artur"]])
data_list.append([datetime.datetime(2021, 2, 24),"Lenzkirch","Germany","Lauchringen","Lauchringen",5,1,-1,0,'Ravennaschlucht and Freiburg 2021',["Artur"]])
data_list.append([datetime.datetime(2021, 2, 24),"Schluchsee","Germany","Lauchringen","Lauchringen",5,1,-1,0,'Ravennaschlucht and Freiburg 2021',["Artur"]])
data_list.append([datetime.datetime(2021, 2, 28),"Rickenbach","Germany","Lauchringen","Lauchringen",34,1,-1,0,'Strahlbrusch Waterfall 2021',["Artur"]])
data_list.append([datetime.datetime(2021, 2, 28),"Murg","Germany","Lauchringen","Lauchringen",7,1,-1,0,'Strahlbrusch Waterfall 2021',["Artur"]])
data_list.append([datetime.datetime(2021, 3, 1),"Waldshut","Germany","Lauchringen","Lauchringen",13,1,-1,0,'Aaremuendung 2021',["Artur"]])
data_list.append([datetime.datetime(2021, 3, 2),"Goerwihl","Germany","Lauchringen","Lauchringen",46,1,-1,0,'Hoellbachfalls 2021',["Artur"]])
data_list.append([datetime.datetime(2021, 3, 2),"Albruck","Germany","Lauchringen","Lauchringen",3,1,-1,0,'Hoellbachfalls 2021',["Artur"]])
data_list.append([datetime.datetime(2021, 3, 6),"Konstanz","Germany","Lauchringen","Lauchringen",81,1,-1,0,'Konstanz and Hohenkraehen 2021',["Artur"]])
data_list.append([datetime.datetime(2021, 3, 6),"Hilzingen","Germany","Lauchringen","Lauchringen",20,1,-1,0,'Konstanz and Hohenkraehen 2021',["Artur"]])
data_list.append([datetime.datetime(2021, 3, 6),"Muehlhausen","Germany","Lauchringen","Lauchringen",16,1,-1,0,'Konstanz and Hohenkraehen 2021',["Artur"]])
data_list.append([datetime.datetime(2021, 3, 6),"Tengen","Germany","Lauchringen","Lauchringen",29,1,-1,0,'Konstanz and Hohenkraehen 2021',["Artur"]])
data_list.append([datetime.datetime(2021, 3, 9),"Walshut","Germany","Lauchringen","Lauchringen",9,1,-1,0,'Waldshut 2021',["Artur"]])
data_list.append([datetime.datetime(2021, 3, 10),"Tiengen","Germany","Lauchringen","Lauchringen",4,1,-1,0,'Tiengen 2021',[]])
data_list.append([datetime.datetime(2021, 3, 11),"Lindau","Germany","Lauchringen","Lauchringen",1,1,-1,0,'Bewerbung Wien 2021',['Artur']])
data_list.append([datetime.datetime(2021, 3, 11),"Kempten","Germany","Lauchringen","Lauchringen",1,1,-1,0,'Bewerbung Wien 2021',[]])
data_list.append([datetime.datetime(2021, 3, 11),"Muenchen","Germany","Lauchringen","Lauchringen",1,1,-1,0,'Bewerbung Wien 2021',[]])
data_list.append([datetime.datetime(2021, 3, 11),"Salzburg","Austria","Lauchringen","Lauchringen",2,1,-1,0,'Bewerbung Wien 2021',[]])
data_list.append([datetime.datetime(2021, 3, 11),"Vienna","Austria","Lauchringen","Lauchringen",3,1,-1,0,'Bewerbung Wien 2021',[]])
data_list.append([datetime.datetime(2021, 3, 25),"Triberg","Germany","Lauchringen","Lauchringen",62,1,-1,0,'Triberg Waterfalls and Villingen 2021',["Artur"]])
data_list.append([datetime.datetime(2021, 3, 25),"Schonach","Germany","Lauchringen","Lauchringen",1,1,-1,0,'Triberg Waterfalls and Villingen 2021',["Artur"]])
data_list.append([datetime.datetime(2021, 3, 25),"Villingen","Germany","Lauchringen","Lauchringen",36,1,-1,0,'Triberg Waterfalls and Villingen 2021',["Artur"]])
data_list.append([datetime.datetime(2021, 3, 28),"Albruck","Germany","Lauchringen","Lauchringen",5,1,-1,0,'Albtal hike 2021',["Artur"]])
data_list.append([datetime.datetime(2021, 3, 28),"Dachsberg","Germany","Lauchringen","Lauchringen",13,1,-1,0,'Albtal hike 2021',["Artur"]])
data_list.append([datetime.datetime(2021, 3, 28),"Goerwihl","Germany","Lauchringen","Lauchringen",10,1,-1,0,'Albtal hike 2021',["Artur"]])
data_list.append([datetime.datetime(2021, 3, 28),"Gutenburg","Germany","Lauchringen","Lauchringen",13,1,-1,0,'Albtal hike 2021',["Artur"]])
data_list.append([datetime.datetime(2021, 3, 30),"Blumberg","Germany","Lauchringen","Lauchringen",13,1,-1,0,'Schleifenbach Falls and Hoewenegg 2021',["Artur"]])
data_list.append([datetime.datetime(2021, 3, 30),"Mundelfingen","Germany","Lauchringen","Lauchringen",11,1,-1,0,'Schleifenbach Falls and Hoewenegg 2021',["Artur"]])
data_list.append([datetime.datetime(2021, 3, 30),"Immendingen","Germany","Lauchringen","Lauchringen",11,1,-1,0,'Schleifenbach Falls and Hoewenegg 2021',["Artur"]])
data_list.append([datetime.datetime(2021, 3, 30),"Moehringen","Germany","Lauchringen","Lauchringen",1,1,-1,0,'Schleifenbach Falls and Hoewenegg 2021',["Artur"]])
data_list.append([datetime.datetime(2021, 4, 11),"Stuehlingen","Germany","Lauchringen","Lauchringen",26,1,-1,0,'Grimmelshofen and Stuehlingen 2021',["Artur"]])
data_list.append([datetime.datetime(2021, 4, 11),"Grimmelshofen","Germany","Lauchringen","Lauchringen",16,1,-1,0,'Grimmelshofen and Stuehlingen 2021',["Artur"]])
data_list.append([datetime.datetime(2021, 4, 16),"Waldshut","Germany","Lauchringen","Lauchringen",20,1,-1,0,'Waldshut Wildgehege 2021',["Artur"]])
data_list.append([datetime.datetime(2021, 4, 20),"Hohentengen","Germany","Lauchringen","Lauchringen",19,1,-1,0,'Hohentengen Hike 2021',["Artur"]])
data_list.append([datetime.datetime(2021, 4, 24),"Bickensohl","Germany","Lauchringen","Lauchringen",39,1,-1,0,'Kaiserstuhl and Breisach 2021',["Artur"]])
data_list.append([datetime.datetime(2021, 4, 24),"Breisach am Rhein","Germany","Lauchringen","Lauchringen",30,1,-1,0,'Kaiserstuhl and Breisach 2021',["Artur"]])
data_list.append([datetime.datetime(2021, 4, 26),"Uberlingen","Germany","Lauchringen","Lauchringen",4,1,-1,0,'Ueberlingen 2021',["Artur",'Christian']])
data_list.append([datetime.datetime(2021, 4, 26),"Sipplingen","Germany","Lauchringen","Lauchringen",3,1,-1,0,'Ueberlingen 2021',["Artur"]])

# %%
#2021
data_list.append([datetime.datetime(2021, 5, 15),"Engelhartstetten","Austria","Vienna","Vienna",110,1,-1,0,'Schloss Hof 2021',[]])
data_list.append([datetime.datetime(2021, 5, 22),"Salzburg","Austria","Vienna","Vienna",457,1,-1,0,'Gollinger Wasserfall and Salzburg I 2021',[]])
data_list.append([datetime.datetime(2021, 5, 23),"Golling an der Salzach","Austria","Vienna","Vienna",54,1,-1,0,'Gollinger Wasserfall and Salzburg I 2021',[]])
data_list.append([datetime.datetime(2021, 5, 23),"Elsbethen","Austria","Vienna","Vienna",1,1,-1,0,'Gollinger Wasserfall and Salzburg I 2021',[]])
data_list.append([datetime.datetime(2021, 5, 24),"Wels","Austria","Vienna","Vienna",1,1,-1,0,'Hallstatt 2021',[]])
data_list.append([datetime.datetime(2021, 5, 24),"Altmuenster","Austria","Vienna","Vienna",1,1,-1,0,'Hallstatt 2021',[]])
data_list.append([datetime.datetime(2021, 5, 24),"Traunkirchen","Austria","Vienna","Vienna",5,1,-1,0,'Hallstatt 2021',[]])
data_list.append([datetime.datetime(2021, 5, 24),"Ebensee","Austria","Vienna","Vienna",1,1,-1,0,'Hallstatt 2021',[]])
data_list.append([datetime.datetime(2021, 5, 24),"Lahnstein","Austria","Vienna","Vienna",1,1,-1,0,'Hallstatt 2021',[]])
data_list.append([datetime.datetime(2021, 5, 24),"Steeg","Austria","Vienna","Vienna",5,1,-1,0,'Hallstatt 2021',[]])
data_list.append([datetime.datetime(2021, 5, 24),"Hallstatt","Austria","Vienna","Vienna",215,1,-1,0,'Hallstatt 2021',[]])
data_list.append([datetime.datetime(2021, 5, 24),"Obertraun","Austria","Vienna","Vienna",26,1,-1,0,'Hallstatt 2021',[]])
data_list.append([datetime.datetime(2021, 5, 24),"Attnang-Puchheim","Austria","Vienna","Vienna",1,1,-1,0,'Hallstatt 2021',[]])
data_list.append([datetime.datetime(2021, 5, 30),"Klosterneuburg","Austria","Vienna","Vienna",268,1,-1,0,'Stift Klosterneuburg 2021',[]])
data_list.append([datetime.datetime(2021, 6, 3),"Althofen","Austria","Vienna","Vienna",3,1,-1,0,'Burg Hochosterwith 2021',[]])
data_list.append([datetime.datetime(2021, 6, 3),"Launsdorf","Austria","Vienna","Vienna",75,1,-1,0,'Burg Hochosterwith 2021',[]])
data_list.append([datetime.datetime(2021, 6, 3),"Breitenstein","Austria","Vienna","Vienna",2,1,-1,0,'Burg Hochosterwith 2021',[]])
data_list.append([datetime.datetime(2021, 6, 3),"Payerbach","Austria","Vienna","Vienna",2,1,-1,0,'Burg Hochosterwith 2021',[]])
data_list.append([datetime.datetime(2021, 6, 3),"Neumart in der Steiermark","Austria","Vienna","Vienna",1,1,-1,0,'Burg Hochosterwith 2021',[]])
data_list.append([datetime.datetime(2021, 6, 12),"Lilienfeld","Austria","Vienna","Vienna",72,1,-1,0,'Stift Lilienfeld and Stift Herzogenburg 2021',[]])
data_list.append([datetime.datetime(2021, 6, 12),"Herzogenburg","Austria","Vienna","Vienna",73,1,-1,0,'Stift Lilienfeld and Stift Herzogenburg 2021',[]])
data_list.append([datetime.datetime(2021, 6, 12),"St Poelten","Austria","Vienna","Vienna",51,1,-1,0,'Stift Lilienfeld and Stift Herzogenburg 2021',[]])
data_list.append([datetime.datetime(2021, 6, 13),"Muggendorf","Austria","Vienna","Vienna",81,1,-1,0,'Stift Lilienfeld and Stift Herzogenburg 2021',[]])
data_list.append([datetime.datetime(2021, 6, 13),"Furth an der Triesting","Austria","Vienna","Vienna",54,1,-1,0,'Myrafaelle and Steinbachklamm 2021',[]])
data_list.append([datetime.datetime(2021, 6, 13),"Pernitz","Austria","Vienna","Vienna",2,1,-1,0,'Myrafaelle and Steinbachklamm 2021',[]])
data_list.append([datetime.datetime(2021, 6, 13),"Wiener Neustadt","Austria","Vienna","Vienna",51,1,-1,0,'Myrafaelle and Steinbachklamm 2021',[]])
data_list.append([datetime.datetime(2021, 6, 19),"Melk","Austria","Vienna","Vienna",2,1,-1,0,'Wachau 2021',[]])
data_list.append([datetime.datetime(2021, 6, 19),"Grimsing","Austria","Vienna","Vienna",5,1,-1,0,'Wachau 2021',[]])
data_list.append([datetime.datetime(2021, 6, 19),"Schallemmersdorf","Austria","Vienna","Vienna",1,1,-1,0,'Wachau 2021',[]])
data_list.append([datetime.datetime(2021, 6, 19),"Emmersdorf an der Donau","Austria","Vienna","Vienna",10,1,-1,0,'Wachau 2021',[]])
data_list.append([datetime.datetime(2021, 6, 19),"Aggsbach Markt","Austria","Vienna","Vienna",1,1,-1,0,'Wachau 2021',[]])
data_list.append([datetime.datetime(2021, 6, 19),"Willendorf in der Wachau","Austria","Vienna","Vienna",1,1,-1,0,'Wachau 2021',[]])
data_list.append([datetime.datetime(2021, 6, 19),"Schwallenbach","Austria","Vienna","Vienna",1,1,-1,0,'Wachau 2021',[]])
data_list.append([datetime.datetime(2021, 6, 19),"Spitz an der Donau","Austria","Vienna","Vienna",29,1,-1,0,'Wachau 2021',[]])
data_list.append([datetime.datetime(2021, 6, 19),"Weissenkirchen in der Wachau","Austria","Vienna","Vienna",4,1,-1,0,'Wachau 2021',[]])
data_list.append([datetime.datetime(2021, 6, 19),"Duernstein","Austria","Vienna","Vienna",131,1,-1,0,'Wachau 2021',[]])
data_list.append([datetime.datetime(2021, 6, 19),"Oberloiben","Austria","Vienna","Vienna",1,1,-1,0,'Wachau 2021',[]])
data_list.append([datetime.datetime(2021, 6, 19),"Unterloiben","Austria","Vienna","Vienna",1,1,-1,0,'Wachau 2021',[]])
data_list.append([datetime.datetime(2021, 6, 19),"Krems an der Donau","Austria","Vienna","Vienna",53,1,-1,0,'Wachau 2021',[]])
data_list.append([datetime.datetime(2021, 6, 19),"Thunau am Kamp","Austria","Vienna","Vienna",2,1,-1,0,'Wachau 2021',[]])
data_list.append([datetime.datetime(2021, 6, 20),"Baden bei Vienna","Austria","Vienna","Vienna",61,1,-1,0,'Baden and Stift Heiligenkreuz 2021',[]])
data_list.append([datetime.datetime(2021, 6, 20),"Heiligenkreuz im Viennaerwald","Austria","Vienna","Vienna",105,1,-1,0,'Baden and Stift Heiligenkreuz 2021',[]])
data_list.append([datetime.datetime(2021, 6, 26),"Seitenstetten","Austria","Vienna","Vienna",81,1,-1,0,'Stift Seitenstetten and Stift St Florian 2021',[]])
data_list.append([datetime.datetime(2021, 6, 26),"Sankt Florian bei Linz","Austria","Vienna","Vienna",164,1,-1,0,'Stift Seitenstetten and Stift St Florian 2021',[]])
data_list.append([datetime.datetime(2021, 6, 26),"Hohenbrunn","Austria","Vienna","Vienna",4,1,-1,0,'Stift Seitenstetten and Stift St Florian 2021',[]])
data_list.append([datetime.datetime(2021, 6, 26),"Linz","Austria","Vienna","Vienna",19,1,-1,0,'Stift Seitenstetten and Stift St Florian 2021',[]])
data_list.append([datetime.datetime(2021, 7, 3),"Obertraun","Austria","Vienna","Vienna",200,1,-1,0,'Dachsteinhoehlen 2021',[]])
data_list.append([datetime.datetime(2021, 7, 3),"Bad Goisern","Austria","Vienna","Vienna",5,1,-1,0,'Dachsteinhoehlen 2021',[]])
data_list.append([datetime.datetime(2021, 7, 3),"Ebensee","Austria","Vienna","Vienna",1,1,-1,0,'Dachsteinhoehlen 2021',[]])
data_list.append([datetime.datetime(2021, 7, 3),"Traunkirchen","Austria","Vienna","Vienna",1,1,-1,0,'Dachsteinhoehlen 2021',[]])
data_list.append([datetime.datetime(2021, 7, 3),"Altmuenster","Austria","Vienna","Vienna",1,1,-1,0,'Dachsteinhoehlen 2021',[]])
data_list.append([datetime.datetime(2021, 7, 10),"Salzburg","Austria","Vienna","Vienna",1,1,-1,0,'Kitzlochklamm and Liechtensteinklamm 2021',[]])
data_list.append([datetime.datetime(2021, 7, 10),"Werfen","Austria","Vienna","Vienna",1,1,-1,0,'Kitzlochklamm and Liechtensteinklamm 2021',[]])
data_list.append([datetime.datetime(2021, 7, 10),"Lend","Austria","Vienna","Vienna",1,1,-1,0,'Kitzlochklamm and Liechtensteinklamm 2021',[]])
data_list.append([datetime.datetime(2021, 7, 10),"Taxenbach","Austria","Vienna","Vienna",96,1,-1,0,'Kitzlochklamm and Liechtensteinklamm 2021',[]])
data_list.append([datetime.datetime(2021, 7, 10),"Schwarzach im Pongau","Austria","Vienna","Vienna",3,1,-1,0,'Kitzlochklamm and Liechtensteinklamm 2021',[]])
data_list.append([datetime.datetime(2021, 7, 10),"Sankt Veit im Pongau","Austria","Vienna","Vienna",8,1,-1,0,'Kitzlochklamm and Liechtensteinklamm 2021',[]])
data_list.append([datetime.datetime(2021, 7, 10),"Sankt Johann im Pongau","Austria","Vienna","Vienna",102,1,-1,0,'Kitzlochklamm and Liechtensteinklamm 2021',[]])
data_list.append([datetime.datetime(2021, 7, 10),"Bischofshofen","Austria","Vienna","Vienna",23,1,-1,0,'Kitzlochklamm and Liechtensteinklamm 2021',[]])
data_list.append([datetime.datetime(2021, 7, 10),"Golling an der Salzach","Austria","Vienna","Vienna",1,1,-1,0,'Kitzlochklamm and Liechtensteinklamm 2021',[]])
data_list.append([datetime.datetime(2021, 7, 17),"Bad Gastein","Austria","Vienna","Vienna",78,1,-1,0,'Bad Gastein and Klagenfurt 2021',[]])
data_list.append([datetime.datetime(2021, 7, 17),"Klagenfurt","Austria","Vienna","Vienna",68,1,-1,0,'Bad Gastein and Klagenfurt 2021',[]])
#Innsbruck 2021
data_list.append([datetime.datetime(2021, 7, 23),"Kiefersfelden","Austria","Vienna","Innsbruck",1,0,1,0,"Innsbruck 2021",[]])
data_list.append([datetime.datetime(2021, 7, 23),"Kufstein","Austria","Vienna","Innsbruck",1,0,1,0,"Innsbruck 2021",[]])
data_list.append([datetime.datetime(2021, 7, 23),"Innsbruck","Austria","Vienna","Innsbruck",67,0,1,0,"Innsbruck 2021",["Grace C","Janina","Sam"]])
data_list.append([datetime.datetime(2021, 7, 24),"Krimml","Austria","Innsbruck","Innsbruck",61,0,-1,0,"Innsbruck 2021",["Grace C","Janina","Sam"]])
data_list.append([datetime.datetime(2021, 7, 24),"Gerlos","Austria","Innsbruck","Innsbruck",10,0,-1,0,"Innsbruck 2021",["Grace C","Janina","Sam"]])
data_list.append([datetime.datetime(2021, 7, 24),"Innsbruck","Austria","Innsbruck","Innsbruck",133,0,-1,0,"Innsbruck 2021",["Grace C","Janina","Sam"]])
data_list.append([datetime.datetime(2021, 7, 25),"Wattens","Austria","Innsbruck","Vienna",106,0,0,0,"Innsbruck 2021",["Grace C","Janina","Sam"]])
data_list.append([datetime.datetime(2021, 7, 25),"Innsbruck","Austria","Innsbruck","Vienna",84,0,0,0,"Innsbruck 2021",["Grace C","Janina","Sam"]])
##
data_list.append([datetime.datetime(2021, 8, 1),"Petronell-Carnuntum","Austria","Vienna","Vienna",56,1,-1,0,'Carnuntum and Schloss Eckartsau 2021',[]])
data_list.append([datetime.datetime(2021, 8, 1),"Bad Deutsch-Altenburg","Austria","Vienna","Vienna",33,1,-1,0,'Carnuntum and Schloss Eckartsau 2021',[]])
data_list.append([datetime.datetime(2021, 8, 1),"Eckartsau","Austria","Vienna","Vienna",87,1,-1,0,'Carnuntum and Schloss Eckartsau 2021',[]])
data_list.append([datetime.datetime(2021, 8, 7),"St Margarethen im Burgenland","Austria","Vienna","Vienna",33,1,-1,0,'Neusiedler See and Eisenstadt 2021',[]])
data_list.append([datetime.datetime(2021, 8, 7),"Rust am See","Austria","Vienna","Vienna",30,1,-1,0,'Neusiedler See and Eisenstadt 2021',[]])
data_list.append([datetime.datetime(2021, 8, 7),"Eisenstadt","Austria","Vienna","Vienna",117,1,-1,0,'Neusiedler See and Eisenstadt 2021',[]])
data_list.append([datetime.datetime(2021, 8, 8),"Laxenburg","Austria","Vienna","Vienna",152,1,-1,0,'Neusiedler See and Eisenstadt 2021',[]])
data_list.append([datetime.datetime(2021, 8, 14),"Rosenburg","Austria","Vienna","Vienna",11,1,-1,0,'Stift Altenburg and Stift Goettweig 2021',[]])
data_list.append([datetime.datetime(2021, 8, 14),"Altenburg","Austria","Vienna","Vienna",131,1,-1,0,'Stift Altenburg and Stift Goettweig 2021',[]])
data_list.append([datetime.datetime(2021, 8, 14),"Furth bei Goettweig","Austria","Vienna","Vienna",77,1,-1,0,'Stift Altenburg and Stift Goettweig 2021',[]])
data_list.append([datetime.datetime(2021, 8, 21),"Semmering","Austria","Vienna","Vienna",38,1,-1,0,'Semmeringbahn 2021',[]])
data_list.append([datetime.datetime(2021, 8, 21),"Breitenstein","Austria","Vienna","Vienna",50,1,-1,0,'Semmeringbahn 2021',[]])
data_list.append([datetime.datetime(2021, 8, 21),"Payerbach","Austria","Vienna","Vienna",10,1,-1,0,'Semmeringbahn 2021',[]])
#Prag trip
data_list.append([datetime.datetime(2021, 8, 27),'Prague',"Czech Republic","Vienna",'Prague',10,0,1,0,"Prague 2021",[]])
data_list.append([datetime.datetime(2021, 8, 28),'Prague',"Czech Republic",'Prague','Prague',361,0,-1,0,"Prague 2021",[]])
data_list.append([datetime.datetime(2021, 8, 28),'Karlstejn',"Czech Republic",'Prague','Prague',37,0,-1,0,"Prague 2021",[]])
data_list.append([datetime.datetime(2021, 8, 29),'Prague',"Czech Republic",'Prague','Vienna',319,0,0,0,"Prague 2021",[]])
##
#Geiselwind trip
data_list.append([datetime.datetime(2021, 9, 2),"Passau","Germany","Vienna","Geiselwind",7,0,0,0,"Geiselwind 2021",[]])
data_list.append([datetime.datetime(2021, 9, 3),"Geiselwind","Germany","Geiselwind","Geiselwind",3,0,-1,0,"Geiselwind 2021",['Artur',"Hannsjoerg","Marion","Julius","Jan-Marc",'Felicitas','Julius',"Anne-Kathrin",'Mathilda','Christian']])
data_list.append([datetime.datetime(2021, 9, 3),"Bamberg","Germany","Geiselwind","Geiselwind",61,0,-1,0,"Geiselwind 2021",["Hannsjoerg"]])
data_list.append([datetime.datetime(2021, 9, 3),"Pommersfelden","Germany","Geiselwind","Geiselwind",7,0,-1,0,"Geiselwind 2021",["Hannsjoerg"]])
data_list.append([datetime.datetime(2021, 9, 4),"Wuerzburg","Germany","Geiselwind","Geiselwind",90,0,-1,0,"Geiselwind 2021",['Artur',"Hannsjoerg","Marion","Julius","Jan-Marc",'Felicitas','Julius',"Anne-Kathrin",'Mathilda','Christian']])
data_list.append([datetime.datetime(2021, 9, 5),"Regensburg","Germany","Geiselwind","Vienna",118,0,0,0,"Geiselwind 2021",[]])
data_list.append([datetime.datetime(2021, 9, 5),"Passau","Germany","Geiselwind","Vienna",78,0,1,0,"Geiselwind 2021",[]])
##
data_list.append([datetime.datetime(2021, 9, 18),"Annaberg bei Mariazell","Austria","Vienna","Vienna",37,1,-1,0,"Oetschergraeben and Mariazell 2021",[]])
data_list.append([datetime.datetime(2021, 9, 18),"Mitterbach am Erlaufsee","Austria","Vienna","Vienna",146,1,-1,0,"Oetschergraeben and Mariazell 2021",[]])
data_list.append([datetime.datetime(2021, 9, 18),"Mariazell","Austria","Vienna","Vienna",45,1,-1,0,"Oetschergraeben and Mariazell 2021",[]])
data_list.append([datetime.datetime(2021, 9, 25),"Salzburg","Austria","Vienna","Vienna",39,1,-1,0,'Salzburg II 2021',["Michael",'Vivan']])
#germany belgium luxemburg Paris trip 2021 October
data_list.append([datetime.datetime(2021, 10, 22),"Nuernberg","Germany","Vienna","Nuernberg",39,0,1,0,"Germany and France 2021",[]])
data_list.append([datetime.datetime(2021, 10, 23),"Nuernberg","Germany","Nuernberg",'Trier',279,0,0,0,"Germany and France 2021",[]])
data_list.append([datetime.datetime(2021, 10, 23),"Trier","Germany","Nuernberg",'Trier',5,0,1,0,"Germany and France 2021",[]])
data_list.append([datetime.datetime(2021, 10, 24),"Luxemburg","Luxemburg","Trier",'Trier',81,0,-1,0,"Germany and France 2021",[]])
data_list.append([datetime.datetime(2021, 10, 24),"Wasserbillig","Luxemburg","Trier",'Trier',1,0,-1,0,"Germany and France 2021",[]])
data_list.append([datetime.datetime(2021, 10, 24),"Trier","Germany","Trier",'Trier',265,0,-1,0,"Germany and France 2021",[]])
data_list.append([datetime.datetime(2021, 10, 25),"Nancy","France","Trier",'Metz',105,0,1,0,"Germany and France 2021",[]])
data_list.append([datetime.datetime(2021, 10, 25),"Metz","France","Trier",'Metz',134,0,1,0,"Germany and France 2021",[]])
data_list.append([datetime.datetime(2021, 10, 26),"Paris","France","Metz","Paris",379,0,1,0,"Germany and France 2021",[]])
data_list.append([datetime.datetime(2021, 10, 27),"Paris","France","Paris","Paris",454,0,-1,0,"Germany and France 2021",[]])
data_list.append([datetime.datetime(2021, 10, 27),"Saint Denis","France","Paris","Paris",92,0,-1,0,"Germany and France 2021",[]])
data_list.append([datetime.datetime(2017, 10, 28),"Tournai","Belgium","Paris","Paris",66,0,-1,0,"Germany and France 2021",[]])
data_list.append([datetime.datetime(2017, 10, 28),"Lille","France","Paris","Paris",16,0,-1,0,"Germany and France 2021",[]])
data_list.append([datetime.datetime(2017, 10, 28),"Oignies","France","Paris","Paris",41,0,-1,0,"Germany and France 2021",[]])
data_list.append([datetime.datetime(2017, 10, 28),"Arras","France","Paris","Paris",65,0,-1,0,"Germany and France 2021",[]])
data_list.append([datetime.datetime(2021, 10, 28),"Paris","France","Paris","Paris",1,0,-1,0,"Germany and France 2021",[]])
data_list.append([datetime.datetime(2021, 10, 29),"Aachen","Germany","Paris","Frankfurt",169,0,1,0,"Germany and France 2021",[]])
data_list.append([datetime.datetime(2021, 10, 29),"Cologne","Germany","Paris","Frankfurt",223,0,1,0,"Germany and France 2021",[]])
data_list.append([datetime.datetime(2021, 10, 29),"Frankfurt","Germany","Paris","Frankfurt",3,0,1,0,"Germany and France 2021",[]])
data_list.append([datetime.datetime(2021, 10, 30),"Mannheim","Germany","Frankfurt","Frankfurt",1,0,-1,0,"Germany and France 2021",[]])
data_list.append([datetime.datetime(2021, 10, 30),"Speyer","Germany","Frankfurt","Frankfurt",100,0,-1,0,"Germany and France 2021",[]])
data_list.append([datetime.datetime(2021, 10, 30),"Worms","Germany","Frankfurt","Frankfurt",46,0,-1,0,"Germany and France 2021",[]])
data_list.append([datetime.datetime(2021, 10, 30),"Darmstadt","Germany","Frankfurt","Frankfurt",68,0,-1,0,"Germany and France 2021",[]])
data_list.append([datetime.datetime(2021, 10, 30),"Frankfurt","Germany","Frankfurt","Frankfurt",17,0,-1,0,"Germany and France 2021",[]])
data_list.append([datetime.datetime(2021, 10, 31),"Kaub","Germany","Frankfurt","Frankfurt",10,0,-1,0,"Germany and France 2021",[]])
data_list.append([datetime.datetime(2021, 10, 31),"Sankt Goarshausen","Germany","Frankfurt","Frankfurt",7,0,-1,0,"Germany and France 2021",[]])
data_list.append([datetime.datetime(2021, 10, 31),"Kesters","Germany","Frankfurt","Frankfurt",1,0,-1,0,"Germany and France 2021",[]])
data_list.append([datetime.datetime(2021, 10, 31),"Kamp-Bornhofen","Germany","Frankfurt","Frankfurt",1,0,-1,0,"Germany and France 2021",[]])
data_list.append([datetime.datetime(2021, 10, 31),"Braubach","Germany","Frankfurt","Frankfurt",85,0,-1,0,"Germany and France 2021",[]])
data_list.append([datetime.datetime(2021, 10, 31),"Lahnstein","Germany","Frankfurt","Frankfurt",1,0,-1,0,"Germany and France 2021",[]])
data_list.append([datetime.datetime(2021, 10, 31),"Koblenz","Germany","Frankfurt","Frankfurt",1,0,-1,0,"Germany and France 2021",[]])
data_list.append([datetime.datetime(2021, 10, 31),"Duisburg","Germany","Frankfurt","Frankfurt",1,0,-1,0,"Germany and France 2021",[]])
data_list.append([datetime.datetime(2021, 10, 31),"Essen","Germany","Frankfurt","Frankfurt",83,0,-1,0,"Germany and France 2021",[]])
data_list.append([datetime.datetime(2021, 10, 31),"Frankfurt","Germany","Frankfurt",'Vienna',1,0,0,0,"Germany and France 2021",[]])
##

# %%
##2022
##Spain
data_list.append([datetime.datetime(2022, 3, 19),"Madrid","Spain","Vienna","Malaga",99,0,1,1,'Spain 2022',[]])
data_list.append([datetime.datetime(2022, 3, 19),"Malaga","Spain","Vienna","Malaga",23,0,1,1,'Spain 2022',[]])
data_list.append([datetime.datetime(2022, 3, 20),"Malaga","Spain","Malaga","Malaga",266,0,-1,0,'Spain 2022',[]])
data_list.append([datetime.datetime(2022, 3, 21),"Maro","Spain","Malaga","Granada",79,0,0,0,'Spain 2022',[]])
data_list.append([datetime.datetime(2022, 3, 21),"Malaga","Spain","Malaga","Granada",4,0,0,0,'Spain 2022',[]])
data_list.append([datetime.datetime(2022, 3, 21),"Granada","Spain","Malaga","Granada",128,0,1,0,'Spain 2022',[]])
data_list.append([datetime.datetime(2022, 3, 22),"Granada","Spain","Granada","Granada",439,0,-1,0,'Spain 2022',[]])
data_list.append([datetime.datetime(2022, 3, 23),"Granada","Spain","Granada","Granada",2,0,-1,0,'Spain 2022',[]])
data_list.append([datetime.datetime(2022, 3, 23),"Jaen","Spain","Granada","Granada",134,0,-1,0,'Spain 2022',[]])
data_list.append([datetime.datetime(2022, 3, 23),"Ubeda","Spain","Granada","Granada",173,0,-1,0,'Spain 2022',[]])
data_list.append([datetime.datetime(2022, 3, 24),"Cordoba","Spain","Granada","Cordoba",358,0,1,0,'Spain 2022',[]])
data_list.append([datetime.datetime(2022, 3, 25),"Sevilla","Spain","Cordoba","Sevilla",611,0,1,0,'Spain 2022',[]])
data_list.append([datetime.datetime(2022, 3, 26),"Caceres","Spain","Sevilla","Sevilla",155,0,-1,0,'Spain 2022',[]])
data_list.append([datetime.datetime(2022, 3, 26),"Sevilla","Spain","Sevilla","Sevilla",1,0,-1,0,'Spain 2022',[]])
data_list.append([datetime.datetime(2022, 3, 27),"Merida","Spain","Sevilla","Sevilla",203,0,-1,0,'Spain 2022',[]])
data_list.append([datetime.datetime(2022, 3, 27),"Sevilla","Spain","Sevilla","Sevilla",1,0,-1,0,'Spain 2022',[]])
data_list.append([datetime.datetime(2022, 3, 28),"Madrid","Spain","Sevilla","Madrid",133,0,1,0,'Spain 2022',[]])
data_list.append([datetime.datetime(2022, 3, 28),"Cuenca","Spain","Sevilla","Madrid",192,0,1,0,'Spain 2022',[]])
data_list.append([datetime.datetime(2022, 3, 29),"Madrid","Spain","Madrid","Madrid",99,0,-1,0,'Spain 2022',[]])
data_list.append([datetime.datetime(2022, 3, 29),"Alcala de Henares","Spain","Madrid","Madrid",90,0,-1,0,'Spain 2022',[]])
data_list.append([datetime.datetime(2022, 3, 30),"Toledo","Spain","Madrid","Madrid",554,0,-1,0,'Spain 2022',[]])
data_list.append([datetime.datetime(2022, 3, 31),"Leon","Spain","Madrid","Madrid",167,0,-1,0,'Spain 2022',[]])
data_list.append([datetime.datetime(2022, 3, 31),"Astorga","Spain","Madrid","Madrid",134,0,-1,0,'Spain 2022',[]])
data_list.append([datetime.datetime(2022, 4, 1),"Segovia","Spain","Madrid","Madrid",261,0,-1,0,'Spain 2022',[]])
data_list.append([datetime.datetime(2022, 4, 1),"La Granja de San Ilfefonso","Spain","Madrid","Madrid",76,0,-1,0,'Spain 2022',[]])
data_list.append([datetime.datetime(2022, 4, 1),"Madrid","Spain","Madrid","Madrid",29,0,-1,0,'Spain 2022',[]])
data_list.append([datetime.datetime(2022, 4, 2),"Aranjuez","Spain","Madrid","Madrid",67,0,-1,0,'Spain 2022',[]])
data_list.append([datetime.datetime(2022, 4, 2),"El Escorial","Spain","Madrid","Madrid",125,0,-1,0,'Spain 2022',[]])
data_list.append([datetime.datetime(2022, 4, 3),"Madrid","Spain","Madrid","Vienna",196,0,0,2,'Spain 2022',[]])
data_list.append([datetime.datetime(2022, 5, 15),"Pannonhalma","Hungary","Vienna","Vienna",98,1,-1,0,'Pannonhalma and Gyor 2022',[]])
data_list.append([datetime.datetime(2022, 5, 15),"Gyor","Hungary","Vienna","Vienna",29,1,-1,0,'Pannonhalma and Gyor 2022',[]])
data_list.append([datetime.datetime(2022, 5, 25),"Budapest","Hungary","Vienna","Budapest",201,0,1,0,'Budapest I 2022',['Chris M']])
data_list.append([datetime.datetime(2022, 5, 26),"Budapest","Hungary","Budapest","Budapest",202,0,-1,0,'Budapest I 2022',['Chris M']])
data_list.append([datetime.datetime(2022, 5, 27),"Budapest","Hungary","Budapest","Vienna",4,0,0,0,'Budapest I 2022',['Chris M']])
data_list.append([datetime.datetime(2022, 6, 4),"Bratislava","Slovakia","Vienna","Vienna",146,1,-1,0,'Bratislava 2022',["Artur"]])
data_list.append([datetime.datetime(2022, 6, 5),"Budapest","Hungary","Vienna","Vienna",138,1,-1,0,'Budapest II 2022',["Artur"]])
data_list.append([datetime.datetime(2022, 6, 11),"Augsburg","Germany","Vienna","Vienna",217,1,-1,0,'Augsburg and Muenchen 2022',[]])
data_list.append([datetime.datetime(2022, 6, 11),"Muenchen","Germany","Vienna","Vienna",52,1,-1,0,'Augsburg and Muenchen 2022',[]])
data_list.append([datetime.datetime(2022, 6, 16),"Stralsund","Germany","Vienna","Berlin",114,0,1,1,'Berlin 2022',[]])
data_list.append([datetime.datetime(2022, 6, 16),"Rostock","Germany","Vienna","Berlin",55,0,1,1,'Berlin 2022',[]])
data_list.append([datetime.datetime(2022, 6, 17),"Dresden","Germany","Berlin","Berlin",1,0,-1,0,'Berlin 2022',[]])
data_list.append([datetime.datetime(2022, 6, 17),"Freiberg","Germany","Berlin","Berlin",99,0,-1,0,'Berlin 2022',[]])
data_list.append([datetime.datetime(2022, 6, 17),"Moritzburg","Germany","Berlin","Berlin",90,0,-1,0,'Berlin 2022',[]])
data_list.append([datetime.datetime(2022, 6, 17),"Berlin","Germany","Berlin","Berlin",1,0,-1,0,'Berlin 2022',['Hannsjoerg']])
data_list.append([datetime.datetime(2022, 6, 18),"Potsdam","Germany","Berlin","Berlin",310,0,-1,0,'Berlin 2022',['Hannsjoerg']])
data_list.append([datetime.datetime(2022, 6, 19),"Berlin","Germany","Berlin","Vienna",85,0,0,2,'Berlin 2022',[]])
data_list.append([datetime.datetime(2022, 6, 19),"Leipzig","Germany","Berlin","Vienna",6,0,0,2,'Berlin 2022',['Christian','Paulina','Mathilda','Anne-Kathrin']])
data_list.append([datetime.datetime(2022, 7, 10),"Cesky Krumlov","Czech Republic","Vienna","Vienna",125,1,-1,0,'Cesky Krumlov 2022',[]])
data_list.append([datetime.datetime(2022, 7, 10),"Ceske Budejovice","Czech Republic","Vienna","Vienna",13,1,-1,0,'Cesky Krumlov 2022',[]])
data_list.append([datetime.datetime(2022, 7, 16),"Kromeriz","Czech Republic","Vienna","Vienna",131,1,-1,0,'Kromeriz and Olomouc 2022',[]])
data_list.append([datetime.datetime(2022, 7, 16),"Olomouc","Czech Republic","Vienna","Vienna",140,1,-1,0,'Kromeriz and Olomouc 2022',[]])
data_list.append([datetime.datetime(2022, 7, 29),"Modena","Italy","Vienna","Milano",141,0,1,1,'Italy 2022',[]])
data_list.append([datetime.datetime(2022, 7, 29),"Milano","Italy","Vienna","Milano",18,0,1,1,'Italy 2022',['Riju']])
data_list.append([datetime.datetime(2022, 7, 30),"Milano","Italy","Milano","Angera",141,0,0,0,'Italy 2022',['Riju']])
data_list.append([datetime.datetime(2022, 7, 30),"Busto Arsizio","Italy","Milano","Angera",13,0,0,0,'Italy 2022',['Riju','Luke','Michela']])
data_list.append([datetime.datetime(2022, 7, 30),"Angera","Italy","Milano","Angera",13,0,1,0,'Italy 2022',['Riju']])
data_list.append([datetime.datetime(2022, 7, 30),"Angera","Italy","Milano","Angera",39,0,1,0,'Italy 2022',['Riju','Michela','Luke']])
data_list.append([datetime.datetime(2022, 7, 31),"Angera","Italy","Milano","Angera",13,0,1,0,'Italy 2022',['Riju','Michela','Luke']])
data_list.append([datetime.datetime(2022, 7, 31),"Milano","Italy","Angera","Naples",132,0,0,0,'Italy 2022',['Riju','Michela','Luke']])
data_list.append([datetime.datetime(2022, 8, 1),"Anacapri","Italy","Naples","Naples",9,0,-1,0,'Italy 2022',['Riju']])
data_list.append([datetime.datetime(2022, 8, 1),"Naples","Italy","Naples","Naples",16,0,-1,0,'Italy 2022',['Riju']])
data_list.append([datetime.datetime(2022, 8, 1),"Capri","Italy","Naples","Naples",87,0,-1,0,'Italy 2022',['Riju']])
data_list.append([datetime.datetime(2022, 8, 2),"Atrani","Italy","Naples","Naples",2,0,-1,0,'Italy 2022',[]])
data_list.append([datetime.datetime(2022, 8, 2),"Castaglione","Italy","Naples","Naples",3,0,-1,0,'Italy 2022',[]])
data_list.append([datetime.datetime(2022, 8, 2),"Ravello","Italy","Naples","Naples",147,0,-1,0,'Italy 2022',['Riju']])
data_list.append([datetime.datetime(2022, 8, 2),"Amalfi","Italy","Naples","Naples",48,0,-1,0,'Italy 2022',['Riju']])
data_list.append([datetime.datetime(2022, 8, 2),"Positano","Italy","Naples","Naples",5,0,-1,0,'Italy 2022',['Riju']])
data_list.append([datetime.datetime(2022, 8, 3),"Pompei","Italy","Naples","Milano",97,0,0,0,'Italy 2022',['Riju']])
data_list.append([datetime.datetime(2022, 8, 3),"Naples","Italy","Naples","Milano",88,0,0,0,'Italy 2022',['Riju']])
data_list.append([datetime.datetime(2022, 8, 4),"Pisa","Italy","Milano","Florence",273,0,1,0,'Italy 2022',[]])
data_list.append([datetime.datetime(2022, 8, 4),"Siena","Italy","Milano","Florence",179,0,1,0,'Italy 2022',[]])
data_list.append([datetime.datetime(2022, 8, 4),"Florence","Italy","Milano","Florence",64,0,1,0,'Italy 2022',[]])
data_list.append([datetime.datetime(2022, 8, 5),"Florence","Italy","Florence","Venice",273,0,0,0,'Italy 2022',[]])
data_list.append([datetime.datetime(2022, 8, 5),"Bologna","Italy","Florence","Venice",146,0,0,0,'Italy 2022',[]])
data_list.append([datetime.datetime(2022, 8, 5),"Venice","Italy","Florence","Venice",26,0,1,0,'Italy 2022',[]])
data_list.append([datetime.datetime(2022, 8, 6),"Venice","Italy","Venice","Milano",584,0,0,0,'Italy 2022',[]])
data_list.append([datetime.datetime(2022, 8, 7),"Parma","Italy","Milano","Vienna",158,0,0,2,'Italy 2022',[]])
data_list.append([datetime.datetime(2022, 8, 7),"Milano","Italy","Milano","Vienna",5,0,0,2,'Italy 2022',[]])
data_list.append([datetime.datetime(2022, 8, 13),"Prague","Czech Republic","Prague","Prague",24,0,-1,0,'Prague 2022',[]])
data_list.append([datetime.datetime(2022, 8, 13),"Kutna Hora","Czech Republic","Prague","Prague",153,0,-1,0,'Prague 2022',[]])
data_list.append([datetime.datetime(2022, 8, 14),"Prague","Czech Republic","Prague","Vienna",172,0,0,0,'Prague 2022',[]])
data_list.append([datetime.datetime(2022, 8, 15),"Lednice","Czech Republic","Vienna","Vienna",222,1,-1,0,'Lednice 2022',[]])
data_list.append([datetime.datetime(2022, 8, 21),"Zdar nad Sazavou","Czech Republic","Vienna","Vienna",72,1,-1,0,'Zdar nad Sazavou and Brno 2022',[]])
data_list.append([datetime.datetime(2022, 8, 21),"Brno","Czech Republic","Vienna","Vienna",144,1,-1,0,'Zdar nad Sazavou and Brno 2022',[]])
data_list.append([datetime.datetime(2022, 8, 26),"Rundale","Latvia","Riga","Riga",134,0,-1,0,'Latvia and Lithuania 2022',['Artur']])
data_list.append([datetime.datetime(2022, 8, 26),"Riga","Latvia","Riga","Riga",135,0,-1,0,'Latvia and Lithuania 2022',['Artur']])
data_list.append([datetime.datetime(2022, 8, 27),"Vilnius","Lithuania","Riga","Riga",161,0,-1,0,'Latvia and Lithuania 2022',['Artur']])
data_list.append([datetime.datetime(2022, 8, 28),"Riga","Latvia","Riga","Vienna",98,0,0,2,'Latvia and Lithuania 2022',['Artur']])
data_list.append([datetime.datetime(2022, 9, 3),"Valtice","Czech Republic","Vienna","Vienna",156,1,-1,0,'Valtice 2022',[]])
data_list.append([datetime.datetime(2022, 9, 4),"Brno","Czech Republic","Vienna","Vienna",1,1,-1,0,'Trebic 2022',[]])
data_list.append([datetime.datetime(2022, 9, 4),"Trebic","Czech Republic","Vienna","Vienna",117,1,-1,0,'Trebic 2022',[]])
data_list.append([datetime.datetime(2022, 9, 10),"Brno","Czech Republic","Vienna","Vienna",37,1,-1,0,'Litomysl 2022',[]])
data_list.append([datetime.datetime(2022, 9, 10),"Litomysl","Czech Republic","Vienna","Vienna",149,1,-1,0,'Litomysl 2022',[]])
data_list.append([datetime.datetime(2022, 9, 25),"Laxenburg","Austria","Vienna","Vienna",45,1,-1,0,'Laxenburg 2022',[]])
data_list.append([datetime.datetime(2022, 10, 8),"Eisenerz","Austria","Vienna","Vienna",118,1,-1,0,'Eisenerz 2022',[]])
data_list.append([datetime.datetime(2022, 10, 9),"Kremsmuenster","Austria","Vienna","Vienna",121,1,-1,0,'Kremsmuenster and Linz 2022',[]])
data_list.append([datetime.datetime(2022, 10, 9),"Linz","Austria","Vienna","Vienna",94,1,-1,0,'Kremsmuenster and Linz 2022',[]])
data_list.append([datetime.datetime(2022, 10, 15),"Schlierbach","Austria","Vienna","Vienna",44,1,-1,0,'Schlierbach and Steyr 2022',[]])
data_list.append([datetime.datetime(2022, 10, 15),"Steyr","Austria","Vienna","Vienna",61,1,-1,0,'Schlierbach and Steyr 2022',[]])
data_list.append([datetime.datetime(2022, 10, 16),"Hieflau","Austria","Vienna","Vienna",22,1,-1,0,'Nationalpark Gesaeuse 2022',[]])
data_list.append([datetime.datetime(2022, 10, 16),"Johnsbach","Austria","Vienna","Vienna",99,1,-1,0,'Nationalpark Gesaeuse 2022',[]])
data_list.append([datetime.datetime(2022, 10, 16),"Admont","Austria","Vienna","Vienna",6,1,-1,0,'Nationalpark Gesaeuse 2022',[]])
data_list.append([datetime.datetime(2022, 10, 29),"Bruck an der Mur","Austria","Vienna","Vienna",10,1,-1,0,'Lurgrotte & Graz 2022',[]])
data_list.append([datetime.datetime(2022, 10, 29),"Peggau","Austria","Vienna","Vienna",35,1,-1,0,'Lurgrotte & Graz 2022',[]])
data_list.append([datetime.datetime(2022, 10, 29),"Graz","Austria","Vienna","Vienna",51,1,-1,0,'Lurgrotte & Graz 2022',[]])
data_list.append([datetime.datetime(2022, 10, 29),"Semriach","Austria","Vienna","Vienna",122,1,-1,0,'Lurgrotte & Graz 2022',[]])
data_list.append([datetime.datetime(2022, 11, 2),"Katowice","Poland","Vienna","Katowice",4,0,1,0,"Warsaw 2022",[]])
data_list.append([datetime.datetime(2022, 11, 3),"Katowice","Poland","Katowice","Warsaw",1,0,0,0,"Warsaw 2022",[]])
data_list.append([datetime.datetime(2022, 11, 3),"Warsaw","Poland","Warsaw","Warsaw",409,0,-1,0,"Warsaw 2022",[]])
data_list.append([datetime.datetime(2022, 11, 4),"Warsaw","Poland","Warsaw","Warsaw",7,0,-1,0,"Warsaw 2022",[]])
data_list.append([datetime.datetime(2022, 11, 4),"Torun","Poland","Warsaw","Warsaw",193,0,-1,0,"Warsaw 2022",[]])
data_list.append([datetime.datetime(2022, 11, 5),"Warsaw","Poland","Warsaw","Warsaw",2,0,-1,0,"Warsaw 2022",[]])
data_list.append([datetime.datetime(2022, 11, 5),"Malbork","Poland","Warsaw","Warsaw",256,0,-1,0,"Warsaw 2022",[]])
data_list.append([datetime.datetime(2022, 11, 5),"Danzig","Poland","Warsaw","Warsaw",233,0,-1,0,"Warsaw 2022",[]])
data_list.append([datetime.datetime(2022, 11, 6),"Warsaw","Poland","Warsaw","Vienna",126,0,0,0,"Warsaw 2022",[]])
data_list.append([datetime.datetime(2022, 12, 2),"Cologne","Germany","Dusseldorf","Dusseldorf",337,0,-1,0,"Dusseldorf 2022",['Artur']])
data_list.append([datetime.datetime(2022, 12, 3),"Nordkirchen","Germany","Dusseldorf","Dusseldorf",36,0,-1,0,"Dusseldorf 2022",['Artur']])
data_list.append([datetime.datetime(2022, 12, 3),"Muenster","Germany","Dusseldorf","Dusseldorf",95,0,-1,0,"Dusseldorf 2022",['Artur']])
data_list.append([datetime.datetime(2022, 12, 4),"Dusseldorf","Germany","Dusseldorf","Vienna",136,0,0,2,"Dusseldorf 2022",['Artur']])
data_list.append([datetime.datetime(2022, 12, 4),"Dusseldorf","Germany","Dusseldorf","Vienna",1,0,0,2,"Dusseldorf 2022",[]])
data_list.append([datetime.datetime(2022, 12, 23),"Zuerich","Switzerland","Vienna","Lauchringen",1,1,0,0,"Lauchringen Year End 2022",[]])
data_list.append([datetime.datetime(2022, 12, 26),"Blaubeuren","Germany","Lauchringen","Lauchringen",65,0,-1,0,"Lauchringen Year End 2022",['Artur']])
data_list.append([datetime.datetime(2022, 12, 26),"Ulm","Germany","Lauchringen","Lauchringen",76,0,-1,0,"Lauchringen Year End 2022",['Artur']])
data_list.append([datetime.datetime(2022, 12, 26),"Wiblingen","Germany","Lauchringen","Lauchringen",56,0,-1,0,"Lauchringen Year End 2022",['Artur']])
data_list.append([datetime.datetime(2022, 12, 27),"Biel/Bienne","Switzerland","Lauchringen","Lauchringen",72,0,0,0,"Lauchringen Year End 2022",['Artur']])
data_list.append([datetime.datetime(2022, 12, 27),"Bern","Switzerland","Lauchringen","Lauchringen",7,0,-1,0,"Lauchringen Year End 2022",['Artur']])
data_list.append([datetime.datetime(2022, 12, 28),"Santa Maria Val Muestair","Switzerland","Lauchringen","Lauchringen",1,0,0,0,"Lauchringen Year End 2022",['Artur']])
data_list.append([datetime.datetime(2022, 12, 28),"Fuldera","Switzerland","Lauchringen","Lauchringen",1,0,-1,0,"Lauchringen Year End 2022",['Artur']])
data_list.append([datetime.datetime(2022, 12, 28),"Muestair","Switzerland","Lauchringen","Lauchringen",47,0,-1,0,"Lauchringen Year End 2022",['Artur']])
data_list.append([datetime.datetime(2022, 12, 28),"Taufers im Muenstertal","Italy","Lauchringen","Lauchringen",1,0,-1,0,"Lauchringen Year End 2022",['Artur']])
data_list.append([datetime.datetime(2022, 12, 28),"Tschierv","Switzerland","Lauchringen","Lauchringen",22,0,-1,0,"Lauchringen Year End 2022",['Artur']])
data_list.append([datetime.datetime(2022, 12, 28),"Zernez","Switzerland","Lauchringen","Lauchringen",27,0,-1,0,"Lauchringen Year End 2022",['Artur']])
data_list.append([datetime.datetime(2022, 12, 28),"Bever","Switzerland","Lauchringen","Lauchringen",2,0,-1,0,"Lauchringen Year End 2022",['Artur']])
data_list.append([datetime.datetime(2022, 12, 28),"Samedan","Switzerland","Lauchringen","Lauchringen",9,0,-1,0,"Lauchringen Year End 2022",['Artur']])
data_list.append([datetime.datetime(2022, 12, 28),"Berguen","Switzerland","Lauchringen","Lauchringen",12,0,-1,0,"Lauchringen Year End 2022",['Artur']])
data_list.append([datetime.datetime(2022, 12, 29),"Orschwiller","France","Lauchringen","Lauchringen",70,0,-1,0,"Lauchringen Year End 2022",['Artur']])
data_list.append([datetime.datetime(2022, 12, 29),"Selestat","France","Lauchringen","Lauchringen",24,0,-1,0,"Lauchringen Year End 2022",['Artur']])
data_list.append([datetime.datetime(2022, 12, 29),"Neuf-Brisach","France","Lauchringen","Lauchringen",30,0,-1,0,"Lauchringen Year End 2022",['Artur']])
data_list.append([datetime.datetime(2022, 12, 29),"Arlesheim","Switzerland","Lauchringen","Lauchringen",12,0,-1,0,"Lauchringen Year End 2022",['Artur']])
data_list.append([datetime.datetime(2022, 12, 29),"Basel","Switzerland","Lauchringen","Lauchringen",83,0,-1,0,"Lauchringen Year End 2022",['Artur']])
data_list.append([datetime.datetime(2022, 12, 30),"Sigmaringen","Germany","Lauchringen","Lauchringen",53,0,-1,0,"Lauchringen Year End 2022",['Artur']])
data_list.append([datetime.datetime(2022, 12, 30),"Lichtenstein","Germany","Lauchringen","Lauchringen",22,0,-1,0,"Lauchringen Year End 2022",['Artur']])
data_list.append([datetime.datetime(2022, 12, 30),"Hechingen","Germany","Lauchringen","Lauchringen",2,0,-1,0,"Lauchringen Year End 2022",['Artur']])
data_list.append([datetime.datetime(2022, 12, 30),"Bisingen","Germany","Lauchringen","Lauchringen",60,0,-1,0,"Lauchringen Year End 2022",['Artur']])

# %%
#2023

data_list.append([datetime.datetime(2023, 2, 14),"Munich","Germany","Vienna","Munich",2,0,0,1,'Munich AWS 2023',[]])
data_list.append([datetime.datetime(2023, 2, 15),"Munich","Germany","Munich","Munich",21,0,-1,0,'Munich AWS 2023',[]])
data_list.append([datetime.datetime(2023, 2, 25),"Blansko","Germany","Vienna","Vienna",80,1,-1,0,'Blansko and Brno 2023',['Janina','Kevin']])
data_list.append([datetime.datetime(2023, 2, 25),"Brno","Germany","Vienna","Vienna",10,1,-1,0,'Blansko and Brno 2023',['Janina','Kevin']])
data_list.append([datetime.datetime(2023, 3, 3),"Lisbon","Portugal","Lisbon","Lagos",54,0,0,0,'Portugal 2023',[]])
data_list.append([datetime.datetime(2023, 3, 4),"Lisbon","Portugal","Lisbon","Lagos",207,0,0,0,'Portugal 2023',[]])
data_list.append([datetime.datetime(2023, 3, 4),"Belem","Portugal","Lisbon","Lagos",149,0,0,0,'Portugal 2023',[]])
data_list.append([datetime.datetime(2023, 3, 4),"Tunes","Portugal","Lisbon","Lagos",1,0,1,0,'Portugal 2023',[]])
data_list.append([datetime.datetime(2023, 3, 4),"Lagos","Portugal","Lisbon","Lagos",9,0,1,0,'Portugal 2023',[]])
data_list.append([datetime.datetime(2023, 3, 5),"Portimao","Portugal","Lagos","Lagos",36,0,-1,0,'Portugal 2023',[]])
data_list.append([datetime.datetime(2023, 3, 5),"Ferragudo","Portugal","Lagos","Lagos",17,0,-1,0,'Portugal 2023',[]])
data_list.append([datetime.datetime(2023, 3, 5),"Estombar","Portugal","Lagos","Lagos",8,0,-1,0,'Portugal 2023',[]])
data_list.append([datetime.datetime(2023, 3, 5),"Corvoeiro","Portugal","Lagos","Lagos",50,0,-1,0,'Portugal 2023',[]])
data_list.append([datetime.datetime(2023, 3, 5),"Benagli","Portugal","Lagos","Lagos",12,0,-1,0,'Portugal 2023',[]])
data_list.append([datetime.datetime(2023, 3, 5),"Sagres","Portugal","Lagos","Lagos",93,0,-1,0,'Portugal 2023',[]])
data_list.append([datetime.datetime(2023, 3, 6),"Lagos","Portugal","Lagos","Lisbon",112,0,0,0,'Portugal 2023',[]])
data_list.append([datetime.datetime(2023, 3, 7),"Sintra","Portugal","Lisbon","Lisbon",202,0,-1,0,'Portugal 2023',[]])
data_list.append([datetime.datetime(2023, 3, 7),"Colares","Portugal","Lisbon","Lisbon",8,0,-1,0,'Portugal 2023',[]])
data_list.append([datetime.datetime(2023, 3, 7),"Cascais","Portugal","Lisbon","Lisbon",62,0,-1,0,'Portugal 2023',[]])
data_list.append([datetime.datetime(2023, 3, 8),"Lisbon","Portugal","Lisbon","Lisbon",158,0,-1,0,'Portugal 2023',[]])
data_list.append([datetime.datetime(2023, 3, 8),"Tomar","Portugal","Lisbon","Lisbon",136,0,-1,0,'Portugal 2023',[]])
data_list.append([datetime.datetime(2023, 3, 9),"Lisbon","Portugal","Lisbon","Lisbon",2,0,-1,0,'Portugal 2023',[]])
data_list.append([datetime.datetime(2023, 3, 9),"Mafra","Portugal","Lisbon","Lisbon",86,0,-1,0,'Portugal 2023',[]])
data_list.append([datetime.datetime(2023, 3, 9),"Queluz","Portugal","Lisbon","Lisbon",96,0,-1,0,'Portugal 2023',[]])
data_list.append([datetime.datetime(2023, 3, 9),"Sintra","Portugal","Lisbon","Lisbon",167,0,-1,0,'Portugal 2023',[]])
data_list.append([datetime.datetime(2023, 3, 10),"Porto","Portugal","Lisbon","Porto",216,0,1,0,'Portugal 2023',['Artur']])
data_list.append([datetime.datetime(2023, 3, 10),"Vila Nova de Gaia","Portugal","Lisbon","Porto",17,0,1,0,'Portugal 2023',['Artur']])
data_list.append([datetime.datetime(2023, 3, 11),"Braga","Portugal","Porto","Porto",198,0,-1,0,'Portugal 2023',['Artur']])
data_list.append([datetime.datetime(2023, 3, 11),"Mire de Tibaes","Portugal","Porto","Porto",44,0,-1,0,'Portugal 2023',['Artur']])
data_list.append([datetime.datetime(2023, 3, 11),"Porto","Portugal","Lisbon","Porto",21,0,1,0,'Portugal 2023',['Artur']])
data_list.append([datetime.datetime(2023, 3, 12),"Porto","Portugal","Porto","Porto",68,0,-1,0,'Portugal 2023',['Artur']])
data_list.append([datetime.datetime(2023, 3, 12),"Guimaraes","Portugal","Porto","Porto",110,0,-1,0,'Portugal 2023',['Artur']])
data_list.append([datetime.datetime(2023, 3, 12),"Vila Nova de Gaia","Portugal","Porto","Porto",20,0,-1,0,'Portugal 2023',['Artur']])
data_list.append([datetime.datetime(2023, 3, 13),"Santiago de Compostela","Spain","Porto","Porto",235,0,-1,0,'Portugal 2023',['Artur']])
data_list.append([datetime.datetime(2023, 3, 14),"Porto","Portugal","Porto","Coimbra",2,0,0,0,'Portugal 2023',[]])
data_list.append([datetime.datetime(2023, 3, 14),"Coimbra","Portugal","Porto","Coimbra",375,0,1,0,'Portugal 2023',[]])
data_list.append([datetime.datetime(2023, 3, 15),"Lisbon","Portugal","Coimbra","Lisbon",251,0,1,0,'Portugal 2023',[]])
data_list.append([datetime.datetime(2023, 3, 16),"Leiria","Portugal","Lisbon","Lisbon",12,0,-1,0,'Portugal 2023',[]])
data_list.append([datetime.datetime(2023, 3, 16),"Batalha","Portugal","Lisbon","Lisbon",91,0,-1,0,'Portugal 2023',[]])
data_list.append([datetime.datetime(2023, 3, 16),"Alcobaca","Portugal","Lisbon","Lisbon",118,0,-1,0,'Portugal 2023',[]])
data_list.append([datetime.datetime(2023, 3, 16),"Nazare","Portugal","Lisbon","Lisbon",50,0,-1,0,'Portugal 2023',[]])
data_list.append([datetime.datetime(2023, 3, 17),"Evora","Portugal","Lisbon","Lisbon",244,0,-1,0,'Portugal 2023',[]])
data_list.append([datetime.datetime(2023, 3, 17),"Elvas","Portugal","Lisbon","Lisbon",87,0,-1,0,'Portugal 2023',[]])
data_list.append([datetime.datetime(2023, 3, 18),"Vila Vicosa","Portugal","Lisbon","Lisbon",107,0,-1,0,'Portugal 2023',[]])
data_list.append([datetime.datetime(2023, 4, 28),"Katowice","Poland","Vienna","Katowice",25,0,1,0,'South Poland 2023',[]])
data_list.append([datetime.datetime(2023, 4, 29),"Krakow","Poland","Katowice","Katowice",438,0,-1,0,'South Poland 2023',[]])
data_list.append([datetime.datetime(2023, 4, 30),"Tarnowskie Gory","Poland","Katowice","Krakow",40,0,0,0,'South Poland 2023',[]])
data_list.append([datetime.datetime(2023, 4, 30),"Oswiecim","Poland","Katowice","Krakow",31,0,0,0,'South Poland 2023',[]])
data_list.append([datetime.datetime(2023, 4, 30),"Brzezinka","Poland","Katowice","Krakow",12,0,0,0,'South Poland 2023',[]])
data_list.append([datetime.datetime(2023, 4, 30),"Katowice","Poland","Katowice","Krakow",1,0,0,0,'South Poland 2023',[]])
data_list.append([datetime.datetime(2023, 5, 1),"Kalwaria Zebrzydowska","Poland","Krakow","Vienna",46,0,0,0,'South Poland 2023',[]])
data_list.append([datetime.datetime(2023, 5, 1),"Bugaj","Poland","Krakow","Vienna",22,0,0,0,'South Poland 2023',[]])
data_list.append([datetime.datetime(2023, 5, 1),"Brody","Poland","Krakow","Vienna",29,0,0,0,'South Poland 2023',[]])
data_list.append([datetime.datetime(2023, 5, 21),"Wilhering","Austria","Vienna","Vienna",49,1,-1,0,'Wilhering, Lambach & Wels 2023',[]])
data_list.append([datetime.datetime(2023, 5, 21),"Lambach","Austria","Vienna","Vienna",49,1,-1,0,'Wilhering, Lambach & Wels 2023',[]])
data_list.append([datetime.datetime(2023, 5, 21),"Wels","Austria","Vienna","Vienna",25,1,-1,0,'Wilhering, Lambach & Wels 2023',[]])
data_list.append([datetime.datetime(2023, 6, 3),"Stockholm","Sweden","Stockholm","Stockholm",59,0,-1,0,'Sweden I 2023',[]])
data_list.append([datetime.datetime(2023, 6, 3),"Vaesteras","Sweden","Stockholm","Stockholm",1,0,-1,0,'Sweden I 2023',[]])
data_list.append([datetime.datetime(2023, 6, 3),"Aengelsberg","Sweden","Stockholm","Stockholm",52,0,-1,0,'Sweden I 2023',[]])
data_list.append([datetime.datetime(2023, 6, 3),"Stockholm","Sweden","Stockholm","Stockholm",9,0,-1,0,'Sweden I 2023',['Rickard']])
data_list.append([datetime.datetime(2023, 6, 4),"Stockholm","Sweden","Stockholm","Stockholm",188,0,-1,0,'Sweden I 2023',['Rickard']])
data_list.append([datetime.datetime(2023, 6, 4),"Ulriksdal","Sweden","Stockholm","Stockholm",38,0,-1,0,'Sweden I 2023',['Rickard']])
data_list.append([datetime.datetime(2023, 6, 4),"Rosersberg","Sweden","Stockholm","Stockholm",64,0,-1,0,'Sweden I 2023',['Rickard']])
data_list.append([datetime.datetime(2023, 6, 5),"Falun","Sweden","Stockholm","Stockholm",70,0,-1,0,'Sweden I 2023',[]])
data_list.append([datetime.datetime(2023, 6, 5),"Uppsala","Sweden","Stockholm","Stockholm",114,0,-1,0,'Sweden I 2023',[]])
data_list.append([datetime.datetime(2023, 6, 6),"Solna","Sweden","Stockholm","Vienna",53,0,0,1,'Sweden I 2023',[]])
data_list.append([datetime.datetime(2023, 6, 6),"Drottningholm","Sweden","Stockholm","Vienna",183,0,0,1,'Sweden I 2023',[]])
data_list.append([datetime.datetime(2023, 6, 6),"Stockholm-Arlanda","Sweden","Stockholm","Vienna",1,0,0,1,'Sweden I 2023',[]])
data_list.append([datetime.datetime(2023, 6, 23),"Sofia","Bulgarien","Sofia","Vienna",30,0,1,2,'Bulgaria 2023',[]])
data_list.append([datetime.datetime(2023, 6, 24),"Sofia","Bulgarien","Sofia","Sofia",40,0,-1,0,'Bulgaria 2023',[]])
data_list.append([datetime.datetime(2023, 6, 24),"Rilski Manastir","Bulgarien","Sofia","Sofia",118,0,-1,0,'Bulgaria 2023',[]])
data_list.append([datetime.datetime(2023, 6, 25),"Sofia","Bulgarien","Sofia","Sofia",8,0,-1,0,'Bulgaria 2023',[]])
data_list.append([datetime.datetime(2023, 6, 25),"Plovdiv","Bulgarien","Sofia","Sofia",147,0,-1,0,'Bulgaria 2023',[]])
data_list.append([datetime.datetime(2023, 6, 25),"Bachkovo","Bulgarien","Sofia","Sofia",87,0,-1,0,'Bulgaria 2023',[]])
data_list.append([datetime.datetime(2023, 6, 26),"Sofia","Bulgarien","Sofia","Vienna",112,0,0,1,'Bulgaria 2023',[]])
data_list.append([datetime.datetime(2023, 7, 22),"Copenhagen","Denmark","Copenhagen","Copenhagen",51,0,-1,0,'Denmark & Sweden 2023',[]])
data_list.append([datetime.datetime(2023, 7, 22),"Lyngby","Denmark","Copenhagen","Copenhagen",42,0,-1,0,'Denmark & Sweden 2023',[]])
data_list.append([datetime.datetime(2023, 7, 22),"Klampenborg","Denmark","Copenhagen","Copenhagen",5,0,-1,0,'Denmark & Sweden 2023',[]])
data_list.append([datetime.datetime(2023, 7, 22),"Koege","Denmark","Copenhagen","Copenhagen",1,0,-1,0,'Denmark & Sweden 2023',[]])
data_list.append([datetime.datetime(2023, 7, 22),"Roedvig","Denmark","Copenhagen","Copenhagen",40,0,-1,0,'Denmark & Sweden 2023',[]])
data_list.append([datetime.datetime(2023, 7, 22),"Hoejerup","Denmark","Copenhagen","Copenhagen",16,0,-1,0,'Denmark & Sweden 2023',[]])
data_list.append([datetime.datetime(2023, 7, 23),"Copenhagen","Denmark","Copenhagen","Vienna",1,0,0,1,'Denmark & Sweden 2023',[]])
data_list.append([datetime.datetime(2023, 7, 23),"Helsingor","Denmark","Copenhagen","Vienna",116,0,0,1,'Denmark & Sweden 2023',[]])
data_list.append([datetime.datetime(2023, 7, 23),"Helsinborg","Sweden","Copenhagen","Vienna",6,0,0,1,'Denmark & Sweden 2023',[]])
data_list.append([datetime.datetime(2023, 7, 23),"Lund","Sweden","Copenhagen","Vienna",48,0,0,1,'Denmark & Sweden 2023',[]])
data_list.append([datetime.datetime(2023, 7, 23),"Malmoe","Sweden","Copenhagen","Vienna",24,0,0,1,'Denmark & Sweden 2023',[]])
data_list.append([datetime.datetime(2023, 8, 12),"Weimar","Germany","Frankfurt","Frankfurt",112,0,-1,0,'Germany 2023',[]])
data_list.append([datetime.datetime(2023, 8, 12),"Erfurt","Germany","Frankfurt","Frankfurt",91,0,-1,0,'Germany 2023',[]])
data_list.append([datetime.datetime(2023, 8, 12),"Naumburg","Germany","Frankfurt","Frankfurt",99,0,-1,0,'Germany 2023',[]])
data_list.append([datetime.datetime(2023, 8, 13),"Niederheimbach","Germany","Frankfurt","Frankfurt",1,0,-1,0,'Germany 2023',[]])
data_list.append([datetime.datetime(2023, 8, 13),"Bruehl","Germany","Frankfurt","Frankfurt",219,0,-1,0,'Germany 2023',[]])
data_list.append([datetime.datetime(2023, 8, 13),"Boppard","Germany","Frankfurt","Frankfurt",41,0,-1,0,'Germany 2023',[]])
data_list.append([datetime.datetime(2023, 8, 13),"St Goar","Germany","Frankfurt","Frankfurt",82,0,-1,0,'Germany 2023',[]])
data_list.append([datetime.datetime(2023, 8, 13),"Oberwesel","Germany","Frankfurt","Frankfurt",1,0,-1,0,'Germany 2023',[]])
data_list.append([datetime.datetime(2023, 8, 13),"Bacharach","Germany","Frankfurt","Frankfurt",30,0,-1,0,'Germany 2023',[]])
data_list.append([datetime.datetime(2023, 8, 13),"Frankfurt","Germany","Frankfurt","Frankfurt",8,0,-1,0,'Germany 2023',[]])
data_list.append([datetime.datetime(2023, 8, 14),"Messel","Germany","Frankfurt","Frankfurt",28,0,-1,0,'Germany 2023',[]])
data_list.append([datetime.datetime(2023, 8, 14),"Bad Ems","Germany","Frankfurt","Frankfurt",49,0,-1,0,'Germany 2023',[]])
data_list.append([datetime.datetime(2023, 8, 14),"Limburg","Germany","Frankfurt","Frankfurt",59,0,-1,0,'Germany 2023',[]])
data_list.append([datetime.datetime(2023, 8, 15),"Kassel","Germany","Frankfurt","Vienna",55,0,0,1,'Germany 2023',[]])
data_list.append([datetime.datetime(2023, 8, 15),"Wuerzburg","Germany","Frankfurt","Vienna",167,0,0,1,'Germany 2023',[]])
data_list.append([datetime.datetime(2023, 8, 15),"Frankfurt","Germany","Frankfurt","Vienna",49,0,0,1,'Germany 2023',[]])
data_list.append([datetime.datetime(2023, 8, 25),"Banska Stiavnica","Slovakia","Vienna","Banska Stiavnica",43,0,1,0,'Slovakia, Poland, Hungary and Austria 2023',['Artur']])
data_list.append([datetime.datetime(2023, 8, 26),"Banska Stiavnica","Slovakia","Banska Stiavnica","Spisska Kapitula",20,0,0,0,'Slovakia, Poland, Hungary and Austria 2023',['Artur']])
data_list.append([datetime.datetime(2023, 8, 26),"Banska Stiavnica","Slovakia","Banska Stiavnica","Spisska Kapitula",43,0,0,0,'Slovakia, Poland, Hungary and Austria 2023',[]])
data_list.append([datetime.datetime(2023, 8, 26),"Banska Bela","Slovakia","Banska Stiavnica","Spisska Kapitula",1,0,0,0,'Slovakia, Poland, Hungary and Austria 2023',['Artur']])
data_list.append([datetime.datetime(2023, 8, 26),"Hronsek","Slovakia","Banska Stiavnica","Spisska Kapitula",23,0,0,0,'Slovakia, Poland, Hungary and Austria 2023',['Artur']])
data_list.append([datetime.datetime(2023, 8, 26),"Donovaly","Slovakia","Banska Stiavnica","Spisska Kapitula",1,0,0,0,'Slovakia, Poland, Hungary and Austria 2023',['Artur']])
data_list.append([datetime.datetime(2023, 8, 26),"Vlkolinec","Slovakia","Banska Stiavnica","Spisska Kapitula",21,0,0,0,'Slovakia, Poland, Hungary and Austria 2023',['Artur']])
data_list.append([datetime.datetime(2023, 8, 26),"Likavka","Slovakia","Banska Stiavnica","Spisska Kapitula",17,0,0,0,'Slovakia, Poland, Hungary and Austria 2023',[]])
data_list.append([datetime.datetime(2023, 8, 26),"Likavka","Slovakia","Banska Stiavnica","Spisska Kapitula",1,0,0,0,'Slovakia, Poland, Hungary and Austria 2023',['Artur']])
data_list.append([datetime.datetime(2023, 8, 26),"Spisska Kapitula","Slovakia","Banska Stiavnica","Spisska Kapitula",8,0,1,0,'Slovakia, Poland, Hungary and Austria 2023',['Artur']])
data_list.append([datetime.datetime(2023, 8, 27),"Spisska Kapitula","Slovakia","Spisska Kapitula","Spisska Kapitula",10,0,-1,0,'Slovakia, Poland, Hungary and Austria 2023',['Artur']])
data_list.append([datetime.datetime(2023, 8, 27),"Bardejov","Slovakia","Spisska Kapitula","Spisska Kapitula",42,0,-1,0,'Slovakia, Poland, Hungary and Austria 2023',['Artur']])
data_list.append([datetime.datetime(2023, 8, 27),"Kwiaton","Poland","Spisska Kapitula","Spisska Kapitula",3,0,-1,0,'Slovakia, Poland, Hungary and Austria 2023',['Artur']])
data_list.append([datetime.datetime(2023, 8, 27),"Brunary","Poland","Spisska Kapitula","Spisska Kapitula",8,0,-1,0,'Slovakia, Poland, Hungary and Austria 2023',['Artur']])
data_list.append([datetime.datetime(2023, 8, 27),"Sekowa","Poland","Spisska Kapitula","Spisska Kapitula",10,0,-1,0,'Slovakia, Poland, Hungary and Austria 2023',['Artur']])
data_list.append([datetime.datetime(2023, 8, 27),"Owczary","Poland","Spisska Kapitula","Spisska Kapitula",14,0,-1,0,'Slovakia, Poland, Hungary and Austria 2023',['Artur']])
data_list.append([datetime.datetime(2023, 8, 27),"Binarowa","Poland","Spisska Kapitula","Spisska Kapitula",18,0,-1,0,'Slovakia, Poland, Hungary and Austria 2023',['Artur']])
data_list.append([datetime.datetime(2023, 8, 27),"Hervartov","Poland","Spisska Kapitula","Spisska Kapitula",2,0,-1,0,'Slovakia, Poland, Hungary and Austria 2023',['Artur']])
data_list.append([datetime.datetime(2023, 8, 27),"Spisske Podhradie","Slovakia","Spisska Kapitula","Spisska Kapitula",5,0,-1,0,'Slovakia, Poland, Hungary and Austria 2023',['Artur']])
data_list.append([datetime.datetime(2023, 8, 28),"Spisske Podhradie","Slovakia","Spisska Kapitula","Kosice",1,0,0,0,'Slovakia, Poland, Hungary and Austria 2023',['Artur']])
data_list.append([datetime.datetime(2023, 8, 28),"Spisska Kapitula","Slovakia","Spisska Kapitula","Kosice",45,0,0,0,'Slovakia, Poland, Hungary and Austria 2023',['Artur']])
data_list.append([datetime.datetime(2023, 8, 28),"Zehra","Slovakia","Spisska Kapitula","Kosice",63,0,0,0,'Slovakia, Poland, Hungary and Austria 2023',['Artur']])
data_list.append([datetime.datetime(2023, 8, 28),"Levoca","Slovakia","Spisska Kapitula","Kosice",35,0,0,0,'Slovakia, Poland, Hungary and Austria 2023',['Artur']])
data_list.append([datetime.datetime(2023, 8, 28),"Kosice","Slovakia","Spisska Kapitula","Kosice",76,0,0,1,'Slovakia, Poland, Hungary and Austria 2023',['Artur']])
data_list.append([datetime.datetime(2023, 8, 29),"Kosice","Slovakia","Kosice","Roznava",1,0,0,1,'Slovakia, Poland, Hungary and Austria 2023',['Artur']])
data_list.append([datetime.datetime(2023, 8, 29),"Jasov","Slovakia","Kosice","Roznava",120,0,0,0,'Slovakia, Poland, Hungary and Austria 2023',['Artur']])
data_list.append([datetime.datetime(2023, 8, 29),"Ochtina","Slovakia","Kosice","Roznava",76,0,0,1,'Slovakia, Poland, Hungary and Austria 2023',['Artur']])
data_list.append([datetime.datetime(2023, 8, 29),"Stitnik","Slovakia","Kosice","Roznava",17,0,0,1,'Slovakia, Poland, Hungary and Austria 2023',['Artur']])
data_list.append([datetime.datetime(2023, 8, 29),"Dobsina","Slovakia","Kosice","Roznava",41,0,0,1,'Slovakia, Poland, Hungary and Austria 2023',[]])
data_list.append([datetime.datetime(2023, 8, 29),"Dobsina","Slovakia","Kosice","Roznava",1,0,0,1,'Slovakia, Poland, Hungary and Austria 2023',['Artur']])
data_list.append([datetime.datetime(2023, 8, 29),"Roznava","Slovakia","Kosice","Roznava",6,0,0,1,'Slovakia, Poland, Hungary and Austria 2023',['Artur']])
data_list.append([datetime.datetime(2023, 8, 30),"Roznava","Slovakia","Roznava","Tokaj",1,0,0,0,'Slovakia, Poland, Hungary and Austria 2023',['Artur']])
data_list.append([datetime.datetime(2023, 8, 30),"Kecovo","Slovakia","Roznava","Tokaj",105,0,0,0,'Slovakia, Poland, Hungary and Austria 2023',['Artur']])
data_list.append([datetime.datetime(2023, 8, 30),"Aggtelek","Hungary","Roznava","Tokaj",240,0,0,0,'Slovakia, Poland, Hungary and Austria 2023',['Artur']])
data_list.append([datetime.datetime(2023, 8, 30),"Tokaj","Hungary","Roznava","Tokaj",7,0,1,0,'Slovakia, Poland, Hungary and Austria 2023',['Artur']])
data_list.append([datetime.datetime(2023, 8, 31),"Tokaj","Hungary","Tokaj","Tokaj",39,0,-1,0,'Slovakia, Poland, Hungary and Austria 2023',['Artur']])
data_list.append([datetime.datetime(2023, 8, 31),"Hortobagy","Hungary","Tokaj","Tokaj",11,0,-1,0,'Slovakia, Poland, Hungary and Austria 2023',['Artur']])
data_list.append([datetime.datetime(2023, 8, 31),"Nagyhegyes","Hungary","Tokaj","Tokaj",3,0,-1,0,'Slovakia, Poland, Hungary and Austria 2023',['Artur']])
data_list.append([datetime.datetime(2023, 8, 31),"Debrecen","Hungary","Tokaj","Tokaj",6,0,-1,0,'Slovakia, Poland, Hungary and Austria 2023',['Artur']])
data_list.append([datetime.datetime(2023, 8, 31),"Nyiregyhaza","Hungary","Tokaj","Tokaj",7,0,-1,0,'Slovakia, Poland, Hungary and Austria 2023',['Artur']])
data_list.append([datetime.datetime(2023, 9, 1),"Visegrad","Hungary","Tokaj","Dunaujvaros",7,0,0,1,'Slovakia, Poland, Hungary and Austria 2023',['Artur']])
data_list.append([datetime.datetime(2023, 9, 1),"Esztergom","Hungary","Tokaj","Dunaujvaros",26,0,0,1,'Slovakia, Poland, Hungary and Austria 2023',['Artur']])
data_list.append([datetime.datetime(2023, 9, 1),"Sturovo","Hungary","Tokaj","Dunaujvaros",2,0,0,1,'Slovakia, Poland, Hungary and Austria 2023',['Artur']])
data_list.append([datetime.datetime(2023, 9, 1),"Donaujvaros","Hungary","Tokaj","Dunaujvaros",1,0,0,1,'Slovakia, Poland, Hungary and Austria 2023',['Artur']])
data_list.append([datetime.datetime(2023, 9, 2),"Pecs","Hungary","Keszthely","Dunaujvaros",109,0,0,0,'Slovakia, Poland, Hungary and Austria 2023',['Artur']])
data_list.append([datetime.datetime(2023, 9, 2),"Keszthely","Hungary","Dunaujvaros","Keszthely",55,0,0,0,'Slovakia, Poland, Hungary and Austria 2023',['Artur']])
data_list.append([datetime.datetime(2023, 9, 3),"Heviz","Hungary","Dunaujvaros","Keszthely",55,0,0,0,'Slovakia, Poland, Hungary and Austria 2023',['Artur']])
data_list.append([datetime.datetime(2023, 9, 3),"Graz","Austria","Keszthely","Schladming",102,0,1,0,'Slovakia, Poland, Hungary and Austria 2023',['Artur']])
data_list.append([datetime.datetime(2023, 9, 3),"Schladming","Austria","Keszthely","Schladming",9,0,1,0,'Slovakia, Poland, Hungary and Austria 2023',['Artur']])
data_list.append([datetime.datetime(2023, 9, 4),"Schladming","Austria","Schladming","Vienna",2,0,1,0,'Slovakia, Poland, Hungary and Austria 2023',['Artur']])
data_list.append([datetime.datetime(2023, 9, 4),"Ramsau am Dachstein",'Austria',"Schladming","Vienna",13,0,1,0,'Slovakia, Poland, Hungary and Austria 2023',['Artur']])
data_list.append([datetime.datetime(2023, 9, 4),"Obertraun",'Austria',"Schladming","Vienna",100,0,1,0,'Slovakia, Poland, Hungary and Austria 2023',['Artur']])
data_list.append([datetime.datetime(2023, 9, 4),"Oberscheffau",'Austria',"Schladming","Vienna",58,0,1,0,'Slovakia, Poland, Hungary and Austria 2023',['Artur']])
data_list.append([datetime.datetime(2023, 9, 4),"Golling an der Salzach","Austria","Schladming","Vienna",6,1,1,0,'Slovakia, Poland, Hungary and Austria 2023',['Artur']])
data_list.append([datetime.datetime(2023, 9, 4),"Golling an der Salzach","Austria","Schladming","Vienna",10,1,1,0,'Slovakia, Poland, Hungary and Austria 2023',[]])
data_list.append([datetime.datetime(2023, 9, 4),"Salzburg","Austria","Schladming","Vienna",61,1,1,0,'Slovakia, Poland, Hungary and Austria 2023',['Artur']])
data_list.append([datetime.datetime(2023, 9, 4),"Salzburg","Austria","Schladming","Vienna",8,1,1,0,'Slovakia, Poland, Hungary and Austria 2023',[]])
data_list.append([datetime.datetime(2023, 9, 9),"Telc","Czech Republic","Vienna","Vienna",155,1,-1,0,'Telc 2023',['Grace C']])
data_list.append([datetime.datetime(2023, 9, 24),"Vranov nad Dyji","Czech Republic","Vienna","Vienna",118,1,-1,0,'Vranov nad Dyji and Znojmo 2023',[]])
data_list.append([datetime.datetime(2023, 9, 24),"Znojmo","Czech Republic","Vienna","Vienna",64,1,-1,0,'Vranov nad Dyji and Znojmo 2023',[]])
data_list.append([datetime.datetime(2023, 10, 1),"Trencin","Slovakia","Vienna","Vienna",111,0,-1,0,'Trencin 2023',['Bing']])
data_list.append([datetime.datetime(2023, 10, 26),"Nynaeshamn","Sweden","Stockholm","Visby",4,0,0,0,'Sweden II 2023',[]])
data_list.append([datetime.datetime(2023, 10, 26),"Schweden","Sweden","Stockholm","Visby",2,0,0,0,'Sweden II 2023',[]])
data_list.append([datetime.datetime(2023, 10, 26),"Visby","Sweden","Stockholm","Visby",186,0,1,0,'Sweden II 2023',[]])
data_list.append([datetime.datetime(2023, 10, 27),"Visby","Sweden","Visby","Solna",143,0,0,0,'Sweden II 2023',[]])
data_list.append([datetime.datetime(2023, 10, 27),"Solna","Sweden","Visby","Solna",1,0,1,0,'Sweden II 2023',[]])
data_list.append([datetime.datetime(2023, 10, 28),"Solna","Sweden","Solna","Solna",1,0,-1,0,'Sweden II 2023',[]])
data_list.append([datetime.datetime(2023, 10, 28),"Stockholm","Sweden","Solna","Solna",60,0,-1,0,'Sweden II 2023',[]])
data_list.append([datetime.datetime(2023, 10, 28),"Stockholm","Sweden","Solna","Solna",74,0,-1,0,'Sweden II 2023',['Rebeca', 'Elias']])
data_list.append([datetime.datetime(2023, 10, 28),"Stockholm","Sweden","Solna","Solna",41,0,-1,0,'Sweden II 2023',['Rickard','Tony']])
data_list.append([datetime.datetime(2023, 10, 29),"Solna","Sweden","Solna","Karlskrona",1,0,0,0,'Sweden II 2023',[]])
data_list.append([datetime.datetime(2023, 10, 29),"Stockholm","Sweden","Solna","Karlskrona",95,0,0,0,'Sweden II 2023',[]])
data_list.append([datetime.datetime(2023, 10, 30),"Karlskrona","Sweden","Karlskrona","Kalmar",168,0,0,0,'Sweden II 2023',[]])
data_list.append([datetime.datetime(2023, 10, 30),"Kalmar","Sweden","Karlskrona","Kalmar",8,0,1,0,'Sweden II 2023',[]])
data_list.append([datetime.datetime(2023, 10, 31),"Moerbylanga","Sweden","Kalmar","Stockholm-Arlanda",16,0,0,0,'Sweden II 2023',[]])
data_list.append([datetime.datetime(2023, 10, 31),"Kalmar","Sweden","Kalmar","Stockholm-Arlanda",85,0,0,0,'Sweden II 2023',[]])
data_list.append([datetime.datetime(2023, 11, 11),"Leopoldov","Slovakia","Vienna","Vienna",2,0,-1,0,'Nitra and Trnava 2023',[]])
data_list.append([datetime.datetime(2023, 11, 11),"Nitra","Slovakia","Vienna","Vienna",34,0,-1,0,'Nitra and Trnava 2023',[]])
data_list.append([datetime.datetime(2023, 11, 11),"Trnava","Slovakia","Vienna","Vienna",42,0,-1,0,'Nitra and Trnava 2023',[]])
data_list.append([datetime.datetime(2023, 12, 8),"La Chaux-de-Fonds","Switzerland","St-Genis-Pouilly","St-Genis-Pouilly",60,0,-1,0,'St-Genis-Pouilly 2023',[]])
data_list.append([datetime.datetime(2023, 12, 8),"Payerne","Switzerland","St-Genis-Pouilly","St-Genis-Pouilly",69,0,-1,0,'St-Genis-Pouilly 2023',[]])
data_list.append([datetime.datetime(2023, 12, 9),"Lyon","France","St-Genis-Pouilly","St-Genis-Pouilly",239,0,-1,0,'St-Genis-Pouilly 2023',['Bing','Sasha']])
data_list.append([datetime.datetime(2023, 12, 10),"St-Genis-Pouilly","France","St-Genis-Pouilly","Vienna",239,0,0,1,'St-Genis-Pouilly 2023',['Bing','Sasha']])
data_list.append([datetime.datetime(2023, 12, 10),"Geneva","Switzerland","St-Genis-Pouilly","Vienna",8,0,0,1,'St-Genis-Pouilly 2023',[]])
data_list.append([datetime.datetime(2023, 12, 10),"Geneva","Switzerland","St-Genis-Pouilly","Vienna",25,0,0,1,'St-Genis-Pouilly 2023',['Kostas','Eleni']])
data_list.append([datetime.datetime(2023,12,22),"Zuerich","Switzerland","Vienna","Lauchringen",3,0,1,1,"Christmas & New Year 2023",[]])
data_list.append([datetime.datetime(2023,12,25),"Lauchringen","Germany","Lauchringen","Lauchringen",1,0,-1,1,"Christmas & New Year 2023",['Artur','Hannsjoerg','Jennet']])
data_list.append([datetime.datetime(2023,12,25),"St Blasien","Germany","Lauchringen","Lauchringen",13,0,-1,1,"Christmas & New Year 2023",['Artur','Hannsjoerg','Jennet']])
data_list.append([datetime.datetime(2023,12,25),"Todtmoos","Germany","Lauchringen","Lauchringen",16,0,-1,1,"Christmas & New Year 2023",['Artur','Hannsjoerg','Jennet']])
data_list.append([datetime.datetime(2023,12,26),"Reichenau","Germany","Lauchringen","Lauchringen",46,0,-1,1,"Christmas & New Year 2023",['Artur','Hannsjoerg','Jennet']])
data_list.append([datetime.datetime(2023,12,26),"Konstanz","Germany","Lauchringen","Lauchringen",36,0,-1,1,"Christmas & New Year 2023",['Artur','Hannsjoerg','Jennet']])
data_list.append([datetime.datetime(2023,12,26),"Stein am Rhein","Switzerland","Lauchringen","Lauchringen",33,0,-1,1,"Christmas & New Year 2023",['Artur','Hannsjoerg','Jennet']])
data_list.append([datetime.datetime(2023,12,28),"Nuernberg","Germany","Nuernberg","Lauchringen",46,0,1,1,'Christmas & New Year 2023',['Artur',"Hannsjoerg","Jennet"]])
data_list.append([datetime.datetime(2023,12,29),"Nuernberg","Germany","Nuernberg","Nuernberg",218,0,1,1,'Christmas & New Year 2023',['Artur',"Hannsjoerg","Jennet"]])
data_list.append([datetime.datetime(2023,12,29),"Nuernberghttp://localhost:8888/notebooks/picture_TripDays.ipynb#","Germany","Nuernberg","Nuernberg",16,0,-1,1,'Christmas & New Year 2023',['Artur']])
data_list.append([datetime.datetime(2023,12,29),"Nuernberg","Germany","Nuernberg","Nuernberg",9,0,-1,1,'Christmas & New Year 2023',["Hannsjoerg","Jennet"]])
data_list.append([datetime.datetime(2023,12,30),"Bayreuth","Germany","Nuernberg","Leipzig",105,0,0,1,'Christmas & New Year 2023',["Hannsjoerg","Jennet"]])
data_list.append([datetime.datetime(2023,12,31),"Leipzig","Germany","Leipzig","Leipzig",23,0,-1,1,'Christmas & New Year 2023',["Hannsjoerg","Jennet"]])

# %%
data_list.append([datetime.datetime(2024,1,1),"Prague","Czech Republic","Leipzig","Vienna",144,0,0,1,'Christmas & New Year 2023',[]])
data_list.append([datetime.datetime(2024, 1, 25),"Trento","Italy","Bozen",'Verona',219,0,0,0,'Northern Italy 2024',[]])
data_list.append([datetime.datetime(2024, 1, 25),"Brixen","Italy","Bozen",'Verona',119,0,0,0,'Northern Italy 2024',[]])
data_list.append([datetime.datetime(2024, 1, 25),"Bozen","Italy","Bozen",'Verona',25,0,0,0,'Northern Italy 2024',[]])
data_list.append([datetime.datetime(2024, 1, 26),"Padua","Italy","Verona",'Verona',394,0,-1,0,'Northern Italy 2024',[]])
data_list.append([datetime.datetime(2024, 1, 27),"Verona","Italy","Verona",'Bozen',476,0,0,0,'Northern Italy 2024',[]])
data_list.append([datetime.datetime(2024, 1, 28),"Bozen","Italy","Bozen",'Vienna',82,0,0,0,'Northern Italy 2024',[]])
data_list.append([datetime.datetime(2024, 1, 28),"Steinach am Brenner","Italy","Bozen",'Vienna',3,0,0,0,'Northern Italy 2024',[]])
data_list.append([datetime.datetime(2024, 1, 28),"Matrei am Brenner","Italy","Bozen",'Vienna',1,0,0,0,'Northern Italy 2024',[]])
data_list.append([datetime.datetime(2024, 1, 28),"Innsbruck","Austria","Bozen",'Vienna',8,0,0,0,'Northern Italy 2024',[]])
data_list.append([datetime.datetime(2024, 1, 28),"Rum","Austria","Bozen",'Vienna',2,0,0,0,'Northern Italy 2024',[]])
data_list.append([datetime.datetime(2024, 1, 28),"Hall in Tirol","Austria","Bozen",'Vienna',1,0,0,0,'Northern Italy 2024',[]])
data_list.append([datetime.datetime(2024, 2, 17),"Ferrara","Italy","Venice","Venice",317,0,-1,0,'Veneto 2024',[]])
data_list.append([datetime.datetime(2024, 2, 18),"Vicenza","Italy","Venice","Venice",337,0,-1,0,'Veneto 2024',[]])
data_list.append([datetime.datetime(2024, 2, 18),"Caldogno","Italy","Venice","Venice",59,0,-1,0,'Veneto 2024',[]])
data_list.append([datetime.datetime(2024, 2, 19),"Ravenna","Italy","Venice","Venice",291,0,-1,0,'Veneto 2024',[]])
data_list.append([datetime.datetime(2024, 2, 19),"Classe","Italy","Venice","Venice",31,0,-1,0,'Veneto 2024',[]])
data_list.append([datetime.datetime(2024, 2, 19),"Venice","Italy","Venice","Vienna",287,0,0,0,'Veneto 2024',[]])
data_list.append([datetime.datetime(2024, 3, 23),"Gratwein","Austria","Vienna","Vienna",1,0,-1,1,'Rein & Leoben 2024',[]])
data_list.append([datetime.datetime(2024, 3, 23),"Rein","Austria","Vienna","Vienna",67,0,-1,1,'Rein & Leoben 2024',[]])
data_list.append([datetime.datetime(2024, 3, 23),"Leoben","Austria","Vienna","Vienna",21,0,-1,1,'Rein & Leoben 2024',[]])
data_list.append([datetime.datetime(2024, 3, 23),"Goess","Austria","Vienna","Vienna",15,0,-1,1,'Rein & Leoben 2024',[]])
data_list.append([datetime.datetime(2024, 3, 31),"Thessaloniki","Greece","Vienna","Thessaloniki",86,0,1,2,'Greece & North Macedonia 2024',['Artur']])
data_list.append([datetime.datetime(2024, 4, 1),"Thessaloniki","Greece","Thessaloniki","Thessaloniki",1,0,-1,0,'Greece & North Macedonia 2024',['Artur']])
data_list.append([datetime.datetime(2024, 4, 1),"Kavala","Greece","Thessaloniki","Thessaloniki",33,0,-1,0,'Greece & North Macedonia 2024',['Artur']])
data_list.append([datetime.datetime(2024, 4, 1),"Krenides","Greece","Thessaloniki","Thessaloniki",75,0,-1,0,'Greece & North Macedonia 2024',['Artur']])
data_list.append([datetime.datetime(2024, 4, 2),"Vergina","Greece","Thessaloniki","Thessaloniki",75,0,-1,0,'Greece & North Macedonia 2024',['Artur']])
data_list.append([datetime.datetime(2024, 4, 2),"Edessa","Greece","Thessaloniki","Thessaloniki",39,0,-1,0,'Greece & North Macedonia 2024',['Artur']])
data_list.append([datetime.datetime(2024, 4, 2),"Palitatsia","Greece","Thessaloniki","Thessaloniki",16,0,-1,0,'Greece & North Macedonia 2024',['Artur']])
data_list.append([datetime.datetime(2024, 4, 2),"Thessaloniki","Greece","Thessaloniki","Thessaloniki",1,0,-1,0,'Greece & North Macedonia 2024',['Artur']])
data_list.append([datetime.datetime(2024, 4, 3),"Evzonoi","Greece","Thessaloniki","Skopje",1,0,0,0,'Greece & North Macedonia 2024',['Artur']])
data_list.append([datetime.datetime(2024, 4, 3),"Gevgelija","North Macedonia","Thessaloniki","Skopje",2,0,0,0,'Greece & North Macedonia 2024',['Artur']])
data_list.append([datetime.datetime(2024, 4, 3),"Demir Kapija","North Macedonia","Thessaloniki","Skopje",1,0,0,0,'Greece & North Macedonia 2024',['Artur']])
data_list.append([datetime.datetime(2024, 4, 3),"Bashino Selo","North Macedonia","Thessaloniki","Skopje",1,0,0,0,'Greece & North Macedonia 2024',['Artur']])
data_list.append([datetime.datetime(2024, 4, 3),"Otovitsa","North Macedonia","Thessaloniki","Skopje",2,0,1,0,'Greece & North Macedonia 2024',['Artur']])
data_list.append([datetime.datetime(2024, 4, 3),"North Macedonia","North Macedonia","Thessaloniki","Skopje",5,0,1,0,'Greece & North Macedonia 2024',['Artur']])
data_list.append([datetime.datetime(2024, 4, 3),"Matka","North Macedonia","Thessaloniki","Skopje",89,0,1,0,'Greece & North Macedonia 2024',['Artur']])
data_list.append([datetime.datetime(2024, 4, 3),"Skopje","North Macedonia","Thessaloniki","Skopje",26,0,1,0,'Greece & North Macedonia 2024',['Artur']])
data_list.append([datetime.datetime(2024, 4, 4),"Tetovo","North Macedonia","Skopje","Skopje",2,0,-1,0,'Greece & North Macedonia 2024',['Artur']])
data_list.append([datetime.datetime(2024, 4, 4),"Ohrid","North Macedonia","Skopje","Skopje",131,0,-1,0,'Greece & North Macedonia 2024',['Artur']])
data_list.append([datetime.datetime(2024, 4, 4),"Skopje","North Macedonia","Skopje","Skopje",6,0,-1,0,'Greece & North Macedonia 2024',['Artur']])
data_list.append([datetime.datetime(2024, 4, 5),"Skopje","North Macedonia","Skopje","Thessaloniki",109,0,0,0,'Greece & North Macedonia 2024',['Artur']])
data_list.append([datetime.datetime(2024, 4, 5),"North Macedonia","North Macedonia","Skopje","Thessaloniki",4,0,0,0,'Greece & North Macedonia 2024',['Artur']])
data_list.append([datetime.datetime(2024, 4, 6),"Thessaloniki","Greece","Thessaloniki","Kalambaka",47,0,0,0,'Greece & North Macedonia 2024',[]])
data_list.append([datetime.datetime(2024, 4, 6),"Thessaloniki","Greece","Thessaloniki","Kalambaka",12,0,0,0,'Greece & North Macedonia 2024',['Artur','Messay']])
data_list.append([datetime.datetime(2024, 4, 6),"Thessaloniki","Greece","Thessaloniki","Kalambaka",154,0,0,0,'Greece & North Macedonia 2024',['Artur']])
data_list.append([datetime.datetime(2024, 4, 6),"Kalambaka","Greece","Thessaloniki","Kalambaka",1,0,1,0,'Greece & North Macedonia 2024',['Artur']])
data_list.append([datetime.datetime(2024, 4, 7),"Kalambaka","Greece","Kalambaka","Kalambaka",128,0,-1,0,'Greece & North Macedonia 2024',["Artur"]])
data_list.append([datetime.datetime(2024, 4, 7),"Kalambaka","Greece","Kalambaka","Kalambaka",162,0,-1,0,'Greece & North Macedonia 2024',[]])
data_list.append([datetime.datetime(2024, 4, 8),"Kalambaka","Greece","Kalambaka","Thessaloniki",7,0,1,0,'Greece & North Macedonia 2024',[]])
data_list.append([datetime.datetime(2024, 4, 8),"Kalambaka","Greece","Kalambaka","Thessaloniki",42,0,1,0,'Greece & North Macedonia 2024',['Artur']])
data_list.append([datetime.datetime(2024, 4, 8),"Kastraki","Greece","Kalambaka","Thessaloniki",90,0,1,0,'Greece & North Macedonia 2024',['Artur']])
data_list.append([datetime.datetime(2024, 4, 9),"Thessaloniki","Greece","Thessaloniki","Vienna",66,0,0,1,'Greece & North Macedonia 2024',['Artur']])
data_list.append([datetime.datetime(2024, 4, 9),"Belgrade","Serbia","Thessaloniki","Vienna",2,0,1,1,'Greece & North Macedonia 2024',['Artur']])
data_list.append([datetime.datetime(2024, 4, 9),"Vienna","Austria","Thessaloniki","Vienna",6,0,1,1,'Greece & North Macedonia 2024',['Artur']])
data_list.append([datetime.datetime(2024, 4, 24),"Copenhagen","Denmark","Vienna","Copenhagen",6,0,1,2,'Copenhagen DTU 2024',[]])
data_list.append([datetime.datetime(2024, 5, 1),"London","United Kingdom","London","London",5,0,-1,0,'England 2024',[]])
data_list.append([datetime.datetime(2024, 5, 1),"Durham","United Kingdom","London","London",111,0,-1,0,'England 2024',[]])
data_list.append([datetime.datetime(2024, 5, 1),"York","United Kingdom","London","London",179,0,-1,0,'England 2024',[]])
data_list.append([datetime.datetime(2024, 5, 1),"Saltaire","United Kingdom","London","London",29,0,-1,0,'England 2024',[]])
data_list.append([datetime.datetime(2024, 5, 2),"London","United Kingdom","London","London",304,0,-1,0,'England 2024',[]])
data_list.append([datetime.datetime(2024, 5, 2),"Canterbury","United Kingdom","London","London",214,0,-1,0,'England 2024',[]])
data_list.append([datetime.datetime(2024, 5, 3),"London","United Kingdom","London","London",3,0,-1,0,'England 2024',[]])
data_list.append([datetime.datetime(2024, 5, 3),"Kendal","United Kingdom","London","London",1,0,-1,0,'England 2024',[]])
data_list.append([datetime.datetime(2024, 5, 3),"Stavely","United Kingdom","London","London",1,0,-1,0,'England 2024',[]])
data_list.append([datetime.datetime(2024, 5, 3),"Windermere","United Kingdom","London","London",30,0,-1,0,'England 2024',[]])
data_list.append([datetime.datetime(2024, 5, 3),"Ambleside","United Kingdom","London","London",33,0,-1,0,'England 2024',[]])
data_list.append([datetime.datetime(2024, 5, 3),"Rydal","United Kingdom","London","London",57,0,-1,2,'England 2024',[]])
data_list.append([datetime.datetime(2024, 5, 3),"Grasmere","United Kingdom","London","London",38,0,-1,2,'England 2024',[]])
data_list.append([datetime.datetime(2024, 5, 4),"London","United Kingdom","London","London",47,0,-1,2,'England 2024',[]])
data_list.append([datetime.datetime(2024, 5, 4),"Poole","United Kingdom","London","London",1,0,-1,2,'England 2024',[]])
data_list.append([datetime.datetime(2024, 5, 4),"London","United Kingdom","London","Vienna",5,0,0,1,'England 2024',[]])
data_list.append([datetime.datetime(2024, 5, 4),"Stansted","United Kingdom","London","Vienna",2,0,0,1,'England 2024',[]])
data_list.append([datetime.datetime(2024, 5, 4),"Cambridge","United Kingdom","London","Vienna",3,0,0,1,'England 2024',['May','Eric','Siyi']])
data_list.append([datetime.datetime(2024, 5, 4),"Ely","United Kingdom","London","Vienna",9,0,0,1,'England 2024',['May','Eric','Siyi']])
data_list.append([datetime.datetime(2024, 5, 4),"Luton","United Kingdom","London","Vienna",2,0,0,1,'England 2024',[]])
data_list.append([datetime.datetime(2024, 5, 9),"Idrija","Slovenia","Ljubljana","Ljubljana",110,0,-1,1,'Slovenia 2024',[]])
data_list.append([datetime.datetime(2024, 5, 9),"Ljubljana","Slovenia","Ljubljana","Ljubljana",55,0,-1,1,'Slovenia 2024',[]])
data_list.append([datetime.datetime(2024, 5, 10),"Borovnica","Slovenia","Ljubljana","Ljubljana",1,0,-1,1,'Slovenia 2024',[]])
data_list.append([datetime.datetime(2024, 5, 10),"Postojna","Slovenia","Ljubljana","Ljubljana",170,0,-1,1,'Slovenia 2024',[]])
data_list.append([datetime.datetime(2024, 5, 10),"Veliki Otok","Slovenia","Ljubljana","Ljubljana",68,0,-1,1,'Slovenia 2024',[]])
data_list.append([datetime.datetime(2024, 5, 10),"Zagon","Slovenia","Ljubljana","Ljubljana",4,0,-1,1,'Slovenia 2024',[]])
data_list.append([datetime.datetime(2024, 5, 10),"Mali Otok","Slovenia","Ljubljana","Ljubljana",4,0,-1,1,'Slovenia 2024',[]])
data_list.append([datetime.datetime(2024, 5, 10),"Hrasce","Slovenia","Ljubljana","Ljubljana",3,0,-1,1,'Slovenia 2024',[]])
data_list.append([datetime.datetime(2024, 5, 10),"Landol","Slovenia","Ljubljana","Ljubljana",1,0,-1,1,'Slovenia 2024',[]])
data_list.append([datetime.datetime(2024, 5, 10),"Predjama","Slovenia","Ljubljana","Ljubljana",32,0,-1,1,'Slovenia 2024',[]])
data_list.append([datetime.datetime(2024, 5, 10),"Belsko","Slovenia","Ljubljana","Ljubljana",1,0,-1,1,'Slovenia 2024',[]])
data_list.append([datetime.datetime(2024, 5, 11),"Divaca","Slovenia","Ljubljana","Ljubljana",255,0,-1,0,'Slovenia 2024',[]])
data_list.append([datetime.datetime(2024, 5, 12),"Ljubljana","Slovenia","Ljubljana","Vienna",133,0,0,0,'Slovenia 2024',[]])
data_list.append([datetime.datetime(2024, 5, 17),"Croatia","Malta","Vienna","Msida",7,0,0,2,'Malta 2024',[]])
data_list.append([datetime.datetime(2024, 5, 17),"Italy","Malta","Vienna","Msida",10,0,1,2,'Malta 2024',[]])
data_list.append([datetime.datetime(2024, 5, 18),"Msida","Malta","Msida","Msida",6,0,-1,0,'Malta 2024',['Artur']])
data_list.append([datetime.datetime(2024, 5, 18),"Rabat","Malta","Msida","Msida",90,0,-1,0,'Malta 2024',['Artur']])
data_list.append([datetime.datetime(2024, 5, 18),"Mdina","Malta","Msida","Msida",141,0,-1,0,'Malta 2024',['Artur']])
data_list.append([datetime.datetime(2024, 5, 18),"Gzira","Malta","Msida","Msida",21,0,-1,0,'Malta 2024',['Artur']])
data_list.append([datetime.datetime(2024, 5, 19),"Qrendi","Malta","Msida","Msida",159,0,-1,0,'Malta 2024',['Artur']])
data_list.append([datetime.datetime(2024, 5, 19),"Zurrieq","Malta","Msida","Msida",12,0,-1,0,'Malta 2024',['Artur']])
data_list.append([datetime.datetime(2024, 5, 19),"Paola","Malta","Msida","Msida",11,0,-1,0,'Malta 2024',['Artur']])
data_list.append([datetime.datetime(2024, 5, 19),"Tarxien","Malta","Msida","Msida",36,0,-1,0,'Malta 2024',['Artur']])
data_list.append([datetime.datetime(2024, 5, 19),"Floriana","Malta","Msida","Msida",7,0,-1,0,'Malta 2024',['Artur']])
data_list.append([datetime.datetime(2024, 5, 19),"Valletta","Malta","Msida","Msida",465,0,-1,0,'Malta 2024',['Artur']])
data_list.append([datetime.datetime(2024, 5, 30),"Sopron","Austria","Vienna","Vienna",69,0,-1,0,'Sopron & Fertoed 2024',[]])
data_list.append([datetime.datetime(2024, 5, 30),"Fertoed","Austria","Vienna","Vienna",118,0,-1,0,'Sopron & Fertoed 2024',[]])
data_list.append([datetime.datetime(2024, 5, 31),"Kirchberg am Wechsel","Austria","Vienna","Vienna",76,0,-1,0,'Kirchberg am Wechsel 2024',[]])
data_list.append([datetime.datetime(2024, 6, 2),"Hinterbruehl","Austria","Vienna","Vienna",30,0,-1,0,'Moedling, Hinterbruehl & Mauerbach 2024',[]])
data_list.append([datetime.datetime(2024, 6, 2),"Moedling","Austria","Vienna","Vienna",44,0,-1,0,'Moedling, Hinterbruehl & Mauerbach 2024',[]])
data_list.append([datetime.datetime(2024, 6, 2),"Maria Enzersdorf","Austria","Vienna","Vienna",40,0,-1,0,'Moedling, Hinterbruehl & Mauerbach 2024',[]])
data_list.append([datetime.datetime(2024, 6, 2),"Mauerbach","Austria","Vienna","Vienna",67,0,-1,0,'Moedling, Hinterbruehl & Mauerbach 2024',[]])
data_list.append([datetime.datetime(2024, 6, 8),"Zwettl","Austria","Vienna","Vienna",127,0,-1,0,'Zwettl 2024',[]])

#TripDestinationCloser (second to last)
#-1 if Destination and Origin are the same, 1 if Destination is closer, 0 if Origin is closer
#FlightFlag (last) 0 both of them reached without flight 1 if flight from Origin (aka end trip), 2 if flight to Destination (aka start trip)

# %%
df = pd.DataFrame(data_list,columns=['Date', 'Place','Country','Trip Origin',"Trip Destination",'Picture Count',"Day-Trip",'TripDestinationCloser','FlightFlag',"Trip Name","Co-Travellers"])
df["No Co-Travellers"]=df["Co-Travellers"].str.len()
df.to_csv("../data/data_TripPhotos.csv")

# %%
for d in data_list:
    if len(d)>9:
        print(d)
# Out:
# [datetime.datetime(1996, 4, 10, 0, 0), 'Birnau', 'Germany', 'Lauchringen', 'Lauchringen', 2, 1, -1, 0, 'Birnau 96', ['Artur', 'Hannsjoerg', 'Heidrun', 'Jan-Marc', 'Anne-Kathrin']]
# [datetime.datetime(1996, 4, 14, 0, 0), 'Unteruhldingen', 'Germany', 'Lauchringen', 'Lauchringen', 4, 1, -1, 0, 'Pfahlbauten 96', ['Artur', 'Hannsjoerg', 'Heidrun', 'Jan-Marc', 'Anne-Kathrin']]
# [datetime.datetime(1996, 5, 8, 0, 0), 'Hartmannswiller', 'France', 'Lauchringen', 'Lauchringen', 3, 1, -1, 0, 'Hartmannswiller 96', ['Artur', 'Hannsjoerg', 'Heidrun', 'Jan-Marc', 'Anne-Kathrin']]
# [datetime.datetime(1996, 5, 10, 0, 0), 'Thun', 'Switzerland', 'Lauchringen', 'Beatenberg', 4, 0, 1, 0, 'Beatenberg 96', ['Artur', 'Jan-Marc', 'Anne-Kathrin']]
# [datetime.datetime(1996, 5, 10, 0, 0), 'Hilterfingen', 'Switzerland', 'Lauchringen', 'Beatenberg', 1, 0, -1, 0, 'Beatenberg 96', ['Artur', 'Jan-Marc', 'Anne-Kathrin']]
# ...

# %%
df=pd.read_csv("../data/data_tripPhotos.csv",index_col=0)
df.sort_values(by=["Co-Travellers","Date"]).tail(40)
# Out:
#             Date                 Place         Country Trip Origin  \
# 2343  2024-05-01                Durham  United Kingdom      London
# 2344  2024-05-01                  York  United Kingdom      London
# 2345  2024-05-01              Saltaire  United Kingdom      London
# 2346  2024-05-02                London  United Kingdom      London
# 2347  2024-05-02            Canterbury  United Kingdom      London
# 2348  2024-05-03                London  United Kingdom      London
# 2349  2024-05-03                Kendal  United Kingdom      London
# 2350  2024-05-03               Stavely  United Kingdom      London
# 2351  2024-05-03            Windermere  United Kingdom      London
# 2352  2024-05-03             Ambleside  United Kingdom      London
# 2353  2024-05-03                 Rydal  United Kingdom      London
# 2354  2024-05-03              Grasmere  United Kingdom      London
# 2355  2024-05-04                London  United Kingdom      London
# ...

# %%
df.head(40)
# Out:
#           Date            Place         Country  Trip Origin Trip Destination  \
# 0   1996-04-10           Birnau         Germany  Lauchringen      Lauchringen
# 1   1996-04-14   Unteruhldingen         Germany  Lauchringen      Lauchringen
# 2   1996-05-08  Hartmannswiller          France  Lauchringen      Lauchringen
# 3   1996-05-10             Thun     Switzerland  Lauchringen       Beatenberg
# 4   1996-05-10     Hilterfingen     Switzerland  Lauchringen       Beatenberg
# 5   1996-05-10        Oberhofen     Switzerland  Lauchringen       Beatenberg
# 6   1996-05-10       Beatenberg     Switzerland  Lauchringen       Beatenberg
# 7   1996-05-11       Ballenberg     Switzerland   Beatenberg      Lauchringen
# 8   1996-08-24           London  United Kingdom  Lauchringen           London
# 9   1996-08-25           London  United Kingdom       London           London
# 10  1996-08-26           London  United Kingdom       London           London
# ...

# %%
df["Date"]=pd.to_datetime(df["Date"])

# %%
def func_cot(x_list):
    xl_r=[]
    for x_l in x_list:
        #print ("go now to",x_l)
        if len(x_l)>len(xl_r):
            xl_r = x_l
    return xl_r

# %%
df.dtypes
# Out:
# Date                     datetime64[ns]
# Place                            object
# Country                          object
# Trip Origin                      object
# Trip Destination                 object
# Picture Count                     int64
# Day-Trip                          int64
# TripDestinationCloser             int64
# FlightFlag                        int64
# Trip Name                        object
# Co-Travellers                    object
# No Co-Travellers                  int64
# dtype: object

# %%
df.loc[(df['Co-Travellers'].isna())]
# Out:
# Empty DataFrame
# Columns: [Date, Place, Country, Trip Origin, Trip Destination, Picture Count, Day-Trip, TripDestinationCloser, FlightFlag, Trip Name, Co-Travellers, No Co-Travellers]
# Index: []

# %%
df["Date"].nunique()
# Out:
# 1191

# %%
df["Co-Travellers"].unique()
# Out:
# array(["['Artur', 'Hannsjoerg', 'Heidrun', 'Jan-Marc', 'Anne-Kathrin']",
#        "['Artur', 'Jan-Marc', 'Anne-Kathrin']", "['Artur', 'Heidrun']",
#        "['Artur', 'Heidrun', 'Hannsjoerg', 'Anne-Kathrin']", "['school']",
#        "['Hochrhein Seminar']", "['Vera']", "['Christine S']",
#        "['Heidrun', 'Artur', 'Hannsjoerg', 'Anne-Kathrin']",
#        "['School Concert']", "['KGT']",
#        "['Heidrun', 'Anne-Kathrin', 'Artur', 'Hannsjoerg']",
#        "['Boeni', 'Sigi', 'Gianrico']", "['Sigi', 'Gianrico']",
#        "['Sigi', 'Gianrico', 'Anne F']", '[]', "['ETH Astro Crew']",
#        "['Artur', 'Heidrun', 'Hannsjoerg']",
#        "['Artur', 'Anne-Kathrin', 'Heidrun', 'Hannsjoerg']",
#        "['Artur', 'Hannsjoerg']", "['Anne F', 'Sigi', 'Gianrico']",
#        "['Artur', 'Jan-Marc']", "['Hannsjoerg']",
#        "['Hannsjoerg', 'Heidrun', 'Artur']",
#        "['Hannsjoerg', 'Artur', 'Heidrun']", "['Zhiling']", "['Filip']",
# ...

# %%
df_place_agg=df.loc[(df["Place"]==df['Trip Origin']) | (df["Place"]==df['Trip Destination'])].groupby(
    ["Date","Place"]).agg( 
                        DayTrip=('Day-Trip','min'),
                        PictureCountAtPlace=("Picture Count",'sum'),
                        CoTravellers=("Co-Travellers",lambda x: func_cot(x)),
                        NoCoT=("No Co-Travellers",'max')
).reset_index()
df_place_agg
# Out:
#           Date       Place  DayTrip  PictureCountAtPlace  \
# 0   1996-05-10  Beatenberg        0                   13
# 1   1996-08-24      London        0                    2
# 2   1996-08-25      London        0                    6
# 3   1996-08-26      London        0                    9
# 4   1996-08-27      London        0                    5
# ..         ...         ...      ...                  ...
# 758 2024-05-03      London        0                    3
# 759 2024-05-04      London        0                   52
# 760 2024-05-09   Ljubljana        0                   55
# 761 2024-05-12   Ljubljana        0                  133
# 762 2024-05-18       Msida        0                    6
#
#                                           CoTravellers  NoCoT
# 0                ['Artur', 'Jan-Marc', 'Anne-Kathrin']      3
# 1    ['Artur', 'Hannsjoerg', 'Heidrun', 'Jan-Marc',...      5
# 2    ['Artur', 'Hannsjoerg', 'Heidrun', 'Jan-Marc',...      5
# ...

# %%
df.columns
# Out:
# Index(['Date', 'Place', 'Country', 'Trip Origin', 'Trip Destination',
#        'Picture Count', 'Day-Trip', 'TripDestinationCloser', 'FlightFlag',
#        'Trip Name', 'Co-Travellers', 'No Co-Travellers'],
#       dtype='object')

# %%
df.groupby(["Trip Name"]).agg(
    start=('Date','first'),
    n_days=('Date','nunique'),
    n_places=('Place','nunique'),
    n_pictures=('Picture Count','sum'),
    n_co_travellers=('No Co-Travellers','max'),
    day_trip=('Day-Trip','max')
).sort_values(by=['n_pictures'],ascending=False).reset_index().head(50)
# Out:
#                                      Trip Name      start  n_days  n_places  \
# 0                                   Spain 2022 2022-03-19      16        19
# 1                          Rome and Italy 2020 2020-02-20      12        21
# 2                                Portugal 2023 2023-03-03      16        30
# 3                         Bari and Naples 2019 2019-03-10      13        38
# 4                          China 2017 and 2018 2017-12-30      21        15
# 5                      Germany and France 2021 2021-10-22      11        28
# 6                                   Italy 2022 2022-07-29      10        19
# 7                London and South England 2014 2014-07-24      12        19
# 8                                    Rome 2013 2013-04-03       9         3
# 9     US National Parks and Washington DC 2016 2016-08-13      17        27
# 10  Slovakia, Poland, Hungary and Austria 2023 2023-08-25      11        44
# ...

# %%
df_PlaceStay_agg=df.loc[(df["Place"]==df['Trip Origin']) & (df["Place"]==df['Trip Destination'])].groupby(
            ["Date","Place"]).agg(
                        PictureCountAtPlace=("Picture Count",'sum'),
                        CoTravellersS=("Co-Travellers",lambda x: func_cot(x)),
                        NoCoS=("No Co-Travellers",'max')
                ).reset_index()
df_PlaceStay_agg
# Out:
#           Date      Place  PictureCountAtPlace  \
# 0   1996-08-25     London                    6
# 1   1996-08-26     London                    9
# 2   1996-08-27     London                    5
# 3   1996-08-28     London                   25
# 4   1996-08-29     London                    7
# ..         ...        ...                  ...
# 403 2024-05-02     London                  304
# 404 2024-05-03     London                    3
# 405 2024-05-04     London                   47
# 406 2024-05-09  Ljubljana                   55
# 407 2024-05-18      Msida                    6
#
#                                          CoTravellersS  NoCoS
# 0    ['Artur', 'Hannsjoerg', 'Heidrun', 'Jan-Marc',...      5
# 1    ['Artur', 'Hannsjoerg', 'Heidrun', 'Jan-Marc',...      5
# 2    ['Artur', 'Hannsjoerg', 'Heidrun', 'Jan-Marc',...      5
# 3    ['Artur', 'Hannsjoerg', 'Heidrun', 'Jan-Marc',...      5
# 4    ['Artur', 'Hannsjoerg', 'Heidrun', 'Jan-Marc',...      5
# ...

# %%
df_PlaceStay_fullSum=df_PlaceStay_agg.groupby(['Place']).agg(
    PictureCountTotalAtPlace_NoMove=('PictureCountAtPlace','sum'),
    n_DaysTotAtPlace_NoMove=('Date','nunique')
).reset_index().sort_values(by=['PictureCountTotalAtPlace_NoMove'],ascending=False,ignore_index='True')
df_PlaceStay_fullSum.head(10)
# Out:
#            Place  PictureCountTotalAtPlace_NoMove  n_DaysTotAtPlace_NoMove
# 0           Rome                             4886                       23
# 1          Paris                             2708                       30
# 2         London                             1769                       27
# 3        Beijing                             1102                        5
# 4         Venice                             1057                        8
# 5         Naples                              954                        8
# 6         Berlin                              858                       14
# 7  New York City                              771                        4
# 8         Vienna                              753                        9
# 9      Stockholm                              706                        8

# %%
df_neitherplace_agg=df.loc[(df["Place"]!=df['Trip Origin']) & (df["Place"]!=df['Trip Destination'])].groupby(
    ["Date","Place"]).agg( 
                        DayTrip=('Day-Trip','min'),
                        PictureCountAtPlace=("Picture Count",'sum'),
                        CoTravellers=("Co-Travellers",lambda x: func_cot(x)),
                        NoCoT=("No Co-Travellers",'max')
).reset_index()
df_neitherplace_fullSum=df_neitherplace_agg.groupby(['Place']).agg(
    PictureCountToPlace_NoStay=('PictureCountAtPlace','sum'),
    n_DaysTotToPlace_NoStay=('Date','nunique')
).reset_index().sort_values(by=['PictureCountToPlace_NoStay'],ascending=False,ignore_index='True')
df_neitherplace_fullSum.head(10)
# Out:
#         Place  PictureCountToPlace_NoStay  n_DaysTotToPlace_NoStay
# 0     Zermatt                        1524                       10
# 1    Chamonix                        1340                       11
# 2    Florence                        1203                        5
# 3     Potsdam                        1164                        7
# 4  Versailles                        1067                        5
# 5      Krakow                         786                        3
# 6      Toledo                         774                        3
# 7       Padua                         676                        3
# 8       Siena                         645                        4
# 9     Chicago                         609                        5

# %%
df_PlaceInOrigOrDestOnly_agg=df.loc[((df["Place"]==df['Trip Origin']) | (df["Place"]==df['Trip Destination']))
                                   & (df["Trip Destination"]!=df['Trip Origin'])].groupby(
            ["Date","Place"]).agg(
                        PictureCountAtDestOrOrigOnly=("Picture Count",'sum'),
                        CoTravellersAtDestOrOrigOnly=("Co-Travellers",lambda x: func_cot(x)),
                        NoCoAtDestOrOrigOnly=("No Co-Travellers",'max')
                ).reset_index()
df_PlaceInOrigOrDestOnly_agg
df_PlaceInOrigOrDestOnly_fullSum=df_PlaceInOrigOrDestOnly_agg.groupby(['Place']).agg(
    PictureCountAtPlace_OnlyStartOrEnd=('PictureCountAtDestOrOrigOnly','sum'),
    n_DaysTotOnlyStartOrEnd=('Date','nunique')
).reset_index().sort_values(by=['PictureCountAtPlace_OnlyStartOrEnd'],ascending=False,ignore_index='True')
df_PlaceInOrigOrDestOnly_fullSum.head(10)
# Out:
#        Place  PictureCountAtPlace_OnlyStartOrEnd  n_DaysTotOnlyStartOrEnd
# 0      Paris                                1914                       15
# 1     Venice                                1187                        6
# 2     London                                 927                       12
# 3   Florence                                 785                        4
# 4     Prague                                 772                        5
# 5     Lisbon                                 739                        5
# 6  Barcelona                                 667                        4
# 7       Rome                                 622                        6
# 8    Sevilla                                 613                        2
# 9     Berlin                                 612                        9

# %%
df_PicsAtOrigDest_diffOrigDest_fullSum=df_PlaceInOrigOrDestOnly_agg.groupby(['Place']).agg(
    PictureCountEitherOrigDest=('PictureCountAtDestOrOrigOnly','sum'),
    n_DaysTot_AtOrigDestSame=('Date','nunique')
).reset_index().sort_values(by=['PictureCountEitherOrigDest'],ascending=False,ignore_index='True')
df_PicsAtOrigDest_diffOrigDest_fullSum.head(10)
# Out:
#        Place  PictureCountEitherOrigDest  n_DaysTot_AtOrigDestSame
# 0      Paris                        1914                        15
# 1     Venice                        1187                         6
# 2     London                         927                        12
# 3   Florence                         785                         4
# 4     Prague                         772                         5
# 5     Lisbon                         739                         5
# 6  Barcelona                         667                         4
# 7       Rome                         622                         6
# 8    Sevilla                         613                         2
# 9     Berlin                         612                         9

# %%
#places of photos where the origin is not the place
#but also not a flight from the origin or a transfer place between flights
df_OtherPlace_GroupOrig=df.loc[(df["Place"]!=df['Trip Origin']) & (df['Trip Origin']!=df['Trip Destination'])
                    & (df['FlightFlag']!=3)& (df['FlightFlag']!=1)].groupby(
            ["Date","Trip Origin"]).agg(
                        PictureCount_DiffFromOrig=("Picture Count",'sum'),
                        n_Places_DiffFromOrig=("Place",'nunique'),
                        CoTravellers_DiffFromOrig=("Co-Travellers",lambda x: func_cot(x)),
                        NoCo_DiffFromOrig=("No Co-Travellers",'max')
                ).reset_index()
df_OtherPlace_GroupOrig.sort_values(by=['PictureCount_DiffFromOrig'],ascending=False,ignore_index='True').head(50)
df_OtherPlace_Orig_fullSum=df_OtherPlace_GroupOrig.groupby(['Trip Origin']).agg(
    PictureCountOtherPlace_OrigAtPlace=('PictureCount_DiffFromOrig','sum'),
    n_DaysOtherPlace_OrigAtPlace=('Date','nunique')
).reset_index().sort_values(by=['PictureCountOtherPlace_OrigAtPlace'],ascending=False,ignore_index='True')
df_OtherPlace_Orig_fullSum=df_OtherPlace_Orig_fullSum.rename(columns={'Trip Origin':'Place'})
df_OtherPlace_Orig_fullSum.head(10)
# Out:
#          Place  PictureCountOtherPlace_OrigAtPlace  \
# 0         Genf                                1981
# 1       Milano                                1328
# 2  Lauchringen                                1197
# 3        Paris                                 781
# 4      Cordoba                                 613
# 5       Vienna                                 511
# 6      Fuessen                                 428
# 7       Lisbon                                 413
# 8         Metz                                 379
# 9        Porto                                 375
#
#    n_DaysOtherPlace_OrigAtPlace
# 0                            24
# 1                             8
# 2                            26
# 3                             5
# 4                             2
# 5                            13
# 6                             2
# 7                             3
# 8                             1
# 9                             1

# %%
#places of photos where the Destination is not the place
#but also not a flight from the Destination or a transfer place between flights
df_OtherPlace_StayConst=df.loc[(df["Place"]!=df['Trip Destination']) & (df['Trip Destination']==df['Trip Origin'])
                    & (df['FlightFlag']!=3)].groupby(
            ["Date","Trip Destination"]).agg(
                        PictureCount_OtherPlace_StayConst=("Picture Count",'sum'),
                        n_Places_OtherPlace_StayConst=("Place",'nunique'),
                        CoTravellers_OtherPlace_StayConst=("Co-Travellers",lambda x: func_cot(x)),
                        NoCo_OtherPlace_StayConst=("No Co-Travellers",'max')
                ).reset_index()
#df_OtherPlace_StayConst.sort_values(by=['PictureCount_OtherPlace_StayConst'],ascending=False,ignore_index='True').head(50)

df_OtherPlace_StayConst_fullSum=df_OtherPlace_StayConst.groupby(['Trip Destination']).agg(
    PictureCount_OtherPlace_StayConst=('PictureCount_OtherPlace_StayConst','sum'),
    n_Days_OtherPlace_StayConst=('Date','nunique')
).reset_index().sort_values(by=['PictureCount_OtherPlace_StayConst'],ascending=False,ignore_index='True')
df_OtherPlace_StayConst_fullSum=df_OtherPlace_StayConst_fullSum.rename(columns={'Trip Destination':'Place'})
df_OtherPlace_StayConst_fullSum.head(10)
# Out:
#          Place  PictureCount_OtherPlace_StayConst  n_Days_OtherPlace_StayConst
# 0         Genf                              13013                          136
# 1       Vienna                               8639                           51
# 2  Lauchringen                               4812                           95
# 3        Paris                               3661                           22
# 4       Madrid                               3152                           16
# 5         Rome                               2602                           10
# 6       Lisbon                               2246                           14
# 7       Naples                               2229                           11
# 8    Frankfurt                               1927                            8
# 9       London                               1886                           11

# %%
#places of photos where the Destination is not the place
#but also not a flight from the Destination or a transfer place between flights
df_OtherPlace_GroupDest=df.loc[(df["Place"]!=df['Trip Destination']) & (df['Trip Destination']!=df['Trip Origin'])
                    & (df['FlightFlag']!=3)& (df['FlightFlag']!=2)].groupby(
            ["Date","Trip Destination"]).agg(
                        PictureCount_DiffFromDest=("Picture Count",'sum'),
                        n_Places_DiffFromDest=("Place",'nunique'),
                        CoTravellers_DiffFromDest=("Co-Travellers",lambda x: func_cot(x)),
                        NoCo_DiffFromDest=("No Co-Travellers",'max')
                ).reset_index()
df_OtherPlace_GroupDest.sort_values(by=['PictureCount_DiffFromDest'],ascending=False,ignore_index='True').head(50)
df_OtherPlace_Dest_fullSum=df_OtherPlace_GroupDest.groupby(['Trip Destination']).agg(
    PictureCountOtherPlace_DestAtPlace=('PictureCount_DiffFromDest','sum'),
    n_DaysOtherPlace_DestAtPlace=('Date','nunique')
).reset_index().sort_values(by=['PictureCountOtherPlace_DestAtPlace'],ascending=False,ignore_index='True')
df_OtherPlace_Dest_fullSum=df_OtherPlace_Dest_fullSum.rename(columns={'Trip Destination':'Place'})
df_OtherPlace_Dest_fullSum.head(10)
# Out:
#          Place  PictureCountOtherPlace_DestAtPlace  \
# 0         Genf                                4498
# 1       Vienna                                3201
# 2       Milano                                 967
# 3  Lauchringen                                 710
# 4        Bozen                                 476
# 5      Beijing                                 457
# 6     Florence                                 452
# 7       Venice                                 419
# 8        Lagos                                 411
# 9       Berlin                                 400
#
#    n_DaysOtherPlace_DestAtPlace
# 0                            39
# 1                            21
# 2                             4
# 3                            21
# 4                             1
# 5                             2
# 6                             1
# 7                             1
# 8                             2
# 9                             3

# %%
df_PlaceTotalSummary=df_PlaceStay_fullSum.merge(df_PlaceInOrigOrDestOnly_fullSum, how='outer',on='Place')
df_PlaceTotalSummary=df_PlaceTotalSummary.merge(df_neitherplace_fullSum, how='outer',on='Place')
df_PlaceTotalSummary=df_PlaceTotalSummary.merge(df_OtherPlace_Orig_fullSum, how='outer',on='Place')
df_PlaceTotalSummary=df_PlaceTotalSummary.merge(df_OtherPlace_Dest_fullSum, how='outer',on='Place')
df_PlaceTotalSummary=df_PlaceTotalSummary.merge(df_OtherPlace_StayConst_fullSum, how='outer',on='Place')
df_PlaceTotalSummary=df_PlaceTotalSummary.fillna(0)
df_PlaceTotalSummary.head(30)
# Out:
#                Place  PictureCountTotalAtPlace_NoMove  \
# 0               Rome                           4886.0
# 1              Paris                           2708.0
# 2             London                           1769.0
# 3            Beijing                           1102.0
# 4             Venice                           1057.0
# 5             Naples                            954.0
# 6             Berlin                            858.0
# 7      New York City                            771.0
# 8             Vienna                            753.0
# 9          Stockholm                            706.0
# 10          Istanbul                            695.0
# 11            Warsaw                            669.0
# 12            Prague                            636.0
# 13            Munich                            605.0
# 14  Saint Petersburg                            572.0
# 15           Dresden                            566.0
# ...

# %%
df_PlaceTotalSummary['PictureCountTotalTakenAtPlace']=df_PlaceTotalSummary['PictureCountTotalAtPlace_NoMove']+df_PlaceTotalSummary['PictureCountAtPlace_OnlyStartOrEnd']+df_PlaceTotalSummary['PictureCountToPlace_NoStay']
df_PlaceTotalSummary['n_DaysAtPlace']=df_PlaceTotalSummary['n_DaysTotAtPlace_NoMove']+df_PlaceTotalSummary['n_DaysTotOnlyStartOrEnd']+df_PlaceTotalSummary['n_DaysTotToPlace_NoStay']
df_PlaceTotalSummary['PictureCountTotalTakenAtOtherPlace']=df_PlaceTotalSummary['PictureCountOtherPlace_OrigAtPlace']+df_PlaceTotalSummary['PictureCountOtherPlace_DestAtPlace']+df_PlaceTotalSummary['PictureCount_OtherPlace_StayConst']
df_PlaceTotalSummary['n_DaysVisitOtherPlace']=df_PlaceTotalSummary['n_DaysOtherPlace_DestAtPlace']+df_PlaceTotalSummary['n_DaysOtherPlace_OrigAtPlace']+df_PlaceTotalSummary['n_Days_OtherPlace_StayConst']
df_PlaceTotalSummary['PictureCountTotal_RelatedToPlace']=df_PlaceTotalSummary['PictureCountTotalTakenAtPlace']+df_PlaceTotalSummary['PictureCountTotalTakenAtOtherPlace']
for col in df_PlaceTotalSummary.columns:
    if col!='Place':
        df_PlaceTotalSummary[col]=df_PlaceTotalSummary[col].astype(int)

# %%
df_PlaceTotalSummary[['Place','PictureCountTotalTakenAtPlace','PictureCountTotalTakenAtOtherPlace',
                     'n_DaysAtPlace','n_DaysVisitOtherPlace',
                     'PictureCountTotal_RelatedToPlace']].sort_values(
by=['PictureCountTotal_RelatedToPlace'],ascending=False,ignore_index='True').head(50)
# Out:
#                Place  PictureCountTotalTakenAtPlace  \
# 0               Genf                            444
# 1             Vienna                           1323
# 2              Paris                           4628
# 3               Rome                           5508
# 4        Lauchringen                            382
# 5             London                           2710
# 6             Madrid                           1230
# 7             Venice                           2244
# 8             Milano                           1071
# 9             Naples                           1353
# 10            Lisbon                           1015
# 11            Berlin                           1470
# 12          Florence                           2181
# 13         Frankfurt                            312
# 14           Beijing                           1112
# 15            Warsaw                            942
# 16            Prague                           1552
# ...

# %%
df_PlaceStay_agg.sort_values(by=['PictureCountAtPlace'],ascending=False,ignore_index='True').head(50)
# Out:
#          Date          Place  PictureCountAtPlace  \
# 0  2020-02-28           Rome                  610
# 1  2013-04-04           Rome                  602
# 2  2017-09-07           Rome                  548
# 3  2020-02-29           Rome                  535
# 4  2017-09-08           Rome                  495
# 5  2021-10-27          Paris                  454
# 6  2022-03-22        Granada                  439
# 7  2022-11-03         Warsaw                  409
# 8  2014-04-21         Munich                  394
# 9  2018-01-07        Beijing                  390
# 10 2019-12-31        Dresden                  382
# 11 2021-08-28         Prague                  361
# 12 2017-09-09           Rome                  357
# 13 2018-01-09        Beijing                  357
# 14 2016-03-18        Palermo                  356
# 15 2019-09-21          Paris                  354
# 16 2013-09-06         Venice                  339
# 17 2016-03-27      Barcelona                  316
# ...

# %%
df_PlaceInOrigOrDestOnly_agg.sort_values(by=['PictureCountAtDestOrOrigOnly'],ascending=False,ignore_index='True').head(50)
# Out:
#          Date             Place  PictureCountAtDestOrOrigOnly  \
# 0  2022-03-25           Sevilla                           611
# 1  2022-08-06            Venice                           584
# 2  2024-01-27            Verona                           476
# 3  2014-09-21             Paris                           390
# 4  2021-10-26             Paris                           379
# 5  2023-03-14           Coimbra                           375
# 6  2022-03-24           Cordoba                           358
# 7  2019-09-22             Paris                           324
# 8  2021-08-29            Prague                           319
# 9  2016-03-26         Barcelona                           319
# 10 2019-03-15            Naples                           308
# 11 2024-02-19            Venice                           287
# 12 2017-09-17            London                           280
# 13 2021-10-23         Nuernberg                           279
# ...

# %%
#places of photos where the origin is not the place
#but also not a flight from the origin or a transfer place between flights
df_OtherPlace_GroupDest=df.loc[(df["Place"]!=df['Trip Destination']) & (df['Trip Origin']!=df['Trip Destination'])
                    & (df['FlightFlag']!=3)& (df['FlightFlag']!=2)].groupby(
            ["Date","Trip Destination"]).agg(
                        PictureCount_DiffFromDest=("Picture Count",'sum'),
                        n_Places_DiffFromDest=("Place",'nunique'),
                        CoTravellers_DiffFromDest=("Co-Travellers",lambda x: func_cot(x)),
                        NoCo_DiffFromDest=("No Co-Travellers",'max')
                ).reset_index()
df_OtherPlace_GroupDest.sort_values(by=['PictureCount_DiffFromDest'],ascending=False,ignore_index='True').head(50)
# Out:
#          Date Trip Destination  PictureCount_DiffFromDest  \
# 0  2022-08-06           Milano                        584
# 1  2024-01-27            Bozen                        476
# 2  2022-08-04         Florence                        452
# 3  2022-08-05           Venice                        419
# 4  2021-10-29        Frankfurt                        392
# 5  2014-09-21             Genf                        390
# 6  2024-01-25           Verona                        363
# 7  2018-01-12          Beijing                        358
# 8  2023-03-04            Lagos                        357
# 9  2023-08-30            Tokaj                        346
# 10 2019-09-22             Genf                        324
# 11 2021-08-29           Vienna                        319
# 12 2024-02-19           Vienna                        287
# 13 2018-04-14    Frederiskberg                        286
# 14 2014-04-19        Rosenheim                        284
# ...

# %%
#places of photos where the origin is not the place
#but also not a flight from the origin or a transfer place between flights
df_PlaceNot_OrigDest=df.loc[(df["Place"]!=df['Trip Origin']) & (df["Place"]!=df['Trip Destination'])
                    & (df['FlightFlag']!=3)].groupby(
            ["Date","Place"]).agg(
                        PictureCount_DiffStay=("Picture Count",'sum'),
                        CoTravellers_DiffStay=("Co-Travellers",lambda x: func_cot(x)),
                        NoCo_DiffStay=("No Co-Travellers",'max')
                ).reset_index()
df_PlaceNot_OrigDest.sort_values(by=['PictureCount_DiffStay'],ascending=False,ignore_index='True').head(50)
# Out:
#          Date                   Place  PictureCount_DiffStay  \
# 0  2020-02-26                Florence                    768
# 1  2022-03-30                  Toledo                    554
# 2  2024-05-19                Valletta                    465
# 3  2021-05-22                Salzburg                    457
# 4  2023-04-29                  Krakow                    438
# 5  2024-01-26                   Padua                    394
# 6  2010-08-29                 Zermatt                    375
# 7  2015-07-18              Versailles                    358
# 8  2018-09-08                 Potsdam                    350
# 9  2019-04-21                 Bourges                    347
# 10 2024-02-18                 Vicenza                    337
# 11 2022-12-02                 Cologne                    337
# 12 2010-09-12                Chamonix                    322
# 13 2024-02-17                 Ferrara                    317
# ...

# %%
df_ext_agg=df.loc[(df["Place"]!=df['Trip Origin'])].groupby(["Date","Place"]).agg(
                        DayTrip=('Day-Trip','min'),
                        PictureCountToPlace=("Picture Count",'sum'),
                        CoTravellersE=("Co-Travellers",lambda x: func_cot(x)),
                        NoCoTE=("No Co-Travellers",'max')
                ).reset_index()
df_ext_agg
# Out:
#            Date             Place  DayTrip  PictureCountToPlace  \
# 0    1996-04-10            Birnau        1                    2
# 1    1996-04-14    Unteruhldingen        1                    4
# 2    1996-05-08   Hartmannswiller        1                    3
# 3    1996-05-10        Beatenberg        0                   13
# 4    1996-05-10      Hilterfingen        0                    1
# ...         ...               ...      ...                  ...
# 1722 2024-06-02      Hinterbruehl        0                   30
# 1723 2024-06-02  Maria Enzersdorf        0                   40
# 1724 2024-06-02         Mauerbach        0                   67
# 1725 2024-06-02          Moedling        0                   44
# 1726 2024-06-08            Zwettl        0                  127
#
#                                           CoTravellersE  NoCoTE
# 0     ['Artur', 'Hannsjoerg', 'Heidrun', 'Jan-Marc',...       5
# 1     ['Artur', 'Hannsjoerg', 'Heidrun', 'Jan-Marc',...       5
# ...

# %%
df_ext_destination_agg=df.loc[(df["Place"]!=df['Trip Origin']) & (df["Place"]!=df['Trip Destination'])
                        ].groupby(["Date","Trip Destination"]).agg(
                        DayTrip=('Day-Trip','min'),
                        PictureCountToPlace=("Picture Count",'sum'),
                        N_OtherPlace_ToDest=('Place','nunique'),
                        CoTravellersOutside=("Co-Travellers",lambda x: func_cot(x)),
                        NoCoTO=("No Co-Travellers",'max')
                ).reset_index()
df_ext_destination_agg=df_ext_destination_agg.rename(columns={'Trip Origin': 'Place'})
df_ext_destination_agg
# Out:
#           Date Trip Destination  DayTrip  PictureCountToPlace  \
# 0   1996-04-10      Lauchringen        1                    2
# 1   1996-04-14      Lauchringen        1                    4
# 2   1996-05-08      Lauchringen        1                    3
# 3   1996-05-10       Beatenberg        0                    7
# 4   1996-05-11      Lauchringen        0                    8
# ..         ...              ...      ...                  ...
# 784 2024-05-19            Msida        0                  690
# 785 2024-05-30           Vienna        0                  187
# 786 2024-05-31           Vienna        0                   76
# 787 2024-06-02           Vienna        0                  181
# 788 2024-06-08           Vienna        0                  127
#
#      N_OtherPlace_ToDest                                CoTravellersOutside  \
# 0                      1  ['Artur', 'Hannsjoerg', 'Heidrun', 'Jan-Marc',...
# ...

# %%
df_ext_origin_agg=df.loc[(df["Place"]!=df['Trip Origin']) & (df["Place"]!=df['Trip Destination'])
                        ].groupby(["Date","Trip Origin"]).agg(
                        DayTrip=('Day-Trip','min'),
                        PictureCountFromPlace=("Picture Count",'sum'),
                        N_OtherPlace_ToOrig=('Place','nunique'),
                        CoTravellersOutside=("Co-Travellers",lambda x: func_cot(x)),
                        NoCoTO=("No Co-Travellers",'max')
                ).reset_index()
df_ext_origin_agg=df_ext_origin_agg.rename(columns={'Trip Origin': 'Place'})
df_ext_origin_agg
# Out:
#           Date        Place  DayTrip  PictureCountFromPlace  \
# 0   1996-04-10  Lauchringen        1                      2
# 1   1996-04-14  Lauchringen        1                      4
# 2   1996-05-08  Lauchringen        1                      3
# 3   1996-05-10  Lauchringen        0                      7
# 4   1996-05-11   Beatenberg        0                      8
# ..         ...          ...      ...                    ...
# 783 2024-05-19        Msida        0                    690
# 784 2024-05-30       Vienna        0                    187
# 785 2024-05-31       Vienna        0                     76
# 786 2024-06-02       Vienna        0                    181
# 787 2024-06-08       Vienna        0                    127
#
#      N_OtherPlace_ToOrig                                CoTravellersOutside  \
# 0                      1  ['Artur', 'Hannsjoerg', 'Heidrun', 'Jan-Marc',...
# 1                      1  ['Artur', 'Hannsjoerg', 'Heidrun', 'Jan-Marc',...
# ...

# %%
df_PlaceInOrigOrDestOnly_agg.columns
# Out:
# Index(['Date', 'Place', 'PictureCountAtDestOrOrigOnly',
#        'CoTravellersAtDestOrOrigOnly', 'NoCoAtDestOrOrigOnly'],
#       dtype='object')

# %%
#there are double dates aka if flight and airport destinations are counted 
#as separate place or origin
df_travel_place=df_place_agg.merge(df_ext_origin_agg,how='outer',on=["Date","Place",'DayTrip'])
df_travel_place=df_travel_place.merge(df_ext_agg,how='outer',on=["Date","Place",'DayTrip'])
df_travel_place['PictureCountAtPlace']=df_travel_place['PictureCountAtPlace'].fillna(0)
df_travel_place['PictureCountFromPlace']=df_travel_place['PictureCountFromPlace'].fillna(0)
df_travel_place['PictureCountToPlace']=df_travel_place['PictureCountToPlace'].fillna(0)
df_travel_place['PictureTotal']=df_travel_place['PictureCountToPlace']+df_travel_place['PictureCountFromPlace']+df_travel_place['PictureCountAtPlace']
print(df_travel_place.columns)
df_travel_place['NoCoTO']=df_travel_place['NoCoTO'].fillna(0)
df_travel_place['NoCoT']=df_travel_place['NoCoT'].fillna(0)
df_travel_place['NoCoTE']=df_travel_place['NoCoTE'].fillna(0)
df_travel_place['N_OtherPlace_ToOrig']=df_travel_place['N_OtherPlace_ToOrig'].fillna(0)
df_travel_place['CoTravellers']=df_travel_place['CoTravellers'].fillna({i: [] for i in df_travel_place.index})
df_travel_place['CoTravellersE']=df_travel_place['CoTravellersE'].fillna({i: [] for i in df_travel_place.index})
df_travel_place['CoTravellersOutside']=df_travel_place['CoTravellersOutside'].fillna({i: [] for i in df_travel_place.index})
df_travel_place['Co-Travellers']=np.where(df_travel_place["NoCoT"]>df_travel_place["NoCoTO"],
                                          df_travel_place['CoTravellers'],df_travel_place['CoTravellersOutside'])
df_travel_place['Co-Travellers']=np.where(df_travel_place["NoCoT"]>df_travel_place["NoCoTE"],
                                         df_travel_place['Co-Travellers'],df_travel_place['CoTravellersE'])

df_travel_place["No Co-Travellers"]=df_travel_place[['NoCoT','NoCoTO','NoCoTE']].max(axis=1)
df_travel_place=df_travel_place.drop(columns=['NoCoT','NoCoTO','NoCoTE','CoTravellers','CoTravellersE','CoTravellersOutside'])
df_travel_place
# Out:
# Index(['Date', 'Place', 'DayTrip', 'PictureCountAtPlace', 'CoTravellers',
#        'NoCoT', 'PictureCountFromPlace', 'N_OtherPlace_ToOrig',
#        'CoTravellersOutside', 'NoCoTO', 'PictureCountToPlace', 'CoTravellersE',
#        'NoCoTE', 'PictureTotal'],
#       dtype='object')
#            Date             Place  DayTrip  PictureCountAtPlace  \
# 0    1996-05-10        Beatenberg        0                 13.0
# 1    1996-08-24            London        0                  2.0
# 2    1996-08-25            London        0                  6.0
# 3    1996-08-26            London        0                  9.0
# 4    1996-08-27            London        0                  5.0
# ...         ...               ...      ...                  ...
# 2847 2024-06-02      Hinterbruehl        0                  0.0
# 2848 2024-06-02  Maria Enzersdorf        0                  0.0
# 2849 2024-06-02         Mauerbach        0                  0.0
# ...

# %%
df_place_year_count=df_travel_place.groupby(["Place",df_travel_place['Date'].dt.year]).agg(
    PicturesAtPlacePerYear=('PictureCountAtPlace','sum'),
    PicturesFromPlacePerYear=('PictureCountFromPlace','sum'),
    PicturesToPlacePerYear=('PictureCountToPlace','sum'),
    PictureTotalPerYear=("PictureTotal","sum"),
    DaysPerYear=('Date','nunique')
).reset_index()
df_place_year_count.sort_values(by=['PictureTotalPerYear'],ascending=False
                               ).reset_index().drop(columns=['index']).head(50)
# Out:
#                Place  Date  PicturesAtPlacePerYear  PicturesFromPlacePerYear  \
# 0               Rome  2020                  1966.0                    2256.0
# 1             Vienna  2021                     0.0                    3980.0
# 2             Vienna  2022                     0.0                    3225.0
# 3             London  2014                  1331.0                    1190.0
# 4             Naples  2019                   932.0                    1386.0
# 5             Lisbon  2023                   672.0                    1633.0
# 6               Genf  2019                     0.0                    2432.0
# 7               Rome  2013                  1792.0                     339.0
# 8               Genf  2010                     0.0                    2184.0
# 9             Madrid  2022                   457.0                    1474.0
# 10             Paris  2010                   960.0                     737.0
# ...

# %%
df_travel_place['year']=df_travel_place['Date'].dt.year
df_place_alltime_count=df_travel_place.groupby(["Place"]).agg(
    PicturesAtPlaceAllTime=('PictureCountAtPlace','sum'),
    PicturesFromPlaceAllTime=('PictureCountFromPlace','sum'),
    PicturesToPlaceAllTime=('PictureCountToPlace','sum'),
    PictureTotalAllTime=("PictureTotal","sum"),
    DaysAllTime=('Date','nunique'),
    yearsAllTime=('year','nunique')
).reset_index()
df_place_alltime_count.sort_values(by=['PictureTotalAllTime'],ascending=False
                                  ).reset_index().drop(columns=['index']).head(50)
# Out:
#                Place  PicturesAtPlaceAllTime  PicturesFromPlaceAllTime  \
# 0               Genf                     2.0                   14936.0
# 1             Vienna                  1314.0                    9078.0
# 2              Paris                  4622.0                    4439.0
# 3               Rome                  5508.0                    2605.0
# 4        Lauchringen                   382.0                    5606.0
# 5             London                  2696.0                    1917.0
# 6             Madrid                  1131.0                    3311.0
# 7             Venice                  2244.0                    1691.0
# 8             Naples                  1353.0                    2328.0
# 9             Lisbon                  1015.0                    2413.0
# 10            Berlin                  1470.0                    1812.0
# 11          Florence                   978.0                     297.0
# ...

# %%
df_travel_place["Date"].nunique()
# Out:
# 1191

# %%
df_travel_place.groupby(['Date']).agg(date_count=('Date','count')).sort_values(by="date_count",ascending=False).reset_index().head(50)
# Out:
#          Date  date_count
# 0  2019-03-20          18
# 1  2021-06-19          15
# 2  2016-09-13          13
# 3  2024-05-10          10
# 4  2021-05-24          10
# 5  2022-12-28          10
# 6  2021-07-10          10
# 7  2021-10-31          10
# 8  2017-11-11           9
# 9  2019-04-06           9
# 10 2017-06-23           9
# 11 2023-08-27           9
# 12 2024-04-03           9
# 13 2016-08-19           8
# 14 2021-02-24           8
# 15 2020-07-04           8
# 16 2009-03-21           8
# 17 2016-05-16           7
# 18 2023-08-26           7
# 19 2023-03-05           7
# 20 2019-08-31           7
# 21 2020-02-24           7
# 22 2024-05-03           7
# 23 2017-10-15           7
# 24 2024-05-19           7
# 25 2023-08-13           7
# 26 2014-07-28           7
# 27 2024-05-04           6
# 28 2019-10-06           6
# 29 2008-03-05           6
# 30 2018-08-05           6
# 31 2021-07-03           6
# 32 2020-05-17           6
# 33 2023-08-29           6
# ...

# %%
df_temp=df.groupby(["Country","Place",df['Date'].dt.year]).agg(PicturesPlacePerYear=('Picture Count','sum')).reset_index()
df_temp.sort_values(by="PicturesPlacePerYear",ascending=False).reset_index().drop(columns='index').head(60)
# Out:
#            Country             Place  Date  PicturesPlacePerYear
# 0   United Kingdom            London  2014                  1331
# 1            Italy              Rome  2020                  1328
# 2            Italy              Rome  2013                  1328
# 3            Italy              Rome  2017                  1236
# 4            China           Beijing  2018                  1112
# 5            Italy          Florence  2014                  1041
# 6           France             Paris  2010                   960
# 7            Italy            Naples  2019                   932
# 8              USA     New York City  2009                   894
# 9           France             Paris  2019                   842
# 10          France             Paris  2021                   834
# 11           Italy            Venice  2013                   807
# 12         Austria            Vienna  2014                   807
# ...

# %%
df_temp=df.groupby(["Place",df['Date'].dt.year]).agg(PicturesPlacePerYear=('Picture Count','sum')).reset_index()
df_temp.sort_values(by="PicturesPlacePerYear",ascending=False).reset_index().drop(columns='index').head(60)
# Out:
#                Place  Date  PicturesPlacePerYear
# 0               Rome  2020                  1966
# 1               Rome  2013                  1792
# 2               Rome  2017                  1657
# 3             London  2014                  1331
# 4            Beijing  2018                  1112
# 5           Florence  2014                  1041
# 6              Paris  2010                   960
# 7             Naples  2019                   932
# 8      New York City  2009                   894
# 9              Paris  2019                   842
# 10             Paris  2021                   834
# 11            Vienna  2014                   807
# 12            Venice  2013                   807
# 13         Barcelona  2016                   770
# 14          Florence  2020                   768
# 15            Berlin  2012                   740
# 16            Prague  2021                   690
# 17             Paris  2013                   681
# ...

# %%
df_temp_dt=df.loc[(df['Day-Trip']==1)].groupby(["Country","Place",df['Date'].dt.year]).agg(PicturesPlacePerYear=('Picture Count','sum')).reset_index()
df_temp_dt.sort_values(by="PicturesPlacePerYear",ascending=False).reset_index().head(60)
# Out:
#     index         Country                    Place  Date  PicturesPlacePerYear
# 0     520     Switzerland                  Zermatt  2010                   540
# 1      60         Austria                 Salzburg  2021                   499
# 2     119          France                 Chamonix  2010                   439
# 3     358     Switzerland                     Genf  2007                   282
# 4      35         Austria           Klosterneuburg  2021                   268
# 5     305           Italy                   Milano  2013                   251
# 6     465     Switzerland                 Saas Fee  2010                   247
# 7     521     Switzerland                  Zermatt  2011                   243
# 8     364     Switzerland              Grindelwald  2010                   242
# 9      53         Austria                Obertraun  2021                   226
# 10    365     Switzerland              Grindelwald  2011                   223
# ...

# %%
df.groupby(["Country","Place"]).sum().tail(60)
# Out:
# /var/folders/8d/gvjspwlj4hq61gsmkn1p_h480000gn/T/ipykernel_6373/3648594197.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(["Country","Place"]).sum().tail(60)
#                                   Picture Count  Day-Trip  \
# Country        Place
# United Kingdom Ballycastle                   46         0
#                Bangor                         5         0
#                Bath                          75         0
#                Belfast                       26         0
#                Brighton                      55         0
#                Bushmills                     61         0
#                Caernarfon                    55         0
#                Cambridge                    106         0
#                Canterbury                   317         0
# ...

# %%
df['Date']=pd.to_datetime(df['Date'])

# %%
import re
#re.sub(r'\W+', '', your_string)

cotravellers=set()

#if I consider unique() just alone, then it would split everything directly into 

for expr in df['Co-Travellers'].unique():
    word_V1=expr.split(", ")
    for w in word_V1:
        name=re.sub(r"[^\w-]", ' ', w).strip()
        if name!="":
            cotravellers.add(name)
len(cotravellers)
# Out:
# 146

# %%
df_list_co_travellers=[]
for ind,ct in enumerate(cotravellers):
    print(ind, ct,": total/multi",df.loc[df['Co-Travellers'].str.contains(ct),"Picture Count"].sum(),df.loc[(df['Co-Travellers'].str.contains(ct)) & (df['Day-Trip']==0),"Picture Count"].sum(),
         "joined on",df.loc[(df['Co-Travellers'].str.contains(ct)),"Date"].nunique(),"dates")
    df_list_co_travellers.append([ct,
                                df.loc[df['Co-Travellers'].str.contains(ct),"Picture Count"].sum(),
                                df.loc[(df['Co-Travellers'].str.contains(ct)) &
                                        (df['Day-Trip']==0),"Picture Count"].sum(),
                                df.loc[(df['Co-Travellers'].str.contains(ct)) &
                                        (df['Day-Trip']==1),"Picture Count"].sum(),
                                df.loc[(df['Co-Travellers'].str.contains(ct)),"Date"].nunique(),
                                df.loc[(df['Co-Travellers'].str.contains(ct)) &
                                        (df['Day-Trip']==0),"Date"].nunique(),
                                df.loc[(df['Co-Travellers'].str.contains(ct)) &
                                        (df['Day-Trip']==1),"Date"].nunique(),
                                df.loc[df['Co-Travellers'].str.contains(ct),"Country"].nunique(),
                                df.loc[df['Co-Travellers'].str.contains(ct),"Place"].nunique(),
                                df.loc[(df['Co-Travellers'].str.contains(ct)),"Date"].min(),
                                df.loc[(df['Co-Travellers'].str.contains(ct)),"Date"].max()                             
                                 ])
    if df.loc[(df['Co-Travellers'].str.contains(ct)),"Date"].nunique()>1:
        min_x=df.loc[(df['Co-Travellers'].str.contains(ct)),"Date"].min()-np.timedelta64(2,"M")
        max_x=df.loc[(df['Co-Travellers'].str.contains(ct)),"Date"].max()+np.timedelta64(2,"M")
        fig, ax = plt.subplots()
        max_y=1.25*df[df['Co-Travellers'].str.contains(ct)].groupby(pd.Grouper(key="Date", freq="1D")).sum()["Picture Count"].max()
        df[df['Co-Travellers'].str.contains(ct)].groupby(pd.Grouper(key="Date", freq="1D")).sum()["Picture Count"].plot(title="daily count of pictures in trips",ylabel="picture count",xlim=(min_x,max_x),ylim=(0,max_y))
        plt.show()
# Out:
# 0 May : total/multi 12 12 joined on 1 dates
# 1 Santona : total/multi 825 488 joined on 5 dates
# /var/folders/8d/gvjspwlj4hq61gsmkn1p_h480000gn/T/ipykernel_6373/831692796.py:25: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   max_y=1.25*df[df['Co-Travellers'].str.contains(ct)].groupby(pd.Grouper(key="Date", freq="1D")).sum()["Picture Count"].max()
# /var/folders/8d/gvjspwlj4hq61gsmkn1p_h480000gn/T/ipykernel_6373/831692796.py:26: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
# ...

# %%
df_coTrav = pd.DataFrame(df_list_co_travellers,columns=['Co-Traveller', 'Photos','PhotosMultiDay','PhotosSingleDay','Days',"Days_Multi","Days_Single","N_Countries","N_Places","FirstTripDate",'LastTripDate'])
df_coTrav=df_coTrav.sort_values(by="Photos",ascending=False).reset_index().drop(columns='index')
df_coTrav.to_csv("../data/data_cotravellers.csv")

# %%
df_coTrav.head(60)
# Out:
#       Co-Traveller  Photos  PhotosMultiDay  PhotosSingleDay  Days  Days_Multi  \
# 0            Artur   30931           25781             5150   388         285
# 1          Heidrun   23038           20389             2649   296         240
# 2       Hannsjoerg   14008            9230             4778   260         185
# 3             Riju    8659            7719              940    61          51
# 4            Reyer    4479            4437               42    29          28
# 5             Eric    3647            3322              325    30          26
# 6     Anne-Kathrin    3392            2545              847   143         111
# 7          Chris B    3134            2446              688    19          14
# 8           Manuel    2303            2033              270    21          17
# 9             Amin    2302            2302                0    14          14
# 10         Grace C    2100            1346              754    14           8
# ...

# %%
df_coTrav
# Out:
#     Co-Traveller  Photos  PhotosMultiDay  PhotosSingleDay  Days  Days_Multi  \
# 0          Artur   30931           25781             5150   388         285
# 1        Heidrun   23038           20389             2649   296         240
# 2     Hannsjoerg   14008            9230             4778   260         185
# 3           Riju    8659            7719              940    61          51
# 4          Reyer    4479            4437               42    29          28
# ..           ...     ...             ...              ...   ...         ...
# 141       Fabian       3               0                3     1           0
# 142        Sofie       3               0                3     1           0
# 143         Kate       2               0                2     1           0
# 144       Ursula       2               0                2     1           0
# 145     US folks       1               0                1     1           0
#
# ...

# %%
#Germany,Switzerland,Austria,Luxemburg,Belgium,Ecuador,Japanese,USA,Mexico,China,Italy
#Canada,Poland,Bulgaria,Norway,Greece,Iran,Bangladesh,Czech,Ukraine,India,Romania
#Sweden,United Kingdom,Slovenia,Egypt,Cuba,Indonesia,Serbia

#oberunterhitze 200

# %%
df.groupby(["Place"]).agg(
    PicturesAtPlace=('Picture Count','sum'),
    DaysWithPictures=('Date','nunique')).sort_values(
    by=["PicturesAtPlace"],ascending=False).reset_index().head(40)
# Out:
#                Place  PicturesAtPlace  DaysWithPictures
# 0               Rome             5508                29
# 1              Paris             4628                46
# 2             London             2710                41
# 3             Venice             2244                14
# 4           Florence             2181                10
# 5             Prague             1552                 9
# 6           Chamonix             1543                13
# 7            Zermatt             1524                10
# 8             Berlin             1470                23
# 9             Munich             1420                18
# 10            Naples             1353                11
# 11            Vienna             1323                15
# 12            Madrid             1230                27
# 13         Barcelona             1193                11
# 14           Potsdam             1164                 7
# 15           Beijing             1112                 7
# ...

# %%
df.loc[(df['Place']=='Meyrin')].groupby(["Place"]).agg(
    PicturesAtPlace=('Picture Count','sum'),
    DaysWithPictures=('Date','nunique')).sort_values(
    by=["PicturesAtPlace"],ascending=False).reset_index().head(40)
# Out:
#     Place  PicturesAtPlace  DaysWithPictures
# 0  Meyrin               98                14
