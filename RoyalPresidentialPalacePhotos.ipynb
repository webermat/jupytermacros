# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime

# %%
data_list=[]

# %%
#1996
data_list.append([datetime.datetime(1996, 8, 28),4,"Tower of London","London","United Kingdom","Romanesque",'','',"Tower of London",0,["Heidrun",'Artur','Jan-Marc','Hannsjoerg','Anne-Kathrin']])
data_list.append([datetime.datetime(1996, 8, 27),5,"Hampton Court Palace","London","United Kingdom","Gothic",'Baroque','',"",0,["Heidrun",'Artur','Jan-Marc','Hannsjoerg','Anne-Kathrin']])
data_list.append([datetime.datetime(1996, 8, 28),1,"Kensington Palace","London","United Kingdom","Baroque",'','',"",0,["Heidrun",'Artur','Jan-Marc','Hannsjoerg','Anne-Kathrin']])
data_list.append([datetime.datetime(1996, 8, 30),1,"St James's Palace","London","United Kingdom","Gothic",'','',"",0,["Heidrun",'Artur','Jan-Marc','Hannsjoerg','Anne-Kathrin']])
data_list.append([datetime.datetime(1996, 8, 30),1,"Whitehall - Banqueting House","London","United Kingdom","Baroque",'','',"",0,["Heidrun",'Artur','Jan-Marc','Hannsjoerg','Anne-Kathrin']])
data_list.append([datetime.datetime(1996, 8, 26),2,"Buckingham Palace","London","United Kingdom","Classicist",'','',"",0,["Heidrun",'Artur','Hannsjoerg','Jan-Marc','Anne-Kathrin']])
data_list.append([datetime.datetime(1996, 8, 29),2,"Queen's House","London","United Kingdom","Renaissance",'','',"Maritime Greenwich",0,["Heidrun",'Artur','Hannsjoerg','Jan-Marc','Anne-Kathrin']])
#1997
data_list.append([datetime.datetime(1997, 8, 27),3,"Palazzo Apostolico","Rome","Vatican","Renaissance",'Gothic','',"Vatican City",0,["Heidrun",'Artur','Hannsjoerg','Jan-Marc','Anne-Kathrin']])
data_list.append([datetime.datetime(1997, 8, 27),1,"Castel Sant'Angelo","Rome","Italy","Renaissance",'Roman','',"Rome",0,["Heidrun",'Artur','Hannsjoerg','Jan-Marc','Anne-Kathrin']])
data_list.append([datetime.datetime(1997, 8, 24),1,"Palazzo Quirinale","Rome","Italy","Baroque",'Classicist','',"Rome",0,["Heidrun",'Artur','Hannsjoerg','Jan-Marc','Anne-Kathrin']])
data_list.append([datetime.datetime(1997, 8, 25),3,"Imperial Palace on Palatine Hill","Rome","Italy","Roman",'','',"Rome",0,["Heidrun",'Artur','Hannsjoerg','Jan-Marc','Anne-Kathrin']])
data_list.append([datetime.datetime(1997, 8, 31),4,"Palazzo Apostolico","Rome","Vatican","Renaissance",'Gothic','',"Vatican City",0,["Heidrun",'Artur','Hannsjoerg','Jan-Marc','Anne-Kathrin']])
data_list.append([datetime.datetime(1997, 5, 22),3,"Munich Residence","Munich","Germany","Classicist",'Baroque','Renaissance',"",0,["Heidrun",'Artur','Hannsjoerg','Jan-Marc','Anne-Kathrin']])
data_list.append([datetime.datetime(1997, 5, 23),1,"Schloss Nymphenburg","Munich","Germany","Baroque",'Classicist','',"",0,["Heidrun",'Artur','Hannsjoerg','Jan-Marc','Anne-Kathrin']])
data_list.append([datetime.datetime(1997, 5, 23),2,"Amalienburg","Munich","Germany","Rococo",'','',"",0,["Heidrun",'Artur','Hannsjoerg','Jan-Marc','Anne-Kathrin']])
data_list.append([datetime.datetime(1997, 5, 23),1,"Badenburg","Munich","Germany","Baroque",'','',"",0,["Heidrun",'Artur','Hannsjoerg','Jan-Marc','Anne-Kathrin']])
#1998
data_list.append([datetime.datetime(1998, 8, 25),3,"Chateau de Versailles","Versailles","Paris","Baroque",'Rococo','Classicist',"Palace and Park of Versailles",0,["Heidrun",'Artur','Hannsjoerg','Jan-Marc','Anne-Kathrin']])
data_list.append([datetime.datetime(1998, 8, 25),1,"Grand Trianon","Versailles","Paris","Baroque",'Classicist','',"Palace and Park of Versailles",0,["Heidrun",'Artur','Hannsjoerg','Jan-Marc','Anne-Kathrin']])
data_list.append([datetime.datetime(1998, 8, 25),1,"Petit Trianon","Versailles","Paris",'Classicist','','',"Palace and Park of Versailles",0,["Heidrun",'Artur','Hannsjoerg','Jan-Marc','Anne-Kathrin']])
data_list.append([datetime.datetime(1998, 8, 23),15,"Palais du Louvre","Paris","France","Baroque",'Renaissance','Classicist',"Paris, Banks of the Seine",0,["Heidrun",'Artur','Hannsjoerg','Jan-Marc','Anne-Kathrin']])
data_list.append([datetime.datetime(1998, 8, 24),7,"Palais de la Cite","Paris","France","Gothic",'','',"Paris, Banks of the Seine",0,["Heidrun",'Artur','Hannsjoerg','Jan-Marc','Anne-Kathrin']])
#2000
data_list.append([datetime.datetime(2000, 5, 18),5,"Munich Residence","Munich","Germany","Classicist",'Baroque','Renaissance',"",0,['Vera']])

# %%
#2004
data_list.append([datetime.datetime(2004, 10, 17),8,"Tower of London","London","United Kingdom","Romanesque",'','',"Tower of London",0,["Gianrico","Sigi",'Anne']])
data_list.append([datetime.datetime(2004, 7, 7),6,"Bardo Palace","Tunis","Tunisia","Islamic",'','',"Tunis",0,["Gianrico","Sigi"]])

#2006
data_list.append([datetime.datetime(2006, 7, 14),1,"Tower of London","London","United Kingdom","Romanesque",'','',"Tower of London",0,["Heidrun",'Artur','Jan-Marc','Hannsjoerg','Anne-Kathrin']])
data_list.append([datetime.datetime(2006, 7, 13),1,"Kensington Palace","London","United Kingdom","Baroque",'','',"",0,["Heidrun",'Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2006, 7, 11),1,"Buckingham Palace","London","United Kingdom","Classicist",'','',"",0,["Heidrun",'Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2006, 7, 11),1,"St James's Palace","London","United Kingdom","Gothic",'','',"",0,["Heidrun",'Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2006, 7, 12),17,"Windsor Castle","Windsor","United Kingdom","Baroque",'Gothic','neo-Gothic',"",0,["Heidrun",'Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2006, 7, 12),6,"Palace of Westminster","London","United Kingdom","Gothic",'','',"Westminster",0,["Heidrun",'Artur','Hannsjoerg']])

# %%
#2010
data_list.append([datetime.datetime(2010, 4, 5),11,"Schloss Hohenschwangau","Schwangau","Germany","neo-Gothic",'','',"",0,['Hannsjoerg']])
data_list.append([datetime.datetime(2010, 4, 5),37,"Schloss Neuschwanstein","Schwangau","Germany","neo-Romanesque",'','',"",0,['Hannsjoerg']])
data_list.append([datetime.datetime(2010, 4, 6),34,"Schloss Linderhof","Ettal","Germany","neo-Rococo",'','',"",0,['Hannsjoerg']])
data_list.append([datetime.datetime(2014, 4, 8),70,"Munich Residence","Munich","Germany","Classicist",'Baroque','Renaissance',"",0,['Hannsjoerg']])
data_list.append([datetime.datetime(2014, 4, 7),32,"Schloss Nymphenburg","Munich","Germany","Baroque",'Classicist','',"",0,['Hannsjoerg']])
data_list.append([datetime.datetime(2014, 4, 7),13,"Amalienburg","Munich","Germany","Rococo",'','',"",0,['Hannsjoerg']])
data_list.append([datetime.datetime(2014, 4, 7),8,"Badenburg","Munich","Germany","Baroque",'','',"",0,['Hannsjoerg']])
data_list.append([datetime.datetime(2014, 4, 7),6,"Pagodenburg","Munich","Germany","Rococo",'','',"",0,['Hannsjoerg']])
data_list.append([datetime.datetime(2014, 4, 7),6,"Magdalenenklause","Munich","Germany","Revival",'','',"",0,['Hannsjoerg']])
data_list.append([datetime.datetime(2010, 7, 25),115,"Chateau de Versailles","Versailles","Paris","Baroque",'Rococo','Classicist',"Palace and Park of Versailles",0,[]])
data_list.append([datetime.datetime(2010, 7, 25),28,"Grand Trianon","Versailles","Paris","Baroque",'Classicist','',"Palace and Park of Versailles",0,[]])
data_list.append([datetime.datetime(2010, 7, 25),24,"Petit Trianon","Versailles","Paris",'Classicist','','',"Palace and Park of Versailles",0,[]])
data_list.append([datetime.datetime(2010, 8, 1),52,"Palais du Louvre","Paris","France","Baroque",'Renaissance','Classicist',"Paris, Banks of the Seine",0,['Heidrun','Artur']])
data_list.append([datetime.datetime(2010, 7, 21),36,"Palais de la Cite","Paris","France","Gothic",'','',"Paris, Banks of the Seine",0,[]])
data_list.append([datetime.datetime(2010, 7, 21),10,"Palais du Louvre","Paris","France","Baroque",'Renaissance','Classicist',"Paris, Banks of the Seine",0,[]])
data_list.append([datetime.datetime(2010, 7, 23),1,"Palais de la Cite","Paris","France","Gothic",'','',"Paris, Banks of the Seine",0,[]])
data_list.append([datetime.datetime(2010, 7, 23),12,"Palais du Louvre","Paris","France","Baroque",'Renaissance','Classicist',"Paris, Banks of the Seine",0,[]])
data_list.append([datetime.datetime(2010, 7, 30),75,"Chateau de Fontainebleau","Fontainebleau","France","Classicist",'Renaissance','Baroque',"Fontainebleau",0,['Heidrun',"Artur"]])
data_list.append([datetime.datetime(2010, 7, 31),41,"Chateau des Vincennes","Vincennes","France","Gothic",'Baroque','',"",0,['Heidrun',"Artur"]])
data_list.append([datetime.datetime(2010, 8, 22),42,"Burg Hohenzollern","Hechingen","Germany","neo-Gothic",'Gothic','',"",1,['Heidrun',"Artur","Hannsjoerg"]])

#2011
data_list.append([datetime.datetime(2011, 1, 11),2,"Palazzo Reale","Milano","Italy","Classicist",'','',"",1,['Hannsjoerg']])
data_list.append([datetime.datetime(2011, 8, 28),108,"Residenzschloss Ludwigsburg","Ludwigsburg","Germany","Baroque",'Rokoko','Classicist',"",1,['Hannsjoerg','Heidrun','Artur']])
data_list.append([datetime.datetime(2011, 8, 28),14,"Schloss Favorite","Ludwigsburg","Germany","Classicist",'','',"",1,['Hannsjoerg','Heidrun','Artur']])
data_list.append([datetime.datetime(2021, 9,5),3,"Hofburg","Innsbruck","Austria","Baroque",'Classicist','',"",0,['Heidrun']])
data_list.append([datetime.datetime(2011, 12, 28),23,"Hofburg","Vienna","Austria","Baroque",'Classicist','Renaissance',"Vienna",0,['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2011, 12, 29),50,"Hofburg","Vienna","Austria","Baroque",'Classicist','Renaissance',"Vienna",0,['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2011, 12, 30),5,"Hofburg","Vienna","Austria","Baroque",'Classicist','Renaissance',"Vienna",0,['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2011, 12, 27),24,"Schloss Schoenbrunn","Vienna","Austria","Rococo","Baroque",'Classicist',"Gardens and Palace of Schoenbrunn",0,['Heidrun','Artur','Hannsjoerg']])

# %%
#2012
data_list.append([datetime.datetime(2012, 5, 11),16,"Karlstejn Castle","Karlstejn","Czech","Gothic",'','',"",0,['Heidrun','Artur']])
data_list.append([datetime.datetime(2012, 5, 11),13,"Prague Castle","Prague","Czech","Baroque",'Renaissance','',"Prague",0,['Heidrun','Artur']])
data_list.append([datetime.datetime(2012, 5, 12),98,"Prague Castle","Prague","Czech","Baroque",'Renaissance','',"Prague",0,['Heidrun','Artur']])
data_list.append([datetime.datetime(2012, 5, 31),57,"Chateau de Chenonceau","Chenonceaux","France","Renaissance",'','',"",0,['Heidrun','Artur']])
data_list.append([datetime.datetime(2012, 5, 31),3,"Chateau de Blois","Blois","France","Renaissance",'Baroque','',"Loire Valley between Sully-sur-Loire and Chalonnes",0,['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2012, 6, 1),62,"Chateau de Blois","Blois","France","Renaissance",'Baroque','',"Loire Valley between Sully-sur-Loire and Chalonnes",0,['Heidrun','Artur']])
data_list.append([datetime.datetime(2012, 6, 1),35,"Chateau de Amboise","Amboise","France","Renaissance",'Gothic','',"Loire Valley between Sully-sur-Loire and Chalonnes",0,['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2012, 6, 2),87,"Chateau de Chambord","Chambord","France","Renaissance",'Baroque','',"Loire Valley between Sully-sur-Loire and Chalonnes",0,['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2012, 7, 26),51,"Schloss Sanssouci","Potsdam","Germany","Rococo",'Classicist','',"Palaces and Parks of Potsdam and Berlin",0,[]])
data_list.append([datetime.datetime(2012, 7, 26),13,"Schloss Sanssouci - Neues Palais","Potsdam","Germany","Rococo",'Classicist','neo-Baroque',"Palaces and Parks of Potsdam and Berlin",0,[]])
data_list.append([datetime.datetime(2012, 7, 26),20,"Schloss Sanssouci - Orangerieschloss","Potsdam","Germany","neo-Renaissance",'','',"Palaces and Parks of Potsdam and Berlin",0,[]])
data_list.append([datetime.datetime(2012, 7, 26),12,"Schloss Sanssouci - Charlottenhof","Potsdam","Germany","Classicist",'','',"Palaces and Parks of Potsdam and Berlin",0,[]])
data_list.append([datetime.datetime(2012, 7, 26),5,"Schloss Sanssouci - Roemisches Bad","Potsdam","Germany","neo-Roman",'','',"Palaces and Parks of Potsdam and Berlin",0,[]])
data_list.append([datetime.datetime(2012, 7, 26),46,"Marmorpalais","Potsdam","Germany","Classicist",'','',"Palaces and Parks of Potsdam and Berlin",0,[]])
data_list.append([datetime.datetime(2012, 7, 27),23,"Schloss Glienicke","Berlin","Germany","Classicist",'','',"Palaces and Parks of Potsdam and Berlin",0,[]])
data_list.append([datetime.datetime(2012, 7, 27),33,"Schloss Pfaueninsel","Berlin","Germany","Baroque",'','',"Palaces and Parks of Potsdam and Berlin",0,[]])
data_list.append([datetime.datetime(2012, 7, 27),10,"Schloss Babelsberg","Potsdam","Germany","neo-Gothic",'','',"Palaces and Parks of Potsdam and Berlin",0,[]])
data_list.append([datetime.datetime(2012, 7, 28),59,"Schloss Sanssouci","Potsdam","Germany","Rococo",'Classicist','',"Palaces and Parks of Potsdam and Berlin",0,["Gianrico"]])
data_list.append([datetime.datetime(2012, 7, 28),2,"Schloss Sanssouci - Neues Palais","Potsdam","Germany","Rococo",'Classicist','neo-Baroque',"Palaces and Parks of Potsdam and Berlin",0,[]])
data_list.append([datetime.datetime(2012, 7, 28),6,"Schloss Sanssouci - Orangerieschloss","Potsdam","Germany","neo-Renaissance",'','',"Palaces and Parks of Potsdam and Berlin",0,['Gianrico']])
data_list.append([datetime.datetime(2012, 7, 28),12,"Schloss Sanssouci - Maschinenhaus","Potsdam","Germany","neo-Islamic",'','',"Palaces and Parks of Potsdam and Berlin",0,[]])
data_list.append([datetime.datetime(2012, 7, 30),34,"Schloss Bellevue","Berlin","Germany","Baroque",'','',"",0,[]])
data_list.append([datetime.datetime(2012, 7, 25),75,"Schloss Charlottenburg","Berlin","Germany","Rococo",'Baroque','Classicist',"",0,[]])
data_list.append([datetime.datetime(2012, 7, 25),15,"Schloss Charlottenburg - Neuer Pavillon","Berlin","Germany","Classicist",'','',"",0,[]])
data_list.append([datetime.datetime(2012, 7, 25),36,"Schloss Schoenhausen","Berlin","Germany","Baroque",'neo-Baroque','',"",0,[]])
data_list.append([datetime.datetime(2012, 8, 31),44,"Palacio de Mafra","Mafra","Portugal","Baroque",'','',"Palace of Mafra",0,[]])
data_list.append([datetime.datetime(2012, 8, 31),48,"Palacio de Queluz","Queluz","Portugal","Rokoko",'','',"",0,[]])
data_list.append([datetime.datetime(2012, 8, 31),26,"Sinta National Palace","Sintra","Portugal","Gothic",'Renaissance','',"Cultural Landscape of Sintra",0,[]])
data_list.append([datetime.datetime(2012, 8, 31),1,"Palacio de Pena","Sintra","Portugal","Gothic",'Renaissance','',"Cultural Landscape of Sintra",0,[]])
data_list.append([datetime.datetime(2012, 9, 1),28,"Palacio de Pena","Sintra","Portugal","Gothic",'Renaissance','',"Cultural Landscape of Sintra",0,[]])
data_list.append([datetime.datetime(2012, 9, 1),2,"Sinta National Palace","Sintra","Portugal","Gothic",'Renaissance','',"Cultural Landscape of Sintra",0,[]])
data_list.append([datetime.datetime(2012, 9, 2),36,"Palacio de Ajuda","Belem","Portugal","Classicist",'','',"",0,['David']])
data_list.append([datetime.datetime(2012, 9, 2),14,"Palacio de Belem","Belem","Portugal","Baroque",'','',"",0,['David']])
data_list.append([datetime.datetime(2012, 9, 28),21,"Lazienkowski - Palace on the Water","Warsaw","Classicist","",'','',"",0,['Eric']])
data_list.append([datetime.datetime(2012, 9, 28),40,"Lazienkowski - Myslewicki Palace","Warsaw","Classicist","",'','',"",0,['Eric']])
data_list.append([datetime.datetime(2012, 9, 28),1,"Lazienkowski - White House","Warsaw","Classicist","",'','',"",0,['Eric']])
data_list.append([datetime.datetime(2012, 9, 29),16,"Wawel Royal Palace","Krakow","Poland","Renaissance",'','',"Krakow",0,['Eric']])
data_list.append([datetime.datetime(2012, 9, 30),69,"Wilanow Palace","Warsaw","Baroque","",'','',"",0,['Eric']])
data_list.append([datetime.datetime(2012, 9, 30),63,"Royal Palace","Warsaw","Baroque","Classicist",'','',"Warsaw",0,['Eric']])
data_list.append([datetime.datetime(2012, 10, 1),7,"Lazienkowski - White House","Warsaw","Classicist","",'','',"",0,['Eric']])
data_list.append([datetime.datetime(2012, 10, 1),10,"Lazienkowski - Orangerie Palace","Warsaw","Classicist","",'','',"",0,['Eric']])

# %%
#2013
data_list.append([datetime.datetime(2013, 1, 2),60,"Royal Palace","Amsterdam","Netherlands","Baroque",'Classicist','',"",0,["Heidrun",'Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2013, 1, 3),66,"Het Loo Palace","Appeldoorn","Netherlands","Baroque",'Classicist','',"",0,[]])
data_list.append([datetime.datetime(2013, 1, 4),16,"Binnenhof","Den Haag","Netherlands","Gothic",'Baroque','',"",0,["Heidrun",'Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2013, 1, 4),2,"Kneuterdijk Palace","Den Haag","Netherlands","Gothic",'Baroque','',"",0,["Heidrun",'Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2013, 1, 4),2,"Noordeinde Palace","Den Haag","Netherlands","Classicist",'','',"",0,["Heidrun",'Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2013, 1, 4),15,"Lange Voorhout Palace","Den Haag","Netherlands","Classicist",'Baroque','',"",0,["Heidrun",'Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2013, 1, 5),9,"Soestdijk Palace","Soestdijk","Netherlands","Classicist",'','',"",0,[]])
data_list.append([datetime.datetime(2013, 3, 22),124,"Chateau de Versailles","Versailles","Paris","Baroque",'Rococo','Classicist',"Palace and Park of Versailles",0,["Andrew"]])
data_list.append([datetime.datetime(2013, 3, 22),24,"Grand Trianon","Versailles","Paris","Baroque",'Classicist','',"Palace and Park of Versailles",0,["Andrew"]])
data_list.append([datetime.datetime(2013, 3, 22),24,"Petit Trianon","Versailles","Paris",'Classicist','','',"Palace and Park of Versailles",0,["Andrew"]])
data_list.append([datetime.datetime(2013, 3, 22),38,"Palais du Louvre","Paris","France","Baroque",'Renaissance','Classicist',"Paris, Banks of the Seine",0,['Andrew']])
data_list.append([datetime.datetime(2013, 3, 22),37,"Palais de la Cite","Paris","France","Gothic",'','',"Paris, Banks of the Seine",0,['Andrew']])
data_list.append([datetime.datetime(2013, 3, 24),123,"Chateau de Fontainebleau","Fontainebleau","France","Classicist",'Renaissance','Baroque',"Fontainebleau",0,['Andrew']])
data_list.append([datetime.datetime(2013, 4, 4),86,"Palazzo Apostolico","Rome","Vatican","Renaissance",'Gothic','',"Vatican City",0,["Heidrun"]])
data_list.append([datetime.datetime(2013, 4, 4),7,"Castel Sant'Angelo","Rome","Italy","Renaissance",'Roman','',"Rome",0,["Heidrun"]])
data_list.append([datetime.datetime(2013, 4, 5),47,"Palazzo del Laterano","Rome","Vatican","Baroque",'','',"Rome",0,["Heidrun"]])
data_list.append([datetime.datetime(2013, 4, 7),7,"Palazzo Quirinale","Rome","Italy","Baroque",'Classicist','',"Rome",0,["Heidrun"]])
data_list.append([datetime.datetime(2013, 4, 8),14,"Imperial Palace on Palatine Hill","Rome","Italy","Roman",'','',"Rome",0,["Heidrun"]])
data_list.append([datetime.datetime(2013, 4, 9),63,"Villa Adriana","Tivoli","Italy","Roman",'','',"Villa Adriana",0,["Heidrun"]])
data_list.append([datetime.datetime(2013, 7, 7),24,"Palazzo Reale","Milano","Italy","Classicist",'','',"",0,['Nick','Andrew']])
data_list.append([datetime.datetime(2013, 7, 15),35,"Royal Palace","Stockholm","Sweden","Baroque",'Classicist','',"",0,[]])
data_list.append([datetime.datetime(2013, 7, 16),27,"Drottningholm Palace","Drottningholm","Sweden","Baroque",'','',"Royal Domain of Drottningholm",0,[]])
data_list.append([datetime.datetime(2013, 7, 16),11,"Drottningholm Palace - Chinese Palace","Drottningholm","Sweden","Rococo",'','',"Royal Domain of Drottningholm",0,[]])
data_list.append([datetime.datetime(2013, 7, 16),14,"Ulriksdal Palace","Ulriksdal","Sweden","neo-Gothic",'','',"",0,[]])
data_list.append([datetime.datetime(2013, 7, 17),45,"Gripsholmm Palace","Mariefred","Sweden","Renaissance",'Baroque','',"",0,[]])
data_list.append([datetime.datetime(2013, 7, 20),21,"Royal Palace","Stockholm","Sweden","Baroque",'Classicist','',"",0,[]])
data_list.append([datetime.datetime(2013, 7, 21),16,"Rosersberg Palace","Rosersberg","Sweden","Classicist",'','',"",0,[]])
data_list.append([datetime.datetime(2013, 7, 21),12,"Rosendal Palace","Stockholm","Sweden","Classicist",'','',"",0,[]])
data_list.append([datetime.datetime(2013, 7, 23),4,"Pavilion Gustav III","Stockholm","Sweden","Baroque",'','',"",0,[]])
data_list.append([datetime.datetime(2013, 7, 25),61,"Frederiskborg","Hillerod","Denmark","Renaissance",'','',"",0,[]])
data_list.append([datetime.datetime(2013, 7, 26),81,"Kronborg","Helsingor","Denmark","Renaissance",'','',"Kronborg",0,[]])
data_list.append([datetime.datetime(2013, 7, 26),33,"Fredensborg","Fredensborg","Denmark","Rococo",'Baroque','',"",0,[]])
data_list.append([datetime.datetime(2013, 7, 25),119,"Christiansborg","Copenhagen","Denmark","neo-Baroque",'','',"",0,[]])
data_list.append([datetime.datetime(2013, 7, 27),138,"Rosenborg","Copenhagen","Denmark","Renaissance",'Baroque','',"",0,['Susanne']])
data_list.append([datetime.datetime(2013, 7, 27),51,"Amalienborg","Copenhagen","Denmark","Classicist",'Rococo','',"",0,['Susanne']])
data_list.append([datetime.datetime(2013, 7, 28),5,"Christiansborg","Copenhagen","Denmark","neo-Baroque",'','',"",0,[]])
data_list.append([datetime.datetime(2013, 9, 6),21,"Palazzo Reale","Venice","Italy","Classicist",'','',"Venice and its Lagoon",0,[]])
data_list.append([datetime.datetime(2013, 11, 8),48,"Chateau de Compiegne","Compiegne","France","Classicist",'','',"",0,['Eric','Chris Clarke','Chris Lee']])
data_list.append([datetime.datetime(2013, 11, 8),32,"Palais du Louvre","Paris","France","Baroque",'Renaissance','Classicist',"Paris, Banks of the Seine",0,['Eric','Chris Clarke','Chris Lee']])
data_list.append([datetime.datetime(2013, 11, 9),38,"Chateau de Malmaison","Malmaison","France","Classicist",'','',"",0,['Eric']])
data_list.append([datetime.datetime(2013, 11, 11),42,"Palais de la Cite","Paris","France","Gothic",'','',"Paris, Banks of the Seine",0,['Eric','Chris Clarke','Chris Lee']])

# %%
#2014
data_list.append([datetime.datetime(2014, 4, 18),16,"Schloss Hohenschwangau","Schwangau","Germany","neo-Gothic",'','',"",0,['Indara','Eric']])
data_list.append([datetime.datetime(2014, 4, 18),35,"Schloss Neuschwanstein","Schwangau","Germany","neo-Romanesque",'','',"",0,['Indara','Eric']])
data_list.append([datetime.datetime(2014, 4, 19),52,"Schloss Linderhof","Ettal","Germany","neo-Rococo",'','',"",0,['Indara','Eric']])
data_list.append([datetime.datetime(2014, 4, 20),12,"Schloss Herrenchiemsee","Herrenchiemsee","Germany","neo-Baroque",'','',"",0,['Indara','Eric']])
data_list.append([datetime.datetime(2014, 4, 20),8,"Residenz","Landshut","Germany","Renaissance",'Classicist','',"",0,['Indara','Eric']])
data_list.append([datetime.datetime(2014, 4, 20),181,"Munich Residence","Munich","Germany","Classicist",'Baroque','Renaissance',"",0,['Indara','Eric']])
data_list.append([datetime.datetime(2014, 4, 20),64,"Schloss Nymphenburg","Munich","Germany","Baroque",'Classicist','',"",0,['Indara','Eric']])
data_list.append([datetime.datetime(2014, 4, 20),35,"Amalienburg","Munich","Germany","Rococo",'','',"",0,['Indara','Eric']])
data_list.append([datetime.datetime(2014, 4, 20),19,"Badenburg","Munich","Germany","Baroque",'','',"",0,['Indara','Eric']])
data_list.append([datetime.datetime(2014, 4, 20),17,"Pagodenburg","Munich","Germany","Rococo",'','',"",0,['Indara','Eric']])
data_list.append([datetime.datetime(2014, 4, 20),13,"Magdalenenklause","Munich","Germany","Revival",'','',"",0,['Indara','Eric']])
data_list.append([datetime.datetime(2014, 7, 24),17,"Kew Palace","London","United Kingdom","Baroque",'','',"Kew Gardens",0,['Artur',"Heidrun",'Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(2014, 7, 25),103,"Windsor Castle","Windsor","United Kingdom","Baroque",'Gothic','neo-Gothic',"",0,["Heidrun"]])
data_list.append([datetime.datetime(2014, 7, 26),58,"Royal Pavilion","Brighton","United Kingdom","neo-Islamic",'','',"",0,["Heidrun"]])
data_list.append([datetime.datetime(2014, 7, 27),7,"Eltham Palace","London","United Kingdom","Gothic",'','',"",0,["Heidrun",'Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2014, 7, 27),45,"Kensington Palace","London","United Kingdom","Baroque",'','',"",0,["Heidrun"]])
data_list.append([datetime.datetime(2014, 7, 27),1,"St James's Palace","London","United Kingdom","Gothic",'','',"",0,["Heidrun",'Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2014, 7, 28),34,"Osborne House","East Cowen","United Kingdom","Classicist",'','',"",0,["Heidrun"]])
data_list.append([datetime.datetime(2014, 7, 29),30,"Tower of London","London","United Kingdom","Romanesque",'','',"Tower of London",0,["Heidrun"]])
data_list.append([datetime.datetime(2014, 7, 31),16,"Palace of Westminster","London","United Kingdom","Gothic",'','',"Westminster",0,["Heidrun",'Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2014, 7, 31),19,"Whitehall - Banqueting House","London","United Kingdom","Baroque",'','',"",0,["Heidrun"]])
data_list.append([datetime.datetime(2014, 8, 3),141,"Hampton Court Palace","London","United Kingdom","Gothic",'Baroque','',"",0,["Heidrun"]])
data_list.append([datetime.datetime(2014, 8, 4),21,"Buckingham Palace","London","United Kingdom","Classicist",'','',"",0,["Heidrun",'Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2014, 8, 4),1,"St James's Palace","London","United Kingdom","Gothic",'','',"",0,["Heidrun",'Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2014, 8, 22),92,"Hofburg","Vienna","Austria","Baroque",'Classicist','Renaissance',"Vienna",0,[]])
data_list.append([datetime.datetime(2014, 8, 23),20,"Hofburg","Vienna","Austria","Baroque",'Classicist','Renaissance',"Vienna",0,[]])
data_list.append([datetime.datetime(2014, 8, 23),2,"Palais Grassalkovich","Bratislava","Slovakia","Baroque",'','',"",0,[]])
data_list.append([datetime.datetime(2014, 8, 24),23,"Burg Pressburg","Bratislava","Slovakia","Baroque",'Modern','',"",0,[]])
data_list.append([datetime.datetime(2014, 8, 24),37,"Schloss Hof","Engelhartstetten","Austria","Baroque",'','',"",0,[]])
data_list.append([datetime.datetime(2014, 8, 26),2,"Hofburg","Vienna","Austria","Baroque",'Classicist','Renaissance',"Vienna",0,[]])
data_list.append([datetime.datetime(2014, 8, 27),58,"Hofburg","Vienna","Austria","Baroque",'Classicist','Renaissance',"Vienna",0,[]])
data_list.append([datetime.datetime(2014, 8, 28),102,"Schloss Schoenbrunn","Vienna","Austria","Rococo","Baroque",'Classicist',"Gardens and Palace of Schoenbrunn",0,[]])
data_list.append([datetime.datetime(2014, 8, 28),37,"Hermesvilla","Vienna","Classicist","",'','',"",0,[]])
data_list.append([datetime.datetime(2014, 8, 29),5,"Hofburg","Vienna","Austria","Baroque",'Classicist','Renaissance',"Vienna",0,[]])
data_list.append([datetime.datetime(2014, 8, 30),41,"Burgpalast","Budapest","Hungary","neo-Baroque",'','',"Budapest, including the Banks of the Danube, the Buda Castle Quarter and Andrassy Avenue",0,[]])
data_list.append([datetime.datetime(2014, 8, 30),2,"Sandorpalast","Budapest","Hungary","neo-Baroque",'','',"Budapest, including the Banks of the Danube, the Buda Castle Quarter and Andrassy Avenue",0,[]])
data_list.append([datetime.datetime(2014, 8, 30),46,"Goedoello Palace","Goedoello","Hungary","Classicist",'Baroque','',"",0,[]])
data_list.append([datetime.datetime(2014, 8, 31),26,"Burgpalast","Budapest","Hungary","neo-Baroque",'','',"Budapest, including the Banks of the Danube, the Buda Castle Quarter and Andrassy Avenue",0,[]])
data_list.append([datetime.datetime(2014, 8, 31),1,"Sandorpalast","Budapest","Hungary","neo-Baroque",'','',"Budapest, including the Banks of the Danube, the Buda Castle Quarter and Andrassy Avenue",0,[]])
data_list.append([datetime.datetime(2014, 9, 6),148,"Palazzo Pitti","Florence","Italy","Baroque",'Classicist','',"Florence",0,[]])
data_list.append([datetime.datetime(2014, 9, 6),76,"Villa della Petraia","Florence","Italy","Renaissance",'neo-Renaissance','',"Medici Villas and Gardens",0,[]])
data_list.append([datetime.datetime(2014, 9, 20),91,"Palais d'Elysee","Paris","France","Classicist",'Baroque','',"",0,[]])
data_list.append([datetime.datetime(2014, 10, 24),55,"Dolmabahce Palace","Istanbul","Turkey","Classicist",'Baroque','',"",0,['Chris Martin']])
data_list.append([datetime.datetime(2014, 10, 24),7,"Ihlamur Pavilions","Istanbul","Turkey","Baroque",'','',"",0,['Chris Martin']])
data_list.append([datetime.datetime(2014, 10, 25),146,"Topkapi Palace","Istanbul","Turkey","Islamic",'','',"Istanbul",0,['Chris Martin']])
data_list.append([datetime.datetime(2014, 10, 25),8,"Aynalikavak Pavilion","Istanbul","Turkey","Baroque",'','',"",0,['Chris Martin']])
data_list.append([datetime.datetime(2014, 10, 25),3,"Tekfur Palace","Istanbul","Turkey","Byzantine",'','',"Istanbul",0,['Chris Martin']])
data_list.append([datetime.datetime(2014, 10, 26),24,"Beylerbeyi Palace","Istanbul","Turkey","Baroque",'','',"",0,[]])
data_list.append([datetime.datetime(2014, 10, 26),21,"Kuecueksu Kiosk","Istanbul","Turkey","Rococo",'','',"",0,[]])
data_list.append([datetime.datetime(2014, 12, 13),32,"Hampton Court Palace","London","United Kingdom","Gothic",'Baroque','',"",0,["Manuel"]])
data_list.append([datetime.datetime(2014, 12, 13),4,"Tower of London","London","United Kingdom","Romanesque",'','',"Tower of London",0,["Manuel"]])
data_list.append([datetime.datetime(2014, 12, 14),15,"Windsor Castle","Windsor","United Kingdom","Baroque",'Gothic','neo-Gothic',"",0,["Manuel"]])

# %%
#2015
data_list.append([datetime.datetime(2015, 3, 14),53,"Villa Reale","Monza","Italy","Classicist",'','',"",0,['Nate','Laser','Devin','Kennedy','Can','Aaron','Christine']])
data_list.append([datetime.datetime(2015, 3, 14),6,"Palazzo Reale","Milano","Italy","Classicist",'','',"",0,['Nate','Laser','Devin','Kennedy','Can','Aaron','Christine']])
data_list.append([datetime.datetime(2015, 3, 15),18,"Palazzo Reale","Milano","Italy","Classicist",'','',"",0,['Nate','Laser','Devin','Kennedy','Can','Aaron','Christine']])
data_list.append([datetime.datetime(2015, 3, 29),55,"Alcazar","Sevilla","Spain","Islamic",'Renaissance','',"Cathedral, Alcazar and Archivo de Indias in Seville",0,['Manuel']])
data_list.append([datetime.datetime(2015, 3, 30),115,"Alhambra","Granada","Spain","Islamic",'Renaissance','',"Alhambra, Generalife and Albayzin",0,['Manuel']])
data_list.append([datetime.datetime(2015, 3, 30),8,"Generalife","Granada","Spain","Islamic",'','',"Alhambra, Generalife and Albayzin",0,['Manuel']])
data_list.append([datetime.datetime(2015, 3, 31),38,"Medina Azahara","Cordoba","Spain","Islamic",'','',"Medina Azahara",0,['Manuel']])
data_list.append([datetime.datetime(2015, 4, 1),27,"Alcazar","Segovia","Spain","Gothic",'Renaissance','',"Segovia",0,['Manuel']])
data_list.append([datetime.datetime(2015, 4, 1),24,"Palacio Real de La Granja de San Ildefenso","La Granja","Spain","Baroque",'','',"",0,['Manuel']])
data_list.append([datetime.datetime(2015, 4, 3),23,"Palacio de El Escorial","El Escorial","Spain","Renaissance",'Baroque','',"El Escorial Monastery",0,['Manuel']])
data_list.append([datetime.datetime(2015, 4, 3),3,"Casa dei Principe","El Escorial","Spain","Baroque",'','',"El Escorial Monastery",0,['Manuel']])
data_list.append([datetime.datetime(2015, 4, 5),16,"Palacio Real","Aranjuez","Spain","Baroque",'','',"Aranjuez Cultural Landscape",0,['Eric']])
data_list.append([datetime.datetime(2015, 4, 5),9,"Palacio Real","El Pardo","Spain","Baroque",'','',"",0,['Eric']])
data_list.append([datetime.datetime(2015, 4, 5),5,"Palacio Real","Madrid","Spain","Baroque",'','',"",0,['Eric']])
data_list.append([datetime.datetime(2015, 4, 6),36,"Palacio Real","Madrid","Spain","Baroque",'','',"",0,['Eric']])
data_list.append([datetime.datetime(2015, 5, 16),24,"Reggia di Portici","Portici","Italy","Baroque",'Classicist','',"",0,['AJ','Stephan']])
data_list.append([datetime.datetime(2015, 5, 16),7,"Castel Nuovo","Naples","Italy","Gothic",'','',"Naples",0,['AJ','Stephan']])
data_list.append([datetime.datetime(2015, 5, 17),156,"Reggia di Caserta","Caserta","Italy","Classicist",'','',"Reggia di Caserta",0,['AJ','Stephan']])
data_list.append([datetime.datetime(2015, 5, 17),29,"Reggia di Capodimonte","Naples","Italy","Classicist",'Baroque','',"Naples",0,['AJ','Stephan']])
data_list.append([datetime.datetime(2015, 5, 18),56,"Palazzo Reale","Naples","Italy","Classicist",'Baroque','',"Naples",0,['AJ','Stephan']])
data_list.append([datetime.datetime(2015, 5, 18),15,"Castel Nuovo","Naples","Italy","Gothic",'','',"Naples",0,[]])
data_list.append([datetime.datetime(2015, 7, 18),170,"Chateau de Versailles","Versailles","Paris","Baroque",'Rococo','Classicist',"Palace and Park of Versailles",0,["Riju"]])
data_list.append([datetime.datetime(2015, 7, 18),46,"Grand Trianon","Versailles","Paris","Baroque",'Classicist','',"Palace and Park of Versailles",0,["Riju"]])
data_list.append([datetime.datetime(2015, 7, 18),36,"Petit Trianon","Versailles","Paris",'Classicist','','',"Palace and Park of Versailles",0,["Riju"]])
data_list.append([datetime.datetime(2015, 8, 22),9,"Prince's Palace","Monaco","Monaco",'Classicist','Baroque','',"",0,["AJ",'Laser','Evan']])
data_list.append([datetime.datetime(2015, 8, 28),1,"Peterhof Palace","Peterhof","Russia",'Baroque','Classicist','',"Petersburg and Related Groups of Monuments",0,[]])
data_list.append([datetime.datetime(2015, 8, 28),1,"Konstantin's Palace","Strelna","Russia",'neo-Classicist','','',"Petersburg and Related Groups of Monuments",0,[]])
data_list.append([datetime.datetime(2015, 8, 28),1,"Winter Palace","St Petersburg","Russia",'Baroque','Classicist','',"Petersburg and Related Groups of Monuments",0,[]])
data_list.append([datetime.datetime(2015, 8, 30),72,"Pavlovsk Palace","Pavlovsk","Russia",'Classicist','','',"Petersburg and Related Groups of Monuments",0,[]])
data_list.append([datetime.datetime(2015, 8, 30),57,"Gatchina Palace","Gatchina","Russia",'Classicist','','',"Petersburg and Related Groups of Monuments",0,[]])
data_list.append([datetime.datetime(2015, 9, 2),62,"Kremlin","Moscow","Russia",'Classicist','Gothic','',"Kremlin and Red Square",0,['Manuel']])
data_list.append([datetime.datetime(2015, 9, 3),25,"Peterhof Palace","Peterhof","Russia",'Baroque','Classicist','',"Petersburg and Related Groups of Monuments",0,[]])
data_list.append([datetime.datetime(2015, 9, 5),2,"Michael's Castle","St Petersburg","Russia",'Classicist','','',"Petersburg and Related Groups of Monuments",0,["Manuel"]])
data_list.append([datetime.datetime(2015, 9, 5),8,"Winter Palace","St Petersburg","Russia",'Baroque','Classicist','',"Petersburg and Related Groups of Monuments",0,['Manuel']])
data_list.append([datetime.datetime(2015, 9, 6),5,"Alexander Palace","St Petersburg","Russia",'Classicist','','',"Petersburg and Related Groups of Monuments",0,['Manuel']])
data_list.append([datetime.datetime(2015, 9, 6),183,"Catherine Palace","St Petersburg","Russia",'Baroque','Rococo','Classicist',"Petersburg and Related Groups of Monuments",0,['Manuel']])
data_list.append([datetime.datetime(2015, 9, 6),20,"Catherine Palace - Eremitage","St Petersburg","Russia",'Baroque','','',"Petersburg and Related Groups of Monuments",0,['Manuel']])
data_list.append([datetime.datetime(2015, 9, 6),17,"Catherine Palace - Turkish Bath","St Petersburg","Russia",'Islamic','','',"Petersburg and Related Groups of Monuments",0,['Manuel']])
data_list.append([datetime.datetime(2015, 9, 7),14,"Michael's Castle","St Petersburg","Russia",'Classicist','','',"Petersburg and Related Groups of Monuments",0,["Manuel"]])
data_list.append([datetime.datetime(2015, 9, 8),139,"Winter Palace","St Petersburg","Russia",'Baroque','Classicist','',"Petersburg and Related Groups of Monuments",0,['Manuel']])
data_list.append([datetime.datetime(2015, 9, 9),22,"Elagin Palace","St Petersburg","Russia",'Classicist','','',"Petersburg and Related Groups of Monuments",0,[]])
data_list.append([datetime.datetime(2015, 9, 10),48,"Peterhof Palace","Peterhof","Russia",'Baroque','Classicist','',"Petersburg and Related Groups of Monuments",0,[]])
data_list.append([datetime.datetime(2015, 9, 10),37,"Colonist Park Pavilions","Peterhof","Russia",'Classicist','','',"Petersburg and Related Groups of Monuments",0,[]])
data_list.append([datetime.datetime(2015, 9, 10),37,"Peterhof Palaces","Peterhof","Russia",'neo-Gothic','','',"Petersburg and Related Groups of Monuments",0,[]])
data_list.append([datetime.datetime(2015, 9, 11),33,"Konstantin's Palace","Strelna","Russia",'neo-Classicist','','',"Petersburg and Related Groups of Monuments",0,[]])
data_list.append([datetime.datetime(2015, 9, 11),2,"Palace of Peter I","Strelna","Russia",'neo-Classicist','','',"Petersburg and Related Groups of Monuments",0,[]])
data_list.append([datetime.datetime(2015, 9, 20),3,"Palais de la Cite","Paris","France","Gothic",'','',"Paris, Banks of the Seine",0,["Christine",'Reyer']])
data_list.append([datetime.datetime(2015, 10, 4),55,"Munich Residence","Munich","Germany","Classicist",'Baroque','Renaissance',"",0,['Eric','Siyi']])
data_list.append([datetime.datetime(2015, 11, 8),60,"Schloss Sanssouci","Potsdam","Germany","Rococo",'Classicist','',"Palaces and Parks of Potsdam and Berlin",0,['Artur','Heidrun']])
data_list.append([datetime.datetime(2015, 11, 8),78,"Schloss Sanssouci - Neues Palais","Potsdam","Germany","Rococo",'Classicist','neo-Baroque',"Palaces and Parks of Potsdam and Berlin",0,['Artur','Heidrun']])
data_list.append([datetime.datetime(2015, 11, 8),1,"Schloss Sanssouci - Orangerieschloss","Potsdam","Germany","neo-Renaissance",'','',"Palaces and Parks of Potsdam and Berlin",0,['Artur','Heidrun']])
data_list.append([datetime.datetime(2015, 11, 10),1,"Stadtschloss","Berlin","Germany","Baroque",'','',"",0,['Artur','Heidrun','Anne-Kathrin']])
data_list.append([datetime.datetime(2015, 11, 12),22,"Schloss Bellevue","Berlin","Germany","Baroque",'','',"",0,['Artur','Heidrun','Anne-Kathrin']])
data_list.append([datetime.datetime(2015, 11, 15),132,"Schloss Charlottenburg","Berlin","Germany","Rococo",'Baroque','Classicist',"",0,['Artur','Heidrun']])
data_list.append([datetime.datetime(2015, 11, 15),11,"Schloss Charlottenburg - Neuer Pavillon","Berlin","Germany","Classicist",'','',"",0,['Artur','Heidrun']])

# %%
#2016
data_list.append([datetime.datetime(2016, 3, 17),1,"Norman Palace","Palermo","Italy","Romanesque",'Baroque','',"Arab-Norman Palermo and the Cathedral Churches of Cefalu and Monreale",0,['Artur','Heidrun']])
data_list.append([datetime.datetime(2016, 3, 18),76,"Norman Palace","Palermo","Italy","Romanesque",'Baroque','',"Arab-Norman Palermo and the Cathedral Churches of Cefalu and Monreale",0,['Artur','Heidrun']])
data_list.append([datetime.datetime(2016, 3, 18),47,"Castello della Zisa","Palermo","Italy","Romanesque",'','',"Arab-Norman Palermo and the Cathedral Churches of Cefalu and Monreale",0,['Artur','Heidrun']])
data_list.append([datetime.datetime(2016, 3, 18),11,"Castello della Cuba","Palermo","Italy","Romanesque",'','',"Arab-Norman Palermo and the Cathedral Churches of Cefalu and Monreale",0,[]])
data_list.append([datetime.datetime(2016, 3, 18),2,"Castello Ursino","Palermo","Italy","Romanesque",'','',"",0,[]])
data_list.append([datetime.datetime(2016, 3, 28),65,"Palacio de la Aljaferia","Zaragoza","Spain","Islamic",'Gothic','',"Mudejar Architecture of Aragon",0,['Riju']])
data_list.append([datetime.datetime(2016, 5, 5),74,"Reggia di Venaria Reale","Venaria Reale","Italy","Baroque",'','',"Residences of the Royal House of Savoy",0,[]])
data_list.append([datetime.datetime(2016, 5, 5),32,"Castello della Mandria","Venaria Reale","Italy","Classicist",'','',"Residences of the Royal House of Savoy",0,[]])
data_list.append([datetime.datetime(2016, 5, 5),84,"Palazzo Reale","Torino","Italy","Baroque",'Classicist','',"Residences of the Royal House of Savoy",0,[]])
data_list.append([datetime.datetime(2016, 5, 7),80,"Palazzina di Caccia di Stupinigi","Nichelino","Italy","Rococo",'','',"Residences of the Royal House of Savoy",0,[]])
data_list.append([datetime.datetime(2016, 5, 14),71,"Palazzo Reale","Genua","Italy","Classicist",'Baroque','',"",0,['Amin']])
data_list.append([datetime.datetime(2016, 5, 30),25,"Palacio de la Magdalena","Santander","Spain","neo-Gothic",'','',"",0,['']])
data_list.append([datetime.datetime(2016, 5, 31),2,"Palacio de la Magdalena","Santander","Spain","neo-Gothic",'','',"",0,['']])
data_list.append([datetime.datetime(2016, 6, 2),1,"Palacio de la Magdalena","Santander","Spain","neo-Gothic",'','',"",0,['']])
data_list.append([datetime.datetime(2016, 6, 3),6,"Palacio de la Magdalena","Santander","Spain","neo-Gothic",'','',"",0,['']])
data_list.append([datetime.datetime(2016, 7, 23),53,"Palais Royal","Brussels","Belgium","neo-Baroque",'','',"",0,['']])
data_list.append([datetime.datetime(2016, 7, 24),2,"Laeken Palace","Brussels","Belgium","Classicist",'','',"",0,['']])
data_list.append([datetime.datetime(2016, 8, 26),4,"White House","Washington DC","USA","Classicist",'','',"",0,['Artur','Heidrun']])
data_list.append([datetime.datetime(2016, 8, 28),2,"White House","Washington DC","USA","Classicist",'','',"",0,['Artur','Heidrun']])
data_list.append([datetime.datetime(2016, 11, 26),7,"Palazzo Reale","Milano","Italy","Classicist",'','',"",0,['Riju']])
data_list.append([datetime.datetime(2016, 12, 11),61,"Imperial Palace","Kyoto","Japan","Japanese",'','',"",0,[]])
data_list.append([datetime.datetime(2016, 12, 11),23,"Nijo Castle","Kyoto","Japan","Japanese",'','',"Historic Monuments of Ancient Kyoto (Kyoto, Uji and Otsu Cities)",0,[]])
data_list.append([datetime.datetime(2016, 12, 17),34,"Imperial Palace","Tokyo","Japan","Modern",'','',"",0,[]])

# %%
#2017
data_list.append([datetime.datetime(2017, 1, 2),43,"Dublin Castle","Dublin","Ireland","Classicist",'neo-Gothic','',"",0,['Chris Martin']])
data_list.append([datetime.datetime(2017, 1, 14),9,"Palais des Papes","Avignon","France","Gothic",'','',"Papal Palace, Episcopal Ensemble and Avignon Bridge",0,[]])
data_list.append([datetime.datetime(2017, 1, 15),100,"Palais des Papes","Avignon","France","Gothic",'','',"Papal Palace, Episcopal Ensemble and Avignon Bridge",0,[]])
data_list.append([datetime.datetime(2017, 2, 12),9,"Paleis op de Meir","Antwerp","Belgium","Baroque",'','',"",0,['Riju']])
data_list.append([datetime.datetime(2017, 4, 29),32,"Pompejanum","Aschaffenburg","Germany","neo-Roman",'','',"",0,[]])
data_list.append([datetime.datetime(2017, 4, 29),64,"Stadtschloss","Wiesbaden","Germany","Classicist",'','',"",0,[]])
data_list.append([datetime.datetime(2017, 5, 1),59,"Schloss Wilhelmshoehe","Kassel","Germany","Classicist",'','',"Bergpark Wilhelmshoehe",0,[]])
data_list.append([datetime.datetime(2017, 5, 1),16,"Loewenburg","Kassel","Germany","neo-Gothic",'','',"Bergpark Wilhelmshoehe",0,[]])
data_list.append([datetime.datetime(2017, 5, 26),12,"Palau de Cervello","Valencia","Spain","Classicist",'','',"",0,[]])
data_list.append([datetime.datetime(2017, 7, 8),39,"Palazzo Reale","Venice","Italy","Classicist",'','',"Venice and its Lagoon",0,["Reyer",'Riju','Indara']])
data_list.append([datetime.datetime(2017, 7, 21),1,"Royal Palace","Oslo","Norway","Classicist",'','',"",0,[]])
data_list.append([datetime.datetime(2017, 7, 22),2,"Royal Palace","Oslo","Norway","Classicist",'','',"",0,[]])
data_list.append([datetime.datetime(2017, 7, 23),1,"Royal Palace","Oslo","Norway","Classicist",'','',"",0,[]])
data_list.append([datetime.datetime(2017, 7, 22),62,"Akershus Castle","Oslo","Norway","Renaissanca",'','',"",0,[]])
data_list.append([datetime.datetime(2017, 7, 23),13,"Oskarshall","Oslo","Norway","neo-Gothic",'','',"",0,[]])
data_list.append([datetime.datetime(2017, 7, 30),64,"Schloss Nymphenburg","Munich","Germany","Baroque",'Classicist','',"",0,[]])
data_list.append([datetime.datetime(2017, 8, 27),119,"Palace of Diocletian","Split","Croatia","Roman",'','',"Historical Complex of Split with the Palace of Diocletian",0,[]])
data_list.append([datetime.datetime(2017, 9, 7),89,"Palazzo Apostolico","Rome","Vatican","Renaissance",'Gothic','',"Vatican City",0,["Riju"]])
data_list.append([datetime.datetime(2017, 9, 7),55,"Castel Sant'Angelo","Rome","Italy","Renaissance",'Roman','',"Rome",0,["Riju"]])
data_list.append([datetime.datetime(2017, 9, 8),89,"Palazzo Quirinale","Rome","Italy","Baroque",'Classicist','',"Rome",0,["Riju"]])
data_list.append([datetime.datetime(2017, 9, 9),51,"Domus Aurea","Rome","Italy","Roman",'','',"Rome",0,["Riju",'Amin']])
data_list.append([datetime.datetime(2017, 9, 16),27,"Palace of Westminster","London","United Kingdom","Gothic",'','',"Westminster",0,["Riju"]])
data_list.append([datetime.datetime(2017, 9, 16),2,"St James's Palace","London","United Kingdom","Gothic",'','',"",0,["Riju"]])
data_list.append([datetime.datetime(2017, 9, 17),12,"Buckingham Palace","London","United Kingdom","Classicist",'','',"",0,["Riju"]])
data_list.append([datetime.datetime(2017, 9, 17),3,"Tower of London","London","United Kingdom","Romanesque",'','',"Tower of London",0,["Riju"]])
data_list.append([datetime.datetime(2017, 10, 8),25,"Kadriorg Palace","Tallinn","Estonia","Baroque",'','',"",0,["Riju",'Reyer','Rachel']])
data_list.append([datetime.datetime(2017, 10, 8),2,"Tompea Palace","Tallinn","Estonia","Baroque",'','',"Tallinn",0,["Riju",'Reyer','Rachel']])
data_list.append([datetime.datetime(2017, 11, 11),22,"Badia Palace","Marrakesh","Morocco","Islamic",'','',"Marrakesh",0,["Riju",'Tony','Cameron']])
data_list.append([datetime.datetime(2017, 1, 13),1,"Badia Palace","Marrakesh","Morocco","Islamic",'','',"Marrakesh",0,["Riju",'Tony','Cameron']])

# %%
#2018
data_list.append([datetime.datetime(2018, 1, 4),20,"Chaotian Palace","Nanjing","China","Chinese",'','',"",0,[]])
data_list.append([datetime.datetime(2018, 1, 4),47,"Presidential Palace","Nanjing","China","Chinese",'','',"",0,[]])
data_list.append([datetime.datetime(2018, 1, 5),16,"Meiling Villa","Nanjing","China","neo-Chinese",'','',"",0,['Siyi']])
data_list.append([datetime.datetime(2018, 1, 6),8,"Ming Palace","Nanjing","China","neo-Chinese",'','',"",0,[]])
data_list.append([datetime.datetime(2018, 1, 7),276,"Forbidden City","Beijing","China","Chinese",'','',"Beijing Forbidden City",0,['Serena','Lingpao']])
data_list.append([datetime.datetime(2018, 1, 9),152,"Summer Palace","Beijing","China","Chinese",'','',"Beijing Summer Palace",0,[]])
data_list.append([datetime.datetime(2018, 1, 10),99,"Beihai Park","Beijing","China","Chinese",'','',"",0,[]])
data_list.append([datetime.datetime(2018, 1, 10),12,"Forbidden City","Beijing","China","Chinese",'','',"Beijing Forbidden City",0,[]])
data_list.append([datetime.datetime(2018, 3, 10),68,"Royal Palace","Amsterdam","Netherlands","Baroque",'Classicist','',"",0,["Mohammed"]])
data_list.append([datetime.datetime(2018, 3, 11),1,"Royal Palace","Brussels","Belgium","neo-Baroque",'','',"",0,["Mohammed"]])
data_list.append([datetime.datetime(2018, 4, 14),61,"Christiansborg","Copenhagen","Denmark","neo-Baroque",'','',"",0,["Riju",'Reyer','Rachel']])
data_list.append([datetime.datetime(2018, 4, 14),81,"Rosenborg","Copenhagen","Denmark","Renaissance",'Baroque','',"",0,["Riju",'Reyer','Rachel']])
data_list.append([datetime.datetime(2018, 4, 14),4,"Amalienborg","Copenhagen","Denmark","Classicist",'Rococo','',"",0,["Riju",'Reyer','Rachel']])
data_list.append([datetime.datetime(2018, 4, 29),188,"Chateau de Versailles","Versailles","Paris","Baroque",'Rococo','Classicist',"Palace and Park of Versailles",0,["Christine",'Reyer']])
data_list.append([datetime.datetime(2018, 4, 29),54,"Palais de la Cite","Paris","France","Gothic",'','',"Paris, Banks of the Seine",0,["Christine",'Reyer']])
data_list.append([datetime.datetime(2018, 5, 21),1,"Palazzo Reale","Milano","Italy","Classicist",'','',"",0,['Amin']])
data_list.append([datetime.datetime(2018, 6, 3),1,"Edinburgh Castle","Edinburgh","United Kingdom","Gothic",'Renaissance','',"Edinburgh",0,[]])
data_list.append([datetime.datetime(2018, 6, 3),31,"Holyrood Palace","Edinburgh","United Kingdom","Baroque",'Renaissance','Gothic',"Edinburgh",0,[]])
data_list.append([datetime.datetime(2018, 6, 3),31,"Stirling Castle","Stirling","United Kingdom","Gothic",'neo-Romanesque','neo-Gothic','',0,['Artur','Heidrun']])
data_list.append([datetime.datetime(2018, 6, 3),41,"Linlithgow Palace","Linlithgow","United Kingdom","Renaissance",'','',"",0,[]])
data_list.append([datetime.datetime(2018, 6, 8),53,"Conwy Castle","Conwy","United Kingdom","Romanesque",'','',"Castles and Town Walls of King Edward in Gwynedd",0,["Artur",'Heidrun']])
data_list.append([datetime.datetime(2018, 6, 8),50,"Caernarfon Castle","Caernarfon","United Kingdom","Romanesque",'','',"Castles and Town Walls of King Edward in Gwynedd",0,["Artur",'Heidrun']])
data_list.append([datetime.datetime(2018, 7, 3),78,"Changdeokgung Palace","Seoul","South Korea","Korean",'','',"Changdeokgung Palace",0,["Eva",'Ulrike']])
data_list.append([datetime.datetime(2018, 7, 3),19,"Changgyeonggung Palace","Seoul","South Korea","Korean",'','',"",0,["Eva",'Ulrike']])
data_list.append([datetime.datetime(2018, 7, 3),38,"Deoksugung Palace","Seoul","South Korea","neo-Classicist",'Korean','',"",0,["Eva",'Ulrike']])
data_list.append([datetime.datetime(2018, 7, 4),37,"Gyeongbokgung Palace","Seoul","South Korea","Korean",'','',"",0,[]])
data_list.append([datetime.datetime(2018, 7, 4),2,"Blaues Haus","Seoul","South Korea","neo-Korean",'','',"",0,[]])
data_list.append([datetime.datetime(2018, 7, 4),6,"Gyeonghuigung Palace","Seoul","South Korea","Korean",'','',"",0,[]])
data_list.append([datetime.datetime(2018, 7, 12),7,"Hwaseong Palace","Suwon","South Korea","Korean",'','',"Hwaseong Fortress",0,[]])
data_list.append([datetime.datetime(2018, 7, 12),5,"Namhansanseong Emergency Palace","Suwon","South Korea","Korean",'','',"Namhansanseong",0,[]])
data_list.append([datetime.datetime(2018, 9, 1),103,"Munich Residence","Munich","Germany","Classicist",'Baroque','Renaissance',"",0,['Reyer','Chris Brainerd']])
data_list.append([datetime.datetime(2018, 9, 1),3,"Schloss Nymphenburg","Munich","Germany","Baroque",'Classicist','',"",0,['Reyer','Chris Brainerd']])
data_list.append([datetime.datetime(2018, 9, 1),30,"Amalienburg","Munich","Germany","Rococo",'','',"",0,['Reyer','Chris Brainerd']])
data_list.append([datetime.datetime(2018, 9, 1),17,"Badenburg","Munich","Germany","Baroque",'','',"",0,['Reyer','Chris Brainerd']])
data_list.append([datetime.datetime(2018, 9, 1),13,"Pagodenburg","Munich","Germany","Rococo",'','',"",0,['Reyer','Chris Brainerd']])
data_list.append([datetime.datetime(2018, 9, 1),10,"Magdalenenklause","Munich","Germany","Revival",'','',"",0,['Reyer','Chris Brainerd']])
data_list.append([datetime.datetime(2018, 9, 2),2,"Schloss Hohenschwangau","Schwangau","Germany","neo-Gothic",'','',"",0,['Reyer','Chris Brainerd']])
data_list.append([datetime.datetime(2018, 9, 2),11,"Schloss Neuschwanstein","Schwangau","Germany","neo-Romanesque",'','',"",0,['Reyer','Chris Brainerd']])
data_list.append([datetime.datetime(2018, 9, 2),21,"Schloss Linderhof","Ettal","Germany","neo-Rococo",'','',"",0,['Reyer','Chris Brainerd']])
data_list.append([datetime.datetime(2018, 9, 8),131,"Schloss Sanssouci","Potsdam","Germany","Rococo",'Classicist','',"Palaces and Parks of Potsdam and Berlin",0,['Reyer','Chris Brainerd','Riju']])
data_list.append([datetime.datetime(2018, 9, 8),107,"Schloss Sanssouci - Neues Palais","Potsdam","Germany","Rococo",'Classicist','neo-Baroque',"Palaces and Parks of Potsdam and Berlin",0,['Reyer','Chris Brainerd','Riju']])
data_list.append([datetime.datetime(2018, 9, 8),36,"Schloss Sanssouci - Orangerieschloss","Potsdam","Germany","neo-Renaissance",'','',"Palaces and Parks of Potsdam and Berlin",0,['Reyer','Chris Brainerd','Riju']])
data_list.append([datetime.datetime(2018, 9, 8),34,"Schloss Sanssouci - Charlottenhof","Potsdam","Germany","Classicist",'','',"Palaces and Parks of Potsdam and Berlin",0,['Reyer','Chris Brainerd','Riju']])
data_list.append([datetime.datetime(2018, 9, 8),19,"Schloss Sanssouci - Roemisches Bad","Potsdam","Germany","neo-Roman",'','',"Palaces and Parks of Potsdam and Berlin",0,['Reyer','Chris Brainerd','Riju']])
data_list.append([datetime.datetime(2018, 9, 9),3,"Stadtschloss","Berlin","Germany","Baroque",'','',"",0,['Reyer','Chris Brainerd','Riju']])
data_list.append([datetime.datetime(2018, 11, 18),4,"Palais du Pharo","Marseille","Germany","Classicist",'','',"",0,['Reyer','Chris Brainerd','Riju']])

# %%
#2019
data_list.append([datetime.datetime(2019, 3, 10),30,"Castello Svevo","Bari","Italy","Romanesque",'Gothic','',"",0,['Artur','Heidrun']])
data_list.append([datetime.datetime(2019, 3, 12),45,"Castel del Monte","Andria","Italy","Romanesque",'','',"Castel del Monte",0,['Artur','Heidrun']])
data_list.append([datetime.datetime(2019, 3, 15),39,"Reggia di Capodimonte","Naples","Italy","Classicist",'Baroque','',"Naples",0,['Artur','Heidrun']])
data_list.append([datetime.datetime(2019, 3, 16),155,"Reggia di Caserta","Caserta","Italy","Classicist",'','',"Reggia di Caserta",0,['Artur','Heidrun']])
data_list.append([datetime.datetime(2019, 3, 17),38,"Reggia di Portici","Portici","Italy","Baroque",'Classicist','',"",0,['Artur','Heidrun']])
data_list.append([datetime.datetime(2019, 3, 17),90,"Palazzo Reale","Naples","Italy","Classicist",'Baroque','',"Naples",0,['Artur','Heidrun']])
data_list.append([datetime.datetime(2019, 3, 17),4,"Castel Nuovo","Naples","Italy","Gothic",'','',"Naples",0,['Artur','Heidrun']])
data_list.append([datetime.datetime(2019, 4, 14),22,"Queen's House","London","United Kingdom","Renaissance",'','',"Maritime Greenwich",0,["Heidrun",'Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2019, 4, 20),233,"Chateau de Fontainebleau","Fontainebleau","France","Classicist",'Renaissance','Baroque',"Fontainebleau",0,['Riju','Chris Brainerd']])
data_list.append([datetime.datetime(2019, 5, 26),10,"Schloss Vaduz","Vaduz","Liechtenstein","Renaissance",'Gothic','',"",1,['Riju']])
data_list.append([datetime.datetime(2019, 5, 26),33,"Kaiserpfalz Goslar","Goslar","Germany","Romanesque",'neo-Romanesque','',"",0,['Grace']])
data_list.append([datetime.datetime(2019, 9, 21),37,"Palais de la Cite","Paris","France","Gothic",'','',"Paris, Banks of the Seine",0,['Vivan','Sam','Michael',"Nhi"]])
data_list.append([datetime.datetime(2019, 9, 21),4,"Palais du Louvre","Paris","France","Baroque",'Renaissance','Classicist',"Paris, Banks of the Seine",0,['Vivan','Sam','Michael',"Nhi"]])
data_list.append([datetime.datetime(2019, 9, 22),9,"Palais du Louvre","Paris","France","Baroque",'Renaissance','Classicist',"Paris, Banks of the Seine",0,['Vivan','Sam','Michael',"Nhi"]])
data_list.append([datetime.datetime(2019, 12, 29),5,"Residenzschloss Dresden","Dresden","Germany","Baroque",'Renaissance','',"",0,['Artur']])
data_list.append([datetime.datetime(2019, 12, 30),8,"Residenzschloss Dresden","Dresden","Germany","Baroque",'Renaissance','',"",0,['Artur']])
data_list.append([datetime.datetime(2019, 12, 31),64,"Residenzschloss Dresden","Dresden","Germany","Baroque",'Renaissance','',"",0,['Artur']])

#2020
data_list.append([datetime.datetime(2020, 1, 2),12,"Wawel Royal Palace","Krakow","Poland","Renaissance",'','',"Krakow",0,['Artur']])
data_list.append([datetime.datetime(2020, 1, 3),19,"Koenigsschloss Breslau","Wroclaw","Poland","Classicist",'','',"",0,['Artur']])
data_list.append([datetime.datetime(2020, 2, 22),39,"Palazzo Ponfitico","Castle Gandolfo","Vatican","Classicist",'Modern','',"",0,[]])
data_list.append([datetime.datetime(2020, 2, 22),9,"Palazzo di Bonifacio VIII","Anagni","Italy","Gothic",'','',"",0,[]])
data_list.append([datetime.datetime(2020, 2, 26),123,"Palazzo Pitti","Florence","Italy","Baroque",'Classicist','',"Florence",0,[]])
data_list.append([datetime.datetime(2020, 2, 28),116,"Palazzo Apostolico","Rome","Vatican","Renaissance",'Gothic','',"Vatican City",0,["Bryan"]])
data_list.append([datetime.datetime(2020, 2, 27),3,"Castel Sant'Angelo","Rome","Italy","Renaissance",'Roman','',"Rome",0,["Bryan"]])
data_list.append([datetime.datetime(2020, 2, 28),44,"Castel Sant'Angelo","Rome","Italy","Renaissance",'Roman','',"Rome",0,["Bryan"]])
data_list.append([datetime.datetime(2020, 2, 29),122,"Imperial Palace on Palatine Hill","Rome","Italy","Roman",'','',"Rome",0,["Bryan"]])
data_list.append([datetime.datetime(2020, 2, 29),107,"Palazzo Quirinale","Rome","Italy","Baroque",'Classicist','',"Rome",0,["Bryan"]])
data_list.append([datetime.datetime(2020, 3, 1),94,"Villa Adriana","Tivoli","Italy","Roman",'','',"Villa Adriana",0,["Bryan"]])
#2021
data_list.append([datetime.datetime(2021, 8, 1),71,"Schloss Eckartsau","Eckartsau","Austria","Baroque",'Classicist','',"",1,[]])
data_list.append([datetime.datetime(2021, 5, 4),13,"Hofburg","Vienna","Austria","Baroque",'Classicist','Renaissance',"Vienna",1,[]])
data_list.append([datetime.datetime(2021, 5, 6),51,"Hofburg","Vienna","Austria","Baroque",'Classicist','Renaissance',"Vienna",1,[]])
data_list.append([datetime.datetime(2021, 5, 7),4,"Hofburg","Vienna","Austria","Baroque",'Classicist','Renaissance',"Vienna",1,[]])
data_list.append([datetime.datetime(2021, 5, 8),30,"Hofburg","Vienna","Austria","Baroque",'Classicist','Renaissance',"Vienna",1,[]])
data_list.append([datetime.datetime(2021, 5, 9),52,"Hofburg","Vienna","Austria","Baroque",'Classicist','Renaissance',"Vienna",1,[]])
data_list.append([datetime.datetime(2021, 5, 10),2,"Hofburg","Vienna","Austria","Baroque",'Classicist','Renaissance',"Vienna",1,[]])
data_list.append([datetime.datetime(2021, 5, 11),3,"Hofburg","Vienna","Austria","Baroque",'Classicist','Renaissance',"Vienna",1,[]])
data_list.append([datetime.datetime(2021, 5, 23),41,"Hofburg","Vienna","Austria","Baroque",'Classicist','Renaissance',"Vienna",1,[]])
data_list.append([datetime.datetime(2021, 5, 28),4,"Hofburg","Vienna","Austria","Baroque",'Classicist','Renaissance',"Vienna",1,[]])
data_list.append([datetime.datetime(2021, 7, 2),19,"Hofburg","Vienna","Austria","Baroque",'Classicist','Renaissance',"Vienna",1,[]])
data_list.append([datetime.datetime(2021, 7, 4),2,"Hofburg","Vienna","Austria","Baroque",'Classicist','Renaissance',"Vienna",1,[]])
data_list.append([datetime.datetime(2021, 8, 19),13,"Hofburg","Vienna","Austria","Baroque",'Classicist','Renaissance',"Vienna",1,[]])
data_list.append([datetime.datetime(2021, 9, 23),2,"Hofburg","Vienna","Austria","Baroque",'Classicist','Renaissance',"Vienna",1,[]])
data_list.append([datetime.datetime(2021, 9, 26),7,"Hofburg","Vienna","Austria","Baroque",'Classicist','Renaissance',"Vienna",1,[]])
data_list.append([datetime.datetime(2021, 5, 30),85,"Stift Klosterneuburg - Kaisertrakt","Klosterneuburg","Austria","Baroque",'','',"",1,[]])
data_list.append([datetime.datetime(2021, 8, 28),32,"Karlstejn Castle","Karlstejn","Czech","Gothic",'','',"",0,[]])
data_list.append([datetime.datetime(2021, 8, 28),68,"Prague Castle","Prague","Czech","Baroque",'Renaissance','',"Prague",0,[]])
data_list.append([datetime.datetime(2021, 8, 29),3,"Prague Castle","Prague","Czech","Baroque",'Renaissance','',"Prague",0,[]])
data_list.append([datetime.datetime(2021, 6, 6),46,"Hermesvilla","Vienna","Classicist","",'','',"",1,[]])
data_list.append([datetime.datetime(2021, 5, 7),104,"Schloss Schoenbrunn","Vienna","Austria","Rococo","Baroque",'Classicist',"Gardens and Palace of Schoenbrunn",1,[]])
data_list.append([datetime.datetime(2021, 5, 11),5,"Schloss Schoenbrunn","Vienna","Austria","Rococo","Baroque",'Classicist',"Gardens and Palace of Schoenbrunn",1,[]])
data_list.append([datetime.datetime(2021, 5, 13),2,"Schloss Schoenbrunn","Vienna","Austria","Rococo","Baroque",'Classicist',"Gardens and Palace of Schoenbrunn",1,[]])
data_list.append([datetime.datetime(2021, 5, 15),20,"Schloss Schoenbrunn","Vienna","Austria","Rococo","Baroque",'Classicist',"Gardens and Palace of Schoenbrunn",1,[]])
data_list.append([datetime.datetime(2021, 10, 9),2,"Schloss Schoenbrunn","Vienna","Austria","Rococo","Baroque",'Classicist',"Gardens and Palace of Schoenbrunn",1,[]])
data_list.append([datetime.datetime(2021, 11, 1),1,"Schloss Schoenbrunn","Vienna","Austria","Rococo","Baroque",'Classicist',"Gardens and Palace of Schoenbrunn",1,[]])
data_list.append([datetime.datetime(2021, 5, 15),49,"Schloss Hof","Engelhartstetten","Austria","Baroque",'','',"",1,[]])
data_list.append([datetime.datetime(2021, 8, 8),82,"Laxenburg Palaces and Franzensburg","Laxenburg","Austria","Baroque",'neo-Gothic','Gothic',"",1,[]])
data_list.append([datetime.datetime(2021, 7, 24),24,"Hofburg","Innsbruck","Austria","Baroque",'Classicist','',"",0,['Sam','Grace','Janina']])
data_list.append([datetime.datetime(2021, 10, 22),11,"Kaiserburg","Nuremburg","Germany","Romanesque",'Gothic','',"",0,[]])
data_list.append([datetime.datetime(2021, 10, 23),47,"Kaiserburg","Nuremburg","Germany","Romanesque",'Gothic','',"",0,[]])
data_list.append([datetime.datetime(2021, 10, 24),5,"Grand Ducal Palace","Luxemburg","Luxemburg","neo-Renaissance",'','',"City of Luxembourg: its Old Quarters and Fortifications",0,[]])
data_list.append([datetime.datetime(2021, 10, 24),6,"Konstantinbasilika","Trier","Germany","Roman",'','',"Roman Monuments, Cathedral of St Peter and Church of Our Lady",0,[]])
data_list.append([datetime.datetime(2021, 10, 27),75,"Palais de la Cite","Paris","France","Gothic",'','',"Paris, Banks of the Seine",0,[]])
data_list.append([datetime.datetime(2021, 10, 27),93,"Palais du Louvre","Paris","France","Baroque",'Renaissance','Classicist',"Paris, Banks of the Seine",0,[]])
#2022
data_list.append([datetime.datetime(2022, 2, 18),6,"Schloss Schoenbrunn","Vienna","Austria","Rococo","Baroque",'Classicist',"Gardens and Palace of Schoenbrunn",1,[]])
data_list.append([datetime.datetime(2022, 3, 19),4,"Alcazaba","Malaga","Spain","Islamic",'','',"",0,[]])
data_list.append([datetime.datetime(2022, 3, 20),51,"Alcazaba","Malaga","Spain","Islamic",'','',"",0,[]])
data_list.append([datetime.datetime(2022, 3, 21),8,"Alhambra","Granada","Spain","Islamic",'Renaissance','',"Alhambra, Generalife and Albayzin",0,[]])
data_list.append([datetime.datetime(2022, 3, 21),1,"Generalife","Granada","Spain","Islamic",'','',"Alhambra, Generalife and Albayzin",0,[]])
data_list.append([datetime.datetime(2022, 3, 22),159,"Alhambra","Granada","Spain","Islamic",'Renaissance','',"Alhambra, Generalife and Albayzin",0,[]])
data_list.append([datetime.datetime(2022, 3, 22),35,"Generalife","Granada","Spain","Islamic",'','',"Alhambra, Generalife and Albayzin",0,[]])
data_list.append([datetime.datetime(2022, 3, 22),8,"Palacio Dar al-Horra","Granada","Spain","Islamic",'','',"Alhambra, Generalife and Albayzin",0,[]])
data_list.append([datetime.datetime(2022, 3, 22),7,"Cuarto Real de Santo Domingo","Granada","Spain","Islamic",'','',"Alhambra, Generalife and Albayzin",0,[]])
data_list.append([datetime.datetime(2022, 3, 24),29,"Medina Azahara","Cordoba","Spain","Islamic",'','',"Medina Azahara",0,[]])
data_list.append([datetime.datetime(2022, 3, 24),32,"Alcazar","Cordoba","Spain","Gothic",'Renaissance','',"Cordoba",0,[]])
data_list.append([datetime.datetime(2022, 3, 25),138,"Alcazar","Sevilla","Spain","Islamic",'Renaissance','',"Cathedral, Alcazar and Archivo de Indias in Seville",0,[]])
data_list.append([datetime.datetime(2022, 3, 28),9,"Palacio Real","Madrid","Spain","Baroque",'','',"",0,[]])
data_list.append([datetime.datetime(2022, 4, 1),48,"Alcazar","Segovi","Spain","Gothic",'Renaissance','',"Segovia",0,[]])
data_list.append([datetime.datetime(2022, 4, 1),13,"Palacio Real de La Granja de San Ildefenso","La Granja","Spain","Baroque",'','',"",0,[]])
data_list.append([datetime.datetime(2022, 4, 2),22,"Palacio Real","Aranjuez","Spain","Baroque",'','',"Aranjuez Cultural Landscape",0,[]])
data_list.append([datetime.datetime(2022, 4, 2),26,"Palacio de El Escorial","El Escorial","Spain","Renaissance",'Baroque','',"El Escorial Monastery",0,[]])
data_list.append([datetime.datetime(2022, 4, 2),9,"Casa dei Principe","El Escorial","Spain","Baroque",'','',"El Escorial Monastery",0,[]])
data_list.append([datetime.datetime(2022, 4, 3),60,"Palacio Real","Madrid","Spain","Baroque",'','',"",0,[]])
data_list.append([datetime.datetime(2022, 5, 3),8,"Schloss Schoenbrunn","Vienna","Austria","Rococo","Baroque",'Classicist',"Gardens and Palace of Schoenbrunn",1,[]])
data_list.append([datetime.datetime(2022, 5, 21),6,"Schloss Schoenbrunn","Vienna","Austria","Rococo","Baroque",'Classicist',"Gardens and Palace of Schoenbrunn",1,['Rachel','Chris Martin']])
data_list.append([datetime.datetime(2021, 5, 23),47,"Hofburg","Vienna","Austria","Baroque",'Classicist','Renaissance',"Vienna",1,[]])
data_list.append([datetime.datetime(2022, 5, 25),56,"Burgpalast","Budapest","Hungary","neo-Baroque",'','',"Budapest, including the Banks of the Danube, the Buda Castle Quarter and Andrassy Avenue",0,['Chris Martin']])
data_list.append([datetime.datetime(2022, 6, 4),2,"Palais Grassalkovich","Bratislava","Slovakia","Baroque",'','',"",1,['Artur']])
data_list.append([datetime.datetime(2022, 6, 4),23,"Burg Pressburg","Bratislava","Slovakia","Baroque",'Modern','',"",1,['Artur']])
data_list.append([datetime.datetime(2022, 6, 5),5,"Burgpalast","Budapest","Hungary","neo-Baroque",'','',"Budapest, including the Banks of the Danube, the Buda Castle Quarter and Andrassy Avenue",1,['Artur']])
data_list.append([datetime.datetime(2022, 6, 17),89,"Schloss Moritzburg mit Fasanenschloesschen","Moritzburg","Germany","Baroque",'','',"",0,[]])
data_list.append([datetime.datetime(2022, 6, 18),74,"Schloss Sanssouci","Potsdam","Germany","Rococo",'Classicist','',"Palaces and Parks of Potsdam and Berlin",0,['Hannsjoerg']])
data_list.append([datetime.datetime(2022, 6, 18),102,"Schloss Sanssouci - Neues Palais","Potsdam","Germany","Rococo",'Classicist','neo-Baroque',"Palaces and Parks of Potsdam and Berlin",0,['Hannsjoerg']])
data_list.append([datetime.datetime(2022, 6, 18),14,"Schloss Sanssouci - Orangerieschloss","Potsdam","Germany","neo-Renaissance",'','',"Palaces and Parks of Potsdam and Berlin",0,['Hannsjoerg']])
data_list.append([datetime.datetime(2022, 6, 18),6,"Stadtschloss","Potsdam","Germany","Baroque",'','',"",0,['Hannsjoerg']])
data_list.append([datetime.datetime(2022, 6, 18),65,"Marmorpalais","Potsdam","Germany","Classicist",'','',"Palaces and Parks of Potsdam and Berlin",0,['Hannsjoerg']])
data_list.append([datetime.datetime(2022, 6, 19),18,"Stadtschloss","Berlin","Germany","Baroque",'','',"",0,[]])


data_list.append([datetime.datetime(2022, 8, 13),21,"Italienischer Hof","Kutna Hora","Czech","neo-gothic",'Renaissance','',"Kutna Hora",0,[]])
data_list.append([datetime.datetime(2022, 8, 13),1,"Prague Castle","Prague","Czech","Baroque",'Renaissance','',"Prague",0,[]])
data_list.append([datetime.datetime(2022, 8, 14),38,"Jagdschloss Stern","Prague","Czech",'Renaissance','','','',0,[]])
data_list.append([datetime.datetime(2022, 8, 26),4,"Riga Castle","Riga","Latvia",'Baroque','','','Riga',0,['Artur']])
data_list.append([datetime.datetime(2022, 8, 27),13,"Presidential Palace","Vilnius","Lithuania",'Baroque','','','Vilnius',0,['Artur']])
data_list.append([datetime.datetime(2022, 8, 27),28,"Grand Ducal Palace","Vilnius","Lithuania",'Renaissance','Baroque','','Vilnius',0,['Artur']])


df = pd.DataFrame(data_list,columns=['Date','Pictures', 'Palace','Place', 'Country','Style 1','Style 2','Style 3','Unesco Site','Day Trip','Co-Travellers'])
df["Number of Co-Travellers"]=df["Co-Travellers"].str.len()
df.to_csv("../data/RoyalPresidentialPalace_Photos.csv")
df
# Out:
#           Date  Pictures                        Palace    Place  \
# 0   1996-08-28         4               Tower of London   London
# 1   1996-08-27         5          Hampton Court Palace   London
# 2   1996-08-28         1             Kensington Palace   London
# 3   1996-08-30         1             St James's Palace   London
# 4   1996-08-30         1  Whitehall - Banqueting House   London
# ..         ...       ...                           ...      ...
# 442 2022-08-13         1                 Prague Castle   Prague
# 443 2022-08-14        38             Jagdschloss Stern   Prague
# 444 2022-08-26         4                   Riga Castle     Riga
# 445 2022-08-27        13           Presidential Palace  Vilnius
# 446 2022-08-27        28            Grand Ducal Palace  Vilnius
#
#             Country      Style 1      Style 2 Style 3      Unesco Site  \
# 0    United Kingdom   Romanesque                       Tower of London
# 1    United Kingdom       Gothic      Baroque
# ...

# %%
df.groupby(['Palace','Place','Country']).agg(Pictures=('Pictures','sum')).sort_values(by='Pictures',ascending=False).reset_index().head(30)
# Out:
#                               Palace          Place         Country  Pictures
# 0              Chateau de Versailles     Versailles           Paris       600
# 1                            Hofburg         Vienna         Austria       545
# 2           Chateau de Fontainebleau  Fontainebleau          France       431
# 3                   Munich Residence         Munich         Germany       417
# 4                  Schloss Sanssouci        Potsdam         Germany       375
# 5                  Reggia di Caserta        Caserta           Italy       311
# 6   Schloss Sanssouci - Neues Palais        Potsdam         Germany       302
# 7                 Palazzo Apostolico           Rome         Vatican       298
# 8                  Palais de la Cite          Paris          France       292
# 9                     Forbidden City        Beijing           China       288
# 10                          Alhambra        Granada           Spain       282
# ...

# %%
import re
#re.sub(r'\W+', '', your_string)

cotravellers=set()

#if I consider unique() just alone, then it would split everything directly into 

for expr in df['Co-Travellers'].values:
    for w in expr:
        name=re.sub(r"[^\w-]", ' ', w).strip()
        if name!="":
            cotravellers.add(name)
print(cotravellers)
# Out:
# {'Gianrico', 'Rachel', 'Heidrun', 'Aaron', 'Cameron', 'Kennedy', 'Serena', 'Janina', 'Amin', 'Chris Clarke', 'Vivan', 'Nhi', 'Mohammed', 'Michael', 'Chris Martin', 'Chris Lee', 'Bryan', 'Can', 'Sam', 'Riju', 'Grace', 'Lingpao', 'Christine', 'Indara', 'Devin', 'Vera', 'Siyi', 'Andrew', 'Laser', 'Tony', 'Anne', 'David', 'Eva', 'Hannsjoerg', 'Sigi', 'Chris Brainerd', 'Ulrike', 'Eric', 'Manuel', 'Artur', 'Stephan', 'Susanne', 'Reyer', 'Nate', 'Evan', 'Jan-Marc', 'Nick', 'AJ', 'Anne-Kathrin'}

# %%
df_list_co_travellers=[]
for ind_ct,ct in enumerate(cotravellers):
    cot_flag=np.zeros(len(df))
    for ind,expr in enumerate(df['Co-Travellers'].values):
        if ct in expr:
            cot_flag[ind]=1
    df["cot_flag"]=cot_flag
    
    print(ind_ct, ct,": total/multi",df.loc[df['cot_flag']==1,"Pictures"].sum(),df.loc[(df['cot_flag']==1) & (df['Day Trip']==0),"Pictures"].sum(),
         "joined on",df.loc[(df['cot_flag']==1),"Date"].nunique(),"dates")
    df_list_co_travellers.append([ct,
                                df.loc[(df['cot_flag']==1),"Pictures"].sum(),
                                df.loc[(df['cot_flag']==1)&
                                        (df['Day Trip']==0),"Pictures"].sum(),
                                df.loc[(df['cot_flag']==1) &
                                        (df['Day Trip']==1),"Pictures"].sum(),
                                df.loc[(df['cot_flag']==1),"Date"].nunique(),
                                df.loc[(df['cot_flag']==1) &
                                        (df['Day Trip']==0),"Date"].nunique(),
                                df.loc[(df['cot_flag']==1) &
                                        (df['Day Trip']==1),"Date"].nunique(),
                                df.loc[(df['cot_flag']==1),"Country"].nunique(),
                                df.loc[(df['cot_flag']==1),"Place"].nunique(),
                                df.loc[(df['cot_flag']==1),"Date"].min(),
                                df.loc[(df['cot_flag']==1),"Date"].max()                             
                                 ])
    if df.loc[(df['cot_flag']==1),"Date"].nunique()>1:
        min_x=df.loc[(df['cot_flag']==1),"Date"].min()-np.timedelta64(2,"M")
        max_x=df.loc[(df['cot_flag']==1),"Date"].max()+np.timedelta64(2,"M")
        fig, ax = plt.subplots()
        max_y=1.25*df[(df['cot_flag']==1)].groupby(pd.Grouper(key="Date", freq="1D")).sum()["Pictures"].max()
        df[(df['cot_flag']==1)].groupby(pd.Grouper(key="Date", freq="1D")).sum()["Pictures"].plot(title="daily count of catedral pictures in trips",ylabel="picture count",xlim=(min_x,max_x),ylim=(0,max_y))
        plt.show()
# Out:
# 0 Gianrico : total/multi 79 79 joined on 3 dates
# 1 Rachel : total/multi 179 173 joined on 3 dates
# 2 Heidrun : total/multi 2701 2537 joined on 65 dates
# 3 Aaron : total/multi 77 77 joined on 2 dates
# 4 Cameron : total/multi 23 23 joined on 2 dates
# 5 Kennedy : total/multi 77 77 joined on 2 dates
# 6 Serena : total/multi 276 276 joined on 1 dates
# 7 Janina : total/multi 24 24 joined on 1 dates
# 8 Amin : total/multi 123 123 joined on 3 dates
# 9 Chris Clarke : total/multi 122 122 joined on 2 dates
# 10 Vivan : total/multi 50 50 joined on 2 dates
# 11 Nhi : total/multi 50 50 joined on 2 dates
# 12 Mohammed : total/multi 69 69 joined on 2 dates
# 13 Michael : total/multi 50 50 joined on 2 dates
# 14 Chris Martin : total/multi 324 318 joined on 5 dates
# 15 Chris Lee : total/multi 122 122 joined on 2 dates
# 16 Bryan : total/multi 486 486 joined on 4 dates
# 17 Can : total/multi 77 77 joined on 2 dates
# 18 Sam : total/multi 74 74 joined on 3 dates
# ...

# %%
df_coTrav = pd.DataFrame(df_list_co_travellers,columns=['Co-Traveller', 'Photos','PhotosMultiDay','PhotosSingleDay','Days',"Days_Multi","Days_Single","N_Countries","N_Places","FirstTripDate",'LastTripDate'])
df_coTrav=df_coTrav.sort_values(by="Photos",ascending=False).reset_index().drop(columns='index')
df_coTrav.to_csv("../data/palace_cotravellers.csv")
df_coTrav.head(50)
# Out:
#       Co-Traveller  Photos  PhotosMultiDay  PhotosSingleDay  Days  Days_Multi  \
# 0          Heidrun    2701            2537              164    65          63
# 1            Artur    2227            2033              194    63          59
# 2             Riju    1473            1463               10    19          18
# 3       Hannsjoerg    1140             974              166    40          37
# 4            Reyer    1001            1001                0    10          10
# 5             Eric     960             960                0    13          13
# 6           Manuel     794             794                0    12          12
# 7   Chris Brainerd     777             777                0     6           6
# 8           Indara     491             491                0     4           4
# 9            Bryan     486             486                0     4           4
# 10          Andrew     394             394                0     3           3
# ...
