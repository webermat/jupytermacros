# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime

# %%
data_list=[]


data_list.append([datetime.datetime(1984, 8, 18),1984,"Waldshut","Germany","","Koblenz","Switzerland","",0,0,0,["Artur","Heidrun",'Anne-Kathrin','Jan-Marc']])
data_list.append([datetime.datetime(1984, 8, 18),1984,"Koblenz","Switzerland","","Waldshut","Germany","",0,0,0,["Artur","Heidrun",'Anne-Kathrin','Jan-Marc']])
data_list.append([datetime.datetime(1984, 8, 21),1984,"Waldshut","Germany","","Basel","Switzerland","Basel Bad BF",0,0,0,["Artur","Heidrun",'Anne-Kathrin','Jan-Marc']])
data_list.append([datetime.datetime(1984, 8, 21),1984,"Basel","Switzerland","Basel Bad BF","Waldshut","Germany","",0,0,0,["Artur","Heidrun",'Anne-Kathrin','Jan-Marc']])

data_list.append([datetime.datetime(1985, 8, 17),1985,"Waldshut","Germany","","Basel","Switzerland","Basel Bad BF",0,0,0,["Artur","Heidrun",'Anne-Kathrin','Jan-Marc']])
data_list.append([datetime.datetime(1985, 8, 17),1985,"Basel","Switzerland","Basel Bad BF","Waldshut","Germany","",0,0,0,["Artur","Heidrun",'Anne-Kathrin','Jan-Marc']])

data_list.append([datetime.datetime(1987, 3, 15),1987,"Waldshut","Germany","","Schaffhausen","Switzerland","",0,0,0,["Artur",'Hannsjoerg',"Heidrun",'Anne-Kathrin','Jan-Marc']])
data_list.append([datetime.datetime(1987, 3, 15),1987,"Schaffhausen","Switzerland","","Waldshut","Germany","",0,0,0,["Artur",'Hannsjoerg',"Heidrun",'Anne-Kathrin','Jan-Marc']])
data_list.append([datetime.datetime(1987, 8, 8),1987,"Waldshut","Germany","","Basel","Switzerland","Basel Bad BF",0,0,0,["Artur","Heidrun",'Anne-Kathrin','Jan-Marc']])
data_list.append([datetime.datetime(1987, 8, 8),1987,"Basel","Switzerland","Basel Bad BF","Waldshut","Germany","",0,0,0,["Artur","Heidrun",'Anne-Kathrin','Jan-Marc']])

data_list.append([datetime.datetime(1989, 7, 14),1989,"Waldshut","Germany","","Basel","Switzerland","Basel Bad BF",0,0,0,["Artur","Heidrun",'Anne-Kathrin','Jan-Marc']])
data_list.append([datetime.datetime(1989, 7, 14),1989,"Basel","Switzerland","Basel Bad BF","Waldshut","Germany","",0,0,0,["Artur","Heidrun",'Anne-Kathrin','Jan-Marc']])

data_list.append([datetime.datetime(1987, 7, 6),1990,"Waldshut","Germany","","Basel","Switzerland","Basel Bad BF",0,0,0,["Artur","Heidrun",'Anne-Kathrin','Jan-Marc']])
data_list.append([datetime.datetime(1987, 7, 6),1990,"Basel","Switzerland","Basel Bad BF","Waldshut","Germany","",0,0,0,["Artur","Heidrun",'Anne-Kathrin','Jan-Marc']])

data_list.append([datetime.datetime(1987, 8, 16),1991,"Zuerich","Switzerland","Zuerich Flughafen","Zuerich","Switzerland","Zuerich Brunau",0,0,0,["Artur","Heidrun",'Anne-Kathrin','Jan-Marc']])
data_list.append([datetime.datetime(1987, 8, 16),1991,"Zuerich","Switzerland","Zuerich Brunau","Zuerich","Germany","Zuerich Flughafen",0,0,0,["Artur","Heidrun",'Anne-Kathrin','Jan-Marc']])


#added dummy landschulheim & dummy Bahro trip
#freiburg concert by bus, Bael theatre by bus too

#missing SPG Basel
#grid days Bern  --> sometime late in the year

#all teaching, all studies, all feste/Kinos/exams
#two day exam protocol, 3-4 day checking of exams each year/summer

# %%
#uetliberg  end of semesterr

#1996
data_list.append([datetime.datetime(1996, 8, 24),1996,"Stansted","United Kingdom","Stansted Airport","London","United Kingdom","Liverpool Street",1,0,0,["Artur","Heidrun","Hannsjoerg",'Anne-Kathrin','Jan-Marc']])
data_list.append([datetime.datetime(1996, 8, 31),1996,"London","United Kingdom","Waterloo Station","London","United Kingdom","Hampton Court",0,0,0,["Artur","Heidrun","Hannsjoerg",'Anne-Kathrin','Jan-Marc']])
data_list.append([datetime.datetime(1996, 8, 31),1996,"London","United Kingdom","Hampton Court","London","United Kingdom","Waterloo Station",0,0,0,["Artur","Heidrun","Hannsjoerg",'Anne-Kathrin','Jan-Marc']])
data_list.append([datetime.datetime(1996, 8, 31),1996,"London","United Kingdom","Liverpool Street","Stansted","United Kingdom","Stansted Airport",1,0,0,["Artur","Heidrun","Hannsjoerg",'Anne-Kathrin','Jan-Marc']])
#1997
#shaky but assume it is correct
data_list.append([datetime.datetime(1997, 4, 10),1997,"Tiengen","Germany","","Basel","Switzerland","Basel Bad BF",1,1,0,["Landschulheim"]])
data_list.append([datetime.datetime(1997, 4, 10),1997,"Basel","Switzerland","Basel Bad BF","Hamburg","Germany","Hamburg Altona",1,1,1,["Landschulheim"]])
data_list.append([datetime.datetime(1997, 4, 10),1997,"Hamburg","Germany","Hamburg Altona","St Peter Ording","Germany","",0,0,1,["Landschulheim"]])
data_list.append([datetime.datetime(1997, 4, 16),1997,"St Peter Ording","Germany","","Hamburg","Germany","Hamburg Altona",0,1,0,["Landschulheim"]])
data_list.append([datetime.datetime(1997, 4, 16),1997,"Hamburg","Germany","Hamburg Altona","Basel","Switzerland","Basel Bad BF",1,1,1,["Landschulheim"]])
data_list.append([datetime.datetime(1997, 4, 16),1997,"Basel","Switzerland","Basel Bad BF","Tiengen","Germany","",1,0,1,["Landschulheim"]])

data_list.append([datetime.datetime(1997, 8, 28),1997,"Rom","Italy","Ostia Antica","Rom","Italy","Basilica San Paolo",0,0,0,["Artur","Heidrun","Hannsjoerg",'Anne-Kathrin','Jan-Marc']])
data_list.append([datetime.datetime(1997, 8, 28),1997,"Rom","Italy","Basilica San Paolo","Rom","Italy","Ostia Antica",0,0,0,["Artur","Heidrun","Hannsjoerg",'Anne-Kathrin','Jan-Marc']])
data_list.append([datetime.datetime(1997, 8, 28),1997,"Rom","Italy","Ostia Antica","Rom","Italy","Basilica San Paolo",0,0,0,["Artur","Heidrun","Hannsjoerg",'Anne-Kathrin','Jan-Marc']])
#1998
data_list.append([datetime.datetime(1998, 8, 25),1998,"Paris","France","St-Michel Notre-Dame","Versailles","France","Versailles Rive-Gauche",0,0,0,["Artur","Heidrun","Hannsjoerg",'Anne-Kathrin','Jan-Marc']])
data_list.append([datetime.datetime(1998, 8, 25),1998,"Versailles","France","Versailles Rive Gauche","Paris","France","St-Michel Notre-Dame",1,0,0,["Artur","Heidrun","Hannsjoerg",'Anne-Kathrin','Jan-Marc']])
data_list.append([datetime.datetime(1998, 8, 26),1998,"Paris","France","Gare du Nord","St Denis","France","Stade de France-St Denis",0,0,0,["Artur","Heidrun","Hannsjoerg",'Anne-Kathrin','Jan-Marc']])
data_list.append([datetime.datetime(1998, 8, 26),1998,"St Denis","France","St Denis","Paris","France","Chatelet-Les Halles",0,0,0,["Artur","Heidrun","Hannsjoerg",'Anne-Kathrin','Jan-Marc']])
#2000
data_list.append([datetime.datetime(2000, 5, 18),2000,"Waldshut","Germany","","Lindau","Germany","Lindau-Insel",1,1,0,["Hochrhein Seminar"]])
data_list.append([datetime.datetime(2000, 5, 18),2000,"Lindau","Germany","Lindau-Insel","Muenchen","Germany","Muenchen HBF",1,0,1,['Hochrhein Seminar']])
data_list.append([datetime.datetime(2000, 5, 21),2000,"Muenchen","Germany","Muenchen HBF","Lindau","Germany","Lindau-Insel",1,1,0,['Hochrhein Seminar']])
data_list.append([datetime.datetime(2000, 5, 21),2000,"Lindau","Germany","Lindau Insel","Waldshut","Germany","",1,0,1,["Hochrhein Seminar"]])
data_list.append([datetime.datetime(2000, 8, 24),2000,"Waldshut","Germany","","Basel","Switzerland","Basel Bad BF",1,1,0,["Artur","Heidrun","Hannsjoerg",'Anne-Kathrin']])
data_list.append([datetime.datetime(2000, 8, 24),2000,"Basel","Switzerland","Basel Bad BF","Frankfurt am Main","Germany","Frankfurt Flughafen",1,1,0,["Artur","Heidrun","Hannsjoerg",'Anne-Kathrin']])
data_list.append([datetime.datetime(2000, 9, 7),2000,"Frankfurt am Main","Germany","Frankfurt Flughafen","Basel","Switzerland","Basel Bad BF",1,1,0,["Artur","Heidrun","Hannsjoerg",'Anne-Kathrin']])
data_list.append([datetime.datetime(2000, 9, 8),2000,"Basel","Switzerland","Basel Bad BF","Waldshut","Germany","",1,0,1,["Artur","Heidrun","Hannsjoerg",'Anne-Kathrin']])
#2001
data_list.append([datetime.datetime(2001, 5, 29),2001,"Berlin","Germany","Berlin-Bellevue","Potsdam","Germany","Potsdam HBF",0,0,0,["Heidrun",'Artur','Hannsjoerg','Anne-Kathrin']])
data_list.append([datetime.datetime(2001, 5, 29),2001,"Potsdam","Germany","Potsdam HBF","Berlin","Germany","Berlin-Charlottenburg",0,0,0,["Heidrun",'Artur','Hannsjoerg','Anne-Kathrin']])
data_list.append([datetime.datetime(2001, 8, 21),2000,"Waldshut","Germany","","Basel","Switzerland","Basel Bad BF",1,1,0,["Artur","Heidrun","Hannsjoerg",'Anne-Kathrin']])
data_list.append([datetime.datetime(2001, 8, 21),2000,"Basel","Switzerland","Basel Bad BF","Frankfurt am Main","Germany","Frankfurt Flughafen",1,1,0,["Artur","Heidrun","Hannsjoerg",'Anne-Kathrin']])
data_list.append([datetime.datetime(2001, 9, 3),2000,"Frankfurt am Main","Germany","Frankfurt Flughafen","Basel","Switzerland","Basel Bad BF",1,1,0,["Artur","Heidrun","Hannsjoerg",'Anne-Kathrin']])
data_list.append([datetime.datetime(2001, 9, 4),2000,"Basel","Switzerland","Basel Bad BF","Waldshut","Germany","",1,0,1,["Artur","Heidrun","Hannsjoerg",'Anne-Kathrin']])
#shaky about this date too
data_list.append([datetime.datetime(2001, 10, 10),2001,"Koblenz","Switzerland","","Baden","Switzerland","",0,1,0,['Englisch Grundkurs']])
data_list.append([datetime.datetime(2001, 10, 10),2001,"Baden","Switzerland","","Zuerich","Switzerland","Zuerich HB",0,0,1,['Englisch Grundkurs']])
data_list.append([datetime.datetime(2001, 10, 10),2001,"Zuerich","Switzerland","Zuerich HB","Baden","Switzerland","",0,1,0,['Englisch Grundkurs']])
data_list.append([datetime.datetime(2001, 10, 10),2001,"Baden","Switzerland","","Koblenz","Switzerland","",0,0,1,['Englisch Grundkurs']])
#2004
data_list.append([datetime.datetime(2004, 7, 25),2004,"Koblenz","Switzerland","","Zuerich","Switzerland","Zuerich HB",1,1,0,[]])
data_list.append([datetime.datetime(2004, 7, 25),2004,"Zuerich","Switzerland","Zuerich HB","St Gallen","Switzerland","",1,1,0,["Anne","Gianrico","Sigi"]])
data_list.append([datetime.datetime(2004, 7, 25),2004,"St Gallen","Switzerland","","St Margrethen","Switzerland","",0,1,1,["Anne","Gianrico","Sigi"]])
data_list.append([datetime.datetime(2004, 7, 25),2004,"St Margrethen","Switzerland","","Bregenz","Austria","",0,0,1,["Anne","Gianrico","Sigi"]])
data_list.append([datetime.datetime(2004, 7, 26),2004,"Bregenz","Austria","","St Gallen","Switzerland","",1,1,0,["Anne","Gianrico","Sigi"]])
data_list.append([datetime.datetime(2004, 7, 26),2004,"St Gallen","Switzerland","","Zuerich","Switzerland","Zuerich HB",1,1,1,["Anne","Gianrico","Sigi"]])
data_list.append([datetime.datetime(2004, 7, 26),2004,"Zuerich","Switzerland","Zuerich HB","Koblenz","Switzerland","",0,0,1,[]])
data_list.append([datetime.datetime(2004, 10, 15),2004,"Luton","United Kingdom","Luton Airport Parkway","London","United Kingdom","St Pancras",0,0,0,["Anne","Gianrico","Sigi"]])
data_list.append([datetime.datetime(2004, 10, 20),2004,"London","United Kingdom","St Pancras","Luton","United Kingdom","Luton Airport Parkway",0,0,0,["Anne","Gianrico","Sigi"]])
#2005 
data_list.append([datetime.datetime(2005, 2, 7),2005,"Zuerich","Switzerland","Zuerich HB","Chur","Switzerland","",0,0,1,["ETH Physicists"]])
data_list.append([datetime.datetime(2005, 2, 7),2005,"Chur","Switzerland","","Samedan","Switzerland","",1,1,1,["ETH Physicists"]])
data_list.append([datetime.datetime(2005, 2, 7),2005,"Samedan","Switzerland","","Pontresina","Switzerland","",0,1,1,["ETH Physicists"]])
data_list.append([datetime.datetime(2005, 2, 7),2005,"Pontresina","Switzerland","","Bernina Diavolezza","Switzerland","",0,0,1,["ETH Physicists"]])
data_list.append([datetime.datetime(2005, 2, 11),2005,"Bernina Diavolezza","Switzerland","","Pontresina","Switzerland","",0,1,0,["ETH Physicists"]])
data_list.append([datetime.datetime(2005, 2, 11),2005,"Pontresina","Switzerland","","Samedan","Switzerland","",0,1,1,["ETH Physicists"]])
data_list.append([datetime.datetime(2005, 2, 11),2005,"Samedan","Switzerland","","Chur","Switzerland","",1,1,1,["ETH Physicists"]])
data_list.append([datetime.datetime(2005, 2, 11),2005,"Chur","Switzerland","","Zuerich","Switzerland","Zuerich HB",1,0,1,["ETH Physicists"]])
data_list.append([datetime.datetime(2005, 3, 31),2005,"Koblenz","Switzerland","","Zuerich","Switzerland","Zuerich HB",0,0,1,[]])
data_list.append([datetime.datetime(2005, 3, 31),2005,"Zuerich","Switzerland","Zuerich HB","Muenchen","Germany","Muenchen HBF",1,0,0,[]])
data_list.append([datetime.datetime(2005, 4, 1),2005,"Muenchen","Switzerland","Muenchen HBF","Zuerich","Switzerland","Zuerich HB",1,1,0,[]])
data_list.append([datetime.datetime(2005, 4, 1),2005,"Zuerich","Switzerland","Zuerich HB","Koblenz","Switzerland","",0,0,1,[]])
#trip to CERN (2nd)
data_list.append([datetime.datetime(2005, 6, 24),2005,"Koblenz","Switzerland","","Zuerich","Switzerland","Zuerich HB",0,1,0,[]])
data_list.append([datetime.datetime(2005, 6, 24),2005,"Zuerich","Switzerland","Zuerich HB","Genf","Switzerland","Cornavin",1,0,1,["Physicists 3rd year"]])
data_list.append([datetime.datetime(2005, 6, 24),2005,"Genf","Switzerland","Cornavin","Zuerich","Switzerland","Zuerich HB",1,0,1,["Physicists 3rd year"]])
data_list.append([datetime.datetime(2005, 6, 24),2005,"Zuerich","Switzerland","Zuerich HB","Koblenz","Switzerland","",0,1,0,[]])

data_list.append([datetime.datetime(2005, 8, 31),2005,"Lissabon","Portugal","Cais do Sodre","Belem","Portugal","",0,0,1,["Heidrun",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(2005, 8, 31),2005,"Belem","Portugal","","Lissabon","Portugal","Lisboa Cais do Sodre",0,0,1,["Heidrun",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(2005, 8, 31),2005,"Lissabon","Portugal","Lisboa Rossio","Queluz","Portugal","Queluz-Belas",0,0,0,["Heidrun",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(2005, 8, 31),2005,"Queluz","Portugal","Queluz-Belas","Sintra","Portugal","",0,0,0,["Heidrun",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(2005, 8, 31),2005,"Sintra","Portugal","","Lissabon","Portugal","Rossio",0,0,0,["Heidrun",'Artur','Anne-Kathrin','Hannsjoerg']])
#2006
data_list.append([datetime.datetime(2006, 7, 11),2006,"Luton","United Kingdom","Luton Airport Parkway","London","United Kingdom","St Pancras",0,0,0,["Artur","Heidrun","Hannsjoerg"]])
data_list.append([datetime.datetime(2006, 7, 12),2006,"London","United Kingdom","Paddington",'Windsor','United Kingdom',"Windsor & Eton Central",0,0,0,["Artur","Heidrun","Hannsjoerg"]])
data_list.append([datetime.datetime(2006, 7, 12),2006,'Windsor','United Kingdom',"Windsor & Eton Central","London","United Kingdom","Paddington",0,0,0,["Artur","Heidrun","Hannsjoerg"]])
data_list.append([datetime.datetime(2006, 7, 17),2006,"London","United Kingdom","St Pancras","Luton","United Kingdom","Luton Airport Parkway",0,0,0,["Artur","Heidrun","Hannsjoerg"]])
data_list.append([datetime.datetime(2006, 10, 6),2006,"Koblenz","Switzerland","","Baden","Switzerland","",0,1,0,[]])
data_list.append([datetime.datetime(2006, 10, 6),2006,"Baden","Switzerland","","Zuerich","Switzerland","Zuerich HB",0,0,1,[]])
data_list.append([datetime.datetime(2006, 10, 6),2006,"Zuerich","Switzerland","Zuerich HB","Baden","Switzerland","",0,1,0,[]])
data_list.append([datetime.datetime(2006, 10, 6),2006,"Baden","Switzerland","","Koblenz","Switzerland","",0,0,1,[]])
data_list.append([datetime.datetime(2006, 10, 10),2006,"Koblenz","Switzerland","","Baden","Switzerland","",0,1,0,['Hannsjoerg']])
data_list.append([datetime.datetime(2006, 10, 10),2006,"Baden","Switzerland","","Zuerich","Switzerland","Zuerich HB",0,0,1,['Hannsjoerg']])
data_list.append([datetime.datetime(2006, 10, 10),2006,"Zuerich","Switzerland","Zuerich HB","Baden","Switzerland","",0,1,0,['Hannsjoerg']])
data_list.append([datetime.datetime(2006, 10, 10),2006,"Baden","Switzerland","","Koblenz","Switzerland","",0,0,1,['Hannsjoerg']])
data_list.append([datetime.datetime(2006, 12, 22),2006,"Genf","Switzerland","Cornavin","Aargau","Switzerland","",1,1,0,[]])
data_list.append([datetime.datetime(2006, 12, 22),2006,"Aargau","Switzerland","","Turgi","Switzerland","",0,1,1,[]])
data_list.append([datetime.datetime(2006, 12, 22),2006,"Turgi","Switzerland","","Koblenz","Switzerland","",0,0,1,[]])
#2007
data_list.append([datetime.datetime(2007, 1, 7),2007,"Koblenz","Switzerland","","Turgi","Switzerland","",0,1,0,[]])
data_list.append([datetime.datetime(2007, 1, 7),2007,"Turgi","Switzerland","","Aargau","Switzerland","",0,1,1,[]])
data_list.append([datetime.datetime(2007, 1, 7),2007,"Aargau","Switzerland","","Genf","Switzerland","Cornavin",1,0,1,[]])
data_list.append([datetime.datetime(2007, 3, 21),2007,"Koblenz","Switzerland","","Baden","Switzerland","",0,1,0,[]])
data_list.append([datetime.datetime(2007, 3, 21),2007,"Baden","Switzerland","","Zuerich","Switzerland","Zuerich HB",0,0,1,[]])
data_list.append([datetime.datetime(2007, 3, 21),2007,"Zuerich","Switzerland","Zuerich HB","Baden","Switzerland","",0,1,0,[]])
data_list.append([datetime.datetime(2007, 3, 21),2007,"Baden","Switzerland","","Koblenz","Switzerland","",0,0,1,[]])
data_list.append([datetime.datetime(2007, 8, 3),2007,"Genf","Switzerland","Cornavin","Aargau","Switzerland","",1,1,0,[]])
data_list.append([datetime.datetime(2007, 8, 3),2007,"Aargau","Switzerland","","Turgi","Switzerland","",0,1,1,[]])
data_list.append([datetime.datetime(2007, 8, 3),2007,"Turgi","Switzerland","","Koblenz","Switzerland","",0,0,1,[]])
data_list.append([datetime.datetime(2007, 8, 5),2007,"Koblenz","Switzerland","","Turgi","Switzerland","",0,1,0,[]])
data_list.append([datetime.datetime(2007, 8, 5),2007,"Turgi","Switzerland","","Aargau","Switzerland","",0,1,1,[]])
data_list.append([datetime.datetime(2007, 8, 5),2007,"Aargau","Switzerland","","Genf","Switzerland","Cornavin",1,0,1,[]])
data_list.append([datetime.datetime(2007, 8, 22),2007,"Genf","Switzerland","Cornavin","Genf","Switzerland","Lancy-Pont-Rouge",0,0,0,['Artur']])
data_list.append([datetime.datetime(2007, 8, 22),2007,"Genf","Switzerland","Lancy-Pont-Rouge","Genf","Switzerland","Cornavin",0,0,0,['Artur']])
data_list.append([datetime.datetime(2007, 9, 9),2007,"Genf","Switzerland","Cornavin","Lausanne","Switzerland","",1,1,0,[]])
data_list.append([datetime.datetime(2007, 9, 9),2007,"Lausanne","Switzerland","","Villeneuve","Switzerland","",0,0,1,[]])
data_list.append([datetime.datetime(2007, 9, 9),2007,"Territet","Switzerland","","Lausanne","Switzerland","",0,0,0,[]])
data_list.append([datetime.datetime(2007, 9, 9),2007,"Lausanne","Switzerland","","Genf","Switzerland","Cornavin",1,0,0,[]])
data_list.append([datetime.datetime(2007, 12, 16),2007,"Genf","Switzerland","Cornavin","Visp","Switzerland","",1,1,0,[]])
data_list.append([datetime.datetime(2007, 12, 16),2007,"Visp","Switzerland","","Zermatt","Switzerland","Cornavin",1,0,1,[]])
data_list.append([datetime.datetime(2007, 12, 16),2007,"Zermatt","Switzerland","Cornavin","Visp","Switzerland","",1,1,0,[]])
data_list.append([datetime.datetime(2007, 12, 16),2007,"Visp","Switzerland","","Genf","Switzerland","Cornavin",1,0,1,[]])
data_list.append([datetime.datetime(2007, 12, 21),2007,"Genf","Switzerland","Cornavin","Aargau","Switzerland","",1,1,0,[]])
data_list.append([datetime.datetime(2007, 12, 21),2007,"Aargau","Switzerland","","Turgi","Switzerland","",0,1,1,[]])
data_list.append([datetime.datetime(2007, 12, 21),2007,"Turgi","Switzerland","","Koblenz","Switzerland","",0,0,1,[]])

#2008
data_list.append([datetime.datetime(2008, 1, 6),2008,"Koblenz","Switzerland","Cornavin","Turgi","Switzerland","",0,1,0,[]])
data_list.append([datetime.datetime(2008, 1, 6),2008,"Turgi","Switzerland","","Aargau","Switzerland","",0,1,1,[]])
data_list.append([datetime.datetime(2008, 1, 6),2008,"Aargau","Switzerland","","Genf","Switzerland","Cornavin",1,0,1,[]])
data_list.append([datetime.datetime(2008, 1, 11),2008,"Genf","Switzerland","Cornavin","Zuerich","Switzerland","Zuerich HB",1,1,0,[]])
data_list.append([datetime.datetime(2008, 1, 11),2008,"Zuerich","Switzerland","Zuerich HB","Ziegelbruecke","Switzerland","Zuerich HB",0,1,1,[]])
data_list.append([datetime.datetime(2008, 1, 17),2008,"Ziegelbruecke","Switzerland","","St Gallen","Switzerland","St Gallen HB",0,0,1,[]])
data_list.append([datetime.datetime(2008, 1, 17),2008,"St Gallen","Switzerland","St Gallen HB","Ziegelbruecke","Switzerland",'',0,1,0,[]])
data_list.append([datetime.datetime(2008, 1, 20),2008,"Zuerich","Switzerland","Zuerich HB","Genf","Switzerland","Cornavin",1,0,1,[]])
data_list.append([datetime.datetime(2008, 1, 20),2008,"Ziegelbruecke","Switzerland",'',"Zuerich","Switzerland","Zuerich HB",0,1,1,[]])
data_list.append([datetime.datetime(2008, 5, 3),2008,"Genf","Switzerland","Cornavin","Neuchatel","Switzerland","",1,0,0,['Zhiling']])
data_list.append([datetime.datetime(2008, 5, 3),2008,"Neuchatel","Switzerland","","Solothurn","Switzerland","Solothurn HB",1,0,0,['Zhiling']])
data_list.append([datetime.datetime(2008, 5, 3),2008,"Solothurn","Switzerland","Solothurn HB","Bern","Switzerland","Bern HB",0,0,0,['Zhiling']])
data_list.append([datetime.datetime(2008, 5, 3),2008,"Bern","Switzerland","Bern HB","Visp","Switzerland","",1,1,0,['Zhiling']])
data_list.append([datetime.datetime(2008, 5, 3),2008,"Visp","Switzerland","","Sion","Switzerland","",1,0,1,['Zhiling']])
data_list.append([datetime.datetime(2008, 5, 3),2008,"Sion","Switzerland","","Lausanne","Switzerland","",1,0,0,['Zhiling']])
data_list.append([datetime.datetime(2008, 5, 3),2008,"Lausanne","Switzerland","","Genf","Switzerland","Cornavin",1,0,0,['Zhiling']])
data_list.append([datetime.datetime(2008, 5, 15),2008,"Genf","Switzerland","Cornavin","Aargau","Switzerland","",1,1,0,[]])
data_list.append([datetime.datetime(2008, 5, 15),2008,"Aargau","Switzerland","","Turgi","Switzerland","",0,1,1,[]])
data_list.append([datetime.datetime(2008, 5, 15),2008,"Turgi","Switzerland","","Koblenz","Switzerland","",0,0,1,[]])
data_list.append([datetime.datetime(2008, 5, 18),2008,"Koblenz","Switzerland","Cornavin","Turgi","Switzerland","",0,1,0,[]])
data_list.append([datetime.datetime(2008, 5, 18),2008,"Turgi","Switzerland","","Aargau","Switzerland","",0,1,1,[]])
data_list.append([datetime.datetime(2008, 5, 18),2008,"Aargau","Switzerland","","Genf","Switzerland","Cornavin",1,0,1,[]])
data_list.append([datetime.datetime(2008, 7, 28),2008,"Genf","Switzerland","Cornavin","Genf","Switzerland","Geneve Aeoroport",0,0,0,[]])
data_list.append([datetime.datetime(2008, 7, 28),2008,"Philadelphia","USA","Airport Terminal A","Philadelphia","USA","30th Street",0,0,0,["Joanna"]])
data_list.append([datetime.datetime(2008, 8, 6),2008,"Philadelphia","USA","30th Street","Philadelphia","USA","Airport Terminal A",0,0,0,["Joanna"]])
data_list.append([datetime.datetime(2008, 8, 7),2008,"Genf","Switzerland","Geneve Aeroport","Genf","Switzerland","Cornavin",0,0,0,[]])
data_list.append([datetime.datetime(2008, 8, 15),2008,"Genf","Switzerland","Cornavin","Aargau","Switzerland","",1,1,0,[]])
data_list.append([datetime.datetime(2008, 8, 15),2008,"Aargau","Switzerland","","Turgi","Switzerland","",0,1,1,[]])
data_list.append([datetime.datetime(2008, 8, 15),2008,"Turgi","Switzerland","","Koblenz","Switzerland","",0,0,1,[]])
data_list.append([datetime.datetime(2008, 8, 17),2008,"Koblenz","Switzerland","Cornavin","Turgi","Switzerland","",0,1,0,[]])
data_list.append([datetime.datetime(2008, 8, 17),2008,"Turgi","Switzerland","","Aargau","Switzerland","",0,1,1,[]])
data_list.append([datetime.datetime(2008, 8, 17),2008,"Aargau","Switzerland","","Genf","Switzerland","Cornavin",1,0,1,[]])
data_list.append([datetime.datetime(2008, 9, 5),2008,"Genf","Switzerland","Cornavin","Genf","Switzerland","Geneve Aeoroport",0,0,0,[]])
data_list.append([datetime.datetime(2008, 9, 5),2008,"Madrid","Spain","Sol","El Escorial","Spain","",0,0,0,['Heidrun','Hannsjoerg','Artur']])
data_list.append([datetime.datetime(2008, 9, 5),2008,"El Escorial","Spain","","Madrid","Spain","Sol",0,0,0,['Heidrun','Hannsjoerg','Artur']])
data_list.append([datetime.datetime(2008, 9, 6),2008,"Madrid","Spain","Chamartin","Segovia","Spain","Segovia AVE",1,0,0,['Heidrun']])
data_list.append([datetime.datetime(2008, 9, 6),2008,"Segovia","Spain","Segovia AVE","Madrid","Spain","Chamartin",1,0,0,['Heidrun']])
data_list.append([datetime.datetime(2008, 9, 9),2008,"Genf","Switzerland","Geneve Aeroport","Genf","Switzerland","Cornavin",0,0,0,[]])
data_list.append([datetime.datetime(2008, 10, 5),2008,"Genf","Switzerland","Cornavin","Bern","Switzerland","Bern HB",1,1,0,[]])
data_list.append([datetime.datetime(2008, 10, 5),2008,"Bern","Switzerland","Bern HB","Spiez","Switzerland","",1,1,1,[]])
data_list.append([datetime.datetime(2008, 10, 5),2008,"Spiez","Switzerland","","Interlaken Ost","Switzerland","",1,1,1,['Anne','Sigi']])
data_list.append([datetime.datetime(2008, 10, 5),2008,"Interlaken Ost","Switzerland","","Grindelwald","Switzerland","",0,1,1,['Anne','Sigi']])
data_list.append([datetime.datetime(2008, 10, 5),2008,"Lauterbrunnen","Switzerland","","Interlaken Ost","Switzerland","",0,1,1,['Anne','Sigi']])
data_list.append([datetime.datetime(2008, 10, 5),2008,"Interlaken Ost","Switzerland","","Bern","Switzerland","Bern HB",1,1,1,['Anne','Sigi']])
data_list.append([datetime.datetime(2008, 10, 5),2008,"Bern","Switzerland","Bern HB","Genf","Switzerland","Cornavin",1,0,1,[]])
data_list.append([datetime.datetime(2008, 11, 27),2008,"Genf","Switzerland","Cornavin","Biel/Bienne","Switzerland","",1,1,0,[]])
data_list.append([datetime.datetime(2008, 11, 27),2008,"Biel/Bienne","Switzerland","","Zuerich","Switzerland","Zuerich HB",1,0,1,[]])
data_list.append([datetime.datetime(2008, 11, 27),2008,"Zuerich","Switzerland","Zuerich HB","Genf","Switzerland","Cornavin",1,0,0,[]])
data_list.append([datetime.datetime(2008, 11, 27),2008,"Zuerich","Switzerland","Zuerich HB","Baden","Switzerland","",1,1,0,[]])
data_list.append([datetime.datetime(2008, 11, 27),2008,"Baden","Switzerland","","Koblenz","Switzerland","",0,0,1,[]])
data_list.append([datetime.datetime(2008, 12, 2),2008,"Koblenz","Switzerland","","Turgi","Switzerland","",0,1,0,[]])
data_list.append([datetime.datetime(2008, 12, 2),2008,"Turgi","Switzerland","","Aargau","Switzerland","",0,1,1,[]])
data_list.append([datetime.datetime(2008, 12, 2),2008,"Aargau","Switzerland","","Genf","Switzerland","Cornavin",1,0,1,[]])
data_list.append([datetime.datetime(2008, 12, 19),2008,"Genf","Switzerland","Cornavin","Aargau","Switzerland","",1,1,0,[]])
data_list.append([datetime.datetime(2008, 12, 19),2008,"Aargau","Switzerland","","Turgi","Switzerland","",0,1,1,[]])
data_list.append([datetime.datetime(2008, 12, 19),2008,"Turgi","Switzerland","","Koblenz","Switzerland","",0,0,1,[]])

# %%
#2009
data_list.append([datetime.datetime(2009, 1, 4),2009,"Koblenz","Switzerland","","Turgi","Switzerland","",0,1,0,[]])
data_list.append([datetime.datetime(2009, 1, 4),2009,"Turgi","Switzerland","","Aargau","Switzerland","",0,1,1,[]])
data_list.append([datetime.datetime(2009, 1, 4),2009,"Aargau","Switzerland","","Genf","Switzerland","Cornavin",1,0,1,[]])
data_list.append([datetime.datetime(2009, 1, 16),2009,"Genf","Switzerland","Cornavin","Aargau","Switzerland","",1,1,0,[]])
data_list.append([datetime.datetime(2009, 1, 16),2009,"Aargau","Switzerland","","Turgi","Switzerland","",0,1,1,[]])
data_list.append([datetime.datetime(2009, 1, 16),2009,"Turgi","Switzerland","","Koblenz","Switzerland","",0,0,1,[]])
data_list.append([datetime.datetime(2009, 1, 18),2009,"Koblenz","Switzerland","","Turgi","Switzerland","",0,1,0,[]])
data_list.append([datetime.datetime(2009, 1, 18),2009,"Turgi","Switzerland","","Aargau","Switzerland","",0,1,1,[]])
data_list.append([datetime.datetime(2009, 1, 18),2009,"Aargau","Switzerland","","Genf","Switzerland","Cornavin",1,0,1,[]])
data_list.append([datetime.datetime(2009, 1, 21),2009,"Genf","Switzerland","Cornavin","Biel/Bienne","Switzerland","",1,1,0,[]])
data_list.append([datetime.datetime(2009, 1, 21),2009,"Biel/Bienne","Switzerland","","Zuerich","Switzerland","Zuerich HB",1,0,1,[]])
data_list.append([datetime.datetime(2009, 1, 21),2009,"Zuerich","Switzerland","Zuerich HB","Genf","Switzerland","Cornavin",1,0,0,[]])
data_list.append([datetime.datetime(2009, 2, 1),2009,"Genf","Switzerland","Cornavin","Lausanne","Switzerland","",1,0,0,[]])
data_list.append([datetime.datetime(2009, 2, 1),2009,"Lausanne","Switzerland","","Morges","Switzerland","",1,0,0,[]])
data_list.append([datetime.datetime(2009, 2, 1),2009,"Morges","Switzerland","","Nyon","Switzerland","",1,0,0,[]])
data_list.append([datetime.datetime(2009, 2, 1),2009,"Nyon","Switzerland","","Genf","Switzerland","Cornavin",1,0,0,[]])
data_list.append([datetime.datetime(2009, 3, 21),2009,"Genf","Switzerland","Cornavin","Biel/Bienne","Switzerland","",1,1,0,[]])
data_list.append([datetime.datetime(2009, 3, 21),2009,"Biel/Bienne","Switzerland","","Basel","Switzerland","Basel SBB",1,0,1,[]])
data_list.append([datetime.datetime(2009, 3, 21),2009,"Basel","Switzerland","Basel SBB","Bern","Switzerland","Bern HB",1,1,0,[]])
data_list.append([datetime.datetime(2009, 3, 21),2009,"Bern","Switzerland","Bern HB","Fribourg","Switzerland","",1,0,1,[]])
data_list.append([datetime.datetime(2009, 3, 21),2009,"Fribourg","Switzerland","","Lausanne","Switzerland","",1,1,0,[]])
data_list.append([datetime.datetime(2009, 3, 21),2009,"Lausanne","Switzerland","","St Maurice","Switzerland","",1,0,1,[]])
data_list.append([datetime.datetime(2009, 3, 21),2009,"St Maurice","Switzerland","","Genf","Switzerland","Cornavin",1,0,0,[]])
data_list.append([datetime.datetime(2009, 4, 9),2009,"Genf","Switzerland","Cornavin","Aargau","Switzerland","",1,1,0,[]])
data_list.append([datetime.datetime(2009, 4, 9),2009,"Aargau","Switzerland","","Turgi","Switzerland","",0,1,1,[]])
data_list.append([datetime.datetime(2009, 4, 9),2009,"Turgi","Switzerland","","Koblenz","Switzerland","",0,0,1,[]])
data_list.append([datetime.datetime(2009, 4, 13),2009,"Koblenz","Switzerland","","Turgi","Switzerland","",0,1,0,[]])
data_list.append([datetime.datetime(2009, 4, 13),2009,"Turgi","Switzerland","","Aargau","Switzerland","",0,1,1,[]])
data_list.append([datetime.datetime(2009, 4, 13),2009,"Aargau","Switzerland","","Genf","Switzerland","Cornavin",1,0,1,[]])
data_list.append([datetime.datetime(2009, 4, 25),2009,"Genf","Switzerland","Cornavin","Genf","Switzerland","Geneve Aeoroport",0,0,0,[]])
data_list.append([datetime.datetime(2015, 4, 25),2009,"Madrid","Spain","Aeropuerto Madrid-Barajas T4","Madrid","Spain","Chamartin",0,1,0,[]])
data_list.append([datetime.datetime(2009, 4, 29),2009,"Madrid","Spain","Madrid-Puerta de Atocha","Getafe","Spain","Getafe Central",0,0,0,[]])
data_list.append([datetime.datetime(2009, 4, 29),2009,"Getafe","Spain","Getafe Central","Madrid","Spain","Madrid-Puerta de Atocha",0,0,0,[]])
data_list.append([datetime.datetime(2009, 4, 29),2009,"Madrid","Spain","Madrid-Puerta de Atocha","Toledo","Spain","",1,0,0,[]])
data_list.append([datetime.datetime(2009, 4, 29),2009,"Toledo","Spain","","Madrid","Spain","Madrid-Puerta de Atocha",1,1,0,[]])
data_list.append([datetime.datetime(2009, 4, 29),2009,"Madrid","Spain","Madrid-Puerta de Atocha","Madrid","Spain","Chamartin",0,0,1,[]])
data_list.append([datetime.datetime(2015, 5, 1),2015,"Madrid","Spain","Chamartin","Madrid","Spain","Aeropuerto Madrid-Barajas T4",0,0,0,[]])
data_list.append([datetime.datetime(2009, 5, 1),2009,"Genf","Switzerland","Geneve Aeroport","Genf","Switzerland","Geneve Cornavin",0,0,0,[]])
data_list.append([datetime.datetime(2009, 5, 15),2009,"Genf","Switzerland","Cornavin","Aargau","Switzerland","",1,1,0,[]])
data_list.append([datetime.datetime(2009, 5, 15),2009,"Aargau","Switzerland","","Turgi","Switzerland","",0,1,1,[]])
data_list.append([datetime.datetime(2009, 5, 15),2009,"Turgi","Switzerland","","Koblenz","Switzerland","",0,0,1,[]])
data_list.append([datetime.datetime(2009, 5, 17),2009,"Koblenz","Switzerland","Cornavin","Turgi","Switzerland","",0,1,0,[]])
data_list.append([datetime.datetime(2009, 5, 17),2009,"Turgi","Switzerland","","Aargau","Switzerland","",0,1,1,[]])
data_list.append([datetime.datetime(2009, 5, 17),2009,"Aargau","Switzerland","","Genf","Switzerland","Cornavin",1,0,1,[]])
data_list.append([datetime.datetime(2009, 6, 5),2009,"Genf","Switzerland","Cornavin","Aargau","Switzerland","",1,1,0,[]])
data_list.append([datetime.datetime(2009, 6, 5),2009,"Aargau","Switzerland","","Turgi","Switzerland","",0,1,1,[]])
data_list.append([datetime.datetime(2009, 6, 5),2009,"Turgi","Switzerland","","Koblenz","Switzerland","",0,0,1,[]])
data_list.append([datetime.datetime(2009, 6, 7),2009,"Koblenz","Switzerland","Cornavin","Turgi","Switzerland","",0,1,0,[]])
data_list.append([datetime.datetime(2009, 6, 7),2009,"Turgi","Switzerland","","Aargau","Switzerland","",0,1,1,[]])
data_list.append([datetime.datetime(2009, 6, 7),2009,"Aargau","Switzerland","","Genf","Switzerland","Cornavin",1,0,1,[]])
data_list.append([datetime.datetime(2009, 6, 23),2009,"Genf","Switzerland","Cornavin","Genf","Switzerland","Geneve Aeoroport",0,0,0,[]])
data_list.append([datetime.datetime(2009, 7, 3),2009,"New York City","USA","Jamaica","New York City","USA","Pennsylvania Station",0,0,0,[]])
data_list.append([datetime.datetime(2009, 7, 8),2009,"New York City","USA","Pennsylvania Station","New York City","USA","Jamaica",0,0,0,[]])
data_list.append([datetime.datetime(2009, 7, 9),2009,"Genf","Switzerland","Geneve Aeroport","Genf","Switzerland","Geneve Cornavin",0,0,0,[]])
data_list.append([datetime.datetime(2009, 7, 26),2009,"Genf","Switzerland","Cornavin","St Maurice","Switzerland","",1,0,0,[]])
data_list.append([datetime.datetime(2009, 7, 26),2009,"St Maurice","Switzerland","","Sion","Switzerland","",1,0,0,[]])
data_list.append([datetime.datetime(2009, 7, 26),2009,"Sion","Switzerland","","St-Leonard","Switzerland","",0,0,0,[]])
data_list.append([datetime.datetime(2009, 7, 26),2009,"St-Leonard","Switzerland","","Sierre/Sieders","Switzerland","",0,1,0,[]])
data_list.append([datetime.datetime(2009, 7, 26),2009,"Sierre/Sieders","Switzerland","","Brig","Switzerland","",1,0,1,[]])
data_list.append([datetime.datetime(2009, 7, 26),2009,"Brig","Switzerland","","Genf","Switzerland","Cornavin",1,0,0,[]])
data_list.append([datetime.datetime(2009, 8, 14),2009,"Genf","Switzerland","Cornavin","Aargau","Switzerland","",1,1,0,[]])
data_list.append([datetime.datetime(2009, 8, 14),2009,"Aargau","Switzerland","","Turgi","Switzerland","",0,1,1,[]])
data_list.append([datetime.datetime(2009, 8, 14),2009,"Turgi","Switzerland","","Koblenz","Switzerland","",0,0,1,[]])
#this could have been exam season
data_list.append([datetime.datetime(2009, 8, 16),2009,"Koblenz","Switzerland","Cornavin","Turgi","Switzerland","",0,1,0,[]])
data_list.append([datetime.datetime(2009, 8, 16),2009,"Turgi","Switzerland","","Aargau","Switzerland","",0,1,1,[]])
data_list.append([datetime.datetime(2009, 8, 16),2009,"Aargau","Switzerland","","Genf","Switzerland","Cornavin",1,0,1,[]])
data_list.append([datetime.datetime(2009, 8, 23),2009,"Genf","Switzerland","Cornavin","Visp","Switzerland","",1,1,0,[]])
data_list.append([datetime.datetime(2009, 8, 23),2009,"Visp","Switzerland","","Zermatt","Switzerland","Cornavin",0,0,1,[]])
data_list.append([datetime.datetime(2009, 8, 23),2009,"Zermatt","Switzerland","Cornavin","Visp","Switzerland","",0,1,0,[]])
data_list.append([datetime.datetime(2009, 8, 23),2009,"Visp","Switzerland","","Genf","Switzerland","Cornavin",1,0,1,[]])
data_list.append([datetime.datetime(2009, 8, 30),2009,"Genf","Switzerland","Cornavin","Bern","Switzerland","Bern HB",1,0,1,[]])
data_list.append([datetime.datetime(2009, 8, 30),2009,"Bern","Switzerland","Bern HB","Interlaken","Switzerland","Interlaken Ost",1,1,1,[]])
data_list.append([datetime.datetime(2009, 8, 30),2009,"Interlaken","Switzerland","Interlaken Ost","Meiringen","Switzerland","",1,1,1,[]])
data_list.append([datetime.datetime(2009, 8, 30),2009,"Meiringen","Switzerland","","Innertkirchen","Switzerland","Aareschlucht Ost",0,0,1,[]])
data_list.append([datetime.datetime(2009, 8, 30),2009,"Meiringen","Switzerland","","Interlaken","Switzerland","Interlaken West",1,1,0,[]])
data_list.append([datetime.datetime(2009, 8, 30),2009,"Interlaken","Switzerland","Interlaken West","Lauterbrunnen","Switzerland","",1,0,1,[]])
data_list.append([datetime.datetime(2009, 8, 30),2009,"Lauterbrunnen","Switzerland","","Interlaken","Switzerland","Interlaken West",0,1,0,[]])
data_list.append([datetime.datetime(2009, 8, 30),2009,"Interlaken","Switzerland","Interlaken West","Thun","Switzerland","",0,1,1,[]])
data_list.append([datetime.datetime(2009, 8, 30),2009,"Thun","Switzerland","","Bern","Switzerland","Bern HB",1,1,0,[]])
data_list.append([datetime.datetime(2009, 8, 30),2009,"Bern","Switzerland","Bern HB","Genf","Switzerland","Cornavin",1,0,0,[]])
data_list.append([datetime.datetime(2009, 9, 1),2009,"Genf","Switzerland","Cornavin","Zuerich","Switzerland","Zuerich HB",1,1,0,[]])
data_list.append([datetime.datetime(2009, 9, 1),2009,"Zuerich","Switzerland","Zuerich HB","Innsbruck","Austria","",1,0,1,[]])
data_list.append([datetime.datetime(2009, 9, 5),2009,"Innsbruck","Austria","","Feldkirch","Austria","",1,1,0,[]])
data_list.append([datetime.datetime(2009, 9, 5),2009,"Feldkirch","Austria","","Buchs","Switzerland","",0,1,1,[]])
data_list.append([datetime.datetime(2009, 9, 5),2009,"Buchs","Switzerland","","Sargans","Switzerland","",0,1,1,[]])
data_list.append([datetime.datetime(2009, 9, 5),2009,"Sargans","Switzerland","","Zuerich","Switzerland","Zuerich HB",1,1,1,[]])
data_list.append([datetime.datetime(2009, 9, 5),2009,"Zuerich","Switzerland","Zuerich HB","Genf","Switzerland","Cornavin",1,0,1,[]])
data_list.append([datetime.datetime(2009, 11, 26),2009,"Genf","Switzerland","Cornavin","Bern","Switzerland","Bern HB",1,0,1,[]])
data_list.append([datetime.datetime(2009, 11, 26),2009,"Bern","Switzerland","Bern HB","Genf","Switzerland","Cornavin",1,1,1,[]])
#check here, for sure i came to Lauchringen over Zuerich on Dec 10
data_list.append([datetime.datetime(2009, 12, 10),2009,"Genf","Switzerland","Cornavin","Bienne/Biel","Switzerland","",1,1,0,[]])
data_list.append([datetime.datetime(2009, 12, 10),2009,"Bienne/Biel","Switzerland","","Zuerich","Switzerland","Zuerich HB",1,1,1,[]])
data_list.append([datetime.datetime(2009, 12, 10),2009,"Zuerich","Switzerland","Zuerich HB","Koblenz","Switzerland","",0,0,0,[]])

# %%
#2010
data_list.append([datetime.datetime(2010, 1, 3),2010,"Koblenz","Switzerland","","Turgi","Switzerland","",0,1,0,[]])
data_list.append([datetime.datetime(2010, 1, 3),2010,"Turgi","Switzerland","","Aargau","Switzerland","",0,1,1,[]])
data_list.append([datetime.datetime(2010, 1, 3),2010,"Aargau","Switzerland","","Genf","Switzerland","Cornavin",1,0,1,[]])
data_list.append([datetime.datetime(2010, 1, 16),2010,"Genf","Switzerland","Cornavin","Domodossola","Italy","",1,1,0,[]])
data_list.append([datetime.datetime(2010, 1, 16),2010,"Domodossola","Italy","","Locarno","Switzerland","",0,0,1,[]])
data_list.append([datetime.datetime(2010, 1, 21),2010,"Locarno","Switzerland","","Bellinzona","Switzerland","",0,0,0,[]])
data_list.append([datetime.datetime(2010, 1, 21),2010,"Bellinzona","Switzerland","","Locarno","Switzerland","",0,0,0,[]])
data_list.append([datetime.datetime(2010, 1, 24),2010,"Locarno","Switzerland","","Bellinzona","Switzerland","",0,0,0,[]])
data_list.append([datetime.datetime(2010, 1, 24),2010,"Lugano","Switzerland","","Bellinzona","Switzerland","",0,1,0,[]])
data_list.append([datetime.datetime(2010, 1, 24),2010,"Chiasso","Switzerland","","Como","Italy","S Giovanni",0,0,1,[]])
data_list.append([datetime.datetime(2010, 1, 24),2010,"Como S Giovanni","Switzerland","","Chiasso","Switzerland","",0,1,0,[]])
data_list.append([datetime.datetime(2010, 1, 24),2010,"Chiasso","Switzerland","","Lugano","Switzerland","",0,1,1,[]])
data_list.append([datetime.datetime(2010,
Gianrico']])
data_list.append([datetime.datetime(2012, 7, 28),2012,"Potsdam","Germany","Potsdam HBF","Berlin","Germany","Berlin-Zoologischer Garten",0,0,0,["Gianrico"]])
data_list.append([datetime.datetime(2012, 7, 29),2012,"Berlin","Germany","Berlin-Innsbrucker Platz","Berlin","Germany","Berlin-S+U Tempelhof",0,0,0,["Gianrico"]])
data_list.append([datetime.datetime(2012, 7, 29),2012,"Berlin","Germany","Berlin-Alexanderplatz","Berlin","Germany","Berlin-Zoologischer Garten",0,0,0,[]])
data_list.append([datetime.datetime(2012, 7, 30),2012,"Berlin","Germany","Berlin-Zoologischer Garten","Berlin","Germany","Berlin-Bellevue",0,0,0,[]])
data_list.append([datetime.datetime(2012, 7, 30),2012,"Berlin","Germany","Berlin-Bellevue","Berlin","Germany","Hackescher Markt",0,0,0,[]])
data_list.append([datetime.datetime(2012, 7, 31),2012,"Berlin","Germany","Berlin-Zoologischer Garten","Berlin","Germany","Berlin-Hackescher Markt",0,0,0,[]])
data_list.append([datetime.datetime(2012, 7, 31),2012,"Berlin","Germany","Berlin-Zoologischer Garten","Schoenefeld","Germany","Berlin-Schoenefeld",0,0,0,[]])
data_list.append([datetime.datetime(2012, 7, 31),2012,"Genf","Switzerland","Geneve Aeroport","Genf","Switzerland","Cornavin",0,0,0,[]])
data_list.append([datetime.datetime(2011, 8, 18),2012,"Genf","Switzerland","Cornavin","Bern","Switzerland","Bern HB",1,1,0,[]])
data_list.append([datetime.datetime(2011, 8, 18),2012,"Bern","Switzerland","Bern HB","Interlaken","Switzerland","Interlaken Ost",1,1,1,[]])
data_list.append([datetime.datetime(2011, 8, 18),2012,"Interlaken","Switzerland","Interlaken Ost","Grindelwald","Switzerland","",0,0,1,[]])
data_list.append([datetime.datetime(2011, 8, 18),2012,"Grindelald","Switzerland","","Interlaken","Switzerland","Interlaken West",0,0,0,['Indara']])
data_list.append([datetime.datetime(2011, 8, 18),2012,"Interlaken","Switzerland","Interlaken Ost","Bern","Switzerland","Bern HB",1,1,0,['Indara','Jacob',"Kate",'Stan','Brant']])
data_list.append([datetime.datetime(2011, 8, 18),2012,"Bern","Switzerland","Bern HB","Olten","Switzerland","",1,1,1,['Indara','Jacob',"Kate",'Stan','Brant']])
data_list.append([datetime.datetime(2011, 8, 18),2012,"Olten","Switzerland","","Lausanne","Switzerland","",1,1,1,['Indara','Jacob',"Kate",'Stan','Brant']])
data_list.append([datetime.datetime(2011, 8, 18),2012,"Lausanne","Switzerland","","Genf","Switzerland","Cornavin",0,0,1,['Indara','Jacob',"Kate",'Stan','Brant']])
data_list.append([datetime.datetime(2012, 8, 30),2012,"Genf","Switzerland","Cornavin","Genf","Switzerland","Geneve Aeroport",0,0,0,[]])
data_list.append([datetime.datetime(2005, 8, 31),2012,"Lissabon","Portugal","Rossio","Queluz","Portugal","Queluz-Belas",0,0,0,[]])
data_list.append([datetime.datetime(2005, 8, 31),2012,"Queluz","Portugal","Queluz-Belas","Sintra","Portugal","",0,0,0,[]])
data_list.append([datetime.datetime(2005, 8, 31),2012,"Sintra","Portugal","","Lissabon","Portugal","Rossio",0,0,0,[]])
data_list.append([datetime.datetime(2005, 9, 1),2012,"Lissabon","Portugal","Rossio","Queluz","Portugal","Sintra",0,0,0,[]])
data_list.append([datetime.datetime(2005, 9, 1),2012,"Sintra","Portugal","","Lissabon","Portugal","Rossio",0,0,0,[]])
data_list.append([datetime.datetime(2005, 9, 2),2012,"Cais do Sodre","Portugal","","Lissabon","Portugal","Belem",0,0,0,['David Saltzberg']])
data_list.append([datetime.datetime(2005, 9, 2),2012,"Belem","Portugal","","Lissabon","Portugal","Cais do Sodre",0,0,0,['David Saltzberg']])
data_list.append([datetime.datetime(2005, 9, 6),2012,"Lissabon","Portugal","Oriente","Tomar","Portugal","Sintra",0,0,0,[]])
data_list.append([datetime.datetime(2005, 9, 6),2012,"Tomar","Portugal","","Lissabon","Portugal","Oriente",0,0,0,[]])
data_list.append([datetime.datetime(2005, 9, 7),2012,"Lissabon","Portugal","Cais do Sodre","Cascais","Portugal","",0,0,0,[]])
data_list.append([datetime.datetime(2005, 9, 7),2012,"Cascais","Portugal","","Lissabon","Portugal","Cais do Sodre",0,0,0,[]])
data_list.append([datetime.datetime(2005, 9, 7),2012,"Lissabon","Portugal","Santa Apolonia","Porto","Portugal","Sao Bento",1,0,0,[]])
data_list.append([datetime.datetime(2005, 9, 7),2012,"Porto","Portugal","Sao Bento","Coimbra","Portugal","",1,0,0,[]])
data_list.append([datetime.datetime(2005, 9, 7),2012,"Coimbra","Portugal","","Lissabon","Portugal","Santa Apolonia",1,0,0,[]])
data_list.append([datetime.datetime(2005, 9, 8),2012,"Lissabon","Portugal","Alcantara-Mar","Lissabon","Portugal","Cais do Sodre",0,1,0,[]])
data_list.append([datetime.datetime(2012,9, 8),2012,"Genf","Switzerland","Geneve Aeroport","Genf","Switzerland","Cornavin",0,0,0,[]])
data_list.append([datetime.datetime(2012,9, 16),2012,"Genf","Switzerland","Cornavin","Lausanne","Switzerland","",1,1,0,[]])
data_list.append([datetime.datetime(2012,9, 16),2012,"Lausanne","Switzerland","","Bern","Switzerland","Bern HB",1,1,1,[]])
data_list.append([datetime.datetime(2012,9, 16),2012,"Bern","Switzerland","Bern HB","Spiez","Switzerland","",1,1,1,[]])
data_list.append([datetime.datetime(2012,9, 16),2012,"Spiez","Switzerland","","Interlaken","Switzerland","Interlaken Ost",0,1,1,[]])
data_list.append([datetime.datetime(2012,9, 16),2012,"Interlaken","Switzerland","Interlaken Ost","Meiringen","Switzerland","",0,1,1,[]])
data_list.append([datetime.datetime(2012,9, 16),2012,"Oberwald","Switzerland","","Brig","Switzerland","",0,1,1,[]])
data_list.append([datetime.datetime(2012,9, 16),2012,"Brig","Switzerland","","Genf","Switzerland","Cornavin",0,0,1,[]])
data_list.append([datetime.datetime(2012, 9, 28),2012,"Genf","Switzerland","Cornavin","Genf","Switzerland","Geneve Aeroport",0,0,0,["Eric"]])
data_list.append([datetime.datetime(2012, 9, 28),2012,"Warschau","Poland","Warszawa Chopin Airport","Warschau","Poland","Warsaw West",0,1,0,['Eric']])
data_list.append([datetime.datetime(2012, 9, 28),2012,"Warschau","Poland","Warszawa West","Warschau","Poland","Warszawa Centralna",0,0,1,['Eric']])
data_list.append([datetime.datetime(2012, 9, 29),2012,"Warschau","Poland","Warszawa Centralna","Krakau","Poland","Krakow Glowny",1,0,0,['Eric']])
data_list.append([datetime.datetime(2012, 9, 29),2012,"Krakau","Poland","Krakow Glowny","Warschau","Poland"," Warszawa Centralna",1,0,0,['Eric']])
data_list.append([datetime.datetime(2012, 10, 1),2012,"Warschau","Poland","Warszawa Centralna","Warschau","Poland","Warszawa Centralna",0,0,1,['Eric']])
data_list.append([datetime.datetime(2012,10, 1),2012,"Genf","Switzerland","Geneve Aeroport","Genf","Switzerland","Cornavin",0,0,0,["Eric"]])

# %%
#2013
data_list.append([datetime.datetime(2013,1, 2),2013,"Schiphol","Netherlands","Schiphol Airport","Amsterdam","Netherlands","Amsterdam Centraal",1,0,0,["Heidrun",'Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2013,1, 3),2013,"Amsterdam","Netherlands","Amsterdam Centraal","Hilversum","Netherlands","",1,1,0,[]])
data_list.append([datetime.datetime(2013,1, 3),2013,"Hilversum","Netherlands","","Apeldoorn","Netherlands","",1,0,1,[]])
data_list.append([datetime.datetime(2013,1, 3),2013,"Apeldoorn","Netherlands","","Amsterdam","Netherlands","Amsterdam Centraal",1,0,0,[]])
data_list.append([datetime.datetime(2013,1, 4),2013,"Amsterdam","Netherlands","Amsterdam Centraal","Den Haag","Netherlands","Den Haag Centraal",1,0,0,["Heidrun",'Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2013,1, 4),2013,"Den Haag","Netherlands","Den Haag Centraal","Amsterdam","Netherlands","Amsterdam Centraal",1,0,0,["Heidrun",'Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2013,1, 5),2013,"Amsterdam","Netherlands","Amsterdam Centraal","Hilversum","Netherlands","",1,1,0,[]])
data_list.append([datetime.datetime(2013,1, 5),2013,"Hilversum","Netherlands","","Baarn","Netherlands","",1,0,1,[]])
data_list.append([datetime.datetime(2013,1, 5),2013,"Baarn","Netherlands","","Hilversum","Netherlands","",1,0,1,[]])
data_list.append([datetime.datetime(2013,1, 5),2013,"Hilversum","Netherlands","","Amsterdam","Netherlands","Amsterdam Centraal",1,0,0,[]])
data_list.append([datetime.datetime(2013,1, 6),2013,"Amsterdam","Netherlands","Amsterdam Centraal","Schiphol","Netherlands","Schiphol Airport",1,0,0,["Heidrun",'Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2013, 3, 22),2013,"Genf",'Switzerland',"Cornavin","Paris","France","Gare de Lyon",1,0,0,["Andrew"]])
data_list.append([datetime.datetime(2013, 3, 22),2013,"Paris",'France',"Gare d'Austerlitz","Versailles","France","Versailles Rive Gauche",0,0,1,["Andrew"]])
data_list.append([datetime.datetime(2013, 3, 22),2013,"Versailles","France","Versailles Rive Gauche","Paris","France","Musee d'Orsay",0,0,0,["Andrew"]])
data_list.append([datetime.datetime(2013, 3, 24),2013,"Paris","France","Gare de Lyon","Avon","France","Fontainebleau-Avon",0,0,0,['Andrew']])
data_list.append([datetime.datetime(2013, 3, 24),2013,"Avon","France","Fontaineblau-Avon","Paris","France","Gare de Lyon",0,0,0,['Andrew']])
data_list.append([datetime.datetime(2013, 3, 25),2013,"Paris","France","Gare du Nord","St Denis","France","St Denis",0,0,1,['Andrew']])
data_list.append([datetime.datetime(2013, 3, 25),2013,"St Denis","France","St Denis","Paris","France","Chatelet-Les Halles",0,1,0,['Andrew']])
data_list.append([datetime.datetime(2013, 3, 25),2013,"Paris","France","Chatelet-Les Halles","Paris","France","Charles de Gaulle-Etoile",0,1,0,['Andrew']])
data_list.append([datetime.datetime(2013, 3, 25),2013,"Paris",'France',"Gare de Lyon","Genf","Switzerland","Cornavin",1,0,0,["Andrew"]])
data_list.append([datetime.datetime(2013, 4, 3),2013,"Genf","Switzerland","Cornavin","Genf","Switzerland","Geneve Aeroport",0,0,0,[]])
data_list.append([datetime.datetime(2013, 4, 3),2013,"Fiumicino","Italy","Fiumicino Aeroporto","Rom","Italy","Roma Termini",0,0,0,["Heidrun"]])
data_list.append([datetime.datetime(2013, 4, 9),2013,"Rom","Italy","Roma Termini","Tivoli","Italy","",0,0,0,["Heidrun"]])
data_list.append([datetime.datetime(2013, 4, 9),2013,"Tivoli","Italy","","Rom","Italy","Roma Termini",0,0,0,["Heidrun"]])
data_list.append([datetime.datetime(2013, 4, 10),2013,"Rom","Italy","Basilica S Paolo","Rom","Italy","Ostia Antica",0,0,0,["Heidrun"]])
data_list.append([datetime.datetime(2013, 4, 10),2013,"Rom","Italy","Ostia Antica","Lido di Ostia","Italy","Lido Centro",0,0,0,["Heidrun"]])
data_list.append([datetime.datetime(2013, 4, 11),2013,"Lido di Ostia","Italy","Lido Centro","Rom","Italy","Basilica S Paolo",0,0,0,["Heidrun"]])
data_list.append([datetime.datetime(2013, 4, 11),2013,"Rom","Italy","Roma Termini","Fiumicino","Italy","Fiumicino Aeroporto",0,0,0,["Heidrun"]])
data_list.append([datetime.datetime(2013, 4, 11),2013,"Genf","Switzerland","Geneve Aeroport","Genf","Switzerland","Cornavin",0,0,0,[]])
data_list.append([datetime.datetime(2013, 4, 14),2013,"Genf","Switzerland","Cornavin","Lausanne","Switzerland","",1,1,0,['Hannsjoerg']])
data_list.append([datetime.datetime(2013, 4, 14),2013,"Lausanne","Switzerland","","Grandvaux","Switzerland","",0,0,1,['Hannsjoerg']])
data_list.append([datetime.datetime(2013, 4, 14),2013,"Grandvaux","Switzerland","","Lausanne","Switzerland","",0,1,0,['Hannsjoerg']])
data_list.append([datetime.datetime(2013, 4, 14),2013,"Lausanne","Switzerland","","Genf","Switzerland","Cornavin",1,0,1,['Hannsjoerg']])
data_list.append([datetime.datetime(2013, 5, 26),2013,"Genf",'Switzerland',"Cornavin","Lyon","France","Lyon Part-Dieu",1,0,0,["Andrew",'Hannsjoerg']])
data_list.append([datetime.datetime(2013, 5, 25),2013,"Lyon",'France',"Lyon Part Part-Dieu","Genf","Switzerland","Cornavin",1,0,0,["Andrew","Hannsjoerg"]])
data_list.append([datetime.datetime(2013, 7, 7),2013,"Genf","Switzerland","Cornavin","Milano","Italy","Milano Centrale",1,0,0,['Andrew','Nick']])
data_list.append([datetime.datetime(2013, 7, 7),2013,"Milano","Italy","Milano Centrale","Genf","Switzerland","Cornavin",1,0,0,['Andrew','Nick']])
data_list.append([datetime.datetime(2013, 7, 14),2013,"Genf","Switzerland","Cornavin","Genf","Switzerland","Geneve Aeroport",0,0,0,[]])
data_list.append([datetime.datetime(2013, 7, 14),2013,"Stockholm-Arlanda","Sweden","Arlanda Central","Stockholm","Sweden","Stockholm Soedra",0,0,0,[]])
data_list.append([datetime.datetime(2013, 7, 16),2013,"Stockholm","Sweden","Stockholm Soedra","Solna","Sweden","Solna",0,1,0,[]])
data_list.append([datetime.datetime(2013, 7, 16),2013,"Solna","Sweden","Solna","Solna","Sweden","Ulriksdal",0,0,1,[]])
data_list.append([datetime.datetime(2013, 7, 16),2013,"Solna","Sweden","Ulriksdal","Stockholm","Sweden","Stockholm Centralstation",0,0,0,[]])
data_list.append([datetime.datetime(2013, 7, 17),2013,"Stockholm","Sweden","Stockholm Soedra","Stockholm","Sweden","Stockholm City",0,0,0,[]])
data_list.append([datetime.datetime(2013, 7, 17),2013,"Stockholm","Sweden","Stockholm Citz","Soedertaelje","Sweden","Soedertealje Syd",0,1,0,[]])
data_list.append([datetime.datetime(2013, 7, 17),2013,"Soedertaelje","Sweden","Soedertealje Syd","Laeggesta","Sweden","",1,0,1,[]])
data_list.append([datetime.datetime(2013, 7, 17),2013,"Laeggesta","Sweden","","Fleminsberg","Sweden","Soedertealje Syd",1,1,0,[]])
data_list.append([datetime.datetime(2013, 7, 17),2013,"Fleminsberg","Sweden","","Stockholmm","Sweden","Stockholm Soedra",0,0,1,[]])
data_list.append([datetime.datetime(2013, 7, 18),2013,"Stockholm","Sweden","Stockholm Soedra","Stockholm","Sweden","Stockholm City",0,0,0,[]])
data_list.append([datetime.datetime(2013, 7, 18),2013,"Stockholm","Sweden","Stockholm City","Stockholm","Sweden","Stockholm Soedra",0,0,0,[]])
data_list.append([datetime.datetime(2013, 7, 20),2013,"Stockholm","Sweden","Stockholm Soedra","Balsta","Sweden","",0,0,0,[]])
data_list.append([datetime.datetime(2013, 7, 20),2013,"Balsta","Sweden","","Stockholm","Sweden","Stockholm City",0,0,0,[]])
data_list.append([datetime.datetime(2013, 7, 21),2013,"Stockholm","Sweden","Stockholm Soedra","Rosersberg","Sweden","",0,0,0,[]])
data_list.append([datetime.datetime(2013, 7, 21),2013,"Rosersberg","Sweden","","Stockholm","Sweden","Stockholm City",0,0,0,[]])
data_list.append([datetime.datetime(2013, 7, 23),2013,"Stockholm","Sweden","Stockholm Soedra","Solna","Sweden","Solna",0,0,0,[]])
data_list.append([datetime.datetime(2013, 7, 23),2013,"Solna","Sweden","Solna","Stockholm","Sweden","Stockholm City",0,0,0,[]])
data_list.append([datetime.datetime(2013, 7, 23),2013,"Stockholm","Sweden","Stockholm Soedra","Stockholm","Sweden","Stockholm City",0,0,0,[]])
data_list.append([datetime.datetime(2013, 7, 23),2013,"Stockholm","Sweden","Stockholm City","Stockholm","Sweden","Stockholm Soedra",0,0,0,[]])
data_list.append([datetime.datetime(2013, 7, 24),2013,"Stockholm","Sweden","Stockholm Soedra","Stockholm-Arlanda","Sweden","Arlanda Central",0,0,0,[]])
data_list.append([datetime.datetime(2013, 7, 24),2013,"Kastrup","Denmark","CPH Lufthavn","Kopenhagen","Denmark","Kobenhavn H",0,0,0,[]])
data_list.append([datetime.datetime(2013, 7, 25),2013,"Kopenhagen","Denmark","Kobenhavn H","Hillerod","Denmark","",0,0,0,[]])
data_list.append([datetime.datetime(2013, 7, 25),2013,"Hillerod","Denmark","","Kopenhagen","Denmark","Kobenhavn H",0,0,0,[]])
data_list.append([datetime.datetime(2013, 7, 26),2013,"Kopenhagen","Denmark","Kobenhavn H","Helsingor","Denmark","",0,0,0,[]])
data_list.append([datetime.datetime(2013, 7, 26),2013,"Helsingor","Denmark","","Fredensborg","Denmark","",0,0,0,[]])
data_list.append([datetime.datetime(2013, 7, 26),2013,"Fredensborg","Denmark","","Hillerod","Denmark","",0,0,0,[]])
data_list.append([datetime.datetime(2013, 7, 26),2013,"Hillerod","Denmark","","Kopenhagen","Denmark","Kobenhavn H",0,0,0,[]])
data_list.append([datetime.datetime(2013, 7, 28),2013,"Kopenhagen","Denmark","Kobenhavn H","Kastrup","Denmark","CPH Lufthavn",0,0,0,[]])
data_list.append([datetime.datetime(2013, 7, 28),2013,"Genf","Switzerland","Geneve Aeroport","Genf","Switzerland","Cornavin",0,0,0,[]])
data_list.append([datetime.datetime(2013, 9, 5),2013,"Genf","Switzerland","Cornavin","Genf","Switzerland","Geneve Aeroport",0,0,0,[]])
data_list.append([datetime.datetime(2013, 9, 8),2013,"Genf","Switzerland","Geneve Aeroport","Genf","Switzerland","Cornavin",0,0,0,[]])
data_list.append([datetime.datetime(2013, 11, 7),2013,"Genf",'Switzerland',"Cornavin","Paris","France","Gare de Lyon",1,0,0,["Chris Clarke",'Chris Lee','Eric']])
data_list.append([datetime.datetime(2013, 11, 8),2013,"Paris",'France',"Gare du Nord","Compiegne","France","",0,0,0,["Chris Clarke",'Chris Lee','Eric']])
data_list.append([datetime.datetime(2013, 11, 8),2013,"Compiegne",'France',"","Chantilly","France","Gare de Chantilly Gouvieux",0,0,0,["Chris Clarke",'Chris Lee','Eric']])
data_list.append([datetime.datetime(2013, 11, 8),2013,"Chantilly",'France',"","Paris","France","Chatelet-Les Halles",0,0,0,["Chris Clarke",'Chris Lee','Eric']])
data_list.append([datetime.datetime(2013, 11, 9),2013,"Paris","France","Chatelet-Les Halles","Rueil-Malmaison",'France',"",0,0,0,['Eric']])
data_list.append([datetime.datetime(2013, 11, 9),2013,"Rueil-Malmaison",'France',"","Puteaux","France","La Defense",0,1,1,['Eric']])
data_list.append([datetime.datetime(2013, 11, 9),2013,"Puteaux","France","La Defense"," Garenne-Colombes",'France',"",0,1,1,['Eric']])
data_list.append([datetime.datetime(2013, 11, 10),2013,"Paris",'France',"Nation","Noisiel","France","Noisiel–Le Luzard",0,0,1,["Chris Clarke",'Chris Lee','Eric']])
data_list.append([datetime.datetime(2013, 11, 10),2013,"Noisiel","France","Noisiel–Le Luzard","Paris",'France',"Gare de Lyon",0,1,0,["Chris Clarke",'Chris Lee','Eric']])
data_list.append([datetime.datetime(2013, 11, 10),2013,"Paris","France","Gare de Lyon","Melun",'France',"",0,1,1,["Chris Clarke",'Chris Lee','Eric']])
data_list.append([datetime.datetime(2013, 11, 10),2013,"Melun",'France',"","Paris","France","Chatelet-Les Halles",0,1,1,["Chris Clarke",'Chris Lee','Eric']])
data_list.append([datetime.datetime(2013, 11, 11),2013,"Paris","France","Gare du Nord","St Denis",'France',"St Denis",0,0,1,["Chris Clarke",'Chris Lee','Eric']])
data_list.append([datetime.datetime(2013, 11, 11),2013,"St Denis",'France',"St Denis","Paris","France","Chatelet-Les Halles",0,1,0,["Chris Clarke",'Chris Lee','Eric']])
data_list.append([datetime.datetime(2013, 11, 11),2013,"Paris",'France',"Chatelet-Les Halles","Paris","France","Auber",0,0,1,["Chris Clarke",'Chris Lee','Eric']])
data_list.append([datetime.datetime(2013, 11, 11),2013,"Paris",'France',"Gare de Lyon","Genf","Switzerland","Cornavin",1,0,0,["Chris Clarke",'Chris Lee','Eric']])
data_list.append([datetime.datetime(2013, 11, 30),2013,"Genf",'Switzerland',"Cornavin","Gland","Switzerland","",1,1,0,['Hannsjoerg']])
data_list.append([datetime.datetime(2013, 11, 30),2013,"Gland","Switzerland","","Genf",'Switzerland',"Cornavin",1,0,1,["Hannsjoerg"]])

# %%
#2014
data_list.append([datetime.datetime(2014, 4, 18),2014,"Genf","Switzerland","Cornavin","Genf","Switzerland","Geneve Aeroport",0,0,0
"Genf","Switzerland","Cornavin","Genf","Switzerland","Geneve Aeroport",0,0,0,[]])
data_list.append([datetime.datetime(2014, 8, 23),2014,"Wien","Austria","Wien Praterstern","Wien","Austria","Wien HBF",0,0,0,[]])
data_list.append([datetime.datetime(2014, 8, 23),2014,"Wien","Austria","Wien HBF","Eisenstadt","Austria","",0,0,0,[]])
data_list.append([datetime.datetime(2014, 8, 23),2014,"Neusiedl am See","Austria","","Fertoszentmiklos","Hungary","",0,1,1,[]])
data_list.append([datetime.datetime(2014, 8, 23),2014,"Fertoszentmiklos","Hungary","","Fertoed","Hungary","Fertoszeplka-Fertoed",0,0,1,[]])
data_list.append([datetime.datetime(2014, 8, 23),2014,"Fertoszentmiklos","Hungary","","Sopron","Hungary","",0,1,0,[]])
data_list.append([datetime.datetime(2014, 8, 23),2014,"Sopron","Hungary","","Wien","Austria","Wien Meidling",0,1,1,[]])
data_list.append([datetime.datetime(2014, 8, 23),2014,"Wien","Austria","Wien Meidling","Wien","Austria","Wien Praterstern",0,1,1,[]])
data_list.append([datetime.datetime(2014, 8, 24),2014,"Wien","Austria","Wien Praterstern","Wien","Austria","Wien Meidling",0,0,0,[]])
data_list.append([datetime.datetime(2014, 8, 24),2014,"Wien","Austria","Wien Meidling","Bratislava","Slovakia","Bratislava HS",0,0,0,[]])
data_list.append([datetime.datetime(2014, 8, 24),2014,"Marchegg","Austria","","Wien","Austria","Stadlau",0,1,1,[]])
data_list.append([datetime.datetime(2014, 8, 24),2014,"Wien","Austria","Stadlau","Wien","Austria","Wien Meidling",0,1,1,[]])
data_list.append([datetime.datetime(2014, 8, 24),2014,"Wien","Austria","Wien Meidling","Wien","Austria","Wien Praterstern",0,1,1,[]])
data_list.append([datetime.datetime(2014, 8, 29),2014,"Wien","Austria","Wien Praterstern","Wien","Austria","Wien Meidling",1,0,0,[]])
data_list.append([datetime.datetime(2014, 8, 29),2014,"Wien","Austria","Wien Meidling","Budapest","Hungary","Budapest-Keleti",1,0,0,[]])
data_list.append([datetime.datetime(2014, 8, 30),2014,"Budapest","Hungary","Budapest-Keleti","Goedoello","Hungary","",0,0,1,[]])
data_list.append([datetime.datetime(2014, 8, 30),2014,"Goedoello","Hungary","","Budapest","Hungary","Budapest-Keleti",0,1,0,[]])
data_list.append([datetime.datetime(2014, 8, 31),2014,"Genf","Switzerland","Geneve Aeroport","Genf","Switzerland","Cornavin",0,0,0,["Hannsjoerg"]])
data_list.append([datetime.datetime(2014, 9, 6),2014,"Genf","Switzerland","Cornavin","Milano","Italy","Milano Centrale",1,1,0,[]])
data_list.append([datetime.datetime(2014, 9, 6),2014,"Milano","Italy","Milano Centrale","Bologna","Italy","Bologna Centrale",1,0,1,[]])
data_list.append([datetime.datetime(2014, 9, 6),2014,"Bologna","Italy","Bologna Centrale","Firenze","Italy","Firenze Santa Maria Novella",1,0,0,[]])
data_list.append([datetime.datetime(2014, 9, 6),2014,"Firenze","Italy","Firenze Santa Maria Novella","Bologna","Italy","Bologna Centrale",1,0,0,[]])
data_list.append([datetime.datetime(2014, 9, 7),2014,"Bologna","Italy","Bologna Centrale","Firenze","Italy","Firenze Santa Maria Novella",1,1,0,[]])
data_list.append([datetime.datetime(2014, 9, 7),2014,"Firenze","Italy","Firenze Santa Maria Novella","Pisa","Italy","Pisa Centrale",0,0,1,[]])
data_list.append([datetime.datetime(2014, 9, 7),2014,"Pisa","Italy","Pisa Centrale","Empoli","Italy","",0,1,0,[]])
data_list.append([datetime.datetime(2014, 9, 7),2014,"Empoli","Italy","","Firenze","Italy","Firenze Santa Maria Novella",0,0,1,[]])
data_list.append([datetime.datetime(2014, 9, 7),2014,"Firenze","Italy","Firenze Santa Maria Novella","Bologna","Italy","Bologna Centrale",1,0,0,[]])
data_list.append([datetime.datetime(2014, 9, 12),2014,"Bologna","Italy","Bologna Centrale","Firenze","Italy","Firenze Santa Maria Novella",1,0,0,[]])
data_list.append([datetime.datetime(2014, 9, 13),2014,"Firenze","Italy","Firenze Santa Maria Novella","Siena","Italy","",0,0,0,[]])
data_list.append([datetime.datetime(2014, 9, 13),2014,"Siena","Italy","","Firenze","Italy","Firenze Santa Maria Novella",0,0,0,[]])
data_list.append([datetime.datetime(2014, 9, 14),2014,"Firenze","Italy","Firenze Santa Maria Novella","Milano","Italy","Milano Centrale",1,1,0,[]])
data_list.append([datetime.datetime(2014, 9, 14),2014,"Milano","Italy","Milano Centrale","Genf","Switzerland","Cornavin",1,0,1,[]])
data_list.append([datetime.datetime(2014, 9, 19),2014,"Genf",'Switzerland',"Cornavin","Paris","France","Gare de Lyon",1,0,0,[]])
data_list.append([datetime.datetime(2014, 9, 19),2014,"Paris",'France',"Gare de Lyon","Paris","France","Chatelet-Les Halles",0,0,0,[]])
data_list.append([datetime.datetime(2014, 9, 21),2014,"Paris","France","Chatelet-Les Halles","Paris",'France',"Gare de Lyon",0,0,0,[]])
data_list.append([datetime.datetime(2014, 9, 21),2014,"Paris","France","Gare de Lyon","Genf",'Switzerland',"Cornavin",1,0,0,[]])
data_list.append([datetime.datetime(2014, 12, 13),2014,"Gatwick","United Kingdom","Gatwick Airport","London","United Kingdom","St Pancras International",0,0,0,["Manuel"]])
data_list.append([datetime.datetime(2014, 12, 13),2014,"London","United Kingdom","Wimbledon","London","United Kingdom","Hampton Court",0,0,1,["Manuel"]])
data_list.append([datetime.datetime(2014, 12, 13),2014,"London","United Kingdom","Hampton Cout","London","United Kingdom","Waterloo Station",0,0,1,["Manuel"]])
data_list.append([datetime.datetime(2014, 12, 14),2014,"London","United Kingdom","Vauxhall","Windsor","United Kingdom","Windsor & Eton Riverside",0,0,1,["Manuel"]])
data_list.append([datetime.datetime(2014, 12, 14),2014,"Windsor","United Kingdom","Windsor & Eton Riverside","London","United Kingdom","Vauxhall",0,1,0,["Manuel"]])
data_list.append([datetime.datetime(2014, 12, 14),2014,"London","United Kingdom","St Pancras International","Gatwick","United Kingdom","Gatwick Airport",0,0,0,["Manuel"]])
data_list.append([datetime.datetime(2014, 12, 14),2014,"Genf","Switzerland","Geneve Aeroport","Genf","Switzerland","Cornavin",0,0,0,[]])

# %%
#2015
data_list.append([datetime.datetime(2015, 1, 11),2015,"Genf","Switzerland","Cornavin","Montreux","Switzerland","",1,0,0,['Eric','Siyi']])
data_list.append([datetime.datetime(2015, 1, 11),2015,"Montreux","Switzerland","","Genf","Switzerland","Cornavin",1,0,0,["Eric",'Siyi']])
data_list.append([datetime.datetime(2015, 3, 14),2015,"Genf","Switzerland","Cornavin","Milano","Italy","Milano Centrale",1,0,0,['Aaron']])
data_list.append([datetime.datetime(2015, 3, 14),2015,"Milano","Italy","Milano Centrale","Monza","Italy","",0,0,0,['Aaron','Can','Christine','Kennedy','Devin','Nate','Laser']])
data_list.append([datetime.datetime(2015, 3, 14),2015,"Monza","Italy","","Milano","Italy","Milano Centrale",0,0,0,['Aaron','Can','Christine','Kennedy','Devin','Nate','Laser']])
data_list.append([datetime.datetime(2015, 3, 15),2015,"Milano","Italy","Milano Centrale","Genf","Switzerland","Cornavin",1,0,0,['Aaron','Can','Christine','Kennedy','Devin','Nate']])
data_list.append([datetime.datetime(2015, 3, 27),2015,"Madrid","Spain","Aeropuerto Madrid-Barajas T4","Madrid","Spain","Chamartin",0,1,0,[]])
data_list.append([datetime.datetime(2015, 3, 27),2015,"Madrid","Spain","Chamartin","Madrid","Spain","Madrid-Puerta de Atocha",0,0,1,[]])
data_list.append([datetime.datetime(2015, 3, 28),2015,"Madrid","Spain","Madrid-Puerta de Atocha","Cordoba","Spain","",1,0,0,['Manuel']])
data_list.append([datetime.datetime(2015, 3, 29),2015,"Cordoba","Spain","","Sevilla","Spain","Sevilla Santa Justa",1,0,0,['Manuel']])
data_list.append([datetime.datetime(2015, 3, 29),2015,"Sevilla","Spain","Sevilla Santa Justa","Cordoba","Spain","",1,0,0,['Manuel']])
data_list.append([datetime.datetime(2015, 3, 31),2015,"Cordoba","Spain","","Madrid","Spain","Madrid-Puerta de Atocha",1,0,0,['Manuel']])
data_list.append([datetime.datetime(2015, 4, 1),2015,"Madrid","Spain","Sol","Madrid","Spain","Chamartin",0,2,0,['Manuel']])
data_list.append([datetime.datetime(2015, 4, 1),2015,"Madrid","Spain","Chamartin","Segovia","Spain","Segovia AVE",1,0,1,['Manuel']])
data_list.append([datetime.datetime(2015, 4, 1),2015,"Segovia","Spain","Segovia AVE","Madrid","Spain","Chamartin",1,0,1,['Manuel']])
data_list.append([datetime.datetime(2015, 4, 1),2015,"Madrid","Spain","Chamartin","Madrid","Spain","Sol",0,1,0,['Manuel']])
data_list.append([datetime.datetime(2015, 4, 2),2015,"Madrid","Spain","Madrid-Puerta de Atocha","Toledo","Spain","",1,0,0,['Manuel']])
data_list.append([datetime.datetime(2015, 4, 2),2015,"Toledo","Spain","","Madrid","Spain","Madrid-Puerta de Atocha",1,0,0,['Manuel']])
data_list.append([datetime.datetime(2015, 4, 3),2015,"Madrid","Spain","Sol","Madrid","Spain","Chamartin",0,1,0,['Manuel']])
data_list.append([datetime.datetime(2015, 4, 3),2015,"Madrid","Spain","Chamartin","El Escorial","Spain","",0,0,1,['Manuel']])
data_list.append([datetime.datetime(2015, 4, 3),2015,"El Escorial","Spain","","Madrid","Spain","Chamartin",0,1,0,['Manuel']])
data_list.append([datetime.datetime(2015, 4, 3),2015,"Madrid","Spain","Chamartin","Madrid","Spain","Madrid-Puerta de Atocha",0,0,1,['Manuel']])
data_list.append([datetime.datetime(2015, 4, 4),2015,"Madrid","Spain","Madrid-Puerta de Atocha","Cordoba","Spain","",1,0,0,[]])
data_list.append([datetime.datetime(2015, 4, 4),2015,"Cordoba","Spain","","Sevilla","Spain","Sevilla Santa Justa",1,0,0,[]])
data_list.append([datetime.datetime(2015, 4, 4),2015,"Sevilla","Spain","Sevilla Santa Justa","Madrid","Spain","Madrid-Puerta de Atocha",1,0,0,[]])
data_list.append([datetime.datetime(2015, 4, 5),2015,"Madrid","Spain","Madrid-Puerta de Atocha","Aranjuez","Spain","",0,0,0,['Eric']])
data_list.append([datetime.datetime(2015, 4, 5),2015,"Aranjuez","Spain","","Madrid","Spain","Madrid-Puerta de Atocha",0,0,0,['Eric']])
data_list.append([datetime.datetime(2015, 4, 6),2015,"Madrid","Spain","Madrid-Puerta de Atocha","Madrid","Spain","Chamartin",0,1,0,['Eric']])
data_list.append([datetime.datetime(2015, 4, 6),2015,"Madrid","Spain","Chamartin","Madrid","Spain","Aeropuerto Madrid-Barajas T4",0,0,1,[]])
data_list.append([datetime.datetime(2015, 4, 5),2015,"Genf","Switzerland","Geneve Aeroport","Genf","Switzerland","Cornavin",0,0,0,[]])
data_list.append([datetime.datetime(2015, 5, 14),2015,"Genf","Switzerland","Cornavin","Genf","Switzerland","Geneve Aeroport",0,0,0,[]])
data_list.append([datetime.datetime(2015, 5, 15),2015,"Napoli","Italy","Piazza Garibaldi","Pompei","Italy","Pompei Scavi-Villa Dei Misteri",0,0,0,['AJ','Stephan']])
data_list.append([datetime.datetime(2015, 5, 15),2015,"Pompei","Italy","Pompei Scavi-Villa Dei Misteri","Torre Annunziata","Italy","Stazione Villa Regina",0,0,0,['AJ','Stephan']])
data_list.append([datetime.datetime(2015, 5, 15),2015,"Torre Annunziata","Italy","Torre Annunziata Citta","Napoli","Italy","Napoli Centrale",0,0,0,['AJ','Stephan']])
data_list.append([datetime.datetime(2015, 5, 16),2015,"Napoli","Italy","Piazza Garibaldi","Pozzuoli","Italy","Pozzuoli Solfatara",0,0,0,['AJ','Stephan']])
data_list.append([datetime.datetime(2015, 5, 16),2015,"Pozzuoli","Italy","Pozzuoli Solfatara","Napoli","Italy","Piazza Garibaldi",0,1,0,['AJ','Stephan']])
data_list.append([datetime.datetime(2015, 5, 16),2015,"Napoli","Italy","Piazza Garibaldi","Portici","Italy","Portici Via Liberta",0,0,1,['AJ','Stephan']])
data_list.append([datetime.datetime(2015, 5, 16),2015,"Portici","Italy","Portici Via Liberta","Castellammare di Stabia","Italy","",0,0,0,['AJ','Stephan']])
data_list.append([datetime.datetime(2015, 5, 16),2015,"Castellammare di Stabia","Italy","","Napoli","Italy","Piazza Garibaldi",0,0,0,['AJ','Stephan']])
data_list.append([datetime.datetime(2015, 5, 17),2015,"Napoli","Italy","Napoli Centrale","Caserta","Italy","",1,0,0,['AJ','Stephan']])
data_list.append([datetime.datetime(2015, 5, 17),2015,"Caserta","Italy","","Napoli","Italy","Napoli Centrale",1,0,0,['AJ','Stephan']])
data_list.append([datetime.datetime(2015, 5, 17),2015,"Genf","Switzerland","Geneve Aeroport","Genf","Switzerland","Cornavin",0,0,0,["AJ",'Stephan']])
data_list.append([datetime.datetime(2015, 6, 5),2015,"Genf","Switzerland","Cornavin","Zuerich","Switzerland","Zuerich HB",1,0,0,[]])
data_list.append([datetime.datetime(2015, 6, 5),2015,"Koblenz","Switzerland","","Baden","Switzerland","",0,1,0,[]])
data_list.append([datetime.datetime(2015, 6, 5),2015,"Baden","Switzerland","","Zuerich","Switzerland","Zuerich HB",0,1,1,[]])
data_list.append([datetime.datetime(2015, 6, 5),2015,"Zuerich","Switzerland","Zuerich HB","Baden","Switzerland","",0,1,0,[]])
data_list.append([datetime.datetime(2015, 6, 5),2015,"Baden","Switzerland","","Koblenz","Switzerland","",0,1,1,[]])
data_list.append([datetime.datetime(2015, 6, 6),2015,"Koblenz","Switzerland","","Turgi","Switzerland","",0,1,0,[]])
data_list.append([datetime.datetime(2015, 6, 6),2015,"Turgi","Switzerland","","Aargau","Switzerland","",0,1,1,[]])
data_list.append([datetime.datetime(2015, 6, 6),2015,"Aargau","Switzerland","","Genf","Switzerland","Cornavin",1,0,1,[]])
data_list.append([datetime.datetime(2015, 6, 13),2015,"Genf","Switzerland","Cornavin","Genf","Switzerland","Geneve Aeroport",0,0,0,[]])
data_list.append([datetime.datetime(2015, 6, 21),2015,"Genf","Switzerland","Geneve Aeroport","Genf","Switzerland","Cornavin",0,0,0,[]])
data_list.append([datetime.datetime(2015, 7, 7),2015,"Genf",'Switzerland',"Cornavin","Bellegarde-sur-Valserine","France","Bellegarde",0,0,0,["Nathan","Andreas"]])
data_list.append([datetime.datetime(2015, 7, 7),2015,"Bellegarde-sur-Valserine","France","Bellegarde","Genf",'Switzerland',"Cornavin",0,0,0,["Nathan"]])
data_list.append([datetime.datetime(2015, 7, 8),2015,"Genf",'Switzerland',"Cornavin","Bellegarde-sur-Valserine","France","Bellegarde",0,0,0,["Nathan","Andreas"]])
data_list.append([datetime.datetime(2015, 7, 8),2015,"Bellegarde-sur-Valserine","France","Bellegarde","Lyon",'France',"Lyon Part Dieu",0,0,0,["Nathan"]])
data_list.append([datetime.datetime(2015, 7, 10),2015,"Lyon","France","Lyon Part Dieu","Genf",'Switzerland',"Cornavin",0,0,0,["Nathan"]])
data_list.append([datetime.datetime(2015, 7, 17),2015,"Genf",'Switzerland',"Cornavin","Paris","France","Gare de Lyon",1,0,0,[]])
data_list.append([datetime.datetime(2015, 7, 18),2015,"Paris",'France',"Gare de Lyon","Paris","France","Chatelet-Les Halles",0,0,0,[]])
data_list.append([datetime.datetime(2015, 7, 18),2015,"Paris","France",'Pont du Garigliano',"Versailles","France","Versailles Chateau Rive Gauche",0,0,1,[]])
data_list.append([datetime.datetime(2015, 7, 18),2015,"Versailles","France","Versailles Chateau Rive Gauche","Paris","France",'Pont du Garigliano',0,0,1,[]])
data_list.append([datetime.datetime(2015, 7, 19),2015,"Paris","France","Gare Montparnasse","Dol de Bretagne","France","",1,1,0,[]])
data_list.append([datetime.datetime(2015, 7, 19),2015,"Dol de Bretagne","France","","Paris","France",'Gare Montparnasse',1,0,1,[]])
data_list.append([datetime.datetime(2015, 7, 20),2015,"Paris","France","Gare de Lyon","Genf",'Switzerland',"Cornavin",1,0,0,[]])
data_list.append([datetime.datetime(2015, 7, 26),2015,"Genf","Switzerland","Cornavin","Brig","Switzerland","",1,1,0,['Eric']])
data_list.append([datetime.datetime(2015, 7, 26),2015,"Brig","Switzerland","","Zermatt","Switzerland","Cornavin",0,0,1,['Eric']])
data_list.append([datetime.datetime(2015, 7, 26),2015,"Zermatt","Switzerland","Cornavin","Visp","Switzerland","",0,1,0,["Eric"]])
data_list.append([datetime.datetime(2015, 7, 26),2015,"Visp","Switzerland","","Lausanne","Switzerland","Cornavin",1,1,1,['Eric']])
data_list.append([datetime.datetime(2015, 7, 26),2015,"Lausanne","Switzerland","","Genf","Switzerland","Cornavin",0,0,1,["Eric"]])
data_list.append([datetime.datetime(2015, 8, 21),2015,"Nice",'France',"Nice Saint-Augustin","Monaco","Monaco","Monaco-Monte-Carlo",0,0,0,[]])
data_list.append([datetime.datetime(2015, 8,
data_list.append([datetime.datetime(2015, 11, 13),2015,"Berlin","Germany","Berlin HBF","Berlin","Germany","Berlin-Ostbahnhof",0,0,1,[]])
data_list.append([datetime.datetime(2015, 11, 14),2015,"Berlin","Germany","Berlin-Ostbahnhof","Berlin","Germany","Berlin HBF",0,1,0,[]])
data_list.append([datetime.datetime(2015, 11, 14),2015,"Berlin","Germany","Berlin HBF","Jena","Germany","Jena Paradies",1,1,1,[]])
data_list.append([datetime.datetime(2015, 11, 14),2015,"Jena","Germany","Jena Paradies","Rudolstadt","Germany","",0,0,1,[]])
data_list.append([datetime.datetime(2015, 11, 14),2015,"Rudolstadt","Germany","","Bad Koesen","Germany","",0,1,0,[]])
data_list.append([datetime.datetime(2015, 11, 14),2015,"Bad Koesen","Germany","","Gotha","Germany","",0,0,1,[]])
data_list.append([datetime.datetime(2015, 11, 14),2015,"Gotha","Germany","","Erfurt","Germany","Erfurt HBF",0,1,0,[]])
data_list.append([datetime.datetime(2015, 11, 14),2015,"Erfurt","Germany","","Berlin","Germany","Berlin HBF",1,1,1,[]])
data_list.append([datetime.datetime(2015, 11, 14),2015,"Berlin","Germany","Berlin HBF","Berlin","Germany","Berlin-Ostbahnhof",0,0,1,[]])
data_list.append([datetime.datetime(2015, 11, 15),2015,"Berlin","Germany","Berlin-Ostbahnhof","Berlin","Germany","Berlin-Charlottenburg",0,0,0,['Artur','Heidrun']])
data_list.append([datetime.datetime(2015, 11, 15),2015,"Berlin","Germany","Berlin-Charlottenburg","Berlin","Germany","Berlin-Ostbahnhof",0,0,0,['Artur','Heidrun']])
data_list.append([datetime.datetime(2015, 11, 15),2015,"Berlin","Germany","Berlin-Ostbahnhof","Schoenefeld","Germany","Berlin-Schoenefeld",0,0,0,['Artur','Heidrun']])
data_list.append([datetime.datetime(2015, 11, 15),2015,"Genf","Switzerland","Geneve Aeroport","Genf","Switzerland","Cornavin",0,0,0,[]])
data_list.append([datetime.datetime(2015, 12, 18),2015,"Genf","Switzerland","Cornavin","Aargau","Switzerland","",1,1,0,[]])
data_list.append([datetime.datetime(2015, 12, 18),2015,"Aargau","Switzerland","","Turgi","Switzerland","",0,1,1,[]])
data_list.append([datetime.datetime(2015, 12, 18),2015,"Turgi","Switzerland","","Koblenz","Switzerland","",0,1,0,[]])

# %%
#2016
data_list.append([datetime.datetime(2016, 1, 4),2016,"Koblenz","Switzerland","","Turgi","Switzerland","",0,1,1,[]])
data_list.append([datetime.datetime(2016, 1, 4),2016,"Turgi","Switzerland","","Aargau","Switzerland","",0,1,1,[]])
data_list.append([datetime.datetime(2016, 1, 4),2016,"Aargau","Switzerland","","Genf","Switzerland","Cornavin",1,0,1,[]])
data_list.append([datetime.datetime(2016, 2, 6),2016,"Genf","Switzerland","Cornavin","Zuerich","Switzerland","Zuerich HB",1,0,0,[]])
data_list.append([datetime.datetime(2016, 2, 6),2016,"Zuerich","Switzerland","Zuerich HB","Genf","Switzerland","Cornavin",1,0,0,[]])
data_list.append([datetime.datetime(2016, 3, 16),2016,"Genf","Switzerland","Cornavin","Genf","Switzerland","Geneve Aeroport",0,0,0,[]])
data_list.append([datetime.datetime(2016, 3, 26),2016,"Genf","Switzerland","Cornavin","Genf","Switzerland","Geneve Aeroport",0,0,0,[]])
data_list.append([datetime.datetime(2016, 3, 28),2016,"Barcelona","Spain","Barcelona-Sants","Zaragoza","Spain","Zaragoza-Delicias",1,0,1,['Riju']])
data_list.append([datetime.datetime(2016, 3, 28),2016,"Zaragoza","Spain","Zaragoza-Delicias","Barcelona","Spain","Barcelona-Sants",1,1,0,['Riju']])
data_list.append([datetime.datetime(2016, 3, 29),2016,"Genf","Switzerland","Geneve Aeroport","Genf","Switzerland","Cornavin",0,0,0,[]])
data_list.append([datetime.datetime(2016, 4, 10),2016,"Genf","Switzerland","Cornavin","Lausanne","Switzerland","",1,0,0,[]])
data_list.append([datetime.datetime(2016, 4, 10),2016,"Lausanne","Switzerland","","Palezieux","Switzerland","",0,0,0,[]])
data_list.append([datetime.datetime(2016, 4, 10),2016,"Palezieux","Switzerland","","Bulle","Switzerland","",0,0,0,[]])
data_list.append([datetime.datetime(2016, 4, 10),2016,"Bulle","Switzerland","","Gruyeres","Switzerland","",0,0,0,[]])
data_list.append([datetime.datetime(2016, 4, 10),2016,"Gruyeres","Switzerland","","Bulle","Switzerland","",0,0,0,[]])
data_list.append([datetime.datetime(2016, 4, 10),2016,"Bulle","Switzerland","","Palezieux","Switzerland","",0,0,0,[]])
data_list.append([datetime.datetime(2016, 4, 10),2016,"Palezieux","Switzerland","","Lausanne","Switzerland","",0,0,0,[]])
data_list.append([datetime.datetime(2016, 4, 10),2016,"Lausanne","Switzerland","","Genf","Switzerland","Cornavin",1,0,0,[]])
data_list.append([datetime.datetime(2016, 4, 22),2016,"Genf","Switzerland","Cornavin","Aargau","Switzerland","",1,1,0,['Hannsjoerg']])
data_list.append([datetime.datetime(2016, 4, 22),2016,"Aargau","Switzerland","","Turgi","Switzerland","",0,1,1,['Hannsjoerg']])
data_list.append([datetime.datetime(2016, 4, 22),2016,"Turgi","Switzerland","","Koblenz","Switzerland","",0,1,1,['Hannsjoerg']])
data_list.append([datetime.datetime(2016, 4, 24),2016,"Koblenz","Switzerland","","Turgi","Switzerland","",0,1,1,['Hannsjoerg']])
data_list.append([datetime.datetime(2016, 4, 24),2016,"Turgi","Switzerland","","Aargau","Switzerland","",0,1,1,['Hannsjoerg']])
data_list.append([datetime.datetime(2016, 4, 24),2016,"Aargau","Switzerland","","Genf","Switzerland","Cornavin",1,0,1,['Hannsjoerg']])
data_list.append([datetime.datetime(2016, 5, 4),2016,"Genf","Switzerland","Cornavin","Milano","Italy","Milano Centrale",1,1,0,[]])
data_list.append([datetime.datetime(2016, 5, 4),2016,"Milano","Italy","Milano Centrale","Torino","Italy","Torino Porta Nuova",0,0,1,[]])
data_list.append([datetime.datetime(2016, 5, 6),2016,"Torino","Italy","Torino Porta Nuova","Torino","Italy","Torino Porta Susa",0,1,0,[]])
data_list.append([datetime.datetime(2016, 5, 6),2016,"Torino","Italy","Torino Porta Susa","Racconigi","Italy","",0,0,1,[]])
data_list.append([datetime.datetime(2016, 5, 6),2016,"Racconigi","Italy","","Torino Stura","Italy","",0,1,0,[]])
data_list.append([datetime.datetime(2016, 5, 6),2016,"Torino","Italy","Torino Stura","Rivarolo Canavese","Italy","",0,1,1,[]])
data_list.append([datetime.datetime(2016, 5, 6),2016,"Rivarolo Canavese","Italy","","Torino","Italy","Torino Porta Susa",0,1,1,[]])
data_list.append([datetime.datetime(2016, 5, 6),2016,"Torino","Italy","Torino Porta Susa","Torino","Italy","Toriono Porta Nuova",0,0,1,[]])
data_list.append([datetime.datetime(2016, 5, 8),2016,"Torino","Italy","Torino Porta Nuova","Milano","Italy","Milano Centrale",0,1,0,[]])
data_list.append([datetime.datetime(2016, 5, 8),2016,"Milano","Italy","Milano Centrale","Genf","Switzerland","Cornavin",1,0,1,[]])
data_list.append([datetime.datetime(2016, 5, 16),2016,"Genova","Italy","Genova Piazza Pricipe","La Spezia Centrale","Italy","",1,1,0,['Amin']])
data_list.append([datetime.datetime(2016, 5, 16),2016,"La Spezia Centrale","Italy","","Riomaggiore","Italy","",0,0,1,['Amin']])
data_list.append([datetime.datetime(2016, 5, 16),2016,"Riomaggiore","Italy","","Manarola","Italy","",0,0,1,['Amin']])
data_list.append([datetime.datetime(2016, 5, 16),2016,"Manarola","Italy","","Corniglia","Italy","",0,0,1,['Amin']])
data_list.append([datetime.datetime(2016, 5, 16),2016,"Corniglia","Italy","","Monterosso","Italy","",0,0,1,['Amin']])
data_list.append([datetime.datetime(2016, 5, 16),2016,"Riomaggiore","Italy","","La Spezia Centrale","Italy","",0,1,0,['Amin']])
data_list.append([datetime.datetime(2016, 5, 16),2016,"La Spezia Centrale","Italy","","Genova","Italy","Genova Piazza Pricipe",1,0,1,['Amin']])
data_list.append([datetime.datetime(2016, 6, 24),2016,"Genf","Switzerland","Cornavin","Milano","Italy","Milano Centrale",1,0,0,[]])
data_list.append([datetime.datetime(2016, 6, 25),2016,"Milano","Italy","Milano Centrale","Bologna","Italy","Bologna Centrale",1,1,0,['Keyvan']])
data_list.append([datetime.datetime(2016, 6, 25),2016,"Bologna","Italy","Bologna Centrale","Faenza","Italy","",0,1,1,['Keyvan']])
data_list.append([datetime.datetime(2016, 6, 26),2016,"Ravenna","Italy","","Bologna","Italy","Bologna Centrale",0,1,0,['Keyvan']])
data_list.append([datetime.datetime(2016, 6, 25),2016,"Bologna","Italy","Bologna Centrale","Padova","Italy","",0,0,1,[]])
data_list.append([datetime.datetime(2016, 6, 25),2016,"Padova","Italy","","Genf","Switzerland","Cornavin",1,0,0,[]])
data_list.append([datetime.datetime(
0,0,[]])
data_list.append([datetime.datetime(2016, 10, 15),2016,"Duesseldorf","Germany","Duesseldorf-Benrath","Koeln","Germany","Koeln HBF",0,1,0,[]])
data_list.append([datetime.datetime(2016, 10, 15),2016,"Koeln","Germany","Koeln HBF","Koblenz","Germany","Koblenz HBF",1,1,1,[]])
data_list.append([datetime.datetime(2016, 10, 15),2016,"Koblenz","Germany","Koblenz HBF","Limburg an der Lahn","Germany","Limburg (Lahn)",0,0,1,[]])
data_list.append([datetime.datetime(2016, 10, 15),2016,"Limburg an der Lahn","Germany","Limburg (Lahn)","Koblenz","Germany","Koblenz HBF",0,1,0,[]])
data_list.append([datetime.datetime(2016, 10, 15),2016,"Koblenz","Germany","Koblenz HBF","Koeln","Germany","Koeln HBF",1,0,1,[]])
data_list.append([datetime.datetime(2016, 10, 16),2016,"Koeln","Germany","Koeln HBF","Bruehl","Germany","",0,0,0,[]])
data_list.append([datetime.datetime(2016, 10, 16),2016,"Bruehl","Germany","","Bonn","Germany","Bonn HBF",0,0,0,[]])
data_list.append([datetime.datetime(2016, 10, 16),2016,"Bonn","Germany","Bonn HBF","Koeln","Germany","Koeln HBF",0,0,0,[]])
data_list.append([datetime.datetime(2016, 10, 16),2016,"Koeln","Germany","Koeln HBF","Duesseldorf","Germany","Koeln HBF",0,1,0,[]])
data_list.append([datetime.datetime(2016, 10, 16),2016,"Duesseldorf","Germany","Duesseldorf HBF","Duesseldorf","Germany","Duesseldorf Flughafen Terminal",0,0,1,[]])
data_list.append([datetime.datetime(2016, 10, 21),2016,"Genf","Switzerland","Cornavin","Aargau","Switzerland","",1,1,0,[]])
data_list.append([datetime.datetime(2016, 10, 21),2016,"Aargau","Switzerland","","Turgi","Switzerland","",0,1,1,[]])
data_list.append([datetime.datetime(2016, 10, 21),2016,"Turgi","Switzerland","","Koblenz","Switzerland","",0,0,1,[]])
data_list.append([datetime.datetime(2016, 10, 23),2016,"Koblenz","Switzerland","","Turgi","Switzerland","",0,1,0,[]])
data_list.append([datetime.datetime(2016, 10, 23),2016,"Turgi","Switzerland","","Aargau","Switzerland","",0,1,1,[]])
data_list.append([datetime.datetime(2016, 10, 23),2016,"Aargau","Switzerland","","Genf","Switzerland","Cornavin",1,0,1,[]])
data_list.append([datetime.datetime(2016, 11, 25),2016,"Genf","Switzerland","Cornavin","Milano","Italy","Milano Centrale",1,0,0,['Riju']])
data_list.append([datetime.datetime(2016, 11, 26),2016,"Milano","Italy","Milano Centrale","Mantova","Italy","",0,0,0,['Riju']])
data_list.append([datetime.datetime(2016, 11, 27),2016,"Mantova","Italy","","Verona","Italy","Porta Nuova",0,0,0,['Riju']])
data_list.append([datetime.datetime(2016, 11, 27),2016,"Verona","Italy","Porta Nuova","Genf","Switzerland","Cornavin",1,0,0,['Riju']])
data_list.append([datetime.datetime(2016, 12, 2),2016,"Genf","Switzerland","Cornavin","Aargau","Switzerland","",0,1,0,['Hannsjoerg']])
data_list.append([datetime.datetime(2016, 12, 2),2016,"Aargau","Switzerland","","Turgi","Switzerland","",0,1,1,['Hannsjoerg']])
data_list.append([datetime.datetime(2016, 12, 2),2016,"Turgi","Switzerland","","Koblenz","Switzerland","",0,1,1,['Hannsjoerg']])
data_list.append([datetime.datetime(2016, 12, 4),2016,"Tokyo","Japan","Haneda Airport Terminal 1&2","Tokyo","Japan","Shimbashih",0,1,0,[]])
data_list.append([datetime.datetime(2016, 12, 4),2016,"Tokyo","Japan","Shimbashi","Tokyo","Japan","Takaracho",0,0,1,[]])
data_list.append([datetime.datetime(2016, 12, 5),2016,"Tokyo","Japan","","Morioka","Japan","",1,0,0,[]])
data_list.append([datetime.datetime(2016, 12, 8),2016,"Morioka","Japan","","Hiraizumi","Japan","",0,0,0,[]])
data_list.append([datetime.datetime(2016, 12, 8),2016,"Hiraizumi","Japan","","Morioka","Japan","",0,0,0,[]])
data_list.append([datetime.datetime(2016, 12, 9),2016,"Morioka","Japan","","Tokyo","Japan","Tokyo",0,0,0,[]])
data_list.append([datetime.datetime(2016, 12, 9),2016,"Tokyo","Japan","Takaracho","Tokyo","Japan","Honjo-Azumabashi",0,0,0,[]])
data_list.append([datetime.datetime(2016, 12, 9),2016,"Tokyo","Japan","Asakusa","Tokyo","Japan","Daimon",0,0,0,[]])
data_list.append([datetime.datetime(2016, 12, 9),2016,"Tokyo","Japan","Shimbashi","Tokyo","Japan","Takaracho",0,0,1,[]])
data_list.append([datetime.datetime(2016, 12, 10),2016,"Tokyo","Japan","","Utsunomiya","Japan","Tokyo",1,1,0,[]])
data_list.append([datetime.datetime(2016, 12, 10),2016,"Utsunomiya","Japan","Tokyo","Nikko","Japan","Nikko Shiyakusho",0,0,1,[]])
data_list.append([datetime.datetime(2016, 12, 10),2016,"Nikko","Japan","Nikko Shiyakusho","Utsunomiya","Japan","",0,1,0,[]])
data_list.append([datetime.datetime(2016, 12, 10),2016,"Utsunomiya","Japan","","Tokyo","Japan","Tokyo",1,0,1,[]])
data_list.append([datetime.datetime(2016, 12, 11),2016,"Tokyo","Japan","Tokyo","Kyoto","Japan","Kyoto",1,0,0,[]])
data_list.append([datetime.datetime(2016, 12,
"Genf","Switzerland","Geneve Aeroport","Genf","Switzerland","Cornavin",0,0,0,[]])
data_list.append([datetime.datetime(2017, 4, 28),2017,"Frankfurt am Main","Germany","Frankfurt Flughafen","Frankfurt am Main","Germany","Frankfurt (Main) HBF",0,0,0,[]])
data_list.append([datetime.datetime(2017, 4, 29),2017,"Frankfurt am Main","Germany","Frankfurt (Main) HBF","Aschaffenburg","Germany","",0,0,0,[]])
data_list.append([datetime.datetime(2017, 4, 29),2017,"Aschaffenburg","Germany","","Frankfurt am Main","Germany","Frankfurt (Main) HBF",1,1,0,[]])
data_list.append([datetime.datetime(2017, 4, 29),2017,"Frankfurt am Main","Germany","Frankfurt (Main) HBF","Wiesbaden","Germany","Wiesbaden HBF",0,0,1,[]])
data_list.append([datetime.datetime(2017, 4, 29),2017,"Wiesbaden","Germany","Wiesbaden HBF","Frankfurt am Main","Germany","Frankfurt (Main) Hauptwache",0,0,0,[]])
data_list.append([datetime.datetime(2017, 4, 30),2017,"Frankfurt am Main","Germany","Frankfurt (Main) HBF","Karlsruhe","Germany","Karlsruhe HBF",1,1,0,[]])
data_list.append([datetime.datetime(2017, 4, 30),2017,"Karlsruhe","Germany","Karlsruhe HBF","Bruchsal","Germany","",0,0,1,[]])
data_list.append([datetime.datetime(2017, 4, 30),2017,"Bruchsal","Germany","","Mannheim","Germany","Mannheim HBF",0,0,0,[]])
data_list.append([datetime.datetime(2017, 4, 30),2017,"Mannheim","Germany","Mannheim HBF","Speyer","Germany","Speyer HBF",0,0,0,[]])
data_list.append([datetime.datetime(2017, 4, 30),2017,"Speyer","Germany","Speyer HBF","Mainz","Germany","Mainz HBF",0,0,0,[]])
data_list.append([datetime.datetime(2017, 4, 30),2017,"Mainz","Germany","Mainz HBF","Frankfurt am Main","Germany","Frankfurt (Main) HBF",0,0,0,[]])
data_list.append([datetime.datetime(2017, 5, 1),2017,"Frankfurt am Main","Germany","Frankfurt (Main) HBF","Wuerzburg","Germany","Wuerzburg HBF",1,1,0,[]])
data_list.append([datetime.datetime(2017, 5, 1),2017,"Wuerzburg","Germany","Wuerzburg HBF","Kassel","Germany","Kassel-Wilhelmshoehe",1,0,1,[]])
data_list.append([datetime.datetime(2017, 5, 1),2017,"Kassel","Germany","Kassel-Wilhelmshoehe","Frankfurt am Main","Germany","Frankfurt (Main) HBF",1,0,0,[]])
data_list.append([datetime.datetime(2017, 5, 2),2017,"Frankfurt am Main","Germany","Frankfurt (Main) HBF","Frankfurt am Main","Germany","Frankfurt Flughafen",0,0,0,[]])
data_list.append([datetime.datetime(2017, 5, 24),2017,"Madrid","Spain","Aeropuerto Madrid-Barajas T4","Madrid","Spain","Chamartin",0,0,0,[]])
data_list.append([datetime.datetime(2017, 5, 25),2017,"Madrid","Spain","Chamartin","Salamanca","Spain","",1,0,0,[]])
data_list.append([datetime.datetime(2017, 5, 25),2017,"Salamanca","Spain","","Madrid","Spain","Chamartin",1,0,0,[]])
data_list.append([datetime.datetime(2017, 5, 26),2017,"Madrid","Spain","Chamartin","Madrid","Spain","Madrid-Puerta de Atocha",0,1,0,[]])
data_list.append([datetime.datetime(2017, 5, 26),2017,"Madrid","Spain","Madrid-Puerta de Atocha","Valencia","Spain","Valencia Joaquin Sorolla",1,0,1,[]])
data_list.append([datetime.datetime(2017, 5, 26),2017,"Valencia","Spain","Valencia Joaquin Sorolla","Madrid","Spain","Madrid-Puerta de Atocha",1,1,0,[]])
data_list.append([datetime.datetime(2017, 5, 26),2017,"Madrid","Spain","Madrid-Puerta de Atocha","Madrid","Spain","Chamartin",0,0,1,[]])
data_list.append([datetime.datetime(2017, 5, 27),2017,"Madrid","Spain","Chamartin","Leon","Spain","",1,0,0,[]])
data_list.append([datetime.datetime(2017, 5,
['Grace Cummings']])
data_list.append([datetime.datetime(2019, 6, 2),2019,"Hannover","Germany","Hannover HBF","Goslar","Germany","",0,0,0,['Grace Cummings']])
data_list.append([datetime.datetime(2019, 6, 2),2019,"Goslar","Germany","","Hannover","Germany","Hannover HBF",0,0,0,['Grace Cummings']])
data_list.append([datetime.datetime(2019, 6, 3),2019,"Hannover","Germany","Hannover HBF","Hannover","Germany","Hannover Flughafen",0,0,0,['Grace Cummings']])
data_list.append([datetime.datetime(2019, 6, 16),2019,"Genf","Switzerland","Cornavin","Luzern","Switzerland","",1,0,0,['Riju','Rachel','Chris Brainerd']])
data_list.append([datetime.datetime(2019, 6, 16),2019,"Arth-Goldau","Switzerland","","Olten","Switzerland","",1,1,0,['Riju','Rachel','Chris Brainerd']])
data_list.append([datetime.datetime(2019, 6, 16),2019,"Olten","Switzerland","","Genf","Switzerland","Cornavin",1,0,1,['Riju','Rachel','Chris Brainerd']])
data_list.append([datetime.datetime(2019, 6, 22),2019,"Genf","Switzerland","Cornavin","Renens","Switzerland","",0,1,0,[]])
data_list.append([datetime.datetime(2019, 6, 22),2019,"Renens","Switzerland","","Vallorbe","Switzerland","",0,1,0,[]])
data_list.append([datetime.datetime(2019, 7, 28),2019,"Genf","Switzerland","Cornavin","Brig","Switzerland","",1,1,0,['Chris Brainerd',"Ulrike",'Ivan','Jose','Francesca']])
data_list.append([datetime.datetime(2019, 7, 28),2019,"Brig","Switzerland","","Fiesch","Switzerland","",0,1,1,['Chris Brainerd',"Ulrike",'Ivan','Jose','Francesca']])
data_list.append([datetime.datetime(2019, 7, 28),2019,"Fiesch","Switzerland","","Brig","Switzerland","",0,1,0,['Chris Brainerd',"Ulrike",'Ivan','Jose','Francesca']])
data_list.append([datetime.datetime(2019, 7, 28),2019,"Brig","Switzerland","","Genf","Switzerland","Cornavin",1,0,1,['Chris Brainerd',"Ulrike",'Ivan','Jose','Francesca']])
data_list.append([datetime.datetime(2019, 8, 16),2019,"Genf","Switzerland","Cornavin","Aargau","Switzerland","",1,1,0,[]])
data_list.append([datetime.datetime(2019, 8, 16),2019,"Aargau","Switzerland","","Turgi","Switzerland","",0,1,1,[]])
data_list.append([datetime.datetime(2019, 8, 16),2019,"Turgi","Switzerland","","Koblenz","Switzerland","",0,1,1,[]])
data_list.append([datetime.datetime(2019, 8, 18),2019,"Koblenz","Switzerland","","Turgi","Switzerland","",0,1,1,[]])
data_list.append([datetime.datetime(2019, 8, 18),2019,"Turgi","Switzerland","","Aargau","Switzerland","",0,1,1,[]])
data_list.append([datetime.datetime(2019, 8, 18),2019,"Aargau","Switzerland","","Genf","Switzerland","Cornavin",1,0,1,[]])
data_list.append([datetime.datetime(2019, 8, 25),2019,"Genf","Switzerland","Cornavin","Visp","Switzerland","",1,1,0,['Chris Brainerd','Sam','Grace Cummings','Christine','Andres','Janina']])
data_list.append([datetime.datetime(2019, 8, 25),2019,"Visp","Switzerland","","Zermatt","Switzerland","",0,0,1,['Chris Brainerd','Sam','Grace Cummings','Christine','Andres','Janina']])
data_list.append([datetime.datetime(2019, 8, 25),2019,"Zermatt","Switzerland","","Visp","Switzerland","",0,1,0,['Chris Brainerd','Sam','Grace Cummings','Christine','Andres','Janina','David Yu']])
data_list.append([datetime.datetime(2019, 8, 25),2019,"Visp","Switzerland","","Genf","Switzerland","Cornavin",1,0,1,['Chris Brainerd','Sam','Grace Cummings','Christine','Andres','Janina',"David Yu"]])
data_list.append([datetime.datetime(2019, 9, 15),2019,"Genf","Switzerland","Cornavin","Brig","Switzerland","",1,1,0,['Janina']])
data_list.append([datetime.datetime(2019, 9, 15),2019,"Brig","Switzerland","","Goppenstein","Switzerland","",0,0,1,['Janina']])
data_list.append([datetime.datetime(2019, 9, 15),2019,"Goppenstein","Switzerland","","Brig","Switzerland","",0,1,0,['Janina']])
data_list.append([datetime.datetime(2019, 9, 15),2019,"Brig","Switzerland","","Genf","Switzerland","Cornavin",1,0,1,['
Switzerland","",0,1,1,[]])
data_list.append([datetime.datetime(2020, 8, 17),2020,"Aargau","Switzerland","","Genf","Switzerland","Cornavin",1,0,1,[]])
data_list.append([datetime.datetime(2020, 8, 28),2020,"Genf","Switzerland","Cornavin","Aargau","Switzerland","",1,1,0,[]])
data_list.append([datetime.datetime(2020, 8, 28),2020,"Aargau","Switzerland","","Turgi","Switzerland","",0,1,1,[]])
data_list.append([datetime.datetime(2020, 8, 28),2020,"Turgi","Switzerland","","Koblenz","Switzerland","",0,1,1,[]])
data_list.append([datetime.datetime(2020, 10, 11),2020,"Lauchringen","Germany","","Waldshut","Germany","",0,1,0,[]])
data_list.append([datetime.datetime(2020, 10, 11),2020,"Waldshut","Germany","","Baden","Switzerland","",0,1,1,[]])
data_list.append([datetime.datetime(2020, 10, 11),2020,"Baden","Germany","","Zuerich","Switzerland","Zuerich HB",0,1,1,["Namrata"]])
data_list.append([datetime.datetime(2020, 10, 11),2020,"Zuerich","Switzerland","Zuerich HB","Zug","Germany","",0,0,1,["Namrata"]])
data_list.append([datetime.datetime(2020, 10, 11),2020,"Zug","Germany","","Zuerich","Switzerland","Zuerich HB",0,1,0,["Namrata"]])
data_list.append([datetime.datetime(2020, 10, 11),2020,"Zuerich","Switzerland","Zuerich HB","Baden","Germany","",0,1,1,["Namrata"]])
data_list.append([datetime.datetime(2020, 10, 11),2020,"Baden","Germany","","Koblenz","Switzerland","",0,1,1,[]])

# %%
#2021
data_list.append([datetime.datetime(2021, 3, 11),2021,'Lindau','Germany',"Lindau-Insel","Kempten","Germany","Kempten HBF",0,1,1,[]])
data_list.append([datetime.datetime(2021, 3, 11),2021,"Kempten","Germany","Kempten HBF",'Muenchen','Germany',"Muenchen HBF",0,1,1,[]])
data_list.append([datetime.datetime(2021, 3, 11),2021,"Muenchen","Germany","Muenchen HBF",'Salzburg','Austria',"Salzburg HBF",1,1,1,[]])
data_list.append([datetime.datetime(2021, 3, 11),2021,"Salzburg","Austria","Salzburg HBF",'Wien','Austria',"Wien HBF",1,1,0,[]])
data_list.append([datetime.datetime(2021, 3, 11),2021,"Wien","Austria","Wien HBF",'Salzburg','Austria',"Salzburg HBF",1,1,0,[]])
data_list.append([datetime.datetime(2021, 3, 11),2021,'Salzburg','Austria',"Salzburg HBF","Muenchen","Germany","Ulm HBF",1,1,1,[]])
data_list.append([datetime.datetime(2021, 3, 11),2021,'Muenchen','Germany',"Muenchen HBF","Buchloe","Germany","",0,1,1,[]])
data_list.append([datetime.datetime(2021, 3, 11),2021,"Buchloe","Germany","",'Lindau','Germany',"Lindau-Insel",0,1,1,[]])
data_list.append([datetime.datetime(2021, 4, 28),2021,'Ravensburg','Germany',"","Ulm","Germany","Ulm HBF",0,1,1,[]])
data_list.append([datetime.datetime(2021, 4, 28),2021,"Ulm","Germany","Ulm HBF",'Salzburg','Austria',"Salzburg HBF",1,1,1,[]])
data_list.append([datetime.datetime(2021, 4, 28),2021,"Salzburg","Austria","Salzburg HBF",'Wien','Austria',"Wien HBF",1,0,1,[]])
data_list.append([datetime.datetime(2021, 5, 22),2021,"Wien","Austria","Wien HBF",'Salzburg','Austria',"Salzburg HBF",1,1,0,[]])
data_list.append([datetime.datetime(2021, 5, 22),2021,"Salzburg","Austria","Salzburg HBF",'Golling an der Salzach','Austria',"Golling-Abtenau",1,0,1,[]])
data_list.append([datetime.datetime(2021, 5, 22),2021,"Golling an der Salzach","Austria","Golling-Abtenau",'Elsbethen','Austria',"Salzburg Sued",0,0,0,[]])
data_list.append([datetime.datetime(2021, 5, 22),2021,"Salzburg","Austria","Salzburg HBF",'Wien','Austria',"Wien HBF",1,0,0,[]])
data_list.append([datetime.datetime(2021, 5, 24),2021,"Wien","Austria","Wien HBF",'Wels','Austria',"",1,1,0,[]])
data_list.append([datetime.datetime(2021, 5, 24),2021,"Wels","Austria","",'Steeg','Austria',"Steeg-Gosau",0,1,1,[]])
data_list.append([datetime.datetime(2021, 5, 24),2021,"Steeg","Austria","Steeg-Gosau","Attnang",'Austria',"Attnang-Puchheim",0,1,1,[]])
data_list.append([datetime.datetime(2021, 5, 24),2021,"Attnang","Austria","Attnang-Puchheim","Linz",'Austria',"Linz HBF",0,1,1,[]])
data_list.append([datetime.datetime(2021, 5, 24),2021,"Linz","Austria","Linz HBF","Wien",'Austria',"Wien HBF",0,0,1,[]])
data_list.append([datetime.datetime(2021, 5, 30),2021,"Wien","Austria","Wien Heiligenstadt",'Klosterneuburg','Austria',"Klosterneuburg Kierling",0,0,1,[]])
data_list.append([datetime.datetime(2021, 5, 30),2021,'Klosterneuburg','Austria',"Klosterneuburg Kierling","Wien","Austria","Wien Spittelau",0,1,0,[]])
data_list.append([datetime.datetime(2021, 6, 3),2021,"Wien","Austria","Wien HBF",'Althofen','Austria',"",0,1,0,[]])
data_list.append([datetime.datetime(2021, 6, 3),2021,'Althofen','Austria',"Treibach-Althofen","Launsdorf","Austria","Launsdorf-Hochosterwitz",0,0,1,[]])
data_list.append([datetime.datetime(2021, 6, 3),2021,"Launsdorf","Austria","Launsdorf-Hochosterwitz",'Althofen','Austria',"Treibach-Althofen",0,1,0,[]])
data_list.append([datetime.datetime(2021, 6, 3),2021,'Althofen','Austria',"Treibach-Althofen","Wien","Austria","Wien HBF",0,0,1,[]])
data_list.append([datetime.datetime(2021, 6, 12),2021,"Wien","Austria","Wien HBF",'St Poelten','Austria',"St Poelten HBF",1,1,0,[]])
data_list.append([datetime.datetime(2021, 6, 12),2021,"St Poelten","Austria","St Poelten HBF",'Lilienfeld','Austria',"Lilienfeld Bahnhof",0,0,1,[]])
data_list.append([datetime.datetime(2021, 6, 12),2021,'Lilienfeld','Austria',"Lilienfeld Bahnhof","St Poelten","Austria","St Poelten HBF",0,1,0,[]])
data_list.append([datetime.datetime(2021, 6, 12),2021,"St Poelten","Austria","St Poelten HBF",'Herzogenburg','Austria',"Herzogenburg Bahnhof",0,0,1,[]])
data_list.append([datetime.datetime(2021, 6, 12),2021,"Herzogenburg","Austria","Herzogenburg Bahnhof",'St Poelten','Austria',"St Poelten HBF",0,0,0,[]])
data_list.append([datetime.datetime(2021, 6, 12),2021,'St Poelten','Austria',"St Poelten HBF","Wien","Austria","Wien HBF",1,0,0,[]])
data_list.append([datetime.datetime(2021, 6, 13),2021,"Wien","Austria","Wien HBF",'Pernitz','Austria',"Pernitz-Muggendorf Bahnhof",0,0,0,[]])
data_list.append([datetime.datetime(2021, 6, 13),2021,'Pernitz','Austria',"Pernitz-Muggendorf Bahnhof","Wiener Neustadt","Austria","Wiener Neustadt HBF",0,1,0,[]])
data_list.append([datetime.datetime(2021, 6, 13),2021,'Wiener Neustadt','Austria',"Wiener Neustadt HBF","Wien","Austria","Wien HBF",0,0,1,[]])
data_list.append([datetime.datetime(2021, 6, 19),2021,"Wien","Austria","Wien HBF",'St Poelten','Austria',"St Poelten HBF",1,1,0,[]])
data_list.append([datetime.datetime(2021, 6, 19),2021,"St Poelten","Austria","St Poelten HBF",'Melk','Austria',"",0,0,0,[]])
data_list.append([datetime.datetime(2021, 6, 19),2021,"Emmersdorf an der Donau","Austria","Emmersdorf(Donau)",'Spitz an der Donau','Austria',"Spitz(Donau)",0,0,0,[]])
data_list.append([datetime.datetime(2021, 6, 19),2021,"Spitz an der Donau","Austria","Spitz(Donau)",'Duernstein','Austria',"",0,0,0,[]])
data_list.append([datetime.datetime(2021, 6, 19),2021,"Duernstein","Austria","",'Krems an der Donau','Austria',"Krems(Donau)",0,0,0,[]])
data_list.append([datetime.datetime(2021, 6, 19),2021,"Krems an der Donau","Austria","Krems(Donau)",'St Poelten','Austria',"St Poelten HBF",0,1,0,[]])
data_list.append([datetime.datetime(2021, 6, 19),2021,"St Poelten","Austria","St Poelten HBF",'Wien','Austria',"Wien HBF",1,0,1,[]])
data_list.append([datetime.datetime(2021, 6, 20),2021,"Wien","Austria","Wien HBF",'Baden bei Wien','Austria',"Baden",0,0,0,[]])
data_list.append([datetime.datetime(2021, 6, 20),2021,'Baden bei Wien','Austria',"Baden","Wien","Austria","Wien HBF",0,0,1,[]])
data_list.append([datetime.datetime(2021, 6, 26),2021,"Wien","Austria","Wien HBF",'Amstetten','Austria',"",1,1,0,[]])
data_list.append([datetime.datetime(2021, 6, 26),2021,"Amstetten","Austria","",'St Peter','Austria',"St Peter-Seitenstetten",0,0,1,[]])
data_list.append([datetime.datetime(2021, 6, 26),2021,'St Peter','Austria',"St Peter-Seitenstetten","St Valentin","Austria","",0,1,0,[]])
data_list.append([datetime.datetime(2021, 6, 26),2021,'St Valentin','Austria',"","Linz","Austria","Linz HBF",0,1,1,[]])
data_list.append([datetime.datetime(2021, 6, 26),2021,'Linz','Austria',"Linz HBF","Wien","Austria","Wien HBF",0,0,0,[]])
data_list.append([datetime.datetime(2021, 7, 3),2021,"Wien","Austria","Wien HBF",'Wels','Austria',"",1,1,0,[]])
data_list.append([datetime.datetime(2021, 7, 3),2021,"Wels","Austria","",'Obertraun','Austria',"Obertraun Koppenbruellerhoehle Bahnhof",0,0,1,[]])
data_list.append([datetime.datetime(2021, 7, 3),2021,"Obertraun",'Austria',"Obertraun Dachsteinhoehlen Bahnhof","Attnang","Austria","Attnang-Puchheim",0,1,1,[]])
data_list.append([datetime.datetime(2021, 7, 3),2021,"Attnang","Austria","Attnang-Puchheim","Linz",'Austria',"Linz HBF",0,1,1,[]])
data_list.append([datetime.datetime(2021, 7, 3),2021,"Linz","Austria","Linz HBF","Wien",'Austria',"Wien HBF",0,0,1,[]])
data_list.append([datetime.datetime(2021, 7, 10),2021,"Wien","Austria","Wien HBF",'Salzburg','Austria',"Salzburg HBF",1,1,0,[]])
data_list.append([datetime.datetime(2021, 7, 10),2021,'Salzburg','Austria',"Salzburg HBF","Schwarzach im Pongau","Austria","Schwarzach-St Veit",1,1,1,[]])
data_list.append([datetime.datetime(2021, 7, 10),2021,"Schwarzach im Pongau","Austria","Schwarzach-St Veit",'Taxenbach','Austria',"Taxenbach-Rauris",0,0,1,[]])
data_list.append([datetime.datetime(2021, 7, 10),2021,'Taxenbach','Austria',"Taxenbach-Rauris","Schwarzach im Pongau","Austria","Schwarzach-St Veit",0,0,0,[]])
data_list.append([datetime.datetime(2021, 7, 10),2021,"Schwarzach im Pongau","Austria","Schwarzach-St Veit",'Bischofshofen','Austria',"",1,0,0,[]])
data_list.append([datetime.datetime(2021, 7, 10),2021,'Bischofshofen','Austria',"","Salzburg","Austria","Salzburg HBF",1,1,0,[]])
data_list.append([datetime.datetime(2021, 7, 10),2021,'Salzburg','Austria',"Salzburg HBF","Wien","Austria","Wien HBF",1,0,1,[]])
data_list.append([datetime.datetime(2021, 7, 17),2021,"Wien","Austria","Wien HBF",'Salzburg','Austria',"Salzburg HBF",1,1,0,[]])
data_list.append([datetime.datetime(2021, 7, 17),2021,"Salzburg","Austria","Salzburg HBF",'Bad Gastein','Austria',"Bad Gastein",1,0,1,[]])
data_list.append([datetime.datetime(2021, 7, 17),2021,"Bad Gastein","Austria","Golling Abtenau",'Klagenfurt','Austria',"Klagenfurt HBF",1,0,0,[]])
data_list.append([datetime.datetime(2021, 7, 17),2021,"Klagenfurt","Austria","Klagenfurt HBF",'Wien','Austria',"Wien HBF",1,0,0,[]])
data_list.append([datetime.datetime(2021, 7, 23),2021,"Wien","Austria","Wien HBF",'Innsbruck','Austria',"Innsbruck HBF",1,0,0,[]])
data_list.append([datetime.datetime(2021, 7, 25),2021,'Innsbruck','Austria',"Innsbruck HBF","Wien","Austria","Wien HBF",1,0,0,[]])
data_list.append([datetime.datetime(2021, 8, 1),2021,"Wien","Austria","Wien Praterstern",'Petronell-Carnuntum,','Austria',"",0,0,0,[]])
data_list.append([datetime.datetime(2021, 8, 7),2021,"Wien","Austria","Wien HBF",'Eisenstadt','Austria',"Eistenstadt",0,1,0,[]])
data_list.append([datetime.datetime(2021, 8, 7),2021,'Eisenstadt','Austria',"Eisenstadt","Wien","Austria","Wien HBF",0,0,0,[]])
data_list.append([datetime.datetime(2021, 8, 14),2021,"Wien","Austria","Wien Heiligenstadt",'Hadersdorf','Austria',"",0,1,0,[]])
data_list.append([datetime.datetime(2021, 8, 14),2021,'Hadersdorf','Austria',"","Rosenburg","Austria","Rosenburg(Kamp)",0,0,1,[]])
data_list.append([datetime.datetime(2021, 8, 14),2021,"Rosenburg","Austria","Rosenburg(Kamp)","Furth bei Goettweig","Austria","Furth-Goettweig",0,0,1,[]])
data_list.append([datetime.datetime(2021, 8, 14),2021,"Furth bei Goettweig","Austria","Furth-Goettweig","St Poelten","Austria","St Poelten HBF",0,1,0,[]])
data_list.append([datetime.datetime(2021, 8, 14),2021,"St Poelten","Austria","St Poelten HBF","Wien","Austria","Wien HBF",1,0,1,[]])
data_list.append([datetime.datetime(2021, 8, 21),2021,"Wien","Austria","Wien HBF",'Semmering','Austria',"",1,0,0,[]])
data_list.append([datetime.datetime(2021, 8, 21),2021,'Payerbach','Austria',"Payerbach-Reichenau","Wien","Austria","Wien HBF",0,0,0,[]])
data_list.append([datetime.datetime(2021, 8, 27),2021,"Wien","Austria","Wien HBF",'Praha','Czech Republic',"Praha HL.N",1,0,0,[]])
data_list.append([datetime.datetime(2021, 8, 28),2021,'Praha','Czech Republic',"Praha HL.N","Karlstejn","Czech Republic","",0,0,0,[]])
data_list.append([datetime.datetime(2021, 8, 28),2021,"Karlstejn","Czech Republic","",'Praha','Czech Republic',"Praha HL.N",0,0,0,[]])
data_list.append([datetime.datetime(2021, 8, 29),2021,'Praha','Czech Republic',"Praha HL.N","Wien","Austria","Wien HBF",1,0,0,[]])
data_list.append([datetime.datetime(2021, 9, 2),2021,"Wien","Austria","Wien HBF",'Passau','Germany',"Passau HBF",1,0,0,[]])
data_list.append([datetime.datetime(2021, 9, 2),2021,'Passau','Germany',"Passau HBF","Plattling","Germany","",0,1,0,[]])
data_list.append([datetime.datetime(2021, 9, 2),2021,"Plattling","Germany","",'Regensburg','Germany',"Regensburg HBF",0,1,1,[]])
data_list.append([datetime.datetime(2021, 9, 5),2021,'Regensburg','Germany',"Regensburg HBF","Plattling","Germany","",0,1,0,[]])
data_list.append([datetime.datetime(2021, 9, 5),2021,"Plattling","Germany","",'Passau','Germany',"Passau HBF",0,0,1,[]])
data_list.append([datetime.datetime(2021, 9, 5),2021,'Passau','Germany',"Passau HBF","Wien","Austria","Wien HBF",1,0,0,[]])
data_list.append([datetime.datetime(2021, 8, 14),2021,"Wien","Austria","Wien HBF","St Poelten","Austria","St Poelten HBF",1,1,0,[]])
data_list.append([datetime.datetime(2021, 9, 18),2021,"St Poelten","Austria","St Poelten HBF","Annaberg bei Mariazell","Austria","Wienerbruck-Josefsberg",0,0,1,[]])
data_list.append([datetime.datetime(2021, 9, 18),2021,"Mitterbach am Erlaufsee","Austria","Erlaufklause","Mariazell","Austria","",0,0,0,[]])
data_list.append([datetime.datetime(2021, 9, 18),2021,"Mariazell","Austria","","St Poelten","Austria","St Poelten HBF",0,1,0,[]])
data_list.append([datetime.datetime(2021, 9, 18),2021,"St Poelten","Austria","St Poelten HBF","Wien","Austria","Wien HBF",1,0,1,[]])
data_list.append([datetime.datetime(2021, 9, 25),2021,"Wien","Austria","Wien HBF",'Salzburg','Austria',"Salzburg HBF",1,0,0,['Vivan','Michael']])
data_list.append([datetime.datetime(2021, 9, 25),2021,"Salzburg","Austria","Salzburg HBF",'Wien','Austria',"Wien HBF",1,0,0,['Vivan','Michael']])
data_list.append([datetime.datetime(2021, 10, 22),2021,"Wien","Austria","Wien HBF",'Nuernberg','Germany',"Nuernberg HBF",1,0,0,[]])
data_list.append([datetime.datetime(2021, 10, 23),2021,"Nuernberg","Germany","Nuernberg HBF",'Stuttgart','Germany',"Stuttgart HBF",1,1,0,[]])
data_list.append([datetime.datetime(2021, 10, 23),2021,"Stuttgart","Germany","Stuttgart HBF",'Saarbruecken','Germany',"Saarbruecken HBF",1,1,1,[]])
data_list.append([datetime.datetime(2021, 10, 23),2021,"Saarbruecken","Germany","Saarbruecken HBF",'Trier','Germany',"Trier HBF",0,0,1,[]])
data_list.append([datetime.datetime(2021, 10, 24),2021,"Trier","Germany","Trier HBF",'Wasserbillig','Luxemburg',"",0,1,0,[]])
data_list.append([datetime.datetime(2021, 10, 24),2021,"Wasserbillig","Luxemburg","",'Luxemburg','Luxemburg',"",0,0,1,[]])
data_list.append([datetime.datetime(2021, 10, 24),2021,"Luxemburg","Luxemburg","",'Wasserbillig','Luxemburg',"",0,1,0,[]])
data_list.append([datetime.datetime(2021, 10, 24),2021,"Wasserbillig","Luxemburg","",'Trier','Germany',"Trier HBF",0,0,1,[]])
data_list.append([datetime.datetime(2021, 10, 25),2021,"Trier","Germany","Trier HBF",'Luxemburg','Luxemburg',"",0,1,0,[]])
data_list.append([datetime.datetime(2021, 10, 25),2021,"Luxemburg","Luxemburg","",'Metz','France',"",0,1,0,[]])
data_list.append([datetime.datetime(2021, 10, 25),2021,"Metz","France","",'Nancy','France',"",0,0,0,[]])
data_list.append([datetime.datetime(2021, 10, 25),2021,"Nancy","France","",'Metz','France',"",0,0,0,[]])
data_list.append([datetime.datetime(2021, 10, 26),2021,"Metz","France","",'Paris','France',"Gare de l'Est",1,0,0,[]])
data_list.append([datetime.datetime(2021, 10, 28),2021,"Paris","France","Gare du Nord",'Lille','France',"Lille Flanders",1,1,0,[]])
data_list.append([datetime.datetime(2021, 10, 28),2021,"Lille","France","Lille-Flanders",'Tournai','Belgium',"",0,0,1,[]])
data_list.append([datetime.datetime(2021, 10, 28),2021,"Tournai","Belgium","",'Lille','France',"Lille Flanders",1,0,0,[]])
data_list.append([datetime.datetime(2021, 10, 28),2021,"Lille","France","Lille-Flanders",'Libercourt','France',"",0,0,0,[]])
data_list.append([datetime.datetime(2021, 10, 28),2021,"Libercourt","France","",'Douai','France',"",0,1,0,[]])
data_list.append([datetime.datetime(2021, 10, 28),2021,"Douai","France","",'Arras','France',"",0,0,1,[]])
data_list.append([datetime.datetime(2021, 10, 28),2021,"Arras","France","",'Paris','France',"Gare du Nord",1,0,0,[]])
data_list.append([datetime.datetime(2021, 10, 29),2021,"Paris","France","Gare du Nord",'Aachen','Germany',"",1,0,0,[]])
data_list.append([datetime.datetime(2021, 10, 29),2021,"Aachen","Germany","Aachen HBF",'Koeln','Germany',"Koeln-Deutz/Messe",1,0,0,[]])
data_list.append([datetime.datetime(2021, 10, 29),2021,"Koeln","Germany","Koeln-Deutz/Messe","Frankfurt am Main","Germany","Frankfurt HBF",1,0,0,[]])
data_list.append([datetime.datetime(2021, 10, 30),2021,"Frankfurt am Main","Germany","Frankfurt HBF","Mannheim","Germany","",1,1,0,[]])
data_list.append([datetime.datetime(2021, 10, 30),2021,"Mannheim","Germany","","Speyer","Germany","",1,0,1,[]])
data_list.append([datetime.datetime(2021, 10, 30),2021,"Speyer","Germany","","Ludwigshafen","Germany","",0,1,0,[]])
data_list.append([datetime.datetime(2021, 10, 30),2021,"Ludwigshafen","Germany","","Worms","Germany","",0,0,1,[]])
data_list.append([datetime.datetime(2021, 10, 30),2021,"Worms","Germany","","Bensheim","Germany","",0,1,0,[]])
data_list.append([datetime.datetime(2021, 10, 30),2021,"Bensheim","Germany","","Darmstadt","Germany","",1,0,1,[]])
data_list.append([datetime.datetime(2021, 10, 30),2021,"Darmstadt","Germany","","Frankfurt am Main","Germany","Frankfurt HBF",0,0,0,[]])
data_list.append([datetime.datetime(2021, 10, 31),2021,"Frankfurt am Main","Germany","Frankfurt HBF","Braubach","Germany","",0,0,0,[]])
data_list.append([datetime.datetime(2021, 10, 31),2021,"Braubach","Germany","","Koblenz","Germany","Koblenz HBF",0,1,0,[]])
data_list.append([datetime.datetime(2021, 10, 31),2021,"Koblenz","Germany","Koblenz HBF","Duisburg","Germany","Duisburg HBF",1,1,1,[]])
data_list.append([datetime.datetime(2021, 10, 31),2021,"Duisburg","Germany","Duisburg HBF","Essen","Germany","Essen HBF",0,0,1,[]])
data_list.append([datetime.datetime(2021, 10, 31),2021,"Essen","Germany","Essen HBF","Frankfurt am Main","Germany","Frankfurt Flughafen",1,1,0,[]])
data_list.append([datetime.datetime(2021, 10, 31),2021,"Frankfurt am Main","Germany","Frankfurt Flughafen","Frankfurt am Main","Germany","Frankfurt HBF",1,0,1,[]])
data_list.append([datetime.datetime(2021, 11, 1),2021,"Frankfurt am Main","Germany","Frankfurt HBF","Wien","Austria","Wien HBF",1,0,0,[]])
data_list.append([datetime.datetime(2021, 12, 22),2021,"Wien","Austria","Wien HBF","Muenchen","Germany","Muenchen HBF",1,0,0,[]])
data_list.append([datetime.datetime(2021, 12, 22),2021,"Muenchen","Germany","Muenchen HBF",'Ulm','Germany',"Ulm HBF",1,1,1,[]])
data_list.append([datetime.datetime(2021, 12, 22),2021,"Ulm","Germany","Ulm HBF",'Ravensburg','Germany',"",0,0,1,[]])

# %%
#2022
data_list.append([datetime.datetime(2022, 1, 2),2022,"Lauchringen","Germany","Lauchringen-West",'Tiengen','Germany',"",0,1,0,[]])
data_list.append([datetime.datetime(2022, 1, 2),2022,"Tiengen","Germany","",'Friedrichshafen','Germany',"Friedrichshafen-Stadt",1,1,1,[]])
data_list.append([datetime.datetime(2022, 1, 2),2022,"Friedrichshafen","Germany","Friedrichshafen-Stadt","Lindau",'Germany',"Lindau-Reutin",0,1,1,[]])
data_list.append([datetime.datetime(2022, 1, 2),2022,"Lindau","Germany","Lindau-Reutin",'Muenchen','Germany',"Muenchen HBF",1,1,1,[]])
data_list.append([datetime.datetime(2022, 1, 2),2022,"Muenchen","Germany","Muenchen HBF",'Wien','Austria',"Wien HBF",1,0,1,[]])
#spain 23
data_list.append([datetime.datetime(2022, 3, 19),2022,"Wien","Austria","Wien Praterstern","Schwechat","Austria","Wien Flughafen",0,0,0,[]])
data_list.append([datetime.datetime(2022, 3, 19),2022,"Madrid","Spain","Aeropuerto Madrid-Barajas T4","Madrid","Spain","Madrid-Puerta de Atocha",0,0,0,[]])
data_list.append([datetime.datetime(2022, 3, 19),2022,"Madrid","Spain","Madrid-Puerta de Atocha","Malaga","Spain","Maria Z",1,0,0,[]])
data_list.append([datetime.datetime(2022, 3, 21),2022,"Malaga","Spain","Maria Z","Antequera","Spain","Antequera S.Ana",1,0,1,[]])
data_list.append([datetime.datetime(2022, 3, 21),2022,"Antequera","Spain","Antequera S.Ana","Malaga","Spain","Granada",1,1,0,[]])
data_list.append([datetime.datetime(2022, 3, 24),2022,"Granada","Spain","","Cordoba","Spain","",1,0,1,[]])
data_list.append([datetime.datetime(2022, 3, 25),2022,"Cordoba","Spain","","Sevilla","Spain","Sevilla Santa Justa",1,0,1,[]])
data_list.append([datetime.datetime(2022, 3, 28),2022,"Sevilla","Spain","Sevilla Santa Justa","Madrid","Spain","Madrid-Puerta de Atocha",1,0,0,[]])
data_list.append([datetime.datetime(2022, 3, 28),2022,"Madrid","Spain","Madrid-Puerta de Atocha","Cuenca","Spain","Cuenca F.Zobel",1,0,0,[]])
data_list.append([datetime.datetime(2022, 3, 28),2022,"Cuenca","Spain","Cuenca F.Zobel","Madrid","Spain","Madrid-Puerta de Atocha",1,0,0,[]])
data_list.append([datetime.datetime(2022, 3, 29),2022,"Madrid","Spain","Madrid-Puerta de Atocha","Alcala de Henares","Spain","",1,0,0,[]])
data_list.append([datetime.datetime(2022, 3, 29),2022,"Alcala de Henares","Spain","","Madrid","Spain","Madrid-Puerta de Atocha",1,0,0,[]])
data_list.append([datetime.datetime(2022, 3, 30),2022,"Madrid","Spain","Madrid-Puerta de Atocha","Toledo","Spain","",1,0,0,[]])
data_list.append([datetime.datetime(2022, 3, 30),2022,"Toledo","Spain","","Madrid","Spain","Madrid-Puerta de Atocha",1,0,0,[]])
data_list.append([datetime.datetime(2022, 3, 31),2022,"Madrid","Spain","Madrid-Puerta de Atocha","Madrid","Spain","Chamartin",0,0,1,[]])
data_list.append([datetime.datetime(2022, 3, 31),2022,"Madrid","Spain","Chamartin","Leon","Spain","",1,1,0,[]])
data_list.append([datetime.datetime(2022, 3, 31),2022,"Leon","Spain","","Madrid","Spain","Chamartin",1,0,1,[]])
data_list.append([datetime.datetime(2022, 3, 31),2022,"Madrid","Spain","Chamartin","Madrid","Spain","Madrid-Puerta de Atocha",0,1,0,[]])
data_list.append([datetime.datetime(2022, 4, 1),2022,"Madrid","Spain","Madrid-Puerta de Atocha","Madrid","Spain","Chamartin",0,0,1,[]])
data_list.append([datetime.datetime(2022, 4, 1),2022,"Madrid","Spain","Chamartin","Segovia","Spain","Segovia AVE",1,1,0,[]])
data_list.append([datetime.datetime(2022, 4, 1),2022,"Segovia","Spain","Segovia AVE","Madrid","Spain","Chamartin",1,0,1,[]])
data_list.append([datetime.datetime(2022, 4, 1),2022,"Madrid","Spain","Chamartin","Madrid","Spain","Madrid-Puerta de Atocha",0,1,0,[]])
data_list.append([datetime.datetime(2015, 4, 2),2022,"Madrid","Spain","Madrid-Puerta de Atocha","Aranjuez","Spain","",0,0,1,[]])
data_list.append([datetime.datetime(2015, 4, 2),2022,"Aranjuez","Spain","","El Escorial","Spain","",0,0,1,[]])
data_list.append([datetime.datetime(2015, 4, 2),2022,"El Escorial","Spain","","Madrid","Spain","Madrid-Puerta de Atocha",0,0,1,[]])
data_list.append([datetime.datetime(2022, 4, 3),2022,"Madrid","Spain","Madrid-Puerta de Atocha","Madrid","Spain","Aeropuerto Madrid-Barajas T4",0,0,1,[]])
data_list.append([datetime.datetime(2022, 4, 3),2022,"Schwechat","Austria","Wien Flughafen","Wien","Austria","Wien Praterstern",0,0,0,[]])
data_list.append([datetime.datetime(2022, 5, 15),2022,"Wien","Austria","Wien HBF","Gyor","Hungary","Gyor HBF",1,1,0,[]])
data_list.append([datetime.datetime(2022, 5, 15),2022,"Gyor","Hungary","Gyor HBF","Pannonhalma","Hungary","",0,0,1,[]])
data_list.append([datetime.datetime(2022, 5, 15),2022,"Pannonhalma","Hungary","","Gyor","Hungary","Gyor HBF",0,0,1,[]])
data_list.append([datetime.datetime(2022, 5, 15),2022,"Gyor","Hungary","Gyor HBF","Wien","Austria","Wien HBF",1,0,1,[]])
data_list.append([datetime.datetime(2022, 5, 21),2022,"Wien","Austria","Wien Praterstern","Schwechat","Austria","Wien Flughafen",0,0,0,[]])
data_list.append([datetime.datetime(2022, 5, 21),2022,"Schwechat","Austria","Wien Flughafen","Wien","Austria","Wien Praterstern",0,0,0,['Chris Martin']])
data_list.append([datetime.datetime(2022, 5, 25),2022,"Wien","Austria","Wien HBF","Budapest","Hungary","Budapest-Keleti",1,0,0,['Chris Martin']])
data_list.append([datetime.datetime(2022, 5, 27),2022,"Budapest","Hungary","Budapest-Keleti","Wien","Austria","Wien HBF",1,0,0,['Chris Martin']])
data_list.append([datetime.datetime(2022, 6, 4),2022,"Wien","Austria","Wien HBF","Bratislava","Slovakia","Bratislava HS",0,0,0,["Artur"]])
data_list.append([datetime.datetime(2022, 6, 4),2022,"Bratislava","Slovakia","Bratislava HS","Wien","Austria","Wien Stadlau",0,0,0,["Artur"]])
data_list.append([datetime.datetime(2022, 6, 5),2022,"Wien","Austria","Wien HBF","Budapest","Hungary","Budapest-Keleti",1,0,0,['Artur']])
data_list.append([datetime.datetime(2022, 6, 5),2022,"Budapest","Hungary","Budapest-Keleti","Wien","Austria","Wien HBF",1,0,0,['Artur']])
data_list.append([datetime.datetime(2022, 6, 11),2022,"Wien","Austria","Wien HBF","Salzburg","Austria","Salzburg HBF",1,1,0,[]])
data_list.append([datetime.datetime(2022, 6, 11),2022,"Salzburg","Austria","Salzburg HBF","Muenchen","Germany","Muenchen HBF",0,1,1,[]])
data_list.append([datetime.datetime(2022, 6, 11),2022,"Muenchen","Germany","Muenchen HBF","Augsburg","Germany","Augsburg HBF",0,0,1,[]])
data_list.append([datetime.datetime(2022, 6, 11),2022,"Augsburg","Germany","Augsburg HBF","Muenchen","Germany","Muenchen HBF",0,0,0,[]])
data_list.append([datetime.datetime(2022, 6, 11),2022,"Muenchen","Germany","Muenchen HBF","Salzburg","Austria","Salzburg HBF",0,1,0,[]])
data_list.append([datetime.datetime(2022, 6, 11),2022,"Salzburg","Austria","Salzburg HBF","Wien","Austria","Wien HBF",1,0,1,[]])
data_list.append([datetime.datetime(2022, 6, 15),2022,"Wien","Austria","Wien Praterstern","Schwechat","Austria","Wien Flughafen",0,0,0,[]])
data_list.append([datetime.datetime(2022, 6, 15),2022,"Schwechat","Austria","Wien Flughafen","Wien","Austria","Wien Praterstern",0,0,0,[]])
data_list.append([datetime.datetime(2022, 6, 16),2022,"Wien","Austria","Wien Praterstern","Schwechat","Austria","Wien Flughafen",0,0,0,[]])
data_list.append([datetime.datetime(2022, 6, 16),2022,"Schoenefeld","Germany","BER Airport-Terminal 1-2","Berlin","Germany","Berlin-Adlershof",0,0,0,[]])
data_list.append([datetime.datetime(2022, 6, 16),2022,"Berlin","Germany","Berlin-Koepenick","Berlin","Germany","Berlin-Ostkreuz",0,1,0,[]])
data_list.append([datetime.datetime(2022, 6, 16),2022,"Berlin","Germany","Berlin-Ostkreuz","Berlin","Germany","Berlin-Gesundbrunnen",0,1,1,[]])
data_list.append([datetime.datetime(2022, 6, 16),2022,"Berlin","Germany","Berlin-Gesundbrunnen","Stralsund","Germany","Stralsund HBF",0,0,1,[]])
data_list.append([datetime.datetime(2022, 6, 16),2022,"Stralsund","Germany","Stralsund","Rostock","Germany","Rostock HBF",0,0,0,[]])
data_list.append([datetime.datetime(2022, 6, 16),2022,"Rostock","Germany","Rostock HBF","Berlin","Germany","Berlin HBF",0,1,0,[]])
data_list.append([datetime.datetime(2022, 6, 16),2022,"Rostock","Germany","Rostock HBF","Berlin","Germany","Berlin HBF",0,1,0,[]])
data_list.append([datetime.datetime(2022, 6, 16),2022,"Berlin","Germany","Berlin HBF","Berlin","Germany","Berlin-Adlershof",0,0,1,[]])
data_list.append([datetime.datetime(2022, 6, 17),2022,"Berlin","Germany","Berlin-Adlershof","Berlin","Germany","Berlin-Suedkreuz",0,1,0,[]])
data_list.append([datetime.datetime(2022, 6, 17),2022,"Berlin","Germany","Berlin-Suedkreuz","Elsterwerda","Germany","Elsterwerda",0,1,1,[]])
data_list.append([datetime.datetime(2022, 6, 17),2022,"Elsterwerda","Germany","Elsterwerda","Dresden","Germany","Dresden HBF",0,1,1,[]])
data_list.append([datetime.datetime(2022, 6, 17),2022,"Dresden","Germany","Dresden HBF","Freiberg","Germany","Freiberg (Sachs)",0,0,1,[]])
data_list.append([datetime.datetime(2022, 6, 17),2022,"Freiberg","Germany","Freiberg (Sachs)","Dresden","Germany","Dresden HBF",0,1,0,[]])
data_list.append([datetime.datetime(2022, 6, 17),2022,"Dresden","Germany","Dresden HBF","Dresden","Germany","Dresden-Neustadt",0,0,1,[]])
data_list.append([datetime.datetime(2022, 6, 17),2022,"Grossenhain","Germany","Grossenhain Cottbus Bahnhof","Senftenberg","Germany","",0,1,0,[]])
data_list.append([datetime.datetime(2022, 6, 17),2022,"Senftenberg","Germany","","Koenigs Wusterhausen","Germany","",0,1,1,[]])
data_list.append([datetime.datetime(2022, 6, 17),2022,"Koenigs Wusterhausen","Germany","","Berlin","Germany","Berlin-Gruenau",0,0,1,[]])
data_list.append([datetime.datetime(2022, 6, 18),2022,"Berlin","Germany","Berlin-Spindlersfeld","Berlin","Germany","Berlin-Westkreuz",0,1,0,['Hannsjoerg']])
data_list.append([datetime.datetime(2022, 6, 18),2022,"Berlin","Germany","Berlin-Westkreuz","Potsdam","Germany","Potsdam HBF",0,0,1,['Hannsjoerg']])
data_list.append([datetime.datetime(2022, 6, 18),2022,"Potsdam","Germany","Potsdam HBF","Berlin","Germany","Berlin-Ostkreuz",0,1,0,['Hannsjoerg']])
data_list.append([datetime.datetime(2022, 6, 18),2022,"Berlin","Germany","Berlin-Ostkreuz","Berlin","Germany","Berlin-Adlershof",0,0,1,['Hannsjoerg']])
data_list.append([datetime.datetime(2022, 6, 19),2022,"Berlin","Germany","Berlin-Adlershof","Berlin","Germany","Berlin-Alexanderplatz",0,0,0,[]])
data_list.append([datetime.datetime(2022, 6, 19),2022,"Berlin","Germany","Berlin HBF","Berlin","Germany","Berlin-Jungfernheide",0,0,0,[]])
data_list.append([datetime.datetime(2022, 6, 19),2022,"Berlin","Germany","Berlin-Zoologischer Garten","Dessau-Rosslau","Germany","Dessau HBF",0,1,0,[]])
data_list.append([datetime.datetime(2022, 6, 19),2022,"Dessau-Rosslau","Germany","Dessau HBF","Leipzig","Germany","Leipzig Messe",0,0,1,[]])
data_list.append([datetime.datetime(2022, 6, 19),2022,"Schwechat","Austria","Wien Flughafen","Wien","Austria","Wien Praterstern",0,0,0,[]])
data_list.append([datetime.datetime(2022, 7, 10),2022,"Wien","Austria","Wien Heiligenstadt",'Ceske Velenice','Czech Republic',"",0,1,0,[]])
data_list.append([datetime.datetime(2022, 7, 10),2022,"Ceske Velenice","Czech Republic","",'Ceske Budejovice','Czech Republic',"",0,1,1,[]])
data_list.append([datetime.datetime(2022, 7, 10),2022,"Ceske Budejovice","Czech Republic","",'Cesky Krumlov','Czech Republic',"",0,1,0,[]])
data_list.append([datetime.datetime(2022, 7, 10),2022,"Cesky Krumlov","Czech Republic","",'Ceske Budejovice','Czech Republic',"",0,0,0,[]])
data_list.append([datetime.datetime(2022, 7, 10),2022,"Ceske Budejovice","Czech Republic","",'Rybnik','Czech Republic',"",1,0,1,[]])
data_list.append([datetime.datetime(2022, 7, 10),2022,"Linz","Austria","Linz HBF",'Wien','Austria',"Wien HBF",1,1,0,[]])
data_list.append([datetime.datetime(2022, 7, 16),2022,"Wien","Austria","Wien HBF",'Otrokovice','Czech Republic',"",1,1,0,[]])
data_list.append([datetime.datetime(2022, 7, 16),2022,"Otrokovice","Czech Republic","",'Hulin','Czech Republic',"",0,1,1,[]])
data_list.append([datetime.datetime(2022, 7, 16),2022,"Kromeriz","Czech Republic","",'Hulin','Czech Republic',"",0,0,1,[]])
data_list.append([datetime.datetime(2022, 7, 16),2022,"Hulin","Czech Republic","",'Olomouc','Czech Republic',"",0,1,0,[]])
data_list.append([datetime.datetime(2022, 7, 16),2022,"Olmolouc","Czech Republic","",'Prerov','Czech Republic',"",0,0,1,[]])
data_list.append([datetime.datetime(2022, 7, 16),2022,"Prerov","Czech Republic","",'Wien','Austria',"Wien HBF",1,1,0,[]])
data_list.append([datetime.datetime(2022, 7, 29),2022,"Wien","Austria","Wien Praterstern",'Schwechat','Austria',"Wien Flughafen",0,0,0,['Riju']])
data_list.append([datetime.datetime(2022, 7, 29),2022,"Malpensa","Italy","Malpensa Terminal 1",'Milano','Italy',"Milano Centrale",0,0,0,['Riju']])
data_list.append([datetime.datetime(2022, 7, 29),2022,"Milano","Italy","Milano Centrale",'Parma','Italy',"Parma Centrale",0,0,1,[]])
data_list.append([datetime.datetime(2022, 7, 29),2022,"Parma","Italy","Parma Centrale",'Modena','Italy',"",0,1,0,[]])
data_list.append([datetime.datetime(2022, 7, 29),2022,"Modena","Italy","",'Parma','Italy',"Parma Centrale",0,1,0,[]])
data_list.append([datetime.datetime(2022, 7, 29),2022,"Parma","Italy","Parma Centrale",'Milano','Italy',"Milano Centrale",0,0,1,[]])
data_list.append([datetime.datetime(2022, 7, 30),2022,"Milano","Italy","Milano Garibaldi",'Sesto Calende','Italy',"",0,0,0,['Riju']])
data_list.append([datetime.datetime(2022, 7, 31),2022,'Sesto Calende','Italy',"","Milano","Italy","Milano Garibaldi",0,0,0,['Riju']])
data_list.append([datetime.datetime(2022, 7, 31),2022,"Milano","Italy","Milano Centrale",'Napoli','Italy',"Napoli Centrale",1,0,0,['Riju']])
data_list.append([datetime.datetime(2022, 8, 2),2022,"Napoli","Italy","Napoli Centrale",'Salerno','Italy',"",0,0,0,['Riju']])
data_list.append([datetime.datetime(2022, 8, 2),2022,"Sorrento","Italy","",'Napoli','Italy',"Napoli Piazza Garibaldi",0,0,0,['Riju']])
data_list.append([datetime.datetime(2022, 8, 3),2022,"Napoli","Italy","Napoli Centrale",'Pompei','Italy',"Pompei",0,0,0,['Riju']])
data_list.append([datetime.datetime(2022, 8, 3),2022,"Pompei","Italy","Pompei Scavi",'Napoli','Italy',"Napoli Piazza Garibaldi",0,0,0,['Riju']])
data_list.append([datetime.datetime(2022, 8, 3),2022,"Napoli","Italy","Napoli Centrale",'Milano','Italy',"Milano Centrale",1,0,0,['Riju']])
data_list.append([datetime.datetime(2022, 8, 4),2022,'Milano','Italy',"Milano Centrale","Firenze","Italy","Firenze Santa Maria Novella",1,0,0,[]])
data_list.append([datetime.datetime(2022, 8, 4),2022,"Firenze","Italy","Firenze Santa Maria Novella",'Pisa','Italy',"Pisa Centrale",0,0,0,[]])
data_list.append([datetime.datetime(2022, 8, 4),2022,'Pisa','Italy',"Pisa Centrale","Empoli","Italy","",0,1,0,[]])
data_list.append([datetime.datetime(2022, 8, 4),2022,'Empoli','Italy',"","Siena","Italy","",0,0,1,[]])
data_list.append([datetime.datetime(2022, 8, 4),2022,'Siena','Italy',"","Firenze","Italy","Firenze Santa Maria Novella",0,0,0,[]])
data_list.append([datetime.datetime(2022, 8, 5),2022,"Firenze","Italy","Firenze Santa Maria Novella",'Bologna','Italy',"Bologna Centrale",0,0,0,[]])
data_list.append([datetime.datetime(2022, 8, 5),2022,'Bologna','Italy',"Bologna Centrale","Venezia","Italy","Venezia St Lucia",0,0,0,[]])
data_list.append([datetime.datetime(2022, 8, 6),2022,"Venezia","Italy","Venezia St Lucia",'Bologna','Italy',"Bologna Centrale",1,1,0,[]])
data_list.append([datetime.datetime(2022, 8, 6),2022,'Bologna','Italy',"Bologna Centrale",'Milano','Italy',"Milano Centrale",1,0,1,[]])
data_list.append([datetime.datetime(2022, 8, 7),2022,'Milano','Italy',"Milano Centrale",'Parma','Italy',"Parma Centrale",1,0,0,[]])
data_list.append([datetime.datetime(2022, 8, 7),2022,'Parma','Italy',"Parma Centrale",'Milano','Italy',"Milano Centrale",1,0,0,[]])
data_list.append([datetime.datetime(2022, 8, 7),2022,'Milano','Italy',"Milano Centrale","Malpensa","Italy","Malpensa Terminal 1",0,0,0,[]])
data_list.append([datetime.datetime(2022, 8, 7),2022,'Schwechat','Austria',"Wien Flughafen","Wien","Austria","Wien Praterstern",0,0,0,['Riju']])
data_list.append([datetime.datetime(2022, 8, 12),2022,"Wien","Austria","Wien HBF",'Praha','Czech Republic',"Praha HL.N",1,0,0,["Riju"]])
data_list.append([datetime.datetime(2022, 8, 13),2022,'Praha','Czech Republic',"Praha HL.N","Kutna Hora","Czech Republic","Kutna Hora HL.N",1,0,0,[]])
data_list.append([datetime.datetime(2022, 8, 13),2022,"Kutna Hora","Czech Republic","Kutna Hora HL.N",'Praha','Czech Republic',"Praha HL.N",1,0,0,[]])
data_list.append([datetime.datetime(2022, 8, 14),2022,'Praha','Czech Republic',"Praha HL.N","Wien","Austria","Wien HBF",1,0,0,['Riju']])
data_list.append([datetime.datetime(2022, 8, 15),2022,"Wien","Austria","Wien HBF",'Breclav','Czech Republic',"",1,0,0,[]])
data_list.append([datetime.datetime(2022, 8, 15),2022,'Breclav','Czech Republic',"","Wien","Austria","Wien Leopoldau",0,0,0,[]])
data_list.append([datetime.datetime(2022, 8, 21),2022,"Wien","Austria","Wien HBF",'Zdar nad Sazavou','Czech Republic',"",1,0,0,[]])
data_list.append([datetime.datetime(2022, 8, 21),2022,"Zdar nad Sazavou","Czech Republic","",'Brno','Czech Republic',"Brno HL.N",1,0,0,[]])
data_list.append([datetime.datetime(2022, 8, 21),2022,"Brno","Czech Republic","Brno HL.N",'Wien','Austria',"Wien HBF",1,0,0,[]])
data_list.append([datetime.datetime(2022, 8, 25),2022,"Wien","Austria","Wien Praterstern",'Schwechat','Austria',"Wien Flughafen",0,0,0,[]])
data_list.append([datetime.datetime(2022, 8, 28),2022,'Schwechat','Austria',"Wien Flughafen","Wien","Austria","Wien Praterstern",0,0,0,['Artur']])
data_list.append([datetime.datetime(2022, 9, 3),2022,"Wien","Austria","Wien HBF",'Breclav','Czech Republic',"",1,1,0,[]])
data_list.append([datetime.datetime(2022, 9, 3),2022,'Breclav','Czech Republic',"","Valtice","Czech Republic","Valtice Mesto",0,0,1,[]])
data_list.append([datetime.datetime(2022, 9, 3),2022,"Valtice","Czech Republic","Valtice Mesto",'Breclav','Czech Republic',"",1,1,0,[]])
data_list.append([datetime.datetime(2022, 9, 3),2022,'Breclav','Czech Republic',"","Wien","Austria","Wien Leopoldau",0,0,1,[]])
data_list.append([datetime.datetime(2022, 9, 4),2022,"Wien","Austria","Wien HBF",'Brno','Czech Republic',"Brno HL.N",1,1,0,[]])
data_list.append([datetime.datetime(2022, 9, 4),2022,"Brno","Czech Republic","Brno HL.N",'Trebic','Czech Republic',"",0,0,1,[]])
data_list.append([datetime.datetime(2022, 9, 4),2022,"Trebic","Czech Republic","",'Brno','Czech Republic',"Brno HL.N",0,1,0,[]])
data_list.append([datetime.datetime(2022, 9, 4),2022,"Brno","Czech Republic","Brno HL.N",'Wien','Austria',"Wien HBF",1,0,1,[]])
data_list.append([datetime.datetime(2022, 9, 10),2022,"Wien","Austria","Wien HBF",'Brno','Czech Republic',"Brno HL.N",1,1,0,[]])
data_list.append([datetime.datetime(2022, 9, 10),2022,"Brno","Czech Republic","Brno HL.N",'Wien','Austria',"Wien HBF",1,0,1,[]])
data_list.append([datetime.datetime(2022, 9, 27),2022,"Leobersdorf","Austria","Leobersdorf" ,'Wien','Austria',"Wien HBF",0,0,0,[]])
data_list.append([datetime.datetime(2022, 10, 8),2022,"Wien","Austria","Wien HBF",'Leoben','Austria',"Leoben HBF",1,1,0,[]])
data_list.append([datetime.datetime(2022, 10, 8),2022,"Leoben","Austria","Leoben HBF" ,'Wien','Austria',"Wien HBF",1,0,1,[]])
data_list.append([datetime.datetime(2022, 10, 9),2022,"Wien","Austria","Wien HBF","Linz",'Austria',"Linz HBF",1,1,0,[]])
data_list.append([datetime.datetime(2022, 10, 9),2022,"Linz","Austria","Linz HBF","Kremsmuenster",'Austria',"",0,0,1,[]])
data_list.append([datetime.datetime(2022, 10, 9),2022,"Kremsmuenster","Austria","","Linz",'Austria',"Linz HBF",0,0,0,[]])
data_list.append([datetime.datetime(2022, 10, 9),2022,"Linz","Austria","Linz HBF","Wien",'Austria',"Wien HBF",1,0,0,[]])
data_list.append([datetime.datetime(2022, 10, 15),2022,"Wien","Austria","Wien HBF","Linz",'Austria',"Linz HBF",1,1,0,[]])
data_list.append([datetime.datetime(2022, 10, 15),2022,"Linz","Austria","Linz HBF","Schlierbach",'Austria',"",0,0,1,[]])
data_list.append([datetime.datetime(2022, 10, 15),2022,"Schlierbach","Austria","","Linz",'Austria',"Linz HBF",0,1,0,[]])
data_list.append([datetime.datetime(2022, 10, 15),2022,"Linz","Austria","Linz HBF","Steyr",'Austria',"Steyr",0,0,1,[]])
data_list.append([datetime.datetime(2022, 10, 15),2022,"Steyr",'Austria',"Steyr","St Valentin",'Austria',"",0,1,0,[]])
data_list.append([datetime.datetime(2022, 10, 15),2022,"St Valentin",'Austria',"","Wien","Austria","Wien HBF",1,0,1,[]])
data_list.append([datetime.datetime(2022, 10, 16),2022,"Wien","Austria","Wien HBF",'Amstetten','Austria',"",1,1,0,[]])
data_list.append([datetime.datetime(2022, 10, 16),2022,'Amstetten','Austria',"","Hieflau","Austria","",0,0,1,[]])
data_list.append([datetime.datetime(2022, 10, 16),2022,"Johnsbach im Nationalpark","Austria","",'Amstetten','Austria',"",1,1,0,[]])
data_list.append([datetime.datetime(2022, 10, 16),2022,'Amstetten','Austria',"","Wien","Austria","Wien HBF",1,0,1,[]])
data_list.append([datetime.datetime(2022, 10, 29),2022,"Wien","Austria","Wien HBF",'Bruck an der Mur','Austria',"Bruck/Mur",1,0,0,[]])
data_list.append([datetime.datetime(2022, 10, 29),2022,"Bruck an der Mur","Austria","Bruck/Mur",'Peggau','Austria',"Peggau-Deutschfeistritz",0,0,0,[]])
data_list.append([datetime.datetime(2022, 10, 29),2022,'Peggau','Austria',"Peggau-Deutschfeistritz","Graz","Austria","Graz HBF",0,0,0,[]])
data_list.append([datetime.datetime(2022, 10, 29),2022,"Graz","Austria","Graz HBF",'Wien','Austria',"Wien HBF",1,0,0,[]])
data_list.append([datetime.datetime(2022, 11, 2),2022,"Wien","Austria","Wien HBF",'Katowice','Poland',"Katowice",1,0,0,[]])
data_list.append([datetime.datetime(2022, 11, 3),2022,"Katowice","Poland","Katowice",'Warsaw','Poland',"Warszawa Centralna",1,0,0,[]])
data_list.append([datetime.datetime(2022, 11, 4),2022,'Warsaw','Poland',"Warszawa Gdanska","Torun","Poland","Torun Miasto",1,0,0,[]])
data_list.append([datetime.datetime(2022, 11, 4),2022,"Torun","Poland","Torun Miasto",'Warsaw','Poland',"Warszawa Centralna",1,0,0,[]])
data_list.append([datetime.datetime(2022, 11, 5),2022,'Warsaw','Poland',"Warszawa Centralna","Malbork","Poland","Malbork",1,0,0,[]])
data_list.append([datetime.datetime(2022, 11, 5),2022,"Malbork","Poland","Malbork",'Gdansk','Poland',"Gdansk Glowny",1,0,0,[]])
data_list.append([datetime.datetime(2022, 11, 5),2022,"Gdansk","Poland","Gdansk Glowny",'Warsaw','Poland',"Warszawa Centralna",1,0,0,[]])
data_list.append([datetime.datetime(2022, 11, 4),2022,'Warsaw','Poland',"Warszawa Gdanska","Wien","Austria","Wien HBF",1,0,0,[]])
data_list.append([datetime.datetime(2022, 12, 1),2022,"Wien","Austria","Wien Praterstern",'Schwechat','Austria',"Wien Flughafen",0,0,0,[]])
data_list.append([datetime.datetime(2022, 12, 1),2022,"Duesseldorf","Germany","Duesseldorf Flughafen Terminal","Duesseldorf","Germany","Duesseldorf HBF",0,0,0,[]])
data_list.append([datetime.datetime(2022, 12, 2),2022,"Duesseldorf","Germany","Duesseldorf HBF","Koeln","Germany","Koeln HBF",0,0,0,['Artur']])
data_list.append([datetime.datetime(2022, 12, 2),2022,"Koeln","Germany","Koeln HBF","Duesseldorf","Germany","Duesseldorf HBF",0,0,0,['Artur']])
data_list.append([datetime.datetime(2022, 12, 3),2022,"Duesseldorf","Germany","Duesseldorf HBF","Dortmund","Germany","Dortmund HBF",0,1,0,['Artur']])
data_list.append([datetime.datetime(2022, 12, 3),2022,"Duesseldorf","Germany","Dortmund HBF","Capelle","Germany","",0,1,0,['Artur']])
data_list.append([datetime.datetime(2022, 12, 3),2022,"Muenster","Germany","Muenster HBF","Duesseldorf","Germany","Duesseldorf HBF",0,0,0,['Artur']])
data_list.append([datetime.datetime(2022, 12, 4),2022,"Duesseldorf","Germany","Duesseldorf HBF","Duesseldorf","Germany","Duesseldorf Flughafen Terminal",0,0,0,[]])
data_list.append([datetime.datetime(2022, 12, 4),2022,'Schwechat','Austria',"Wien Flughafen","Wien","Austria","Wien Praterstern",0,0,0,[]])
data_list.append([datetime.datetime(2022, 12, 23),2022,"Wien","Austria","Wien HBF",'Zuerich','Switzerland',"Zuerich HB",1,0,0,[]])
data_list.append([datetime.datetime(2022, 12, 23),2022,"Zuerich","Switzerland","Zuerich HB",'Baden','Switzerland',"",1,1,0,[]])
data_list.append([datetime.datetime(2022, 12, 23),2022,"Baden","Switzerland","",'Koblenz','Switzerland',"",0,0,1,[]])
data_list.append([datetime.datetime(2022, 12, 28),2022,"Koblenz","Switzerland","",'Baden','Switzerland',"",0,1,0,['Artur']])
data_list.append([datetime.datetime(2022, 12, 28),2022,"Baden","Switzerland","",'Zuerich','Switzerland',"Zuerich HB",1,1,1,['Artur']])
data_list.append([datetime.datetime(2022, 12, 28),2022,"Zuerich","Switzerland","Zuerich HB",'Landquart','Switzerland',"",1,1,1,['Artur']])
data_list.append([datetime.datetime(2022, 12, 28),2022,"Landquart","Switzerland","",'Sagliains','Switzerland',"",0,1,1,['Artur']])
data_list.append([datetime.datetime(2022, 12, 28),2022,"Sagliains","Switzerland","",'Zernez','Switzerland',"",0,1,1,['Artur']])
data_list.append([datetime.datetime(2022, 12, 28),2022,"Zernez","Switzerland","",'Samedan','Switzerland',"",0,1,1,['Artur']])
data_list.append([datetime.datetime(2022, 12, 28),2022,"Samedan","Switzerland","",'Chur','Switzerland',"",1,1,1,['Artur']])
data_list.append([datetime.datetime(2022, 12, 28),2022,"Chur","Switzerland","",'Zuerich','Switzerland',"Zuerich HB",1,1,1,['Artur']])
data_list.append([datetime.datetime(2022, 12, 28),2022,"Zuerich","Switzerland","Zuerich HB",'Baden','Switzerland',"",1,0,1,['Artur']])
data_list.append([datetime.datetime(2022, 12, 28),2022,'Baden','Switzerland',"","Koblenz","Switzerland","",0,1,1,['Artur']])

# %%
data_list.append([datetime.datetime(2023, 1, 1),2023,'Koblenz','Switzerland',"","Baden","Switzerland","",0,0,1,[]])
data_list.append([datetime.datetime(2023, 1, 1),2023,"Baden",'Switzerland','',"Zuerich","Switzerland",'Zuerich HB',1,1,0,[]])
data_list.append([datetime.datetime(2023, 1, 1),2023,'Zuerich','Switzerland',"Zuerich HB","Wien","Austria","Wien HBF",1,0,0,[]])
data_list.append([datetime.datetime(2023, 2, 25),2023,'Wien','Austria',"Wien HBF","Brno","Czech Republic","Brno HL.N",1,0,1,['Janina','Kevin']])
data_list.append([datetime.datetime(2023, 2, 25),2023,'Brno','Czech Republic',"Brno HL.N","Blansko","Czech Republic","Blansko",0,1,0,['Janina','Kevin']])
data_list.append([datetime.datetime(2023, 2, 25),2023,"Blansko","Czech Republic","Blansko",'Brno','Czech Republic',"Brno HL.N",0,0,0,['Janina','Kevin']])
data_list.append([datetime.datetime(2023, 2, 25),2023,"Brno","Czech Republic","Brno HL.N",'Wien','Austria',"Wien HBF",1,0,0,['Janina','Kevin']])
data_list.append([datetime.datetime(2023, 3, 3),2023,"Wien","Austria","Wien Praterstern",'Schwechat','Austria',"Wien Flughafen",0,0,0,[]])
data_list.append([datetime.datetime(2023, 3, 4),2023,"Lissabon","Portugal","Lisboa Cais do Sodre","Belem","Portugal","",0,0,0,[]])
data_list.append([datetime.datetime(2023, 3, 4),2023,"Belem","Portugal","","Lissabon","Portugal","Lisboa Cais do Sodre",0,0,0,[]])
data_list.append([datetime.datetime(2023, 3, 4),2023,"Lissabon","Portugal","Lisboa Entrecampos","Tunes","Portugal","",1,0,1,[]])
data_list.append([datetime.datetime(2023, 3, 4),2023,"Tunes","Portugal","","Lagos","Portugal","",0,1,0,[]])
data_list.append([datetime.datetime(2023, 3, 5),2023,"Lagos","Portugal","","Lagos","Portugal","",0,0,1,[]])
data_list.append([datetime.datetime(2023, 3, 5),2023,"Portimao","Portugal","","Lagos","Portugal","",0,0,0,[]])
data_list.append([datetime.datetime(2023, 3, 6),2023,"Lagos","Portugal","","Tunes","Portugal","",0,1,0,[]])
data_list.append([datetime.datetime(2023, 3, 6),2023,"Tunes","Portugal","","Lissabon","Portugal","Lisboa Entrecampos",1,0,1,[]])
data_list.append([datetime.datetime(2023, 3, 7),2023,"Lissabon","Portugal","Lisboa Entrecampos","Sintra","Portugal","",1,0,0,[]])
data_list.append([datetime.datetime(2023, 3, 7),2023,"Cascais","Portugal","","Lissabon","Portugal","Lisboa Cais do Sodre",0,0,0,[]])
data_list.append([datetime.datetime(2023, 3, 8),2023,"Lissabon","Portugal","Lisboa Entrecampos","Lissabon","Portugal","Lisboa Oriente",0,1,0,[]])
data_list.append([datetime.datetime(2023, 3, 8),2023,"Lissabon","Portugal","Lisboa Oriente","Tomar","Portugal","",0,0,1,[]])
data_list.append([datetime.datetime(2023, 3, 8),2023,"Tomar","Portugal","","Lissabon","Portugal","Lisboa Santa Apolonia",0,0,0,[]])
data_list.append([datetime.datetime(2023, 3, 9),2023,"Lissabon","Portugal","Lisboa Entrecampos","Queluz","Portugal","Queluz-Belas",0,0,0,[]])
data_list.append([datetime.datetime(2023, 3, 9),2023,"Queluz","Portugal","Queluz-Belas","Sintra","Portugal","",0,0,0,[]])
data_list.append([datetime.datetime(2023, 3, 9),2023,"Sintra","Portugal","","Lissabon","Portugal","Lisboa Entrecampos",0,0,0,[]])
data_list.append([datetime.datetime(2023, 3, 10),2023,"Lissabon","Portugal","Lisboa Oriente","Porto","Portugal","Porto Campanha",1,0,0,[]])
data_list.append([datetime.datetime(2023, 3, 11),2023,"Porto","Portugal","Porto Sao Bento","Braga","Portugal","",0,0,0,['Artur']])
data_list.append([datetime.datetime(2023, 3, 11),2023,"Braga","Portugal","","Porto","Portugal","Porto Sao Bento",0,0,0,['Artur']])
data_list.append([datetime.datetime(2023, 3, 12),2023,"Porto","Portugal","Porto Sao Bento","Guimaraes","Portugal","",0,0,0,['Artur']])
data_list.append([datetime.datetime(2023, 3, 12),2023,"Guimaraes","Portugal","","Porto","Portugal","Porto Sao Bento",0,0,0,['Artur']])
data_list.append([datetime.datetime(2023, 3, 14),2023,"Porto","Portugal","Porto Campanha","Coimbra","Portugal","Coimbra B",1,0,0,[]])
data_list.append([datetime.datetime(2023, 3, 15),2023,"Coimbra","Portugal","Coimbra B","Lissabon","Portugal","Lisboa Entrecampos",1,0,0,[]])
data_list.append([datetime.datetime(2023, 3, 19),2023,'Schwechat','Austria',"Wien Flughafen","Wien","Austria","Wien Praterstern",0,0,0,[]])
data_list.append([datetime.datetime(2023, 4, 28),2023,'Wien','Austria',"Wien HBF","Katowice","Poland","Katowice",1,0,0,[]])
data_list.append([datetime.datetime(2023, 4, 29),2023,"Katowice","Poland","Katowice",'Krakau','Poland',"Krakow Glowny",1,0,0,[]])
data_list.append([datetime.datetime(2023, 4, 29),2023,'Krakau','Poland',"Krakow Glowny","Katowice","Poland","Katowice",0,0,0,[]])
data_list.append([datetime.datetime(2023, 4, 30),2023,"Katowice","Poland","Katowice",'Oswiciem','Poland',"",0,0,1,[]])
data_list.append([datetime.datetime(2023, 4, 30),2023,'Oswiciem','Poland',"","Trzebinia","Poland","Katowice",0,1,0,[]])
data_list.append([datetime.datetime(2023, 4, 30),2023,'Trzebinia','Poland',"","Katowice","Poland","Katowice",1,0,1,[]])
data_list.append([datetime.datetime(2023, 4, 30),2023,"Katowice","Poland","Katowice",'Krakau','Poland',"Krakow Glowny",0,0,0,[]])
data_list.append([datetime.datetime(2023, 5, 1),2023,'Krakau','Poland',"Krakow Glowny","Kalwaria Zebrzydowska","Poland","Kalwaria Zebrzydowska Lanckorona",0,0,0,[]])
data_list.append([datetime.datetime(2023, 5, 1),2023,"Kalwaria Zebrzydowska","Poland","Kalwaria Zebrzydowska","Bielsko-Biala","Poland","Bielsko-Biala Glowny",0,1,0,[]])
data_list.append([datetime.datetime(2023, 5, 1),2023,"Bielsko-Biala","Poland","Bielsko-Biala Glowny","Rybnik","Poland","",1,1,1,[]])
data_list.append([datetime.datetime(2023, 5, 1),2023,"Rybnik","Poland","","Wien","Austria","Wien HBF",1,0,1,[]])
data_list.append([datetime.datetime(2023, 5, 21),2023,"Wien","Austria","Wien HBF","Linz",'Austria',"Linz HBF",1,1,0,[]])
data_list.append([datetime.datetime(2023, 5, 21),2023,"Linz","Austria","Linz HBF","Lambach",'Austria',"Lambach Markt",0,0,1,[]])
data_list.append([datetime.datetime(2023, 5, 21),2023,"Lambach","Austria","Lambach Markt","Wels",'Austria',"Wels HBF",0,0,0,[]])
data_list.append([datetime.datetime(2023, 5, 21),2023,"Wels","Austria","Wels HBF","Linz",'Austria',"Linz HBF",0,1,0,[]])
data_list.append([datetime.datetime(2023, 5, 21),2023,"Linz","Austria","Linz HBF","Wien",'Austria',"Wien HBF",1,0,1,[]])
data_list.append([datetime.datetime(2023, 6, 2),2023,"Wien","Austria","Wien Praterstern",'Schwechat','Austria',"Wien Flughafen",0,0,0,[]])
data_list.append([datetime.datetime(2023, 6, 3),2023,"Stockholm","Sweden","Stockholm Central",'Vaesteras','Sweden',"Vaesteras Central",0,1,0,[]])
data_list.append([datetime.datetime(2023, 6, 3),2023,"Vaesteras","Sweden","Vaesteras Central",'Aengelsberg','Sweden',"",0,0,1,[]])
data_list.append([datetime.datetime(2023, 6, 3),2023,'Aengelsberg','Sweden',"","Vaesteras","Sweden","Vaesteras Central",0,1,0,[]])
data_list.append([datetime.datetime(2023, 6, 3),2023,'Vaesteras','Sweden',"Vaesteras Central","Stockholm","Sweden","Stockholm Central",0,0,1,[]])
data_list.append([datetime.datetime(2023, 6, 4),2023,'Solna','Sweden',"Ulriksdal","Rosersberg","Sweden","Rosersberg",0,0,0,[]])
data_list.append([datetime.datetime(2023, 6, 4),2023,'Rosersberg','Sweden',"","Stockholm","Sweden","Stockholm City",0,0,1,[]])
data_list.append([datetime.datetime(2023, 6, 5),2023,"Stockholm","Sweden","Stockholm Central",'Falun','Sweden',"Falun Central",1,0,0,[]])
data_list.append([datetime.datetime(2023, 6, 5),2023,'Falun','Sweden',"Falun Central","Uppsala","Sweden","Uppsala Central",1,0,0,[]])
data_list.append([datetime.datetime(2023, 6, 5),2023,'Uppsala','Sweden',"Uppsala Central","Stockholm","Sweden","Stockholm Central",0,0,1,[]])
data_list.append([datetime.datetime(2023, 6, 6),2023,'Sollentuna','Sweden',"","Maersta","Sweden","",0,0,0,[]])
data_list.append([datetime.datetime(2023, 6, 6),2023,'Schwechat','Austria',"Wien Flughafen","Wien","Austria","Wien Praterstern",0,0,0,[]])
data_list.append([datetime.datetime(2023, 6, 23),2023,"Wien","Austria","Wien Praterstern",'Schwechat','Austria',"Wien Flughafen",0,0,0,[]])
data_list.append([datetime.datetime(2023, 6, 25),2023,'Sofia','Bulgaria',"Sofia","Plovdiv","Bulgaria","Plovdiv",1,0,0,[]])
data_list.append([datetime.datetime(2023, 6, 25),2023,'Plovdiv','Bulgaria',"Plovdiv","Sofia","Bulgaria","Sofia",1,0,0,[]])
data_list.append([datetime.datetime(2023, 6, 26),2023,'Schwechat','Austria',"Wien Flughafen","Wien","Austria","Wien Praterstern",0,0,0,[]])
data_list.append([datetime.datetime(2023, 6, 29),2023,"Wien","Austria","Wien Praterstern",'Schwechat','Austria',"Wien Flughafen",0,0,0,[]])
data_list.append([datetime.datetime(2023, 6, 29),2023,'Schwechat','Austria',"Wien Flughafen","Wien","Austria","Wien Praterstern",0,0,0,['Sophie','Sam']])
data_list.append([datetime.datetime(2023, 7, 21),2023,"Wien","Austria","Wien Praterstern",'Schwechat','Austria',"Wien Flughafen",0,0,0,[]])
data_list.append([datetime.datetime(2023, 7, 21),2023,"Kastrup","Denmark","CPH Lufthavn",'Kopenhagen','Denmark',"Kobenhavn H",0,0,0,[]])
data_list.append([datetime.datetime(2023, 7, 22),2023,'Kopenhagen','Denmark',"Kobenhavn H","Gentofte","Denmark","Jaegersborg",0,0,0,[]])
data_list.append([datetime.datetime(2023, 7, 22),2023,'Gentofte','Denmark',"Jaegersborg","Lyngby","Denmark","Ravnholm",0,0,0,[]])
data_list.append([datetime.datetime(2023, 7, 22),2023,'Klampenborg','Denmark',"Klampenborg","Koege","Denmark","Koege",0,0,0,[]])
data_list.append([datetime.datetime(2023, 7, 23),2023,'Kopenhagen','Denmark',"Kobenhavn H","Helsingor","Denmark","Helsingor",0,0,0,[]])
data_list.append([datetime.datetime(2023, 7, 23),2023,'Helsingborg','Sweden',"Helsingborg C","Lund","Sweden","Lund C",0,0,0,[]])
data_list.append([datetime.datetime(2023, 7, 23),2023,'Lund','Sweden',"Lund C","Malmoe","Sweden","Malmoe C",0,0,0,[]])
data_list.append([datetime.datetime(2023, 7, 23),2023,'Malmoe','Sweden',"Malmoe C","Kastrup","Denmark","CPH Lufthavn",0,0,0,[]])
data_list.append([datetime.datetime(2023, 7, 23),2023,'Schwechat','Austria',"Wien Flughafen","Wien","Austria","Wien Praterstern",0,0,0,[]])
data_list.append([datetime.datetime(2023, 8, 11),2023,"Wien","Austria","Wien Praterstern",'Schwechat','Austria',"Wien Flughafen",0,0,0,[]])
data_list.append([datetime.datetime(2023, 8, 11),2023,"Frankfurt am Main","Germany","Frankfurt Flughafen","Frankfurt am Main","Germany","Frankfurt (Main) HBF",0,0,0,[]])
data_list.append([datetime.datetime(2023, 8, 12),2023,"Frankfurt am Main","Germany","Frankfurt (Main) HBF","Erfurt","Germany","Erfurt HBF",1,1,0,[]])
data_list.append([datetime.datetime(2023, 8, 12),2023,"Erfurt","Germany","Erfurt HBF","Weimar","Germany","Weimar HBF",0,0,1,[]])
data_list.append([datetime.datetime(2023, 8, 12),2023,"Weimar","Germany","Weimar HBF","Erfurt","Germany","Erfurt HBF",0,0,0,[]])
data_list.append([datetime.datetime(2023, 8, 12),2023,"Erfurt","Germany","Erfurt HBF","Naumburg","Germany","Naumburg (Saale) HBF",0,0,0,[]])
data_list.append([datetime.datetime(2023, 8, 12),2023,"Naumburg","Germany","Naumburg (Saale) HBF","Erfurt","Germany","Erfurt HBF",0,0,0,[]])
data_list.append([datetime.datetime(2023, 8, 12),2023,"Erfurt","Germany","Erfurt HBF","Frankfurt am Main","Germany","Frankfurt (Main) HBF",1,0,0,[]])
data_list.append([datetime.datetime(2023, 8, 13),2023,"Frankfurt am Main","Germany","Frankfurt (Main) HBF","Mainz","Germany","Mainz HBF",0,1,0,[]])
data_list.append([datetime.datetime(2023, 8, 13),2023,"Mainz","Germany","Mainz HBF","Bruehl","Germany","",0,0,1,[]])
data_list.append([datetime.datetime(2023, 8, 13),2023,"Bruehl","Germany","","Boppard","Germany","Boppard HBF",0,0,0,[]])
data_list.append([datetime.datetime(2023, 8, 13),2023,"Boppard","Germany","Boppard HBF","St Goar","Germany","",0,0,0,[]])
data_list.append([datetime.datetime(2023, 8, 13),2023,"St Goar","Germany","","Bacharach","Germany","",0,0,0,[]])
data_list.append([datetime.datetime(2023, 8, 13),2023,"Bacharach","Germany","","Frankfurt am Main","Germany","Frankfurt (Main) HBF",0,0,0,[]])
data_list.append([datetime.datetime(2023, 8, 14),2023,"Frankfurt am Main","Germany","Frankfurt (Main) HBF","Darmstadt","Germany","Darmstadt HBF",0,1,0,[]])
data_list.append([datetime.datetime(2023, 8, 14),2023,"Darmstadt","Germany","Darmstadt HBF","Messel","Germany","",0,0,1,[]])
data_list.append([datetime.datetime(2023, 8, 14),2023,"Messel","Germany","","Darmstadt","Germany","Darmstadt HBF",0,1,0,[]])
data_list.append([datetime.datetime(2023, 8, 14),2023,"Darmstadt","Germany","Darmstadt HBF","Frankfurt am Main","Germany","Frankfurt (Main) HBF",0,1,1,[]])
data_list.append([datetime.datetime(2023, 8, 14),2023,"Frankfurt am Main","Germany","Frankfurt (Main) HBF","Limburg an der Lahn","Germany","Limburg (Lahn)",0,1,1,[]])
data_list.append([datetime.datetime(2023, 8, 14),2023,"Limburg an der Lahn","Germany","Limburg (Lahn)","Bad Ems","Germany","",0,0,1,[]])
data_list.append([datetime.datetime(2023, 8, 14),2023,"Bad Ems","Germany","","Limburg an der Lahn","Germany","Limburg (Lahn)",0,0,0,[]])
data_list.append([datetime.datetime(2023, 8, 14),2023,"Limburg an der Lahn","Germany","Limburg (Lahn)","Frankfurt am Main","Germany","Frankfurt (Main) HBF",0,0,1,[]])
data_list.append([datetime.datetime(2023, 8, 15),2023,"Frankfurt am Main","Germany","Frankfurt (Main) HBF","Kassel","Germany","Kassel-Wilhelmshoehe",0,1,0,[]])
data_list.append([datetime.datetime(2023, 8, 15),2023,"Kassel","Germany","Kassel-Wilhelmshoehe","Fulda","Germany","Fulda HBF",1,1,0,[]])
data_list.append([datetime.datetime(2023, 8, 15),2023,"Fulda","Germany","Fulda HBF","Wuerzburg","Germany","Wuerzburg HBF",1,0,1,[]])
data_list.append([datetime.datetime(2023, 8, 15),2023,"Wuerzburg","Germany","Wuerzburg HBF","Frankfurt am Main","Germany","Frankfurt (Main) Sued",0,0,0,[]])
data_list.append([datetime.datetime(2023, 8, 15),2023,"Frankfurt am Main","Germany","Frankfurt (Main) HBF","Frankfurt am Main","Germany","Frankfurt Flughafen",0,0,0,[]])
data_list.append([datetime.datetime(2023, 8, 15),2023,'Schwechat','Austria',"Wien Flughafen","Wien","Austria","Wien Praterstern",0,0,0,[]])
data_list.append([datetime.datetime(2023, 9, 4),2023,'Elsbethen','Austria',"Salzburg Sued","Salzburg","Austria","Salzburg HBF",0,1,0,[]])
data_list.append([datetime.datetime(2023, 9, 4),2023,"Salzburg","Austria","Salzburg HBF",'Wien','Austria',"Wien HBF",1,0,1,[]])
data_list.append([datetime.datetime(2023, 9, 9),2023,'Wien','Austria',"Wien Leopoldau","Breclav","Czech Republic","",0,1,0,['Grace']])
data_list.append([datetime.datetime(2023, 9, 9),2023,"Breclav","Czech Republic","",'Brno','Czech Republic',"Brno HL.N",1,0,1,['Grace']])
data_list.append([datetime.datetime(2023, 9, 9),2023,'Brno','Czech Republic',"Brno HL.N",'Wien','Austria',"Wien HBF",1,0,0,["Grace"]])
data_list.append([datetime.datetime(2023, 9, 24),2023,'Wien','Austria',"Wien Praterstern",'Znojmo','Czech Republic',"Znojmo",0,0,0,[]])
data_list.append([datetime.datetime(2023, 9, 24),2023,'Znojmo','Czech Republic',"Znojmo",'Wien','Austria',"Wien Florisdorf",0,0,0,[]])
data_list.append([datetime.datetime(2023, 10, 1),2023,"Wien","Austria","Wien HBF","Bratislava","Slovakia","Bratislava HS",0,0,0,["Bing"]])
data_list.append([datetime.datetime(2023, 10, 1),2023,"Bratislava","Slovakia","Bratislava HS","Trencin","Slovakia","Trencin",0,0,0,["Bing"]])
data_list.append([datetime.datetime(2023, 10, 1),2023,"Trencin","Slovakia","Trencin","Bratislava","Slovakia","Bratislava HS",0,0,0,["Bing"]])
data_list.append([datetime.datetime(2023, 10, 1),2023,"Bratislava","Slovakia","Bratislava HS","Wien","Austria","Wien Stadlau",0,0,0,["Bing"]])
data_list.append([datetime.datetime(2023, 10, 25),2023,"Wien","Austria","Wien Praterstern",'Schwechat','Austria',"Wien Flughafen",0,0,0,[]])
data_list.append([datetime.datetime(2023, 10, 25),2023,"Stockholm-Arlanda","Sweden","Arlanda Norra","Stockholm","Sweden","Stockholm Central",1,0,0,[]])
data_list.append([datetime.datetime(2023, 10, 26),2023,"Stockholm","Sweden","Stockholm City","Oesmo","Sweden","",0,0,0,[]])
data_list.append([datetime.datetime(2023, 10, 27),2023,"Nynaeshamn","Sweden","","Stockholm","Sweden","Stockholm City",0,0,0,[]])
data_list.append([datetime.datetime(2023, 10, 29),2023,"Stockholm","Sweden","Stockholm Central","Alvesta","Sweden","",1,1,0,[]])
data_list.append([datetime.datetime(2023, 10, 29),2023,"Alvesta","Sweden","","Emmaboda","Sweden","",0,1,1,[]])
data_list.append([datetime.datetime(2023, 10, 30),2023,"Karlskrona","Sweden","Karlskrona Central","Emmaboda","Sweden","",0,1,0,[]])
data_list.append([datetime.datetime(2023, 10, 30),2023,"Emmaboda","Sweden","","Kalmar","Sweden","Kalmar Central",0,0,1,[]])
data_list.append([datetime.datetime(2023, 10, 31),2023,"Kalmar","Sweden","Kalmar Central","Linkoeping","Sweden","Linkoeping Central",0,1,0,[]])
data_list.append([datetime.datetime(2023, 10, 31),2023,"Linkoeping","Sweden","Linkoeping Central","Stockholm","Sweden","Stockholm Central",1,0,1,[]])
data_list.append([datetime.datetime(2023, 10, 31),2023,"Stockholm","Sweden","Stockholm Central","Stockholm-Arlanda","Sweden","Arlanda Norra",1,0,0,[]])
data_list.append([datetime.datetime(2023, 11, 1),2023,'Schwechat','Austria',"Wien Flughafen","Wien","Austria","Wien Praterstern",0,0,0,[]])
data_list.append([datetime.datetime(2023, 11, 11),2023,"Wien","Austria","Wien Leopoldau","Gaenserndorf","Austria","Bratislava HS",0,1,0,[""]])
data_list.append([datetime.datetime(2023, 11, 11),2023,"Marchegg","Austria","","Bratislava","Slovakia","Bratislava HS",0,1,1,[""]])
data_list.append([datetime.datetime(2023, 11, 11),2023,"Bratislava","Slovakia","Bratislava HS","Leopoldov","Slovakia","",0,1,1,[""]])
data_list.append([datetime.datetime(2023, 11, 11),2023,"Leopoldov","Slovakia","","Nitra","Slovakia","Nitra",0,0,1,[""]])
data_list.append([datetime.datetime(2023, 11, 11),2023,"Nitra","Slovakia","Nitra","Trnava","Slovakia","Trnava",0,0,1,[""]])
data_list.append([datetime.datetime(2023, 11, 11),2023,"Trnava","Slovakia","Trnava","Bratislava","Slovakia","Bratislava HS",0,1,0,[""]])
data_list.append([datetime.datetime(2023, 11, 11),2023,"Bratislava","Slovakia","Bratislava HS","Marchegg","Austria","",0,1,1,[""]])
data_list.append([datetime.datetime(2023, 11, 11),2023,"Lassee","Austria","Schoenfeld-Lassee","Wien","Austria","Wien HBF",0,0,1,[""]])
data_list.append([datetime.datetime(2023, 12, 7),2023,"Wien","Austria","Wien Praterstern",'Schwechat','Austria',"Wien Flughafen",0,0,0,[]])
data_list.append([datetime.datetime(2023, 12, 8),2023,"Genf","Switzerland","Cornavin","Neuchatel","Switzerland","",1,1,0,[]])
data_list.append([datetime.datetime(2023, 12, 8),2023,"Neuchatel","Switzerland","","La-Chaux-de-Fonds","Switzerland","",0,0,1,[]])
data_list.append([datetime.datetime(2023, 12, 8),2023,"La-Chaux-de-Fonds","Switzerland","","Kerzers","Switzerland","",1,1,0,[]])
data_list.append([datetime.datetime(2023, 12, 8),2023,"Kerzers","Switzerland","","Payerne","Switzerland","",0,0,1,[]])
data_list.append([datetime.datetime(2023, 12, 8),2023,"Payerne","Switzerland","","Palezieux","Switzerland","",0,1,0,[]])
data_list.append([datetime.datetime(2023, 12, 8),2023,"Palezieux","Switzerland","","Genf","Switzerland","Cornavin",0,0,1,[]])
data_list.append([datetime.datetime(2023, 12,9),2023,"Genf","Switzerland","Cornavin","Lyon","France","Lyon Part Dieu",0,0,0,['Sasha','Bing']])
data_list.append([datetime.datetime(2023, 12,9),2023,"Lyon","France","Lyon Part Dieu","Genf","Switzerland","Cornavin",0,0,0,['Sasha','Bing']])
data_list.append([datetime.datetime(2023, 12, 10),2023,"Genf","Switzerland","Cornavin","Genf","Switzerland","Geneve Aeroport",1,0,0,[]])
data_list.append([datetime.datetime(2023, 12, 10),2023,'Schwechat','Austria',"Wien Flughafen","Wien","Austria","Wien Praterstern",0,0,0,[]])
data_list.append([datetime.datetime(2023, 12, 22),2023,"Wien","Austria","Wien HBF",'Zuerich','Switzerland',"Zuerich HB",1,0,0,[]])
data_list.append([datetime.datetime(2023, 12, 22),2023,"Zuerich","Switzerland","Zuerich HB",'Baden','Switzerland',"",1,1,0,[]])
data_list.append([datetime.datetime(2023, 12, 22),2023,"Baden","Switzerland","",'Koblenz','Switzerland',"",0,0,1,[]])

# %%
data_list.append([datetime.datetime(2024, 1, 1),2024,"Leipzig","Germany","Leipzig HBF",'Praha','Czech Republic',"Praha HL.N",1,0,0,[]])
data_list.append([datetime.datetime(2024, 1, 1),2024,'Praha','Czech Republic',"Praha HL.N","Wien","Austria","Wien HBF",1,0,0,[]])
data_list.append([datetime.datetime(2024, 1, 24),2024,"Wien","Austria","Wien HBF",'Brennero/Brenner','Italy',"",1,1,0,[]])
data_list.append([datetime.datetime(2024, 1, 24),2024,'Brennero/Brenner','Italy',"","Bolzano/Bozen","Italy","Wien HBF",0,0,1,[]])
data_list.append([datetime.datetime(2024, 1, 25),2024,"Bolzano/Bozen","Italy","",'Trento','Italy',"",0,0,0,[]])
data_list.append([datetime.datetime(2024, 1, 25),2024,'Trento','Italy',"","Bressanone/Brixen","Italy","",0,0,0,[]])
data_list.append([datetime.datetime(2024, 1, 24),2024,"Bressanone/Brixen","Italy","","Bolzano/Bozen","Italy","Wien HBF",0,0,0,[]])
data_list.append([datetime.datetime(2024, 1, 25),2024,"Bolzano/Bozen","Italy","",'Verona','Italy',"Verona Port Nuova",1,0,0,[]])
data_list.append([datetime.datetime(2024, 1, 26),2024,'Verona','Italy',"Verona Port Nuova","Padova","Italy","",0,0,0,[]])
data_list.append([datetime.datetime(2024, 1, 26),2024,"Padova","Italy","",'Verona','Italy',"Verona Port Nuova",0,0,0,[]])
data_list.append([datetime.datetime(2024, 1, 27),2024,'Verona','Italy',"Verona Port Nuova","Bolzano/Bozen","Italy","",1,0,0,[]])
data_list.append([datetime.datetime(2024, 1, 28),2024,"Bolzano/Bozen","Italy","",'Brennero/Brenner','Italy',"",1,1,0,[]])
data_list.append([datetime.datetime(2024, 1, 28),2024,"Brennero/Brenner","Italy","",'Innsbruck','Austria',"Innsbruck HBF",0,1,1,[]])
data_list.append([datetime.datetime(2024, 1, 28),2024,'Innsbruck','Austria',"Innsbruck HBF","Wien","Austria","Wien HBF",1,0,1,[]])
data_list.append([datetime.datetime(2024, 2, 16),2024,"Wien","Austria","Wien HBF",'Villach','Austria',"Villach HBF",1,1,0,[]])
data_list.append([datetime.datetime(2024, 2, 16),2024,'Villach','Austria',"Villach HBF","Udine","Italy","",0,1,1,[]])
data_list.append([datetime.datetime(2024, 2, 16),2024,"Udine","Italy","","Venezia","Italy","Venezia Mestre",0,0,1,[]])
data_list.append([datetime.datetime(2024, 2, 17),2024,"Venezia","Italy","Venezia Mestre","Ferrara","Italy","",0,0,0,[]])
data_list.append([datetime.datetime(2024, 2, 17),2024,"Ferrara","Italy","","Venezia","Italy","Venezia Mestre",0,0,0,[]])
data_list.append([datetime.datetime(2024, 2, 18),2024,"Venezia","Italy","Venezia Mestre","Vicenza","Italy","",0,0,0,[]])
data_list.append([datetime.datetime(2024, 2, 18),2024,"Vicenza","Italy","","Venezia","Italy","Venezia Mestre",0,0,0,[]])
data_list.append([datetime.datetime(2024, 2, 19),2024,"Venezia","Italy","Venezia Mestre","Ferrara","Italy","",0,1,0,[]])
data_list.append([datetime.datetime(2024, 2, 19),2024,"Ferrara","Italy","","Ravenna","Italy","",0,0,1,[]])
data_list.append([datetime.datetime(2024, 2, 19),2024,"Ravenna","Italy","","Ferrara","Italy","",0,1,0,[]])
data_list.append([datetime.datetime(2024, 2, 19),2024,"Ferrara","Italy","","Venezia","Italy","Venezia Mestre",0,0,1,[]])
data_list.append([datetime.datetime(2024, 2, 19),2024,"Venezia","Italy","Venezia Mestre","Venezia","Italy","Venezia St Lucia",0,0,0,[]])
data_list.append([datetime.datetime(2024, 2, 20),2024,"Venezia","Italy","Venezia St Lucia","Wien","Austria","Wien Meidling",1,1,0,[]])
data_list.append([datetime.datetime(2024, 2, 21),2024,"Wien","Austria","Wien Meidling","Wien","Austria","Wien Florisdorf",0,0,1,[]])
data_list.append([datetime.datetime(2024, 3, 23),2024,"Wien","Austria","Wien HBF",'Bruck an der Mur','Austria',"Bruck/Mur",1,1,0,[]])
data_list.append([datetime.datetime(2024, 3, 23),2024,"Bruck an der Mur","Austria","Bruck/Mur",'Gratwein','Austria',"Gratwein-Gratkorn",0,0,1,[]])
data_list.append([datetime.datetime(2024, 3, 23),2024,"Gratwein","Austria","Gratwein-Gratkorn",'Bruck an der Mur','Austria',"Bruck/Mur",0,1,0,[]])
data_list.append([datetime.datetime(2024, 3, 23),2024,"Bruck an der Mur","Austria","Bruck/Mur",'Leoben','Austria',"Leoben HBF",0,0,1,[]])
data_list.append([datetime.datetime(2024, 3, 23),2024,"Leoben","Austria","Leoben HBF",'Bruck an der Mur','Austria',"Bruck/Mur",0,1,0,[]])
data_list.append([datetime.datetime(2024, 3, 23),2024,'Bruck an der Mur','Austria',"Bruck/Mur","Wien","Austria","Wien HBF",1,0,1,[]])
data_list.append([datetime.datetime(2024, 3, 31),2024,"Wien","Austria","Wien Praterstern",'Schwechat','Austria',"Wien Flughafen",0,0,0,[]])
data_list.append([datetime.datetime(2024, 4, 9),2024,'Schwechat','Austria',"Wien Flughafen","Wien","Austria","Wien Praterstern",0,0,0,[]])
data_list.append([datetime.datetime(2024, 4, 24),2024,"Wien","Austria","Wien Praterstern",'Schwechat','Austria',"Wien Flughafen",0,0,0,[]])
data_list.append([datetime.datetime(2024, 4, 25),2024,'Schwechat','Austria',"Wien Flughafen","Wien","Austria","Wien HBF",0,0,0,[]])
data_list.append([datetime.datetime(2024, 4, 30),2024,"Wien","Austria","Wien Praterstern",'Schwechat','Austria',"Wien Flughafen",0,0,0,[]])
data_list.append([datetime.datetime(2024, 4, 30),2024,"London","United Kingdom","Heathrow Terminals 2 & 3",'London','United Kingdom',"Stratford (London)",0,0,0,[]])
data_list.append([datetime.datetime(2024, 5, 1),2024,"London","United Kingdom","Stratford International",'London','United Kingdom',"St Pancras International",0,0,0,[]])
data_list.append([datetime.datetime(2024, 5, 1),2024,"London","United Kingdom","King's Cross",'Durham','United Kingdom',"",1,0,0,[]])
data_list.append([datetime.datetime(2024, 5, 1),2024,"Durham","United Kingdom","",'York','United Kingdom',"",1,0,0,[]])
data_list.append([datetime.datetime(2024, 5, 1),2024,"York","United Kingdom","",'Leeds','United Kingdom',"",1,1,0,[]])
data_list.append([datetime.datetime(2024, 5, 1),2024,"Leeds","United Kingdom","",'Saltaire','United Kingdom',"",1,0,1,[]])
data_list.append([datetime.datetime(2024, 5, 1),2024,"Saltaire","United Kingdom","",'Leeds','United Kingdom',"",1,0,0,[]])
data_list.append([datetime.datetime(2024, 5, 1),2024,"Leeds","United Kingdom","",'London','United Kingdom',"King's Cross",1,1,0,[]])
data_list.append([datetime.datetime(2024, 5, 1),2024,'London','United Kingdom',"St Pancras International","London","United Kingdom","Stratford International",0,0,0,[]])
data_list.append([datetime.datetime(2024, 5, 2),2024,"London","United Kingdom","Stratford",'London','United Kingdom',"Liverpool Street",0,0,0,[]])
data_list.append([datetime.datetime(2024, 5, 2),2024,"London","United Kingdom","Blackfriars",'London','United Kingdom',"St Pancras International",0,0,1,[]])
data_list.append([datetime.datetime(2024, 5, 2),2024,"London","United Kingdom","St Pancras International","Canterbury","United Kingdom","",1,1,0,[]])
data_list.append([datetime.datetime(2024, 5, 2),2024,"Canterbury","United Kingdom","","London","United Kingdom","Standord International",1,0,0,[]])
data_list.append([datetime.datetime(2024, 5, 3),2024,"London","United Kingdom","Stratford",'London','United Kingdom',"Tottenham Court Road",0,0,1,[]])
data_list.append([datetime.datetime(2024, 5, 3),2024,"London","United Kingdom","Euston",'Lancaster','United Kingdom',"",1,1,1,[]])
data_list.append([datetime.datetime(2024, 5, 3),2024,"Lancaster","United Kingdom","",'Windermere','United Kingdom',"",0,1,0,[]])
data_list.append([datetime.datetime(2024, 5, 3),2024,"Windermere","United Kingdom","",'Lancaster','United Kingdom',"",0,0,1,[]])
data_list.append([datetime.datetime(2024, 5, 3),2024,"Lancaster","United Kingdom","Euston",'London','United Kingdom',"Euston",1,1,0,[]])
data_list.append([datetime.datetime(2024, 5, 3),2024,'London','United Kingdom',"Tottenham Court Road","London","United Kingdom","Stratford",0,0,0,[]])
data_list.append([datetime.datetime(2024, 5, 4),2024,"London","United Kingdom","Stratford International",'London','United Kingdom',"St Pancras International",0,1,0,[]])
data_list.append([datetime.datetime(2024, 5, 4),2024,"London","United Kingdom","St Pancras International",'London','United Kingdom',"Blackfriars",0,1,1,[]])
data_list.append([datetime.datetime(2024, 5, 4),2024,"London","United Kingdom","Waterloo Station","Poole","United Kingdom","",1,1,1,[]])
data_list.append([datetime.datetime(2024, 5, 4),2024,"Poole","United Kingdom","","Wool","United Kingdom","",0,0,1,[]])
data_list.append([datetime.datetime(2024, 5, 4),2024,"Wool","United Kingdom","","London","United Kingdom","Waterloo Station",1,0,0,[]])
data_list.append([datetime.datetime(2024, 5, 4),2024,'London','United Kingdom',"Blackfriars","London","United Kingdom","St Pancras International",0,1,0,[]])
data_list.append([datetime.datetime(2024, 5, 4),2024,'London','United Kingdom',"St Pancras International","London","United Kingdom","Stratford International",0,0,1,[]])
data_list.append([datetime.datetime(2024, 5, 5),2024,"Cambridge","United Kingdom","","Ely","United Kingdom","",0,0,0,['Eric','Siyi','May']])
data_list.append([datetime.datetime(2024, 5, 5),2024,"Ely","United Kingdom","","Cambridge","United Kingdom","",0,0,0,['Eric','Siyi','May']])
data_list.append([datetime.datetime(2024, 5, 5),2024,'Schwechat','Austria',"Wien Flughafen","Wien","Austria","Wien HBF",0,0,0,[]])
data_list.append([datetime.datetime(2024, 5, 8),2024,"Wien","Austria","Wien HBF",'Graz','Austria',"Graz HBF",1,1,0,[]])
data_list.append([datetime.datetime(2024, 5, 8),2024,"Graz","Austria","Graz HBF",'Maribor','Slovenia',"Maribor",1,1,1,[]])
data_list.append([datetime.datetime(2024, 5, 8),2024,"Maribor","Slovenia","Maribor",'Ljubljana','Slovenia',"Ljubljana",1,0,1,[]])
data_list.append([datetime.datetime(2024, 5, 10),2024,'Ljubljana','Slovenia',"Ljubljana","Postojna","Slovenia","",0,0,0,[]])
data_list.append([datetime.datetime(2024, 5, 10),2024,"Postojna","Slovenia","",'Ljubljana','Slovenia',"Ljubljana",0,0,0,[]])
data_list.append([datetime.datetime(2024, 5, 11),2024,'Ljubljana','Slovenia',"Ljubljana","Divaca","Slovenia","",0,0,0,[]])
data_list.append([datetime.datetime(2024, 5, 11),2024,"Divaca","Slovenia","",'Ljubljana','Slovenia',"Ljubljana",0,0,0,[]])
data_list.append([datetime.datetime(2024, 5, 12),2024,'Ljubljana','Slovenia',"Ljubljana","Wien","Austria","Wien HBF",0,0,0,[]])
data_list.append([datetime.datetime(2024, 5, 13),2024,"Wien","Austria","Wien HBF",'Leobersdorf','Austria',"",0,0,0,[]])
data_list.append([datetime.datetime(2024, 5, 13),2024,'Leobersdorf','Austria',"","Wien","Austria","Wien HBF",0,0,0,[]])
data_list.append([datetime.datetime(2024, 5, 14),2024,"Wien","Austria","Wien HBF",'Leobersdorf','Austria',"",0,0,0,[]])
data_list.append([datetime.datetime(2024, 5, 14),2024,'Leobersdorf','Austria',"","Wien","Austria","Wien HBF",0,0,0,[]])
data_list.append([datetime.datetime(2024, 5, 17),2024,"Wien","Austria","Wien Praterstern",'Schwechat','Austria',"Wien Flughafen",0,0,0,[]])
data_list.append([datetime.datetime(2024, 5, 21),2024,'Schwechat','Austria',"Wien Flughafen","Wien","Austria","Wien Praterstern",0,0,0,[]])
data_list.append([datetime.datetime(2024, 5, 30),2024,"Wien","Austria","Wien HBF",'Wiener Neustadt','Austria',"Wiener Neustadt HBF",1,1,0,[]])
data_list.append([datetime.datetime(2024, 5, 30),2024,'Wiener Neustadt','Austria',"Wiener Neustadt HBF",'Sopron','Hungary','',0,0,1,[]])
data_list.append([datetime.datetime(2024, 5, 30),2024,"Sopron","Hungary","","Fertoszentmiklos","Hungary","",0,0,1,[]])
data_list.append([datetime.datetime(2024, 5, 30),2024,"Fertoed","Hungary","Fertoszeplka-Fertoed","Wien","Austria","Wien HBF",0,0,0,[]])
data_list.append([datetime.datetime(2024, 5, 31),2024,"Wien","Austria","Wien HBF",'Gloggnitz','Austria',"",0,0,0,[]])
data_list.append([datetime.datetime(2024, 5, 31),2024,"Ternitz","Austria","",'Wien','Austria',"Wien HBF",0,0,0,[]])
data_list.append([datetime.datetime(2024, 6, 2),2024,"Wien","Austria","Wien HBF",'Moedling','Austria',"",0,0,0,[]])
data_list.append([datetime.datetime(2024, 6, 2),2024,'Moedling','Austria',"","Wien","Austria","Wien Meidling",0,0,0,[]])
data_list.append([datetime.datetime(2024, 6, 8),2024,"Wien","Austria","Wien Heiligenstadt",'Schwarzenau im Weinviertel','Austria',"",0,0,0,[]])
data_list.append([datetime.datetime(2024, 6, 8),2024,'Schwarzenau im Weinviertel','Austria',"","Wien","Austria","Wien Heiligenstadt",0,0,0,[]])
data_list.append([datetime.datetime(2024, 6, 22),2024,"Wien","Austria","Wien Heiligenstadt",'Wagram am Wagram','Austria',"Wagram-Grafenegg",0,0,0,[]])
data_list.append([datetime.datetime(2024, 6, 22),2024,'Wagram am Wagram','Austria',"Wagram-Grafenegg","Krems an der Donau","Austria","Krems(Donau)",0,0,0,[]])
data_list.append([datetime.datetime(2024, 6, 22),2024,"Traismauer","Austria","",'Judenau','Austria',"Tullnerfeld",0,1,0,[]])
data_list.append([datetime.datetime(2024, 6, 22),2024,'Judenau','Austria',"Tullnerfeld","Wien","Austria","Wien Westbahnhof",0,0,1,[]])
data_list.append([datetime.datetime(2024, 6, 23),2024,'Wien','Austria',"Wien HBF","St Poelten","Austria","St Poelten HBF",1,1,0,[]])
data_list.append([datetime.datetime(2024, 6, 23),2024,"St Poelten","Austria","St Poelten HBF",'Poechlarn','Austria',"",0,1,1,[]])
data_list.append([datetime.datetime(2024, 6, 23),2024,'Poechlarn','Austria',"","Scheibbs","Austria","",0,0,1,[]])
data_list.append([datetime.datetime(2024, 6, 23),2024,"Scheibbs","Austria","",'Poechlarn','Austria',"",0,1,0,[]])
data_list.append([datetime.datetime(2024, 6, 23),2024,'Poechlarn','Austria',"","Melk","Austria","",0,0,1,[]])
data_list.append([datetime.datetime(2024, 6, 23),2024,'Melk','Austria',"","St Poelten","Austria","St Poelten HBF",0,1,0,[]])
data_list.append([datetime.datetime(2024, 6, 23),2024,"St Poelten","Austria","St Poelten HBF",'Wien','Austria',"Wien HBF",1,0,1,[]])
data_list.append([datetime.datetime(2024, 6, 29),2024,'Wien','Austria',"Wien HBF","St Poelten","Austria","St Poelten HBF",1,1,0,[]])
data_list.append([datetime.datetime(2024, 6, 29),2024,"St Poelten","Austria","St Poelten HBF",'Melk','Austria',"",0,1,1,[]])
data_list.append([datetime.datetime(2024, 6, 29),2024,'Krems an der Donau','Austria',"Krems(Donau)","St Poelten","Austria","St Poelten HBF",0,1,0,[]])
data_list.append([datetime.datetime(2024, 6, 29),2024,"St Poelten","Austria","St Poelten HBF",'Wien','Austria',"Wien HBF",1,0,1,[]])
data_list.append([datetime.datetime(2024, 7, 6),2024,'Wien','Austria',"Wien Spittelau","Wien","Austria","Wien Franz Josefs Bahnhof",1,1,0,[]])
data_list.append([datetime.datetime(2024, 7, 6),2024,'Wien','Austria',"Wien Franz Josefs Bahnhof",'Hadersdorf','Austria',"",0,1,1,[]])
data_list.append([datetime.datetime(2024, 7, 6),2024,'Hadersdorf','Austria',"","Rosenburg","Austria","Rosenburg(Kamp)",0,0,1,[]])
data_list.append([datetime.datetime(2024, 7, 6),2024,'Goepfritz an der Wild','Austria',"Goepfritz (Wild)","Wien","Austria","Spittelau",0,0,0,[]])
data_list.append([datetime.datetime(2024, 7, 13),2024,"Wien","Austria","Wien HBF","Wien","Austria","Wien Meidling",1,0,0,[]])
data_list.append([datetime.datetime(2024, 7, 13),2024,"Wien","Austria","Wien Meidling","Wien","Austria","Wien Quartier Belvedere",0,1,0,[]])
data_list.append([datetime.datetime(2024, 7, 13),2024,"Wien","Austria","Wien Quartier Belvedere","Wien","Austria","Wien Praterstern",0,0,1,[]])
data_list.append([datetime.datetime(2024, 7, 13),2024,'Wien','Austria',"Wien Spittelau","Tulln","Austria","Tulln(Donau)",0,1,0,[]])
data_list.append([datetime.datetime(2024, 7, 13),2024,"Tulln","Austria","Tulln(Donau)",'Zeiselmauer','Austria',"Zeiselmauer-Koenigstetten",0,0,1,[]])
data_list.append([datetime.datetime(2024, 7, 13),2024,'Zeiselmauer','Austria',"Zeiselmauer-Koenigstetten","Tulln","Austria","Tulln(Donau)",0,0,1,[]])
data_list.append([datetime.datetime(2024, 7, 13),2024,"Tulln","Austria","Tulln(Donau) Stadt",'Judenau','Austria',"Tullnerfeld",0,1,0,[]])
data_list.append([datetime.datetime(2024, 7, 13),2024,'Judenau','Austria',"Tullnerfeld","Wien","Austria","Wien HBF",1,0,1,[]])
data_list.append([datetime.datetime(2024, 7, 20),2024,'Wien','Austria',"Wien HBF","Feldkirch","Austria","",1,1,0,[]])
data_list.append([datetime.datetime(2024, 7, 20),2024,"Feldkirch","Austria","",'Dornbirn','Austria',"",1,0,1,[]])
data_list.append([datetime.datetime(2024, 7, 20),2024,'Dornbirn','Austria',"","Wien","Austria","Wien HBF",1,0,0,[]])
data_list.append([datetime.datetime(2024, 8, 2),2024,'Wien','Austria',"Wien HBF","Feldkirch","Austria","",1,1,0,[]])
data_list.append([datetime.datetime(2024, 8, 21),2024,'Feldkirch','Austria',"","Wien","Austria","Wien HBF",1,0,1,[]])
data_list.append([datetime.datetime(2024, 8, 29),2024,"Wien","Austria","Wien Praterstern",'Schwechat','Austria',"Wien Flughafen",0,0,0,[]])
data_list.append([datetime.datetime(2024, 8, 30),2024,"Stansted","United Kingdom","Stansted Airport","London","United Kingdom","Liverpool Street",1,0,0,[]])
data_list.append([datetime.datetime(2024, 8, 30),2024,'London',"United Kingdom","Waterloo Station","Salisbury","United Kingdom","",1,0,0,['Artur']])
data_list.append([datetime.datetime(2024, 8, 30),2024,'Salisbury',"United Kingdom","","Bath","United Kingdom","Bath Spa",1,0,0,['Artur']])
data_list.append([datetime.datetime(2024, 8, 30),2024,'Bath',"United Kingdom","Bath Spa","London","United Kingdom","Paddington",1,0,0,['Artur']])
data_list.append([datetime.datetime(2024, 8, 30),2024,'London',"United Kingdom","Paddington","London","United Kingdom","Liverpool Street",0,0,0,['Artur']])
data_list.append([datetime.datetime(2024, 8, 31),2024,'London',"United Kingdom","Liverpool Street","London","United Kingdom","Paddington",0,0,0,['Artur']])
data_list.append([datetime.datetime(2024, 8, 30),2024,'London',"United Kingdom","Paddington","Oxford","United Kingdom","",1,0,0,['Artur']])
data_list.append([datetime.datetime(2024, 8, 30),2024,'Oxford',"United Kingdom","","London","United Kingdom","Paddington",1,0,0,['Artur']])
data_list.append([datetime.datetime(2024, 8, 30),2024,'London',"United Kingdom","Paddington","London","United Kingdom","Liverpool Street",0,0,0,['Artur']])
data_list.append([datetime.datetime(2024, 9, 1),2024,'London',"United Kingdom","Victoria","London","United Kingdom","Clapham Junction",1,1,0,['Artur']])
data_list.append([datetime.datetime(2024, 9, 1),2024,"London","United Kingdom","Clapham Junction",'London',"United Kingdom","Hampton Court",1,0,1,['Artur']])
data_list.append([datetime.datetime(2024, 9, 1),2024,'London',"United Kingdom","Hampton Court","London","United Kingdom","Wimbledon",0,1,0,['Artur']])
data_list.append([datetime.datetime(2024, 9, 1),2024,'London',"United Kingdom","Wimbledon","St Albans","United Kingdom","St Albans City",0,0,1,['Artur']])
data_list.append([datetime.datetime(2024, 9, 1),2024,"St Albans","United Kingdom","St Albans City",'London',"United Kingdom","West Hampstead Thameslink",0,1,0,['Artur']])
data_list.append([datetime.datetime(2024, 9, 1),2024,'London',"United Kingdom","West Hampstead","London","United Kingdom","Kew Gardens",0,0,1,['Artur']])
data_list.append([datetime.datetime(2024, 9, 1),2024,"London","United Kingdom","Kew Gardens",'London',"United Kingdom","Highbury & Islington",0,1,0,['Artur']])
data_list.append([datetime.datetime(2024, 9, 1),2024,'London',"United Kingdom","Highbury & Islington","London","United Kingdom","Old Street",0,0,1,['Artur']])
data_list.append([datetime.datetime(2024, 9, 2),2024,'London',"United Kingdom","London Bridge","Brighton","United Kingdom","",1,0,0,['Artur']])
data_list.append([datetime.datetime(2024, 9, 2),2024,"Brighton","United Kingdom","",'London',"United Kingdom","Farringdon",1,1,0,['Artur']])
data_list.append([datetime.datetime(2024, 9, 2),2024,"London","United Kingdom","Farringdon",'London',"United Kingdom","Paddington",0,0,1,['Artur']])
data_list.append([datetime.datetime(2024, 9, 2),2024,"London","United Kingdom","Liverpool Street","Stansted","United Kingdom","Stansted Airport",1,0,0,[]])
data_list.append([datetime.datetime(2024, 9, 3),2024,'Schwechat','Austria',"Wien Flughafen","Wien","Austria","Wien Praterstern",0,0,0,[]])
data_list.append([datetime.datetime(2024, 9, 13),2024,"Wien","Austria","Wien Praterstern",'Schwechat','Austria',"Wien Flughafen",0,0,0,[]])
data_list.append([datetime.datetime(2024,9, 13),2024,"Schiphol","Netherlands","Schiphol Airport","Weesp","Netherlands","",0,0,0,[]])
data_list.append([datetime.datetime(2024,9, 13),2024,"Amsterdam","Netherlands","Amsterdam Bijlmer ArenA","Utrecht","Netherlands","Utrecht Centraal",1,0,0,[]])
data_list.append([datetime.datetime(2024,9, 13),2024,"Utrecht","Netherlands","Utrecht Centraal","Rotterdam","Netherlands","Rotterdam Centraal",1,0,0,[]])
data_list.append([datetime.datetime(2024,9, 14),2024,"Rotterdam","Netherlands","Rotterdam Centraal","Den Haag","Netherlands","Den Haag Centraal",1,0,0,[]])
data_list.append([datetime.datetime(2024,9, 14),2024,"Den Haag","Netherlands","Den Haag Centraal","Rotterdam","Netherlands","Rotterdam Centraal",1,0,0,[]])
data_list.append([datetime.datetime(2024,9, 15),2024,"Rotterdam","Netherlands","Rotterdam Centraal","Amsterdam","Netherlands","Amsterdam Centraal",1,0,0,[]])
data_list.append([datetime.datetime(2024,9, 15),2024,"Amsterdam","Netherlands","Amsterdam Centraal","Rotterdam","Netherlands","Rotterdam Centraal",1,0,0,[]])
data_list.append([datetime.datetime(2024,9, 16),2024,"Rotterdam","Netherlands","Rotterdam Centraal","Schiphol","Netherlands","Schiphol Airport",1,0,0,[]])
data_list.append([datetime.datetime(2024, 9, 16),2024,'Schwechat','Austria',"Wien Flughafen","Wien","Austria","Wien Praterstern",0,0,0,[]])

# %%
df = pd.DataFrame(data_list,columns=['Date','Year', 'Origin', 'Origin Country','Origin Station','Destination','Destination Country','Destination Station',"High Speed Train",'End Transfer Station','Start Transfer Station','Co-Travellers'])
df["Number of Co-Travellers"]=df["Co-Travellers"].str.len()
df.to_csv("../data/Trains_StationInfo.csv")
df
# Out:
#            Date  Year     Origin Origin Country      Origin Station  \
# 0    1984-08-18  1984   Waldshut        Germany
# 1    1984-08-18  1984    Koblenz    Switzerland
# 2    1984-08-21  1984   Waldshut        Germany
# 3    1984-08-21  1984      Basel    Switzerland        Basel Bad BF
# 4    1985-08-17  1985   Waldshut        Germany
# ...         ...   ...        ...            ...                 ...
# 2190 2024-09-14  2024   Den Haag    Netherlands   Den Haag Centraal
# 2191 2024-09-15  2024  Rotterdam    Netherlands  Rotterdam Centraal
# 2192 2024-09-15  2024  Amsterdam    Netherlands  Amsterdam Centraal
# 2193 2024-09-16  2024  Rotterdam    Netherlands  Rotterdam Centraal
# 2194 2024-09-16  2024  Schwechat        Austria      Wien Flughafen
#
#      Destination Destination Country Destination Station  High Speed Train  \
# 0        Koblenz         Switzerland                                     0
# 1       Waldshut             Germany                                     0
# ...

# %%
df_station=df.loc[(df['Origin Station'].notna())].groupby("Origin").agg(
    N_orig_stations=('Origin Station','nunique'),
    orig_stations=('Origin Station','unique')
).reset_index()
df_dest_stat=df.loc[(df['Destination Station'].notna())].groupby("Destination").agg(
    N_dest_stations=('Destination Station','nunique'),
    destination_stations=('Destination Station','unique')
).reset_index()
df_station=df_station.merge(df_dest_stat,how="outer",left_on= ['Origin'],right_on=['Destination'])

df_station.loc[(df_station['Origin'].notna()),'Place']=df_station.loc[(df_station['Origin'].notna()),'Origin']
df_station.loc[(df_station['Origin'].isna()),'Place']=df_station.loc[(df_station['Origin'].isna()),'Destination']
df_station["N_orig_stations"]=df_station["N_orig_stations"].fillna(0).astype(int)
df_station["N_dest_stations"]=df_station["N_dest_stations"].fillna(0).astype(int)

# %%
df_station.head(50)
# Out:
#                Origin  N_orig_stations  \
# 0              Aachen                1
# 1              Aargau                1
# 2         Aengelsberg                1
# 3               Aigle                1
# 4                Albi                1
# 5   Alcala de Henares                1
# 6              Alfeld                1
# 7            Althofen                1
# 8             Alvesta                1
# 9              Amiens                1
# 10          Amsterdam                4
# 11          Amstetten                1
# 12             Anagni                1
# 13             Ancona                1
# 14          Andermatt                1
# 15          Antequera                1
# 16          Antwerpen                1
# 17          Apeldoorn                1
# 18           Aranjuez                1
# 19         Argentiere                1
# 20              Arles                1
# 21              Arras                1
# 22        Arth-Goldau                1
# ...

# %%
df.groupby("Year").agg(trainrides_per_year=('Origin','count')).reset_index()
# Out:
#     Year  trainrides_per_year
# 0   1984                    4
# 1   1985                    2
# 2   1987                    4
# 3   1989                    2
# 4   1990                    2
# 5   1991                    2
# 6   1996                    4
# 7   1997                    9
# 8   1998                    4
# 9   2000                   12
# 10  2001                    6
# 11  2004                    9
# 12  2005                   21
# 13  2006                   15
# 14  2007                   26
# 15  2008                   56
# 16  2009                   91
# 17  2010                  117
# 18  2011                   77
# 19  2012                   83
# 20  2013                   86
# 21  2014                  106
# 22  2015                  138
# 23  2016                  156
# 24  2017                  133
# 25  2018                  172
# 26  2019                  131
# 27  2020                   97
# 28  2021                  134
# 29  2022                  190
# ...

# %%
df.groupby(["Year","Origin Country"]).agg(trainrides_per_year_and_country=('Origin','count')).reset_index()
# Out:
#      Year  Origin Country  trainrides_per_year_and_country
# 0    1984         Germany                                2
# 1    1984     Switzerland                                2
# 2    1985         Germany                                1
# 3    1985     Switzerland                                1
# 4    1987         Germany                                2
# ..    ...             ...                              ...
# 128  2024         Hungary                                2
# 129  2024           Italy                               21
# 130  2024     Netherlands                                8
# 131  2024        Slovenia                                6
# 132  2024  United Kingdom                               49
#
# [133 rows x 3 columns]

# %%
df_agg_y_oc=df.groupby(["Year","Origin Country"]).agg(trainrides_per_year_and_country=('Origin','count')).sort_values(
    by="trainrides_per_year_and_country",ascending=False).reset_index()
df_agg_y_oc_diff= df.loc[(df["Origin Country"]!=df['Destination Country'])].groupby(
    ["Year","Destination Country"]).agg(trainrides_diff_per_year_and_country=("Origin",'count')
                              ).reset_index().rename(columns={"Destination Country": "Origin Country"})
df_agg_y_oc=df_agg_y_oc.merge(df_agg_y_oc_diff,on=["Origin Country",'Year'],how='outer')
df_agg_y_oc['trainrides_per_year_and_country']=df_agg_y_oc['trainrides_per_year_and_country'].fillna(0).astype(int)
df_agg_y_oc['trainrides_diff_per_year_and_country']=df_agg_y_oc['trainrides_diff_per_year_and_country'].fillna(0).astype(int)
df_agg_y_oc['trainrides_per_year_and_country']=(df_agg_y_oc['trainrides_per_year_and_country']+df_agg_y_oc['trainrides_diff_per_year_and_country']).astype(int)
df_agg_y_oc=df_agg_y_oc.drop(columns="trainrides_diff_per_year_and_country").rename(
    columns={"Origin Country": "Country"})
df_agg_y_oc.sort_values(by='trainrides_per_year_and_country',ascending=False).reset_index(drop=True).head(50)
# Out:
#     Year         Country  trainrides_per_year_and_country
# 0   2010     Switzerland                              101
# 1   2021         Austria                               86
# 2   2009     Switzerland                               82
# 3   2011     Switzerland                               75
# 4   2024         Austria                               74
# 5   2018     Switzerland                               70
# 6   2022         Austria                               67
# 7   2016     Switzerland                               67
# 8   2017     Switzerland                               66
# 9   2019     Switzerland                               65
# 10  2020     Switzerland                               65
# 11  2008     Switzerland                               50
# 12  2024  United Kingdom                               49
# 13  2012     Switzerland                               45
# 14  2016           Japan                               43
# ...

# %%
df_agg_y_oc['trainrides_per_year_and_country']=df_agg_y_oc['trainrides_per_year_and_country'].astype(int)
df_agg_y_oc.loc[(df_agg_y_oc['Year']==2024)].sort_values(
    by='trainrides_per_year_and_country',ascending=False).reset_index(drop=True).head(50)
# Out:
#    Year         Country  trainrides_per_year_and_country
# 0  2024         Austria                               74
# 1  2024  United Kingdom                               49
# 2  2024           Italy                               23
# 3  2024     Netherlands                                8
# 4  2024        Slovenia                                7
# 5  2024         Hungary                                3
# 6  2024  Czech Republic                                2
# 7  2024         Germany                                1

# %%
df_agg_y_oc.loc[(df_agg_y_oc['Year']==2023)].sort_values(
    by='trainrides_per_year_and_country',ascending=False).reset_index(drop=True).head(50)
# Out:
#     Year         Country  trainrides_per_year_and_country
# 0   2023         Austria                               39
# 1   2023         Germany                               26
# 2   2023        Portugal                               23
# 3   2023          Sweden                               23
# 4   2023     Switzerland                               15
# 5   2023          Poland                               11
# 6   2023        Slovakia                               10
# 7   2023  Czech Republic                                9
# 8   2023         Denmark                                6
# 9   2023        Bulgaria                                2
# 10  2023          France                                2

# %%
df_agg=df.groupby("Origin Country").agg(trainrides_country=('Origin','count')).sort_values(by="trainrides_country",ascending=False).reset_index()

# %%
df_agg_diff= df.loc[(df["Origin Country"]!=df['Destination Country'])].groupby(
    "Destination Country").agg(trainrides_diff=("Origin",'count')
                              ).reset_index().rename(columns={"Destination Country": "Origin Country"})
df_agg_diff
# Out:
#     Origin Country  trainrides_diff
# 0          Austria               34
# 1          Belgium                2
# 2   Czech Republic               13
# 3          Denmark                1
# 4           France               20
# 5          Germany               28
# 6          Hungary                6
# 7            Italy               16
# 8        Luxemburg                2
# 9           Monaco                1
# 10          Poland                2
# 11        Slovakia                4
# 12        Slovenia                1
# 13     Switzerland               53

# %%
df_agg=df_agg.merge(df_agg_diff,on="Origin Country",how='outer')
df_agg['trainrides_country']=df_agg['trainrides_country'].fillna(0).astype(int)
df_agg['trainrides_diff']=df_agg['trainrides_diff'].fillna(0).astype(int)
df_agg['trainrides_country']=df_agg['trainrides_country']+df_agg['trainrides_diff']
df_agg=df_agg.drop(columns="trainrides_diff").rename(columns={"Origin Country": "Country"})
df_agg.sort_values(by='trainrides_country',ascending=False).reset_index(drop=True)
# Out:
#            Country  trainrides_country
# 0      Switzerland                 901
# 1          Germany                 286
# 2          Austria                 285
# 3            Italy                 221
# 4   United Kingdom                 133
# 5           France                 132
# 6            Spain                  77
# 7   Czech Republic                  45
# 8           Sweden                  43
# 9            Japan                  43
# 10        Portugal                  43
# 11          Poland                  27
# 12         Belgium                  24
# 13     Netherlands                  21
# 14         Hungary                  18
# 15         Denmark                  17
# 16          Russia                  13
# 17        Slovakia                  13
# 18           China                  10
# 19        Slovenia                   7
# 20       Luxemburg                   6
# 21             USA                   4
# 22     South Korea                   3
# ...

# %%
df_agg_hs=df.loc[(df["High Speed Train"]==1)].groupby("Origin Country").agg(trainrides_country_hs=('Origin','count')
                                          ).sort_values(by="trainrides_country_hs",ascending=False).reset_index()
df_agg_diff_hs= df.loc[(df["High Speed Train"]==1) &(df["Origin Country"]!=df['Destination Country'])].groupby(
    "Destination Country").agg(trainrides_diff_hs=("Origin",'count')
                              ).reset_index().rename(columns={"Destination Country": "Origin Country"})
df_agg_hs=df_agg_hs.merge(df_agg_diff_hs,on="Origin Country",how='outer')
df_agg_hs['trainrides_country_hs']=df_agg_hs['trainrides_country_hs'].fillna(0).astype(int)
df_agg_hs['trainrides_diff_hs']=df_agg_hs['trainrides_diff_hs'].fillna(0).astype(int)
df_agg_hs['trainrides_country_hs']=df_agg_hs['trainrides_country_hs']+df_agg_hs['trainrides_diff_hs']
df_agg_hs=df_agg_hs.drop(columns="trainrides_diff_hs").rename(columns={"Origin Country": "Country"})
df_agg_hs.sort_values(by='trainrides_country_hs',ascending=False)
# Out:
#            Country  trainrides_country_hs
# 0      Switzerland                    412
# 1          Austria                    113
# 2            Italy                     75
# 3          Germany                     70
# 5           France                     46
# 4            Spain                     43
# 6   United Kingdom                     31
# 8   Czech Republic                     25
# 7      Netherlands                     18
# 9           Poland                     17
# 11         Belgium                     13
# 10           Japan                     13
# 12        Portugal                      9
# 13           China                      8
# 14          Sweden                      8
# 15         Hungary                      7
# 16     South Korea                      3
# 17         Denmark                      2
# 18          Russia                      2
# 19        Bulgaria                      2
# 20        Slovenia                      2

# %%
string_traveller="Riju"
#df_test[(df_test['Co-Travellers'].str.contains('Rachel'))]
df["flag"]=0
#df_test["flag"]=np.where("")
for ind,test in enumerate(df['Co-Travellers'].values):
    if string_traveller in test:
        df.iloc[ind,df.columns.get_loc("flag")]=1
print(len(df.loc[df['flag']==1]))
df.loc[df['flag']==1].head(55)
# Out:
# 68
#            Date  Year                Origin  Origin Country  \
# 883  2016-03-28  2016             Barcelona           Spain
# 884  2016-03-28  2016              Zaragoza           Spain
# 974  2016-11-25  2016                  Genf     Switzerland
# 975  2016-11-26  2016                Milano           Italy
# 976  2016-11-27  2016               Mantova           Italy
# 977  2016-11-27  2016                Verona           Italy
# 1043 2017-02-10  2017              Zaventem         Belgium
# 1047 2016-02-12  2016                  Gent         Belgium
# 1048 2017-02-12  2017             Antwerpen         Belgium
# 1135 2017-09-06  2017             Fiumicino           Italy
# 1136 2017-09-11  2017                   Rom           Italy
# 1137 2017-09-15  2017               Gatwick  United Kingdom
# 1138 2017-09-17  2017         London Bridge  United Kingdom
# 1139 2017-09-18  2017                London  United Kingdom
# 1145 2017-10-15  2017                  Genf     Switzerland
# ...

# %%
df[(df['Date'].dt.year>1980)].groupby(pd.Grouper(key="Date", freq="1M")).count()["Origin"].plot(
    title="Train Rides per Month",figsize=(15,5),
    ylabel="Train Rides",ylim=(0,60))
# Out:
# <AxesSubplot: title={'center': 'Train Rides per Month'}, xlabel='Date', ylabel='Train Rides'>

# %%
df[(df['Date'].dt.year>2006)].groupby(pd.Grouper(key="Date", freq="1M")).count()["Origin"].plot(
    title="Train Rides per Month (2006+)",figsize=(15,5),
    ylabel="Train Rides",ylim=(0,60))
# Out:
# <AxesSubplot: title={'center': 'Train Rides per Month (2006+)'}, xlabel='Date', ylabel='Train Rides'>

# %%
df[(df['Date'].dt.year>2006)].groupby(pd.Grouper(key="Date", freq="1W")).count()["Origin"].plot(
    title="Train Rides per Week",figsize=(20,5),
    ylabel="Train Rides",ylim=(0,40))
# Out:
# <AxesSubplot: title={'center': 'Train Rides per Week'}, xlabel='Date', ylabel='Train Rides'>

# %%
df[(df['Date'].dt.year>1990)].groupby(pd.Grouper(key="Date", freq="1D")).count()["Origin"].sort_values()
# Out:
# Date
# 2009-12-04     0
# 2014-02-08     0
# 2014-02-09     0
# 2014-02-10     0
# 2014-02-11     0
#               ..
# 2022-06-17     9
# 2022-06-16     9
# 2016-12-15     9
# 2009-08-30    10
# 2022-12-28    10
# Name: Origin, Length: 10251, dtype: int64

# %%
df[(df['Date'].dt.year>1990)].groupby(pd.Grouper(key="Date", freq="1D")).count()["Origin"].plot(
    title="Train Rides per Day",figsize=(15,5),
    ylabel="Train Rides",ylim=(0,20))
# Out:
# <AxesSubplot: title={'center': 'Train Rides per Day'}, xlabel='Date', ylabel='Train Rides'>

# %%
string_traveller="Riju"
df["flag"]=0
train_counter=0
for ind,test in enumerate(df['Co-Travellers'].values):
    if string_traveller in test:
        df.iloc[ind,df.columns.get_loc("flag")]=1
        train_counter+=1
print(len(df.loc[df['flag']==1]),train_counter)
df.loc[df['flag']==1].head(15)
# Out:
# 68 68
#            Date  Year         Origin  Origin Country  \
# 883  2016-03-28  2016      Barcelona           Spain
# 884  2016-03-28  2016       Zaragoza           Spain
# 974  2016-11-25  2016           Genf     Switzerland
# 975  2016-11-26  2016         Milano           Italy
# 976  2016-11-27  2016        Mantova           Italy
# 977  2016-11-27  2016         Verona           Italy
# 1043 2017-02-10  2017       Zaventem         Belgium
# 1047 2016-02-12  2016           Gent         Belgium
# 1048 2017-02-12  2017      Antwerpen         Belgium
# 1135 2017-09-06  2017      Fiumicino           Italy
# 1136 2017-09-11  2017            Rom           Italy
# 1137 2017-09-15  2017        Gatwick  United Kingdom
# 1138 2017-09-17  2017  London Bridge  United Kingdom
# 1139 2017-09-18  2017         London  United Kingdom
# 1145 2017-10-15  2017           Genf     Switzerland
#
#                  Origin Station Destination Destination Country  \
# ...

# %%
df.groupby(["Origin",'Destination']).agg(train_rides=('Origin Country','count')).sort_values(
    by="train_rides",ascending=False).reset_index().head(25)
# Out:
#        Origin Destination  train_rides
# 0        Genf        Genf           91
# 1     Koblenz       Turgi           44
# 2       Turgi      Aargau           44
# 3      Aargau        Genf           43
# 4       Turgi     Koblenz           42
# 5      Aargau       Turgi           42
# 6        Genf      Aargau           42
# 7      Berlin      Berlin           38
# 8      London      London           38
# 9   Schwechat        Wien           22
# 10       Wien   Schwechat           22
# 11     Madrid      Madrid           22
# 12    Zuerich        Genf           14
# 13       Genf        Brig           13
# 14      Tokyo       Tokyo           13
# 15       Genf     Zuerich           12
# 16       Bern        Genf           12
# 17       Genf        Bern           12
# 18      Baden     Koblenz           11
# 19    Zuerich       Baden           11
# 20    Zuerich     Koblenz           11
# 21       Wien        Wien           11
# 22    Koblenz     Zuerich           10
# ...

# %%
df.groupby(["Origin"]).agg(train_rides=('Origin Country','count')).sort_values(
    by="train_rides",ascending=False).reset_index().head(25)
# Out:
#                Origin  train_rides
# 0                Genf          253
# 1                Wien          105
# 2              Aargau           86
# 3               Turgi           86
# 4             Koblenz           65
# 5              London           64
# 6              Berlin           54
# 7             Zuerich           49
# 8              Madrid           43
# 9               Paris           42
# 10               Bern           28
# 11             Milano           23
# 12               Brig           23
# 13          Schwechat           22
# 14              Baden           19
# 15  Frankfurt am Main           19
# 16         Interlaken           17
# 17                Rom           17
# 18           Lausanne           17
# 19          Stockholm           16
# 20              Basel           16
# 21              Tokyo           16
# 22               Visp           15
# 23           Lissabon           15
# 24           Muenchen           14

# %%
df.groupby(['Destination']).agg(train_rides=('Origin Country','count')).sort_values(
    by="train_rides",ascending=False).reset_index().head(25)
# Out:
#           Destination  train_rides
# 0                Genf          241
# 1                Wien          106
# 2               Turgi           87
# 3              Aargau           87
# 4             Koblenz           68
# 5              London           64
# 6              Berlin           55
# 7             Zuerich           53
# 8              Madrid           42
# 9               Paris           42
# 10               Bern           26
# 11             Milano           23
# 12               Brig           23
# 13          Schwechat           22
# 14           Lausanne           19
# 15              Baden           19
# 16  Frankfurt am Main           19
# 17           Lissabon           17
# 18              Basel           17
# 19         Interlaken           17
# 20                Rom           17
# 21          Stockholm           16
# 22              Tokyo           16
# 23               Visp           15
# 24             Napoli           14

# %%
df.loc[(df["End Transfer Station"]==0)].groupby(['Destination']).agg(train_rides=('Origin Country','count')).sort_values(
    by="train_rides",ascending=False).reset_index().head(25)
# Out:
#           Destination  train_rides
# 0                Genf          237
# 1                Wien           94
# 2              London           42
# 3              Berlin           39
# 4             Koblenz           36
# 5               Paris           32
# 6              Madrid           29
# 7             Zuerich           24
# 8           Schwechat           22
# 9              Milano           17
# 10                Rom           17
# 11          Stockholm           16
# 12           Lissabon           15
# 13  Frankfurt am Main           14
# 14             Napoli           13
# 15              Tokyo           13
# 16           Waldshut           10
# 17            Venezia           10
# 18            Zermatt            9
# 19              Kyoto            8
# 20            Potsdam            8
# 21           Muenchen            8
# 22           Lausanne            8
# 23              Basel            7
# 24        Duesseldorf            7

# %%
df.loc[(df["Start Transfer Station"]==0)].groupby(['Origin']).agg(train_rides=('Origin Country','count')).sort_values(
    by="train_rides",ascending=False).reset_index().head(25)
# Out:
#                Origin  train_rides
# 0                Genf          248
# 1                Wien           97
# 2              Berlin           39
# 3             Koblenz           38
# 4              London           38
# 5              Madrid           29
# 6               Paris           29
# 7             Zuerich           24
# 8           Schwechat           22
# 9   Frankfurt am Main           16
# 10             Milano           16
# 11          Stockholm           16
# 12                Rom           16
# 13              Tokyo           14
# 14           Lissabon           12
# 15             Napoli           11
# 16            Venezia           10
# 17           Waldshut           10
# 18           Muenchen            9
# 19              Basel            9
# 20              Kyoto            8
# 21           Bruessel            8
# 22            Potsdam            8
# 23          Amsterdam            8
# 24      St Petersburg            7

# %%
import re
#re.sub(r'\W+', '', your_string)

cotravellers=set()

#if I consider unique() just alone, then it would split everything directly into 

for expr in df['Co-Travellers'].values:
    for w in expr:
        name=re.sub(r"[^\w-]", ' ', w).strip()
        if name!="":
            cotravellers.add(name)
print(cotravellers)
# Out:
# {'Stan', 'Bryan', 'Kate', 'Heidrun', 'Andrew', 'Vivan', 'Englisch Grundkurs', 'Indara', 'Nick', 'Nhi', 'Manuel', 'Christine', 'Bing', 'Gianrico', 'Physicists 3rd year', 'Sam', 'Jan-Marc', 'Grace Cummings', 'Hannsjoerg', 'Chris Clarke', 'Steffen', 'Juno', 'Sigi', 'Andres', 'ETH Physicists', 'David Saltzberg', 'Anne-Kathrin', 'Ulrike', 'Grace', 'Jose', 'Riju', 'Stephanie', 'Joanna', 'Landschulheim', 'Aaron', 'Can', 'Nate', 'Laser', 'Rachel', 'Ivan', 'AJ', 'Grace Engels', 'Sophie', 'Michael', 'Jacob', 'Chris Brainerd', 'Santona', 'Brant', 'Eric', 'Francesca', 'Dylan', 'Kevin', 'Hochrhein Seminar', 'Amin', 'Mohammed', 'Andreas', 'Artur', 'Stephan', 'Nathan', 'Siyi', 'Chris Lee', 'Keyvan', 'Reyer', 'Kevin Nash', 'Janina', 'David Yu', 'Namrata', 'Kennedy', 'Devin', 'Sasha', 'Will', 'Zhiling', 'May', 'Chris Martin', 'Tema', 'Anne'}

# %%
df_list_co_travellers=[]
for ind_ct,ct in enumerate(cotravellers):
    cot_flag=np.zeros(len(df))
    for ind,expr in enumerate(df['Co-Travellers'].values):
        if ct in expr:
            cot_flag[ind]=1
    df["cot_flag"]=cot_flag
    
    print(ind_ct, ct,": total/high speed",df.loc[df['cot_flag']==1,"Origin"].count(),df.loc[(df['cot_flag']==1) & (df['High Speed Train']==1),"Origin"].count(),
         "joined on",df.loc[(df['cot_flag']==1),"Date"].nunique(),"dates")
    df_list_co_travellers.append([ct,
                                df.loc[(df['cot_flag']==1),"Origin"].count(),
                                df.loc[(df['cot_flag']==1)&
                                        (df['High Speed Train']==0),"Origin"].count(),
                                df.loc[(df['cot_flag']==1) &
                                        (df['High Speed Train']==1),"Origin"].count(),
                                df.loc[(df['cot_flag']==1),"Date"].nunique(),
                                df.loc[(df['cot_flag']==1) &
                                        (df['High Speed Train']==0),"Date"].nunique(),
                                df.loc[(df['cot_flag']==1) &
                                        (df['High Speed Train']==1),"Date"].nunique(),
                                df.loc[(df['cot_flag']==1),"Origin Country"].nunique(),
                                df.loc[(df['cot_flag']==1),"Origin"].nunique(),
                                df.loc[(df['cot_flag']==1),"Date"].min(),
                                df.loc[(df['cot_flag']==1),"Date"].max()                             
                                 ])
    if df.loc[(df['cot_flag']==1),"Date"].nunique()>1:
        min_x=df.loc[(df['cot_flag']==1),"Date"].min()-np.timedelta64(2,"M")
        max_x=df.loc[(df['cot_flag']==1),"Date"].max()+np.timedelta64(2,"M")
        fig, ax = plt.subplots()
        max_y=1.25*df[(df['cot_flag']==1)].groupby(pd.Grouper(key="Date", freq="1D")).count()["Origin"].max()
        df[(df['cot_flag']==1)].groupby(pd.Grouper(key="Date", freq="1D")).count()["Origin"].plot(title="daily train rides in trips",ylabel="tain rides",xlim=(min_x,max_x),ylim=(0,max_y))
        plt.show()
# Out:
# 0 Stan : total/high speed 4 3 joined on 1 dates
# 1 Bryan : total/high speed 4 0 joined on 2 dates
# 2 Kate : total/high speed 4 3 joined on 1 dates
# 3 Heidrun : total/high speed 165 30 joined on 72 dates
# 4 Andrew : total/high speed 13 6 joined on 6 dates
# 5 Vivan : total/high speed 14 10 joined on 5 dates
# 6 Englisch Grundkurs : total/high speed 4 0 joined on 1 dates
# 7 Indara : total/high speed 7 3 joined on 3 dates
# 8 Nick : total/high speed 2 2 joined on 1 dates
# 9 Nhi : total/high speed 2 2 joined on 2 dates
# 10 Manuel : total/high speed 24 10 joined on 10 dates
# 11 Christine : total/high speed 17 8 joined on 6 dates
# 12 Bing : total/high speed 6 0 joined on 2 dates
# 13 Gianrico : total/high speed 10 3 joined on 6 dates
# 14 Physicists 3rd year : total/high speed 2 2 joined on 1 dates
# 15 Sam : total/high speed 23 15 joined on 8 dates
# 16 Jan-Marc : total/high speed 27 3 joined on 13 dates
# 17 Grace Cummings : total/high speed 36 10 joined on 9 dates
# ...

# %%
df_coTrav = pd.DataFrame(df_list_co_travellers,columns=['Co-Traveller', 'Train Rides','RegionalTrainRides','HighSpeedTrainRides','Days',"Days_Regional","Days_HighSpeed","N_Countries","N_Places","FirstTripDate",'LastTripDate'])
df_coTrav=df_coTrav.sort_values(by="Train Rides",ascending=False).reset_index().drop(columns='index')
df_coTrav.to_csv("../data/train_cotravellers.csv")
df_coTrav.head(50)
# Out:
#           Co-Traveller  Train Rides  RegionalTrainRides  HighSpeedTrainRides  \
# 0           Hannsjoerg          215                 119                   96
# 1                Artur          194                 148                   46
# 2              Heidrun          165                 135                   30
# 3                 Riju           68                  36                   32
# 4         Anne-Kathrin           52                  39                   13
# 5                 Eric           40                  32                    8
# 6       Grace Cummings           36                  26                   10
# 7       Chris Brainerd           28                  17                   11
# 8             Jan-Marc           27                  24                    3
# 9               Manuel           24                  14                   10
# 10                Amin           24                  14                   10
# ...

# %%
data_list_buses=[]

#2009
data_list_buses.append([datetime.datetime(2009, 6, 23),2009,"Chicago","USA","Chicago O'Hare Airport","Madison","USA","Madison Union Station",0,0,0,[]])
data_list_buses.append([datetime.datetime(2009, 6, 28),2009,"Madison","USA","Madison Union Station","Chicago","USA","Chicago Union Station",0,0,0,[]])
data_list_buses.append([datetime.datetime(2009, 6, 28),2009,"Chicago","USA","Chicago Union Station","Madison","USA","Union Station",0,0,0,[]])
#2010
data_list_buses.append([datetime.datetime(2010, 2, 6),2010,"Argentiere","France","Argentiere","Chamonix","France","Chamonix",0,0,0,[]])
data_list_buses.append([datetime.datetime(2010, 2, 6),2010,"Chamonix","France","Chamonix","Argentiere","France","Argentiere",0,0,0,[]])
data_list_buses.append([datetime.datetime(2010, 7, 11),2010,"Oberwald","Switzerland","Oberwald Bahnhof","Furka","Switzerland","Belvedere Furka",0,0,0,[]])
data_list_buses.append([datetime.datetime(2010, 7, 11),2010,"Furka","Switzerland","Belvedere Furka","Andermatt","Switzerland","Andermatt Bahnhof",0,0,0,[]])
data_list_buses.append([datetime.datetime(2010, 7, 11),2010,"Furka","Switzerland","Belvedere Furka","Andermatt","Switzerland","Andermatt Bahnhof",0,0,0,[]])
data_list_buses.append([datetime.datetime(2010, 9, 4),2010,"Brig","Switzerland","Brig Bahnhof","Saas-Fee","Switzerland","Saas-Fee Busterminal",0,0,0,[]])
data_list_buses.append([datetime.datetime(2010, 9, 4),2010,"Saas-Fee","Switzerland","Saas-Fee Busterminal","Saas-Grund","Switzerland","Saas-Grund Bergbahnen",0,0,0,[]])
data_list_buses.append([datetime.datetime(2010, 9, 4),2010,"Saas-Grund","Switzerland","Saas-Grund Bergbahnen","Brig","Switzerland","Brig Bahnhof",0,0,0,[]])
data_list_buses.append([datetime.datetime(2010, 9, 12),2010,"Chamonix","France","Chamonix","Argentiere","France","Argentiere",0,0,0,[]])
#2011
data_list_buses.append([datetime.datetime(2011, 2, 17),2011,"Les Houches","France","Les Houches","Argentiere","France","Argentiere",0,0,0,[]])
data_list_buses.append([datetime.datetime(2011, 2, 17),2011,"Argentiere","France","Argentiere","Chamonix","France","Chamonix",0,0,0,[]])
data_list_buses.append([datetime.datetime(2011, 2, 17),2011,"Chamonix","France","Chamonix","Les Houches","France","Les Houches",0,0,0,[]])
data_list_buses.append([datetime.datetime(2011, 6, 26),2011,"Innertkirchen","Switzerland","Innertkirchen Grimseltor","Gadmen","Switzerland","Gadmen Schwendibruecke",0,0,0,['Hannsjoerg']])
data_list_buses.append([datetime.datetime(2011, 7, 31),2011,"Brig","Switzerland","Brig Bahnhof","Saas-Grund","Switzerland","Saas-Grund Post",0,0,0,['Hannsjoerg']])
data_list_buses.append([datetime.datetime(2011, 7, 31),2011,"Saas-Grund","Switzerland","Saas-Grund Post","Saas-Almagell","Switzerland","Mattmark",0,0,0,['Hannsjoerg']])
data_list_buses.append([datetime.datetime(2011, 7, 31),2011,"Saas-Almagell","Switzerland","Mattmark","Saas-Grund","Switzerland","Saas-Grund Post",0,0,0,['Hannsjoerg']])
data_list_buses.append([datetime.datetime(2011, 7, 31),2011,"Saas-Grund","Switzerland","Saas-Grund Post","Brig","Switzerland","Brig Bahnhof",0,0,0,['Hannsjoerg']])
#2012
data_list_buses.append([datetime.datetime(2012, 7, 17),2011,"Leuk","Switzerland","Leuk Bahnhof","Leukerbad","Switzerland","Leukerbad Stadt",0,0,0,['Hannsjoerg']])
data_list_buses.append([datetime.datetime(2012, 7, 17),2011,"Leukerbad Stadt","Switzerland","Leukerbad Stadt","Leuk","Switzerland","Leuk Bahnhof",0,0,0,['Hannsjoerg']])
data_list_buses.append([datetime.datetime(2012, 7, 17),2010,"Brig","Switzerland","Brig Bahnhof","Saas-Fee","Switzerland","Saas-Fee Busterminal",0,0,0,['Hannsjoerg']])
data_list_buses.append([datetime.datetime(2012, 7, 17),2010,"Saas-Fee","Switzerland","Saas-Fee Busterminal","Brig","Switzerland","Brig Bahnhof",0,0,0,['Hannsjoerg']])
data_list_buses.append([datetime.datetime(2012, 7, 22),2011,"Leuk","Switzerland","Leuk Bahnhof","Leuk","Switzerland","Leuk Stadt",0,0,0,['Hannsjoerg']])
data_list_buses.append([datetime.datetime(2012, 7, 22),2011,"Leuk","Switzerland","Leuk Stadt","Leukerbad","Switzerland","Leukerbad Stadt",0,0,0,['Hannsjoerg']])
data_list_buses.append([datetime.datetime(2012, 7, 22),2011,"Leukerbad Stadt","Switzerland","Leukerbad Stadt","Leuk","Switzerland","Leuk Bahnhof",0,0,0,['Hannsjoerg']])
data_list_buses.append([datetime.datetime(2012, 8, 31),2011,"Lissabon","Portugal","Lisboa Campo Grande","Mafra","Portugal","Mafra",0,0,0,[]])
data_list_buses.append([datetime.datetime(2012, 8, 31),2011,"Mafra","Portugal","Mafra","Lissabon","Portugal","Lisboa Campo Grande",0,0,0,[]])
data_list_buses.append([datetime.datetime(2012, 9, 16),2011,"Innertkirchen","Switzerland","Innertkirchen Grimseltor","Grimsel","Switzerland","Grimsel Hospiz",0,0,0,[]])
data_list_buses.append([datetime.datetime(2012, 9, 16),2011,"Grimsel","Switzerland","Grimsel Passhoehe","Gletsch","Switzerland","Gletsch",0,0,0,[]])
data_list_buses.append([datetime.datetime(2012, 9, 16),2011,"Gletsch","Switzerland","Gletsch","Innertkirchen","Switzerland","Innertkirchen Grimseltor",0,0,0,[]])
#2013
data_list_buses.append([datetime.datetime(2013, 11, 10),2013,"Meudon","France","Meudon Gare","Maincy","France","Chateau Vaux-le-Vicomte",0,0,0,['Eric','Chris Clarke','Chris Lee']])
data_list_buses.append([datetime.datetime(2013, 11, 10),2013,"Maincy","France","Chateau Vaux-le-Vicomte","Meudon","France","Meudon Gare",0,0,0,['Eric','Chris Clarke','Chris Lee']])
#2014
data_list_buses.append([datetime.datetime(2014, 7, 26),2014,"Brighton","United Kingdom","Brighton Railway Station",'Seaford','United Kingdom','Seven Sisters Park Centre',0,0,1,['Heidrun','Artur','Hannsjoerg','Anne-Kathrin']])
data_list_buses.append([datetime.datetime(2014, 7, 26),2014,'Seaford','United Kingdom','Seven Sisters Park Centre',"Brighton","United Kingdom","Brighton Railway Station",0,0,0,['Heidrun','Artur','Hannsjoerg','Anne-Kathrin']])
data_list_buses.append([datetime.datetime(2014, 7, 28),2014,"Ryde","United Kingdom","Ryde Esplanade A",'East Cowes','United Kingdom','Osborne House',0,0,1,['Heidrun']])
data_list_buses.append([datetime.datetime(2014, 7, 28),2014,'East Cowes','United Kingdom','Osborne House',"Newport","United Kingdom","Newport",0,1,0,['Heidrun']])
data_list_buses.append([datetime.datetime(2014, 7, 28),2014,"Newport","United Kingdom","Newport",'Totland','United Kingdom','The Needles',0,0,1,['Heidrun']])
data_list_buses.append([datetime.datetime(2014, 7, 28),2014,'Totland','United Kingdom','The Needles',"Yarmouth","United Kingdom","Yarmouth Car Ferry",0,0,0,['Heidrun']])
data_list_buses.append([datetime.datetime(2014, 7, 30),2014,'Oxford','United Kingdom','Oxford Gloucester Green Bus Station',"Woodstock","United Kingdom","Blenheim Palace",0,0,0,['Heidrun','Artur','Hannsjoerg']])
data_list_buses.append([datetime.datetime(2014, 7, 30),2014,"Woodstock","United Kingdom","Blenheim Palace",'Oxford','United Kingdom','Oxford Gloucester Green Bus Station',0,1,0,['Heidrun','Artur','Hannsjoerg']])
data_list_buses.append([datetime.datetime(2014, 8, 2),2014,'Salisbury','United Kingdom','Salisbury Railway Station',"Amesbury","United Kingdom","Stonehenge",0,0,0,['Heidrun','Artur','Hannsjoerg']])
data_list_buses.append([datetime.datetime(2014, 8, 2),2014,"Amesbury","United Kingdom","Stonehenge",'Salisbury','United Kingdom','Salisbury Railway Station',0,0,0,['Heidrun','Artur','Hannsjoerg']])
data_list_buses.append([datetime.datetime(2014, 8, 24),2014,"Bratislava","Slovakia","Bratislava Most SNP",'Devinska Nova Ves','Slovakia','Uhrovecka',0,0,0,[]])
data_list_buses.append([datetime.datetime(2014, 8, 24),2014,"Schlosshof","Austria","Schlosshof","Marchegg","Austria",'Marchegg Bahnhof',0,1,0,[]])
#2015
data_list_buses.append([datetime.datetime(2015, 3, 30),2015,"Cordoba","Spain","Cordoba Bus Station","Granada","Spain",'Granada Bus Station',0,0,0,['Manuel']])
data_list_buses.append([datetime.datetime(2015, 3, 30),2015,"Granada","Spain",'Granada Bus Station',"Cordoba","Spain","Cordoba Bus Station",0,0,0,['Manuel']])
data_list_buses.append([datetime.datetime(2015, 4, 1),2015,"Segovia","Spain","Segovia Bus Station","La Granja de San Ildefonso","Spain","La Granja Fabrica",0,0,0,['Manuel']])
data_list_buses.append([datetime.datetime(2015, 4, 1),2015,"La Granja de San Ildefonso","Spain","La Granja Fabrica","Segovia","Spain","Segovia Bus Station",0,0,0,['Manuel']])
data_list_buses.append([datetime.datetime(2015, 4, 5),2015,"Madrid","Spain","Madrid Moncloa",'El Pardo','Spain','Ctra.fuencarral-las Monjas',0,0,0,['Eric']])
data_list_buses.append([datetime.datetime(2015, 4, 5),2015,'El Pardo','Spain','Ctra.fuencarral-las Monjas',"Madrid","Spain","Madrid Moncloa",0,0,0,['Eric']])
data_list_buses.append([datetime.datetime(2015, 5, 15),2015,'Pompei','Italy','Pompei Anfiteatro',"Ottaviano","Italy","Vesuvio",0,0,0,['AJ','Stephan']])
data_list_buses.append([datetime.datetime(2015, 5, 15),2015,"Ottaviano","Italy","Vesuvio",'Pompei','Italy','Pompei Anfiteatro',0,0,0,['AJ','Stephan']])
data_list_buses.append([datetime.datetime(2015, 7, 19),2015,'Dole','France','Dole Gare',"Mont St-Michel","France","",1,0,0,[]])
data_list_buses.append([datetime.datetime(2015, 7, 19),2015,"Mont St-Michel","France","",'Dole','France','Dole Gare',1,0,0,[]])
data_list_buses.append([datetime.datetime(2015, 8, 22),2015,"Nice","France","Promenade des Arts",'Beaulieu-sur-Mer','France','Beaulieu-sur-Mer Kerylos',0,0,0,[]])
data_list_buses.append([datetime.datetime(2015, 8, 22),2015,'Beaulieu-sur-Mer','France','Beaulieu-sur-Mer Le Rade',"Nice","France","Promenade des Arts",0,0,0,[]])
data_list_buses.append([datetime.datetime(2015, 9, 10),2015,'Peterhof','Russia','Aleksandriya','St Petersburg','Russia','Avtovo Metro Station',0,0,0,[]])
data_list_buses.append([datetime.datetime(2015, 9, 11),2015,'St Petersburg','Russia','Avtovo Metro Station','Strelna','Russia','Orlovskiy Prud',0,0,0,[]])
data_list_buses.append([datetime.datetime(2015, 9, 11),2015,'Strelna','Russia','Orlovskiy Prud','St Petersburg','Russia','Avtovo Metro Station',0,0,0,[]])
#2016
data_list_buses.append([datetime.datetime(2016, 5, 6),2016,"Rivarolo Canavese","Italy","Rivarolo Canavese FS","Aglie","Italy","Aglie",0,1,0,[]])
data_list_buses.append([datetime.datetime(2016, 5, 6),2016,"Aglie","Italy","Aglie","Rivarolo Canavese","Italy","Rivarolo Canavese FS",0,0,1,[]])
data_list_buses.append([datetime.datetime(2016, 5, 14),2016,"Geneva","Switzerland","Gare Routiere","Genova",'Italy',"Stazione Marittima",0,0,0,['Amin']])
data_list_buses.append([datetime.datetime(2016, 5, 16),2016,"Genova",'Italy',"Stazione Marittima","Geneva","Switzerland","Gare Routiere",0,0,0,['Amin']])
data_list_buses.append([datetime.datetime(2016, 5, 28),2016,"Bilbao",'Spain',"Bilbao Bus Station","Santander","Spain","Santander Bus Station",0,0,0,[]])
data_list_buses.append([datetime.datetime(2016, 5, 29),2016,"Santander","Spain","Santander Bus Station","Puente Viesgo",'Spain',"Puente Viesgo",0,0,0,[]])
data_list_buses.append([datetime.datetime(2016, 5, 29),2016,"Puente Viesgo",'Spain',"Puente Viesgo","Santander","Spain","Santander Bus Station",0,0,0,[]])
data_list_buses.append([datetime.datetime(2016, 5, 30),2016,"Santander","Spain","Santander Bus Station","Burgos",'Spain',"Burgos Bus Station",1,0,0,[]])
data_list_buses.append([datetime.datetime(2016, 5, 30),2016,"Burgos",'Spain',"Burgos Bus Station","Santander","Spain","Santander Bus Station",1,0,0,[]])
data_list_buses.append([datetime.datetime(2016, 6, 3),2016,"Santander","Spain","Santander Bus Station","Bilbao",'Spain',"Bilbao Bus Station",0,0,0,[]])
data_list_buses.append([datetime.datetime(2016, 6, 25),2016,"Faenza","Italy","Faenza FS","Ravenna","Italy","Ravenna FS",1,0,0,['Keyvan']])
data_list_buses.append([datetime.datetime(2016, 6, 25),2016,"Ravenna","Italy","Ravenna FS","Classe","Italy","Classe Basilica",0,0,0,[]])
data_list_buses.append([datetime.datetime(2016, 6, 25),2016,"Classe","Italy","Classe Basilica","Ravenna","Italy","Ravenna Santa Maria In Porto",0,0,0,[]])
data_list_buses.append([datetime.datetime(2016, 8, 29),2016,"Washington DC","USA","Wiehle-Reston East Metro Station","Dulles","USA","Washington Dulles International Airport Arrivals",1,0,0,['Heidrun','Artur']])
data_list_buses.append([datetime.datetime(2016,9,13),2016,"Fort Worth","USA","CentrePort/DFW Airport Station","Arlington","USA","Arlington",1,0,0,[]])
data_list_buses.append([datetime.datetime(2016,12,13),2016,"Nara","Japan","Yakushiji Chushajo Bus Stop","Ikaruga","Japan","Horyujimae",0,0,0,[]])
#2017
data_list_buses.append([datetime.datetime(2017, 3, 25),2017,"Firenze","Italy","Firenze Santa Maria Novella","Assisi","Italy","Assisi Stazione",1,0,1,[]])
data_list_buses.append([datetime.datetime(2017, 5, 27),2017,"Leon","Spain","Leon Bus Station","Oviedo","Spain","Oviedo Bus Station",1,0,0,[]])
data_list_buses.append([datetime.datetime(2017, 5, 27),2017,"Madrid","Spain","Moncloa","Leon","Spain","Leon Bus Station",1,0,0,[]])
data_list_buses.append([datetime.datetime(2017, 7, 12),2017,"Padova","Italy","Padova Stazione","Stra","Italy","Stra Dante",0,0,0,[]])
data_list_buses.append([datetime.datetime(2017, 7, 12),2017,"Stra","Italy","Stra Piazza Marconi","Padova","Italy","Padova Stazione",0,0,0,[]])
data_list_buses.append([datetime.datetime(2017, 7, 14),2017,"Trieste","Italy","Trieste Centrale","Ronchi dei Legionari","Italy","Trieste Airport",0,0,0,['Reyer']])
data_list_buses.append([datetime.datetime(2017, 7, 15),2017,"Ronchi dei Legionari","Italy","Trieste Airport","Grignano","Italy","Grignano/Miramare",0,0,0,['Reyer']])
data_list_buses.append([datetime.datetime(2017, 7, 15),2017,"Grignano","Italy","Grignano/Miramare","Trieste","Italy","Trieste Centrale",0,0,0,['Reyer']])
data_list_buses.append([datetime.datetime(2017, 7, 16),2017,"Trieste","Italy","Trieste Centrale","Sgonico","Italy","Borgo Grotta Gigante",0,0,0,['Reyer']])
data_list_buses.append([datetime.datetime(2017, 7, 16),2017,"Sgonico","Italy","Borgo Grotta Gigante","Trieste","Italy","Trieste Centrale",0,0,0,['Reyer']])
#2018
data_list_buses.append([datetime.datetime(2018, 3, 10),2018,"Brussels","Belgium","Bruxelles Nord","Amsterdam","Netherlands","Amsterdam Sloterdijk",1,0,0,[]])
data_list_buses.append([datetime.datetime(2018, 3, 10),2018,"Amsterdam","Netherlands","Amsterdam Sloterdijk","Brussels","Belgium","Bruxelles Nord",1,0,0,['Mohamed']])
data_list_buses.append([datetime.datetime(2018, 4, 28),2018,"Paris","France","Paris Gare Bercy","Reims","France","Reims Champagne Ardenne TGV",1,0,0,['Reyer','Christine']])
data_list_buses.append([datetime.datetime(2018, 4, 28),2018,"Reims","France","Reims Champagne Ardenne TGV","Paris","France","Paris Gare Bercy",1,0,0,['Reyer','Christine']])
data_list_buses.append([datetime.datetime(2018, 4, 29),2018,"Paris","France","Paris Pont de Sevres","Versailles","France","Chateau de Versailles",0,0,0,['Reyer','Christine']])
data_list_buses.append([datetime.datetime(2018, 4, 29),2018,"Versailles","France","Chateau de Versailles","Paris","France","Paris Pont de Sevres",1,0,0,['Reyer','Christine']])
data_list_buses.append([datetime.datetime(2018, 4, 30),2018,"Caen","France","Caen Gare","Rouen","France","Rouen Gare",1,0,0,['Reyer']])
data_list_buses.append([datetime.datetime(2018, 5, 21),2018,"Rimini","Italy","Rimini Stazione","San Marino","San Marino","Piazzale Calcigni",0,0,0,['Amin']])
data_list_buses.append([datetime.datetime(2018, 5, 21),2018,"San Marino","San Marino","Piazzale Calcigni","Rimini","Italy","Rimini Stazione",0,0,0,['Amin']])
data_list_buses.append([datetime.datetime(2018, 6, 7),2018,"Dore","United Kingdom","Abbeydale Road South/Twentywell Lane","Bakewell","United Kingdom","Chatsworth House",0,0,0,['Artur','Heidrun']])
data_list_buses.append([datetime.datetime(2018, 6, 7),2018,"Bakewell","United Kingdom","Chatsworth House","Sheffield","United Kingdom","Paternoster Row/SS2",0,0,0,['Artur','Heidrun']])
data_list_buses.append([datetime.datetime(2018, 6, 8),2018,"Bangor","United Kingdom","Bangor Railway Station","Caernarfon","United Kingdom","Caernarfon",0,0,0,['Artur','Heidrun']])
data_list_buses.append([datetime.datetime(2018, 6, 8),2018,"Caernarfon","United Kingdom","Caernarfon","Bangor","United Kingdom","Bangor Railway Station",0,0,0,['Artur','Heidrun']])
data_list_buses.append([datetime.datetime(2018, 7, 12),2018,"Seongnam","South Korea","Moran","Sanseong-ri","South Korea","Namhansanseong Fortress",0,0,0,[]])
data_list_buses.append([datetime.datetime(2018, 7, 12),2018,"Sanseong-ri","South Korea","Namhansanseong Fortress","Seongnam","South Korea","Moran",0,0,0,[]])
data_list_buses.append([datetime.datetime(2018, 7, 13),2018,"Hwacheon-ri","South Korea","Singyeongju Station","Gyeongju","South Korea","Jungang Traditional Market",1,1,1,['Steffen','Stefanie']])
data_list_buses.append([datetime.datetime(2018, 7, 13),2018,"Gyeongju","South Korea","Jungang Traditional Market","Gyeongju","South Korea","Bulguksa Temple",0,0,0,['Steffen','Stefanie']])
data_list_buses.append([datetime.datetime(2018, 7, 13),2018,"Gyeongju","South Korea","Jungang Traditional Market","Hwacheon-ri","South Korea","Singyeongju Station",1,0,0,['Steffen','Stefanie']])
data_list_buses.append([datetime.datetime(2018, 8, 5),2018,"Samedan","Switzerland","Samedan Bahnhof","Pontresina","Switzerland","Diavolezza",0,0,0,[]])
data_list_buses.append([datetime.datetime(2018, 8, 5),2018,"Pontresina","Switzerland","Diavolezza","Samedan","Switzerland","Samedan Bahnhof",0,0,0,[]])
#2019
data_list_buses.append([datetime.datetime(2019, 3, 14),2019,"Putignano","Italy","Putignano Stazione","Alberobello","Italy","Alberobello Stazione",0,0,1,['Artur','Heidrun']])
data_list_buses.append([datetime.datetime(2019, 3, 14),2019,"Alberobello","Italy","Alberobello Stazione","Putignano","Italy","Putignano Stazione",0,1,0,['Artur','Heidrun']])
data_list_buses.append([datetime.datetime(2019, 3, 20),2019,"Sorrento","Italy","Sorrento Stazione",'Positano','Italy','Positano Chiesa Nuova',0,0,0,['Artur','Heidrun']])
data_list_buses.append([datetime.datetime(2019, 3, 20),2019,'Positano','Italy','Positano (Sponda)','Amalfi','Italy','Amalfi',0,0,0,['Artur','Heidrun']])
data_list_buses.append([datetime.datetime(2019, 3, 20),2019,"Amalfi","Italy","Amalfi","Salerno","Italy","Salerno Roma Porta Nova",0,0,0,['Artur','Heidrun']])
data_list_buses.append([datetime.datetime(2019, 4, 19),2019,"Poitiers","France","Poitiers Gare","Saint-Savin","France","Saint-Savin",0,0,0,['Riju','Chris Brainerd']])
data_list_buses.append([datetime.datetime(2019, 4, 19),2019,"Saint-Savin","France","Saint-Savin","Poitiers","France","Poitiers Gare",0,1,0,['Riju','Chris Brainerd']])
data_list_buses.append([datetime.datetime(2019, 4, 20),2019,"Perreux-sur-Marne","France","Nogent–Le Perreux",'Provins','France','Provins Gare',1,0,1,['Riju','Chris Brainerd']])
data_list_buses.append([datetime.datetime(2019, 4, 20),2019,"Provins",'France','Provins Gare',"Melun","France","Melun Gare",1,1,0,['Riju','Chris Brainerd']])
#2020
data_list_buses.append([datetime.datetime(2020, 2, 21),2020,"Urbino","Italy","Park S.Lucia","Pesaro","Italy","Pesaro Stazione",1,0,1,[]])
data_list_buses.append([datetime.datetime(2020, 2, 21),2020,"Pesaro","Italy","Pesaro Stazione","Urbino","Italy","Park S.Lucia",1,0,0,[]])
data_list_buses.append([datetime.datetime(2020, 2, 24),2020,"Chiusi Scalo","Italy","Chiusi-Chianciano Terme","Montepulciano","Italy","Montepulciano Autostazione",0,1,1,[]])
data_list_buses.append([datetime.datetime(2020, 2, 24),2020,"Montepulciano","Italy","Montepulciano Autostazione","Pienza","Italy","Pienza",0,1,1,[]])
data_list_buses.append([datetime.datetime(2020, 2, 24),2020,"Pienza","Italy","Pienza N.Insediamento","Montepulciano","Italy","Montepulciano Autostazione",0,1,1,[]])
data_list_buses.append([datetime.datetime(2020, 2, 24),2020,"Montepulciano","Italy","Montepulciano Autostazione","Chiusi Scalo","Italy","Chiusi-Chianciano Terme",0,1,1,[]])
data_list_buses.append([datetime.datetime(2020, 2, 25),2020,"Chiusi Scalo","Italy","Chiusi-Chianciano Terme","Siena","Italy","Siena-Ferrovia",0,0,1,[]])
data_list_buses.append([datetime.datetime(2020, 2, 25),2020,"Siena","Italy","Siena Autostazione","San Gimignano","Italy","San Gimignano Porta San Matteo",0,0,0,[]])
data_list_buses.append([datetime.datetime(2020, 2, 25),2020,"San Gimignano","Italy","San Gimignano Porta San Matteo","Poggibonsi","Italy","Poggibonsi-S. Gimignano",0,1,0,[]])
data_list_buses.append([datetime.datetime(2020, 8, 1),2020,"Brig","Switzerland","Brig Bahnhof","Blatten","Switzerland","Blatten Luftseilbahn",0,1,1,["Sam"]])
data_list_buses.append([datetime.datetime(2020, 8, 1),2020,"Blatten","Switzerland","Blatten Luftseilbahn","Brig","Switzerland","Brig Bahnhof",0,1,1,["Sam"]])
data_list_buses.append([datetime.datetime(2020, 10, 11),2020,"Zug","Germany","Bahnhof Zug","Baar","Switzerland","Baar Tobelbruecke-Hoellgrotten",0,0,1,["Namrata"]])
#2021
data_list_buses.append([datetime.datetime(2021, 5, 24),2021,"Steeg","Austria","xyz",'Hallstatt','Austria',"Hallstatt Hafen",0,0,1,[]])
data_list_buses.append([datetime.datetime(2021, 5, 24),2021,"Hallstatt","Austria","Hallstatt Hafen",'Steeg','Austria',"Bahnhof Steeg-Gosau",0,1,0,[]])
data_list_buses.append([datetime.datetime(2021, 6, 19),2021,'Melk','Austria',"Bahnhof Melk","Emmersdorf an der Donau","Austria","Emmersdorf(Donau)",0,1,0,[]])
data_list_buses.append([datetime.datetime(2021, 6, 20),2021,'Baden bei Wien','Austria',"Bahnhof Baden","Heiligenkreuz im Wienerwald","Austria","Heiligenkreuz Stift",0,0,0,[]])
data_list_buses.append([datetime.datetime(2021, 6, 20),2021,"Heiligenkreuz im Wienerwald","Austria","Heiligenkreuz Stift",'Baden bei Wien','Austria',"Bahnhof Baden",0,0,1,[]])
data_list_buses.append([datetime.datetime(2021, 6, 26),2021,'Linz','Austria',"Linz Busbahnhof","St Florian bei Linz","Austria","xyz",0,1,0,[]])
data_list_buses.append([datetime.datetime(2021, 6, 26),2021,'St Florian bei Linz','Austria',"xyz","Linz","Austria","Linz Busbahnhof",0,0,1,[]])
data_list_buses.append([datetime.datetime(2021, 8, 1),2021,'Bad Deutsch-Altenburg','Austria',"Bad Deutsch-Altenburg Bahnhof","Wagram an der Donau","Austria","Wagram an der Donau",0,0,0,[]])
data_list_buses.append([datetime.datetime(2021, 8, 1),2021,"Wagram an der Donau","Austria","Wagram an der Donau","Wien","Austria","Wien Aspern",0,0,0,[]])
data_list_buses.append([datetime.datetime(2021, 8, 7),2021,'Eisenstadt','Austria',"Eisenstadt Bahnhof","St Margarethen im Burgenland","Austria","St Margarethen im Burgenland Family Park",0,0,0,[]])
data_list_buses.append([datetime.datetime(2021, 8, 7),2021,"Rust am See","Austria","xyz",'Eisenstadt','Austria',"Eistenstadt Busbahnhof",0,1,0,[]])
data_list_buses.append([datetime.datetime(2021, 8, 8),2022,"Wien","Austria","Wie HBF","Laxenburg","Austria","Laxenburg Franz-Joseph-Platz",0,0,0,[]])
data_list_buses.append([datetime.datetime(2021, 8, 8),2022,"Laxenburg","Austria","Laxenburg Franz-Joseph-Platz","Wien","Austria","Wien HBF",0,0,0,[]])
#2022
data_list_buses.append([datetime.datetime(2022, 3, 21),2022,"Malaga","Spain","Malaga Maria Zambrano","Maro","Spain","Maro",0,0,0,[]])
data_list_buses.append([datetime.datetime(2022, 3, 21),2022,"Maro","Spain","Cueva de Nerja","Malaga","Spain","Malaga Port xyz",0,0,0,[]])
data_list_buses.append([datetime.datetime(2022, 3, 23),2022,"Granada","Spain","Granada Bus Station","Jaen","Spain","Jaen Bus Station",1,0,0,[]])
data_list_buses.append([datetime.datetime(2022, 3, 23),2022,"Jaen","Spain","Jaen Bus Station","Ubeda","Spain","Ubeda Bus Station",0,0,0,[]])
data_list_buses.append([datetime.datetime(2022, 3, 23),2022,"Ubeda","Spain","Ubeda Bus Station","Jaen","Spain","Jaen Bus Station",0,0,0,[]])
data_list_buses.append([datetime.datetime(2022, 3, 23),2022,"Jaen","Spain","Jaen Bus Station","Granada","Spain","Granada Bus Station",1,0,0,[]])
data_list_buses.append([datetime.datetime(2022, 3, 26),2022,"Sevilla","Spain","Sevilla Bus Station","Caceres","Spain","Caceres Bus Station",1,0,0,[]])
data_list_buses.append([datetime.datetime(2022, 3, 26),2022,"Caceres","Spain","Caceres Bus Station","Sevilla","Spain","Sevilla Bus Station",1,0,0,[]])
data_list_buses.append([datetime.datetime(2022, 3, 27),2022,"Sevilla","Spain","Sevilla Bus Station","Merida","Spain","Merida Bus Station",1,0,0,[]])
data_list_buses.append([datetime.datetime(2022, 3, 27),2022,"Merida","Spain","Merida Bus Station","Sevilla","Spain","Sevilla Bus Station",1,0,0,[]])
data_list_buses.append([datetime.datetime(2022, 3, 31),2022,"Leon","Spain","Leon Bus Station","Astorga","Spain","Astorga Bus Station",1,0,0,[]])
data_list_buses.append([datetime.datetime(2022, 3, 31),2022,"Astorga","Spain","Astorga Bus Station","Leon","Spain","Leon Bus Station",1,0,0,[]])
data_list_buses.append([datetime.datetime(2022, 4, 1),2022,"Segovia","Spain","Segovia Bus Station","La Granja de San Ildefonso","Spain","La Granja Fabrica",0,0,0,[]])
data_list_buses.append([datetime.datetime(2022, 4, 1),2022,"La Granja de San Ildefonso","Spain","La Granja Fabrica","Segovia","Spain","Segovia Bus Station",0,0,0,[]])
data_list_buses.append([datetime.datetime(2022, 6, 17),2022,"Dresden","Germany","Dresden-Neustadt","Moritzburg","Germany","Moritzburg Schloss",0,0,0,[]])
data_list_buses.append([datetime.datetime(2022, 6, 17),2022,"Moritzburg","Germany","Moritzburg Orangerie","Grossenhain","Germany","Grossenhain Cottbus Bahnhof",0,0,0,[]])
data_list_buses.append([datetime.datetime(2022, 7, 10),2022,'Rybnik','Czech Republic',"Rybnik Train Station","Linz","Austria","Linz HBF",1,1,1,[]])
data_list_buses.append([datetime.datetime(2022, 7, 16),2022,'Hulin','Czech Republic',"Hulin Station","Kromeriz","Czech Republic","Kromeriz Station",0,0,0,[]])
data_list_buses.append([datetime.datetime(2022, 7, 31),2022,'Angera','Italy',"xyz","Sesto Calende","Italy","Sesto Calende Station",0,0,0,['Riju']])
data_list_buses.append([datetime.datetime(2022, 8, 2),2022,'Salerno','Italy',"Salerno Centrale","Castiglione","Italy","Castiglione",0,0,0,['Riju']])
data_list_buses.append([datetime.datetime(2022, 8, 2),2022,'Castiglione','Italy',"Castiglione","Ravello","Italy","xyz",0,0,0,['Riju']])
data_list_buses.append([datetime.datetime(2022, 8, 2),2022,'Ravello','Italy',"xyz","Amalfi","Italy","xyz",0,0,0,['Riju']])
data_list_buses.append([datetime.datetime(2022, 8, 2),2022,'Amalfi','Italy',"xyz","Positano","Italy","Positano Sponda",0,0,0,['Riju']])
data_list_buses.append([datetime.datetime(2022, 8, 2),2022,'Positano','Italy',"Positano Sponda","Sorrento","Italy","xyz",0,0,0,['Riju']])
data_list_buses.append([datetime.datetime(2022, 8, 15),2022,'Breclav','Czech Republic',"Breclav Station","Lednice","Czech Republic","xyz",0,0,0,[]])
data_list_buses.append([datetime.datetime(2022, 8, 15),2022,"Lednice","Czech Republic","xyz",'Breclav','Czech Republic',"Breclav Station",0,0,0,[]])
data_list_buses.append([datetime.datetime(2022, 8, 26),2022,"Riga","Latvia","Riga Bus Station",'Bauskas','Latvia',"Bauskas Bus Station",0,1,0,[]])
data_list_buses.append([datetime.datetime(2022, 8, 26),2022,'Bauskas','Latvia',"Bauskas Bus Station","Rundale","Latvia","Rundale Castle",0,0,1,[]])
data_list_buses.append([datetime.datetime(2022, 8, 26),2022,"Rundale","Latvia","Rundale Castle",'Bauskas','Latvia',"Bauskas Bus Station",0,1,0,[]])
data_list_buses.append([datetime.datetime(2022, 8, 26),2022,'Bauskas','Latvia',"Bauskas Bus Station","Riga","Latvia","Riga Bus Station",0,0,1,[]])
data_list_buses.append([datetime.datetime(2022, 8, 27),2022,"Riga","Latvia","Riga Bus Station",'Vilnius','Lithuania',"Vilnius Bus Station",1,0,0,[]])
data_list_buses.append([datetime.datetime(2022, 8, 27),2022,'Vilnius','Lithuania',"Vilnius Bus Station","Riga","Latvia","Riga Bus Station",1,0,0,[]])
data_list_buses.append([datetime.datetime(2022, 9, 10),2022,'Brno','Czech Republic',"Brno Bus Station","Litomysl","Czech Republic","Litomysl Bus Station",1,0,0,[]])
data_list_buses.append([datetime.datetime(2022, 9, 10),2022,"Litomysl","Czech Republic","Litomysl Bus Station",'Brno','Czech Republic',"Brno Bus Station",1,0,0,[]])
data_list_buses.append([datetime.datetime(2022, 9, 25),2022,"Wien","Austria","Wie HBF","Laxenburg","Austria","Laxenburg Franz-Joseph-Platz",0,0,0,[]])
data_list_buses.append([datetime.datetime(2022, 9, 25),2022,"Laxenburg","Austria","Laxenburg Franz-Joseph-Platz","Wien","Austria","Wien HBF",0,0,0,[]])
data_list_buses.append([datetime.datetime(2022, 10, 8),2022,"Leoben","Austria","Leoben HBF","Eisenerz","Austria","Eisenerz Busbahnhof",0,0,0,[]])
data_list_buses.append([datetime.datetime(2022,
bus Station",1,0,0,[]])
data_list_buses.append([datetime.datetime(2023, 4, 30),2023,"Tarnowskie Gory Bus Station","Poland","Tarnowskie Góry","Katowice","Poland","Katowice Sadowa",1,0,0,[]])
data_list_buses.append([datetime.datetime(2023, 5, 21),2023,"Linz","Austria","Linz Busbahnhof","Wilhering",'Austria',"Wilhering Ortsmitte",0,0,1,[]])
data_list_buses.append([datetime.datetime(2023, 5, 21),2023,"Wilhering","Austria","Wilhering Ortsmitte","Linz",'Austria',"Linz Busbahnhof",0,1,0,[]])
data_list_buses.append([datetime.datetime(2023, 6, 3),2023,"Maersta","Sweden","Arlanda Terminal 4","Stockholm",'Sweden',"Stockholm Eriksplanen",0,1,0,[]])
data_list_buses.append([datetime.datetime(2023, 6, 25),2023,"Plovdiv","Bulgaria","Plovdiv Rodopi","Bachkovo",'Bulgaria',"Bachkovo Monastery",1,0,0,[]])
data_list_buses.append([datetime.datetime(2023, 6, 25),2023,"Bachkovo",'Bulgaria',"Bachkovo Monastery","Plovdiv","Bulgaria","Plovdiv Rodopi",1,0,0,[]])
data_list_buses.append([datetime.datetime(2023, 7, 22),2023,"Koege",'Denmark',"Koege St Oestre Banevej","Harlev",'Denmark',"Harlev St",1,0,0,[]])
data_list_buses.append([datetime.datetime(2023, 7, 22),2023,"Harlev",'Denmark',"Harlev St","Roedvig Stevns",'Denmark',"Roedvig St",1,0,0,[]])
data_list_buses.append([datetime.datetime(2023, 7, 22),2023,"Roedvig Stevns",'Denmark',"Roedvig St","Harlev",'Denmark',"Harlev St",1,0,0,[]])
data_list_buses.append([datetime.datetime(2023, 7, 22),2023,"Harlev",'Denmark',"Harlev St","Koege",'Denmark',"Koege St Oestre Banevej",1,0,0,[]])
data_list_buses.append([datetime.datetime(2023, 9, 9),2023,'Brno','Czech Republic',"Brno Bus Station","Telc","Czech Republic","Telc Bus Station",1,0,0,[]])
data_list_buses.append([datetime.datetime(2023, 9, 9),2023,"Telc","Czech Republic","Telc Bus Station",'Brno','Czech Republic',"Brno Bus Station",1,0,0,[]])
data_list_buses.append([datetime.datetime(2023, 9, 24),2023,'Znojmo','Czech Republic',"Znojmo Bus Station",'Vranov na Dyji','Czech Republic',"Vranov na Dyji Namesti",1,0,0,[]])
data_list_buses.append([datetime.datetime(2023, 9, 24),2023,'Vranov na Dyji','Czech Republic',"Vranov na Dyji Namesti",'Znojmo','Czech Republic',"Znojmo Bus Station",1,0,0,[]])
data_list_buses.append([datetime.datetime(2023, 10, 29),2023,"Oesmo","Sweden","Oesmo Station","Nymnashamn","Sweden","Nymnashamn Industrivaegen",0,0,1,[]])
data_list_buses.append([datetime.datetime(2023, 10, 29),2023,"Emmaboda","Sweden","Emmaboda Station","Karlskrona","Sweden","Karlskrona Central",0,0,1,[]])
data_list_buses.append([datetime.datetime(2023, 10, 31),2023,"Kalmar","Sweden","Kalmar Central","Moerbylanga","Sweden","Moerbylanga Bustation",0,0,1,[]])
data_list_buses.append([datetime.datetime(2023, 10, 31),2023,"Moerbylanga","Sweden","Moerbylanga Trollet","Kalmar","Sweden","Kalmar Central",0,0,1,[]])
data_list_buses.append([datetime.datetime(2023, 11, 11),2023,"Gaenserndorf","Austria","Bahnhof Gaenserndorf","Marchegg","Austria","Bahnhof Marchegg",0,1,1,[]])
data_list_buses.append([datetime.datetime(2023, 11, 11),2023,"Marchegg","Austria","Bahnhof Marchegg","Lassee","Austria","Bahnhof Schönfeld-Lassee",0,1,1,[]])
data_list_buses.append([datetime.datetime(2024, 2, 18),2024,"Vicenza","Italy","Vicenza Via Giuriolo","Caldogno","Italy","Caldogno Via Zanella Fronte Civico 38",0,0,0,[]])
data_list_buses.append([datetime.datetime(2024, 2, 18),2024,"Caldogno","Italy","Caldogno Via Zanella Fronte Civico 38","Vicenza","Italy","Vicenza Via Giuriolo",0,0,0,[]])
data_list_buses.append([datetime.datetime(2024, 2, 19),2024,"Ravenna","Italy","Ravenna Piazza Caduti","Classe","Italy","Classe Piazza",0,0,0,[]])
data_list_buses.append([datetime.datetime(2024, 2, 19),2024,"Classe","Italy","Classe Piazza","Ravenna","Italy","Ravenna Via de Gasperi",0,0,0,[]])
data_list_buses.append([datetime.datetime(2024, 4, 1),2024,"Thessaloniki","Greece","Thessaloniki Macedonia KTEL","Kavala","Greece","Kavala KTEL",1,1,0,['Artur']])
data_list_buses.append([datetime.datetime(2024, 4, 1),2024,"Kavala","Greece","Kavala KTEL","Krenides","Greece","Krenides 1",0,0,1,['Artur']])
data_list_buses.append([datetime.datetime(2024, 4, 1),2024,"Krenides","Greece","Krenides 1","Kavala","Greece","Kavala KTEL",0,0,0,['Artur']])
data_list_buses.append([datetime.datetime(2024, 4, 1),2024,"Kavala","Greece","Kavala KTEL","Thessaloniki","Greece","Thessaloniki Macedonia KTEL",1,0,0,['Artur']])
data_list_buses.append([datetime.datetime(2024, 4, 3),2024,"Thessaloniki","Greece","Thessaloniki Railway KTEL","Skopje","North Macedonia","Skopje Bus Station",1,0,0,['Artur']])
data_list_buses.append([datetime.datetime(2024, 4, 4),2024,"Skopje","North Macedonia","Skopje Bus Station","Ohrid","North Macedonia","Ohrid Bus Station",1,0,0,['Artur']])
data_list_buses.append([datetime.datetime(2024, 4, 4),2024,"Ohrid","North Macedonia","Ohrid Bus Station","Skopje","North Macedonia","Skopje Bus Station",1,0,0,['Artur']])
data_list_buses.append([datetime.datetime(2024, 4, 5),2024,"Skopje","North Macedonia","Skopje Bus Station","Thessaloniki","Greece","Thessaloniki Railway KTEL",1,0,0,['Artur']])
data_list_buses.append([datetime.datetime(2024, 4, 6),2024,"Thessaloniki","Greece","Thessaloniki Macedonia KTEL","Kavala","Greece","Kavala KTEL",1,1,0,['Artur']])
data_list_buses.append([datetime.datetime(2024, 4, 6),2024,"Trikala","Greece","Trikala KTEL","Kalambaka","Greece","Kalambaka KTEL",0,0,1,['Artur']])
data_list_buses.append([datetime.datetime(2024, 4, 8),2024,"Kalambaka","Greece","Kalambaka KTEL","Trikala","Greece","Trikala KTEL",0,1,0,['Artur']])
data_list_buses.append([datetime.datetime(2024, 4, 8),2024,"Trikala","Greece","Trikala KTEL","Thessaloniki","Greece","Thessaloniki Macedonia KTEL",1,0,1,['Artur']])
data_list_buses.append([datetime.datetime(2024, 5, 3),2024,"Windermere","United Kingdom","Windermere Station","Grasmere","United Kingdom","Dove Cottage",0,0,0,[]])
data_list_buses.append([datetime.datetime(2024, 5, 4),2024,"Wool","United Kingdom","Wool Station","West Lulworth","United Kingdom","Lulworth Cove",0,0,0,[]])
data_list_buses.append([datetime.datetime(2024, 5, 4),2024,"West Lulworth","United Kingdom","Lulworth Cove","Wool","United Kingdom","Wool Station",0,0,0,[]])
data_list_buses.append([datetime.datetime(2024, 5, 5),2024,"London","United Kingdom","Stratford City","Stanstead","United Kingdom","Stanstead Airport Bus Station",1,1,0,[]])
data_list_buses.append([datetime.datetime(2024, 5, 5),2024,"Stanstead","United Kingdom","Stanstead Airport Bus Station","Cambridge","United Kingdom","Cambridge Parkside",1,0,1,[]])
data_list_buses.append([datetime.datetime(2024, 5, 5),2024,"Cambridge","United Kingdom","Cambridge Parkside","London","United Kingdom","Heathrow Airport Central",1,0,0,[]])
data_list_buses.append([datetime.datetime(2024, 5, 9),2024,"Ljubljana","Slovenia","Ljubljana Bus Station","Idrija","Slovenia","Idrija Bus Station",1,0,0,[]])
data_list_buses.append([datetime.datetime(2024, 5, 9),2024,"Idrija","Slovenia","Idrija Bus Station","Ljubljana","Slovenia","Ljubljana Bus Station",1,0,0,[]])
data_list_buses.append([datetime.datetime(2024, 5, 31),2024,"Gloggnitz","Austria","Gloggnitz Bahnhof","Kirchberg am Wechsel","Austria","Kirchberg am Wechsel Friedhof",0,0,0,[]])
data_list_buses.append([datetime.datetime(2024,
data_list_buses.append([datetime.datetime(2024,9, 16),2024,"Rotterdame","Netherlands","Rotterdam Kralingse Zoom","Kinderdijk","Netherlands","Kinderdijk Molenkande",0,0,0,[]])

# %%
#only long distance buses, aka between several places, not only between the city itself
#or city to high speed station shuttle bus, or shuttle aiport city center
df_bus = pd.DataFrame(data_list_buses,columns=['Date','Year', 'Origin', 'Origin Country','Origin Station','Destination','Destination Country','Destination Station',"High Speed Bus",'End Transfer Station','Start Transfer Station','Co-Travellers'])
df_bus["Number of Co-Travellers"]=df_bus["Co-Travellers"].str.len()
df_bus.to_csv("../data/Bus_StationInfo.csv")
df_bus
# Out:
#           Date  Year      Origin  Origin Country            Origin Station  \
# 0   2009-06-23  2009     Chicago             USA    Chicago O'Hare Airport
# 1   2009-06-28  2009     Madison             USA     Madison Union Station
# 2   2009-06-28  2009     Chicago             USA     Chicago Union Station
# 3   2010-02-06  2010  Argentiere          France                Argentiere
# 4   2010-02-06  2010    Chamonix          France                  Chamonix
# ..         ...   ...         ...             ...                       ...
# 267 2024-08-31  2024      Oxford  United Kingdom    Oxford Magdalen Street
# 268 2024-08-31  2024   Woodstock  United Kingdom           Blenheim Palace
# 269 2024-09-13  2024       Weesp     Netherlands             Weesp Station
# 270 2024-09-13  2024      Muiden     Netherlands        Muiden P+R terrein
# 271 2024-09-16  2024  Rotterdame     Netherlands  Rotterdam Kralingse Zoom
#
# ...

# %%
df_bus.groupby("Year").agg(busrides_per_year=('Origin','count')).reset_index()
# Out:
#     Year  busrides_per_year
# 0   2009                  3
# 1   2010                 11
# 2   2011                 18
# 3   2013                  2
# 4   2014                 12
# 5   2015                 15
# 6   2016                 16
# 7   2017                 10
# 8   2018                 20
# 9   2019                  9
# 10  2020                 12
# 11  2021                 11
# 12  2022                 47
# 13  2023                 38
# 14  2024                 48

# %%
df_bus_agg=df_bus.groupby("Origin Country").agg(busrides_country=('Origin','count')).sort_values(by="busrides_country",ascending=False).reset_index()
df_bus_agg_diff= df_bus.loc[(df_bus["Origin Country"]!=df_bus['Destination Country'])].groupby(
    "Destination Country").agg(busrides_diff=("Origin",'count')
                              ).reset_index().rename(columns={"Destination Country": "Origin Country"})
df_bus_agg=df_bus_agg.merge(df_bus_agg_diff,on="Origin Country",how='outer')
df_bus_agg['busrides_country']=df_bus_agg['busrides_country'].fillna(0).astype(int)
df_bus_agg['busrides_diff']=df_bus_agg['busrides_diff'].fillna(0).astype(int)
df_bus_agg['busrides_country']=df_bus_agg['busrides_country']+df_bus_agg['busrides_diff']
df_bus_agg=df_bus_agg.drop(columns="busrides_diff").rename(columns={"Origin Country": "Country"})
df_bus_agg.sort_values(by='busrides_country',ascending=False).reset_index(drop=True)
# Out:
#             Country  busrides_country
# 0             Italy                43
# 1           Austria                40
# 2             Spain                30
# 3       Switzerland                30
# 4    United Kingdom                24
# 5            France                23
# 6          Portugal                19
# 7    Czech Republic                10
# 8            Greece                10
# 9           Germany                 6
# 10           Latvia                 6
# 11      Netherlands                 5
# 12      South Korea                 5
# 13           Sweden                 5
# 14              USA                 5
# 15          Denmark                 4
# 16  North Macedonia                 4
# 17           Russia                 3
# 18         Slovenia                 2
# 19           Poland                 2
# 20         Bulgaria                 2
# 21       San Marino                 2
# 22          Belgium                 2
# 23        Lithuania                 2
# ...

# %%
#seilbahnen/zahnrad too???

data_list_tel=[]

#1987
data_list_tel.append([datetime.datetime(1987, 10, 10),1987,"Flumserberg-Maschgenkamm",'Flumserberg',"Switzerland","gondola lift",['Artur','Heidrun','Hannsjoerg','Anne-Kathrin','Jan-Marc']])
data_list_tel.append([datetime.datetime(1987, 10, 10),1987,"Maschgenkamm-Flumserberg",'Flumserberg',"Switzerland","gondola lift",['Artur','Heidrun','Hannsjoerg','Anne-Kathrin','Jan-Marc']])
#1988
data_list_tel.append([datetime.datetime(1988, 10, 25),1988,"Truemmelbach","Stechelberg","Switzerland","funicular",['Artur','Heidrun','Hannsjoerg','Anne-Kathrin','Jan-Marc']])
data_list_tel.append([datetime.datetime(1988, 10, 26),1988,"Beatenberg-Vorsass","Beatenberg","Switzerland","chair lift",['Artur','Heidrun','Hannsjoerg','Anne-Kathrin','Jan-Marc']])
data_list_tel.append([datetime.datetime(1988, 10, 26),1988,"Vorsass-Niederhorn","Beatenberg","Switzerland","chair lift",['Artur','Heidrun','Hannsjoerg','Anne-Kathrin','Jan-Marc']])
data_list_tel.append([datetime.datetime(1988, 10, 26),1988,"Niederhorn-Vorsass","Beatenberg","Switzerland","chair lift",['Artur','Heidrun','Hannsjoerg','Anne-Kathrin','Jan-Marc']])
#1989
data_list_tel.append([datetime.datetime(1989, 11, 11),1989,"Oberstdorf-Hoefatsblick","Oberstdorf","Germany","cable car",['Artur','Heidrun','Hannsjoerg','Anne-Kathrin','Jan-Marc']])
data_list_tel.append([datetime.datetime(1989, 11, 11),1989,"Hoefatsblick-Oberstdorf","Oberstdorf","Germany","cable car",['Artur','Heidrun','Hannsjoerg','Anne-Kathrin','Jan-Marc']])
#1992
data_list_tel.append([datetime.datetime(1992, 8, 8),1992,"Feldberg up","Feldberg","Germany","chair lift",['Artur','Heidrun','Hannsjoerg','Anne-Kathrin','Jan-Marc']])
data_list_tel.append([datetime.datetime(1992, 8, 8),1992,"Feldberg down","Feldberg","Germany","chair lift",['Artur','Heidrun','Hannsjoerg','Anne-Kathrin','Jan-Marc']])
#1993
data_list_tel.append([datetime.datetime(1993, 11, 3),1993,"Ehrwald-Zugspitze","Ehrwald","Austria","cable car",['Artur','Heidrun','Hannsjoerg','Anne-Kathrin','Jan-Marc']])
data_list_tel.append([datetime.datetime(1993, 11, 3),1993,"Zugspitze-Ehrwald","Ehrwald","Austria","cable car",['Artur','Heidrun','Hannsjoerg','Anne-Kathrin','Jan-Marc']])
#1994
data_list_tel.append([datetime.datetime(1994, 10, 30),1994,"Mittenwald-Karwendel","Mittenwald","Germany","cable car",['Artur','Heidrun','Hannsjoerg','Anne-Kathrin','Jan-Marc']])
data_list_tel.append([datetime.datetime(1994, 10, 30),1994,"Karwendel-Mittenwald","Mittenwald","Germany","cable car",['Artur','Heidrun','Hannsjoerg','Anne-Kathrin','Jan-Marc']])
#1996
data_list_tel.append([datetime.datetime(1996, 8, 26),1996,"Beatenberg-Vorsass","Beatenberg","Switzerland","chair lift",['Artur','Claudia','Ursula','Anne-Kathrin','Conny']])
#2001
data_list_tel.append([datetime.datetime(2001, 5, 10),2001,"Montserrat-Sant Joan Funicular Station","Montserrat","Spain","funicular",[]])
data_list_tel.append([datetime.datetime(2001, 5, 10),2001,"Sant Joan Funicular Station-Montserrat","Montserrat","Spain","funicular",[]])
#2005
data_list_tel.append([datetime.datetime(2005, 2, 7),2005,"Diavolezza-Lagalb AG-Berghaus Diavolezza","Diavolezza","Switzerland","cable car",[]])
data_list_tel.append([datetime.datetime(2005, 2, 12),2005,"Berghaus Diavolezza-Diavolezza-Lagalb AG","Diavolezza","Switzerland","cable car",[]])
#2006
data_list_tel.append([datetime.datetime(2006, 11, 25),2006,"Chamonix-Montenvers","Chamonix","France","rack railway",['Artur','Heidrun','Hannsjoerg']])
data_list_tel.append([datetime.datetime(2006, 11, 25),2006,"Montenvers-Chamonix","Chamonix","France","rack railway",['Artur','Heidrun','Hannsjoerg']])
#2007
data_list_tel.append([datetime.datetime(2007, 6, 3),2007,"Saleve Up","Etrembieres","France","cable car",['Artur','Heidrun','Hannsjoerg']])
data_list_tel.append([datetime.datetime(2007, 6, 3),2007,"Saleve Down","Etrembieres","France","cable car",['Artur','Heidrun','Hannsjoerg']])
data_list_tel.append([datetime.datetime(2007, 12, 6),2007,"Zermatt-Furi",'Zermatt',"Switzerland","gondola lift",[]])
data_list_tel.append([datetime.datetime(2007, 12, 6),2007,"Furi-Trockener Steg",'Zermatt',"Switzerland","cable car",[]])
data_list_tel.append([datetime.datetime(2007, 12, 6),2007,"Trockener Steg-Furi",'Zermatt',"Switzerland","cable car",[]])
data_list_tel.append([datetime.datetime(2007, 12, 6),2007,"Kleinmatterhorn-Trockener Steg",'Zermatt',"Switzerland","cable car",[]])
data_list_tel.append([datetime.datetime(2007, 12, 6),2007,"Trockener Steg-Kleinmatterhorn",'Zermatt',"Switzerland","cable car",[]])
data_list_tel.append([datetime.datetime(2007, 12, 6),2007,"Furi-Zermatt",'Zermatt',"Switzerland","gondola lift",[]])
#2008
data_list_tel.append([datetime.datetime(2008, 10, 5),2008,"Grindelwald-Kleine Scheidegg","Grindelwald","Switzerland","rack railway",['Sigi','Anne']])
data_list_tel.append([datetime.datetime(2008, 10, 5),2008,"Kleine Scheidegg-Jungfraujoch","Lauterbrunnen","Switzerland","rack railway",['Sigi','Anne']])
data_list_tel.append([datetime.datetime(2008, 10, 5),2008,"Jungfraujoch-Kleine Scheidegg","Lauterbrunnen","Switzerland","rack railway",['Sigi','Anne']])
data_list_tel.append([datetime.datetime(2008, 10, 5),2008,"Kleine Scheidegg-Lauterbrunnen","Lauterbrunnen","Switzerland","rack railway",['Sigi','Anne']])
#2009
data_list_tel.append([datetime.datetime(2009, 8, 23),2009,"Zermatt-Gornergrat","Zermatt","Switzerland","rack railway",[]])
data_list_tel.append([datetime.datetime(2009, 8, 23),2009,"Riffelberg-Zermatt","Zermatt","Switzerland","rack railway",[]])
data_list_tel.append([datetime.datetime(2009, 8, 30),2009,"Truemmelbach","Stechelberg","Switzerland","funicular",[]])
data_list_tel.append([datetime.datetime(2009, 9, 5),2009,"Congress-Hungerburg","Innsbruck","Austria","funicular",[]])
data_list_tel.append([datetime.datetime(2009, 9, 5),2009,"Hungerburg-Seegrube","Innsbruck","Austria","cable car",[]])
data_list_tel.append([datetime.datetime(2009, 9, 5),2009,"Seegrube-Hafelekar","Innsbruck","Austria","cable car",[]])
data_list_tel.append([datetime.datetime(2009, 9, 5),2009,"Hafelekar-Seegrube","Innsbruck","Austria","cable car",[]])
data_list_tel.append([datetime.datetime(2009, 9, 5),2009,"Seegrube-Hungerburg","Innsbruck","Austria","cable car",[]])
data_list_tel.append([datetime.datetime(2009, 9, 5),2009,"Hungerburg-Congress","Innsbruck","Austria","funicular",[]])
#2010
data_list_tel.append([datetime.datetime(2010, 2, 5),2010,"Argentiere-Plan Joran","Argentiere","France","cable car",[]])
data_list_tel.append([datetime.datetime(2010, 2, 5),2010,"Plan Joran-Grand Montets","Argentiere","France","cable car",[]])
data_list_tel.append([datetime.datetime(2010, 2, 5),2010,"Grand Montets-Plan Joran","Argentiere","France","cable car",[]])
data_list_tel.append([datetime.datetime(2010, 2, 5),2010,"Plan Joran-Argentiere","Argentiere","France","cable car",[]])
data_list_tel.append([datetime.datetime(2010, 2, 5),2006,"Chamonix-Montenvers","Chamonix","France","rack railway",[]])
data_list_tel.append([datetime.datetime(2010, 2, 5),2006,"Montenvers-Chamonix","Chamonix","France","rack railway",[]])
data_list_tel.append([datetime.datetime(2010, 2, 6),2010,"Chamonix-Plan de l'Aiguille","Chamonix","France","cable car",[]])
data_list_tel.append([datetime.datetime(2010,
Argentiere","France","cable car",[]])
data_list_tel.append([datetime.datetime(2011, 2, 17),2011,"Plan Joran-Argentiere","Argentiere","France","cable car",[]])
data_list_tel.append([datetime.datetime(2011, 2, 17),2011,"Chamonix-Montenvers","Chamonix","France","rack railway",[]])
data_list_tel.append([datetime.datetime(2011, 2, 17),2011,"Montenvers-Chamonix","Chamonix","France","rack railway",[]])
data_list_tel.append([datetime.datetime(2011, 4, 3),2011,"Lauterbrunnen-Kleine Scheidegg","Lauterbrunnen","Switzerland","rack railway",[]])
data_list_tel.append([datetime.datetime(2011, 4, 3),2011,"Kleine Scheidegg-Jungfraujoch","Lauterbrunnen","Switzerland","rack railway",[]])
data_list_tel.append([datetime.datetime(2011, 4, 3),2011,"Jungfraujoch-Kleine Scheidegg","Lauterbrunnen","Switzerland","rack railway",[]])
data_list_tel.append([datetime.datetime(2011, 4, 3),2011,"Kleine Scheidegg-Lauterbrunnen","Lauterbrunnen","Switzerland","rack railway",[]])
data_list_tel.append([datetime.datetime(2011, 5, 29),2011,"Grindelwald-First","Grindelwald","Switzerland","gondola lift",['Hannsjoerg']])
data_list_tel.append([datetime.datetime(2011, 5, 29),2011,"First-Grindelwald","Grindelwald","Switzerland","gondola lift",['Hannsjoerg']])
data_list_tel.append([datetime.datetime(2011, 5, 29),2011,"Grindelwald-Pfingstegg","Grindelwald","Switzerland","gondola lift",['Hannsjoerg']])
data_list_tel.append([datetime.datetime(2011, 5, 29),2011,"Pfingstegg-Grindelwald","Grindelwald","Switzerland","gondola lift",['Hannsjoerg']])
data_list_tel.append([datetime.datetime(2011, 5, 29),2011,"Grindelwald-Kleine Scheidegg","Grindelwald","Switzerland","rack railway",['Hannsjoerg']])
data_list_tel.append([datetime.datetime(2011, 5, 29),2011,"Kleine Scheidegg-Lauterbrunnen","Lauterbrunnen","Switzerland","rack railway",['Hannsjoerg']])
data_list_tel.append([datetime.datetime(2011, 6, 19),2011,"Zermatt-Gornergrat","Zermatt","Switzerland","rack railway",['Hannsjoerg']])
data_list_tel.append([datetime.datetime(2011, 6, 19),2011,"Riffelberg-Zermatt","Zermatt","Switzerland","rack railway",['Hannsjoerg']])
data_list_tel.append([datetime.datetime(2011, 6, 19),2011,"Zermatt-Trockener Steg","Zermatt","Switzerland","gondola lift",['Hannsjoerg']])
data_list_tel.append([datetime.datetime(2011, 6, 19),2011,"Trockener Steg-Zermatt","Zermatt","Switzerland","gondola lift",['Hannsjoerg']])
data_list_tel.append([datetime.datetime(2011, 6, 26),2011,"Gadmen-Trift","Gadmen","Switzerland","cable car",['Artur','Heidrun','Hannsjoerg']])
data_list_tel.append([datetime.datetime(2011, 6, 26),2011,"Trift-Gadmen","Gadmen","Switzerland","cable car",['Artur','Heidrun','Hannsjoerg']])
data_list_tel.append([datetime.datetime(2011, 7, 3),2011,"Fiesch-Fiescheralp","Fiesch","Switzerland","cable car",['Hannsjoerg']])
data_list_tel.append([datetime.datetime(2011, 7, 3),2011,"Fiescheralp-Eggishorn","Fiescheralp","Switzerland","cable car",['Hannsjoerg']])
data_list_tel.append([datetime.datetime(2011, 7, 3),2011,"Eggishorn-Fiescheralp","Fiescheralp","Switzerland","cable car",['Hannsjoerg']])
data_list_tel.append([datetime.datetime(2011, 7, 3),2011,"Fiescheralp-Fiesch","Fiesch","Switzerland","cable car",['Hannsjoerg']])
data_list_tel.append([datetime.datetime(2011, 9, 3),2011,"Hintertux-Sommerbergalm","Hintertux","Austria","gondola lift",['Heidrun']])
data_list_tel.append([datetime.datetime(2011, 9, 3),2011,"Sommerbergalm-Fernerhaus","Hintertux","Austria","gondola lift",['Heidrun']])
data_list_tel.append([datetime.datetime(2011, 9, 3),2011,"Fernerhaus-Gletscherbus 3 Bergstation","Hintertux","Austria","gondola lift",['Heidrun']])
data_list_tel.append([datetime.datetime(2011, 9, 3),2011,"Gletscherbus 3 Bergstation-Fernerhaus","Hintertux","Austria","gondola lift",['Heidrun']])
data_list_tel.append([datetime.datetime(2011, 9, 3),2011,"Fernerhaus-Sommerbergalm","Hintertux","Austria","gondola lift",['Heidrun']])
data_list_tel.append([datetime.datetime(2011, 9, 3),2011,"Sommerbergalm-Hintertux","Hintertux","Austria","gondola lift",['Heidrun']])
data_list_tel.append([datetime.datetime(2011, 10, 16),2011,"Chamonix-Plan de l'Aiguille","Chamonix","France","cable car",['Hannsjoerg']])
data_list_tel.append([datetime.datetime(2011, 10, 16),2011,"Plan de l'Aiguille-Chamonix","Chamonix","France","cable car",['Hannsjoerg']])
#2012  
data_list_tel.append([datetime.datetime(2012, 6, 27),2012,"Saas Fee-Felskinn","Saas Fee","Switzerland","cable car",['Hannsjoerg']])
data_list_tel.append([datetime.datetime(2012, 6, 17),2012,"Felskinn-Mittelallalin","Saas Fee","Switzerland","rack railway",['Hannsjoerg']])
data_list_tel.append([datetime.datetime(2012, 6, 17),2012,"Mittelallalin-Felskinn","Saas Fee","Switzerland","rack railway",['Hannsjoerg']])
data_list_tel.append([datetime.datetime(2012, 6, 17),2012,"Felskinn-Saas Fee","Saas Fee","Switzerland","cable car",['Hannsjoerg']])
data_list_tel.append([datetime.datetime(2012, 7, 22),2012,"Leukerbad-Gemmipass","Leukerbad","Switzerland","cable car",['Hannsjoerg']])
data_list_tel.append([datetime.datetime(2012, 7, 22),2012,"Gemmipass-Daubensee","Leukerbad","Switzerland","cable car",['Hannsjoerg']])
data_list_tel.append([datetime.datetime(2012, 7, 22),2012,"Daubensee-Gemmipass","Leukerbad","Switzerland","cable car",['Hannsjoerg']])
data_list_tel.append([datetime.datetime(2012, 7, 22),2012,"Gemmipass-Leukerbad","Leukerbad","Switzerland","cable car",['Hannsjoerg']])
data_list_tel.append([datetime.datetime(2012, 8, 12),2012,"Argentiere-Plan Joran","Argentiere","France","cable car",['Brant','Dan','Jacob','Jesse']])
data_list_tel.append([datetime.datetime(2012, 8, 12),2012,"Plan Joran-Grand Montets","Argentiere","France","cable car",['Brant','Dan','Jacob','Jesse']])
data_list_tel.append([datetime.datetime(2012, 8, 12),2012,"Grand Montets-Plan Joran","Argentiere","France","cable car",['Brant','Dan','Jacob','Jesse']])
data_list_tel.append([datetime.datetime(2012, 8, 12),2012,"Plan Joran-Argentiere","Argentiere","France","cable car",['Brant','Dan','Jacob','Jesse']])
data_list_tel.append([datetime.datetime(2012, 8, 18),2012,"Lauterbrunnen-Kleine Scheidegg","Lauterbrunnen","Switzerland","rack railway",[]])
data_list_tel.append([datetime.datetime(2012, 8, 18),2012,"Kleine Scheidegg-Jungfraujoch","Lauterbrunnen","Switzerland","rack railway",['Indara']])
data_list_tel.append([datetime.datetime(2012, 8, 18),2012,"Jungfraujoch-Kleine Scheidegg","Lauterbrunnen","Switzerland","rack railway",['Indara']])
data_list_tel.append([datetime.datetime(2012, 8, 18),2012,"Kleine Scheidegg-Grindelwald","Lauterbrunnen","Switzerland","rack railway",['Indara']])    
data_list_tel.append([datetime.datetime(2012, 8, 18),2012,"Grindelwald-First","Grindelwald","Switzerland","gondola lift",['Indara']])
data_list_tel.append([datetime.datetime(2012, 8, 18),2012,"First-Grindelwald","Grindelwald","Switzerland","gondola lift",['Indara']])
data_list_tel.append([datetime.datetime(2012, 9, 16),2012,"Grimsel Hospiz-Sidelhornbahn Bergstation","Gutannen","Switzerland","cable car",[]])
#2013
data_list_tel.append([datetime.datetime(2013, 5, 25),2013,"Funiculaire Fourviere up","Lyon","France","funicular",['Artur','Heidrun','Hannsjoerg']])
data_list_tel.append([datetime.datetime(2013, 7, 4),2013,"Le Praz-Flegere","Le Praz","France","cable car",["Andrew",'Nick','Pieter','Eve','Chris S','David','Cameron']])
data_list_tel.append([datetime.datetime(2013, 7, 4),2013,"Flegere-Le Praz","Le Praz","France","cable car",["Andrew",'Nick','Pieter','Eve','Chris S','David','Cameron']])
data_list_tel.append([datetime.datetime(2013, 9, 21),2013,"Chamonix-Plan de l'Aiguille","Chamonix","France","cable car",['Indara','James']])
data_list_tel.append([datetime.datetime(2013, 9, 21),2013,"Plan de l'Aiguille-Aiguille du Midi","Chamonix","France","cable car",['Indara','James']])
data_list_tel.append([datetime.datetime(2013, 9, 21),2013,"Aiguille du Midi-Plan de l'Aiguille","Chamonix","France","cable car",['Indara','James']])
data_list_tel.append([datetime.datetime(2013, 9, 21),2013,"Plan de l'Aiguille-Chamonix","Chamonix","France","cable car",['Indara','James']])
#2014
data_list_tel.append([datetime.datetime(2014, 6, 8),2014,"Grindelwald-Pfingstegg","Grindelwald","Switzerland","gondola lift",['Chris M']])
data_list_tel.append([datetime.datetime(2014, 6, 8),2014,"Pfingstegg-Grindelwald","Grindelwald","Switzerland","gondola lift",['Chris M']])
data_list_tel.append([datetime.datetime(2014, 6, 22),2014,"Reichenbachfall up","Meiringen","Switzerland","funicular",['Hannsjoerg']])
#2015
data_list_tel.append([datetime.datetime(2015, 7, 4),2015,"La Tour-Charamillon","La Tour","France","chair lift",['Line','Pieter','Jonas']])
data_list_tel.append([datetime.datetime(2015, 7, 4),2015,"Charamillon-Vallorcine","La Tour","France","chair lift",['Line','Pieter','Jonas']])
data_list_tel.append([datetime.datetime(2015, 7, 4),2015,"Vallorcine-Charamillon","La Tour","France","chair lift",['Line','Pieter','Jonas']])
data_list_tel.append([datetime.datetime(2015, 7, 4),2015,"Charamillon-La Tour","La Tour","France","chair lift",['Line','Pieter','Jonas']])
data_list_tel.append([datetime.datetime(2015, 7, 11),2015,"Les Bossons-Chalet du Glacier","Les Bossons","France","chair lift",['Manuel']])
data_list_tel.append([datetime.datetime(2015, 7, 11),2015,"Chalet du Glacier-Les Bossons","Les Bossons","France","chair lift",['Manuel']])
data_list_tel.append([datetime.datetime(2015, 7, 26),2015,"Zermatt-Trockener Steg","Zermatt","Switzerland","gondola lift",['Eric']])
data_list_tel.append([datetime.datetime(2015, 7, 26),2015,"Trockener Steg-Kleinmatterhorn","Zermatt","Switzerland","cable car",['Eric']])
data_list_tel.append([datetime.datetime(2015, 7, 26),2015,"Kleinmatterhorn-Trockener Steg","Zermatt","Switzerland","cable car",['Eric']])
data_list_tel.append([datetime.datetime(2015, 7, 26),2015,"Trockener Steg-Schwarzsee","Zermatt","Switzerland","gondola lift",['Eric']])
data_list_tel.append([datetime.datetime(2015, 7, 26),2015,"Schwarzsee-Zermatt","Zermatt","Switzerland","gondola lift",['Eric','Manuel','Stani']])
data_list_tel.append([datetime.datetime(2015, 7, 26),2015,"Zermatt-Gornergrat","Zermatt","Switzerland","rack railway",['Eric']])
data_list_tel.append([datetime.datetime(2015, 7, 26),2015,"Gornergrat-Zermatt","Zermatt","Switzerland","rack railway",['Eric']])
#2016
data_list_tel.append([datetime.datetime(2016, 6, 11),2016,"Truemmelbach","Stechelberg","Switzerland","funicular",['Andrew']])
data_list_tel.append([datetime.datetime(2016, 7, 10),2016,"Les Houches-Bellevue","Les Houches","Switzerland","funicular",['Grace S','Chris S','Riju','Pieter','Jonas']])
data_list_tel.append([datetime.datetime(2016, 7, 10),2016,"Nid d'Aigle-Bellevue","Les Houches","Switzerland","rack railway",['Grace S','Chris S','Riju','Pieter','Jonas']])
data_list_tel.append([datetime.datetime(2016, 7, 10),2016,"Bellevue-Les Houches","Les Houches","Switzerland","funicular",['Riju','Pieter','Jonas']])
data_list_tel.append([datetime.datetime(2016, 7, 16),2016,"Zermatt-Trockener Steg","Zermatt","Switzerland","gondola lift",['Artur','Heidrun']])
data_list_tel.append([datetime.datetime(2016, 7, 16),2016,"Trockener Steg-Kleinmatterhorn","Zermatt","Switzerland","cable car",['Artur','Heidrun']])
data_list_tel.append([datetime.datetime(2016, 7, 16),2016,"Kleinmatterhorn-Trockener Steg","Zermatt","Switzerland","cable car",['Artur','Heidrun']])
data_list_tel.append([datetime.datetime(2016, 7, 16),2016,"Schwarzsee-Zermatt","Zermatt","Switzerland","gondola lift",['Artur','Heidrun']])
data_list_tel.append([datetime.datetime(2016, 7, 17),2016,"Moerel–Riederalp","Moerel","Switzerland","gondola lift",['Artur','Heidrun']])
data_list_tel.append([datetime.datetime(2016, 7, 17),2016,"Riederalp-Moosfluh","Riederalp","Switzerland","gondola lift",['Artur','Heidrun']])
data_list_tel.append([datetime.datetime(2016, 7, 17),2016,"Moosfluh-Riederalp","Riederalp","Switzerland","gondola lift",['Artur','Heidrun']])
data_list_tel.append([datetime.datetime(2016, 7, 17),2016,"Riederalp-Moerel","Moerel","Switzerland","gondola lift",['Artur','Heidrun']])
data_list_tel.append([datetime.datetime(2016, 7, 17),2016,"Fiesch-Fiescheralp","Fiesch","Switzerland","cable car",['Artur','Heidrun']])
data_list_tel.append([datetime.datetime(2016, 7, 17),2016,"Fiescheralp-Eggishorn","Fiescheralp","Switzerland","cable car",['Artur','Heidrun']])
data_list_tel.append([datetime.datetime(2016, 7, 17),2016,"Eggishorn-Fiescheralp","Fiescheralp","Switzerland","cable car",['Artur','Heidrun']])
data_list_tel.append([datetime.datetime(2016, 7, 17),2016,"Fiescheralp-Fiesch","Fiesch","Switzerland","cable car",['Artur','Heidrun']])
data_list_tel.append([datetime.datetime(2016, 9, 10),2016,"Le Chable TV-Verbier","Le Chable","Switzerland","gondola lift",[]])
data_list_tel.append([datetime.datetime(2016, 9, 10),2016,"Verbier-Croix des Ruinettes","Verbier","Switzerland","gondola lift",[]])
data_list_tel.append([datetime.datetime(2016, 9, 10),2016,"Croix des Ruinettes-La Chaux","Verbier","Switzerland","gondola lift",[]])
data_list_tel.append([datetime.datetime(2016, 9, 10),2016,"La Chaux-Les 4 Vallees","Verbier","Switzerland","gondola lift",[]])
data_list_tel.append([datetime.datetime(2016, 9, 10),2016,"Les 4 Vallees-Mont Fort","Verbier","Switzerland","cable car",[]])
data_list_tel.append([datetime.datetime(2016, 9, 10),2016,"Mont Fort-Les 4 Vallees","Verbier","Switzerland","cable car",[]])
data_list_tel.append([datetime.datetime(2016, 9, 10),2016,"Les 4 Vallees-La Chaux","Verbier","Switzerland","gondola lift",[]])
data_list_tel.append([datetime.datetime(2016, 9, 10),2016,"La Chaux-Croix des Ruinettes","Verbier","Switzerland","gondola lift",[]])
data_list_tel.append([datetime.datetime(2016, 9, 10),2016,"Croix des Ruinettes-Verbier","Verbier","Switzerland","gondola lift",[]])
data_list_tel.append([datetime.datetime(2016, 9, 10),2016,"Verbier-Le Chable TV","Verbier","Switzerland","gondola lift",[]])
#2017
data_list_tel.append([datetime.datetime(2017, 4, 26),2017,"Funicolare up","Perugia","Italy","funicular",[]])
data_list_tel.append([datetime.datetime(2017, 4, 26),2017,"Funicolare down","Perugia","Italy","funicular",[]])
data_list_tel.append([datetime.datetime(2017, 8, 26),2017,"Col du Pillon-Tete aux Chamois","Les Diablerets","Switzerland","cable car",[]])
data_list_tel.append([datetime.datetime(2017, 8, 26),2017,"Tete aux Chamois-Scex Rouge","Les Diablerets","Switzerland","cable car",[]])
data_list_tel.append([datetime.datetime(2017, 8, 26),2017,"Scex Rouge-Tete aux Chamois","Les Diablerets","Switzerland","cable car",[]])
data_list_tel.append([datetime.datetime(2017, 8, 26),2017,"Tete aux Chamois-Col du Pillon","Les Diablerets","Switzerland","cable car",[]])
data_list_tel.append([datetime.datetime(2017, 10, 15),2017,"Zermatt-Rotenboden","Zermatt","Switzerland","rack railway",['Riju']])
data_list_tel.append([datetime.datetime(2017, 10, 15),2017,"Gornergrat-Zermatt","Zermatt","Switzerland","rack railway",['Riju']])
#2018
data_list_tel.append([datetime.datetime(2018, 1, 17),2018,"The Peak Tram-Peak Tower Station","Hong Kong","China","funicular",[]])
data_list_tel.append([datetime.datetime(2018, 1, 17),2018,"Peak Tower Station-The Peak Tram","Hong Kong","China","funicular",[]])
data_list_tel.append([datetime.datetime(2018, 1, 20),2018,"Ngong Ping Cable Car Tung Chung Station-Ngong Ping Cable Car Ngong Ping Station","Hong Kong","China","gondola lift",[]])
data_list_tel.append([datetime.datetime(2018, 1, 20),2018,"Ngong Ping Cable Car Ngong Ping Station-Ngong Ping Cable Car Tung Chung Station","Hong Kong","China","gondola lift",[]])
data_list_tel.append([datetime.datetime(2018, 5, 20),2018,"Funicolare Citta Alta-Citta Alta","Bergamo","Italy","funicular",['Amin']])
data_list_tel.append([datetime.datetime(2018, 8, 5),2018,"Diavolezza-Lagalb AG-Berghaus Diavolezza","Diavolezza","Switzerland","cable car",[]])
data_list_tel.append([datetime.datetime(2018, 8, 5),2018,"Berghaus Diavolezza-Diavolezza-Lagalb AG","Diavolezza","Switzerland","cable car",[]])
data_list_tel.append([datetime.datetime(2018, 8, 26),2018,"Kandersteg-Oeschinensee","Kandersteg","Switzerland","gondola lift",['Riju']])
data_list_tel.append([datetime.datetime(2018, 8, 26),2018,"Oeschinensee-Kandersteg","Kandersteg","Switzerland","gondola lift",['Riju']])
#2019
data_list_tel.append([datetime.datetime(2019, 2, 24),2019,"Chamonix-Plan de l'Aiguille","Chamonix","France","cable car",['Grace','Riju','Christine']])
data_list_tel.append([datetime.datetime(2019, 2, 24),2019,"Plan de l'Aiguille-Aiguille du Midi","Chamonix","France","cable car",['Grace','Riju','Christine']])
data_list_tel.append([datetime.datetime(2019, 2, 24),2019,"Aiguille du Midi-Plan de l'Aiguille","Chamonix","France","cable car",['Grace','Riju','Christine']])
data_list_tel.append([datetime.datetime(2019, 2, 24),2019,"Plan de l'Aiguille-Chamonix","Chamonix","France","cable car",['Grace','Riju','Christine']])
data_list_tel.append([datetime.datetime(2019, 3, 18),2019,"Cimarosa-Morghen","Napoli","Italy","funicular",['Heidrun','Artur']])
data_list_tel.append([datetime.datetime(2019, 6, 16),2019,"Weggis-Rigi Kaltbad","Weggis","Switzerland","cable car",['Racheel','Riju','Chris B']])
data_list_tel.append([datetime.datetime(2019, 6, 16),2019,"Rigi Kaltbad-Rigi Kulm","Rigi","Switzerland","rack railway",['Racheel','Riju','Chris B']])
data_list_tel.append([datetime.datetime(2019, 6, 16),2019,"Rigi Kulm-Arth Goldau RB","Rigi","Switzerland","rack railway",['Racheel','Riju','Chris B']])
data_list_tel.append([datetime.datetime(2019, 7, 28),2019,"Fiesch-Fiescheralp","Fiesch","Switzerland","cable car",['Ivan','Jose','Chris B','Francesca','Ulrike']])
data_list_tel.append([datetime.datetime(2019, 7, 28),2019,"Fiescheralp-Eggishorn","Fiescheralp","Switzerland","cable car",['Ivan','Jose','Chris B','Francesca','Ulrike']])
data_list_tel.append([datetime.datetime(2019, 7, 28),2019,"Eggishorn-Fiescheralp","Fiescheralp","Switzerland","cable car",['Ivan','Jose','Chris B','Francesca','Ulrike']])
data_list_tel.append([datetime.datetime(2019, 7, 28),2019,"Fiescheralp-Fiesch","Fiesch","Switzerland","cable car",['Ivan','Jose','Chris B','Francesca','Ulrike']])
#2020
data_list_tel.append([datetime.datetime(2020, 2, 20),2020,"Funicolare di Orvieto Scalo-P.Cahen Funicolare","Orvieto","Italy","funicular",[]])
data_list_tel.append([datetime.datetime(2020, 2, 20),2020,"P.Cahen Funicolare-Funicolare Funicolare di Orvieto Scalo","Orvieto","Italy","funicular",[]])
data_list_tel.append([datetime.datetime(2020, 7, 18),2020,"Chamonix-Montenvers","Chamonix","France","rack railway",['Sasha','Juno','Tema','Mikhail']])
data_list_tel.append([datetime.datetime(2020, 7, 18),2020,"Montenvers-Chamonix","Chamonix","France","rack railway",['Sasha','Juno','Tema','Mikhail']])
data_list_tel.append([datetime.datetime(2020, 8, 1),2020,"Blatten-Belalp","Blatten","Switzerland","cable car",['Sam']])
data_list_tel.append([datetime.datetime(2020, 8, 1),2020,"Belalp Bruchegg-Belalp Hohbiel","Belalp","Switzerland","chair lift",['Sam']])
data_list_tel.append([datetime.datetime(2020, 8, 1),2020,"Belalp Hohbiel-Belalp Bruchegg","Belalp","Switzerland","chair lift",['Sam']])
data_list_tel.append([datetime.datetime(2020, 8, 1),2020,"Belalp-Blatten","Belalp","Switzerland","cable car",['Sam']])
data_list_tel.append([datetime.datetime(2020, 7, 18),2020,"Lauterbrunnen-Kleine Scheidegg","Lauterbrunnen","Switzerland","rack railway",['Tema']])
data_list_tel.append([datetime.datetime(2020, 7, 18),2020,"Kleine Scheidegg-Jungfraujoch","Lauterbrunnen","Switzerland","rack railway",['Tema']])
data_list_tel.append([datetime.datetime(2020, 7, 18),2020,"Fiescheralp-Fiesch","Fiesch","Switzerland","gondola lift",['Sasha','Juno','Tema']])
#2021
data_list_tel.append([datetime.datetime(2021, 5, 22),2021,"Hohensalzburg up","Salzburg","Austria","funicular",[]])
data_list_tel.append([datetime.datetime(2021, 5, 24),2021,"Hallstatt Salzberg up","Hallstatt","Austria","funicular",[]])
data_list_tel.append([datetime.datetime(2021, 7, 3),2021,"Dachstein Talstation Krippenstein-Schoenbergalm","Obertraun","Austria","cable car",[]])
data_list_tel.append([datetime.datetime(2021, 7, 3),2021,"Schoenbergalm-Dachsteinbahn Bergstation Krippenstein","Obertraun","Austria","cable car",[]])
data_list_tel.append([datetime.datetime(2021, 7, 3),2021,"Dachsteinbahn Bergstation Krippenstein-Dachsteinbahn Talstation Gjaidalm","Obertraun","Austria","cable car",[]])
data_list_tel.append([datetime.datetime(2021, 7, 3),2021,"Dachsteinbahn Talstation Gjaidalm-Dachsteinbahn Bergstation Krippenstein","Obertraun","Austria","cable car",[]])
data_list_tel.append([datetime.datetime(2021, 7, 3),2021,"Dachsteinbahn Bergstation Krippenstein-Schoenbergalm","Obertraun","Austria","cable car",[]])
data_list_tel.append([datetime.datetime(2021, 7, 3),2021,"Schoenbergalm-Dachstein Talstation Krippenstein","Obertraun","Austria","cable car",[]])
#2023
data_list_tel.append([datetime.datetime(2023, 9, 4),2023,"Dachstein Suedwand up","Ramsau am Dachstein","Austria","cable car",['Artur']])
data_list_tel.append([datetime.datetime(2023, 9, 4),2023,"Dachstein Suedwand down","Ramsau am Dachstein","Austria","cable car",['Artur']])

df_cablecar = pd.DataFrame(data_list_tel,columns=['Date','Year', 'track','place','Country','type of lift','Co-Travellers'])

# %%
df_cablecar_agg=df_cablecar.groupby("Year").agg(cablecar_year=('place','count')).sort_values(by="cablecar_year",ascending=False).reset_index()
df_cablecar_agg.head(25)
# Out:
#     Year  cablecar_year
# 0   2010             77
# 1   2011             36
# 2   2016             26
# 3   2012             19
# 4   2015             13
# 5   2019             12
# 6   2020             11
# 7   2018              9
# 8   2009              9
# 9   2017              8
# 10  2007              8
# 11  2021              8
# 12  2013              7
# 13  2006              4
# 14  2008              4
# 15  1988              4
# 16  2014              3
# 17  1987              2
# 18  2005              2
# 19  2001              2
# 20  1994              2
# 21  1993              2
# 22  1992              2
# 23  1989              2
# 24  2023              2

# %%
df_cablecar_agg=df_cablecar.groupby("Country").agg(cablecar_country=('place','count')).sort_values(by="cablecar_country",ascending=False).reset_index()
df_cablecar_agg.head(25)
# Out:
#        Country  cablecar_country
# 0  Switzerland               162
# 1       France                66
# 2      Austria                26
# 3      Germany                 8
# 4        Italy                 7
# 5        China                 4
# 6        Spain                 2

# %%
#seilbahnen/zahnrad too???

data_list_ships=[]

#1989
data_list_ships.append([datetime.datetime(1989, 6, 10),1989,"Horn",'Bodensee',"Germany",'Reichenau','Bodensee',"Germany",['Artur','Heidrun','Hannsjoerg','Anne-Kathrin','Jan-Marc']])
data_list_ships.append([datetime.datetime(1989, 6, 10),1989,"Reichenau",'Bodensee',"Germany",'Horn','Bodensee',"Germany",['Artur','Heidrun','Hannsjoerg','Anne-Kathrin','Jan-Marc']])
#1991
data_list_ships.append([datetime.datetime(1991, 8, 8),1991,"Ueberlingen",'Bodensee',"Germany",'Mainau','Bodensee',"Germany",['Artur','Heidrun','Hannsjoerg','Anne-Kathrin','Jan-Marc']])
data_list_ships.append([datetime.datetime(1991, 8, 8),1991,"Mainau",'Bodensee',"Germany",'Ueberlingen','Bodensee',"Germany",['Artur','Heidrun','Hannsjoerg','Anne-Kathrin','Jan-Marc']])
#1996
data_list_ships.append([datetime.datetime(1996, 8, 25),1996,"Thun",'Thuner See',"Switzerland",'Neuhaus','Thuner See',"Switzerland",['Artur','Anne-Kathrin','Jan-Marc']])

#1996
data_list_ships.append([datetime.datetime(2000, 8, 27),2000,"Yalova",'Marmara Sea',"Turkey",'Pendik','Marmara Sea',"Turkey",['Artur','Anne-Kathrin','Heidrun','Hannsjoerg']])
data_list_ships.append([datetime.datetime(2000, 8, 29),2000,"Istanbul",'Bosporus',"Turkey",'Istanbul','Bosporus',"Turkey",['Artur','Anne-Kathrin','Heidrun','Hannsjoerg']])
#2003
data_list_ships.append([datetime.datetime(2003, 7, 5),2003,"Bodrum",'Mediterranean Sea',"Turkey",'Bodrum','Mediterranean Sea',"Turkey",['Boeni','Gianrico','Sigi']])
#2005
data_list_ships.append([datetime.datetime(2005, 3, 23),2005,"Luxor",'Nile',"Egypt",'Edfu','Nile',"Egypt",['Artur','Heidrun','Hannsjoerg']])
data_list_ships.append([datetime.datetime(2005, 3, 23),2005,"Edfu",'Nile',"Egypt",'Khom Ombo','Nile',"Egypt",['Artur','Heidrun','Hannsjoerg']])
data_list_ships.append([datetime.datetime(2005, 3, 24),2005,"Khom Ombo",'Nile',"Egypt",'Aswan','Nile',"Egypt",['Artur','Heidrun','Hannsjoerg']])
data_list_ships.append([datetime.datetime(2005, 3, 25),2005,"Aswan",'Nile',"Egypt",'Philae','Nile',"Egypt",['Artur','Heidrun','Hannsjoerg']])
data_list_ships.append([datetime.datetime(2005, 3, 25),2005,"Philae",'Nile',"Egypt",'Aswan','Nile',"Egypt",['Artur','Heidrun','Hannsjoerg']])
data_list_ships.append([datetime.datetime(2005, 3, 25),2005,"Aswan",'Nile',"Egypt",'Aswan','Nile',"Egypt",['Artur','Heidrun','Hannsjoerg']])
data_list_ships.append([datetime.datetime(2005, 9, 4),2005,"Almada",'Tagus',"Portugal",'Tagus','Lisbon',"Portugal",['Artur','Heidrun','Hannsjoerg']])
#2009
data_list_ships.append([datetime.datetime(2009, 4, 11),2009,"Neuhausen Woerth",'Rhine',"Switzerland",'Neuhausen Rhine Falls','Rhine',"Switzerland",['Artur']])
data_list_ships.append([datetime.datetime(2009, 4, 11),2009,"Neuhausen Rhine Falls",'Rhine',"Switzerland",'Laufen am Rheinfall','Rhine',"Switzerland",['Artur']])
data_list_ships.append([datetime.datetime(2009, 6, 28),2009,"Chicago Fields Museum",'Lake Michigan',"USA",'Chicago Navy Pier','Lake Michigan',"USA",[]])
data_list_ships.append([datetime.datetime(2009, 7, 7),2009,"NYC Financial Center",'Hudson River',"USA",'Jersey City','Hudson River',"USA",[]])
data_list_ships.append([datetime.datetime(2009, 7, 7),2009,"Jersey City",'Hudson River',"USA",'NYC Ellis Island','Hudson River',"USA",[]])
data_list_ships.append([datetime.datetime(2009, 7, 7),2009,"NYC Ellis Island",'Hudson River',"USA",'NYC Liberty Island','Hudson River',"USA",[]])
data_list_ships.append([datetime.datetime(2009, 7, 7),2009,"NYC Liberty Island",'Hudson River',"USA",'Jersey City','Hudson River',"USA",[]])
#2010
data_list_ships.append([datetime.datetime(2010, 8, 27),2010,"Brenets",'Lac des Brenets',"Switzerland",'Saut du Doubs','Lac des Brenets',"Switzerland",[]])
#2012
data_list_ships.append([datetime.datetime(2012, 5, 27),2012,"Brienz",'Brienzer See',"Switzerland",'Giessbach','Brienzer See',"Switzerland",['Hannsjoerg']])
data_list_ships.append([datetime.datetime(2012, 5, 27),2012,"Giessbach",'Brienzer See',"Switzerland",'Interlaken','Aare',"Switzerland",['Hannsjoerg']])
data_list_ships.append([datetime.datetime(2012, 5, 27),2012,"Interlaken",'Aare',"Switzerland",'Thun','Thuner See',"Switzerland",['Hannsjoerg']])
data_list_ships.append([datetime.datetime(2012, 7, 27),2012,"Berlin zur Pfaueninsel",'Havel',"Germany",'Berlin Pfaueninsel','Havel',"Germany",[]])
data_list_ships.append([datetime.datetime(2012, 7, 27),2012,"Berlin Pfaueninsel",'Havel',"Germany",'Berlin zur Pfaueninsel','Havel',"Germany",[]])
#2013
data_list_ships.append([datetime.datetime(2013, 7, 23),2012,"Stockholm",'Baltic Sea',"Sweden",'Stockholm','Baltic Sea',"Sweden",['YanYan']])
#2014
data_list_ships.append([datetime.datetime(2014, 4, 19),2014,"Prien",'Chiemsee',"Germany",'Herrenchiemsee','Chiemsee',"Germany",['Eric',"Indara"]])
data_list_ships.append([datetime.datetime(2014, 4, 19),2014,"Herrenchiemsee",'Chiemsee',"Germany",'Prien','Chiemsee',"Germany",['Eric',"Indara"]])
data_list_ships.append([datetime.datetime(2014, 5, 4),2014,"Stresa",'Lago Maggiore',"Italy",'Isola Superiore','Lago Maggiore',"Italy",["Hannsjoerg"]])
data_list_ships.append([datetime.datetime(2014, 5, 4),2014,"Isola Superiore",'Lago Maggiore',"Italy",'Stresa','Lago Maggiore',"Italy",["Hannsjoerg"]])
data_list_ships.append([datetime.datetime(2014, 5, 4),2014,"Stresa",'Lago Maggiore',"Italy",'Isola Madre','Lago Maggiore',"Italy",["Hannsjoerg"]])
data_list_ships.append([datetime.datetime(2014, 5, 4),2014,"Isola Madre",'Lago Maggiore',"Italy",'Isola Bella','Lago Maggiore',"Italy",["Hannsjoerg"]])
data_list_ships.append([datetime.datetime(2014, 5, 4),2014,"Isola Bella",'Lago Maggiore',"Italy",'Baveno','Lago Maggiore',"Italy",["Hannsjoerg"]])
data_list_ships.append([datetime.datetime(2014, 6, 22),2014,"Spiez",'Thuner See',"Switzerland",'Oberhofen','Thuner See',"Switzerland",['Hannsjoerg']])
data_list_ships.append([datetime.datetime(2014, 6, 22),2014,"Oberhofen",'Thuner See',"Switzerland",'Thun','Thuner See',"Switzerland",['Hannsjoerg']])
data_list_ships.append([datetime.datetime(2014, 7, 28),2014,"Portsmouth",'Atlantic Ocean',"United Kingdom",'Fishbourne','Atlantic Ocean',"United Kingdom",['Heidrun']])
data_list_ships.append([datetime.datetime(2014, 7, 28),2014,"Alum Bay",'Atlantic Ocean',"United Kingdom",'Alum Bay','Atlantic Ocean',"United Kingdom",['Heidrun']])
data_list_ships.append([datetime.datetime(2014, 7, 28),2014,"East Cowes",'Atlantic Ocean',"United Kingdom",'Southampton','Atlantic Ocean',"United Kingdom",['Heidrun']])
data_list_ships.append([datetime.datetime(2014, 10, 26),2014,"Yoros",'Bosporus',"Turkey",'Istanbul','Bosporus',"Turkey",['Chris M']])
#2015
data_list_ships.append([datetime.datetime(2015, 9, 3),2015,"St Petersburg",'Nerva',"Russia",'Peterhof','Nerva',"Baltic Sea",[]])
data_list_ships.append([datetime.datetime(2015, 9, 5),2015,"St Petersburg",'Nerva',"Russia",'St Petersburg','Nerva',"Russia",['Manuel','Nathan']])
data_list_ships.append([datetime.datetime(2015, 10, 7),2015,"Tegernsee",'Tegernsee',"Germany",'Tegernsee','Tegernsee',"Germany",['Manuel','Nathan']])
data_list_ships.append([datetime.datetime(2015, 11, 9),2015,"Hamburg St Pauli",'Elbe',"Germany",'Hamburg St Pauli','Elbe',"Germany",['Artur','Anne-Kathrin','Heidrun']])
#2016
data_list_ships.append([datetime.datetime(2016, 7, 5),2016,"Monterosso al Mare",'Mediterranean Sea',"Italy",'Riomaggiore','Mediterranean Sea',"Italy",['Amin']])
data_list_ships.append([datetime.datetime(2016, 12, 15),2016,"Miyajimaguchi",'Seto Inland Sea',"Japan",'Miyajima','Seto Inland Sea',"Japan",[]])
data_list_ships.append([datetime.datetime(2016, 12, 15),2016,"Miyajima",'Seto Inland Sea',"Japan",'Miyajimaguchi','Seto Inland Sea',"Japan",[]])
#2017
data_list_ships.append([datetime.datetime(2017, 10, 7),2017,"Tallin",'Baltic Sea',"Estonia",'Helsinki','Baltic Sea',"Finland",['Rachel','Riju','Reyer']])
data_list_ships.append([datetime.datetime(2017, 10, 7),2017,'Helsinki','Baltic Sea',"Finland","Tallin",'Baltic Sea',"Estonia",['Rachel','Riju','Reyer']])
#2018
data_list_ships.append([datetime.datetime(2018, 1, 16),2018,"Hong Kong",'South China Sea',"China",'Macau','South China Sea',"China",[]])
data_list_ships.append([datetime.datetime(2018, 1, 16),2018,'Macau','South China Sea',"China","Hong Kong",'South China Sea',"China",[]])
#2019
data_list_ships.append([datetime.datetime(2019, 6, 16),2019,"Lucerne",'Vierwaldstaetter See',"Switzerland",'Weggis','Vierwaldstaetter See',"Switzerland",['Rachel','Riju','Chris B']])
#2020
data_list_ships.append([datetime.datetime(2020, 6, 2),2020,"Murg",'Walensee',"Switzerland",'Quinten','Walensee',"Switzerland",['Juno']])
#2021
data_list_ships.append([datetime.datetime(2021, 5, 24),2021,"Hallstatt",'Hallstaetter See',"Austria",'Hallstatt','Hallstaetter See',"Austria",[]])
#2022
data_list_ships.append([datetime.datetime(2022, 5, 25),2022,"Budapest",'Danube',"Hungary",'Budapest','Danube',"Hungary",["Chris M"]])
data_list_ships.append([datetime.datetime(2022, 8, 1),2022,"Napoli",'Mediterranean Sea',"Italy",'Capri','Mediterranean Sea',"Italy",["Riju"]])
data_list_ships.append([datetime.datetime(2022, 8, 1),2022,'Capri','Mediterranean Sea',"Italy","Napoli",'Mediterranean Sea',"Italy",["Riju"]])
#2023
data_list_ships.append([datetime.datetime(2023, 3, 5),2023,'Portimao','Atlantic Ocean',"Portugal","Portimao",'Atlantic Ocean',"Portugal",[]])
data_list_ships.append([datetime.datetime(2023, 3, 12),2023,'Porto','Douro',"Portugal","Porto",'Douro',"Portugal",['Artur']])
data_list_ships.append([datetime.datetime(2023, 7, 23),2023,'Helsingor','Northern Sea',"Denmark","Helsingborg",'Northern Sea',"Sweden",[]])
data_list_ships.append([datetime.datetime(2023, 10, 26),2023,'Nynaeshamn','Baltic Sea',"Sweden","Visby",'Baltic Sea',"Sweden",[]])
data_list_ships.append([datetime.datetime(2023, 10, 27),2023,'Visby','Baltic Sea',"Sweden","Nynaeshamn",'Baltic Sea',"Sweden",[]])
data_list_ships.append([datetime.datetime(2023, 10, 30),2023,'Karlskrona','Baltic Sea',"Sweden","Aspoe",'Baltic Sea',"Sweden",[]])
data_list_ships.append([datetime.datetime(2023, 10, 30),2023,"Aspoe",'Baltic Sea',"Sweden",'Karlskrona','Baltic Sea',"Sweden",[]])
#2024
data_list_ships.append([datetime.datetime(2024, 6, 29),2024,'Spitz an der Donau','Danube',"Austria","Oberarnsdorf",'Danube',"Austria",[]])
data_list_ships.append([datetime.datetime(2024, 6, 29),2024,'St Lorenz','Danube',"Austria","Weissenkirchen in der Wachau",'Danube',"Austria",[]])
data_list_ships.append([datetime.datetime(2024, 9, 16),2024,'Kinderdijk','Nieuwe Maas',"Netherlands","Rotterdam",'Nieuwe Maas',"Netherlands",[]])

df_ships = pd.DataFrame(data_list_ships,columns=['Date','Year','Origin','origin body of water','Origin Country','Destination','destination body of water','Destination Country','Co-Travellers'])
df_ships
# Out:
#          Date  Year              Origin origin body of water Origin Country  \
# 0  1989-06-10  1989                Horn             Bodensee        Germany
# 1  1989-06-10  1989           Reichenau             Bodensee        Germany
# 2  1991-08-08  1991         Ueberlingen             Bodensee        Germany
# 3  1991-08-08  1991              Mainau             Bodensee        Germany
# 4  1996-08-25  1996                Thun           Thuner See    Switzerland
# ..        ...   ...                 ...                  ...            ...
# 64 2023-10-30  2023          Karlskrona           Baltic Sea         Sweden
# 65 2023-10-30  2023               Aspoe           Baltic Sea         Sweden
# 66 2024-06-29  2024  Spitz an der Donau               Danube        Austria
# 67 2024-06-29  2024           St Lorenz               Danube        Austria
# 68 2024-09-16  2024          Kinderdijk          Nieuwe Maas    Netherlands
#
# ...

# %%
df_ship_agg=df_ships.groupby("Origin Country").agg(ship_country=('Origin','count')).sort_values(by="ship_country",ascending=False).reset_index()
df_ship_agg.head(25)
# Out:
#     Origin Country  ship_country
# 0      Switzerland            11
# 1          Germany            10
# 2            Italy             8
# 3            Egypt             6
# 4              USA             5
# 5           Sweden             5
# 6           Turkey             4
# 7          Austria             3
# 8         Portugal             3
# 9   United Kingdom             3
# 10           China             2
# 11          Russia             2
# 12           Japan             2
# 13     Netherlands             1
# 14         Hungary             1
# 15         Finland             1
# 16         Estonia             1
# 17         Denmark             1

# %%
df_ships_agg=df_ships.groupby("Year").agg(ship_year=('Origin','count')).sort_values(by="ship_year",ascending=False).reset_index()
df_ships_agg.head(25)
# Out:
#     Year  ship_year
# 0   2014         13
# 1   2023          7
# 2   2005          7
# 3   2009          7
# 4   2012          6
# 5   2015          4
# 6   2022          3
# 7   2016          3
# 8   2024          3
# 9   1991          2
# 10  2017          2
# 11  2018          2
# 12  2000          2
# 13  1989          2
# 14  2010          1
# 15  2003          1
# 16  2019          1
# 17  2020          1
# 18  2021          1
# 19  1996          1
