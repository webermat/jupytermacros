# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime as dt

# %%
data_list=[]
#album type: 1 yes, 2 live album, 3 best of, 4 sound track, 5 musical
#year release/album name/artist/album type/earliest released song/latest released song
#/number of discs/number of songs/duration of album/genre
data_list.append([1995,"Hits Unlimited","2 Unlimited",3,1991,1995,1,16,dt.timedelta(minutes = 60, seconds=40),'Eurodance'])
data_list.append([1998,"Greatest Hits","2 Pac",3,1991,1998,2,25,dt.timedelta(hours=1,minutes = 54, seconds=43),'Hip Hop'])
data_list.append([2010,"25","a-ha",3,1985,2010,2,39,dt.timedelta(minutes = 156, seconds=46),'Pop'])
data_list.append([2001,"The Definite Collection","ABBA",3,1972,1983,2,39,dt.timedelta(minutes = 147, seconds=38),'Pop'])
data_list.append([2010,"Iron Man 2","AC/DC",3,1975,2008,1,15,dt.timedelta(minutes = 60, seconds=15),'Hard Rock'])
data_list.append([2011,"21","Adele",1,2011,2011,1,11,dt.timedelta(minutes = 48, seconds=12),'Pop'])
data_list.append([2002,"The Essential Aerosmith","Aerosmith",3,1972,2002,2,30,dt.timedelta(minutes = 132, seconds=7),'Hard Rock'])
data_list.append([1995,"Jagged Little Pill","Alanis Morisette",1,1995,1995,1,13,dt.timedelta(minutes = 57, seconds=23),'Pop Rock'])
data_list.append([2004,"So-Called Chaos","Alanis Morisette",1,2004,2004,1,10,dt.timedelta(minutes = 41, seconds=5),'Pop Rock'])
data_list.append([2003,"Speakerboxxx/The Love Below","Outkast",1,2003,2003,2,39,dt.timedelta(minutes = 134, seconds=44),'Hip Hop'])
data_list.append([1996,"Evita OST","Madonna, Antonio Banderas et al",4,1996,1996,1,19,dt.timedelta(minutes = 77, seconds=17),'Pop'])
data_list.append([2006,"Whatever People Say I Am, That's What I'm Not","Arctic Monkeys",1,2006,2006,1,13,dt.timedelta(minutes = 40, seconds=56),'Rock'])
data_list.append([2007,"Favourite Worst Nightmare","Arctic Monkeys",1,2007,2007,1,12,dt.timedelta(minutes = 37, seconds=18),'Rock'])
data_list.append([2002,"Respect: The Very Best Of Aretha Franklin","Aretha Franklin",3,1967,1994,2,43,dt.timedelta(hours=2,minutes = 35, seconds=48),'Soul'])
data_list.append([2001,"The Hits - Chapter One","Backstreet Boys",3,1995,2001,1,16,dt.timedelta(minutes = 65, seconds=3),'Pop'])
data_list.append([2001,"The Ultimate Bee Gees","Bee Gees",3,1967,2001,2,40,dt.timedelta(minutes = 146, seconds=50),'Pop'])
data_list.append([2003,"Dangerously In Love","Beyonce",1,2003,2003,1,15,dt.timedelta(minutes = 60, seconds=52),'R&B'])
data_list.append([2006,"B'Day","Beyonce",1,2006,2006,1,14,dt.timedelta(minutes = 51, seconds=8),'R&B'])
data_list.append([2001,"Greatest Hits","Billy Idol",3,1981,1993,1,16,dt.timedelta(minutes = 71, seconds=50),'Punk Rock'])
data_list.append([2007,"A Weekend In The City","Bloc Party",1,2007,2007,1,12,dt.timedelta(minutes = 51, seconds=13),'Punk Rock'])
data_list.append([2002,"Greatest Hits","Blondie",3,1976,1998,1,19,dt.timedelta(minutes = 67, seconds=53),'New Wave'])
data_list.append([2012,"The Essential Boney M","Boney M",3,1975,2010,2,36,dt.timedelta(minutes = 140, seconds=14),'Pop Rock'])
data_list.append([2003,"In The Zone","Britney Spears",1,2003,2003,1,14,dt.timedelta(minutes = 50, seconds=2),'Pop'])
data_list.append([2007,"Blackout","Britney Spears",1,2007,2007,1,12,dt.timedelta(minutes = 43, seconds=37),'Pop'])
data_list.append([2004,"Greatest Hits: My Prerogative","Britney Spears",3,1998,2004,1,19,dt.timedelta(minutes = 67, seconds=37),'Pop'])
data_list.append([1984,"Born In The U.S.A","Bruce Springsteen",1,1984,1984,1,12,dt.timedelta(minutes = 46, seconds=57),'Rock'])
data_list.append([2008,"My Love: Essential Collection","Celine Dion",3,1990,2008,2,36,dt.timedelta(minutes = 158, seconds=11),'Pop'])
data_list.append([2000,"The Anthology","Chuck Berry",3,1955,1973,2,50,dt.timedelta(minutes = 130, seconds=57),'Rock and Roll'])
data_list.append([2016,"4ever","Prince",3,1977,1993,2,40,dt.timedelta(minutes = 169, seconds=8),'Pop'])
data_list.append([2008,"808s & Heartbreak","Kanye West",1,2008,2008,1,12,dt.timedelta(minutes = 51, seconds=58),'R&B'])
data_list.append([2004,"All The Best","Tina Turner",3,1966,2004,2,33,dt.timedelta(minutes = 143, seconds=1),'R&B'])
data_list.append([2005,"Anthology","Bryan Adams",3,1978,2005,2,36,dt.timedelta(minutes = 155, seconds=57),'Rock'])
data_list.append([2016,"Anti","Rihanna",1,2016,2016,1,13,dt.timedelta(minutes = 43, seconds=36),'R&B'])
data_list.append([2008,"Brass Knuckles","Nelly",1,2008,2008,1,14,dt.timedelta(minutes = 58, seconds=15),'Hip Hop'])
data_list.append([2015,"Elvis Forever","Elvis Presley",3,1954,2003,2,61,dt.timedelta(minutes = 158, seconds=15),'Rock and Roll'])
data_list.append([2006,"Gold","Lionel Richie",3,1974,2000,2,32,dt.timedelta(hours=2,minutes = 38, seconds=34),'Pop'])
data_list.append([2002,"Greatest Hits 1970-2002","Elton John",3,1970,2002,2,32,dt.timedelta(hours=2,minutes = 36, seconds=46),'Rock'])
data_list.append([1991,"Greatest Hits II","Queen",3,1980,1990,1,17,dt.timedelta(minutes = 75, seconds=57),'Rock'])
data_list.append([2005,"Greatest Hitz","Limp Bizkit",3,1997,2005,1,17,dt.timedelta(minutes = 71, seconds=11),'Nu Metal'])
data_list.append([2008,"I Am... Sasha Fierce","Beyonce",1,2008,2008,1,20,dt.timedelta(minutes = 74, seconds=29),'R&B'])
data_list.append([2008,"Keeps Gettin' Better: A Decade of Hits","Christina Aguilera",3,1998,2008,1,16,dt.timedelta(minutes = 62, seconds=55),'Pop'])
data_list.append([2010,"Last Train To Paris","Diddy – Dirty Money",1,2010,2010,1,16,dt.timedelta(minutes = 64, seconds=32),'Pop'])
data_list.append([2009,"Liebe ist für alle da","Rammstein",1,2009,2009,2,16,dt.timedelta(minutes = 68, seconds=21),'Industrial Metal'])
data_list.append([2010,"Loud","Rihanna",1,2010,2010,1,11,dt.timedelta(minutes = 46, seconds=39),'R&B'])
data_list.append([2019,"Madame X","Madonna",1,2019,2019,2,18,dt.timedelta(minutes = 77, seconds=41),'Pop'])
data_list.append([2010,"Man on the Moon II: The Legend of Mr. Rager","Kid Cudi",1,2010,2010,1,17,dt.timedelta(minutes = 62, seconds=6),'Hip Hop'])
data_list.append([2010,"My Beautiful Dark Twisted Fantasy","Kanye West",1,2010,2010,1,13,dt.timedelta(minutes = 68, seconds=36),'Hip Hop'])
data_list.append([2003,"PopArt: The Hits","Pet Shop Boys",3,1985,2003,2,35,dt.timedelta(minutes = 147, seconds=19),'Traditional Pop'])
data_list.append([2009,"R.O.O.T.S.","Flo Rida",1,2009,2009,1,13,dt.timedelta(minutes = 50, seconds=50),'Hip Hop'])
data_list.append([2013,"Racine carree","Stromae",1,2013,2013,1,13,dt.timedelta(minutes = 46, seconds=4),'Hip Hop'])
data_list.append([2009,"Rated R","Rihanna",1,2009,2009,1,13,dt.timedelta(minutes = 51, seconds=48),'R&B'])
data_list.append([2010,"Recovery","Eminem",1,2010,2010,1,17,dt.timedelta(minutes = 76, seconds=56),'Hip Hop'])
data_list.append([2007,"Shakedown","Freemasons",1,2007,2007,2,29,dt.timedelta(minutes = 170, seconds=26),'Dance'])
data_list.append([1982,"The Best Of Quincy Jones","Quincy Jones",3,1963,1981,1,16,dt.timedelta(minutes = 170, seconds=26),'R&B'])
data_list.append([2009,"The Blueprint 3","Jay-Z",1,2009,2009,1,15,dt.timedelta(minutes = 60, seconds=44),'Hip Hop'])
data_list.append([2005,"The Collection","Alanis Morisette",3,1995,2005,1,18,dt.timedelta(minutes = 75, seconds=45),'Pop Rock'])
data_list.append([2011,"The Greatest","Diana Ross",3,1964,2005,2,44,dt.timedelta(minutes = 160, seconds=13),'R&B'])
data_list.append([2011,"The Singles Collection 2001–2011","Gorillaz",3,2001,2011,1,15,dt.timedelta(minutes = 56, seconds=10),'R&B'])
data_list.append([1995,"Michael Jackson: The Very Best Of Michael Jackson With The Jackson Five","Jackson Five",3,1969,1995,1,21,dt.timedelta(minutes = 74, seconds=17),'R&B'])
data_list.append([2015,"Unbreakable","Janet Jackson",1,2015,2015,1,17,dt.timedelta(minutes = 64, seconds=37),'R&B'])
data_list.append([2017,"Witness","Katy Perry",1,2017,2017,1,15,dt.timedelta(minutes = 57, seconds=28),'Dance'])
data_list.append([1999,"Universal Masters Collection","James Brown",3,1958,1988,1,18,dt.timedelta(minutes = 0, seconds=0),'Funk'])
data_list.append([2001,"Best Of Culture Beat","Culture Beat",3,1989,1998,1,15,dt.timedelta(minutes = 69, seconds=16),'Funk'])
data_list.append([2009,"True Colors: The Best of Cyndi Lauper","Cindy Lauper",3,1983,1996,2,36,dt.timedelta(minutes = 139, seconds=3),'Pop'])
data_list.append([2013,"Random Access Memories","Daft Punk",1,2013,2013,1,13,dt.timedelta(minutes = 74, seconds=24),'Dance'])
data_list.append([2006,"The Hits & Beyond","Danii Minogue",3,1989,2006,1,20,dt.timedelta(minutes = 76, seconds=45),'Dance'])
data_list.append([2002,"Best of Bowie","David Bowie",3,1969,2002,1,20,dt.timedelta(minutes = 87, seconds=44),'Rock'])
data_list.append([2009,"One Love","David Guetta",1,2009,2009,1,15,dt.timedelta(minutes = 55, seconds=18),'EDM'])
data_list.append([2010,"That's the Way I Like It: The Best of Dead or Alive","Dead Or Alive",3,1983,1989,1,15,dt.timedelta(minutes = 55, seconds=18),'EDM'])
data_list.append([1990,"Violator","Depeche Mode",1,1990,1990,1,9,dt.timedelta(minutes = 47, seconds=2),'Synthpop'])
data_list.append([2006,"The Best of Depeche Mode Volume 1","Depeche Mode",3,1981,2005,2,23,dt.timedelta(minutes = 74, seconds=56),'Synthpop'])
data_list.append([2009,"Tongue n' Cheek","Dizzee Rascal",1,2009,2009,1,11,dt.timedelta(minutes = 41, seconds=32),'Hip Hop'])
data_list.append([2014,"Best Of","DJ Bobo",3,1992,2010,1,20,dt.timedelta(minutes = 69, seconds=27),'Eurodance'])
data_list.append([2002,"Greatest Hits","Will Smith",3,1987,2002,1,15,dt.timedelta(minutes = 62, seconds=4),'Hip Hop'])
data_list.append([1999,"Universal Masters Collection","Donna Summer",3,1975,1983,1,18,dt.timedelta(minutes = 0, seconds=0),'Disco'])
data_list.append([1997,"The Very Best of 1990–1997","Dr Alban",3,1990,1997,1,16,dt.timedelta(minutes = 70, seconds=47),'Eurodance'])
data_list.append([1999,"2001","Dr Dre",1,1999,1999,1,22,dt.timedelta(minutes = 68, seconds=1),'Hip Hop'])
data_list.append([1998,"Greatest","Duran Duran",3,1980,1997,1,19,dt.timedelta(minutes = 78, seconds=14),'New Wave'])
data_list.append([1992,"Walthamstow","East 17",1,1992,1992,1,14,dt.timedelta(minutes = 66, seconds=7),'Pop'])
data_list.append([2005,"Curtain Call: The Hits","Eminem",3,1999,2005,1,17,dt.timedelta(hours=1,minutes = 17, seconds=55),'Hip Hop'])
data_list.append([1985,"Be Yourself Tonight","Eurythmics",1,1985,1985,1,9,dt.timedelta(minutes = 43, seconds=15),'Pop'])
data_list.append([2009,"Insomnia: The Best of Faithless","Faithless",3,1996,2004,1,9,dt.timedelta(minutes = 146, seconds=24),'Dance'])
data_list.append([2017,"Falco 60","Falco",3,1981,1998,2,37,dt.timedelta(minutes = 229, seconds=42),'Pop'])
data_list.append([1988,"Greatest Hits","Fleetwood Mac",3,1975,1988,1,17,dt.timedelta(minutes = 66, seconds=45),'Rock'])
data_list.append([2008,"Mail On Sunday","Flo Rida",1,2008,2008,1,14,dt.timedelta(minutes = 53, seconds=21),'Hip Hop'])
data_list.append([1992,"The Very Best...And Beyond","Foreigner",3,1977,1992,1,17,dt.timedelta(minutes = 73, seconds=10),'Rock'])
data_list.append([2009,"Frankie Say Greatest","Frankie Goes To Hollywood",3,1983,1987,1,17,dt.timedelta(minutes = 76, seconds=34),'Rock'])
data_list.append([1988,"Frankie Say Greatest","Freddie Mercury and Montserrat Caballe",1,1988,1988,1,8,dt.timedelta(minutes = 39, seconds=56),'Classic Crossover'])
data_list.append([2004,"Platinum Collection","Genesis",3,1970,1997,3,40,dt.timedelta(hours=3,minutes = 54, seconds=29),'Rock'])
data_list.append([2004,"Patience","George Michael",1,2004,2004,1,14,dt.timedelta(minutes = 70, seconds=15),'Pop'])
data_list.append([2006,"Twenty Five","George Michael",3,1984,2006,2,31,dt.timedelta(minutes = 73, seconds=25),'Pop'])
data_list.append([2012,"Ten","Girls Aloud",3,2002,2012,1,18,dt.timedelta(minutes = 68, seconds=0),'Pop'])
data_list.append([2008,"The Odd Couple","Gnarls Barkley",1,2008,2008,1,13,dt.timedelta(minutes = 39, seconds=12),'Soul'])
data_list.append([2004,"American Idiot","Green Day",1,2004,2004,1,13,dt.timedelta(minutes = 57, seconds=14),'Rock'])
data_list.append([1987,"Appetite For Destruction","Guns N'Roses",1,1987,1987,1,12,dt.timedelta(minutes = 53, seconds=52),'Hard Rock'])
data_list.append([1988,"G N'R Lies","Guns N'Roses",1,1988,1988,1,8,dt.timedelta(minutes = 33, seconds=31),'Hard Rock'])
data_list.append([1991,"Use Your Illusion I","Guns N'Roses",1,1991,1991,1,16,dt.timedelta(minutes = 76, seconds=9),'Hard Rock'])
data_list.append([1991,"Use Your Illusion II","Guns N'Roses",1,1991,1991,1,14,dt.timedelta(minutes = 76, seconds=9),'Hard Rock'])
data_list.append([2008,"Chinese Democracy","Guns N'Roses",1,2008,2008,1,14,dt.timedelta(minutes = 71, seconds=18),'Hard Rock'])
data_list.append([2004,"Best of Haddaway: What Is Love","Haddaway",3,1993,1998,1,17,dt.timedelta(minutes = 73, seconds=27),'Eurodance'])
data_list.append([2003,"State Of Mind","Holly Valance",1,2003,2003,1,12,dt.timedelta(minutes = 42, seconds=7),'Dance'])
data_list.append([2003,"The Very Best Of Ike & Tina Turner","Ike & Tina Turner",3,2003,2003,1,18,dt.timedelta(minutes = 42, seconds=7),'Dance'])
data_list.append([2011,"The Very Best","INXS",3,1980,2011,1,20,dt.timedelta(minutes = 75, seconds=14),'Rock'])
data_list.append([1986,"Control","Janet Jackson",1,1986,1986,1,9,dt.timedelta(minutes = 41, seconds=41),'R&B'])
data_list.append([1989,"Rhythm Nation 1814","Janet Jackson",1,1989,1989,1,20,dt.timedelta(minutes = 64, seconds=34),'R&B'])
data_list.append([1993,"Janet","Janet Jackson",1,1993,1993,1,28,dt.timedelta(minutes = 75, seconds=23),'R&B'])
data_list.append([1997,"The Velvet Rope","Janet Jackson",1,1997,1997,1,22,dt.timedelta(minutes = 75, seconds=23),'R&B'])
data_list.append([2004,"Damita Jo","Janet Jackson",1,2004,2004,1,22,dt.timedelta(minutes = 65, seconds=2),'R&B'])
data_list.append([2006,"20 Y.O.","Janet Jackson",1,2006,2006,1,16,dt.timedelta(minutes = 49, seconds=54),'R&B'])
data_list.append([2008,"Discipline","Janet Jackson",1,2008,2008,1,22,dt.timedelta(minutes = 53, seconds=55),'R&B'])
data_list.append([1999,"On The 6","Jennifer Lopez",1,1999,1999,1,14,dt.timedelta(minutes = 64, seconds=1),'R&B'])
data_list.append([2001,"J. Lo","Jennifer Lopez",1,2001,2001,1,15,dt.timedelta(minutes = 61, seconds=30),'R&B'])
data_list.append([2007,"Brave","Jennifer Lopez",1,2007,2007,1,13,dt.timedelta(minutes = 47, seconds=53),'R&B'])
data_list.append([2011,"Love?","Jennifer Lopez",1,2011,2011,1,13,dt.timedelta(minutes = 46, seconds=58),'R&B'])
data_list.append([2012,"All The Best","Jethro Tull",3,2011,2011,2,40,dt.timedelta(minutes = 156, seconds=24),'Rock'])


























df = pd.DataFrame(data_list,columns=['Release Year', 'Album Name', 'Artist','Album Type','Earliest Year of Song',
                                     'Last Year of Song','Discs','Number of Songs','playlist duration','genre'])
df.to_csv("../data/music_albumInfo.csv")
df
# Out:
#      Release Year               Album Name          Artist  Album Type  \
# 0            1995           Hits Unlimited     2 Unlimited           3
# 1            1998            Greatest Hits           2 Pac           3
# 2            2010                       25            a-ha           3
# 3            2001  The Definite Collection            ABBA           3
# 4            2010               Iron Man 2           AC/DC           3
# ..            ...                      ...             ...         ...
# 110          1999                 On The 6  Jennifer Lopez           1
# 111          2001                    J. Lo  Jennifer Lopez           1
# 112          2007                    Brave  Jennifer Lopez           1
# 113          2011                    Love?  Jennifer Lopez           1
# 114          2012             All The Best     Jethro Tull           3
#
#      Earliest Year of Song  Last Year of Song  Discs  Number of Songs  \
# ...
