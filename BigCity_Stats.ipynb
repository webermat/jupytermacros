# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime

# %%
data_list=[]
data_list.append([datetime.datetime(1996, 8, 25),datetime.datetime(2017, 8, 25),7,1,9.79,14.26
    ,"London","United Kingdom",['Jan-Marc','Heidrun','Artur','Anne-Kathrin','Hannsjoerg',
    'Anne','Sigi','Gianrico','Manuel','Riju','Hossein','Clive']])
data_list.append([datetime.datetime(1996, 8, 25),datetime.datetime(2022, 8, 25),7,1,1.49,2.61
    ,"Munich","Germany",['Jan-Marc','Heidrun','Artur','Anne-Kathrin','Hannsjoerg',
    'Vera','Helmut','Reyer','Siyi','Eric','Indara','Chris B']])
data_list.append([datetime.datetime(1992, 8, 25),datetime.datetime(2022, 8, 25),5,7,1.07,3.60
    ,"Cologne","Germany",['Jan-Marc','Heidrun','Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1997, 8, 25),datetime.datetime(2020, 8, 25),4,1,2.86,4.34
    ,"Rome","Italy",['Jan-Marc','Heidrun','Artur','Anne-Kathrin','Hannsjoerg',
                   'Amin','Riju']])
data_list.append([datetime.datetime(1998, 8, 25),datetime.datetime(2020, 8, 25),11,1,2.85,12.0
    ,"Paris","France",['Jan-Marc','Heidrun','Artur','Anne-Kathrin','Hannsjoerg',
        'Chris B','Riju','Reyer','Christine','Chris L','Chris C','Michael',"Nhi",
        'Andrew','Vivan','Sam','Eric']])
data_list.append([datetime.datetime(1999, 8, 25),datetime.datetime(2018, 6, 6),2,1,3.04,3.72
    ,"Athens","Greece",['Jan-Marc','Heidrun','Artur','Anne-Kathrin','Hannsjoerg',
        'MaryAnn','Riju','Amin']])
data_list.append([datetime.datetime(2000, 8, 25),datetime.datetime(2014, 8, 25),2,1,15.91,15.91
    ,"Istanbul","Turkey",['Heidrun','Artur','Anne-Kathrin','Hannsjoerg','Chris M']])
data_list.append([datetime.datetime(2000, 8, 25),datetime.datetime(2000, 8, 25),1,3,1.34,2.62
    ,"Antalya","Turkey",['Heidrun','Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(2000, 8, 25),datetime.datetime(2000, 8, 25),1,2,2.00,3.10
    ,"Bursa","Turkey",['Heidrun','Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(2001, 8, 25),datetime.datetime(2018, 8, 25),2,1,1.62,5.47
        ,"Barcelona","Spain",['Riju','Rachel']])
data_list.append([datetime.datetime(2001, 8, 25),datetime.datetime(2022, 8, 25),5,1,3.68,4.47
    ,"Berlin","Germany",['Heidrun','Artur','Anne-Kathrin','Hannsjoerg','Gianrico','Riju','Reyer',
                        'Chris B']])
data_list.append([datetime.datetime(2001, 8, 25),datetime.datetime(2001, 8, 25),1,2,3.36,4.27
    ,"Casablanca","Morocco",['Heidrun','Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(2001, 8, 25),datetime.datetime(2001, 8, 25),1,2,1.11,2.74
    ,"Fez","Morocco",['Heidrun','Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(2001, 8, 25),datetime.datetime(2001, 8, 25),1,1,1.11,2.74
    ,"Rabat","Morocco",['Heidrun','Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(2005, 8, 25),datetime.datetime(2005, 8, 25),1,1,10.10,21.90
    ,"Cairo","Egypt",['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2005, 8, 25),datetime.datetime(2005, 8, 25),1,1,4.49,9.20
    ,"Giza","Egypt",['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2008, 8, 25),datetime.datetime(2008, 8, 25),1,1,1.57,5.70
    ,"Phildalphia","USA",[]])
data_list.append([datetime.datetime(2008, 8, 25),datetime.datetime(2022, 8, 25),5,1,3.22,6.21
    ,"Madrid","Spain",['Heidrun','Artur','Hannsjoerg','Eric','Manuel','Maria']])
data_list.append([datetime.datetime(2008, 8, 25),datetime.datetime(2016, 8, 25),3,4,2.75,8.67
    ,"Chicago","USA",['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2009, 8, 25),datetime.datetime(2009, 8, 25),3,1,8.80,19.42
    ,"New York City","USA",['Kendal']])
data_list.append([datetime.datetime(2011, 8, 25),datetime.datetime(2022, 8, 25),6,1,1.37,4.34
    ,"Milan","Italy",['Hannsjoerg','Andrew','Nick','Kennedy','Aaron','Nate','Can','Devin',
                     'Laser','Christine','Riju','Amin','Keyvan']])
data_list.append([datetime.datetime(2011, 12, 27),datetime.datetime.now().date(),2,1,1.95,2.89
    ,"Vienna","Austria",['Hannsjoerg','Artur','Heidrun','Namrata','Chris M','Michael','Vivan','Riju',
                     'Monica','Sasha','Rachel']])
data_list.append([datetime.datetime(2012, 8, 25),datetime.datetime(2022, 8, 25),3,1,1.28,2.71
    ,"Prague","Czech Republic",['Heidrun','Artur','Riju','Karen']])
data_list.append([datetime.datetime(2012, 8, 25),datetime.datetime(2022, 8, 25),2,1,1.86,3.10
    ,"Warsaw","Poland",['Eric']])
data_list.append([datetime.datetime(2013, 8, 25),datetime.datetime(2023, 7, 23),4,1,1.37,2.14
    ,"Copenhagen","Denmark",['Rachel','Reyer','Riju','Susanne']])
data_list.append([datetime.datetime(2014, 8, 25),datetime.datetime(2022, 8, 25),3,1,1.75,3.00
    ,"Budapest","Hungary",['Chris M','Artur']])
data_list.append([datetime.datetime(2015, 8, 25),datetime.datetime(2015, 8, 25),1,1,3.99,12.24
    ,"Los Angeles","USA",['Eric','Cameron']])
data_list.append([datetime.datetime(2015, 8, 25),datetime.datetime(2015, 8, 25),1,1,13.01,17.00
    ,"Moscow","Russia",['Manuel']])
data_list.append([datetime.datetime(2015, 8, 25),datetime.datetime(2015, 8, 25),1,1,5.35,5.35
    ,"St Petersburg","Russia",['Manuel','Nathan']])
data_list.append([datetime.datetime(2015, 8, 25),datetime.datetime(2022, 8, 25),1,1,1.91,2.48
    ,"Hamburg","Germany",['Heidrun','Artur','Anne-Kathrin']])
data_list.append([datetime.datetime(2016, 8, 25),datetime.datetime(2018, 8, 25),4,1,1.22,2.50
    ,"Brussels","Belgium",['Riju','Rachel','Mohammed','Tomislav']])
data_list.append([datetime.datetime(2016, 8, 25),datetime.datetime(2016, 8, 25),1,1,13.99,39.10
    ,"Tokyo","Japan",[]])
data_list.append([datetime.datetime(2016, 8, 25),datetime.datetime(2016, 8, 25),1,1,1.46,3.78
    ,"Kyoto","Japan",[]])
data_list.append([datetime.datetime(2016, 8, 25),datetime.datetime(2016, 8, 25),1,1,1.20,1.43
    ,"Hiroshima","Japan",[]])
data_list.append([datetime.datetime(2016, 8, 25),datetime.datetime(2016, 8, 25),1,1,2.75,19.3
    ,"Osaka","Japan",[]])
data_list.append([datetime.datetime(2017, 8, 25),datetime.datetime(2017, 8, 25),1,1,2.96,3.48
    ,"Kyiv","Ukraine",[]])
data_list.append([datetime.datetime(2018, 8, 25),datetime.datetime(2018, 8, 25),1,1,24.88,41.35
    ,"Shanghai","China",['Siyi']])
data_list.append([datetime.datetime(2018, 8, 25),datetime.datetime(2018, 8, 25),1,3,6.72,12.75
    ,"Suzhou","China",[]])
data_list.append([datetime.datetime(2018, 8, 25),datetime.datetime(2018, 8, 25),1,1,10.71,11.94
    ,"Hangzhou","China",[]])
data_list.append([datetime.datetime(2018, 8, 25),datetime.datetime(2018, 8, 25),1,2,1.64,1.64
    ,"Kunshan","China",['Siyi']])
data_list.append([datetime.datetime(2018, 8, 25),datetime.datetime(2018, 8, 25),1,1,9.31,9.65
    ,"Nanjing","China",['Siyi']])
data_list.append([datetime.datetime(2018, 8, 25),datetime.datetime(2018, 8, 25),1,1,21.89,22.36
    ,"Beijing","China",['Selena']])
data_list.append([datetime.datetime(2018, 8, 25),datetime.datetime(2018, 8, 25),1,1,2.25,7.06
    ,"Luoyang","China",[]])
data_list.append([datetime.datetime(2018, 8, 25),datetime.datetime(2018, 8, 25),1,2,11.90,12.28
    ,"Xi'an","China",[]])
data_list.append([datetime.datetime(2018, 8, 25),datetime.datetime(2018, 8, 25),1,1,7.29,7.29
    ,"Hong Kong","China",[]])
data_list.append([datetime.datetime(2018, 8, 25),datetime.datetime(2018, 8, 25),1,1,9.44,26.04
    ,"Seoul","South Korea",['Eva','Ulrike','Cameron']])
data_list.append([datetime.datetime(2018, 8, 25),datetime.datetime(2018, 8, 25),1,1,1.19,1.19
    ,"Suwon","South Korea",[]])
data_list.append([datetime.datetime(2018, 8, 25),datetime.datetime(2018, 8, 25),1,2,3.33,7.00
    ,"Busan","South Korea",['Steffen','Stephanie']])
data_list.append([datetime.datetime(2018, 8, 25),datetime.datetime(2018, 8, 25),1,4,1.25,1.67
    ,"Sofia","Bulgaria",[]])

df = pd.DataFrame(data_list,columns=['Date First Visit','Date Last Visit', 'N_Visits','N_Days', 
        'City Population','Metropolitan Area Population','City Name','Country','Co-Travellers'])
df.to_csv("../data/BigCityVisits.csv")

# %%
df.head(50)
# Out:
#    Date First Visit Date Last Visit  N_Visits  N_Days  City Population  \
# 0        1996-08-25      2017-08-25         7       1             9.79
# 1        1996-08-25      2022-08-25         7       1             1.49
# 2        1992-08-25      2022-08-25         5       7             1.07
# 3        1997-08-25      2020-08-25         4       1             2.86
# 4        1998-08-25      2020-08-25        11       1             2.85
# 5        1999-08-25      2018-06-06         2       1             3.04
# 6        2000-08-25      2014-08-25         2       1            15.91
# 7        2000-08-25      2000-08-25         1       3             1.34
# 8        2000-08-25      2000-08-25         1       2             2.00
# 9        2001-08-25      2018-08-25         2       1             1.62
# 10       2001-08-25      2022-08-25         5       1             3.68
# 11       2001-08-25      2001-08-25         1       2             3.36
# ...

# %%
df.groupby(["Country"]).agg(
    N_Cities=('City Name','count')).reset_index().sort_values(
    by=['N_Cities'],ascending=False).head(25)
# Out:
#            Country  N_Cities
# 3            China         9
# 19             USA         4
# 8          Germany         4
# 12           Japan         4
# 13         Morocco         3
# 18          Turkey         3
# 16     South Korea         3
# 11           Italy         2
# 6            Egypt         2
# 17           Spain         2
# 15          Russia         2
# 20         Ukraine         1
# 14          Poland         1
# 0          Austria         1
# 1          Belgium         1
# 10         Hungary         1
# 9           Greece         1
# 7           France         1
# 5          Denmark         1
# 4   Czech Republic         1
# 2         Bulgaria         1
# 21  United Kingdom         1
