# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime
import seaborn as sns

# %%
# missing: 

#student parties
#erstsemester 03 & 04
#kinos
#basler 03,04
#gsiberger 04,05
#physiker 03,04
#fonduessen 04,05

#OBERKIRCH parteitag 2 naechte

#2 nights schlieren juli 03 ?

data_list=[]
#day start/day end/year/place/community/country/hotel/people
#1982
data_list.append([datetime.datetime(1982, 4, 6),datetime.datetime(1982, 4, 11),1982,"Waldshut",'Waldshut-Tiengen',"Germany",'Krankenhaus Waldshut',['Heidrun']])
data_list.append([datetime.datetime(1982, 4, 11),datetime.datetime(1982, 6, 26),1982,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun',"Jan-Marc",'Artur']])
#check here
data_list.append([datetime.datetime(1982, 6, 26),datetime.datetime(1982, 7, 10),1982,"Gossersweiler",'Gossersweiler',"Germany",'',['Heidrun',"Jan-Marc",'Artur']])
data_list.append([datetime.datetime(1982, 7, 10),datetime.datetime(1982, 12, 31),1982,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun',"Jan-Marc",'Artur']])
data_list.append([datetime.datetime(1982, 12, 31),datetime.datetime(1983, 1, 1),1982,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun',"Jan-Marc",'Artur']])
data_list.append([datetime.datetime(1983, 1, 1),datetime.datetime(1983, 5, 18),1983,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun',"Jan-Marc",'Artur']])
data_list.append([datetime.datetime(1983, 5, 18),datetime.datetime(1983, 5, 25),1983,"San Carlos",'San Carlos',"Spain",'',['Heidrun',"Jan-Marc",'Artur']])
data_list.append([datetime.datetime(1983, 5, 25),datetime.datetime(1983, 12, 31),1983,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun',"Jan-Marc",'Artur']])
data_list.append([datetime.datetime(1983, 12, 31),datetime.datetime(1984, 1, 1),1983,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun',"Jan-Marc",'Artur']])
data_list.append([datetime.datetime(1984, 1, 1),datetime.datetime(1984, 12, 31),1984,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun',"Jan-Marc",'Artur']])
data_list.append([datetime.datetime(1984, 12, 31),datetime.datetime(1985, 1, 1),1984,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin']])
data_list.append([datetime.datetime(1985, 1, 1),datetime.datetime(1985, 6, 26),1985,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin']])
data_list.append([datetime.datetime(1985, 6, 26),datetime.datetime(1985, 7, 9),1985,"Santa Eulalia",'Santa Eulalia',"Spain",'',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin']])
data_list.append([datetime.datetime(1985, 7, 9),datetime.datetime(1985, 12, 31),1985,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin']])
data_list.append([datetime.datetime(1985, 12, 31),datetime.datetime(1986, 1, 1),1985,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin']])
data_list.append([datetime.datetime(1986, 1, 1),datetime.datetime(1986, 12, 31),1986,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1986, 12, 31),datetime.datetime(1987, 1, 1),1986,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1987, 1, 1),datetime.datetime(1987, 6, 28),1987,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1987, 6, 28),datetime.datetime(1987, 7, 11),1987,"Calas del Mallorca",'Calas del Mallorca',"Spain",'',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1987, 7, 11),datetime.datetime(1987, 10, 24),1987,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1987, 10, 24),datetime.datetime(1987, 10, 31),1987,"Flumserberg",'Flumserberg',"Switzerland",'',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1987, 10, 31),datetime.datetime(1987, 11, 5),1987,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1987, 11, 5),datetime.datetime(1987, 11, 8),1987,"Loerrach",'Loerrach',"Germany","Kinderkrankenhaus Loerrach",['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1987, 11, 8),datetime.datetime(1987, 12, 31),1987,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1987, 12, 31),datetime.datetime(1988, 1, 1),1987,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1988, 1, 1),datetime.datetime(1988, 5, 22),1988,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1988, 5, 22),datetime.datetime(1988, 5, 29),1988,"Horn",'Horn',"Germany",'Horn',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1988, 5, 29),datetime.datetime(1988, 7, 2),1988,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1988, 7, 2),datetime.datetime(1988, 7, 16),1988,"Horn",'Horn',"Germany",'Horn',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1988, 7, 16),datetime.datetime(1988, 10, 24),1988,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1988, 10, 24),datetime.datetime(1988, 10, 29),1988,"Beatenberg",'Beatenberg',"Switzerland",'Dorinthotel Beatenberg',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1988, 10, 29),datetime.datetime(1988, 12, 31),1988,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1988, 12, 31),datetime.datetime(1989, 1, 1),1988,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1989, 1, 1),datetime.datetime(1989, 5, 10),1989,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1989, 5, 10),datetime.datetime(1989, 5, 17),1989,"Beatenberg",'Beatenberg',"Switzerland",'Dorinthotel Beatenberg',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1989, 5, 17),datetime.datetime(1989, 6, 20),1989,"Unterlauchringen",'Lauchringen',"Germany","",['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1989, 6, 20),datetime.datetime(1989, 6, 27),1989,"Horn",'Horn',"Germany",'Campingplatz Horn',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1989, 6, 27),datetime.datetime(1989, 10, 30),1989,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1989, 10, 30),datetime.datetime(1989, 11, 5),1989,"Missen Willams",'Missen Willams',"Germany",'',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1989, 11, 5),datetime.datetime(1989, 12, 31),1989,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1989, 12, 31),datetime.datetime(1990, 1, 1),1989,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1990, 1, 1),datetime.datetime(1990, 5, 25),1990,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1990, 5, 25),datetime.datetime(1990, 6, 8),1990,"San Antonio",'San Antonio',"Spain",'',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1990, 6, 8),datetime.datetime(1990, 10, 27),1990,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1990, 10, 27),datetime.datetime(1990, 11, 3),1990,"Lechbruck",'Lechbruck',"Germany",'',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1990, 11, 3),datetime.datetime(1990, 12, 31),1990,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1990, 12, 31),datetime.datetime(1991, 1, 1),1990,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1991, 1, 1),datetime.datetime(1991, 5, 18),1991,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1991, 5, 18),datetime.datetime(1991, 6, 1),1991,"Kell am See",'Kell am See',"Germany",'',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1991, 6, 1),datetime.datetime(1991, 8, 3),1991,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1991, 8, 3),datetime.datetime(1991, 8, 13),1991,"Ueberlingen",'Ueberlingen',"Germany",'Campingplatz Ueberlingen',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1991, 8, 13),datetime.datetime(1991, 12, 31),1991,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1991, 12, 31),datetime.datetime(1992, 1, 1),1991,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1992, 1, 1),datetime.datetime(1992, 7, 5),1992,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1992, 7, 5),datetime.datetime(1992, 7, 19),1992,"Daun",'Daun',"Germany",'',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1992, 7, 19),datetime.datetime(1992, 10, 25),1992,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1992, 10, 25),datetime.datetime(1992, 11, 1),1992,"Lechbruck",'Lechbruck',"Germany",'',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1992, 11, 1),datetime.datetime(1992, 12, 31),1992,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1992, 12, 31),datetime.datetime(1993, 1, 1),1992,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1993, 1, 1),datetime.datetime(1993, 10, 30),1993,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1993, 10, 30),datetime.datetime(1993, 11, 6),1993,"Telfs",'Telfs',"Austria",'',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1993, 11, 6),datetime.datetime(1993, 12, 31),1993,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1993, 12, 31),datetime.datetime(1994, 1, 1),1993,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1994, 1, 1),datetime.datetime(1994, 7, 9),1994,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1994, 7, 9),datetime.datetime(1994, 7, 23),1994,"Oberlahr",'Oberlahr',"Germany",'Westerwaldtreff',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1994, 7, 23),datetime.datetime(1994, 10, 27),1994,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1994, 10, 27),datetime.datetime(1994, 11, 2),1994,"Telfs",'Telfs',"Austria",'',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1994, 11, 2),datetime.datetime(1994, 12, 31),1994,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1994, 12, 31),datetime.datetime(1995, 1, 1),1994,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1995, 1, 1),datetime.datetime(1995, 8, 5),1995,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1995, 8, 5),datetime.datetime(1995, 8, 19),1995,"Kirchheim",'Kirchheim',"Germany",'Westerwaldtreff',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1995, 8, 19),datetime.datetime(1995, 12, 31),1995,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1995, 12, 31),datetime.datetime(1996, 1, 1),1995,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1996, 1, 1),datetime.datetime(1996, 5, 5),1996,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1996, 5, 5),datetime.datetime(1996, 5, 6),1996,"Beatenberg",'Beatenberg',"Switzerland",'Dorinthotel Beatenberg',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1996, 5, 6),datetime.datetime(1996, 8, 23),1996,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1996, 8, 23),datetime.datetime(1996, 8, 30),1996,"London",'London',"United Kingdom",'Hotel President',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1996, 8, 30),datetime.datetime(1996, 10, 10),1996,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1996, 10, 10),datetime.datetime(1996,10, 13),1996,"St Pierre de Chandieu",'St Pierre de Chandieu',"France",'',['Artur','Hannsjoerg','Anne-Kathrin','Jan-Marc']])
data_list.append([datetime.datetime(1996, 10, 13),datetime.datetime(1996, 10, 26),1996,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1996, 10, 26),datetime.datetime(1996, 11, 1),1996,"Stromberg",'Stromberg',"Germany",'',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1996, 11, 1),datetime.datetime(1996, 12, 31),1996,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1996, 12, 31),datetime.datetime(1997, 1, 1),1996,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1997, 1, 1),datetime.datetime(1997, 4, 10),1997,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1997, 4, 10),datetime.datetime(1997, 4, 16),1997,"St Peter Ording",'St Peter Ording',"Germany",'',['Schulklasse']])
data_list.append([datetime.datetime(1997, 4, 16),datetime.datetime(1997, 5, 21),1997,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1997, 5, 21),datetime.datetime(1997, 5, 25),1997,"Muenchen",'Muenchen',"Germany",'',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1997, 5, 25),datetime.datetime(1997, 8, 24),1997,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1997, 8, 24),datetime.datetime(1997, 8, 31),1997,"Rom",'Rom',"Italy",'',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1997, 8, 31),datetime.datetime(1997, 9, 11),1997,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1997, 9, 11),datetime.datetime(1997, 9, 14),1997,"Steinabad",'Bonndorf',"Germany",'Steinabad',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1997, 9, 14),datetime.datetime(1997, 12, 31),1997,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1997, 12, 31),datetime.datetime(1998, 1, 1),1997,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1998, 1, 1),datetime.datetime(1998, 4, 17),1998,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1998, 4, 17),datetime.datetime(1998, 4, 18),1998,"Ulm",'Ulm',"Germany",'',['Heidrun','Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1998, 4, 18),datetime.datetime(1998, 8, 22),1998,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1998, 8, 22),datetime.datetime(1998, 8, 30),1998,"Paris",'Paris',"France",'',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1998, 8, 30),datetime.datetime(1998, 9, 25),1998,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1998, 9, 25),datetime.datetime(1998, 9, 26),1998,"Frankfurt",'Frankfurt',"Germany",'',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1998, 9, 26),datetime.datetime(1998, 12, 31),1998,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1998, 12, 31),datetime.datetime(1999, 1, 1),1998,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1999, 1, 1),datetime.datetime(1999, 4, 25),1999,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1999, 4, 25),datetime.datetime(1999, 4, 28),1999,"Bad Honnef",'Bad Honnef',"Germany",'',['Schulklasse']])
data_list.append([datetime.datetime(1999, 4, 28),datetime.datetime(1999, 5, 26),1999,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1999, 5, 26),datetime.datetime(1999, 5, 27),1999,"Tiengen",'Waldshut-Tiengen',"Germany",'Chez Schwabe',['Tobias Schwabe',"Stephan Schalk",'Jan Perius','Falko Schmidt',"Alain Lafon",'Anna']])
data_list.append([datetime.datetime(1999, 5, 27),datetime.datetime(1999, 6, 12),1999,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1999, 6, 12),datetime.datetime(1999, 6, 13),1999,"Horheim",'Wutoeschingen',"Germany",'Chez Schalk',['Tobias Schwabe',"Stephan Schalk",'Jan Perius','Falko Schmidt',"Alain Lafon"]])
data_list.append([datetime.datetime(1999, 6, 13),datetime.datetime(1999, 6, 23),1999,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1999, 6, 23),datetime.datetime(1999, 6, 25),1999,"Untermettingen",'Untermettingen',"Germany",'',['Schulklasse']])
data_list.append([datetime.datetime(1999, 6, 25),datetime.datetime(1999, 8, 27),1999,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1999, 8, 27),datetime.datetime(1999, 8, 29),1999,"Athen",'Athen',"Greece",'',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1999, 8, 29),datetime.datetime(1999, 8, 30),1999,"Nauplia",'Nauplia',"Greece",'',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1999, 8, 30),datetime.datetime(1999, 8, 31),1999,"Olympia",'Olympia',"Greece",'',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1999, 8, 31),datetime.datetime(1999, 9, 1),1999,"Delphi",'Delphi',"Greece",'',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1999, 9, 1),datetime.datetime(1999, 9, 3),1999,"Athen",'Athen',"Greece",'',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1999, 9, 3),datetime.datetime(1999, 9, 8),1999,"Eretria",'Evia',"Greece",'',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1999, 9, 8),datetime.datetime(1999, 12, 31),1999,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1999, 12, 31),datetime.datetime(2000, 1, 1),1999,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(2000, 1, 1),datetime.datetime(2000, 5, 18),2000,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(2000, 5, 18),datetime.datetime(2000, 5, 21),2000,"Muenchen",'Muenchen',"Germany",'',['Hochrheinseminar']])
data_list.append([datetime.datetime(2000, 5, 21),datetime.datetime(2000, 6, 3),2000,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(2000, 6, 3),datetime.datetime(2000, 6, 6),2000,"Hannover",'Hannover',"Germany",'',['Heidrun','Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(2000, 6, 6),datetime.datetime(2000, 7, 9),2000,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(2000, 7, 9),datetime.datetime(2000, 7, 10),2000,"Bechtersbohl",'Kuessaberg',"Germany",'',['Schulklasse']])
data_list.append([datetime.datetime(2000, 7, 10),datetime.datetime(2000, 8, 24),2000,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(2000, 8, 24),datetime.datetime(2000, 8, 25),2000,"ICE Basel-Frankfurt",'ICE',"Germany",'',['Heidrun','Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(2000, 8, 25),datetime.datetime(2000, 8, 26),2000,"Antalya",'Antalya',"Turkey",'',['Heidrun','Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(2000, 8, 26),datetime.datetime(2000, 8, 27),2000,"Bursa",'Bursa',"Turkey",'',['Heidrun','Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(2000, 8, 27),datetime.datetime(2000, 8, 29),2000,"Istanbul",'Istanbul',"Turkey",'',['Heidrun','Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(2000, 8, 29),datetime.datetime(2000, 8, 30),2000,"Canakkale",'Canakkale',"Turkey",'',['Heidrun','Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(2000, 8, 30),datetime.datetime(2000, 8, 31),2000,"Selcuk",'Selcuk',"Turkey",'',['Heidrun','Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(2000, 8, 31),datetime.datetime(2000, 9, 7),2000,"Kemer",'Kemer',"Turkey",'Kemer Holiday Village',['Heidrun','Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(2000, 9, 7),datetime.datetime(2000, 9, 8),2000,"ICE Frankfurt-Basel",'ICE',"Germany",'',['Heidrun','Artur','Anne-Kathrin','Hannsjoerg']])
#champions league tiengen, Horheim Pokal, bechtersbohl party
#schlieren???/ZRH
data_list.append([datetime.datetime(2000, 9, 8),datetime.datetime(2000, 12, 31),2000,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(2000, 12, 31),datetime.datetime(2001, 1, 1),2000,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(2001, 1, 1),datetime.datetime(2001, 4, 19),2001,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(2001, 4, 19),datetime.datetime(2001, 4, 20),2001,"Bus Tiengen-Barcelona",'Bus',"Bus Central Europe",'',["School Outing"]])
data_list.append([datetime.datetime(2001, 4, 20),datetime.datetime(2001, 4, 25),2001,"Barcelona",'Barcelona',"Spain",'',["School Outing"]])
data_list.append([datetime.datetime(2001, 4, 25),datetime.datetime(2001, 4, 26),2001,"Bus Barcelona-Tiengen",'Bus',"Bus Central Europe",'',["School Outing"]])
data_list.append([datetime.datetime(2001, 4, 26),datetime.datetime(2001, 5, 5),2001,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(2001, 5, 5),datetime.datetime(2001,5, 6),2001,"St Pierre de Chandieu",'St Pierre de Chandieu',"France",'',['Hannsjoerg','Anne-Kathrin']])
data_list.append([datetime.datetime(2001, 5, 6),datetime.datetime(2001, 5, 25),2001,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(2001, 5, 25),datetime.datetime(2001, 5, 31),2001,"Berlin",'Berlin',"Germany",'',['Heidrun','Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(2001, 5, 31),datetime.datetime(2001, 8, 21),2001,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(2001, 8, 21),datetime.datetime(2001, 8, 22),2001,"ICE Basel-Frankfurt",'ICE',"Germany",'',['Heidrun','Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(2001, 8, 22),datetime.datetime(2001, 8, 23),2001,"Malaga",'Malaga',"Spain",'',['Heidrun','Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(2001, 8, 23),datetime.datetime(2001, 8, 24),2001,"Granada",'Granada',"Spain",'',['Heidrun','Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(2001, 8, 24),datetime.datetime(2001, 8, 25),2001,"Cordoba",'Cordoba',"Spain",'',['Heidrun','Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(2001, 8, 25),datetime.datetime(2001, 8, 27),2001,"Sevilla",'Sevilla',"Spain",'',['Heidrun','Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(2001, 8, 27),datetime.datetime(2001, 8, 28),2001,"Arcos de la Frontera",'Arcos de la Frontera',"Spain",'',['Heidrun','Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(2001, 8, 28),datetime.datetime(2001, 8, 29),2001,"Ronda",'Ronda',"Spain",'',['Heidrun','Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(2001, 8, 29),datetime.datetime(2001, 9, 3),2001,"Marbella",'Marbella',"Spain",'',['Heidrun','Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(2001, 9, 3),datetime.datetime(2001, 9, 4),2001,"ICE Frankfurt-Basel",'ICE',"Germany",'',['Heidrun','Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(2001, 9, 4),datetime.datetime(2001, 12, 31),2001,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(2001, 12, 31),datetime.datetime(2002, 1, 1),2001,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(2002, 1, 1),datetime.datetime(2002, 5, 25),2002,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(2002, 5, 25),datetime.datetime(2002, 5, 30),2002,"Montainone",'Montainone',"Italy",'',['Heidrun','Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(2002, 5, 30),datetime.datetime(2002, 8, 20),2002,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(2002, 8, 20),datetime.datetime(2002, 8, 21),2002,"Agadir",'Agadir',"Morocco",'',['Heidrun','Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(2002, 8, 21),datetime.datetime(2002, 8, 22),2002,"Marrakesh",'Marrakesh',"Morocco",'',['Heidrun','Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(2002, 8, 22),datetime.datetime(2002, 8, 24),2002,"Fes",'Fes',"Morocco",'',['Heidrun','Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(2002, 8, 24),datetime.datetime(2002, 8, 25),2002,"Volubilis",'Volubilis',"Morocco",'',['Heidrun','Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(2002, 8, 25),datetime.datetime(2002, 8, 26),2002,"Casablanca",'Casablanca',"Morocco",'',['Heidrun','Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(2002, 8, 26),datetime.datetime(2002, 8, 27),2002,"Eassouira",'Eassouira',"Morocco",'',['Heidrun','Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(2002, 8, 27),datetime.datetime(2002, 9, 3),2002,"Agadir",'Agadir',"Morocco",'',['Heidrun','Artur','Anne-Kathrin','Hannsjoerg']])

# %%
#studium etc check what might have started around the time HERE
data_list.append([datetime.datetime(2002, 9, 3),datetime.datetime(2002, 12, 31),2002,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(2002, 12, 31),datetime.datetime(2003, 1, 1),2002,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(2003, 1, 1),datetime.datetime(2003, 3, 15),2003,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(2003, 3, 15),datetime.datetime(2003, 3, 16),2003,"St Pierre de Chandieu",'St Pierre de Chandieu',"France",'',['Hannsjoerg','Anne-Kathrin','Artur','Jan-Marc']])
data_list.append([datetime.datetime(2003, 3, 16),datetime.datetime(2003, 7, 3),2003,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(2003, 7, 3),datetime.datetime(2003, 7, 4),2003,"Stuttgart Flughafen",'Stuttgart',"Germany",'',['Sigi',"Gianrico",'Boeni']])
data_list.append([datetime.datetime(2003, 7, 4),datetime.datetime(2003, 7, 11),2003,"Bodrum",'Bodrum',"Turkey",'',['Sigi',"Gianrico",'Boeni']])
data_list.append([datetime.datetime(2003, 7, 11),datetime.datetime(2003, 12, 31),2003,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(2003, 12, 31),datetime.datetime(2004, 1, 1),2003,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(2004, 1, 1),datetime.datetime(2004, 7, 2),2004,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(2004, 7, 2),datetime.datetime(2004, 7, 9),2004,"Monastir",'Monastir',"Tunisia",'',['Sigi',"Gianrico"]])
data_list.append([datetime.datetime(2004, 7, 9),datetime.datetime(2004, 7, 22),2004,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(2004, 7, 22),datetime.datetime(2004, 7, 23),2004,"Bregenz",'Bregenz',"Austria",'',['Sigi',"Gianrico",'Anne']])
data_list.append([datetime.datetime(2004, 7, 23),datetime.datetime(2004, 10, 15),2004,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(2004, 10, 15),datetime.datetime(2004, 10, 20),2004,"London",'London',"United Kingdom",'',['Gianrico','Anne Feidt','Sigi']])
data_list.append([datetime.datetime(2004, 10, 20),datetime.datetime(2004, 12, 31),2004,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun',"Jan-Marc",'Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2004, 12, 31),datetime.datetime(2005, 1, 1),2004,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(2005, 1, 1),datetime.datetime(2005, 2, 1),2005,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(2005, 2, 1),datetime.datetime(2005, 2, 5),2005,"Diavolezza",'Samedan',"Switzerland",'',["ETH Group"]])
data_list.append([datetime.datetime(2005, 2, 5),datetime.datetime(2005, 3, 20),2005,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun',"Jan-Marc",'Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2005, 3, 20),datetime.datetime(2005, 3, 22),2005,"Cairo",'Cairo',"Egypt",'',["Heidrun",'Hannsjoerg','Artur']])
data_list.append([datetime.datetime(2005, 3, 22),datetime.datetime(2005, 3, 23),2005,"Luxor",'Luxor',"Egypt",'',["Heidrun",'Hannsjoerg','Artur']])
data_list.append([datetime.datetime(2005, 3, 23),datetime.datetime(2005, 3, 24),2005,"Edfu",'Edfu',"Egypt",'',["Heidrun",'Hannsjoerg','Artur']])
data_list.append([datetime.datetime(2005, 3, 24),datetime.datetime(2005, 3, 25),2005,"Khom Ombo",'Khom Ombo',"Egypt",'',["Heidrun",'Hannsjoerg','Artur']])
data_list.append([datetime.datetime(2005, 3, 25),datetime.datetime(2005, 3, 26),2005,"Assuan",'Assuan',"Egypt",'',["Heidrun",'Hannsjoerg','Artur']])
data_list.append([datetime.datetime(2005, 3, 26),datetime.datetime(2005, 3, 28),2005,"Cairo",'Cairo',"Egypt",'',["Heidrun",'Hannsjoerg','Artur']])
data_list.append([datetime.datetime(2005, 3, 28),datetime.datetime(2005, 8, 28),2005,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun',"Jan-Marc",'Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2005, 8, 28),datetime.datetime(2005, 9, 4),2005,"Lissabon",'Lissabon',"Portugal",'',['Heidrun',"Anne-Kathrin",'Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2005, 9, 4),datetime.datetime(2005, 12, 31),2005,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun',"Jan-Marc",'Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2005, 12, 31),datetime.datetime(2006, 1, 1),2005,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(2006, 1, 1),datetime.datetime(2006, 7, 11),2006,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(2006, 7, 11),datetime.datetime(2006, 7, 28),2006,"London",'London',"United Kingdom",'',['Heidrun',"Jan-Marc",'Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2006, 7, 28),datetime.datetime(2006, 10, 16),2006,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun',"Jan-Marc",'Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2006, 10, 16),datetime.datetime(2006, 12, 22),2006,"Meyrin",'Meyrin',"Switzerland",'CERN Hostel',[]])
data_list.append([datetime.datetime(2006, 12, 22),datetime.datetime(2006, 12, 31),2006,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun',"Anne-Kathrin",'Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2006, 12, 31),datetime.datetime(2007, 1, 1),2006,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(2007, 1, 1),datetime.datetime(2007, 1, 8),2007,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun',"Jan-Marc",'Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(2007, 1, 8),datetime.datetime(2007, 3, 10),2007,"Meyrin",'Meyrin',"Switzerland",'CERN Hostel',[]])
data_list.append([datetime.datetime(2007, 3, 10),datetime.datetime(2007, 3, 12),2007,"St Pierre de Chandieu",'St Pierre de Chandieu',"France",'',['Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2007, 3, 12),datetime.datetime(2007, 3, 15),2007,"Meyrin",'Meyrin',"Switzerland",'CERN Hostel',[]])
data_list.append([datetime.datetime(2007, 3, 15),datetime.datetime(2007, 5, 16),2007,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun','Artur','Hannsjoerg']])

# %%
data_list.append([datetime.datetime(2007, 5, 16),datetime.datetime(2007, 8, 10),2007,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2007, 8, 10),datetime.datetime(2007, 8, 13),2007,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2007, 8, 13),datetime.datetime(2007, 12, 21),2007,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2007, 12, 21),datetime.datetime(2007, 12, 31),2007,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun','Artur','Hannsjoerg','Anne-Kathrin']])
data_list.append([datetime.datetime(2007, 12, 31),datetime.datetime(2008, 1, 1),2007,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun','Artur','Hannsjoerg','Anne-Kathrin']])
data_list.append([datetime.datetime(2008, 1, 1),datetime.datetime(2008, 1, 2),2008,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun','Artur','Hannsjoerg','Anne-Kathrin']])
data_list.append([datetime.datetime(2008, 1, 2),datetime.datetime(2008, 1, 4),2008,"Dresden",'Dresden',"Germany",'',['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2008, 1, 4),datetime.datetime(2008, 1, 6),2008,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2008, 1, 6),datetime.datetime(2008, 1, 11),2008,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2008, 1, 11),datetime.datetime(2008, 1, 20),2008,"Naefels",'Naefels',"Switzerland",'',["CHIPP School 2008"]])
data_list.append([datetime.datetime(2008, 1, 20),datetime.datetime(2008, 2, 20),2008,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2008, 2, 20),datetime.datetime(2008, 2, 22),2008,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2008, 2, 22),datetime.datetime(2008, 7, 28),2008,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2008, 7, 28),datetime.datetime(2008, 8, 6),2008,"Philadelphia",'Philadelphia',"USA",'',[]])
data_list.append([datetime.datetime(2008, 8, 6),datetime.datetime(2008, 8, 7),2008,"Flight Philadelphia-Frankfurt",'Flight',"Atlantic",'',[]])
data_list.append([datetime.datetime(2008, 8, 7),datetime.datetime(2008, 8, 20),2008,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2008, 8, 20),datetime.datetime(2008, 8, 24),2008,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2008, 8, 24),datetime.datetime(2008, 9, 3),2008,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2008, 9, 3),datetime.datetime(2008, 9, 9),2008,"Madrid",'Madrid',"Spain",'',['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2008, 9, 9),datetime.datetime(2008, 11, 28),2008,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2008, 11, 28),datetime.datetime(2008, 11, 29),2008,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2008, 11, 29),datetime.datetime(2008, 12, 1),2008,"Nuernberg",'Nuernberg',"Germany",'',['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2008, 12, 1),datetime.datetime(2008, 12, 2),2008,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2008, 12, 2),datetime.datetime(2008, 12, 19),2008,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2008, 12, 19),datetime.datetime(2008, 12, 31),2008,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun','Artur','Hannsjoerg','Anne-Kathrin']])
data_list.append([datetime.datetime(2008, 12, 31),datetime.datetime(2009, 1, 1),2008,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2009, 1, 1),datetime.datetime(2009, 1, 4),2009,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2009, 1, 4),datetime.datetime(2009, 2, 3),2009,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2009, 2, 3),datetime.datetime(2009, 2, 5),2009,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun','Artur','Hannsjoerg','Anne-Kathrin']])
data_list.append([datetime.datetime(2009, 2, 5),datetime.datetime(2009, 4, 25),2009,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2009, 4, 25),datetime.datetime(2009, 4, 30),2009,"Madrid",'Madrid',"Spain",'',[]])
data_list.append([datetime.datetime(2009, 4, 30),datetime.datetime(2009, 6, 23),2009,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2009, 6, 23),datetime.datetime(2009, 7, 3),2009,"Madison",'Madison',"USA",'',['CTEQ09']])
data_list.append([datetime.datetime(2009, 7, 3),datetime.datetime(2009, 7, 8),2009,"New York City",'New York City',"USA",'Hilton Times Square',[]])
data_list.append([datetime.datetime(2009, 7, 8),datetime.datetime(2009, 7, 9),2009,"Flight JFK-CDG",'Flight',"Atlantic",'',[]])
data_list.append([datetime.datetime(2009, 7, 9),datetime.datetime(2009, 8, 14),2009,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2009, 8, 14),datetime.datetime(2009, 8, 20),2009,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2009, 8, 20),datetime.datetime(2009, 9, 1),2009,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2009, 9, 1),datetime.datetime(2009, 9, 5),2009,"Innsbruck",'Innsbruck',"Austria",'',['ETH Group']])
data_list.append([datetime.datetime(2009, 9, 5),datetime.datetime(2009, 12, 10),2009,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2009, 12, 10),datetime.datetime(2009, 12, 13),2009,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2009, 12, 13),datetime.datetime(2009, 12, 18),2009,"Karlsruhe",'Karlsruhe',"Germany",'',['Anne-Kathrin']])
data_list.append([datetime.datetime(2009, 12, 18),datetime.datetime(2009, 12, 31),2009,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun','Artur','Hannsjoerg','Anne-Kathrin']])
data_list.append([datetime.datetime(2009, 12, 31),datetime.datetime(2010, 1, 1),2009,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2010, 1, 1),datetime.datetime(2010, 1, 3),2010,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2010, 1, 3),datetime.datetime(2010, 1, 19),2010,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2010, 1, 19),datetime.datetime(2010, 1, 25),2010,"Ascona",'Ascona',"Switzerland",'',["CHIPP School 2010"]])
data_list.append([datetime.datetime(2010, 1, 25),datetime.datetime(2010, 2, 6),2010,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2010, 2, 6),datetime.datetime(2010, 2, 7),2010,"Chamonix",'Chamonix',"France",'',["Wieland",'Filip','Benjamin']])
data_list.append([datetime.datetime(2010, 2, 7),datetime.datetime(2010, 2, 9),2010,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2010, 2, 9),datetime.datetime(2010, 4, 1),2010,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2010, 4, 1),datetime.datetime(2010, 4, 5),2010,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2010, 4, 5),datetime.datetime(2010, 4, 6),2010,"Schwangau",'Schwangau',"Germany",'Landgasthof zur Post',['Hannsjoerg']])
data_list.append([datetime.datetime(2010, 4, 6),datetime.datetime(2010, 4, 7),2010,"Garmisch",'Garmisch-Partenkirchen',"Germany",'Hotel Vier Jahreszeiten',['Hannsjoerg']])
data_list.append([datetime.datetime(2010, 4, 7),datetime.datetime(2010, 4, 9),2010,"Muenchen",'Muenchen',"Germany",'Hotel Italia',['Hannsjoerg']])
data_list.append([datetime.datetime(2010, 4, 9),datetime.datetime(2010, 4, 11),2010,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2010, 4, 11),datetime.datetime(2010, 5, 21),2010,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2010, 5, 21),datetime.datetime(2010, 5, 24),2010,"Unterlauchringen",'Lauchringen',"Germany",'',["Anne-Kathrin",'Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2010, 5, 24),datetime.datetime(2010, 7, 21),2010,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2010, 7, 21),datetime.datetime(2010, 8, 4),2010,"Paris",'Paris',"France",'',["Artur",'Heidrun']])
data_list.append([datetime.datetime(2010, 8, 4),datetime.datetime(2010, 8, 17),2010,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2010, 8, 17),datetime.datetime(2010, 8, 22),2010,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2010, 8, 22),datetime.datetime(2010, 11, 11),2010,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2010, 11, 11),datetime.datetime(2010,11, 14),2010,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun','Artur']])
data_list.append([datetime.datetime(2010, 11, 14),datetime.datetime(2010, 12, 21),2010,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2010, 12, 21),datetime.datetime(2010, 12, 31),2010,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun','Artur','Hannsjoerg','Anne-Kathrin']])
data_list.append([datetime.datetime(2010, 12, 31),datetime.datetime(2011, 1, 1),2010,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2011, 1, 1),datetime.datetime(2011, 1, 4),2011,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2011, 1, 4),datetime.datetime(2011, 2, 4),2011,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2011, 2, 4),datetime.datetime(2011, 2, 8),2011,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun','Artur']])
data_list.append([datetime.datetime(2011, 2, 8),datetime.datetime(2011, 2, 13),2011,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2011, 2, 13),datetime.datetime(2011, 2, 19),2011,"Les Houches",'Les Houches',"France",'',["Les Houches 2011"]])
data_list.append([datetime.datetime(2011, 2, 19),datetime.datetime(2011, 4, 21),2011,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2011, 4, 21),datetime.datetime(2011, 4, 25),2011,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2011, 4, 25),datetime.datetime(2011, 6, 1),2011,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2011, 6, 1),datetime.datetime(2011, 6, 5),2011,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2011, 6, 5),datetime.datetime(2011, 8, 23),2011,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2011, 8, 23),datetime.datetime(2011, 8, 28),2011,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2011, 8, 28),datetime.datetime(2011, 9, 28),2011,"Genf",'Genf',"Switzerland",'',[]])

# %%
data_list.append([datetime.datetime(2011, 9, 28),datetime.datetime(2011, 9, 29),2011,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun','Artur']])
data_list.append([datetime.datetime(2011, 9, 29),datetime.datetime(2011, 10, 1),2011,"Bamberg",'Bamberg',"Germany",'',[]])
data_list.append([datetime.datetime(2011, 10, 1),datetime.datetime(2011, 10, 2),2011,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun','Artur']])
data_list.append([datetime.datetime(2011, 10, 2),datetime.datetime(2011, 10, 14),2011,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2011, 10, 14),datetime.datetime(2011, 10, 16),2011,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun','Artur']])
data_list.append([datetime.datetime(2011, 10, 16),datetime.datetime(2011, 12, 21),2011,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2011, 12, 21),datetime.datetime(2011, 12, 27),2011,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun','Artur','Hannsjoerg',"Anne-Kathrin"]])
data_list.append([datetime.datetime(2011, 12, 27),datetime.datetime(2011, 12, 30),2011,"Wien",'Wien',"Austria",'',['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2011, 12, 30),datetime.datetime(2011, 12, 31),2011,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2011, 12, 31),datetime.datetime(2012, 1, 1),2011,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2012, 1, 1),datetime.datetime(2012, 1, 4),2012,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2012, 1, 4),datetime.datetime(2012, 1, 13),2012,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2012, 1, 13),datetime.datetime(2012, 1, 15),2012,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun','Artur']])
data_list.append([datetime.datetime(2012, 1, 15),datetime.datetime(2012, 2, 13),2012,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2012, 2, 13),datetime.datetime(2012, 2, 26),2012,"St Charles",'St Charles',"USA",'',['EDIT2012']])
data_list.append([datetime.datetime(2012, 2, 26),datetime.datetime(2012, 2, 27),2012,"Flight IAD-GVA",'Flight',"Atlantic",'',[]])
data_list.append([datetime.datetime(2012, 2, 27),datetime.datetime(2012, 5, 11),2012,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2012, 5, 11),datetime.datetime(2012, 5, 13),2012,"Prag",'Prag',"Czech Republic",'',['Artur','Heidrun']])
data_list.append([datetime.datetime(2012, 5, 13),datetime.datetime(2012, 5, 30),2012,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2012, 5, 30),datetime.datetime(2012, 5, 31),2012,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun','Artur']])
data_list.append([datetime.datetime(2012, 5, 31),datetime.datetime(2012, 6, 3),2012,"Blois",'Blois',"France","Appart'City Classic Blois",['Heidrun','Artur',"Hannsjoerg"]])
data_list.append([datetime.datetime(2012, 6, 3),datetime.datetime(2012, 7, 24),2012,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2012, 7, 24),datetime.datetime(2012, 7, 31),2012,"Berlin",'Berlin',"Germany",'Motel One',['Gianrico']])
data_list.append([datetime.datetime(2012, 7, 31),datetime.datetime(2012, 8, 30),2012,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2012, 8, 30),datetime.datetime(2012, 9, 9),2012,"Lissabon",'Lissabon',"Portugal",'Grande Pensao Residencial Alcobia',["CMS Week"]])
data_list.append([datetime.datetime(2012, 9, 9),datetime.datetime(2012, 9, 28),2012,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2012, 9, 28),datetime.datetime(2012, 10, 1),2012,"Warschau",'Warschau',"Poland",'',["Eric"]])
data_list.append([datetime.datetime(2012, 10, 1),datetime.datetime(2012, 11, 9),2012,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2012, 11, 9),datetime.datetime(2012, 11, 12),2012,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun','Artur',"Hannsjoerg"]])
data_list.append([datetime.datetime(2012, 11, 12),datetime.datetime(2012, 12, 21),2012,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2012, 12, 21),datetime.datetime(2012, 12, 31),2012,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun','Artur',"Hannsjoerg",'Anne-Kathrin']])
data_list.append([datetime.datetime(2012, 12, 31),datetime.datetime(2013, 1, 1),2012,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun','Artur',"Hannsjoerg"]])
data_list.append([datetime.datetime(2013, 1, 1),datetime.datetime(2013, 1, 2),2013,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun','Artur',"Hannsjoerg"]])
data_list.append([datetime.datetime(2013, 1, 2),datetime.datetime(2013, 1, 6),2013,"Amsterdam",'Amsterdam',"Netherlands",'',['Heidrun','Artur',"Hannsjoerg"]])
data_list.append([datetime.datetime(2013, 1, 6),datetime.datetime(2013, 1, 7),2013,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun','Artur',"Hannsjoerg"]])
data_list.append([datetime.datetime(2013, 1, 7),datetime.datetime(2013, 3, 21),2013,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2013, 3, 21),datetime.datetime(2013, 3, 25),2013,"Paris",'Paris',"France",'Hotel de Nevers',['Andrew']])
data_list.append([datetime.datetime(2013, 3, 25),datetime.datetime(2013, 4, 3),2013,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2013, 4, 3),datetime.datetime(2013, 4, 11),2013,"Rom",'Rom',"Italy",'Hotel King',['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 11),datetime.datetime(2013, 7, 14),2013,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2013, 7, 14),datetime.datetime(2013, 7, 24),2013,"Stockholm",'Stockholm',"Sweden",'Alexandra Hotel',['EPS2013']])
data_list.append([datetime.datetime(2013, 7, 24),datetime.datetime(2013, 7, 28),2013,"Kopenhagen",'Kopenhagen',"Denmark",'Cabinn City',[]])
data_list.append([datetime.datetime(2013, 7, 28),datetime.datetime(2013, 9, 5),2013,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2013, 9, 5),datetime.datetime(2013, 9, 8),2013,"Venedig",'Venedig',"Italy",'Hotel Mignon',[]])
data_list.append([datetime.datetime(2013, 9, 8),datetime.datetime(2013, 9, 14),2013,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2013, 9, 14),datetime.datetime(2013, 9, 16),2013,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun','Artur',"Hannsjoerg"]])
data_list.append([datetime.datetime(2013, 9, 16),datetime.datetime(2013, 11, 8),2013,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2013, 11, 8),datetime.datetime(2013, 11, 11),2013,"Paris",'Paris',"France",'',['Eric','Chris Lee','Chris Clarke']])
data_list.append([datetime.datetime(2013, 11, 11),datetime.datetime(2013, 12, 20),2013,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2013, 12, 20),datetime.datetime(2013, 12, 31),2013,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun','Artur',"Hannsjoerg",'Anne-Kathrin']])
data_list.append([datetime.datetime(2013, 12, 31),datetime.datetime(2014, 1, 1),2013,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun','Artur',"Hannsjoerg"]])
data_list.append([datetime.datetime(2014, 1, 1),datetime.datetime(2014, 1, 5),2014,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun','Artur',"Hannsjoerg"]])
data_list.append([datetime.datetime(2014, 1, 5),datetime.datetime(2014, 4, 18),2014,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2014, 4, 18),datetime.datetime(2014, 4, 19),2014,"Fuessen",'Fuessen',"Germany",'House LA Neuschwanstein Blick',["Eric",'Indara']])
data_list.append([datetime.datetime(2014, 4, 19),datetime.datetime(2014, 4, 20),2014,"Rosenheim",'Rosenheim',"Germany",'Gasthof-Hotel Hoehensteiger',["Eric",'Indara']])
data_list.append([datetime.datetime(2014, 4, 20),datetime.datetime(2014, 4, 22),2014,"Muenchen",'Muenchen',"Germany",'Hotel Deutsches Theater Stadtzentrum',["Eric",'Indara']])
data_list.append([datetime.datetime(2014, 4, 22),datetime.datetime(2014, 5, 18),2014,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2014, 5, 18),datetime.datetime(2014, 5, 20),2014,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun','Artur',"Hannsjoerg"]])
data_list.append([datetime.datetime(2014, 5, 20),datetime.datetime(2014, 7, 24),2014,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2014, 7, 24),datetime.datetime(2014, 8, 4),2014,"London",'London',"United Kingdom",'',['Heidrun','Artur',"Hannsjoerg",'Anne-Kathrin']])
data_list.append([datetime.datetime(2014, 8, 4),datetime.datetime(2014, 8, 22),2014,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2014, 8, 22),datetime.datetime(2014, 8, 29),2014,"Wien",'Wien',"Austria",'AllYouNeed Hotel Vienna 2',["JetMET Workshop 2014"]])
data_list.append([datetime.datetime(2014, 8, 29),datetime.datetime(2014, 8, 31),2014,"Budapest",'Budapest',"Hungary",'',[]])
data_list.append([datetime.datetime(2014, 8, 31),datetime.datetime(2014, 9, 6),2014,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2014, 9, 6),datetime.datetime(2014, 9, 12),2014,"Bologna",'Bologna',"Italy",'Dada',['ISMD 2014']])
data_list.append([datetime.datetime(2014, 9, 12),datetime.datetime(2014, 9, 14),2014,"Florenz",'Florenz',"Italy",'',[]])
data_list.append([datetime.datetime(2014, 9, 14),datetime.datetime(2014, 9, 19),2014,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2014, 9, 19),datetime.datetime(2014, 9, 21),2014,"Paris",'Paris',"France",'Hotel de Roubaix',[]])
data_list.append([datetime.datetime(2014, 9, 21),datetime.datetime(2014, 10, 11),2014,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2014, 10, 11),datetime.datetime(2014, 10, 13),2014,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun','Artur',"Hannsjoerg"]])
data_list.append([datetime.datetime(2014, 10, 13),datetime.datetime(2014, 10, 23),2014,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2014, 10, 23),datetime.datetime(2014, 10, 27),2014,"Istanbul",'Istanbul',"Turkey",'Turvan Hotel',['Chris Martin']])
data_list.append([datetime.datetime(2014, 10, 27),datetime.datetime(2014, 12, 12),2014,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2014, 12, 12),datetime.datetime(2014, 12, 14),2014,"London",'London',"United Kingdom",'',['Manuel']])
data_list.append([datetime.datetime(2014, 12, 14),datetime.datetime(2014, 12, 19),2014,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2014, 12, 19),datetime.datetime(2014, 12, 31),2014,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun','Artur',"Hannsjoerg","Anne-Kathrin"]])
data_list.append([datetime.datetime(2014, 12, 31),datetime.datetime(2015, 1, 1),2014,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun','Artur',"Hannsjoerg"]])
data_list.append([datetime.datetime(2015, 1, 1),datetime.datetime(2015, 1, 5),2015,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun','Artur',"Hannsjoerg"]])
data_list.append([datetime.datetime(2015, 1, 5),datetime.datetime(2015, 3, 14),2015,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2015, 3, 14),datetime.datetime(2015, 3, 15),2015,"Mailand",'Mailand',"Italy",'',['Aaron','Nate','Laser','Kennedy','Devin','Can','Christine']])
data_list.append([datetime.datetime(2015, 3, 15),datetime.datetime(2015, 3, 27),2015,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2015, 3, 27),datetime.datetime(2015, 3, 28),2015,"Madrid",'Madrid',"Spain",'',[]])
data_list.append([datetime.datetime(2015, 3, 28),datetime.datetime(2015, 3, 31),2015,"Cordoba",'Cordoba',"Spain",'',["Manuel"]])
data_list.append([datetime.datetime(2015, 3, 31),datetime.datetime(2015, 4, 4),2015,"Madrid",'Madrid',"Spain",'Hostal Palacios Fuencarrral',['Manuel']])
data_list.append([datetime.datetime(2015, 4, 4),datetime.datetime(2015, 4, 6),2015,"Madrid",'Madrid',"Spain",'Hostal Palacios Fuencarrral',["Eric"]])
data_list.append([datetime.datetime(2015, 4, 6),datetime.datetime(2015, 5, 14),2015,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2015, 5, 14),datetime.datetime(2015, 5, 18),2015,"Neapel",'Neapel',"Italy",'',['AJ',"Stephan"]])
data_list.append([datetime.datetime(2015, 5, 18),datetime.datetime(2015, 6, 6),2015,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2015, 6, 6),datetime.datetime(2015, 6, 8),2015,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun','Artur']])
data_list.append([datetime.datetime(2015, 6, 8),datetime.datetime(2015, 6, 13),2015,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2015, 6, 13),datetime.datetime(2015, 6, 21),2015,"Los Angeles",'Los Angeles',"USA",'',['Cameron','Eric']])
data_list.append([datetime.datetime(2015, 6, 21),datetime.datetime(2015, 6, 22),2015,"Flight LAX-LHR",'Flight',"Atlantic",'',[]])
data_list.append([datetime.datetime(2015, 6, 22),datetime.datetime(2015, 7, 8),2015,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2015, 7, 8),datetime.datetime(2015, 7, 10),2015,"Lyon",'Lyon',"France",'',["JetMET Workshop 2015"]])
data_list.append([datetime.datetime(2015, 7, 10),datetime.datetime(2015, 7, 17),2015,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2015, 7, 17),datetime.datetime(2015, 7, 20),2015,"Paris",'Paris',"France",'',['Riju']])
data_list.append([datetime.datetime(2015, 7, 20),datetime.datetime(2015, 8, 21),2015,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2015, 8, 21),datetime.datetime(2015, 8, 23),2015,"Beausoleil",'Beausoleil',"France",'',["AJ","Laser",'Evan']])
data_list.append([datetime.datetime(2015, 8, 23),datetime.datetime(2015, 8, 28),2015,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2015, 8, 28),datetime.datetime(2015, 8, 30),2015,"St Petersburg",'St Petersburg',"Russia",'',[]])
data_list.append([datetime.datetime(2015, 8, 30),datetime.datetime(2015, 9, 9),2015,"St Petersburg",'St Petersburg',"Russia",'',['Manuel','LHCP2015']])
data_list.append([datetime.datetime(2015, 9, 9),datetime.datetime(2015, 9, 12),2015,"St Petersburg",'St Petersburg',"Russia",'',[]])
data_list.append([datetime.datetime(2015, 9, 12),datetime.datetime(2015, 9, 18),2015,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2015, 9, 18),datetime.datetime(2015, 9, 20),2015,"Paris",'Paris',"France",'',[]])
data_list.append([datetime.datetime(2015, 9, 20),datetime.datetime(2015, 10, 2),2015,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2015, 10, 2),datetime.datetime(2015, 10, 4),2015,"Garching",'Garching',"Germany",'Chez Eric-Siyi',['Eric','Siyi']])
data_list.append([datetime.datetime(2015, 10, 4),datetime.datetime(2015, 10, 9),2015,"Wildbad Kreuth",'Kreuth',"Germany",'',['ISMD2015']])
data_list.append([datetime.datetime(2015, 10, 9),datetime.datetime(2015, 10, 10),2015,"Poechlarn",'Poechlarn',"Austria",'',["Eric",'Siyi']])
data_list.append([datetime.datetime(2015, 10, 10),datetime.datetime(2015, 10, 11),2015,"Salzburg",'Salzburg',"Austria",'',['Eric','Siyi']])
data_list.append([datetime.datetime(2015, 10, 11),datetime.datetime(2015, 11, 8),2015,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2015, 11, 8),datetime.datetime(2015, 11, 15),2015,"Berlin",'Berlin',"Germany",'',['Anne-Kathrin','Artur','Heidrun']])
data_list.append([datetime.datetime(2015, 11, 15),datetime.datetime(2015, 12, 18),2015,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2015, 12, 18),datetime.datetime(2015, 12, 31),2015,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun','Artur','Hannsjoerg','Anne-Kathrin']])
data_list.append([datetime.datetime(2015, 12, 31),datetime.datetime(2016, 1, 1),2015,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2016, 1, 1),datetime.datetime(2016, 1, 4),2016,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2016, 1, 4),datetime.datetime(2016, 3, 16),2016,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2016, 3, 16),datetime.datetime(2016, 3, 17),2016,"Piazza Armerina",'Piazza Armerina',"Italy",'',['Heidrun','Artur']])
data_list.append([datetime.datetime(2016, 3, 17),datetime.datetime(2016, 3, 19),2016,"Palermo",'Palermo',"Italy",'Casa Orioles',['Heidrun','Artur']])
data_list.append([datetime.datetime(2016, 3, 19),datetime.datetime(2016, 3, 20),2016,"Castellamare",'Castellamare',"Italy",'Helios B&B',['Heidrun','Artur']])
data_list.append([datetime.datetime(2016, 3, 20),datetime.datetime(2016, 3, 21),2016,"Agrigent",'Agrigent',"Italy",'Valle dei Templi',['Heidrun','Artur']])
data_list.append([datetime.datetime(2016, 3, 21),datetime.datetime(2016, 3, 22),2016,"Siracusa",'Siracusa',"Italy",'Hotel Teocrito',['Heidrun','Artur']])
data_list.append([datetime.datetime(2016, 3, 22),datetime.datetime(2016, 3, 25),2016,"Catania",'Catania',"Italy",'City-In Hostel B&B',['Heidrun','Artur']])
data_list.append([datetime.datetime(2016, 3, 25),datetime.datetime(2016, 3, 26),2016,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2016, 3, 26),datetime.datetime(2016, 3, 29),2016,"Barcelona",'Barcelona',"Spain",'',['Riju']])
data_list.append([datetime.datetime(2016, 3, 29),datetime.datetime(2016, 4, 23),2016,"Genf",'Genf',"Switzerland",'',[]])

# %%
data_list.append([datetime.datetime(2016, 4, 23),datetime.datetime(2016, 4, 25),2016,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun','Artur']])
data_list.append([datetime.datetime(2016, 4, 25),datetime.datetime(2016, 5, 4),2016,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2016, 5, 4),datetime.datetime(2016, 5, 8),2016,"Turin",'Turin',"Italy",'Hotel Romano',[]])
data_list.append([datetime.datetime(2016, 5, 8),datetime.datetime(2016, 5, 13),2016,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2016, 5, 13),datetime.datetime(2016, 5, 14),2016,"Bus Genf-Genua",'Bus',"Italy",'',["Amin"]])
data_list.append([datetime.datetime(2016, 5, 14),datetime.datetime(2016, 5, 16),2016,"Genua",'Genua',"Italy",'Hotel Galata',['Amin']])
data_list.append([datetime.datetime(2016, 5, 16),datetime.datetime(2016, 5, 28),2016,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2016, 5, 28),datetime.datetime(2016, 6, 3),2016,"Santander",'Santander',"Spain",'',['European LC Workshop 2016']])
data_list.append([datetime.datetime(2016, 6, 3),datetime.datetime(2016, 6, 4),2016,"Bilbao",'Bilbao',"Spain",'Hotel Conde Duque Bilbao',[]])
data_list.append([datetime.datetime(2016, 6, 4),datetime.datetime(2016, 6, 24),2016,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2016, 6, 24),datetime.datetime(2016, 6, 25),2016,"Mailand",'Mailand',"Italy",'Hotel Bernina',["Keyvan"]])
data_list.append([datetime.datetime(2016, 6, 25),datetime.datetime(2016, 6, 26),2016,"Ravenna",'Ravenna',"Italy",'',['Keyvan']])
data_list.append([datetime.datetime(2016, 6, 26),datetime.datetime(2016, 7, 1),2016,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2016, 7, 1),datetime.datetime(2016, 7, 3),2016,"Bordeaux",'Bordeaux',"France",'',['Artur','Heidrun','Anne-Kathrin']])
data_list.append([datetime.datetime(2016, 7, 3),datetime.datetime(2016, 7, 16),2016,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2016, 7, 16),datetime.datetime(2016, 7, 17),2016,"Fiesch",'Fiesch',"Switzerland",'Hotel Fiescherhof',['Artur','Heidrun']])
data_list.append([datetime.datetime(2016, 7, 17),datetime.datetime(2016, 7, 22),2016,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2016, 7, 22),datetime.datetime(2016, 7, 24),2016,"Bruessel",'Bruessel',"Belgium",'Hotel Mozart',[]])
data_list.append([datetime.datetime(2016, 7, 24),datetime.datetime(2016, 8, 13),2016,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2016, 8, 13),datetime.datetime(2016, 8, 15),2016,"Aurora",'Aurora',"USA",'Chez Hannsjoerg',['Artur','Heidrun','Hannsjoerg']])
data_list.append([datetime.datetime(2016, 8, 15),datetime.datetime(2016, 8, 18),2016,"Tusayan",'Tusayan',"USA",'',['Artur','Heidrun','Hannsjoerg']])
data_list.append([datetime.datetime(2016, 8, 18),datetime.datetime(2016, 8, 19),2016,"Monument Valley",'Monument Valley',"USA",'Kayenta Monument Valley Inn',['Artur','Heidrun','Hannsjoerg']])
data_list.append([datetime.datetime(2016, 8, 19),datetime.datetime(2016, 8, 20),2016,"Cortez",'Cortez',"USA",'Far View Lodge, Mesa Verde National Park',['Artur','Heidrun','Hannsjoerg']])
data_list.append([datetime.datetime(2016, 8, 20),datetime.datetime(2016, 8, 22),2016,"Moab",'Moab',"USA",'Holiday Inn Express & Suites Moab',['Artur','Heidrun','Hannsjoerg']])
data_list.append([datetime.datetime(2016, 8, 22),datetime.datetime(2016, 8, 23),2016,"Bryce Canyon City",'Bryce Canyon City',"USA","Best Western Plus Ruby's Inn",['Artur','Heidrun','Hannsjoerg']])
data_list.append([datetime.datetime(2016, 8, 23),datetime.datetime(2016, 8, 24),2016,"Springdale",'Springdale',"USA",'Bumbleberry Inn',['Artur','Heidrun','Hannsjoerg']])
data_list.append([datetime.datetime(2016, 8, 24),datetime.datetime(2016, 8, 26),2016,"Las Vegas",'Las Vegas',"USA",'Hotel Excalibur',['Artur','Heidrun','Hannsjoerg']])
data_list.append([datetime.datetime(2016, 8, 26),datetime.datetime(2016, 8, 29),2016,"Washington DC",'Washington DC',"USA",'Hyatt Place Washington DC/White House',['Artur','Heidrun']])
data_list.append([datetime.datetime(2016, 8, 29),datetime.datetime(2016, 8, 30),2016,"Flight IAD-GVA",'Flight',"Atlantic",'',[]])
data_list.append([datetime.datetime(2016, 8, 30),datetime.datetime(2016, 9, 3),2016,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2016, 9, 3),datetime.datetime(2016, 9, 4),2016,"Unterlauchringen",'Lauchringen',"Germany",'',['Artur','Heidrun']])
data_list.append([datetime.datetime(2016, 9, 4),datetime.datetime(2016, 9, 13),2016,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2016, 9, 13),datetime.datetime(2016, 9, 17),2016,"Arlington",'Arlington',"USA",'Parkway Inn Arlington',["Calice Workshop 2016"]])
data_list.append([datetime.datetime(2016, 9, 17),datetime.datetime(2016, 9, 18),2016,"Flight DAL-LHR",'Flight',"Atlantic",'',[]])
data_list.append([datetime.datetime(2016, 9, 18),datetime.datetime(2016, 10, 8),2016,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2016, 10, 8),datetime.datetime(2016, 10, 9),2016,"Santiago de Compostela",'Santiago de Compostela',"Spain",'Capitol Boutique Hotel',[]])
data_list.append([datetime.datetime(2016, 10, 9),datetime.datetime(2016, 10, 14),2016,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2016, 10, 14),datetime.datetime(2016, 10, 16),2016,"Koeln",'Koeln',"Germany",'Centro Hotel Central am Dom',[]])
data_list.append([datetime.datetime(2016, 10, 16),datetime.datetime(2016, 10, 17),2016,"Duesseldorf",'Duesseldorf',"Germany",'',[]])
data_list.append([datetime.datetime(2016, 10, 17),datetime.datetime(2016, 10, 21),2016,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2016, 10, 21),datetime.datetime(2016, 10, 23),2016,"Unterlauchringen",'Lauchringen',"Germany",'',['Artur','Heidrun']])
data_list.append([datetime.datetime(2016, 10, 23),datetime.datetime(2016, 11, 25),2016,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2016, 11, 25),datetime.datetime(2016, 11, 26),2016,"Mailand",'Mailand',"Italy",'Hotel Bernina',['Riju']])
data_list.append([datetime.datetime(2016, 11, 26),datetime.datetime(2016, 11, 27),2016,"Mantua",'Mantua',"Italy",'Rechigi Hotel',['Riju']])
data_list.append([datetime.datetime(2016, 11, 27),datetime.datetime(2016, 12, 2),2016,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2016, 12, 2),datetime.datetime(2016, 12, 4),2016,"Unterlauchringen",'Lauchringen',"Germany",'',['Artur','Heidrun','Hannsjoerg','Anne-Kathrin']])
data_list.append([datetime.datetime(2016, 12, 4),datetime.datetime(2016, 12, 5),2016,"Flight CDG-HND",'Flight',"Europe & Asia",'',[]])
data_list.append([datetime.datetime(2016, 12, 5),datetime.datetime(2016, 12, 6),2016,"Tokyo",'Tokyo',"Japan",'APA Hotel Ginza-Takaracho Tokyo Yaesu Minami-guchi',[]])
data_list.append([datetime.datetime(2016, 12, 6),datetime.datetime(2016, 12, 9),2016,"Morioka",'Morioka',"Japan",'OLD Tokyo Inn Morioka Ekimae',[]])
data_list.append([datetime.datetime(2016, 12, 9),datetime.datetime(2016, 12, 11),2016,"Tokyo",'Tokyo',"Japan",'APA Hotel Ginza-Takaracho Tokyo Yaesu Minami-guchi',[]])
data_list.append([datetime.datetime(2016, 12, 11),datetime.datetime(2016, 12, 16),2016,"Kyoto",'Kyoto',"Japan",'El Inn Kyoto',[]])
data_list.append([datetime.datetime(2016, 12, 16),datetime.datetime(2016, 12, 17),2016,"Tokyo",'Tokyo',"Japan",'APA Hotel Ginza-Takaracho Tokyo Yaesu Minami-guchi',[]])
data_list.append([datetime.datetime(2016, 12, 17),datetime.datetime(2016, 12, 18),2016,"Flight HND-CDG",'Flight',"Europe & Asia",'',[]])
data_list.append([datetime.datetime(2016, 12, 18),datetime.datetime(2016, 12, 21),2016,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2016, 12, 21),datetime.datetime(2016, 12, 31),2016,"Unterlauchringen",'Lauchringen',"Germany",'',['Anne-Kathrin','Artur','Heidrun','Hannsjoerg']])
data_list.append([datetime.datetime(2016, 12, 31),datetime.datetime(2017, 1, 1),2016,"Unterlauchringen",'Lauchringen',"Germany",'',['Anne-Kathrin','Artur','Heidrun','Hannsjoerg']])
data_list.append([datetime.datetime(2017, 1, 1),datetime.datetime(2017, 1, 2),2017,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2017, 1, 2),datetime.datetime(2017, 1, 4),2017,"Dublin",'Dublin',"Ireland",'',["Chris Martin"]])
data_list.append([datetime.datetime(2017, 1, 4),datetime.datetime(2017, 1, 13),2017,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2017, 1, 13),datetime.datetime(2017, 1, 15),2017,"Avignon",'Avignon',"France","ibis Avignon Centre Pont de l'Europe",[]])
data_list.append([datetime.datetime(2017, 1, 15),datetime.datetime(2017, 2, 10),2017,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2017, 2, 10),datetime.datetime(2017, 2, 11),2017,"Bruessel",'Bruessel',"Belgium",'Hotel Mozart',['Riju']])
data_list.append([datetime.datetime(2017, 2, 11),datetime.datetime(2017, 2, 12),2017,"Gent",'Gent',"Belgium",'ROXI Residence Gent',['Riju']])
data_list.append([datetime.datetime(2017, 2, 12),datetime.datetime(2017, 3, 3),2017,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2017, 3, 3),datetime.datetime(2017, 3, 5),2017,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun','Artur']])
data_list.append([datetime.datetime(2017, 3, 5),datetime.datetime(2017, 3, 24),2017,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2017, 3, 24),datetime.datetime(2017, 3, 25),2017,"Mailand",'Mailand',"Italy",'Hotel Bernina',[]])
data_list.append([datetime.datetime(2017, 3, 25),datetime.datetime(2017, 3, 26),2017,"Assisi",'Assisi',"Italy",'Hotel Trattoria Pallotta',[]])
data_list.append([datetime.datetime(2017, 3, 26),datetime.datetime(2017, 4, 14),2017,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2017, 4, 14),datetime.datetime(2017, 4, 17),2017,"Kiew",'Kiew',"Ukraine",'Express hotel',[]])
data_list.append([datetime.datetime(2017, 4, 17),datetime.datetime(2017, 4, 28),2017,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2017, 4, 28),datetime.datetime(2017, 5, 2),2017,"Frankfurt",'Frankfurt',"Germany",'Hotel Union',[]])
data_list.append([datetime.datetime(2017, 5, 2),datetime.datetime(2017, 5, 24),2017,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2017, 5, 24),datetime.datetime(2017, 5, 28),2017,"Madrid",'Madrid',"Spain",'Hotel Weare Chamartín',[]])
data_list.append([datetime.datetime(2017, 5, 28),datetime.datetime(2017, 6, 3),2017,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2017, 6, 3),datetime.datetime(2017, 6, 6),2017,"Athen",'Athen',"Greece",'Carolina Hotel since 1934',["Riju",'Amin']])
data_list.append([datetime.datetime(2017, 6, 6),datetime.datetime(2017, 6, 9),2017,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2017, 6, 9),datetime.datetime(2017, 6, 11),2017,"Twin Falls",'Twin Falls',"USA",'Shilo Inn Suites - Twin Falls',['Artur','Heidrun','Hannsjoerg']])
data_list.append([datetime.datetime(2017, 6, 11),datetime.datetime(2017, 6, 17),2017,"Island Park",'Island Park',"USA",'Sawtelle Mountain Resort',['Heidrun','Artur',"Hannsjoerg"]])
data_list.append([datetime.datetime(2017, 6, 17),datetime.datetime(2017, 6, 20),2017,"Jackson",'Jackson',"USA",'',['Artur','Heidrun','Hannsjoerg']])
data_list.append([datetime.datetime(2017, 6, 20),datetime.datetime(2017, 6, 22),2017,"Salt Lake City",'Salt Lake City',"USA",'',['Artur','Heidrun','Hannsjoerg']])
data_list.append([datetime.datetime(2017, 6, 22),datetime.datetime(2017, 6, 23),2017,"Flight SLC-CDG",'Flight',"Atlantic",'',['Artur','Heidrun']])
data_list.append([datetime.datetime(2017, 6, 23),datetime.datetime(2017, 7, 5),2017,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2017, 7, 5),datetime.datetime(2017, 7, 12),2017,"Venedig",'Venedig',"Italy",'Hotel Biasutti',["Reyer",'Riju','EPS2017']])
data_list.append([datetime.datetime(2017, 7, 12),datetime.datetime(2017, 7, 13),2017,"Mestre",'Venedig',"Italy",'Hotel Regit',[]])
data_list.append([datetime.datetime(2017, 7, 13),datetime.datetime(2017, 7, 16),2017,"Trieste",'Trieste',"Italy",'',["Reyer"]])
data_list.append([datetime.datetime(2017, 7, 16),datetime.datetime(2017, 7, 21),2017,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2017, 7, 21),datetime.datetime(2017, 7, 23),2017,"Oslo",'Oslo',"Norway",'Smarthotel Oslo',[]])
data_list.append([datetime.datetime(2017, 7, 23),datetime.datetime(2017, 7, 28),2017,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2017, 7, 28),datetime.datetime(2017, 7, 30),2017,"Garching",'Garching',"Germany",'Chez Eric-Siyi',['Eric','Siyi']])
data_list.append([datetime.datetime(2017, 7, 30),datetime.datetime(2017, 8, 27),2017,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2017, 8, 27),datetime.datetime(2017, 8, 28),2017,"Split",'Split',"Croatia",'Hotel Dujam',[]])
data_list.append([datetime.datetime(2017, 8, 28),datetime.datetime(2017, 9, 1),2017,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2017, 9, 1),datetime.datetime(2017, 9, 3),2017,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun','Artur']])
data_list.append([datetime.datetime(2017, 9, 3),datetime.datetime(2017, 9, 6),2017,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2017, 9, 6),datetime.datetime(2017, 9, 8),2017,"Rom",'Rom',"Italy",'Hotel Trinita Dei Monti',['Riju']])
data_list.append([datetime.datetime(2017, 9, 8),datetime.datetime(2017, 9, 11),2017,"Rom",'Rom',"Italy",'Hotel Trinita Dei Monti',['Riju','Amin']])
data_list.append([datetime.datetime(2017, 9, 11),datetime.datetime(2017, 9, 15),2017,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2017, 9, 15),datetime.datetime(2017, 9, 18),2017,"London",'London',"United Kingdom",'Point A Hotel London Kings Cross – St Pancras',['Riju']])
data_list.append([datetime.datetime(2017, 9, 18),datetime.datetime(2017, 9, 30),2017,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2017, 9, 30),datetime.datetime(2017, 10, 1),2017,"Graz",'Graz',"Austria",'Centro Hotel Strasser',[]])
data_list.append([datetime.datetime(2017, 10, 1),datetime.datetime(2017, 10, 6),2017,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2017, 10, 6),datetime.datetime(2017, 10, 9),2017,"Tallin",'Tallin',"Estonia",'Rixwell Old Town Hotel',['Riju','Rachel','Reyer']])
data_list.append([datetime.datetime(2017, 10, 9),datetime.datetime(2017, 11, 10),2017,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2017, 11, 10),datetime.datetime(2017, 11, 13),2017,"Marrakesh",'Marrakesh',"Morocco",'Riad Hotel Essaouira',['Riju','Cameron','Tony']])
data_list.append([datetime.datetime(2017, 11, 13),datetime.datetime(2017, 12, 2),2017,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2017, 12, 2),datetime.datetime(2017, 12, 4),2017,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun','Artur']])
data_list.append([datetime.datetime(2017, 12, 4),datetime.datetime(2017, 12, 22),2017,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2017, 12, 22),datetime.datetime(2017, 12, 29),2017,"Unterlauchringen",'Lauchringens',"Germany",'',['Heidrun','Artur']])
data_list.append([datetime.datetime(2017, 12, 29),datetime.datetime(2017, 12, 30),2017,"Flight ZRH-",'Flight',"Europe & Asia",'',['Heidrun','Artur']])
data_list.append([datetime.datetime(2017, 12, 30),datetime.datetime(2017, 12, 31),2017,"Shanghai",'Shanghai',"China",'Holiday Inn Shanghai Nanjing Road',[]])
data_list.append([datetime.datetime(2017, 12, 31),datetime.datetime(2018, 1, 1),2017,"Shanghai",'Shanghai',"China",'Holiday Inn Shanghai Nanjing Road',["Siyi"]])                                                                                                                   
data_list.append([datetime.datetime(2018, 1, 1),datetime.datetime(2018, 1, 3),2018,"Suzhou",'Suzhou',"China",'Hotel Soul Suzhou',[]])                                                                                                                   
data_list.append([datetime.datetime(2018, 1, 3),datetime.datetime(2018, 1, 4),2018,"Kunshan",'Kunshan',"China",'',["Siyi","Siyi's Parents"]])                                                                                                                   
data_list.append([datetime.datetime(2018, 1, 4),datetime.datetime(2018, 1, 6),2018,"Nanjing",'Nanjing',"China",'Jinling Hotel',["Siyi",'xyz']])                                                                                                                   
data_list.append([datetime.datetime(2018, 1, 6),datetime.datetime(2018, 1, 11),2018,"Beijing",'Beijing',"China",'Inner Mongolia Grand Hotel',[]])                                                                                                                   
data_list.append([datetime.datetime(2018, 1, 11),datetime.datetime(2018, 1, 12),2018,"Xi'an","Xi'an","China","ibis Xi'an North Train Station Executive Center",[]])                                                                                                                   
data_list.append([datetime.datetime(2018, 1, 12),datetime.datetime(2018, 1, 14),2018,"Beijing",'Beijing',"China",'Inner Mongolia Grand Hotel',[]])                                                                                                                   
data_list.append([datetime.datetime(2018, 1, 14),datetime.datetime(2018, 1, 20),2018,"Hongkong",'Hongkong',"China",'Shamrock Hotel',[]])                                                                                                                   
data_list.append([datetime.datetime(2018, 1, 20),datetime.datetime(2018, 1, 21),2018,"Flight HKG-FRA",'Flight',"Europe & Asia",'',[]])                                                                                                                   
data_list.append([datetime.datetime(2018, 1, 21),datetime.datetime(2018, 3, 2),2018,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2018, 3, 2),datetime.datetime(2018, 3, 3),2018,"Toulouse",'Toulouse',"France",'ibis budget Toulouse Centre Gare',[]])
data_list.append([datetime.datetime(2018, 3, 3),datetime.datetime(2018, 3, 9),2018,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2018, 3, 9),datetime.datetime(2018, 3, 11),2018,"Bruessel",'Bruessel',"Belgium",'',['Mohammed']])
data_list.append([datetime.datetime(2018, 3, 11),datetime.datetime(2018, 3, 28),2018,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2018, 3, 28),datetime.datetime(2018, 3, 31),2018,"Reykjavik",'Reykjavik',"Iceland",'Fosshotel Lind',['Riju','Reyer','Rachel']])
data_list.append([datetime.datetime(2018, 3, 31),datetime.datetime(2018, 4, 13),2018,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2018, 4, 13),datetime.datetime(2018, 4, 14),2018,"Oberding",'Oberding',"Germany",'',[]])
data_list.append([datetime.datetime(2018, 4, 14),datetime.datetime(2018, 4, 15),2018,"Frederiksberg",'Frederiksberg',"Denmark",'Cabinn Scandinavia Hotel - Frederiksberg',['Riju','Reyer','Rachel']])
data_list.append([datetime.datetime(2018, 4, 15),datetime.datetime(2018, 4, 27),2018,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2018, 4, 27),datetime.datetime(2018, 4, 29),2018,"Paris",'Paris',"France",'Hotel De Venise',['Christine','Reyer']])
data_list.append([datetime.datetime(2018, 4, 29),datetime.datetime(2018, 5, 1),2018,"Paris",'Paris',"France",'Hotel De Venise',['Reyer']])
data_list.append([datetime.datetime(2018, 5, 1),datetime.datetime(2018, 5, 10),2018,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2018, 5, 10),datetime.datetime(2018, 5, 12),2018,"Buehl",'Buehl',"Germany",'',['Heidrun','Artur','Hannsjoerg','Felicitas','Angelika','Wolfgang','Franziska','Jan-Marc','Anne-Kathrin','Christian']])
data_list.append([datetime.datetime(2018, 5, 12),datetime.datetime(2018, 5, 13),2018,"Unterlauchringen",'Lauchringen',"Germany",'',['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2018, 5, 13),datetime.datetime(2018, 5, 18),2018,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2018, 5, 18),datetime.datetime(2018, 5, 21),2018,"Mailand",'Mailand',"Italy",'Hotel Bernina',["Ami"]])
data_list.append([datetime.datetime(2018, 5, 21),datetime.datetime(2018, 5, 25),2018,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2018, 5, 25),datetime.datetime(2018, 5, 27),2018,"Barcelona",'Barcelona',"Spain",'',['Rachel']])
data_list.append([datetime.datetime(2018, 5, 27),datetime.datetime(2018, 5, 28),2018,"Castelldefels",'Castelldefels',"Spain",'',[]])
data_list.append([datetime.datetime(2018, 5, 28),datetime.datetime(2018, 6, 2),2018,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2018, 6, 2),datetime.datetime(2018, 6, 4),2018,"Edinburgh",'Edinburgh',"United Kingdom",'Brooks Hotel',['Artur','Heidrun']])
data_list.append([datetime.datetime(2018, 6, 4),datetime.datetime(2018, 6, 6),2018,"York",'York',"United Kingdom",'ibis York Centre',['Artur','Heidrun']])
data_list.append([datetime.datetime(2018, 6, 6),datetime.datetime(2018, 6, 9),2018,"Manchester",'Manchester',"United Kingdom",'The Gardens Hotel',['Artur','Heidrun']])
data_list.append([datetime.datetime(2018, 6, 9),datetime.datetime(2018, 6, 10),2018,"Manchester",'Manchester',"United Kingdom",'The Gardens Hotel',[]])
data_list.append([datetime.datetime(2018, 6, 10),datetime.datetime(2018, 7, 1),2018,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2018, 7, 1),datetime.datetime(2018, 7, 2),2018,"Dubai Airport",'Dubai Airport',"United Arab Emirates",'',[]])
data_list.append([datetime.datetime(2018, 7, 2),datetime.datetime(2018, 7, 13),2018,"Seoul",'Seoul',"South Korea",'Ibis Styles Ambassador Seoul Gangnam',['ICHEP2008']])
data_list.append([datetime.datetime(2018, 7, 13),datetime.datetime(2018, 7, 14),2018,"Busan",'Busan',"South Korea",'Best in City Hotel',["Steffen",'Stephanie']])
data_list.append([datetime.datetime(2018, 7, 14),datetime.datetime(2018, 7, 15),2018,"Genf",'Genf',"Switzerland",'Ibis Styles Ambassador Seoul Gangnam',[]])
data_list.append([datetime.datetime(2018, 7, 15),datetime.datetime(2018, 7, 16),2018,"Dubai Airport",'Dubai Airport',"United Arab Emirates",'',[]])
data_list.append([datetime.datetime(2018, 7, 16),datetime.datetime(2018, 7, 27),2018,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2018, 7, 27),datetime.datetime(2018, 7, 29),2018,"Unterlauchringen",'Lauchringen',"Germany",'',['Artur','Heidrun']])
data_list.append([datetime.datetime(2018, 7, 29),datetime.datetime(2018, 8, 17),2018,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2018, 8, 17),datetime.datetime(2018, 8, 19),2018,"Unterlauchringen",'Lauchringen',"Germany",'',['Artur','Heidrun']])
data_list.append([datetime.datetime(2018, 8, 19),datetime.datetime(2018, 8, 31),2018,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2018, 8, 31),datetime.datetime(2018, 9, 1),2018,"Muenchen",'Muenchen',"Germany",'',['Reyer','Chris Brainerd']])
data_list.append([datetime.datetime(2018, 9, 1),datetime.datetime(2018, 9, 2),2018,"Fuessen",'Fuessen',"Germany",'Luitpoldpark-Hotel',['Reyer','Chris Brainerd']])
data_list.append([datetime.datetime(2018, 9, 2),datetime.datetime(2018, 9, 3),2018,"Regensburg",'Regensburg',"Germany",'',['Reyer','Chris Brainerd']])
data_list.append([datetime.datetime(2018, 9, 3),datetime.datetime(2018, 9, 4),2018,"Bamberg",'Bamberg',"Germany",'Hotel Europa',['Reyer','Chris Brainerd']])
data_list.append([datetime.datetime(2018, 9, 4),datetime.datetime(2018, 9, 5),2018,"Bayreuth",'Bayreuth',"Germany",'Hotel Goldener Hirsch',['Reyer','Chris Brainerd']])
data_list.append([datetime.datetime(2018, 9, 5),datetime.datetime(2018, 9, 7),2018,"Dessau",'Dessau-Rosslau',"Germany",'DORMERO Hotel Dessau-Rosslau',['Reyer','Chris Brainerd']])
data_list.append([datetime.datetime(2018, 9, 7),datetime.datetime(2018, 9, 9),2018,"Berlin",'Berlin',"Germany",'',['Reyer','Chris Brainerd','Riju']])
data_list.append([datetime.datetime(2018, 9, 9),datetime.datetime(2018, 9, 21),2018,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2018, 9, 21),datetime.datetime(2018, 9, 23),2018,"Bruessel",'Bruessel',"Belgium",'',['Rachel']])
data_list.append([datetime.datetime(2018, 9, 23),datetime.datetime(2018, 11, 17),2018,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2018, 11, 17),datetime.datetime(2018, 11, 19),2018,"Nimes",'Nimes',"France",'ibis budget Nimes Centre Gare',['Santona']])
data_list.append([datetime.datetime(2018, 11, 19),datetime.datetime(2018, 11, 30),2018,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2018, 11, 30),datetime.datetime(2018, 12, 2),2018,"Unterlauchringen",'Lauchringen',"Germany",'',['Artur','Heidrun']])
data_list.append([datetime.datetime(2018, 12, 2),datetime.datetime(2018, 12, 21),2018,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2018, 12, 21),datetime.datetime(2018, 12, 28),2018,"Unterlauchringen",'Lauchringen',"Germany",'',['Artur','Heidrun']])
data_list.append([datetime.datetime(2018, 12, 28),datetime.datetime(2018, 12, 30),2018,"Ladenburg",'Ladenburg',"Germany",'',['Artur','Heidrun']])
data_list.append([datetime.datetime(2018, 12, 30),datetime.datetime(2018, 12, 31),2018,"Unterlauchringen",'Lauchringen',"Germany",'',['Artur','Heidrun']])
data_list.append([datetime.datetime(2018, 12, 31),datetime.datetime(2019, 1, 1),2018,"Unterlauchringen",'Lauchringen',"Germany",'',['Artur','Heidrun']])
data_list.append([datetime.datetime(2019, 1, 1),datetime.datetime(2019, 1, 6),2019,"Unterlauchringen",'Lauchringen',"Germany",'',['Artur','Heidrun']])
data_list.append([datetime.datetime(2019, 1, 6),datetime.datetime(2019, 1, 18),2019,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2019, 1, 18),datetime.datetime(2019, 1, 20),2019,"Unterlauchringen",'Lauchringen',"Germany",'',['Artur','Heidrun']])
data_list.append([datetime.datetime(2019, 1, 20),datetime.datetime(2019, 3, 10),2019,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2019, 3, 10),datetime.datetime(2019, 3, 15),2019,"Bari",'Bari',"Italy","Grand Hotel Leon D'Oro",['Heidrun','Artur']])
data_list.append([datetime.datetime(2019, 3, 15),datetime.datetime(2019, 3, 22),2019,"Neapel",'Neapel',"Italy",'',['Heidrun','Artur']])

# %%
data_list.append([datetime.datetime(2019, 3, 22),datetime.datetime(2019, 4, 13),2019,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2019, 4, 13),datetime.datetime(2019, 4, 14),2019,"London",'London',"United Kingdom",'Harlingford Hotel',[]])
data_list.append([datetime.datetime(2019, 4, 14),datetime.datetime(2019, 4, 17),2019,"Oxford",'Oxford',"United Kingdom",'The Bocardo Hotel',["CEPC Workshop 2019"]])
data_list.append([datetime.datetime(2019, 4, 17),datetime.datetime(2019, 4, 18),2019,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2019, 4, 18),datetime.datetime(2019, 4, 22),2019,"Paris",'Paris',"France",'',['Riju','Chris Brainerd']])
data_list.append([datetime.datetime(2019, 4, 22),datetime.datetime(2019, 5, 30),2019,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2019, 5, 30),datetime.datetime(2019, 6, 3),2019,"Hannover",'Hannover',"Germany",'',['Grace']])
data_list.append([datetime.datetime(2019, 6, 3),datetime.datetime(2019, 6, 7),2019,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2019, 6, 7),datetime.datetime(2019, 6, 10),2019,"Unterlauchringen",'Lauchringen',"Germany",'',[]])
data_list.append([datetime.datetime(2019, 6, 10),datetime.datetime(2019, 8, 16),2019,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2019, 8, 16),datetime.datetime(2019, 8, 18),2019,"Unterlauchringen",'Lauchringen',"Germany",'',[]])
data_list.append([datetime.datetime(2019, 8, 18),datetime.datetime(2019, 9, 20),2019,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2019, 9, 20),datetime.datetime(2019, 9, 22),2019,"Paris",'Paris',"France",'Kyriad Paris 12 - Nation',["Sam",'Nhi','Michael','Vivan']])
data_list.append([datetime.datetime(2019, 9, 22),datetime.datetime(2019, 11, 17),2019,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2019, 11, 17),datetime.datetime(2019, 11, 18),2019,"Unterlauchringen",'Lauchringen',"Germany",'',['Artur','Christian','Mathilda','Christian']])
data_list.append([datetime.datetime(2019, 11, 18),datetime.datetime(2019, 12, 18),2019,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2019, 12, 18),datetime.datetime(2019, 12, 29),2019,"Unterlauchringen",'Lauchringen',"Germany",'',['Artur','Anne-Kathrin','Christian','Mathilda']])
data_list.append([datetime.datetime(2019, 12, 29),datetime.datetime(2019, 12, 31),2019,"Dresden",'Dresden',"Germany",'Motel One Dresden - Palaisplatz',["Artur"]])
data_list.append([datetime.datetime(2019, 12, 31),datetime.datetime(2020, 1, 1),2019,"Dresden",'Dresden',"Germany",'Motel One Dresden - Palaisplatz',["Artur"]])
data_list.append([datetime.datetime(2020, 1, 1),datetime.datetime(2020, 1, 5),2020,"Wroclaw",'Wroclaw',"Poland",'RentPlanet - Aparrtamenty Centrum',["Artur"]])
data_list.append([datetime.datetime(2020, 1, 5),datetime.datetime(2020, 1, 6),2020,"Bayreuth",'Bayreuth',"Germany",'Hotel Rheingold',["Artur"]])
data_list.append([datetime.datetime(2020, 1, 6),datetime.datetime(2020, 1, 7),2020,"Unterlauchringen",'Lauchringen',"Germany",'',["Artur"]])
data_list.append([datetime.datetime(2020, 1, 7),datetime.datetime(2020, 1, 17),2020,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2020, 1, 17),datetime.datetime(2020, 1, 19),2020,"Unterlauchringen",'Lauchringen',"Germany",'',['Artur','Anne-Kathrin','Christian','Mathilda']])
data_list.append([datetime.datetime(2020, 1, 19),datetime.datetime(2020, 2, 20),2020,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2020, 2, 20),datetime.datetime(2020, 2, 27),2020,"Rom","Rom",'Italy','Augusta Lucilla Palace',[]])
data_list.append([datetime.datetime(2020, 2, 27),datetime.datetime(2020, 3, 2),2020,"Rom",'Rom','Italy','',['Bryan']])
data_list.append([datetime.datetime(2020, 3, 2),datetime.datetime(2020, 5, 31),2020,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2020, 5, 31),datetime.datetime(2020, 6, 1),2020,"Ebenalp",'Wasserauen',"Switzerland",'',['Juno']])
data_list.append([datetime.datetime(2020, 6, 1),datetime.datetime(2020, 6, 2),2020,"Murg",'Murg',"Switzerland",'Seeblick SMART Hotel Roessli',['Juno']])
data_list.append([datetime.datetime(2020, 6, 2),datetime.datetime(2020, 6, 18),2020,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2020, 6, 18),datetime.datetime(2020, 6, 21),2020,"Unterlauchringen",'Lauchringen',"Germany",'',['Artur']])
data_list.append([datetime.datetime(2020, 6, 21),datetime.datetime(2020, 8, 9),2020,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2020, 8, 9),datetime.datetime(2020, 8, 10),2020,"Konkordiahuette",'Fiescheralp',"Switzerland",'',['Sasha','Tema','Juno']])
data_list.append([datetime.datetime(2020, 8, 10),datetime.datetime(2020, 8, 28),2020,"Genf",'Genf',"Switzerland",'',[]])
data_list.append([datetime.datetime(2020, 8, 28),datetime.datetime(2020, 12, 31),2020,"Unterlauchringen",'Lauchringen',"Germany",'',['Artur']])
data_list.append([datetime.datetime(2020, 12, 31),datetime.datetime(2021, 1, 1),2020,"Unterlauchringen",'Lauchringen',"Germany",'',['Artur']])
data_list.append([datetime.datetime(2021, 1, 1),datetime.datetime(2021, 4, 28),2021,"Unterlauchringen",'Lauchringen',"Germany",'',['Artur']])

# %%
data_list.append([datetime.datetime(2021, 4, 28),datetime.datetime(2021, 7, 23),2021,"Wien",'Wien',"Austria",'',[]])
data_list.append([datetime.datetime(2021, 7, 23),datetime.datetime(2021, 7, 25),2021,"Innsbruck",'Innsbruck',"Austria",'',['Sam','Grace','Janina']])
data_list.append([datetime.datetime(2021, 7, 25),datetime.datetime(2021, 8, 27),2021,"Wien",'Wien',"Austria",'',[]])
data_list.append([datetime.datetime(2021, 8, 27),datetime.datetime(2021, 8, 29),2021,"Prag",'Prag',"Czech Republic",'K+K Hotel Central',[]])
data_list.append([datetime.datetime(2021, 8, 29),datetime.datetime(2021, 9, 2),2021,"Wien",'Wien',"Austria",'',[]])
data_list.append([datetime.datetime(2021, 9, 2),datetime.datetime(2021, 9, 5),2021,"Geiselwind",'Geiselwind',"Germany",'',["Marion",'Artur','Hannsjoerg','Felicitas','Julius','Jan-Marc','Franziska','Anne-Kathrin','Christian','Mathilda']])
data_list.append([datetime.datetime(2021, 9, 5),datetime.datetime(2021, 10, 22),2021,"Wien",'Wien',"Austria",'',[]])
data_list.append([datetime.datetime(2021, 10, 22),datetime.datetime(2021, 10, 23),2021,"Nuernberg",'Nuernberg',"Germany",'',[]])
data_list.append([datetime.datetime(2021, 10, 23),datetime.datetime(2021, 10, 25),2021,"Trier",'Trier',"Germany",'Hotel Roemischer Kaiser',[]])
data_list.append([datetime.datetime(2021, 10, 25),datetime.datetime(2021, 10, 26),2021,"Metz",'Metz',"France",'Hotel Escurial - Centre Gare',[]])
data_list.append([datetime.datetime(2021, 10, 26),datetime.datetime(2021, 10, 29),2021,"Paris",'Paris',"France",'Kyriad Paris 10 - Canal St Martin-Republique',[]])
data_list.append([datetime.datetime(2021, 10, 29),datetime.datetime(2021, 11, 1),2021,"Frankfurt",'Frankfurt',"Germany",'Hotel Europa Life',[]])
data_list.append([datetime.datetime(2021, 11, 1),datetime.datetime(2021, 12, 22),2021,"Wien",'Wien',"Austria",'',[]])
data_list.append([datetime.datetime(2021, 12, 22),datetime.date(2021,12,27),2021,"Unterlauchringen",'Lauchringen',"Germany",'',["Artur",'Hannsjoerg']])
data_list.append([datetime.datetime(2021, 12, 27),datetime.date(2021,12,31),2021,"Unterlauchringen",'Lauchringen',"Germany",'',['Hannsjoerg']])
data_list.append([datetime.datetime(2021, 12, 31),datetime.datetime(2022, 1, 1),2021,"Unterlauchringen",'Lauchringen',"Germany",'',['Hannsjoerg']])
data_list.append([datetime.datetime(2022, 1, 1),datetime.datetime(2022, 1, 2),2022,"Unterlauchringen",'Lauchringen',"Germany",'',['Hannsjoerg']])
data_list.append([datetime.datetime(2022, 1, 2),datetime.datetime(2022,3,19),2022,"Wien",'Wien',"Austria",'',[]])
data_list.append([datetime.datetime(2022, 3, 19),datetime.datetime(2022,3,21),2022,"Malaga",'Malaga',"Spain",'Pension Terminal',[]])
data_list.append([datetime.datetime(2022,3,21),datetime.datetime(2022,3,24),2022,"Granada",'Granada',"Spain",'Hotel Macia Condor',[]])
data_list.append([datetime.datetime(2022,3,24),datetime.datetime(2022,3,25),2022,"Cordoba",'Cordoba',"Spain",'Hotel Serrano',[]])
data_list.append([datetime.datetime(2022,3,25),datetime.datetime(2022,3,28),2022,"Sevilla",'Sevilla',"Spain",'Ayre Hotel Sevilla',[]])
data_list.append([datetime.datetime(2022,3,28),datetime.datetime(2022,4,3),2022,"Madrid",'Madrid',"Spain",'Hotel Mediodia',[]])
data_list.append([datetime.datetime(2022,4,3),datetime.datetime(2022,5,20),2022,"Wien",'Wien',"Austria",'',[]])
data_list.append([datetime.datetime(2022,5,20),datetime.datetime(2022,5,21),2022,"Wien",'Wien',"Austria",'',['Rachel']])
data_list.append([datetime.datetime(2022,5,21),datetime.datetime(2022,5,23),2022,"Wien",'Wien',"Austria",'',['Rachel','Chris Martin']])
data_list.append([datetime.datetime(2022,5,23),datetime.datetime(2022,5,25),2022,"Wien",'Wien',"Austria",'',["Chris Martin"]])
data_list.append([datetime.datetime(2022,5,25),datetime.datetime(2022,5,27),2022,"Budapest",'Budapest',"Hungary",'',["Chris Martin"]])
data_list.append([datetime.datetime(2022,5,27),datetime.datetime(2022,5,28),2022,"Wien",'Wien',"Austria",'',["Chris Martin"]])
data_list.append([datetime.datetime(2022,5,28),datetime.datetime(2022,6,2),2022,"Wien",'Wien',"Austria",'',[]])
data_list.append([datetime.datetime(2022,6,2),datetime.datetime(2022,6,7),2022,"Wien",'Wien',"Austria",'',['Artur']])
data_list.append([datetime.datetime(2022,6,7),datetime.datetime(2022,6,16),2022,"Wien",'Wien',"Austria",'',[]])
data_list.append([datetime.datetime(2022,6,16),datetime.datetime(2022,6,19),2022,"Berlin",'Berlin',"Germany",'',['Hannsjoerg']])
data_list.append([datetime.datetime(2022,6,19),datetime.datetime(2022,7,28),2022,"Wien",'Wien',"Austria",'',[]])
data_list.append([datetime.datetime(2022,7,28),datetime.datetime(2022,7,29),2022,"Wien",'Wien',"Austria",'',['Riju']])
data_list.append([datetime.datetime(2022,7,29),datetime.datetime(2022,7,30),2022,"Mailand",'Mailand',"Italy",'Hotel Bernina',['Riju']])
data_list.append([datetime.datetime(2022,7,30),datetime.datetime(2022,7,31),2022,"Angera",'Angera',"Italy",'Hotel Dei Tegli',['Riju']])
data_list.append([datetime.datetime(2022,7,31),datetime.datetime(2022,8,3),2022,"Naples",'Naples',"Italy",'Hotel Garibaldi',['Riju']])
data_list.append([datetime.datetime(2022,8,3),datetime.datetime(2022,8,4),2022,"Mailand",'Mailand',"Italy",'Hotel Bernina',['Riju']])
data_list.append([datetime.datetime(2022,8,4),datetime.datetime(2022,8,5),2022,"Florenz",'Florenz',"Italy",'Hotel Desiree',[]])
data_list.append([datetime.datetime(2022,8,5),datetime.datetime(2022,8,6),2022,"Venedig",'Venedig',"Italy",'Hotel Il Moro di Venezia',[]])
data_list.append([datetime.datetime(2022,8,6),datetime.datetime(2022,8,7),2022,"Mailand",'Mailand',"Italy",'Hotel Bernina',[]])
data_list.append([datetime.datetime(2022,8,7),datetime.datetime(2022,8,12),2022,"Wien",'Wien',"Austria",'',['Riju']])
data_list.append([datetime.datetime(2022,8,12),datetime.datetime(2022,8,14),2022,"Prag",'Prag',"Czech Republic",'',['Riju']])
data_list.append([datetime.datetime(2022,8,14),datetime.datetime(2022,8,19),2022,"Wien",'Wien',"Austria",'',['Riju']])
data_list.append([datetime.datetime(2022,8,19),datetime.datetime(2022,8,22),2022,"Wien",'Wien',"Austria",'',[]])
data_list.append([datetime.datetime(2022,8,22),datetime.datetime(2022,8,23),2022,"Wien",'Wien',"Austria",'',['Riju']])
data_list.append([datetime.datetime(2022,8,23),datetime.datetime(2022,8,25),2022,"Wien",'Wien',"Austria",'',[]])
data_list.append([datetime.datetime(2022,8,25),datetime.datetime(2022,8,28),2022,"Riga",'Riga',"Latvia",'',['Artur']])
data_list.append([datetime.datetime(2022,8,28),datetime.datetime(2022,8,29),2022,"Wien",'Wien',"Austria",'',['Artur']])
data_list.append([datetime.datetime(2022,8,29),datetime.datetime(2022,11,2),2022,"Wien",'Wien',"Austria",'',[]])
data_list.append([datetime.datetime(2022,11,2),datetime.datetime(2022,11,3),2022,"Katowice",'Katowice',"Poland",'Best Western Hotel Mariacki Katowice',[]])
data_list.append([datetime.datetime(2022,11,3),datetime.datetime(2022,11,6),2022,"Warschau",'Warschau',"Poland",'',[]])
data_list.append([datetime.datetime(2022,11,6),datetime.datetime(2022,11,7),2022,"Night train Warsaw Vienna",'Night train Warsaw Vienna',"Czech Republic",'',[]])
data_list.append([datetime.datetime(2022,11,7),datetime.datetime(2022,12,1),2022,"Wien",'Wien',"Austria",'',[]])
data_list.append([datetime.datetime(2022,12,1),datetime.datetime(2022,12,4),2022,"Duesseldorf",'Duesseldorf',"Germany",'',['Artur']])
data_list.append([datetime.datetime(2022,12,4),datetime.datetime(2022,12,23),2022,"Wien",'Wien',"Austria",'',[]])
data_list.append([datetime.datetime(2022,12,23),datetime.datetime(2022,12,31),2022,"Unterlauchringen",'Lauchringen',"Germany",'',['Artur']])
data_list.append([datetime.datetime(2022,12,31),datetime.datetime(2023,1,1),2022,"Unterlauchringen",'Lauchringen',"Germany",'',['Artur']])

# %%
data_list.append([datetime.datetime(2023,1,1),datetime.datetime(2023,2,14),2023,"Wien",'Wien',"Austria",'',[]])
data_list.append([datetime.datetime(2023,2,14),datetime.datetime(2023,2,16),2023,"Muenchen",'Muenchen',"Germany",'',[]])
data_list.append([datetime.datetime(2023,2,16),datetime.datetime(2023,2,23),2023,"Wien",'Wien',"Austria",'',[]])
data_list.append([datetime.datetime(2023,2,23),datetime.datetime(2023,2,27),2023,"Wien",'Wien',"Austria",'',['Janina','Kevin']])
data_list.append([datetime.datetime(2023,2,27),datetime.datetime(2023,3,3),2023,"Wien",'Wien',"Austria",'',[]])
data_list.append([datetime.datetime(2023,3,3),datetime.datetime(2023,3,4),2023,"Lissabon",'Lissabon',"Portugal",'Hotel Alif Campo Pequeno',[]])
data_list.append([datetime.datetime(2023,3,4),datetime.datetime(2023,3,6),2023,"Lagos",'Lagos',"Portugal",'Tivoli Lagos',[]])
data_list.append([datetime.datetime(2023,3,6),datetime.datetime(2023,3,10),2023,"Lissabon",'Lissabon',"Portugal",'Hotel Italia',[]])
data_list.append([datetime.datetime(2023,3,10),datetime.datetime(2023,3,15),2023,"Porto",'Porto',"Portugal",'',['Artur']])
data_list.append([datetime.datetime(2023,3,15),datetime.datetime(2023,3,16),2023,"Coimbra",'Coimbra',"Portugal",'Tivoli Coimbra Hotel',[]])
data_list.append([datetime.datetime(2023,3,16),datetime.datetime(2023,3,18),2023,"Lissabon",'Lissabon',"Portugal",'Hotel Italia',[]])
data_list.append([datetime.datetime(2023,3,18),datetime.datetime(2023,3,19),2023,"Lissabon",'Lissabon',"Portugal",'Star Inn Lisbon Airport',[]])
data_list.append([datetime.datetime(2023,3,19),datetime.datetime(2023,4,28),2023,"Wien",'Wien',"Austria",'',[]])
data_list.append([datetime.datetime(2023,4,28),datetime.datetime(2023,4,30),2023,"Katowice",'Katowice',"Poland",'Hotel Diament Plaza Katowice',[]])
data_list.append([datetime.datetime(2023,4,30),datetime.datetime(2023,5,1),2023,"Krakow",'Krakow',"Poland",'',[]])
data_list.append([datetime.datetime(2023,5,1),datetime.datetime(2023,6,2),2023,"Wien",'Wien',"Austria",'',[]])
data_list.append([datetime.datetime(2023,6,2),datetime.datetime(2023,6,6),2023,"Kista",'Stockholm',"Sweden",'Good Morning Kista',[]])
data_list.append([datetime.datetime(2023,6,6),datetime.datetime(2023,6,23),2023,"Wien",'Wien',"Austria",'',[]])
data_list.append([datetime.datetime(2023,6,23),datetime.datetime(2023,6,26),2023,"Sofia",'Sofia',"Bulgaria",'Sofia Place Hotel by HMG',[]])
data_list.append([datetime.datetime(2023,6,26),datetime.datetime(2023,6,29),2023,"Wien",'Wien',"Austria",'',[]])
data_list.append([datetime.datetime(2023,6,29),datetime.datetime(2023,7,3),2023,"Wien",'Wien',"Austria",'',["Sam",'Sophie']])
data_list.append([datetime.datetime(2023,7,3),datetime.datetime(2023,7,21),2023,"Wien",'Wien',"Austria",'',[]])
data_list.append([datetime.datetime(2023,7,21),datetime.datetime(2023,7,23),2023,"Kopenhagen",'Kopenhagen',"Denmark",'Cabinn Ciy',[]])
data_list.append([datetime.datetime(2023,7,23),datetime.datetime(2023,8,11),2023,"Wien",'Wien',"Austria",'',[]])
data_list.append([datetime.datetime(2023,8,11),datetime.datetime(2023,8,15),2023,"Frankfurt",'Frankfurt',"Germany",'Leonardo Hotel Frankfurt City Center',[]])
data_list.append([datetime.datetime(2023,8,15),datetime.datetime(2023,8,25),2023,"Wien",'Wien',"Austria",'',[]])
data_list.append([datetime.datetime(2023,8,25),datetime.datetime(2023,8,26),2023,"Banksa Stiavnica",'Banksa Stiavnica',"Slovakia",'Penzion Prijemny Oddych',['Artur']])
data_list.append([datetime.datetime(2023,8,26),datetime.datetime(2023,8,28),2023,"Spisska Kapitula",'Spisske Podhradie',"Slovakia",'Penzion St Martin',['Artur']])
data_list.append([datetime.datetime(2023,8,28),datetime.datetime(2023,8,29),2023,"Kosice",'Kosice',"Slovakia",'Penzion Dobre Casy',['Artur']])
data_list.append([datetime.datetime(2023,8,29),datetime.datetime(2023,8,30),2023,"Roznava",'Roznava',"Slovakia",'Penzion Luxury',['Artur']])
data_list.append([datetime.datetime(2023,8,30),datetime.datetime(2023,9,1),2023,"Tokaj",'Tokaj',"Hungary",'Torkolat Panzio',['Artur']])
data_list.append([datetime.datetime(2023,9,1),datetime.datetime(2023,9,2),2023,"Dunaujvaros",'Dunaujvvros',"Hungary",'Hotel Kerpely',['Artur']])
data_list.append([datetime.datetime(2023,9,2),datetime.datetime(2023,9,3),2023,"Keszthely",'Keszthely',"Hungary",'Tokajer Wellness Panzio',['Artur']])
data_list.append([datetime.datetime(2023,9,3),datetime.datetime(2023,9,4),2023,"Schladming",'Schladming',"Austria",'Alpine Club',['Artur']])
data_list.append([datetime.datetime(2023,9,4),datetime.datetime(2023,9,5),2023,"Wien",'Wien',"Austria",'',[]])
data_list.append([datetime.datetime(2023,9,5),datetime.datetime(2023,9,10),2023,"Wien",'Wien',"Austria",'',['Grace']])
data_list.append([datetime.datetime(2023,9,10),datetime.datetime(2023,9,29),2023,"Wien",'Wien',"Austria",'',[]])
data_list.append([datetime.datetime(2023,9,29),datetime.datetime(2023,10,6),2023,"Wien",'Wien',"Austria",'',['Bing']])
data_list.append([datetime.datetime(2023,10,6),datetime.datetime(2023,10,25),2023,"Wien",'Wien',"Austria",'',[]])
data_list.append([datetime.datetime(2023,10,25),datetime.datetime(2023,10,26),2023,"Stockholm",'Stockholm',"Sweden",'Best Western Hotel Fridhemsplan',[]])
data_list.append([datetime.datetime(2023,10,26),datetime.datetime(2023,10,27),2023,"Visby",'Visby',"Sweden",'Hotell Villa Borgen',[]])
data_list.append([datetime.datetime(2023,10,27),datetime.datetime(2023,10,29),2023,"Solna",'Solna',"Sweden",'Park Inn by Radisson Solna',[]])
data_list.append([datetime.datetime(2023,10,29),datetime.datetime(2023,10,30),2023,"Karlskrona",'Karlskrona',"Sweden",'Best Western Plus JA Hotel Karlskrona',[]])
data_list.append([datetime.datetime(2023,10,30),datetime.datetime(2023,10,31),2023,"Kalmar",'Kalmar',"Sweden",'Slottshotellet Annex',[]])
data_list.append([datetime.datetime(2023,10,31),datetime.datetime(2023,11,1),2023,"Arlanda",'Arlanda',"Sweden",'Radisson Blu Arlandia Hotel',[]])
data_list.append([datetime.datetime(2023,11,1),datetime.datetime(2023,12,7),2023,"Wien",'Wien',"Austria",'',[]])
data_list.append([datetime.datetime(2023,12,7),datetime.datetime(2023,12,10),2023,"St Genis",'St Genis-Pouilly',"France",'',['Bing']])
data_list.append([datetime.datetime(2023,12,10),datetime.datetime(2023,12,22),2023,"Wien",'Wien',"Austria",'',[]])
data_list.append([datetime.datetime(2023,12,22),datetime.datetime(2023,12,24),2023,"Unterlauchringen",'Lauchringen',"Germany",'',['Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2023,12,24),datetime.datetime(2023,12,28),2023,"Unterlauchringen",'Lauchringen',"Germany",'',['Artur','Jennet''Hannsjoerg']])
data_list.append([datetime.datetime(2023,12,28),datetime.datetime(2023,12,30),2023,"Nuernberg",'Nuernberg',"Germany",'',['Artur','Jennet','Hannsjoerg']])
data_list.append([datetime.datetime(2023,12,30),datetime.datetime(2023,12,31),2023,"Leipzig",'Leipzig',"Germany",'Ibis Budget Leipzig Messe',['Artur']])
data_list.append([datetime.datetime(2023,12,31),datetime.datetime(2024,1,1),2023,"Leipzig",'Leipzig',"Germany",'Ibis Budget Leipzig Messe',['Artur']])

# %%
data_list.append([datetime.datetime(2024,1,1),datetime.datetime(2024,1,24),2024,"Wien",'Wien',"Austria",'',[]])
data_list.append([datetime.datetime(2024,1,24),datetime.datetime(2024,1,25),2024,"Bolzano/Bozen",'Bolzano/Bozen',"Italy",'Hotel Adria',[]])
data_list.append([datetime.datetime(2024,1,25),datetime.datetime(2024,1,27),2024,"Verona",'Verona',"Italy",'Hotel Martini',[]])
data_list.append([datetime.datetime(2024,1,27),datetime.datetime(2024,1,28),2024,"Bolzano/Bozen",'Bolzano/Bozen',"Italy",'Hotel Adria',[]])
data_list.append([datetime.datetime(2024,1,28),datetime.datetime(2024,2,16),2024,"Wien",'Wien',"Austria",'',[]])
data_list.append([datetime.datetime(2024,2,16),datetime.datetime(2024,2,19),2024,"Mestre",'Venedig',"Italy",'Hotel Regit',[]])
data_list.append([datetime.datetime(2024,2,19),datetime.datetime(2024,2,20),2024,"Venedig",'Venedig',"Italy",'Hotel Il Moro di Venezia',[]])
data_list.append([datetime.datetime(2024,2,21),datetime.datetime(2024,3,31),2024,"Wien",'Wien',"Austria",'',[]])
data_list.append([datetime.datetime(2024,3,31),datetime.datetime(2024,4,3),2024,"Thessaloniki",'Thessaloniki',"Greece",'Hotel Anessis',['Artur']])
data_list.append([datetime.datetime(2024,4,3),datetime.datetime(2024,4,5),2024,"Skopje",'Skopje',"North Macedonia",'Hotel DOA',['Artur']])
data_list.append([datetime.datetime(2024,4,5),datetime.datetime(2024,4,6),2024,"Thessaloniki",'Thessaloniki',"Greece",'Hotel Anessis',['Artur']])
data_list.append([datetime.datetime(2024,4,6),datetime.datetime(2024,4,8),2024,"Kalambaka",'Kalambaka',"Greece",'Hotel Famissi',['Artur']])
data_list.append([datetime.datetime(2024,4,8),datetime.datetime(2024,4,9),2024,"Thessaloniki",'Thessaloniki',"Greece",'Hotel Anessis',['Artur']])
data_list.append([datetime.datetime(2024,4,9),datetime.datetime(2024,4,24),2024,"Wien",'Wien',"Austria",'',[]])
data_list.append([datetime.datetime(2024,4,24),datetime.datetime(2024,4,25),2024,"Kopenhagen",'Kopenhagen',"Denmark",'Hotel Wakeup Copenhagen Bernstoffsgate',[]])
data_list.append([datetime.datetime(2024,4,25),datetime.datetime(2024,4,30),2024,"Wien",'Wien',"Austria",'',[]])
data_list.append([datetime.datetime(2024,4,30),datetime.datetime(2024,5,5),2024,"Stratford",'London',"United Kingdom",'Epsilon Hotel',[]])
data_list.append([datetime.datetime(2024,5,5),datetime.datetime(2024,5,8),2024,"Wien",'Wien',"Austria",'',[]])
data_list.append([datetime.datetime(2024,5,8),datetime.datetime(2024,5,12),2024,"Ljubljana",'Ljubljana',"Slovenia",'Ljubljana Ibis Styles Fuzzy Log',[]])
data_list.append([datetime.datetime(2024,5,12),datetime.datetime(2024,5,17),2024,"Wien",'Wien',"Austria",'',[]])
data_list.append([datetime.datetime(2024,5,17),datetime.datetime(2024,5,21),2024,"Msida",'Msida',"Malta",'Aparthotel Adagio Malta Central',['Artur']])
data_list.append([datetime.datetime(2024,5,21),datetime.datetime.now(),2024,"Wien",'Wien',"Austria",'',[]])

# %%
df = pd.DataFrame(data_list,columns=['Date Start','Date End', 'Year','Place', 'Community/City','Country','Hotel','People'])
df["Duration"]=((df['Date End']-df['Date Start'])/np.timedelta64(1,"D")).astype(int)
df.to_csv("../data/NightStays_StationInfo.csv")

# %%
def place_is_home(date_end,place):
    home_flag=0
    if date_end<datetime.datetime(2006, 10, 17): 
        if place == "Unterlauchringen":
            home_flag=1
    elif date_end<datetime.datetime(2007, 3, 16):
        if place == "Meyrin":
            home_flag=1
    elif date_end<datetime.datetime(2007, 5, 17):
        if place == "Unterlauchringen":
            home_flag=1
    elif date_end<datetime.datetime(2020, 8, 29):
        if place == "Genf":
            home_flag=1
    elif date_end<datetime.datetime(2021, 4, 29):
        if place == "Unterlauchringen":
            home_flag=1
    else:
    #elif date_end<(datetime.date.today()+datetime.timedelta(days=60)):
        if place == "Wien":
            home_flag=1
    return home_flag

# %%
df.loc[(df["Community/City"]=="")]
# Out:
# Empty DataFrame
# Columns: [Date Start, Date End, Year, Place, Community/City, Country, Hotel, People, Duration]
# Index: []

# %%
df[['Place','Date End']]
# Out:
#                 Place                   Date End
# 0            Waldshut 1982-04-11 00:00:00.000000
# 1    Unterlauchringen 1982-06-26 00:00:00.000000
# 2       Gossersweiler 1982-07-10 00:00:00.000000
# 3    Unterlauchringen 1982-12-31 00:00:00.000000
# 4    Unterlauchringen 1983-01-01 00:00:00.000000
# ..                ...                        ...
# 757              Wien 2024-05-08 00:00:00.000000
# 758         Ljubljana 2024-05-12 00:00:00.000000
# 759              Wien 2024-05-17 00:00:00.000000
# 760             Msida 2024-05-21 00:00:00.000000
# 761              Wien 2024-05-21 18:34:20.428770
#
# [762 rows x 2 columns]

# %%
df.columns
# Out:
# Index(['Date Start', 'Date End', 'Year', 'Place', 'Community/City', 'Country',
#        'Hotel', 'People', 'Duration'],
#       dtype='object')

# %%
df["home"]=df[['Place','Date End']].apply(lambda x:place_is_home(x['Date End'],x['Place']),axis=1)

# %%
df.head(10)
# Out:
#   Date Start   Date End  Year             Place    Community/City  Country  \
# 0 1982-04-06 1982-04-11  1982          Waldshut  Waldshut-Tiengen  Germany
# 1 1982-04-11 1982-06-26  1982  Unterlauchringen       Lauchringen  Germany
# 2 1982-06-26 1982-07-10  1982     Gossersweiler     Gossersweiler  Germany
# 3 1982-07-10 1982-12-31  1982  Unterlauchringen       Lauchringen  Germany
# 4 1982-12-31 1983-01-01  1982  Unterlauchringen       Lauchringen  Germany
# 5 1983-01-01 1983-05-18  1983  Unterlauchringen       Lauchringen  Germany
# 6 1983-05-18 1983-05-25  1983        San Carlos        San Carlos    Spain
# 7 1983-05-25 1983-12-31  1983  Unterlauchringen       Lauchringen  Germany
# 8 1983-12-31 1984-01-01  1983  Unterlauchringen       Lauchringen  Germany
# 9 1984-01-01 1984-12-31  1984  Unterlauchringen       Lauchringen  Germany
#
#                   Hotel                      People  Duration  home
# 0  Krankenhaus Waldshut                   [Heidrun]         5     0
# ...

# %%
df.tail(10)
# Out:
#     Date Start                   Date End  Year         Place Community/City  \
# 752 2024-04-08 2024-04-09 00:00:00.000000  2024  Thessaloniki   Thessaloniki
# 753 2024-04-09 2024-04-24 00:00:00.000000  2024          Wien           Wien
# 754 2024-04-24 2024-04-25 00:00:00.000000  2024    Kopenhagen     Kopenhagen
# 755 2024-04-25 2024-04-30 00:00:00.000000  2024          Wien           Wien
# 756 2024-04-30 2024-05-05 00:00:00.000000  2024     Stratford         London
# 757 2024-05-05 2024-05-08 00:00:00.000000  2024          Wien           Wien
# 758 2024-05-08 2024-05-12 00:00:00.000000  2024     Ljubljana      Ljubljana
# 759 2024-05-12 2024-05-17 00:00:00.000000  2024          Wien           Wien
# 760 2024-05-17 2024-05-21 00:00:00.000000  2024         Msida          Msida
# 761 2024-05-21 2024-05-21 18:34:20.428770  2024          Wien           Wien
#
#             Country                                   Hotel   People  \
# ...

# %%
print(df['Place'].nunique(),df['Country'].nunique())
# Out:
# 242 41

# %%
for place in df["Place"].unique():
    if df.loc[(df['Place']==place),'home'].nunique()>1:
            print(place,":",df.loc[(df['Place']==place) & (df['home']==0),'Duration'].sum(),
              df.loc[(df['Place']==place) & (df['home']==1),'Duration'].sum(),
              df.loc[(df['Place']==place) & (df['home']==0),'Duration'].sum()/df.loc[(df['Place']==place) & (df['home']==1),'Duration'].sum(),
              df.loc[(df['Place']==place) & (df['home']==0),'Duration'].sum()/365.25,
              df.loc[(df['Place']==place) & (df['home']==1),'Duration'].sum()/365.25
                 )
# Out:
# Unterlauchringen : 330 8856 0.03726287262872629 0.9034907597535934 24.246406570841888
# Wien : 10 944 0.01059322033898305 0.02737850787132101 2.5845311430527036

# %%
df_agg_per_place = df.groupby(['Community/City',"Country"]).agg(Nights=("Duration",'sum')).sort_values(
    by="Nights",ascending=False).reset_index().rename(columns={"Community/City":'Place'})
df_agg_per_place.head(60)
# Out:
#                     Place         Country  Nights
# 0             Lauchringen         Germany    9179
# 1                    Genf     Switzerland    4022
# 2                    Wien         Austria     954
# 3                  Meyrin     Switzerland     131
# 4                  London  United Kingdom      51
# 5                   Paris          France      49
# 6                     Rom           Italy      31
# 7                    Horn         Germany      28
# 8                  Madrid           Spain      28
# 9                  Berlin         Germany      25
# 10               Lissabon        Portugal      25
# 11                Venedig           Italy      16
# 12              Stockholm          Sweden      15
# 13          St Petersburg          Russia      15
# 14              Lechbruck         Germany      14
# 15              Kirchheim         Germany      14
# 16               Muenchen         Germany      14
# 17          Gossersweiler         Germany      14
# ...

# %%
datetime.date.today()-datetime.date(1982, 4, 6)
# Out:
# datetime.timedelta(days=15386)

# %%
df_nights_country=df_agg_per_place.groupby(['Country']).agg(Nights=("Nights",'sum'),
                                                            N_Places=("Place",'nunique')
                                                           ).sort_values(by="Nights",ascending=False).reset_index()
df_nights_country["ratio_lifetime"]=df_nights_country["Nights"]/((datetime.date.today()-datetime.date(1982, 4, 6))/datetime.timedelta(days=1))
df_nights_country["year_spent"]=df_nights_country["Nights"]/365.25
df_nights_country
# Out:
#                  Country  Nights  N_Places  ratio_lifetime  year_spent
# 0                Germany    9464        48        0.615105   25.911020
# 1            Switzerland    4196        11        0.272715   11.488022
# 2                Austria     978         8        0.063564    2.677618
# 3                  Spain     118        17        0.007669    0.323066
# 4                  Italy     117        25        0.007604    0.320329
# 5                 France      81        13        0.005265    0.221766
# 6                    USA      78        19        0.005070    0.213552
# 7         United Kingdom      62         5        0.004030    0.169747
# 8               Portugal      33         4        0.002145    0.090349
# 9                 Turkey      24         7        0.001560    0.065708
# 10                Greece      22         7        0.001430    0.060233
# 11                Sweden      21         6        0.001365    0.057495
# ...

# %%
df.loc[(df['home']==0),["Duration",'Year']].groupby("Year").sum().values
# Out:
# array([[19],
#        [ 7],
#        [13],
#        [23],
#        [26],
#        [20],
#        [21],
#        [24],
#        [21],
#        [ 7],
#        [20],
#        [14],
#        [17],
#        [20],
#        [10],
#        [19],
#        [22],
#        [28],
#        [19],
#        [ 9],
#        [13],
#        [19],
#        [27],
#        [23],
#        [53],
#        [58],
#        [57],
#        [43],
#        [59],
#        [52],
#        [61],
#        [84],
#        [96],
#        [83],
#        [93],
#        [53],
#        [25],
#        [27],
#        [52],
#        [64],
#        [31]])

# %%
df_year_stat=df.groupby("Year").agg(N_Countries=("Country",'nunique')).reset_index()
df_year_stat["nights_at_home"]=df.loc[(df['home']==1),["Duration",'Year']].groupby("Year").sum().values
df_not_home=df.loc[(df['home']==0),["Duration",'Year']].groupby("Year").agg(
    nights_away_from_home=('Duration','sum')).reset_index()
df_year_stat=df_year_stat.merge(df_not_home,how='left',on="Year")
df_year_stat['nights_away_from_home']=df_year_stat['nights_away_from_home'].fillna(0).astype(int)
df_year_stat["days_lived_in_year"]=(df_year_stat["nights_at_home"]+df_year_stat['nights_away_from_home']).astype(int)
df_year_stat['away_ratio']=df_year_stat['nights_away_from_home']/df_year_stat["days_lived_in_year"]
df_year_stat
# Out:
#     Year  N_Countries  nights_at_home  nights_away_from_home  \
# 0   1982            1             251                     19
# 1   1983            2             358                      7
# 2   1984            1             366                      0
# 3   1985            2             352                     13
# 4   1986            1             365                      0
# 5   1987            3             342                     23
# 6   1988            2             340                     26
# 7   1989            2             345                     20
# 8   1990            2             344                     21
# 9   1991            1             341                     24
# 10  1992            1             345                     21
# 11  1993            2             358                      7
# 12  1994            2             345                     20
# 13  1995            1             351                     14
# ...

# %%
label_format='{:.2f}'

fig,ax=plt.subplots(1,1,figsize=(20,10))
sns.barplot(data=df_year_stat,x='Year',y="away_ratio",ax=ax,color='blue')
ax.set_ylabel("away ratio",fontsize=25)
yticks_loc=ax.get_yticks()
ax.set_yticks(yticks_loc)
ax.set_yticklabels([label_format.format(y) for y in yticks_loc],size=20)
ax.set_xticklabels(ax.get_xticklabels(),rotation=90,size=22)
ax.set_xlabel("Year",fontsize=25)
#sns.set(font_scale=2.0)
plt.show()

# %%
datetime.datetime(2003, 7, 4)-datetime.datetime(1982,7, 3)
# Out:
# datetime.timedelta(days=7671)

# %%
df.loc[(df["Date Start"]-df['Date End'].shift(1))!=np.timedelta64(0,'D'),"Date Start"]
# Out:
# 0     1982-04-06
# 747   2024-02-21
# Name: Date Start, dtype: datetime64[ns]

# %%
9416.0/365.25
# Out:
# 25.779603011635867

# %%
4209.0/365.25
# Out:
# 11.523613963039015

# %%
df.loc[(df["Date Start"]-df['Date Start'].shift(1))<np.timedelta64(0,'D'),"Date Start"]
# Out:
# Series([], Name: Date Start, dtype: datetime64[ns])

# %%
df.loc[(df["Date End"]-df['Date End'].shift(1))<np.timedelta64(0,'D'),"Date Start"]
# Out:
# Series([], Name: Date Start, dtype: datetime64[ns])

# %%
string_traveller="Rachel"
df["flag"]=0
night_counter=0
for ind,test in enumerate(df['People'].values):
    if string_traveller in test:
        df.iloc[ind,df.columns.get_loc("flag")]=1
        night_counter+=df.iloc[ind,df.columns.get_loc("Duration")]
print(len(df.loc[df['flag']==1]),night_counter,night_counter/365.25)
df.loc[df['flag']==1].head(15)
# Out:
# 7 14 0.038329911019849415
#     Date Start   Date End  Year          Place Community/City  Country  \
# 512 2017-10-06 2017-10-09  2017         Tallin         Tallin  Estonia
# 535 2018-03-28 2018-03-31  2018      Reykjavik      Reykjavik  Iceland
# 538 2018-04-14 2018-04-15  2018  Frederiksberg  Frederiksberg  Denmark
# 548 2018-05-25 2018-05-27  2018      Barcelona      Barcelona    Spain
# 574 2018-09-21 2018-09-23  2018       Bruessel       Bruessel  Belgium
# 652 2022-05-20 2022-05-21  2022           Wien           Wien  Austria
# 653 2022-05-21 2022-05-23  2022           Wien           Wien  Austria
#
#                                         Hotel                  People  \
# 512                    Rixwell Old Town Hotel   [Riju, Rachel, Reyer]
# 535                            Fosshotel Lind   [Riju, Reyer, Rachel]
# 538  Cabinn Scandinavia Hotel - Frederiksberg   [Riju, Reyer, Rachel]
# 548                                                          [Rachel]
# ...

# %%
df['People'].values
# Out:
# array([list(['Heidrun']), list(['Heidrun', 'Jan-Marc', 'Artur']),
#        list(['Heidrun', 'Jan-Marc', 'Artur']),
#        list(['Heidrun', 'Jan-Marc', 'Artur']),
#        list(['Heidrun', 'Jan-Marc', 'Artur']),
#        list(['Heidrun', 'Jan-Marc', 'Artur']),
#        list(['Heidrun', 'Jan-Marc', 'Artur']),
#        list(['Heidrun', 'Jan-Marc', 'Artur']),
#        list(['Heidrun', 'Jan-Marc', 'Artur']),
#        list(['Heidrun', 'Jan-Marc', 'Artur']),
#        list(['Heidrun', 'Jan-Marc', 'Artur', 'Anne-Kathrin']),
#        list(['Heidrun', 'Jan-Marc', 'Artur', 'Anne-Kathrin']),
#        list(['Heidrun', 'Jan-Marc', 'Artur', 'Anne-Kathrin']),
#        list(['Heidrun', 'Jan-Marc', 'Artur', 'Anne-Kathrin']),
#        list(['Heidrun', 'Jan-Marc', 'Artur', 'Anne-Kathrin']),
#        list(['Heidrun', 'Jan-Marc', 'Artur', 'Anne-Kathrin', 'Hannsjoerg']),
#        list(['Heidrun', 'Jan-Marc', 'Artur', 'Anne-Kathrin', 'Hannsjoerg']),
# ...

# %%
import re
#re.sub(r'\W+', '', your_string)

cotravellers=set()

#if I consider unique() just alone, then it would split everything directly into 

for expr in df['People'].values:
    for w in expr:
        name=re.sub(r"[^\w-]", ' ', w).strip()
        if name!="":
            cotravellers.add(name)
print(cotravellers)
# Out:
# {'School Outing', 'Schulklasse', 'Chris Martin', 'ICHEP2008', 'Anne-Kathrin', 'Benjamin', 'Nhi', 'EPS2013', 'Franziska', 'Jan-Marc', 'Heidrun', 'Mohammed', 'Calice Workshop 2016', 'Wolfgang', 'Michael', 'Wieland', 'CHIPP School 2010', 'Felicitas', 'Keyvan', 'ISMD2015', 'CMS Week', 'Bing', 'CEPC Workshop 2019', 'AJ', 'Artur', 'Anne', 'CHIPP School 2008', 'Sam', 'Grace', 'ISMD 2014', 'Stephanie', 'Riju', 'Chris Lee', 'Manuel', 'Tobias Schwabe', 'LHCP2015', 'Boeni', 'Tony', 'Christine', 'Julius', 'Devin', 'Juno', 'Nate', 'Christian', 'Evan', 'Angelika', 'EPS2017', 'Bryan', 'Alain Lafon', 'JennetHannsjoerg', 'Chris Brainerd', 'Anne Feidt', 'Vivan', 'Cameron', 'Sasha', 'Hochrheinseminar', 'Kevin', 'ETH Group', 'Tema', 'Gianrico', 'Andrew', 'European LC Workshop 2016', 'Stephan', 'Kennedy', 'Mathilda', 'Eric', 'Can', 'Laser', 'Jan Perius', 'Jennet', 'Reyer', 'Santona', 'Janina', 'Amin', 'Siyi', 'Siyi s Parents', 'Hannsjoerg', 'Les Houches 2011', 'Indara', 'JetMET Workshop 2014', 'Rachel', 
# ...

# %%
df_list_co_travellers=[]
for ind_ct,ct in enumerate(cotravellers):
    cot_flag=np.zeros(len(df))
    for ind,expr in enumerate(df['People'].values):
        if ct in expr:
            cot_flag[ind]=1
    df["cot_flag"]=cot_flag
    
    print(ind_ct, ct,": total nights",df.loc[df['cot_flag']==1,"Duration"].sum(),
         "joined on",df.loc[(df['cot_flag']==1),"Date Start"].nunique(),"separate occasions")
    df_list_co_travellers.append([ct,
                                df.loc[(df['cot_flag']==1),"Duration"].sum(),
                                df.loc[(df['cot_flag']==1),"Date Start"].nunique(),
                                df.loc[(df['cot_flag']==1),"Country"].nunique(),
                                df.loc[(df['cot_flag']==1),"Community/City"].nunique(),
                                df.loc[(df['cot_flag']==1),"Date Start"].min(),
                                df.loc[(df['cot_flag']==1),"Date Start"].max()                             
                                 ])
    if df.loc[(df['cot_flag']==1),"Date Start"].nunique()>1:
        min_x=df.loc[(df['cot_flag']==1),"Date Start"].min()-np.timedelta64(2,"M")
        max_x=df.loc[(df['cot_flag']==1),"Date Start"].max()+np.timedelta64(2,"M")
        fig, ax = plt.subplots()
        max_y=1.25*df[(df['cot_flag']==1)].groupby(pd.Grouper(key="Date Start", freq="1D")).sum()["Duration"].max()
        df[(df['cot_flag']==1)].groupby(pd.Grouper(key="Date Start", freq="1D")).sum()["Duration"].plot(title="count of nights",ylabel="night count",xlim=(min_x,max_x),ylim=(0,max_y))
        plt.show()
# Out:
# 0 School Outing : total nights 7 joined on 3 separate occasions
# /var/folders/8d/gvjspwlj4hq61gsmkn1p_h480000gn/T/ipykernel_3892/753845480.py:23: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   max_y=1.25*df[(df['cot_flag']==1)].groupby(pd.Grouper(key="Date Start", freq="1D")).sum()["Duration"].max()
# /var/folders/8d/gvjspwlj4hq61gsmkn1p_h480000gn/T/ipykernel_3892/753845480.py:24: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df[(df['cot_flag']==1)].groupby(pd.Grouper(key="Date Start", freq="1D")).sum()["Duration"].plot(title="count of nights",ylabel="night count",xlim=(min_x,max_x),ylim=(0,max_y))
# ...

# %%
df_coTrav = pd.DataFrame(df_list_co_travellers,columns=['Co-Traveller', 'Nights','TripStays',"N_Countries","N_Places","FirstTripDate",'LastTripDate'])
df_coTrav=df_coTrav.sort_values(by="Nights",ascending=False).reset_index().drop(columns='index')
df_coTrav.to_csv("../data/NightStay_cotravellers.csv")
df_coTrav.head(50)
# Out:
#                  Co-Traveller  Nights  TripStays  N_Countries  N_Places  \
# 0                       Artur    9705        342           23       117
# 1                     Heidrun    9376        301           17        98
# 2                    Jan-Marc    8844        149            8        33
# 3                  Hannsjoerg    7917        257           14        80
# 4                Anne-Kathrin    7596        187           11        58
# 5                        Riju      64         26           13        19
# 6                       Reyer      30         14            6        13
# 7                    Gianrico      28          6            5         6
# 8                        Eric      26         11            6        10
# 9                        Sigi      21          5            5         5
# 10                     Manuel      19          4            3         4
# 11                  Christian      19          5            1         3
# ...
