# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime

# %%
data_list=[]
#data/photo count/church/place/country/style 0/style 1/style 2/unesco/day trip/co-trav
data_list.append([datetime.datetime(1996, 8, 25),1,"Westminster Cathedral","London","United Kingdom","neo-Byzantine",'','',"",0,['Jan-Marc','Heidrun','Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1996, 8, 26),2,"Westminster Cathedral","London","United Kingdom","neo-Byzantine",'','',"",0,['Jan-Marc','Heidrun','Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1996, 8, 26),1,"Westminster Abbey","London","United Kingdom","Gothic",'','',"Westminster",0,['Jan-Marc','Heidrun','Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1996, 8, 28),2,"St Paul's Cathedral","London","United Kingdom","Baroque",'','',"",0,['Jan-Marc','Heidrun','Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1996, 8, 28),13,"Westminster Abbey","London","United Kingdom","Gothic",'','',"Westminster",0,['Artur']])
data_list.append([datetime.datetime(1996, 10, 27),16,"Dom","Speyer","Germany","Romanesque",'','',"Speyer Cathedral",0,['Jan-Marc','Heidrun','Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1996, 10, 30),9,"Dom","Worms","Germany","Romanesque",'Baroque','',"",0,['Jan-Marc','Heidrun','Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1996, 10, 31),10,"Dom","Mainz","Germany","Romanesque",'Baroque','',"",0,['Jan-Marc','Heidrun','Artur','Anne-Kathrin','Hannsjoerg']])
#1997
data_list.append([datetime.datetime(1997, 5, 22),6,"Frauenkirche","Munich","Germany","Gothic",'','',"",0,['Jan-Marc','Heidrun','Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1997, 5, 24),1,"Frauenkirche","Munich","Germany","Gothic",'','',"",0,['Jan-Marc','Heidrun','Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1997, 8, 28),4,"San Giovanni in Laterano","Rome","Vatican","Baroque",'','',"Rome",0,['Jan-Marc','Heidrun','Artur','Anne-Kathrin','Hannsjoerg']])
#1998
data_list.append([datetime.datetime(1998, 8, 26),5,"Basilique","Saint Denis","France","Gothic",'','',"",0,['Jan-Marc','Heidrun','Artur','Anne-Kathrin','Hannsjoerg']])
#1999
data_list.append([datetime.datetime(1999, 8, 27),2,"Cathedral","Athens","Greece","neo-Byzantine",'','',"",0,['Jan-Marc','Heidrun','Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1999, 8, 28),1,"Dionysius Areopagita Cathedral","Athens","Greece","Classicist",'','',"",0,['Jan-Marc','Heidrun','Artur','Anne-Kathrin','Hannsjoerg']])
#2000
data_list.append([datetime.datetime(1998, 11, 12),4,"Minster","Freiburg","Germany","Gothic",'Romanesque','',"",1,[]])
data_list.append([datetime.datetime(2000,8,27),26,"Hagia Sophia","Istanbul","Turkey","Byzantine",'Islamic','',"Istanbul",0,['Heidrun','Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(2000,8,28),3,"Hagia Sophia","Istanbul","Turkey","Byzantine",'Islamic','',"Istanbul",0,['Heidrun','Artur','Anne-Kathrin','Hannsjoerg']])
#2001
data_list.append([datetime.datetime(2001,5,18),9,"Cathedral","Barcelona","Spain","Gothic",'','',"",0,[]])
data_list.append([datetime.datetime(2001,8,24),1,"Cathedral","Granada","Spain","Renaissance",'','',"",0,['Heidrun','Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(2001,8,24),3,"Mezquita-Cathedral","Cordoba","Spain","Islamic",'Renaissance','',"Cordoba",0,['Heidrun','Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(2001,8,25),33,"Mezquita-Cathedral","Cordoba","Spain","Islamic",'Renaissance','',"Cordoba",0,['Heidrun','Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(2001,8,26),24,"Cathedral","Sevilla","Spain","Gothic",'','',"Cathedral, Alcazar and Archivo de Indias in Seville",0,['Heidrun','Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(2001,8,27),3,"Cathedral","Cadiz","Spain","Baroque",'','',"",0,['Heidrun','Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(2001,8,27),1,"Cathedral","Jerez de la Frontera","Spain","Gothic",'','',"",0,['Heidrun','Artur','Anne-Kathrin','Hannsjoerg']])
#2002
data_list.append([datetime.datetime(2002,5,27),13,"Duomo","Siena","Italy","Gothic",'','',"Siena",0,['Heidrun','Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(2002,5,28),9,"Duomo","Florence","Italy","Renaissance",'Gothic','',"Florence",0,['Heidrun','Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(2002,5,28),20,"Duomo","Pisa","Italy","Romanesque",'Baroque','',"Pisa",0,['Heidrun','Artur','Anne-Kathrin','Hannsjoerg']])
#2004
data_list.append([datetime.datetime(2004, 10, 18),2,"St Paul's Cathedral","London","United Kingdom","Baroque",'','',"",0,['Sigi','Gianrico','Anne']])
#2005
data_list.append([datetime.datetime(2005, 8, 29),1,"Se Catedral","Lissabon","Portugal","Romanesque",'Baroque','',"",0,['Heidrun','Artur','Anne-Kathrin','Hannsjoerg']])
#2006
data_list.append([datetime.datetime(2006, 7, 10),10,"Westminster Cathedral","London","United Kingdom","neo-Byzantine",'','',"",0,['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2006, 7, 10),2,"Westminster Abbey","London","United Kingdom","Gothic",'','',"Westminster",0,['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2006, 7, 11),12,"Westminster Abbey","London","United Kingdom","Gothic",'','',"Westminster",0,['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2006, 7, 13),6,"Southwark Cathedral","London","United Kingdom","neo-Byzantine",'','',"",0,['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2006, 7, 16),16,"St Paul's Cathedral","London","United Kingdom","Baroque",'','',"",0,['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2006, 10, 27),8,"Cathedral","Geneva","Switzerland","Gothic",'Romanesque','neo-Gothic',"",1,['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2006, 11, 30),1,"Cathedral","Geneva","Switzerland","Gothic",'Romanesque','neo-Gothic',"",1,[]])
data_list.append([datetime.datetime(2006, 12, 2),11,"Cathedral","Geneva","Switzerland","Gothic",'Romanesque','neo-Gothic',"",1,[]])
data_list.append([datetime.datetime(2006, 12, 9),3,"Cathedral","Geneva","Switzerland","Gothic",'Romanesque','neo-Gothic',"",1,[]])
data_list.append([datetime.datetime(2006, 12, 10),4,"Cathedral","Geneva","Switzerland","Gothic",'Romanesque','neo-Gothic',"",1,[]])
#2007
data_list.append([datetime.datetime(2007, 9, 9),60,"Cathedral","Lausanne","Switzerland","Gothic",'','',"",1,[]])
data_list.append([datetime.datetime(2007, 1, 13),19,"Cathedral","Geneva","Switzerland","Gothic",'Romanesque','neo-Gothic',"",1,[]])
data_list.append([datetime.datetime(2007, 1, 27),1,"Cathedral","Geneva","Switzerland","Gothic",'Romanesque','neo-Gothic',"",1,[]])
data_list.append([datetime.datetime(2007, 2, 4),6,"Cathedral","Geneva","Switzerland","Gothic",'Romanesque','neo-Gothic',"",1,["Zhiling"]])
data_list.append([datetime.datetime(2007, 2, 11),16,"Cathedral","Geneva","Switzerland","Gothic",'Romanesque','neo-Gothic',"",1,[]])
data_list.append([datetime.datetime(2007, 2, 18),5,"Cathedral","Geneva","Switzerland","Gothic",'Romanesque','neo-Gothic',"",1,[]])
data_list.append([datetime.datetime(2007, 2, 24),7,"Cathedral","Geneva","Switzerland","Gothic",'Romanesque','neo-Gothic',"",1,[]])
data_list.append([datetime.datetime(2007, 6, 10),2,"Cathedral","Geneva","Switzerland","Gothic",'Romanesque','neo-Gothic',"",1,[]])
data_list.append([datetime.datetime(2007, 6, 24),6,"Cathedral","Geneva","Switzerland","Gothic",'Romanesque','neo-Gothic',"",1,[]])
data_list.append([datetime.datetime(2007, 7, 1),14,"Cathedral","Geneva","Switzerland","Gothic",'Romanesque','neo-Gothic',"",1,[]])
data_list.append([datetime.datetime(2007, 7, 14),1,"Cathedral","Geneva","Switzerland","Gothic",'Romanesque','neo-Gothic',"",1,[]])
data_list.append([datetime.datetime(2007, 11, 25),7,"Cathedral","Geneva","Switzerland","Gothic",'Romanesque','neo-Gothic',"",1,[]])
data_list.append([datetime.datetime(2007, 12, 1),3,"Cathedral","Geneva","Switzerland","Gothic",'Romanesque','neo-Gothic',"",1,[]])
#2008
data_list.append([datetime.datetime(2008, 1, 2),4,"Hofkirche","Dresden","Germany","Baroque",'','',"Dresden",0,['Artur','Heidrun','Hannsjoerg']])
data_list.append([datetime.datetime(2008, 1, 3),32,"Dom","Meissen","Germany","Gothic",'','',"",0,['Artur','Heidrun','Hannsjoerg']])
data_list.append([datetime.datetime(2008, 1, 4),28,"Hofkirche","Dresden","Germany","Baroque",'','',"Dresden",0,['Artur','Heidrun','Hannsjoerg']])
data_list.append([datetime.datetime(2008, 1, 17),32,"Cathedral","St Gallen","Switzerland","Baroque",'Classicist','',"Abbey of St Gall",1,[]])
data_list.append([datetime.datetime(2008, 5, 3),26,"Cathedral","Solothurn","Switzerland","Classicist",'','',"",1,['Zhiling']])
data_list.append([datetime.datetime(2008, 5, 3),23,"Minster","Bern","Switzerland","Gothic",'','',"Bern",1,['Zhiling']])
data_list.append([datetime.datetime(2008, 5, 3),2,"Cathedral","Sion","Switzerland","Gothic",'Romanesque','',"",1,['Zhiling']])
data_list.append([datetime.datetime(2008, 7, 19),6,"Cathedral","Annecy","France","Baroque",'Gothic','',"",1,['Artur','Heidrun','Hannsjoerg']])
data_list.append([datetime.datetime(2008, 7, 29),19,"Cathedral","Philadelphia","USA","neo-Baroque",'','',"",0,[]])
data_list.append([datetime.datetime(2008, 9, 3),2,"Military Cathedral","Madrid","Spain","Baroque",'','',"",0,['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2008, 9, 3),3,"Almudena Cathedral","Madrid","Spain","neo-Gothic",'neo-Baroque','',"",0,['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2008, 9, 4),35,"Almudena Cathedral","Madrid","Spain","neo-Gothic",'neo-Baroque','',"",0,['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2008, 9, 4),23,"San Isidro","Madrid","Spain","Baroque",'','',"",0,['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2008, 9, 4),41,"Cathedral","Segovia","Spain","Gothic",'','',"Segovia",0,['Heidrun']])
data_list.append([datetime.datetime(2008, 9, 7),9,"San Isidro","Madrid","Spain","Baroque",'','',"",0,['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2008, 3, 2),19,"Cathedral","Geneva","Switzerland","Gothic",'Romanesque','neo-Gothic',"",1,[]])
data_list.append([datetime.datetime(2008, 9, 22),16,"Cathedral","Geneva","Switzerland","Gothic",'Romanesque','neo-Gothic',"",1,[]])
data_list.append([datetime.datetime(2008, 9, 29),4,"Cathedral","Geneva","Switzerland","Gothic",'Romanesque','neo-Gothic',"",1,[]])
data_list.append([datetime.datetime(2008, 10, 27),20,"Cathedral","Geneva","Switzerland","Gothic",'Romanesque','neo-Gothic',"",1,[]])
data_list.append([datetime.datetime(2008, 11, 16),50,"Cathedral","Geneva","Switzerland","Gothic",'Romanesque','neo-Gothic',"",1,[]])
#2009
data_list.append([datetime.datetime(2009, 1, 3),45,"Minster","Konstanz","Germany","Gothic",'Classicist','neo-Gothic',"",1,['Heidrun','Hannsjoerg','Artur']])
data_list.append([datetime.datetime(2009, 3, 2),33,"Cathedral","Lausanne","Switzerland","Gothic",'','',"",1,[]])
data_list.append([datetime.datetime(2009, 3, 21),34,"Minster","Basel","Switzerland","Romanesque",'Gothic','',"",1,[]])
data_list.append([datetime.datetime(2009, 3, 21),25,"Cathedral","Fribourg","Switzerland","Gothic",'Baroque','',"",1,[]])
data_list.append([datetime.datetime(2009, 4, 25),12,"Almudena Cathedral","Madrid","Spain","neo-Gothic",'neo-Baroque','',"",0,[]])
data_list.append([datetime.datetime(2009, 4, 29),12,"Cathedral","Getafe","Spain","Renaissance",'Baroque','',"",0,[]])
data_list.append([datetime.datetime(2009, 4, 29),26,"Cathedral","Toledo","Spain","Gothic",'Baroque','',"Toledo",0,[]])
data_list.append([datetime.datetime(2009, 4, 30),3,"Almudena Cathedral","Madrid","Spain","neo-Gothic",'neo-Baroque','',"",0,[]])
data_list.append([datetime.datetime(2009, 6, 28),4,"Cathedral","Chicago","USA","neo-Gothic",'','',"",0,[]])
data_list.append([datetime.datetime(2009, 7, 3),11,"St Patrick's Cathedral","New York City","USA","neo-Gothic",'','',"",0,[]])
data_list.append([datetime.datetime(2009, 7, 5),6,"St Patrick's Cathedral","New York City","USA","neo-Gothic",'','',"",0,[]])
data_list.append([datetime.datetime(2009, 7, 5),25,"St John the Divine","New York City","USA","neo-Gothic",'','',"",0,[]])
data_list.append([datetime.datetime(2009, 7, 26),6,"Cathedral","Sion","Switzerland","Gothic",'Romanesque','',"",0,[]])
data_list.append([datetime.datetime(2009, 9, 1),26,"Dom","Innsbruck","Austria","Baroque",'','',"",0,[]])
data_list.append([datetime.datetime(2009, 9, 4),6,"Dom","Innsbruck","Austria","Baroque",'','',"",0,[]])
data_list.append([datetime.datetime(2009, 9, 5),6,"Dom","Feldkirch","Austria","Gothic",'','',"",0,[]])
data_list.append([datetime.datetime(2009,11,26),12,"Minster","Bern","Switzerland","Gothic",'','',"",1,[]])
data_list.append([datetime.datetime(2009, 12, 20),35,"Dom","Speyer","Germany","Romanesque",'','',"Speyer Cathedral",0,['Anne-Kathrin']])
data_list.append([datetime.datetime(2009, 12, 19),27,"Dom","Mainz","Germany","Romanesque",'','',"",0,['Anne-Kathrin']])
data_list.append([datetime.datetime(2009, 12, 20),38,"Dom","Worms","Germany","Romanesque",'Baroque','',"",0,['Anne-Kathrin']])
data_list.append([datetime.datetime(2009, 1, 11),26,"Cathedral","Geneva","Switzerland","Gothic",'Romanesque','neo-Gothic',"",1,[]])
data_list.append([datetime.datetime(2009, 1, 25),5,"Cathedral","Geneva","Switzerland","Gothic",'Romanesque','neo-Gothic',"",1,[]])
data_list.append([datetime.datetime(2009, 3, 1),24,"Cathedral","Geneva","Switzerland","Gothic",'Romanesque','neo-Gothic',"",1,[]])
data_list.append([datetime.datetime(2009, 12, 13),2,"Cathedral","Geneva","Switzerland","Gothic",'Romanesque','neo-Gothic',"",1,[]])

# %%
data_list.append([datetime.datetime(2010, 1, 12),12,"Cathedral","Lugano","Switzerland","Gothic",'Baroque','',"",1,[]])
data_list.append([datetime.datetime(2010, 1, 12),25,"Cathedral","Como","Italy","Baroque",'Renaissance','',"",1,[]])
data_list.append([datetime.datetime(2010, 4, 8),8,"Frauenkirche","Munich","Germany","Gothic",'','',"",0,['Hannsjoerg']])
data_list.append([datetime.datetime(2010, 4, 9),12,"Dom","Augsburg","Germany","Romanesque",'Gothic','',"",0,['Hannsjoerg']])
data_list.append([datetime.datetime(2010, 12, 27),15,"Minster","Bern","Switzerland","Gothic",'','',"",1,['Hannsjoerg']])
data_list.append([datetime.datetime(2010, 9, 26),9,"Cathedral","Geneva","Switzerland","Gothic",'Romanesque','neo-Gothic',"",1,[]])
data_list.append([datetime.datetime(2010, 7, 21),37,"Notre-Dame","Paris","France","Gothic",'','',"Paris, Banks of the Seine",0,[]])
data_list.append([datetime.datetime(2010, 7, 21),5,"Cathedrale St Louis des Invalides","Paris","France","Baroque",'','',"Paris, Banks of the Seine",0,[]])
data_list.append([datetime.datetime(2010, 7, 22),4,"Notre-Dame","Paris","France","Gothic",'','',"Paris, Banks of the Seine",0,[]])
data_list.append([datetime.datetime(2010, 7, 26),7,"Notre-Dame","Paris","France","Gothic",'','',"Paris, Banks of the Seine",0,[]])
data_list.append([datetime.datetime(2010, 7, 29),87,"Cathedral","Chartres","France","Gothic",'','',"Chartres Cathedral",0,[]])
data_list.append([datetime.datetime(2010, 7, 31),71,"Basilique","Saint Denis","France","Gothic",'','',"",0,['Heidrun','Artur']])
data_list.append([datetime.datetime(2010, 8, 3),88,"Cathedral","Reims","France","Gothic",'','',"Cathedral of Notre-Dame, Former Abbey of Saint-Remi and Palace of Tau",0,[]])
#2011
data_list.append([datetime.datetime(2011, 1, 16),22,"Cathedral","Lausanne","Switzerland","Gothic",'','',"",1,['Hannsjoerg']])
data_list.append([datetime.datetime(2011, 1, 23),86,"Duomo","Milano","Italy","Gothic",'','',"",1,['Hannsjoerg']])
data_list.append([datetime.datetime(2011, 4, 22),28,"Minster","Freiburg","Germany","Gothic",'Romanesque','',"",1,['Hannsjoerg','Artur','Heidrun']])
data_list.append([datetime.datetime(2011, 5, 22),18,"Cathedral","Lyon","France","Gothic",'','',"Lyon",1,['Hannsjoerg','Artur','Heidrun']])
data_list.append([datetime.datetime(2011, 9, 5),8,"Dom","Innsbruck","Austria","Baroque",'','',"",0,['Hannsjoerg','Artur','Heidrun','Anne-Kathrin','Jan-Marc','Franziska']])
data_list.append([datetime.datetime(2011, 9, 29),6,"Dom","Bamberg","Germany","Romanesque",'','',"Bamberg",0,['Artur','Heidrun']])
data_list.append([datetime.datetime(2011, 9, 29),9,"Dom","Wuerzburg","Germany","Modern",'Romanesque','',"",0,['Artur','Heidrun']])
data_list.append([datetime.datetime(2011, 9, 30),48,"Dom","Bamberg","Germany","Romanesque",'','',"Bamberg",0,['Artur','Heidrun']])
data_list.append([datetime.datetime(2011, 12, 27),28,"Stephansdom","Vienna","Austria","Gothic",'Baroque','',"Vienna",0,['Artur','Heidrun','Hannsjoerg']])
data_list.append([datetime.datetime(2011, 12, 28),1,"Stephansdom","Vienna","Austria","Gothic",'Baroque','',"Vienna",0,['Artur','Heidrun','Hannsjoerg']])
data_list.append([datetime.datetime(2012, 10, 15),9,"Cathedral","Geneva","Switzerland","Gothic",'Romanesque','neo-Gothic',"",1,['Hannsjoerg']])
#2012
data_list.append([datetime.datetime(2012, 3, 24),9,"Cathedral","Geneva","Switzerland","Gothic",'Romanesque','neo-Gothic',"",1,['Hannsjoerg']])
data_list.append([datetime.datetime(2012, 2, 18),5,"Cathedral","Chicago","USA","neo-Gothic",'','',"",1,['Ina','Jingtuan']])
data_list.append([datetime.datetime(2012, 5, 11),15,"Cathedral","Prague","Czech","Gothic",'','',"Prague",0,['Heidrun','Artur']])
data_list.append([datetime.datetime(2012, 5, 12),68,"Cathedral","Prague","Czech","Gothic",'','',"Prague",0,['Heidrun','Artur']])
data_list.append([datetime.datetime(2012, 5, 31),1,"Cathedral","Blois","France","Renaissance",'','',"Loire Valley between Sully-sur-Loire and Chalonnes",0,['Heidrun','Artur']])
data_list.append([datetime.datetime(2012, 6, 1),9,"Cathedral","Blois","France","Renaissance",'','',"Loire Valley between Sully-sur-Loire and Chalonnes",0,['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2012, 6, 2),33,"Cathedral","Orleans","France","Gothic",'','',"",0,['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2012, 7, 25),3,"Hedwigskathedrale","Berlin","Germany","Modern",'Classicist','',"",0,[]])
data_list.append([datetime.datetime(2012, 8, 30),17,"Se Catedral","Lisbon","Portugal","Romanesque",'Baroque','',"",0,[]])
data_list.append([datetime.datetime(2012, 9, 8),13,"Se Catedral","Porto","Portugal","Romanesque",'Baroque','',"Porto",0,[]])
data_list.append([datetime.datetime(2012, 9, 8),26,"Old Cathedral","Coimbra","Portugal","Romanesque",'Gothic','',"University of Coimbra – Alta and Sofia",0,[]])
data_list.append([datetime.datetime(2012, 9, 8),17,"New Cathedral","Coimbra","Portugal","Classicist",'','',"University of Coimbra – Alta and Sofia",0,[]])
data_list.append([datetime.datetime(2012, 9, 29),32,"Cathedral","Krakow","Poland","Baroque",'Gothic','Renaissance',"Krakow",0,["Eric"]])
data_list.append([datetime.datetime(2012, 9, 30),12,"St John's Cathedral","Warsaw","Poland","Gothic",'Modern','',"Warsaw",0,["Eric"]])
data_list.append([datetime.datetime(2012, 9, 30),3,"Military Cathedral","Warsaw","Poland","Classicist",'Modern','',"Warsaw",0,["Eric"]])
data_list.append([datetime.datetime(2012, 9, 30),4,"St Florians's Cathedral","Warsaw","Poland","neo-Gothic",'','',"",0,["Eric"]])

# %%
#2013
data_list.append([datetime.datetime(2010, 7, 25),13,"Cathedral","Versailles","France","Baroque",'','',"",0,[]])
data_list.append([datetime.datetime(2013, 3, 23),21,"Notre-Dame","Paris","France","Gothic",'','',"Paris, Banks of the Seine",0,['Andrew']])
data_list.append([datetime.datetime(2013, 3, 25),36,"Basilique","Saint Denis","France","Gothic",'','',"",0,['Andrew']])
data_list.append([datetime.datetime(2013, 4, 5),56,"San Giovanni in Laterano","Rome","Vatican","Baroque",'','',"Rome",0,['Heidrun']])
data_list.append([datetime.datetime(2013, 5, 25),19,"Cathedral","Lyon","France","Gothic",'','',"Lyon",1,['Hannsjoerg','Andrew']])
data_list.append([datetime.datetime(2013, 7, 7),55,"Duomo","Milano","Italy","Gothic",'','',"",1,['Nick','Andrew']])
data_list.append([datetime.datetime(2013, 7, 15),19,"Cathedral","Stockholm","Sweden","Gothic",'Baroque','',"",0,[]])
data_list.append([datetime.datetime(2013, 7, 27),1,"Cathedral","Copenhagen","Denmark","Classicist",'','',"",0,['Susanne']])
data_list.append([datetime.datetime(2013, 7, 27),2,"Cathedral","Copenhagen","Denmark","Classicist",'','',"",0,['']])
data_list.append([datetime.datetime(2013, 9, 6),28,"St Mark's Cathedral","Venice","Italy","Byzantine",'','',"Venice",0,['']])
data_list.append([datetime.datetime(2013, 9, 8),4,"St Mark's Cathedral","Venice","Italy","Byzantine",'','',"Venice",0,['']])
data_list.append([datetime.datetime(2013, 11, 9),6,"Notre-Dame","Paris","France","Gothic",'','',"Paris, Banks of the Seine",0,['Eric']])
data_list.append([datetime.datetime(2013, 11, 11),49,"Basilique","Saint Denis","France","Gothic",'','',"",0,['Eric','Chris Clarke','Chris Lee']])
data_list.append([datetime.datetime(2013, 11, 11),11,"Notre-Dame","Paris","France","Gothic",'','',"Paris, Banks of the Seine",0,['Eric','Chris Clarke','Chris Lee']])
data_list.append([datetime.datetime(2013, 12, 27),49,"Minster","Strasbourg","France","Gothic",'Romanesque','',"Strasbourg",1,['Artur','Heidrun','Hannsjoerg']])
#2014
data_list.append([datetime.datetime(2014, 4, 22),2,"Frauenkirche","Munich","Germany","Gothic",'','',"",0,['Eric']])
data_list.append([datetime.datetime(2014, 7, 29),56,"St Paul's Cathedral","London","United Kingdom","Baroque",'','',"",0,['Heidrun']])
data_list.append([datetime.datetime(2014, 7, 30),42,"Christ Church Cathedral","Oxford","United Kingdom","Gothic",'','',"",0,['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2014, 7, 31),52,"Westminster Abbey","London","United Kingdom","Gothic",'','',"Westminster",0,['Heidrun']])
data_list.append([datetime.datetime(2014, 7, 31),39,"Westminster Cathedral","London","United Kingdom","neo-Byzantine",'','',"",0,['Heidrun']])
data_list.append([datetime.datetime(2014, 8, 1),35,"Cathedral","Rochester","United Kingdom","Romanesque",'Gothic','',"",0,['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2014, 8, 1),90,"Cathedral","Canterbury","United Kingdom","Gothic",'','',"Canterbury Cathedral",0,['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2014, 8, 1),61,"Cathedral","Salisbury","United Kingdom","Gothic",'','',"",0,['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2014, 8, 4),4,"St Paul's Cathedral","London","United Kingdom","Baroque",'','',"",0,['Hannsjoerg']])
data_list.append([datetime.datetime(2014, 8, 22),8,"Stephansdom","Vienna","Austria","Gothic",'Baroque','',"Vienna",0,[]])
data_list.append([datetime.datetime(2014, 8, 24),17,"Martinsdom","Bratislava","Slovakia","Gothic",'','',"",0,[]])
data_list.append([datetime.datetime(2014, 8, 26),4,"Stephansdom","Vienna","Austria","Gothic",'Baroque','',"Vienna",0,["Dooyeon",'Viola']])
data_list.append([datetime.datetime(2014, 8, 28),18,"Stephansdom","Vienna","Austria","Gothic",'Baroque','',"Vienna",0,[]])
data_list.append([datetime.datetime(2014, 8, 30),26,"Stephen's Basilica","Budapest","Hungary","Classicist",'','',"",0,[]])
data_list.append([datetime.datetime(2014, 8, 31),16,"Stephen's Basilica","Budapest","Hungary","Classicist",'','',"",0,[]])
data_list.append([datetime.datetime(2014,9,6),5,"Duomo","Florence","Italy","Renaissance",'Gothic','',"Florence",0,[]])
data_list.append([datetime.datetime(2014,9,7),73,"Duomo","Pisa","Italy","Romanesque",'Baroque','',"Pisa",0,[]])
data_list.append([datetime.datetime(2014,9,7),15,"Duomo","Florence","Italy","Renaissance",'Gothic','',"Florence",0,[]])
data_list.append([datetime.datetime(2004,9,9),19,"Cathedral","Bologna","Italy","Baroque",'','',"Bologna",0,[]])
data_list.append([datetime.datetime(2004,9,10),4,"Cathedral","Bologna","Italy","Baroque",'','',"Bologna",0,[]])
data_list.append([datetime.datetime(2004,9,11),3,"Cathedral","Bologna","Italy","Baroque",'','',"Bologna",0,[]])
data_list.append([datetime.datetime(2014,9,12),2,"Duomo","Florence","Italy","Renaissance",'Gothic','',"Florence",0,[]])
data_list.append([datetime.datetime(2014,9,13),29,"Duomo","Florence","Italy","Renaissance",'Gothic','',"Florence",0,[]])
data_list.append([datetime.datetime(2014,9,13),100,"Duomo","Siena","Italy","Gothic",'','',"Siena",0,[]])
data_list.append([datetime.datetime(2014,9,14),5,"Duomo","Florence","Italy","Renaissance",'Gothic','',"Florence",0,[]])
data_list.append([datetime.datetime(2014, 9, 21),1,"Notre-Dame","Paris","France","Gothic",'','',"Paris, Banks of the Seine",0,[]])
data_list.append([datetime.datetime(2014, 10, 24),67,"Hagia Sophia","Istanbul","Turkey","Byzantine",'Islamic','',"Istanbul",0,[]])
data_list.append([datetime.datetime(2014, 10, 25),8,"Hagia Sophia","Istanbul","Turkey","Byzantine",'Islamic','',"Istanbul",0,[]])
data_list.append([datetime.datetime(2014, 10, 26),2,"Hagia Sophia","Istanbul","Turkey","Byzantine",'Islamic','',"Istanbul",0,[]])
data_list.append([datetime.datetime(2014, 12, 13),13,"Westminster Abbey","London","United Kingdom","Gothic",'','',"Westminster",0,['Manuel']])

# %%
#2015
data_list.append([datetime.datetime(2015, 12, 11),2,"Cathedral","Geneva","Switzerland","Gothic",'Romanesque','neo-Gothic',"",1,[]])
data_list.append([datetime.datetime(2015, 3, 14),57,"Duomo","Milano","Italy","Gothic",'','',"",1,['Christine','Aaron','Laser',"Can",'Nate','Devin','Kennedy']])
data_list.append([datetime.datetime(2015, 3, 15),2,"Duomo","Milano","Italy","Gothic",'','',"",1,['Christine','Aaron',"Can",'Nate','Devin','Kennedy']])
data_list.append([datetime.datetime(2015,3,29),6,"Cathedral","Sevilla","Spain","Gothic",'','',"Cathedral, Alcazar and Archivo de Indias in Seville",0,['Manuel']])
data_list.append([datetime.datetime(2014,3,30),44,"Cathedral","Granada","Spain","Renaissance",'','',"",0,['Manuel']])
data_list.append([datetime.datetime(2015,3,31),6,"Mezquita-Cathedral","Cordoba","Spain","Islamic",'Renaissance','',"Cordoba",0,['Manuel']])
data_list.append([datetime.datetime(2015,4,1),75,"Cathedral","Segovia","Spain","Gothic",'','',"Segovia",0,['Manuel']])
data_list.append([datetime.datetime(2015, 4, 1),1,"Military Cathedral","Madrid","Spain","Baroque",'','',"",0,['Manuel']])
data_list.append([datetime.datetime(2015, 4, 1),3,"Almudena Cathedral","Madrid","Spain","neo-Gothic",'neo-Baroque','',"",0,['Manuel']])
data_list.append([datetime.datetime(2015, 4, 2),97,"Cathedral","Toledo","Spain","Gothic",'Baroque','',"Toledo",0,['Manuel']])
data_list.append([datetime.datetime(2015,4,4),111,"Mezquita-Cathedral","Cordoba","Spain","Islamic",'Renaissance','',"Cordoba",0,[]])
data_list.append([datetime.datetime(2015,4,4),89,"Cathedral","Sevilla","Spain","Gothic",'','',"Cathedral, Alcazar and Archivo de Indias in Seville",0,[]])
data_list.append([datetime.datetime(2015, 4, 5),17,"Almudena Cathedral","Madrid","Spain","neo-Gothic",'neo-Baroque','',"",0,['Eric']])
data_list.append([datetime.datetime(2015, 4, 5),1,"Military Cathedral","Madrid","Spain","Baroque",'','',"",0,['Eric']])
data_list.append([datetime.datetime(2015, 4, 6),28,"Almudena Cathedral","Madrid","Spain","neo-Gothic",'neo-Baroque','',"",0,['Eric']])
data_list.append([datetime.datetime(2015, 4, 6),17,"San Isidro","Madrid","Spain","Baroque",'','',"",0,['Eric']])
data_list.append([datetime.datetime(2015, 5, 15),17,"Shrine of the Virgin of the Rosary of Pompei","Pompei","Italy","neo-Baroque",'','',"",0,['AJ','Stephan']])
data_list.append([datetime.datetime(2015, 5, 18),47,"Duomo","Naples","Italy","Baroque",'Gothic','',"Naples",0,['AJ','Stephan']])
data_list.append([datetime.datetime(2015, 7, 18),3,"Cathedral","Versailles","France","Baroque",'','',"",0,['Riju']])
data_list.append([datetime.datetime(2015, 8, 22),13,"Cathedral","Monaco","Monaco","neo-Romanesque",'','',"",0,['AJ','Laser','Evan']])
data_list.append([datetime.datetime(2015, 8, 23),10,"Cathedral","Nice","France","Baroque",'','',"Nice",0,[]])
data_list.append([datetime.datetime(2015, 8, 28),10,"Kazan Cathedral","St Petersburg","Russia","Classicist",'','',"Petersburg and Related Groups of Monuments",0,[]])
data_list.append([datetime.datetime(2015, 8, 28),45,"Isaac's Cathedral","St Petersburg","Russia","Classicist",'','',"Petersburg and Related Groups of Monuments",0,[]])
data_list.append([datetime.datetime(2015, 8, 29),46,"Peter-and-Paul Cathedral","St Petersburg","Russia","Classicist",'','',"Petersburg and Related Groups of Monuments",0,[]])
data_list.append([datetime.datetime(2015, 9, 2),7,"Cathedral of the Archangel","Moscow","Russia","Russian Gothic",'','',"Kremlin and Red Square",0,['Manuel']])
data_list.append([datetime.datetime(2015, 9, 2),5,"Cathedral of the Annunciation","Moscow","Russia","Russian Gothic",'','',"Kremlin and Red Square",0,['Manuel']])
data_list.append([datetime.datetime(2015, 9, 2),4,"Cathedral of Christ the Saviour","Moscow","Russia","Russian Revival",'','',"",0,['Manuel']])
data_list.append([datetime.datetime(2015, 9, 2),56,"St Basil's Cathedral","Moscow","Russia","Russian Gothic",'','',"Kremlin and Red Square",0,['Manuel']])
data_list.append([datetime.datetime(2015, 9, 6),3,"Catherine's Cathedral","Pushkin","Russia","Russian Revival",'','',"Petersburg and Related Groups of Monuments",0,['Manuel']])
data_list.append([datetime.datetime(2015, 9, 10),3,"Peter-and-Paul Cathedral","Peterhof","Russia","Russian Revival",'','',"Petersburg and Related Groups of Monuments",0,[]])
data_list.append([datetime.datetime(2015, 10, 3),4,"Frauenkirche","Munich","Germany","Gothic",'','',"",0,['Eric','Siyi']])
data_list.append([datetime.datetime(2015, 10, 10),28,"Dom","Passau","Germany","Baroque",'','',"",0,['Eric','Siyi']])
data_list.append([datetime.datetime(2015, 10, 11),31,"Dom","Salzburg","Austria","Baroque",'','',"Salzburg",0,['Eric','Siyi']])
data_list.append([datetime.datetime(2015, 11, 11),10,"Dom","Schwerin","Germany","Gothic",'','',"",0,[]])
data_list.append([datetime.datetime(2015, 11, 11),21,"Dom","Luebeck","Germany","Gothic",'','',"Luebeck",0,[]])
data_list.append([datetime.datetime(2015, 11, 13),32,"Dom","Erfurt","Germany","Gothic",'Baroque','',"",0,[]])
data_list.append([datetime.datetime(2015, 11, 13),39,"Dom","Fulda","Germany","Baroque",'','',"",0,[]])

# %%
#2016
data_list.append([datetime.datetime(2016, 3, 16),1,"Cathedral","Piazza Armerina","Italy","Baroque",'','',"",0,['Heidrun','Artur']])
data_list.append([datetime.datetime(2016, 3, 17),2,"Cathedral","Piazza Armerina","Italy","Baroque",'','',"",0,['Heidrun','Artur']])
data_list.append([datetime.datetime(2016, 3, 17),32,"Duomo","Cefalu","Italy","Romanesque",'Byzantine','',"Arab-Norman Palermo and the Cathedral Churches of Cefalu and Monreale",0,['Heidrun','Artur']])
data_list.append([datetime.datetime(2016, 3, 17),122,"Duomo","Monreale","Italy","Romanesque",'Byzantine','',"Arab-Norman Palermo and the Cathedral Churches of Cefalu and Monreale",0,['Heidrun','Artur']])
data_list.append([datetime.datetime(2016, 3, 17),3,"Cathedral","Palermo","Italy","Romanesque",'Baroque','',"Arab-Norman Palermo and the Cathedral Churches of Cefalu and Monreale",0,['Heidrun','Artur']])
data_list.append([datetime.datetime(2016, 3, 17),31,"Cathedral","Palermo","Italy","Romanesque",'Baroque','',"Arab-Norman Palermo and the Cathedral Churches of Cefalu and Monreale",0,['Heidrun','Artur']])
data_list.append([datetime.datetime(2016, 3, 21),1,"Duomo","Agrigent","Italy","Baroque",'','',"",0,['Heidrun','Artur']])
data_list.append([datetime.datetime(2016, 3, 22),18,"Cathedral","Noto","Italy","Baroque",'Modern','',"Late Baroque Towns of the Val di Noto",0,['Heidrun','Artur']])
data_list.append([datetime.datetime(2016, 3, 22),2,"Duomo","Syracuse","Italy","Roman",'Romanesque','Baroque',"Syracuse",0,['Heidrun','Artur']])
data_list.append([datetime.datetime(2016, 3, 23),24,"Duomo","Syracuse","Italy","Roman",'Romanesque','Baroque',"Syracuse",0,['Heidrun','Artur']])
data_list.append([datetime.datetime(2016, 3, 23),26,"Cathedral","Catania","Italy","Baroque",'','',"Late Baroque Towns of the Val di Noto",0,['Heidrun','Artur']])
data_list.append([datetime.datetime(2016, 3, 25),1,"Cathedral","Catania","Italy","Baroque",'','',"Late Baroque Towns of the Val di Noto",0,['Heidrun','Artur']])
data_list.append([datetime.datetime(2016, 3, 27),48,"Cathedral","Barcelona","Spain","Gothic",'','',"",0,['Riju']])
data_list.append([datetime.datetime(2016, 3, 28),25,"Cathedral","Zaragoza","Spain","Gothic",'','',"",0,['Riju']])
data_list.append([datetime.datetime(2016, 3, 28),63,"Catedral-Basilica del Pilar","Zaragoza","Spain","Baroque",'','',"",0,['Riju']])
data_list.append([datetime.datetime(2016, 5, 5),11,"Duomo","Torino","Italy","Renaissance",'Baroque','',"",0,[]])
data_list.append([datetime.datetime(2016, 5, 8),1,"Duomo","Torino","Italy","Renaissance",'Baroque','',"",0,[]])
data_list.append([datetime.datetime(2016, 5, 14),24,"Cathedral","Genova","Italy","Romanesque",'Baroque','',"",0,['Amin']])
data_list.append([datetime.datetime(2016, 5, 28),2,"Cathedral","Santander","Spain","Gothic",'','',"",0,['']])
data_list.append([datetime.datetime(2016, 5, 29),20,"Cathedral","Santander","Spain","Gothic",'','',"",0,['']])
data_list.append([datetime.datetime(2016, 5, 29),160,"Cathedral","Burgos","Spain","Gothic",'','',"Burgos Cathedral",0,['']])
data_list.append([datetime.datetime(2016, 6, 3),16,"Cathedral","Bilbao","Spain","Gothic",'','',"Routes of Santiago de Compostela",0,['']])
data_list.append([datetime.datetime(2016, 6, 11),20,"Minster","Bern","Switzerland","Gothic",'','',"Bern",1,['Andrew']])
data_list.append([datetime.datetime(2016, 6, 11),17,"Duomo","Ravenna","Italy","Classicist",'Baroque','',"",0,['']])
data_list.append([datetime.datetime(2016, 6, 11),12,"Duomo","Padova","Italy","Renaissance",'Baroque','',"",0,['']])
data_list.append([datetime.datetime(2016, 7, 1),25,"Cathedral","Bordeaux","France","Gothic",'','',"Bordeaux",0,['Heidrun','Artur','Anne-Kathrin']])
data_list.append([datetime.datetime(2016, 7, 23),40,"Cathedral","Brussels","Belgium","Gothic",'','',"",0,[]])
data_list.append([datetime.datetime(2016, 7, 23),38,"Dom","Aachen","Germany","Karolingian",'Gothic','',"Aachen Cathedral",0,[]])
data_list.append([datetime.datetime(2016, 7, 23),7,"Military Cathedral Saint Jacques-sur-Coudenberg","Brussels","Belgium","Classicist",'','',"",0,[]])
data_list.append([datetime.datetime(2016, 8, 27),34,"Washington National Cathedral","Washington DC","USA","neo-Gothic",'','',"",0,['Heidrun','Artur']])
data_list.append([datetime.datetime(2016, 8, 28),8,"St Matthew the Apostle","Washington DC","USA","neo-Baroque",'','',"",0,[]])
data_list.append([datetime.datetime(2016, 10, 8),93,"Cathedral","Santiago de Compostela","Spain","Romanesque",'Baroque','',"Santiago de Compostela",0,[]])
data_list.append([datetime.datetime(2016, 10, 14),15,"Dom","Cologne","Germany","Gothic",'neo-Gothic','',"Cologne Cathedral",0,[]])
data_list.append([datetime.datetime(2016, 10, 15),101,"Dom","Cologne","Germany","Gothic",'neo-Gothic','',"Cologne Cathedral",0,[]])
data_list.append([datetime.datetime(2016, 10, 15),38,"Dom","Limburg","Germany","Romanesque",'','',"",0,[]])
data_list.append([datetime.datetime(2016, 10, 15),11,"Dom","Cologne","Germany","Gothic",'neo-Gothic','',"Cologne Cathedral",0,[]])
data_list.append([datetime.datetime(2016, 11, 26),25,"Duomo","Milano","Italy","Gothic",'','',"",0,['Riju']])
data_list.append([datetime.datetime(2016, 11, 23),11,"Duomo","Mantova","Italy","Baroque",'','',"",0,['Riju']])
data_list.append([datetime.datetime(2016, 11, 23),10,"Duomo","Mantova","Italy","Baroque",'','',"",0,['Riju']])

# %%
data_list.append([datetime.datetime(2017, 1, 2),15,"Christ Church Cathedral","Dublin","Ireland","neo-Gothic",'','',"",0,['Chris Martin']])
data_list.append([datetime.datetime(2017, 1, 3),6,"St Mary's Pro Cathedral","Dublin","Ireland","Classicist",'','',"",0,['Chris Martin']])
data_list.append([datetime.datetime(2017, 1, 3),20,"St Patrick's Cathedral","Dublin","Ireland","Gothic",'','',"",0,['Chris Martin']])
data_list.append([datetime.datetime(2017, 1, 3),1,"Christ Church Cathedral","Dublin","Ireland","neo-Gothic",'','',"",0,['Chris Martin']])
data_list.append([datetime.datetime(2017, 1, 4),7,"St Anne's Cathedral","Belfast","United Kingdom","neo-Romanesque",'','',"",0,[]])
data_list.append([datetime.datetime(2017, 1, 14),19,"Basilique Saint-Nazaire","Carcassonne","France","Gothic",'','',"Cite de Carcassonne",0,[]])
data_list.append([datetime.datetime(2017, 1, 14),11,"Cathedral","Carcassonne","France","Gothic",'','',"",0,[]])
data_list.append([datetime.datetime(2017, 1, 14),2,"Cathedral","Avignon","France","Romanesque",'Gothic','Baroque',"Papal Palace, Episcopal Ensemble and Avignon Bridge",0,[]])
data_list.append([datetime.datetime(2017, 1, 15),35,"Cathedral","Avignon","France","Romanesque",'Gothic','Baroque',"Papal Palace, Episcopal Ensemble and Avignon Bridge",0,[]])
data_list.append([datetime.datetime(2017, 2, 11),19,"Cathedral","Bruges","Belgium","Gothic",'neo-Gothic','',"Bruges",0,[]])
data_list.append([datetime.datetime(2017, 2, 11),30,"Cathedral","Ghent","Belgium","Gothic",'Baroque','',"",0,[]])
data_list.append([datetime.datetime(2017, 2, 12),65,"Cathedral","Antwerp","Belgium","Gothic",'','',"Belfries of Belgium and France",0,['Riju']])
data_list.append([datetime.datetime(2017, 3, 24),21,"Cathedral","Assisi","Italy","Renaissance",'Romanesque','',"Assisi",0,[]])
data_list.append([datetime.datetime(2017, 3, 25),4,"Cathedral","Assisi","Italy","Renaissance",'Romanesque','',"Assisi",0,[]])
data_list.append([datetime.datetime(2017, 3, 25),21,"Cathedral","Perugia","Italy","Gothic",'','',"",0,[]])
data_list.append([datetime.datetime(2017, 3, 25),2,"Duomo","Florence","Italy","Renaissance",'Gothic','',"Florence",0,[]])
data_list.append([datetime.datetime(2017, 4, 14),12,"Volodymyr's Cathedral","Kiev","Ukraine","neo-Byzantine",'','',"",0,[]])
data_list.append([datetime.datetime(2017, 4, 14),39,"Dormition Cathedral","Kiev","Ukraine","Russian Gothic",'','',"Saint-Sophia Cathedral and Kyiv-Pechersk Lavra",0,[]])
data_list.append([datetime.datetime(2017, 4, 14),35,"Sophia Cathedral","Kiev","Ukraine","Byzantine",'','',"Saint-Sophia Cathedral and Kyiv-Pechersk Lavra",0,[]])
data_list.append([datetime.datetime(2017, 4, 15),4,"Alexander Co-Cathedral","Kiev","Ukraine","Classicist",'','',"",0,[]])
data_list.append([datetime.datetime(2017, 4, 30),73,"Dom","Speyer","Germany","Romanesque",'','',"Speyer Cathedral",0,[]])
data_list.append([datetime.datetime(2017, 4, 30),33,"Dom","Mainz","Germany","Romanesque",'Baroque','',"",0,[]])
data_list.append([datetime.datetime(2017, 5, 25),100,"Cathedral","Salamanca","Spain","Renaissance",'Baroque','',"Salamanca",0,[]])
data_list.append([datetime.datetime(2017, 5, 25),66,"Old Cathedral","Salamanca","Spain","Gothic",'Romanesque','',"Salamanca",0,[]])
data_list.append([datetime.datetime(2017, 5, 26),72,"Cathedral","Valencia","Spain","Gothic",'','',"",0,[]])
data_list.append([datetime.datetime(2017, 5, 26),76,"Cathedral","Leon","Spain","Gothic",'','',"Routes of Santiago de Compostela",0,[]])
data_list.append([datetime.datetime(2017, 5, 26),76,"Cathedral","Oviedo","Spain","Gothic",'Romanesque','',"Routes of Santiago de Compostela",0,[]])
data_list.append([datetime.datetime(2017, 5, 26),73,"Cathedral","Oviedo","Spain","Gothic",'Romanesque','',"Routes of Santiago de Compostela",0,[]])
data_list.append([datetime.datetime(2017, 5, 26),19,"Cathedral","Oviedo","Spain","Gothic",'Romanesque','',"Monuments of Oviedo and the Kingdom of the Asturias",0,[]])
data_list.append([datetime.datetime(2017, 5, 27),68,"Cathedral","Avila","Spain","Gothic",'','',"Avila",0,[]])
data_list.append([datetime.datetime(2017, 6, 4),13,"Cathedral","Athens","Greece","neo-Byzantine",'','',"",0,["Riju",'Amin']])
data_list.append([datetime.datetime(2017, 6, 21),13,"Cathedral","Salt Lake City","USA","neo-Gothic",'','',"",0,["Artur",'Heidrun','Artur']])
data_list.append([datetime.datetime(2017, 7, 8),11,"St Mark's Cathedral","Venice","Italy","Byzantine",'','',"Venice",0,['Riju','Reyer','Indara']])
data_list.append([datetime.datetime(2017, 7, 9),23,"Duomo","Ancona","Italy","Romanesque",'','',"",0,[]])
data_list.append([datetime.datetime(2017, 7, 10),30,"St Mark's Cathedral","Venice","Italy","Byzantine",'','',"Venice",0,[]])
data_list.append([datetime.datetime(2017, 7, 12),23,"Duomo","Vicenza","Italy","Gothic",'Renaissance','',"City of Vicenza and the Palladian Villas of the Veneto",0,[]])
data_list.append([datetime.datetime(2017, 7, 13),18,"Cathedral","Ferrara","Italy","Romanesque",'Baroque','',"Ferrara, City of the Renaissance, and its Po Delta",0,[]])
data_list.append([datetime.datetime(2017, 7, 14),61,"Euphrasien Basilica","Porec","Croatia","Byzantine",'','',"Euphrasien Basilica",0,['Reyer']])
data_list.append([datetime.datetime(2017, 7, 15),40,"Basilica","Aquileia","Italy","Romanesque",'early-Christian','',"Archaeological Area and the Patriarchal Basilica of Aquileia",0,['Reyer']])
data_list.append([datetime.datetime(2017, 7, 16),14,"Duomo","Trieste","Italy","Romanesque",'','',"",0,['Reyer']])
data_list.append([datetime.datetime(2017, 7, 21),10,"Domkirke","Oslo","Norway","neo-Gothic",'modern','',"",0,[]])
data_list.append([datetime.datetime(2017, 7, 22),12,"Domkirke","Oslo","Norway","neo-Gothic",'modern','',"",0,[]])
data_list.append([datetime.datetime(2017, 7, 29),7,"Frauenkirche","Munich","Germany","Gothic",'','',"",0,['Eric','Siyi']])
data_list.append([datetime.datetime(2017, 8, 27),42,"Cathedral","Trogir","Croatia","Romanesque",'','',"Trogir",0,[]])
data_list.append([datetime.datetime(2017, 8, 27),70,"Cathedral","Split","Croatia","Roman",'Romanesque','',"Historical Complex of Split with the Palace of Diocletian",0,[]])
data_list.append([datetime.datetime(2017, 9, 8),37,"San Giovanni in Laterano","Rome","Vatican","Baroque",'','',"Rome",0,['Riju','Amin']])
data_list.append([datetime.datetime(2017, 9, 9),1,"San Giovanni in Laterano","Rome","Vatican","Baroque",'','',"Rome",0,['Riju','Amin']])
data_list.append([datetime.datetime(2017, 9, 16),70,"Westminster Abbey","London","United Kingdom","Gothic",'','',"Westminster",0,['Riju']])
data_list.append([datetime.datetime(2017, 9, 17),7,"St Paul's Cathedral","London","United Kingdom","Baroque",'','',"",0,['Riju']])
data_list.append([datetime.datetime(2017, 9, 30),21,"Dom","Graz","Austria","Gothic",'Baroque','',"Graz",0,[]])
data_list.append([datetime.datetime(2017, 10, 1),1,"Dom","Graz","Austria","Gothic",'Baroque','',"Graz",0,[]])
data_list.append([datetime.datetime(2017, 10, 7),13,"Uspenski-Cathedral","Helsinki","Finland","neo-Byzantine",'','',"",0,['Riju','Reyer','Rachel']])
data_list.append([datetime.datetime(2017, 10, 7),12,"Dom","Helsinki","Finland","Classicist",'','',"",0,['Riju','Reyer','Rachel']])
data_list.append([datetime.datetime(2017, 10, 8),7,"Alexander Nevsky Cathedral","Tallinn","Estonia","neo-Byzantine",'','',"Tallinn",0,['Riju','Reyer','Rachel']])
data_list.append([datetime.datetime(2017, 10, 8),22,"Dom","Tallinn","Estonia","Gothic",'','',"Tallinn",0,['Riju','Reyer','Rachel']])
data_list.append([datetime.datetime(2017, 11, 4),69,"Cathedral","St Gallen","Switzerland","Baroque",'Classicist','',"Abbey of St Gall",1,[]])
data_list.append([datetime.datetime(2017, 11, 4),32,"Minster","Konstanz","Germany","Gothic",'Classicist','neo-Gothic',"",1,[]])
data_list.append([datetime.datetime(2017, 11, 19),18,"Cathedral","Besancon","France","Baroque",'Gothic','',"",1,['Andrew']])
data_list.append([datetime.datetime(2017, 12, 9),1,"Cathedral","Lyon","France","Gothic",'','',"Lyon",1,['Riju','Reyer','Rachel']])

# %%
data_list.append([datetime.datetime(2018, 1, 13),5,"Cathedral","Beijing","China","neo-Baroque",'','',"",0,[]])
data_list.append([datetime.datetime(2018, 1, 16),4,"Cathedral","Macau","China","neo-Renaissance",'','',"Macau",0,[]])
data_list.append([datetime.datetime(2018, 1, 16),5,"St John's Cathedral","Hongkong","China","neo-Gothic",'','',"",0,[]])
data_list.append([datetime.datetime(2018, 1, 17),4,"Macau","Hongkong","China","neo-Gothic",'','',"",0,[]])
data_list.append([datetime.datetime(2018, 1, 28),13,"Cathedral","Lausanne","Switzerland","Gothic",'','',"",1,['Hannsjoerg']])
data_list.append([datetime.datetime(2018, 3, 3),106,"Cathedral","Albi","France","Gothic",'Renaissance','',"Episcopal City of Albi",0,[]])
data_list.append([datetime.datetime(2018, 3, 3),25,"Cathedral","Toulouse","France","Gothic",'Romanesque','',"",0,[]])
data_list.append([datetime.datetime(2018, 3, 4),21,"Cathedral","Toulouse","France","Gothic",'Romanesque','',"",0,[]])
data_list.append([datetime.datetime(2018, 3, 11),12,"Cathedral","Brussels","Belgium","Gothic",'','',"",0,['Mohammed']])
data_list.append([datetime.datetime(2018, 3, 11),3,"Military Cathedral Saint Jacques-sur-Coudenberg","Brussels","Belgium","Classicist",'','',"",0,['Mohammed']])
data_list.append([datetime.datetime(2018, 3, 31),1,"Dom","Reykjavik","Iceland","neo-Gothic",'','',"",0,['Riju']])
data_list.append([datetime.datetime(2018, 3, 31),4,"Cathedral","Reykjavik","Iceland","neo-Gothic",'','',"",0,['Riju']])
data_list.append([datetime.datetime(2018, 4, 7),11,"Cathedral","Sion","Switzerland","Gothic",'Romanesque','',"",1,['Heidrun','Artur']])
data_list.append([datetime.datetime(2018, 4, 15),115,"Domkirke","Roskilde","Denmark","Gothic",'','',"Roskilde Cathedral",0,['Riju','Reyer','Rachel']])
data_list.append([datetime.datetime(2018, 4, 28),66,"Cathedral","Reims","France","Gothic",'','',"Cathedral of Notre-Dame, Former Abbey of Saint-Remi and Palace of Tau",0,['Reyer','Christine']])
data_list.append([datetime.datetime(2018, 4, 29),31,"Notre-Dame","Paris","France","Gothic",'','',"Paris, Banks of the Seine",0,[]])
data_list.append([datetime.datetime(2018, 4, 30),25,"Cathedral","Bayeux","France","Gothic",'','',"",0,['Reyer']])
data_list.append([datetime.datetime(2018, 4, 30),60,"Cathedral","Rouen","France","Gothic",'','',"",0,['Reyer']])
data_list.append([datetime.datetime(2018, 5, 1),111,"Cathedral","Amiens","France","Gothic",'','',"Amiens Cathedral",0,['Reyer']])
data_list.append([datetime.datetime(2018, 5, 1),108,"Cathedral","Chartres","France","Gothic",'','',"Chartres Cathedral",0,[]])
data_list.append([datetime.datetime(2018, 5, 19),18,"Duomo","Pavia","Italy","Renaissance",'','',"",0,['Amin']])
data_list.append([datetime.datetime(2018, 5, 19),17,"Duomo Nuovo","Brescia","Italy","Renaissance",'','',"",0,['Amin']])
data_list.append([datetime.datetime(2018, 5, 19),19,"Duomo Vecchio","Brescia","Italy","Romanesque",'','',"",0,['Amin']])
data_list.append([datetime.datetime(2018, 5, 20),37,"Duomo","Bergamo","Italy","Baroque",'','',"Venetian Works of Defence between the 16th and 17th Centuries",0,['Amin']])
data_list.append([datetime.datetime(2018, 5, 20),64,"Duomo","Cremona","Italy","Renaissance",'Gothic','Romanesque',"",0,['Amin']])
data_list.append([datetime.datetime(2018, 5, 21),8,"Basilica","San Marino","San Marino","Classicist",'','',"San Marino",0,['Amin']])
data_list.append([datetime.datetime(2018, 5, 21),99,"Duomo","Milano","Italy","Gothic",'','',"",0,['Amin']])
data_list.append([datetime.datetime(2018, 5, 26),61,"Cathedral","Tarragona","Spain","Gothic",'Romanesque','',"",0,[]])
data_list.append([datetime.datetime(2018, 5, 27),2,"Cathedral","Barcelona","Spain","Gothic",'','',"",0,[]])
data_list.append([datetime.datetime(2018, 6, 3),10,"Cathedral","Edinburgh","United Kingdom","Gothic",'','',"Edinburgh",0,[]])
data_list.append([datetime.datetime(2018, 6, 4),24,"Cathedral","Glasgow","United Kingdom","Gothic",'','',"",0,['Artur','Heidrun']])
data_list.append([datetime.datetime(2018, 6, 4),26,"Minster","York","United Kingdom","Gothic",'','',"",0,['Artur','Heidrun']])
data_list.append([datetime.datetime(2018, 6, 5),99,"Minster","York","United Kingdom","Gothic",'','',"",0,['Artur','Heidrun']])
data_list.append([datetime.datetime(2018, 6, 5),42,"Cathedral","Durham","United Kingdom","Romanesque",'','',"Durham Castle and Cathedral",0,['Artur','Heidrun']])
data_list.append([datetime.datetime(2018, 6, 7),81,"Cathedral","Lincoln","United Kingdom","Gothic",'','',"",0,['Artur','Heidrun']])
data_list.append([datetime.datetime(2018, 6, 8),3,"Cathedral","Bangor","United Kingdom","Gothic",'','',"",0,[]])
data_list.append([datetime.datetime(2018, 6, 9),40,"Cathedral","Liverpool","United Kingdom","neo-Gothic",'','',"",0,['Artur','Heidrun']])
data_list.append([datetime.datetime(2018, 6, 9),20,"Metropolitan Cathedral","Liverpool","United Kingdom","Modern",'','',"",0,['Artur','Heidrun']])
data_list.append([datetime.datetime(2018, 6, 9),44,"Cathedral","Chester","United Kingdom","Gothic",'','',"",0,[]])
data_list.append([datetime.datetime(2018, 6, 10),38,"Cathedral","Manchester","United Kingdom","Gothic",'','',"",0,[]])
data_list.append([datetime.datetime(2018, 7, 15),4,"Myeong-dong Cathedral","Seoul","South Korea","neo-Gothic",'','',"",0,[]])
data_list.append([datetime.datetime(2018, 8, 5),17,"Cathedral","Chur","Switzerland","Romanesque",'Gothic','',"",1,[]])
data_list.append([datetime.datetime(2018, 8, 28),26,"Minster","Bern","Switzerland","Gothic",'','',"Bern",1,['Riju']])
data_list.append([datetime.datetime(2018, 9, 2),39,"Dom","Regensburg","Germany","Gothic",'','',"Regensburg",0,['Reyer','Chris Brainerd']])
data_list.append([datetime.datetime(2018, 9, 3),36,"Dom","Bamberg","Germany","Romanesque",'','',"Bamberg",0,['Reyer','Chris Brainerd']])
data_list.append([datetime.datetime(2018, 9, 4),14,"Dom","Wuerzburg","Germany","Modern",'Romanesque','',"",0,['Reyer','Chris Brainerd']])
data_list.append([datetime.datetime(2018, 9, 5),51,"Dom","Naumburg","Germany","Romanesque",'Gothic','',"Naumburg Cathedral",0,['Reyer','Chris Brainerd']])
data_list.append([datetime.datetime(2018, 9, 22),2,"Cathedral","Antwerp","Belgium","Gothic",'','',"Belfries of Belgium and France",0,[]])
data_list.append([datetime.datetime(2018, 9, 22),29,"Cathedral","Mechelen","Belgium","Gothic",'','',"Belfries of Belgium and France",0,[]])
data_list.append([datetime.datetime(2018, 9, 22),1,"Cathedral","Brussels","Belgium","Gothic",'','','',0,['Rachel']])
data_list.append([datetime.datetime(2018, 11, 17),49,"Cathedral","Arles","France","Romanesque",'','','Arles, Roman and Romanesque Monuments',0,['Santona']])
data_list.append([datetime.datetime(2018, 11, 18),29,"Cathedral","Marseille","France","neo-Byzantine",'','','',0,['Santona']])
data_list.append([datetime.datetime(2018, 11, 19),12,"Cathedral","Nimes","France","Romanesque",'','','',0,['Santona']])
data_list.append([datetime.datetime(2018, 11, 19),6,"Cathedral","Orange","France","Baroque",'Romanesque','','',0,['Santona']])
data_list.append([datetime.datetime(2018, 11, 25),80,"Minster","Freiburg","Germany","Gothic",'Romanesque','',"",1,['Santona','Riju']])
data_list.append([datetime.datetime(2018, 11, 25),12,"Minster","Basel","Switzerland","Romanesque",'Gothic','',"",1,['Santona','Riju']])
data_list.append([datetime.datetime(2018, 12, 8),35,"Cathedral","Dijon","France","Gothic",'Romanesque','',"Climats, Terroirs of Burgundy",1,['Santona','Graham','Yao-Yao','Chris Brainerd']])

# %%
data_list.append([datetime.datetime(2019, 3, 10),37,"Cathedral","Bari","Italy","Romanesque",'','',"",0,['Heidrun','Artur']])
data_list.append([datetime.datetime(2019, 3, 11),33,"Duomo","Matera","Italy","Baroque",'Romanesque','',"Matera",0,['Heidrun','Artur']])
data_list.append([datetime.datetime(2019, 3, 12),16,"Duomo di San Corrado","Molfetta","Italy","Romanesque",'','',"",0,['Heidrun','Artur']])
data_list.append([datetime.datetime(2019, 3, 12),8,"Kathedrale Santa Maria Assunta","Molfetta","Italy","Baroque",'','',"",0,['Heidrun','Artur']])
data_list.append([datetime.datetime(2019, 3, 12),80,"Kathedrale","Bitonto","Italy","Romanesque",'','',"",0,['Heidrun','Artur']])
data_list.append([datetime.datetime(2019, 3, 12),27,"Kathedrale","Trani","Italy","Romanesque",'','',"",0,['Heidrun','Artur']])
data_list.append([datetime.datetime(2019, 3, 13),56,"Duomo","Lecce","Italy","Baroque",'','',"",0,['Heidrun','Artur']])
data_list.append([datetime.datetime(2019, 3, 15),18,"Duomo","Naples","Italy","Baroque",'Gothic','',"Naples",0,['Artur','Heidrun']])
data_list.append([datetime.datetime(2019, 3, 16),19,"Duomo","Benevento","Italy","Modern",'Romanesque','',"",0,['Artur','Heidrun']])
data_list.append([datetime.datetime(2019, 3, 17),78,"Duomo","Naples","Italy","Baroque",'Gothic','',"Naples",0,['Artur','Heidrun']])
data_list.append([datetime.datetime(2019, 3, 19),20,"Shrine of the Virgin of the Rosary of Pompei","Pompei","Italy","neo-Baroque",'','',"",0,['Artur','Heidrun']])
data_list.append([datetime.datetime(2019, 3, 20),95,"Duomo","Amalfi","Italy","Baroque",'Romanesque','Gothic',"Amalfi Coast",0,['Artur','Heidrun']])
data_list.append([datetime.datetime(2019, 4, 13),62,"Cathedral","Peterborough","United Kingdom","Gothic",'Romanesque','',"",0,[]])
data_list.append([datetime.datetime(2019, 4, 13),77,"Cathedral","Ely","United Kingdom","Gothic",'','',"",0,[]])
data_list.append([datetime.datetime(2019, 4, 19),27,"Cathedral","Poitiers","France","Gothic",'','',"",0,['Riju','Chris Brainerd']])
data_list.append([datetime.datetime(2019, 4, 20),9,"Notre-Dame","Paris","France","Gothic",'','',"Paris, Banks of the Seine",0,['Riju','Chris Brainerd']])
data_list.append([datetime.datetime(2019, 4, 21),195,"Cathedral","Bourges","France","Gothic",'','',"Bourges Cathedral",0,[]])
data_list.append([datetime.datetime(2019, 5, 26),13,"Cathedral","Vaduz","Liechtenstein","neo-Gothic",'','',"",0,['Riju']])
data_list.append([datetime.datetime(2019, 5, 31),27,"Corvey Monastery","Hoexter","Germany","Karolingian",'Baroque','Gothic',"Corvey",0,['Grace']])
data_list.append([datetime.datetime(2019, 5, 31),36,"Dom","Hildesheimm","Germany","Romanesque",'','',"St Mary's Cathedral and St Michael's Church at Hildesheim",0,['Grace']])
data_list.append([datetime.datetime(2019, 5, 31),5,"Dom","Braunschweig","Germany","Romanesque",'Gothic','',"",0,['Grace']])
data_list.append([datetime.datetime(2019, 6, 1),41,"Dom","Bremen","Germany","Romanesque",'Gothic','neo-Romanesque',"",0,['Grace']])
data_list.append([datetime.datetime(2019, 9, 22),1,"Notre-Dame","Paris","France","Gothic",'','',"Paris, Banks of the Seine",0,['Sam','Michael','Nhi','Vivan']])
data_list.append([datetime.datetime(2019, 12, 30),5,"Hofkirche","Dresden","Germany","Baroque",'','',"",0,['Artur']])
data_list.append([datetime.datetime(2019, 12, 31),17,"Hofkirche","Dresden","Germany","Baroque",'','',"",0,['Artur']])
#2020
data_list.append([datetime.datetime(2020, 1, 1),14,"Cathedral","Swidnica","Poland","Gothic",'Baroque','',"",0,['Artur']])
data_list.append([datetime.datetime(2020, 1, 1),43,"Cathedral","Krakow","Poland","Baroque",'Gothic','Renaissance',"Krakow",0,["Artur"]])
data_list.append([datetime.datetime(2020, 1, 1),89,"Dom","Wroclaw","Poland","Gothic",'Baroque','',"",0,["Artur"]])
data_list.append([datetime.datetime(2020, 2, 8),43,"Cathedral","St Gallen","Switzerland","Baroque",'Classicist','',"Abbey of St Gall",1,['Vivan','Dylan','Grace','Sam']])
data_list.append([datetime.datetime(2020, 2, 8),46,"Minster","Konstanz","Germany","Gothic",'Classicist','neo-Gothic',"",1,['Vivan','Dylan','Grace','Sam']])
data_list.append([datetime.datetime(2020, 2, 20),97,"Duomo","Orvieto","Italy","Gothic",'Baroque','',"",0,[]])
data_list.append([datetime.datetime(2020, 2, 21),4,"Duomo","Urbino","Italy","Renaissance",'','',"Urbino",0,[]])
data_list.append([datetime.datetime(2020, 2, 21),5,"Duomo","Pesaro","Italy","Classicist",'','',"",0,[]])
data_list.append([datetime.datetime(2020, 2, 22),92,"Duomo","Anagni","Italy","Romanesque",'','',"",0,[]])
data_list.append([datetime.datetime(2020, 2, 23),2,"Duomo","Terni","Italy","Baroque",'','',"",0,[]])
data_list.append([datetime.datetime(2020, 2, 24),18,"Duomo","Pienza","Italy","Renaissance",'','',"Pienza",0,[]])
data_list.append([datetime.datetime(2020, 2, 25),216,"Duomo","Siena","Italy","Gothic",'','',"Siena",0,[]])
data_list.append([datetime.datetime(2020, 2, 26),79,"Duomo","Florence","Italy","Renaissance",'Gothic','',"Florence",0,[]])
data_list.append([datetime.datetime(2020, 2, 27),66,"San Giovanni in Laterano","Rome","Vatican","Baroque",'','',"Rome",0,["Bryan"]])
data_list.append([datetime.datetime(2020, 2, 29),4,"Military Cathedral Santa Caterina da Siena in Magnanapoli","Rome","Italy","Baroque",'','',"Rome",0,["Bryan"]])
data_list.append([datetime.datetime(2020, 3, 1),1,"Duomo","Tivoli","Italy","Baroque",'','',"",0,['Bryan']])
data_list.append([datetime.datetime(2020, 6, 20),74,"Minster","Strasbourg","France","Gothic",'Romanesque','',"Strasbourg",1,['Artur']])

# %%
data_list.append([datetime.datetime(2021, 2, 27),35,"Minster","Freiburg","Germany","Gothic",'Romanesque','',"",1,['Artur']])
data_list.append([datetime.datetime(2021, 3, 6),45,"Minster","Konstanz","Germany","Gothic",'Classicist','neo-Gothic',"",1,['Artur']])
data_list.append([datetime.datetime(2021, 5, 4),79,"Stephansdom","Vienna","Austria","Gothic",'Baroque','',"Vienna",1,[]])
data_list.append([datetime.datetime(2021, 5, 6),8,"Stephansdom","Vienna","Austria","Gothic",'Baroque','',"Vienna",1,[]])
data_list.append([datetime.datetime(2021, 5, 8),1,"Stephansdom","Vienna","Austria","Gothic",'Baroque','',"Vienna",1,[]])
data_list.append([datetime.datetime(2021, 5, 12),1,"Stephansdom","Vienna","Austria","Gothic",'Baroque','',"Vienna",1,[]])
data_list.append([datetime.datetime(2021, 5, 22),62,"Dom","Salzburg","Austria","Baroque",'','',"Salzburg",1,[]])
data_list.append([datetime.datetime(2021, 5, 23),3,"Stephansdom","Vienna","Austria","Gothic",'Baroque','',"Vienna",1,[]])
data_list.append([datetime.datetime(2021, 5, 28),18,"Stephansdom","Vienna","Austria","Gothic",'Baroque','',"Vienna",1,['Bob']])
data_list.append([datetime.datetime(2021, 6, 12),34,"Dom","St Poelten","Austria","Baroque",'','',"",1,[]])
data_list.append([datetime.datetime(2021, 6, 13),7,"Georgskathedrale","Wiener Neustadt","Austria","Gothic",'Romanesque','Baroque',"",1,[]])
data_list.append([datetime.datetime(2021, 6, 13),20,"Dom","Wiener Neustadt","Austria","Gothic",'Romanesque','Baroque',"",1,[]])
data_list.append([datetime.datetime(2021, 6, 26),1,"Alter Dom","Linz","Austria","Baroque",'','',"",1,[]])
data_list.append([datetime.datetime(2021, 6, 26),9,"Dom","Linz","Austria","neo-Gothic",'','',"",1,[]])
data_list.append([datetime.datetime(2021, 7, 2),17,"Stephansdom","Vienna","Austria","Gothic",'Baroque','',"Vienna",1,[]])
data_list.append([datetime.datetime(2021, 7, 4),10,"Stephansdom","Vienna","Austria","Gothic",'Baroque','',"Vienna",1,[]])
data_list.append([datetime.datetime(2021, 7, 17),20,"Dom","Klagenfurt","Austria","Baroque",'','',"",1,[]])
data_list.append([datetime.datetime(2021, 7, 23),20,"Dom","Innsbruck","Austria","Baroque",'','',"",0,[]])
data_list.append([datetime.datetime(2021, 7, 23),1,"Dom","Innsbruck","Austria","Baroque",'','',"",0,['Sam','Grace','Janina']])
data_list.append([datetime.datetime(2021, 7, 24),3,"Dom","Innsbruck","Austria","Baroque",'','',"",0,['Sam','Grace','Janina']])
data_list.append([datetime.datetime(2021, 8, 5),7,"Stephansdom","Vienna","Austria","Gothic",'Baroque','',"Vienna",1,['Namrata']])
data_list.append([datetime.datetime(2021, 8, 27),1,"Cathedral","Prague","Czech","Gothic",'','',"Prague",0,[]])
data_list.append([datetime.datetime(2021, 8, 28),91,"Cathedral","Prague","Czech","Gothic",'','',"Prague",0,[]])
data_list.append([datetime.datetime(2021, 8, 29),1,"Cathedral","Prague","Czech","Gothic",'','',"Prague",0,[]])
data_list.append([datetime.datetime(2021, 9, 2),2,"Dom","Passau","Germany","Baroque",'','',"",0,[]])
data_list.append([datetime.datetime(2021, 9, 3),21,"Dom","Bamberg","Germany","Romanesque",'','',"Bamberg",0,['Hannsjoerg']])
data_list.append([datetime.datetime(2021, 9, 4),16,"Dom","Wuerzburg","Germany","Modern",'Romanesque','',"",0,['Hannsjoerg','Marion','Julius','Felicitas','Franziska','Artur','Jan-Marc']])
data_list.append([datetime.datetime(2021, 9, 5),24,"Dom","Regensburg","Germany","Gothic",'','',"Regensburg",0,[]])
data_list.append([datetime.datetime(2021, 9, 5),30,"Dom","Passau","Germany","Baroque",'','',"",0,[]])
data_list.append([datetime.datetime(2021, 9, 25),10,"Dom","Salzburg","Austria","Baroque",'','',"Salzburg",1,['Vivan','Michael']])
data_list.append([datetime.datetime(2021, 10, 24),58,"Dom","Trier","Germany","Romanesque",'Baroque','',"Roman Monuments, Cathedral of St Peter and Church of Our Lady",0,[]])
data_list.append([datetime.datetime(2021, 10, 24),21,"Cathedral","Luxemburg","Luxemburg","Modern",'neo-Gothic','Baroque',"City of Luxembourg: its Old Quarters and Fortifications",0,[]])
data_list.append([datetime.datetime(2021, 10, 25),79,"Cathedral","Metz","France","Gothic",'','',"",0,[]])
data_list.append([datetime.datetime(2021, 10, 25),22,"Cathedral","Nancy","France","Baroque",'','',"",0,[]])
data_list.append([datetime.datetime(2021, 10, 26),5,"Cathedrale St Louis des Invalides","Paris","France","Baroque",'','',"Paris, Banks of the Seine",0,[]])
data_list.append([datetime.datetime(2021, 10, 27),92,"Basilique","Saint Denis","France","Gothic",'','',"",0,[]])
data_list.append([datetime.datetime(2021, 10, 27),1,"Notre Dame","Paris","France","Gothic",'','',"Paris, Banks of the Seine",0,[]])
data_list.append([datetime.datetime(2021, 10, 28),56,"Cathedral","Tournai","Belgium","Romanesque",'Gothic','',"Tournai Cathedral",0,[]])
data_list.append([datetime.datetime(2021, 10, 28),4,"Cathedral","Arras","France","Baroque",'','',"",0,[]])
data_list.append([datetime.datetime(2021, 10, 29),114,"Dom","Aachen","Germany","Karolingian",'Gothic','',"Aachen Cathedral",0,[]])
data_list.append([datetime.datetime(2021, 10, 29),171,"Dom","Cologne","Germany","Gothic",'neo-Gothic','',"Cologne Cathedral",0,[]])
data_list.append([datetime.datetime(2021, 10, 30),70,"Dom","Speyer","Germany","Romanesque",'','',"Speyer Cathedral",0,[]])
data_list.append([datetime.datetime(2021, 10, 30),44,"Dom","Worms","Germany","Romanesque",'Baroque','',"",0,[]])
data_list.append([datetime.datetime(2021, 10, 31),14,"Minster","Essen","Germany","Gothic",'Romanesque','',"",0,[]])
data_list.append([datetime.datetime(2021, 12, 12),8,"Stephansdom","Vienna","Austria","Gothic",'Baroque','',"Vienna",1,[]])

# %%
data_list.append([datetime.datetime(2022, 1, 30),3,"Stephansdom","Vienna","Austria","Gothic",'Baroque','',"Vienna",1,[]])
data_list.append([datetime.datetime(2022, 3, 19),9,"Cathedral","Malaga","Spain","Renaissance",'Baroque','',"",0,[]])
data_list.append([datetime.datetime(2022, 3, 20),107,"Cathedral","Malaga","Spain","Renaissance",'Baroque','',"",0,[]])
data_list.append([datetime.datetime(2022, 3, 21),5,"Cathedral","Granada","Spain","Renaissance",'','',"",0,[]])
data_list.append([datetime.datetime(2022, 3, 22),56,"Cathedral","Granada","Spain","Renaissance",'','',"",0,[]])
data_list.append([datetime.datetime(2022, 3, 23),89,"Cathedral","Jaen","Spain","Renaissance",'','',"",0,[]])
data_list.append([datetime.datetime(2022, 3, 24),175,"Mezquita-Cathedral","Cordoba","Spain","Islamic",'Renaissance','',"Cordoba",0,[]])
data_list.append([datetime.datetime(2022, 3, 25),222,"Cathedral","Sevilla","Spain","Gothic",'','',"Cathedral, Alcazar and Archivo de Indias in Seville",0,[]])
data_list.append([datetime.datetime(2022, 3, 26),89,"Cathedral","Jaen","Spain","Renaissance",'','',"",0,[]])
data_list.append([datetime.datetime(2022, 3, 27),38,"Co-Cathedral","Caceres","Spain","Gothic",'','',"Caceres",0,[]])
data_list.append([datetime.datetime(2022, 3, 27),6,"Cathedral","Merida","Spain","Gothic",'','',"",0,[]])
data_list.append([datetime.datetime(2022, 3, 28),120,"Cathedral","Cuenca","Spain","Gothic",'','',"Cuenca",0,[]])
data_list.append([datetime.datetime(2022, 3, 28),51,"Almudena Cathedral","Madrid","Spain","neo-Gothic",'neo-Baroque','',"",0,[]])
data_list.append([datetime.datetime(2022, 3, 28),6,"Military Cathedral","Madrid","Spain","Baroque",'','',"",0,[]])
data_list.append([datetime.datetime(2022, 3, 29),1,"Almudena Cathedral","Madrid","Spain","neo-Gothic",'neo-Baroque','',"",0,[]])
data_list.append([datetime.datetime(2022, 3, 29),5,"Cathedral","Alcala de Henares","Spain","Gothic",'','',"",0,[]])
data_list.append([datetime.datetime(2022, 3, 30),240,"Cathedral","Toledo","Spain","Gothic",'Baroque','',"Toledo",0,[]])
data_list.append([datetime.datetime(2022, 3, 31),111,"Cathedral","Leon","Spain","Gothic",'','',"Routes of Santiago de Compostela",0,[]])
data_list.append([datetime.datetime(2022, 3, 31),74,"Cathedral","Astorga","Spain","Gothic",'Renaissance','',"Routes of Santiago de Compostela",0,[]])
data_list.append([datetime.datetime(2022, 4, 1),85,"Cathedral","Segovia","Spain","Gothic",'','',"Segovia",0,[]])
data_list.append([datetime.datetime(2022, 4, 3),2,"Almudena Cathedral","Madrid","Spain","neo-Gothic",'neo-Baroque','',"",0,[]])
data_list.append([datetime.datetime(2022, 4, 8),2,"Stephansdom","Vienna","Austria","Gothic",'Baroque','',"Vienna",1,[]])
data_list.append([datetime.datetime(2022, 5, 15),11,"Cathedral","Gyor","Hungary","neo-Gothic",'Baroque','',"",1,[]])
data_list.append([datetime.datetime(2022, 5, 25),22,"Stephen's Basilica","Budapest","Hungary","Classicist",'','',"",0,["Chris Martin"]])
data_list.append([datetime.datetime(2022, 6, 4),21,"Martinsdom","Bratislava","Slovakia","Gothic",'','',"",1,['Artur']])
data_list.append([datetime.datetime(2022, 6, 11),40,"Frauenkirche","Munich","Germany","Gothic",'','',"",1,[]])
data_list.append([datetime.datetime(2022, 6, 11),69,"Dom","Augsburg","Germany","Romanesque",'Gothic','',"",1,[]])
data_list.append([datetime.datetime(2022, 7, 16),18,"Wenzelsdom","Olomouc","Czech","Gothic",'neo-Gothic','',"",1,[]])
data_list.append([datetime.datetime(2022,7,29),98,"Duomo","Modena","Italy","Romanesque",'','',"",0,[]])
data_list.append([datetime.datetime(2022,7,29),22,"Duomo","Milano","Italy","Gothic",'','',"",0,['Riju']])
data_list.append([datetime.datetime(2022,7,30),103,"Duomo","Milano","Italy","Gothic",'','',"",0,['Riju']])
data_list.append([datetime.datetime(2022,8,2),14,"Duomo","Ravello","Italy","Romanesque",'','',"Amalfi Coast",0,['Riju']])
data_list.append([datetime.datetime(2022,8,2),44,"Duomo","Amalfi","Italy","Baroque",'Romanesque','Gothic',"Amalfi Coast",0,['Riju']])
data_list.append([datetime.datetime(2022,8,3),2,"Duomo","Naples","Italy","Baroque",'Gothic','',"Naples",0,[]])
data_list.append([datetime.datetime(2022,8,3),33,"Duomo","Naples","Italy","Baroque",'Gothic','',"Naples",0,['Riju']])
data_list.append([datetime.datetime(2022,8,4),110,"Duomo","Pisa","Italy","Romanesque",'Baroque','',"Pisa",0,[]])
data_list.append([datetime.datetime(2022,8,4),107,"Duomo","Siena","Italy","Gothic",'','',"Siena",0,[]])
data_list.append([datetime.datetime(2022,8,4),22,"Duomo","Florence","Italy","Renaissance",'Gothic','',"Florence",0,[]])
data_list.append([datetime.datetime(2022,8,5),72,"Duomo","Florence","Italy","Renaissance",'Gothic','',"Florence",0,[]])
data_list.append([datetime.datetime(2022, 8, 5),6,"St Mark's Cathedral","Venice","Italy","Byzantine",'','',"Venice",0,[]])
data_list.append([datetime.datetime(2022, 8, 6),213,"St Mark's Cathedral","Venice","Italy","Byzantine",'','',"Venice",0,[]])
data_list.append([datetime.datetime(2022, 8, 6),10,"San Pietro di Castello","Venice","Italy","Renaissance",'Baroque','',"Venice",0,[]])
data_list.append([datetime.datetime(2022, 8, 7),36,"Dom","Parma","Italy","Baroque",'Romanesque','',"",0,[]])
data_list.append([datetime.datetime(2022,8,21),16,"Cathedral","Brno","Czech","Gothic",'Baroque','neo-Gothic',"",1,[]])
data_list.append([datetime.datetime(2022, 8, 26),37,"Dom","Riga","Latvia","Gothic",'neo-Gothic','Baroque',"",0,['Artur']])
data_list.append([datetime.datetime(2022, 8, 26),2,"Jacob's Cathedral","Riga","Latvia","Gothic",'','',"",0,['Artur']])
data_list.append([datetime.datetime(2022, 8, 26),7,"Nativity Cathedral","Riga","Latvia","Russian Revival",'','',"",0,['Artur']])
data_list.append([datetime.datetime(2022, 8, 27),3,"Orthodox Cathedral","Vilnius","Lithuania","Russian Revival",'','',"",0,['Artur']])
data_list.append([datetime.datetime(2022, 8, 27),29,"Cathedral","Vilnius","Lithuania","Classicist",'Baroque','',"",0,['Artur']])
data_list.append([datetime.datetime(2022,9,10),1,"Cathedral","Brno","Czech","Gothic",'Baroque','neo-Gothic',"",1,[]])
data_list.append([datetime.datetime(2022,9,30),2,"Stephansdom","Vienna","Austria","Gothic",'Baroque','',"Vienna",1,[]])
data_list.append([datetime.datetime(2022,10,9),10,"Dom","Linz","Austria","neo-Gothic",'','',"",1,[]])
data_list.append([datetime.datetime(2022,10,9),9,"Alter Dom","Linz","Austria","Baroque",'','',"",1,[]])
data_list.append([datetime.datetime(2022,11,3),41,"St John's Cathedral","Warsaw","Poland","Gothic",'Modern','',"Warsaw",0,[]])
data_list.append([datetime.datetime(2022,11,3),11,"Military Cathedral","Warsaw","Poland","Classicist",'Modern','',"Warsaw",0,[]])
data_list.append([datetime.datetime(2022,11,3),2,"St Florians's Cathedral","Warsaw","Poland","neo-Gothic",'','',"",0,[]])
data_list.append([datetime.datetime(2022,11,4),34,"Cathedral","Torun","Poland","Gothic",'Baroque','',"Torun",0,[]])
data_list.append([datetime.datetime(2022,11,5),51,"Marienkirche","Danzig","Poland","Gothic",'','',"",0,[]])
data_list.append([datetime.datetime(2022,11,13),4,"Stephansdom","Vienna","Austria","Gothic",'Baroque','',"Vienna",1,[]])
data_list.append([datetime.datetime(2022,12,2),175,"Dom","Cologne","Germany","Gothic",'neo-Gothic','',"Cologne Cathedral",0,['Artur']])
data_list.append([datetime.datetime(2022,12,3),34,"Dom","Muenster","Germany","Gothic",'Romanesque','Baroque',"",0,['Artur']])
data_list.append([datetime.datetime(2022,12,10),6,"Stephansdom","Vienna","Austria","Gothic",'Baroque','',"Vienna",1,[]])
data_list.append([datetime.datetime(2022,12,17),66,"Stephansdom","Vienna","Austria","Gothic",'Baroque','',"Vienna",1,[]])
data_list.append([datetime.datetime(2022,12,27),45,"Minster","Bern","Switzerland","Gothic",'','',"Bern",1,['Artur']])
data_list.append([datetime.datetime(2022,12,29),12,"Dom","Arlesheim","Switzerland","Baroque",'','',"",1,['Artur']])
data_list.append([datetime.datetime(2022,12,29),18,"Minster","Basel","Switzerland","Romanesque",'Gothic','',"",1,['Artur']])

# %%
data_list.append([datetime.datetime(2023,1,7),44,"Stephansdom","Vienna","Austria","Gothic",'Baroque','',"Vienna",1,[]])
data_list.append([datetime.datetime(2023,1,14),2,"Stephansdom","Vienna","Austria","Gothic",'Baroque','',"Vienna",1,[]])
data_list.append([datetime.datetime(2023,1,22),2,"Stephansdom","Vienna","Austria","Gothic",'Baroque','',"Vienna",1,[]])
data_list.append([datetime.datetime(2023, 3, 4),55,"Se Catedral","Lisbon","Portugal","Romanesque",'Baroque','',"",0,[]])
data_list.append([datetime.datetime(2023, 3, 8),3,"Se Catedral","Lisbon","Portugal","Romanesque",'Baroque','',"",0,[]])
data_list.append([datetime.datetime(2023, 3, 10),57,"Se Catedral","Porto","Portugal","Romanesque",'Baroque','',"Porto",0,['Artur']])
data_list.append([datetime.datetime(2023, 3, 11),58,"Se Catedral","Braga","Portugal","Romanesque",'Baroque','',"",0,['Artur']])
data_list.append([datetime.datetime(2023, 3, 10),4,"Se Catedral","Porto","Portugal","Romanesque",'Baroque','',"Porto",0,['Artur']])
data_list.append([datetime.datetime(2023, 3, 13),127,"Cathedral","Santiago de Compostela","Spain","Romanesque",'Baroque','',"Santiago de Compostela",0,['Artur']])
data_list.append([datetime.datetime(2023, 3, 14),45,"Old Cathedral","Coimbra","Portugal","Romanesque",'Gothic','',"University of Coimbra – Alta and Sofia",0,[]])
data_list.append([datetime.datetime(2023, 3, 14),12,"New Cathedral","Coimbra","Portugal","Classicist",'','',"University of Coimbra – Alta and Sofia",0,[]])
data_list.append([datetime.datetime(2023, 3, 15),4,"Se Catedral","Lisbon","Portugal","Romanesque",'Baroque','',"",0,[]])
data_list.append([datetime.datetime(2023, 3, 16),9,"Catedral","Leiria","Portugal","Renaissance",'','',"",0,[]])
data_list.append([datetime.datetime(2023, 3, 17),63,"Catedral","Evora","Portugal","Gothic",'','',"Historic Centre of Evora",0,[]])
data_list.append([datetime.datetime(2023, 3, 17),4,"Catedral","Elvas","Portugal","Renaissance",'','',"Garrison Border Town of Elvas and its Fortifications",0,[]])
data_list.append([datetime.datetime(2023, 4, 28),13,"Cathedral","Katowice","Poland","Modernist",'','',"",0,[]])
data_list.append([datetime.datetime(2023, 4, 29),36,"Cathedral","Krakow","Poland","Baroque",'Gothic','Renaissance',"Krakow",0,[]])
data_list.append([datetime.datetime(2023, 6, 3),4,"Cathedral","Stockholm","Sweden","Gothic",'Baroque','',"",0,[]])
data_list.append([datetime.datetime(2023, 6, 4),3,"Cathedral","Stockholm","Sweden","Gothic",'Baroque','',"",0,[]])
data_list.append([datetime.datetime(2023, 6, 4),72,"Dom","Uppsala","Sweden","Gothic",'neo-Gothic','Baroque',"",0,[]])
data_list.append([datetime.datetime(2023, 6, 23),3,"Alexander Nevsky Cathedral","Sofia","Bulgaria","neo-Byzantine",'','',"",0,[]])
data_list.append([datetime.datetime(2023, 6, 24),25,"Alexander Nevsky Cathedral","Sofia","Bulgaria","neo-Byzantine",'','',"",0,[]])
data_list.append([datetime.datetime(2023, 6, 24),1,"Josefskathedrale","Sofia","Bulgaria","Modern",'','',"",0,[]])
data_list.append([datetime.datetime(2023, 6, 25),4,"Ludwigskathedrale","Plovdiv","Bulgaria","Classicist",'','',"",0,[]])
data_list.append([datetime.datetime(2023, 6, 25),31,"Bishop's Basilica of Philippopolis","Plovdiv","Bulgaria","Early Christian",'','',"",0,[]])
data_list.append([datetime.datetime(2023, 6, 25),2,"Muttergotteskathedrale","Plovdiv","Bulgaria","early christian",'','',"",0,[]])
data_list.append([datetime.datetime(2023, 6, 25),39,"Marienkathedrale","Bachkovo","Bulgaria","Byzantine",'neo-Byzantine','',"",0,[]])
data_list.append([datetime.datetime(2023, 7, 22),9,"Cathedral","Copenhagen","Denmark","Classicist",'','',"",0,[]])
data_list.append([datetime.datetime(2023, 7, 22),3,"Ansgardomkirche","Copenhagen","Denmark","Classicist",'','',"",0,[]])
data_list.append([datetime.datetime(2023, 7, 23),17,"Olavsdomkirche","Helsingor","Denmark","Gothic",'','',"",0,[]])
data_list.append([datetime.datetime(2023, 7, 23),47,"Dom","Lund","Sweden","Romanesque",'Gothic','',"",0,[]])
data_list.append([datetime.datetime(2023, 8, 12),56,"Dom","Erfurt","Germany","Gothic",'Baroque','',"",0,[]])
data_list.append([datetime.datetime(2023, 8, 12),98,"Dom","Naumburg","Germany","Romanesque",'Gothic','',"Naumburg Cathedral",0,[]])
data_list.append([datetime.datetime(2023, 8, 14),44,"Dom","Limburg","Germany","Romanesque",'','',"",0,[]])
data_list.append([datetime.datetime(2023, 8, 26),2,"Cathedral","Spisska Kapitula","Slovakia","Gothic",'Romanesque','',"Levoca, Spissky Hrad and the Associated Cultural Monuments",0,['Artur']])
data_list.append([datetime.datetime(2023, 8, 27),2,"Cathedral","Spisska Kapitula","Slovakia","Gothic",'Romanesque','',"Levoca, Spissky Hrad and the Associated Cultural Monuments",0,['Artur']])
data_list.append([datetime.datetime(2023, 8, 28),39,"Cathedral","Spisska Kapitula","Slovakia","Gothic",'Romanesque','',"Levoca, Spissky Hrad and the Associated Cultural Monuments",0,['Artur']])
data_list.append([datetime.datetime(2023, 8, 29),43,"Cathedral","Kosice","Slovakia","Gothic",'','',"",0,['Artur']])
data_list.append([datetime.datetime(2023, 8, 31),6,"Co-Cathedral","Nyiregyhaza","Hungary","neo-Romanesque",'','',"",0,['Artur']])
data_list.append([datetime.datetime(2023, 9, 1),14,"Cathedral","Esztergom","Hungary","Classicist",'','',"",0,['Artur']])
data_list.append([datetime.datetime(2023, 9, 2),42,"Cathedral","Pecs","Hungary","neo-Romanesque",'','',"",0,['Artur']])
data_list.append([datetime.datetime(2023, 9, 3),42,"Dom","Graz","Austria","Gothic",'Baroque',"","Graz",0,['Artur']])
data_list.append([datetime.datetime(2023, 10, 26),33,"Cathedral","Visby","Sweden","Gothic",'Romanesque',"","Hanseatic Town of Visby",0,[]])
data_list.append([datetime.datetime(2023, 10, 28),32,"Cathedral","Stockholm","Sweden","Gothic",'Baroque','',"",0,['Rebeca',"Elias"]])
data_list.append([datetime.datetime(2023, 10, 29),3,"Eric's Cathedral","Stockholm","Sweden","neo-Romanesque",'Modern',"","",0,[]])
data_list.append([datetime.datetime(2023, 10, 30),3,"Cathedral","Kalmar","Sweden","Baroque",'',"","",0,[]])
data_list.append([datetime.datetime(2023, 10, 31),16,"Cathedral","Kalmar","Sweden","Baroque",'',"","",0,[]])
data_list.append([datetime.datetime(2023, 11, 11),23,"Cathedral","Nitra","Slovakia","Baroque",'Gothic',"","",0,[]])
data_list.append([datetime.datetime(2023, 11, 11),11,"Cathedral","Trnava","Slovakia","Baroque",'',"","",0,[]])
data_list.append([datetime.datetime(2023, 12, 9),71,"Cathedral","Lyon","France","Gothic",'','',"Lyon",0,['Bing','Sasha']])
data_list.append([datetime.datetime(2023, 12, 10),14,"Cathedral","Geneva","Switzerland","Gothic",'Romanesque','neo-Gothic',"",0,['Eleni','Kostas']])
data_list.append([datetime.datetime(2023, 12, 26),34,"Minster","Konstanz","Germany","Gothic",'Classicist','neo-Gothic',"",1,['Jennet','Hannsjoerg','Artur']])

# %%
data_list.append([datetime.datetime(2024, 1, 1),3,"Cathedral","Prague","Czech","Gothic",'','',"Prague",0,[]])
data_list.append([datetime.datetime(2024, 1, 1),3,"Cyril-and-Methodius-Cathedral","Prague","Czech","Baroque",'','',"Prague",0,[]])
data_list.append([datetime.datetime(2024, 1, 25),48,"Duomo","Trento","Italy","Romanesque",'Gothic','Baroque',"",0,[]])
data_list.append([datetime.datetime(2024, 1, 25),60,"Dom","Brixen","Italy","Baroque",'Gothic','',"",0,[]])
data_list.append([datetime.datetime(2024, 1, 25),6,"Dom","Bozen","Italy","Gothic",'Baroque','',"",0,[]])
data_list.append([datetime.datetime(2024, 1, 26),8,"Duomo","Padova","Italy","Renaissance",'Baroque','',"",0,['']])
data_list.append([datetime.datetime(2024, 1, 27),48,"Duomo","Verona","Italy","Gothic",'Romanesque','',"",0,[]])
data_list.append([datetime.datetime(2024, 1, 28),15,"Dom","Bozen","Italy","Gothic",'Baroque','',"",0,[]])
data_list.append([datetime.datetime(2024, 2, 17),11,"Cathedral","Ferrara","Italy","Romanesque",'Baroque','',"Ferrara, City of the Renaissance, and its Po Delta",0,[]])
data_list.append([datetime.datetime(2024, 2, 18),29,"Duomo","Vicenza","Italy","Gothic",'Renaissance','',"City of Vicenza and the Palladian Villas of the Veneto",0,[]])
data_list.append([datetime.datetime(2024, 2, 19),14,"Duomo","Ravenna","Italy","Classicist",'Baroque','',"",0,['']])
data_list.append([datetime.datetime(2024, 2, 20),35,"St Mark's Cathedral","Venice","Italy","Byzantine",'','',"Venice",0,['']])
data_list.append([datetime.datetime(2024, 2, 20),41,"Basilika Santa Maria Assunta","Torcello","Italy","Romanesque",'Byzantine','',"Venice",0,['']])
data_list.append([datetime.datetime(2024, 3, 10),18,"Stephansdom","Vienna","Austria","Gothic",'Baroque','',"Vienna",1,[]])
data_list.append([datetime.datetime(2024, 3, 23),10,"Goesser Stiftskirche","Leoben","Austria","Gothic",'Baroque','',"",1,[]])
data_list.append([datetime.datetime(2024, 4, 4),29,"Sophia Cathedral","Ohrid","North Macedonia","Byzantine",'','',"",0,[]])
data_list.append([datetime.datetime(2024, 4, 5),4,"Clemens-of-Ohrid-Cathedral","Skopje","North Macedonia","neo-Byzantine",'','',"",0,[]])
data_list.append([datetime.datetime(2024, 4, 9),3,"Stephansdom","Vienna","Austria","Gothic",'Baroque','',"Vienna",1,[]])
data_list.append([datetime.datetime(2024, 5, 1),99,"Minster","York","United Kingdom","Gothic",'','',"",0,[]])
data_list.append([datetime.datetime(2024, 5, 1),158,"Cathedral","Durham","United Kingdom","Romanesque",'','',"Durham Castle and Cathedral",0,[]])
data_list.append([datetime.datetime(2024, 5, 2),151,"Westminster Abbey","London","United Kingdom","Gothic",'','',"Westminster",0,[]])
data_list.append([datetime.datetime(2024, 5, 2),70,"St Paul's Cathedral","London","United Kingdom","Baroque",'','',"",0,[]])
data_list.append([datetime.datetime(2024, 5, 2),175,"Cathedral","Canterbury","United Kingdom","Gothic",'','',"Canterbury Cathedral",0,[]])
data_list.append([datetime.datetime(2024, 5, 4),6,"St Paul's Cathedral","London","United Kingdom","Baroque",'','',"",0,[]])
data_list.append([datetime.datetime(2024, 5, 5),8,"Cathedral","Ely","United Kingdom","Gothic",'','',"",0,['Eric','May','Siyi']])
data_list.append([datetime.datetime(2024, 5, 9),7,"Cathedral","Ljubljana","Slovenia","Baroque",'','',"",0,[]])
data_list.append([datetime.datetime(2024, 5, 12),23,"Cathedral","Ljubljana","Slovenia","Baroque",'','',"",0,[]])
data_list.append([datetime.datetime(2024, 5, 18),1,"St Paul's Cathedral","Valletta","Malta","Classicist",'','',"City of Valletta",0,[]])
data_list.append([datetime.datetime(2024, 5, 20),6,"St Paul's Cathedral","Valletta","Malta","Classicist",'','',"City of Valletta",0,[]])
data_list.append([datetime.datetime(2024, 5, 20),108,"St John's Co-Cathedral","Valletta","Malta","Baroque",'','',"City of Valletta",0,[]])

# %%
df = pd.DataFrame(data_list,columns=['Date','Pictures', 'Church','Place', 'Country','Style 1','Style 2','Style 3','Unesco Site','Day Trip','Co-Travellers'])
df["Number of Co-Travellers"]=df["Co-Travellers"].str.len()
df.to_csv("../data/Cathedral_Photos.csv")
df
# Out:
#           Date  Pictures                  Church      Place         Country  \
# 0   1996-08-25         1   Westminster Cathedral     London  United Kingdom
# 1   1996-08-26         2   Westminster Cathedral     London  United Kingdom
# 2   1996-08-26         1       Westminster Abbey     London  United Kingdom
# 3   1996-08-28         2     St Paul's Cathedral     London  United Kingdom
# 4   1996-08-28        13       Westminster Abbey     London  United Kingdom
# ..         ...       ...                     ...        ...             ...
# 603 2024-05-09         7               Cathedral  Ljubljana        Slovenia
# 604 2024-05-12        23               Cathedral  Ljubljana        Slovenia
# 605 2024-05-18         1     St Paul's Cathedral   Valletta           Malta
# 606 2024-05-20         6     St Paul's Cathedral   Valletta           Malta
# 607 2024-05-20       108  St John's Co-Cathedral   Valletta           Malta
#
# ...

# %%
df.groupby(['Church','Place','Country']).agg(Pictures=('Pictures','sum')).sort_values(by='Pictures',ascending=False).reset_index().head(50)
# Out:
#                       Church                   Place         Country  Pictures
# 0                        Dom                 Cologne         Germany       473
# 1                      Duomo                  Milano           Italy       449
# 2                      Duomo                   Siena           Italy       436
# 3                  Cathedral                  Toledo           Spain       363
# 4                Stephansdom                  Vienna         Austria       363
# 5                  Cathedral                 Sevilla           Spain       341
# 6         Mezquita-Cathedral                 Cordoba           Spain       328
# 7        St Mark's Cathedral                  Venice           Italy       327
# 8                  Cathedral                  Geneva     Switzerland       323
# 9          Westminster Abbey                  London  United Kingdom       314
# 10                 Cathedral              Canterbury  United Kingdom       265
# ...

# %%
df.groupby(['Country']).agg(Pictures=('Pictures','sum'),No_Cathedrals=("Place",'nunique')).sort_values(by='Pictures',ascending=False).reset_index().head(30)
# Out:
#             Country  Pictures  No_Cathedrals
# 0             Italy      3665             57
# 1             Spain      3393             28
# 2           Germany      2444             29
# 3            France      1964             30
# 4    United Kingdom      1776             17
# 5       Switzerland       911             11
# 6           Austria       720             10
# 7          Portugal       388              8
# 8            Poland       385              7
# 9           Belgium       264              6
# 10           Sweden       232              5
# 11            Czech       217              3
# 12           Russia       179              4
# 13          Croatia       173              3
# 14          Vatican       164              1
# 15         Slovakia       158              5
# 16          Denmark       147              3
# 17          Hungary       137              5
# 18              USA       125              5
# 19            Malta       115              1
# ...

# %%
df[df['Style 1']==""]
# Out:
# Empty DataFrame
# Columns: [Date, Pictures, Church, Place, Country, Style 1, Style 2, Style 3, Unesco Site, Day Trip, Co-Travellers, Number of Co-Travellers]
# Index: []

# %%
df.groupby(['Style 1']).agg(Pictures=('Pictures','sum')).sort_values(by='Pictures',ascending=False).reset_index().head(30)
# Out:
#             Style 1  Pictures
# 0            Gothic      9651
# 1        Romanesque      2973
# 2           Baroque      2064
# 3       Renaissance       963
# 4         Byzantine       597
# 5        neo-Gothic       398
# 6        Classicist       380
# 7           Islamic       328
# 8       Karolingian       179
# 9     neo-Byzantine       166
# 10   Russian Gothic       107
# 11           Modern       103
# 12            Roman        96
# 13   neo-Romanesque        71
# 14      neo-Baroque        69
# 15  Early Christian        31
# 16  Russian Revival        20
# 17        Modernist        13
# 18  neo-Renaissance         4
# 19  early christian         2

# %%
import re
#re.sub(r'\W+', '', your_string)

cotravellers=set()

#if I consider unique() just alone, then it would split everything directly into 

for expr in df['Co-Travellers'].values:
    for w in expr:
        name=re.sub(r"[^\w-]", ' ', w).strip()
        if name!="":
            cotravellers.add(name)
print(cotravellers)
# Out:
# {'Zhiling', 'Chris Martin', 'Jingtuan', 'Evan', 'Rachel', 'Anne', 'Jennet', 'Dylan', 'Chris Lee', 'Riju', 'Dooyeon', 'Anne-Kathrin', 'Hannsjoerg', 'Grace', 'Devin', 'Siyi', 'Viola', 'Sam', 'Bob', 'Rebeca', 'Eleni', 'Stephan', 'Christine', 'AJ', 'Gianrico', 'Indara', 'Vivan', 'Heidrun', 'Bing', 'Susanne', 'Felicitas', 'Michael', 'Jan-Marc', 'Franziska', 'Julius', 'Aaron', 'Santona', 'Andrew', 'Nhi', 'Bryan', 'Nate', 'Janina', 'Marion', 'Sigi', 'Artur', 'Manuel', 'Chris Clarke', 'Reyer', 'May', 'Ina', 'Can', 'Amin', 'Nick', 'Kostas', 'Graham', 'Kennedy', 'Eric', 'Namrata', 'Elias', 'Laser', 'Sasha', 'Chris Brainerd', 'Yao-Yao', 'Mohammed'}

# %%
print("total/multi",df["Pictures"].sum(),df.loc[(df['Day Trip']==0),"Pictures"].sum(),
         "seen on",df["Date"].nunique(),"dates")
min_x=df["Date"].min()-np.timedelta64(2,"M")
max_x=df["Date"].max()+np.timedelta64(2,"M")
fig, ax = plt.subplots(figsize=(17,5))
max_y=1.25*df.groupby(pd.Grouper(key="Date", freq="1D")).sum()["Pictures"].max()
df.groupby(pd.Grouper(key="Date", freq="1D")).sum()["Pictures"].plot(title="daily count of catedral pictures in trips",ylabel="picture count",xlim=(min_x,max_x),ylim=(0,max_y))
plt.show()
fig, ax = plt.subplots(figsize=(17,5))
max_y=1.25*df.groupby(pd.Grouper(key="Date", freq="1W")).sum()["Pictures"].max()
df.groupby(pd.Grouper(key="Date", freq="1W")).sum()["Pictures"].plot(title="weekly count of catedral pictures in trips",ylabel="picture count",xlim=(min_x,max_x),ylim=(0,max_y))
plt.show()
fig, ax = plt.subplots(figsize=(17,5))
max_y=1.25*df.groupby(pd.Grouper(key="Date", freq="1M")).sum()["Pictures"].max()
df.groupby(pd.Grouper(key="Date", freq="1M")).sum()["Pictures"].plot(title="monthly count of catedral pictures in trips",ylabel="picture count",xlim=(min_x,max_x),ylim=(0,max_y))
plt.show()
# Out:
# total/multi 18215 15853 seen on 456 dates
# /var/folders/8d/gvjspwlj4hq61gsmkn1p_h480000gn/T/ipykernel_6379/3266872550.py:6: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   max_y=1.25*df.groupby(pd.Grouper(key="Date", freq="1D")).sum()["Pictures"].max()
# /var/folders/8d/gvjspwlj4hq61gsmkn1p_h480000gn/T/ipykernel_6379/3266872550.py:7: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(pd.Grouper(key="Date", freq="1D")).sum()["Pictures"].plot(title="daily count of catedral pictures in trips",ylabel="picture count",xlim=(min_x,max_x),ylim=(0,max_y))
# ...

# %%
df_list_co_travellers=[]
for ind_ct,ct in enumerate(cotravellers):
    cot_flag=np.zeros(len(df))
    for ind,expr in enumerate(df['Co-Travellers'].values):
        if ct in expr:
            cot_flag[ind]=1
    df["cot_flag"]=cot_flag
    
    print(ind_ct, ct,": total/multi",df.loc[df['cot_flag']==1,"Pictures"].sum(),df.loc[(df['cot_flag']==1) & (df['Day Trip']==0),"Pictures"].sum(),
         "joined on",df.loc[(df['cot_flag']==1),"Date"].nunique(),"dates")
    df_list_co_travellers.append([ct,
                                df.loc[(df['cot_flag']==1),"Pictures"].sum(),
                                df.loc[(df['cot_flag']==1)&
                                        (df['Day Trip']==0),"Pictures"].sum(),
                                df.loc[(df['cot_flag']==1) &
                                        (df['Day Trip']==1),"Pictures"].sum(),
                                df.loc[(df['cot_flag']==1),"Date"].nunique(),
                                df.loc[(df['cot_flag']==1) &
                                        (df['Day Trip']==0),"Date"].nunique(),
                                df.loc[(df['cot_flag']==1) &
                                        (df['Day Trip']==1),"Date"].nunique(),
                                df.loc[(df['cot_flag']==1),"Country"].nunique(),
                                df.loc[(df['cot_flag']==1),"Place"].nunique(),
                                df.loc[(df['cot_flag']==1),"Date"].min(),
                                df.loc[(df['cot_flag']==1),"Date"].max()                             
                                 ])
    if df.loc[(df['cot_flag']==1),"Date"].nunique()>1:
        min_x=df.loc[(df['cot_flag']==1),"Date"].min()-np.timedelta64(2,"M")
        max_x=df.loc[(df['cot_flag']==1),"Date"].max()+np.timedelta64(2,"M")
        fig, ax = plt.subplots()
        max_y=1.25*df[(df['cot_flag']==1)].groupby(pd.Grouper(key="Date", freq="1D")).sum()["Pictures"].max()
        df[(df['cot_flag']==1)].groupby(pd.Grouper(key="Date", freq="1D")).sum()["Pictures"].plot(title="daily count of catedral pictures in trips",ylabel="picture count",xlim=(min_x,max_x),ylim=(0,max_y))
        plt.show()
# Out:
# 0 Zhiling : total/multi 57 0 joined on 2 dates
# /var/folders/8d/gvjspwlj4hq61gsmkn1p_h480000gn/T/ipykernel_6379/2699928604.py:31: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   max_y=1.25*df[(df['cot_flag']==1)].groupby(pd.Grouper(key="Date", freq="1D")).sum()["Pictures"].max()
# /var/folders/8d/gvjspwlj4hq61gsmkn1p_h480000gn/T/ipykernel_6379/2699928604.py:32: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df[(df['cot_flag']==1)].groupby(pd.Grouper(key="Date", freq="1D")).sum()["Pictures"].plot(title="daily count of catedral pictures in trips",ylabel="picture count",xlim=(min_x,max_x),ylim=(0,max_y))
# ...

# %%
df_coTrav = pd.DataFrame(df_list_co_travellers,columns=['Co-Traveller', 'Photos','PhotosMultiDay','PhotosSingleDay','Days',"Days_Multi","Days_Single","N_Countries","N_Places","FirstTripDate",'LastTripDate'])
df_coTrav=df_coTrav.sort_values(by="Photos",ascending=False).reset_index().drop(columns='index')
df_coTrav.to_csv("../data/cathedral_cotravellers.csv")
df_coTrav.head(50)
# Out:
#       Co-Traveller  Photos  PhotosMultiDay  PhotosSingleDay  Days  Days_Multi  \
# 0            Artur    3427            2978              449    99          85
# 1          Heidrun    2467            2302              165    76          69
# 2       Hannsjoerg    1108             747              361    57          43
# 3             Riju     947             828              119    26          23
# 4            Reyer     698             697                1    15          14
# 5             Amin     337             337                0     7           7
# 6     Anne-Kathrin     330             330                0    25          25
# 7           Manuel     320             320                0     8           8
# 8             Eric     260             260                0    12          12
# 9          Santona     223              96              127     5           3
# 10  Chris Brainerd     211             176               35     7           6
# ...

# %%
df.columns
# Out:
# Index(['Date', 'Pictures', 'Church', 'Place', 'Country', 'Style 1', 'Style 2',
#        'Style 3', 'Unesco Site', 'Day Trip', 'Co-Travellers',
#        'Number of Co-Travellers', 'cot_flag'],
#       dtype='object')
