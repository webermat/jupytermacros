# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime

# %%
data_list=[]
#year/place start/count start/airp st/place end/count end/airp end/airline/longdist/tranfer end/transfer start/co-trav

#1983
data_list.append([datetime.datetime(1980, 1, 1),1983,"Zurich","Switzerland","ZRH",'Ibiza','Spain',"IBZ",'Balair',0,0,0,['Jan-Marc','Heidrun','Artur']])
data_list.append([datetime.datetime(1980, 1, 1),1983,"Ibiza","Spain","IBZ",'Zurich','Switzerland',"ZHR",'Balair',0,0,0,['Jan-Marc','Heidrun','Artur']])
#1985
data_list.append([datetime.datetime(1985, 6, 26),1985,"Zurich","Switzerland","ZRH",'Ibiza','Spain',"IBZ",'',0,0,0,['Jan-Marc','Heidrun','Artur',"Anne-Kathrin"]])
data_list.append([datetime.datetime(1985, 7, 9),1985,"Ibiza","Spain","IBZ",'Zurich','Switzerland',"ZHR",'',0,0,0,['Jan-Marc','Heidrun','Artur','Anne-Kathrin']])
#1987
data_list.append([datetime.datetime(1980, 1, 1),1987,"Zurich","Switzerland","ZRH",'Palma de Mallorca','Spain',"PMI",'',0,0,0,['Jan-Marc','Heidrun','Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1980, 1, 1),1987,"Palma de Mallorca","Spain","PMI",'Zurich','Switzerland',"ZRH",'',0,0,0,['Jan-Marc','Heidrun','Artur','Anne-Kathrin','Hannsjoerg']])
#1990
data_list.append([datetime.datetime(1990, 5, 25),1990,"Zurich","Switzerland","ZRH",'Ibiza','Spain',"IBZ",'Balair',0,0,0,['Jan-Marc','Heidrun','Artur',"Anne-Kathrin","Hannsjoerg"]])
data_list.append([datetime.datetime(1990, 6, 8),1990,"Ibiza","Spain","IBZ",'Zurich','Switzerland',"ZRH",'Balair',0,0,0,['Jan-Marc','Heidrun','Artur','Anne-Kathrin',"Hannsjoerg"]])
#1996
data_list.append([datetime.datetime(1996, 8, 20),1996,"Zurich","Switzerland","ZRH",'London','United Kingdom',"STN",'Flightline',0,0,0,['Jan-Marc','Heidrun','Artur','Anne-Kathrin',"Hannsjoerg"]])
data_list.append([datetime.datetime(1996, 8, 28),1996,'London','United Kingdom',"STN","Zurich","Switzerland","ZRH",'Flightline',0,0,0,['Jan-Marc','Heidrun','Artur','Anne-Kathrin',"Hannsjoerg"]])
#1997
data_list.append([datetime.datetime(1997, 8, 24),1997,"Zurich","Switzerland","ZRH",'Rome','Italy',"FCO",'Alitalia',0,0,0,['Jan-Marc','Heidrun','Artur','Anne-Kathrin',"Hannsjoerg"]])
data_list.append([datetime.datetime(1997, 8, 31),1997,'Rome','Italy',"FCO","Zurich","Switzerland","ZRH",'Alitalia',0,0,0,['Jan-Marc','Heidrun','Artur','Anne-Kathrin',"Hannsjoerg"]])
#1998
data_list.append([datetime.datetime(1998, 8, 22),1998,"Basel/Mulhouse","France","BSL/MLH",'Paris','France',"CDG",'Air France',0,0,0,['Jan-Marc','Heidrun','Artur','Anne-Kathrin',"Hannsjoerg"]])
data_list.append([datetime.datetime(1998, 8, 30),1998,'Paris','France',"CDG","Basel/Mulhouse","France","BSL/MLH",'Air France',0,0,0,['Jan-Marc','Heidrun','Artur','Anne-Kathrin',"Hannsjoerg"]])
#1999
data_list.append([datetime.datetime(1999, 8, 27),1999,"Zurich","Switzerland","ZRH",'Athens','Greece',"ATH",'Condor',0,0,0,['Jan-Marc','Heidrun','Artur','Anne-Kathrin',"Hannsjoerg"]])
data_list.append([datetime.datetime(1999, 9, 8),1999,'Athens','Greece',"ATH","Zurich","Switzerland","ZRH",'Condor',0,0,0,['Jan-Marc','Heidrun','Artur','Anne-Kathrin',"Hannsjoerg"]])
#2000
data_list.append([datetime.datetime(2000, 8, 25),2000,"Frankfurt","Germany","FRA",'Antalya','Turkey',"AYT",'SunExpress',0,0,0,['Heidrun','Artur','Anne-Kathrin',"Hannsjoerg"]])
data_list.append([datetime.datetime(2000, 9, 7),2000,'Antalya','Turkey',"ATY","Frankfurt","Germany","FRA",'SunExpress',0,0,0,['Heidrun','Artur','Anne-Kathrin',"Hannsjoerg"]])
#2001
data_list.append([datetime.datetime(2001, 8, 22),2001,"Frankfurt","Germany","FRA",'Malaga','Spain',"AGP",'Thomas Cook',0,0,0,['Heidrun','Artur','Anne-Kathrin',"Hannsjoerg"]])
data_list.append([datetime.datetime(2001, 9, 3),2001,'Malaga','Spain',"AGP","Frankfurt","Germany","FRA",'Thomas Cook',0,0,0,['Heidrun','Artur','Anne-Kathrin',"Hannsjoerg"]])
#2002
data_list.append([datetime.datetime(2002, 8, 20),2002,"Basel/Mulhouse","Switzerland","BSL/MLH",'Agadir','Morocco',"AGA",'Condor',0,0,0,['Heidrun','Artur','Anne-Kathrin',"Hannsjoerg"]])
data_list.append([datetime.datetime(2002, 9, 3),2002,'Agadir','Morocco',"AGA","Basel/Mulhouse","Switzerland","BSL/MLH",'Condor',0,0,0,['Heidrun','Artur','Anne-Kathrin',"Hannsjoerg"]])
#2003
data_list.append([datetime.datetime(2003, 7, 4),2003,'Stuttgart','Germany',"STR","Izmir","Turkey","ADB",'Hapag Lloyd',0,1,0,['Sigi','Gianrico','Boeni']])
data_list.append([datetime.datetime(2003, 7, 4),2003,'Izmir','Turkey',"ADB","Bodrum","Turkey","BJV",'Hapag Lloyd',0,0,1,['Sigi','Gianrico','Boeni']])
data_list.append([datetime.datetime(2003, 7, 11),2003,'Bodrum','Turkey',"BJV","Stuttgart","Germany","STR",'Hapag Lloyd',0,0,0,['Sigi','Gianrico','Boeni']])
#2004
data_list.append([datetime.datetime(2004, 7, 2),2004,'Zurich','Switzerland',"ZRH","Monastir","Tunesia","MIR",'TuiFly',0,0,0,['Sigi','Gianrico']])
data_list.append([datetime.datetime(2004, 7, 9),2004,'Monastir','Tunesia',"MIR","Zurich","Switzerland","ZRH",'TuiFly',0,0,0,['Sigi','Gianrico']])
data_list.append([datetime.datetime(2004, 10, 15),2004,'Zurich','Switzerland',"ZRH","London","United Kingdom","LTN",'Easyjet',0,0,0,['Sigi','Gianrico',"Anne"]])
data_list.append([datetime.datetime(2004, 10, 20),2004,'London','United Kingdom',"LTN","Zurich","Switzerland","ZRH",'Easyjet',0,0,0,['Sigi','Gianrico',"Anne"]])
#2005
data_list.append([datetime.datetime(2005, 3, 20),2005,'Zurich','Switzerland',"ZRH","Cairo","Egypt","CAI",'Swiss',0,0,0,['Hannsjoerg','Heidrun','Artur']])
data_list.append([datetime.datetime(2005, 3, 22),2005,'Cairo','Egypt',"CAI","Luxor","Egypt","LXR",'Egypt Air',0,0,0,['Hannsjoerg','Heidrun','Artur']])
data_list.append([datetime.datetime(2005, 3, 26),2005,'Aswan','Egypt',"ASW","Cairo","Egypt","CAI",'Egypt Air',0,0,0,['Hannsjoerg','Heidrun','Artur']])
data_list.append([datetime.datetime(2005, 3, 28),2005,'Cairo','Egypt',"CAI","Zurich","Switzerland","ZRH",'Swiss',0,0,0,['Hannsjoerg','Heidrun','Artur']])
data_list.append([datetime.datetime(2005, 8, 28),2005,'Basel/Mulhouse','Switzerland',"BSL/MLH","Madrid","Spain","MAD",'Easyjet',0,1,0,['Hannsjoerg','Anne-Kathrin','Heidrun','Artur']])
data_list.append([datetime.datetime(2005, 8, 28),2005,'Madrid','Spain',"MAD","Lisbon","Portugal","LIS",'Easyjet',0,0,1,['Hannsjoerg','Anne-Kathrin','Heidrun','Artur']])
data_list.append([datetime.datetime(2005, 9, 4),2005,'Lisbon','Portugal',"LIS","Madrid","Spain","MAD",'Easyjet',0,1,0,['Hannsjoerg','Anne-Kathrin','Heidrun','Artur']])
data_list.append([datetime.datetime(2005, 9, 4),2005,'Madrid','Spain',"MAD","Basel/Mulhouse","Switzerland","BSL/MLH",'Easyjet',0,0,1,['Hannsjoerg','Anne-Kathrin','Heidrun','Artur']])
#2006
data_list.append([datetime.datetime(2006, 7, 11),2006,'Basel/Mulhouse','Switzerland',"BSL/MLH","London","United Kingdom","LTN",'Easyjet',0,0,0,['Artur','Heidrun','Hannsjoerg']])
data_list.append([datetime.datetime(2006, 7, 18),2006,'London','United Kingdom',"LTN","Basel/Mulhouse","Switzerland","BSL/MLH",'Easyjet',0,0,0,['Artur','Heidrun','Hannsjoerg']])
#2008
data_list.append([datetime.datetime(2008, 7, 28),2008,'Geneva','Switzerland',"GVA","Frankfurt","Germany","FRA",'Lufthansa',0,1,0,[]])
data_list.append([datetime.datetime(2008, 7, 28),2008,'Frankfurt','Germany',"FRA","Phildadelphia","USA","PHL",'US Airways',1,0,1,[]])
data_list.append([datetime.datetime(2008, 8, 5),2008,'Philadelphia','Germany',"PHL","Frankfurt","Germany","FRA",'US Airways',1,1,0,[]])
data_list.append([datetime.datetime(2008, 8, 6),2008,'Frankfurt','Germany',"FRA","Geneva","Switzerland","GVA",'Lufthansa',0,0,1,[]])
data_list.append([datetime.datetime(2008, 9, 3),2008,'Geneva','Switzerland',"GVA","Madrid","Spain","MAD",'Easyjet',0,0,0,[]])
data_list.append([datetime.datetime(2008, 9, 9),2008,'Madrid','Spain',"MAD","Geneva","Switzerland","GVA",'Easyjet',0,0,0,[]])
#2009
data_list.append([datetime.datetime(2009, 4, 25),2009,'Geneva','Switzerland',"GVA","Madrid","Spain","MAD",'Iberia',0,0,0,[]])
data_list.append([datetime.datetime(2009, 4, 30),2009,'Madrid','Spain',"MAD","Geneva","Switzerland","GVA",'Iberia',0,0,0,[]])
data_list.append([datetime.datetime(2008, 6, 23),2009,'Geneva','Switzerland',"GVA","Paris","France","CDG",'Air France',0,1,0,[]])
data_list.append([datetime.datetime(2008, 6, 23),2009,'Paris','France',"CDG","Cincinatti","USA","CVG",'Delta',1,1,1,[]])
data_list.append([datetime.datetime(2008, 6, 23),2009,'Cincinatti','USA',"CVG","Chicago","USA","ORD",'Delta',0,0,1,[]])
data_list.append([datetime.datetime(2008, 7, 3),2009,'Dane County','USA',"MSN","Detroit","USA","DTW",'Northwestern',0,1,0,[]])
data_list.append([datetime.datetime(2008, 7, 3),2009,'Detroit','USA',"DTW","New York City","USA","JFK",'Northwestern',0,0,1,[]])
data_list.append([datetime.datetime(2008, 7, 8),2009,'New York City','USA',"JFK","Paris","France","CDG",'Air France',1,1,0,[]])
data_list.append([datetime.datetime(2008, 7, 9),2009,'Paris','France',"CDG","Geneva","Switzerland","GVA",'Air France',0,0,1,[]])
#2011
data_list.append([datetime.datetime(2011, 12, 27),2011,'Zurich','Switzerland',"ZRH","Vienna","Austria","VIE",'NIKI',0,0,0,['Artur',"Heidrun",'Hannsjoerg']])
data_list.append([datetime.datetime(2011, 12, 30),2011,'Vienna','Austria',"VIE","Zurich","Switzerland","ZRH",'NIKI',0,0,0,['Artur',"Heidrun",'Hannsjoerg']])
#2012
data_list.append([datetime.datetime(2011, 2, 11),2012,'Geneva','Switzerland',"GVA","Newark","USA","EWR",'United',1,1,0,[]])
data_list.append([datetime.datetime(2011, 2, 11),2012,'Newark','USA',"EWR","Chicago","USA","ORD",'United',0,0,1,[]])
data_list.append([datetime.datetime(2011, 2, 26),2012,'Chicago','USA',"ORD","Washington DC","USA","IAD",'United',0,1,0,[]])
data_list.append([datetime.datetime(2011, 2, 26),2012,'Washington DC','USA',"IAD","Geneva","Switzerland","GVA",'United',1,0,1,[]])
data_list.append([datetime.datetime(2011, 5, 11),2012,'Geneva','Switzerland',"GVA","Prague","Czech Republic","PRG",'Czech',0,0,0,[]])
data_list.append([datetime.datetime(2011, 5, 13),2012,'Prague','Czech Republic',"PRG","Geneva","Switzerland","GVA",'Czech',0,0,0,[]])
data_list.append([datetime.datetime(2011, 7, 24),2012,'Geneva','Switzerland',"GVA","Berlin","Germany","SXF",'Easyjet',0,0,0,[]])
data_list.append([datetime.datetime(2011, 7, 31),2012,'Berlin','Germany',"SXF","Geneva","Switzerland","GVA",'Easyjet',0,0,0,[]])
data_list.append([datetime.datetime(2011, 8, 30),2012,'Geneva','Switzerland',"GVA","Lisbon","Portugal","LIS",'TAP',0,0,0,[]])
data_list.append([datetime.datetime(2011, 9, 9),2012,'Lisbon','Portugal',"LIS","Geneva","Switzerland","GVA",'TAP',0,0,0,[]])
data_list.append([datetime.datetime(2011, 9, 28),2012,'Geneva','Switzerland',"GVA","Vienna","Austria","VIE",'Austrian Airlines',0,1,0,['Eric']])
data_list.append([datetime.datetime(2011, 9, 28),2012,'Vienna','Austria',"VIE","Warsaw","Poland","WAW",'Austrian Airlines',0,0,1,['Eric']])
data_list.append([datetime.datetime(2011, 10, 1),2012,'Warsaw','Poland',"WAW","Brussels","Belgium","BRU",'Brussels',0,1,0,['Eric']])
data_list.append([datetime.datetime(2011, 10, 1),2012,'Brussels','Belgium',"BRU","Geneva","Switzerland","GVA",'Brussels',0,0,1,['Eric']])
#2013
data_list.append([datetime.datetime(2013, 1, 2),2013,'Basel/Mulhouse','Switzerland',"BSL/MLH","Amsterdam","Netherlands","AMS",'KLM',0,0,0,['Artur','Heidrun','Hannsjoerg']])
data_list.append([datetime.datetime(2013, 1, 6),2013,'Amsterdam','Netherlands',"AMS","Basel/Mulhouse","Switzerland","BSL/MLH",'KLM',0,0,0,['Artur','Heidrun','Hannsjoerg']])
data_list.append([datetime.datetime(2013, 4, 3),2013,'Geneva','Switzerland',"GVA","Rome","Italy","FCO",'Alitalia',0,0,0,[]])
data_list.append([datetime.datetime(2013, 4, 11),2013,'Rome','Italy',"FCO","Geneva","Switzerland","GVA",'Alitalia',0,0,0,[]])
data_list.append([datetime.datetime(2013, 7, 14),2013,'Geneva','Switzerland',"GVA","Stockholm","Sweden","ARN",'SAS',0,0,0,[]])
data_list.append([datetime.datetime(2013, 7, 24),2013,'Stockholm','Sweden',"ARN","Copenhagen","Denmark","CPH",'SAS',0,0,0,[]])
data_list.append([datetime.datetime(2013, 7, 28),2013,'Copenhagen','Denmark',"CPH","Geneva","Switzerland","GVA",'SAS',0,0,0,[]])
data_list.append([datetime.datetime(2013, 9, 5),2013,'Geneva','Switzerland',"GVA","Dusseldorf","Germany","DUS",'Lufthansa',0,1,0,[]])
data_list.append([datetime.datetime(2013, 9, 5),2013,'Dusseldorf','Germany',"DUS","Venice","Italy","VCE",'Lufthansa',0,0,1,[]])
data_list.append([datetime.datetime(2013, 9, 8),2013,'Venice','Italy',"VCE","Zurich","Switzerland","ZRH",'Swiss',0,1,0,[]])
data_list.append([datetime.datetime(2013, 9, 8),2013,'Zurich','Switzerland',"ZRH","Geneva","Switzerland","GVA",'Swiss',0,0,1,[]])
#2014
data_list.append([datetime.datetime(2014, 4, 18),2014,'Geneva','Switzerland',"GVA","Munich","Germany","MUC",'Lufthansa',0,0,0,["Indara",'Eric']])
data_list.append([datetime.datetime(2014, 4, 18),2014,'Munich','Germany',"MUC","Zurich","Switzerland","ZRH",'Swiss',0,1,0,["Indara",'Eric']])
data_list.append([datetime.datetime(2014, 4, 22),2014,'Zurich','Switzerland',"ZRH","Geneva","Switzerland","GVA",'Swiss',0,0,1,["Indara",'Eric']])
data_list.append([datetime.datetime(2014, 7, 24),2014,'Geneva','Switzerland',"GVA","London","United Kingdom","LGW",'Easyjet',0,0,0,["Hannsjoerg"]])
data_list.append([datetime.datetime(2014, 8, 4),2014,'London','United Kingdom',"LGW","Geneva","Switzerland","GVA",'Easyjet',0,0,0,["Hannsjoerg"]])
data_list.append([datetime.datetime(2014, 8, 22),2014,'Geneva','Switzerland',"GVA","Vienna","Austria","VIE",'Austrian Airlines',0,0,0,[]])
data_list.append([datetime.datetime(2014, 8, 31),2014,'Budapest','Hungary',"BUD","Zurich","Switzerland","ZRH",'Swiss',0,1,0,[]])
data_list.append([datetime.datetime(2014, 8, 31),2014,'Zurich','Switzerland',"ZRH","Geneva","Switzerland","GVA",'Swiss',0,0,1,[]])
data_list.append([datetime.datetime(2014, 10, 23),2014,'Geneva','Switzerland',"GVA","Istanbul","Turkey","IST",'Turkish',0,0,0,["Chris M"]])
data_list.append([datetime.datetime(2014, 10, 27),2014,'Istanbul','Turkey',"IST","Geneva","Switzerland","GVA",'Turkish',0,0,0,["Chris M"]])
data_list.append([datetime.datetime(2014, 12, 12),2014,'Geneva','Switzerland',"GVA","London","United Kingdom","LGW",'Easyjet',0,0,0,["Manuel"]])
data_list.append([datetime.datetime(2014, 12, 14),2014,'London','United Kingdom',"LGW","Geneva","Switzerland","GVA",'Easyjet',0,0,0,["Manuel"]])
#2015
data_list.append([datetime.datetime(2015, 3, 27),2015,'Geneva','Switzerland',"GVA","Madrid","Spain","MAD",'Iberia',0,0,0,[]])
data_list.append([datetime.datetime(2015, 4, 6),2015,'Madrid','Spain',"MAD","Geneva","Switzerland","GVA",'Iberia',0,0,0,[]])
data_list.append([datetime.datetime(2015, 5, 14),2015,'Geneva','Switzerland',"GVA","Munich","Germany","MUC",'Lufthansa',0,1,0,["AJ",'Stephan']])
data_list.append([datetime.datetime(2015, 5, 14),2015,'Munich','Germany',"MUC","Napoli","Italy","NAP",'Lufthansa',0,0,1,["AJ",'Stephan']])
data_list.append([datetime.datetime(2015, 5, 18),2015,'Napoli','Italy',"NAP","Munich","Germany","MUC",'Lufthansa',0,1,0,["AJ",'Stephan']])
data_list.append([datetime.datetime(2015, 5, 18),2015,'Munich','Germany',"MUC","Geneva","Switzerland","GVA",'Lufthansa',0,0,1,["AJ",'Stephan']])
data_list.append([datetime.datetime(2015, 6, 13),2015,'Geneva','Switzerland',"GVA","London","United Kingdom","LHR",'British Airways',0,1,0,[]])
data_list.append([datetime.datetime(2015, 6, 13),2015,'London','United Kingdom',"LHR","Los Angeles","USA","LAX",'American Airlines',1,0,1,[]])
data_list.append([datetime.datetime(2015, 6, 20),2015,'Los Angeles','USA',"LAX","London","United Kingdom","LHR",'American Airlines',1,1,0,[]])
data_list.append([datetime.datetime(2015, 6, 21),2015,'London','United Kingdom',"LHR","Geneva","Switzerland","GVA",'British Airways',0,0,1,[]])
data_list.append([datetime.datetime(2015, 8, 21),2015,'Geneva','Switzerland',"GVA","Nice","France","NCE",'Swiss',0,0,0,[]])
data_list.append([datetime.datetime(2015, 8, 23),2015,'Nice','France',"NCE","Geneva","Switzerland","GVA",'Swiss',0,0,0,[]])
data_list.append([datetime.datetime(2015, 8, 28),2015,'Geneva','Switzerland',"GVA","Paris","France","CDG",'Air France',0,1,0,[]])
data_list.append([datetime.datetime(2015, 8, 28),2015,'Paris','France',"CDG","St Petersburg","Russia","LED",'Air France',0,0,1,[]])
data_list.append([datetime.datetime(2015, 9, 12),2015,'St Petersburg','Russia',"LED","Paris","France","CDG",'Air France',0,1,0,[]])
data_list.append([datetime.datetime(2015, 9, 12),2015,'Paris','France',"CDG","Geneva","Switzerland","GVA",'Air France',0,0,1,[]])
data_list.append([datetime.datetime(2015, 10, 3),2015,'Geneva','Switzerland',"GVA","Munich","Germany","MUC",'Lufthansa',0,0,0,[]])
data_list.append([datetime.datetime(2015, 10, 11),2015,'Munich','Germany',"MUC","Geneva","Switzerland","GVA",'Lufthansa',0,0,0,[]])
data_list.append([datetime.datetime(2015, 11, 8),2015,'Geneva','Switzerland',"GVA","Berlin","Germany","SXF",'Easyjet',0,0,0,[]])
data_list.append([datetime.datetime(2015, 11, 15),2015,'Berlin','Germany',"SXF","Geneva","Switzerland","GVA",'Easyjet',0,0,0,[]])
#2016 
data_list.append([datetime.datetime(2016, 3, 16),2016,'Geneva','Switzerland',"GVA","Catania","Italy","CTA",'Easyjet',0,0,0,['Artur','Heidrun']])
data_list.append([datetime.datetime(2016, 3, 25),2016,'Catania','Italy',"CTA","Geneva","Switzerland","GVA",'Easyjet',0,0,0,["Artur",'Heidrun']])
data_list.append([datetime.datetime(2016, 3, 26),2016,'Geneva','Switzerland',"GVA","Barcelona","Spain","BCN",'Vueling',0,0,0,['Riju']])
data_list.append([datetime.datetime(2016, 3, 29),2016,'Barcelona','Spain',"BCN","Geneva","Switzerland","GVA",'Vueling',0,0,0,["Riju"]])
data_list.append([datetime.datetime(2016, 5, 28),2016,'Geneva','Switzerland',"GVA","Bilbao","Spain","BIO",'Easyjet',0,0,0,[]])
data_list.append([datetime.datetime(2016, 6, 3),2016,'Bilbao','Spain',"BIO","Geneva","Switzerland","GVA",'Easyjet',0,0,0,[]])
data_list.append([datetime.datetime(2016, 7, 22),2016,'Geneva','Switzerland',"GVA","Brussels","Belgium","BRU",'Brussels',0,0,0,[]])
data_list.append([datetime.datetime(2016, 7, 24),2016,'Brussels','Belgium',"BRU","Geneva","Switzerland","GVA",'Brussels',0,0,0,[]])
data_list.append([datetime.datetime(2016, 8, 13),2016,'Geneva','Switzerland',"GVA","Brussels","Belgium","BRU",'Brussels',0,1,0,[]])
data_list.append([datetime.datetime(2016, 8, 13),2016,'Brussels','Belgium',"BRU","Chicago","USA","ORD",'United',1,0,1,[]])
data_list.append([datetime.datetime(2016, 8, 15),2016,'Chicago','USA',"ORD","Las Vegas","USA","LAS",'United',0,0,0,['Artur','Heidrun','Hannsjoerg']])
data_list.append([datetime.datetime(2016, 8, 26),2016,'Las Vegas','USA',"LAS","Washington DC","USA","DCA",'American Airlines',0,0,0,['Artur','Heidrun']])
data_list.append([datetime.datetime(2016, 8, 29),2016,'Washington DC','USA',"IAD","Geneva","Switzerland","GVA",'United',1,0,0,[]])
data_list.append([datetime.datetime(2016, 9, 13),2015,'Geneva','Switzerland',"GVA","London","United Kingdom","LHR",'British Airways',0,1,0,[]])
data_list.append([datetime.datetime(2016, 9, 13),2015,'London','United Kingdom',"LHR","Dallas-Fort Worth","USA","DFW",'American Airlines',1,0,1,[]])
data_list.append([datetime.datetime(2016, 9, 17),2015,'Dallas-Fort Worth','USA',"DFW","London","United Kingdom","LHR",'British Airways',1,1,0,[]])
data_list.append([datetime.datetime(2016, 9, 18),2015,'London','United Kingdom',"LHR","Geneva","Switzerland","GVA",'British Airways',0,0,1,[]])
data_list.append([datetime.datetime(2016, 10, 8),2016,'Geneva','Switzerland',"GVA","Santiago de Compostela","Spain","SCQ",'Easyjet',0,0,0,[]])
data_list.append([datetime.datetime(2016, 10, 9),2016,'Santiago de Compostela','Spain',"SCQ","Geneva","Switzerland","GVA",'Easyjet',0,0,0,[]])
data_list.append([datetime.datetime(2016, 10, 13),2016,'Geneva','Switzerland',"GVA","Dusseldorf","Germany","DUS",'Eurowings',0,0,0,[]])
data_list.append([datetime.datetime(2016, 10, 16),2016,'Dusseldorf','Germany',"DUS","Geneva","Switzerland","GVA",'Eurowings',0,0,0,[]])
data_list.append([datetime.datetime(2016, 12, 4),2016,'Zurich','Switzerland',"ZRH","Paris","France","CDG",'Air France',0,1,0,[]])
data_list.append([datetime.datetime(2016, 12, 5),2016,'Paris','France',"CDG","Tokyo","Japan","HND",'Air France',1,0,1,[]])
data_list.append([datetime.datetime(2016, 12, 18),2016,'Tokyo','Japan',"HND","Paris","France","CDG",'Air France',1,1,0,[]])
data_list.append([datetime.datetime(2016, 12, 18),2016,'Paris','France',"CDG","Geneva","Switzerland","GVA",'Air France',0,0,1,[]])
#2017
data_list.append([datetime.datetime(2017, 1, 2),2017,'Geneva','Switzerland',"GVA","Zurich","Switzerland","ZRH",'Swiss',0,1,0,[]])
data_list.append([datetime.datetime(2017, 1, 2),2017,'Zurich','Switzerland',"ZRH","Dublin","Ireland","DUB",'Swiss',0,0,1,[]])
data_list.append([datetime.datetime(2017, 1, 5),2017,'Dublin','Ireland',"DUB","Geneva","Switzerland","GVA",'Air Lingus',0,0,0,[]])
data_list.append([datetime.datetime(2017, 2, 10),2017,'Geneva','Switzerland',"GVA","Brussels","Belgium","BRU",'Brussels',0,0,0,['Riju']])
data_list.append([datetime.datetime(2017, 2, 12),2017,'Brussels','Belgium',"BRU","Geneva","Switzerland","GVA",'Brussels',0,0,0,['Riju']])
data_list.append([datetime.datetime(2017, 4, 14),2017,'Geneva','Switzerland',"GVA","Kiev","Ukraine","IEV",'Ukrainian',0,0,0,[]])
data_list.append([datetime.datetime(2017, 4, 17),2017,'Kiev','Ukraine',"IEV","Geneva","Switzerland","GVA",'Ukrainian',0,0,0,[]])
data_list.append([datetime.datetime(2017, 4, 28),2017,'Geneva','Switzerland',"GVA","Frankfurt","Germany","FRA",'Lufthansa',0,0,0,[]])
data_list.append([datetime.datetime(2017, 5, 2),2017,'Frankfurt','Germany',"FRA","Geneva","Switzerland","GVA",'Lufthansa',0,0,0,[]])
data_list.append([datetime.datetime(2017, 5, 24),2017,'Geneva','Switzerland',"GVA","Madrid","Spain","MAD",'Iberia',0,0,0,[]])
data_list.append([datetime.datetime(2017, 5, 28),2017,'Madrid','Spain',"MAD","Geneva","Switzerland","GVA",'Iberia',0,0,0,[]])
data_list.append([datetime.datetime(2017, 6, 3),2017,'Geneva','Switzerland',"GVA","Athens","Greece","ATH",'Aegean',0,0,0,["Riju",'Amin']])
data_list.append([datetime.datetime(2017, 6, 6),2017,'Athens','Greece',"ATH","Geneva","Switzerland","GVA",'Aegean',0,0,0,["Riju",'Amin']])
data_list.append([datetime.datetime(2017, 6, 9),2017,'Geneva','Switzerland',"GVA","Paris","France","CDG",'Air France',0,1,0,[]])
data_list.append([datetime.datetime(2017, 6, 9),2017,'Paris','France',"CDG","Salt Lake City","USA","SLC",'Delta',1,0,1,['Artur','Heidrun']])
data_list.append([datetime.datetime(2017, 7, 23),2017,'Salt Lake City','USA',"SLC","Paris","France","CDG",'Delta',1,1,0,['Artur','Heidrun']])
data_list.append([datetime.datetime(2017, 7, 23),2017,'Paris','France',"CDG","Geneva","Switzerland","GVA",'Air France',0,0,1,[]])
data_list.append([datetime.datetime(2017, 7, 5),2017,'Geneva','Switzerland',"GVA","Venice","Italy","VCE",'Easyjet',0,0,0,['Reyer']])
data_list.append([datetime.datetime(2017, 7, 16),2017,'Venice','Italy',"VCE","Geneva","Switzerland","GVA",'Easyjet',0,0,0,['Reyer']])
data_list.append([datetime.datetime(2017, 7, 21),2017,'Geneva','Switzerland',"GVA","Brussels","Belgium","BRU",'Brussels',0,1,0,[]])
data_list.append([datetime.datetime(2017, 7, 21),2017,'Brussels','Belgium',"BRU","Oslo","Norway","OSL",'Brussels',0,0,1,[]])
data_list.append([datetime.datetime(2017, 7, 23),2017,'Oslo','Norway',"OSL","Zurich","Switzerland","ZRH",'Helvetic',0,1,0,[]])
data_list.append([datetime.datetime(2017, 7, 23),2017,'Zurich','Switzerland',"ZRH","Geneva","Switzerland","GVA",'Swiss',0,0,1,[]])
data_list.append([datetime.datetime(2017, 7, 28),2017,'Geneva','Switzerland',"GVA","Munich","Germany","MUC",'Lufthansa',0,0,0,[]])
data_list.append([datetime.datetime(2017, 7, 30),2017,'Munich','Germany',"MUC","Geneva","Switzerland","GVA",'Air Dolomiti',0,0,0,[]])
data_list.append([datetime.datetime(2017, 8, 27),2017,'Geneva','Switzerland',"GVA","Split","Croatia","SPU",'Easyjet',0,0,0,[]])
data_list.append([datetime.datetime(2017, 8, 28),2017,'Croatia','Split',"SPU","Geneva","Switzerland","GVA",'Easyjet',0,0,0,[]])
data_list.append([datetime.datetime(2017, 9, 6),2017,'Geneva','Switzerland',"GVA","Rome","Italy","FCO",'Easyjet',0,0,0,['Riju']])
data_list.append([datetime.datetime(2017, 9, 11),2017,'Rome','Italy',"FCO","Geneva","Switzerland","GVA",'Easyjet',0,0,0,['Riju','Amin']])
data_list.append([datetime.datetime(2017, 9, 15),2017,'Geneva','Switzerland',"GVA","London","United Kingdom","LGW",'Easyjet',0,0,0,["Riju"]])
data_list.append([datetime.datetime(2017, 9, 18),2017,'London','United Kingdom',"LGW","Geneva","Switzerland","GVA",'Easyjet',0,0,0,["Riju"]])
data_list.append([datetime.datetime(2017, 9, 30),2017,'Geneva','Switzerland',"GVA","Munich","Germany","MUC",'Air Dolomiti',0,1,0,[]])
data_list.append([datetime.datetime(2017, 9, 30),2017,'Munich','Germany',"MUC","GRZ","Austria","GVA",'Lufthansa',0,0,1,[]])
data_list.append([datetime.datetime(2017, 10, 1),2017,'Graz','Austria',"GRZ","Zurich","Switzerland","ZRH",'Helvetic',0,1,0,[]])
data_list.append([datetime.datetime(2017, 10, 1),2017,'Zurich','Switzerland',"ZRH","Geneva","Switzerland","GVA",'Swiss',0,0,1,[]])
data_list.append([datetime.datetime(2017, 10, 6),2017,'Geneva','Switzerland',"GVA","Warsaw","Poland","WAR",'LOT',0,1,0,['Riju','Reyer','Rachel']])
data_list.append([datetime.datetime(2017, 10, 6),2017,'Warsaw','Poland',"WAW","Tallin","Estonia","TLL",'Nordica',0,0,1,['Riju','Reyer','Rachel']])
data_list.append([datetime.datetime(2017, 10, 9),2017,'Tallin','Estonia',"TLL","Vienna","Austria","VIE",'Nordica',0,1,0,['Riju','Reyer','Rachel']])
data_list.append([datetime.datetime(2017, 10, 9),2017,'Vienna','Austria',"VIE","Geneva","Switzerland","GVA",'Austrian Airlines',0,0,1,['Riju','Reyer','Rachel']])
data_list.append([datetime.datetime(2017, 11, 10),2017,'Geneva','Switzerland',"GVA","Marrakesh","Morocco","RAK",'Easyjet',0,0,0,['Riju','Cameron','Tony']])
data_list.append([datetime.datetime(2017, 11, 13),2017,'Marrakesh','Morocco',"RAK","Geneva","Switzerland","GVA",'Easyjet',0,0,0,['Riju','Cameron','Tony']])
data_list.append([datetime.datetime(2017, 12, 29),2017,'Zurich','Switzerland',"ZRH","Shanghai","China","PVG",'Swiss',1,0,0,[]])
#2018
data_list.append([datetime.datetime(2018, 1, 14),2018,'Beijing','China',"PEK","Hong Kong","China","HKG",'Hongkong Airlines',0,0,0,[]])
data_list.append([datetime.datetime(2018, 1, 21),2018,'Hong Kong','China',"HKG","Frankfurt","Germany","FRA",'Lufthansa',0,1,0,[]])
data_list.append([datetime.datetime(2018, 1, 21),2018,'Frankfurt','Germany',"FRA","Geneva","Switzerland","GVA",'Lufthansa',0,0,1,[]])
data_list.append([datetime.datetime(2018, 3, 3),2018,'Geneva','Switzerland',"GVA","Toulouse","France","TLS",'Easyjet',0,0,0,[]])
data_list.append([datetime.datetime(2018, 3, 4),2018,'Toulouse','France',"TLS","Geneva","Switzerland","GVA",'Easyjet',0,0,0,[]])
data_list.append([datetime.datetime(2018, 3, 9),2018,'Geneva','Switzerland',"GVA","Brussels","Belgium","BRU",'Brussels',0,0,0,[]])
data_list.append([datetime.datetime(2018, 3, 11),2018,'Brussels','Belgium',"BRU","Geneva","Switzerland","GVA",'Brussels',0,0,0,[]])
data_list.append([datetime.datetime(2018, 3, 28),2018,'Geneva','Switzerland',"GVA","Reykjavik","Iceland","RKV",'Easyjet',0,0,0,['Riju','Reyer','Rachel']])
data_list.append([datetime.datetime(2018, 3, 31),2018,'Reykjavik','Iceland',"RKV","Geneva","Switzerland","GVA",'Easyjet',0,0,0,['Riju','Reyer','Rachel']])
data_list.append([datetime.datetime(2018, 4, 13),2018,'Geneva','Switzerland',"GVA","Munich","Germany","MUC",'Lufthansa',0,0,0,[]])
data_list.append([datetime.datetime(2018, 4, 14),2018,'Munich','Germany',"MUC","Copenhagen","Denmark","CPH",'Lufthansa',0,0,0,[]])
data_list.append([datetime.datetime(2018, 4, 15),2018,'Copenhagen','Denmark',"CPH","Munich","Germany","MUC",'Air Dolomiti',0,1,0,[]])
data_list.append([datetime.datetime(2018, 4, 15),2018,'Munich','Germany',"MUC","Geneva","Switzerland","GVA",'Air Dolomiti',0,0,1,[]])
data_list.append([datetime.datetime(2018, 5, 25),2018,'Geneva','Switzerland',"GVA","Barcelona","Spain","BCN",'Easyjet',0,0,0,['Rachel']])
data_list.append([datetime.datetime(2018, 5, 28),2018,'Barcelona','Spain',"BCN","London","United Kingdom","LGW",'Easyjet',0,1,0,[]])
data_list.append([datetime.datetime(2018, 5, 28),2018,'London','United Kingdom',"LGW","Geneva","Switzerland","GVA",'Easyjet',0,0,1,[]])
data_list.append([datetime.datetime(2018, 6, 2),2018,'Geneva','Switzerland',"GVA","Edinburgh","United Kingdom","EDI",'Easyjet',0,0,0,[]])
data_list.append([datetime.datetime(2018, 6, 10),2018,'Manchester','United Kingdom',"MAN","Geneva","Switzerland","GVA",'Easyjet',0,0,0,[]])
data_list.append([datetime.datetime(2018, 7, 1),2018,'Geneva','Switzerland',"GVA","Dubai","United Arab Emirates","DBX",'Emirates',1,1,0,[]])
data_list.append([datetime.datetime(2018, 7, 2),2018,'Dubai','United Arab Emirates',"DBX","Incheon","South Korea","ICN",'Emirates',1,0,1,[]])
data_list.append([datetime.datetime(2018, 7, 15),2018,'Incheon','South Korea',"ICN","Dubai","United Arab Emirates","DBX",'Emirates',1,1,0,[]])
data_list.append([datetime.datetime(2018, 7, 16),2018,'Dubai','United Arab Emirates',"DBX","Geneva","Switzerland","GVA",'Emirates',1,0,1,[]])
data_list.append([datetime.datetime(2018, 8, 31),2018,'Geneva','Switzerland',"GVA","Munich","Germany","MUC",'Lufthansa',0,0,0,['Reyer']])
data_list.append([datetime.datetime(2018, 9, 9),2018,'Berlin','Germany',"TXL","Munich","Germany","MUC",'Lufthansa',0,1,0,['Reyer']])
data_list.append([datetime.datetime(2018, 9, 9),2018,'Munich','Germany',"MUC","GVA","Switzerland","GVA",'Air Dolomiti',0,0,1,['Reyer']])
data_list.append([datetime.datetime(2018, 9, 21),2018,'Geneva','Switzerland',"GVA","Brussels","Belgium","BRU",'Brussels',0,0,0,[]])
data_list.append([datetime.datetime(2018, 9, 23),2018,'Brussels','Belgium',"BRU","Geneva","Switzerland","GVA",'Brussels',0,0,0,['Rachel']])
#2019
data_list.append([datetime.datetime(2019, 3, 10),2019,'Geneva','Switzerland',"GVA","Brindisi","Italy","NAP",'Easyjet',0,0,0,[]])
data_list.append([datetime.datetime(2019, 3, 22),2019,'Napoli','Italy',"NAP","Geneva","Switzerland","GVA",'Easyjet',0,0,0,[]])
data_list.append([datetime.datetime(2019, 4, 13),2019,'Geneva','Switzerland',"GVA","London","United Kingdom","LGW",'Easyjet',0,0,0,[]])
data_list.append([datetime.datetime(2019, 4, 17),2019,'London','United Kingdom',"LGW","Geneva","Switzerland","GVA",'Easyjet',0,0,0,[]])
data_list.append([datetime.datetime(2019, 5, 30),2019,'Geneva','Switzerland',"GVA","Frankfurt","Germany","FRA",'Swiss',0,1,0,['Grace']])
data_list.append([datetime.datetime(2019, 5, 30),2019,'Frankfurt','Germany',"FRA","Hannover","Germany","HAJ",'Lufthansa',0,0,1,['Grace']])
data_list.append([datetime.datetime(2019, 6, 3),2019,'Hannover','Germany',"HAJ","Zurich","Switzerland","ZRH",'Swiss',0,1,0,['Grace']])
data_list.append([datetime.datetime(2019, 6, 3),2019,'Zurich','Switzerland',"ZRH","Geneva","Switzerland","GVA",'Swiss',0,0,1,['Grace']])
#2020
data_list.append([datetime.datetime(2020, 2, 20),2020,"Geneva","Switzerland","GVA",'Rome','Italy',"FCO",'Easyjet',0,0,0,[]])
data_list.append([datetime.datetime(2020, 3, 2),2020,"Rome","Italy","FCO",'Geneva','Switzerland',"GVA",'Easyjet',0,0,0,["Bryan"]])
##2022
data_list.append([datetime.datetime(2022, 3, 19),2022,"Vienna","Austria","VIE",'Madrid','Spain',"MAD",'Iberia',0,0,0,[]])
data_list.append([datetime.datetime(2022, 4, 3),2022,'Madrid','Spain',"MAD","Vienna","Austria","VIE","Iberia",0,0,0,[]])
data_list.append([datetime.datetime(2022, 6, 16),2022,'Vienna','Austria',"VIE","Berlin","Germany","BER","Austrian Airlines",0,0,0,[]])
data_list.append([datetime.datetime(2022, 6, 19),2022,'Leizig','Germany',"LEJ","Vienna","Austria","VIE","Austrian Airlines",0,0,0,[]])
data_list.append([datetime.datetime(2022, 7, 29),2022,'Vienna','Austria',"VIE","Milan","Italy","MXP","Austrian Airlines",0,0,0,['Riju']])
data_list.append([datetime.datetime(2022, 8, 7),2022,'Milan','Italy',"MXP","Vienna","Austria","VIE","Austrian Airlines",0,0,0,["Riju"]])
data_list.append([datetime.datetime(2022, 8, 25),2022,'Vienna','Austria',"VIE","Riga","Latvia","RIX","AirBaltic",0,0,0,[]])
data_list.append([datetime.datetime(2022, 8, 28),2022,'Riga','Latvia',"RIX","Vienna","Austria","VIE","AirBaltic",0,0,0,["Artur"]])
data_list.append([datetime.datetime(2022, 12, 1),2022,'Vienna','Austria',"VIE","Dusseldorf","Germany","DUS","Eurowings",0,0,0,[]])
data_list.append([datetime.datetime(2022, 12, 4),2022,'Dusseldorf','Germany',"DUS","Vienna","Austria","VIE","Austrian Airlines",0,0,0,[]])


df = pd.DataFrame(data_list,columns=['Date','Year', 'Origin Place', 'Origin Country','Origin Airport','Destination Place','Destination Country','Destination Airport',"Airline",'LongDistanceFlight','End Transfer Airport','Start Transfer Airport','Co-Travellers'])
df["Number of Co-Travellers"]=df["Co-Travellers"].str.len()
df.to_csv("../data/Flight_AirportInfo.csv")
df
# Out:
#           Date  Year Origin Place Origin Country Origin Airport  \
# 0   1980-01-01  1983       Zurich    Switzerland            ZRH
# 1   1980-01-01  1983        Ibiza          Spain            IBZ
# 2   1985-06-26  1985       Zurich    Switzerland            ZRH
# 3   1985-07-09  1985        Ibiza          Spain            IBZ
# 4   1980-01-01  1987       Zurich    Switzerland            ZRH
# ..         ...   ...          ...            ...            ...
# 222 2022-08-07  2022        Milan          Italy            MXP
# 223 2022-08-25  2022       Vienna        Austria            VIE
# 224 2022-08-28  2022         Riga         Latvia            RIX
# 225 2022-12-01  2022       Vienna        Austria            VIE
# 226 2022-12-04  2022   Dusseldorf        Germany            DUS
#
#      Destination Place Destination Country Destination Airport  \
# 0                Ibiza               Spain                 IBZ
# 1               Zurich         Switzerland                 ZHR
# ...

# %%
string_traveller="Riju"
#df_test[(df_test['Co-Travellers'].str.contains('Rachel'))]
df["flag"]=0
#df_test["flag"]=np.where("")
for ind,test in enumerate(df['Co-Travellers'].values):
    if string_traveller in test:
        df.iloc[ind,df.columns.get_loc("flag")]=1
print(len(df.loc[df['flag']==1]))
df.loc[df['flag']==1]
# Out:
# 20
#           Date  Year Origin Place  Origin Country Origin Airport  \
# 115 2016-03-26  2016       Geneva     Switzerland            GVA
# 116 2016-03-29  2016    Barcelona           Spain            BCN
# 141 2017-02-10  2017       Geneva     Switzerland            GVA
# 142 2017-02-12  2017     Brussels         Belgium            BRU
# 149 2017-06-03  2017       Geneva     Switzerland            GVA
# 150 2017-06-06  2017       Athens          Greece            ATH
# 165 2017-09-06  2017       Geneva     Switzerland            GVA
# 166 2017-09-11  2017         Rome           Italy            FCO
# 167 2017-09-15  2017       Geneva     Switzerland            GVA
# 168 2017-09-18  2017       London  United Kingdom            LGW
# 173 2017-10-06  2017       Geneva     Switzerland            GVA
# 174 2017-10-06  2017       Warsaw          Poland            WAW
# 175 2017-10-09  2017       Tallin         Estonia            TLL
# ...

# %%
df.loc[df["LongDistanceFlight"]==1]
# Out:
#           Date  Year       Origin Place        Origin Country Origin Airport  \
# 40  2008-07-28  2008          Frankfurt               Germany            FRA
# 41  2008-08-05  2008       Philadelphia               Germany            PHL
# 48  2008-06-23  2009              Paris                France            CDG
# 52  2008-07-08  2009      New York City                   USA            JFK
# 56  2011-02-11  2012             Geneva           Switzerland            GVA
# 59  2011-02-26  2012      Washington DC                   USA            IAD
# 100 2015-06-13  2015             London        United Kingdom            LHR
# 101 2015-06-20  2015        Los Angeles                   USA            LAX
# 122 2016-08-13  2016           Brussels               Belgium            BRU
# 125 2016-08-29  2016      Washington DC                   USA            IAD
# 127 2016-09-13  2015             London        United Kingdom            LHR
# ...

# %%
df.groupby("Airline").agg(flights_per_airline=('Origin Place','count')).sort_values(by="flights_per_airline",ascending=False).reset_index()
# Out:
#               Airline  flights_per_airline
# 0             Easyjet                   49
# 1           Lufthansa                   22
# 2               Swiss                   18
# 3          Air France                   15
# 4            Brussels                   13
# 5   Austrian Airlines                    9
# 6              Iberia                    8
# 7              United                    7
# 8        Air Dolomiti                    5
# 9     British Airways                    5
# 10                                       4
# 11              Delta                    4
# 12             Balair                    4
# 13             Condor                    4
# 14  American Airlines                    4
# 15           Alitalia                    4
# 16           Emirates                    4
# 17                SAS                    3
# 18        Hapag Lloyd                    3
# 19          Eurowings                    3
# 20         Flightline                    2
# ...

# %%
df.groupby("Year").agg(flights_per_year=('Origin Place','count')).reset_index()
# Out:
#     Year  flights_per_year
# 0   1983                 2
# 1   1985                 2
# 2   1987                 2
# 3   1990                 2
# 4   1996                 2
# 5   1997                 2
# 6   1998                 2
# 7   1999                 2
# 8   2000                 2
# 9   2001                 2
# 10  2002                 2
# 11  2003                 3
# 12  2004                 4
# 13  2005                 8
# 14  2006                 2
# 15  2008                 6
# 16  2009                 9
# 17  2011                 2
# 18  2012                14
# 19  2013                11
# 20  2014                12
# 21  2015                24
# 22  2016                21
# 23  2017                42
# 24  2018                27
# 25  2019                 8
# 26  2020                 2
# 27  2022                10

# %%
df.groupby("Origin Place").agg(start_destination=('Year','count')).reset_index().sort_values(by=["start_destination"],ascending=False).head(25)
# Out:
#       Origin Place  start_destination
# 26          Geneva                 61
# 71          Zurich                 20
# 38          London                 12
# 53           Paris                  9
# 46          Munich                  9
# 68          Vienna                  8
# 25       Frankfurt                  7
# 40          Madrid                  7
# 11        Brussels                  7
# 6   Basel/Mulhouse                  5
# 58            Rome                  4
# 30           Ibiza                  3
# 24      Dusseldorf                  3
# 8           Berlin                  3
# 37          Lisbon                  2
# 17      Copenhagen                  2
# 47          Napoli                  2
# 22           Dubai                  2
# 70   Washington DC                  2
# 69          Warsaw                  2
# 4           Athens                  2
# 15         Chicago                  2
# 5        Barcelona                  2
# 13           Cairo                  2
# ...

# %%
df.loc[(df["End Transfer Airport"]==1) & (df["Destination Place"]=="Geneva")]
# Out:
# Empty DataFrame
# Columns: [Date, Year, Origin Place, Origin Country, Origin Airport, Destination Place, Destination Country, Destination Airport, Airline, LongDistanceFlight, End Transfer Airport, Start Transfer Airport, Co-Travellers, Number of Co-Travellers, flag]
# Index: []

# %%
df.loc[df["Start Transfer Airport"]==0].groupby("Origin Place").agg(
    start_destination=('Year','count')).sort_values(
    by=["start_destination"],ascending=False).reset_index().head(25)
# Out:
#       Origin Place  start_destination
# 0           Geneva                 61
# 1           Zurich                 13
# 2           London                  7
# 3           Vienna                  6
# 4   Basel/Mulhouse                  5
# 5           Madrid                  5
# 6             Rome                  4
# 7           Munich                  4
# 8         Brussels                  4
# 9           Berlin                  3
# 10           Ibiza                  3
# 11       Frankfurt                  3
# 12      Copenhagen                  2
# 13          Venice                  2
# 14          Napoli                  2
# 15      Dusseldorf                  2
# 16          Lisbon                  2
# 17         Chicago                  2
# 18           Cairo                  2
# 19          Athens                  2
# 20       Barcelona                  2
# 21         Croatia                  1
# 22  Salt Lake City                  1
# 23            Nice                  1
# ...

# %%
df.loc[df["Start Transfer Airport"]==0].groupby("Origin Country").agg(
    origin_destination_per_country=('Year','count')).sort_values(
    by=["origin_destination_per_country"],ascending=False).reset_index().head(25)
# Out:
#     Origin Country  origin_destination_per_country
# 0      Switzerland                              78
# 1          Germany                              16
# 2            Spain                              14
# 3            Italy                              10
# 4              USA                               9
# 5   United Kingdom                               8
# 6          Austria                               7
# 7           France                               4
# 8          Belgium                               4
# 9           Turkey                               3
# 10           Egypt                               3
# 11           China                               2
# 12         Denmark                               2
# 13        Portugal                               2
# 14         Morocco                               2
# 15          Greece                               2
# 16          Latvia                               1
# ...

# %%
df.loc[df["End Transfer Airport"]==0].groupby("Destination Country").agg(
    end_destination_per_country=('Year','count')).sort_values(
    by=["end_destination_per_country"],ascending=False).reset_index().head(25)
# Out:
#    Destination Country  end_destination_per_country
# 0          Switzerland                           78
# 1              Germany                           15
# 2                Spain                           14
# 3                  USA                           10
# 4                Italy                           10
# 5              Austria                            8
# 6       United Kingdom                            8
# 7              Belgium                            4
# 8               France                            4
# 9                Egypt                            3
# 10              Turkey                            3
# 11              Greece                            2
# 12               China                            2
# 13             Denmark                            2
# 14             Morocco                            2
# 15            Portugal                            2
# 16             Estonia                            1
# ...

# %%
df.loc[df["End Transfer Airport"]==0].groupby("Destination Place").agg(
    end_destination=('Year','count')).sort_values(
    by=["end_destination"],ascending=False).reset_index().head(25)
# Out:
#     Destination Place  end_destination
# 0              Geneva               62
# 1              Zurich               11
# 2              London                7
# 3              Vienna                7
# 4              Munich                5
# 5      Basel/Mulhouse                5
# 6              Madrid                5
# 7                Rome                4
# 8            Brussels                4
# 9               Ibiza                3
# 10          Frankfurt                3
# 11            Chicago                3
# 12             Berlin                3
# 13              Cairo                2
# 14         Copenhagen                2
# 15         Dusseldorf                2
# 16             Venice                2
# 17          Barcelona                2
# 18             Lisbon                2
# 19             Athens                2
# 20  Palma de Mallorca                1
# 21              Paris                1
# 22      Phildadelphia                1
# ...

# %%
df.loc[df["End Transfer Airport"]==1].groupby("Destination Place").agg(
    start_destination=('Year','count')).sort_values(
    by=["start_destination"],ascending=False).reset_index().head(25)
# Out:
#    Destination Place  start_destination
# 0              Paris                  8
# 1             Zurich                  7
# 2             London                  5
# 3             Munich                  5
# 4          Frankfurt                  4
# 5           Brussels                  3
# 6              Dubai                  2
# 7             Madrid                  2
# 8             Vienna                  2
# 9         Cincinatti                  1
# 10           Detroit                  1
# 11        Dusseldorf                  1
# 12             Izmir                  1
# 13            Newark                  1
# 14            Warsaw                  1
# 15     Washington DC                  1

# %%
df[(df['Date'].dt.year>1980)].groupby(pd.Grouper(key="Date", freq="1M")).count()["Origin Place"].plot(
    title="Flights per month",figsize=(15,5),
    ylabel="Flights",ylim=(0,12))
# Out:
# <AxesSubplot: title={'center': 'Flights per month'}, xlabel='Date', ylabel='Flights'>

# %%
df[(df['Date'].dt.year>1980) & (df['Date'].dt.year<2021)].groupby(pd.Grouper(key="Date", freq="1M")).count()["Origin Place"].plot(
    title="Flights per month",figsize=(15,5),
    ylabel="Flights",ylim=(0,12))
# Out:
# <AxesSubplot: title={'center': 'Flights per month'}, xlabel='Date', ylabel='Flights'>

# %%
df.groupby(["Number of Co-Travellers"]).agg(flight_with_people=('Year','count')).sort_values(by='flight_with_people',ascending=False).reset_index()
# Out:
#    Number of Co-Travellers  flight_with_people
# 0                        0                 128
# 1                        1                  32
# 2                        3                  26
# 3                        2                  17
# 4                        4                  12
# 5                        5                  12

# %%
string_traveller1="Riju"
string_traveller2="Reyer"
string_traveller3="Rachel"
#df_test[(df_test['Co-Travellers'].str.contains('Rachel'))]
count=0
#df_test["flag"]=np.where("")
for ind,test in enumerate(df['Co-Travellers'].values):
    if string_traveller1 in test and string_traveller2 in test and string_traveller3 in test:
        count+=1
print(count)
# Out:
# 6

# %%
df['Destination Airport'].unique()
# Out:
# array(['IBZ', 'ZHR', 'PMI', 'ZRH', 'STN', 'FCO', 'CDG', 'BSL/MLH', 'ATH',
#        'AYT', 'FRA', 'AGP', 'AGA', 'ADB', 'BJV', 'STR', 'MIR', 'LTN',
#        'CAI', 'LXR', 'MAD', 'LIS', 'PHL', 'GVA', 'CVG', 'ORD', 'DTW',
#        'JFK', 'VIE', 'EWR', 'IAD', 'PRG', 'SXF', 'WAW', 'BRU', 'AMS',
#        'ARN', 'CPH', 'DUS', 'VCE', 'MUC', 'LGW', 'IST', 'NAP', 'LHR',
#        'LAX', 'NCE', 'LED', 'CTA', 'BCN', 'BIO', 'LAS', 'DCA', 'DFW',
#        'SCQ', 'HND', 'DUB', 'IEV', 'SLC', 'OSL', 'SPU', 'WAR', 'TLL',
#        'RAK', 'PVG', 'HKG', 'TLS', 'RKV', 'EDI', 'DBX', 'ICN', 'HAJ',
#        'BER', 'MXP', 'RIX'], dtype=object)

# %%
df_end=df.groupby("Destination Airport").agg(Landings=("Origin Airport","count")).sort_values(
    by="Landings",ascending=False).reset_index()
df_end=df_end.rename(columns={"Destination Airport":"Airport"})
df_end.head(15)
# Out:
#     Airport  Landings
# 0       GVA        64
# 1       ZRH        16
# 2       MUC        10
# 3       CDG         9
# 4       VIE         9
# 5       FRA         7
# 6       BRU         7
# 7       MAD         7
# 8       LGW         5
# 9   BSL/MLH         5
# 10      LHR         4
# 11      FCO         4
# 12      ORD         3
# 13      IBZ         3
# 14      DUS         3

# %%
df_start=df.groupby("Origin Airport").agg(Starts=("Destination Airport","count")).sort_values(
    by="Starts",ascending=False).reset_index()
df_start=df_start.rename(columns={"Origin Airport":"Airport"})
df_start.head(15)
# Out:
#     Airport  Starts
# 0       GVA      61
# 1       ZRH      20
# 2       MUC       9
# 3       CDG       9
# 4       VIE       8
# 5       BRU       7
# 6       FRA       7
# 7       MAD       7
# 8   BSL/MLH       5
# 9       LGW       5
# 10      FCO       4
# 11      LHR       4
# 12      DUS       3
# 13      IBZ       3
# 14      LTN       2

# %%
df_air=df_end.merge(df_start,how="outer",on="Airport")
df_air["Starts"]=df_air["Starts"].fillna(0)
df_air["Landings"]=df_air["Landings"].fillna(0)
df_air["Flight Movements"]=df_air["Starts"]+df_air["Landings"]
df_air.sort_values(by="Flight Movements",ascending=False).reset_index().head(20)
# Out:
#     index  Airport  Landings  Starts  Flight Movements
# 0       0      GVA      64.0    61.0             125.0
# 1       1      ZRH      16.0    20.0              36.0
# 2       2      MUC      10.0     9.0              19.0
# 3       3      CDG       9.0     9.0              18.0
# 4       4      VIE       9.0     8.0              17.0
# 5       5      FRA       7.0     7.0              14.0
# 6       6      BRU       7.0     7.0              14.0
# 7       7      MAD       7.0     7.0              14.0
# 8       9  BSL/MLH       5.0     5.0              10.0
# 9       8      LGW       5.0     5.0              10.0
# 10     10      LHR       4.0     4.0               8.0
# 11     11      FCO       4.0     4.0               8.0
# 12     13      IBZ       3.0     3.0               6.0
# 13     14      DUS       3.0     3.0               6.0
# 14     12      ORD       3.0     2.0               5.0
# 15     20      NAP       2.0     2.0               4.0
# ...

# %%
df.groupby(["Origin Airport","Destination Airport"]).agg(flight_leg=("Year","count")).sort_values(
    by="flight_leg",ascending=False).reset_index().head(20)
# Out:
#    Origin Airport Destination Airport  flight_leg
# 0             GVA                 MUC           7
# 1             ZRH                 GVA           6
# 2             MUC                 GVA           6
# 3             GVA                 BRU           6
# 4             LGW                 GVA           5
# 5             BRU                 GVA           5
# 6             GVA                 LGW           4
# 7             GVA                 MAD           4
# 8             MAD                 GVA           4
# 9             CDG                 GVA           4
# 10            GVA                 FCO           3
# 11            ZRH                 IBZ           3
# 12            GVA                 FRA           3
# 13            GVA                 CDG           3
# 14            FCO                 GVA           3
# 15            FRA                 GVA           3
# 16            GVA                 LHR           2
# 17            GVA                 DUS           2
# ...
