# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime

# %%
data_list=[]
#1996
data_list.append([datetime.datetime(1996, 8, 24),1,"Somerset House",'London',"United Kingdom",'Lauchringen','London',"",['Heidrun','Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1996, 8, 24),1,"British Museum",'London',"United Kingdom",'Lauchringen','London',"",['Artur']])
data_list.append([datetime.datetime(1996, 8, 25),1,"Westminster Cathedral",'London',"United Kingdom",'London','London',"",['Heidrun','Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1996, 8, 25),1,"National Gallery",'London',"United Kingdom",'London','London',"",['Heidrun','Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1996, 8, 25),1,"St Martin in the Fields",'London',"United Kingdom",'London','London',"",['Heidrun','Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1996, 8, 25),1,"British Museum",'London',"United Kingdom",'London','London',"",['Heidrun','Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1996, 8, 26),2,"Westminster Cathedral",'London',"United Kingdom",'London','London',"",['Heidrun','Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1996, 8, 26),1,"Westminster Abbey",'London',"United Kingdom",'London','London',"Palace of Westminster and Westminster Abbey including Saint Margaret’s Church",['Heidrun','Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1996, 8, 27),5,"Hampton Court Palace",'London',"United Kingdom",'London','London',"",['Heidrun','Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1996, 8, 28),5,"Tower of London",'London',"United Kingdom",'London','London',"Tower of London",['Heidrun','Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1996, 8, 28),5,"Tower Bridge",'London',"United Kingdom",'London','London',"",['Heidrun','Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1996, 8, 28),2,"St Paul's Cathedral",'London',"United Kingdom",'London','London',"",['Heidrun','Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1996, 8, 28),1,"London Monument",'London',"United Kingdom",'London','London',"",['Heidrun','Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1996, 8, 28),1,"Marble Arch",'London',"United Kingdom",'London','London',"",['Heidrun','Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1996, 8, 28),1,"Kensington Palace",'London',"United Kingdom",'London','London',"",['Heidrun','Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1996, 8, 28),1,"Royal Albert Hall",'London',"United Kingdom",'London','London',"",['Heidrun','Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1996, 8, 28),1,"Harrods",'London',"United Kingdom",'London','London',"",['Heidrun','Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1996, 8, 28),13,"Westminster Abbey",'London',"United Kingdom",'London','London',"Palace of Westminster and Westminster Abbey including Saint Margaret’s ChurchWestminster",['Artur']])
data_list.append([datetime.datetime(1996, 8, 29),1,"Old Royal Naval College",'London',"United Kingdom",'London','London',"Maritime Greenwich",['Heidrun','Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1996, 8, 29),2,"Queen's House",'London',"United Kingdom",'London','London',"Maritime Greenwich",['Heidrun','Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1996, 8, 29),3,"Greenwich Observatory",'London',"United Kingdom",'London','London',"Maritime Greenwich",['Heidrun','Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1996, 8, 29),1,"Thames Barrier",'London',"United Kingdom",'London','London',"Maritime Greenwich",['Heidrun','Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1996, 8, 30),0,"Buckingham Palace",'London',"United Kingdom",'London','London',"",['Heidrun','Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1996, 8, 30),1,"Whitehall Horse Guards",'London',"United Kingdom",'London','London',"",['Heidrun','Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1996, 8, 30),1,"Banqueting House",'London',"United Kingdom",'London','London',"",['Heidrun','Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1996, 8, 30),1,"St James's Palace",'London',"United Kingdom",'London','London',"",['Heidrun','Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1996, 8, 30),2,"Piccadilly Circus",'London',"United Kingdom",'London','London',"",['Heidrun','Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1996, 8, 31),3,"Madam Tussauds",'London',"United Kingdom",'London','London',"",['Heidrun','Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(1996, 8, 31),1,"BT Tower",'London',"United Kingdom",'London','London',"",['Heidrun','Artur','Anne-Kathrin','Hannsjoerg']])

# %%
#2002
data_list.append([datetime.datetime(2002, 5, 26),0,"Duomo di San Gimignano",'San Gimignano',"Italy",'Montaione','Montaione',"San Gigmigano",['Heidrun','Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(2002, 5, 26),0,"Torre del Diavolo",'San Gimignano',"Italy",'Montaione','Montaione',"San Gigmigano",['Heidrun','Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(2002, 5, 26),13,"Duomo",'Siena',"Italy",'Montaione','Montaione',"Siena",['Heidrun','Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(2002, 5, 26),1,"San Domenico",'Siena',"Italy",'Montaione','Montaione',"Siena",['Heidrun','Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(2002, 5, 26),1,"Palazzo Pubblico",'Siena',"Italy",'Montaione','Montaione',"Siena",['Heidrun','Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(2002, 5, 26),1,"Piazza Salimbeni",'Siena',"Italy",'Montaione','Montaione',"Siena",['Heidrun','Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(2002, 5, 27),2,"San Lorenzo",'Florence',"Italy",'Montaione','Montaione',"Florence",['Heidrun','Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(2002, 5, 27),2,"Palazzo Medici Riccardi",'Florence',"Italy",'Montaione','Montaione',"Florence",['Heidrun','Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(2002, 5, 27),2,"Baptistery",'Florence',"Italy",'Montaione','Montaione',"Florence",['Heidrun','Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(2002, 5, 27),9,"Duomo",'Florence',"Italy",'Montaione','Montaione',"Florence",['Heidrun','Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(2002, 5, 27),1,"Palazzo Vecchio",'Florence',"Italy",'Montaione','Montaione',"Florence",['Heidrun','Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(2002, 5, 27),1,"Uffizi",'Florence',"Italy",'Montaione','Montaione',"Florence",['Heidrun','Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(2002, 5, 27),3,"Santa Croce",'Florence',"Italy",'Montaione','Montaione',"Florence",['Heidrun','Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(2002, 5, 27),2,"Ponte Vecchio",'Florence',"Italy",'Montaione','Montaione',"Florence",['Heidrun','Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(2002, 5, 27),2,"San Spirito",'Florence',"Italy",'Montaione','Montaione',"Florence",['Heidrun','Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(2002, 5, 27),1,"Boboli Gardens",'Florence',"Italy",'Montaione','Montaione',"Florence",['Heidrun','Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(2002, 5, 27),2,"Palazzo Pitti",'Florence',"Italy",'Montaione','Montaione',"Florence",['Heidrun','Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(2002, 5, 27),1,"Santa Maria Novella",'Florence',"Italy",'Montaione','Montaione',"Florence",['Heidrun','Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(2002, 5, 28),4,"Baptistery",'Pisa',"Italy",'Montaione','Montaione',"Piazza del Duomo, PisaPisa",['Heidrun','Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(2002, 5, 28),21,"Duomo",'Pisa',"Italy",'Montaione','Montaione',"Piazza del Duomo, Pisa",['Heidrun','Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(2002, 5, 28),3,"Camposanto Monumentale",'Pisa',"Italy",'Montaione','Montaione',"Piazza del Duomo, Pisa",['Heidrun','Artur','Anne-Kathrin','Hannsjoerg']])
data_list.append([datetime.datetime(2002, 5, 28),0,"",'Volterra',"Italy",'Montaione','Montaione',"",['Heidrun','Artur','Anne-Kathrin','Hannsjoerg']])

# %%
#2006
#zurich done
data_list.append([datetime.datetime(2006, 10, 6),6,"ETH Hoenggerberg",'Zurich',"Switzerland",'Lauchringen','Lauchringen',"",[]])
data_list.append([datetime.datetime(2006, 10, 6),8,"ETH Zentrum",'Zurich',"Switzerland",'Lauchringen','Lauchringen',"",['Anne','Sigi']])
data_list.append([datetime.datetime(2006, 10, 6),1,"Fraumuenster",'Zurich',"Switzerland",'Lauchringen','Lauchringen',"",['Anne','Sigi']])
data_list.append([datetime.datetime(2006, 10, 6),4,"Grossmuenster",'Zurich',"Switzerland",'Lauchringen','Lauchringen',"",['Anne','Sigi']])
data_list.append([datetime.datetime(2006, 10, 6),2,"Urania Observatory",'Zurich',"Switzerland",'Lauchringen','Lauchringen',"",['Anne','Sigi']])
data_list.append([datetime.datetime(2006, 10, 10),3,"Hauptbahnhof",'Zurich',"Switzerland",'Lauchringen','Lauchringen',"",['Hannsjoerg']])
data_list.append([datetime.datetime(2006, 10, 10),7,"ETH Zentrum",'Zurich',"Switzerland",'Lauchringen','Lauchringen',"",['Hannsjoerg']])
data_list.append([datetime.datetime(2006, 10, 10),2,"Grossmuenster",'Zurich',"Switzerland",'Lauchringen','Lauchringen',"",['Hannsjoerg']])
data_list.append([datetime.datetime(2006, 10, 10),1,"Paradeplatz",'Zurich',"Switzerland",'Lauchringen','Lauchringen',"",['Hannsjoerg']])
data_list.append([datetime.datetime(2006, 10, 10),1,"ETH Hoenggerberg",'Zurich',"Switzerland",'Lauchringen','Lauchringen',"",['Hannsjoerg']])

# %%
#2007
#zurich done
data_list.append([datetime.datetime(2007, 3, 21),2,"University",'Zurich',"Switzerland",'Lauchringen','Lauchringen',"",[]])
data_list.append([datetime.datetime(2007, 3, 21),6,"ETH Zentrum",'Zurich',"Switzerland",'Lauchringen','Lauchringen',"",[]])
data_list.append([datetime.datetime(2007, 3, 21),14,"Fraumuenster",'Zurich',"Switzerland",'Lauchringen','Lauchringen',"",[]])
data_list.append([datetime.datetime(2007, 3, 21),13,"Grossmuenster",'Zurich',"Switzerland",'Lauchringen','Lauchringen',"",[]])
data_list.append([datetime.datetime(2007, 3, 21),1,"Wasserkirche",'Zurich',"Switzerland",'Lauchringen','Lauchringen',"",[]])
data_list.append([datetime.datetime(2007, 3, 21),2,"Rathaus",'Zurich',"Switzerland",'Lauchringen','Lauchringen',"",[]])
data_list.append([datetime.datetime(2007, 3, 21),7,"St Peter",'Zurich',"Switzerland",'Lauchringen','Lauchringen',"",[]])
data_list.append([datetime.datetime(2007, 3, 21),5,"Limmmathof",'Zurich',"Switzerland",'Lauchringen','Lauchringen',"",[]])
data_list.append([datetime.datetime(2007, 3, 21),3,"Predigerkirche",'Zurich',"Switzerland",'Lauchringen','Lauchringen',"",[]])

# %%
#2008
data_list.append([datetime.datetime(2008, 7, 29),20,"Cathedral St Peter & Paul",'Philadelphia',"USA",'Philadelphia','Philadelphia',"",[]])
data_list.append([datetime.datetime(2008, 7, 29),3,"Independence Hall",'Philadelphia',"USA",'Philadelphia','Philadelphia',"Independence Hall",[]])
data_list.append([datetime.datetime(2008, 7, 29),4,"Carpenters Hall",'Philadelphia',"USA",'Philadelphia','Philadelphia',"",[]])
data_list.append([datetime.datetime(2008, 7, 29),7,"National Liberty Museum",'Philadelphia',"USA",'Philadelphia','Philadelphia',"",[]])
data_list.append([datetime.datetime(2008, 7, 30),5,"Cira Center",'Philadelphia',"USA",'Philadelphia','Philadelphia',"",[]])
data_list.append([datetime.datetime(2008, 7, 30),1,"Drexel University",'Philadelphia',"USA",'Philadelphia','Philadelphia',"",[]])
data_list.append([datetime.datetime(2008, 8, 2),1,"Cira Center",'Philadelphia',"USA",'Philadelphia','Philadelphia',"",[]])
data_list.append([datetime.datetime(2008, 8, 4),5,"Philadelphia Museum of Art",'Philadelphia',"USA",'Philadelphia','Philadelphia',"",[]])
data_list.append([datetime.datetime(2008, 8, 4),4,"Washington Monument",'Philadelphia',"USA",'Philadelphia','Philadelphia',"",[]])
data_list.append([datetime.datetime(2008, 8, 4),8,"Irvine Auditorium",'Philadelphia',"USA",'Philadelphia','Philadelphia',"",[]])

#zurich done
data_list.append([datetime.datetime(2008, 11, 28),1,"ETH Zentrum",'Zurich',"Switzerland",'Geneva','Lauchringen',"",[]])
data_list.append([datetime.datetime(2008, 11, 28),2,"Hauptbahnhof",'Zurich',"Switzerland",'Geneva','Lauchringen',"",[]])

# %%
#2009
#zurich done
data_list.append([datetime.datetime(2009, 1, 21),1,"ETH Zentrum",'Zurich',"Switzerland",'Geneva','Lauchringen',"",[]])
data_list.append([datetime.datetime(2009, 1, 21),4,"Fraumuenster",'Zurich',"Switzerland",'Geneva','Lauchringen',"",[]])

# %%
#paris 2010
data_list.append([datetime.datetime(2010,7,21),1,"Opera de Bastille","Paris","France","Geneva","Paris","",[]])
data_list.append([datetime.datetime(2010,7,21),1,"Place de la Bastille","Paris","France","Geneva","Paris","",[]])
data_list.append([datetime.datetime(2010,7,21),3,"St Paul & St Louis","Paris","France","Geneva","Paris","",[]])
data_list.append([datetime.datetime(2010,7,21),4,"Hotel de Ville",'Paris',"France",'Geneva','Paris',"Paris, Banks of the Seine",[]])
data_list.append([datetime.datetime(2010,7,21),38,"Notre Dame",'Paris',"France",'Geneva','Paris',"Paris, Banks of the Seine",[]])
data_list.append([datetime.datetime(2010,7,21),1,"Place du Chatelet",'Paris',"France",'Geneva','Paris',"Paris, Banks of the Seine",[]])
data_list.append([datetime.datetime(2010,7,21),7,"Conciergerie",'Paris',"France",'Geneva','Paris',"Paris, Banks of the Seine",[]])
data_list.append([datetime.datetime(2010,7,21),2,"Palais de Justice",'Paris',"France",'Geneva','Paris',"Paris, Banks of the Seine",[]])
data_list.append([datetime.datetime(2010,7,21),27,"Sainte Chapelle",'Paris',"France",'Geneva','Paris',"Paris, Banks of the Seine",[]])
data_list.append([datetime.datetime(2010,7,21),20,"Pantheon",'Paris',"France",'Geneva','Paris',"",[]])
data_list.append([datetime.datetime(2010,7,21),2,"Tour Eiffel",'Paris',"France",'Geneva','Paris',"Paris, Banks of the Seine",[]])
data_list.append([datetime.datetime(2010,7,21),1,"St Etienne-du-Mont",'Paris',"France",'Geneva','Paris',"",[]])
data_list.append([datetime.datetime(2010,7,21),2,"Palais du Luxembourg",'Paris',"France",'Geneva','Paris',"",[]])
data_list.append([datetime.datetime(2010,7,21),3,"Jardin du Luxembourg",'Paris',"France",'Geneva','Paris',"",[]])
data_list.append([datetime.datetime(2010,7,21),1,"Tour Montparnasse",'Paris',"France",'Geneva','Paris',"",[]])
data_list.append([datetime.datetime(2010,7,21),2,"Chapelle de l'Epiphanie",'Paris',"France",'Geneva','Paris',"",[]])
data_list.append([datetime.datetime(2010,7,21),2,"St Francois-Xavier",'Paris',"France",'Geneva','Paris',"",[]])
data_list.append([datetime.datetime(2010,7,21),39,"Hotel d'Invalides",'Paris',"France",'Geneva','Paris',"Paris, Banks of the Seine",[]])
data_list.append([datetime.datetime(2010,7,21),4,"Pont Alexandre III",'Paris',"France",'Geneva','Paris',"Paris, Banks of the Seine",[]])
data_list.append([datetime.datetime(2010,7,21),1,"Palais Bourbon",'Paris',"France",'Geneva','Paris',"Paris, Banks of the Seine",[]])
data_list.append([datetime.datetime(2010,7,21),1,"Place de la Concorde",'Paris',"France",'Geneva','Paris',"Paris, Banks of the Seine",[]])
data_list.append([datetime.datetime(2010,7,21),4,"La Madelaine",'Paris',"France",'Geneva','Paris',"Paris, Banks of the Seine",[]])
data_list.append([datetime.datetime(2010,7,21),56,"Opera Garnier",'Paris',"France",'Geneva','Paris',"",[]])
data_list.append([datetime.datetime(2010,7,21),1,"Palais Royal",'Paris',"France",'Geneva','Paris',"",[]])
data_list.append([datetime.datetime(2010,7,21),11,"Louvre",'Paris',"France",'Geneva','Paris',"Paris, Banks of the Seine",[]])
data_list.append([datetime.datetime(2010,7,21),3,"Saint-Germain-l'Auxerrois",'Paris',"France",'Geneva','Paris',"Paris, Banks of the Seine",[]])
data_list.append([datetime.datetime(2010,7,22),4,"Notre Dame",'Paris',"France",'Paris','Paris',"Paris, Banks of the Seine",[]])
data_list.append([datetime.datetime(2010,7,22),1,"St Paul & St Louis","Paris","France","Paris","Paris","",[]])
data_list.append([datetime.datetime(2010,7,23),3,"Hotel de Ville",'Paris',"France",'Paris','Paris',"Paris, Banks of the Seine",[]])
data_list.append([datetime.datetime(2010,7,23),2,"Tour St Jacques",'Paris',"France",'Paris','Paris',"Routes of Santiago de Compostela",[]])
data_list.append([datetime.datetime(2010,7,23),1,"Place du Chatelet",'Paris',"France",'Paris','Paris',"Paris, Banks of the Seine",[]])
data_list.append([datetime.datetime(2010,7,23),1,"Conciergerie",'Paris',"France",'Paris','Paris',"Paris, Banks of the Seine",[]])
data_list.append([datetime.datetime(2010,7,23),3,"Tour Eiffel",'Paris',"France",'Paris','Paris',"Paris, Banks of the Seine",[]])
data_list.append([datetime.datetime(2010,7,23),1,"Pont Neuf",'Paris',"France",'Paris','Paris',"Paris, Banks of the Seine",[]])
data_list.append([datetime.datetime(2010,7,23),16,"Louvre",'Paris',"France",'Paris','Paris',"Paris, Banks of the Seine",[]])
data_list.append([datetime.datetime(2010,7,23),1,"Saint-Germain-l'Auxerrois",'Paris',"France",'Paris','Paris',"Paris, Banks of the Seine",[]])
data_list.append([datetime.datetime(2010,7,23),1,"Arc du Carrousel",'Paris',"France",'Paris','Paris',"Paris, Banks of the Seine",[]])
data_list.append([datetime.datetime(2010,7,23),1,"Place des Pyramides",'Paris',"France",'Paris','Paris',"",[]])
data_list.append([datetime.datetime(2010,7,23),2,"Opera Garnier",'Paris',"France",'Paris','Paris',"",[]])
data_list.append([datetime.datetime(2010,7,24),1,"Institut de France",'Paris',"France",'Paris','Paris',"Paris, Banks of the Seine",[]])
data_list.append([datetime.datetime(2010,7,24),1,"Pont Neuf",'Paris',"France",'Paris','Paris',"Paris, Banks of the Seine",[]])
data_list.append([datetime.datetime(2010,7,25),119,"Chateau de Versailles","Versailles","France",'Paris','Paris',"Palace and Park of Versailles",[]])
data_list.append([datetime.datetime(2010,7,25),65,"Chateau de Versailles Gardens","Versailles","France",'Paris','Paris',"Palace and Park of Versailles",[]])
data_list.append([datetime.datetime(2010,7,25),28,"Chateau de Versailles Grand Trianon","Versailles","France",'Paris','Paris',"Palace and Park of Versailles",[]])
data_list.append([datetime.datetime(2010,7,25),4,"Chateau de Versailles Grand Trianon Garden","Versailles","France",'Paris','Paris',"Palace and Park of Versailles",[]])
data_list.append([datetime.datetime(2010,7,25),11,"Chateau de Versailles Petit Trianon","Versailles","France",'Paris','Paris',"Palace and Park of Versailles",[]])
data_list.append([datetime.datetime(2010,7,25),19,"Chateau de Versailles Petit Trianon Garden & Hameau","Versailles","France",'Paris','Paris',"Palace and Park of Versailles",[]])
data_list.append([datetime.datetime(2010,7,25),14,"Cathedral","Versailles","France",'Paris','Paris',"",[]])
data_list.append([datetime.datetime(2010,7,26),2,"Museum of Natural History",'Paris',"France",'Paris','Paris',"",[]])
data_list.append([datetime.datetime(2010,7,26),2,"Grand Mosque",'Paris',"France",'Paris','Paris',"",[]])
data_list.append([datetime.datetime(2010,7,26),1,"Place de la Bastille","Paris","France","Paris","Paris","",[]])
data_list.append([datetime.datetime(2010,7,26),7,"Notre Dame",'Paris',"France",'Paris','Paris',"Paris, Banks of the Seine",[]])
data_list.append([datetime.datetime(2010,7,26),2,"Hotel de Ville",'Paris',"France",'Paris','Paris',"Paris, Banks of the Seine",[]])
data_list.append([datetime.datetime(2010,7,27),3,"Palais des Congress",'Paris',"France",'Paris','Paris',"Paris, Banks of the Seine",[]])
data_list.append([datetime.datetime(2010,7,29),86,"Cathedral","Chartres","France","Paris","Paris","Chartres Cathedral",[]])
data_list.append([datetime.datetime(2010,7,29),1,"Palais Episcopal","Chartres","France","Paris","Paris","",[]])
data_list.append([datetime.datetime(2010,7,29),8,"St Pierre","Chartres","France","Paris","Paris","",[]])
data_list.append([datetime.datetime(2010,7,29),8,"St Aignan","Chartres","France","Paris","Paris","",[]])
data_list.append([datetime.datetime(2010,7,30),73,"Chateau de Fontainebleau",'Fontainebleau',"France",'Paris','Paris',"Palace and Park of Fontainebleau",['Artur','Heidrun']])
data_list.append([datetime.datetime(2010,7,30),10,"Chateau de Fontainebleau Gardens",'Fontainebleau',"France",'Paris','Paris',"Palace and Park of Fontainebleau",['Artur','Heidrun']])
data_list.append([datetime.datetime(2010,7,30),2,"Hotel d'Invalides",'Paris',"France",'Paris','Paris',"Paris, Banks of the Seine",['Artur','Heidrun']])
data_list.append([datetime.datetime(2010,7,30),8,"Tour Eiffel",'Paris',"France",'Paris','Paris',"Paris, Banks of the Seine",['Artur','Heidrun']])
data_list.append([datetime.datetime(2010,7,30),44,"Tour Montparnasse Observatory",'Paris',"France",'Paris','Paris',"",['Artur','Heidrun']])
data_list.append([datetime.datetime(2010,7,30),5,"Notre Dame",'Paris',"France",'Paris','Paris',"Paris, Banks of the Seine",['Artur','Heidrun']])
data_list.append([datetime.datetime(2010,7,30),3,"St Sulpice",'Paris',"France",'Paris','Paris',"",['Artur','Heidrun']])
data_list.append([datetime.datetime(2010,7,30),1,"Centre Pompidou",'Paris',"France",'Paris','Paris',"",['Artur','Heidrun']])
data_list.append([datetime.datetime(2010,7,30),5,"Louvre",'Paris',"France",'Paris','Paris',"Paris, Banks of the Seine",['Artur','Heidrun']])
data_list.append([datetime.datetime(2010,7,30),2,"Place de la Concorde",'Paris',"France",'Paris','Paris',"Paris, Banks of the Seine",['Artur','Heidrun']])
data_list.append([datetime.datetime(2010,7,30),1,"Tour Montparnasse",'Paris',"France",'Paris','Paris',"",['Artur','Heidrun']])
data_list.append([datetime.datetime(2010,7,31),41,"Chateau des Vincennes",'Vincennes',"France",'Paris','Paris',"",['Artur','Heidrun']])
data_list.append([datetime.datetime(2010,7,31),4,"Stade de France",'St Denis',"France",'Paris','Paris',"",['Artur','Heidrun']])
data_list.append([datetime.datetime(2010,7,31),70,"Basilique de St Denis",'St Denis',"France",'Paris','Geneva',"",['Andrew']])
data_list.append([datetime.datetime(2010,7,31),1,"Hotel de Ville",'St Denis',"France",'Paris','Geneva',"",['Andrew']])
data_list.append([datetime.datetime(2010,7,31),1,"Cite de Science et de l'Industrie",'Paris',"France",'Paris','Paris',"",['Artur','Heidrun']])
data_list.append([datetime.datetime(2010,7,31),23,"La Defense",'Puteaux',"France",'Paris','Paris',"",['Artur','Heidrun']])
data_list.append([datetime.datetime(2010,7,31),9,"Arc de Triomphe",'Paris',"France",'Paris','Paris',"",['Artur','Heidrun']])
data_list.append([datetime.datetime(2010,8,1),100,"Louvre",'Paris',"France",'Paris','Paris',"Paris, Banks of the Seine",['Artur','Heidrun']])
data_list.append([datetime.datetime(2010,8,1),1,"Arc du Carrousel",'Paris',"France",'Paris','Paris',"Paris, Banks of the Seine",['Artur','Heidrun']])
data_list.append([datetime.datetime(2010,8,1),2,"Musee d'Orsay",'Paris',"France",'Paris','Paris',"Paris, Banks of the Seine",['Artur','Heidrun']])
data_list.append([datetime.datetime(2010,8,1),1,"Grand Palais",'Paris',"France",'Paris','Paris',"Paris, Banks of the Seine",['Artur','Heidrun']])
data_list.append([datetime.datetime(2010,8,1),5,"Place de la Concorde",'Paris',"France",'Paris','Paris',"Paris, Banks of the Seine",['Artur','Heidrun']])
data_list.append([datetime.datetime(2010,8,1),29,"Orangerie",'Paris',"France",'Paris','Paris',"Paris, Banks of the Seine",['Artur','Heidrun']])
data_list.append([datetime.datetime(2010,8,1),1,"Jardin des Tuileries",'Paris',"France",'Paris','Paris',"Paris, Banks of the Seine",['Artur','Heidrun']])
data_list.append([datetime.datetime(2010,8,1),2,"Tour Eiffel",'Paris',"France",'Paris','Paris',"Paris, Banks of the Seine",['Artur','Heidrun']])
data_list.append([datetime.datetime(2010,8,1),40,"Centre Pompidou",'Paris',"France",'Paris','Paris',"",['Artur','Heidrun']])
data_list.append([datetime.datetime(2010,8,1),2,"Notre Dame",'Paris',"France",'Paris','Paris',"Paris, Banks of the Seine",['Artur','Heidrun']])
data_list.append([datetime.datetime(2010,8,1),2,"Bourse de Commerce",'Paris',"France",'Paris','Paris',"",['Artur','Heidrun']])
data_list.append([datetime.datetime(2010,8,1),1,"Sacre Coeur",'Paris',"France",'Paris','Paris',"",['Artur','Heidrun']])
data_list.append([datetime.datetime(2010,8,1),2,"St Eustache",'Paris',"France",'Paris','Paris',"",['Artur','Heidrun']])
data_list.append([datetime.datetime(2010,8,2),2,"Sacre Coeur",'Paris',"France",'Paris','Paris',"",['Artur','Heidrun']])
data_list.append([datetime.datetime(2010,8,2),1,"Tour Montparnasse",'Paris',"France",'Paris','Paris',"",['Artur','Heidrun']])
data_list.append([datetime.datetime(2010,8,2),2,"Pantheon",'Paris',"France",'Paris','Paris',"",['Artur','Heidrun']])
data_list.append([datetime.datetime(2010,8,2),6,"Palais Bourbon",'Paris',"France",'Paris','Paris',"Paris, Banks of the Seine",['Artur','Heidrun']])
data_list.append([datetime.datetime(2010,8,2),9,"La Madelaine",'Paris',"France",'Paris','Paris',"Paris, Banks of the Seine",['Artur','Heidrun']])
data_list.append([datetime.datetime(2010,8,2),16,"Place de la Concorde",'Paris',"France",'Paris','Paris',"Paris, Banks of the Seine",['Artur','Heidrun']])
data_list.append([datetime.datetime(2010,8,2),2,"Pont Alexandre III",'Paris',"France",'Paris','Paris',"Paris, Banks of the Seine",['Artur','Heidrun']])
data_list.append([datetime.datetime(2010,8,2),12,"Grand Palais",'Paris',"France",'Paris','Paris',"Paris, Banks of the Seine",['Artur','Heidrun']])
data_list.append([datetime.datetime(2010,8,2),4,"Petit Palais",'Paris',"France",'Paris','Paris',"Paris, Banks of the Seine",['Artur','Heidrun']])
data_list.append([datetime.datetime(2010,8,2),1,"Palais d'Elysee",'Paris',"France",'Paris','Paris',"Paris, Banks of the Seine",['Artur','Heidrun']])
data_list.append([datetime.datetime(2010,8,2),2,"Val de Grace",'Paris',"France",'Paris','Paris',"",['Artur','Heidrun']])
data_list.append([datetime.datetime(2010,8,2),2,"Palais du Luxembourg",'Paris',"France",'Paris','Paris',"",['Artur','Heidrun']])
data_list.append([datetime.datetime(2010,8,2),3,"Jardin du Luxembourg",'Paris',"France",'Paris','Paris',"",['Artur','Heidrun']])
data_list.append([datetime.datetime(2010,8,2),22,"St Sulpice",'Paris',"France",'Paris','Paris',"",['Artur','Heidrun']])
data_list.append([datetime.datetime(2010,8,2),21,"St Germain des Pres",'Paris',"France",'Paris','Paris',"",['Artur','Heidrun']])
data_list.append([datetime.datetime(2010,8,2),56,"Tour Eiffel",'Paris',"France",'Paris','Paris',"Paris, Banks of the Seine",['Artur','Heidrun']])
data_list.append([datetime.datetime(2010,8,2),4,"Palais de Chaillot",'Paris',"France",'Paris','Paris',"Paris, Banks of the Seine",['Artur','Heidrun']])
data_list.append([datetime.datetime(2010,8,2),3,"Ecole Militaire",'Paris',"France",'Paris','Paris',"Paris, Banks of the Seine",['Artur','Heidrun']])
data_list.append([datetime.datetime(2010,8,2),48,"Tour Eiffel Observatory",'Paris',"France",'Paris','Paris',"",['Artur','Heidrun']])
data_list.append([datetime.datetime(2010,8,2),5,"Hotel d'Invalides",'Paris',"France",'Paris','Paris',"Paris, Banks of the Seine",['Artur','Heidrun']])
data_list.append([datetime.datetime(2010,8,2),5,"Arc de Triomphe",'Paris',"France",'Paris','Paris',"",['Artur','Heidrun']])
data_list.append([datetime.datetime(2010,8,3),89,"Cathedral","Reims","France","Paris","Paris","Cathedral of Notre-Dame, Former Abbey of Saint-Remi and Palace of Tau, Reims",['Artur','Heidrun']])
data_list.append([datetime.datetime(2010,8,3),23,"Palais du Tau","Reims","France","Paris","Paris","Cathedral of Notre-Dame, Former Abbey of Saint-Remi and Palace of Tau, Reims",['Artur','Heidrun']])
data_list.append([datetime.datetime(2010,8,3),17,"Basilique St Remi","Reims","France","Paris","Paris","Cathedral of Notre-Dame, Former Abbey of Saint-Remi and Palace of Tau, Reims",['Artur','Heidrun']])
data_list.append([datetime.datetime(2010,8,3),3,"Hotel de Ville","Reims","France","Paris","Paris","",['Artur','Heidrun']])
data_list.append([datetime.datetime(2010,8,3),1,"Place Royale","Reims","France","Paris","Paris","",['Artur','Heidrun']])
data_list.append([datetime.datetime(2010,8,3),4,"Gallo-Roman Cryptoporticus","Reims","France","Paris","Paris","",['Artur','Heidrun']])
data_list.append([datetime.datetime(2010,8,3),2,"Porte Mars","Reims","France","Paris","Paris","",['Artur','Heidrun']])
data_list.append([datetime.datetime(2010,8,4),26,"Petit Palais",'Paris',"France",'Paris','Geneva',"Paris, Banks of the Seine",['Artur','Heidrun']])
data_list.append([datetime.datetime(2010,8,4),25,"Hotel de Cluny",'Paris',"France",'Paris','Geneva',"",['Artur','Heidrun']])
data_list.append([datetime.datetime(2010,8,4),1,"Notre Dame",'Paris',"France",'Paris','Geneva',"Paris, Banks of the Seine",['Artur','Heidrun']])
data_list.append([datetime.datetime(2010,8,4),5,"St Gervais & St Protais",'Paris',"France",'Paris','Geneva',"",['Artur','Heidrun']])
data_list.append([datetime.datetime(2010,8,4),1,"Hotel Sully",'Paris',"France",'Paris','Geneva',"",[]])
data_list.append([datetime.datetime(2010,8,4),1,"Opera Bastille",'Paris',"France",'Paris','Geneva',"",[]])
data_list.append([datetime.datetime(2010,8,4),1,"Place de la Bastille",'Paris',"France",'Paris','Geneva',"",[]])
data_list.append([datetime.datetime(2010,8,4),1,"Palais Royal",'Paris',"France",'Paris','Geneva',"",[]])
data_list.append([datetime.datetime(2010,8,4),2,"Pont Neuf",'Paris',"France",'Paris','Geneva',"Paris, Banks of the Seine",[]])
data_list.append([datetime.datetime(2010,8,4),1,"Bourse de Commerce",'Paris',"France",'Paris','Geneva',"",[]])
data_list.append([datetime.datetime(2010,8,4),11,"St Eustache",'Paris',"France",'Paris','Geneva',"",[]])
data_list.append([datetime.datetime(2010,8,4),1,"St Paul & St Louis","Paris","France","Paris","Geneva","",[]])
data_list.append([datetime.datetime(2010,8,4),2,"St Merri","Paris","France","Paris","Geneva","",[]])

# %%
#2011
#milan done
data_list.append([datetime.datetime(2011, 1, 23),1,"Milano Centrale",'Milano',"Italy",'Geneva','Geneva',"",['Hannsjoerg']])
data_list.append([datetime.datetime(2011, 1, 23),22,"Castello Sforzesco",'Milano',"Italy",'Geneva','Geneva',"",['Hannsjoerg']])
data_list.append([datetime.datetime(2011, 1, 23),19,"Galleria Vittorio Emanuele II",'Milano',"Italy",'Geneva','Geneva',"",['Hannsjoerg']])
data_list.append([datetime.datetime(2011, 1, 23),2,"Palazzo Reale",'Milano',"Italy",'Geneva','Geneva',"",['Hannsjoerg']])
data_list.append([datetime.datetime(2011, 1, 23),81,"Duomo",'Milano',"Italy",'Geneva','Geneva',"",['Hannsjoerg']])
data_list.append([datetime.datetime(2011, 1, 23),3,"Palazzo dell'Arengario",'Milano',"Italy",'Geneva','Geneva',"",['Hannsjoerg']])
data_list.append([datetime.datetime(2011, 1, 23),1,"Teatro alla Scala",'Milano',"Italy",'Geneva','Geneva',"",['Hannsjoerg']])
data_list.append([datetime.datetime(2011, 1, 23),1,"San Fedele",'Milano',"Italy",'Geneva','Geneva',"",['Hannsjoerg']])
data_list.append([datetime.datetime(2011, 1, 23),2,"Porta Ticinese",'Milano',"Italy",'Geneva','Geneva',"",['Hannsjoerg']])
data_list.append([datetime.datetime(2011, 1, 23),3,"Colonne di San Lorenzo",'Milano',"Italy",'Geneva','Geneva',"",['Hannsjoerg']])
data_list.append([datetime.datetime(2011, 1, 23),12,"San Lorenzo",'Milano',"Italy",'Geneva','Geneva',"",['Hannsjoerg']])
data_list.append([datetime.datetime(2011, 1, 23),9,"Sant'Ambrogio",'Milano',"Italy",'Geneva','Geneva',"",['Hannsjoerg']])
data_list.append([datetime.datetime(2011, 1, 23),3,"Santa Maria delle Grazie",'Milano',"Italy",'Geneva','Geneva',"Church and Dominican Convent of Santa Maria delle Grazie",['Hannsjoerg']])
data_list.append([datetime.datetime(2011, 1, 23),5,"Santa Sebastiano",'Milano',"Italy",'Geneva','Geneva',"",['Hannsjoerg']])
data_list.append([datetime.datetime(2011, 1, 23),2,"Santa Maria presso San Satiro",'Milano',"Italy",'Geneva','Geneva',"",['Hannsjoerg']])
#lyon done
data_list.append([datetime.datetime(2011, 5, 22),20,"Cathedral",'Lyon',"France",'Geneva','Geneva',"Lyon",['Hannsjoerg','Artur','Heidrun']])
data_list.append([datetime.datetime(2011, 5, 22),2,"Tour Fourviere",'Lyon',"France",'Geneva','Geneva',"Lyon",['Hannsjoerg','Artur','Heidrun']])
data_list.append([datetime.datetime(2011, 5, 22),39,"Notre-Dame de Fourviere",'Lyon',"France",'Geneva','Geneva',"Lyon",['Hannsjoerg','Artur','Heidrun']])
data_list.append([datetime.datetime(2011, 5, 22),8,"Roman Theatre",'Lyon',"France",'Geneva','Geneva',"Lyon",['Hannsjoerg','Artur','Heidrun']])
data_list.append([datetime.datetime(2011, 5, 22),11,"Roman Odeon",'Lyon',"France",'Geneva','Geneva',"Lyon",['Hannsjoerg','Artur','Heidrun']])
data_list.append([datetime.datetime(2011, 5, 22),2,"Place Bellecour",'Lyon',"France",'Geneva','Geneva',"Lyon",['Hannsjoerg','Artur','Heidrun']])
data_list.append([datetime.datetime(2011, 5, 22),2,"Jacobin's Fountain",'Lyon',"France",'Geneva','Geneva',"Lyon",['Hannsjoerg','Artur','Heidrun']])
data_list.append([datetime.datetime(2011, 5, 22),2,"Theatre de Celestins",'Lyon',"France",'Geneva','Geneva',"Lyon",['Hannsjoerg','Artur','Heidrun']])
data_list.append([datetime.datetime(2011, 5, 22),4,"Hotel de Ville",'Lyon',"France",'Geneva','Geneva',"Lyon",['Hannsjoerg','Artur','Heidrun']])
data_list.append([datetime.datetime(2011, 5, 22),3,"Bartholdi Fountain",'Lyon',"France",'Geneva','Geneva',"Lyon",['Hannsjoerg','Artur','Heidrun']])
data_list.append([datetime.datetime(2011, 5, 22),1,"Opera",'Lyon',"France",'Geneva','Geneva',"Lyon",['Hannsjoerg','Artur','Heidrun']])
data_list.append([datetime.datetime(2011, 5, 22),5,"St Nizier",'Lyon',"France",'Geneva','Geneva',"Lyon",['Hannsjoerg','Artur','Heidrun']])
data_list.append([datetime.datetime(2011, 5, 22),2,"St Paul",'Lyon',"France",'Geneva','Geneva',"Lyon",['Hannsjoerg','Artur','Heidrun']])
data_list.append([datetime.datetime(2011, 5, 22),3,"Tour Rose",'Lyon',"France",'Geneva','Geneva',"Lyon",['Hannsjoerg','Artur','Heidrun']])
data_list.append([datetime.datetime(2011, 5, 22),3,"St Georges",'Lyon',"France",'Geneva','Geneva',"Lyon",['Hannsjoerg','Artur','Heidrun']])

#ludwigsburg done
data_list.append([datetime.datetime(2011, 8, 28),124,"Residenzschloss",'Ludwigsburg',"Germany",'Lauchringen','Lauchringen',"",['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2011, 8, 28),11,"Palace Park",'Ludwigsburg',"Germany",'Lauchringen','Lauchringen',"",['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2011, 8, 28),14,"Schloss Favorite",'Ludwigsburg',"Germany",'Lauchringen','Lauchringen',"",['Artur','Hannsjoerg','Heidrun']])

#vienna complete
data_list.append([datetime.datetime(2011, 12, 27),22,"Schloss Schoenbrunn",'Vienna',"Austria",'Lauchringen','Vienna',"Schoenbrunn Palace",['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2011, 12, 27),13,"Schlosspark Schoenbrunn",'Vienna',"Austria",'Lauchringen','Vienna',"Schoenbrunn Palace",['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2011, 12, 27),3,"Schlosspark Schoenbrunn Gloriette",'Vienna',"Austria",'Lauchringen','Vienna',"Schoenbrunn Palace",['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2011, 12, 27),28,"Stephansdom",'Vienna',"Austria",'Lauchringen','Vienna',"Vienna",['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2011, 12, 27),1,"Peterskirche",'Vienna',"Austria",'Lauchringen','Vienna',"Vienna",['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2011, 12, 27),1,"Secession",'Vienna',"Austria",'Lauchringen','Vienna',"Vienna",['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2011, 12, 27),1,"Karlskirche",'Vienna',"Austria",'Lauchringen','Vienna',"Vienna",['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2011, 12, 27),3,"Staatsoper",'Vienna',"Austria",'Lauchringen','Vienna',"Vienna",['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2011, 12, 28),25,"Oberes Belvedere",'Vienna',"Austria",'Vienna','Vienna',"Vienna",['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2011, 12, 28),25,"Unteres Belvedere",'Vienna',"Austria",'Vienna','Vienna',"Vienna",['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2011, 12, 28),14,"Belvederegarten",'Vienna',"Austria",'Vienna','Vienna',"Vienna",['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2011, 12, 28),1,"Stephansdom",'Vienna',"Austria",'Vienna','Vienna',"Vienna",['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2011, 12, 28),2,"Rote Armee Monument",'Vienna',"Austria",'Vienna','Vienna',"Vienna",['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2011, 12, 28),20,"Karlskirche",'Vienna',"Austria",'Vienna','Vienna',"Vienna",['Artur','Hannsjoerg','Heidrun']])
#outside, kaiserappartments, silberkammer in this point
data_list.append([datetime.datetime(2011, 12, 28),14,"Hofburg",'Vienna',"Austria",'Vienna','Vienna',"Vienna",['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2011, 12, 28),2,"Michaelerkirche",'Vienna',"Austria",'Vienna','Vienna',"Vienna",['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2011, 12, 28),13,"Albertina",'Vienna',"Austria",'Vienna','Vienna',"Vienna",['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2011, 12, 28),2,"Staatsoper",'Vienna',"Austria",'Vienna','Vienna',"Vienna",['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2011, 12, 28),8,"Moebelmuseum",'Vienna',"Austria",'Vienna','Vienna',"",['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2011, 12, 29),1,"Naturhistorisches Museum",'Vienna',"Austria",'Vienna','Vienna',"Vienna",['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2011, 12, 29),3,"Maria Theresia Monument",'Vienna',"Austria",'Vienna','Vienna',"Vienna",['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2011, 12, 29),19,"Burgtheater",'Vienna',"Austria",'Vienna','Vienna',"Vienna",['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2011, 12, 29),3,"Rathaus",'Vienna',"Austria",'Vienna','Vienna',"Vienna",['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2011, 12, 29),17,"Hofburg",'Vienna',"Austria",'Vienna','Vienna',"Vienna",['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2011, 12, 29),23,"Parlament",'Vienna',"Austria",'Vienna','Vienna',"Vienna",['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2011, 12, 29),24,"Hofbibliothek",'Vienna',"Austria",'Vienna','Vienna',"Vienna",['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2011, 12, 29),4,"Augustinerkirche",'Vienna',"Austria",'Vienna','Vienna',"Vienna",['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2011, 12, 29),1,"Pestsaeule",'Vienna',"Austria",'Vienna','Vienna',"Vienna",['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2011, 12, 29),17,"Peterskirche",'Vienna',"Austria",'Vienna','Vienna',"Vienna",['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2011, 12, 29),1,"Ankeruhr",'Vienna',"Austria",'Vienna','Vienna',"Vienna",['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2011, 12, 29),1,"Akademie der Wissenschaften",'Vienna',"Austria",'Vienna','Vienna',"Vienna",['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2011, 12, 29),8,"Jesuitenkirche",'Vienna',"Austria",'Vienna','Vienna',"Vienna",['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2011, 12, 29),7,"Dominikanerkirche",'Vienna',"Austria",'Vienna','Vienna',"Vienna",['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2011, 12, 29),5,"Griechenkathedrale",'Vienna',"Austria",'Vienna','Vienna',"Vienna",['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2011, 12, 29),2,"Altes Rathaus",'Vienna',"Austria",'Vienna','Vienna',"Vienna",['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2011, 12, 29),4,"Maria am Gestade",'Vienna',"Austria",'Vienna','Vienna',"Vienna",['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2011, 12, 29),1,"Kirche am Hof",'Vienna',"Austria",'Vienna','Vienna',"Vienna",['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2011, 12, 29),2,"Palais Daun-Kinsky",'Vienna',"Austria",'Vienna','Vienna',"Vienna",['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2011, 12, 29),4,"Schottenkirche",'Vienna',"Austria",'Vienna','Vienna',"Vienna",['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2011, 12, 29),4,"Minoritenkirche",'Vienna',"Austria",'Vienna','Vienna',"Vienna",['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2011, 12, 29),1,"Kunsthistorisches Museum",'Vienna',"Austria",'Vienna','Vienna',"Vienna",['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2011, 12, 30),24,"Ephesusmuseum",'Vienna',"Austria",'Vienna','Vienna',"Vienna",['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2011, 12, 30),3,"Hofburgkapelle",'Vienna',"Austria",'Vienna','Vienna',"Vienna",['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2011, 12, 30),16,"Kaiserliche Schatzkammer",'Vienna',"Austria",'Vienna','Vienna',"Vienna",['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2011, 12, 30),3,"Hofburg",'Vienna',"Austria",'Vienna','Vienna',"Vienna",['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2011, 12, 30),26,"Rathaus",'Vienna',"Austria",'Vienna','Vienna',"",['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2011, 12, 30),4,"Parlament",'Vienna',"Austria",'Vienna','Vienna',"Vienna",['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2011, 12, 30),10,"Votivkirche",'Vienna',"Austria",'Vienna','Vienna',"Vienna",['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2011, 12, 30),2,"Burgtheater",'Vienna',"Austria",'Vienna','Vienna',"Vienna",['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2011, 12, 30),4,"Universitaet",'Vienna',"Austria",'Vienna','Vienna',"Vienna",['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2011, 12, 30),52,"Kunsthistorisches Museum",'Vienna',"Austria",'Vienna','Vienna',"Vienna",['Artur','Hannsjoerg','Heidrun']])

# %%
#2012

#Geneva done
data_list.append([datetime.datetime(2012, 3, 24),1,"Jet d'Eau",'Geneva',"Switzerland",'Geneva','Geneva',"",['Hannsjoerg']])
data_list.append([datetime.datetime(2012, 3, 24),9,"Cathedral",'Geneva',"Switzerland",'Geneva','Geneva',"",['Hannsjoerg']])
data_list.append([datetime.datetime(2012, 3, 25),18,"Musee d'Art et Histoire",'Geneva',"Switzerland",'Geneva','Geneva',"",['Hannsjoerg']])
data_list.append([datetime.datetime(2012, 3, 25),1,"Russian Church",'Geneva',"Switzerland",'Geneva','Geneva',"",['Hannsjoerg']])
data_list.append([datetime.datetime(2012, 3, 25),8,"Museum of Natural History",'Geneva',"Switzerland",'Geneva','Geneva',"",['Hannsjoerg']])
data_list.append([datetime.datetime(2012, 3, 31),5,"Jet d'Eau",'Geneva',"Switzerland",'Geneva','Geneva',"",['Hannsjoerg']])
data_list.append([datetime.datetime(2012, 4, 14),7,"Chateau",'Ferney-Voltaire',"France",'Geneva','Geneva',"",['Hannsjoerg']])
data_list.append([datetime.datetime(2012, 4, 29),12,"Basilique Notre Dame",'Geneva',"Switzerland",'Geneva','Geneva',"",['Hannsjoerg']])
data_list.append([datetime.datetime(2012, 5, 5),3,"Jardin Alpin",'Meyrin',"Switzerland",'Geneva','Geneva',"",['Hannsjoerg']])
data_list.append([datetime.datetime(2012, 5, 20),2,"Chateau La Tour",'Veyvey',"Switzerland",'Geneva','Geneva',"",['Hannsjoerg']])
data_list.append([datetime.datetime(2012, 5, 20),4,"Church",'Veyvey',"Switzerland",'Geneva','Geneva',"",['Hannsjoerg']])
data_list.append([datetime.datetime(2012, 5, 20),1,"Russian Church",'Veyvey',"Switzerland",'Geneva','Geneva',"",['Hannsjoerg']])
data_list.append([datetime.datetime(2012, 6, 7),1,"St Martin",'Geneva',"Switzerland",'Geneva','Geneva',"",['Hannsjoerg']])
data_list.append([datetime.datetime(2012, 6, 14),1,"Mosque",'Geneva',"Switzerland",'Geneva','Geneva',"",['Hannsjoerg']])
data_list.append([datetime.datetime(2012, 9, 15),34,"Palais des Nations",'Geneva',"Switzerland",'Geneva','Geneva',"",['Hannsjoerg']])
data_list.append([datetime.datetime(2012, 9, 15),34,"Palais des Nations",'Geneva',"Switzerland",'Geneva','Geneva',"",['Hannsjoerg']])
data_list.append([datetime.datetime(2012, 12, 9),14,"Hotel de Ville",'Geneva',"Switzerland",'Geneva','Geneva',"",['Hannsjoerg']])
data_list.append([datetime.datetime(2012, 12, 9),3,"College Calvin",'Geneva',"Switzerland",'Geneva','Geneva',"",['Hannsjoerg']])
data_list.append([datetime.datetime(2012, 12, 9),4,"Madeleine",'Geneva',"Switzerland",'Geneva','Geneva',"",['Hannsjoerg']])
data_list.append([datetime.datetime(2012, 12, 15),17,"Musee d'Art et Histoire",'Geneva',"Switzerland",'Geneva','Geneva',"",['Hannsjoerg']])

# %%
#prague done
data_list.append([datetime.datetime(2012, 5, 11),16,"Karlstejn Castle",'Karlstejn',"Czechia",'Geneva','Prague',"",['Artur','Heidrun']])
data_list.append([datetime.datetime(2012, 5, 11),7,"Old Town Square",'Prague',"Czechia",'Geneva','Prague',"Historic Centre of Prague",['Artur','Heidrun']])
data_list.append([datetime.datetime(2012, 5, 11),7,"Old Town Hall",'Prague',"Czechia",'Geneva','Prague',"Historic Centre of Prague",['Artur','Heidrun']])
data_list.append([datetime.datetime(2012, 5, 11),4,"Teyn Church",'Prague',"Czechia",'Geneva','Prague',"Historic Centre of Prague",['Artur','Heidrun']])
data_list.append([datetime.datetime(2012, 5, 11),7,"St Nicholas (Old Town)",'Prague',"Czechia",'Geneva','Prague',"Historic Centre of Prague",['Artur','Heidrun']])
data_list.append([datetime.datetime(2012, 5, 11),4,"Clementinum",'Prague',"Czechia",'Geneva','Prague',"Historic Centre of Prague",['Artur','Heidrun']])
#including the towers
data_list.append([datetime.datetime(2012, 5, 11),16,"Charles Bridge",'Prague',"Czechia",'Geneva','Prague',"Historic Centre of Prague",['Artur','Heidrun']])
data_list.append([datetime.datetime(2012, 5, 11),8,"St Francis of Assisi",'Prague',"Czechia",'Geneva','Prague',"Historic Centre of Prague",['Artur','Heidrun']])
#quarter, not royal palace or vitus, or belvedere, but golden lane
data_list.append([datetime.datetime(2012, 5, 11),12,"Prague Castle",'Prague',"Czechia",'Geneva','Prague',"Historic Centre of Prague",['Artur','Heidrun']])
data_list.append([datetime.datetime(2012, 5, 11),14,"St Vitus Cathedral",'Prague',"Czechia",'Geneva','Prague',"Historic Centre of Prague",['Artur','Heidrun']])
data_list.append([datetime.datetime(2012, 5, 11),7,"St Nicholas (Lesser Side)",'Prague',"Czechia",'Geneva','Prague',"Historic Centre of Prague",['Artur','Heidrun']])
data_list.append([datetime.datetime(2012, 5, 11),2,"Lesser Side Square",'Prague',"Czechia",'Geneva','Prague',"Historic Centre of Prague",['Artur','Heidrun']])
data_list.append([datetime.datetime(2012, 5, 11),4,"Prague Castle State Apartments",'Prague',"Czechia",'Geneva','Prague',"Historic Centre of Prague",['Artur','Heidrun']])
data_list.append([datetime.datetime(2012, 5, 11),4,"Prague Castle Old Royal Palace",'Prague',"Czechia",'Geneva','Prague',"Historic Centre of Prague",['Artur','Heidrun']])
data_list.append([datetime.datetime(2012, 5, 11),3,"Schwarzenberg Palais",'Prague',"Czechia",'Geneva','Prague',"Historic Centre of Prague",['Artur','Heidrun']])
data_list.append([datetime.datetime(2012, 5, 11),3,"Prague Castle St George",'Prague',"Czechia",'Geneva','Prague',"Historic Centre of Prague",['Artur','Heidrun']])
data_list.append([datetime.datetime(2012, 5, 11),2,"Wallenstein Palace",'Prague',"Czechia",'Geneva','Prague',"Historic Centre of Prague",['Artur','Heidrun']])
data_list.append([datetime.datetime(2012, 5, 12),74,"Prague Castle State Apartments",'Prague',"Czechia",'Prague','Prague',"Historic Centre of Prague",['Artur','Heidrun']])
data_list.append([datetime.datetime(2012, 5, 12),70,"St Vitus Cathedral",'Prague',"Czechia",'Prague','Prague',"Historic Centre of Prague",['Artur','Heidrun']])
data_list.append([datetime.datetime(2012, 5, 12),15,"Prague Castle St George",'Prague',"Czechia",'Prague','Prague',"Historic Centre of Prague",['Artur','Heidrun']])
data_list.append([datetime.datetime(2012, 5, 12),24,"Prague Castle Old Royal Palace",'Prague',"Czechia",'Geneva','Prague',"Historic Centre of Prague",['Artur','Heidrun']])
data_list.append([datetime.datetime(2012, 5, 12),11,"Prague Castle",'Prague',"Czechia",'Prague','Prague',"Historic Centre of Prague",['Artur','Heidrun']])
data_list.append([datetime.datetime(2012, 5, 12),2,"Prague Castle Gardens",'Prague',"Czechia",'Prague','Prague',"Historic Centre of Prague",['Artur','Heidrun']])
data_list.append([datetime.datetime(2012, 5, 12),1,"Prague Castle Belvedere",'Prague',"Czechia",'Prague','Prague',"Historic Centre of Prague",['Artur','Heidrun']])
data_list.append([datetime.datetime(2012, 5, 12),33,"Loreto",'Prague',"Czechia",'Prague','Prague',"Historic Centre of Prague",['Artur','Heidrun']])
data_list.append([datetime.datetime(2012, 5, 12),17,"Strahov Monastery",'Prague',"Czechia",'Prague','Prague',"Historic Centre of Prague",['Artur','Heidrun']])
data_list.append([datetime.datetime(2012, 5, 12),1,"St Nicholas (Lesser Side)",'Prague',"Czechia",'Prague','Prague',"Historic Centre of Prague",['Artur','Heidrun']])
data_list.append([datetime.datetime(2012, 5, 13),5,"Municipal House",'Prague',"Czechia",'Prague','Geneva',"Historic Centre of Prague",['Artur','Heidrun']])
data_list.append([datetime.datetime(2012, 5, 13),1,"Powder Tower",'Prague',"Czechia",'Prague','Geneva',"Historic Centre of Prague",['Artur','Heidrun']])
data_list.append([datetime.datetime(2012, 5, 13),4,"St Jacob",'Prague',"Czechia",'Prague','Geneva',"Historic Centre of Prague",['Artur','Heidrun']])
data_list.append([datetime.datetime(2012, 5, 13),2,"Teyn Church",'Prague',"Czechia",'Prague','Geneva',"Historic Centre of Prague",['Artur','Heidrun']])
data_list.append([datetime.datetime(2012, 5, 13),1,"Old Town Square",'Prague',"Czechia",'Prague','Geneva',"Historic Centre of Prague",['Artur','Heidrun']])
data_list.append([datetime.datetime(2012, 5, 13),1,"Old Town Hall",'Prague',"Czechia",'Prague','Geneva',"Historic Centre of Prague",['Artur','Heidrun']])
data_list.append([datetime.datetime(2012, 5, 13),9,"St Nicholas (Old Town)",'Prague',"Czechia",'Prague','Geneva',"Historic Centre of Prague",['Artur','Heidrun']])
data_list.append([datetime.datetime(2012, 5, 13),2,"Zdislava Chapel",'Prague',"Czechia",'Prague','Geneva',"Historic Centre of Prague",['Artur','Heidrun']])
data_list.append([datetime.datetime(2012, 5, 13),4,"Prague Castle",'Prague',"Czechia",'Prague','Geneva',"Historic Centre of Prague",['Artur','Heidrun']])
data_list.append([datetime.datetime(2012, 5, 13),2,"National Theatre",'Prague',"Czechia",'Prague','Geneva',"Historic Centre of Prague",['Artur','Heidrun']])
data_list.append([datetime.datetime(2012, 5, 13),5,"Charles Bridge",'Prague',"Czechia",'Prague','Geneva',"Historic Centre of Prague",['Artur','Heidrun']])
data_list.append([datetime.datetime(2012, 5, 13),1,"Dancing House",'Prague',"Czechia",'Prague','Geneva',"Historic Centre of Prague",['Artur','Heidrun']])
data_list.append([datetime.datetime(2012, 5, 13),2,"St Mary of Victory",'Prague',"Czechia",'Prague','Geneva',"Historic Centre of Prague",['Artur','Heidrun']])
data_list.append([datetime.datetime(2012, 5, 13),50,"St Nicholas (Lesser Side)",'Prague',"Czechia",'Prague','Geneva',"Historic Centre of Prague",['Artur','Heidrun']])
data_list.append([datetime.datetime(2012, 5, 13),4,"St Thomas",'Prague',"Czechia",'Prague','Geneva',"Historic Centre of Prague",['Artur','Heidrun']])
data_list.append([datetime.datetime(2012, 5, 13),35,"Palais Wallenstein",'Prague',"Czechia",'Prague','Geneva',"Historic Centre of Prague",['Artur','Heidrun']])
data_list.append([datetime.datetime(2012, 5, 13),3,"Rudolfinum",'Prague',"Czechia",'Prague','Geneva',"Historic Centre of Prague",['Artur','Heidrun']])
data_list.append([datetime.datetime(2012, 5, 13),5,"Bethlehem Chapel",'Prague',"Czechia",'Prague','Geneva',"Historic Centre of Prague",['Artur','Heidrun']])
data_list.append([datetime.datetime(2012, 5, 13),3,"Wenceslas Square",'Prague',"Czechia",'Prague','Geneva',"Historic Centre of Prague",['Artur','Heidrun']])

# %%
#berlin done
data_list.append([datetime.datetime(2012, 7, 24),1,"Kaiser-Wilhelm-Gedaechtniskirche",'Berlin',"Germany",'Geneva','Berlin',"",[]])
data_list.append([datetime.datetime(2012, 7, 25),77,"Schloss Charlottenburg",'Berlin',"Germany",'Berlin','Berlin',"",[]])
data_list.append([datetime.datetime(2012, 7, 25),11,"Neuer Pavillon Charlottenburg",'Berlin',"Germany",'Berlin','Berlin',"",[]])
data_list.append([datetime.datetime(2012, 7, 25),13,"Belvedere Charlottenburg",'Berlin',"Germany",'Berlin','Berlin',"",[]])
data_list.append([datetime.datetime(2012, 7, 25),8,"Mausoleum Charlottenburg",'Berlin',"Germany",'Berlin','Berlin',"",[]])
data_list.append([datetime.datetime(2012, 7, 25),4,"Schlosspark Charlottenburg",'Berlin',"Germany",'Berlin','Berlin',"",[]])
data_list.append([datetime.datetime(2012, 7, 25),36,"Schloss Schoenhausen",'Berlin',"Germany",'Berlin','Berlin',"",[]])
data_list.append([datetime.datetime(2012, 7, 25),3,"Deutscher Dom",'Berlin',"Germany",'Berlin','Berlin',"",[]])
data_list.append([datetime.datetime(2012, 7, 25),7,"Franzoesischer Dom",'Berlin',"Germany",'Berlin','Berlin',"",[]])
data_list.append([datetime.datetime(2012, 7, 25),32,"Konzerthaus",'Berlin',"Germany",'Berlin','Berlin',"",[]])
data_list.append([datetime.datetime(2012, 7, 25),6,"Friedrichwerdersche Kirche",'Berlin',"Germany",'Berlin','Berlin',"",[]])
data_list.append([datetime.datetime(2012, 7, 25),3,"Dom",'Berlin',"Germany",'Berlin','Berlin',"",[]])
data_list.append([datetime.datetime(2012, 7, 25),2,"Fernsehturm",'Berlin',"Germany",'Berlin','Berlin',"",[]])
data_list.append([datetime.datetime(2012, 7, 25),2,"Staatsratsgebaeude",'Berlin',"Germany",'Berlin','Berlin',"",[]])
data_list.append([datetime.datetime(2012, 7, 25),1,"Altes Museum",'Berlin',"Germany",'Berlin','Berlin',"Museumsinsel",[]])
data_list.append([datetime.datetime(2012, 7, 25),1,"Zeughaus",'Berlin',"Germany",'Berlin','Berlin',"",[]])
data_list.append([datetime.datetime(2012, 7, 25),1,"Neue Wache",'Berlin',"Germany",'Berlin','Berlin',"",[]])
data_list.append([datetime.datetime(2012, 7, 25),1,"Staatsoper Unter den Linden",'Berlin',"Germany",'Berlin','Berlin',"",[]])
data_list.append([datetime.datetime(2012, 7, 25),3,"Hedwigskathedrale",'Berlin',"Germany",'Berlin','Berlin',"",[]])
data_list.append([datetime.datetime(2012, 7, 25),4,"Brandenburger Tor",'Berlin',"Germany",'Berlin','Berlin',"",[]])
data_list.append([datetime.datetime(2012, 7, 25),1,"Reichstag",'Berlin',"Germany",'Berlin','Berlin',"",[]])
data_list.append([datetime.datetime(2012, 7, 25),1,"Holocaust-Mahnmal",'Berlin',"Germany",'Berlin','Berlin',"",[]])
data_list.append([datetime.datetime(2012, 7, 25),2,"Potsdamer Platz",'Berlin',"Germany",'Berlin','Berlin',"",[]])
data_list.append([datetime.datetime(2012, 7, 26),33,"Schloss Cecilienhof",'Potsdam',"Germany",'Berlin','Berlin',"Prussian Palaces of Potsdam and Berlin",[]])
data_list.append([datetime.datetime(2012, 7, 26),3,"Neuer Garten",'Potsdam',"Germany",'Berlin','Berlin',"Prussian Palaces of Potsdam and Berlin",[]])
data_list.append([datetime.datetime(2012, 7, 26),46,"Marmorpalais",'Potsdam',"Germany",'Berlin','Berlin',"Prussian Palaces of Potsdam and Berlin",[]])
data_list.append([datetime.datetime(2012, 7, 26),8,"Belvedere Pfingstberg",'Potsdam',"Germany",'Berlin','Berlin',"Prussian Palaces of Potsdam and Berlin",[]])
data_list.append([datetime.datetime(2012, 7, 26),23,"Schloss Sanssouci",'Potsdam',"Germany",'Berlin','Berlin',"Prussian Palaces of Potsdam and Berlin",[]])
data_list.append([datetime.datetime(2012, 7, 26),9,"Schlosspark Sanssouci",'Potsdam',"Germany",'Berlin','Berlin',"Prussian Palaces of Potsdam and Berlin",[]])
data_list.append([datetime.datetime(2012, 7, 26),12,"Neue Kammern Sanssouci",'Potsdam',"Germany",'Berlin','Berlin',"Prussian Palaces of Potsdam and Berlin",[]])
data_list.append([datetime.datetime(2012, 7, 26),5,"Friedenskirche",'Potsdam',"Germany",'Berlin','Berlin',"Prussian Palaces of Potsdam and Berlin",[]])
data_list.append([datetime.datetime(2012, 7, 26),11,"Gemaeldegalerie Sanssouci",'Potsdam',"Germany",'Berlin','Berlin',"Prussian Palaces of Potsdam and Berlin",[]])
data_list.append([datetime.datetime(2012, 7, 26),21,"Orangerieschloss Sanssouci",'Potsdam',"Germany",'Berlin','Berlin',"Prussian Palaces of Potsdam and Berlin",[]])
data_list.append([datetime.datetime(2012, 7, 26),11,"Charlottenhof Sanssouci",'Potsdam',"Germany",'Berlin','Berlin',"Prussian Palaces of Potsdam and Berlin",[]])
data_list.append([datetime.datetime(2012, 7, 26),5,"Roemisches Bad Sanssouci",'Potsdam',"Germany",'Berlin','Berlin',"Prussian Palaces of Potsdam and Berlin",[]])
data_list.append([datetime.datetime(2012, 7, 26),13,"Neues Palais Sanssouci",'Potsdam',"Germany",'Berlin','Berlin',"Prussian Palaces of Potsdam and Berlin",[]])
data_list.append([datetime.datetime(2012, 7, 27),25,"Schloss Glienicke","Berlin","Germany",'Berlin','Berlin',"Prussian Palaces of Potsdam and Berlin",[]])
data_list.append([datetime.datetime(2012, 7, 27),29,"Schloss Pfaueninsel","Berlin","Germany",'Berlin','Berlin',"Prussian Palaces of Potsdam and Berlin",[]])
data_list.append([datetime.datetime(2012, 7, 27),7,"Schloss Babelsberg","Potsdam","Germany",'Berlin','Berlin',"Prussian Palaces of Potsdam and Berlin",[]])
data_list.append([datetime.datetime(2012, 7, 27),9,"Schlosspark Babelsberg","Potsdam","Germany",'Berlin','Berlin',"Prussian Palaces of Potsdam and Berlin",[]])
data_list.append([datetime.datetime(2012, 7, 27),10,"Nikolaikirche","Potsdam","Germany",'Berlin','Berlin',"",[]])
data_list.append([datetime.datetime(2012, 7, 27),4,"Stadtschloss","Potsdam","Germany",'Berlin','Berlin',"",[]])
data_list.append([datetime.datetime(2012, 7, 28),1,"Brandenburger Tor","Potsdam","Germany",'Berlin','Berlin',"",[]])
data_list.append([datetime.datetime(2012, 7, 28),49,"Schloss Sanssouci",'Potsdam',"Germany",'Berlin','Berlin',"Prussian Palaces of Potsdam and Berlin",['Gianrico']])
data_list.append([datetime.datetime(2012, 7, 28),4,"Schlosspark Sanssouci",'Potsdam',"Germany",'Berlin','Berlin',"Prussian Palaces of Potsdam and Berlin",[]])
data_list.append([datetime.datetime(2012, 7, 28),5,"Neue Kammern Sanssouci",'Potsdam',"Germany",'Berlin','Berlin',"Prussian Palaces of Potsdam and Berlin",['Gianrico']])
data_list.append([datetime.datetime(2012, 7, 28),8,"Chinesisches Teehaus Sanssouci",'Potsdam',"Germany",'Berlin','Berlin',"Prussian Palaces of Potsdam and Berlin",[]])
data_list.append([datetime.datetime(2012, 7, 28),6,"Gemaeldegalerie Sanssouci",'Potsdam',"Germany",'Berlin','Berlin',"Prussian Palaces of Potsdam and Berlin",['Gianrico']])
data_list.append([datetime.datetime(2012, 7, 28),6,"Orangerieschloss Sanssouci",'Potsdam',"Germany",'Berlin','Berlin',"Prussian Palaces of Potsdam and Berlin",['Gianrico']])
data_list.append([datetime.datetime(2012, 7, 28),15,"Ruinenberg Sanssouci",'Potsdam',"Germany",'Berlin','Berlin',"Prussian Palaces of Potsdam and Berlin",[]])
data_list.append([datetime.datetime(2012, 7, 28),5,"Belvedere Sanssouci",'Potsdam',"Germany",'Berlin','Berlin',"Prussian Palaces of Potsdam and Berlin",['Gianrico']])
data_list.append([datetime.datetime(2012, 7, 28),3,"Neues Palais Sanssouci",'Potsdam',"Germany",'Berlin','Berlin',"Prussian Palaces of Potsdam and Berlin",['Gianrico']])
data_list.append([datetime.datetime(2012, 7, 28),12,"Maschinenhaus Sanssouci","Potsdam","Germany",'Berlin','Berlin',"",[]])
data_list.append([datetime.datetime(2012, 7, 29),2,"Flughafen Tempelhof","Berlin","Germany",'Berlin','Berlin',"",['Gianrico']])
data_list.append([datetime.datetime(2012, 7, 29),21,"Dom",'Berlin',"Germany",'Berlin','Berlin',"",['Gianrico']])
data_list.append([datetime.datetime(2012, 7, 29),3,"Rotes Rathaus",'Berlin',"Germany",'Berlin','Berlin',"",['Gianrico']])
data_list.append([datetime.datetime(2012, 7, 29),3,"Neptun Fountain",'Berlin',"Germany",'Berlin','Berlin',"",['Gianrico']])
data_list.append([datetime.datetime(2012, 7, 29),5,"Marienkirche",'Berlin',"Germany",'Berlin','Berlin',"",['Gianrico']])
data_list.append([datetime.datetime(2012, 7, 29),22,"Nikolaikirche",'Berlin',"Germany",'Berlin','Berlin',"",['Gianrico']])
data_list.append([datetime.datetime(2012, 7, 29),3,"Graues Kloster",'Berlin',"Germany",'Berlin','Berlin',"",['Gianrico']])
data_list.append([datetime.datetime(2012, 7, 29),1,"Fernsehturm",'Berlin',"Germany",'Berlin','Berlin',"",['Gianrico']])
data_list.append([datetime.datetime(2012, 7, 29),3,"Alexanderplatz",'Berlin',"Germany",'Berlin','Berlin',"",['Gianrico']])
data_list.append([datetime.datetime(2012, 7, 30),38,"Schloss Bellevue",'Berlin',"Germany",'Berlin','Berlin',"",[]])
data_list.append([datetime.datetime(2012, 7, 30),7,"Bundespraesidialamt",'Berlin',"Germany",'Berlin','Berlin',"",[]])
data_list.append([datetime.datetime(2012, 7, 30),1,"Siegessaeule",'Berlin',"Germany",'Berlin','Berlin',"",[]])
data_list.append([datetime.datetime(2012, 7, 30),1,"Alte Nationalgalerie",'Berlin',"Germany",'Berlin','Berlin',"Museumsinsel",[]])
data_list.append([datetime.datetime(2012, 7, 30),20,"Neues Museum",'Berlin',"Germany",'Berlin','Berlin',"Museumsinsel",[]])
data_list.append([datetime.datetime(2012, 7, 30),34,"Pergamonmuseum",'Berlin',"Germany",'Berlin','Berlin',"Museumsinsel",[]])
data_list.append([datetime.datetime(2012, 7, 30),3,"Dom",'Berlin',"Germany",'Berlin','Berlin',"",[]])
data_list.append([datetime.datetime(2012, 7, 30),2,"Altes Museum",'Berlin',"Germany",'Berlin','Berlin',"Museumsinsel",[]])
data_list.append([datetime.datetime(2012, 7, 30),7,"Rotes Rathaus",'Berlin',"Germany",'Berlin','Berlin',"",[]])
data_list.append([datetime.datetime(2012, 7, 30),1,"Parochialkirche",'Berlin',"Germany",'Berlin','Berlin',"",[]])
data_list.append([datetime.datetime(2012, 7, 30),1,"Fernsehturm",'Berlin',"Germany",'Berlin','Berlin',"",[]])
data_list.append([datetime.datetime(2012, 7, 30),3,"Sophienkirche",'Berlin',"Germany",'Berlin','Berlin',"",[]])
data_list.append([datetime.datetime(2012, 7, 30),1,"Synagoge",'Berlin',"Germany",'Berlin','Berlin',"",[]])
data_list.append([datetime.datetime(2012, 7, 30),1,"Bodemuseum",'Berlin',"Germany",'Berlin','Berlin',"Museumsinsel",[]])
data_list.append([datetime.datetime(2012, 7, 30),3,"Brandenburger Tor",'Berlin',"Germany",'Berlin','Berlin',"",[]])
data_list.append([datetime.datetime(2012, 7, 30),3,"Bundeskanzleramt",'Berlin',"Germany",'Berlin','Berlin',"",[]])
data_list.append([datetime.datetime(2012, 7, 30),30,"Reichstag",'Berlin',"Germany",'Berlin','Berlin',"",[]])
data_list.append([datetime.datetime(2012, 7, 30),1,"Hauptbahnhof",'Berlin',"Germany",'Berlin','Berlin',"",[]])
data_list.append([datetime.datetime(2012, 7, 30),1,"Philharmonie",'Berlin',"Germany",'Berlin','Berlin',"",[]])
data_list.append([datetime.datetime(2012, 7, 31),9,"Kaiser-Wilhelm-Gedaechtniskirche",'Berlin',"Germany",'Geneva','Berlin',"",[]])
data_list.append([datetime.datetime(2012, 7, 31),27,"Alte Nationalgalerie",'Berlin',"Germany",'Geneva','Berlin',"Museumsinsel",[]])
data_list.append([datetime.datetime(2012, 7, 31),7,"Bodemuseum",'Berlin',"Germany",'Geneva','Berlin',"Museumsinsel",[]])
data_list.append([datetime.datetime(2012, 7, 31),3,"Altes Museum",'Berlin',"Germany",'Geneva','Berlin',"Museumsinsel",[]])
data_list.append([datetime.datetime(2012, 7, 31),1,"Dom",'Berlin',"Germany",'Geneva','Berlin',"",[]])
data_list.append([datetime.datetime(2012, 7, 31),1,"Ephraim-Palais",'Berlin',"Germany",'Geneva','Berlin',"",[]])
data_list.append([datetime.datetime(2012, 7, 31),2,"Sony-Center",'Berlin',"Germany",'Geneva','Berlin',"",[]])
data_list.append([datetime.datetime(2012, 7, 31),3,"Philharmonie",'Berlin',"Germany",'Geneva','Berlin',"",[]])
data_list.append([datetime.datetime(2012, 7, 31),15,"Neue Nationalgalerie",'Berlin',"Germany",'Geneva','Berlin',"",[]])
data_list.append([datetime.datetime(2012, 7, 31),15,"Olympiastadion",'Berlin',"Germany",'Geneva','Berlin',"",[]])
data_list.append([datetime.datetime(2012, 7, 31),8,"Olympiapark",'Berlin',"Germany",'Geneva','Berlin',"",[]])

# %%
#2012 Poland
data_list.append([datetime.datetime(2012, 9, 28),7,"Palace of Culture and Sciences",'Warsaw',"Poland",'Geneva','Warsaw',"",["Eric"]])
data_list.append([datetime.datetime(2012, 9, 28),43,"Park Lazienkowski Palace on the Isle",'Warsaw',"Poland",'Geneva','Warsaw',"",["Eric"]])
data_list.append([datetime.datetime(2012, 9, 28),1,"Park Lazienkowski White House",'Warsaw',"Poland",'Geneva','Warsaw',"",["Eric"]])
data_list.append([datetime.datetime(2012, 9, 28),14,"Park Lazienkowski",'Warsaw',"Poland",'Geneva','Warsaw',"",["Eric"]])
data_list.append([datetime.datetime(2012, 9, 28),21,"Park Lazienkowski Myslewicki Palace",'Warsaw',"Poland",'Geneva','Warsaw',"",["Eric"]])
data_list.append([datetime.datetime(2012, 9, 29),1,"Warsaw Centralna Station",'Warsaw',"Poland",'Warsaw','Warsaw',"",["Eric"]])
data_list.append([datetime.datetime(2012, 9, 29),8,"Juliusz Slowacki Theatre",'Krakow',"Poland",'Warsaw','Warsaw',"Historic Centre of Krakow",["Eric"]])
data_list.append([datetime.datetime(2012, 9, 29),4,"Church of the Holy Cross",'Krakow',"Poland",'Warsaw','Warsaw',"Historic Centre of Krakow",["Eric"]])
data_list.append([datetime.datetime(2012, 9, 29),3,"St Adalbert",'Krakow',"Poland",'Warsaw','Warsaw',"Historic Centre of Krakow",["Eric"]])
data_list.append([datetime.datetime(2012, 9, 29),5,"Cloth Hall",'Krakow',"Poland",'Warsaw','Warsaw',"Historic Centre of Krakow",["Eric"]])
data_list.append([datetime.datetime(2012, 9, 29),46,"St Mary's Basilica",'Krakow',"Poland",'Warsaw','Warsaw',"Historic Centre of Krakow",["Eric"]])
data_list.append([datetime.datetime(2012, 9, 29),2,"St Andrew's",'Krakow',"Poland",'Warsaw','Warsaw',"Historic Centre of Krakow",["Eric"]])
data_list.append([datetime.datetime(2012, 9, 29),11,"St Peter & Paul",'Krakow',"Poland",'Warsaw','Warsaw',"Historic Centre of Krakow",["Eric"]])
data_list.append([datetime.datetime(2012, 9, 29),16,"Wawel Castle",'Krakow',"Poland",'Warsaw','Warsaw',"Historic Centre of Krakow",["Eric"]])
data_list.append([datetime.datetime(2012, 9, 29),32,"Wawel Cathedral",'Krakow',"Poland",'Warsaw','Warsaw',"Historic Centre of Krakow",["Eric"]])
data_list.append([datetime.datetime(2012, 9, 29),18,"Wawel Dragon's Den",'Krakow',"Poland",'Warsaw','Warsaw',"Historic Centre of Krakow",["Eric"]])
data_list.append([datetime.datetime(2012, 9, 29),3,"St Bernard of Siena",'Krakow',"Poland",'Warsaw','Warsaw',"Historic Centre of Krakow",["Eric"]])
data_list.append([datetime.datetime(2012, 9, 29),1,"St Barbara",'Krakow',"Poland",'Warsaw','Warsaw',"Historic Centre of Krakow",["Eric"]])
data_list.append([datetime.datetime(2012, 9, 29),5,"Franciscan Church",'Krakow',"Poland",'Warsaw','Warsaw',"Historic Centre of Krakow",["Eric"]])
data_list.append([datetime.datetime(2012, 9, 29),2,"St Florian's Gate",'Krakow',"Poland",'Warsaw','Warsaw',"Historic Centre of Krakow",["Eric"]])
data_list.append([datetime.datetime(2012, 9, 29),2,"Barbakan",'Krakow',"Poland",'Warsaw','Warsaw',"Historic Centre of Krakow",["Eric"]])
data_list.append([datetime.datetime(2012, 9, 29),2,"Matejko Square",'Krakow',"Poland",'Warsaw','Warsaw',"Historic Centre of Krakow",["Eric"]])
data_list.append([datetime.datetime(2012, 9, 29),3,"Palace of Culture and Sciences",'Warsaw',"Poland",'Warsaw','Warsaw',"",["Eric"]])
data_list.append([datetime.datetime(2012, 9, 30),4,"St Anna",'Warsaw',"Poland",'Warsaw','Warsaw',"Historic Centre of Warsaw",["Eric"]])
data_list.append([datetime.datetime(2012, 9, 30),103,"Wilanow Palace",'Warsaw',"Poland",'Warsaw','Warsaw',"",["Eric"]])
data_list.append([datetime.datetime(2012, 9, 30),63,"Royal Palace",'Warsaw',"Poland",'Warsaw','Warsaw',"Historic Centre of Warsaw",["Eric"]])
data_list.append([datetime.datetime(2012, 9, 30),1,"St Martin",'Warsaw',"Poland",'Warsaw','Warsaw',"Historic Centre of Warsaw",["Eric"]])
data_list.append([datetime.datetime(2012, 9, 30),3,"Jesuit Church",'Warsaw',"Poland",'Warsaw','Warsaw',"Historic Centre of Warsaw",["Eric"]])
data_list.append([datetime.datetime(2012, 9, 30),12,"St John's Archcathedral",'Warsaw',"Poland",'Warsaw','Warsaw',"Historic Centre of Warsaw",["Eric"]])
data_list.append([datetime.datetime(2012, 9, 30),3,"Market Square",'Warsaw',"Poland",'Warsaw','Warsaw',"Historic Centre of Warsaw",["Eric"]])
data_list.append([datetime.datetime(2012, 9, 30),2,"Barbakan",'Warsaw',"Poland",'Warsaw','Warsaw',"Historic Centre of Warsaw",["Eric"]])
data_list.append([datetime.datetime(2012, 9, 30),6,"Holy Ghost Church",'Warsaw',"Poland",'Warsaw','Warsaw',"Historic Centre of Warsaw",["Eric"]])
data_list.append([datetime.datetime(2012, 9, 30),2,"St Kazimierz",'Warsaw',"Poland",'Warsaw','Warsaw',"Historic Centre of Warsaw",["Eric"]])
data_list.append([datetime.datetime(2012, 9, 30),3,"St Mary",'Warsaw',"Poland",'Warsaw','Warsaw',"Historic Centre of Warsaw",["Eric"]])
data_list.append([datetime.datetime(2012, 9, 30),3,"Field Cathedral of the Polish Army",'Warsaw',"Poland",'Warsaw','Warsaw',"Historic Centre of Warsaw",["Eric"]])
data_list.append([datetime.datetime(2012, 9, 30),3,"Warsaw Rising Monument",'Warsaw',"Poland",'Warsaw','Warsaw',"Historic Centre of Warsaw",["Eric"]])
data_list.append([datetime.datetime(2012, 9, 30),3,"Carmelite Church",'Warsaw',"Poland",'Warsaw','Warsaw',"Historic Centre of Warsaw",["Eric"]])
data_list.append([datetime.datetime(2012, 9, 30),4,"Cathedral of Michael & Florian",'Warsaw',"Poland",'Warsaw','Warsaw',"",["Eric"]])
data_list.append([datetime.datetime(2012, 9, 30),3,"Palace of Culture and Sciences",'Warsaw',"Poland",'Warsaw','Warsaw',"",["Eric"]])
data_list.append([datetime.datetime(2012, 10, 1),19,"Warsaw Rising Museum",'Warsaw',"Poland",'Warsaw','Geneva',"",["Eric"]])
data_list.append([datetime.datetime(2012, 10, 1),7,"Park Lazienkowski White House",'Warsaw',"Poland",'Warsaw','Geneva',"",["Eric"]])
data_list.append([datetime.datetime(2012, 10, 1),2,"Park Lazienkowski",'Warsaw',"Poland",'Warsaw','Geneva',"",["Eric"]])
data_list.append([datetime.datetime(2012, 10, 1),14,"Park Lazienkowski Old Orangerie",'Warsaw',"Poland",'Warsaw','Geneva',"",["Eric"]])
data_list.append([datetime.datetime(2012, 10, 1),2,"Park Lazienkowski Palace on the Isle",'Warsaw',"Poland",'Warsaw','Geneva',"",["Eric"]])

# %%
#2013
#netherlands complete
data_list.append([datetime.datetime(2013, 1, 2),15,"Rembrandt House",'Amsterdam',"Netherlands",'Lauchringen','Amsterdam',"",['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2013, 1, 2),12,"Nieuwe Kerk",'Amsterdam',"Netherlands",'Lauchringen','Amsterdam',"",['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2013, 1, 2),59,"Royal Palace",'Amsterdam',"Netherlands",'Lauchringen','Amsterdam',"",['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2013, 1, 2),1,"Beurs van Berlage",'Amsterdam',"Netherlands",'Lauchringen','Amsterdam',"",['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2013, 1, 2),20,"Oude Kerk",'Amsterdam',"Netherlands",'Lauchringen','Amsterdam',"",['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2013, 1, 2),2,"De Waag",'Amsterdam',"Netherlands",'Lauchringen','Amsterdam',"",['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2013, 1, 2),6,"He Hua Temple",'Amsterdam',"Netherlands",'Lauchringen','Amsterdam',"",['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2013, 1, 2),3,"New Market Square",'Amsterdam',"Netherlands",'Lauchringen','Amsterdam',"",['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2013, 1, 3),67,"Het Loo Palace",'Apeldoorn',"Netherlands",'Amsterdam','Amsterdam',"",[]])
data_list.append([datetime.datetime(2013, 1, 3),9,"Het Loo Palace Garden",'Apeldoorn',"Netherlands",'Amsterdam','Amsterdam',"",[]])
data_list.append([datetime.datetime(2013, 1, 3),1,"Beurs van Berlage",'Amsterdam',"Netherlands",'Amsterdam','Amsterdam',"",[]])
data_list.append([datetime.datetime(2013, 1, 3),21,"Van Loon House",'Amsterdam',"Netherlands",'Amsterdam','Amsterdam',"Seventeenth-Century Canal Ring Area of Amsterdam inside the Singelgracht",[]])
data_list.append([datetime.datetime(2013, 1, 3),20,"Willet Holthuysen House",'Amsterdam',"Netherlands",'Amsterdam','Amsterdam',"Seventeenth-Century Canal Ring Area of Amsterdam inside the Singelgracht",[]])
data_list.append([datetime.datetime(2013, 1, 3),1,"Portuguese Synagogue",'Amsterdam',"Netherlands",'Amsterdam','Amsterdam',"Seventeenth-Century Canal Ring Area of Amsterdam inside the Singelgracht",[]])
data_list.append([datetime.datetime(2013, 1, 4),18,"Binnenhof",'Den Haag',"Netherlands",'Amsterdam','Amsterdam',"",['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2013, 1, 4),45,"Lange Voorhout Palace",'Den Haag',"Netherlands",'Amsterdam','Amsterdam',"",['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2013, 1, 4),2,"Peace Palace",'Den Haag',"Netherlands",'Amsterdam','Amsterdam',"",['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2013, 1, 4),16,"Gemeentemuseum",'Den Haag',"Netherlands",'Amsterdam','Amsterdam',"",['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2013, 1, 4),8,"GEM",'Den Haag',"Netherlands",'Amsterdam','Amsterdam',"",['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2013, 1, 4),1,"Royal Palace",'Amsterdam',"Netherlands",'Lauchringen','Amsterdam',"",['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2013, 1, 5),6,"Soestdijk Palace",'Soestdijk',"Netherlands",'Lauchringen','Amsterdam',"",[]])
data_list.append([datetime.datetime(2013, 1, 5),10,"Soestdijk Palace Garden",'Soestdijk',"Netherlands",'Lauchringen','Amsterdam',"",[]])
data_list.append([datetime.datetime(2013, 1, 5),1,"Amsterdam Centraal",'Amsterdam',"Netherlands",'Lauchringen','Amsterdam',"",[]])
data_list.append([datetime.datetime(2013, 1, 5),12,"Beurs van Berlage",'Amsterdam',"Netherlands",'Lauchringen','Amsterdam',"",[]])
data_list.append([datetime.datetime(2013, 1, 5),16,"Geelvinck Hinlopen House",'Amsterdam',"Netherlands",'Amsterdam','Amsterdam',"Seventeenth-Century Canal Ring Area of Amsterdam inside the Singelgracht",[]])
data_list.append([datetime.datetime(2013, 1, 5),20,"Rijksmuseum",'Amsterdam',"Netherlands",'Lauchringen','Amsterdam',"",[]])
data_list.append([datetime.datetime(2013, 1, 5),49,"Stedelijkmuseum",'Amsterdam',"Netherlands",'Lauchringen','Amsterdam',"",[]])
data_list.append([datetime.datetime(2013, 1, 5),2,"1.26 Amsterdam",'Amsterdam',"Netherlands",'Lauchringen','Amsterdam',"",['Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2013, 1, 5),6,"Ovo",'Amsterdam',"Netherlands",'Lauchringen','Amsterdam',"",['Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2013, 1, 5),2,"Rembrandtplein",'Amsterdam',"Netherlands",'Lauchringen','Amsterdam',"",['Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2013, 1, 6),20,"Portuguese Synagogue",'Amsterdam',"Netherlands",'Amsterdam','Lauchringen',"Seventeenth-Century Canal Ring Area of Amsterdam inside the Singelgracht",['Heidrun','Hannsjoerg','Artur']])
data_list.append([datetime.datetime(2013, 1, 6),13,"Jewish Museum",'Amsterdam',"Netherlands",'Amsterdam','Lauchringen',"Seventeenth-Century Canal Ring Area of Amsterdam inside the Singelgracht",['Heidrun','Hannsjoerg','Artur']])
data_list.append([datetime.datetime(2013, 1, 6),2,"NEMO",'Amsterdam',"Netherlands",'Amsterdam','Lauchringen',"Seventeenth-Century Canal Ring Area of Amsterdam inside the Singelgracht",['Heidrun','Hannsjoerg','Artur']])
data_list.append([datetime.datetime(2013, 1, 6),5,"Osterdok",'Amsterdam',"Netherlands",'Amsterdam','Lauchringen',"Seventeenth-Century Canal Ring Area of Amsterdam inside the Singelgracht",['Heidrun','Hannsjoerg','Artur']])
data_list.append([datetime.datetime(2013, 1, 6),1,"Amsterdam Centraal",'Amsterdam',"Netherlands",'Amsterdam','Lauchringen',"Seventeenth-Century Canal Ring Area of Amsterdam inside the Singelgracht",['Heidrun','Hannsjoerg','Artur']])
data_list.append([datetime.datetime(2013, 1, 6),2,"Royal Palace",'Amsterdam',"Netherlands",'Amsterdam','Lauchringen',"Seventeenth-Century Canal Ring Area of Amsterdam inside the Singelgracht",['Heidrun','Hannsjoerg','Artur']])
#geneva
data_list.append([datetime.datetime(2013, 2, 3),5,"Basilique Notre Dame",'Geneva',"Switzerland",'Geneva','Geneva',"",['Hannsjoerg']])
data_list.append([datetime.datetime(2013, 5, 5),1,"Chateau",'Hermence',"Switzerland",'Geneva','Geneva',"",['Hannsjoerg']])
data_list.append([datetime.datetime(2013, 5, 26),19,"Victoria Hall",'Geneva',"Switzerland",'Geneva','Geneva',"",['Hannsjoerg']])
data_list.append([datetime.datetime(2013, 5, 26),19,"Grand Theatre",'Geneva',"Switzerland",'Geneva','Geneva',"",['Hannsjoerg']])
data_list.append([datetime.datetime(2013, 5, 26),1,"Conservatoire",'Geneva',"Switzerland",'Geneva','Geneva',"",['Hannsjoerg']])
data_list.append([datetime.datetime(2013, 6, 30),2,"Basilique Notre Dame",'Geneva',"Switzerland",'Geneva','Geneva',"",['Hannsjoerg']])
data_list.append([datetime.datetime(2013, 6, 30),5,"Jet d'Eau",'Geneva',"Switzerland",'Geneva','Geneva',"",['Hannsjoerg']])
data_list.append([datetime.datetime(2013, 9, 28),2,"CERN Microcosm",'Meyrin',"Switzerland",'Geneva','Geneva',"",['Hannsjoerg','Artur','Heidrun','Anne-Kathrin']])
data_list.append([datetime.datetime(2013, 9, 28),8,"ALICE",'St-Genis-Pouilly',"France",'Geneva','Geneva',"",['Hannsjoerg','Artur','Heidrun','Anne-Kathrin']])
data_list.append([datetime.datetime(2013, 11, 23),20,"Maison Tavel",'Geneva',"Switzerland",'Geneva','Geneva',"",['Hannsjoerg']])
data_list.append([datetime.datetime(2013, 12, 19),22,"ATLAS",'Meyrin',"Switzerland",'Geneva','Geneva',"",['Hannsjoerg']])
#paris I
data_list.append([datetime.datetime(2013, 3, 22),124,"Chateau de Versailles","Versailles","France",'Paris','Paris',"Palace and Park of Versailles",['Andrew']])
data_list.append([datetime.datetime(2013, 3, 22),6,"Chateau de Versailles Gardens","Versailles","France",'Paris','Paris',"Palace and Park of Versailles",['Andrew']])
data_list.append([datetime.datetime(2013, 3, 22),26,"Chateau de Versailles Grand Trianon","Versailles","France",'Paris','Paris',"Palace and Park of Versailles",['Andrew']])
data_list.append([datetime.datetime(2013, 3, 22),20,"Chateau de Versailles Petit Trianon","Versailles","France",'Paris','Paris',"Palace and Park of Versailles",['Andrew']])
data_list.append([datetime.datetime(2013, 3, 22),34,"Chateau de Versailles Petit Trianon Garden & Hameau","Versailles","France",'Paris','Paris',"Palace and Park of Versailles",['Andrew']])
data_list.append([datetime.datetime(2013, 3, 22),9,"Hotel de Ville","Versailles","France",'Paris','Paris',"",['Andrew']])
data_list.append([datetime.datetime(2013, 3, 22),2,"Arc du Carrousel",'Paris',"France",'Paris','Paris',"Paris, Banks of the Seine",['Andrew']])
data_list.append([datetime.datetime(2013, 3, 22),84,"Louvre",'Paris',"France",'Paris','Geneva',"Paris, Banks of the Seine",['Andrew']])
data_list.append([datetime.datetime(2013, 3, 23),6,"Place de la Concorde",'Paris',"France",'Paris','Paris',"Paris, Banks of the Seine",['Andrew']])
data_list.append([datetime.datetime(2013, 3, 23),1,"Pont Alexandre III",'Paris',"France",'Paris','Paris',"Paris, Banks of the Seine",['Andrew']])
data_list.append([datetime.datetime(2013, 3, 23),69,"Palais Bourbon",'Paris',"France",'Paris','Paris',"Paris, Banks of the Seine",['Andrew']])
data_list.append([datetime.datetime(2013, 3, 23),4,"Louvre",'Paris',"France",'Paris','Paris',"Paris, Banks of the Seine",['Andrew']])
data_list.append([datetime.datetime(2013, 3, 23),1,"Pont Neuf",'Paris',"France",'Paris','Paris',"Paris, Banks of the Seine",['Andrew']])
data_list.append([datetime.datetime(2013, 3, 23),4,"Tour St Jacques",'Paris',"France",'Paris','Paris',"Routes of Santiago de Compostela",['Andrew']])
data_list.append([datetime.datetime(2013, 3, 23),7,"Conciergerie",'Paris',"France",'Paris','Paris',"Paris, Banks of the Seine",['Andrew']])
data_list.append([datetime.datetime(2013, 3, 23),1,"Palais de Justice",'Paris',"France",'Paris','Paris',"Paris, Banks of the Seine",['Andrew']])
data_list.append([datetime.datetime(2013, 3, 23),28,"Sainte Chapelle",'Paris',"France",'Paris','Paris',"Paris, Banks of the Seine",['Andrew']])
data_list.append([datetime.datetime(2013, 3, 23),22,"Notre Dame",'Paris',"France",'Paris','Paris',"Paris, Banks of the Seine",['Andrew']])
data_list.append([datetime.datetime(2013, 3, 23),1,"Hotel de Ville",'Paris',"France",'Paris','Paris',"Paris, Banks of the Seine",['Andrew']])
data_list.append([datetime.datetime(2013, 3, 23),28,"Chateau & Park Bagatelle",'Paris',"France",'Paris','Paris',"",['Andrew']])
data_list.append([datetime.datetime(2013, 3, 23),32,"Hotel Carnavalet",'Paris',"France",'Paris','Paris',"",['Andrew']])
data_list.append([datetime.datetime(2013, 3, 23),3,"Place des Voges",'Paris',"France",'Paris','Paris',"",['Andrew']])
data_list.append([datetime.datetime(2013, 3, 23),9,"Victor Hugo House",'Paris',"France",'Paris','Paris',"",['Andrew']])
data_list.append([datetime.datetime(2013, 3, 24),124,"Chateau de Fontainebleau",'Fontainebleau',"France",'Paris','Paris',"Palace and Park of Fontainebleau",['Andrew']])
data_list.append([datetime.datetime(2013, 3, 24),1,"Chateau de Fontainebleau Gardens",'Fontainebleau',"France",'Paris','Paris',"Palace and Park of Fontainebleau",['Andrew']])
data_list.append([datetime.datetime(2013, 3, 24),2,"St Louis",'Fontainebleau',"France",'Paris','Paris',"",['Andrew']])
data_list.append([datetime.datetime(2013, 3, 24),2,"Palais de Chaillot",'Paris',"France",'Paris','Paris',"Paris, Banks of the Seine",['Andrew']])
data_list.append([datetime.datetime(2013, 3, 24),8,"Tour Eiffel",'Paris',"France",'Paris','Paris',"Paris, Banks of the Seine",['Andrew']])
data_list.append([datetime.datetime(2013, 3, 24),4,"Tour Eiffel Observatory",'Paris',"France",'Paris','Paris',"",['Andrew']])
data_list.append([datetime.datetime(2013, 3, 24),1,"Ecole Militaire",'Paris',"France",'Paris','Paris',"Paris, Banks of the Seine",['Andrew']])
data_list.append([datetime.datetime(2013, 3, 24),1,"Tour Montparnasse",'Paris',"France",'Paris','Paris',"",['Andrew']])
data_list.append([datetime.datetime(2013, 3, 24),8,"Tour Montparnasse Observatory",'Paris',"France",'Paris','Paris',"",['Andrew']])
data_list.append([datetime.datetime(2013, 3, 24),1,"Notre Dame",'Paris',"France",'Paris','Paris',"Paris, Banks of the Seine",['Andrew']])
data_list.append([datetime.datetime(2013, 3, 25),1,"Place de la Republique",'Paris',"France",'Paris','Geneva',"",['Andrew']])
data_list.append([datetime.datetime(2013, 3, 25),36,"Basilique de St Denis",'St Denis',"France",'Paris','Geneva',"",['Andrew']])
data_list.append([datetime.datetime(2013, 3, 25),1,"Arc de Triomphe",'Paris',"France",'Paris','Geneva',"",['Andrew']])
data_list.append([datetime.datetime(2013, 3, 25),5,"St Augustine",'Paris',"France",'Paris','Geneva',"",['Andrew']])
data_list.append([datetime.datetime(2013, 3, 25),43,"Opera Garnier",'Paris',"France",'Paris','Geneva',"",['Andrew']])
data_list.append([datetime.datetime(2013, 3, 25),3,"Galleries Lafayette",'Paris',"France",'Paris','Geneva',"",['Andrew']])
data_list.append([datetime.datetime(2013, 3, 25),1,"Tour Eiffel",'Paris',"France",'Paris','Geneva',"Paris, Banks of the Seine",['Andrew']])
data_list.append([datetime.datetime(2013, 3, 25),1,"Sacre Coeur",'Paris',"France",'Paris','Geneva',"",['Andrew']])
#including St Louis & Dome d'Invalides
data_list.append([datetime.datetime(2013, 3, 25),31,"Hotel d'Invalides",'Paris',"France",'Paris','Geneva',"Paris, Banks of the Seine",['Andrew']])
data_list.append([datetime.datetime(2013, 3, 25),1,"Sorbonne",'Paris',"France",'Paris','Geneva',"",['Andrew']])
data_list.append([datetime.datetime(2013, 3, 25),14,"Pantheon",'Paris',"France",'Paris','Geneva',"",['Andrew']])
data_list.append([datetime.datetime(2013, 3, 25),2,"Palais du Luxembourg",'Paris',"France",'Paris','Geneva',"",['Andrew']])
data_list.append([datetime.datetime(2013, 3, 25),1,"Jardin du Luxembourg",'Paris',"France",'Paris','Geneva',"",['Andrew']])
data_list.append([datetime.datetime(2013, 3, 25),1,"Centre Pompidou",'Paris',"France",'Paris','Geneva',"",['Andrew']])
data_list.append([datetime.datetime(2013, 3, 25),1,"Hotel de Soubise",'Paris',"France",'Paris','Geneva',"",['Andrew']])
data_list.append([datetime.datetime(2013, 3, 25),10,"Hotel Jacquemart-Andre",'Paris',"France",'Paris','Geneva',"",['Andrew']])

# %%
#rome done
data_list.append([datetime.datetime(2013, 4, 3),10,"Palazzo Farnese",'Rome',"Italy",'Geneva','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 3),1,"Palazzo Spada",'Rome',"Italy",'Geneva','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 3),1,"Campo De Fiori",'Rome',"Italy",'Geneva','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 3),16,"St Andrea della Valle",'Rome',"Italy",'Geneva','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 3),19,"Pantheon",'Rome',"Italy",'Geneva','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 3),2,"Piazza della Rotonda",'Rome',"Italy",'Geneva','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 3),1,"Santa Chiara",'Rome',"Italy",'Geneva','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 3),1,"Piazza della Minerva",'Rome',"Italy",'Geneva','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 3),13,"Maria Sopra Minerva",'Rome',"Italy",'Geneva','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 3),1,"Palazzo Montecitorio",'Rome',"Italy",'Geneva','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 3),2,"Column of Marcus Aurelius",'Rome',"Italy",'Geneva','Rome',"Rome",['Heidrun']])
#mit mariensaeule
data_list.append([datetime.datetime(2013, 4, 3),2,"Piazza Mignanelli",'Rome',"Italy",'Geneva','Rome',"Rome",['Heidrun']])
#including spanish stairs
data_list.append([datetime.datetime(2013, 4, 3),3,"Piazza di Spagna",'Rome',"Italy",'Geneva','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 3),2,"Column of Marcus Aurelius",'Rome',"Italy",'Geneva','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 3),1,"Trinita dei Monti",'Rome',"Italy",'Geneva','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 3),1,"Villa Medici",'Rome',"Italy",'Geneva','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 4),2,"Palazzo Barberini",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 4),3,"San Carlo alle Quattro Fontane",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 4),1,"Piazza Repubblica",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 4),1,"Baths of Diocletian",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 4),9,"Santa Maria degli Angeli",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
#includes Sistine's Chapel & Stanze di Raffaelo
data_list.append([datetime.datetime(2013, 4, 4),162,"Vatican Museums",'Rome',"Vatican",'Rome','Rome',"Vatican",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 4),1,"Vatican Gardens",'Rome',"Vatican",'Rome','Rome',"Vatican",['Heidrun']])
#includes the collonades
data_list.append([datetime.datetime(2013, 4, 4),104,"St Peter's Basilica",'Rome',"Vatican",'Rome','Rome',"Vactican",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 4),2,"Apostolic Palace",'Rome',"Vatican",'Rome','Rome',"Vatican",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 4),7,"Castel Sant'Angelo",'Rome',"Italy",'Rome','Rome',"",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 4),21,"Palazzo Primoli",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 4),1,"Stadium of Domitian",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 4),9,"Piazza Navona",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 4),5,"Sant'Agnese in Agone",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 4),1,"Piazza de'Massimi",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 4),1,"Sant'Andrea della Valle",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 4),1,"Largo di Torre Argentina",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 4),23,"Il Gesu",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 4),16,"Santa Maria in Aracoeli",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
#facade capitoline museums, inside for museum
data_list.append([datetime.datetime(2013, 4, 4),11,"Piazza del Campidoglio",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 4),1,"Synagogue",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 4),1,"San Carlo ai Catinari ",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 4),70,"Capitoline Museums",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 4),9,"Forum Romanum",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 4),4,"Monumento Nazionale a Vittorio Emanuele II",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 4),2,"Palazzo Venezia",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 4),1,"Santa Maria di Loreto",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 4),1,"Santa Maria al Foro Traiano",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 4),1,"Column of Trajan",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 4),9,"Santi Apostoli",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 4),2,"Oratorium Santissimo Crocifisso",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 4),2,"Galleria Sciarra",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 4),10,"Trevi Fountain",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 5),1,"Piazza Viminale",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
#no church in main focus
data_list.append([datetime.datetime(2013, 4, 5),1,"Piazza Santa Maria Maggiore",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 5),33,"Santa Maria Maggiore",'Rome',"Vatican",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 5),16,"Santa Prassede",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 5),5,"Santa Pudenzia",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 5),2,"Trophies of Marius",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 5),11,"Santa Croce in Gerusalemme",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 5),2,"Aurelian Walls",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
#with treasury and cloister
data_list.append([datetime.datetime(2013, 4, 5),55,"Basilica di San Giovanni in Laterano",'Rome',"Vatican",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 5),47,"Palazzo di Laterano",'Rome',"Vatican",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 5),2,"Piazza di Laterano",'Rome',"Vatican",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 5),9,"Battistero Lateranense",'Rome',"Vatican",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 5),3,"Triclinium Leoninum",'Rome',"Vatican",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 5),1,"Porta Asinaria",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 5),37,"Villa dei Quintili",'Rome',"Italy",'Rome','Rome',"",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 5),8,"Via Appia Antica",'Rome',"Italy",'Rome','Rome',"",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 5),8,"Cecilia Metella Mausoleum",'Rome',"Italy",'Rome','Rome',"",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 5),2,"Villa of Maxentius",'Rome',"Italy",'Rome','Rome',"",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 5),13,"San Sebastiano fuori le Mura",'Rome',"Italy",'Rome','Rome',"",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 5),1,"Porta San Sebastiano",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 5),35,"San Paolo fuori le Mura",'Rome',"Vatican",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 6),2,"Column of Marcus Aurelius",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 6),4,"Santa Maria in Aquiro",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 6),2,"Palazzo Madama",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 6),4,"Piazza Navona",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 6),1,"Sant'Agnese in Agone",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 6),3,"Nostra Signora del Sacro Cuore",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 6),93,"Palazzo Colonna",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 6),1,"Monumento Nazionale a Vittorio Emanuele II",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 6),7,"Palazzo Doria Pamphilj",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 6),7,"Santi Apostoli",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 6),20,"Sant'Ignazio'",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 6),4,"Pantheon",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 6),1,"Piazza della Rotonda",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 6),6,"Maria Sopra Minerva",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 6),2,"Sant'Angelo in Pescheria",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 6),4,"Teatro Marcello",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 6),3,"San Nicola in Carcere",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 6),2,"Pont Rotto",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 6),2,"Triton Fountain",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 6),12,"Santa Maria in Cosmedin",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 6),2,"Circus Maximus",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 6),3,"Imperial Palace on Palatine Hill",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 6),1,"Santi Andrea e Gregorio al Celio",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 6),10,"Santa Sabina",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 6),38,"Baths of Caracalla",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 6),6,"Santo Stefano Rotondo",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 6),2,"Basilica di San Giovanni in Laterano",'Rome',"Vatican",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 6),1,"Palazzo di Laterano",'Rome',"Vatican",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 6),5,"Sancta Sanctorum",'Rome',"Vatican",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 7),7,"Palazzo Quirinale",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 7),1,"St Peter's Basilica",'Rome',"Vatican",'Rome','Rome',"Vactican",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 7),14,"Sant'Andrea al Quirinale",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 7),1,"Military Cathedral Santa Caterina da Siena in Magnanapoli",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 7),3,"Column of Trajan",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 7),7,"Santa Maria al Foro Traiano",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 7),12,"Imperial Forums",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 7),10,"Monumento Nazionale a Vittorio Emanuele II",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 7),1,"Trevi Fountain",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 7),1,"Palazzo Montecitorio",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 7),6,"Santa Maria di Loreto",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 7),4,"Colosseum",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
#backside
data_list.append([datetime.datetime(2013, 4, 7),2,"Capitol",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 7),2,"Santi Luca e Martino",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 7),1,"Imperial Palace on Palatine Hill",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 7),3,"Forum Romanum",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 7),7,"Santi Cosma e Damiano",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 7),1,"Arch of Constantine",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 7),6,"Villa Torlonia Park",'Rome',"Italy",'Rome','Rome',"",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 7),36,"Villa Torlonia Casino Nobile",'Rome',"Italy",'Rome','Rome',"",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 7),18,"Villa Torlonia Casina delle Civette",'Rome',"Italy",'Rome','Rome',"",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 7),5,"Santa Constanza",'Rome',"Italy",'Rome','Rome',"",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 7),5,"Sant'Agnese fuori le Mura",'Rome',"Italy",'Rome','Rome',"",['Heidrun']])

data_list.append([datetime.datetime(2013, 4, 8),2,"Santi Claudio e Andrea dei Borgognoni",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 8),5,"San Silvestro in Capite",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 8),1,"Palazzo Montecitorio",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 8),1,"Hadrian's Temple",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 8),4,"Pantheon",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 8),11,"Piazza della Rotonda",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 8),3,"Sapienza",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 8),9,"Sant'Andrea della Valle",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 8),2,"San Carlo",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 8),27,"Villa Farnesina",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 8),5,"San Pietro in Montorio",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 8),1,"Palazzo Farnese",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 8),14,"Santa Maria in Trastevere",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 8),1,"Santi Quaranta Martiri e San Pasquale Babylon",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 8),3,"San Francesco a Ripa in Trastevere",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 8),7,"Santa Cecilia in Trastevere",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 8),1,"Circus Maximus",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 8),20,"Colosseum",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
#backside
data_list.append([datetime.datetime(2013, 4, 8),4,"Capitol",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 7),2,"Santi Luca e Martino",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 8),21,"Imperial Palace on Palatine Hill",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 8),31,"Forum Romanum",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 8),4,"Temple of Venus and Roma",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 8),3,"Arch of Constantine",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 8),11,"Santi Giovanni e Paolo",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 8),3,"Santi Andrea e Gregorio a Celio",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 8),8,"Santa Francesca Romana",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 8),12,"San Clemente",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 8),3,"Baths of Trajan",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 8),15,"San Pietro in Vincoli",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 8),11,"San Carlo alle Quattro Fontane",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 9),65,"Villa Adriana",'Tivoli',"Italy",'Rome','Rome',"Villa Adriana",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 9),98,"Villa d'Este",'Tivoli',"Italy",'Rome','Rome',"Villa d'Este",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 9),55,"Villa Gregoriana",'Tivoli',"Italy",'Rome','Rome',"",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 9),2,"Vesta Temple",'Tivoli',"Italy",'Rome','Rome',"",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 9),1,"Tiburnus Temple",'Tivoli',"Italy",'Rome','Rome',"",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 9),3,"Pincio",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 9),27,"Santa Maria del Popolo",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 9),7,"Piazza del Popolo",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 9),1,"Porta del Popolo",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 9),6,"Santa Maria dei Miracoli",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 9),1,"Santi Ambrogio e Carlo al Corso",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 9),1,"St Peter's Basilica",'Rome',"Vatican",'Rome','Rome',"Vactican",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 9),1,"Monumento Nazionale a Vittorio Emanuele II",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 9),1,"Piazza Mignanelli",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 9),7,"Piazza di Spagna",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 9),8,"Trinita dei Monti",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 10),2,"Porta Pinciana",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 10),9,"Villa Borghese",'Rome',"Italy",'Rome','Rome',"",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 10),8,"Villa Borghese Casino Nobile",'Rome',"Italy",'Rome','Rome',"",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 10),38,"Villa Medici",'Rome',"Italy",'Rome','Rome',"",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 10),1,"Trinita dei Monti",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 10),2,"St Peter's Basilica",'Rome',"Vatican",'Rome','Rome',"Vactican",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 10),90,"Ostia Antica",'Rome',"Italy",'Rome','Rome',"",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 10),14,"Lido Azzuro",'Rome',"Italy",'Rome','Rome',"",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 11),39,"San Lorenzo fuori le Mura",'Rome',"Italy",'Rome','Rome',"",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 11),4,"Piazza Repubblica",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 11),59,"Baths of Diocletian",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])
data_list.append([datetime.datetime(2013, 4, 11),9,"Moses Fountain",'Rome',"Italy",'Rome','Rome',"Rome",['Heidrun']])

# %%
#Mole done
data_list.append([datetime.datetime(2013, 5, 1),9,"Le Mole",'Ayze',"France",'Geneva','Geneva',"",['Pieter','Andrew','David','Rosana']])
data_list.append([datetime.datetime(2013, 5, 1),7,"Le Mole View",'Ayze',"France",'Geneva','Geneva',"",['Pieter','Andrew','David','Rosana']])
#lyon done
data_list.append([datetime.datetime(2013, 5, 25),19,"Cathedral",'Lyon',"France",'Geneva','Geneva',"Lyon",['Hannsjoerg','Andrew']])
data_list.append([datetime.datetime(2013, 5, 25),28,"Notre-Dame de Fourviere",'Lyon',"France",'Geneva','Geneva',"Lyon",['Hannsjoerg','Andrew']])
data_list.append([datetime.datetime(2013, 5, 25),3,"Bartholdi Fountain",'Lyon',"France",'Geneva','Geneva',"Lyon",['Hannsjoerg','Andrew']])
data_list.append([datetime.datetime(2013, 5, 25),17,"Opera",'Lyon',"France",'Geneva','Geneva',"Lyon",['Hannsjoerg','Andrew']])
data_list.append([datetime.datetime(2013, 5, 25),75,"Hotel de Ville",'Lyon',"France",'Geneva','Geneva',"Lyon",['Hannsjoerg','Andrew']])
data_list.append([datetime.datetime(2013, 5, 25),1,"Amphitheatre",'Lyon',"France",'Geneva','Geneva',"Lyon",['Hannsjoerg','Andrew']])
data_list.append([datetime.datetime(2013, 5, 25),5,"Roman Theatre",'Lyon',"France",'Geneva','Geneva',"Lyon",['Hannsjoerg','Andrew']])
data_list.append([datetime.datetime(2013, 5, 25),2,"Roman Odeon",'Lyon',"France",'Geneva','Geneva',"Lyon",['Hannsjoerg','Andrew']])
data_list.append([datetime.datetime(2013, 5, 25),2,"St Nizier",'Lyon',"France",'Geneva','Geneva',"Lyon",['Hannsjoerg','Andrew']])
data_list.append([datetime.datetime(2013, 5, 25),1,"St Paul",'Lyon',"France",'Geneva','Geneva',"Lyon",['Hannsjoerg','Andrew']])
#Reculet done
data_list.append([datetime.datetime(2013, 6, 16),6,"Reculet",'Thoiry',"France",'Geneva','Geneva',"",['Jacob','Jesse','Hannsjoerg','Rosana']])
data_list.append([datetime.datetime(2013, 6, 16),4,"Reculet View",'Thoiry',"France",'Geneva','Geneva',"",['Jacob','Jesse','Hannsjoerg','Rosana']])
#Lac Blanc done
data_list.append([datetime.datetime(2013, 7, 4),1,"Lac d'Index",'Chamonix',"France",'Geneva','Geneva',"",['Pieter','Cameron','Eve','Pieter','Andrew','David','Nick']])
data_list.append([datetime.datetime(2013, 7, 4),12,"Lac Blanc",'Chamonix',"France",'Geneva','Geneva',"",['Pieter','Cameron','Eve','Pieter','Andrew','David','Nick']])
data_list.append([datetime.datetime(2013, 7, 4),12,"Mer de Glace",'Chamonix',"France",'Geneva','Geneva',"",['Pieter','Cameron','Eve','Pieter','Andrew','David','Nick']])
data_list.append([datetime.datetime(2013, 7, 4),3,"Glacier d'Argentiere",'Chamonix',"France",'Geneva','Geneva',"",['Pieter','Cameron','Eve','Pieter','Andrew','David','Nick']])
data_list.append([datetime.datetime(2013, 7, 4),2,"Aiguille Verte",'Chamonix',"France",'Geneva','Geneva',"",['Pieter','Cameron','Eve','Pieter','Andrew','David','Nick']])
data_list.append([datetime.datetime(2013, 7, 4),2,"Mont Blanc",'Chamonix',"France",'Geneva','Geneva',"",['Pieter','Cameron','Eve','Pieter','Andrew','David','Nick']])
#milan done
data_list.append([datetime.datetime(2013, 7, 7),2,"Milano Centrale",'Milano',"Italy",'Geneva','Geneva',"",['Andrew','Nick']])
data_list.append([datetime.datetime(2013, 7, 7),24,"Palazzo Reale",'Milano',"Italy",'Geneva','Geneva',"",['Andrew','Nick']])
data_list.append([datetime.datetime(2013, 7, 7),13,"San Bernardino alle Ossa",'Milano',"Italy",'Geneva','Geneva',"",['Andrew','Nick']])
data_list.append([datetime.datetime(2013, 7, 7),2,"Santo Stefano Maggiore",'Milano',"Italy",'Geneva','Geneva',"",['Andrew','Nick']])
data_list.append([datetime.datetime(2013, 7, 7),7,"San Fedele",'Milano',"Italy",'Geneva','Geneva',"",['Andrew','Nick']])
data_list.append([datetime.datetime(2013, 7, 7),5,"Teatro alla Scala",'Milano',"Italy",'Geneva','Geneva',"",['Andrew','Nick']])
data_list.append([datetime.datetime(2013, 7, 7),7,"Galleria Vittorio Emanuele II",'Milano',"Italy",'Geneva','Geneva',"",['Andrew','Nick']])
data_list.append([datetime.datetime(2013, 7, 7),3,"San Sebastiano",'Milano',"Italy",'Geneva','Geneva',"",['Andrew','Nick']])
data_list.append([datetime.datetime(2013, 7, 7),57,"Duomo",'Milano',"Italy",'Geneva','Geneva',"",['Andrew','Nick']])
data_list.append([datetime.datetime(2013, 7, 7),1,"Palazzo dell'Arengario",'Milano',"Italy",'Geneva','Geneva',"",['Andrew','Nick']])
data_list.append([datetime.datetime(2013, 7, 7),60,"Castello Sforzesco",'Milano',"Italy",'Geneva','Geneva',"",['Andrew','Nick']])
data_list.append([datetime.datetime(2013, 7, 7),5,"Santa Maria delle Grazie",'Milano',"Italy",'Geneva','Geneva',"Church and Dominican Convent of Santa Maria delle Grazie",['Andrew','Nick']])
data_list.append([datetime.datetime(2013, 7, 7),7,"Santa Maria presso San Celso",'Milano',"Italy",'Geneva','Geneva',"",['Andrew','Nick']])
data_list.append([datetime.datetime(2013, 7, 7),7,"Sant'Ambrogio",'Milano',"Italy",'Geneva','Geneva',"",['Andrew','Nick']])
data_list.append([datetime.datetime(2013, 7, 7),2,"Colonne di San Lorenzo",'Milano',"Italy",'Geneva','Geneva',"",['Andrew','Nick']])
data_list.append([datetime.datetime(2013, 7, 7),17,"San Lorenzo",'Milano',"Italy",'Geneva','Geneva',"",['Andrew','Nick']])
data_list.append([datetime.datetime(2013, 7, 7),7,"San Giorgio al Palazzo",'Milano',"Italy",'Geneva','Geneva',"",['Andrew','Nick']])
data_list.append([datetime.datetime(2013, 7, 7),9,"Sant'Alessandro in Zebedia",'Milano',"Italy",'Geneva','Geneva',"",['Andrew','Nick']])
#Stockholm & Copenhagen done
data_list.append([datetime.datetime(2013,7,15),36,"Royal Palace","Stockholm","Sweden","Stockholm","Stockholm","",[]])
data_list.append([datetime.datetime(2013,7,15),18,"Riksdagshuset","Stockholm","Sweden","Stockholm","Stockholm","",[]])
data_list.append([datetime.datetime(2013,7,15),18,"Cathedral","Stockholm","Sweden","Stockholm","Stockholm","",[]])
data_list.append([datetime.datetime(2013,7,15),18,"Riddarholm Church","Stockholm","Sweden","Stockholm","Stockholm","",[]])
data_list.append([datetime.datetime(2013,7,15),5,"City Hall","Stockholm","Sweden","Stockholm","Stockholm","",[]])
data_list.append([datetime.datetime(2013,7,15),20,"Riddarhuset","Stockholm","Sweden","Stockholm","Stockholm","",[]])
data_list.append([datetime.datetime(2013,7,15),24,"Konserthuset","Stockholm","Sweden","Stockholm","Stockholm","",[]])
data_list.append([datetime.datetime(2013,7,16),22,"Drottningholm Palace","Drottningholm","Sweden","Stockholm","Stockholm","Drottningholm Palace",[]])
data_list.append([datetime.datetime(2013,7,16),12,"Drottningholm Palace Garden","Drottningholm","Sweden","Stockholm","Stockholm","Drottningholm Palace",[]])
data_list.append([datetime.datetime(2013,7,16),11,"Drottningholm Chinese Palace","Drottningholm","Sweden","Stockholm","Stockholm","Drottningholm Palace",[]])
data_list.append([datetime.datetime(2013,7,16),7,"Drottningholm Palace Theatre","Drottningholm","Sweden","Stockholm","Stockholm","Drottningholm Palace",[]])
data_list.append([datetime.datetime(2013,7,16),19,"Ulriksdal Palace","Ulriksdal","Sweden","Stockholm","Stockholm","",[]])
data_list.append([datetime.datetime(2013,7,16),45,"Hallwyl Palace","Stockholm","Sweden","Stockholm","Stockholm","",[]])
data_list.append([datetime.datetime(2013,7,16),7,"Royal Theatre","Stockholm","Sweden","Stockholm","Stockholm","",[]])
data_list.append([datetime.datetime(2013,7,17),44,"Gripsholm Palace","Mariefred","Sweden","Stockholm","Stockholm","",[]])
data_list.append([datetime.datetime(2013,7,18),20,"City Hall","Stockholm","Sweden","Stockholm","Stockholm","",[]])
data_list.append([datetime.datetime(2013,7,20),34,"Skokloster Palace","Skokloster","Sweden","Stockholm","Stockholm","",[]])
data_list.append([datetime.datetime(2013,7,20),21,"Royal Palace","Stockholm","Sweden","Stockholm","Stockholm","",[]])
data_list.append([datetime.datetime(2013,7,20),1,"Riksdagshuset","Stockholm","Sweden","Stockholm","Stockholm","",[]])
data_list.append([datetime.datetime(2013,7,21),18,"Rosersberg Palace","Rosersberg","Sweden","Stockholm","Stockholm","",[]])
data_list.append([datetime.datetime(2013,7,21),3,"Klara Church","Stockholm","Sweden","Stockholm","Stockholm","",[]])
data_list.append([datetime.datetime(2013,7,21),12,"Rosendal Palace","Stockholm","Sweden","Stockholm","Stockholm","",[]])
data_list.append([datetime.datetime(2013,7,21),31,"Waldemarsudde","Stockholm","Sweden","Stockholm","Stockholm","",[]])
data_list.append([datetime.datetime(2013,7,21),15,"Waldemarsudde Palace Garden","Stockholm","Sweden","Stockholm","Stockholm","",[]])
data_list.append([datetime.datetime(2013,7,23),24,"Haga Park","Solna","Sweden","Stockholm","Stockholm","",[]])
data_list.append([datetime.datetime(2013,7,23),5,"Gustav III Pavilion","Solna","Sweden","Stockholm","Stockholm","",[]])
data_list.append([datetime.datetime(2013,7,23),21,"Vasa Museum","Stockholm","Sweden","Stockholm","Stockholm","",[]])
data_list.append([datetime.datetime(2013,7,25),17,"Frederiksborg Palace Garden","Hillerod","Denmark","Copenhagen","Copenhagen","",[]])
data_list.append([datetime.datetime(2013,7,25),105,"Frederiksborg Palace","Hillerod","Denmark","Copenhagen","Copenhagen","",[]])
data_list.append([datetime.datetime(2013,7,25),8,"City Hall","Copenhagen","Denmark","Copenhagen","Copenhagen","",[]])
data_list.append([datetime.datetime(2013,7,25),8,"Christiansborg Palace Theatre","Copenhagen","Denmark","Copenhagen","Copenhagen","",[]])
data_list.append([datetime.datetime(2013,7,25),107,"Christiansborg Palace","Copenhagen","Denmark","Copenhagen","Copenhagen","",[]])
data_list.append([datetime.datetime(2013,7,25),3,"Christiansborg Palace Church","Copenhagen","Denmark","Copenhagen","Copenhagen","",[]])
data_list.append([datetime.datetime(2013,7,25),8,"Holmen Church","Copenhagen","Denmark","Copenhagen","Copenhagen","",[]])
data_list.append([datetime.datetime(2013,7,25),5,"Frederik's Church","Copenhagen","Denmark","Copenhagen","Copenhagen","",[]])
data_list.append([datetime.datetime(2013,7,25),4,"Amalienborg Palace","Copenhagen","Denmark","Copenhagen","Copenhagen","",[]])
data_list.append([datetime.datetime(2013,7,25),2,"Ansgar Cathedral","Copenhagen","Denmark","Copenhagen","Copenhagen","",[]])
data_list.append([datetime.datetime(2013,7,25),3,"Kastell","Copenhagen","Denmark","Copenhagen","Copenhagen","",[]])
data_list.append([datetime.datetime(2013,7,25),6,"Little Mermaid","Copenhagen","Denmark","Copenhagen","Copenhagen","",[]])
data_list.append([datetime.datetime(2013,7,25),1,"Rosenborg Palace","Copenhagen","Denmark","Copenhagen","Copenhagen","",[]])
data_list.append([datetime.datetime(2013,7,26),87,"Kronborg Castle","Helsingor","Denmark","Copenhagen","Copenhagen","Kronborg",[]])
data_list.append([datetime.datetime(2013,7,26),33,"Fredensborg Palace","Fredensborg","Denmark","Copenhagen","Copenhagen","",[]])
data_list.append([datetime.datetime(2013,7,26),37,"Fredensborg Palace Garden","Fredensborg","Denmark","Copenhagen","Copenhagen","",[]])
data_list.append([datetime.datetime(2013,7,26),22,"Tivoli","Copenhagen","Denmark","Copenhagen","Copenhagen","",['Susanne']])
data_list.append([datetime.datetime(2013,7,27),52,"Amalienborg Palace","Copenhagen","Denmark","Copenhagen","Copenhagen","",['Susanne']])
data_list.append([datetime.datetime(2013,7,27),192,"Rosenborg Palace","Copenhagen","Denmark","Copenhagen","Copenhagen","",['Susanne']])
data_list.append([datetime.datetime(2013,7,27),1,"Cathedral","Copenhagen","Denmark","Copenhagen","Copenhagen","",['Susanne']])
data_list.append([datetime.datetime(2013,7,27),56,"Tivoli","Copenhagen","Denmark","Copenhagen","Copenhagen","",['Susanne']])
data_list.append([datetime.datetime(2013,7,28),85,"Glyptothek","Copenhagen","Denmark","Copenhagen","Geneva","",[]])
data_list.append([datetime.datetime(2013,7,28),4,"Christiansborg Palace","Copenhagen","Denmark","Copenhagen","Geneva","",[]])
data_list.append([datetime.datetime(2013,7,28),20,"Christiansborg Folketing","Copenhagen","Denmark","Copenhagen","Geneva","",[]])
data_list.append([datetime.datetime(2013,7,28),2,"Cathedral","Copenhagen","Denmark","Copenhagen","Geneva","",[]])
data_list.append([datetime.datetime(2013,7,28),3,"Dragon Fountain","Copenhagen","Denmark","Copenhagen","Geneva","",[]])
data_list.append([datetime.datetime(2013,7,28),1,"City Hall","Copenhagen","Denmark","Copenhagen","Geneva","",[]])
data_list.append([datetime.datetime(2013,7,28),58,"Danish National Museum","Copenhagen","Denmark","Copenhagen","Geneva","",[]])
#venice done
data_list.append([datetime.datetime(2013, 9, 5),4,"Ponte di Rialto",'Venice',"Italy",'Geneva','Venice',"Venice",[]])
data_list.append([datetime.datetime(2013, 9, 5),18,"Ca'Rezzonico",'Venice',"Italy",'Geneva','Venice',"Venice",[]])
data_list.append([datetime.datetime(2013, 9, 5),7,"Carmeni",'Venice',"Italy",'Venice','Geneva',"Venice",[]])
data_list.append([datetime.datetime(2013, 9, 5),15,"Palazzo Zenobio",'Venice',"Italy",'Geneva','Venice',"Venice",[]])
data_list.append([datetime.datetime(2013, 9, 5),24,"Palazzo Franchetti",'Venice',"Italy",'Geneva','Venice',"Venice",[]])
data_list.append([datetime.datetime(2013, 9, 5),1,"Santa Maria della Salute",'Venice',"Italy",'Geneva','Venice',"Venice",[]])
data_list.append([datetime.datetime(2013, 9, 5),2,"Palazzo Loredan",'Venice',"Italy",'Venice','Geneva',"Venice",[]])
data_list.append([datetime.datetime(2013, 9, 5),6,"Ca'Giustinian",'Venice',"Italy",'Geneva','Venice',"Venice",[]])
data_list.append([datetime.datetime(2013, 9, 5),1,"Palazzo Fortuny",'Venice',"Italy",'Geneva','Venice',"Venice",[]])
data_list.append([datetime.datetime(2013, 9, 6),15,"Ca d'Oro",'Venice',"Italy",'Venice','Venice',"Venice",[]])
data_list.append([datetime.datetime(2013, 9, 6),3,"San Giacomo di Rialto",'Venice',"Italy",'Venice','Venice',"Venice",[]])
data_list.append([datetime.datetime(2013, 9, 6),33,"Palazzo Pisani Moretta",'Venice',"Italy",'Venice','Venice',"Venice",[]])
data_list.append([datetime.datetime(2013, 9, 6),4,"Casa di Carlo Goldoni",'Venice',"Italy",'Venice','Venice',"Venice",[]])
data_list.append([datetime.datetime(2013, 9, 6),4,"San Rocco",'Venice',"Italy",'Venice','Venice',"Venice",[]])
data_list.append([datetime.datetime(2013, 9, 6),23,"Scuola Grande di San Rocco",'Venice',"Italy",'Venice','Venice',"Venice",[]])
data_list.append([datetime.datetime(2013, 9, 6),2,"Santa Maria Gloriosa dei Frari",'Venice',"Italy",'Venice','Venice',"Venice",[]])
data_list.append([datetime.datetime(2013, 9, 6),6,"San Pantalon",'Venice',"Italy",'Venice','Venice',"Venice",[]])
data_list.append([datetime.datetime(2013, 9, 6),5,"Ca'Foscari",'Venice',"Italy",'Venice','Venice',"Venice",[]])
data_list.append([datetime.datetime(2013, 9, 5),2,"Palazzo Giustinian",'Venice',"Italy",'Geneva','Venice',"Venice",[]])
data_list.append([datetime.datetime(2013, 9, 6),19,"Scuola Grande di San Giovanni Evangelista",'Venice',"Italy",'Venice','Venice',"Venice",[]])
data_list.append([datetime.datetime(2013, 9, 6),9,"San Giovanni Evangelista",'Venice',"Italy",'Venice','Venice',"Venice",[]])
data_list.append([datetime.datetime(2013, 9, 6),20,"Scuola Grande dei Carmini",'Venice',"Italy",'Venice','Venice',"Venice",[]])
data_list.append([datetime.datetime(2013, 9, 6),1,"San Vidal",'Venice',"Italy",'Venice','Venice',"Venice",[]])
data_list.append([datetime.datetime(2013, 9, 6),15,"Teatro La Fenice",'Venice',"Italy",'Venice','Venice',"Venice",[]])
data_list.append([datetime.datetime(2013, 9, 6),4,"Ateneo Veneto",'Venice',"Italy",'Venice','Venice',"Venice",[]])
data_list.append([datetime.datetime(2013, 9, 6),2,"San Zulian",'Venice',"Italy",'Venice','Venice',"Venice",[]])
data_list.append([datetime.datetime(2013, 9, 6),12,"Palazzo Grimani",'Venice',"Italy",'Venice','Venice',"Venice",[]])
data_list.append([datetime.datetime(2013, 9, 6),40,"Palazzo Querini Stampalia",'Venice',"Italy",'Venice','Venice',"Venice",[]])
data_list.append([datetime.datetime(2013, 9, 6),29,"Basilica di San Marco",'Venice',"Italy",'Venice','Venice',"Venice",[]])
data_list.append([datetime.datetime(2013, 9, 6),4,"Palazzo Correr",'Venice',"Italy",'Venice','Venice',"Venice",[]])
data_list.append([datetime.datetime(2013, 9, 6),4,"Biblioteca Nazionale Marciana",'Venice',"Italy",'Venice','Venice',"Venice",[]])
data_list.append([datetime.datetime(2013, 9, 6),3,"San Giorgio Maggiore",'Venice',"Italy",'Venice','Venice',"Venice",[]])
data_list.append([datetime.datetime(2013, 9, 6),21,"Palazzo Reale",'Venice',"Italy",'Venice','Venice',"Venice",[]])
data_list.append([datetime.datetime(2013, 9, 6),42,"Palazzo Ducale",'Venice',"Italy",'Venice','Venice',"Venice",[]])
data_list.append([datetime.datetime(2013, 9, 7),8,"San Salvador",'Venice',"Italy",'Venice','Venice',"Venice",[]])
data_list.append([datetime.datetime(2013, 9, 7),4,"Basilica di San Marco",'Venice',"Italy",'Venice','Venice',"Venice",[]])
data_list.append([datetime.datetime(2013, 9, 7),18,"Palazzo Ducale",'Venice',"Italy",'Venice','Venice',"Venice",[]])
data_list.append([datetime.datetime(2013, 9, 7),20,"Santa Maria della Salute",'Venice',"Italy",'Geneva','Venice',"Venice",[]])
data_list.append([datetime.datetime(2013, 9, 7),1,"Palazzo Franchetti",'Venice',"Italy",'Geneva','Venice',"Venice",[]])
data_list.append([datetime.datetime(2013, 9, 7),4,"Ca'Rezzonico",'Venice',"Italy",'Geneva','Venice',"Venice",[]])
data_list.append([datetime.datetime(2013, 9, 7),1,"Palazzo Grassi",'Venice',"Italy",'Venice','Venice',"Venice",[]])
data_list.append([datetime.datetime(2013, 9, 7),1,"Palazzo Pisani Moretta",'Venice',"Italy",'Venice','Venice',"Venice",[]])
data_list.append([datetime.datetime(2013, 9, 7),2,"Ca d'Oro",'Venice',"Italy",'Venice','Venice',"Venice",[]])
data_list.append([datetime.datetime(2013, 9, 7),5,"Ponte di Rialto",'Venice',"Italy",'Geneva','Venice',"Venice",[]])
data_list.append([datetime.datetime(2013, 9, 7),1,"Ca'Pesaro",'Venice',"Italy",'Venice','Venice',"Venice",[]])
data_list.append([datetime.datetime(2013, 9, 7),1,"San Simeone Piccolo",'Venice',"Italy",'Venice','Venice',"Venice",[]])
data_list.append([datetime.datetime(2013, 9, 7),1,"Santa Maria della Visitazione",'Venice',"Italy",'Venice','Venice',"Venice",[]])
data_list.append([datetime.datetime(2013, 9, 7),23,"San Giorgio Maggiore",'Venice',"Italy",'Venice','Venice',"Venice",[]])
data_list.append([datetime.datetime(2013, 9, 7),9,"Palazzo delle Prigioni",'Venice',"Italy",'Venice','Venice',"Venice",[]])
data_list.append([datetime.datetime(2013, 9, 7),2,"San Maurizio",'Venice',"Italy",'Venice','Venice',"Venice",[]])
data_list.append([datetime.datetime(2013, 9, 7),1,"San Moise",'Venice',"Italy",'Venice','Venice',"Venice",[]])
data_list.append([datetime.datetime(2013, 9, 7),2,"Santo Stefano",'Venice',"Italy",'Venice','Venice',"Venice",[]])
data_list.append([datetime.datetime(2013, 9, 7),4,"Palazzo Fortuny",'Venice',"Italy",'Geneva','Venice',"Venice",[]])
data_list.append([datetime.datetime(2013, 9, 7),4,"Santi Apostoli",'Venice',"Italy",'Venice','Venice',"Venice",[]])
data_list.append([datetime.datetime(2013, 9, 8),4,"Galleria dell'Academia",'Venice',"Italy",'Venice','Geneva',"Venice",[]])
data_list.append([datetime.datetime(2013, 9, 8),39,"Palazzo Grassi",'Venice',"Italy",'Venice','Geneva',"Venice",[]])
data_list.append([datetime.datetime(2013, 9, 8),5,"San Giovanni Elemosinario",'Venice',"Italy",'Venice','Geneva',"Venice",[]])
data_list.append([datetime.datetime(2013, 9, 8),7,"Ca'Corner",'Venice',"Italy",'Venice','Geneva',"Venice",[]])
data_list.append([datetime.datetime(2013, 9, 8),13,"Ca'Pesaro",'Venice',"Italy",'Venice','Geneva',"Venice",[]])
data_list.append([datetime.datetime(2013, 9, 8),2,"Ca d'Oro",'Venice',"Italy",'Venice','Geneva',"Venice",[]])
data_list.append([datetime.datetime(2013, 9, 8),7,"Palazzo Pisani a Santa Maria",'Venice',"Italy",'Venice','Geneva',"Venice",[]])
data_list.append([datetime.datetime(2013, 9, 8),42,"San Giovanni e Paolo",'Venice',"Italy",'Venice','Geneva',"Venice",[]])
data_list.append([datetime.datetime(2013, 9, 8),1,"I Gesuiti",'Venice',"Italy",'Venice','Geneva',"Venice",[]])
data_list.append([datetime.datetime(2013, 9, 8),11,"Palazzo Mora",'Venice',"Italy",'Venice','Geneva',"Venice",[]])
data_list.append([datetime.datetime(2013, 9, 8),7,"Palazzo Michiel dal Brusa",'Venice',"Italy",'Venice','Geneva',"Venice",[]])
data_list.append([datetime.datetime(2013, 9, 8),29,"Palazzo Albrizzi",'Venice',"Italy",'Venice','Geneva',"Venice",[]])

# %%
#Paris II done
data_list.append([datetime.datetime(2013, 11, 8),48,"Chateau de Compiegne","Compiegne","France",'Paris','Paris',"",['Eric','Chris Lee',"Chris Clarke"]])
data_list.append([datetime.datetime(2013, 11, 8),6,"St Jacques","Compiegne","France",'Paris','Paris',"Routes of Santiago de Compostela",['Eric','Chris Lee',"Chris Clarke"]])
data_list.append([datetime.datetime(2013, 11, 8),4,"Chateau de Chantilly","Chantilly","France",'Paris','Paris',"",['Eric','Chris Lee',"Chris Clarke"]])
data_list.append([datetime.datetime(2013, 11, 8),4,"Chateau de Chantilly Parks","Chantilly","France",'Paris','Paris',"",['Eric','Chris Lee',"Chris Clarke"]])
data_list.append([datetime.datetime(2013, 11, 8),60,"Louvre",'Paris',"France",'Paris','Paris',"Paris, Banks of the Seine",['Eric','Chris Lee',"Chris Clarke"]])
data_list.append([datetime.datetime(2013, 11, 8),1,"Arc du Carousel",'Paris',"France",'Paris','Paris',"Paris, Banks of the Seine",['Eric','Chris Lee',"Chris Clarke"]])
data_list.append([datetime.datetime(2013, 11, 8),1,"Palais Royal",'Paris',"France",'Paris','Paris',"",['Eric','Chris Lee',"Chris Clarke"]])
data_list.append([datetime.datetime(2013, 11, 8),2,"Place des Pyramides",'Paris',"France",'Paris','Paris',"",['Eric','Chris Lee',"Chris Clarke"]])
data_list.append([datetime.datetime(2013, 11, 9),31,"Banque de France",'Paris',"France",'Paris','Paris',"",['Eric','Chris Lee',"Chris Clarke"]])
data_list.append([datetime.datetime(2013, 11, 9),41,"Chateau de Malmaison",'Malmaison',"France",'Paris','Paris',"",['Eric']])
data_list.append([datetime.datetime(2013, 11, 9),30,"Chateau de Maisons",'Maisons-Lafitte',"France",'Paris','Paris',"",['Eric']])
data_list.append([datetime.datetime(2013, 11, 2),8,"Tour Eiffel",'Paris',"France",'Paris','Paris',"Paris, Banks of the Seine",['Eric']])
data_list.append([datetime.datetime(2013, 11, 2),10,"Tour Montparnasse Observatory",'Paris',"France",'Paris','Paris',"",['Eric']])
data_list.append([datetime.datetime(2013, 11, 9),7,"Notre Dame",'Paris',"France",'Paris','Paris',"Paris, Banks of the Seine",['Eric']])
data_list.append([datetime.datetime(2013, 11, 9),4,"Hotel de Ville",'Paris',"France",'Paris','Paris',"Paris, Banks of the Seine",['Eric']])
data_list.append([datetime.datetime(2013, 11, 9),2,"Place de la Republique",'Paris',"France",'Paris','Paris',"Paris, Banks of the Seine",['Eric']])
data_list.append([datetime.datetime(2013, 11, 10),50,"Chateau de Champs-sur-Marne","Champs-sur-Marne","France",'Paris','Paris',"",['Eric','Chris Lee',"Chris Clarke"]])
data_list.append([datetime.datetime(2013, 11, 10),12,"Chateau de Champs-sur-Marne Park","Champs-sur-Marne","France",'Paris','Paris',"",['Eric','Chris Lee',"Chris Clarke"]])
data_list.append([datetime.datetime(2013, 11, 10),72,"Chateau de Vaux-le-Vicomte","Vaux-le-Vicomte","France",'Paris','Paris',"",['Eric','Chris Lee',"Chris Clarke"]])
data_list.append([datetime.datetime(2013, 11, 10),16,"Chateau de Vaux-le-Vicomte Park","Vaux-le-Vicomte","France",'Paris','Paris',"",['Eric','Chris Lee',"Chris Clarke"]])
data_list.append([datetime.datetime(2013, 11, 11),49,"Basilique de St Denis",'St Denis',"France",'Paris','Geneva',"",['Eric','Chris Lee',"Chris Clarke"]])
data_list.append([datetime.datetime(2013, 11, 11),32,"Opera Garnier",'Paris',"France",'Paris','Geneva',"",['Eric','Chris Lee',"Chris Clarke"]])
data_list.append([datetime.datetime(2013, 11, 11),1,"Tour Eiffel",'Paris',"France",'Paris','Paris',"Paris, Banks of the Seine",['Eric','Chris Lee',"Chris Clarke"]])
data_list.append([datetime.datetime(2013, 11, 11),4,"Galleries Lafayette",'Paris',"France",'Paris','Paris',"",['Eric','Chris Lee',"Chris Clarke"]])
data_list.append([datetime.datetime(2013, 11, 11),1,"Sacre Coeur",'Paris',"France",'Paris','Paris',"",['Eric','Chris Lee',"Chris Clarke"]])
data_list.append([datetime.datetime(2013, 11, 11),4,"Place du Chatelet",'Paris',"France",'Paris','Paris',"Paris, Banks of the Seine",['Eric','Chris Lee',"Chris Clarke"]])
data_list.append([datetime.datetime(2013, 11, 11),1,"Tour St Jacques","Paris","France",'Paris','Paris',"Routes of Santiago de Compostela",['Eric','Chris Lee',"Chris Clarke"]])
data_list.append([datetime.datetime(2013, 11, 11),2,"Conciergerie",'Paris',"France",'Paris','Paris',"Paris, Banks of the Seine",['Eric','Chris Lee',"Chris Clarke"]])
data_list.append([datetime.datetime(2013, 11, 11),40,"Sainte Chapelle",'Paris',"France",'Paris','Paris',"Paris, Banks of the Seine",['Eric','Chris Lee',"Chris Clarke"]])
data_list.append([datetime.datetime(2013, 11, 11),11,"Notre Dame",'Paris',"France",'Paris','Paris',"Paris, Banks of the Seine",['Eric','Chris Lee',"Chris Clarke"]])
data_list.append([datetime.datetime(2013, 11, 11),2,"Hotel de Ville",'Paris',"France",'Paris','Paris',"Paris, Banks of the Seine",['Eric','Chris Lee',"Chris Clarke"]])
data_list.append([datetime.datetime(2013, 11, 11),2,"Arc de Triomphe",'Paris',"France",'Paris','Paris',"",['Eric','Chris Lee',"Chris Clarke"]])
#prangins
data_list.append([datetime.datetime(2013, 11, 30),29,"Chateau de Prangins",'Prangins',"Switzerland",'Geneva','Geneva',"",["Hannsjoerg"]])
#Strasbourg
data_list.append([datetime.datetime(2013, 12, 27),49,"Minster",'Strasbourg',"France",'Lauchringen','Lauchringen',"",["Hannsjoerg",'Heidrun','Artur']])
data_list.append([datetime.datetime(2013, 12, 27),49,"Palais Rohan",'Strasbourg',"France",'Lauchringen','Lauchringen',"",["Hannsjoerg",'Heidrun','Artur']])
data_list.append([datetime.datetime(2013, 12, 27),2,"Palais du Rhin",'Strasbourg',"France",'Lauchringen','Lauchringen',"",["Hannsjoerg",'Heidrun','Artur']])

# %%
#2014
data_list.append([datetime.datetime(2014, 5, 10),2,"Parc des Bastions",'Geneva',"Switzerland",'Geneva','Geneva',"",['Hannsjoerg']])
data_list.append([datetime.datetime(2014, 5, 25),1,"Victoria Hall",'Geneva',"Switzerland",'Geneva','Geneva',"",['Hannsjoerg']])
data_list.append([datetime.datetime(2014, 6, 15),3,"Pont Hans Wilsdorf",'Geneva',"Switzerland",'Geneva','Geneva',"",['Hannsjoerg']])
data_list.append([datetime.datetime(2014, 7, 6),2,"Jet d'Eau",'Geneva',"Switzerland",'Geneva','Geneva',"",['Hannsjoerg']])
data_list.append([datetime.datetime(2014, 7, 6),12,"Ethnographical Museum",'Geneva',"Switzerland",'Geneva','Geneva',"",['Hannsjoerg']])

data_list.append([datetime.datetime(2014,5,1),13,"Collegiale",'Neuchatel',"Switzerland",'Geneva','Geneva',"",['Hannsjoerg']])
data_list.append([datetime.datetime(2014,5,1),31,"Chateau",'Neuchatel',"Switzerland",'Geneva','Geneva',"",['Hannsjoerg']])


data_list.append([datetime.datetime(2014,5,29),92,"Gorges du Durnand",'Bovernier',"Switzerland",'Geneva','Geneva',"",['Hannsjoerg']])
data_list.append([datetime.datetime(2014,5,29),2,"Amphitheatre",'Martigny',"Switzerland",'Geneva','Geneva',"",['Hannsjoerg']])

data_list.append([datetime.datetime(2014,6,22),25,"Reichenbach Falls",'Meiringen',"Switzerland",'Geneva','Geneva',"",['Hannsjoerg']])
data_list.append([datetime.datetime(2014,6,22),48,"Aareschlucht",'Meiringen',"Switzerland",'Geneva','Geneva',"",['Hannsjoerg']])
data_list.append([datetime.datetime(2014,6,22),64,"Schloss Oberhofen",'Oberhofen',"Switzerland",'Geneva','Geneva',"",['Hannsjoerg']])
data_list.append([datetime.datetime(2014,6,22),12,"Schlosspark Oberhofen",'Oberhofen',"Switzerland",'Geneva','Geneva',"",['Hannsjoerg']])
data_list.append([datetime.datetime(2014,6,22),3,"Schloss Schadau",'Thun',"Switzerland",'Geneva','Geneva',"",['Hannsjoerg']])
data_list.append([datetime.datetime(2014,6,22),1,"Schloss Spiez",'Spiez',"Switzerland",'Geneva','Geneva',"",['Hannsjoerg']])



#london I 2014 done
data_list.append([datetime.datetime(2014, 7, 24),21,"Syon House",'London',"United Kingdom",'Geneva','London',"",['Heidrun']])
data_list.append([datetime.datetime(2014, 7, 24),21,"Syon House Gardens",'London',"United Kingdom",'Geneva','London',"",['Heidrun']])
data_list.append([datetime.datetime(2014, 7, 24),90,"Kew Gardens",'London',"United Kingdom",'Geneva','London',"Royal Botanic Gardens, Kew",['Anne-Kathrin','Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2014, 7, 24),19,"Kew Gardens - Kew Palace",'London',"United Kingdom",'Geneva','London',"Royal Botanic Gardens, Kew",['Anne-Kathrin','Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2014, 7, 25),6,"Windsor Castle",'Windsor',"United Kingdom",'London','London',"",['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2014, 7, 25),79,"Windsor Castle",'Windsor',"United Kingdom",'London','London',"",['Heidrun']])
data_list.append([datetime.datetime(2014, 7, 25),2,"Eton College",'Eton',"United Kingdom",'London','London',"",['Heidrun']])
data_list.append([datetime.datetime(2014, 7, 25),1,"George V Monument",'Windsor',"United Kingdom",'London','London',"",['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2014, 7, 25),58,"Hatfield House",'Hatfield',"United Kingdom",'London','London',"",['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2014, 7, 25),16,"Hatfield House Gardens",'Hatfield',"United Kingdom",'London','London',"",['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2014, 7, 25),58,"Victoria & Albert Museum",'London',"United Kingdom",'London','London',"",['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2014, 7, 26),7,"Cuckmere Haven",'Seaford',"United Kingdom",'London','London',"",['Anne-Kathrin','Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2014, 7, 26),21,"Seven Sisters",'Seaford',"United Kingdom",'London','London',"",['Anne-Kathrin','Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2014, 7, 26),50,"Royal Pavilion",'Brighton',"United Kingdom",'London','London',"",['Heidrun']])
data_list.append([datetime.datetime(2014, 7, 26),8,"Royal Pavilion",'Brighton',"United Kingdom",'London','London',"",['Anne-Kathrin','Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2014, 7, 26),12,"Brighton Pier",'Brighton',"United Kingdom",'London','London',"",['Anne-Kathrin','Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2014, 7, 26),1,"The Shard",'London',"United Kingdom",'London','London',"",['Anne-Kathrin','Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2014, 7, 27),2,"The Shard",'London',"United Kingdom",'London','London',"",['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2014, 7, 27),28,"Eltham Palace",'London',"United Kingdom",'London','London',"",['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2014, 7, 27),11,"Eltham Palace Gardens",'London',"United Kingdom",'London','London',"",['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2014, 7, 27),1,"Admiralty Arch",'London',"United Kingdom",'London','London',"",['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2014, 7, 27),3,"Trafalgar Square",'London',"United Kingdom",'London','London',"",['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2014, 7, 27),1,"St James's Palace",'London',"United Kingdom",'London','London',"",['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2014, 7, 27),4,"Spencer House",'London',"United Kingdom",'London','London',"",['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2014, 7, 27),46,"Kensington Palace",'London',"United Kingdom",'London','London',"",['Heidrun']])
data_list.append([datetime.datetime(2014, 7, 27),2,"Kensington Gardens",'London',"United Kingdom",'London','London',"",['Heidrun']])
data_list.append([datetime.datetime(2014, 7, 27),6,"British Museum",'London',"United Kingdom",'London','London',"",['Heidrun']])
data_list.append([datetime.datetime(2014, 7, 28),2,"Waterloo Station",'London',"United Kingdom",'London','London',"",['Heidrun']])
data_list.append([datetime.datetime(2014, 7, 28),5,"Spinnaker Tower",'Portsmouth',"United Kingdom",'London','London',"",['Heidrun']])
data_list.append([datetime.datetime(2014, 7, 28),1,"Spitbank Fort",'Portsmouth',"United Kingdom",'London','London',"",['Heidrun']])
data_list.append([datetime.datetime(2014, 7, 28),35,"Osbourne House",'East Cowes',"United Kingdom",'London','London',"",['Heidrun']])
data_list.append([datetime.datetime(2014, 7, 28),15,"Osbourne House Gardens",'East Cowes',"United Kingdom",'London','London',"",['Heidrun']])
data_list.append([datetime.datetime(2014, 7, 28),25,"The Needles",'Totland',"United Kingdom",'London','London',"",['Heidrun']])
data_list.append([datetime.datetime(2014, 7, 28),81,"Alum Bay",'Totland',"United Kingdom",'London','London',"",['Heidrun']])
data_list.append([datetime.datetime(2014, 7, 28),3,"Yarmouth Castle",'Yarmouth',"United Kingdom",'London','London',"",['Heidrun']])
data_list.append([datetime.datetime(2014, 7, 28),3,"Fort Victoria",'Yarmouth',"United Kingdom",'London','London',"",['Heidrun']])
data_list.append([datetime.datetime(2014, 7, 28),1,"Hurst Castle",'Yarmouth',"United Kingdom",'London','London',"",['Heidrun']])
data_list.append([datetime.datetime(2014,7,29),2,"London Monument",'London',"United Kingdom",'London','London',"",['Heidrun']])
data_list.append([datetime.datetime(2014,7,29),3,"Walkie Talkie",'London',"United Kingdom",'London','London',"",['Heidrun']])
data_list.append([datetime.datetime(2014,7,29),5,"The Shard",'London',"United Kingdom",'London','London',"",['Heidrun']])
data_list.append([datetime.datetime(2014,7,29),6,"All Hallows-by-the-Tower",'London',"United Kingdom",'London','London',"",['Heidrun']])
data_list.append([datetime.datetime(2014,7,29),57,"Tower of London",'London',"United Kingdom",'London','London',"Tower of London",['Heidrun']])
data_list.append([datetime.datetime(2014,7,29),2,"City Hall",'London',"United Kingdom",'London','London',"",['Heidrun']])
data_list.append([datetime.datetime(2014,7,29),1,"City Wall",'London',"United Kingdom",'London','London',"",['Heidrun']])
data_list.append([datetime.datetime(2014,7,29),4,"Tower Bridge",'London',"United Kingdom",'London','London',"",['Heidrun']])
data_list.append([datetime.datetime(2014,7,29),1,"HMS Belfast",'London',"United Kingdom",'London','London',"",['Heidrun']])
data_list.append([datetime.datetime(2014,7,29),59,"St Paul's Cathedral",'London',"United Kingdom",'London','London',"",['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2014,7,29),13,"St Paul's Cathedral Dome",'London',"United Kingdom",'London','London',"",['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2014,7,29),1,"Tate Modern",'London',"United Kingdom",'London','London',"",['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2014,7,29),1,"BT Tower",'London',"United Kingdom",'London','London',"",['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2014,7,29),1,"Temple Bar Gate",'London',"United Kingdom",'London','London',"",['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2014,7,29),1,"Queen Anne Monument",'London',"United Kingdom",'London','London',"",['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2014,7,29),5,"Mansion House",'London',"United Kingdom",'London','London',"",['Heidrun']])
data_list.append([datetime.datetime(2014,7,29),7,"Freemason's Hall",'London',"United Kingdom",'London','London',"",['Heidrun']])
data_list.append([datetime.datetime(2014, 7, 30),3,"Radcliffe Camera",'Oxford',"United Kingdom",'London','London',"",['Heidrun']])
data_list.append([datetime.datetime(2014, 7, 30),1,"Clarendon Building",'Oxford',"United Kingdom",'London','London',"",['Heidrun']])
data_list.append([datetime.datetime(2014, 7, 30),1,"Sheldonian Theatre",'Oxford',"United Kingdom",'London','London',"",['Heidrun']])
data_list.append([datetime.datetime(2014, 7, 30),1,"Balliol College",'Oxford',"United Kingdom",'London','London',"",['Heidrun']])
data_list.append([datetime.datetime(2014, 7, 30),22,"Bodleian Library",'Oxford',"United Kingdom",'London','London',"",['Heidrun']])
data_list.append([datetime.datetime(2014, 7, 30),6,"University Church St Mary",'Oxford',"United Kingdom",'London','London',"",['Heidrun']])
data_list.append([datetime.datetime(2014, 7, 30),1,"All Soul's College",'Oxford',"United Kingdom",'London','London',"",['Heidrun']])
data_list.append([datetime.datetime(2014, 7, 30),24,"Christ Church College",'Oxford',"United Kingdom",'London','London',"",['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2014, 7, 30),41,"Christ Church College Cathedral",'Oxford',"United Kingdom",'London','London',"",['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2014, 7, 30),1,"Carfax Tower",'Oxford',"United Kingdom",'London','London',"",['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2014, 7, 30),111,"Blenheim Palace",'Woodstock',"United Kingdom",'London','London',"Blenheim Palace",['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2014, 7, 30),27,"Blenheim Palace Gardens",'Woodstock',"United Kingdom",'London','London',"Blenheim Palace",['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2014,7,31),39,"Palace of Westminster",'London',"United Kingdom",'London','London',"Palace of Westminster and Westminster Abbey including Saint Margaret’s Church",['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2014,7,31),1,"London County Hall",'London',"United Kingdom",'London','London',"",['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2014,7,31),2,"St Margaret's",'London',"United Kingdom",'London','London',"Palace of Westminster and Westminster Abbey including Saint Margaret’s Church",['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2014,7,31),1,"Winston Churchill Monument",'London',"United Kingdom",'London','London',"",['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2014,7,31),3,"Westminster Abbey",'London',"United Kingdom",'London','London',"Palace of Westminster and Westminster Abbey including Saint Margaret’s Church",['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2014,7,31),1,"Old Palace Yard",'London',"United Kingdom",'London','London',"",['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2014,7,31),19,"Banqueting House",'London',"United Kingdom",'London','London',"",['Heidrun']])
data_list.append([datetime.datetime(2014,7,31),1,"Whitehall Horse Guards",'London',"United Kingdom",'London','London',"",['Heidrun']])
data_list.append([datetime.datetime(2014,7,31),9,"St Margaret's",'London',"United Kingdom",'London','London',"Palace of Westminster and Westminster Abbey including Saint Margaret’s Church",['Heidrun']])
data_list.append([datetime.datetime(2014,7,31),50,"Westminster Abbey",'London',"United Kingdom",'London','London',"Palace of Westminster and Westminster Abbey including Saint Margaret’s Church",['Heidrun']])
data_list.append([datetime.datetime(2014,7,31),7,"Palace of Westminster",'London',"United Kingdom",'London','London',"Palace of Westminster and Westminster Abbey including Saint Margaret’s Church",['Heidrun']])
data_list.append([datetime.datetime(2014,7,31),2,"Jewel Tower",'London',"United Kingdom",'London','London',"",['Heidrun']])
data_list.append([datetime.datetime(2014,7,31),39,"Westminster Cathedral",'London',"United Kingdom",'London','London',"",['Heidrun']])
data_list.append([datetime.datetime(2014,7,31),8,"Apsley House",'London',"United Kingdom",'London','London',"",['Heidrun']])
data_list.append([datetime.datetime(2014,7,31),2,"Wellington Arch",'London',"United Kingdom",'London','London',"",['Heidrun']])
data_list.append([datetime.datetime(2014,7,31),1,"Wellington Monument",'London',"United Kingdom",'London','London',"",['Heidrun']])
data_list.append([datetime.datetime(2014,7,31),1,"Royal Artillery Monument",'London',"United Kingdom",'London','London',"",['Heidrun']])
data_list.append([datetime.datetime(2014,7,31),2,"Australian War Memorial",'London',"United Kingdom",'London','London',"",['Heidrun']])
data_list.append([datetime.datetime(2014,7,31),42,"British Museum",'London',"United Kingdom",'London','London',"",['Heidrun']])
data_list.append([datetime.datetime(2014,8,1),35,"Cathedral",'Rochester',"United Kingdom",'London','London',"",['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2014,8,1),37,"Rochester Castle",'Rochester',"United Kingdom",'London','London',"",['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2014,8,1),90,"Cathedral",'Canterbury',"United Kingdom",'London','London',"Canterbury Cathedral",['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2014,8,1),7,"Canterbury Castle",'Canterbury',"United Kingdom",'London','London',"",['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2014,8,1),1,"Town Walls",'Canterbury',"United Kingdom",'London','London',"",['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2014,8,1),2,"Christ Church Gate",'Canterbury',"United Kingdom",'London','London',"",['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2014,8,1),45,"Dover Castle",'Dover',"United Kingdom",'London','London',"",['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2014,8,1),3,"White Cliffs of Dover",'Dover',"United Kingdom",'London','London',"",['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2014, 8, 2),20,"Stonehenge",'Amesbury',"United Kingdom",'London','London',"Stonehenge, Avebury and Associated Sites",['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2014, 8, 2),61,"Cathedral",'Salisbury',"United Kingdom",'London','London',"",['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2014, 8, 2),43,"Roman Baths",'Bath',"United Kingdom",'London','London',"City of Bath",['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2014, 8, 2),25,"Bath Abbey",'Bath',"United Kingdom",'London','London',"City of Bath",['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2014, 8, 2),1,"Guildhall",'Bath',"United Kingdom",'London','London',"City of Bath",['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2014, 8, 2),3,"The Circus",'Bath',"United Kingdom",'London','London',"City of Bath",['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2014, 8, 2),2,"Royal Crescent",'Bath',"United Kingdom",'London','London',"City of Bath",['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2014,8,3),141,"Hampton Court Palace",'London',"United Kingdom",'London','London',"",['Heidrun']])
data_list.append([datetime.datetime(2014,8,3),30,"Hampton Court Palace Gardens",'London',"United Kingdom",'London','London',"",['Heidrun']])
data_list.append([datetime.datetime(2014,8,3),46,"Strawberry Hill House",'London',"United Kingdom",'London','London',"",['Heidrun']])
data_list.append([datetime.datetime(2014,8,3),21,"Chiswick House",'London',"United Kingdom",'London','London',"",['Heidrun']])
data_list.append([datetime.datetime(2014,8,3),18,"Chiswick House Gardens",'London',"United Kingdom",'London','London',"",['Heidrun']])
data_list.append([datetime.datetime(2014,8,3),18,"Chiswick House Gardens",'London',"United Kingdom",'London','London',"",['Heidrun']])
data_list.append([datetime.datetime(2014,8,3),1,"World War I Memorial",'London',"United Kingdom",'London','London',"",['Heidrun']])
data_list.append([datetime.datetime(2014,8,4),22,"Buckingham Palace",'London',"United Kingdom",'London','Geneva',"",['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2014,8,4),10,"Buckingham Palace Gardens",'London',"United Kingdom",'London','Geneva',"",['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2014,8,4),8,"Queen Victoria Memorial",'London',"United Kingdom",'London','Geneva',"",['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2014,8,4),1,"St James's Palace",'London',"United Kingdom",'London','Geneva',"",['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2014,8,4),1,"George VI Memorial",'London',"United Kingdom",'London','Geneva',"",['Hannsjoerg']])
data_list.append([datetime.datetime(2014,8,4),1,"Duke of York Column",'London',"United Kingdom",'London','Geneva',"",['Hannsjoerg']])
data_list.append([datetime.datetime(2014,8,4),1,"Admiralty Arch",'London',"United Kingdom",'London','Geneva',"",['Hannsjoerg']])
data_list.append([datetime.datetime(2014,8,4),1,"Trafalgar Square",'London',"United Kingdom",'London','Geneva',"",['Hannsjoerg']])
data_list.append([datetime.datetime(2014,8,4),34,"Somerset House",'London',"United Kingdom",'London','Geneva',"",['Hannsjoerg']])
data_list.append([datetime.datetime(2014,8,4),15,"Guildhall",'London',"United Kingdom",'London','Geneva',"",['Hannsjoerg']])
data_list.append([datetime.datetime(2014,8,4),4,"St Paul's Cathedral",'London',"United Kingdom",'London','Geneva',"",['Hannsjoerg']])
#vienna & budapest done
data_list.append([datetime.datetime(2014, 8, 22),9,"Stephansdom",'Vienna',"Austria",'Geneva','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2014, 8, 22),2,"Pestsaeule",'Vienna',"Austria",'Geneva','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2014, 8, 22),1,"Peterskirche",'Vienna',"Austria",'Geneva','Vienna',"Vienna",[]])
#outside, kaiserappartments, silberkammer in this point
data_list.append([datetime.datetime(2014, 8, 22),71,"Hofburg",'Vienna',"Austria",'Geneva','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2014, 8, 22),5,"Michaelerkirche",'Vienna',"Austria",'Geneva','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2014, 8, 22),35,"Hofbibliothek",'Vienna',"Austria",'Geneva','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2014, 8, 22),6,"Augustinerkirche",'Vienna',"Austria",'Geneva','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2014, 8, 22),22,"Kaiserliche Schatzkammer",'Vienna',"Austria",'Geneva','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2014, 8, 22),5,"Volksgarten",'Vienna',"Austria",'Geneva','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2014, 8, 22),3,"Parlament",'Vienna',"Austria",'Geneva','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2014, 8, 22),3,"Burgtheater",'Vienna',"Austria",'Geneva','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2014, 8, 22),3,"Rathaus",'Vienna',"Austria",'Geneva','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2014, 8, 22),29,"Gartenpalais Liechtenstein",'Vienna',"Austria",'Geneva','Vienna',"",[]])
data_list.append([datetime.datetime(2014, 8, 22),1,"Votivkirche",'Vienna',"Austria",'Vienna','Geneva',"Vienna",[]])
data_list.append([datetime.datetime(2014, 8, 22),1,"Schottenkirche",'Vienna',"Austria",'Vienna','Geneva',"Vienna",[]])
data_list.append([datetime.datetime(2014, 8, 22),40,"Stadtpalais Liechtenstein",'Vienna',"Austria",'Geneva','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2014, 8, 22),1,"Palais Daun-Kinsky",'Vienna',"Austria",'Geneva','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2014, 8, 23),79,"Schloss Esterhazy",'Eisenstadt',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2014, 8, 23),1,"Johanneskapelle",'Neusiedl am See',"Austria",'Vienna','Vienna',"Fertoe Neusiedlersee Cultural Landscape",[]])
data_list.append([datetime.datetime(2014, 8, 23),102,"Esterhazy Palace",'Fertoed',"Hungary",'Vienna','Vienna',"Fertoe Neusiedlersee Cultural Landscape",[]])
data_list.append([datetime.datetime(2014, 8, 23),20,"Hofburg",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2014, 8, 24),5,"Palais Grassalkovich",'Bratislava',"Slovakia",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2014, 8, 24),9,"Palais Grassalkovich Gardens",'Bratislava',"Slovakia",'Vienna','Vienna',"",[]])
#including national gallery
data_list.append([datetime.datetime(2014, 8, 24),54,"Bratislava Castle",'Bratislava',"Slovakia",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2014, 8, 24),15,"Martin's Cathedral",'Bratislava',"Slovakia",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2014, 8, 24),2,"Novy Most",'Bratislava',"Slovakia",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2014, 8, 24),23,"Old Town Hall",'Bratislava',"Slovakia",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2014, 8, 24),30,"Primartialpalais",'Bratislava',"Slovakia",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2014, 8, 24),21,"Palais Apponyi",'Bratislava',"Slovakia",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2014, 8, 24),3,"Main Square",'Bratislava',"Slovakia",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2014, 8, 24),37,"Schloss Hof",'Engelhartstetten',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2014, 8, 24),33,"Schloss Hof Garten",'Engelhartstetten',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2014, 8, 24),7,"Schloss Hof Gutshof",'Engelhartstetten',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2014, 8, 25),1,"Technische Universitaet",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2014, 8, 25),13,"Karlskirche",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2014, 8, 25),3,"Staatsoper",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2014, 8, 25),4,"Stephansdom",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2014, 8, 25),1,"Peterskirche",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2014, 8, 25),4,"Hofburg",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2014, 8, 27),6,"Peterskirche",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2014, 8, 27),1,"Neuer Markt",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2014, 8, 27),58,"Albertina",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2014, 8, 27),1,"Staatsoper",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2014, 8, 28),67,"Schloss Schoenbrunn",'Vienna',"Austria",'Vienna','Vienna',"Schoenbrunn Palace",[]])
data_list.append([datetime.datetime(2014, 8, 28),33,"Schlosspark Schoenbrunn",'Vienna',"Austria",'Vienna','Vienna',"Schoenbrunn Palace",[]])
data_list.append([datetime.datetime(2014, 8, 28),10,"Schlosspark Schoenbrunn Gloriette",'Vienna',"Austria",'Vienna','Vienna',"Schoenbrunn Palace",[]])
data_list.append([datetime.datetime(2014, 8, 28),41,"Hermesvilla",'Vienna',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2014, 8, 28),1,"Musikverein",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2014, 8, 28),1,"Kuenstlerhaus - Albertina Modern",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2014, 8, 28),42,"Staatsoper",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2014, 8, 28),22,"Winterpalais Prinz Eugen",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2014, 8, 28),18,"Stephansdom",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2014, 8, 28),36,"Schloss Schoenbrunn Palace Theatre",'Vienna',"Austria",'Vienna','Vienna',"Schoenbrunn Palace",[]])
data_list.append([datetime.datetime(2014, 8, 29),12,"Secession",'Vienna',"Austria",'Vienna','Budapest',"Vienna",['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2014, 8, 29),5,"Karlskirche",'Vienna',"Austria",'Vienna','Budapest',"Vienna",['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2014, 8, 29),9,"Musikverein",'Vienna',"Austria",'Vienna','Budapest',"Vienna",['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2014, 8, 29),2,"Staatsoper",'Vienna',"Austria",'Vienna','Budapest',"Vienna",['Artur','Hannsjoerg','Heidrun']])
data_list.append([datetime.datetime(2014, 8, 29),43,"Oberes Belvedere",'Vienna',"Austria",'Vienna','Budapest',"Vienna",[]])
data_list.append([datetime.datetime(2014, 8, 29),32,"Unteres Belvedere",'Vienna',"Austria",'Vienna','Budapest',"Vienna",[]])
data_list.append([datetime.datetime(2014, 8, 29),32,"Belvederegarten",'Vienna',"Austria",'Vienna','Budapest',"Vienna",[]])
data_list.append([datetime.datetime(2014, 8, 29),1,"Stephansdom",'Vienna',"Austria",'Vienna','Budapest',"Vienna",[]])
data_list.append([datetime.datetime(2014, 8, 29),2,"Salesianerinnenkirche",'Vienna',"Austria",'Vienna','Budapest',"Vienna",[]])
data_list.append([datetime.datetime(2014, 8, 29),6,"Alte Donau",'Vienna',"Austria",'Vienna','Budapest',"",[]])
data_list.append([datetime.datetime(2014, 8, 29),3,"Kapuzinerkirche",'Vienna',"Austria",'Vienna','Budapest',"Vienna",[]])
data_list.append([datetime.datetime(2014, 8, 29),3,"Albertina",'Vienna',"Austria",'Vienna','Budapest',"Vienna",[]])
data_list.append([datetime.datetime(2014, 8, 29),1,"Antifaschismusdenkmal",'Vienna',"Austria",'Vienna','Budapest',"Vienna",[]])
data_list.append([datetime.datetime(2014, 8, 29),8,"Hofburg",'Vienna',"Austria",'Vienna','Budapest',"Vienna",[]])
data_list.append([datetime.datetime(2014, 8, 29),3,"Burggarten",'Vienna',"Austria",'Vienna','Budapest',"Vienna",[]])
data_list.append([datetime.datetime(2014, 8, 29),1,"Rathaus",'Vienna',"Austria",'Vienna','Budapest',"Vienna",[]])
data_list.append([datetime.datetime(2014, 8, 29),4,"Pestsaeule",'Vienna',"Austria",'Vienna','Budapest',"Vienna",[]])
data_list.append([datetime.datetime(2014, 8, 30),48,"Parliament",'Budapest',"Hungary",'Budapest','Budapest',"Budapest, including the Banks of the Danube, the Buda Castle Quarter and Andrassy Avenue",[]])
data_list.append([datetime.datetime(2014, 8, 30),45,"Buda Castle",'Budapest',"Hungary",'Budapest','Budapest',"Budapest, including the Banks of the Danube, the Buda Castle Quarter and Andrassy Avenue",[]])
data_list.append([datetime.datetime(2014, 8, 30),1,"St Anne",'Budapest',"Hungary",'Budapest','Budapest',"Budapest, including the Banks of the Danube, the Buda Castle Quarter and Andrassy Avenue",[]])
data_list.append([datetime.datetime(2014, 8, 30),15,"Matthias Church",'Budapest',"Hungary",'Budapest','Budapest',"Budapest, including the Banks of the Danube, the Buda Castle Quarter and Andrassy Avenue",[]])
data_list.append([datetime.datetime(2014, 8, 30),6,"Parliament Square & Monuments",'Budapest',"Hungary",'Budapest','Budapest',"Budapest, including the Banks of the Danube, the Buda Castle Quarter and Andrassy Avenue",[]])
data_list.append([datetime.datetime(2014, 8, 30),38,"Goedoello Palace",'Goedoello',"Hungary",'Budapest','Budapest',"",[]])
data_list.append([datetime.datetime(2014, 8, 30),8,"Goedoello Palace Theatre",'Goedoello',"Hungary",'Budapest','Budapest',"",[]])
data_list.append([datetime.datetime(2014, 8, 30),26,"St Stephan's Basilica",'Budapest',"Hungary",'Budapest','Budapest',"",[]])
data_list.append([datetime.datetime(2014, 8, 30),41,"State Opera",'Budapest',"Hungary",'Budapest','Budapest',"Budapest, including the Banks of the Danube, the Buda Castle Quarter and Andrassy Avenue",[]])
data_list.append([datetime.datetime(2014, 8, 30),12,"Fisherman's Bastion",'Budapest',"Hungary",'Budapest','Budapest',"Budapest, including the Banks of the Danube, the Buda Castle Quarter and Andrassy Avenue",[]])
data_list.append([datetime.datetime(2014, 8, 30),7,"Szechenyi Chain Bridge",'Budapest',"Hungary",'Budapest','Budapest',"Budapest, including the Banks of the Danube, the Buda Castle Quarter and Andrassy Avenue",[]])
data_list.append([datetime.datetime(2014, 8, 30),3,"Holy Trinity Square",'Budapest',"Hungary",'Budapest','Budapest',"Budapest, including the Banks of the Danube, the Buda Castle Quarter and Andrassy Avenue",[]])
data_list.append([datetime.datetime(2014, 8, 30),3,"Sandor Palace",'Budapest',"Hungary",'Budapest','Budapest',"Budapest, including the Banks of the Danube, the Buda Castle Quarter and Andrassy Avenue",[]])
data_list.append([datetime.datetime(2014, 8, 30),1,"Great Synagogue",'Budapest',"Hungary",'Budapest','Budapest',"",[]])
data_list.append([datetime.datetime(2014, 8, 31),2,"Deak Ferenc Square",'Budapest',"Hungary",'Budapest','Budapest',"",[]])
data_list.append([datetime.datetime(2014, 8, 31),77,"Buda Castle",'Budapest',"Hungary",'Budapest','Budapest',"Budapest, including the Banks of the Danube, the Buda Castle Quarter and Andrassy Avenue",[]])
data_list.append([datetime.datetime(2014, 8, 31),1,"Sandor Palace",'Budapest',"Hungary",'Budapest','Budapest',"Budapest, including the Banks of the Danube, the Buda Castle Quarter and Andrassy Avenue",[]])
data_list.append([datetime.datetime(2014, 8, 31),2,"Szechenyi Chain Bridge",'Budapest',"Hungary",'Budapest','Budapest',"Budapest, including the Banks of the Danube, the Buda Castle Quarter and Andrassy Avenue",[]])
data_list.append([datetime.datetime(2014, 8, 31),44,"Matthias Church",'Budapest',"Hungary",'Budapest','Budapest',"Budapest, including the Banks of the Danube, the Buda Castle Quarter and Andrassy Avenue",[]])
data_list.append([datetime.datetime(2014, 8, 31),2,"Parliament",'Budapest',"Hungary",'Budapest','Budapest',"Budapest, including the Banks of the Danube, the Buda Castle Quarter and Andrassy Avenue",[]])
data_list.append([datetime.datetime(2014, 8, 31),2,"Fisherman's Bastion",'Budapest',"Hungary",'Budapest','Budapest',"Budapest, including the Banks of the Danube, the Buda Castle Quarter and Andrassy Avenue",[]])
data_list.append([datetime.datetime(2014, 8, 31),15,"St Stephan's Basilica",'Budapest',"Hungary",'Budapest','Budapest',"",[]])
data_list.append([datetime.datetime(2014, 8, 31),11,"Great Synagogue",'Budapest',"Hungary",'Budapest','Budapest',"",[]])
data_list.append([datetime.datetime(2014, 8, 31),13,"Jewish Museum",'Budapest',"Hungary",'Budapest','Budapest',"",[]])

# %%
#tuscany done
data_list.append([datetime.datetime(2014, 9, 6),1,"Porta Galliera",'Bologna',"Italy",'Geneva','Bologna',"",[]])
data_list.append([datetime.datetime(2014, 9, 6),1,"Castel Galliera",'Bologna',"Italy",'Geneva','Bologna',"",[]])
data_list.append([datetime.datetime(2014, 9, 6),1,"Pincio",'Bologna',"Italy",'Geneva','Bologna',"",[]])
data_list.append([datetime.datetime(2014, 9, 6),7,"Ponte Vecchio",'Florence',"Italy",'Geneva','Bologna',"Florence",[]])
data_list.append([datetime.datetime(2014, 9, 6),46,"Boboli Gardens",'Florence',"Italy",'Geneva','Bologna',"Florence",[]])
data_list.append([datetime.datetime(2014, 9, 6),173,"Palazzo Pitti",'Florence',"Italy",'Geneva','Bologna',"Florence",[]])
data_list.append([datetime.datetime(2014, 9, 6),6,"Duomo",'Florence',"Italy",'Geneva','Bologna',"Florence",[]])
data_list.append([datetime.datetime(2014, 9, 6),2,"Palazzo Vecchio",'Florence',"Italy",'Geneva','Bologna',"Florence",[]])
data_list.append([datetime.datetime(2014, 9, 6),1,"San Spirito",'Florence',"Italy",'Geneva','Bologna',"Florence",[]])
data_list.append([datetime.datetime(2014, 9, 6),53,"Santa Croce",'Florence',"Italy",'Geneva','Bologna',"Florence",[]])
data_list.append([datetime.datetime(2014, 9, 6),1,"San Miniato al Monte",'Florence',"Italy",'Geneva','Bologna',"Florence",[]])
data_list.append([datetime.datetime(2014, 9, 6),2,"Neptune Fountain",'Florence',"Italy",'Geneva','Bologna',"Florence",[]])
data_list.append([datetime.datetime(2014, 9, 6),1,"Basilica San Petronio",'Bologna',"Italy",'Geneva','Bologna',"The Porticoes of Bologna",[]])
data_list.append([datetime.datetime(2014, 9, 6),2,"Palazzo d'Accursio",'Bologna',"Italy",'Geneva','Bologna',"The Porticoes of Bologna",[]])
data_list.append([datetime.datetime(2014, 9, 7),72,"Duomo",'Pisa',"Italy",'Bologna','Bologna',"Piazza del Duomo, Pisa",[]])
data_list.append([datetime.datetime(2014, 9, 7),30,"Baptistery",'Pisa',"Italy",'Bologna','Bologna',"Piazza del Duomo, Pisa",[]])
data_list.append([datetime.datetime(2014, 9, 7),7,"Piazza dei Cavalieri",'Pisa',"Italy",'Bologna','Bologna',"",[]])
data_list.append([datetime.datetime(2014, 9, 7),4,"Santo Stefano dei Cavalieri",'Pisa',"Italy",'Bologna','Bologna',"",[]])
data_list.append([datetime.datetime(2014, 9, 7),3,"Santa Maria della Spina",'Pisa',"Italy",'Bologna','Bologna',"",[]])
data_list.append([datetime.datetime(2014, 9, 7),26,"Palazzo Blu",'Pisa',"Italy",'Bologna','Bologna',"",[]])
data_list.append([datetime.datetime(2014, 9, 7),2,"San Michele in Borgo",'Pisa',"Italy",'Bologna','Bologna',"",[]])
data_list.append([datetime.datetime(2014, 9, 7),2,"Orsanmichele Church",'Florence',"Italy",'Bologna','Bologna',"Florence",[]])
data_list.append([datetime.datetime(2014, 9, 7),5,"Piazza di Santa Trinita",'Florence',"Italy",'Bologna','Bologna',"Florence",[]])
data_list.append([datetime.datetime(2014, 9, 7),3,"Uffizi",'Florence',"Italy",'Bologna','Bologna',"Florence",[]])
data_list.append([datetime.datetime(2014, 9, 7),53,"Palazzo Medici Riccardi",'Florence',"Italy",'Bologna','Bologna',"Florence",[]])
data_list.append([datetime.datetime(2014, 9, 7),50,"Galleria Academia",'Florence',"Italy",'Bologna','Bologna',"Florence",[]])
data_list.append([datetime.datetime(2014, 9, 7),15,"Duomo",'Florence',"Italy",'Bologna','Bologna',"Florence",[]])
data_list.append([datetime.datetime(2014, 9, 7),2,"Palazzo Strozzi",'Florence',"Italy",'Bologna','Bologna',"Florence",[]])
data_list.append([datetime.datetime(2014, 9, 7),9,"San Gaetano",'Florence',"Italy",'Bologna','Bologna',"Florence",[]])
data_list.append([datetime.datetime(2014, 9, 7),1,"Santa Maria Novella",'Florence',"Italy",'Bologna','Bologna',"Florence",[]])
data_list.append([datetime.datetime(2014, 9, 7),3,"Ponte Vecchio",'Florence',"Italy",'Bologna','Bologna',"Florence",[]])
data_list.append([datetime.datetime(2014, 9, 7),3,"Loggia dei Lanzi",'Florence',"Italy",'Bologna','Bologna',"Florence",[]])
data_list.append([datetime.datetime(2014, 9, 7),2,"Neptune Fountain",'Florence',"Italy",'Bologna','Bologna',"Florence",[]])
data_list.append([datetime.datetime(2014, 9, 7),2,"Palazzo Vecchio",'Florence',"Italy",'Bologna','Bologna',"Florence",[]])
data_list.append([datetime.datetime(2014, 9, 8),8,"Oratorio San Filippo Neri",'Bologna',"Italy",'Bologna','Bologna',"The Porticoes of Bologna",[]])
data_list.append([datetime.datetime(2014, 9, 9),2,"Palazzo d'Accursio",'Bologna',"Italy",'Bologna','Bologna',"The Porticoes of Bologna",[]])
data_list.append([datetime.datetime(2014, 9, 9),1,"Basilica San Petronio",'Bologna',"Italy",'Bologna','Bologna',"The Porticoes of Bologna",[]])
data_list.append([datetime.datetime(2014, 9, 9),10,"Cathedral",'Bologna',"Italy",'Bologna','Bologna',"",[]])
data_list.append([datetime.datetime(2014, 9, 6),1,"Madonna di San Luca",'Bologna',"Italy",'Bologna','Bologna',"",[]])
data_list.append([datetime.datetime(2014, 9, 10),14,"Basilica San Petronio",'Bologna',"Italy",'Bologna','Bologna',"The Porticoes of Bologna",[]])
data_list.append([datetime.datetime(2014, 9, 10),3,"Basilica Santo Stefano",'Bologna',"Italy",'Bologna','Bologna',"The Porticoes of Bologna",[]])
data_list.append([datetime.datetime(2014, 9, 10),4,"Piazza Santo Stefano",'Bologna',"Italy",'Bologna','Bologna',"The Porticoes of Bologna",[]])
data_list.append([datetime.datetime(2014, 9, 10),44,"Archiginnasio",'Bologna',"Italy",'Bologna','Bologna',"The Porticoes of Bologna",[]])
data_list.append([datetime.datetime(2014, 9, 10),15,"Palazzo d'Accursio",'Bologna',"Italy",'Bologna','Bologna',"The Porticoes of Bologna",[]])
data_list.append([datetime.datetime(2014, 9, 10),4,"Cathedral",'Bologna',"Italy",'Bologna','Bologna',"",[]])
data_list.append([datetime.datetime(2014, 9, 10),18,"Palazzo Grassi",'Bologna',"Italy",'Bologna','Bologna',"",[]])
data_list.append([datetime.datetime(2014, 9, 11),28,"Palazzo d'Accursio",'Bologna',"Italy",'Bologna','Bologna',"The Porticoes of Bologna",[]])
data_list.append([datetime.datetime(2014, 9, 11),9,"Santa Maria della Vita",'Bologna',"Italy",'Bologna','Bologna',"",[]])
data_list.append([datetime.datetime(2014, 9, 11),26,"Basilica di San Domenico",'Bologna',"Italy",'Bologna','Bologna',"",[]])
data_list.append([datetime.datetime(2014, 9, 11),9,"Santa Maria della Vita",'Bologna',"Italy",'Bologna','Bologna',"",[]])
data_list.append([datetime.datetime(2014, 9, 11),13,"Corpus Domini (Chiesa della Santa)",'Bologna',"Italy",'Bologna','Bologna',"",[]])
data_list.append([datetime.datetime(2014, 9, 11),21,"Palazzo Pepoli Campogrande",'Bologna',"Italy",'Bologna','Bologna',"",[]])
data_list.append([datetime.datetime(2014, 9, 11),20,"Basilica Santo Stefano",'Bologna',"Italy",'Bologna','Bologna',"The Porticoes of Bologna",[]])
data_list.append([datetime.datetime(2014, 9, 11),18,"San Giacomo MaggioreSan Giacomo Maggiore",'Bologna',"Italy",'Bologna','Bologna',"The Porticoes of Bologna",[]])
data_list.append([datetime.datetime(2014, 9, 11),8,"Cathedral",'Bologna',"Italy",'Bologna','Bologna',"",[]])
data_list.append([datetime.datetime(2014, 9, 11),3,"Madonna di San Luca",'Bologna',"Italy",'Bologna','Bologna',"",[]])
data_list.append([datetime.datetime(2014, 9, 12),4,"San Lorenzo",'Florence',"Italy",'Bologna','Florence',"Florence",[]])
data_list.append([datetime.datetime(2014, 9, 12),2,"Duomo",'Florence',"Italy",'Bologna','Florence',"Florence",[]])
data_list.append([datetime.datetime(2014, 9, 12),21,"Baptistery",'Florence',"Italy",'Bologna','Florence',"Florence",[]])
data_list.append([datetime.datetime(2014, 9, 12),122,"Palazzo Vecchio",'Florence',"Italy",'Bologna','Florence',"Florence",[]])
data_list.append([datetime.datetime(2014, 9, 12),1,"Neptune Fountain",'Florence',"Italy",'Bologna','Florence',"Florence",[]])
data_list.append([datetime.datetime(2014, 9, 12),34,"Capelle Medicee",'Florence',"Italy",'Bologna','Florence',"Florence",[]])
data_list.append([datetime.datetime(2014, 9, 13),2,"San Lorenzo",'Florence',"Italy",'Florence','Florence',"Florence",[]])
data_list.append([datetime.datetime(2014, 9, 13),42,"Palazzo Davanzati",'Florence',"Italy",'Florence','Florence',"Florence",[]])
data_list.append([datetime.datetime(2014, 9, 13),5,"Baptistery",'Florence',"Italy",'Florence','Florence',"Florence",[]])
data_list.append([datetime.datetime(2014, 9, 13),30,"Duomo",'Florence',"Italy",'Florence','Florence',"Florence",[]])
data_list.append([datetime.datetime(2014, 9, 13),50,"Santa Croce",'Florence',"Italy",'Florence','Florence',"Florence",[]])
data_list.append([datetime.datetime(2014, 9, 13),1,"Palazzo Vecchio",'Florence',"Italy",'Florence','Florence',"Florence",[]])
data_list.append([datetime.datetime(2014, 9, 13),1,"Palazzo Pitti",'Florence',"Italy",'Florence','Florence',"Florence",[]])
data_list.append([datetime.datetime(2014, 9, 13),11,"San Spirito",'Florence',"Italy",'Florence','Florence',"Florence",[]])
data_list.append([datetime.datetime(2014, 9, 13),42,"Casa Martelli",'Florence',"Italy",'Florence','Florence',"Florence",[]])
data_list.append([datetime.datetime(2014, 9, 13),1,"Ponte Vecchio",'Florence',"Italy",'Florence','Florence',"Florence",[]])
data_list.append([datetime.datetime(2014, 9, 13),6,"Piazza del Campo",'Siena',"Italy",'Florence','Florence',"Siena",[]])
data_list.append([datetime.datetime(2014, 9, 13),5,"Piazza Salimbeni",'Siena',"Italy",'Florence','Florence',"Siena",[]])
data_list.append([datetime.datetime(2014, 9, 13),34,"Palazzo Pubblico",'Siena',"Italy",'Florence','Florence',"Siena",[]])
data_list.append([datetime.datetime(2014, 9, 13),79,"Duomo",'Siena',"Italy",'Florence','Florence',"Siena",[]])
data_list.append([datetime.datetime(2014, 9, 13),14,"Baptistery",'Siena',"Italy",'Florence','Florence',"Siena",[]])
data_list.append([datetime.datetime(2014, 9, 13),7,"Duomo Crypt",'Siena',"Italy",'Florence','Florence',"Siena",[]])
data_list.append([datetime.datetime(2014, 9, 13),1,"San Domenico",'Siena',"Italy",'Florence','Florence',"Siena",[]])
data_list.append([datetime.datetime(2014, 9, 14),31,"Villa Corsini",'Florence',"Italy",'Florence','Geneva',"",[]])
data_list.append([datetime.datetime(2014, 9, 14),88,"Villa della Petraia",'Florence',"Italy",'Florence','Geneva',"Medici Villas and Gardens in Tuscany",[]])
data_list.append([datetime.datetime(2014, 9, 14),1,"Fortezza da Basso",'Florence',"Italy",'Florence','Geneva',"Florence",[]])
data_list.append([datetime.datetime(2014, 9, 14),8,"Palazzo Vecchio",'Florence',"Italy",'Florence','Geneva',"Florence",[]])
data_list.append([datetime.datetime(2014, 9, 14),4,"Loggia dei Lanzi",'Florence',"Italy",'Florence','Geneva',"Florence",[]])
data_list.append([datetime.datetime(2014, 9, 14),72,"Santa Maria Novella",'Florence',"Italy",'Florence','Geneva',"Florence",[]])
data_list.append([datetime.datetime(2014, 9, 14),4,"Duomo",'Florence',"Italy",'Florence','Geneva',"Florence",[]])
data_list.append([datetime.datetime(2014, 9, 14),38,"Palazzo Bargello",'Florence',"Italy",'Florence','Geneva',"Florence",[]])
data_list.append([datetime.datetime(2014, 9, 14),2,"San Firenze",'Florence',"Italy",'Florence','Geneva',"Florence",[]])
data_list.append([datetime.datetime(2014, 9, 14),7,"San Lorenzo",'Florence',"Italy",'Florence','Geneva',"Florence",[]])
data_list.append([datetime.datetime(2014, 9, 14),1,"Capelle Medicee",'Florence',"Italy",'Florence','Geneva',"Florence",[]])
data_list.append([datetime.datetime(2014, 9, 14),1,"Piazza Santa Maria Novella",'Florence',"Italy",'Florence','Geneva',"Florence",[]])

# %%
#paris done
data_list.append([datetime.datetime(2014, 9, 20),102,"Palais d'Elysee",'Paris',"France",'Paris','Paris',"",[]])
data_list.append([datetime.datetime(2014, 9, 20),11,"Hotel de Beauvau",'Paris',"France",'Paris','Paris',"",[]])
data_list.append([datetime.datetime(2014, 9, 20),23,"Hotel de Charost",'Paris',"France",'Paris','Paris',"",[]])
data_list.append([datetime.datetime(2014, 9, 20),45,"Hotel de Monaco",'Paris',"France",'Paris','Paris',"",[]])
data_list.append([datetime.datetime(2014, 9, 20),5,"Hotel de Besenval",'Paris',"France",'Paris','Paris',"",[]])
data_list.append([datetime.datetime(2014, 9, 20),18,"Hotel de Chatelet",'Paris',"France",'Paris','Paris',"",[]])
data_list.append([datetime.datetime(2014, 9, 20),17,"Hotel de Clermont",'Paris',"France",'Paris','Paris',"",[]])
data_list.append([datetime.datetime(2014, 9, 20),20,"Hotel de Villeroy",'Paris',"France",'Paris','Paris',"",[]])
data_list.append([datetime.datetime(2014, 9, 20),9,"Hotel de Castries",'Paris',"France",'Paris','Paris',"",[]])
data_list.append([datetime.datetime(2014, 9, 20),38,"Hotel de Matignon",'Paris',"France",'Paris','Paris',"",[]])
data_list.append([datetime.datetime(2014, 9, 21),72,"Palais du Luxembourg",'Paris',"France",'Paris','Geneva',"",[]])
data_list.append([datetime.datetime(2014, 9, 21),30,"Petit Luxembourg",'Paris',"France",'Paris','Geneva',"",[]])
data_list.append([datetime.datetime(2014, 9, 21),63,"Hotel de Ville",'Paris',"France",'Paris','Geneva',"Paris, Banks of the Seine",[]])
data_list.append([datetime.datetime(2014, 9, 21),1,"Notre Dame",'Paris',"France",'Paris','Paris',"Geneva, Banks of the Seine",[]])
data_list.append([datetime.datetime(2014, 9, 21),75,"Palais Royal",'Paris',"France",'Paris','Geneva',"",[]])
data_list.append([datetime.datetime(2014, 9, 21),2,"Place de Vendome",'Paris',"France",'Paris','Geneva',"",[]])
data_list.append([datetime.datetime(2014, 9, 21),23,"Hotel de Bourvallais",'Paris',"France",'Paris','Geneva',"",[]])
data_list.append([datetime.datetime(2014, 9, 21),22,"Hotel de Talleyrand",'Paris',"France",'Paris','Geneva',"",[]])
data_list.append([datetime.datetime(2014, 9, 21),35,"Hotel de la Marine",'Paris',"France",'Paris','Geneva',"",[]])
data_list.append([datetime.datetime(2014, 9, 21),22,"Hotel de Salm",'Paris',"France",'Paris','Geneva',"",[]])
data_list.append([datetime.datetime(2014, 9, 21),13,"Hotel de Galliffet",'Paris',"France",'Paris','Geneva',"",[]])
data_list.append([datetime.datetime(2014, 9, 21),18,"Hotel d'Estrees",'Paris',"France",'Paris','Geneva',"",[]])
data_list.append([datetime.datetime(2014, 9, 21),13,"Hotel de Roquelaure",'Paris',"France",'Paris','Geneva',"",[]])
#creux du van
data_list.append([datetime.datetime(2014, 10, 4),12,"Creux du Van",'Montalchez',"Switzerland",'Geneva','Geneva',"",['Manuel','Bing']])

#london II 2014 done
data_list.append([datetime.datetime(2014, 12, 13),13,"Westminster Abbey",'London',"United Kingdom",'London','London',"Palace of Westminster and Westminster Abbey including Saint Margaret’s Church",['Manuel']])
data_list.append([datetime.datetime(2014, 12, 13),4,"Palace of Westminster",'London',"United Kingdom",'London','London',"Palace of Westminster and Westminster Abbey including Saint Margaret’s Church",['Manuel']])
data_list.append([datetime.datetime(2014, 12, 13),11,"Museum of Natural History",'London',"United Kingdom",'London','London',"",['Manuel']])
data_list.append([datetime.datetime(2014, 12, 13),17,"Royal Albert Hall",'London',"United Kingdom",'London','London',"",['Manuel']])
data_list.append([datetime.datetime(2014, 12, 13),4,"Albert Memorial",'London',"United Kingdom",'London','London',"",['Manuel']])
data_list.append([datetime.datetime(2014, 12, 13),33,"Hampton Court Palace",'London',"United Kingdom",'London','London',"",['Manuel']])
data_list.append([datetime.datetime(2014, 12, 13),3,"London Eye",'London',"United Kingdom",'London','London',"",['Manuel']])
data_list.append([datetime.datetime(2014, 12, 13),3,"The Shard",'London',"United Kingdom",'London','London',"",['Manuel']])
data_list.append([datetime.datetime(2014, 12, 13),1,"City Hall",'London',"United Kingdom",'London','London',"",['Manuel']])
data_list.append([datetime.datetime(2014, 12, 13),6,"Tower Bridge",'London',"United Kingdom",'London','London',"",['Manuel']])
data_list.append([datetime.datetime(2014, 12, 13),6,"Tower of London",'London',"United Kingdom",'London','London',"Tower of London",['Manuel']])
data_list.append([datetime.datetime(2014, 12, 13),1,"HMS Belfast",'London',"United Kingdom",'London','London',"",['Manuel']])
data_list.append([datetime.datetime(2014, 12, 13),3,"Piccadilly Circus",'London',"United Kingdom",'London','London',"",['Manuel']])
data_list.append([datetime.datetime(2014, 12, 14),1,"Battersea Power Station",'London',"United Kingdom",'London','Geneva',"",['Manuel']])
data_list.append([datetime.datetime(2014, 12, 14),15,"Windsor Castle",'Windsor',"United Kingdom",'London','Geneva',"",['Manuel']])
data_list.append([datetime.datetime(2014, 12, 14),50,"Wallace House",'London',"United Kingdom",'London','Geneva',"",['Manuel']])
data_list.append([datetime.datetime(2014, 12, 14),14,"British Museum",'London',"United Kingdom",'London','Geneva',"",['Manuel']])

# %%
#2015


#milan & Monza done
data_list.append([datetime.datetime(2015, 3, 14),59,"Duomo",'Milano',"Italy",'Geneva','Milan',"",['Aaron','Can','Nate','Laser','Christine','Kennedy','Devin']])
data_list.append([datetime.datetime(2015, 3, 14),1,"Palazzo dell'Arengario",'Milano',"Italy",'Geneva','Milano',"",['Laser','Aaron','Can','Nate','Christine','Kennedy','Devin']])
data_list.append([datetime.datetime(2015, 3, 14),54,"Villa Reale",'Monza',"Italy",'Geneva','Milano',"",['Laser','Aaron','Can','Nate','Christine','Kennedy','Devin']])
data_list.append([datetime.datetime(2015, 3, 14),6,"Palazzo Reale",'Milano',"Italy",'Geneva','Milano',"",['Laser','Aaron','Can','Nate','Christine','Kennedy','Devin']])
data_list.append([datetime.datetime(2015, 3, 14),2,"Galleria Vittorio Emanuele II",'Milano',"Italy",'Milano','Geneva',"",['Laser','Aaron','Can','Nate','Christine','Kennedy','Devin']])
data_list.append([datetime.datetime(2015, 3, 15),2,"Duomo",'Milano',"Italy",'Milano','Geneva',"",['Aaron','Can','Nate','Christine','Kennedy','Devin']])
data_list.append([datetime.datetime(2015, 3, 15),19,"Palazzo Reale",'Milano',"Italy",'Milano','Geneva',"",['Aaron','Can','Nate','Christine','Kennedy','Devin']])
data_list.append([datetime.datetime(2015, 3, 15),8,"San Bernardino alle Ossa",'Milano',"Italy",'Milano','Geneva',"",['Aaron','Can','Nate','Christine','Kennedy','Devin']])
data_list.append([datetime.datetime(2015, 3, 15),53,"Villa Belgiojoso Bonaparte",'Milano',"Italy",'Milano','Geneva',"",['Aaron','Kennedy','Devin']])
data_list.append([datetime.datetime(2015, 3, 15),1,"San Fedele",'Milano',"Italy",'Milano','Geneva',"",['Aaron','Can','Nate','Christine','Kennedy','Devin']])
data_list.append([datetime.datetime(2015, 3, 15),25,"Palazzo Beltrami",'Milano',"Italy",'Milano','Geneva',"",['Aaron','Can','Nate','Christine','Kennedy','Devin']])
data_list.append([datetime.datetime(2015, 3, 15),13,"Palazzo Amguissola",'Milano',"Italy",'Milano','Geneva',"",['Aaron','Can','Nate','Christine','Kennedy','Devin']])
data_list.append([datetime.datetime(2015, 3, 15),27,"Palazzo Bagatti Valsecchi",'Milano',"Italy",'Milano','Geneva',"",['Aaron','Can','Nate','Christine','Kennedy','Devin']])
data_list.append([datetime.datetime(2015, 3, 15),35,"Villa Necchi Campiglio",'Milano',"Italy",'Milano','Geneva',"",['Aaron','Can','Nate','Christine','Kennedy','Devin']])

data_list.append([datetime.datetime(2015, 3, 28),3,"Basilica of Jesus de Medinaceli",'Madrid',"Spain",'Madrid','Cordoba',"",[]])
data_list.append([datetime.datetime(2015, 3, 28),2,"Palacio de las Cortes",'Madrid',"Spain",'Madrid','Cordoba',"Paseo del Prado and Buen Retiro, a landscape of Arts and Sciences",[]])
data_list.append([datetime.datetime(2015, 3, 28),4,"Palacio de Linares",'Madrid',"Spain",'Madrid','Cordoba',"Paseo del Prado and Buen Retiro, a landscape of Arts and Sciences",['Manuel']])
data_list.append([datetime.datetime(2015, 3, 28),16,"Palacio de Cibeles",'Madrid',"Spain",'Madrid','Cordoba',"Paseo del Prado and Buen Retiro, a landscape of Arts and Sciences",['Manuel']])
data_list.append([datetime.datetime(2015, 3, 28),3,"Plaza de Cibeles with Cibeles Fountain",'Madrid',"Spain",'Madrid','Cordoba',"Paseo del Prado and Buen Retiro, a landscape of Arts and Sciences",['Manuel']])
data_list.append([datetime.datetime(2015, 3, 28),1,"Puerta de Alcala",'Madrid',"Spain",'Madrid','Cordoba',"Paseo del Prado and Buen Retiro, a landscape of Arts and Sciences",['Manuel']])
data_list.append([datetime.datetime(2015, 3, 28),1,"Cason del Buen Retiro",'Madrid',"Spain",'Madrid','Cordoba',"Paseo del Prado and Buen Retiro, a landscape of Arts and Sciences",['Manuel']])
data_list.append([datetime.datetime(2015, 3, 29),4,"Plaza de la Encarnacion",'Sevilla',"Spain",'Cordoba','Cordoba',"",['Manuel']])
data_list.append([datetime.datetime(2015, 3, 29),23,"Palacio de Lebrija",'Sevilla',"Spain",'Cordoba','Cordoba',"",['Manuel']])
data_list.append([datetime.datetime(2015, 3, 29),7,"Cathedral",'Sevilla',"Spain",'Cordoba','Cordoba',"Cathedral, Alcazar and Archivo de Indias in Seville",['Manuel']])
data_list.append([datetime.datetime(2015, 3, 29),8,"Archivo General de Indias",'Sevilla',"Spain",'Cordoba','Cordoba',"Cathedral, Alcazar and Archivo de Indias in Seville",['Manuel']])
data_list.append([datetime.datetime(2015, 3, 29),71,"Alcazar",'Sevilla',"Spain",'Cordoba','Cordoba',"Cathedral, Alcazar and Archivo de Indias in Seville",['Manuel']])
data_list.append([datetime.datetime(2015, 3, 29),1,"Torre del Oro",'Sevilla',"Spain",'Cordoba','Cordoba',"",['Manuel']])
data_list.append([datetime.datetime(2015, 3, 29),4,"Palacio San Telmo",'Sevilla',"Spain",'Cordoba','Cordoba',"",['Manuel']])
data_list.append([datetime.datetime(2015, 3, 29),14,"Plaza de Espana",'Sevilla',"Spain",'Cordoba','Cordoba',"",['Manuel']])
data_list.append([datetime.datetime(2015, 3, 29),42,"Casa de Pilatos",'Sevilla',"Spain",'Cordoba','Cordoba',"",['Manuel']])
data_list.append([datetime.datetime(2015, 3, 29),1,"San Salvador",'Sevilla',"Spain",'Cordoba','Cordoba',"",['Manuel']])
data_list.append([datetime.datetime(2015, 3, 29),1,"San Juan",'Sevilla',"Spain",'Cordoba','Cordoba',"",['Manuel']])
data_list.append([datetime.datetime(2015, 3, 30),42,"Cathedral",'Granada',"Spain",'Cordoba','Cordoba',"",['Manuel']])
data_list.append([datetime.datetime(2015, 3, 30),13,"Palacio de la Madraza",'Granada',"Spain",'Cordoba','Cordoba',"",['Manuel']])
data_list.append([datetime.datetime(2015, 3, 30),2,"Capilla Real",'Granada',"Spain",'Cordoba','Cordoba',"",['Manuel']])
data_list.append([datetime.datetime(2015, 3, 30),116,"Alhambra",'Granada',"Spain",'Cordoba','Cordoba',"Alhambra, Generalife and Albayzin, Granada",['Manuel']])
data_list.append([datetime.datetime(2015, 3, 30),20,"Generalife",'Granada',"Spain",'Cordoba','Cordoba',"Alhambra, Generalife and Albayzin, Granada",['Manuel']])
data_list.append([datetime.datetime(2015, 3, 30),20,"Carmen Rodriguez-Acosta",'Granada',"Spain",'Cordoba','Cordoba',"Alhambra, Generalife and Albayzin, Granada",['Manuel']])

data_list.append([datetime.datetime(2015, 3, 31),43,"Medina Azahara",'Cordoba',"Spain",'Cordoba','Madrid',"Caliphate City of Medina Azahara",['Manuel']])

data_list.append([datetime.datetime(2015, 3, 31),2,"Casa de Sefarad",'Cordoba',"Spain",'Cordoba','Madrid',"Historic Centre of Cordoba",['Manuel']])
data_list.append([datetime.datetime(2015, 3, 31),2,"Synagogue",'Cordoba',"Spain",'Cordoba','Madrid',"Historic Centre of Cordoba",['Manuel']])
data_list.append([datetime.datetime(2015, 3, 31),9,"Banos Califales",'Cordoba',"Spain",'Cordoba','Madrid',"Historic Centre of Cordoba",['Manuel']])
data_list.append([datetime.datetime(2015, 3, 31),4,"Mezqita Cathedral",'Cordoba',"Spain",'Cordoba','Madrid',"Historic Centre of Cordoba",['Manuel']])
data_list.append([datetime.datetime(2015, 3, 31),3,"Column of St Rafael",'Cordoba',"Spain",'Cordoba','Madrid',"Historic Centre of Cordoba",['Manuel']])
data_list.append([datetime.datetime(2015, 3, 31),2,"Roman Bridge",'Cordoba',"Spain",'Cordoba','Madrid',"Historic Centre of Cordoba",['Manuel']])
data_list.append([datetime.datetime(2015, 3, 31),1,"Torre Calahorra",'Cordoba',"Spain",'Cordoba','Madrid',"Historic Centre of Cordoba",['Manuel']])
data_list.append([datetime.datetime(2015, 3, 31),28,"Alcazar de los Reyes Cristianos",'Cordoba',"Spain",'Cordoba','Madrid',"Historic Centre of Cordoba",['Manuel']])
data_list.append([datetime.datetime(2015, 3, 31),2,"Roman Temple",'Cordoba',"Spain",'Cordoba','Madrid',"",['Manuel']])
data_list.append([datetime.datetime(2015, 3, 31),1,"Torre de la Malmuerta",'Cordoba',"Spain",'Cordoba','Madrid',"",['Manuel']])
data_list.append([datetime.datetime(2015, 3, 31),27,"Palacio de Viana",'Cordoba',"Spain",'Cordoba','Madrid',"",['Manuel']])
data_list.append([datetime.datetime(2015,4,1),1,"Puerta de Sol",'Cordoba',"Spain",'Madrid','Madrid',"",['Manuel']])
data_list.append([datetime.datetime(2015,4,1),6,"Roman Aqueduct",'Segovia',"Spain",'Madrid','Madrid',"Old Town of Segovia and its Aqueduct",['Manuel']])
data_list.append([datetime.datetime(2015,4,1),74,"Cathedral",'Segovia',"Spain",'Madrid','Madrid',"Old Town of Segovia and its Aqueduct",['Manuel']])
data_list.append([datetime.datetime(2015,4,1),1,"Plaza Mayor",'Segovia',"Spain",'Madrid','Madrid',"Old Town of Segovia and its Aqueduct",['Manuel']])
data_list.append([datetime.datetime(2015,4,1),28,"Alcazar",'Segovia',"Spain",'Madrid','Madrid',"Old Town of Segovia and its Aqueduct",['Manuel']])
data_list.append([datetime.datetime(2015,4,1),1,"Puerta de San Andres",'Segovia',"Spain",'Madrid','Madrid',"Old Town of Segovia and its Aqueduct",['Manuel']])
data_list.append([datetime.datetime(2015,4,1),25,"Palacio Real de La Granja de San Ildefenso",'La Granja',"Spain",'Madrid','Madrid',"",['Manuel']])
data_list.append([datetime.datetime(2015,4,1),52,"Palacio Real de La Granja de San Ildefenso Gardens",'La Granja',"Spain",'Madrid','Madrid',"",['Manuel']])
data_list.append([datetime.datetime(2015,4,1),1,"San Martin",'Segovia',"Spain",'Madrid','Madrid',"Old Town of Segovia and its Aqueduct",['Manuel']])
data_list.append([datetime.datetime(2015,4,1),1,"Plaza Medina del Campo",'Segovia',"Spain",'Madrid','Madrid',"Old Town of Segovia and its Aqueduct",['Manuel']])
data_list.append([datetime.datetime(2015,4,1),1,"Plaza Mayor",'Madrid',"Spain",'Madrid','Madrid',"",['Manuel']])
data_list.append([datetime.datetime(2015,4,1),1,"San Isidro",'Madrid',"Spain",'Madrid','Madrid',"",['Manuel']])
data_list.append([datetime.datetime(2015,4,1),1,"Casa de Villa",'Madrid',"Spain",'Madrid','Madrid',"",['Manuel']])
data_list.append([datetime.datetime(2015,4,1),1,"Army Cathedral",'Madrid',"Spain",'Madrid','Madrid',"",['Manuel']])
data_list.append([datetime.datetime(2015,4,1),3,"Almudena Cathedral ",'Madrid',"Spain",'Madrid','Madrid',"",['Manuel']])
data_list.append([datetime.datetime(2015,4,1),3,"Palacio Real",'Madrid',"Spain",'Madrid','Madrid',"",['Manuel']])
data_list.append([datetime.datetime(2015,4,1),1,"Plaza de Oriente",'Madrid',"Spain",'Madrid','Madrid',"",['Manuel']])
#naples

#LA

#la tour

#lyon done
data_list.append([datetime.datetime(2015, 7, 8),2,"Jacobin's Fountain",'Lyon',"France",'Lyon','Lyon',"Lyon",[]])
#paris I done
data_list.append([datetime.datetime(2015, 7, 18),141,"Chateau de Versailles","Versailles","France",'Paris','Paris',"Palace and Park of Versailles",['Riju']])
data_list.append([datetime.datetime(2015, 7, 18),38,"Chateau de Versailles","Versailles","France",'Paris','Paris',"Palace and Park of Versailles",[]])
data_list.append([datetime.datetime(2015, 7, 18),71,"Chateau de Versailles Gardens","Versailles","France",'Paris','Paris',"Palace and Park of Versailles",['Riju']])
data_list.append([datetime.datetime(2015, 7, 18),46,"Chateau de Versailles Grand Trianon","Versailles","France",'Paris','Paris',"Palace and Park of Versailles",['Riju']])
data_list.append([datetime.datetime(2015, 7, 18),6,"Chateau de Versailles Grand Trianon Garden","Versailles","France",'Paris','Paris',"Palace and Park of Versailles",['Riju']])
data_list.append([datetime.datetime(2015, 7, 18),22,"Chateau de Versailles Petit Trianon","Versailles","France",'Paris','Paris',"Palace and Park of Versailles",['Riju']])
data_list.append([datetime.datetime(2015, 7, 18),21,"Chateau de Versailles Petit Trianon Garden & Hameau","Versailles","France",'Paris','Paris',"Palace and Park of Versailles",['Riju']])
data_list.append([datetime.datetime(2015, 7, 18),3,"Cathedral","Versailles","France",'Paris','Paris',"",['Riju']])
data_list.append([datetime.datetime(2015, 7, 19),49,"Abbey","Mont-Saint-Michel","France",'Paris','Paris',"Mont-Saint-Michel and its Bay",[]])
data_list.append([datetime.datetime(2015, 7, 19),7,"Town Wall","Mont-Saint-Michel","France",'Paris','Paris',"Mont-Saint-Michel and its Bay",[]])
data_list.append([datetime.datetime(2015, 7, 19),3,"Couesnon Weir","Mont-Saint-Michel","France",'Paris','Paris',"",[]])


#monaco & nice done
data_list.append([datetime.datetime(2015, 8, 22),38,"Monte Carlo Casino",'Monaco',"Monaco",'Beausoleil','Beausoleil',"",['AJ','Laser','Evan']])
data_list.append([datetime.datetime(2015, 8, 22),12,"Monte Carlo Harbour",'Monaco',"Monaco",'Beausoleil','Beausoleil',"",['AJ','Laser','Evan']])
data_list.append([datetime.datetime(2015, 8, 22),12,"Prince's Palace",'Monaco',"Monaco",'Beausoleil','Beausoleil',"",['AJ','Laser','Evan']])
data_list.append([datetime.datetime(2015, 8, 22),12,"Cathedral",'Monaco',"Monaco",'Beausoleil','Beausoleil',"",['AJ','Laser','Evan']])
data_list.append([datetime.datetime(2015, 8, 22),18,"Prince's Car Collection",'Monaco',"Monaco",'Beausoleil','Beausoleil',"",['AJ','Laser','Evan']])
data_list.append([datetime.datetime(2015, 8, 22),13,"Jardin Exotique",'Monaco',"Monaco",'Beausoleil','Beausoleil',"",[]])
data_list.append([datetime.datetime(2015, 8, 22),47,"Grotte de l'Observatoire",'Monaco',"Monaco",'Beausoleil','Beausoleil',"",[]])
data_list.append([datetime.datetime(2015, 8, 23),11,"Cathedral",'Nice',"France",'Beausoleil','Geneva',"",[]])
data_list.append([datetime.datetime(2015, 8, 23),16,"Palais Lascaris",'Nice',"France",'Beausoleil','Beausoleil',"",[]])
data_list.append([datetime.datetime(2015, 8, 23),1,"Villa Massena",'Nice',"France",'Beausoleil','Beausoleil',"",[]])
data_list.append([datetime.datetime(2015, 8, 23),36,"Villa Kerylos",'Beaulieu-sur-Mer',"France",'Beausoleil','Beausoleil',"",[]])
data_list.append([datetime.datetime(2015, 8, 23),29,"Villa Ephrussi de Rothschild",'Beaulieu-sur-Mer',"France",'Beausoleil','Beausoleil',"",[]])
data_list.append([datetime.datetime(2015, 8, 23),17,"Villa Ephrussi de Rothschild Park",'Beaulieu-sur-Mer',"France",'Beausoleil','Beausoleil',"",[]])
data_list.append([datetime.datetime(2015, 8, 23),1,"Villa Massena",'Nice',"France",'Beausoleil','Beausoleil',"",[]])
data_list.append([datetime.datetime(2015, 8, 23),2,"Place Garibaldi",'Nice',"France",'Beausoleil','Beausoleil',"",[]])
data_list.append([datetime.datetime(2015, 8, 23),3,"Place Massena",'Nice',"France",'Beausoleil','Beausoleil',"",[]])


data_list.append([datetime.datetime(2015, 8, 28),11,"Kazan Cathedral",'St Petersburg',"Russia",'Geneva','St Petersburg',"Historic Centre of Saint Petersburg and Related Groups of Monuments",[]])
data_list.append([datetime.datetime(2015, 8, 28),45,"Church of the Savior on Spilled Blood",'St Petersburg',"Russia",'Geneva','St Petersburg',"Historic Centre of Saint Petersburg and Related Groups of Monuments",[]])
data_list.append([datetime.datetime(2015, 8, 28),1,"Winter Palace",'St Petersburg',"Russia",'Geneva','St Petersburg',"Historic Centre of Saint Petersburg and Related Groups of Monuments",[]])
data_list.append([datetime.datetime(2015, 8, 28),45,"St Isaac's Cathedral",'St Petersburg',"Russia",'Geneva','St Petersburg',"Historic Centre of Saint Petersburg and Related Groups of Monuments",[]])
data_list.append([datetime.datetime(2015, 8, 29),5,"St Michaels's Cathedral",'Lomonosow',"Russia",'St Petersburg','St Petersburg',"",[]])
data_list.append([datetime.datetime(2015, 8, 29),24,"Great Menshikow Palace",'Lomonosow',"Russia",'St Petersburg','St Petersburg',"Historic Centre of Saint Petersburg and Related Groups of Monuments",[]])
data_list.append([datetime.datetime(2015, 8, 29),2,"Sliding Hill Pavilion",'Lomonosow',"Russia",'St Petersburg','St Petersburg',"Historic Centre of Saint Petersburg and Related Groups of Monuments",[]])
data_list.append([datetime.datetime(2015, 8, 29),4,"Stone Hall Pavilion",'Lomonosow',"Russia",'St Petersburg','St Petersburg',"Historic Centre of Saint Petersburg and Related Groups of Monuments",[]])
data_list.append([datetime.datetime(2015, 8, 29),3,"Chinese Palace",'Lomonosow',"Russia",'St Petersburg','St Petersburg',"Historic Centre of Saint Petersburg and Related Groups of Monuments",[]])
data_list.append([datetime.datetime(2015, 8, 29),2,"Peter III Palace",'Lomonosow',"Russia",'St Petersburg','St Petersburg',"Historic Centre of Saint Petersburg and Related Groups of Monuments",[]])
data_list.append([datetime.datetime(2015, 8, 29),49,"Peter & Paul Fortress",'St Petersburg',"Russia",'St Petersburg','St Petersburg',"Historic Centre of Saint Petersburg and Related Groups of Monuments",[]])
data_list.append([datetime.datetime(2015, 8, 29),1,"St Isaac's Cathedral",'St Petersburg',"Russia",'Geneva','St Petersburg',"Historic Centre of Saint Petersburg and Related Groups of Monuments",[]])
data_list.append([datetime.datetime(2015, 8, 29),2,"Winter Palace",'St Petersburg',"Russia",'St Petersburg','St Petersburg',"Historic Centre of Saint Petersburg and Related Groups of Monuments",[]])
data_list.append([datetime.datetime(2015, 8, 29),3,"Church of the Savior on Spilled Blood",'St Petersburg',"Russia",'Geneva','St Petersburg',"Historic Centre of Saint Petersburg and Related Groups of Monuments",[]])
data_list.append([datetime.datetime(2015, 8, 29),1,"Mikhailovsky Palace",'St Petersburg',"Russia",'St Petersburg','St Petersburg',"Historic Centre of Saint Petersburg and Related Groups of Monuments",[]])
data_list.append([datetime.datetime(2015, 8, 29),1,"St Michael's Castle",'St Petersburg',"Russia",'St Petersburg','St Petersburg',"Historic Centre of Saint Petersburg and Related Groups of Monuments",[]])
data_list.append([datetime.datetime(2015, 8, 30),70,"Pavlovsk Palace",'Pavlovsk',"Russia",'St Petersburg','St Petersburg',"Historic Centre of Saint Petersburg and Related Groups of Monuments",[]])
data_list.append([datetime.datetime(2015, 8, 30),10,"Pavlovsk Palace Park",'Pavlovsk',"Russia",'St Petersburg','St Petersburg',"Historic Centre of Saint Petersburg and Related Groups of Monuments",[]])
data_list.append([datetime.datetime(2015, 8, 30),5,"Gatchina Palace Park",'Gatchina',"Russia",'St Petersburg','St Petersburg',"Historic Centre of Saint Petersburg and Related Groups of Monuments",[]])
data_list.append([datetime.datetime(2015, 8, 30),6,"Venus Pavilion Gatchina",'Gatchina',"Russia",'St Petersburg','St Petersburg',"Historic Centre of Saint Petersburg and Related Groups of Monuments",[]])
data_list.append([datetime.datetime(2015, 8, 30),5,"Gatchina Palace Park",'Gatchina',"Russia",'St Petersburg','St Petersburg',"Historic Centre of Saint Petersburg and Related Groups of Monuments",[]])
data_list.append([datetime.datetime(2015, 8, 30),45,"Gatchina Palace",'Gatchina',"Russia",'St Petersburg','St Petersburg',"Historic Centre of Saint Petersburg and Related Groups of Monuments",[]])
data_list.append([datetime.datetime(2015, 8, 30),5,"St Paul's Cathedral",'Gatchina',"Russia",'St Petersburg','St Petersburg',"Historic Centre of Saint Petersburg and Related Groups of Monuments",[]])
data_list.append([datetime.datetime(2015, 8, 30),6,"Birch House Gatchina",'Gatchina',"Russia",'St Petersburg','St Petersburg',"Historic Centre of Saint Petersburg and Related Groups of Monuments",[]])
data_list.append([datetime.datetime(2015, 8, 30),2,"Vladimirskaya Church",'St Petersburg',"Russia",'St Petersburg','St Petersburg',"Historic Centre of Saint Petersburg and Related Groups of Monuments",[]])

# %%
#paris II 2015
data_list.append([datetime.datetime(2015, 9, 19),25,"Hotel de Lassay",'Paris',"France",'Paris','Paris',"Paris, Banks of the Seine",[]])
data_list.append([datetime.datetime(2015, 9, 19),30,"Palais Bourbon",'Paris',"France",'Paris','Paris',"Paris, Banks of the Seine",[]])
data_list.append([datetime.datetime(2015, 9, 19),54,"Hotel du Quai d'Orsay",'Paris',"France",'Paris','Paris',"Paris, Banks of the Seine",[]])
data_list.append([datetime.datetime(2015, 9, 19),21,"Hotel de Brienne",'Paris',"France",'Paris','Paris',"",[]])
data_list.append([datetime.datetime(2015, 9, 19),1,"Arc de Triomphe",'Paris',"France",'Paris','Paris',"",[]])
data_list.append([datetime.datetime(2015, 9, 19),15,"Hotel de Breteuil",'Paris',"France",'Paris','Paris',"",[]])
data_list.append([datetime.datetime(2015, 9, 19),34,"Hotel Potocki",'Paris',"France",'Paris','Paris',"",[]])
data_list.append([datetime.datetime(2015, 9, 19),12,"Embassy of Argentina",'Paris',"France",'Paris','Paris',"",[]])
data_list.append([datetime.datetime(2015, 9, 19),7,"Tour Eiffel",'Paris',"France",'Paris','Paris',"Paris, Banks of the Seine",[]])
data_list.append([datetime.datetime(2015, 9, 19),10,"Hotel de La Tremoille",'Paris',"France",'Paris','Paris',"",[]])
data_list.append([datetime.datetime(2015, 9, 19),19,"Hotel de Behague",'Paris',"France",'Paris','Paris',"",[]])
data_list.append([datetime.datetime(2015, 9, 19),16,"Ecole Militaire",'Paris',"France",'Paris','Paris',"Paris, Banks of the Seine",[]])
data_list.append([datetime.datetime(2015, 9, 19),30,"Hotel de Soubise",'Paris',"France",'Paris','Paris',"",[]])
data_list.append([datetime.datetime(2015, 9, 19),11,"Hotel de Rohan",'Paris',"France",'Paris','Paris',"",[]])
data_list.append([datetime.datetime(2015, 9, 20),21,"Hotel de Noirmoutier",'Paris',"France",'Paris','Geneva',"",[]])
data_list.append([datetime.datetime(2015, 9, 20),10,"Hotel de Villars",'Paris',"France",'Paris','Geneva',"",[]])
data_list.append([datetime.datetime(2015, 9, 20),3,"Hotel Brion",'Paris',"France",'Paris','Geneva',"",[]])
data_list.append([datetime.datetime(2015, 9, 20),13,"Hotel de Montmorin",'Paris',"France",'Paris','Geneva',"",[]])
data_list.append([datetime.datetime(2015, 9, 20),5,"Hotel de Vogue",'Paris',"France",'Paris','Geneva',"",[]])
data_list.append([datetime.datetime(2015, 9, 20),53,"Sorbonne",'Paris',"France",'Paris','Geneva',"",[]])
data_list.append([datetime.datetime(2015, 9, 20),5,"MINES ParisTech",'Paris',"France",'Paris','Geneva',"",[]])
data_list.append([datetime.datetime(2015, 9, 20),22,"Val de Grace",'Paris',"France",'Paris','Geneva',"",[]])
data_list.append([datetime.datetime(2015, 9, 20),1,"Place Alphonse Laveran",'Paris',"France",'Paris','Geneva',"",[]])
data_list.append([datetime.datetime(2015, 9, 20),3,"St Patrick's Chapel",'Paris',"France",'Paris','Geneva',"",[]])
data_list.append([datetime.datetime(2015, 9, 20),17,"Pantheon",'Paris',"France",'Paris','Geneva',"",[]])
data_list.append([datetime.datetime(2015, 9, 20),13,"St Etienne-du-Mont",'Paris',"France",'Paris','Geneva',"",[]])
data_list.append([datetime.datetime(2015, 9, 20),6,"Pavillon Boncourt",'Paris',"France",'Paris','Geneva',"",[]])
data_list.append([datetime.datetime(2015, 9, 20),2,"College de France",'Paris',"France",'Paris','Geneva',"",[]])
data_list.append([datetime.datetime(2015, 9, 20),16,"Institut de France",'Paris',"France",'Paris','Geneva',"Paris, Banks of the Seine",[]])
data_list.append([datetime.datetime(2015, 9, 20),1,"Pont Neuf",'Paris',"France",'Paris','Geneva',"Paris, Banks of the Seine",[]])
data_list.append([datetime.datetime(2015, 9, 20),3,"Bourse de Commerce",'Paris',"France",'Paris','Geneva',"",[]])
data_list.append([datetime.datetime(2015, 9, 20),6,"St Eustache",'Paris',"France",'Paris','Geneva',"",[]])
data_list.append([datetime.datetime(2015, 9, 20),2,"Credit Municipal de Paris",'Paris',"France",'Paris','Geneva',"",[]])
data_list.append([datetime.datetime(2015, 9, 20),2,"Hotel de Ville",'Paris',"France",'Paris','Geneva',"Paris, Banks of the Seine",[]])
data_list.append([datetime.datetime(2015, 9, 20),2,"Place du Chatelet",'Paris',"France",'Paris','Geneva',"Paris, Banks of the Seine",[]])
data_list.append([datetime.datetime(2015, 9, 20),2,"Conciergerie",'Paris',"France",'Paris','Geneva',"Paris, Banks of the Seine",[]])
data_list.append([datetime.datetime(2015, 9, 20),1,"Sainte Chapelle",'Paris',"France",'Paris','Geneva',"Paris, Banks of the Seine",[]])
data_list.append([datetime.datetime(2015, 9, 20),2,"Tour St Jacques",'Paris',"France",'Paris','Geneva',"Routes of Santiago de Compostela",[]])

# %%
#munich & Austria 2015
data_list.append([datetime.datetime(2015,10,3),1,"Bavaria","Munich","Germany","Geneva","Garching","",['Eric','Siyi']])
data_list.append([datetime.datetime(2015,10,3),1,"Ruhmeshalle","Munich","Germany","Geneva","Garching","",['Eric','Siyi']])
data_list.append([datetime.datetime(2015,10,3),4,"Frauenkirche","Munich","Germany","Geneva","Garching","",['Eric','Siyi']])
data_list.append([datetime.datetime(2015,10,3),3,"St Michael","Munich","Germany","Geneva","Garching","",['Eric','Siyi']])
data_list.append([datetime.datetime(2015,10,3),2,"Rathaus","Munich","Germany","Geneva","Garching","",['Eric','Siyi']])
data_list.append([datetime.datetime(2015,10,3),4,"Heilig-Geist-Kirche","Munich","Germany","Geneva","Garching","",['Eric','Siyi']])
data_list.append([datetime.datetime(2015,10,3),4,"St Peter","Munich","Germany","Geneva","Garching","",['Eric','Siyi']])
data_list.append([datetime.datetime(2015,10,3),11,"Asamkirche","Munich","Germany","Geneva","Garching","",['Eric','Siyi']])
data_list.append([datetime.datetime(2015,10,3),2,"Theatine Church","Munich","Germany","Geneva","Garching","",['Eric','Siyi']])
data_list.append([datetime.datetime(2015,10,3),2,"Residence","Munich","Germany","Geneva","Garching","",['Eric','Siyi']])
data_list.append([datetime.datetime(2015,10,4),53,"Residence","Munich","Germany","Garching","Wildbad Kreuth","",['Eric','Siyi']])
data_list.append([datetime.datetime(2015,10,4),1,"Frauenkirche","Munich","Germany","Garching","Wildbad Kreuth","",['Eric','Siyi']])
data_list.append([datetime.datetime(2015,10,4),3,"Wildbad Kreuth","Wildbad Kreuth","Germany","Wildbad Kreuth","Wildbad Kreuth","",['Eric','Siyi']])
data_list.append([datetime.datetime(2015,10,8),3,"Wildbad Kreuth","Wildbad Kreuth","Germany","Wildbad Kreuth","Wildbad Kreuth","",['Eric','Siyi']])
data_list.append([datetime.datetime(2015,10,10),62,"Stift Melk","Melk","Austria","Poechlarn","Salzburg","Wachau Cultural Landscape",['Eric','Siyi']])
data_list.append([datetime.datetime(2015,10,10),6,"Stift Melk Gartenpavillon","Melk","Austria","Poechlarn","Salzburg","Wachau Cultural Landscape",['Eric','Siyi']])
data_list.append([datetime.datetime(2015,10,10),1,"Stift Melk Stiftsgarten","Melk","Austria","Poechlarn","Salzburg","Wachau Cultural Landscape",['Eric','Siyi']])
data_list.append([datetime.datetime(2015,10,10),56,"Stift Goettweig","Furth bei Goettweig","Austria","Poechlarn","Salzburg","Wachau Cultural Landscape",['Eric','Siyi']])
data_list.append([datetime.datetime(2015,10,10),28,"Dom","Passau","Germany","Poechlarn","Salzburg","",['Eric','Siyi']])
data_list.append([datetime.datetime(2015,10,10),4,"Neue Residenz","Passau","Germany","Poechlarn","Salzburg","",['Eric','Siyi']])
data_list.append([datetime.datetime(2015,10,10),1,"Veste Oberhaus","Passau","Germany","Poechlarn","Salzburg","",['Eric','Siyi']])
data_list.append([datetime.datetime(2015,10,10),1,"Veste Niederhaus","Passau","Germany","Poechlarn","Salzburg","",['Eric','Siyi']])
data_list.append([datetime.datetime(2015,10,10),2,"Rathaus","Passau","Germany","Poechlarn","Salzburg","",['Eric','Siyi']])
data_list.append([datetime.datetime(2015,10,11),3,"Kajetanerkirche","Salzburg","Austria","Salzburg","Geneva","Salzburg",['Eric','Siyi']])
data_list.append([datetime.datetime(2015,10,11),28,"Alte Residenz","Salzburg","Austria","Salzburg","Geneva","Salzburg",['Eric','Siyi']])
data_list.append([datetime.datetime(2015,10,11),2,"Kapuzinerkloster","Salzburg","Austria","Salzburg","Geneva","Salzburg",['Eric','Siyi']])
data_list.append([datetime.datetime(2015,10,11),1,"Neue Residenz","Salzburg","Austria","Salzburg","Geneva","Salzburg",['Eric','Siyi']])
data_list.append([datetime.datetime(2015,10,11),30,"Dom","Salzburg","Austria","Salzburg","Geneva","Salzburg",['Eric','Siyi']])
data_list.append([datetime.datetime(2015,10,11),31,"Festung Hohensalzburg","Salzburg","Austria","Salzburg","Geneva","Salzburg",['Eric','Siyi']])
data_list.append([datetime.datetime(2015,10,11),1,"Kapitelschwemme","Salzburg","Austria","Salzburg","Geneva","Salzburg",['Eric','Siyi']])

# %%
#berlin 2015
data_list.append([datetime.datetime(2015,11,8),2,"Fernsehturm","Berlin","Germany","Geneva","Berlin","",['Artur','Heidrun']])
data_list.append([datetime.datetime(2015,11,8),7,"Communs Sanssouci","Potsdam","Germany","Geneva","Berlin","Prussian Palaces of Potsdam and Berlin",['Artur','Heidrun']])
data_list.append([datetime.datetime(2015,11,8),71,"Neues Palais Sanssouci","Potsdam","Germany","Geneva","Berlin","Prussian Palaces of Potsdam and Berlin",['Artur','Heidrun']])
data_list.append([datetime.datetime(2015,11,8),1,"Orangerieschloss Sanssouci","Potsdam","Germany","Geneva","Berlin","Prussian Palaces of Potsdam and Berlin",['Artur','Heidrun']])
data_list.append([datetime.datetime(2015,11,8),1,"Neue Kammern Sanssouci","Potsdam","Germany","Geneva","Berlin","Prussian Palaces of Potsdam and Berlin",['Artur','Heidrun']])
data_list.append([datetime.datetime(2015,11,8),2,"Schlosspark Sanssouci","Potsdam","Germany","Geneva","Berlin","Prussian Palaces of Potsdam and Berlin",['Artur','Heidrun']])
data_list.append([datetime.datetime(2015,11,8),57,"Schloss Sanssouci","Potsdam","Germany","Geneva","Berlin","Prussian Palaces of Potsdam and Berlin",['Artur','Heidrun']])
data_list.append([datetime.datetime(2015,11,9),1,"Hauptbahnhof","Hamburg","Germany","Berlin","Berlin","",['Anne-Kathrin','Artur','Heidrun']])
data_list.append([datetime.datetime(2015,11,9),1,"Moeckebergbrunnen","Hamburg","Germany","Berlin","Berlin","",['Anne-Kathrin','Artur','Heidrun']])
data_list.append([datetime.datetime(2015,11,9),61,"Rathaus","Hamburg","Germany","Berlin","Berlin","",['Anne-Kathrin','Artur','Heidrun']])
data_list.append([datetime.datetime(2015,11,9),15,"St Michaelis","Hamburg","Germany","Berlin","Berlin","",['Anne-Kathrin','Artur','Heidrun']])
data_list.append([datetime.datetime(2015,11,9),2,"Petrikirche","Hamburg","Germany","Berlin","Berlin","",['Anne-Kathrin','Artur','Heidrun']])
data_list.append([datetime.datetime(2015,11,9),2,"Elbphilharmonie","Hamburg","Germany","Berlin","Berlin","",['Anne-Kathrin','Artur','Heidrun']])
data_list.append([datetime.datetime(2015,11,9),1,"Cap San Diego","Hamburg","Germany","Berlin","Berlin","",['Anne-Kathrin','Artur','Heidrun']])
data_list.append([datetime.datetime(2015,11,9),4,"St Pauli-Landungsbruecken","Hamburg","Germany","Berlin","Berlin","",['Anne-Kathrin','Artur','Heidrun']])
data_list.append([datetime.datetime(2015,11,9),3,"Rickmer Rickmers","Hamburg","Germany","Berlin","Berlin","",['Anne-Kathrin','Artur','Heidrun']])
data_list.append([datetime.datetime(2015,11,9),4,"Speicherstadt","Hamburg","Germany","Berlin","Berlin","Speicherstadt and Kontorhaus District with Chilehaus",['Anne-Kathrin','Artur','Heidrun']])
data_list.append([datetime.datetime(2015,11,9),5,"Elbtunnel","Hamburg","Germany","Berlin","Berlin","",['Anne-Kathrin','Artur','Heidrun']])
data_list.append([datetime.datetime(2015,11,9),1,"Dancing Towers","Hamburg","Germany","Berlin","Berlin","",['Anne-Kathrin','Artur','Heidrun']])
data_list.append([datetime.datetime(2015,11,9),1,"Millerntor Stadion","Hamburg","Germany","Berlin","Berlin","",['Anne-Kathrin','Artur','Heidrun']])
data_list.append([datetime.datetime(2015,11,10),1,"Michaelkirche","Berlin","Germany","Berlin","Berlin","",['Anne-Kathrin','Artur','Heidrun']])
data_list.append([datetime.datetime(2015,11,10),1,"Staatsrats Building","Berlin","Germany","Berlin","Berlin","",['Anne-Kathrin','Artur','Heidrun']])
data_list.append([datetime.datetime(2015,11,10),2,"Stadtschloss","Berlin","Germany","Berlin","Berlin","",['Anne-Kathrin','Artur','Heidrun']])
data_list.append([datetime.datetime(2015,11,10),1,"Friedrichwerdersche Kirche","Berlin","Germany","Berlin","Berlin","",['Anne-Kathrin','Artur','Heidrun']])
data_list.append([datetime.datetime(2015,11,10),1,"Schlossbruecke","Berlin","Germany","Berlin","Berlin","",['Anne-Kathrin','Artur','Heidrun']])
data_list.append([datetime.datetime(2015,11,10),13,"Zeughaus","Berlin","Germany","Berlin","Berlin","",['Anne-Kathrin','Artur','Heidrun']])
data_list.append([datetime.datetime(2015,11,10),3,"Dom","Berlin","Germany","Berlin","Berlin","",['Anne-Kathrin','Artur','Heidrun']])
data_list.append([datetime.datetime(2015,11,10),1,"Altes Museum","Berlin","Germany","Berlin","Berlin","Museumsinsel",['Anne-Kathrin','Artur','Heidrun']])
data_list.append([datetime.datetime(2015,11,10),9,"East Side Gallery","Berlin","Germany","Berlin","Berlin","",['Anne-Kathrin','Artur','Heidrun']])
data_list.append([datetime.datetime(2015,11,10),1,"Mercedes-Benz-Arena","Berlin","Germany","Berlin","Berlin","",['Anne-Kathrin','Artur','Heidrun']])
data_list.append([datetime.datetime(2015,11,11),62,"Schloss","Schwerin","Germany","Berlin","Berlin","",[]])
data_list.append([datetime.datetime(2015,11,11),6,"Schlosspark","Schwerin","Germany","Berlin","Berlin","",[]])
data_list.append([datetime.datetime(2015,11,11),10,"Dom","Schwerin","Germany","Berlin","Berlin","",[]])
data_list.append([datetime.datetime(2015,11,11),1,"Hauptbahnhof","Schwerin","Germany","Berlin","Berlin","",[]])
data_list.append([datetime.datetime(2015,11,11),1,"Rathausmarkt","Schwerin","Germany","Berlin","Berlin","",[]])
data_list.append([datetime.datetime(2015,11,11),1,"Holstentor","Luebeck","Germany","Berlin","Berlin","Hanseatic City of Luebeck",[]])
data_list.append([datetime.datetime(2015,11,11),31,"Marienkirche","Luebeck","Germany","Berlin","Berlin","Hanseatic City of Luebeck",[]])
data_list.append([datetime.datetime(2015,11,11),5,"Rathaus","Luebeck","Germany","Berlin","Berlin","Hanseatic City of Luebeck",[]])
data_list.append([datetime.datetime(2015,11,11),3,"Petrikirche","Luebeck","Germany","Berlin","Berlin","Hanseatic City of Luebeck",[]])
data_list.append([datetime.datetime(2015,11,11),21,"Dom","Luebeck","Germany","Berlin","Berlin","Hanseatic City of Luebeck",[]])
data_list.append([datetime.datetime(2015,11,11),1,"Hauptbahnhof","Luebeck","Germany","Berlin","Berlin","Hanseatic City of Luebeck",[]])
data_list.append([datetime.datetime(2015,11,11),2,"Hauptbahnhof","Berlin","Germany","Berlin","Berlin","",[]])
data_list.append([datetime.datetime(2015,11,12),21,"Schloss Bellevue",'Berlin',"Germany",'Berlin','Berlin',"",['Anne-Kathrin','Artur','Heidrun']])
data_list.append([datetime.datetime(2015,11,12),2,"Bundespraesidialamt",'Berlin',"Germany",'Berlin','Berlin',"",['Anne-Kathrin','Artur','Heidrun']])
data_list.append([datetime.datetime(2015,11,12),8,"Siegessaeule",'Berlin',"Germany",'Berlin','Berlin',"",['Anne-Kathrin','Artur','Heidrun']])
data_list.append([datetime.datetime(2015,11,12),1,"Moltke Denkmal",'Berlin',"Germany",'Berlin','Berlin',"",['Anne-Kathrin','Artur','Heidrun']])
data_list.append([datetime.datetime(2015,11,12),1,"Bismarck Denkmal",'Berlin',"Germany",'Berlin','Berlin',"",['Anne-Kathrin','Artur','Heidrun']])
data_list.append([datetime.datetime(2015,11,12),9,"Brandenburger Tor",'Berlin',"Germany",'Berlin','Berlin',"",['Anne-Kathrin','Artur','Heidrun']])
data_list.append([datetime.datetime(2015,11,12),2,"Sowjetisches Ehrenmal",'Berlin',"Germany",'Berlin','Berlin',"",['Anne-Kathrin','Artur','Heidrun']])
data_list.append([datetime.datetime(2015,11,12),11,"Reichstag",'Berlin',"Germany",'Berlin','Berlin',"",['Anne-Kathrin','Artur','Heidrun']])
data_list.append([datetime.datetime(2015,11,12),9,"Reichstag Kuppel",'Berlin',"Germany",'Berlin','Berlin',"",['Anne-Kathrin','Artur','Heidrun']])
data_list.append([datetime.datetime(2015,11,12),3,"Bundeskanzleramt",'Berlin',"Germany",'Berlin','Berlin',"",['Anne-Kathrin','Artur','Heidrun']])
data_list.append([datetime.datetime(2015,11,12),3,"Hauptbahnhof",'Berlin',"Germany",'Berlin','Berlin',"",['Anne-Kathrin','Artur','Heidrun']])
data_list.append([datetime.datetime(2015,11,12),4,"Sony Center",'Berlin',"Germany",'Berlin','Berlin',"",['Anne-Kathrin','Artur','Heidrun']])
data_list.append([datetime.datetime(2015,11,13),79,"Stadtschloss",'Weimar',"Germany",'Berlin','Berlin',"Classical Weimar",[]])
data_list.append([datetime.datetime(2015,11,13),15,"Herzogin-Anna-Amalia-Bibliothek",'Weimar',"Germany",'Berlin','Berlin',"Classical Weimar",[]])
data_list.append([datetime.datetime(2015,11,13),2,"Platz der Demokratie",'Weimar',"Germany",'Berlin','Berlin',"Classical Weimar",[]])
data_list.append([datetime.datetime(2015,11,13),13,"Severikirche",'Erfurt',"Germany",'Berlin','Berlin',"",[]])
data_list.append([datetime.datetime(2015,11,13),32,"Dom",'Erfurt',"Germany",'Berlin','Berlin',"",[]])
data_list.append([datetime.datetime(2015,11,13),1,"Domplatz",'Erfurt',"Germany",'Berlin','Berlin',"",[]])
data_list.append([datetime.datetime(2015,11,13),39,"Dom",'Fulda',"Germany",'Berlin','Berlin',"",[]])
data_list.append([datetime.datetime(2015,11,13),35,"Stadtschloss",'Fulda',"Germany",'Berlin','Berlin',"",[]])
data_list.append([datetime.datetime(2015,11,13),4,"Orangerie",'Fulda',"Germany",'Berlin','Berlin',"",[]])
data_list.append([datetime.datetime(2015,11,13),1,"Bonifatiusplatz",'Fulda',"Germany",'Berlin','Berlin',"",[]])
data_list.append([datetime.datetime(2015,11,13),4,"Michaelskirche",'Fulda',"Germany",'Berlin','Berlin',"",[]])
data_list.append([datetime.datetime(2015,11,13),7,"Blasiuskirche",'Fulda',"Germany",'Berlin','Berlin',"",[]])
data_list.append([datetime.datetime(2015,11,15),83,"Schloss Heidecksburg",'Rudolstadt',"Germany",'Berlin','Berlin',"",[]])
data_list.append([datetime.datetime(2015,11,15),73,"Schloss Friedenstein",'Gotha',"Germany",'Berlin','Berlin',"",[]])
data_list.append([datetime.datetime(2015,11,15),2,"Rathaus",'Gotha',"Germany",'Berlin','Berlin',"",[]])
data_list.append([datetime.datetime(2015,11,16),132,"Schloss Charlottenburg",'Berlin',"Germany",'Berlin','Geneva',"",['Artur','Heidrun']])
data_list.append([datetime.datetime(2015,11,16),16,"Neuer Pavillon Charlottenburg",'Berlin',"Germany",'Berlin','Geneva',"",['Artur','Heidrun']])
data_list.append([datetime.datetime(2015,11,16),27,"Museum Berggruen",'Berlin',"Germany",'Berlin','Geneva',"",['Artur','Heidrun']])
data_list.append([datetime.datetime(2015,11,16),30,"Sammlung Scharf-Gerstenberg",'Berlin',"Germany",'Berlin','Geneva',"",['Artur','Heidrun']])

# %%
### 2016
#colmar done
data_list.append([datetime.datetime(2016, 1, 2),16,"Martinsmuenster",'Colmar',"France",'Lauchringen','Lauchringen',"",['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2016, 1, 2),55,"Unterlindenmuseum",'Colmar',"France",'Lauchringen','Lauchringen',"",['Heidrun','Artur','Hannsjoerg']])
#zurich done
data_list.append([datetime.datetime(2016, 2, 6),7,"Grossmuenster",'Zurich',"Switzerland",'Geneva','Geneva',"",[]])
data_list.append([datetime.datetime(2016, 2, 6),4,"Fraumuenster",'Zurich',"Switzerland",'Geneva','Geneva',"",[]])
data_list.append([datetime.datetime(2016, 2, 6),2,"St Peter",'Zurich',"Switzerland",'Geneva','Geneva',"",[]])
data_list.append([datetime.datetime(2016, 2, 6),1,"Predigerkirche",'Zurich',"Switzerland",'Geneva','Geneva',"",[]])
data_list.append([datetime.datetime(2016, 2, 6),1,"ETH Zentrum",'Zurich',"Switzerland",'Geneva','Geneva',"",[]])
data_list.append([datetime.datetime(2016, 2, 6),1,"Universitaet",'Zurich',"Switzerland",'Geneva','Geneva',"",[]])
data_list.append([datetime.datetime(2016, 2, 6),2,"Wasserkirche",'Zurich',"Switzerland",'Geneva','Geneva',"",[]])
data_list.append([datetime.datetime(2016, 2, 6),1,"Rathaus",'Zurich',"Switzerland",'Geneva','Geneva',"",[]])
#sicily done
data_list.append([datetime.datetime(2016, 3, 17),55,"Villa Romana del Casale",'Piazza Armerina',"Italy",'Piazza Armerina','Palermo',"Villa Romana del Casale",['Heidrun','Artur']])
data_list.append([datetime.datetime(2016, 3, 17),31,"Duomo",'Cefalu',"Italy",'Piazza Armerina','Palermo',"Arab-Norman Palermo and the Cathedral Churches of Cefalu and Monreale",['Heidrun','Artur']])
data_list.append([datetime.datetime(2016, 3, 17),121,"Duomo",'Monreale',"Italy",'Piazza Armerina','Palermo',"Arab-Norman Palermo and the Cathedral Churches of Cefalu and Monreale",['Heidrun','Artur']])
data_list.append([datetime.datetime(2016, 3, 17),1,"Palazzo Sclafani",'Palermo',"Italy",'Piazza Armerina','Palermo',"",['Heidrun','Artur']])
data_list.append([datetime.datetime(2016, 3, 17),1,"Palazzo dei Normanni",'Palermo',"Italy",'Piazza Armerina','Palermo',"Arab-Norman Palermo and the Cathedral Churches of Cefalu and Monreale",['Heidrun','Artur']])
data_list.append([datetime.datetime(2016, 3, 17),3,"Cathedral",'Palermo',"Italy",'Palermo','Piazza Armerina',"Arab-Norman Palermo and the Cathedral Churches of Cefalu and Monreale",['Heidrun','Artur']])
data_list.append([datetime.datetime(2016, 3, 18),1,"Palazzo Sclafani",'Palermo',"Italy",'Palermo','Palermo',"",['Heidrun','Artur']])
data_list.append([datetime.datetime(2016, 3, 18),77,"Palazzo dei Normanni",'Palermo',"Italy",'Palermo','Palermo',"Arab-Norman Palermo and the Cathedral Churches of Cefalu and Monreale",['Heidrun','Artur']])
data_list.append([datetime.datetime(2016, 3, 18),4,"San Giorgio in Kemonia",'Palermo',"Italy",'Palermo','Palermo',"",['Heidrun','Artur']])
data_list.append([datetime.datetime(2016, 3, 18),13,"San Giovanni degli Eremiti",'Palermo',"Italy",'Palermo','Palermo',"Arab-Norman Palermo and the Cathedral Churches of Cefalu and Monreale",['Heidrun','Artur']])
data_list.append([datetime.datetime(2016, 3, 18),72,"Chiesa del Gesu",'Palermo',"Italy",'Palermo','Palermo',"",['Heidrun','Artur']])
data_list.append([datetime.datetime(2016, 3, 18),9,"San Cataldo",'Palermo',"Italy",'Palermo','Palermo',"Arab-Norman Palermo and the Cathedral Churches of Cefalu and Monreale",['Heidrun','Artur']])
data_list.append([datetime.datetime(2016, 3, 18),38,"La Martorana",'Palermo',"Italy",'Palermo','Palermo',"Arab-Norman Palermo and the Cathedral Churches of Cefalu and Monreale",['Heidrun','Artur']])
data_list.append([datetime.datetime(2016, 3, 18),10,"Fontana Pretoria",'Palermo',"Italy",'Palermo','Palermo',"",['Heidrun','Artur']])
data_list.append([datetime.datetime(2016, 3, 18),10,"Piazza Vigliena",'Palermo',"Italy",'Palermo','Palermo',"",['Heidrun','Artur']])
data_list.append([datetime.datetime(2016, 3, 18),32,"Cathedral",'Palermo',"Italy",'Palermo','Palermo',"Arab-Norman Palermo and the Cathedral Churches of Cefalu and Monreale",['Heidrun','Artur']])
data_list.append([datetime.datetime(2016, 3, 18),3,"Porta Nuova",'Palermo',"Italy",'Palermo','Palermo',"",['Heidrun','Artur']])
data_list.append([datetime.datetime(2016, 3, 18),49,"Castello della Zisa",'Palermo',"Italy",'Palermo','Palermo',"Arab-Norman Palermo and the Cathedral Churches of Cefalu and Monreale",['Heidrun','Artur']])
data_list.append([datetime.datetime(2016, 3, 18),11,"Castello della Cuba",'Palermo',"Italy",'Palermo','Palermo',"Arab-Norman Palermo and the Cathedral Churches of Cefalu and Monreale",[]])
data_list.append([datetime.datetime(2016, 3, 18),15,"Teatro Massimo",'Palermo',"Italy",'Palermo','Palermo',"",[]])
data_list.append([datetime.datetime(2016, 3, 18),8,"Giuseppe dei Teatini",'Palermo',"Italy",'Palermo','Palermo',"",[]])
data_list.append([datetime.datetime(2016, 3, 19),11,"Giuseppe dei Teatini",'Palermo',"Italy",'Palermo','Castellammare del Golfo',"",['Heidrun','Artur']])
data_list.append([datetime.datetime(2016, 3, 19),2,"Piazza Vigliena",'Palermo',"Italy",'Palermo','Castellammare del Golfo',"",['Heidrun','Artur']])
data_list.append([datetime.datetime(2016, 3, 19),46,"Palazzo Mirto",'Palermo',"Italy",'Palermo','Castellammare del Golfo',"",['Heidrun','Artur']])
data_list.append([datetime.datetime(2016, 3, 19),17,"Oratorio dei Bianchi",'Palermo',"Italy",'Palermo','Castellammare del Golfo',"",['Heidrun','Artur']])
data_list.append([datetime.datetime(2016, 3, 19),7,"Francesco di Assisi Church",'Palermo',"Italy",'Palermo','Castellammare del Golfo',"",['Heidrun','Artur']])
data_list.append([datetime.datetime(2016, 3, 19),13,"Oratorio di San Lorenzo",'Palermo',"Italy",'Palermo','Castellammare del Golfo',"",['Heidrun','Artur']])
data_list.append([datetime.datetime(2016, 3, 19),5,"San Matteo",'Palermo',"Italy",'Palermo','Castellammare del Golfo',"",['Heidrun','Artur']])
data_list.append([datetime.datetime(2016, 3, 19),8,"Segesta Temple of Hero",'Calatafimi',"Italy",'Palermo','Castellammare del Golfo',"",['Heidrun','Artur']])
data_list.append([datetime.datetime(2016, 3, 19),2,"Segesta Greek Theatre",'Calatafimi',"Italy",'Palermo','Castellammare del Golfo',"",['Heidrun','Artur']])
data_list.append([datetime.datetime(2016, 3, 19),8,"Castel di Castellammare del Golfo",'Castellammare del Golfo',"Italy",'Palermo','Castellammare del Golfo',"",['Heidrun','Artur']])
data_list.append([datetime.datetime(2016, 3, 19),6,"Church",'Castellammare del Golfo',"Italy",'Palermo','Castellammare del Golfo',"",['Heidrun','Artur']])
data_list.append([datetime.datetime(2016, 3, 20),14,"Selinunte Temple E",'Selinunte',"Italy",'Castellammare del Golfo','Agrigento',"",['Heidrun','Artur']])
data_list.append([datetime.datetime(2016, 3, 20),4,"Selinunte Temple F",'Selinunte',"Italy",'Castellammare del Golfo','Agrigento',"",['Heidrun','Artur']])
data_list.append([datetime.datetime(2016, 3, 20),6,"Selinunte Temple G",'Selinunte',"Italy",'Castellammare del Golfo','Agrigento',"",['Heidrun','Artur']])
data_list.append([datetime.datetime(2016, 3, 20),13,"Selinunte Akropolis",'Selinunte',"Italy",'Castellammare del Golfo','Agrigento',"",['Heidrun','Artur']])
data_list.append([datetime.datetime(2016, 3, 20),8,"Selinunte Temple C",'Selinunte',"Italy",'Castellammare del Golfo','Agrigento',"",['Heidrun','Artur']])
data_list.append([datetime.datetime(2016, 3, 20),27,"Scala dei Turchi",'Realmonte',"Italy",'Castellammare del Golfo','Agrigento',"",['Heidrun','Artur']])
data_list.append([datetime.datetime(2016, 3, 20),7,"San Francesco d'Assisi o dell'Immacolata",'Agrigento',"Italy",'Castellammare del Golfo','Agrigento',"",['Heidrun','Artur']])
data_list.append([datetime.datetime(2016, 3, 20),7,"San Lorenzo",'Agrigento',"Italy",'Castellammare del Golfo','Agrigento',"",['Heidrun','Artur']])
data_list.append([datetime.datetime(2016, 3, 20),6,"Temple of Castor & Pollux",'Agrigento',"Italy",'Agrigento','Agrigento',"Valle dei Templi",['Heidrun','Artur']])
data_list.append([datetime.datetime(2016, 3, 20),9,"Temple of Olympic Zeus",'Agrigento',"Italy",'Agrigento','Agrigento',"Valle dei Templi",['Heidrun','Artur']])
data_list.append([datetime.datetime(2016, 3, 20),8,"Temple of Herakles",'Agrigento',"Italy",'Agrigento','Agrigento',"Valle dei Templi",['Heidrun','Artur']])
data_list.append([datetime.datetime(2016, 3, 20),11,"Temple of Concordia",'Agrigento',"Italy",'Agrigento','Agrigento',"Valle dei Templi",['Heidrun','Artur']])
data_list.append([datetime.datetime(2016, 3, 20),5,"Fallen Ikarus",'Agrigento',"Italy",'Agrigento','Agrigento',"Valle dei Templi",['Heidrun','Artur']])
data_list.append([datetime.datetime(2016, 3, 20),4,"Temple of Juno",'Agrigento',"Italy",'Agrigento','Agrigento',"Valle dei Templi",['Heidrun','Artur']])
data_list.append([datetime.datetime(2016, 3, 20),11,"Nicolas Church",'Agrigento',"Italy",'Agrigento','Agrigento',"",['Heidrun','Artur']])
data_list.append([datetime.datetime(2016, 3, 20),4,"Agora",'Agrigento',"Italy",'Agrigento','Agrigento',"",['Heidrun','Artur']])
data_list.append([datetime.datetime(2016, 3, 20),50,"Archaeological Museum",'Agrigento',"Italy",'Agrigento','Agrigento',"",['Heidrun','Artur']])
data_list.append([datetime.datetime(2016, 3, 20),5,"San Spirito",'Agrigento',"Italy",'Agrigento','Agrigento',"",['Heidrun','Artur']])
data_list.append([datetime.datetime(2016, 3, 21),2,"San Biagio",'Comiso',"Italy",'Agrigento','Siracusa',"",['Heidrun','Artur']])
data_list.append([datetime.datetime(2016, 3, 21),15,"San Maria Assunta",'Comiso',"Italy",'Agrigento','Siracusa',"",['Heidrun','Artur']])
data_list.append([datetime.datetime(2016, 3, 21),7,"San Domenico",'Noto',"Italy",'Agrigento','Siracusa',"Val di Noto",['Heidrun','Artur']])
data_list.append([datetime.datetime(2016, 3, 21),2,"Hercules Fountain",'Noto',"Italy",'Agrigento','Siracusa',"Val di Noto",['Heidrun','Artur']])
data_list.append([datetime.datetime(2016, 3, 21),17,"Palazzo Nicolaci di Villadorata",'Noto',"Italy",'Agrigento','Siracusa',"Val di Noto",['Heidrun','Artur']])
data_list.append([datetime.datetime(2016, 3, 21),10,"Palazzo Ducezio",'Noto',"Italy",'Agrigento','Siracusa',"Val di Noto",['Heidrun','Artur']])
data_list.append([datetime.datetime(2016, 3, 21),18,"Cathedral",'Noto',"Italy",'Agrigento','Siracusa',"Val di Noto",['Heidrun','Artur']])
data_list.append([datetime.datetime(2016, 3, 21),6,"San Salvatore",'Noto',"Italy",'Agrigento','Siracusa',"Val di Noto",['Heidrun','Artur']])
data_list.append([datetime.datetime(2016, 3, 21),6,"San Francesco",'Noto',"Italy",'Agrigento','Siracusa',"Val di Noto",['Heidrun','Artur']])
data_list.append([datetime.datetime(2016, 3, 21),2,"Porta Reale",'Noto',"Italy",'Agrigento','Siracusa',"Val di Noto",['Heidrun','Artur']])
data_list.append([datetime.datetime(2016, 3, 21),6,"San Carlo al Corso",'Noto',"Italy",'Agrigento','Siracusa',"Val di Noto",['Heidrun','Artur']])
data_list.append([datetime.datetime(2016, 3, 21),5,"Chiesa di Montevergine",'Noto',"Italy",'Agrigento','Siracusa',"Val di Noto",['Heidrun','Artur']])
data_list.append([datetime.datetime(2016, 3, 21),6,"Santa Chiara",'Noto',"Italy",'Agrigento','Siracusa',"Val di Noto",['Heidrun','Artur']])
data_list.append([datetime.datetime(2016, 3, 21),2,"Temple of Apollo",'Siracusa',"Italy",'Agrigento','Siracusa',"Syracuse and the Rocky Necropolis of Pantalica",['Heidrun','Artur']])
data_list.append([datetime.datetime(2016, 3, 21),3,"Diana Fountain",'Siracusa',"Italy",'Agrigento','Siracusa',"Syracuse and the Rocky Necropolis of Pantalica",['Heidrun','Artur']])
data_list.append([datetime.datetime(2016, 3, 21),3,"Piazza Duomo",'Siracusa',"Italy",'Agrigento','Siracusa',"Syracuse and the Rocky Necropolis of Pantalica",['Heidrun','Artur']])
data_list.append([datetime.datetime(2016, 3, 21),2,"Duomo",'Siracusa',"Italy",'Agrigento','Siracusa',"Syracuse and the Rocky Necropolis of Pantalica",['Heidrun','Artur']])
data_list.append([datetime.datetime(2016, 3, 21),3,"Aretusa Fountain",'Siracusa',"Italy",'Agrigento','Siracusa',"Syracuse and the Rocky Necropolis of Pantalica",['Heidrun','Artur']])
data_list.append([datetime.datetime(2016, 3, 21),1,"Santa Lucia alla Badia",'Siracusa',"Italy",'Agrigento','Siracusa',"Syracuse and the Rocky Necropolis of Pantalica",['Heidrun','Artur']])
data_list.append([datetime.datetime(2016, 3, 22),10,"Santuario della Madonna delle Lacrime",'Siracusa',"Italy",'Siracusa','Catania',"",['Heidrun','Artur']])
data_list.append([datetime.datetime(2016, 3, 22),5,"Temple of Apollo",'Siracusa',"Italy",'Siracusa','Catania',"Syracuse and the Rocky Necropolis of Pantalica",['Heidrun','Artur']])
data_list.append([datetime.datetime(2016, 3, 22),3,"Diana Fountain",'Siracusa',"Italy",'Siracusa','Catania',"Syracuse and the Rocky Necropolis of Pantalica",['Heidrun','Artur']])
data_list.append([datetime.datetime(2016, 3, 22),4,"Piazza Duomo",'Siracusa',"Italy",'Siracusa','Catania',"Syracuse and the Rocky Necropolis of Pantalica",['Heidrun','Artur']])
data_list.append([datetime.datetime(2016, 3, 22),24,"Duomo",'Siracusa',"Italy",'Siracusa','Catania',"Syracuse and the Rocky Necropolis of Pantalica",['Heidrun','Artur']])
data_list.append([datetime.datetime(2016, 3, 22),3,"Aretusa Fountain",'Siracusa',"Italy",'Siracusa','Catania',"Syracuse and the Rocky Necropolis of Pantalica",['Heidrun','Artur']])
data_list.append([datetime.datetime(2016, 3, 22),1,"San Paolo",'Siracusa',"Italy",'Siracusa','Catania',"Syracuse and the Rocky Necropolis of Pantalica",['Heidrun','Artur']])
data_list.append([datetime.datetime(2016, 3, 22),7,"Chiesa del Carmine",'Siracusa',"Italy",'Siracusa','Catania',"Syracuse and the Rocky Necropolis of Pantalica",['Heidrun','Artur']])
data_list.append([datetime.datetime(2016, 3, 22),1,"Santa Lucia alla Badia",'Siracusa',"Italy",'Siracusa','Catania',"Syracuse and the Rocky Necropolis of Pantalica",['Heidrun','Artur']])
data_list.append([datetime.datetime(2016, 3, 22),3,"Amphitheatre",'Siracusa',"Italy",'Siracusa','Catania',"Syracuse and the Rocky Necropolis of Pantalica",['Heidrun','Artur']])
data_list.append([datetime.datetime(2016, 3, 22),2,"Hireon Altar",'Siracusa',"Italy",'Siracusa','Catania',"Syracuse and the Rocky Necropolis of Pantalica",['Heidrun','Artur']])
data_list.append([datetime.datetime(2016, 3, 22),3,"Greek Theatre",'Siracusa',"Italy",'Siracusa','Catania',"Syracuse and the Rocky Necropolis of Pantalica",['Heidrun','Artur']])
data_list.append([datetime.datetime(2016, 3, 22),2,"Grotta del Ninfeo",'Siracusa',"Italy",'Siracusa','Catania',"Syracuse and the Rocky Necropolis of Pantalica",['Heidrun','Artur']])
data_list.append([datetime.datetime(2016, 3, 22),8,"Necropolis",'Siracusa',"Italy",'Siracusa','Catania',"Syracuse and the Rocky Necropolis of Pantalica",['Heidrun','Artur']])
data_list.append([datetime.datetime(2016, 3, 22),15,"Latomia del Paradiso",'Siracusa',"Italy",'Siracusa','Catania',"Syracuse and the Rocky Necropolis of Pantalica",['Heidrun','Artur']])
data_list.append([datetime.datetime(2016, 3, 22),15,"San Benedetto",'Catania',"Italy",'Siracusa','Catania',"Val di Noto",['Heidrun','Artur']])
data_list.append([datetime.datetime(2016, 3, 22),1,"San Francesco",'Catania',"Italy",'Catania','Catania',"Val di Noto",['Artur']])
data_list.append([datetime.datetime(2016, 3, 22),10,"San Francisco de Borja",'Catania',"Italy",'Siracusa','Catania',"Val di Noto",['Heidrun','Artur']])
data_list.append([datetime.datetime(2016, 3, 22),11,"Collegiata",'Catania',"Italy",'Siracusa','Catania',"Val di Noto",['Heidrun','Artur']])
data_list.append([datetime.datetime(2016, 3, 22),27,"Cathedral",'Catania',"Italy",'Siracusa','Catania',"Val di Noto",['Heidrun','Artur']])
data_list.append([datetime.datetime(2016, 3, 22),2,"Chiesa della Badia",'Catania',"Italy",'Siracusa','Catania',"Val di Noto",['Heidrun','Artur']])
data_list.append([datetime.datetime(2016, 3, 22),3,"Elephant Fountain",'Catania',"Italy",'Siracusa','Catania',"Val di Noto",['Heidrun','Artur']])
data_list.append([datetime.datetime(2016, 3, 22),3,"Amenano Fountain",'Catania',"Italy",'Siracusa','Catania',"Val di Noto",['Heidrun','Artur']])
data_list.append([datetime.datetime(2016, 3, 22),1,"Castello Ursino",'Catania',"Italy",'Siracusa','Catania',"",['Heidrun','Artur']])
data_list.append([datetime.datetime(2016, 3, 23),60,"Etna",'Nicolosi',"Italy",'Catania','Catania',"Mount Etna",['Heidrun','Artur']])
data_list.append([datetime.datetime(2016, 3, 23),10,"Grotta dei tre Livelli",'Nicolosi',"Italy",'Catania','Catania',"Mount Etna",['Heidrun','Artur']])
data_list.append([datetime.datetime(2016, 3, 23),12,"Roman Theatre",'Catania',"Italy",'Catania','Catania',"Val di Noto",['Artur']])
data_list.append([datetime.datetime(2016, 3, 23),3,"Roman Odeon",'Catania',"Italy",'Catania','Catania',"Val di Noto",['Artur']])
data_list.append([datetime.datetime(2016, 3, 23),1,"Giovanni di Bosco Church",'Catania',"Italy",'Catania','Catania',"Val di Noto",['Artur']])
data_list.append([datetime.datetime(2016, 3, 23),1,"San Francesco",'Catania',"Italy",'Catania','Catania',"Val di Noto",['Artur']])
data_list.append([datetime.datetime(2016, 3, 23),6,"San Nicola Monastery",'Catania',"Italy",'Catania','Catania',"Val di Noto",['Artur']])
data_list.append([datetime.datetime(2016, 3, 23),1,"Castello Ursino",'Catania',"Italy",'Catania','Catania',"",['Artur']])
data_list.append([datetime.datetime(2016, 3, 24),17,"San Nicola Monastery",'Catania',"Italy",'Catania','Catania',"Val di Noto",['Artur']])
data_list.append([datetime.datetime(2016, 3, 24),13,"San Francesco",'Catania',"Italy",'Catania','Catania',"Val di Noto",['Artur']])
data_list.append([datetime.datetime(2016, 3, 24),5,"San Benedetto",'Catania',"Italy",'Catania','Catania',"Val di Noto",['Artur']])
data_list.append([datetime.datetime(2016, 3, 24),1,"Cathedral",'Catania',"Italy",'Catania','Catania',"Val di Noto",['Artur']])
data_list.append([datetime.datetime(2016, 3, 24),2,"Chiesa della Badia",'Catania',"Italy",'Catania','Catania',"Val di Noto",['Artur']])
data_list.append([datetime.datetime(2016, 3, 24),1,"Elephant Fountain",'Catania',"Italy",'Catania','Catania',"Val di Noto",['Artur']])
data_list.append([datetime.datetime(2016, 3, 24),19,"Castello Ursino",'Catania',"Italy",'Catania','Catania',"",['Artur','Heidrun']])

# %%
#barcelona 2016
data_list.append([datetime.datetime(2016,3,26),7,"Casa Calvet","Barcelona","Spain","Geneva","Barcelona","",['Riju']])
data_list.append([datetime.datetime(2016,3,26),37,"Casa Mila","Barcelona","Spain","Geneva","Barcelona","Works of Antoni Gaudi",['Riju']])
data_list.append([datetime.datetime(2016,3,26),2,"Casa Llero Morera","Barcelona","Spain","Geneva","Barcelona","",['Riju']])
data_list.append([datetime.datetime(2016,3,26),3,"Casa Amatller","Barcelona","Spain","Geneva","Barcelona","",['Riju']])
data_list.append([datetime.datetime(2016,3,26),44,"Casa Batllo","Barcelona","Spain","Geneva","Barcelona","Works of Antoni Gaudi",['Riju']])
data_list.append([datetime.datetime(2016,3,26),40,"Casa Llero Morera","Barcelona","Spain","Geneva","Barcelona","",[]])
data_list.append([datetime.datetime(2016,3,26),30,"Casa Amatller","Barcelona","Spain","Geneva","Barcelona","",[]])
data_list.append([datetime.datetime(2016,3,26),2,"Casa Batllo","Barcelona","Spain","Geneva","Barcelona","Works of Antoni Gaudi",[]])
data_list.append([datetime.datetime(2016,3,26),44,"Sagrada Familia","Barcelona","Spain","Geneva","Barcelona","Works of Antoni Gaudi",['Riju']])
data_list.append([datetime.datetime(2016,3,26),83,"Sagrada Familia","Barcelona","Spain","Geneva","Barcelona","",['Riju']])
data_list.append([datetime.datetime(2016,3,26),23,"Casa Mila","Barcelona","Spain","Geneva","Barcelona","Works of Antoni Gaudi",[]])
data_list.append([datetime.datetime(2016,3,27),46,"Cathedral","Barcelona","Spain","Barcelona","Barcelona","",['Riju']])
data_list.append([datetime.datetime(2016,3,27),1,"Casa de l'Ardiaca","Barcelona","Spain","Barcelona","Barcelona","",['Riju']])
data_list.append([datetime.datetime(2016,3,27),40,"Casa de la Ciutat","Barcelona","Spain","Barcelona","Barcelona","",['Riju']])
data_list.append([datetime.datetime(2016,3,27),2,"Palau de la Generalitat de Catalunya","Barcelona","Spain","Barcelona","Barcelona","",['Riju']])
data_list.append([datetime.datetime(2016,3,27),47,"Palau de la Generalitat de Catalunya","Barcelona","Spain","Barcelona","Barcelona","",[]])
data_list.append([datetime.datetime(2016,3,27),8,"Basilica Santa Maria del Pi","Barcelona","Spain","Barcelona","Barcelona","",['Riju']])
data_list.append([datetime.datetime(2016,3,27),53,"Palau Guell","Barcelona","Spain","Barcelona","Barcelona","Works of Antoni Gaudi",['Riju']])
data_list.append([datetime.datetime(2016,3,27),40,"Palau de la Musica Catalana","Barcelona","Spain","Barcelona","Barcelona","Palau de la Musica Catalana and Hospital de Sant Pau",['Riju']])
data_list.append([datetime.datetime(2016,3,27),4,"Placa Reial","Barcelona","Spain","Barcelona","Barcelona","Palau de la Musica Catalana and Hospital de Sant Pau",['Riju']])
data_list.append([datetime.datetime(2016,3,27),1,"Olympic Flame","Barcelona","Spain","Barcelona","Barcelona","",['Riju']])
data_list.append([datetime.datetime(2016,3,27),1,"Palau Nacional","Barcelona","Spain","Barcelona","Barcelona","",['Riju']])
data_list.append([datetime.datetime(2016,3,27),12,"Gran Teatre del Liceu","Barcelona","Spain","Barcelona","Barcelona","",[]])
data_list.append([datetime.datetime(2016,3,27),1,"Palau de la Virreina","Barcelona","Spain","Barcelona","Barcelona","",[]])
data_list.append([datetime.datetime(2016,3,27),3,"Cathedral","Barcelona","Spain","Barcelona","Barcelona","",[]])
data_list.append([datetime.datetime(2016,3,27),4,"Basilica Santa Maria del Mar","Barcelona","Spain","Barcelona","Barcelona","",[]])
data_list.append([datetime.datetime(2016,3,27),2,"The Head","Barcelona","Spain","Barcelona","Barcelona","",[]])
data_list.append([datetime.datetime(2016,3,27),2,"Christoph Columbus Monument","Barcelona","Spain","Barcelona","Barcelona","",[]])
data_list.append([datetime.datetime(2016,3,27),11,"Basilica de la Merce","Barcelona","Spain","Barcelona","Barcelona","",[]])
data_list.append([datetime.datetime(2016,3,27),10,"Palau Reial Major","Barcelona","Spain","Barcelona","Barcelona","",[]])
data_list.append([datetime.datetime(2016,3,27),9,"Archaeological Museum","Barcelona","Spain","Barcelona","Barcelona","",[]])
data_list.append([datetime.datetime(2016,3,27),4,"Frederic Mares Museum","Barcelona","Spain","Barcelona","Barcelona","",[]])
data_list.append([datetime.datetime(2016,3,28),65,"Palacio de la Aljaferia","Zaragoza","Spain","Barcelona","Barcelona","Mudejar Architecture of Aragon",['Riju']])
data_list.append([datetime.datetime(2016,3,28),6,"Ibercaja Patio de la Infanta","Zaragoza","Spain","Barcelona","Barcelona","",['Riju']])
data_list.append([datetime.datetime(2016,3,28),3,"Basilica de Santa Engracia","Zaragoza","Spain","Barcelona","Barcelona","",['Riju']])
data_list.append([datetime.datetime(2016,3,28),5,"Plaza de Espana","Zaragoza","Spain","Barcelona","Barcelona","",['Riju']])
data_list.append([datetime.datetime(2016,3,28),3,"San Gil Abad","Zaragoza","Spain","Barcelona","Barcelona","",['Riju']])
data_list.append([datetime.datetime(2016,3,28),2,"La Lonja","Zaragoza","Spain","Barcelona","Barcelona","",['Riju']])
data_list.append([datetime.datetime(2016,3,28),62,"Catedral-Basilica del Pilar","Zaragoza","Spain","Barcelona","Barcelona","",['Riju']])
data_list.append([datetime.datetime(2016,3,28),24,"Cathedral","Zaragoza","Spain","Barcelona","Barcelona","Mudejar Architecture of Aragon",['Riju']])
data_list.append([datetime.datetime(2016,3,28),4,"Puente de Piedra","Zaragoza","Spain","Barcelona","Barcelona","",['Riju']])
data_list.append([datetime.datetime(2016,3,28),3,"San Juan de los Panetes","Zaragoza","Spain","Barcelona","Barcelona","",['Riju']])
data_list.append([datetime.datetime(2016,3,28),2,"Fuente de la Hispanidad","Zaragoza","Spain","Barcelona","Barcelona","",['Riju']])
data_list.append([datetime.datetime(2016,3,28),2,"Roman Town Walls","Zaragoza","Spain","Barcelona","Barcelona","",['Riju']])
data_list.append([datetime.datetime(2016,3,28),1,"Mercado Central","Zaragoza","Spain","Barcelona","Barcelona","",['Riju']])
data_list.append([datetime.datetime(2016,3,28),2,"Zaragossa-Delicias Station","Zaragoza","Spain","Barcelona","Barcelona","",['Riju']])
data_list.append([datetime.datetime(2016,3,28),3,"Woman and Bird","Barcelona","Spain","Barcelona","Barcelona","",['Riju']])
data_list.append([datetime.datetime(2016,3,28),2,"Bullfighting Arena","Barcelona","Spain","Barcelona","Barcelona","",['Riju']])
data_list.append([datetime.datetime(2016,3,29),1,"Bullfighting Arena","Barcelona","Spain","Barcelona","Geneva","",['Riju']])
data_list.append([datetime.datetime(2016,3,29),1,"Temple Expiatori del Sagrat Cor","Barcelona","Spain","Barcelona","Geneva","",['Riju']])
data_list.append([datetime.datetime(2016,3,29),60,"Park Guell","Barcelona","Spain","Barcelona","Geneva","Works of Antoni Gaudi",['Riju']])
data_list.append([datetime.datetime(2016,3,29),54,"Hospital de Sant Pau","Barcelona","Spain","Barcelona","Barcelona","Palau de la Musica Catalana and Hospital de Sant Pau",[]])
data_list.append([datetime.datetime(2016,3,29),2,"Sagrada Familia","Barcelona","Spain","Barcelona","Geneva","Works of Antoni Gaudi",[]])
data_list.append([datetime.datetime(2016,3,29),2,"Sagrada Familia","Barcelona","Spain","Barcelona","Geneva","",['Riju']])
data_list.append([datetime.datetime(2016,3,29),2,"Sagrada Familia","Barcelona","Spain","Barcelona","Geneva","Works of Antoni Gaudi",['Riju']])
data_list.append([datetime.datetime(2016,3,29),2,"Placa d'Espanya","Barcelona","Spain","Barcelona","Geneva","",['Riju']])

# %%
#genua
data_list.append([datetime.datetime(2016,5,14),1,"Christoph Columbus Monument","Genua","Italy","Bus Geneva-Genua","Genua","",['Amin']])
data_list.append([datetime.datetime(2016,5,14),89,"Palazzo Reale","Genua","Italy","Bus Geneva-Genua","Genua","Genoa: Le Strade Nuove and the system of the Palazzi dei Rolli",['Amin']])
data_list.append([datetime.datetime(2016,5,14),27,"Basilica dell'Annunziata","Genua","Italy","Bus Geneva-Genua","Genua","Genoa: Le Strade Nuove and the system of the Palazzi dei Rolli",['Amin']])
data_list.append([datetime.datetime(2016,5,14),2,"Loggia dei Mercanti","Genua","Italy","Bus Geneva-Genua","Genua","Genoa: Le Strade Nuove and the system of the Palazzi dei Rolli",['Amin']])
data_list.append([datetime.datetime(2016,5,14),24,"Cathedral San Lorenzo","Genua","Italy","Bus Geneva-Genua","Genua","",['Amin']])
data_list.append([datetime.datetime(2016,5,14),13,"Palazzo Ducale","Genua","Italy","Bus Geneva-Genua","Genua","",['Amin']])
data_list.append([datetime.datetime(2016,5,14),26,"Chiesa del Gesu","Genua","Italy","Bus Geneva-Genua","Genua","",['Amin']])
data_list.append([datetime.datetime(2016,5,14),4,"Piazza de Ferrari","Genua","Italy","Bus Geneva-Genua","Genua","",['Amin']])
data_list.append([datetime.datetime(2016,5,14),16,"Basilica di Santa Maria delle Vigne","Genua","Italy","Bus Geneva-Genua","Genua","Genoa: Le Strade Nuove and the system of the Palazzi dei Rolli",['Amin']])
data_list.append([datetime.datetime(2016,5,14),35,"Palazzo Spinola di Pellicceria","Genua","Italy","Bus Geneva-Genua","Genua","Genoa: Le Strade Nuove and the system of the Palazzi dei Rolli",['Amin']])
data_list.append([datetime.datetime(2016,5,14),1,"Palazzo Doria Tursi","Genua","Italy","Bus Geneva-Genua","Genua","Genoa: Le Strade Nuove and the system of the Palazzi dei Rolli",['Amin']])
data_list.append([datetime.datetime(2016,5,14),7,"Santi Vittore e Carlo","Genua","Italy","Bus Geneva-Genua","Genua","Genoa: Le Strade Nuove and the system of the Palazzi dei Rolli",['Amin']])
data_list.append([datetime.datetime(2016,5,14),2,"Palazzo dell'Universita","Genua","Italy","Bus Geneva-Genua","Genua","Genoa: Le Strade Nuove and the system of the Palazzi dei Rolli",['Amin']])
data_list.append([datetime.datetime(2016,5,14),2,"San Luca","Genua","Italy","Bus Geneva-Genua","Genua","Genoa: Le Strade Nuove and the system of the Palazzi dei Rolli",['Amin']])
data_list.append([datetime.datetime(2016,5,14),4,"San Pietro in Banchi","Genua","Italy","Bus Geneva-Genua","Genua","Genoa: Le Strade Nuove and the system of the Palazzi dei Rolli",['Amin']])
data_list.append([datetime.datetime(2016,5,14),6,"San Donato","Genua","Italy","Bus Geneva-Genua","Genua","",['Amin']])
data_list.append([datetime.datetime(2016,5,14),1,"Santi Cosma e Damiano","Genua","Italy","Bus Geneva-Genua","Genua","",['Amin']])
data_list.append([datetime.datetime(2016,5,14),3,"Palazzo San Giorgio","Genua","Italy","Bus Geneva-Genua","Genua","Genoa: Le Strade Nuove and the system of the Palazzi dei Rolli",['Amin']])
data_list.append([datetime.datetime(2016,5,14),2,"Piazza Caricamento","Genua","Italy","Bus Geneva-Genua","Genua","",['Amin']])
data_list.append([datetime.datetime(2016,5,14),2,"Commenda San Giovanni di Pre","Genua","Italy","Bus Geneva-Genua","Genua","",['Amin']])
data_list.append([datetime.datetime(2016,5,15),56,"Villa del Principe","Genua","Italy","Genua","Genua","",['Amin']])
data_list.append([datetime.datetime(2016,5,15),41,"Castello d'Albertis","Genua","Italy","Genua","Genua","",['Amin']])
data_list.append([datetime.datetime(2016,5,15),10,"Palazzo Bianco","Genua","Italy","Genua","Genua","Genoa: Le Strade Nuove and the system of the Palazzi dei Rolli",['Amin']])
data_list.append([datetime.datetime(2016,5,15),6,"Palazzo Angelo Giovanni Spinola","Genua","Italy","Genua","Genua","Genoa: Le Strade Nuove and the system of the Palazzi dei Rolli",['Amin']])
data_list.append([datetime.datetime(2016,5,15),1,"Chiesa del Gesu","Genua","Italy","Genua","Genua","",['Amin']])
data_list.append([datetime.datetime(2016,5,15),1,"Piazza de Ferrari","Genua","Italy","Genua","Genua","",['Amin']])
data_list.append([datetime.datetime(2016,5,15),16,"Palazzo Doria Tursi","Genua","Italy","Genua","Genua","Genoa: Le Strade Nuove and the system of the Palazzi dei Rolli",['Amin']])
data_list.append([datetime.datetime(2016,5,15),61,"Palazzo Rosso","Genua","Italy","Genua","Genua","Genoa: Le Strade Nuove and the system of the Palazzi dei Rolli",['Amin']])
data_list.append([datetime.datetime(2016,5,15),1,"Loggia dei Mercanti","Genua","Italy","Genua","Genua","Genoa: Le Strade Nuove and the system of the Palazzi dei Rolli",['Amin']])
data_list.append([datetime.datetime(2016,5,15),2,"Porta Suprana","Genua","Italy","Genua","Genua","",[]])
data_list.append([datetime.datetime(2016,5,15),1,"Palazzo Ducale","Genua","Italy","Genua","Genua","",[]])
data_list.append([datetime.datetime(2016,5,15),12,"Basilica di San Siro","Genua","Italy","Genua","Genua","Genoa: Le Strade Nuove and the system of the Palazzi dei Rolli",[]])
data_list.append([datetime.datetime(2016,5,16),7,"Harbour","Riomaggiore","Italy","Genua","Geneva","Portovenere, Cinque Terre, and the Islands (Palmaria, Tino and Tinetto)",['Amin']])
data_list.append([datetime.datetime(2016,5,16),8,"Harbour","Manarola","Italy","Genua","Geneva","Portovenere, Cinque Terre, and the Islands (Palmaria, Tino and Tinetto)",['Amin']])
data_list.append([datetime.datetime(2016,5,16),10,"Beach","Monterosso al Mare","Italy","Genua","Geneva","Portovenere, Cinque Terre, and the Islands (Palmaria, Tino and Tinetto)",['Amin']])
data_list.append([datetime.datetime(2016,5,16),4,"Oratorium of the Dead","Monterosso al Mare","Italy","Genua","Geneva","Portovenere, Cinque Terre, and the Islands (Palmaria, Tino and Tinetto)",['Amin']])
data_list.append([datetime.datetime(2016,5,16),2,"St John Baptist","Monterosso al Mare","Italy","Genua","Geneva","Portovenere, Cinque Terre, and the Islands (Palmaria, Tino and Tinetto)",['Amin']])
data_list.append([datetime.datetime(2016,5,16),5,"Harbour","Vernazza","Italy","Genua","Geneva","Portovenere, Cinque Terre, and the Islands (Palmaria, Tino and Tinetto)",['Amin']])

# %%
#brussels 2016 done
data_list.append([datetime.datetime(2016, 7, 22),4,"Grand Place",'Brussels',"Belgium",'Geneva','Brussels',"Grand Place",[]])
data_list.append([datetime.datetime(2016, 7, 22),3,"Stadhuis",'Brussels',"Belgium",'Geneva','Brussels',"Grand Place",[]])
data_list.append([datetime.datetime(2016, 7, 22),2,"Maison Roi",'Brussels',"Belgium",'Geneva','Brussels',"Grand Place",[]])
data_list.append([datetime.datetime(2016, 7, 23),1,"Grasmarkt",'Brussels',"Belgium",'Brussels','Brussels',"",[]])
data_list.append([datetime.datetime(2016, 7, 23),40,"Cathedral",'Brussels',"Belgium",'Brussels','Brussels',"",[]])
data_list.append([datetime.datetime(2016, 7, 23),3,"Palais Stoclet",'Brussels',"Belgium",'Brussels','Brussels',"Palais Stoclet",[]])
data_list.append([datetime.datetime(2016, 7, 23),1,"Place Royale",'Brussels',"Belgium",'Brussels','Brussels',"",[]])
data_list.append([datetime.datetime(2016, 7, 23),7,"Saint Jacques-sur-Coudenberg",'Brussels',"Belgium",'Brussels','Brussels',"",[]])
data_list.append([datetime.datetime(2016, 7, 23),53,"Royal Palace",'Brussels',"Belgium",'Brussels','Brussels',"",[]])
data_list.append([datetime.datetime(2016, 7, 23),2,"Manneken Pis",'Brussels',"Belgium",'Brussels','Brussels',"",[]])
data_list.append([datetime.datetime(2016, 7, 23),9,"Grand Place",'Brussels',"Belgium",'Brussels','Brussels',"Grand Place",[]])
data_list.append([datetime.datetime(2016, 7, 23),3,"Stadhuis",'Brussels',"Belgium",'Brussels','Brussels',"Grand Place",[]])
data_list.append([datetime.datetime(2016, 7, 23),14,"Maison Roi",'Brussels',"Belgium",'Brussels','Brussels',"Grand Place",[]])
data_list.append([datetime.datetime(2016, 7, 23),3,"Elisenbrunnen",'Aachen',"Germany",'Brussels','Brussels',"",[]])
data_list.append([datetime.datetime(2016, 7, 23),38,"Cathedral",'Aachen',"Germany",'Brussels','Brussels',"Aachen Cathedral",[]])
data_list.append([datetime.datetime(2016, 7, 23),1,"City Hall",'Aachen',"Germany",'Brussels','Brussels',"",[]])
data_list.append([datetime.datetime(2016, 7, 23),23,"Cathedral Treasury",'Aachen',"Germany",'Brussels','Brussels',"",[]])
data_list.append([datetime.datetime(2016, 7, 23),1,"Church Franziska of Aachen",'Aachen',"Germany",'Brussels','Brussels',"",[]])
data_list.append([datetime.datetime(2016, 7, 23),1,"Brussel-Centraal Station",'Brussels',"Belgium",'Brussels','Brussels',"",[]])
data_list.append([datetime.datetime(2016, 7, 23),1,"Notre-Dame du Sablon",'Brussels',"Belgium",'Brussels','Brussels',"",[]])
data_list.append([datetime.datetime(2016, 7, 23),1,"National Basilica",'Koekelberg',"Belgium",'Brussels','Brussels',"",[]])
data_list.append([datetime.datetime(2016, 7, 23),5,"Palace of Justice",'Brussels',"Belgium",'Brussels','Brussels',"",[]])
data_list.append([datetime.datetime(2016, 7, 24),1,"Maison Roi",'Brussels',"Belgium",'Brussels','Geneva',"Grand Place",[]])
data_list.append([datetime.datetime(2016, 7, 24),5,"Grand Place",'Brussels',"Belgium",'Brussels','Geneva',"Grand Place",[]])
data_list.append([datetime.datetime(2016, 7, 24),10,"Stadhuis",'Brussels',"Belgium",'Brussels','Geneva',"Grand Place",[]])
data_list.append([datetime.datetime(2016, 7, 24),7,"Nicolas Church",'Brussels',"Belgium",'Brussels','Geneva',"",[]])
data_list.append([datetime.datetime(2016, 7, 24),5,"Sainte Catherine",'Brussels',"Belgium",'Brussels','Geneva',"",[]])
data_list.append([datetime.datetime(2016, 7, 24),21,"National Basilica",'Koekelberg',"Belgium",'Brussels','Geneva',"",[]])
data_list.append([datetime.datetime(2016, 7, 24),2,"Notre-Dame du Finistere",'Brussels',"Belgium",'Brussels','Geneva',"",[]])
data_list.append([datetime.datetime(2016, 7, 24),1,"Place Royale",'Brussels',"Belgium",'Brussels','Brussels',"",[]])
data_list.append([datetime.datetime(2016, 7, 24),16,"Notre-Dame du Sablon",'Brussels',"Belgium",'Brussels','Brussels',"",[]])
data_list.append([datetime.datetime(2016, 7, 24),1,"Palace of Justice",'Brussels',"Belgium",'Brussels','Brussels',"",[]])
data_list.append([datetime.datetime(2016, 7, 24),1,"Saint Jacques-sur-Coudenberg",'Brussels',"Belgium",'Brussels','Brussels',"",[]])
data_list.append([datetime.datetime(2016, 7, 24),2,"Maison Horta",'Brussels',"Belgium",'Brussels','Brussels',"Horta Town Houses",[]])
data_list.append([datetime.datetime(2016, 7, 24),1,"Halleport",'Brussels',"Belgium",'Brussels','Brussels',"",[]])
data_list.append([datetime.datetime(2016, 7, 24),11,"Notre-Dame de Laeken",'Brussels',"Belgium",'Brussels','Brussels',"",[]])
data_list.append([datetime.datetime(2016, 7, 24),24,"Atomium",'Brussels',"Belgium",'Brussels','Brussels',"",[]])
data_list.append([datetime.datetime(2016, 7, 24),2,"Laeken Castle",'Brussels',"Belgium",'Brussels','Brussels',"",[]])

# %%
#arlington
data_list.append([datetime.datetime(2016, 9, 13),3,"Windsor Castle",'Windsor',"United Kingdom",'Geneva','Arlington',"",[]])
#Santiago de Compostela
data_list.append([datetime.datetime(2016, 10, 8),5,"Praza do Obradoiro",'Santiago de Compostela',"Spain",'Geneva','Santiago de Compostela',"Santiago de Compostela (Old Town)",[]])
data_list.append([datetime.datetime(2016, 10, 8),90,"Cathedral",'Santiago de Compostela',"Spain",'Geneva','Santiago de Compostela',"Santiago de Compostela (Old Town)",[]])
data_list.append([datetime.datetime(2016, 10, 8),5,"Praza de Praterias",'Santiago de Compostela',"Spain",'Geneva','Santiago de Compostela',"Santiago de Compostela (Old Town)",[]])
data_list.append([datetime.datetime(2016, 10, 8),2,"San Paio de Antealtares Monastery",'Santiago de Compostela',"Spain",'Geneva','Santiago de Compostela',"Santiago de Compostela (Old Town)",[]])
data_list.append([datetime.datetime(2016, 10, 8),2,"San Fructuosus",'Santiago de Compostela',"Spain",'Geneva','Santiago de Compostela',"Santiago de Compostela (Old Town)",[]])
data_list.append([datetime.datetime(2016, 10, 8),8,"Bishop's Palace",'Santiago de Compostela',"Spain",'Geneva','Santiago de Compostela',"Santiago de Compostela (Old Town)",[]])
data_list.append([datetime.datetime(2016, 10, 8),17,"University",'Santiago de Compostela',"Spain",'Geneva','Santiago de Compostela',"Santiago de Compostela (Old Town)",[]])
data_list.append([datetime.datetime(2016, 10, 8),2,"Franciscan Church",'Santiago de Compostela',"Spain",'Geneva','Santiago de Compostela',"Santiago de Compostela (Old Town)",[]])
data_list.append([datetime.datetime(2016, 10, 8),1,"Capilla San Roque",'Santiago de Compostela',"Spain",'Geneva','Santiago de Compostela',"Santiago de Compostela (Old Town)",[]])
#Cologne done
data_list.append([datetime.datetime(2016, 10, 14),15,"Dom",'Cologne',"Germany",'Geneva','Cologne',"Cologne Cathedral",[]])
data_list.append([datetime.datetime(2016, 10, 14),1,"Roemisch-Germanisches Museum",'Cologne',"Germany",'Geneva','Cologne',"",[]])
data_list.append([datetime.datetime(2016, 10, 15),101,"Dom",'Cologne',"Germany",'Cologne','Cologne',"Cologne Cathedral",[]])
data_list.append([datetime.datetime(2016, 10, 15),2,"Maria Himmelfahrt",'Cologne',"Germany",'Cologne','Cologne',"",[]])
data_list.append([datetime.datetime(2016, 10, 15),5,"Gross St Martin",'Cologne',"Germany",'Cologne','Cologne',"",[]])
data_list.append([datetime.datetime(2016, 10, 15),2,"Rathaus",'Cologne',"Germany",'Cologne','Cologne',"",[]])
data_list.append([datetime.datetime(2016, 10, 15),26,"Schloss Benrath",'Duesseldorf',"Germany",'Cologne','Cologne',"",[]])
data_list.append([datetime.datetime(2016, 10, 15),3,"Schloss Limburg",'Limburg',"Germany",'Cologne','Cologne',"",[]])
data_list.append([datetime.datetime(2016, 10, 15),38,"Dom",'Limburg',"Germany",'Cologne','Cologne',"",[]])
data_list.append([datetime.datetime(2016, 10, 15),2,"Bischofsresidenz",'Limburg',"Germany",'Cologne','Cologne',"",[]])
data_list.append([datetime.datetime(2016, 10, 15),1,"Hohenzollerndenkmal",'Cologne',"Germany",'Cologne','Cologne',"",[]])
data_list.append([datetime.datetime(2016, 10, 15),4,"Hohenzollernbruecke",'Cologne',"Germany",'Cologne','Cologne',"",[]])
data_list.append([datetime.datetime(2016, 10, 15),1,"Friedrich Wilhelm III Monument",'Cologne',"Germany",'Cologne','Cologne',"",[]])
data_list.append([datetime.datetime(2016, 10, 16),2,"Hauptbahnhof",'Cologne',"Germany",'Cologne','Duesseldorf',"",[]])
data_list.append([datetime.datetime(2016, 10, 16),11,"Dom",'Cologne',"Germany",'Cologne','Duesseldorf',"Cologne Cathedral",[]])
data_list.append([datetime.datetime(2016, 10, 16),18,"Schloss Augustusburg",'Bruehl',"Germany",'Cologne','Duesseldorf',"Castles of Augustusburg and Falkenlust at Brühl",[]])
data_list.append([datetime.datetime(2016, 10, 16),13,"Schloss Augustusburg Park",'Bruehl',"Germany",'Cologne','Duesseldorf',"Castles of Augustusburg and Falkenlust at Brühl",[]])
data_list.append([datetime.datetime(2016, 10, 16),17,"Schloss Falkenlust",'Bruehl',"Germany",'Cologne','Duesseldorf',"Castles of Augustusburg and Falkenlust at Brühl",[]])
data_list.append([datetime.datetime(2016, 10, 16),22,"Minster",'Bonn',"Germany",'Cologne','Duesseldorf',"",[]])
data_list.append([datetime.datetime(2016, 10, 16),4,"Kurfuerstliches Schloss",'Bonn',"Germany",'Cologne','Duesseldorf',"",[]])
data_list.append([datetime.datetime(2016, 10, 16),1,"Altes Rathaus",'Bonn',"Germany",'Cologne','Duesseldorf',"",[]])
data_list.append([datetime.datetime(2016, 10, 16),4,"Poppelsdorfr Schloss",'Bonn',"Germany",'Cologne','Duesseldorf',"",[]])
data_list.append([datetime.datetime(2016, 10, 16),10,"Dominikanerkirche",'Cologne',"Germany",'Cologne','Duesseldorf',"",[]])
data_list.append([datetime.datetime(2016, 10, 17),1,"Duesseldorf Airport",'Duesseldorf',"Germany",'Duesseldorf','Geneva',"",[]])

# %%
#Milan & Mantua done
data_list.append([datetime.datetime(2016, 11, 26),13,"Santa Maria delle Grazie",'Milano',"Italy",'Milano','Mantua',"Church and Dominican Convent of Santa Maria delle Grazie",['Riju']])
data_list.append([datetime.datetime(2016, 11, 26),19,"Santa Maria delle Grazie Refectory",'Milano',"Italy",'Milano','Mantua',"Church and Dominican Convent of Santa Maria delle Grazie",['Riju']])
data_list.append([datetime.datetime(2016, 11, 26),1,"Galleria Vittorio Emanuele II",'Milano',"Italy",'Geneva','Geneva',"",['Riju']])
data_list.append([datetime.datetime(2016, 11, 26),25,"Duomo",'Milano',"Italy",'Milano','Mantua',"",['Riju']])
data_list.append([datetime.datetime(2016, 11, 26),1,"Santo Stefano Maggiore",'Milano',"Italy",'Milano','Mantua',"",['Riju']])
data_list.append([datetime.datetime(2016, 11, 26),7,"San Bernardino alle Ossa",'Milano',"Italy",'Milano','Mantua',"",['Riju']])
data_list.append([datetime.datetime(2016, 11, 26),9,"Palazzo Reale",'Milano',"Italy",'Milano','Mantua',"",['Riju']])
data_list.append([datetime.datetime(2016, 11, 26),75,"Palazzo Te",'Mantua',"Italy",'Milano','Mantua',"Mantua",['Riju']])
data_list.append([datetime.datetime(2016, 11, 26),1,"Chiesa della Madonna del Terremoto",'Mantua',"Italy",'Milano','Mantua',"Mantua",['Riju']])
data_list.append([datetime.datetime(2016, 11, 26),27,"Basilica di Sant'Andrea",'Mantua',"Italy",'Milano','Mantua',"Mantua",['Riju']])
data_list.append([datetime.datetime(2016, 11, 26),11,"Duomo",'Mantua',"Italy",'Milano','Mantua',"Mantua",['Riju']])
data_list.append([datetime.datetime(2016, 11, 26),2,"Palazzo Ducale",'Mantua',"Italy",'Milano','Mantua',"Mantua",['Riju']])
data_list.append([datetime.datetime(2016, 11, 27),2,"Basilica di Sant'Andrea",'Mantua',"Italy",'Mantua','Geneva',"Mantua",['Riju']])
data_list.append([datetime.datetime(2016, 11, 27),11,"Duomo",'Mantua',"Italy",'Mantua','Geneva',"Mantua",['Riju']])
data_list.append([datetime.datetime(2016, 11, 27),113,"Palazzo Ducale",'Mantua',"Italy",'Mantua','Geneva',"Mantua",['Riju']])
data_list.append([datetime.datetime(2016, 11, 27),6,"Basilica di Santa Barbara",'Mantua',"Italy",'Mantua','Geneva',"Mantua",['Riju']])
data_list.append([datetime.datetime(2016, 11, 27),8,"Teatro Bibiena",'Mantua',"Italy",'Mantua','Geneva',"Mantua",['Riju']])
data_list.append([datetime.datetime(2016, 11, 27),6,"Arena",'Verona',"Italy",'Mantua','Geneva',"Verona",['Riju']])
data_list.append([datetime.datetime(2016, 11, 27),2,"Piazza Bra",'Verona',"Italy",'Mantua','Geneva',"Verona",['Riju']])
data_list.append([datetime.datetime(2016, 11, 27),4,"Piazza delle Erbe",'Verona',"Italy",'Mantua','Geneva',"Verona",['Riju']])
data_list.append([datetime.datetime(2016, 11, 27),2,"Piazza dei Signori",'Verona',"Italy",'Mantua','Geneva',"Verona",['Riju']])
data_list.append([datetime.datetime(2016, 11, 27),3,"Palazzo della Ragione",'Verona',"Italy",'Mantua','Geneva',"Verona",['Riju']])
data_list.append([datetime.datetime(2016, 11, 27),5,"Scalinger Tombs",'Verona',"Italy",'Mantua','Geneva',"Verona",['Riju']])
data_list.append([datetime.datetime(2016, 11, 27),1,"Monument Guglielmos da Castelbaro",'Verona',"Italy",'Mantua','Geneva',"Verona",['Riju']])
data_list.append([datetime.datetime(2016, 11, 27),5,"San Giorgetto o San Pietro Martire",'Verona',"Italy",'Mantua','Geneva',"Verona",['Riju']])
data_list.append([datetime.datetime(2016, 11, 27),28,"Basilica Sant'Anastasia",'Verona',"Italy",'Mantua','Geneva',"Verona",['Riju']])
data_list.append([datetime.datetime(2016, 11, 27),7,"Baptistery",'Verona',"Italy",'Mantua','Geneva',"Verona",['Riju']])
data_list.append([datetime.datetime(2016, 11, 27),32,"Duomo",'Verona',"Italy",'Mantua','Geneva',"Verona",['Riju']])
data_list.append([datetime.datetime(2016, 11, 27),1,"Santa Maria Antica",'Verona',"Italy",'Mantua','Geneva',"Verona",['Riju']])
#Japan done
data_list.append([datetime.datetime(2016, 12, 6),1,"JR Tokyo Station","Tokyo","Japan",'Tokyo','Morioka',"",[]])
data_list.append([datetime.datetime(2016, 12, 8),1,"Ganjoju-in","Hiraizumi","Japan",'Morioka','Morioka',"",[]])
data_list.append([datetime.datetime(2016, 12, 8),21,"Chuson-ji Temple","Hiraizumi","Japan",'Morioka','Morioka',"Hiraizumi – Temples, Gardens and Archaeological Sites",[]])
data_list.append([datetime.datetime(2016, 12, 8),20,"Motsuji Temple","Hiraizumi","Japan",'Morioka','Morioka',"Hiraizumi – Temples, Gardens and Archaeological Sites",[]])
data_list.append([datetime.datetime(2016, 12, 9),3,"Tokyo Skytree","Tokyo","Japan",'Morioka','Tokyo',"",[]])
data_list.append([datetime.datetime(2016, 12, 9),33,"Tokyo Skytree Observatory","Tokyo","Japan",'Morioka','Tokyo',"",[]])
data_list.append([datetime.datetime(2016, 12, 9),9,"Senso-ji Temple","Tokyo","Japan",'Morioka','Tokyo',"",[]])
data_list.append([datetime.datetime(2016, 12, 9),4,"Tokyo Tower","Tokyo","Japan",'Morioka','Tokyo',"",[]])
data_list.append([datetime.datetime(2016, 12, 10),3,"Shinkyo Bridge","Nikko","Japan",'Tokyo','Tokyo',"Shrines and Temples of Nikko",[]])
data_list.append([datetime.datetime(2016, 12, 10),51,"Rinno-ji Temple","Nikko","Japan",'Tokyo','Tokyo',"Shrines and Temples of Nikko",[]])
data_list.append([datetime.datetime(2016, 12, 10),92,"Toshogu-Shrine","Nikko","Japan",'Tokyo','Tokyo',"Shrines and Temples of Nikko",[]])
data_list.append([datetime.datetime(2016, 12, 10),7,"Futarasan-Shrine","Nikko","Japan",'Tokyo','Tokyo',"Shrines and Temples of Nikko",[]])
data_list.append([datetime.datetime(2016, 12, 11),64,"Imperial Palace","Kyoto","Japan",'Tokyo','Kyoto',"",[]])
data_list.append([datetime.datetime(2016, 12, 11),26,"Nijo Castle","Kyoto","Japan",'Tokyo','Kyoto',"Historic Monuments of Ancient Kyoto (Kyoto, Uji and Otsu Cities)",[]])
data_list.append([datetime.datetime(2016, 12, 11),2,"Kyoto Tower","Kyoto","Japan",'Tokyo','Kyoto',"",[]])
data_list.append([datetime.datetime(2016, 12, 11),21,"To-ji Temple","Kyoto","Japan",'Tokyo','Kyoto',"Historic Monuments of Ancient Kyoto (Kyoto, Uji and Otsu Cities)",[]])
data_list.append([datetime.datetime(2016, 12, 11),24,"Nishi Hongwan-ji Temple","Kyoto","Japan",'Tokyo','Kyoto',"Historic Monuments of Ancient Kyoto (Kyoto, Uji and Otsu Cities)",[]])
data_list.append([datetime.datetime(2016, 12, 11),8,"Kosho-ji Temple","Kyoto","Japan",'Tokyo','Kyoto',"",[]])
data_list.append([datetime.datetime(2016, 12, 11),1,"Higashi Hongwan-ji Temple","Kyoto","Japan",'Tokyo','Kyoto',"",[]])
data_list.append([datetime.datetime(2016, 12, 11),7,"JR Kyoto Station","Kyoto","Japan",'Tokyo','Kyoto',"",[]])
data_list.append([datetime.datetime(2016, 12, 12),21,"Kiyomizu-dera Temple","Kyoto","Japan",'Kyoto','Kyoto',"Historic Monuments of Ancient Kyoto (Kyoto, Uji and Otsu Cities)",[]])
data_list.append([datetime.datetime(2016, 12, 12),21,"Ginkaku-ji Temple","Kyoto","Japan",'Kyoto','Kyoto',"Historic Monuments of Ancient Kyoto (Kyoto, Uji and Otsu Cities)",[]])
data_list.append([datetime.datetime(2016, 12, 12),12,"Rokuon-ji Temple","Kyoto","Japan",'Kyoto','Kyoto',"Historic Monuments of Ancient Kyoto (Kyoto, Uji and Otsu Cities)",[]])
data_list.append([datetime.datetime(2016, 12, 12),21,"Ryoan-ji Temple","Kyoto","Japan",'Kyoto','Kyoto',"Historic Monuments of Ancient Kyoto (Kyoto, Uji and Otsu Cities)",[]])
data_list.append([datetime.datetime(2016, 12, 12),36,"Ninna-ji Temple","Kyoto","Japan",'Kyoto','Kyoto',"Historic Monuments of Ancient Kyoto (Kyoto, Uji and Otsu Cities)",[]])
data_list.append([datetime.datetime(2016, 12, 12),9,"Kamigamo Shrine","Kyoto","Japan",'Kyoto','Kyoto',"Historic Monuments of Ancient Kyoto (Kyoto, Uji and Otsu Cities)",[]])
data_list.append([datetime.datetime(2016, 12, 12),5,"Shimogamo Shrine","Kyoto","Japan",'Kyoto','Kyoto',"Historic Monuments of Ancient Kyoto (Kyoto, Uji and Otsu Cities)",[]])
data_list.append([datetime.datetime(2016, 12, 12),4,"Rishoin","Kyoto","Japan",'Kyoto','Kyoto',"",[]])
data_list.append([datetime.datetime(2016, 12, 12),39,"Daigo-ji Temple","Kyoto","Japan",'Kyoto','Kyoto',"Historic Monuments of Ancient Kyoto (Kyoto, Uji and Otsu Cities)",[]])
data_list.append([datetime.datetime(2016, 12, 13),10,"Kofuku-ji Temple","Nara","Japan",'Kyoto','Kyoto',"Historic Monuments of Ancient Nara",[]])
data_list.append([datetime.datetime(2016, 12, 13),24,"Todai-ji Temple","Nara","Japan",'Kyoto','Kyoto',"Historic Monuments of Ancient Nara",[]])
data_list.append([datetime.datetime(2016, 12, 13),10,"Kasuga-taisha Shrine","Nara","Japan",'Kyoto','Kyoto',"Historic Monuments of Ancient Nara",[]])
data_list.append([datetime.datetime(2016, 12, 13),5,"Shin-yakushi-ji Temple","Nara","Japan",'Kyoto','Kyoto',"",[]])
data_list.append([datetime.datetime(2016, 12, 13),7,"Gango-ji Temple","Nara","Japan",'Kyoto','Kyoto',"Historic Monuments of Ancient Nara",[]])
data_list.append([datetime.datetime(2016, 12, 13),10,"Toshodai-ji Temple","Nara","Japan",'Kyoto','Kyoto',"Historic Monuments of Ancient Nara",[]])
data_list.append([datetime.datetime(2016, 12, 13),13,"Yakushi-ji Temple","Nara","Japan",'Kyoto','Kyoto',"Historic Monuments of Ancient Nara",[]])
data_list.append([datetime.datetime(2016, 12, 13),14,"Horyu-ji Temple","Ikaruga","Japan",'Kyoto','Kyoto',"Buddhist Monuments in the Horyu-ji Area",[]])
data_list.append([datetime.datetime(2016, 12, 13),4,"Chugu-ji Temple","Ikaruga","Japan",'Kyoto','Kyoto',"Buddhist Monuments in the Horyu-ji Area",[]])
data_list.append([datetime.datetime(2016, 12, 13),5,"Horin-ji Temple","Ikaruga","Japan",'Kyoto','Kyoto',"",[]])
data_list.append([datetime.datetime(2016, 12, 13),2,"Hokki-ji Temple","Ikaruga","Japan",'Kyoto','Kyoto',"Buddhist Monuments in the Horyu-ji Area",[]])
data_list.append([datetime.datetime(2016, 12, 14),10,"Atomic Bomb Dome","Hiroshima","Japan",'Kyoto','Kyoto',"Hiroshima Peace Memorial (Genbaku Dome)",[]])
data_list.append([datetime.datetime(2016, 12, 14),15,"Hiroshima Peace Memorial Park","Hiroshima","Japan",'Kyoto','Kyoto',"Hiroshima Peace Memorial (Genbaku Dome)",[]])
data_list.append([datetime.datetime(2016, 12, 14),7,"Hiroshima Castle","Hiroshima","Japan",'Kyoto','Kyoto',"",[]])
data_list.append([datetime.datetime(2016, 12, 14),63,"Himeji Castle","Himji","Japan",'Kyoto','Kyoto',"Himeji Castle",[]])
data_list.append([datetime.datetime(2016, 12, 14),23,"Koko-en Garden","Himji","Japan",'Kyoto','Kyoto',"Himeji Castle",[]])
data_list.append([datetime.datetime(2016, 12, 14),1,"Kyo-Ichi Pachinko","Kyoto","Japan",'Kyoto','Kyoto',"",[]])
data_list.append([datetime.datetime(2016, 12, 15),32,"Itsukushima Shinto Shrine","Harsukaichi","Japan",'Kyoto','Kyoto',"Itsukushima Shinto Shrine",[]])
data_list.append([datetime.datetime(2016, 12, 15),8,"Senjokaku Temple","Harsukaichi","Japan",'Kyoto','Kyoto',"",[]])
data_list.append([datetime.datetime(2016, 12, 15),2,"Daigan-ji Temple","Harsukaichi","Japan",'Kyoto','Kyoto',"",[]])
data_list.append([datetime.datetime(2016, 12, 15),1,"Tahoto Pagoda","Harsukaichi","Japan",'Kyoto','Kyoto',"I",[]])
data_list.append([datetime.datetime(2016, 12, 15),16,"Osaka Castle","Osaka","Japan",'Kyoto','Kyoto',"",[]])
data_list.append([datetime.datetime(2016, 12, 15),3,"Hokoku Shrine","Osaka","Japan",'Kyoto','Kyoto',"",[]])
data_list.append([datetime.datetime(2016, 12, 15),4,"Umeda Sky Building","Osaka","Japan",'Kyoto','Kyoto',"",[]])
data_list.append([datetime.datetime(2016, 12, 15),23,"Umeda Sky Building Observatory","Osaka","Japan",'Kyoto','Kyoto',"",[]])
data_list.append([datetime.datetime(2016, 12, 15),1,"JR Osaka Station","Osaka","Japan",'Kyoto','Kyoto',"",[]])
data_list.append([datetime.datetime(2016, 12, 16),12,"Fushimi Inari-Taisha Shrine","Kyoto","Japan",'Kyoto','Tokyo',"",[]])
data_list.append([datetime.datetime(2016, 12, 16),15,"Byodo-in Temple","Uji","Japan",'Kyoto','Tokyo',"Historic Monuments of Ancient Kyoto (Kyoto, Uji and Otsu Cities)",[]])
data_list.append([datetime.datetime(2016, 12, 16),1,"Ujigami Shrine","Uji","Japan",'Kyoto','Tokyo',"Historic Monuments of Ancient Kyoto (Kyoto, Uji and Otsu Cities)",[]])
data_list.append([datetime.datetime(2016, 12, 16),14,"Tenryu-ji Temple","Kyoto","Japan",'Kyoto','Tokyo',"Historic Monuments of Ancient Kyoto (Kyoto, Uji and Otsu Cities)",[]])
data_list.append([datetime.datetime(2016, 12, 16),17,"National Museum of Western Art","Tokyo","Japan",'Kyoto','Tokyo',"The Architectural Work of Le Corbusier",[]])
data_list.append([datetime.datetime(2016, 12, 16),18,"Tokyo Metropolitan Art Museum","Tokyo","Japan",'Kyoto','Tokyo',"",[]])
data_list.append([datetime.datetime(2016, 12, 16),35,"National Museum Tokyo","Tokyo","Japan",'Kyoto','Tokyo',"",[]])
data_list.append([datetime.datetime(2016, 12, 16),3,"Tokyo JR Station","Tokyo","Japan",'Kyoto','Tokyo',"",[]])
data_list.append([datetime.datetime(2016, 12, 17),1,"Tokyo JR Station","Tokyo","Japan",'Tokyo','Plane HND-CDG',"",[]])
data_list.append([datetime.datetime(2016, 12, 17),47,"Imperial Palace","Tokyo","Japan",'Tokyo','Plane HND-CDG',"",[]])
data_list.append([datetime.datetime(2016, 12, 17),4,"Metropolitan Government Building","Tokyo","Japan",'Tokyo','Plane HND-CDG',"",[]])
data_list.append([datetime.datetime(2016, 12, 17),47,"Metropolitan Government Building Observatory","Tokyo","Japan",'Tokyo','Plane HND-CDG',"",[]])
data_list.append([datetime.datetime(2016, 12, 17),3,"Akasaka Palace","Tokyo","Japan",'Tokyo','Plane HND-CDG',"",[]])
data_list.append([datetime.datetime(2016, 12, 17),1,"National Diet Building","Tokyo","Japan",'Tokyo','Plane HND-CDG',"",[]])
data_list.append([datetime.datetime(2016, 12, 17),16,"Teien Palace","Tokyo","Japan",'Tokyo','Plane HND-CDG',"",[]])

# %%
#2017
#dublin and northern ireland done
data_list.append([datetime.datetime(2017, 1, 2),2,"General Post Office",'Dublin',"Ireland",'Geneva','Dublin',"",['Chris Martin']])
data_list.append([datetime.datetime(2017, 1, 2),1,"City Hall",'Dublin',"Ireland",'Geneva','Dublin',"",['Chris Martin']])
data_list.append([datetime.datetime(2017, 1, 2),43,"Dublin Castle",'Dublin',"Ireland",'Geneva','Dublin',"",['Chris Martin']])
data_list.append([datetime.datetime(2017, 1, 2),15,"Christ Church Cathedral",'Dublin',"Ireland",'Geneva','Dublin',"",['Chris Martin']])
data_list.append([datetime.datetime(2017, 1, 3),6,"St Mary's Pro Cathedral",'Dublin',"Ireland",'Dublin','Dublin',"",['Chris Martin']])
data_list.append([datetime.datetime(2017, 1, 3),1,"General Post Office",'Dublin',"Ireland",'Dublin','Dublin',"",['Chris Martin']])
data_list.append([datetime.datetime(2017, 1, 3),13,"Trinity College",'Dublin',"Ireland",'Dublin','Dublin',"",['Chris Martin']])
data_list.append([datetime.datetime(2017, 1, 3),9,"City Hall",'Dublin',"Ireland",'Dublin','Dublin',"",['Chris Martin']])
data_list.append([datetime.datetime(2017, 1, 3),20,"St Patrick's Cathedral",'Dublin',"Ireland",'Dublin','Dublin',"",['Chris Martin']])
data_list.append([datetime.datetime(2017, 1, 3),1,"Christ Church Cathedral",'Dublin',"Ireland",'Dublin','Dublin',"",['Chris Martin']])
data_list.append([datetime.datetime(2017, 1, 3),1,"The Temple Bar",'Dublin',"Ireland",'Dublin','Dublin',"",['Chris Martin']])
data_list.append([datetime.datetime(2017, 1, 3),4,"Whiskey Museum",'Dublin',"Ireland",'Dublin','Dublin',"",['Chris Martin']])
data_list.append([datetime.datetime(2017, 1, 3),13,"Guiness Storehouse",'Dublin',"Ireland",'Dublin','Dublin',"",['Chris Martin']])
data_list.append([datetime.datetime(2017, 1, 4),4,"The Dark Hedges",'Ballymoney',"United Kingdom",'Dublin','Dublin',"",['Chris Martin']])
data_list.append([datetime.datetime(2017, 1, 4),39,"Carrick-a-Rede Cliff Coast",'Ballycastle',"United Kingdom",'Dublin','Dublin',"",['Chris Martin']])
data_list.append([datetime.datetime(2017, 1, 4),47,"Giant's Causeway",'Bushmills',"United Kingdom",'Dublin','Dublin',"Giant's Causeway",['Chris Martin']])
data_list.append([datetime.datetime(2017, 1, 4),7,"Port Noffer",'Bushmills',"United Kingdom",'Dublin','Dublin',"Giant's Causeway",['Chris Martin']])
data_list.append([datetime.datetime(2017, 1, 4),2,"Dunluce Castle",'Bushmills',"United Kingdom",'Dublin','Dublin',"Giant's Causeway",['Chris Martin']])
data_list.append([datetime.datetime(2017, 1, 4),10,"City Hall",'Belfast',"United Kingdom",'Dublin','Dublin',"Giant's Causeway",['Chris Martin']])
data_list.append([datetime.datetime(2017, 1, 4),7,"St Anne's Cathedral",'Belfast',"United Kingdom",'Dublin','Dublin',"Giant's Causeway",['Chris Martin']])
#avignon & Carcassonne
data_list.append([datetime.datetime(2017, 1, 13),1,"Town Walls",'Avignon',"France",'Geneva','Avignon',"",[]])
data_list.append([datetime.datetime(2017, 1, 14),4,"Canal du Midi",'Carcassonne',"France",'Avignon','Avignon',"Canal du Midi",[]])
data_list.append([datetime.datetime(2017, 1, 14),3,"Chapelle Notre-Dame-de-Sante",'Carcassonne',"France",'Avignon','Avignon',"",[]])
data_list.append([datetime.datetime(2017, 1, 14),6,"Cite de Carcassonne",'Carcassonne',"France",'Avignon','Avignon',"Historic Fortified City of Carcassonne",[]])
data_list.append([datetime.datetime(2017, 1, 14),30,"Cite de Carcassonne Chateau Comtal",'Carcassonne',"France",'Avignon','Avignon',"Historic Fortified City of Carcassonne",[]])
data_list.append([datetime.datetime(2017, 1, 14),37,"Cite de Carcassonne Town Walls",'Carcassonne',"France",'Avignon','Avignon',"Historic Fortified City of Carcassonne",[]])
data_list.append([datetime.datetime(2017, 1, 14),4,"Cite de Carcassonne Porte Narbonnaise",'Carcassonne',"France",'Avignon','Avignon',"Historic Fortified City of Carcassonne",[]])
data_list.append([datetime.datetime(2017, 1, 14),21,"Cite de Carcassonne Basilique St-Nazaire",'Carcassonne',"France",'Avignon','Avignon',"Historic Fortified City of Carcassonne",[]])
data_list.append([datetime.datetime(2017, 1, 14),17,"St Vincent",'Carcassonne',"France",'Avignon','Avignon',"",[]])
data_list.append([datetime.datetime(2017, 1, 14),4,"Cite de Carcassonne Theatre Jean Deschamps",'Carcassonne',"France",'Avignon','Avignon',"Historic Fortified City of Carcassonne",[]])
data_list.append([datetime.datetime(2017, 1, 14),1,"Le Dome",'Carcassonne',"France",'Avignon','Avignon',"",[]])
data_list.append([datetime.datetime(2017, 1, 14),13,"Cathedral",'Carcassonne',"France",'Avignon','Avignon',"",[]])
data_list.append([datetime.datetime(2017, 1, 14),1,"Neptune Fountain",'Carcassonne',"France",'Avignon','Avignon',"",[]])
data_list.append([datetime.datetime(2017, 1, 14),1,"Lapidarium",'Avignon',"France",'Avignon','Avignon',"",[]])
data_list.append([datetime.datetime(2017, 1, 14),1,"Temple St Martial",'Avignon',"France",'Avignon','Avignon',"",[]])
data_list.append([datetime.datetime(2017, 1, 14),3,"Place de l'Horloge",'Avignon',"France",'Avignon','Avignon',"",[]])
data_list.append([datetime.datetime(2017, 1, 14),2,"Hotel de Ville",'Avignon',"France",'Avignon','Avignon',"",[]])
data_list.append([datetime.datetime(2017, 1, 14),8,"Papal Palace",'Avignon',"France",'Avignon','Avignon',"Historic Centre of Avignon: Papal Palace, Episcopal Ensemble and Avignon Bridge",[]])
data_list.append([datetime.datetime(2017, 1, 14),1,"Cathedral",'Avignon',"France",'Avignon','Avignon',"Historic Centre of Avignon: Papal Palace, Episcopal Ensemble and Avignon Bridge",[]])
data_list.append([datetime.datetime(2017, 1, 14),1,"Petit Palais",'Avignon',"France",'Avignon','Avignon',"Historic Centre of Avignon: Papal Palace, Episcopal Ensemble and Avignon Bridge",[]])
data_list.append([datetime.datetime(2017, 1, 15),2,"Town Walls",'Avignon',"France",'Avignon','Geneva',"",[]])
data_list.append([datetime.datetime(2017, 1, 15),4,"Hotel de Ville",'Avignon',"France",'Avignon','Geneva',"",[]])
data_list.append([datetime.datetime(2017, 1, 15),102,"Papal Palace",'Avignon',"France",'Avignon','Geneva',"Historic Centre of Avignon: Papal Palace, Episcopal Ensemble and Avignon Bridge",[]])
data_list.append([datetime.datetime(2017, 1, 15),1,"Place de l'Horloge",'Avignon',"France",'Avignon','Geneva',"",[]])
data_list.append([datetime.datetime(2017, 1, 15),18,"Petit Palais",'Avignon',"France",'Avignon','Geneva',"Historic Centre of Avignon: Papal Palace, Episcopal Ensemble and Avignon Bridge",[]])
data_list.append([datetime.datetime(2017, 1, 15),38,"Cathedral",'Avignon',"France",'Avignon','Geneva',"Historic Centre of Avignon: Papal Palace, Episcopal Ensemble and Avignon Bridge",[]])
data_list.append([datetime.datetime(2017, 1, 15),13,"Pont Saint-Benezet",'Avignon',"France",'Avignon','Geneva',"Historic Centre of Avignon: Papal Palace, Episcopal Ensemble and Avignon Bridge",[]])
data_list.append([datetime.datetime(2017, 1, 15),4,"Tour Philippe de Bel",'Villeneuve-les-Avignon',"France",'Avignon','Geneva',"",[]])
data_list.append([datetime.datetime(2017, 1, 15),3,"Place du Palais",'Avignon',"France",'Avignon','Geneva',"Historic Centre of Avignon: Papal Palace, Episcopal Ensemble and Avignon Bridge",[]])
data_list.append([datetime.datetime(2017, 1, 15),7,"Fort St-Andre",'Villeneuve-les-Avignon',"France",'Avignon','Geneva',"",[]])
data_list.append([datetime.datetime(2017, 1, 15),4,"Rocher des Doms",'Avignon',"France",'Avignon','Geneva',"Historic Centre of Avignon: Papal Palace, Episcopal Ensemble and Avignon Bridge",[]])
data_list.append([datetime.datetime(2017, 1, 15),16,"Basilique St Pierre",'Avignon',"France",'Avignon','Geneva',"",[]])
data_list.append([datetime.datetime(2017, 1, 15),2,"Temple St Martial",'Avignon',"France",'Avignon','Geneva',"",[]])
data_list.append([datetime.datetime(2017, 1, 15),9,"Lapidarium",'Avignon',"France",'Avignon','Geneva',"",[]])
data_list.append([datetime.datetime(2017, 1, 15),1,"Monument for the Victims of May 1, 1891",'Avignon',"France",'Avignon','Geneva',"",[]])
#LHCb
data_list.append([datetime.datetime(2017, 1, 23),10,"LHCb",'Feney-Voltaire',"France",'Geneva','Geneva',"",[]])
data_list.append([datetime.datetime(2017, 1, 23),11,"Delphi",'Feney-Voltaire',"France",'Geneva','Geneva',"",[]])
#belgium 2017 done
data_list.append([datetime.datetime(2017, 2, 11),2,"Grand Place",'Brussels',"Belgium",'Geneva','Brussels',"Grand Place",['Riju']])
data_list.append([datetime.datetime(2017, 2, 11),1,"Stadhuis",'Brussels',"Belgium",'Geneva','Brussels',"Grand Place",['Riju']])
data_list.append([datetime.datetime(2017, 2, 11),19,"St Salvator Cathedral",'Bruges',"Belgium",'Brussels','Ghent',"Bruges",[]])
data_list.append([datetime.datetime(2017, 2, 11),4,"Belfry",'Bruges',"Belgium",'Brussels','Ghent',"Bruges",[]])
data_list.append([datetime.datetime(2017, 2, 11),15,"Town Hall",'Bruges',"Belgium",'Brussels','Ghent',"Bruges",[]])
data_list.append([datetime.datetime(2017, 2, 11),11,"Liberty of Bruges",'Bruges',"Belgium",'Brussels','Ghent',"Bruges",[]])
data_list.append([datetime.datetime(2017, 2, 11),17,"Basilica of Holy Blood",'Bruges',"Belgium",'Brussels','Ghent',"Bruges",[]])
data_list.append([datetime.datetime(2017, 2, 11),4,"Grote Markt",'Bruges',"Belgium",'Brussels','Ghent',"Bruges",[]])
data_list.append([datetime.datetime(2017, 2, 11),23,"Church of Our Lady",'Bruges',"Belgium",'Brussels','Ghent',"Bruges",[]])
data_list.append([datetime.datetime(2017, 2, 11),2,"Train Station",'Bruges',"Belgium",'Brussels','Ghent',"Bruges",[]])
data_list.append([datetime.datetime(2017, 2, 11),2,"Belfry",'Ghent',"Belgium",'Brussels','Ghent',"Belfries of Belgium and France",[]])
data_list.append([datetime.datetime(2017, 2, 11),11,"Niklaaskerk",'Ghent',"Belgium",'Brussels','Ghent',"",[]])
data_list.append([datetime.datetime(2017, 2, 11),30,"St Bavo Cathedral",'Ghent',"Belgium",'Brussels','Ghent',"",[]])
data_list.append([datetime.datetime(2017, 2, 11),8,"Hotel Clemmen",'Ghent',"Belgium",'Brussels','Ghent',"",[]])
data_list.append([datetime.datetime(2017, 2, 11),52,"Hotel d'Hane-Steenhuyse",'Ghent',"Belgium",'Brussels','Ghent',"",[]])
data_list.append([datetime.datetime(2017, 2, 11),2,"Town Hall",'Ghent',"Belgium",'Brussels','Ghent',"",["Riju"]])
data_list.append([datetime.datetime(2017, 2, 11),2,"Belfry",'Ghent',"Belgium",'Brussels','Ghent',"Belfries of Belgium and France",["Riju"]])
data_list.append([datetime.datetime(2017, 2, 11),1,"Niklaaskerk",'Ghent',"Belgium",'Brussels','Ghent',"",["Riju"]])
data_list.append([datetime.datetime(2017, 2, 11),2,"St Bavo Cathedral",'Ghent',"Belgium",'Brussels','Ghent',"",["Riju"]])
data_list.append([datetime.datetime(2017, 2, 11),4,"Gravensteen",'Ghent',"Belgium",'Brussels','Ghent',"",["Riju"]])
data_list.append([datetime.datetime(2017, 2, 12),1,"Hotel Clemmen",'Ghent',"Belgium",'Ghent','Geneva',"",["Riju"]])
data_list.append([datetime.datetime(2017, 2, 12),1,"Hotel d'Hane-Steenhuyse",'Ghent',"Belgium",'Ghent','Geneva',"",['Riju']])
data_list.append([datetime.datetime(2017, 2, 12),5,"Korenmarkt",'Ghent',"Belgium",'Ghent','Geneva',"",['Riju']])
data_list.append([datetime.datetime(2017, 2, 12),26,"Gravensteen",'Ghent',"Belgium",'Ghent','Geneva',"",['Riju']])
data_list.append([datetime.datetime(2017, 2, 12),9,"Town Hall",'Ghent',"Belgium",'Ghent','Geneva',"",["Riju"]])
data_list.append([datetime.datetime(2017, 2, 12),1,"Belfry",'Ghent',"Belgium",'Ghent','Geneva',"Belfries of Belgium and France",["Riju"]])
data_list.append([datetime.datetime(2017, 2, 12),1,"St Bavo Cathedral",'Ghent',"Belgium",'Ghent','Geneva',"",["Riju"]])
data_list.append([datetime.datetime(2017, 2, 12),1,"Niklaaskerk",'Ghent',"Belgium",'Ghent','Geneva',"",["Riju"]])
data_list.append([datetime.datetime(2017, 2, 12),12,"Antwerp-Centraal",'Antwerp',"Belgium",'Ghent','Geneva',"",["Riju"]])
data_list.append([datetime.datetime(2017, 2, 12),9,"Palais op de Meir",'Antwerp',"Belgium",'Ghent','Geneva',"",["Riju"]])
data_list.append([datetime.datetime(2017, 2, 12),68,"Cathedral",'Antwerp',"Belgium",'Ghent','Geneva',"Belfries of Belgium and France",["Riju"]])
data_list.append([datetime.datetime(2017, 2, 12),6,"Grote Markt",'Antwerp',"Belgium",'Ghent','Geneva',"",["Riju"]])
data_list.append([datetime.datetime(2017, 2, 12),5,"Town Hall",'Antwerp',"Belgium",'Ghent','Geneva',"Belfries of Belgium and France",["Riju"]])
data_list.append([datetime.datetime(2017, 2, 12),7,"Hetsteen",'Antwerp',"Belgium",'Ghent','Geneva',"",["Riju"]])
data_list.append([datetime.datetime(2017, 2, 12),2,"Sint-Carolus Borromeuskerk",'Antwerp',"Belgium",'Ghent','Geneva',"",["Riju"]])
data_list.append([datetime.datetime(2017, 2, 12),43,"Rubens House",'Antwerp',"Belgium",'Ghent','Geneva',"",["Riju"]])
data_list.append([datetime.datetime(2017, 2, 12),33,"Stadsfeestzaal",'Antwerp',"Belgium",'Ghent','Geneva',"",["Riju"]])
data_list.append([datetime.datetime(2017, 2, 12),3,"Gare Cornavin",'Geneva',"Switzerland",'Ghent','Geneva',"",[]])

# %%
#CMS
data_list.append([datetime.datetime(2017,2,17),9,"CMS",'Cessy',"France",'Geneva','Geneva',"",['Pieter','Simon','Rickard']])
#brenets
data_list.append([datetime.datetime(2017,3,12),17,"Lac des Brenets Canyon",'Brenets',"Switzerland",'Geneva','Geneva',"",['Riju','Sarah']])
data_list.append([datetime.datetime(2017,3,12),20,"Doubs",'Villers-le-Lac',"Switzerland",'Geneva','Geneva',"",['Riju','Sarah']])
data_list.append([datetime.datetime(2017,3,12),13,"Saut du Doubs",'Brenets',"Switzerland",'Geneva','Geneva',"",['Riju','Sarah']])
data_list.append([datetime.datetime(2017,3,12),4,"Lac Neuchatel",'Neuchatel',"Switzerland",'Geneva','Geneva',"",['Riju','Sarah']])
data_list.append([datetime.datetime(2017,3,12),4,"Collegiale",'Neuchatel',"Switzerland",'Geneva','Geneva',"",['Riju','Sarah']])
data_list.append([datetime.datetime(2017,3,12),2,"Chateau",'Neuchatel',"Switzerland",'Geneva','Geneva',"",['Riju','Sarah']])
#Umbrien 2017
data_list.append([datetime.datetime(2017,3,24),4,"Milano Centrale",'Milano',"Italy",'Geneva','Milano',"",[]])
data_list.append([datetime.datetime(2017,3,25),1,"Assisi Stazione",'Assisi',"Italy",'Milano','Assisi',"Assisi, the Basilica of San Francesco and Other Franciscan Sites",[]])
data_list.append([datetime.datetime(2017,3,25),12,"Palazzo Comunale",'Assisi',"Italy",'Milano','Assisi',"Assisi, the Basilica of San Francesco and Other Franciscan Sites",[]])
data_list.append([datetime.datetime(2017,3,25),21,"Cathedral San Rufino",'Assisi',"Italy",'Milano','Assisi',"Assisi, the Basilica of San Francesco and Other Franciscan Sites",[]])
data_list.append([datetime.datetime(2017,3,25),3,"Rocca Maggiore",'Assisi',"Italy",'Milano','Assisi',"Assisi, the Basilica of San Francesco and Other Franciscan Sites",[]])
data_list.append([datetime.datetime(2017,3,25),14,"Basilica di Santa Chiara",'Assisi',"Italy",'Milano','Assisi',"Assisi, the Basilica of San Francesco and Other Franciscan Sites",[]])
data_list.append([datetime.datetime(2017,3,25),14,"Chiesa Nuova",'Assisi',"Italy",'Milano','Assisi',"Assisi, the Basilica of San Francesco and Other Franciscan Sites",[]])
data_list.append([datetime.datetime(2017,3,25),5,"Piazza del Comune",'Assisi',"Italy",'Milano','Assisi',"Assisi, the Basilica of San Francesco and Other Franciscan Sites",[]])
data_list.append([datetime.datetime(2017,3,25),11,"Tempio di Minerva",'Assisi',"Italy",'Milano','Assisi',"Assisi, the Basilica of San Francesco and Other Franciscan Sites",[]])
data_list.append([datetime.datetime(2017,3,25),7,"Oratorio dei Pellegrini",'Assisi',"Italy",'Milano','Assisi',"Assisi, the Basilica of San Francesco and Other Franciscan Sites",[]])
data_list.append([datetime.datetime(2017,3,25),61,"Basilica Papale di San Francesco d'Assisi",'Assisi',"Italy",'Milano','Assisi',"Assisi, the Basilica of San Francesco and Other Franciscan Sites",[]])
data_list.append([datetime.datetime(2017,3,25),38,"Basilica Papale di Santa Maria degli Angeli",'Assisi',"Italy",'Milano','Assisi',"Assisi, the Basilica of San Francesco and Other Franciscan Sites",[]])
data_list.append([datetime.datetime(2017,3,26),4,"Cathedral San Rufino",'Assisi',"Italy",'Assisi','Geneva',"Assisi, the Basilica of San Francesco and Other Franciscan Sites",[]])
data_list.append([datetime.datetime(2017,3,26),1,"Rocca Maggiore",'Assisi',"Italy",'Assisi','Geneva',"Assisi, the Basilica of San Francesco and Other Franciscan Sites",[]])
data_list.append([datetime.datetime(2017,3,26),1,"Rocca Minore",'Assisi',"Italy",'Assisi','Geneva',"Assisi, the Basilica of San Francesco and Other Franciscan Sites",[]])
data_list.append([datetime.datetime(2017,3,26),8,"Basilica di San Domenico",'Perugia',"Italy",'Assisi','Geneva',"",[]])
data_list.append([datetime.datetime(2017,3,26),1,"Porta di San Pietro",'Perugia',"Italy",'Assisi','Geneva',"",[]])
data_list.append([datetime.datetime(2017,3,26),21,"Basilica di San Pietro",'Perugia',"Italy",'Assisi','Geneva',"",[]])
data_list.append([datetime.datetime(2017,3,26),8,"Chiesa del Gesu",'Perugia',"Italy",'Assisi','Geneva',"",[]])
data_list.append([datetime.datetime(2017,3,26),9,"Palazzo dei Priori",'Perugia',"Italy",'Assisi','Geneva',"",[]])
data_list.append([datetime.datetime(2017,3,26),20,"Cathedral San Lorenzo",'Perugia',"Italy",'Assisi','Geneva',"",[]])
data_list.append([datetime.datetime(2017,3,26),6,"San Filippo Neri",'Perugia',"Italy",'Assisi','Geneva',"",[]])
data_list.append([datetime.datetime(2017,3,26),1,"Fontana Maggiore",'Perugia',"Italy",'Assisi','Geneva',"",[]])
data_list.append([datetime.datetime(2017,3,26),3,"Capella di San Severo",'Perugia',"Italy",'Assisi','Geneva',"",[]])
data_list.append([datetime.datetime(2017,3,26),5,"Collegio del Cambio",'Perugia',"Italy",'Assisi','Geneva',"",[]])
data_list.append([datetime.datetime(2017,3,26),8,"Rocca Paolina",'Perugia',"Italy",'Assisi','Geneva',"",[]])
data_list.append([datetime.datetime(2017,3,26),1,"Santa Maria Novella",'Florence',"Italy",'Assisi','Geneva',"Florence",[]])
data_list.append([datetime.datetime(2017,3,26),2,"Duomo",'Florence',"Italy",'Assisi','Geneva',"Florence",[]])
data_list.append([datetime.datetime(2017,3,26),1,"Stazione Santa Maria Novella",'Florence',"Italy",'Assisi','Geneva',"Florence",[]])
data_list.append([datetime.datetime(2017,3,26),1,"Bologna Centrale",'Bologna',"Italy",'Assisi','Geneva',"",[]])
data_list.append([datetime.datetime(2017,3,26),2,"Milano Centrale",'Milano',"Italy",'Assisi','Geneva',"",[]])

# %%
#kiev done
data_list.append([datetime.datetime(2017, 4, 14),2,"Kiev-Passaschyrskyj Stations",'Kiev',"Ukraine",'Geneva','Kiev',"",[]])
data_list.append([datetime.datetime(2017, 4, 15),14,"St Volodymyr's Cathedral",'Kiev',"Ukraine",'Kiev','Kiev',"",[]])
data_list.append([datetime.datetime(2017, 4, 15),2,"Golden Gate",'Kiev',"Ukraine",'Kiev','Kiev',"",[]])
data_list.append([datetime.datetime(2017, 4, 15),48,"Gorodetsky House",'Kiev',"Ukraine",'Kiev','Kiev',"",[]])
data_list.append([datetime.datetime(2017, 4, 15),35,"St Sophia Cathedral",'Kiev',"Ukraine",'Kiev','Kiev',"Saint-Sophia Cathedral and Related Monastic Buildings, Kyiv-Pechersk Lavra",[]])
data_list.append([datetime.datetime(2017, 4, 15),105,"Kyiv Pechersk Lavra Cave Monastery",'Kiev',"Ukraine",'Kiev','Kiev',"Saint-Sophia Cathedral and Related Monastic Buildings, Kyiv-Pechersk Lavra",[]])
data_list.append([datetime.datetime(2017, 4, 15),1,"Motherland Monument",'Kiev',"Ukraine",'Kiev','Kiev',"",[]])
data_list.append([datetime.datetime(2017, 4, 15),4,"Vechnoy Slavy Park",'Kiev',"Ukraine",'Kiev','Kiev',"",[]])
data_list.append([datetime.datetime(2017, 4, 15),2,"Sergios Radonesch Church",'Kiev',"Ukraine",'Kiev','Kiev',"",[]])
data_list.append([datetime.datetime(2017, 4, 15),5,"Feodosiyivskyy Monastery",'Kiev',"Ukraine",'Kiev','Kiev',"",[]])
data_list.append([datetime.datetime(2017, 4, 15),7,"Majdan Square",'Kiev',"Ukraine",'Kiev','Kiev',"",[]])
data_list.append([datetime.datetime(2017, 4, 15),9,"Michael's Monastery",'Kiev',"Ukraine",'Kiev','Kiev',"",[]])
data_list.append([datetime.datetime(2017, 4, 15),2,"St Andrew Church",'Kiev',"Ukraine",'Kiev','Kiev',"",[]])
data_list.append([datetime.datetime(2017, 4, 16),5,"Nikolai-Prytyska Church",'Kiev',"Ukraine",'Kiev','Kiev',"",[]])
data_list.append([datetime.datetime(2017, 4, 16),8,"Florivsky Monastery",'Kiev',"Ukraine",'Kiev','Kiev',"",[]])
data_list.append([datetime.datetime(2017, 4, 16),3,"Church of Mary Ascension",'Kiev',"Ukraine",'Kiev','Kiev',"",[]])
data_list.append([datetime.datetime(2017, 4, 16),2,"Church of St Nicholas of Myra",'Kiev',"Ukraine",'Kiev','Kiev',"",[]])
data_list.append([datetime.datetime(2017, 4, 16),2,"Michael's Monastery",'Kiev',"Ukraine",'Kiev','Kiev',"",[]])
data_list.append([datetime.datetime(2017, 4, 16),4,"Alexander Church",'Kiev',"Ukraine",'Kiev','Kiev',"",[]])
data_list.append([datetime.datetime(2017, 4, 16),3,"Majdan Square",'Kiev',"Ukraine",'Kiev','Kiev',"",[]])
data_list.append([datetime.datetime(2017, 4, 16),4,"Nicholas Cathedral",'Kiev',"Ukraine",'Kiev','Kiev',"",[]])
data_list.append([datetime.datetime(2017, 4, 16),62,"Airplane Museum",'Kiev',"Ukraine",'Kiev','Kiev',"",[]])
data_list.append([datetime.datetime(2017, 4, 16),2,"Kiev-Passaschyrskyj Stations",'Kiev',"Ukraine",'Geneva','Kiev',"",[]])

# %%
#Frankfurt done
data_list.append([datetime.datetime(2017,4,28),1,"Hauptbahnhof",'Frankfurt',"Germany",'Geneva','Frankfurt',"",[]])
data_list.append([datetime.datetime(2017,4,28),1,"Euro Monument",'Frankfurt',"Germany",'Geneva','Frankfurt',"",[]])
data_list.append([datetime.datetime(2017,4,28),13,"Main Tower Observatory",'Frankfurt',"Germany",'Geneva','Frankfurt',"",[]])
data_list.append([datetime.datetime(2017,4,29),2,"Hauptbahnhof",'Frankfurt',"Germany",'Frankfurt','Frankfurt',"",[]])
data_list.append([datetime.datetime(2017,4,29),9,"Park Schoenbusch",'Aschaffenburg',"Germany",'Frankfurt','Frankfurt',"",[]])
data_list.append([datetime.datetime(2017,4,29),4,"Schloss Schoenbusch",'Aschaffenburg',"Germany",'Frankfurt','Frankfurt',"",[]])
data_list.append([datetime.datetime(2017,4,29),7,"Park Schoenbusch Festsaal",'Aschaffenburg',"Germany",'Frankfurt','Frankfurt',"",[]])
data_list.append([datetime.datetime(2017,4,29),34,"Pompejanum",'Aschaffenburg',"Germany",'Frankfurt','Frankfurt',"",[]])
data_list.append([datetime.datetime(2017,4,29),31,"Schloss Johannisburg",'Aschaffenburg',"Germany",'Frankfurt','Frankfurt',"",[]])
data_list.append([datetime.datetime(2017,4,29),6,"Frauenkirche",'Aschaffenburg',"Germany",'Frankfurt','Frankfurt',"",[]])
data_list.append([datetime.datetime(2017,4,29),12,"Stiftsbasilika St Peter & Alexander",'Aschaffenburg',"Germany",'Frankfurt','Frankfurt',"",[]])
data_list.append([datetime.datetime(2017,4,29),67,"Stadtschloss",'Wiesbaden',"Germany",'Frankfurt','Frankfurt',"",[]])
data_list.append([datetime.datetime(2017,4,29),6,"Neues Rathaus",'Wiesbaden',"Germany",'Frankfurt','Frankfurt',"",[]])
data_list.append([datetime.datetime(2017,4,29),3,"Hessisches Staatstheater",'Wiesbaden',"Germany",'Frankfurt','Frankfurt',"",[]])
data_list.append([datetime.datetime(2017,4,29),14,"Kurhaus",'Wiesbaden',"Germany",'Frankfurt','Frankfurt',"",[]])
data_list.append([datetime.datetime(2017,4,29),2,"Kurpark",'Wiesbaden',"Germany",'Frankfurt','Frankfurt',"",[]])
data_list.append([datetime.datetime(2017,4,29),3,"Marktkirche",'Wiesbaden',"Germany",'Frankfurt','Frankfurt',"",[]])
data_list.append([datetime.datetime(2017,4,29),2,"Hauptbahnhof",'Wiesbaden',"Germany",'Frankfurt','Frankfurt',"",[]])
data_list.append([datetime.datetime(2017,4,29),3,"Katharinenkirche",'Frankfurt',"Germany",'Frankfurt','Frankfurt',"",[]])
data_list.append([datetime.datetime(2017,4,29),2,"Hauptwache",'Frankfurt',"Germany",'Frankfurt','Frankfurt',"",[]])
data_list.append([datetime.datetime(2017,4,29),4,"Commerzbank Tower",'Frankfurt',"Germany",'Frankfurt','Frankfurt',"",[]])
data_list.append([datetime.datetime(2017,4,29),5,"Paulskirche",'Frankfurt',"Germany",'Frankfurt','Frankfurt',"",[]])
data_list.append([datetime.datetime(2017,4,29),6,"Roemer",'Frankfurt',"Germany",'Frankfurt','Frankfurt',"",[]])
data_list.append([datetime.datetime(2017,4,29),4,"Alte Nikolaikirche",'Frankfurt',"Germany",'Frankfurt','Frankfurt',"",[]])
data_list.append([datetime.datetime(2017,4,29),26,"Kaiserdom St Bartholomaeus",'Frankfurt',"Germany",'Frankfurt','Frankfurt',"",[]])
data_list.append([datetime.datetime(2017,4,29),18,"Kaiserdom St Bartholomaeus Turm",'Frankfurt',"Germany",'Frankfurt','Frankfurt',"",[]])
data_list.append([datetime.datetime(2017,4,29),1,"Liebfrauenberg",'Frankfurt',"Germany",'Frankfurt','Frankfurt',"",[]])
data_list.append([datetime.datetime(2017,4,29),15,"Galeria Frankfurt Zeil Dachterrasse",'Frankfurt',"Germany",'Frankfurt','Frankfurt',"",[]])
data_list.append([datetime.datetime(2017,4,30),1,"Damianstor",'Bruchsal',"Germany",'Frankfurt','Frankfurt',"",[]])
data_list.append([datetime.datetime(2017,4,30),101,"Schloss Bruchsal",'Bruchsal',"Germany",'Frankfurt','Frankfurt',"",[]])
data_list.append([datetime.datetime(2017,4,30),47,"Schloss Mannheim",'Mannheim',"Germany",'Frankfurt','Frankfurt',"",[]])
data_list.append([datetime.datetime(2017,4,30),12,"Jesuitenkirche",'Mannheim',"Germany",'Frankfurt','Frankfurt',"",[]])
data_list.append([datetime.datetime(2017,4,30),60,"Dom",'Speyer',"Germany",'Frankfurt','Frankfurt',"Speyer Cathedral",[]])
data_list.append([datetime.datetime(2017,4,30),4,"Oelberg",'Speyer',"Germany",'Frankfurt','Frankfurt',"",[]])
data_list.append([datetime.datetime(2017,4,30),1,"Heidentuermchen",'Speyer',"Germany",'Frankfurt','Frankfurt',"",[]])
data_list.append([datetime.datetime(2017,4,30),5,"Dom Turm",'Speyer',"Germany",'Frankfurt','Frankfurt',"",[]])
data_list.append([datetime.datetime(2017,4,30),33,"Dom",'Mainz',"Germany",'Frankfurt','Frankfurt',"",[]])
data_list.append([datetime.datetime(2017,4,30),3,"Zum Roemischen Kaiser",'Mainz',"Germany",'Frankfurt','Frankfurt',"",[]])
data_list.append([datetime.datetime(2017,4,30),4,"Kurfuerstliches Schloss",'Mainz',"Germany",'Frankfurt','Frankfurt',"",[]])
data_list.append([datetime.datetime(2017,4,30),1,"Eisenturm",'Mainz',"Germany",'Frankfurt','Frankfurt',"",[]])
data_list.append([datetime.datetime(2017,4,30),1,"Rathaus",'Mainz',"Germany",'Frankfurt','Frankfurt',"",[]])
data_list.append([datetime.datetime(2017,4,30),3,"Schillerplatz",'Mainz',"Germany",'Frankfurt','Frankfurt',"",[]])
data_list.append([datetime.datetime(2017,5,1),3,"Kollegialstift Haug",'Wuerzburg',"Germany",'Frankfurt','Frankfurt',"",[]])
data_list.append([datetime.datetime(2017,5,1),5,"Koenigsplatz",'Kassel',"Germany",'Frankfurt','Frankfurt',"",[]])
data_list.append([datetime.datetime(2017,5,1),2,"Rathaus",'Kassel',"Germany",'Frankfurt','Frankfurt',"",[]])
data_list.append([datetime.datetime(2017,5,1),1,"Elisabethkirche",'Kassel',"Germany",'Frankfurt','Frankfurt',"",[]])
data_list.append([datetime.datetime(2017,5,1),4,"Karlsaue",'Kassel',"Germany",'Frankfurt','Frankfurt',"",[]])
data_list.append([datetime.datetime(2017,5,1),5,"Orangerieschloss",'Kassel',"Germany",'Frankfurt','Frankfurt',"",[]])
data_list.append([datetime.datetime(2017,5,1),20,"Orangerieschloss Marmorbad",'Kassel',"Germany",'Frankfurt','Frankfurt',"",[]])
data_list.append([datetime.datetime(2017,5,1),54,"Schloss Wilhelmshoehe",'Kassel',"Germany",'Frankfurt','Frankfurt',"Bergpark Wilhelmshoehe",[]])
data_list.append([datetime.datetime(2017,5,1),27,"Bergpark Wilhelmshoehe",'Kassel',"Germany",'Frankfurt','Frankfurt',"Bergpark Wilhelmshoehe",[]])
#oktogon & kaskadenbauten
data_list.append([datetime.datetime(2017,5,1),38,"Bergpark Wilhelmshoehe Oktogon",'Kassel',"Germany",'Frankfurt','Frankfurt',"Bergpark Wilhelmshoehe",[]])
data_list.append([datetime.datetime(2017,5,1),16,"Bergpark Wilhelmshoehe Loewenburg",'Kassel',"Germany",'Frankfurt','Frankfurt',"Bergpark Wilhelmshoehe",[]])
data_list.append([datetime.datetime(2017,5,1),13,"Bergpark Wilhelmshoehe Steinhoefer Wasserfall",'Kassel',"Germany",'Frankfurt','Frankfurt',"Bergpark Wilhelmshoehe",[]])
data_list.append([datetime.datetime(2017,5,1),3,"Bergpark Wilhelmshoehe Teufelsbruecke",'Kassel',"Germany",'Frankfurt','Frankfurt',"Bergpark Wilhelmshoehe",[]])
data_list.append([datetime.datetime(2017,5,1),10,"Bergpark Wilhelmshoehe Aquaedukt",'Kassel',"Germany",'Frankfurt','Frankfurt',"Bergpark Wilhelmshoehe",[]])
data_list.append([datetime.datetime(2017,5,2),1,"Frankfurt Flughafen",'Frankfurt',"Germany",'Frankfurt','Geneva',"",[]])

# %%
#madrid done
data_list.append([datetime.datetime(2017, 5, 24),2,"Cuatro Torres Business Area",'Madrid',"Spain",'Geneva','Madrid',"",[]])
data_list.append([datetime.datetime(2017, 5, 25),2,"Plaza Mayor",'Salamanca',"Spain",'Madrid','Madrid',"Old City of Salamanca",[]])
data_list.append([datetime.datetime(2017, 5, 25),4,"La Clerica",'Salamanca',"Spain",'Madrid','Madrid',"Old City of Salamanca",[]])
data_list.append([datetime.datetime(2017, 5, 25),34,"University",'Salamanca',"Spain",'Madrid','Madrid',"Old City of Salamanca",[]])
data_list.append([datetime.datetime(2017, 5, 25),98,"Cathedral",'Salamanca',"Spain",'Madrid','Madrid',"Old City of Salamanca",[]])
data_list.append([datetime.datetime(2017, 5, 25),4,"Palacio de Anaya",'Salamanca',"Spain",'Madrid','Madrid',"Old City of Salamanca",[]])
data_list.append([datetime.datetime(2017, 5, 25),41,"Convento de San Esteban",'Salamanca',"Spain",'Madrid','Madrid',"Old City of Salamanca",[]])
data_list.append([datetime.datetime(2017, 5, 25),5,"Palacio de la Salina",'Salamanca',"Spain",'Madrid','Madrid',"Old City of Salamanca",[]])
data_list.append([datetime.datetime(2017, 5, 25),66,"Old Cathedral",'Salamanca',"Spain",'Madrid','Madrid',"Old City of Salamanca",[]])
data_list.append([datetime.datetime(2017, 5, 26),1,"Station Valencia del Nord",'Valencia',"Spain",'Madrid','Madrid',"",[]])
data_list.append([datetime.datetime(2017, 5, 26),26,"City Hall",'Valencia',"Spain",'Madrid','Madrid',"",[]])
data_list.append([datetime.datetime(2017, 5, 26),75,"Cathedral",'Valencia',"Spain",'Madrid','Madrid',"",[]])
data_list.append([datetime.datetime(2017, 5, 26),7,"Basilica de la Virgen de los Desamparados",'Valencia',"Spain",'Madrid','Madrid',"",[]])
data_list.append([datetime.datetime(2017, 5, 26),22,"Sant Nicolau",'Valencia',"Spain",'Madrid','Madrid',"",[]])
data_list.append([datetime.datetime(2017, 5, 26),5,"Almudin",'Valencia',"Spain",'Madrid','Madrid',"",[]])
data_list.append([datetime.datetime(2017, 5, 26),6,"Banos del Almirante",'Valencia',"Spain",'Madrid','Madrid',"",[]])
data_list.append([datetime.datetime(2017, 5, 26),55,"Palacio del Marques de Dos Aguas",'Valencia',"Spain",'Madrid','Madrid',"",[]])
data_list.append([datetime.datetime(2017, 5, 26),7,"Santo Tomas Apostol & San Felipe Neri",'Valencia',"Spain",'Madrid','Madrid',"",[]])
data_list.append([datetime.datetime(2017, 5, 26),12,"Palau de Cervello",'Valencia',"Spain",'Madrid','Madrid',"",[]])
data_list.append([datetime.datetime(2017, 5, 26),1,"Plaza de la Virgen",'Valencia',"Spain",'Madrid','Madrid',"",[]])
data_list.append([datetime.datetime(2017, 5, 26),3,"Mercado Central",'Valencia',"Spain",'Madrid','Madrid',"",[]])
data_list.append([datetime.datetime(2017, 5, 26),23,"Llotja de la Seda",'Valencia',"Spain",'Madrid','Madrid',"La Llotja de la Seda de Valencia",[]])
data_list.append([datetime.datetime(2017, 5, 26),2,"Porta de la Mar",'Valencia',"Spain",'Madrid','Madrid',"",[]])
data_list.append([datetime.datetime(2017, 5, 26),5,"Palau de les Arts Reina Sofia",'Valencia',"Spain",'Madrid','Madrid',"",[]])
data_list.append([datetime.datetime(2017, 5, 26),4,"Hemisferic",'Valencia',"Spain",'Madrid','Madrid',"",[]])
data_list.append([datetime.datetime(2017, 5, 26),9,"Museum of Science",'Valencia',"Spain",'Madrid','Madrid',"",[]])
data_list.append([datetime.datetime(2017, 5, 26),2,"Agora",'Valencia',"Spain",'Madrid','Madrid',"",[]])
data_list.append([datetime.datetime(2017, 5, 26),2,"Oceanografic",'Valencia',"Spain",'Madrid','Madrid',"",[]])
data_list.append([datetime.datetime(2017, 5, 26),2,"Church of Our Lady of Monteolivete",'Valencia',"Spain",'Madrid','Madrid',"",[]])
data_list.append([datetime.datetime(2017, 5, 27),1,"Plaza de San Domingo",'Leon',"Spain",'Madrid','Madrid',"Routes of Santiago de Compostela",[]])
data_list.append([datetime.datetime(2017, 5, 27),2,"San Marcelo",'Leon',"Spain",'Madrid','Madrid',"Routes of Santiago de Compostela",[]])
data_list.append([datetime.datetime(2017, 5, 27),2,"Casa Botines",'Leon',"Spain",'Madrid','Madrid',"Routes of Santiago de Compostela",[]])
data_list.append([datetime.datetime(2017, 5, 27),76,"Cathedral",'Leon',"Spain",'Madrid','Madrid',"Routes of Santiago de Compostela",[]])
data_list.append([datetime.datetime(2017, 5, 27),26,"Basilica de San Isidro",'Leon',"Spain",'Madrid','Madrid',"Routes of Santiago de Compostela",[]])
data_list.append([datetime.datetime(2017, 5, 27),2,"Plaza Mayor",'Leon',"Spain",'Madrid','Madrid',"Routes of Santiago de Compostela",[]])
data_list.append([datetime.datetime(2017, 5, 27),2,"San Martin",'Leon',"Spain",'Madrid','Madrid',"Routes of Santiago de Compostela",[]])
data_list.append([datetime.datetime(2017, 5, 27),1,"Plaza Guzman",'Leon',"Spain",'Madrid','Madrid',"Routes of Santiago de Compostela",[]])
data_list.append([datetime.datetime(2017, 5, 27),3,"La Foncalada",'Oviedo',"Spain",'Madrid','Madrid',"Monuments of Oviedo and the Kingdom of the Asturias",[]])
data_list.append([datetime.datetime(2017, 5, 27),1,"Balesquida Chapel",'Oviedo',"Spain",'Madrid','Madrid',"",[]])
data_list.append([datetime.datetime(2017, 5, 27),73,"Cathedral",'Oviedo',"Spain",'Madrid','Madrid',"Routes of Santiago de Compostela",[]])
data_list.append([datetime.datetime(2017, 5, 27),18,"Cathedral Camara Santa",'Oviedo',"Spain",'Madrid','Madrid',"Monuments of Oviedo and the Kingdom of the Asturias",[]])
data_list.append([datetime.datetime(2017, 5, 27),3,"San Julian de los Prados",'Oviedo',"Spain",'Madrid','Madrid',"Monuments of Oviedo and the Kingdom of the Asturias",[]])
data_list.append([datetime.datetime(2017, 5, 27),3,"Jardin de los Reyes",'Oviedo',"Spain",'Madrid','Madrid',"",[]])
data_list.append([datetime.datetime(2017, 5, 28),9,"Convento de San Jose",'Avila',"Spain",'Madrid','Geneva',"Old Town of Avila with its Extra-Muros Churches",[]])
data_list.append([datetime.datetime(2017, 5, 28),3,"San Pedro Apostol",'Avila',"Spain",'Madrid','Geneva',"Old Town of Avila with its Extra-Muros Churches",[]])
data_list.append([datetime.datetime(2017, 5, 28),5,"Town Walls",'Avila',"Spain",'Madrid','Geneva',"Old Town of Avila with its Extra-Muros Churches",[]])
data_list.append([datetime.datetime(2017, 5, 28),69,"Cathedral",'Avila',"Spain",'Madrid','Geneva',"Old Town of Avila with its Extra-Muros Churches",[]])
data_list.append([datetime.datetime(2017, 5, 28),8,"Santo Tome",'Avila',"Spain",'Madrid','Geneva',"",[]])
data_list.append([datetime.datetime(2017, 5, 28),3,"San Pedro Apostol",'Avila',"Spain",'Madrid','Geneva',"Old Town of Avila with its Extra-Muros Churches",[]])
data_list.append([datetime.datetime(2017, 5, 28),25,"San Vicente",'Avila',"Spain",'Madrid','Geneva',"Old Town of Avila with its Extra-Muros Churches",[]])
data_list.append([datetime.datetime(2017, 5, 28),2,"Capilla de las Nieves",'Avila',"Spain",'Madrid','Geneva',"Old Town of Avila with its Extra-Muros Churches",[]])
data_list.append([datetime.datetime(2017, 5, 28),3,"San Juan Bautista",'Avila',"Spain",'Madrid','Geneva',"Old Town of Avila with its Extra-Muros Churches",[]])
data_list.append([datetime.datetime(2017, 5, 28),25,"Real Monasterio de Santo Tomas",'Avila',"Spain",'Madrid','Geneva',"Old Town of Avila with its Extra-Muros Churches",[]])
data_list.append([datetime.datetime(2017, 5, 28),1,"Plaza del Mercado Chico",'Avila',"Spain",'Madrid','Geneva',"Old Town of Avila with its Extra-Muros Churches",[]])

# %%
#athens done
data_list.append([datetime.datetime(2017, 6, 3),2,"Kapnikarea Church",'Athens',"Greece",'Geneva','Athens',"",['Riju','Amin']])
data_list.append([datetime.datetime(2017, 6, 3),12,"Cathedral",'Athens',"Greece",'Geneva','Athens',"",['Riju','Amin']])
data_list.append([datetime.datetime(2017, 6, 3),3,"Agios Eleftherios Church",'Athens',"Greece",'Geneva','Athens',"",['Riju','Amin']])
data_list.append([datetime.datetime(2017, 6, 3),2,"Lysikrates Monument",'Athens',"Greece",'Geneva','Athens',"",['Riju','Amin']])
data_list.append([datetime.datetime(2017, 6, 3),14,"Akropolis Museum",'Athens',"Greece",'Geneva','Athens',"",["MaryAnn",'Riju','Amin']])
data_list.append([datetime.datetime(2017, 6, 3),15,"Akropolis",'Athens',"Greece",'Geneva','Athens',"Athens Akropolis",["MaryAnn",'Riju','Amin']])
data_list.append([datetime.datetime(2017, 6, 3),6,"Odeon of Herod",'Athens',"Greece",'Geneva','Athens',"",["MaryAnn",'Riju','Amin']])
data_list.append([datetime.datetime(2017, 6, 3),1,"Roman Agora",'Athens',"Greece",'Geneva','Athens',"",["MaryAnn",'Riju','Amin']])
data_list.append([datetime.datetime(2017, 6, 3),2,"Hadrian's Library",'Athens',"Greece",'Geneva','Athens',"",["MaryAnn",'Riju','Amin']])
data_list.append([datetime.datetime(2017, 6, 3),2,"Tzistarakis Mosque",'Athens',"Greece",'Geneva','Athens',"",["MaryAnn",'Riju','Amin']])
data_list.append([datetime.datetime(2017, 6, 4),54,"Akropolis",'Athens',"Greece",'Geneva','Athens',"Athens Akropolis",["MaryAnn",'Riju','Amin']])
data_list.append([datetime.datetime(2017, 6, 4),2,"Odeon of Herod",'Athens',"Greece",'Athens','Athens',"",["MaryAnn",'Riju','Amin']])
data_list.append([datetime.datetime(2017, 6, 4),8,"Roman Agora",'Athens',"Greece",'Athens','Athens',"",["MaryAnn",'Riju','Amin']])
data_list.append([datetime.datetime(2017, 6, 4),3,"Panathinaiko Stadium",'Athens',"Greece",'Athens','Athens',"",["MaryAnn",'Riju','Amin']])
data_list.append([datetime.datetime(2017, 6, 4),2,"Parliament",'Athens',"Greece",'Athens','Athens',"",["MaryAnn",'Riju','Amin']])
data_list.append([datetime.datetime(2017, 6, 4),8,"Temple of Olympic Zeus",'Athens',"Greece",'Athens','Athens',"",["MaryAnn",'Riju','Amin']])
data_list.append([datetime.datetime(2017, 6, 4),3,"Cathedral",'Athens',"Greece",'Athens','Athens',"",['Riju','Amin']])
data_list.append([datetime.datetime(2017, 6, 4),10,"Hadrian's Library",'Athens',"Greece",'Athens','Athens',"",["MaryAnn",'Riju','Amin']])
data_list.append([datetime.datetime(2017, 6, 4),2,"Tzistarakis Mosque",'Athens',"Greece",'Athens','Athens',"",["MaryAnn",'Riju','Amin']])
data_list.append([datetime.datetime(2017, 6, 4),9,"Agora",'Athens',"Greece",'Athens','Athens',"",["MaryAnn",'Riju','Amin']])
data_list.append([datetime.datetime(2017, 6, 4),11,"Church of Holy Apostles",'Athens',"Greece",'Athens','Athens',"",["MaryAnn",'Riju','Amin']])
data_list.append([datetime.datetime(2017, 6, 4),2,"Hadrian's Gate",'Athens',"Greece",'Athens','Athens',"",["MaryAnn",'Riju','Amin']])
data_list.append([datetime.datetime(2017, 6, 4),55,"National Museum of Archaeology",'Athens',"Greece",'Athens','Athens',"",['Riju','Amin']])
data_list.append([datetime.datetime(2017, 6, 4),4,"Academy",'Athens',"Greece",'Athens','Athens',"",['Riju','Amin']])
data_list.append([datetime.datetime(2017, 6, 5),1,"Tzistarakis Mosque",'Athens',"Greece",'Athens','Athens',"",['Riju','Amin']])
data_list.append([datetime.datetime(2017, 6, 5),36,"Excavations of Delphi",'Delphi',"Greece",'Athens','Athens',"Delphi",['Riju','Amin']])
data_list.append([datetime.datetime(2017, 6, 5),35,"Museum of Delphi",'Delphi',"Greece",'Athens','Athens',"Delphi",['Riju','Amin']])
data_list.append([datetime.datetime(2017, 6, 6),1,"Tzistarakis Mosque",'Athens',"Greece",'Athens','Geneva',"",['Riju','Amin']])

# %%
#usa done
data_list.append([datetime.datetime(2017, 6, 10),22,"Shoshone Falls",'Twin Falls',"USA",'Twin Falls','Twin Falls',"",['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2017, 6, 10),8,"Snake River Canyon",'Twin Falls',"USA",'Twin Falls','Twin Falls',"",['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2017, 6, 10),24,"Bruneau Dunes",'Bruneau',"USA",'Twin Falls','Twin Falls',"",['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2017, 6, 10),5,"Snake River Canyon",'Bliss',"USA",'Twin Falls','Twin Falls',"",['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2017, 6, 10),4,"Thousand Springs",'Salmon Springs',"USA",'Twin Falls','Twin Falls',"",['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2017, 6, 10),4,"Perrin Memorial Bridge",'Twin Falls',"USA",'Twin Falls','Twin Falls',"",['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2017, 6, 10),2,"Pillar Falls",'Twin Falls',"USA",'Twin Falls','Twin Falls',"",['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2017, 6, 11),106,"Craters of the Moon",'Arco',"USA",'Twin Falls','Island Park',"",['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2017, 6, 12),12,"Firehole Canyon",'Yellowstone National Park',"USA",'Island Park','Island Park',"Yellowstone National Park",['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2017, 6, 12),16,"Fountain Paint Pots",'Yellowstone National Park',"USA",'Island Park','Island Park',"Yellowstone National Park",['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2017, 6, 12),7,"Lower Geyser Basin",'Yellowstone National Park',"USA",'Island Park','Island Park',"Yellowstone National Park",['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2017, 6, 12),1,"Upper Geyser Basin",'Yellowstone National Park',"USA",'Island Park','Island Park',"Yellowstone National Park",['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2017, 6, 12),6,"Old Faithful",'Yellowstone National Park',"USA",'Island Park','Island Park',"Yellowstone National Park",['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2017, 6, 13),18,"Yellowstone National Park",'Yellowstone National Park',"USA",'Island Park','Island Park',"Yellowstone National Park",['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2017, 6, 13),2,"Gibbon Falls",'Yellowstone National Park',"USA",'Island Park','Island Park',"Yellowstone National Park",['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2017, 6, 13),57,"Norris Geyser Basin",'Yellowstone National Park',"USA",'Island Park','Island Park',"Yellowstone National Park",['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2017, 6, 13),1,"Sheepeater Cliff",'Yellowstone National Park',"USA",'Island Park','Island Park',"Yellowstone National Park",['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2017, 6, 13),2,"Golden Gate Canyon",'Yellowstone National Park',"USA",'Island Park','Island Park',"Yellowstone National Park",['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2017, 6, 13),38,"Mammoth Hot Springs",'Yellowstone National Park',"USA",'Island Park','Island Park',"Yellowstone National Park",['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2017, 6, 14),9,"Yellowstone National Park",'Yellowstone National Park',"USA",'Island Park','Island Park',"Yellowstone National Park",['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2017, 6, 14),1,"Virginia Cascade",'Yellowstone National Park',"USA",'Island Park','Island Park',"Yellowstone National Park",['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2017, 6, 14),44,"Yellowstone Canyon",'Yellowstone National Park',"USA",'Island Park','Island Park',"Yellowstone National Park",['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2017, 6, 14),11,"Yellowstone Canyon Lower Falls",'Yellowstone National Park',"USA",'Island Park','Island Park',"Yellowstone National Park",['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2017, 6, 14),7,"Yellowstone Canyon Upper Falls",'Yellowstone National Park',"USA",'Island Park','Island Park',"Yellowstone National Park",['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2017, 6, 14),15,"Yellowstone River",'Yellowstone National Park',"USA",'Island Park','Island Park',"Yellowstone National Park",['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2017, 6, 14),2,"Cascade Falls",'Yellowstone National Park',"USA",'Island Park','Island Park',"Yellowstone National Park",['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2017, 6, 14),3,"Tower Falls",'Yellowstone National Park',"USA",'Island Park','Island Park',"Yellowstone National Park",['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2017, 6, 14),2,"Petrified Tree",'Yellowstone National Park',"USA",'Island Park','Island Park',"Yellowstone National Park",['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2017, 6, 15),9,"Yellowstone River",'Yellowstone National Park',"USA",'Island Park','Island Park',"Yellowstone National Park",['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2017, 6, 15),24,"Mud Volcano",'Yellowstone National Park',"USA",'Island Park','Island Park',"Yellowstone National Park",['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2017, 6, 15),16,"Lake Yellowstone",'Yellowstone National Park',"USA",'Island Park','Island Park',"Yellowstone National Park",['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2017, 6, 15),3,"Natural Bridge",'Yellowstone National Park',"USA",'Island Park','Island Park',"Yellowstone National Park",['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2017, 6, 15),28,"West Thumb Geyser Basin",'Yellowstone National Park',"USA",'Island Park','Island Park',"Yellowstone National Park",['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2017, 6, 15),3,"Kepler Cascades",'Yellowstone National Park',"USA",'Island Park','Island Park',"Yellowstone National Park",['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2017, 6, 15),25,"Upper Geyser Basin",'Yellowstone National Park',"USA",'Island Park','Island Park',"Yellowstone National Park",['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2017, 6, 15),3,"Old Faithful",'Yellowstone National Park',"USA",'Island Park','Island Park',"Yellowstone National Park",['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2017, 6, 15),14,"Yellowstone National Park",'Yellowstone National Park',"USA",'Island Park','Island Park',"Yellowstone National Park",['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2017, 6, 16),7,"Upper Mesa Falls",'Ashton',"USA",'Island Park','Island Park',"",['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2017, 6, 16),6,"Henry's Fork",'Ashton',"USA",'Island Park','Island Park',"",['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2017, 6, 16),2,"Upper Mesa Falls",'Ashton',"USA",'Island Park','Island Park',"",['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2017, 6, 16),7,"Warm River",'Ashton',"USA",'Island Park','Island Park',"",['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2017, 6, 17),11,"Grand Teton National Park",'Grand Teton National Park',"USA",'Island Park','Jackson',"",['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2017, 6, 17),3,"Phelps Lake",'Grand Teton National Park',"USA",'Island Park','Jackson',"",['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2017, 6, 18),26,"Grand Teton Range",'Grand Teton National Park',"USA",'Jackson','Jackson',"",['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2017, 6, 18),5,"Leigh Lake",'Grand Teton National Park',"USA",'Jackson','Jackson',"",['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2017, 6, 18),2,"String Lake",'Grand Teton National Park',"USA",'Jackson','Jackson',"",['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2017, 6, 18),8,"Grand Teton National Park",'Grand Teton National Park',"USA",'Jackson','Jackson',"",['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2017, 6, 18),14,"Jenny Lake",'Grand Teton National Park',"USA",'Jackson','Jackson',"",['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2017, 6, 18),5,"Hidden Falls",'Grand Teton National Park',"USA",'Jackson','Jackson',"",['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2017, 6, 18),6,"Cascade Creek",'Grand Teton National Park',"USA",'Jackson','Jackson',"",['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2017, 6, 18),2,"Chapel of Transfiguration",'Grand Teton National Park',"USA",'Jackson','Jackson',"",['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2017, 6, 18),1,"Deer Monument",'Grand Teton National Park',"USA",'Jackson','Jackson',"",['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2017, 6, 18),2,"Elk Antler Arches",'Jackson',"USA",'Jackson','Jackson',"",['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2017, 6, 19),33,"Grand Teton Range",'Grand Teton National Park',"USA",'Jackson','Jackson',"",['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2017, 6, 19),6,"Snake River",'Grand Teton National Park',"USA",'Jackson','Jackson',"",['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2017, 6, 19),15,"Jackson Lake",'Grand Teton National Park',"USA",'Jackson','Jackson',"",['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2017, 6, 19),3,"Jackson Lake Dam",'Grand Teton National Park',"USA",'Jackson','Jackson',"",['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2017, 6, 19),5,"Grand Teton National Park",'Grand Teton National Park',"USA",'Jackson','Jackson',"",['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2017, 6, 20),7,"National Museum of Wildlife Art",'Jackson',"USA",'Jackson','Jackson',"",['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2017, 6, 20),11,"Periodic Spring",'Afton',"USA",'Jackson','Salt Lake City',"",['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2017, 6, 20),1,"Elk Antler Arch",'Afton',"USA",'Jackson','Salt Lake City',"",['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2017, 6, 21),5,"City Hall",'Salt Lake City',"USA",'Salt Lake City','Salt Lake City',"",['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2017, 6, 21),7,"City Library",'Salt Lake City',"USA",'Salt Lake City','Salt Lake City',"",['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2017, 6, 21),14,"Cathedral St Madelaine",'Salt Lake City',"USA",'Salt Lake City','Salt Lake City',"",['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2017, 6, 21),30,"Utah State Capitol",'Salt Lake City',"USA",'Salt Lake City','Salt Lake City',"",['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2017, 6, 21),1,"Eagle Gate",'Salt Lake City',"USA",'Salt Lake City','Salt Lake City',"",['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2017, 6, 21),11,"Beehive House",'Salt Lake City',"USA",'Salt Lake City','Salt Lake City',"",['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2017, 6, 21),4,"Joseph Smith Memorial Building",'Salt Lake City',"USA",'Salt Lake City','Salt Lake City',"",['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2017, 6, 21),4,"Salt Lake Temple",'Salt Lake City',"USA",'Salt Lake City','Salt Lake City',"",['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2017, 6, 21),2,"Assembly Hall",'Salt Lake City',"USA",'Salt Lake City','Salt Lake City',"",['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2017, 6, 21),1,"Salt Lake Tabernacle",'Salt Lake City',"USA",'Salt Lake City','Salt Lake City',"",['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2017, 6, 21),11,"Latter-Day Saints Church Office Building Roof Terrace",'Salt Lake City',"USA",'Salt Lake City','Salt Lake City',"",['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2017, 6, 22),22,"Great Salt Lake",'Magna',"USA",'Salt Lake City','Flight SLC-CDG',"",['Heidrun','Artur','Hannsjoerg']])
data_list.append([datetime.datetime(2017, 6, 22),56,"Hogle Zoo",'Salt Lake City',"USA",'Salt Lake City','Flight SLC-CDG',"",['Heidrun','Artur','Hannsjoerg']])

# %%
#venice done
data_list.append([datetime.datetime(2017, 7, 6),2,"San Giorgio Maggiore",'Venice',"Italy",'Venice','Venice',"Venice",[]])
data_list.append([datetime.datetime(2017, 7, 6),1,"Il Redentore",'Venice',"Italy",'Venice','Venice',"Venice",[]])
data_list.append([datetime.datetime(2017, 7, 6),6,"Santa Maria della Salute",'Venice',"Italy",'Venice','Venice',"Venice",[]])
data_list.append([datetime.datetime(2017, 7, 6),1,"Palazzo Ducale",'Venice',"Italy",'Venice','Venice',"Venice",[]])
data_list.append([datetime.datetime(2017, 7, 6),1,"Peggy Guggenheim",'Venice',"Italy",'Venice','Venice',"Venice",[]])
data_list.append([datetime.datetime(2017, 7, 6),2,"Galleria dell'Academia",'Venice',"Italy",'Venice','Venice',"Venice",[]])
data_list.append([datetime.datetime(2017, 7, 6),1,"Palazzo Grassi",'Venice',"Italy",'Venice','Venice',"Venice",[]])
data_list.append([datetime.datetime(2017, 7, 6),1,"San Toma",'Venice',"Italy",'Venice','Venice',"Venice",[]])
data_list.append([datetime.datetime(2017, 7, 6),2,"San Gregorio",'Venice',"Italy",'Venice','Venice',"Venice",[]])
data_list.append([datetime.datetime(2017, 7, 6),3,"Casa di Carlo Goldoni",'Venice',"Italy",'Venice','Venice',"Venice",[]])
data_list.append([datetime.datetime(2017, 7, 7),7,"Palazzo del Casino",'Venice',"Italy",'Venice','Venice',"Venice",[]])
data_list.append([datetime.datetime(2017, 7, 8),1,"San Gregorio",'Venice',"Italy",'Venice','Venice',"Venice",[]])
data_list.append([datetime.datetime(2017, 7, 8),2,"Palazzo Ducale",'Venice',"Italy",'Venice','Venice',"Venice",[]])
data_list.append([datetime.datetime(2017, 7, 8),23,"Santa Maria della Salute",'Venice',"Italy",'Venice','Venice',"Venice",['Indara']])
data_list.append([datetime.datetime(2017, 7, 8),11,"Peggy Guggenheim",'Venice',"Italy",'Venice','Venice',"Venice",['Indara','Riju']])
data_list.append([datetime.datetime(2017, 7, 8),1,"Santa Maria della Visitazione",'Venice',"Italy",'Venice','Venice',"Venice",[]])
data_list.append([datetime.datetime(2017, 7, 8),3,"San Moise",'Venice',"Italy",'Venice','Venice',"Venice",['Indara']])
data_list.append([datetime.datetime(2017, 7, 8),13,"Basilica di San Marco",'Venice',"Italy",'Venice','Venice',"Venice",['Indara']])
data_list.append([datetime.datetime(2017, 7, 8),43,"Palazzo Reale",'Venice',"Italy",'Venice','Venice',"Venice",['Indara','Riju','Reyer']])
data_list.append([datetime.datetime(2017, 7, 8),5,"Palazzo Correr",'Venice',"Italy",'Venice','Venice',"Venice",['Indara','Riju','Reyer']])
data_list.append([datetime.datetime(2017, 7, 8),17,"Biblioteca Nazionale Marciana",'Venice',"Italy",'Venice','Venice',"Venice",['Indara','Riju','Reyer']])
data_list.append([datetime.datetime(2017, 7, 8),82,"Palazzo Ducale",'Venice',"Italy",'Venice','Venice',"Venice",['Indara','Riju','Reyer']])
data_list.append([datetime.datetime(2017, 7, 9),1,"San Gregorio",'Venice',"Italy",'Venice','Venice',"Venice",[]])
data_list.append([datetime.datetime(2017, 7, 9),6,"Palazzo Ducale",'Venice',"Italy",'Venice','Venice',"Venice",[]])
data_list.append([datetime.datetime(2017, 7, 9),6,"Santa Maria della Salute",'Venice',"Italy",'Venice','Venice',"Venice",[]])
data_list.append([datetime.datetime(2017, 7, 9),2,"Il Redentore",'Venice',"Italy",'Venice','Venice',"Venice",[]])
data_list.append([datetime.datetime(2017, 7, 9),3,"Santa Maria del Rosario",'Venice',"Italy",'Venice','Venice',"Venice",[]])
data_list.append([datetime.datetime(2017, 7, 9),75,"Basilica della Santa Casa",'Loreto',"Italy",'Venice','Venice',"",[]])
data_list.append([datetime.datetime(2017, 7, 9),2,"Porta Pia",'Ancona',"Italy",'Venice','Venice',"",[]])
data_list.append([datetime.datetime(2017, 7, 9),3,"San Francesco delle Scale",'Ancona',"Italy",'Venice','Venice',"",[]])
data_list.append([datetime.datetime(2017, 7, 9),23,"Duomo",'Ancona',"Italy",'Venice','Venice',"",[]])
data_list.append([datetime.datetime(2017, 7, 9),32,"Palazzo Ferretti",'Ancona',"Italy",'Venice','Venice',"",[]])
data_list.append([datetime.datetime(2017, 7, 9),2,"San Simeone Piccolo",'Venice',"Italy",'Venice','Venice',"Venice",[]])
data_list.append([datetime.datetime(2017, 7, 9),1,"Ca d'Oro",'Venice',"Italy",'Venice','Venice',"Venice",[]])
data_list.append([datetime.datetime(2017, 7, 9),1,"Ponte di Rialto",'Venice',"Italy",'Venice','Venice',"Venice",[]])
data_list.append([datetime.datetime(2017, 7, 9),1,"Palazzo Grassi",'Venice',"Italy",'Venice','Venice',"Venice",[]])
data_list.append([datetime.datetime(2017, 7, 10),16,"I Gesuiti",'Venice',"Italy",'Venice','Venice',"Venice",[]])
data_list.append([datetime.datetime(2017, 7, 10),7,"San Pietro Martire",'Venice',"Italy",'Venice','Venice',"Venice",[]])
data_list.append([datetime.datetime(2017, 7, 10),22,"Santa Maria e San Donato",'Venice',"Italy",'Venice','Venice',"Venice",[]])
data_list.append([datetime.datetime(2017, 7, 10),2,"San Giovanni Crisostomo",'Venice',"Italy",'Venice','Venice',"Venice",[]])
data_list.append([datetime.datetime(2017, 7, 10),3,"San Silvestro",'Venice',"Italy",'Venice','Venice',"Venice",[]])
data_list.append([datetime.datetime(2017, 7, 10),36,"Santa Maria Gloriosa dei Frari",'Venice',"Italy",'Venice','Venice',"Venice",[]])
data_list.append([datetime.datetime(2017, 7, 10),49,"Ca'Rezzonico",'Venice',"Italy",'Venice','Venice',"Venice",[]])
data_list.append([datetime.datetime(2017, 7, 10),1,"Palazzo Grassi",'Venice',"Italy",'Venice','Venice',"Venice",[]])
data_list.append([datetime.datetime(2017, 7, 10),30,"Basilica di San Marco",'Venice',"Italy",'Venice','Venice',"Venice",[]])
data_list.append([datetime.datetime(2017, 7, 10),1,"Palazzo Ducale",'Venice',"Italy",'Venice','Venice',"Venice",[]])
data_list.append([datetime.datetime(2017, 7, 10),3,"Palazzo del Cinema",'Venice',"Italy",'Venice','Venice',"Venice",[]])
data_list.append([datetime.datetime(2017, 7, 10),4,"Palazzo del Casino",'Venice',"Italy",'Venice','Venice',"Venice",[]])
data_list.append([datetime.datetime(2017, 7, 12),3,"Piazza Castello",'Vicenza',"Italy",'Venice','Venice',"City of Vicenza and the Palladian Villas of the Veneto",[]])
data_list.append([datetime.datetime(2017, 7, 12),35,"Duomo",'Vicenza',"Italy",'Venice','Venice',"City of Vicenza and the Palladian Villas of the Veneto",[]])
data_list.append([datetime.datetime(2017, 7, 12),13,"Villa Rotonda",'Vicenza',"Italy",'Venice','Venice',"City of Vicenza and the Palladian Villas of the Veneto",[]])
data_list.append([datetime.datetime(2017, 7, 12),34,"Villa Valmarana ai Nanai",'Vicenza',"Italy",'Venice','Venice',"",[]])
data_list.append([datetime.datetime(2017, 7, 12),11,"Basilica di Santa Maria di Monte Berico",'Vicenza',"Italy",'Venice','Venice',"",[]])
data_list.append([datetime.datetime(2017, 7, 12),7,"Basilica Palladiana",'Vicenza',"Italy",'Venice','Venice',"City of Vicenza and the Palladian Villas of the Veneto",[]])
data_list.append([datetime.datetime(2017, 7, 12),4,"Santa Maria dei Servi",'Vicenza',"Italy",'Venice','Venice',"City of Vicenza and the Palladian Villas of the Veneto",[]])
data_list.append([datetime.datetime(2017, 7, 12),3,"Piazza dei Signori",'Vicenza',"Italy",'Venice','Venice',"City of Vicenza and the Palladian Villas of the Veneto",[]])
data_list.append([datetime.datetime(2017, 7, 12),3,"Santa Gaetano",'Vicenza',"Italy",'Venice','Venice',"City of Vicenza and the Palladian Villas of the Veneto",[]])
data_list.append([datetime.datetime(2017, 7, 12),31,"Santa Corona",'Vicenza',"Italy",'Venice','Venice',"City of Vicenza and the Palladian Villas of the Veneto",[]])
data_list.append([datetime.datetime(2017, 7, 12),21,"Teatro Olimpicio",'Vicenza',"Italy",'Venice','Venice',"City of Vicenza and the Palladian Villas of the Veneto",[]])
data_list.append([datetime.datetime(2017, 7, 12),14,"Palazzo Barbaran da Porto",'Vicenza',"Italy",'Venice','Venice',"City of Vicenza and the Palladian Villas of the Veneto",[]])
data_list.append([datetime.datetime(2017, 7, 12),59,"Villa Pisani",'Stra',"Italy",'Venice','Venice',"",[]])
data_list.append([datetime.datetime(2017, 7, 13),23,"Palazzo Municipale",'Ferrara',"Italy",'Venice','Trieste',"Ferrara",[]])
data_list.append([datetime.datetime(2017, 7, 13),19,"Cathedral",'Ferrara',"Italy",'Venice','Trieste',"Ferrara",[]])
data_list.append([datetime.datetime(2017, 7, 13),7,"Basilica di San Francesco",'Ferrara',"Italy",'Venice','Trieste',"Ferrara",[]])
data_list.append([datetime.datetime(2017, 7, 13),3,"San Girolamo",'Ferrara',"Italy",'Venice','Trieste',"Ferrara",[]])
data_list.append([datetime.datetime(2017, 7, 13),19,"Palazzina Marfisa d’Este",'Ferrara',"Italy",'Venice','Trieste',"Ferrara",[]])
data_list.append([datetime.datetime(2017, 7, 13),15,"Basilica Santa Maria in Vado",'Ferrara',"Italy",'Venice','Trieste',"Ferrara",[]])
data_list.append([datetime.datetime(2017, 7, 13),23,"Palazzo Costabili",'Ferrara',"Italy",'Venice','Trieste',"Ferrara",[]])
data_list.append([datetime.datetime(2017, 7, 13),21,"Palazzo Schifanoia",'Ferrara',"Italy",'Venice','Trieste',"Ferrara",[]])
data_list.append([datetime.datetime(2017, 7, 13),4,"Biblioteca Ariostea",'Ferrara',"Italy",'Venice','Trieste',"Ferrara",[]])
data_list.append([datetime.datetime(2017, 7, 13),34,"Castello Estense",'Ferrara',"Italy",'Venice','Trieste',"Ferrara",[]])
data_list.append([datetime.datetime(2017, 7, 13),2,"Basilica di Sant'Antonio",'Padua',"Italy",'Venice','Trieste',"Padua's fourteenth-century fresco cycles",[]])
data_list.append([datetime.datetime(2017, 7, 13),12,"Basilica di Santa Giustina",'Padua',"Italy",'Venice','Trieste',"",[]])
data_list.append([datetime.datetime(2017, 7, 13),25,"Orto Botanico",'Padua',"Italy",'Venice','Trieste',"Orto Botanico",[]])
data_list.append([datetime.datetime(2017, 7, 13),34,"Cappella degli Scrovegni",'Padua',"Italy",'Venice','Trieste',"Padua's fourteenth-century fresco cycles",[]])
data_list.append([datetime.datetime(2017, 7, 14),83,"Skocjan Caves",'Divaca',"Slovenia",'Trieste','Trieste',"Skocjan Caves",['Reyer']])
data_list.append([datetime.datetime(2017, 7, 14),83,"Euphrasien Basilica",'Porec',"Croatia",'Trieste','Trieste',"Euphrasien Basilica",['Reyer']])
data_list.append([datetime.datetime(2017, 7, 14),1,"Church of Our Lady of Angels",'Porec',"Croatia",'Trieste','Trieste',"",['Reyer']])
data_list.append([datetime.datetime(2017, 7, 14),2,"Piazza delle Borsa",'Trieste',"Italy",'Trieste','Trieste',"",['Reyer']])
data_list.append([datetime.datetime(2017, 7, 14),6,"Piazza Unita d'Italia",'Trieste',"Italy",'Trieste','Trieste',"",['Reyer']])
data_list.append([datetime.datetime(2017, 7, 14),2,"Canal Grande",'Trieste',"Italy",'Trieste','Trieste',"",['Reyer']])
data_list.append([datetime.datetime(2017, 7, 15),40,"Basilica",'Aquileia',"Italy",'Trieste','Trieste',"Archaeological Area and the Patriarchal Basilica of Aquileia",['Reyer']])
data_list.append([datetime.datetime(2017, 7, 15),2,"Forum Romanum",'Aquileia',"Italy",'Trieste','Trieste',"Archaeological Area and the Patriarchal Basilica of Aquileia",['Reyer']])
data_list.append([datetime.datetime(2017, 7, 15),9,"Duomo",'Cividale del Friuli',"Italy",'Trieste','Trieste',"Longobards in Italy. Places of the Power",['Reyer']])
data_list.append([datetime.datetime(2017, 7, 15),4,"Museo Cristiano",'Cividale del Friuli',"Italy",'Trieste','Trieste',"Longobards in Italy. Places of the Power",['Reyer']])
data_list.append([datetime.datetime(2017, 7, 15),24,"Santa Maria in Valle & Tempietto Langobardo",'Cividale del Friuli',"Italy",'Trieste','Trieste',"Longobards in Italy. Places of the Power",['Reyer']])
data_list.append([datetime.datetime(2017, 7, 15),1,"Devil's Bridge",'Cividale del Friuli',"Italy",'Trieste','Trieste',"",['Reyer']])
data_list.append([datetime.datetime(2017, 7, 15),11,"Archaeological Museum",'Cividale del Friuli',"Italy",'Trieste','Trieste',"",['Reyer']])
data_list.append([datetime.datetime(2017, 7, 15),39,"Miramare Castle",'Trieste',"Italy",'Trieste','Trieste',"",['Reyer']])
data_list.append([datetime.datetime(2017, 7, 16),114,"Grotta Gigante",'Sgonico',"Italy",'Trieste','Geneva',"",['Reyer']])
data_list.append([datetime.datetime(2017, 7, 16),4,"Castello di San Giusto",'Trieste',"Italy",'Trieste','Geneva',"",['Reyer']])
data_list.append([datetime.datetime(2017, 7, 16),15,"Cathedral",'Trieste',"Italy",'Trieste','Geneva',"",['Reyer']])

# %%
#oslo
data_list.append([datetime.datetime(2017, 7, 21),10,"Dom",'Oslo',"Norway",'Geneva','Oslo',"",[]])
data_list.append([datetime.datetime(2017, 7, 21),4,"Storting",'Oslo',"Norway",'Geneva','Oslo',"",[]])
data_list.append([datetime.datetime(2017, 7, 21),1,"Royal Palace",'Oslo',"Norway",'Geneva','Oslo',"",[]])
data_list.append([datetime.datetime(2017, 7, 22),3,"Royal Palace",'Oslo',"Norway",'Oslo','Oslo',"",[]])
data_list.append([datetime.datetime(2017, 7, 22),30,"City Hall",'Oslo',"Norway",'Oslo','Oslo',"",[]])
data_list.append([datetime.datetime(2017, 7, 22),63,"Akershus Fortress",'Oslo',"Norway",'Oslo','Oslo',"",[]])
data_list.append([datetime.datetime(2017, 7, 22),4,"She Lies",'Oslo',"Norway",'Oslo','Oslo',"",[]])
data_list.append([datetime.datetime(2017, 7, 22),7,"Opera",'Oslo',"Norway",'Oslo','Oslo',"",[]])
data_list.append([datetime.datetime(2017, 7, 22),12,"Dom",'Oslo',"Norway",'Oslo','Oslo',"",[]])
data_list.append([datetime.datetime(2017, 7, 22),1,"Storting",'Oslo',"Norway",'Oslo','Oslo',"",[]])
data_list.append([datetime.datetime(2017, 7, 22),34,"National Gallery",'Oslo',"Norway",'Oslo','Oslo',"",[]])
data_list.append([datetime.datetime(2017, 7, 22),4,"Royal Palace Park",'Oslo',"Norway",'Oslo','Oslo',"",[]])
data_list.append([datetime.datetime(2017, 7, 22),34,"Vigeland Park",'Oslo',"Norway",'Oslo','Oslo',"",[]])
data_list.append([datetime.datetime(2017, 7, 23),1,"Royal Palace",'Oslo',"Norway",'Oslo','Geneva',"",[]])
data_list.append([datetime.datetime(2017, 7, 23),16,"Oskarshall",'Oslo',"Norway",'Oslo','Geneva',"",[]])
data_list.append([datetime.datetime(2017, 7, 23),20,"Viking Ships Museum",'Oslo',"Norway",'Oslo','Geneva',"",[]])
data_list.append([datetime.datetime(2017, 7, 23),14,"Fram Museum",'Oslo',"Norway",'Oslo','Geneva',"",[]])
data_list.append([datetime.datetime(2017, 7, 23),5,"Kon-Tiki Museum",'Oslo',"Norway",'Oslo','Geneva',"",[]])
data_list.append([datetime.datetime(2017, 7, 23),32,"Folkemuseum",'Oslo',"Norway",'Oslo','Geneva',"",[]])
data_list.append([datetime.datetime(2017, 7, 23),1,"City Hall",'Oslo',"Norway",'Oslo','Geneva',"",[]])
data_list.append([datetime.datetime(2017, 7, 23),13,"Museum of Cultural History",'Oslo',"Norway",'Oslo','Geneva',"",[]])
#munich
data_list.append([datetime.datetime(2017,7,29),38,"Rathaus","Munich","Germany","Garching","Garching","",['Eric','Siyi']])
data_list.append([datetime.datetime(2017,7,29),11,"St Peter","Munich","Germany","Garching","Garching","",['Eric','Siyi']])
data_list.append([datetime.datetime(2017,7,29),6,"Altes Rathaus","Munich","Germany","Garching","Garching","",['Eric','Siyi']])
data_list.append([datetime.datetime(2017,7,29),4,"Marienplatz","Munich","Germany","Garching","Garching","",['Eric','Siyi']])
data_list.append([datetime.datetime(2017,7,29),5,"Frauenkirche","Munich","Germany","Garching","Garching","",['Eric','Siyi']])
data_list.append([datetime.datetime(2017,7,29),9,"St Michael","Munich","Germany","Garching","Garching","",['Eric','Siyi']])
data_list.append([datetime.datetime(2017,7,29),5,"Buergersaalkirche","Munich","Germany","Garching","Garching","",['Eric','Siyi']])
data_list.append([datetime.datetime(2017,7,29),3,"Stiftskirche St Anna","Munich","Germany","Garching","Garching","",['Eric','Siyi']])
data_list.append([datetime.datetime(2017,7,29),3,"St Peter Turm","Munich","Germany","Garching","Garching","",['Eric','Siyi']])
data_list.append([datetime.datetime(2017,7,29),1,"Olympiaturm","Munich","Germany","Garching","Garching","",['Eric','Siyi']])
data_list.append([datetime.datetime(2017,7,29),1,"Residence","Munich","Germany","Garching","Garching","",['Eric','Siyi']])
data_list.append([datetime.datetime(2017,7,29),1,"Maximilianeum","Munich","Germany","Garching","Garching","",['Eric','Siyi']])
data_list.append([datetime.datetime(2017,7,29),1,"Lukaskirche","Munich","Germany","Garching","Garching","",['Eric','Siyi']])
data_list.append([datetime.datetime(2017,7,29),1,"St Anna imm Lehel","Munich","Germany","Garching","Garching","",['Eric','Siyi']])
data_list.append([datetime.datetime(2017,7,29),12,"Theatine Church","Munich","Germany","Garching","Garching","",['Eric','Siyi']])
data_list.append([datetime.datetime(2017,7,29),1,"Bavarian State Library","Munich","Germany","Garching","Garching","",['Eric','Siyi']])
data_list.append([datetime.datetime(2017,7,29),8,"St Ludwig","Munich","Germany","Garching","Garching","",['Eric','Siyi']])
data_list.append([datetime.datetime(2017,7,29),29,"Lenbachhaus","Munich","Germany","Garching","Garching","",['Eric','Siyi']])
data_list.append([datetime.datetime(2017,7,29),1,"Glyptothek","Munich","Germany","Garching","Garching","",['Eric','Siyi']])
data_list.append([datetime.datetime(2017,7,29),1,"Propylaeen","Munich","Germany","Garching","Garching","",['Eric','Siyi']])
data_list.append([datetime.datetime(2017,7,30),64,"Nymphenburg","Munich","Germany","Garching","Geneva","",[]])
data_list.append([datetime.datetime(2017,7,30),9,"Neue Pinakothek","Munich","Germany","Garching","Geneva","",[]])
data_list.append([datetime.datetime(2017,7,30),28,"Villa Stuck","Munich","Germany","Garching","Geneva","",[]])
data_list.append([datetime.datetime(2017,7,30),22,"Pinakothek der Moderne","Munich","Germany","Garching","Geneva","",[]])
data_list.append([datetime.datetime(2017,7,30),8,"Alte Pinakothek","Munich","Germany","Garching","Geneva","",[]])
data_list.append([datetime.datetime(2017,7,30),11,"Glyptothek","Munich","Germany","Garching","Geneva","",[]])
data_list.append([datetime.datetime(2017,7,30),9,"Staatliche Antikensammlungen","Munich","Germany","Garching","Geneva","",[]])
data_list.append([datetime.datetime(2017,7,30),1,"Isartor","Munich","Germany","Garching","Geneva","",[]])
data_list.append([datetime.datetime(2017,7,30),1,"Deutsches Museum","Munich","Germany","Garching","Geneva","",[]])
data_list.append([datetime.datetime(2017,7,30),1,"Bayrische Staatskanzlei","Munich","Germany","Garching","Geneva","",[]])
data_list.append([datetime.datetime(2017,7,30),1,"Hofgarten","Munich","Germany","Garching","Geneva","",[]])
data_list.append([datetime.datetime(2017,7,30),1,"Prinz-Karl-Palais","Munich","Germany","Garching","Geneva","",[]])
#all lauchringen done
data_list.append([datetime.datetime(2017, 8, 5),11,"Kuessaburg",'Bechtersbohl',"Germany",'Lauchringen','Lauchringen',"",['Artur','Christian','Anne-Kathrin']])
#glacier 3000
data_list.append([datetime.datetime(2017, 8, 26),7,"Scex Rouge",'Les-Diablerets',"Switzerland",'Geneva','Geneva',"",[]])
data_list.append([datetime.datetime(2017, 8, 26),4,"Glacier de Prapio",'Les-Diablerets',"Switzerland",'Geneva','Geneva',"",[]])
data_list.append([datetime.datetime(2017, 8, 26),11,"Oldenhorn",'Les-Diablerets',"Switzerland",'Geneva','Geneva',"",[]])
data_list.append([datetime.datetime(2017, 8, 26),29,"Tsanfleuron",'Les-Diablerets',"Switzerland",'Geneva','Geneva',"",[]])
data_list.append([datetime.datetime(2017, 8, 26),4,"Tete Ronde",'Les-Diablerets',"Switzerland",'Geneva','Geneva',"",[]])
data_list.append([datetime.datetime(2017, 8, 26),3,"Glacier des Diablerets",'Les-Diablerets',"Switzerland",'Geneva','Geneva',"",[]])
data_list.append([datetime.datetime(2017, 8, 26),3,"Tour St Martin",'Les-Diablerets',"Switzerland",'Geneva','Geneva',"",[]])
#all Split done
data_list.append([datetime.datetime(2017, 8, 27),1,"St Mary",'Trogir',"Croatia",'Geneva','Split',"",[]])
data_list.append([datetime.datetime(2017, 8, 27),3,"Ivana Pavla II Square",'Trogir',"Croatia",'Geneva','Split',"",[]])
data_list.append([datetime.datetime(2017, 8, 27),43,"Cathedral",'Trogir',"Croatia",'Geneva','Split',"",[]])
data_list.append([datetime.datetime(2017, 8, 27),3,"Town Walls",'Trogir',"Croatia",'Geneva','Split',"",[]])
data_list.append([datetime.datetime(2017, 8, 27),2,"Kamerlengo Fortress",'Trogir',"Croatia",'Geneva','Split',"",[]])
data_list.append([datetime.datetime(2017, 8, 27),86,"Palace of Diocletian",'Split',"Croatia",'Geneva','Split',"Historical Complex of Split with the Palace of Diocletian",[]])
data_list.append([datetime.datetime(2017, 8, 27),2,"Augubio Palace",'Split',"Croatia",'Geneva','Split',"Historical Complex of Split with the Palace of Diocletian",[]])
data_list.append([datetime.datetime(2017, 8, 27),73,"Cathedral",'Split',"Croatia",'Geneva','Split',"Historical Complex of Split with the Palace of Diocletian",[]])
data_list.append([datetime.datetime(2017, 8, 27),2,"Dominican Church",'Split',"Croatia",'Geneva','Split',"Historical Complex of Split with the Palace of Diocletian",[]])
data_list.append([datetime.datetime(2017, 8, 27),2,"Venetian Tower",'Split',"Croatia",'Geneva','Split',"Historical Complex of Split with the Palace of Diocletian",[]])
data_list.append([datetime.datetime(2017, 8, 27),3,"Franciscan Church",'Split',"Croatia",'Geneva','Split',"Historical Complex of Split with the Palace of Diocletian",[]])
data_list.append([datetime.datetime(2017, 8, 27),11,"Kastelet",'Split',"Croatia",'Geneva','Split',"",[]])
data_list.append([datetime.datetime(2017, 8, 27),23,"Ivan Mestrovic Gallery",'Split',"Croatia",'Geneva','Split',"",[]])
data_list.append([datetime.datetime(2017, 8, 27),5,"Great Papalic Palace",'Split',"Croatia",'Geneva','Split',"Historical Complex of Split with the Palace of Diocletian",[]])
data_list.append([datetime.datetime(2017, 8, 27),4,"Strossmayer Fountain",'Split',"Croatia",'Geneva','Split',"Historical Complex of Split with the Palace of Diocletian",[]])

# %%
#Rome 2017 done
data_list.append([datetime.datetime(2017, 9, 6),1,"Trinita dei Monti",'Rome',"Italy",'Geneva','Rome',"Rome",['Riju']])
#including spanish stairs
data_list.append([datetime.datetime(2017, 9, 6),5,"Piazza di Spagna",'Rome',"Italy",'Geneva','Rome',"Rome",['Riju']])
data_list.append([datetime.datetime(2017, 9, 6),15,"Trevi Fountain",'Rome',"Italy",'Geneva','Rome',"Rome",['Riju']])
data_list.append([datetime.datetime(2017, 9, 6),1,"Santa Vincenzo e Anastasio a Fontana di Trevi",'Rome',"Italy",'Geneva','Rome',"Rome",['Riju']])
data_list.append([datetime.datetime(2017, 9, 6),1,"Piazza Mignanelli",'Rome',"Italy",'Geneva','Rome',"Rome",['Riju']])
data_list.append([datetime.datetime(2017, 9, 7),4,"Piazza di Spagna",'Rome',"Italy",'Rome','Rome',"Rome",['Riju']])
#includes Sistine's Chapel & Stanze di Raffaelo, walls,scala regia and exterior for apostolic palace
data_list.append([datetime.datetime(2017, 9, 7),15,"Apostolic Palace",'Rome',"Vatican",'Rome','Rome',"Vatican",['Riju']])
data_list.append([datetime.datetime(2017, 9, 7),138,"Vatican Museums",'Rome',"Vatican",'Rome','Rome',"Vatican",['Riju']])
data_list.append([datetime.datetime(2017, 9, 7),10,"Vatican Gardens",'Rome',"Vatican",'Rome','Rome',"Vatican",['Riju']])
#includes the collonades
data_list.append([datetime.datetime(2017, 9, 7),110,"St Peter's Basilica",'Rome',"Vatican",'Rome','Rome',"Vactican",['Riju']])
data_list.append([datetime.datetime(2017, 9, 7),2,"Sant'Anna",'Rome',"Vatican",'Rome','Rome',"Vatican",['Riju']])
data_list.append([datetime.datetime(2017, 9, 7),11,"St Peter's Basilica Dome",'Rome',"Vatican",'Rome','Rome',"Vactican",['Riju']])
data_list.append([datetime.datetime(2017, 9, 7),8,"Campo Santo Teutonico",'Rome',"Vatican",'Rome','Rome',"Vactican",['Riju']])
data_list.append([datetime.datetime(2017, 9, 7),2,"Vatican Audience Hall",'Rome',"Vatican",'Rome','Rome',"Vactican",['Riju']])
data_list.append([datetime.datetime(2017, 9, 7),2,"Vatican Station",'Rome',"Vatican",'Rome','Rome',"Vactican",['Riju']])
data_list.append([datetime.datetime(2017, 9, 7),1,"Aurelian Walls",'Rome',"Italy",'Rome','Rome',"Rome",['Riju']])
data_list.append([datetime.datetime(2017, 9, 7),1,"Santa Maria in Traspontina",'Rome',"Italy",'Rome','Rome',"",['Riju']])
data_list.append([datetime.datetime(2017, 9, 7),57,"Castel Sant'Angelo",'Rome',"Italy",'Rome','Rome',"",['Riju']])
data_list.append([datetime.datetime(2017, 9, 7),5,"Castel Sant'Angelo Terrace",'Rome',"Italy",'Rome','Rome',"",['Riju']])
data_list.append([datetime.datetime(2017, 9, 7),1,"Monumento Nazionale a Vittorio Emanuele II",'Rome',"Italy",'Rome','Rome',"Rome",['Riju']])
data_list.append([datetime.datetime(2017, 9, 7),1,"Palazzo Quirinale",'Rome',"Italy",'Rome','Rome',"Rome",['Riju']])
data_list.append([datetime.datetime(2017, 9, 7),6,"Palace of Justice",'Rome',"Italy",'Rome','Rome',"",['Riju']])
data_list.append([datetime.datetime(2017, 9, 7),2,"Mausoleum of Augustus",'Rome',"Italy",'Rome','Rome',"Rome",['Riju']])
data_list.append([datetime.datetime(2017, 9, 7),2,"Ara Pietatis",'Rome',"Italy",'Rome','Rome',"Rome",['Riju']])
data_list.append([datetime.datetime(2017, 9, 7),9,"Ara Pacis Augustae",'Rome',"Italy",'Rome','Rome',"Rome",['Riju']])
data_list.append([datetime.datetime(2017, 9, 7),16,"Santi Ambrogio e Carlo al Corso",'Rome',"Italy",'Rome','Rome',"Rome",['Riju']])
data_list.append([datetime.datetime(2017, 9, 7),3,"San Giacomo in Augusta",'Rome',"Italy",'Rome','Rome',"Rome",['Riju']])
data_list.append([datetime.datetime(2017, 9, 7),3,"Chiesa di Gesu e Maria",'Rome',"Italy",'Rome','Rome',"Rome",['Riju']])
data_list.append([datetime.datetime(2017, 9, 7),4,"Piazza del Popolo",'Rome',"Italy",'Rome','Rome',"Rome",['Riju']])
data_list.append([datetime.datetime(2017, 9, 7),2,"Santa Maria in Montesanto",'Rome',"Italy",'Rome','Rome',"Rome",['Riju']])
data_list.append([datetime.datetime(2017, 9, 7),1,"Pincio",'Rome',"Italy",'Rome','Rome',"Rome",['Riju']])
data_list.append([datetime.datetime(2017, 9, 7),18,"Santa Maria del Popolo",'Rome',"Italy",'Rome','Rome',"Rome",['Riju']])
data_list.append([datetime.datetime(2017, 9, 7),4,"Villa Borghese",'Rome',"Italy",'Rome','Rome',"",['Riju']])
data_list.append([datetime.datetime(2017, 9, 7),78,"Villa Borghese Casino Nobile",'Rome',"Italy",'Rome','Rome',"",['Riju']])
data_list.append([datetime.datetime(2017, 9, 7),4,"Moses Fountain",'Rome',"Italy",'Rome','Rome',"Rome",['Riju']])
data_list.append([datetime.datetime(2017, 9, 7),1,"Santa Maria della Vittoria",'Rome',"Italy",'Rome','Rome',"Rome",['Riju']])
data_list.append([datetime.datetime(2017, 9, 7),2,"Piazza Repubblica",'Rome',"Italy",'Rome','Rome',"Rome",['Riju']])
data_list.append([datetime.datetime(2017, 9, 7),11,"Santa Maria degli Angeli",'Rome',"Italy",'Rome','Rome',"Rome",['Riju']])
data_list.append([datetime.datetime(2017, 9, 7),2,"Baths of Diocletian",'Rome',"Italy",'Rome','Rome',"Rome",['Riju']])
data_list.append([datetime.datetime(2017, 9, 7),1,"Santa Susanna alle Terme di Diocleziano",'Rome',"Italy",'Rome','Rome',"Rome",['Riju']])
data_list.append([datetime.datetime(2017, 9, 7),1,"Triton Fountain",'Rome',"Italy",'Rome','Rome',"Rome",['Riju']])
data_list.append([datetime.datetime(2017, 9, 7),1,"Palazzo Barberini",'Rome',"Italy",'Rome','Rome',"Rome",['Riju']])
data_list.append([datetime.datetime(2017, 9, 7),1,"Santi Ildefonso e Tommaso da Villanova",'Rome',"Italy",'Rome','Rome',"Rome",['Riju']])
data_list.append([datetime.datetime(2017, 9, 7),7,"Trinita dei Monti",'Rome',"Italy",'Rome','Rome',"Rome",['Riju']])
data_list.append([datetime.datetime(2017, 9, 8),4,"Piazza delle Quattro Fontane",'Rome',"Italy",'Rome','Rome',"Rome",['Riju']])
data_list.append([datetime.datetime(2017, 9, 8),8,"San Carlo alle Quattro Fontane",'Rome',"Italy",'Rome','Rome',"Rome",['Riju']])
data_list.append([datetime.datetime(2017, 9, 8),1,"Santa Maria Maggiore",'Rome',"Vatican",'Rome','Rome',"Rome",['Riju']])
data_list.append([datetime.datetime(2017, 9, 8),56,"Piazza Santa Maria Maggiore",'Rome',"Vatican",'Rome','Rome',"Rome",['Riju']])
data_list.append([datetime.datetime(2017, 9, 8),25,"Santa Prassede",'Rome',"Italy",'Rome','Rome',"Rome",['Riju']])
data_list.append([datetime.datetime(2017, 9, 8),56,"Santa Pudenzia",'Rome',"Italy",'Rome','Rome',"Rome",['Riju']])
data_list.append([datetime.datetime(2017, 9, 8),3,"San Bernardo alle Terme",'Rome',"Italy",'Rome','Rome',"Rome",['Riju']])
data_list.append([datetime.datetime(2017, 9, 8),10,"Santa Maria della Vittoria",'Rome',"Italy",'Rome','Rome',"Rome",['Riju']])
data_list.append([datetime.datetime(2017, 9, 8),11,"Sant'Andrea al Quirinale",'Rome',"Italy",'Rome','Rome',"Rome",['Riju']])
data_list.append([datetime.datetime(2017, 9, 8),91,"Palazzo Quirinale",'Rome',"Italy",'Rome','Rome',"Rome",['Riju']])
data_list.append([datetime.datetime(2017, 9, 8),1,"Triclinium Leoninum",'Rome',"Vatican",'Rome','Rome',"Rome",['Riju']])
data_list.append([datetime.datetime(2017, 9, 8),2,"Basilica di San Giovanni in Laterano",'Rome',"Vatican",'Rome','Rome',"Rome",['Riju']])
data_list.append([datetime.datetime(2017, 9, 8),34,"Basilica di San Giovanni in Laterano",'Rome',"Vatican",'Rome','Rome',"Rome",['Riju','Amin']])
data_list.append([datetime.datetime(2017, 9, 8),17,"Battistero Lateranense",'Rome',"Vatican",'Rome','Rome',"Rome",['Riju','Amin']])
data_list.append([datetime.datetime(2017, 9, 8),1,"Piazza di Laterano",'Rome',"Italy",'Rome','Rome',"Rome",['Riju','Amin']])
data_list.append([datetime.datetime(2017, 9, 8),6,"Sancta Sanctorum",'Rome',"Vatican",'Rome','Rome',"Rome",['Riju','Amin']])
data_list.append([datetime.datetime(2017, 9, 8),11,"Sant'Ignazio",'Rome',"Italy",'Rome','Rome',"Rome",['Riju','Amin']])
data_list.append([datetime.datetime(2017, 9, 8),1,"Piazza della Rotonda",'Rome',"Italy",'Rome','Rome',"Rome",['Riju','Amin']])
data_list.append([datetime.datetime(2017, 9, 8),12,"Pantheon",'Rome',"Italy",'Rome','Rome',"Rome",['Riju','Amin']])
data_list.append([datetime.datetime(2017, 9, 8),1,"Piazza della Rotonda",'Rome',"Italy",'Rome','Rome',"Rome",['Riju','Amin']])
data_list.append([datetime.datetime(2017, 9, 8),1,"Piazza della Minerva",'Rome',"Italy",'Rome','Rome',"Rome",['Riju','Amin']])
data_list.append([datetime.datetime(2017, 9, 8),11,"Maria Sopra Minerva",'Rome',"Italy",'Rome','Rome',"Rome",['Riju','Amin']])
data_list.append([datetime.datetime(2017, 9, 8),27,"Il Gesu",'Rome',"Italy",'Rome','Rome',"Rome",['Riju','Amin']])
data_list.append([datetime.datetime(2017, 9, 8),9,"St Andrea della Valle",'Rome',"Italy",'Rome','Rome',"Rome",['Riju','Amin']])
data_list.append([datetime.datetime(2017, 9, 8),1,"Palazzo Spada",'Rome',"Italy",'Rome','Rome',"Rome",['Riju','Amin']])
data_list.append([datetime.datetime(2017, 9, 8),1,"Piazza Farnese",'Rome',"Italy",'Rome','Rome',"Rome",['Riju','Amin']])
data_list.append([datetime.datetime(2017, 9, 8),11,"Palazzo Farnese",'Rome',"Italy",'Rome','Rome',"Rome",['Riju','Amin']])
data_list.append([datetime.datetime(2017, 9, 8),3,"Largo di Torre Argentina",'Rome',"Italy",'Rome','Rome',"Rome",['Riju','Amin']])
data_list.append([datetime.datetime(2017, 9, 8),26,"Palazzo Venezia",'Rome',"Italy",'Rome','Rome',"Rome",['Riju','Amin']])
data_list.append([datetime.datetime(2017, 9, 8),1,"Santa Maria in Aracoeli",'Rome',"Italy",'Rome','Rome',"Rome",['Riju','Amin']])
#facades of capitol,inside in museums
data_list.append([datetime.datetime(2017, 9, 8),5,"Piazza del Campidoglio",'Rome',"Italy",'Rome','Rome',"Rome",['Riju','Amin']])
data_list.append([datetime.datetime(2017, 9, 8),52,"Capitoline Museums",'Rome',"Italy",'Rome','Rome',"Rome",['Riju','Amin']])
data_list.append([datetime.datetime(2017, 9, 8),14,"Forum Romanum",'Rome',"Italy",'Rome','Rome',"Rome",['Riju','Amin']])
#backside & tabularium
data_list.append([datetime.datetime(2017, 9, 8),4,"Capitol",'Rome',"Italy",'Rome','Rome',"Rome",['Riju','Amin']])
data_list.append([datetime.datetime(2017, 9, 8),1,"Santa Maria di Loreto",'Rome',"Italy",'Rome','Rome',"Rome",['Riju','Amin']])
data_list.append([datetime.datetime(2017, 9, 8),2,"Santa Maria al Foro Traiano",'Rome',"Italy",'Rome','Rome',"Rome",['Riju','Amin']])
data_list.append([datetime.datetime(2017, 9, 8),4,"Column of Trajan",'Rome',"Italy",'Rome','Rome',"Rome",['Riju','Amin']])
data_list.append([datetime.datetime(2017, 9, 8),3,"Monumento Nazionale a Vittorio Emanuele II",'Rome',"Italy",'Rome','Rome',"Rome",['Riju','Amin']])
data_list.append([datetime.datetime(2017, 9, 8),4,"Imperial Forums",'Rome',"Italy",'Rome','Rome',"Rome",['Riju','Amin']])
data_list.append([datetime.datetime(2017, 9, 8),3,"San Marcello al Corso",'Rome',"Italy",'Rome','Rome',"Rome",['Riju','Amin']])
data_list.append([datetime.datetime(2017, 9, 9),4,"Basilica di Sant'Andrea delle Fratte",'Rome',"Italy",'Rome','Rome',"Rome",['Amin']])
data_list.append([datetime.datetime(2017, 9, 9),4,"San Silvestro in Capite",'Rome',"Italy",'Rome','Rome',"Rome",['Amin']])
data_list.append([datetime.datetime(2017, 9, 9),4,"Santi Claudio e Andrea dei Borgognoni",'Rome',"Italy",'Rome','Rome',"Rome",['Amin']])
data_list.append([datetime.datetime(2017, 9, 9),2,"Santa Maria in Via Lata",'Rome',"Italy",'Rome','Rome',"Rome",['Amin']])
data_list.append([datetime.datetime(2017, 9, 9),8,"Trevi Fountain",'Rome',"Italy",'Rome','Rome',"Rome",['Amin']])
data_list.append([datetime.datetime(2017, 9, 9),4,"Column of Marcus Aurelius",'Rome',"Italy",'Rome','Rome',"Rome",['Amin']])
data_list.append([datetime.datetime(2017, 9, 9),1,"Palazzo Montecitorio",'Rome',"Italy",'Rome','Rome',"Rome",['Amin']])
data_list.append([datetime.datetime(2017, 9, 9),1,"Piazza Montecitorio",'Rome',"Italy",'Rome','Rome',"Rome",['Amin']])
data_list.append([datetime.datetime(2017, 9, 9),3,"Santa Maria in Aquiro",'Rome',"Italy",'Rome','Rome',"Rome",['Amin']])
data_list.append([datetime.datetime(2017, 9, 9),13,"Pantheon",'Rome',"Italy",'Rome','Rome',"Rome",['Amin']])
data_list.append([datetime.datetime(2017, 9, 9),1,"Piazza della Rotonda",'Rome',"Italy",'Rome','Rome',"Rome",['Amin']])
data_list.append([datetime.datetime(2017, 9, 9),1,"Sapienza",'Rome',"Italy",'Rome','Rome',"Rome",['Amin']])
data_list.append([datetime.datetime(2017, 9, 9),2,"Sant'Eustacio",'Rome',"Italy",'Rome','Rome',"Rome",['Amin']])
data_list.append([datetime.datetime(2017, 9, 9),1,"Palazzo Madama",'Rome',"Italy",'Rome','Rome',"Rome",['Amin']])
data_list.append([datetime.datetime(2017, 9, 9),1,"St Andrea della Valle",'Rome',"Italy",'Rome','Rome',"Rome",['Amin']])
data_list.append([datetime.datetime(2017, 9, 9),6,"Piazza Navona",'Rome',"Italy",'Rome','Rome',"Rome",['Amin']])
data_list.append([datetime.datetime(2017, 9, 9),12,"Sant'Agnese in Agone",'Rome',"Italy",'Rome','Rome',"Rome",['Amin']])
data_list.append([datetime.datetime(2017, 9, 9),6,"Santa Maria dell'Anima",'Rome',"Italy",'Rome','Rome',"Rome",['Amin']])
data_list.append([datetime.datetime(2017, 9, 9),13,"Santa Maria della Pace",'Rome',"Italy",'Rome','Rome',"Rome",['Amin']])
data_list.append([datetime.datetime(2017, 9, 9),1,"Synagogue",'Rome',"Italy",'Rome','Rome',"Rome",['Amin']])
data_list.append([datetime.datetime(2017, 9, 9),1,"San Carlo ai Catinari",'Rome',"Italy",'Rome','Rome',"Rome",['Amin']])
data_list.append([datetime.datetime(2017, 9, 9),1,"Teatro Marcello",'Rome',"Italy",'Rome','Rome',"Rome",['Amin']])
data_list.append([datetime.datetime(2017, 9, 9),5,"San Bartolomeo all'Isola",'Rome',"Italy",'Rome','Rome',"Rome",['Amin']])
data_list.append([datetime.datetime(2017, 9, 9),21,"Santa Cecilia in Trastevere",'Rome',"Italy",'Rome','Rome',"Rome",['Amin']])
data_list.append([datetime.datetime(2017, 9, 9),1,"Basilica di San Crisogono",'Rome',"Italy",'Rome','Rome',"Rome",['Amin']])
data_list.append([datetime.datetime(2017, 9, 9),17,"Santa Maria in Trastevere",'Rome',"Italy",'Rome','Rome',"Rome",['Amin']])
data_list.append([datetime.datetime(2017, 9, 9),5,"Santa Maria della Scala",'Rome',"Italy",'Rome','Rome',"Rome",['Amin']])
data_list.append([datetime.datetime(2017, 9, 9),1,"Porta Septimiana",'Rome',"Italy",'Rome','Rome',"Rome",['Amin']])
data_list.append([datetime.datetime(2017, 9, 9),20,"Palazzo Corsini",'Rome',"Italy",'Rome','Rome',"Rome",[]])
data_list.append([datetime.datetime(2017, 9, 9),2,"Palazzo Farnese",'Rome',"Italy",'Rome','Rome',"Rome",[]])
data_list.append([datetime.datetime(2017, 9, 9),16,"Palazzo Spada",'Rome',"Italy",'Rome','Rome',"Rome",[]])
data_list.append([datetime.datetime(2017, 9, 9),2,"Santissima Trinita dei Pellegrini",'Rome',"Italy",'Rome','Rome',"Rome",[]])
data_list.append([datetime.datetime(2017, 9, 9),1,"Turtle Fountain",'Rome',"Italy",'Rome','Rome',"Rome",[]])
data_list.append([datetime.datetime(2017, 9, 9),1,"Hadrian's Temple",'Rome',"Italy",'Rome','Rome',"Rome",[]])
data_list.append([datetime.datetime(2017, 9, 9),1,"San Nicola dei Lorenesi",'Rome',"Italy",'Rome','Rome',"Rome",[]])
data_list.append([datetime.datetime(2017, 9, 9),4,"Stadium of Domitian",'Rome',"Italy",'Rome','Rome',"Rome",[]])
data_list.append([datetime.datetime(2017, 9, 9),1,"Turtle Fountain",'Rome',"Italy",'Rome','Rome',"Rome",[]])
data_list.append([datetime.datetime(2017, 9, 9),1,"Hadrian's Temple",'Rome',"Italy",'Rome','Rome',"Rome",[]])
data_list.append([datetime.datetime(2017, 9, 9),1,"San Nicola dei Lorenesi",'Rome',"Italy",'Rome','Rome',"Rome",[]])
data_list.append([datetime.datetime(2017, 9, 9),1,"Santi Apostoli",'Rome',"Italy",'Rome','Rome',"Rome",[]])
data_list.append([datetime.datetime(2017, 9, 9),1,"Palazzo Colonna",'Rome',"Italy",'Rome','Rome',"Rome",[]])
data_list.append([datetime.datetime(2017, 9, 9),2,"Piazza del Campidoglio",'Rome',"Italy",'Rome','Rome',"Rome",[]])
data_list.append([datetime.datetime(2017, 9, 9),13,"Santa Maria in Aracoeli",'Rome',"Italy",'Rome','Rome',"Rome",[]])
data_list.append([datetime.datetime(2017, 9, 9),26,"Forum Romanum",'Rome',"Italy",'Rome','Rome',"Rome",[]])
data_list.append([datetime.datetime(2017, 9, 9),2,"Capitol",'Rome',"Italy",'Rome','Rome',"Rome",[]])
data_list.append([datetime.datetime(2017, 9, 9),5,"Santi Luca e Martino",'Rome',"Italy",'Rome','Rome',"Rome",[]])
data_list.append([datetime.datetime(2017, 9, 9),2,"St Joseph dei Falegnami",'Rome',"Italy",'Rome','Rome',"Rome",[]])
data_list.append([datetime.datetime(2017, 9, 9),1,"Monumento Nazionale a Vittorio Emanuele II",'Rome',"Italy",'Rome','Rome',"Rome",[]])
data_list.append([datetime.datetime(2017, 9, 9),2,"Imperial Forums",'Rome',"Italy",'Rome','Rome',"Rome",[]])
data_list.append([datetime.datetime(2017, 9, 9),2,"Colosseum",'Rome',"Italy",'Rome','Rome',"Rome",[]])
data_list.append([datetime.datetime(2017, 9, 9),2,"Arch of Constantine",'Rome',"Italy",'Rome','Rome',"Rome",[]])
data_list.append([datetime.datetime(2017, 9, 9),2,"Temple of Venus and Roma",'Rome',"Italy",'Rome','Rome',"Rome",[]])
data_list.append([datetime.datetime(2017, 9, 9),2,"Santa Francesca Romana",'Rome',"Italy",'Rome','Rome',"Rome",[]])
data_list.append([datetime.datetime(2017, 9, 9),5,"Santi Cosma e Damiano",'Rome',"Italy",'Rome','Rome',"Rome",[]])
data_list.append([datetime.datetime(2017, 9, 9),7,"Basilica di Santi Quattro Coronati",'Rome',"Italy",'Rome','Rome',"Rome",[]])
data_list.append([datetime.datetime(2017, 9, 9),18,"San Clemente",'Rome',"Italy",'Rome','Rome',"Rome",[]])
data_list.append([datetime.datetime(2017, 9, 9),19,"Colosseum",'Rome',"Italy",'Rome','Rome',"Rome",['Riju']])
data_list.append([datetime.datetime(2017, 9, 9),5,"Arch of Constantine",'Rome',"Italy",'Rome','Rome',"Rome",['Riju']])
data_list.append([datetime.datetime(2017, 9, 9),1,"Temple of Venus and Roma",'Rome',"Italy",'Rome','Rome',"Rome",['Riju']])
data_list.append([datetime.datetime(2017, 9, 9),4,"Baths of Trajan",'Rome',"Italy",'Rome','Rome',"Rome",['Riju']])
data_list.append([datetime.datetime(2017, 9, 9),1,"Domus Aurea",'Rome',"Italy",'Rome','Rome',"Rome",['Riju']])
data_list.append([datetime.datetime(2017, 9, 9),3,"Triton Fountain",'Rome',"Italy",'Rome','Rome',"Rome",['Riju','Amin']])
data_list.append([datetime.datetime(2017, 9, 9),4,"Colosseum",'Rome',"Italy",'Rome','Rome',"Rome",['Riju','Amin']])
data_list.append([datetime.datetime(2017, 9, 9),3,"Arch of Constantine",'Rome',"Italy",'Rome','Rome',"Rome",['Riju','Amin']])
data_list.append([datetime.datetime(2017, 9, 9),1,"Basilica di San Giovanni in Laterano",'Rome',"Vatican",'Rome','Rome',"Rome",['Riju','Amin']])
data_list.append([datetime.datetime(2017, 9, 9),10,"St Peter's Basilica",'Rome',"Vatican",'Rome','Rome',"Vactican",['Riju','Amin']])
data_list.append([datetime.datetime(2017, 9, 9),2,"Temple of Venus and Roma",'Rome',"Italy",'Rome','Rome',"Rome",['Riju','Amin']])
data_list.append([datetime.datetime(2017, 9, 9),5,"Forum Romanum",'Rome',"Italy",'Rome','Rome',"Rome",['Riju','Amin']])
data_list.append([datetime.datetime(2017, 9, 9),1,"Santa Maria della Concezione dei Cappuccini",'Rome',"Italy",'Rome','Rome',"Rome",['Riju','Amin']])
data_list.append([datetime.datetime(2017, 9, 10),51,"Domus Aurea",'Rome',"Italy",'Rome','Rome',"Rome",['Riju','Amin']])
data_list.append([datetime.datetime(2017, 9, 10),37,"Palazzo Barberini",'Rome',"Italy",'Rome','Rome',"Rome",[]])
data_list.append([datetime.datetime(2017, 9, 10),31,"Palazzo Altemps",'Rome',"Italy",'Rome','Rome',"Rome",[]])
data_list.append([datetime.datetime(2017, 9, 10),8,"Piazza Navona",'Rome',"Italy",'Rome','Rome',"Rome",[]])
data_list.append([datetime.datetime(2017, 9, 10),1,"Sant'Agnese in Agone",'Rome',"Italy",'Rome','Rome',"Rome",[]])
data_list.append([datetime.datetime(2017, 9, 10),20,"Palazzo Braschi",'Rome',"Italy",'Rome','Rome',"Rome",[]])
data_list.append([datetime.datetime(2017, 9, 10),1,"St Andrea della Valle",'Rome',"Italy",'Rome','Rome',"Rome",[]])
data_list.append([datetime.datetime(2017, 9, 10),63,"Palazzo Doria Pamphilj",'Rome',"Italy",'Rome','Rome',"Rome",[]])
data_list.append([datetime.datetime(2017, 9, 10),4,"Santa Maria in Via Lata",'Rome',"Italy",'Rome','Rome',"Rome",[]])
data_list.append([datetime.datetime(2017, 9, 10),1,"Temple of Nymphes",'Rome',"Italy",'Rome','Rome',"Rome",[]])
data_list.append([datetime.datetime(2017, 9, 10),10,"Crypta Balbi",'Rome',"Italy",'Rome','Rome',"Rome",[]])
data_list.append([datetime.datetime(2017, 9, 10),1,"San Stanislao alle Botteghe Oscure",'Rome',"Italy",'Rome','Rome',"Rome",[]])
data_list.append([datetime.datetime(2017, 9, 10),3,"Santa Maria della Concezione dei Cappuccini Crypt",'Rome',"Italy",'Rome','Rome',"Rome",[]])
data_list.append([datetime.datetime(2017, 9, 10),1,"Piazza della Repubblica",'Rome',"Italy",'Rome','Rome',"Rome",['Riju','Amin']])

# %%
#london 2017 done
data_list.append([datetime.datetime(2017,9,16),2,"London St Pancras","London","United Kingdom","London","London","",['Riju']])
data_list.append([datetime.datetime(2017,9,16),2,"St Margaret's",'London',"United Kingdom",'London','London',"Palace of Westminster and Westminster Abbey including Saint Margaret’s Church",['Riju']])
data_list.append([datetime.datetime(2017,9,16),69,"Westminster Abbey",'London',"United Kingdom",'London','London',"Palace of Westminster and Westminster Abbey including Saint Margaret’s Church",['Riju']])
data_list.append([datetime.datetime(2017,9,16),40,"Palace of Westminster",'London',"United Kingdom",'London','London',"Palace of Westminster and Westminster Abbey including Saint Margaret’s Church",['Riju']])
data_list.append([datetime.datetime(2017,9,16),4,"Government Offices Great George Street",'London',"United Kingdom",'London','London',"",['Riju']])
data_list.append([datetime.datetime(2017,9,16),47,"Foreign & Commonwealth Office",'London',"United Kingdom",'London','London',"",['Riju']])
data_list.append([datetime.datetime(2017,9,16),2,"St James's Palace",'London',"United Kingdom",'London','London',"",['Riju']])
data_list.append([datetime.datetime(2017,9,16),4,"Marlborough House",'London',"United Kingdom",'London','London',"",['Riju']])
data_list.append([datetime.datetime(2017,9,16),13,"The Royal Society",'London',"United Kingdom",'London','London',"",['Riju']])
data_list.append([datetime.datetime(2017,9,16),1,"Whitehall Horse Guards",'London',"United Kingdom",'London','London',"",['Riju']])
data_list.append([datetime.datetime(2017,9,16),1,"Admiralty Arch",'London',"United Kingdom",'London','London',"",['Riju']])
data_list.append([datetime.datetime(2017,9,16),1,"Admiralty House",'London',"United Kingdom",'London','London',"",['Riju']])
data_list.append([datetime.datetime(2017,9,16),3,"St Martin in the Fields",'London',"United Kingdom",'London','London',"",['Riju']])
data_list.append([datetime.datetime(2017,9,16),28,"National Gallery",'London',"United Kingdom",'London','London',"",[]])
data_list.append([datetime.datetime(2017,9,16),2,"Court of Justice",'London',"United Kingdom",'London','London',"",[]])
data_list.append([datetime.datetime(2017,9,16),11,"King's College",'London',"United Kingdom",'London','London',"",[]])
data_list.append([datetime.datetime(2017,9,16),3,"Trafalgar Square",'London',"United Kingdom",'London','London',"",[]])
data_list.append([datetime.datetime(2017,9,16),1,"Canada House",'London',"United Kingdom",'London','London',"",[]])
data_list.append([datetime.datetime(2017,9,16),6,"Piccadilly Circus",'London',"United Kingdom",'London','London',"",[]])
data_list.append([datetime.datetime(2017,9,16),5,"Queen's Theatre",'London',"United Kingdom",'London','London',"",['Riju']])
data_list.append([datetime.datetime(2017,9,17),15,"Buckingham Palace",'London',"United Kingdom",'London','London',"",['Riju']])
data_list.append([datetime.datetime(2017,9,17),2,"Victoria Monument",'London',"United Kingdom",'London','London',"",['Riju']])
data_list.append([datetime.datetime(2017,9,17),86,"Lancaster House",'London',"United Kingdom",'London','London',"",['Riju']])
data_list.append([datetime.datetime(2017,9,17),36,"Canada House",'London',"United Kingdom",'London','London',"",['Riju']])
data_list.append([datetime.datetime(2017,9,17),7,"Trafalgar Square",'London',"United Kingdom",'London','London',"",['Riju']])
data_list.append([datetime.datetime(2017,9,17),34,"National Gallery",'London',"United Kingdom",'London','London',"",['Riju']])
data_list.append([datetime.datetime(2017,9,17),10,"St Paul's Cathedral",'London',"United Kingdom",'London','London',"",['Riju']])
data_list.append([datetime.datetime(2017,9,17),14,"Tate Modern",'London',"United Kingdom",'London','London',"",['Riju']])
#including observatory
data_list.append([datetime.datetime(2017,9,17),45,"The Shard",'London',"United Kingdom",'London','London',"",['Riju']])
data_list.append([datetime.datetime(2017,9,17),6,"Blackfriars Bridges",'London',"United Kingdom",'London','London',"",['Riju']])
data_list.append([datetime.datetime(2017,9,17),2,"Millenium Bridge",'London',"United Kingdom",'London','London',"",['Riju']])
data_list.append([datetime.datetime(2017,9,17),8,"Tate Modern Roof Terrace",'London',"United Kingdom",'London','London',"",['Riju']])
data_list.append([datetime.datetime(2017,9,17),1,"Winchester Palace",'London',"United Kingdom",'London','London',"",['Riju']])
data_list.append([datetime.datetime(2017,9,17),2,"Tower of London",'London',"United Kingdom",'London','London',"Tower of London",['Riju']])
data_list.append([datetime.datetime(2017,9,17),4,"Tower Bridge",'London',"United Kingdom",'London','London',"",['Riju']])
data_list.append([datetime.datetime(2017,9,17),1,"Southwark Cathedral",'London',"United Kingdom",'London','London',"",['Riju']])
data_list.append([datetime.datetime(2017,9,17),2,"London Monument",'London',"United Kingdom",'London','London',"",['Riju']])
data_list.append([datetime.datetime(2017,9,17),2,"HMS Belfast",'London',"United Kingdom",'London','London',"",['Riju']])
#Graz
data_list.append([datetime.datetime(2017,9,30),3,"Am Eisernen Tor",'Graz',"Austria",'Geneva','Graz',"City of Graz – Historic Centre and Schloss Eggenberg",[]])
data_list.append([datetime.datetime(2017,9,30),8,"Town Parish Church",'Graz',"Austria",'Geneva','Graz',"City of Graz – Historic Centre and Schloss Eggenberg",[]])
data_list.append([datetime.datetime(2017,9,30),10,"Landhaus",'Graz',"Austria",'Geneva','Graz',"City of Graz – Historic Centre and Schloss Eggenberg",[]])
data_list.append([datetime.datetime(2017,9,30),2,"Painted House",'Graz',"Austria",'Geneva','Graz',"City of Graz – Historic Centre and Schloss Eggenberg",[]])
data_list.append([datetime.datetime(2017,9,30),21,"Dom",'Graz',"Austria",'Geneva','Graz',"City of Graz – Historic Centre and Schloss Eggenberg",[]])
data_list.append([datetime.datetime(2017,9,30),23,"St Katharina von Alexandrien & Ferdinandmausoleum",'Graz',"Austria",'Geneva','Graz',"City of Graz – Historic Centre and Schloss Eggenberg",[]])
data_list.append([datetime.datetime(2017,9,30),3,"Schlossberg",'Graz',"Austria",'Geneva','Graz',"City of Graz – Historic Centre and Schloss Eggenberg",[]])
data_list.append([datetime.datetime(2017,9,30),3,"Burg",'Graz',"Austria",'Geneva','Graz',"City of Graz – Historic Centre and Schloss Eggenberg",[]])
data_list.append([datetime.datetime(2017,9,30),2,"Stiegenkirche",'Graz',"Austria",'Geneva','Graz',"City of Graz – Historic Centre and Schloss Eggenberg",[]])
data_list.append([datetime.datetime(2017,9,30),6,"Mariahelferkirche",'Graz',"Austria",'Geneva','Graz',"City of Graz – Historic Centre and Schloss Eggenberg",[]])
data_list.append([datetime.datetime(2017,9,30),4,"Murinsel",'Graz',"Austria",'Geneva','Graz',"City of Graz – Historic Centre and Schloss Eggenberg",[]])
data_list.append([datetime.datetime(2017,9,30),2,"Kunsthaus",'Graz',"Austria",'Geneva','Graz',"City of Graz – Historic Centre and Schloss Eggenberg",[]])
data_list.append([datetime.datetime(2017,9,30),30,"Schloss Eggenberg",'Graz',"Austria",'Geneva','Graz',"City of Graz – Historic Centre and Schloss Eggenberg",[]])
data_list.append([datetime.datetime(2017,9,30),16,"Basilica Mariatrost",'Graz',"Austria",'Geneva','Graz',"",[]])
data_list.append([datetime.datetime(2017,9,30),1,"Rathaus",'Graz',"Austria",'Geneva','Graz',"City of Graz – Historic Centre and Schloss Eggenberg",[]])
data_list.append([datetime.datetime(2017,10,1),2,"Rathaus",'Graz',"Austria",'Graz','Geneva',"City of Graz – Historic Centre and Schloss Eggenberg",[]])
data_list.append([datetime.datetime(2017,10,1),1,"Erzherzog-Johanne-Brunnen",'Graz',"Austria",'Graz','Geneva',"City of Graz – Historic Centre and Schloss Eggenberg",[]])
data_list.append([datetime.datetime(2017,10,1),18,"Palais Herberstein",'Graz',"Austria",'Graz','Geneva',"City of Graz – Historic Centre and Schloss Eggenberg",[]])
data_list.append([datetime.datetime(2017,10,1),14,"Kunsthaus",'Graz',"Austria",'Graz','Geneva',"City of Graz – Historic Centre and Schloss Eggenberg",[]])
data_list.append([datetime.datetime(2017,10,1),6,"Mariahelferkirche",'Graz',"Austria",'Graz','Geneva',"City of Graz – Historic Centre and Schloss Eggenberg",[]])
data_list.append([datetime.datetime(2017,10,1),6,"Schlossberg",'Graz',"Austria",'Graz','Geneva',"City of Graz – Historic Centre and Schloss Eggenberg",[]])
data_list.append([datetime.datetime(2017,10,1),1,"Dom",'Graz',"Austria",'Graz','Geneva',"City of Graz – Historic Centre and Schloss Eggenberg",[]])
data_list.append([datetime.datetime(2017,10,1),1,"Dreifaltigkeitskirche",'Graz',"Austria",'Graz','Geneva',"City of Graz – Historic Centre and Schloss Eggenberg",[]])
data_list.append([datetime.datetime(2017,10,1),4,"Franziskanerkirche",'Graz',"Austria",'Graz','Geneva',"City of Graz – Historic Centre and Schloss Eggenberg",[]])
data_list.append([datetime.datetime(2017,10,1),11,"Barmherzigenkirche",'Graz',"Austria",'Graz','Geneva',"City of Graz – Historic Centre and Schloss Eggenberg",[]])
data_list.append([datetime.datetime(2017,10,1),1,"Flughafen Graz",'Graz',"Austria",'Graz','Geneva',"City of Graz – Historic Centre and Schloss Eggenberg",[]])

# %%
data_list.append([datetime.datetime(2017,10,6),1,"Fat Margaret",'Tallinn',"Estonia",'Geneva','Tallinn',"Historic Centre (Old Town) of Tallinn",['Riju','Reyer','Rachel']])
data_list.append([datetime.datetime(2017,10,6),3,"St Olav",'Tallinn',"Estonia",'Geneva','Tallinn',"Historic Centre (Old Town) of Tallinn",['Riju','Reyer','Rachel']])
data_list.append([datetime.datetime(2017,10,6),5,"Town Hall",'Tallinn',"Estonia",'Geneva','Tallinn',"Historic Centre (Old Town) of Tallinn",['Riju','Reyer','Rachel']])
data_list.append([datetime.datetime(2017,10,7),37,"Suomenlinna",'Helsinki',"Finland",'Tallinn','Tallinn',"Fortress of Suomenlinna",['Riju','Reyer','Rachel']])
data_list.append([datetime.datetime(2017,10,7),13,"Uspenski Cathedral",'Helsinki',"Finland",'Tallinn','Tallinn',"",['Riju','Reyer','Rachel']])
data_list.append([datetime.datetime(2017,10,7),15,"Cathedral",'Helsinki',"Finland",'Tallinn','Tallinn',"",['Riju','Reyer','Rachel']])
data_list.append([datetime.datetime(2017,10,7),6,"Senate Square",'Helsinki',"Finland",'Tallinn','Tallinn',"",['Riju','Reyer','Rachel']])
data_list.append([datetime.datetime(2017,10,7),2,"Helsinki Main Station",'Helsinki',"Finland",'Tallinn','Tallinn',"",['Riju','Reyer','Rachel']])
data_list.append([datetime.datetime(2017,10,7),1,"Fat Margaret",'Tallinn',"Estonia",'Tallin','Tallinn',"Historic Centre (Old Town) of Tallinn",['Riju','Reyer','Rachel']])
data_list.append([datetime.datetime(2017,10,8),4,"St Olav",'Tallinn',"Estonia",'Tallin','Tallinn',"Historic Centre (Old Town) of Tallinn",['Riju']])
data_list.append([datetime.datetime(2017,10,8),9,"Town Wall",'Tallinn',"Estonia",'Tallin','Tallinn',"Historic Centre (Old Town) of Tallinn",['Riju']])
data_list.append([datetime.datetime(2017,10,8),10,"Town Wall",'Tallinn',"Estonia",'Tallin','Tallinn',"Historic Centre (Old Town) of Tallinn",['Riju','Reyer','Rachel']])
data_list.append([datetime.datetime(2017,10,8),5,"St Olav",'Tallinn',"Estonia",'Tallin','Tallinn',"Historic Centre (Old Town) of Tallinn",['Riju','Reyer','Rachel']])
data_list.append([datetime.datetime(2017,10,8),35,"Kadriorg Palace",'Tallinn',"Estonia",'Tallin','Tallinn',"",['Riju','Reyer','Rachel']])
data_list.append([datetime.datetime(2017,10,8),22,"Cathedral",'Tallinn',"Estonia",'Tallin','Tallinn',"Historic Centre (Old Town) of Tallinn",['Riju','Reyer','Rachel']])
data_list.append([datetime.datetime(2017,10,8),8,"Alexander Nevsky Cathedral",'Tallinn',"Estonia",'Tallin','Tallinn',"Historic Centre (Old Town) of Tallinn",['Riju','Reyer','Rachel']])
data_list.append([datetime.datetime(2017,10,8),24,"St Nicholas",'Tallinn',"Estonia",'Tallin','Tallinn',"Historic Centre (Old Town) of Tallinn",['Riju','Reyer','Rachel']])
#zermatt
data_list.append([datetime.datetime(2017,10,15),5,"Bisgletscher",'Randa',"Switzerland",'Geneva','Geneva',"",['Riju']])
data_list.append([datetime.datetime(2017,10,15),14,"Matterhorn including Zmuttgletscher",'Zermatt',"Switzerland",'Geneva','Geneva',"",['Riju']])
data_list.append([datetime.datetime(2017,10,15),2,"Gornergrat Ride & Viewpoint",'Zermatt',"Switzerland",'Geneva','Geneva',"",['Riju']])
#whole glacier system without Breithorn
data_list.append([datetime.datetime(2017,10,15),27,"Monte-Rosa with Gorner- & Grenzgletscher",'Zermatt',"Switzerland",'Geneva','Geneva',"",['Riju']])
data_list.append([datetime.datetime(2017,10,15),4,"Breithorn",'Zermatt',"Switzerland",'Geneva','Geneva',"",['Riju']])
data_list.append([datetime.datetime(2017,10,15),4,"Kleinmatterhorn with Kleinmatterhorn- & Theodulgletschern",'Zermatt',"Switzerland",'Geneva','Geneva',"",['Riju']])
data_list.append([datetime.datetime(2017,10,15),3,"Riffelsee & Riffelberg",'Zermatt',"Switzerland",'Geneva','Geneva',"",['Riju']])
data_list.append([datetime.datetime(2017,10,15),4,"Findelgetscher",'Zermatt',"Switzerland",'Geneva','Geneva',"",['Riju']])
data_list.append([datetime.datetime(2017,10,15),23,"Dent Blanche, Obergabel-, Zinalroth- & Weisshorn group",'Zermatt',"Switzerland",'Geneva','Geneva',"",['Riju']])
data_list.append([datetime.datetime(2017,10,15),11,"Mischabel group",'Zermatt',"Switzerland",'Geneva','Geneva',"",['Riju']])
#st Gallen & Reichenau
data_list.append([datetime.datetime(2017,11,4),2,"Abbey",'St Gallen',"Switzerland",'Geneva','Geneva',"Abbey of St Gall",[]])
data_list.append([datetime.datetime(2017,11,4),69,"Abbey Cathedral",'St Gallen',"Switzerland",'Geneva','Geneva',"Abbey of St Gall",[]])
data_list.append([datetime.datetime(2017,11,4),2,"St Laurenzen",'St Gallen',"Switzerland",'Geneva','Geneva',"",[]])
data_list.append([datetime.datetime(2017,11,4),1,"Station",'St Gallen',"Switzerland",'Geneva','Geneva',"",[]])
data_list.append([datetime.datetime(2017,11,4),17,"St Georg",'Reichenau',"Germany",'Geneva','Geneva',"Monastic Island of Reichenau",[]])
data_list.append([datetime.datetime(2017,11,4),18,"Monastery",'Reichenau',"Germany",'Geneva','Geneva',"Monastic Island of Reichenau",[]])
data_list.append([datetime.datetime(2017,11,4),12,"St Peter & Paul",'Reichenau',"Germany",'Geneva','Geneva',"Monastic Island of Reichenau",[]])
data_list.append([datetime.datetime(2017,11,4),1,"Imperia",'Konstanz',"Germany",'Geneva','Geneva',"",[]])
data_list.append([datetime.datetime(2017,11,4),1,"Konzilgebaeude",'Konstanz',"Germany",'Geneva','Geneva',"",[]])
data_list.append([datetime.datetime(2017,11,4),32,"Minster",'Konstanz',"Germany",'Geneva','Geneva',"",[]])
#marrakesh done
data_list.append([datetime.datetime(2017, 11, 10),2,"Airport",'Marrakesh',"Morocco",'Geneva','Marrakesh',"Medina of Marrakesh",['Tony','Cameron','Riju']])
data_list.append([datetime.datetime(2017, 11, 10),64,"Bahia Palace",'Marrakesh',"Morocco",'Geneva','Marrakesh',"Medina of Marrakesh",['Tony','Cameron','Riju']])
data_list.append([datetime.datetime(2017, 11, 10),22,"Badia Palace",'Marrakesh',"Morocco",'Geneva','Marrakesh',"Medina of Marrakesh",['Tony','Cameron','Riju']])
data_list.append([datetime.datetime(2017, 11, 10),4,"Koutoubia Mosque",'Marrakesh',"Morocco",'Geneva','Marrakesh',"Medina of Marrakesh",['Tony','Cameron','Riju']])
data_list.append([datetime.datetime(2017, 11, 10),36,"Saadian Tombs",'Marrakesh',"Morocco",'Geneva','Marrakesh',"Medina of Marrakesh",['Tony','Cameron','Riju']])
data_list.append([datetime.datetime(2017, 11, 10),1,"Bab Agnaou",'Marrakesh',"Morocco",'Geneva','Marrakesh',"Medina of Marrakesh",['Tony','Cameron','Riju']])
data_list.append([datetime.datetime(2017, 11, 10),4,"Djemaa el Fna",'Marrakesh',"Morocco",'Geneva','Marrakesh',"Medina of Marrakesh",['Tony','Cameron','Riju']])
data_list.append([datetime.datetime(2017, 11, 11),6,"Tizi N'Tichka","Tizi N'Tichka Pass","Morocco",'Marrakesh','Marrakesh',"",['Tony','Cameron','Riju']])
data_list.append([datetime.datetime(2017, 11, 11),26,"Kasbah","Telouet","Morocco",'Marrakesh','Marrakesh',"",['Tony','Cameron','Riju']])
data_list.append([datetime.datetime(2017, 11, 11),39,"Ksar of Ait-Ben-Haddou","Ait-Ben-Haddou","Morocco",'Marrakesh','Marrakesh',"Ksar of Ait-Ben-Haddou",['Tony','Cameron','Riju']])
data_list.append([datetime.datetime(2017, 11, 11),1,"Koutoubia Mosque",'Marrakesh',"Morocco",'Marrakesh','Marrakesh',"Medina of Marrakesh",['Tony','Cameron','Riju']])
data_list.append([datetime.datetime(2017, 11, 12),55,"Ben Youssef Mederssa",'Marrakesh',"Morocco",'Marrakesh','Marrakesh',"Medina of Marrakesh",['Tony','Cameron','Riju']])
data_list.append([datetime.datetime(2017, 11, 12),3,"Almoravidic Kouba",'Marrakesh',"Morocco",'Marrakesh','Marrakesh',"Medina of Marrakesh",['Tony','Cameron','Riju']])
data_list.append([datetime.datetime(2017, 11, 12),43,"Mnebhi Palace - Marrakesh Museum",'Marrakesh',"Morocco",'Marrakesh','Marrakesh',"Medina of Marrakesh",['Tony','Cameron','Riju']])
data_list.append([datetime.datetime(2017, 11, 12),10,"Jardin Secret",'Marrakesh',"Morocco",'Marrakesh','Marrakesh',"Medina of Marrakesh",['Tony','Cameron','Riju']])
data_list.append([datetime.datetime(2017, 11, 12),5,"Djemaa el Fna",'Marrakesh',"Morocco",'Marrakesh','Marrakesh',"Medina of Marrakesh",['Tony','Cameron','Riju']])
data_list.append([datetime.datetime(2017, 11, 12),2,"Koutoubia Mosque",'Marrakesh',"Morocco",'Marrakesh','Marrakesh',"Medina of Marrakesh",['Tony','Cameron','Riju']])
data_list.append([datetime.datetime(2017, 11, 13),1,"Menara Gardens",'Marrakesh',"Morocco",'Marrakesh','Geneva',"",['Tony','Cameron','Riju']])
data_list.append([datetime.datetime(2017, 11, 13),1,"Badia Palace",'Marrakesh',"Morocco",'Marrakesh','Marrakesh',"Medina of Marrakesh",['Tony','Cameron','Riju']])
#france unesco
data_list.append([datetime.datetime(2017, 11, 19),50,"Abbey of Fontenay",'Marmagne',"France",'Geneva','Geneva',"Cistercian Abbey of Fontenay",['Andrew']])
data_list.append([datetime.datetime(2017, 11, 19),12,"Saltworks",'Arc-et-Senans',"France",'Geneva','Geneva',"From the Great Saltworks of Salins-les-Bains to the Royal Saltworks of Arc-et-Senans, the Production of Open-pan Salt",['Andrew']])
data_list.append([datetime.datetime(2017, 11, 19),1,"Porte de Rivotte",'Besancon',"France",'Geneva','Geneva',"Fortifications of Vauban",['Andrew']])
data_list.append([datetime.datetime(2017, 11, 19),12,"Citadel",'Besancon',"France",'Geneva','Geneva',"Fortifications of Vauban",['Andrew']])
data_list.append([datetime.datetime(2017, 11, 19),18,"Cathedral",'Besancon',"France",'Geneva','Geneva',"Fortifications of Vauban",['Andrew']])
data_list.append([datetime.datetime(2017, 11, 19),1,"Roman Temple",'Besancon',"France",'Geneva','Geneva',"Fortifications of Vauban",['Andrew']])
#lyon done
data_list.append([datetime.datetime(2017, 12, 9),1,"Cathedral",'Lyon',"France",'Geneva','Geneva',"Lyon",['Riju','Reyer','Tony','Cameron','Rachel','Jan','Juliette','Juliana','Paul']])
data_list.append([datetime.datetime(2017, 12, 9),4,"Notre-Dame de Fourviere",'Lyon',"France",'Geneva','Geneva',"Lyon",['Riju','Reyer','Tony','Cameron','Rachel','Jan','Juliette','Juliana','Paul']])
data_list.append([datetime.datetime(2017, 12, 9),9,"Place Bellecour",'Lyon',"France",'Geneva','Geneva',"Lyon",['Riju','Reyer','Tony','Cameron','Rachel','Jan','Juliette','Juliana','Paul']])
data_list.append([datetime.datetime(2017, 12, 9),1,"Hotel de Ville",'Lyon',"France",'Geneva','Geneva',"Lyon",['Riju','Reyer','Tony','Cameron','Rachel','Jan','Juliette','Juliana','Paul']])
data_list.append([datetime.datetime(2017, 12, 9),1,"Opera",'Lyon',"France",'Geneva','Geneva',"Lyon",['Riju','Reyer','Tony','Cameron','Rachel','Jan','Juliette','Juliana','Paul']])
data_list.append([datetime.datetime(2017, 12, 9),4,"St Nonaventura",'Lyon',"France",'Geneva','Geneva',"Lyon",['Riju','Reyer','Tony','Cameron','Rachel','Jan','Juliette','Juliana','Paul']])
#shanghai done
data_list.append([datetime.datetime(2017, 12, 30),4,"People's Square",'Shanghai',"China",'Flight ZRH-BVG','Shanghai',"",[]])
data_list.append([datetime.datetime(2017, 12, 30),3,"Oriental Pearl TV Tower",'Shanghai',"China",'Flight ZRH-BVG','Shanghai',"",[]])
data_list.append([datetime.datetime(2017, 12, 30),3,"The Bund",'Shanghai',"China",'Flight ZRH-BVG','Shanghai',"",[]])
data_list.append([datetime.datetime(2017, 12, 31),13,"The Bund",'Shanghai',"China",'Shanghai','Shanghai',"",['Siyi']])
data_list.append([datetime.datetime(2017, 12, 31),8,"Oriental Pearl TV Tower",'Shanghai',"China",'Shanghai','Shanghai',"",['Siyi']])
data_list.append([datetime.datetime(2017, 12, 31),9,"Shanghai Old Town",'Shanghai',"China",'Shanghai','Shanghai',"",['Siyi']])
data_list.append([datetime.datetime(2017, 12, 31),5,"Shanghai Old Town Yuyan Garden",'Shanghai',"China",'Shanghai','Shanghai',"",['Siyi']])

# %%
#2018
#china done
data_list.append([datetime.datetime(2018, 1, 1),3,"Oriental Pearl TV Tower",'Shanghai',"China",'Shanghai','Suzhou',"",['Siyi']])
data_list.append([datetime.datetime(2018, 1, 1),1,"The Bund",'Shanghai',"China",'Shanghai','Suzhou',"",['Siyi']])
data_list.append([datetime.datetime(2018, 1, 1),3,"Xuanmiao Temple",'Suzhou',"China",'Shanghai','Suzhou',"",[]])
data_list.append([datetime.datetime(2018, 1, 2),1,"City Wall",'Suzhou',"China",'Suzhou','Suzhou',"The Grand Canal",[]])
data_list.append([datetime.datetime(2018, 1, 2),41,"West Lake",'Hangzhou',"China",'Suzhou','Suzhou',"West Lake Cultural Landscape of Hangzhou",[]])
data_list.append([datetime.datetime(2018, 1, 2),2,"Bai Juyi Monument",'Hangzhou',"China",'Suzhou','Suzhou',"West Lake Cultural Landscape of Hangzhou",[]])
data_list.append([datetime.datetime(2018, 1, 2),7,"Baochu Pagoda & Rock Garden",'Hangzhou',"China",'Suzhou','Suzhou',"West Lake Cultural Landscape of Hangzhou",[]])
data_list.append([datetime.datetime(2018, 1, 2),45,"Leifeng Pagoda",'Hangzhou',"China",'Suzhou','Suzhou',"West Lake Cultural Landscape of Hangzhou",[]])
data_list.append([datetime.datetime(2018, 1, 2),10,"Zhejiang Provincial Museum",'Hangzhou',"China",'Suzhou','Suzhou',"West Lake Cultural Landscape of Hangzhou",[]])
data_list.append([datetime.datetime(2018, 1, 2),6,"Zongshan Park",'Hangzhou',"China",'Suzhou','Suzhou',"West Lake Cultural Landscape of Hangzhou",[]])
data_list.append([datetime.datetime(2018, 1, 2),13,"Temple of General Yue Fei",'Hangzhou',"China",'Suzhou','Suzhou',"West Lake Cultural Landscape of Hangzhou",[]])
data_list.append([datetime.datetime(2018, 1, 2),20,"Island of three Ponds",'Hangzhou',"China",'Suzhou','Suzhou',"West Lake Cultural Landscape of Hangzhou",[]])
data_list.append([datetime.datetime(2018, 1, 3),63,"Humble Administrator's Garden",'Suzhou',"China",'Suzhou','Kunshan',"Classical Gardens of Suzhou",[]])
data_list.append([datetime.datetime(2018, 1, 3),27,"Lion Grove Garden",'Suzhou',"China",'Suzhou','Kunshan',"Classical Gardens of Suzhou",[]])
data_list.append([datetime.datetime(2018, 1, 3),10,"Mountain Villa with Embracing Beauty",'Suzhou',"China",'Suzhou','Kunshan',"Classical Gardens of Suzhou",[]])
data_list.append([datetime.datetime(2018, 1, 3),16,"Garden of Cultivation",'Suzhou',"China",'Suzhou','Kunshan',"Classical Gardens of Suzhou",[]])
data_list.append([datetime.datetime(2018, 1, 3),5,"Chenghuang Temple",'Suzhou',"China",'Suzhou','Kunshan',"",[]])
data_list.append([datetime.datetime(2018, 1, 3),9,"Xuanmiao Temple",'Suzhou',"China",'Suzhou','Kunshan',"",[]])
data_list.append([datetime.datetime(2018, 1, 3),21,"Luzhi Watertown",'Luzhi Town',"China",'Suzhou','Kunshan',"",['Siyi']])
data_list.append([datetime.datetime(2018, 1, 3),4,"Xiaozai Residence",'Luzhi Town',"China",'Suzhou','Kunshan',"",['Siyi']])
data_list.append([datetime.datetime(2018, 1, 3),3,"Shen Residence",'Luzhi Town',"China",'Suzhou','Kunshan',"",['Siyi']])
data_list.append([datetime.datetime(2018, 1, 3),8,"Bacheng-Yangcheng Lake Old Town",'Kunshan',"China",'Suzhou','Kunshan',"",['Siyi']])
data_list.append([datetime.datetime(2018, 1, 4),46,"Chaotian Palace - Nanjing City Museum",'Nanjing',"China",'Kunshan','Nanjing',"",[]])
data_list.append([datetime.datetime(2018, 1, 4),59,"Presidential Palace",'Nanjing',"China",'Kunshan','Nanjing',"",[]])
data_list.append([datetime.datetime(2018, 1, 6),49,"Xiaoling Mausoleum",'Nanjing',"China",'Nanjing','Nanjing',"Imperial Tombs of the Ming and Qing Dynasties",["Zhicheng",'Siyi']])
data_list.append([datetime.datetime(2018, 1, 6),9,"Purple Mountain",'Nanjing',"China",'Nanjing','Nanjing',"",["Zhicheng",'Siyi']])
data_list.append([datetime.datetime(2018, 1, 6),16,"Dr Sun Yat-sen Mausoleum",'Nanjing',"China",'Nanjing','Nanjing',"",["Zhicheng",'Siyi']])
data_list.append([datetime.datetime(2018, 1, 6),3,"Open-air Music Hall",'Nanjing',"China",'Nanjing','Nanjing',"",["Zhicheng",'Siyi']])
data_list.append([datetime.datetime(2018, 1, 6),16,"Meiling Villa",'Nanjing',"China",'Nanjing','Nanjing',"",["Zhicheng",'Siyi']])
data_list.append([datetime.datetime(2018, 1, 6),19,"Jiming Temple",'Nanjing',"China",'Nanjing','Nanjing',"",[]])
data_list.append([datetime.datetime(2018, 1, 6),8,"City Wall",'Nanjing',"China",'Nanjing','Nanjing',"",[]])
data_list.append([datetime.datetime(2018, 1, 6),11,"Zhonghuamen",'Nanjing',"China",'Nanjing','Nanjing',"",[]])
data_list.append([datetime.datetime(2018, 1, 6),81,"Nanjing Museum",'Nanjing',"China",'Nanjing','Beijing',"",[]])
data_list.append([datetime.datetime(2018, 1, 6),10,"Ming Palace (Forbidden City)",'Nanjing',"China",'Nanjing','Beijing',"",[]])
data_list.append([datetime.datetime(2018, 1, 6),2,"Nanjing South Station",'Nanjing',"China",'Nanjing','Beijing',"",[]])
data_list.append([datetime.datetime(2018, 1, 7),2,"Tian'anmen Square",'Beijing',"China",'Beijing','Beijing',"",[]])
data_list.append([datetime.datetime(2018, 1, 7),6,"Forbidden City",'Beijing',"China",'Beijing','Beijing',"Imperial Palaces of the Ming and Qing Dynasties in Beijing and Shenyang",[]])
data_list.append([datetime.datetime(2018, 1, 7),4,"Tian'anmen Square",'Beijing',"China",'Beijing','Beijing',"",['Serena',"Lingpao"]])
data_list.append([datetime.datetime(2018, 1, 7),291,"Forbidden City",'Beijing',"China",'Beijing','Beijing',"Imperial Palaces of the Ming and Qing Dynasties in Beijing and Shenyang",['Serena',"Lingpao"]])
data_list.append([datetime.datetime(2018, 1, 7),76,"Chinese National Museum",'Beijing',"China",'Beijing','Beijing',"",['Serena',"Lingpao"]])
data_list.append([datetime.datetime(2018, 1, 7),1,"Jingshan Park",'Beijing',"China",'Beijing','Beijing',"",['Serena',"Lingpao"]])
data_list.append([datetime.datetime(2018, 1, 8),7,"The Great Wall",'Juyongguan',"China",'Beijing','Beijing',"The Great Wall",[]])
data_list.append([datetime.datetime(2018, 1, 8),77,"The Great Wall",'Badaling',"China",'Beijing','Beijing',"The Great Wall",[]])
data_list.append([datetime.datetime(2018, 1, 8),40,"Yonghe Temple",'Beijing',"China",'Beijing','Beijing',"",[]])
data_list.append([datetime.datetime(2018, 1, 8),4,"Tian'anmen Square",'Beijing',"China",'Beijing','Beijing',"",[]])
data_list.append([datetime.datetime(2018, 1, 8),2,"Mao Mausoleum",'Beijing',"China",'Beijing','Beijing',"",[]])
data_list.append([datetime.datetime(2018, 1, 8),1,"Chinese National Museum",'Beijing',"China",'Beijing','Beijing',"",[]])
data_list.append([datetime.datetime(2018, 1, 8),19,"Zhengyangmen",'Beijing',"China",'Beijing','Beijing',"",[]])
data_list.append([datetime.datetime(2018, 1, 9),117,"Temple of Heaven",'Beijing',"China",'Beijing','Beijing',"Temple of Heaven",[]])
data_list.append([datetime.datetime(2018, 1, 9),176,"Summer Palace",'Beijing',"China",'Beijing','Beijing',"Summer Palace, an Imperial Garden in Beijing",[]])
data_list.append([datetime.datetime(2018, 1, 9),54,"Olympic Green",'Beijing',"China",'Beijing','Beijing',"",[]])
data_list.append([datetime.datetime(2018, 1, 10),3,"Drum Tower",'Beijing',"China",'Beijing','Beijing',"",[]])
data_list.append([datetime.datetime(2018, 1, 10),2,"Bell Tower",'Beijing',"China",'Beijing','Beijing',"",[]])
data_list.append([datetime.datetime(2018, 1, 10),2,"Houhai & Qianhai Lakes",'Beijing',"China",'Beijing','Beijing',"Grand Canal",[]])
data_list.append([datetime.datetime(2018, 1, 10),55,"Prince Gong's House",'Beijing',"China",'Beijing','Beijing',"",[]])
data_list.append([datetime.datetime(2018, 1, 10),111,"Beihai Park",'Beijing',"China",'Beijing','Beijing',"",[]])
data_list.append([datetime.datetime(2018, 1, 10),8,"Jingshan Park",'Beijing',"China",'Beijing','Beijing',"",[]])
data_list.append([datetime.datetime(2018, 1, 10),14,"Forbidden City",'Beijing',"China",'Beijing','Beijing',"Imperial Palaces of the Ming and Qing Dynasties in Beijing and Shenyang",[]])
data_list.append([datetime.datetime(2018, 1, 10),4,"Tian'anmen Square",'Beijing',"China",'Beijing','Beijing',"",[]])
data_list.append([datetime.datetime(2018, 1, 10),4,"Mao Mausoleum",'Beijing',"China",'Beijing','Beijing',"",[]])
data_list.append([datetime.datetime(2018, 1, 10),2,"Zhengyangmen",'Beijing',"China",'Beijing','Beijing',"",[]])
data_list.append([datetime.datetime(2018, 1, 11),106,"Longmen Grottoes",'Luoyang',"China",'Beijing',"Xi'an","Longmen Grottoes",[]])
data_list.append([datetime.datetime(2018, 1, 11),15,"Xiangshan Temple",'Luoyang',"China",'Beijing',"Xi'an","Longmen Grottoes",[]])
data_list.append([datetime.datetime(2018, 1, 11),2,"Jiang & Song's Villa",'Luoyang',"China",'Beijing',"Xi'an","",[]])
data_list.append([datetime.datetime(2018, 1, 11),6,"Baijuyi Cemetery",'Luoyang',"China",'Beijing',"Xi'an","Longmen Grottoes",[]])
data_list.append([datetime.datetime(2018, 1, 11),3,"Bell Tower","Xi'an","China",'Beijing',"Xi'an","",[]])
data_list.append([datetime.datetime(2018, 1, 11),8,"Drum Tower","Xi'an","China",'Beijing',"Xi'an","",[]])
data_list.append([datetime.datetime(2018, 1, 11),4,"City Wall","Xi'an","China",'Beijing',"Xi'an","",[]])
data_list.append([datetime.datetime(2018, 1, 11),8,"Yongningmen","Xi'an","China",'Beijing',"Xi'an","",[]])
data_list.append([datetime.datetime(2018, 1, 12),81,"Tomb of Emperor Qinshihuang","Xi'an","China","Xi'an",'Beijing',"Mausoleum of the First Qin Emperor",[]])
data_list.append([datetime.datetime(2018, 1, 12),6,"Green Dragon Temple","Xi'an","China","Xi'an",'Beijing',"",[]])
data_list.append([datetime.datetime(2018, 1, 12),56,"Daci'en Temple","Xi'an","China","Xi'an",'Beijing',"Silk Roads: The Routes Network of Chang'an-Tian Shan Corridor",[]])
data_list.append([datetime.datetime(2018, 1, 12),1,"Bell Tower","Xi'an","China","Xi'an",'Beijing',"",[]])
data_list.append([datetime.datetime(2018, 1, 12),2,"Drum Tower","Xi'an","China","Xi'an",'Beijing',"",[]])
data_list.append([datetime.datetime(2018, 1, 12),3,"City Wall","Xi'an","China","Xi'an",'Beijing',"",[]])
data_list.append([datetime.datetime(2018, 1, 12),2,"Yongningmen","Xi'an","China","Xi'an",'Beijing',"",[]])
data_list.append([datetime.datetime(2018, 1, 12),16,"Mosque","Xi'an","China","Xi'an",'Beijing',"",[]])
data_list.append([datetime.datetime(2018, 1, 12),2,"Bazar","Xi'an","China","Xi'an",'Beijing',"",[]])
data_list.append([datetime.datetime(2018, 1, 13),1,"Yonghe Temple",'Beijing',"China",'Beijing','Beijing',"",[]])
data_list.append([datetime.datetime(2018, 1, 13),16,"Imperial Academy",'Beijing',"China",'Beijing','Beijing',"",[]])
data_list.append([datetime.datetime(2018, 1, 13),29,"Temple of Confucius",'Beijing',"China",'Beijing','Beijing',"",[]])
data_list.append([datetime.datetime(2018, 1, 13),5,"Cathedral of Immaculate Conception",'Beijing',"China",'Beijing','Beijing',"",[]])
data_list.append([datetime.datetime(2018, 1, 13),5,"Mao Mausoleum",'Beijing',"China",'Beijing','Beijing',"",[]])
data_list.append([datetime.datetime(2018, 1, 13),3,"Zhengyangmen",'Beijing',"China",'Beijing','Beijing',"",[]])
data_list.append([datetime.datetime(2018, 1, 15),16,"Two International Finance Centre Observatory",'Hong Kong',"China",'Hong Kong','Hong Kong',"",[]])
data_list.append([datetime.datetime(2018, 1, 15),86,"International Commerce Centre Observatory",'Hong Kong',"China",'Hong Kong','Hong Kong',"",[]])
data_list.append([datetime.datetime(2018, 1, 16),15,"Grand Lisboa",'Macau',"China",'Hong Kong','Hong Kong',"",[]])
data_list.append([datetime.datetime(2018, 1, 16),4,"Cathedral",'Macau',"China",'Hong Kong','Hong Kong',"Historic Centre of Macau",[]])
data_list.append([datetime.datetime(2018, 1, 16),2,"Na Tcha Temple",'Macau',"China",'Hong Kong','Hong Kong',"Historic Centre of Macau",[]])
data_list.append([datetime.datetime(2018, 1, 16),2,"Monte Forte",'Macau',"China",'Hong Kong','Hong Kong',"Historic Centre of Macau",[]])
data_list.append([datetime.datetime(2018, 1, 16),5,"St Paul",'Macau',"China",'Hong Kong','Hong Kong',"Historic Centre of Macau",[]])
data_list.append([datetime.datetime(2018, 1, 16),3,"St Antony",'Macau',"China",'Hong Kong','Hong Kong',"Historic Centre of Macau",[]])
data_list.append([datetime.datetime(2018, 1, 16),5,"Camoes Garden",'Macau',"China",'Hong Kong','Hong Kong',"Historic Centre of Macau",[]])
data_list.append([datetime.datetime(2018, 1, 16),4,"Dominican Church",'Macau',"China",'Hong Kong','Hong Kong',"Historic Centre of Macau",[]])
data_list.append([datetime.datetime(2018, 1, 16),9,"Largo do Senado",'Macau',"China",'Hong Kong','Hong Kong',"Historic Centre of Macau",[]])
data_list.append([datetime.datetime(2018, 1, 16),9,"Sam Kai Vui Kun Temple",'Macau',"China",'Hong Kong','Hong Kong',"Historic Centre of Macau",[]])
data_list.append([datetime.datetime(2018, 1, 16),1,"Sir Robert Ho Tung Library",'Macau',"China",'Hong Kong','Hong Kong',"Historic Centre of Macau",[]])
data_list.append([datetime.datetime(2018, 1, 16),1,"Dom Pedro V Theatre",'Macau',"China",'Hong Kong','Hong Kong',"Historic Centre of Macau",[]])
data_list.append([datetime.datetime(2018, 1, 16),5,"St Joseph",'Macau',"China",'Hong Kong','Hong Kong',"Historic Centre of Macau",[]])
data_list.append([datetime.datetime(2018, 1, 16),3,"St Lawrence",'Macau',"China",'Hong Kong','Hong Kong',"Historic Centre of Macau",[]])
data_list.append([datetime.datetime(2018, 1, 16),7,"Mandarin's House",'Macau',"China",'Hong Kong','Hong Kong',"Historic Centre of Macau",[]])
data_list.append([datetime.datetime(2018, 1, 16),2,"Moorish Barracks",'Macau',"China",'Hong Kong','Hong Kong',"Historic Centre of Macau",[]])
data_list.append([datetime.datetime(2018, 1, 16),4,"A-Ma Temple",'Macau',"China",'Hong Kong','Hong Kong',"Historic Centre of Macau",[]])
data_list.append([datetime.datetime(2018, 1, 16),6,"Lou Kau House",'Macau',"China",'Hong Kong','Hong Kong',"Historic Centre of Macau",[]])
data_list.append([datetime.datetime(2018, 1, 16),6,"Fisherman's Wharf",'Macau',"China",'Hong Kong','Hong Kong',"",[]])
data_list.append([datetime.datetime(2018, 1, 16),5,"St John's Cathedral",'Hong Kong',"China",'Hong Kong','Hong Kong',"",[]])
data_list.append([datetime.datetime(2018, 1, 16),17,"Zoological & Botanical Gardens",'Hong Kong',"China",'Hong Kong','Hong Kong',"",[]])
data_list.append([datetime.datetime(2018, 1, 16),2,"French Mission Building",'Hong Kong',"China",'Hong Kong','Hong Kong',"",[]])
data_list.append([datetime.datetime(2018, 1, 17),13,"Victoria Peak Panoramic Walk",'Hong Kong',"China",'Hong Kong','Hong Kong',"",[]])
data_list.append([datetime.datetime(2018, 1, 17),8,"Cathedral of Immaculate Conception",'Hong Kong',"China",'Hong Kong','Hong Kong',"",[]])
data_list.append([datetime.datetime(2018, 1, 15),15,"Tian Tan Buddha",'Hong Kong',"China",'Hong Kong','Flight HKG-FRA',"",[]])
data_list.append([datetime.datetime(2018, 1, 15),31,"Po Lin Monastery",'Hong Kong',"China",'Hong Kong','Flight HKG-FRA',"",[]])
data_list.append([datetime.datetime(2018, 1, 15),6,"Ngong Ping Piazza",'Hong Kong',"China",'Hong Kong','Flight HKG-FRA',"",[]])

# %%
#Lausanne done
data_list.append([datetime.datetime(2018,1,28),31,"Palais de Rumine","Lausanne","Switzerland","Geneva","Geneva","",['Hannsjoerg']])
data_list.append([datetime.datetime(2018,1,28),13,"Cathedral","Lausanne","Switzerland","Geneva","Geneva","",['Hannsjoerg']])
#nyon done
data_list.append([datetime.datetime(2018,2,4),9,"Chateau","Nyon","Switzerland","Geneva","Geneva","",['Artur','Heidrun','Hannsjoerg']])
data_list.append([datetime.datetime(2018,2,4),1,"Roman Temple","Nyon","Switzerland","Geneva","Geneva","",['Artur','Heidrun','Hannsjoerg']])
data_list.append([datetime.datetime(2018,2,4),7,"Roman Museum","Nyon","Switzerland","Geneva","Geneva","",['Artur','Heidrun','Hannsjoerg']])
#geneva
data_list.append([datetime.datetime(2018,2,18),3,"Maison Clarte","Geneva","Switzerland","Geneva","Geneva","The Architectural Work of Le Corbusier",[]])
#albi & Toulouse
data_list.append([datetime.datetime(2018,3,3),1,"Aoeroport Toulouse Blagnac","Toulouse","France","Geneva","Toulouse","",[]])
data_list.append([datetime.datetime(2018,3,3),105,"Cathedral","Albi","France","Geneva","Toulouse","Episcopal City of Albi",[]])
data_list.append([datetime.datetime(2018,3,3),9,"Palais de la Berbie","Albi","France","Geneva","Toulouse","Episcopal City of Albi",[]])
data_list.append([datetime.datetime(2018,3,3),2,"Pont Vieux","Albi","France","Geneva","Toulouse","",[]])
data_list.append([datetime.datetime(2018,3,3),5,"Collegiale St Salvi","Albi","France","Geneva","Toulouse","",[]])
data_list.append([datetime.datetime(2018,3,3),4,"Hotel Reynes","Albi","France","Geneva","Toulouse","",[]])
data_list.append([datetime.datetime(2018,3,3),2,"Maison Enjalbert","Albi","France","Geneva","Toulouse","",[]])
data_list.append([datetime.datetime(2018,3,3),6,"Chapelle des Carmelites","Toulouse","France","Geneva","Toulouse","",[]])
data_list.append([datetime.datetime(2018,3,3),63,"Basilique St-Sernin","Toulouse","France","Geneva","Toulouse","Routes of Santiago de Compostela",[]])
data_list.append([datetime.datetime(2018,3,3),4,"Capitole","Toulouse","France","Geneva","Toulouse","",[]])
data_list.append([datetime.datetime(2018,3,3),1,"St Jerome","Toulouse","France","Geneva","Toulouse","",[]])
data_list.append([datetime.datetime(2018,3,3),25,"Cathedral","Toulouse","France","Geneva","Toulouse","",[]])
data_list.append([datetime.datetime(2018,3,3),1,"Donjon","Toulouse","France","Geneva","Toulouse","",[]])
data_list.append([datetime.datetime(2018,3,3),1,"War Monument of Haute-Garonne","Toulouse","France","Geneva","Toulouse","",[]])
data_list.append([datetime.datetime(2018,3,3),2,"Fontaine Boulbonne","Toulouse","France","Geneva","Toulouse","",[]])
data_list.append([datetime.datetime(2018,3,3),2,"Canal du Midi","Toulouse","France","Geneva","Toulouse","Canal du Midi",[]])
data_list.append([datetime.datetime(2018,3,4),4,"Canal du Midi","Toulouse","France","Toulouse","Geneva","Canal du Midi",[]])
data_list.append([datetime.datetime(2018,3,4),21,"Cathedral","Toulouse","France","Toulouse","Geneva","",[]])
data_list.append([datetime.datetime(2018,3,4),31,"Hotel d'Assezat","Toulouse","France","Toulouse","Geneva","",[]])
data_list.append([datetime.datetime(2018,3,4),4,"Basilique Notre-Dame de la Daurade","Toulouse","France","Toulouse","Geneva","",[]])
data_list.append([datetime.datetime(2018,3,4),42,"Jacobine Convent","Toulouse","France","Toulouse","Geneva","",[]])
data_list.append([datetime.datetime(2018,3,4),25,"Capitole","Toulouse","France","Toulouse","Geneva","",[]])
data_list.append([datetime.datetime(2018,3,4),2,"Donjon","Toulouse","France","Toulouse","Geneva","",[]])
data_list.append([datetime.datetime(2018,3,4),4,"Basilique St-Sernin","Toulouse","France","Toulouse","Geneva","Routes of Santiago de Compostela",[]])
data_list.append([datetime.datetime(2018,3,4),2,"Notre-Dame du Taur","Toulouse","France","Toulouse","Geneva","",[]])
data_list.append([datetime.datetime(2018,3,4),2,"Aoeroport Toulouse Blagnac","Toulouse","France","Toulouse","Geneva","",[]])

# %%
#brussels I done
data_list.append([datetime.datetime(2018,3,10),1,"Brussel-Centraal Station","Brussels","Belgium","Brussels","Brussels","",[]])
data_list.append([datetime.datetime(2018,3,10),2,"Amsterdam Centraal","Amsterdam","Netherlands","Brussels","Brussels","",['Mohamed']])
data_list.append([datetime.datetime(2018,3,10),1,"Beurs van Berlage","Amsterdam","Netherlands","Brussels","Brussels","",['Mohamed']])
data_list.append([datetime.datetime(2018,3,10),70,"Royal Palace","Amsterdam","Netherlands","Brussels","Brussels","",['Mohamed']])
data_list.append([datetime.datetime(2018,3,10),2,"Herengracht",'Amsterdam',"Netherlands",'Brussels','Brussels',"Seventeenth-Century Canal Ring Area of Amsterdam inside the Singelgracht",['Heidrun','Hannsjoerg','Artur']])
data_list.append([datetime.datetime(2018,3,10),18,"Rijksmuseum",'Amsterdam',"Netherlands",'Brussels','Brussels',"Seventeenth-Century Canal Ring Area of Amsterdam inside the Singelgracht",['Heidrun','Hannsjoerg','Artur']])
data_list.append([datetime.datetime(2018,3,10),2,"Van Gogh Museum",'Amsterdam',"Netherlands",'Brussels','Brussels',"Seventeenth-Century Canal Ring Area of Amsterdam inside the Singelgracht",['Heidrun','Hannsjoerg','Artur']])
data_list.append([datetime.datetime(2018,3,10),1,"Nieuwe Kerk",'Amsterdam',"Netherlands",'Brussels','Brussels',"Seventeenth-Century Canal Ring Area of Amsterdam inside the Singelgracht",['Heidrun','Hannsjoerg','Artur']])
data_list.append([datetime.datetime(2018,3,10),1,"He Hua Temple",'Amsterdam',"Netherlands",'Brussels','Brussels',"Seventeenth-Century Canal Ring Area of Amsterdam inside the Singelgracht",['Heidrun','Hannsjoerg','Artur']])
data_list.append([datetime.datetime(2018,3,11),1,"Place d'Agora","Brussels","Belgium","Brussels","Brussels","",['Mohamed']])
data_list.append([datetime.datetime(2018,3,11),1,"Galeries Royal St-Hubert","Brussels","Belgium","Brussels","Brussels","",['Mohamed']])
data_list.append([datetime.datetime(2018,3,11),12,"Grand Place",'Brussels',"Belgium",'Brussels','Brussels',"Grand Place",['Mohamed']])
data_list.append([datetime.datetime(2018,3,11),60,"Stadhuis",'Brussels',"Belgium",'Brussels','Geneva',"Grand Place",['Mohamed']])
data_list.append([datetime.datetime(2018,3,11),1,"Maison Roi",'Brussels',"Belgium",'Geneva','Brussels',"Grand Place",['Mohamed']])
data_list.append([datetime.datetime(2018,3,11),2,"Notre-Dame du Finistere",'Brussels',"Belgium",'Brussels','Geneva',"",['Mohamed']])
data_list.append([datetime.datetime(2018,3,11),3,"Nicolas Church",'Brussels',"Belgium",'Brussels','Geneva',"",['Mohamed']])
data_list.append([datetime.datetime(2018,3,11),12,"Cathedral",'Brussels',"Belgium",'Brussels','Geneva',"",['Mohamed']])
data_list.append([datetime.datetime(2018,3,11),1,"Royal Palace",'Brussels',"Belgium",'Brussels','Geneva',"",['Mohamed']])
data_list.append([datetime.datetime(2018,3,11),3,"Saint Jacques-sur-Coudenberg",'Brussels',"Belgium",'Brussels','Geneva',"",['Mohamed']])
data_list.append([datetime.datetime(2018,3,11),38,"Royal Museum of Fine Arts",'Brussels',"Belgium",'Brussels','Geneva',"",['Mohamed']])
data_list.append([datetime.datetime(2018,3,11),2,"Anneessen Gate",'Brussels',"Belgium",'Brussels','Geneva',"",['Mohamed']])
data_list.append([datetime.datetime(2018,3,11),11,"Notre-Dame du Sablon",'Brussels',"Belgium",'Brussels','Geneva',"",['Mohamed']])
data_list.append([datetime.datetime(2018,3,11),1,"National Basilica",'Koekelberg',"Belgium",'Brussels','Geneva',"",['Mohamed']])
data_list.append([datetime.datetime(2018,3,11),1,"Atomium",'Brussels',"Belgium",'Brussels','Geneva',"",['Mohamed']])
data_list.append([datetime.datetime(2018,3,11),3,"Palace of Justice",'Brussels',"Belgium",'Brussels','Geneva',"",['Mohamed']])
#iceland
data_list.append([datetime.datetime(2018,3,28),1,"The Sun Voyager",'Reykjavik',"Iceland",'Geneva','Reykjavik',"",['Rachel','Reyer','Riju']])
data_list.append([datetime.datetime(2018,3,28),1,"Hallgrimskirkja",'Reykjavik',"Iceland",'Geneva','Reykjavik',"",['Rachel','Reyer','Riju']])
data_list.append([datetime.datetime(2018,3,28),6,"Harpa Concert Hall",'Reykjavik',"Iceland",'Geneva','Reykjavik',"",['Rachel','Reyer','Riju']])
data_list.append([datetime.datetime(2018,3,29),18,"Seljalandsfoss",'Iceland',"Iceland",'Reykjavik','Reykjavik',"",['Rachel','Reyer','Riju']])
data_list.append([datetime.datetime(2018,3,29),11,"Skogafoss",'Iceland',"Iceland",'Reykjavik','Reykjavik',"",['Rachel','Reyer','Riju']])
data_list.append([datetime.datetime(2018,3,29),2,"Steinbogafoss",'Iceland',"Iceland",'Reykjavik','Reykjavik',"",['Rachel','Reyer','Riju']])
data_list.append([datetime.datetime(2018,3,29),31,"Reynisfjara Black Sand Beach",'Vik i Myrdal',"Iceland",'Reykjavik','Reykjavik',"",['Rachel','Reyer','Riju']])
data_list.append([datetime.datetime(2018,3,29),110,"Solheimajoekull",'Vik i Myrdal',"Iceland",'Reykjavik','Reykjavik',"",['Rachel','Reyer','Riju']])
data_list.append([datetime.datetime(2018,3,29),1,"City Hall",'Reykjavik',"Iceland",'Reykjavik','Reykjavik',"",['Rachel','Reyer','Riju']])
data_list.append([datetime.datetime(2018,3,29),1,"Hallgrimskirkja",'Reykjavik',"Iceland",'Reykjavik','Reykjavik',"",['Rachel','Reyer','Riju']])
data_list.append([datetime.datetime(2018,3,30),35,"Hafnarfjoerthur Lava Cave",'Iceland"',"Iceland",'Reykjavik','Reykjavik',"",['Rachel','Reyer','Riju']])
data_list.append([datetime.datetime(2018,3,30),31,"Thingvellir National Park",'Iceland"',"Iceland",'Reykjavik','Reykjavik',"Thingvellir National Park",['Rachel','Reyer','Riju']])
data_list.append([datetime.datetime(2018,3,30),13,"Thingvellir National Park",'Iceland"',"Iceland",'Reykjavik','Reykjavik',"",['Rachel','Reyer','Riju']])
data_list.append([datetime.datetime(2018,3,30),21,"Gullfoss",'Iceland"',"Iceland",'Reykjavik','Reykjavik',"",['Rachel','Reyer','Riju']])
data_list.append([datetime.datetime(2018,3,30),33,"Geyser Field",'Haukadalur Valley"',"Iceland",'Reykjavik','Reykjavik',"",['Rachel','Reyer','Riju']])
data_list.append([datetime.datetime(2018,3,31),12,"Hallgrimskirkja",'Reykjavik',"Iceland",'Reykjavik','Geneva',"",['Riju']])
data_list.append([datetime.datetime(2018,3,31),2,"Leif Eriksson Monument",'Reykjavik',"Iceland",'Reykjavik','Geneva',"",['Riju']])
data_list.append([datetime.datetime(2018,3,31),2,"City Hall",'Reykjavik',"Iceland",'Reykjavik','Geneva',"",['Riju']])
data_list.append([datetime.datetime(2018,3,31),4,"Althing",'Reykjavik',"Iceland",'Reykjavik','Geneva',"",['Riju']])
data_list.append([datetime.datetime(2018,3,31),12,"Christ King Cathedral",'Reykjavik',"Iceland",'Reykjavik','Geneva',"",['Riju']])
data_list.append([datetime.datetime(2018,3,31),1,"Hallgrimskirkja",'Reykjavik',"Iceland",'Reykjavik','Geneva',"",['Rachel','Reyer','Riju']])
data_list.append([datetime.datetime(2018,3,31),3,"Keflavik International Airport",'Reykjavik',"Iceland",'Reykjavik','Geneva',"",['Rachel','Reyer','Riju']])
#valais
data_list.append([datetime.datetime(2018,4,7),5,"Majorie",'Sion',"Switzerland",'Geneva','Geneva',"",['Artur','Heidrun']])
data_list.append([datetime.datetime(2018,4,7),10,"Chateau Tourbillon",'Sion',"Switzerland",'Geneva','Geneva',"",['Artur','Heidrun']])
data_list.append([datetime.datetime(2018,4,7),19,"Chateau Valere",'Sion',"Switzerland",'Geneva','Geneva',"",['Artur','Heidrun']])
data_list.append([datetime.datetime(2018,4,7),11,"Cathedral",'Sion',"Switzerland",'Geneva','Geneva',"",['Artur','Heidrun']])
data_list.append([datetime.datetime(2018,4,7),1,"St Theodule",'Sion',"Switzerland",'Geneva','Geneva',"",['Artur','Heidrun']])
data_list.append([datetime.datetime(2018,4,7),6,"Pissevache",'Vernayaz',"Switzerland",'Geneva','Geneva',"",['Artur','Heidrun']])
#copenhagen done
data_list.append([datetime.datetime(2018,4,14),63,"City Hall","Copenhagen","Denmark","Oberding","Frederiksberg","",['Rachel','Reyer','Riju']])
data_list.append([datetime.datetime(2018,4,14),1,"Dragon Fountain","Copenhagen","Denmark","Oberding","Frederiksberg","",['Rachel','Reyer','Riju']])
data_list.append([datetime.datetime(2018,4,14),130,"Rosenborg Palace","Copenhagen","Denmark","Oberding","Frederiksberg","",['Rachel','Reyer','Riju']])
data_list.append([datetime.datetime(2018,4,14),61,"Christiansborg Palace","Copenhagen","Denmark","Oberding","Frederiksberg","",['Rachel','Reyer','Riju']])
data_list.append([datetime.datetime(2018,4,14),4,"Amalienborg Palace","Copenhagen","Denmark","Oberding","Frederiksberg","",['Rachel','Reyer','Riju']])
data_list.append([datetime.datetime(2018,4,14),2,"Frederik's Church","Copenhagen","Denmark","Oberding","Frederiksberg","",['Rachel','Reyer','Riju']])
data_list.append([datetime.datetime(2018,4,14),1,"Cathedral","Copenhagen","Denmark","Oberding","Frederiksberg","",['Rachel','Reyer','Riju']])
data_list.append([datetime.datetime(2018,4,14),17,"Tivoli","Copenhagen","Denmark","Oberding","Frederiksberg","",['Rachel','Reyer','Riju']])
data_list.append([datetime.datetime(2018,4,15),119,"Cathedral","Roskilde","Denmark","Frederiksberg","Geneva","Roskilde Cathedral",['Rachel','Reyer','Riju']])

# %%
#paris 2018
data_list.append([datetime.datetime(2018,4,28),67,"Cathedral","Reims","France","Paris","Paris","Cathedral of Notre-Dame, Former Abbey of Saint-Remi and Palace of Tau, Reims",['Reyer','Christine']])
data_list.append([datetime.datetime(2018,4,28),37,"Palais du Tau","Reims","France","Paris","Paris","Cathedral of Notre-Dame, Former Abbey of Saint-Remi and Palace of Tau, Reims",['Reyer','Christine']])
data_list.append([datetime.datetime(2018,4,28),37,"Basilique St Remi","Reims","France","Paris","Paris","Cathedral of Notre-Dame, Former Abbey of Saint-Remi and Palace of Tau, Reims",['Reyer','Christine']])
data_list.append([datetime.datetime(2018,4,28),35,"Champagne House Taittinger","Reims","France","Paris","Paris","Champagne Hillsides, Houses and Cellars",['Reyer','Christine']])
data_list.append([datetime.datetime(2018,4,28),1,"Opera de Bastille","Paris","France","Paris","Paris","",['Reyer','Christine']])
data_list.append([datetime.datetime(2018,4,28),1,"Place de la Bastille","Paris","France","Paris","Paris","",['Reyer','Christine']])
data_list.append([datetime.datetime(2018,4,29),101,"Chateau de Versailles","Versailles","France",'Paris','Paris',"Palace and Park of Versailles",['Reyer','Christine']])
data_list.append([datetime.datetime(2018,4,29),87,"Chateau de Versailles Gardens","Versailles","France",'Paris','Paris',"Palace and Park of Versailles",['Reyer','Christine']])
data_list.append([datetime.datetime(2018,4,29),1,"Tour St Jacques",'Paris',"France",'Paris','Paris',"Routes of Santiago de Compostela",['Reyer','Christine']])
data_list.append([datetime.datetime(2018,4,29),2,"Conciergerie",'Paris',"France",'Paris','Paris',"Paris, Banks of the Seine",['Reyer','Christine']])
data_list.append([datetime.datetime(2018,4,29),1,"Pont Neuf",'Paris',"France",'Paris','Paris',"Paris, Banks of the Seine",['Reyer','Christine']])
data_list.append([datetime.datetime(2018,4,29),1,"Place du Chatelet",'Paris',"France",'Paris','Paris',"Paris, Banks of the Seine",['Reyer','Christine']])
data_list.append([datetime.datetime(2018,4,29),1,"Palais de Justice",'Paris',"France",'Paris','Paris',"Paris, Banks of the Seine",['Reyer','Christine']])
data_list.append([datetime.datetime(2018,4,29),51,"Sainte Chapelle",'Paris',"France",'Paris','Paris',"Paris, Banks of the Seine",['Reyer','Christine']])
data_list.append([datetime.datetime(2018,4,29),31,"Notre Dame",'Paris',"France",'Paris','Paris',"Paris, Banks of the Seine",[]])
data_list.append([datetime.datetime(2018,4,30),22,"Bayeux Tapestry","Bayeux","France","Paris","Paris","",['Reyer']])
data_list.append([datetime.datetime(2018,4,30),1,"Hotel de Ville","Bayeux","France","Paris","Paris","",['Reyer']])
data_list.append([datetime.datetime(2018,4,30),25,"Cathedral","Bayeux","France","Paris","Paris","",['Reyer']])
data_list.append([datetime.datetime(2018,4,30),14,"Abbaye aux Hommes","Caen","France","Paris","Paris","",['Reyer']])
data_list.append([datetime.datetime(2018,4,30),2,"St-Etienne-le-Vieux","Caen","France","Paris","Paris","",['Reyer']])
data_list.append([datetime.datetime(2018,4,30),3,"St-Sauveur","Caen","France","Paris","Paris","",['Reyer']])
data_list.append([datetime.datetime(2018,4,30),1,"Chateau de Caen","Caen","France","Paris","Paris","",['Reyer']])
data_list.append([datetime.datetime(2018,4,30),15,"St-Pierre","Caen","France","Paris","Paris","",['Reyer']])
data_list.append([datetime.datetime(2018,4,30),3,"Hotel d'Escoville","Caen","France","Paris","Paris","",['Reyer']])
data_list.append([datetime.datetime(2018,4,30),7,"St Jean","Caen","France","Paris","Paris","",['Reyer']])
data_list.append([datetime.datetime(2018,4,30),1,"Donjon","Rouen","France","Paris","Paris","",['Reyer']])
data_list.append([datetime.datetime(2018,4,30),2,"Hotel de Ville","Rouen","France","Paris","Paris","",['Reyer']])
data_list.append([datetime.datetime(2018,4,30),7,"Abbaye St-Ouen","Rouen","France","Paris","Paris","",['Reyer']])
data_list.append([datetime.datetime(2018,4,30),4,"St-Maclou","Rouen","France","Paris","Paris","",['Reyer']])
data_list.append([datetime.datetime(2018,4,30),1,"Place Bathelemy","Rouen","France","Paris","Paris","",['Reyer']])
data_list.append([datetime.datetime(2018,4,30),62,"Cathedral","Rouen","France","Paris","Paris","",['Reyer']])
data_list.append([datetime.datetime(2018,4,30),2,"Gros-Horloge","Rouen","France","Paris","Paris","",['Reyer']])
data_list.append([datetime.datetime(2018,4,30),5,"Palais de Justice","Rouen","France","Paris","Paris","",['Reyer']])
data_list.append([datetime.datetime(2018,4,30),11,"St-Jeanne-d'Arc","Rouen","France","Paris","Paris","",['Reyer']])
data_list.append([datetime.datetime(2018,4,30),3,"Hotel d e Bourgtheroulde","Rouen","France","Paris","Paris","",['Reyer']])
data_list.append([datetime.datetime(2018,4,30),2,"Gare Rouen Rive Droite","Rouen","France","Paris","Paris","",['Reyer']])
data_list.append([datetime.datetime(2018,4,30),1,"Gare du Nord","Paris","France","Paris","Geneva","",['Reyer']])
data_list.append([datetime.datetime(2018,5,1),111,"Cathedral","Amiens","France","Paris","Paris","Amiens Cathedral",['Reyer']])
data_list.append([datetime.datetime(2018,5,1),1,"Belfry","Amiens","France","Paris","Paris","Belfries of Belgium and France",['Reyer']])
data_list.append([datetime.datetime(2018,5,1),3,"Palais de Justice","Amiens","France","Paris","Paris","",['Reyer']])
data_list.append([datetime.datetime(2018,5,1),1,"Gare","Amiens","France","Paris","Paris","",['Reyer']])
data_list.append([datetime.datetime(2018,5,1),108,"Cathedral","Chartres","France","Paris","Paris","Chartres Cathedral",['Reyer']])
data_list.append([datetime.datetime(2018,5,1),2,"Palais Episcopal","Chartres","France","Paris","Paris","",['Reyer']])

# %%
#milano
data_list.append([datetime.datetime(2018,5,19),73,"Certosa di Pavia","Certosa di Pavia","Italy","Milano","Milano","",['Amin']])
data_list.append([datetime.datetime(2018,5,19),17,"Duomo","Pavia","Italy","Milano","Milano","",['Amin']])
data_list.append([datetime.datetime(2018,5,19),24,"San Teodoro","Pavia","Italy","Milano","Milano","",['Amin']])
data_list.append([datetime.datetime(2018,5,19),21,"San Michle Maggiore","Pavia","Italy","Milano","Milano","",['Amin']])
data_list.append([datetime.datetime(2018,5,19),1,"Galleria Arnaboldi","Pavia","Italy","Milano","Milano","",['Amin']])
data_list.append([datetime.datetime(2018,5,19),2,"Piazza della Vittoria","Pavia","Italy","Milano","Milano","",['Amin']])
data_list.append([datetime.datetime(2018,5,19),9,"Santa Maria del Carmine","Pavia","Italy","Milano","Milano","",['Amin']])
data_list.append([datetime.datetime(2018,5,19),19,"San Pietro in Ciel d'Oro","Pavia","Italy","Milano","Milano","",['Amin']])
data_list.append([datetime.datetime(2018,5,19),5,"Santa Maria dei Miracoli","Brescia","Italy","Milano","Milano","",['Amin']])
data_list.append([datetime.datetime(2018,5,19),5,"Piazza della Loggia","Brescia","Italy","Milano","Milano","",['Amin']])
data_list.append([datetime.datetime(2018,5,19),9,"Santa Maria della Carita","Brescia","Italy","Milano","Milano","",['Amin']])
data_list.append([datetime.datetime(2018,5,19),3,"San Zeno al Foro","Brescia","Italy","Milano","Milano","",['Amin']])
data_list.append([datetime.datetime(2018,5,19),11,"Capitol","Brescia","Italy","Milano","Milano","Longobards in Italy. Places of the Power",['Amin']])
data_list.append([datetime.datetime(2018,5,19),9,"Republican Sanctuary","Brescia","Italy","Milano","Milano","Longobards in Italy. Places of the Power",['Amin']])
data_list.append([datetime.datetime(2018,5,19),8,"Roman Theatre","Brescia","Italy","Milano","Milano","Longobards in Italy. Places of the Power",['Amin']])
data_list.append([datetime.datetime(2018,5,19),102,"Santa Giulia Monastery","Brescia","Italy","Milano","Milano","Longobards in Italy. Places of the Power",['Amin']])
data_list.append([datetime.datetime(2018,5,19),15,"Domus dell'Ortaglia","Brescia","Italy","Milano","Milano","Longobards in Italy. Places of the Power",['Amin']])
data_list.append([datetime.datetime(2018,5,19),16,"Duomo Nuovo","Brescia","Italy","Milano","Milano","",['Amin']])
data_list.append([datetime.datetime(2018,5,19),19,"Duomo Vecchio","Brescia","Italy","Milano","Milano","",['Amin']])
data_list.append([datetime.datetime(2018,5,19),5,"Palazzo Martinengo","Brescia","Italy","Milano","Milano","",['Amin']])
data_list.append([datetime.datetime(2018,5,20),2,"Santa Maria Immacolata delle Grazie","Bergamo","Italy","Milano","Milano","",['Amin']])
data_list.append([datetime.datetime(2018,5,20),5,"Piazza Vittorio Veneto","Bergamo","Italy","Milano","Milano","",['Amin']])
data_list.append([datetime.datetime(2018,5,20),39,"Duomo","Bergamo","Italy","Milano","Milano","Venetian Works of Defence between the 16th and 17th",['Amin']])
data_list.append([datetime.datetime(2018,5,20),5,"Baptistery","Bergamo","Italy","Milano","Milano","Venetian Works of Defence between the 16th and 17th",['Amin']])
data_list.append([datetime.datetime(2018,5,20),9,"Capella Colleoni","Bergamo","Italy","Milano","Milano","Venetian Works of Defence between the 16th and 17th",['Amin']])
data_list.append([datetime.datetime(2018,5,20),7,"Palazzo della Ragione","Bergamo","Italy","Milano","Milano","Venetian Works of Defence between the 16th and 17th",['Amin']])
data_list.append([datetime.datetime(2018,5,20),44,"Santa Maria Maggiore","Bergamo","Italy","Milano","Milano","Venetian Works of Defence between the 16th and 17th",['Amin']])
data_list.append([datetime.datetime(2018,5,20),8,"Town Walls","Bergamo","Italy","Milano","Milano","Venetian Works of Defence between the 16th and 17th",['Amin']])
data_list.append([datetime.datetime(2018,5,20),11,"San Michele al Pozzo Bianco","Bergamo","Italy","Milano","Milano","Venetian Works of Defence between the 16th and 17th",['Amin']])
data_list.append([datetime.datetime(2018,5,20),1,"Sant'Andrea","Bergamo","Italy","Milano","Milano","Venetian Works of Defence between the 16th and 17th",['Amin']])
data_list.append([datetime.datetime(2018,5,20),5,"Sant'Alessandro in Colonna","Bergamo","Italy","Milano","Milano","",['Amin']])
data_list.append([datetime.datetime(2018,5,20),3,"Fontana del Lantro","Bergamo","Italy","Milano","Milano","Venetian Works of Defence between the 16th and 17th",['Amin']])
data_list.append([datetime.datetime(2018,5,20),1,"San Lorenzo alla Boccola","Bergamo","Italy","Milano","Milano","Venetian Works of Defence between the 16th and 17th",['Amin']])
data_list.append([datetime.datetime(2018,5,20),1,"Dolphin Fountain","Bergamo","Italy","Milano","Milano","",['Amin']])
data_list.append([datetime.datetime(2018,5,20),2,"Sant'Alessandro della Croce","Bergamo","Italy","Milano","Milano","",['Amin']])
data_list.append([datetime.datetime(2018,5,20),2,"San Marco","Bergamo","Italy","Milano","Milano","",['Amin']])
data_list.append([datetime.datetime(2018,5,20),1,"Santi Bargolomeo e Stefano","Bergamo","Italy","Milano","Milano","",['Amin']])
data_list.append([datetime.datetime(2018,5,20),1,"War Memorial","Bergamo","Italy","Milano","Milano","",['Amin']])
data_list.append([datetime.datetime(2018,5,20),67,"Duomo","Cremona","Italy","Milano","Milano","",['Amin']])
data_list.append([datetime.datetime(2018,5,20),13,"Baptistery","Cremona","Italy","Milano","Milano","",['Amin']])
data_list.append([datetime.datetime(2018,5,20),8,"Palazzo Comunale","Cremona","Italy","Milano","Milano","",['Amin']])
data_list.append([datetime.datetime(2018,5,21),1,"Porta di Augusto","Rimini","Italy","Milano","Geneva","",['Amin']])
data_list.append([datetime.datetime(2018,5,21),12,"Town Walls","San Marino","San Marino","Milano","Geneva","San Marino Historic Centre and Mount Titano",['Amin']])
data_list.append([datetime.datetime(2018,5,21),2,"San Francesco","San Marino","San Marino","Milano","Geneva","San Marino Historic Centre and Mount Titano",['Amin']])
data_list.append([datetime.datetime(2018,5,21),12,"Palazzo Pubblico","San Marino","San Marino","Milano","Geneva","San Marino Historic Centre and Mount Titano",['Amin']])
data_list.append([datetime.datetime(2018,5,21),8,"Basilica di San Marino","San Marino","San Marino","Milano","Geneva","San Marino Historic Centre and Mount Titano",['Amin']])
data_list.append([datetime.datetime(2018,5,21),15,"Rocca della Guaita","San Marino","San Marino","Milano","Geneva","San Marino Historic Centre and Mount Titano",['Amin']])
data_list.append([datetime.datetime(2018,5,21),10,"Rocca della Cesta","San Marino","San Marino","Milano","Geneva","San Marino Historic Centre and Mount Titano",['Amin']])
data_list.append([datetime.datetime(2018,5,21),7,"San Marino National Museum","San Marino","San Marino","Milano","Geneva","San Marino Historic Centre and Mount Titano",['Amin']])
data_list.append([datetime.datetime(2018,5,21),100,"Duomo","Milano","Italy","Milano","Geneva","",['Amin']])
data_list.append([datetime.datetime(2018,5,21),1,"Palazzo Reale","Milano","Italy","Milano","Geneva","",['Amin']])
data_list.append([datetime.datetime(2018,5,21),3,"Galleria Vittorio Emanuele II","Milano","Italy","Milano","Geneva","",['Amin']])

# %%
#barcelona
data_list.append([datetime.datetime(2018,5,25),1,"Olympic Flame","Barcelona","Spain","Geneva","Barcelona","",['Rachel']])
data_list.append([datetime.datetime(2018,5,25),1,"Palau Nacional","Barcelona","Spain","Geneva","Barcelona","",['Rachel']])
data_list.append([datetime.datetime(2018,5,26),136,"Teatre-Museu Dali","Figueras","Spain","Barcelona","Barcelona","",[]])
data_list.append([datetime.datetime(2018,5,26),7,"Sant Pere","Figueras","Spain","Barcelona","Barcelona","",[]])
data_list.append([datetime.datetime(2018,5,26),3,"Platja del Miracle","Tarragona","Spain","Barcelona","Barcelona","",[]])
data_list.append([datetime.datetime(2018,5,26),7,"Amphitheatre","Tarragona","Spain","Barcelona","Barcelona","Archaeological Ensemble of Tarraco",[]])
data_list.append([datetime.datetime(2018,5,26),10,"Torre del Pretori","Tarragona","Spain","Barcelona","Barcelona","Archaeological Ensemble of Tarraco",[]])
data_list.append([datetime.datetime(2018,5,26),2,"Torre de les Monges","Tarragona","Spain","Barcelona","Barcelona","Archaeological Ensemble of Tarraco",[]])
data_list.append([datetime.datetime(2018,5,26),9,"Roman Circus","Tarragona","Spain","Barcelona","Barcelona","Archaeological Ensemble of Tarraco",[]])
data_list.append([datetime.datetime(2018,5,26),61,"Cathedral","Tarragona","Spain","Barcelona","Barcelona","",[]])
data_list.append([datetime.datetime(2018,5,26),8,"Town Walls","Tarragona","Spain","Barcelona","Barcelona","Archaeological Ensemble of Tarraco",[]])
data_list.append([datetime.datetime(2018,5,26),9,"Forum Romanum","Tarragona","Spain","Barcelona","Barcelona","Archaeological Ensemble of Tarraco",[]])
data_list.append([datetime.datetime(2018,5,26),2,"Roman Theatre","Tarragona","Spain","Barcelona","Barcelona","Archaeological Ensemble of Tarraco",[]])
data_list.append([datetime.datetime(2018,5,26),26,"Sagrada Familia","Barcelona","Spain","Barcelona","Barcelona","Works of Antoni Gaudi",['Rachel']])
data_list.append([datetime.datetime(2018,5,26),62,"Sagrada Familia","Barcelona","Spain","Barcelona","Barcelona","",['Rachel']])
data_list.append([datetime.datetime(2018,5,26),26,"Casa Mila","Barcelona","Spain","Barcelona","Barcelona","Works of Antoni Gaudi",['Rachel']])
data_list.append([datetime.datetime(2018,5,26),1,"Hospital de Sant Pau","Barcelona","Spain","Barcelona","Barcelona","Palau de la Musica Catalana and Hospital de Sant Pau",['Rachel']])
data_list.append([datetime.datetime(2018,5,26),1,"Casa Batllo","Barcelona","Spain","Barcelona","Barcelona","Works of Antoni Gaudi",['Rachel']])
data_list.append([datetime.datetime(2018,5,27),1,"Palau Nacional","Barcelona","Spain","Barcelona","Castelldefels","",['Rachel']])
data_list.append([datetime.datetime(2018,5,27),4,"Bullfighting Arena","Barcelona","Spain","Barcelona","Castelldefels","",['Rachel']])
data_list.append([datetime.datetime(2018,5,27),1,"Woman and Bird","Barcelona","Spain","Barcelona","Castelldefels","",['Rachel']])
data_list.append([datetime.datetime(2018,5,27),3,"Placa d'Espanya","Barcelona","Spain","Barcelona","Castelldefels","",['Rachel']])
data_list.append([datetime.datetime(2018,5,27),6,"Fonta Magica de Montjuic","Barcelona","Spain","Barcelona","Castelldefels","",[]])
data_list.append([datetime.datetime(2018,5,27),114,"Palau Nacional","Barcelona","Spain","Barcelona","Castelldefels","",[]])
data_list.append([datetime.datetime(2018,5,27),1,"Sagrada Familia","Barcelona","Spain","Barcelona","Castelldefels","",[]])
data_list.append([datetime.datetime(2018,5,27),4,"Jardins de Joan Maragall","Barcelona","Spain","Barcelona","Castelldefels","",[]])
data_list.append([datetime.datetime(2018,5,27),1,"Olympic Flame","Barcelona","Spain","Barcelona","Castelldefels","",[]])
data_list.append([datetime.datetime(2018,5,27),2,"Olympic Stadium","Barcelona","Spain","Barcelona","Castelldefels","",[]])
data_list.append([datetime.datetime(2018,5,27),3,"Palauet Albeniz","Barcelona","Spain","Barcelona","Castelldefels","",[]])
data_list.append([datetime.datetime(2018,5,27),47,"Casa Vincens","Barcelona","Spain","Barcelona","Barcelona","Works of Antoni Gaudi",[]])
data_list.append([datetime.datetime(2018,5,27),14,"Casa de les Punxes","Barcelona","Spain","Barcelona","Castelldefels","",[]])
data_list.append([datetime.datetime(2018,5,27),3,"Cathedral","Barcelona","Spain","Barcelona","Castelldefels","",[]])
data_list.append([datetime.datetime(2018,5,27),3,"Temple of Augustus","Barcelona","Spain","Barcelona","Castelldefels","",[]])
data_list.append([datetime.datetime(2018,5,27),1,"Casa de l'Ardiaca","Barcelona","Spain","Barcelona","Castelldefels","",[]])

# %%
#uk 2018
data_list.append([datetime.datetime(2018,6,3),36,"Edinburgh Castle","Edinburgh","United Kingdom","Edinburgh","Edinburgh","Old and New Towns of Edinburgh",[]])
data_list.append([datetime.datetime(2018,6,3),11,"St Giles' Cathedral","Edinburgh","United Kingdom","Edinburgh","Edinburgh","Old and New Towns of Edinburgh",[]])
data_list.append([datetime.datetime(2018,6,3),4,"Museum on the Mound","Edinburgh","United Kingdom","Edinburgh","Edinburgh","Old and New Towns of Edinburgh",[]])
data_list.append([datetime.datetime(2018,6,3),5,"Parliament Square","Edinburgh","United Kingdom","Edinburgh","Edinburgh","Old and New Towns of Edinburgh",[]])
data_list.append([datetime.datetime(2018,6,3),26,"Holyrood Palace","Edinburgh","United Kingdom","Edinburgh","Edinburgh","Old and New Towns of Edinburgh",[]])
data_list.append([datetime.datetime(2018,6,3),32,"Stirling Castle","Stirling","United Kingdom","Edinburgh","Edinburgh","",["Artur",'Heidrun']])
data_list.append([datetime.datetime(2018,6,3),11,"Church of the Holy Rude","Stirling","United Kingdom","Edinburgh","Edinburgh","",["Artur",'Heidrun']])
data_list.append([datetime.datetime(2018,6,3),7,"St Michael's","Linlithgow","United Kingdom","Edinburgh","Edinburgh","",[]])
data_list.append([datetime.datetime(2018,6,3),43,"Linlithgow Palace","Linlithgow","United Kingdom","Edinburgh","Edinburgh","",[]])
data_list.append([datetime.datetime(2018,6,3),14,"Forth Bridge","Queensferry","United Kingdom","Edinburgh","Edinburgh","The Forth Bridge",['Artur','Heidrun']])
data_list.append([datetime.datetime(2018,6,3),6,"Forth Road Bridge","Queensferry","United Kingdom","Edinburgh","Edinburgh","",['Artur','Heidrun']])
data_list.append([datetime.datetime(2018,6,4),5,"George Square","Glasgow","United Kingdom","Edinburgh","York","",['Artur','Heidrun']])
data_list.append([datetime.datetime(2018,6,4),37,"City Chambers","Glasgow","United Kingdom","Edinburgh","York","",['Artur','Heidrun']])
data_list.append([datetime.datetime(2018,6,4),24,"Cathedral","Glasgow","United Kingdom","Edinburgh","York","",['Artur','Heidrun']])
data_list.append([datetime.datetime(2018,6,4),5,"Fallkirk Wheel","Fallkirk","United Kingdom","Edinburgh","York","",['Artur','Heidrun']])
data_list.append([datetime.datetime(2018,6,4),9,"Rough Castle Fort","Fallkirk","United Kingdom","Edinburgh","York","Frontiers of the Roman Empire",['Artur','Heidrun']])
data_list.append([datetime.datetime(2018,6,4),3,"Micklegate Bar","York","United Kingdom","Edinburgh","York","",['Artur','Heidrun']])
data_list.append([datetime.datetime(2018,6,4),2,"All Saints Church","York","United Kingdom","Edinburgh","York","",['Artur','Heidrun']])
data_list.append([datetime.datetime(2018,6,4),25,"York Minster","York","United Kingdom","Edinburgh","York","",['Artur','Heidrun']])
data_list.append([datetime.datetime(2018,6,4),1,"St Mary's Abbey","York","United Kingdom","Edinburgh","York","",['Artur','Heidrun']])
data_list.append([datetime.datetime(2018,6,4),2,"Town Walls","York","United Kingdom","Edinburgh","York","",['Artur','Heidrun']])
data_list.append([datetime.datetime(2018,6,5),2,"Clifford's Tower","York","United Kingdom","York","York","",['Artur','Heidrun']])
data_list.append([datetime.datetime(2018,6,5),99,"York Minster","York","United Kingdom","York","York","",['Artur','Heidrun']])
data_list.append([datetime.datetime(2018,6,5),23,"Cathedral","Durham","United Kingdom","York","York","Durham Castle and Cathedral",['Artur','Heidrun']])
data_list.append([datetime.datetime(2018,6,5),43,"Durham Castle","Durham","United Kingdom","York","York","Durham Castle and Cathedral",['Artur','Heidrun']])
data_list.append([datetime.datetime(2018,6,5),1,"Micklegate Bar","York","United Kingdom","York","York","",['Artur','Heidrun']])
data_list.append([datetime.datetime(2018,6,5),1,"Town Walls","York","United Kingdom","York","York","",['Artur','Heidrun']])
data_list.append([datetime.datetime(2018,6,6),6,"Knaresborough Castle","Knaresborough","United Kingdom","York","Manchester","",['Artur','Heidrun']])
data_list.append([datetime.datetime(2018,6,6),65,"Fountains Abbey","Ripon","United Kingdom","York","Manchester","Studley Royal Park including the Ruins of Fountains Abbey",['Artur','Heidrun']])
data_list.append([datetime.datetime(2018,6,6),32,"Studley Royal Water Garden","Ripon","United Kingdom","York","Manchester","Studley Royal Park including the Ruins of Fountains Abbey",['Artur','Heidrun']])
data_list.append([datetime.datetime(2018,6,6),2,"White Horse","Kilburn","United Kingdom","York","Manchester","",[]])
data_list.append([datetime.datetime(2018,6,6),94,"Castle Howard","York","United Kingdom","York","Manchester","",['Artur','Heidrun']])
data_list.append([datetime.datetime(2018,6,6),52,"Castle Howard Gardens","York","United Kingdom","York","Manchester","",['Artur','Heidrun']])
data_list.append([datetime.datetime(2018,6,7),121,"Chatsworth House","Bakewell","United Kingdom","Manchester","Manchester","",['Artur','Heidrun']])
data_list.append([datetime.datetime(2018,6,7),28,"Lincoln Castle","Lincoln","United Kingdom","Manchester","Manchester","",['Artur','Heidrun']])
data_list.append([datetime.datetime(2018,6,7),81,"Cathedral","Lincoln","United Kingdom","Manchester","Manchester","",['Artur','Heidrun']])
data_list.append([datetime.datetime(2018,6,8),1,"Manchester Piccadilly","Manchester","United Kingdom","Manchester","Manchester","",['Artur','Heidrun']])
data_list.append([datetime.datetime(2018,6,8),55,"Conwy Castle","Conwy","United Kingdom","Manchester","Manchester","Castles and Town Walls of King Edward in Gwynedd",['Artur','Heidrun']])
data_list.append([datetime.datetime(2018,6,8),6,"Town Wall","Conwy","United Kingdom","Manchester","Manchester","Castles and Town Walls of King Edward in Gwynedd",['Artur','Heidrun']])
data_list.append([datetime.datetime(2018,6,8),1,"Mill Gate","Conwy","United Kingdom","Manchester","Manchester","Castles and Town Walls of King Edward in Gwynedd",['Artur','Heidrun']])
data_list.append([datetime.datetime(2018,6,8),50,"Caernarfon Castle","Caernarfon","United Kingdom","Manchester","Manchester","Castles and Town Walls of King Edward in Gwynedd",['Artur','Heidrun']])
data_list.append([datetime.datetime(2018,6,8),2,"Town Wall","Caernarfon","United Kingdom","Manchester","Manchester","Castles and Town Walls of King Edward in Gwynedd",['Artur','Heidrun']])
data_list.append([datetime.datetime(2018,6,8),3,"Cathedral","Bangor","United Kingdom","Manchester","Manchester","",['Artur','Heidrun']])
data_list.append([datetime.datetime(2018,6,8),1,"Memorial Gate","Bangor","United Kingdom","Manchester","Manchester","",['Artur','Heidrun']])
data_list.append([datetime.datetime(2018,6,8),1,"Victoria Monument","Manchester","United Kingdom","Manchester","Manchester","",['Artur','Heidrun']])
data_list.append([datetime.datetime(2018,6,9),1,"Grand Central Hall","Liverpool","United Kingdom","Manchester","Manchester","",['Artur','Heidrun']])
data_list.append([datetime.datetime(2018,6,9),2,"Chinatown Gate","Liverpool","United Kingdom","Manchester","Manchester","",['Artur','Heidrun']])
data_list.append([datetime.datetime(2018,6,9),40,"Cathedral","Liverpool","United Kingdom","Manchester","Manchester","",['Artur','Heidrun']])
data_list.append([datetime.datetime(2018,6,9),21,"Metropolitan Cathedral","Liverpool","United Kingdom","Manchester","Manchester","",['Artur','Heidrun']])
data_list.append([datetime.datetime(2018,6,9),11,"St George's Hall","Liverpool","United Kingdom","Manchester","Manchester","Liverpool – Maritime Mercantile City",['Artur','Heidrun']])
data_list.append([datetime.datetime(2018,6,9),5,"Royal Liver Building","Liverpool","United Kingdom","Manchester","Manchester","Liverpool – Maritime Mercantile City",['Artur','Heidrun']])
data_list.append([datetime.datetime(2018,6,9),3,"Port of Liverpool Building","Liverpool","United Kingdom","Manchester","Manchester","Liverpool – Maritime Mercantile City",['Artur','Heidrun']])
data_list.append([datetime.datetime(2018,6,9),5,"St John the Baptist","Chester","United Kingdom","Manchester","Manchester","",[]])
data_list.append([datetime.datetime(2018,6,9),44,"Cathedral","Chester","United Kingdom","Manchester","Manchester","",[]])
data_list.append([datetime.datetime(2018,6,10),1,"Wellington Monument","Manchester","United Kingdom","Manchester","Geneva","",[]])
data_list.append([datetime.datetime(2018,6,10),2,"Town Hall","Manchester","United Kingdom","Manchester","Geneva","",[]])
data_list.append([datetime.datetime(2018,6,10),19,"Museum of Science and Industry","Manchester","United Kingdom","Manchester","Geneva","",[]])
data_list.append([datetime.datetime(2018,6,10),2,"Roman Fort of Mamucium","Manchester","United Kingdom","Manchester","Geneva","",[]])
data_list.append([datetime.datetime(2018,6,10),14,"Castlefield","Manchester","United Kingdom","Manchester","Geneva","",[]])
data_list.append([datetime.datetime(2018,6,10),15,"John Rydlands Library","Manchester","United Kingdom","Manchester","Geneva","",[]])
data_list.append([datetime.datetime(2018,6,10),37,"Cathedral","Manchester","United Kingdom","Manchester","Geneva","",[]])
data_list.append([datetime.datetime(2018,6,10),2,"Royal Exchange","Manchester","United Kingdom","Manchester","Geneva","",[]])
data_list.append([datetime.datetime(2018,6,10),2,"St Ann's","Manchester","United Kingdom","Manchester","Geneva","",[]])
data_list.append([datetime.datetime(2018,6,10),4,"St Mary's the Hidden Gem","Manchester","United Kingdom","Manchester","Geneva","",[]])
data_list.append([datetime.datetime(2018,6,10),1,"Chinatown Gate","Manchester","United Kingdom","Manchester","Geneva","",[]])

# %%
#seoul done
data_list.append([datetime.datetime(2018,7,3),53,"Changdeokgung Palace","Seoul","South Korea","Seoul","Seoul","Changdeokgung Palace Complex",['Ulrike','Eva']])
data_list.append([datetime.datetime(2018,7,3),1,"N Seoul Tower","Seoul","South Korea","Seoul","Seoul","Changdeokgung Palace Complex",['Ulrike','Eva']])
data_list.append([datetime.datetime(2018,7,3),31,"Changdeokgung Palace Huwon Park","Seoul","South Korea","Seoul","Seoul","Changdeokgung Palace Complex",['Ulrike','Eva']])
data_list.append([datetime.datetime(2018,7,3),22,"Changgyeonggung Palace","Seoul","South Korea","Seoul","Seoul","",['Ulrike','Eva']])
data_list.append([datetime.datetime(2018,7,3),2,"Cheondogyo Temple","Seoul","South Korea","Seoul","Seoul","",['Ulrike','Eva']])
data_list.append([datetime.datetime(2018,7,3),3,"Jogyesa Temple","Seoul","South Korea","Seoul","Seoul","",['Ulrike','Eva']])
data_list.append([datetime.datetime(2018,7,3),40,"Deoksugung Palace","Seoul","South Korea","Seoul","Seoul","",['Ulrike','Eva']])
data_list.append([datetime.datetime(2018,7,3),5,"City Hall","Seoul","South Korea","Seoul","Seoul","",['Ulrike','Eva']])
data_list.append([datetime.datetime(2018,7,3),2,"Sungnyemun Gate","Seoul","South Korea","Seoul","Seoul","",['Ulrike','Eva']])
data_list.append([datetime.datetime(2018,7,4),12,"Unhyeongung Palace","Seoul","South Korea","Seoul","Seoul","",[]])
data_list.append([datetime.datetime(2018,7,4),20,"Jongmyo Shrine","Seoul","South Korea","Seoul","Seoul","Jongmyo Shrine",[]])
data_list.append([datetime.datetime(2018,7,4),37,"Gyeongbokgung Palace","Seoul","South Korea","Seoul","Seoul","",[]])
data_list.append([datetime.datetime(2018,7,4),2,"Blue House","Seoul","South Korea","Seoul","Seoul","",[]])
data_list.append([datetime.datetime(2018,7,4),16,"National Palace Museum","Seoul","South Korea","Seoul","Seoul","",[]])
data_list.append([datetime.datetime(2018,7,4),3,"Gwanghwamun Plaza","Seoul","South Korea","Seoul","Seoul","",[]])
data_list.append([datetime.datetime(2018,7,4),6,"Gyeonghuigung Palace","Seoul","South Korea","Seoul","Seoul","",[]])
data_list.append([datetime.datetime(2018,7,4),6,"City Wall","Seoul","South Korea","Seoul","Seoul","",[]])
data_list.append([datetime.datetime(2018,7,4),3,"Heunginjimun Gate","Seoul","South Korea","Seoul","Seoul","",[]])
data_list.append([datetime.datetime(2018,7,4),17,"Seolleung","Seoul","South Korea","Seoul","Seoul","Royal Tombs of the Joseon Dynasty",[]])
data_list.append([datetime.datetime(2018,7,4),6,"Jeongneung","Seoul","South Korea","Seoul","Seoul","Royal Tombs of the Joseon Dynasty",[]])
data_list.append([datetime.datetime(2018,7,4),1,"Deoksugung Palace","Seoul","South Korea","Seoul","Seoul","",[]])
data_list.append([datetime.datetime(2018,7,7),40,"Lotte World Tower Observatory","Seoul","South Korea","Seoul","Seoul","",["Ulrike",'Eva','Steffen','Stephanie']])
data_list.append([datetime.datetime(2018,7,8),17,"Imjingak Park","Paju","South Korea","Seoul","Seoul","",["Ulrike",'Eva','Cameron']])
data_list.append([datetime.datetime(2018,7,8),3,"Third Tunnel","Paju","South Korea","Seoul","Seoul","",["Ulrike",'Eva','Cameron']])
data_list.append([datetime.datetime(2018,7,8),17,"Dora Observatory","Paju","South Korea","Seoul","Seoul","",["Ulrike",'Eva','Cameron']])
data_list.append([datetime.datetime(2018,7,8),10,"Dorasan Station","Paju","South Korea","Seoul","Seoul","",["Ulrike",'Eva','Cameron']])
data_list.append([datetime.datetime(2018,7,8),16,"Bongeunsa Temple","Seoul","South Korea","Seoul","Seoul","",['Cameron']])
data_list.append([datetime.datetime(2018,7,8),2,"N Seoul Tower","Seoul","South Korea","Seoul","Seoul","",[]])
data_list.append([datetime.datetime(2018,7,8),4,"City Wall","Seoul","South Korea","Seoul","Seoul","",[]])
data_list.append([datetime.datetime(2018,7,8),46,"N Seoul Tower Observatory","Seoul","South Korea","Seoul","Seoul","",['Cameron']])
data_list.append([datetime.datetime(2018,7,8),2,"N Seoul Tower","Seoul","South Korea","Seoul","Seoul","",['Cameron']])
data_list.append([datetime.datetime(2018,7,8),2,"City Wall","Seoul","South Korea","Seoul","Seoul","",['Cameron']])
data_list.append([datetime.datetime(2018,7,8),2,"Amabel Art Installation","Seoul","South Korea","Seoul","Seoul","",[]])
data_list.append([datetime.datetime(2018,7,9),1,"COEX Starfield Library","Seoul","South Korea","Seoul","Seoul","",[]])
data_list.append([datetime.datetime(2018,7,12),66,"Hwaseong Fortress","Suwon","South Korea","Seoul","Seoul","Hwaseong Fortress",[]])
data_list.append([datetime.datetime(2018,7,12),38,"Namhansanseong","Gwangju","South Korea","Seoul","Seoul","Namhansanseong",[]])
data_list.append([datetime.datetime(2018,7,12),2,"Lotte World Tower Observatory","Seoul","South Korea","Seoul","Seoul","",[]])
data_list.append([datetime.datetime(2018,7,12),1,"G20 Monument","Seoul","South Korea","Seoul","Seoul","",[]])
data_list.append([datetime.datetime(2018,7,13),45,"Bulguksa Temple","Gyeongju","South Korea","Seoul","Busan","Seokguram Grotto and Bulguksa Temple",['Steffen','Stephanie']])
data_list.append([datetime.datetime(2018,7,13),21,"Yangdong Village","Gyeongju","South Korea","Seoul","Busan","Historic Villages of Korea: Hahoe and Yangdong",['Steffen','Stephanie']])
data_list.append([datetime.datetime(2018,7,13),5,"Hwango-dong Tombs","Gyeongju","South Korea","Seoul","Busan","Gyeongju Historic Areas",['Steffen','Stephanie']])
data_list.append([datetime.datetime(2018,7,13),3,"Jjoksaem Tomb","Gyeongju","South Korea","Seoul","Busan","Gyeongju Historic Areas",['Steffen','Stephanie']])
data_list.append([datetime.datetime(2018,7,13),2,"Eastern Tombs","Gyeongju","South Korea","Seoul","Busan","Gyeongju Historic Areas",['Steffen','Stephanie']])
data_list.append([datetime.datetime(2018,7,13),2,"Cheomseongdae Obervatory","Gyeongju","South Korea","Seoul","Busan","Gyeongju Historic Areas",['Steffen','Stephanie']])
data_list.append([datetime.datetime(2018,7,13),7,"Daerungwon Tombs","Gyeongju","South Korea","Seoul","Busan","Gyeongju Historic Areas",['Steffen','Stephanie']])
data_list.append([datetime.datetime(2018,7,13),4,"Singyeongju Station","Gyeongju","South Korea","Seoul","Busan","",['Steffen','Stephanie']])
data_list.append([datetime.datetime(2018,7,13),5,"Busan Tower","Busan","South Korea","Seoul","Busan","",['Steffen','Stephanie']])
data_list.append([datetime.datetime(2018,7,13),1,"Mother's Heart Art Installation","Busan","South Korea","Seoul","Busan","",['Steffen','Stephanie']])
data_list.append([datetime.datetime(2018,7,13),3,"Admiral Yi Sun-Sin Monument","Busan","South Korea","Seoul","Busan","",['Steffen','Stephanie']])
data_list.append([datetime.datetime(2018,7,14),33,"Haedong Yonggung Temple","Busan","South Korea","Busan","Seoul","",['Steffen','Stephanie']])
data_list.append([datetime.datetime(2018,7,14),14,"Haeundae Beach","Busan","South Korea","Busan","Seoul","",['Steffen','Stephanie']])
data_list.append([datetime.datetime(2018,7,14),9,"Dongbak Park","Busan","South Korea","Busan","Seoul","",['Steffen','Stephanie']])
data_list.append([datetime.datetime(2018,7,14),11,"Nurimaru APEC House","Busan","South Korea","Busan","Seoul","",['Steffen','Stephanie']])
data_list.append([datetime.datetime(2018,7,14),1,"Suseo Station","Seoul","South Korea","Busan","Seoul","",['Steffen','Stephanie']])
data_list.append([datetime.datetime(2018,7,15),1,"N Seoul Tower","Seoul","South Korea","Seoul","Flight ICN-DXB","",[]])
data_list.append([datetime.datetime(2018,7,15),146,"South Korean National Museum","Seoul","South Korea","Seoul","Flight ICN-DXB","",[]])
data_list.append([datetime.datetime(2018,7,15),4,"Myeong-dong Cathedral","Seoul","South Korea","Seoul","Flight ICN-DXB","",[]])
data_list.append([datetime.datetime(2018,7,15),13,"Dongdaemun Design Plaza","Seoul","South Korea","Seoul","Flight ICN-DXB","",[]])
data_list.append([datetime.datetime(2018,7,15),2,"Lotte World Tower","Seoul","South Korea","Seoul","Flight ICN-DXB","",[]])
data_list.append([datetime.datetime(2018,7,15),16,"Olympic Park","Seoul","South Korea","Seoul","Flight ICN-DXB","",[]])

# %%
data_list.append([datetime.datetime(2018,8,5),199,"Morteratsch Glacier","Pontresina","Switzerland","Geneva","Geneva","",[]])
data_list.append([datetime.datetime(2018,8,5),27,"Pers Glacier","Pontresina","Switzerland","Geneva","Geneva","",[]])
data_list.append([datetime.datetime(2018,8,5),16,"Bernina Massif","Pontresina","Switzerland","Geneva","Geneva","",[]])
data_list.append([datetime.datetime(2018,8,5),18,"Cathedral","Chur","Switzerland","Geneva","Geneva","",[]])
data_list.append([datetime.datetime(2018,8,5),3,"Stadtkirche","Chur","Switzerland","Geneva","Geneva","",[]])
data_list.append([datetime.datetime(2018,8,11),1,"Jet d'Eau","Geneva","Switzerland","Geneva","Geneva","",['Riju','Chris Brainerd']])
data_list.append([datetime.datetime(2018,8,12),26,"Fort l'Ecluse","Leaz","France","Geneva","Geneva","",['Riju']])
data_list.append([datetime.datetime(2018,8,18),1,"Liebfrauenkirche","Waldshut","Switzerland","Lauchringen","Lauchringen","",['Anne-Kathrin','Christian']])
data_list.append([datetime.datetime(2018,8,28),41,"Oeschinensee & Bluemlisalp","Kandersteg","Switzerland","Geneva","Geneva","Swiss Alps Jungfrau-Aletsch",['Riju']])
data_list.append([datetime.datetime(2018,8,28),3,"Bundeshaus","Bern","Switzerland","Geneva","Geneva","Old City of Berne",['Riju']])
data_list.append([datetime.datetime(2018,8,28),24,"Minster","Bern","Switzerland","Geneva","Geneva","Old City of Berne",['Riju']])
data_list.append([datetime.datetime(2018,8,28),2,"City Hall","Bern","Switzerland","Geneva","Geneva","Old City of Berne",['Riju']])
data_list.append([datetime.datetime(2018,8,28),1,"Venner Fountain","Bern","Switzerland","Geneva","Geneva","Old City of Berne",['Riju']])
data_list.append([datetime.datetime(2018,8,28),1,"Samson Fountain","Bern","Switzerland","Geneva","Geneva","Old City of Berne",['Riju']])
data_list.append([datetime.datetime(2018,8,28),1,"Zaehringer Fountain","Bern","Switzerland","Geneva","Geneva","Old City of Berne",['Riju']])
data_list.append([datetime.datetime(2018,8,28),6,"Zytglogge","Bern","Switzerland","Geneva","Geneva","Old City of Berne",['Riju']])
data_list.append([datetime.datetime(2018,8,28),1,"Anna Seiler Fountain","Bern","Switzerland","Geneva","Geneva","Old City of Berne",['Riju']])
data_list.append([datetime.datetime(2018,8,28),2,"Whistler Fountain","Bern","Switzerland","Geneva","Geneva","Old City of Berne",['Riju']])

# %%
data_list.append([datetime.datetime(2018,8,31),6,"Aeroport","Geneva","Germany","Geneva","Munich","",['Reyer']])
data_list.append([datetime.datetime(2018,9,1),1,"St Michael","Munich","Germany","Munich","Fuessen","",['Reyer','Chris Brainerd']])
data_list.append([datetime.datetime(2018,9,1),96,"Residence","Munich","Germany","Munich","Fuessen","",['Reyer','Chris Brainerd']])
data_list.append([datetime.datetime(2018,9,1),13,"Residence Treasury","Munich","Germany","Munich","Fuessen","",['Reyer','Chris Brainerd']])
data_list.append([datetime.datetime(2018,9,1),6,"Residence Cuvillies Theatre","Munich","Germany","Munich","Fuessen","",['Reyer','Chris Brainerd']])
data_list.append([datetime.datetime(2018,9,1),10,"Theatine Church","Munich","Germany","Munich","Fuessen","",['Reyer','Chris Brainerd']])
data_list.append([datetime.datetime(2018,9,1),4,"Nymphenburg","Munich","Germany","Munich","Fuessen","",['Reyer','Chris Brainerd']])
data_list.append([datetime.datetime(2018,9,1),30,"Nymphenburg Amalienburg","Munich","Germany","Munich","Fuessen","",['Reyer','Chris Brainerd']])
data_list.append([datetime.datetime(2018,9,1),17,"Nymphenburg Badenburg","Munich","Germany","Munich","Fuessen","",['Reyer','Chris Brainerd']])
data_list.append([datetime.datetime(2018,9,1),13,"Nymphenburg Pagodenburg","Munich","Germany","Munich","Fuessen","",['Reyer','Chris Brainerd']])
data_list.append([datetime.datetime(2018,9,1),10,"Nymphenburg Magdalenenklause","Munich","Germany","Munich","Fuessen","",['Reyer','Chris Brainerd']])
data_list.append([datetime.datetime(2018,9,2),2,"Hohenschwangau Castle","Schwangau","Germany","Fuessen","Regensburg","",['Reyer','Chris Brainerd']])
data_list.append([datetime.datetime(2018,9,2),11,"Neuschwanstein Castle","Schwangau","Germany","Fuessen","Regensburg","",['Reyer','Chris Brainerd']])
data_list.append([datetime.datetime(2018,9,2),6,"Poellatschlucht","Schwangau","Germany","Fuessen","Regensburg","",['Reyer','Chris Brainerd']])
data_list.append([datetime.datetime(2018,9,2),17,"Wieskirche","Steingaden","Germany","Fuessen","Regensburg","Pilgrimage Church of Wies",['Reyer','Chris Brainerd']])
data_list.append([datetime.datetime(2018,9,2),2,"Linderhof Palace Moroccan House","Ettal","Germany","Fuessen","Regensburg","",['Reyer','Chris Brainerd']])
data_list.append([datetime.datetime(2018,9,2),6,"Linderhof Palace","Ettal","Germany","Fuessen","Regensburg","",['Reyer','Chris Brainerd']])
data_list.append([datetime.datetime(2018,9,2),13,"Linderhof Palace Park","Ettal","Germany","Fuessen","Regensburg","",['Reyer','Chris Brainerd']])
data_list.append([datetime.datetime(2018,9,2),9,"Linderhof Palace Moorish Kiosk","Ettal","Germany","Fuessen","Regensburg","",['Reyer','Chris Brainerd']])
data_list.append([datetime.datetime(2018,9,2),14,"Ettal Monastery","Ettal","Germany","Fuessen","Regensburg","",['Reyer','Chris Brainerd']])
data_list.append([datetime.datetime(2018,9,2),4,"Old Town Hall","Regensburg","Germany","Fuessen","Regensburg","Old town of Regensburg with Stadtamhof",['Reyer','Chris Brainerd']])
data_list.append([datetime.datetime(2018,9,2),37,"Dom","Regensburg","Germany","Fuessen","Regensburg","Old town of Regensburg with Stadtamhof",['Reyer','Chris Brainerd']])
data_list.append([datetime.datetime(2018,9,2),1,"St Johann","Regensburg","Germany","Fuessen","Regensburg","Old town of Regensburg with Stadtamhof",['Reyer','Chris Brainerd']])
#including bridge tower
data_list.append([datetime.datetime(2018,9,2),5,"Stone Bridge","Regensburg","Germany","Fuessen","Regensburg","Old town of Regensburg with Stadtamhof",['Reyer','Chris Brainerd']])
data_list.append([datetime.datetime(2018,9,3),55,"Donaudurchbruch","Kehlheim","Germany","Regensburg","Bamberg","",['Reyer','Chris Brainerd']])
data_list.append([datetime.datetime(2018,9,3),22,"Liberation Hall","Kehlheim","Germany","Regensburg","Bamberg","",['Reyer','Chris Brainerd']])
data_list.append([datetime.datetime(2018,9,3),25,"Weltenburg Monastery","Kehlheim","Germany","Regensburg","Bamberg","",['Reyer','Chris Brainerd']])
data_list.append([datetime.datetime(2018,9,3),20,"Walhalla","Donaustauf","Germany","Regensburg","Bamberg","",['Reyer','Chris Brainerd']])
data_list.append([datetime.datetime(2018,9,3),38,"Seedorf Palace & Gardens","Memmelsdorf","Germany","Regensburg","Bamberg","",['Reyer','Chris Brainerd']])
data_list.append([datetime.datetime(2018,9,3),3,"Maximiliansplatz","Bamberg","Germany","Regensburg","Bamberg","Town of Bamberg",['Reyer','Chris Brainerd']])
data_list.append([datetime.datetime(2018,9,3),3,"St Martin","Bamberg","Germany","Regensburg","Bamberg","Town of Bamberg",['Reyer','Chris Brainerd']])
data_list.append([datetime.datetime(2018,9,3),7,"Old Town Hall","Bamberg","Germany","Regensburg","Bamberg","Town of Bamberg",['Reyer','Chris Brainerd']])
data_list.append([datetime.datetime(2018,9,3),1,"New Residence","Bamberg","Germany","Regensburg","Bamberg","Town of Bamberg",['Reyer','Chris Brainerd']])
data_list.append([datetime.datetime(2018,9,3),36,"Dom","Bamberg","Germany","Regensburg","Bamberg","Town of Bamberg",['Reyer','Chris Brainerd']])
data_list.append([datetime.datetime(2018,9,3),4,"New Residence Rose Garden","Bamberg","Germany","Regensburg","Bamberg","Town of Bamberg",['Reyer','Chris Brainerd']])
data_list.append([datetime.datetime(2018,9,3),1,"Michaelsberg Monastery","Bamberg","Germany","Regensburg","Bamberg","Town of Bamberg",['Reyer','Chris Brainerd']])
data_list.append([datetime.datetime(2018,9,3),3,"Alte Hofhaltung","Bamberg","Germany","Regensburg","Bamberg","Town of Bamberg",['Reyer','Chris Brainerd']])
data_list.append([datetime.datetime(2018,9,4),31,"Residence","Wuerzburg","Germany","Bamberg","Bayreuth","Wuerzburg Residence with the Court Gardens and Residence Square",['Reyer','Chris Brainerd']])
data_list.append([datetime.datetime(2018,9,4),2,"Residence Court Gardens","Wuerzburg","Germany","Bamberg","Bayreuth","Wuerzburg Residence with the Court Gardens and Residence Square",['Reyer','Chris Brainerd']])
data_list.append([datetime.datetime(2018,9,4),14,"Dom","Wuerzburg","Germany","Bamberg","Bayreuth","",['Reyer','Chris Brainerd']])
data_list.append([datetime.datetime(2018,9,4),25,"Margravial Opera House","Bayreuth","Germany","Bamberg","Bayreuth","Margravial Opera House Bayreuth",['Reyer','Chris Brainerd']])
data_list.append([datetime.datetime(2018,9,4),20,"New Palace","Bayreuth","Germany","Bamberg","Bayreuth","",['Reyer','Chris Brainerd']])
data_list.append([datetime.datetime(2018,9,4),5,"Eremitage New Palace","Bayreuth","Germany","Bamberg","Bayreuth","",['Reyer','Chris Brainerd']])
data_list.append([datetime.datetime(2018,9,4),24,"Eremitage Old Palace","Bayreuth","Germany","Bamberg","Bayreuth","",['Reyer','Chris Brainerd']])
data_list.append([datetime.datetime(2018,9,4),9,"Eremitage Gardens","Bayreuth","Germany","Bamberg","Bayreuth","",['Reyer','Chris Brainerd']])
data_list.append([datetime.datetime(2018,9,4),2,"Maisel Brewery","Bayreuth","Germany","Bamberg","Bayreuth","",['Reyer','Chris Brainerd']])
data_list.append([datetime.datetime(2018,9,5),77,"Wartburg Castle","Eisenach","Germany","Bayreuth","Dessau","Wartburg Castle",['Reyer','Chris Brainerd']])
data_list.append([datetime.datetime(2018,9,5),16,"National Park Hainich","Schoenstedt","Germany","Bayreuth","Dessau","Ancient and Primeval Beech Forests of the Carpathians and Other Regions of Europe",['Reyer','Chris Brainerd']])
data_list.append([datetime.datetime(2018,9,5),51,"Dom","Naumburg","Germany","Bayreuth","Dessau","Naumburg Cathedral",['Reyer','Chris Brainerd']])
data_list.append([datetime.datetime(2018,9,6),4,"Bauhaus","Dessau","Germany","Dessau","Dessau","Bauhaus and its Sites in Weimar, Dessau and Bernau",['Reyer','Chris Brainerd']])
data_list.append([datetime.datetime(2018,9,6),19,"Masters' Houses","Dessau","Germany","Dessau","Dessau","Bauhaus and its Sites in Weimar, Dessau and Bernau",['Reyer','Chris Brainerd']])
data_list.append([datetime.datetime(2018,9,6),50,"Mosigkau Palace","Mosigkau","Germany","Dessau","Dessau","Garden Kingdom of Dessau-Woerlitz",['Reyer','Chris Brainerd']])
data_list.append([datetime.datetime(2018,9,6),2,"Oranienbaum Palace","Oranienbaum","Germany","Dessau","Dessau","Garden Kingdom of Dessau-Woerlitz",['Reyer','Chris Brainerd']])
data_list.append([datetime.datetime(2018,9,6),102,"Woerlitz Gardens Palace","Woerlitz","Germany","Dessau","Dessau","Garden Kingdom of Dessau-Woerlitz",['Reyer','Chris Brainerd']])
data_list.append([datetime.datetime(2018,9,6),53,"Woerlitz Gardens","Woerlitz","Germany","Dessau","Dessau","Garden Kingdom of Dessau-Woerlitz",['Reyer','Chris Brainerd']])
data_list.append([datetime.datetime(2018,9,6),22,"Woerlitz Gardens Villa Hamilton","Woerlitz","Germany","Dessau","Dessau","Garden Kingdom of Dessau-Woerlitz",['Reyer','Chris Brainerd']])
data_list.append([datetime.datetime(2018,9,6),5,"Woerlitz Gardens Gothic House","Woerlitz","Germany","Dessau","Dessau","Garden Kingdom of Dessau-Woerlitz",['Reyer','Chris Brainerd']])
data_list.append([datetime.datetime(2018,9,6),1,"Dessau Palace","Dessau","Germany","Dessau","Dessau","",['Reyer','Chris Brainerd']])
data_list.append([datetime.datetime(2018,9,6),2,"Town Hall","Dessau","Germany","Dessau","Dessau","",['Reyer','Chris Brainerd']])
data_list.append([datetime.datetime(2018,9,7),2,"Town Hall","Wittenberg","Germany","Dessau","Berlin","",['Reyer','Chris Brainerd']])
data_list.append([datetime.datetime(2018,9,7),1,"Melanchthon House","Wittenberg","Germany","Dessau","Berlin","Luther Memorials in Eisleben and Wittenberg",['Reyer','Chris Brainerd']])
data_list.append([datetime.datetime(2018,9,7),2,"Luther House","Wittenberg","Germany","Dessau","Berlin","Luther Memorials in Eisleben and Wittenberg",['Reyer','Chris Brainerd']])
data_list.append([datetime.datetime(2018,9,7),15,"Town Church","Wittenberg","Germany","Dessau","Berlin","Luther Memorials in Eisleben and Wittenberg",['Reyer','Chris Brainerd']])
data_list.append([datetime.datetime(2018,9,7),19,"Castle Church","Wittenberg","Germany","Dessau","Berlin","Luther Memorials in Eisleben and Wittenberg",['Reyer','Chris Brainerd']])
data_list.append([datetime.datetime(2018,9,7),25,"Collegiate Church","Quedlinburg","Germany","Dessau","Berlin","Collegiate Church, Castle and Old Town of Quedlinburg",['Reyer','Chris Brainerd']])
data_list.append([datetime.datetime(2018,9,7),21,"Castle","Quedlinburg","Germany","Dessau","Berlin","Collegiate Church, Castle and Old Town of Quedlinburg",['Reyer','Chris Brainerd']])
data_list.append([datetime.datetime(2018,9,7),2,"Alexanderplatz","Berlin","Germany","Dessau","Berlin","",['Reyer','Chris Brainerd','Riju']])
data_list.append([datetime.datetime(2018,9,7),4,"Fernsehturm","Berlin","Germany","Dessau","Berlin","",['Reyer','Chris Brainerd','Riju']])
data_list.append([datetime.datetime(2018,9,7),1,"Rotes Rathaus","Berlin","Germany","Dessau","Berlin","",['Reyer','Chris Brainerd','Riju']])
data_list.append([datetime.datetime(2018,9,7),1,"Marienkirche","Berlin","Germany","Dessau","Berlin","",['Reyer','Chris Brainerd','Riju']])
data_list.append([datetime.datetime(2018,9,7),4,"Fernsehturm Observatory","Berlin","Germany","Dessau","Berlin","",['Reyer','Chris Brainerd','Riju']])
data_list.append([datetime.datetime(2018,9,7),5,"Brandenburger Tor","Berlin","Germany","Dessau","Berlin","",['Reyer','Chris Brainerd','Riju']])
data_list.append([datetime.datetime(2018,9,7),1,"Reichstag","Berlin","Germany","Dessau","Berlin","",['Reyer','Chris Brainerd','Riju']])
data_list.append([datetime.datetime(2018,9,8),13,"Philharmonie","Berlin","Germany","Berlin","Berlin","",['Reyer','Chris Brainerd','Riju']])
data_list.append([datetime.datetime(2018,9,8),66,"Schloss Sanssouci","Potsdam","Germany","Berlin","Berlin","Prussian Palaces of Potsdam and Berlin",['Reyer','Chris Brainerd','Riju']])
data_list.append([datetime.datetime(2018,9,8),23,"Schlosspark Sanssouci","Potsdam","Germany","Berlin","Berlin","Prussian Palaces of Potsdam and Berlin",['Reyer','Chris Brainerd','Riju']])
data_list.append([datetime.datetime(2018,9,8),46,"Neue Kammern Sanssouci","Potsdam","Germany","Berlin","Berlin","Prussian Palaces of Potsdam and Berlin",['Reyer','Chris Brainerd','Riju']])
data_list.append([datetime.datetime(2018,9,8),101,"Neues Palais Sanssouci","Potsdam","Germany","Berlin","Berlin","Prussian Palaces of Potsdam and Berlin",['Reyer','Chris Brainerd','Riju']])
data_list.append([datetime.datetime(2018,9,8),37,"Orangerieschloss Sanssouci","Potsdam","Germany","Berlin","Berlin","Prussian Palaces of Potsdam and Berlin",['Reyer','Chris Brainerd','Riju']])
data_list.append([datetime.datetime(2018,9,8),5,"Communs Sanssouci","Potsdam","Germany","Berlin","Berlin","Prussian Palaces of Potsdam and Berlin",['Reyer','Chris Brainerd','Riju']])
data_list.append([datetime.datetime(2018,9,8),34,"Charlottenhof Sanssouci","Potsdam","Germany","Berlin","Berlin","Prussian Palaces of Potsdam and Berlin",['Reyer','Chris Brainerd','Riju']])
data_list.append([datetime.datetime(2018,9,8),16,"Roemisches Bad Sanssouci","Potsdam","Germany","Berlin","Berlin","Prussian Palaces of Potsdam and Berlin",['Reyer','Chris Brainerd','Riju']])
data_list.append([datetime.datetime(2018,9,8),19,"Gemaeldegalerie Sanssouci","Potsdam","Germany","Berlin","Berlin","Prussian Palaces of Potsdam and Berlin",['Reyer','Chris Brainerd','Riju']])
data_list.append([datetime.datetime(2018,9,8),2,"Sony Center","Berlin","Germany","Berlin","Berlin","",['Reyer','Chris Brainerd','Riju']])
data_list.append([datetime.datetime(2018,9,9),1,"Bodemuseum","Berlin","Germany","Berlin","Geneva","Museumsinsel",['Reyer','Chris Brainerd','Riju']])
data_list.append([datetime.datetime(2018,9,9),3,"Alte Nationalgalerie","Berlin","Germany","Berlin","Geneva","Museumsinsel",['Reyer','Chris Brainerd','Riju']])
data_list.append([datetime.datetime(2018,9,9),29,"Dom","Berlin","Germany","Berlin","Geneva","",['Reyer','Chris Brainerd','Riju']])
data_list.append([datetime.datetime(2018,9,9),54,"Neues Museum","Berlin","Germany","Berlin","Geneva","Museumsinsel",['Reyer','Chris Brainerd','Riju']])
data_list.append([datetime.datetime(2018,9,9),80,"Pergamonmuseum","Berlin","Germany","Berlin","Geneva","Museumsinsel",['Reyer','Chris Brainerd','Riju']])
data_list.append([datetime.datetime(2018,9,9),54,"Neues Museum","Berlin","Germany","Berlin","Geneva","Museumsinsel",['Reyer','Chris Brainerd','Riju']])
data_list.append([datetime.datetime(2018,9,9),1,"Altes Museum","Berlin","Germany","Berlin","Geneva","Museumsinsel",['Reyer','Chris Brainerd','Riju']])
data_list.append([datetime.datetime(2018,9,9),5,"Stadtschloss","Berlin","Germany","Berlin","Geneva","Museumsinsel",['Reyer','Chris Brainerd','Riju']])
data_list.append([datetime.datetime(2018,9,9),11,"Dom Observatory","Berlin","Germany","Berlin","Geneva","",['Reyer','Chris Brainerd','Riju']])
data_list.append([datetime.datetime(2018,9,9),2,"Flughafen Berlin Tegel","Berlin","Germany","Berlin","Geneva","",['Reyer']])

# %%
#brussels II done
data_list.append([datetime.datetime(2018,9,22),1,"Brussel-Nord Station","Brussels","Belgium","Brussels","Brussels","",[]])
data_list.append([datetime.datetime(2018,9,22),1,"Antwerp-Centraal",'Antwerp',"Belgium",'Brussels','Brussels',"",[]])
data_list.append([datetime.datetime(2018,9,22),2,"Cathedral",'Antwerp',"Belgium",'Brussels','Brussels',"Belfries of Belgium and France",[]])
data_list.append([datetime.datetime(2018,9,22),43,"Plantin-Moretus Museum",'Antwerp',"Belgium",'Brussels','Brussels',"Plantin-Moretus Workshop",[]])
data_list.append([datetime.datetime(2018,9,22),11,"Sint-Carolus Borromeuskerk",'Antwerp',"Belgium",'Brussels','Brussels',"",[]])
data_list.append([datetime.datetime(2018,9,22),28,"Cathedral",'Mechelen',"Belgium",'Brussels','Brussels',"Belfries of Belgium and France",[]])
data_list.append([datetime.datetime(2018,9,22),4,"Town Hall",'Mechelen',"Belgium",'Brussels','Brussels',"Belfries of Belgium and France",[]])
data_list.append([datetime.datetime(2018,9,22),1,"Brussel-Centraal Station","Brussels","Belgium","Brussels","Brussels","",[]])
data_list.append([datetime.datetime(2018,9,22),1,"Cathedral","Brussels","Belgium","Brussels","Brussels","",['Rachel']])
data_list.append([datetime.datetime(2018,9,22),13,"Cantillon Brewery","Brussels","Belgium","Brussels","Brussels","",['Rachel']])
data_list.append([datetime.datetime(2018,9,22),12,"Atomium","Brussels","Belgium","Brussels","Brussels","",['Rachel']])
data_list.append([datetime.datetime(2018,9,22),1,"National Basilica","Koekelberg","Belgium","Brussels","Brussels","",['Rachel']])
data_list.append([datetime.datetime(2018,9,22),1,"Sainte Catherine",'Brussels',"Belgium",'Brussels','Brussels',"",['Rachel']])
data_list.append([datetime.datetime(2018,9,23),2,"Groot Begijnhof",'Leuven',"Belgium",'Brussels','Geneva',"Flemish Beguinages",['Rachel']])
data_list.append([datetime.datetime(2018,9,23),4,"Anthony Church",'Leuven',"Belgium",'Brussels','Geneva',"",['Rachel']])
data_list.append([datetime.datetime(2018,9,23),50,"Town Hall",'Leuven',"Belgium",'Brussels','Geneva',"",['Rachel']])
data_list.append([datetime.datetime(2018,9,23),35,"St Peter",'Leuven',"Belgium",'Brussels','Geneva',"Belfries of Belgium and France",['Rachel']])

# %%
data_list.append([datetime.datetime(2018,11,4),1,"Prieure St Pierre","Motiers","Switzerland","Geneva","Geneva","",['Rachel','Christine','Sasha','Chris Brainerd']])
data_list.append([datetime.datetime(2018,11,4),6,"Grotte de Cascade","Motiers","Switzerland","Geneva","Geneva","",['Rachel','Christine','Sasha','Chris Brainerd']])
data_list.append([datetime.datetime(2018,11,4),8,"Cascade","Motiers","Switzerland","Geneva","Geneva","",['Rachel','Christine','Sasha','Chris Brainerd']])
data_list.append([datetime.datetime(2018,11,4),4,"Church","Motiers","Switzerland","Geneva","Geneva","",['Rachel','Christine','Sasha','Chris Brainerd']])
#provence done
data_list.append([datetime.datetime(2018,11,17),1,"Fontaine Amedee Pichot","Arles","France","Nimes","Geneva","",['Santona']])
data_list.append([datetime.datetime(2018,11,17),15,"Amphitheatre","Arles","France","Nimes","Geneva","Arles, Roman and Romanesque Monuments",['Santona']])
data_list.append([datetime.datetime(2018,11,17),4,"Roman Theatre","Arles","France","Nimes","Geneva","Arles, Roman and Romanesque Monuments",['Santona']])
data_list.append([datetime.datetime(2018,11,17),3,"Alyscamps","Arles","France","Nimes","Geneva","Arles, Roman and Romanesque Monuments",['Santona']])
data_list.append([datetime.datetime(2018,11,17),14,"St Honorat","Arles","France","Nimes","Geneva","Arles, Roman and Romanesque Monuments",['Santona']])
data_list.append([datetime.datetime(2018,11,17),49,"Cathedral St Trophime","Arles","France","Nimes","Geneva","Arles, Roman and Romanesque Monuments",['Santona']])
data_list.append([datetime.datetime(2018,11,17),2,"Place de la Republique","Arles","France","Nimes","Geneva","",['Santona']])
data_list.append([datetime.datetime(2018,11,17),11,"Episcopal Palace","Arles","France","Nimes","Geneva","",['Santona']])
data_list.append([datetime.datetime(2018,11,17),4,"Cryptoporticus","Arles","France","Nimes","Geneva","Arles, Roman and Romanesque Monuments",['Santona']])
data_list.append([datetime.datetime(2018,11,17),5,"Baths of Constantine","Arles","France","Nimes","Geneva","Arles, Roman and Romanesque Monuments",['Santona']])
data_list.append([datetime.datetime(2018,11,17),12,"Musee Reattu","Arles","France","Nimes","Geneva","",['Santona']])
data_list.append([datetime.datetime(2018,11,18),27,"Basilique Notre-Dame de la Garde","Marseille","France","Nimes","Nimes","",['Santona']])
data_list.append([datetime.datetime(2018,11,18),1,"Gare Marseille St Charles","Marseille","France","Nimes","Nimes","",['Santona']])
data_list.append([datetime.datetime(2018,11,18),9,"Vieux Port","Marseille","France","Nimes","Nimes","",['Santona']])
data_list.append([datetime.datetime(2018,11,18),1,"Basilique Notre-Dame de la Garde","Marseille","France","Nimes","Nimes","",['Santona']])
data_list.append([datetime.datetime(2018,11,18),1,"St-Ferreol les Augustins","Marseille","France","Nimes","Nimes","",['Santona']])
data_list.append([datetime.datetime(2018,11,18),4,"Fort St-Nicolas","Marseille","France","Nimes","Nimes","",['Santona']])
data_list.append([datetime.datetime(2018,11,18),12,"Fort St-Jean","Marseille","France","Nimes","Nimes","",['Santona']])
data_list.append([datetime.datetime(2018,11,18),3,"Palais du Faro","Marseille","France","Nimes","Nimes","",['Santona']])
data_list.append([datetime.datetime(2018,11,18),29,"Cathedral","Marseille","France","Nimes","Nimes","",['Santona']])
data_list.append([datetime.datetime(2018,11,18),29,"Abbaye St Victor","Marseille","France","Nimes","Nimes","",['Santona']])
data_list.append([datetime.datetime(2018,11,18),26,"Palais Longchamp","Marseille","France","Nimes","Nimes","",['Santona']])
data_list.append([datetime.datetime(2018,11,18),6,"Palais Longchamp Museum of Fine Arts","Marseille","France","Nimes","Nimes","",['Santona']])
data_list.append([datetime.datetime(2018,11,18),1,"War Memmorial","Marseille","France","Nimes","Nimes","",['Santona']])
data_list.append([datetime.datetime(2018,11,18),2,"Maison Carree","Niimes","France","Nimes","Nimes","",['Santona']])
data_list.append([datetime.datetime(2018,11,18),1,"Clock Tower","Marseille","France","Nimes","Nimes","",['Santona']])
data_list.append([datetime.datetime(2018,11,18),1,"Esplanade Charles-de-Gaulle","Nimes","France","Nimes","Nimes","",['Santona']])
data_list.append([datetime.datetime(2018,11,18),1,"Amphitheatre","Nimes","France","Nimes","Nimes","",['Santona']])
data_list.append([datetime.datetime(2018,11,19),16,"Amphitheatre","Nimes","France","Nimes","Geneva","",['Santona']])
data_list.append([datetime.datetime(2018,11,19),6,"Tour Magne","Nimes","France","Nimes","Geneva","",['Santona']])
data_list.append([datetime.datetime(2018,11,19),13,"Cathedral","Nimes","France","Nimes","Geneva","",['Santona']])
data_list.append([datetime.datetime(2018,11,19),4,"Maison Carree","Nimes","France","Nimes","Geneva","",['Santona']])
data_list.append([datetime.datetime(2018,11,19),6,"Jardin de la Fontaine","Nimes","France","Nimes","Geneva","",['Santona']])
data_list.append([datetime.datetime(2018,11,19),10,"Temple of Diana","Nimes","France","Nimes","Geneva","",['Santona']])
data_list.append([datetime.datetime(2018,11,19),32,"Roman Theatre","Orange","France","Nimes","Geneva","Roman Theatre and its Surroundings and the Triumphal Arch of Orange",['Santona']])
data_list.append([datetime.datetime(2018,11,19),5,"Triumphal Arch","Orange","France","Nimes","Geneva","Roman Theatre and its Surroundings and the Triumphal Arch of Orange",['Santona']])
data_list.append([datetime.datetime(2018,11,19),6,"Cathedral","Orange","France","Nimes","Geneva","",['Santona']])
data_list.append([datetime.datetime(2018,11,19),15,"Museum","Orange","France","Nimes","Geneva","",['Santona']])
#Freiburg & Basel
data_list.append([datetime.datetime(2018,11,25),5,"Rathaus","Freiburg","Germany","Geneva","Geneva","",['Santona','Riju']])
data_list.append([datetime.datetime(2018,11,25),7,"Altes Kaufhaus","Freiburg","Germany","Geneva","Geneva","",['Santona','Riju']])
data_list.append([datetime.datetime(2018,11,25),80,"Minster","Freiburg","Germany","Geneva","Geneva","",['Santona','Riju']])
data_list.append([datetime.datetime(2018,11,25),2,"Martinstor","Freiburg","Germany","Geneva","Geneva","",['Santona','Riju']])
data_list.append([datetime.datetime(2018,11,25),1,"Georg's Fountain","Freiburg","Germany","Geneva","Geneva","",['Santona','Riju']])
data_list.append([datetime.datetime(2018,11,25),3,"Schwabentor","Freiburg","Germany","Geneva","Geneva","",['Santona','Riju']])
data_list.append([datetime.datetime(2018,11,25),2,"Tinguely Fountain","Basel","Switzerland","Geneva","Geneva","",['Santona','Riju']])
data_list.append([datetime.datetime(2018,11,25),13,"Rathaus","Basel","Switzerland","Geneva","Geneva","",['Santona','Riju']])
data_list.append([datetime.datetime(2018,11,25),12,"Minster","Basel","Switzerland","Geneva","Geneva","",['Santona','Riju']])

# %%
data_list.append([datetime.datetime(2018,12,8),58,"Hotel-Dieu des Hospices Civil de Beaune","Beaune","France","Geneva","Geneva","The Climats, terroirs of Burgundy",['Santona','Graham','YaoYao',"Chris Brainerd"]])
data_list.append([datetime.datetime(2018,12,8),35,"Cathedral","Dijon","France","Geneva","Geneva","The Climats, terroirs of Burgundy",['Santona','Graham','YaoYao',"Chris Brainerd"]])
data_list.append([datetime.datetime(2018,12,8),7,"Palais des Ducs","Dijon","France","Geneva","Geneva","The Climats, terroirs of Burgundy",['Santona','Graham','YaoYao',"Chris Brainerd"]])
data_list.append([datetime.datetime(2018,12,8),2,"Hotel Aubriot","Dijon","France","Geneva","Geneva","The Climats, terroirs of Burgundy",['Santona','Graham','YaoYao',"Chris Brainerd"]])
data_list.append([datetime.datetime(2018,12,8),19,"Notre-Dame","Dijon","France","Geneva","Geneva","The Climats, terroirs of Burgundy",['Santona','Graham','YaoYao',"Chris Brainerd"]])
data_list.append([datetime.datetime(2018,12,8),16,"St Michel","Dijon","France","Geneva","Geneva","The Climats, terroirs of Burgundy",['Santona','Graham','YaoYao',"Chris Brainerd"]])
data_list.append([datetime.datetime(2018,12,8),37,"Chateau du Clos de Vougeot","Vougeot","France","Geneva","Geneva","The Climats, terroirs of Burgundy",['Santona','Graham','YaoYao',"Chris Brainerd"]])
#ladenburg
data_list.append([datetime.datetime(2018,12,28),92,"Maulbronn Monastery","Maulbronn","Germany","Lauchringen","Ladenburg","Maulbronn Monastery Complex",['Heidrun',"Artur"]])
data_list.append([datetime.datetime(2018,12,28),2,"Martin's Tower","Ladenburg","Germany","Lauchringen","Ladenburg","",['Heidrun',"Artur"]])
data_list.append([datetime.datetime(2018,12,28),3,"Witches' Tower","Ladenburg","Germany","Lauchringen","Ladenburg","",['Heidrun',"Artur"]])
data_list.append([datetime.datetime(2018,12,28),6,"Market Square","Ladenburg","Germany","Lauchringen","Ladenburg","",['Heidrun',"Artur"]])
data_list.append([datetime.datetime(2018,12,28),4,"Gallus Church","Ladenburg","Germany","Lauchringen","Ladenburg","",['Heidrun',"Artur"]])
data_list.append([datetime.datetime(2018,12,28),2,"Protestant Church","Ladenburg","Germany","Lauchringen","Ladenburg","",['Heidrun',"Artur"]])
data_list.append([datetime.datetime(2018,12,28),2,"Dr Carl Benz Garage","Ladenburg","Germany","Lauchringen","Ladenburg","",['Heidrun',"Artur"]])
data_list.append([datetime.datetime(2018,12,29),91,"Ironworks","Voelklingen","Germany","Ladenburg","Ladenburg","Voelklingen Ironworks",['Heidrun',"Artur"]])
data_list.append([datetime.datetime(2018,12,29),15,"Ludwigskirche","Saarbruecken","Germany","Ladenburg","Ladenburg","",['Heidrun',"Artur"]])
data_list.append([datetime.datetime(2018,12,29),5,"Schloss","Saarbruecken","Germany","Ladenburg","Ladenburg","",['Heidrun',"Artur"]])
data_list.append([datetime.datetime(2018,12,29),30,"Lorsch Abbey","Lorsch","Germany","Ladenburg","Ladenburg","Abbey and Altenmuenster of Lorsch",['Heidrun',"Artur"]])
data_list.append([datetime.datetime(2018,12,30),71,"Schloss Mannheim","Mannheim","Germany","Ladenburg","Lauchringen","",['Heidrun',"Artur"]])
data_list.append([datetime.datetime(2018,12,30),2,"Jesuitenkirche","Mannheim","Germany","Ladenburg","Lauchringen","",['Heidrun',"Artur"]])
data_list.append([datetime.datetime(2018,12,30),105,"Rastatt Palace","Rastatt","Germany","Ladenburg","Lauchringen","",['Heidrun',"Artur"]])
data_list.append([datetime.datetime(2018,12,30),7,"Alexander Church","Rastatt","Germany","Ladenburg","Lauchringen","",['Heidrun',"Artur"]])
data_list.append([datetime.datetime(2018,12,30),1,"Johannes-Nepomuk-Fountain","Rastatt","Germany","Ladenburg","Lauchringen","",['Heidrun',"Artur"]])

# %%
#2019 complete
data_list.append([datetime.datetime(2019,3,10),37,"Cathedral San Sabino","Bari","Italy","Geneva","Bari","",['Heidrun','Artur']])
data_list.append([datetime.datetime(2019,3,10),64,"Basilica San Nicola","Bari","Italy","Geneva","Bari","",['Heidrun','Artur']])
data_list.append([datetime.datetime(2019,3,10),2,"Santa Maria del Buonconsiglio","Bari","Italy","Geneva","Bari","",['Heidrun','Artur']])
data_list.append([datetime.datetime(2019,3,10),44,"Castello Svevo","Bari","Italy","Geneva","Bari","",['Heidrun','Artur']])
data_list.append([datetime.datetime(2019,3,11),6,"Santa Maria de Idris","Matera","Italy","Bari","Bari","The Sassi and the Park of Rupestrian Churches of Matera",['Heidrun','Artur']])
data_list.append([datetime.datetime(2019,3,11),3,"Santa Chiara","Matera","Italy","Bari","Bari","The Sassi and the Park of Rupestrian Churches of Matera",['Heidrun','Artur']])
data_list.append([datetime.datetime(2019,3,11),7,"Chiesa del Purgatorio","Matera","Italy","Bari","Bari","The Sassi and the Park of Rupestrian Churches of Matera",['Heidrun','Artur']])
data_list.append([datetime.datetime(2019,3,11),10,"San Francesco d'Assisi","Matera","Italy","Bari","Bari","The Sassi and the Park of Rupestrian Churches of Matera",['Heidrun','Artur']])
data_list.append([datetime.datetime(2019,3,11),1,"Piazza del Sedile","Matera","Italy","Bari","Bari","The Sassi and the Park of Rupestrian Churches of Matera",['Heidrun','Artur']])
data_list.append([datetime.datetime(2019,3,11),32,"Duomo","Matera","Italy","Bari","Bari","The Sassi and the Park of Rupestrian Churches of Matera",['Heidrun','Artur']])
data_list.append([datetime.datetime(2019,3,11),6,"San Pietro Barisano","Matera","Italy","Bari","Bari","The Sassi and the Park of Rupestrian Churches of Matera",['Heidrun','Artur']])
data_list.append([datetime.datetime(2019,3,11),11,"Augustine Monastery","Matera","Italy","Bari","Bari","The Sassi and the Park of Rupestrian Churches of Matera",['Heidrun','Artur']])
data_list.append([datetime.datetime(2019,3,11),50,"San Nicola Dei Greci and Madonna Delle Virtu","Matera","Italy","Bari","Bari","The Sassi and the Park of Rupestrian Churches of Matera",['Heidrun','Artur']])
data_list.append([datetime.datetime(2019,3,11),9,"San Pietro Caveoso","Matera","Italy","Bari","Bari","The Sassi and the Park of Rupestrian Churches of Matera",['Heidrun','Artur']])
data_list.append([datetime.datetime(2019,3,11),12,"Casa Grotta","Matera","Italy","Bari","Bari","The Sassi and the Park of Rupestrian Churches of Matera",['Heidrun','Artur']])
data_list.append([datetime.datetime(2019,3,11),4,"Santa Lucia alle Malve","Matera","Italy","Bari","Bari","The Sassi and the Park of Rupestrian Churches of Matera",['Heidrun','Artur']])
data_list.append([datetime.datetime(2019,3,11),2,"Convicinio di San Antonio","Matera","Italy","Bari","Bari","The Sassi and the Park of Rupestrian Churches of Matera",['Heidrun','Artur']])
data_list.append([datetime.datetime(2019,3,12),16,"Duomo di San Corrado","Molfetta","Italy","Bari","Bari","",['Heidrun','Artur']])
data_list.append([datetime.datetime(2019,3,12),8,"Cathedral Santa Maria Assunta","Molfetta","Italy","Bari","Bari","",['Heidrun','Artur']])
data_list.append([datetime.datetime(2019,3,12),2,"Porta del Carmine","Bitonto","Italy","Bari","Bari","",['Heidrun','Artur']])
data_list.append([datetime.datetime(2019,3,12),1,"Guglia dell'Immacolata","Bitonto","Italy","Bari","Bari","",['Heidrun','Artur']])
data_list.append([datetime.datetime(2019,3,12),63,"Cathedral","Bitonto","Italy","Bari","Bari","",['Heidrun','Artur']])
data_list.append([datetime.datetime(2019,3,12),17,"Cathedral","Bitonto","Italy","Bari","Bari","",[]])
data_list.append([datetime.datetime(2019,3,12),1,"Piazza Camillo Benso Conte di Cavour","Bitonto","Italy","Bari","Bari","",['Heidrun','Artur']])
data_list.append([datetime.datetime(2019,3,12),2,"Torrione Angioino","Bitonto","Italy","Bari","Bari","",['Heidrun','Artur']])
data_list.append([datetime.datetime(2019,3,12),45,"Castel del Monte","Andria","Italy","Bari","Bari","Castel del Monte",['Heidrun','Artur']])
data_list.append([datetime.datetime(2019,3,12),27,"Cathedral","Trani","Italy","Bari","Bari","",['Heidrun','Artur']])
data_list.append([datetime.datetime(2019,3,13),20,"Chiesa del Carmine","Lecce","Italy","Bari","Bari","",['Heidrun','Artur']])
data_list.append([datetime.datetime(2019,3,13),11,"Basilica San Giovanni Battista","Lecce","Italy","Bari","Bari","",['Heidrun','Artur']])
data_list.append([datetime.datetime(2019,3,13),57,"Duomo","Lecce","Italy","Bari","Bari","",['Heidrun','Artur']])
data_list.append([datetime.datetime(2019,3,13),18,"Chiesa del Gesu","Lecce","Italy","Bari","Bari","",['Heidrun','Artur']])
data_list.append([datetime.datetime(2019,3,13),1,"Piazza Castromediano Sigismondo","Lecce","Italy","Bari","Bari","",['Heidrun','Artur']])
data_list.append([datetime.datetime(2019,3,13),3,"Palazzo del Seggio","Lecce","Italy","Bari","Bari","",['Heidrun','Artur']])
data_list.append([datetime.datetime(2019,3,13),2,"Amphitheatre","Lecce","Italy","Bari","Bari","",['Heidrun','Artur']])
data_list.append([datetime.datetime(2019,3,13),5,"Santa Maria della Grazia","Lecce","Italy","Bari","Bari","",['Heidrun','Artur']])
data_list.append([datetime.datetime(2019,3,13),1,"Fontana Dell'Armonia","Lecce","Italy","Bari","Bari","",['Heidrun','Artur']])
data_list.append([datetime.datetime(2019,3,13),35,"Basilica di Santa Croce","Lecce","Italy","Bari","Bari","",['Heidrun','Artur']])
data_list.append([datetime.datetime(2019,3,13),17,"San Matteo","Lecce","Italy","Bari","Bari","",['Heidrun','Artur']])
data_list.append([datetime.datetime(2019,3,13),2,"Roman Theatre","Lecce","Italy","Bari","Bari","",['Heidrun','Artur']])
data_list.append([datetime.datetime(2019,3,13),3,"Piazza Mercantile","Bari","Italy","Bari","Bari","",[]])
data_list.append([datetime.datetime(2019,3,13),3,"Piazza Farnese","Bari","Italy","Bari","Bari","",[]])
data_list.append([datetime.datetime(2019,3,13),1,"Piazza Umberto","Bari","Italy","Bari","Bari","",[]])
data_list.append([datetime.datetime(2019,3,13),4,"San Ferdinando","Bari","Italy","Bari","Bari","",[]])
data_list.append([datetime.datetime(2019,3,14),56,"Grotte di Castellana","Castellana Grotte","Italy","Bari","Bari","",['Heidrun','Artur']])
data_list.append([datetime.datetime(2019,3,14),28,"Trulli","Alberobello","Italy","Bari","Bari","The Trulli of Alberobello",['Heidrun','Artur']])
data_list.append([datetime.datetime(2019,3,14),7,"Sant'Antonio di Padova","Alberobello","Italy","Bari","Bari","The Trulli of Alberobello",['Heidrun','Artur']])
data_list.append([datetime.datetime(2019,3,14),2,"Largo Martellotta","Castellana Grotte","Italy","Bari","Bari","",['Heidrun','Artur']])
data_list.append([datetime.datetime(2019,3,15),2,"Santa Caterina a Formiello","Naples","Italy","Bari","Naples","Naples",['Heidrun','Artur']])
data_list.append([datetime.datetime(2019,3,15),50,"San Giovanni a Carbonara","Naples","Italy","Bari","Naples","Naples",['Heidrun','Artur']])
data_list.append([datetime.datetime(2019,3,15),2,"Porta San Gennaro","Naples","Italy","Bari","Naples","Naples",['Heidrun','Artur']])
data_list.append([datetime.datetime(2019,3,15),106,"Reggia di Capodimonte","Naples","Italy","Bari","Naples","Naples",['Heidrun','Artur']])
data_list.append([datetime.datetime(2019,3,15),1,"Vesuvius","Octaviano","Italy","Bari","Naples","Naples",['Heidrun','Artur']])
data_list.append([datetime.datetime(2019,3,15),118,"National Museum of Archaeology","Naples","Italy","Bari","Naples","Naples",['Heidrun','Artur']])
data_list.append([datetime.datetime(2019,3,15),2,"Santa Maria del Rosario alle Pigne","Naples","Italy","Bari","Naples","Naples",['Heidrun','Artur']])
data_list.append([datetime.datetime(2019,3,15),18,"Duomo","Naples","Italy","Bari","Naples","Naples",['Heidrun','Artur']])
data_list.append([datetime.datetime(2019,3,16),168,"Caserta Palace","Caserta","Italy","Naples","Naples","Reggia di Caserta",['Heidrun','Artur']])
data_list.append([datetime.datetime(2019,3,16),32,"Caserta Palace Park","Caserta","Italy","Naples","Naples","Reggia di Caserta",['Heidrun','Artur']])
data_list.append([datetime.datetime(2019,3,16),24,"Arch of Trajan","Benevento","Italy","Naples","Naples","",['Heidrun','Artur']])
data_list.append([datetime.datetime(2019,3,16),4,"Basilica Bartolomeo","Benevento","Italy","Naples","Naples","",['Heidrun','Artur']])
data_list.append([datetime.datetime(2019,3,16),32,"Museo del Sannio","Benevento","Italy","Naples","Naples","",['Heidrun','Artur']])
data_list.append([datetime.datetime(2019,3,16),35,"Santa Sofia","Benevento","Italy","Naples","Naples","Longobards in Italy. Places of the Power",['Heidrun','Artur']])
data_list.append([datetime.datetime(2019,3,16),19,"Duomo","Benevento","Italy","Naples","Naples","Longobards in Italy. Places of the Power",['Heidrun','Artur']])
data_list.append([datetime.datetime(2019,3,16),5,"Roman Theatre","Benevento","Italy","Naples","Naples","Longobards in Italy. Places of the Power",['Heidrun','Artur']])
data_list.append([datetime.datetime(2019,3,17),127,"Herculaneum Excavations","Ercolano","Italy","Naples","Naples","Pompei, Herculaneum and Torre Annunziata",['Heidrun','Artur']])
data_list.append([datetime.datetime(2019,3,17),44,"Villa Campolieto","Ercolano","Italy","Naples","Naples","",['Heidrun','Artur']])
data_list.append([datetime.datetime(2019,3,17),42,"Reggia di Portici","Portici","Italy","Naples","Naples","",['Heidrun','Artur']])
data_list.append([datetime.datetime(2019,3,17),16,"Reggia di Portici Botanical Garden","Portici","Italy","Naples","Naples","",['Heidrun','Artur']])
data_list.append([datetime.datetime(2019,3,17),1,"Certosa di San Martino","Naples","Italy","Naples","Naples","Naples",['Heidrun','Artur']])
data_list.append([datetime.datetime(2019,3,17),4,"Castel Nuovo","Naples","Italy","Naples","Naples","Naples",['Heidrun','Artur']])
data_list.append([datetime.datetime(2019,3,17),90,"Palazzo Reale","Naples","Italy","Naples","Naples","Naples",['Heidrun','Artur']])
data_list.append([datetime.datetime(2019,3,17),7,"Galleria Umberto I","Naples","Italy","Naples","Naples","Naples",['Heidrun','Artur']])
data_list.append([datetime.datetime(2019,3,17),2,"Teatro San Carlo","Naples","Italy","Naples","Naples","Naples",['Heidrun','Artur']])
data_list.append([datetime.datetime(2019,3,17),1,"Piazza Triesste","Naples","Italy","Naples","Naples","Naples",['Heidrun','Artur']])
data_list.append([datetime.datetime(2019,3,17),1,"Basilica Reale San Francesco da Paola","Naples","Italy","Naples","Naples","Naples",['Heidrun','Artur']])
data_list.append([datetime.datetime(2019,3,17),3,"Santa Chiara","Naples","Italy","Naples","Naples","Naples",['Heidrun','Artur']])
data_list.append([datetime.datetime(2019,3,17),1,"Guglia dell'Immacolata","Naples","Italy","Naples","Naples","Naples",['Heidrun','Artur']])
data_list.append([datetime.datetime(2019,3,17),15,"Chiesa del Gesu Nuovo","Naples","Italy","Naples","Naples","Naples",['Heidrun','Artur']])
data_list.append([datetime.datetime(2019,3,17),22,"Basilica San Domenico Maggiore","Naples","Italy","Naples","Naples","Naples",['Heidrun','Artur']])
data_list.append([datetime.datetime(2019,3,17),1,"San Lorenzo Maggiore","Naples","Italy","Naples","Naples","Naples",['Heidrun','Artur']])
data_list.append([datetime.datetime(2019,3,17),1,"San Paolo Maggiore","Naples","Italy","Naples","Naples","Naples",['Heidrun','Artur']])
data_list.append([datetime.datetime(2019,3,17),33,"Duomo Treasury","Naples","Italy","Naples","Naples","Naples",[]])
data_list.append([datetime.datetime(2019,3,17),65,"Duomo","Naples","Italy","Naples","Naples","Naples",['Heidrun','Artur']])
data_list.append([datetime.datetime(2019,3,18),1,"Town Walls","Paestum","Italy","Naples","Naples","Cilento and Vallo di Diano National Park with the Archeological Sites of Paestum and Velia, and the Certosa di Padula",['Heidrun','Artur']])
data_list.append([datetime.datetime(2019,3,18),4,"Forum","Paestum","Italy","Naples","Naples","Cilento and Vallo di Diano National Park with the Archeological Sites of Paestum and Velia, and the Certosa di Padula",['Heidrun','Artur']])
data_list.append([datetime.datetime(2019,3,18),1,"Amphitheatre","Paestum","Italy","Naples","Naples","Cilento and Vallo di Diano National Park with the Archeological Sites of Paestum and Velia, and the Certosa di Padula",['Heidrun','Artur']])
data_list.append([datetime.datetime(2019,3,18),6,"Athena Temple","Paestum","Italy","Naples","Naples","Cilento and Vallo di Diano National Park with the Archeological Sites of Paestum and Velia, and the Certosa di Padula",['Heidrun','Artur']])
data_list.append([datetime.datetime(2019,3,18),21,"Poseidon Temple","Paestum","Italy","Naples","Naples","Cilento and Vallo di Diano National Park with the Archeological Sites of Paestum and Velia, and the Certosa di Padula",['Heidrun','Artur']])
data_list.append([datetime.datetime(2019,3,18),13,"Hera Temple","Paestum","Italy","Naples","Naples","Cilento and Vallo di Diano National Park with the Archeological Sites of Paestum and Velia, and the Certosa di Padula",['Heidrun','Artur']])
data_list.append([datetime.datetime(2019,3,18),54,"Villa Pignatelli","Naples","Italy","Naples","Naples","Naples",['Heidrun','Artur']])
data_list.append([datetime.datetime(2019,3,18),3,"Castel Sant'Elmo","Naples","Italy","Naples","Naples","Naples",['Heidrun','Artur']])
data_list.append([datetime.datetime(2019,3,18),127,"Certosa di San Martino","Naples","Italy","Naples","Naples","Naples",['Heidrun','Artur']])
data_list.append([datetime.datetime(2019,3,18),21,"Santa Chiara","Naples","Italy","Naples","Naples","Naples",['Heidrun','Artur']])
data_list.append([datetime.datetime(2019,3,18),1,"Vesuvio","Naples","Italy","Naples","Naples","",['Heidrun','Artur']])
data_list.append([datetime.datetime(2019,3,18),1,"Chiese del Gesu Nuovo","Naples","Italy","Naples","Naples","Naples",['Heidrun','Artur']])
data_list.append([datetime.datetime(2019,3,18),2,"Guglia dell'Immacolata","Naples","Italy","Naples","Naples","Naples",['Heidrun','Artur']])
data_list.append([datetime.datetime(2019,3,18),1,"San Domenico Obelisk","Naples","Italy","Naples","Naples","Naples",['Heidrun','Artur']])
data_list.append([datetime.datetime(2019,3,18),4,"Piazza Dante","Naples","Italy","Naples","Naples","Naples",['Heidrun','Artur']])
data_list.append([datetime.datetime(2019,3,19),20,"Shrine of the Virgin of the Rosary of Pompei","Pompei","Italy","Naples","Naples","",['Heidrun','Artur']])
data_list.append([datetime.datetime(2019,3,19),142,"Excavations","Pompei","Italy","Naples","Naples","Archaeological Areas of Pompei, Herculaneum and Torre Annunziata",['Heidrun','Artur']])
data_list.append([datetime.datetime(2019,3,19),2,"Vesuvio","Naples","Italy","Naples","Naples","",['Heidrun','Artur']])
data_list.append([datetime.datetime(2019,3,19),25,"Excavations Villa of Mysteries","Pompei","Italy","Naples","Naples","Archaeological Areas of Pompei, Herculaneum and Torre Annunziata",['Heidrun','Artur']])
data_list.append([datetime.datetime(2019,3,19),73,"Villa Poppaea","Torre Annunziata","Italy","Naples","Naples","Archaeological Areas of Pompei, Herculaneum and Torre Annunziata",['Heidrun','Artur']])
data_list.append([datetime.datetime(2019,3,19),6,"Piazza Dante","Naples","Italy","Naples","Naples","Naples",['Heidrun','Artur']])
data_list.append([datetime.datetime(2019,3,19),48,"Santa Chiara","Naples","Italy","Naples","Naples","Naples",['Heidrun','Artur']])
data_list.append([datetime.datetime(2019,3,19),18,"San Domenico Maggiore","Naples","Italy","Naples","Naples","Naples",['Artur']])
data_list.append([datetime.datetime(2019,3,20),8,"Santa Maria Assunta","Positano","Italy","Naples","Naples","Costiera Amalfitana",['Heidrun','Artur']])
data_list.append([datetime.datetime(2019,3,20),16,"Cloister of Paradise","Amalfi","Italy","Naples","Naples","Costiera Amalfitana",['Heidrun','Artur']])
data_list.append([datetime.datetime(2019,3,20),24,"Basilica of the Crucifix","Amalfi","Italy","Naples","Naples","Costiera Amalfitana",['Heidrun','Artur']])
data_list.append([datetime.datetime(2019,3,20),52,"Duomo","Amalfi","Italy","Naples","Naples","Costiera Amalfitana",['Heidrun','Artur']])
data_list.append([datetime.datetime(2019,3,20),3,"Piazza di Duomo","Amalfi","Italy","Naples","Naples","Costiera Amalfitana",['Heidrun','Artur']])
data_list.append([datetime.datetime(2019,3,20),1,"Piazza Flavio Gioia","Salerno","Italy","Naples","Naples","",['Heidrun','Artur']])
data_list.append([datetime.datetime(2019,3,20),1,"Porta Nova","Salerno","Italy","Naples","Naples","",['Heidrun','Artur']])
data_list.append([datetime.datetime(2019,3,20),62,"Duomo","Salerno","Italy","Naples","Naples","",['Heidrun','Artur']])
data_list.append([datetime.datetime(2019,3,20),28,"Amphitheatre","Pozzuoli","Italy","Naples","Naples","",['Heidrun','Artur']])
data_list.append([datetime.datetime(2019,3,20),3,"Temple of Neptune","Pozzuoli","Italy","Naples","Naples","",['Heidrun','Artur']])
data_list.append([datetime.datetime(2019,3,20),3,"Macellum","Pozzuoli","Italy","Naples","Naples","",['Heidrun','Artur']])
data_list.append([datetime.datetime(2019,3,20),5,"San Raffaelo","Pozzuoli","Italy","Naples","Naples","",['Heidrun','Artur']])
data_list.append([datetime.datetime(2019,3,20),2,"San Giuseppe","Pozzuoli","Italy","Naples","Naples","",['Heidrun','Artur']])
data_list.append([datetime.datetime(2019,3,20),47,"Roman Baths","Baia","Italy","Naples","Naples","",['Heidrun','Artur']])
data_list.append([datetime.datetime(2019,3,20),2,"Temple of Venus","Baia","Italy","Naples","Naples","",['Heidrun','Artur']])
data_list.append([datetime.datetime(2019,3,20),2,"Temple of Mercury","Baia","Italy","Naples","Naples","",['Heidrun','Artur']])
data_list.append([datetime.datetime(2019,3,20),7,"Monte Nuovo","Baia","Italy","Naples","Naples","",['Artur']])
data_list.append([datetime.datetime(2019,3,20),2,"Santa Maria di Montesanto","Naples","Italy","Naples","Naples","Naples",[]])
data_list.append([datetime.datetime(2019,3,20),2,"San Michele Arcangelo a Port'Alba","Naples","Italy","Naples","Naples","Naples",[]])
data_list.append([datetime.datetime(2019,3,20),1,"Piazza Dante","Naples","Italy","Naples","Naples","Naples",[]])
data_list.append([datetime.datetime(2019,3,20),43,"San Lorenzo Maggiore","Naples","Italy","Naples","Naples","Naples",[]])
data_list.append([datetime.datetime(2019,3,20),2,"Santa Maria delle Anime del Purgatorio ad Arco","Naples","Italy","Naples","Naples","Naples",[]])
data_list.append([datetime.datetime(2019,3,20),2,"Port d'Alba","Naples","Italy","Naples","Naples","Naples",[]])
data_list.append([datetime.datetime(2019,3,21),1,"Piazza Garibaldi","Naples","Italy","Naples","Naples","",['Heidrun','Artur']])

# %%
#paris I done
data_list.append([datetime.datetime(2019, 4, 18),1,"Tour St Jacques",'Paris',"France",'Geneva','Paris',"Routes of Santiago de Compostela",['Chris Brainerd','Riju']])
data_list.append([datetime.datetime(2019, 4, 19),103,"Abbey of St Savin",'St Savin',"France",'Paris','Paris',"Abbey Church of St Savin",['Chris Brainerd','Riju']])
data_list.append([datetime.datetime(2019, 4, 19),3,"Old Bridge",'St Savin',"France",'Paris','Paris',"",['Chris Brainerd','Riju']])
data_list.append([datetime.datetime(2019, 4, 19),2,"Place de la Republique",'St Savin',"France",'Paris','Paris',"",['Chris Brainerd','Riju']])
data_list.append([datetime.datetime(2019, 4, 19),29,"St Hilaire-le-Grand",'Poitiers',"France",'Paris','Paris',"Routes of Santiago de Compostela",['Chris Brainerd','Riju']])
data_list.append([datetime.datetime(2019, 4, 19),3,"Palais des Ducs de Aquitaine",'Poitiers',"France",'Paris','Paris',"",['Chris Brainerd','Riju']])
data_list.append([datetime.datetime(2019, 4, 19),23,"Notre-Dame-la-Grande",'Poitiers',"France",'Paris','Paris',"",['Chris Brainerd','Riju']])
data_list.append([datetime.datetime(2019, 4, 19),28,"Cathedral",'Poitiers',"France",'Paris','Paris',"",['Chris Brainerd','Riju']])
data_list.append([datetime.datetime(2019, 4, 19),20,"Baptistery",'Poitiers',"France",'Paris','Paris',"",['Chris Brainerd','Riju']])
data_list.append([datetime.datetime(2019, 4, 19),15,"St Radegonde",'Poitiers',"France",'Paris','Paris',"",['Chris Brainerd','Riju']])
data_list.append([datetime.datetime(2019, 4, 19),4,"Hotel Fume",'Poitiers',"France",'Paris','Paris',"",['Chris Brainerd','Riju']])
data_list.append([datetime.datetime(2019, 4, 19),1,"Hotel Berthelot",'Poitiers',"France",'Paris','Paris',"",['Chris Brainerd','Riju']])
data_list.append([datetime.datetime(2019, 4, 19),2,"St Jean de Montierneuf",'Poitiers',"France",'Paris','Paris',"",['Chris Brainerd','Riju']])
data_list.append([datetime.datetime(2019, 4, 19),1,"Tour Montparnasse",'Paris',"France",'Paris','Paris',"",['Chris Brainerd','Riju']])
data_list.append([datetime.datetime(2019, 4, 19),1,"Gare Montparnasse",'Paris',"France",'Paris','Paris',"",['Chris Brainerd','Riju']])
#including St Louis & Dome d'Invalides
data_list.append([datetime.datetime(2019, 4, 19),1,"Hotel d'Invalides",'Paris',"France",'Paris','Paris',"Paris, Banks of the Seine",['Chris Brainerd','Riju']])
data_list.append([datetime.datetime(2019, 4, 19),3,"Tour Eiffel",'Paris',"France",'Paris','Paris',"Paris, Banks of the Seine",['Chris Brainerd','Riju']])
data_list.append([datetime.datetime(2019, 4, 19),17,"Tour Montparnasse Observatory",'Paris',"France",'Paris','Paris',"",['Chris Brainerd','Riju']])
data_list.append([datetime.datetime(2019, 4, 19),1,"St Sulpice",'Paris',"France",'Paris','Paris',"",['Chris Brainerd','Riju']])
data_list.append([datetime.datetime(2019, 4, 19),1,"Louvre",'Paris',"France",'Paris','Paris',"Paris, Banks of the Seine",['Chris Brainerd','Riju']])
data_list.append([datetime.datetime(2019, 4, 19),1,"Pantheon",'Paris',"France",'Paris','Paris',"",['Chris Brainerd','Riju']])
data_list.append([datetime.datetime(2019, 4, 20),16,"Collegiale St Quiriace",'Provins',"France",'Paris','Paris',"Provins",['Chris Brainerd','Riju']])
data_list.append([datetime.datetime(2019, 4, 20),11,"Tour Cesar",'Provins',"France",'Paris','Paris',"Provins",['Chris Brainerd','Riju']])
data_list.append([datetime.datetime(2019, 4, 20),3,"Porte St Jean",'Provins',"France",'Paris','Paris',"Provins",['Chris Brainerd','Riju']])
data_list.append([datetime.datetime(2019, 4, 20),14,"Town Walls",'Provins',"France",'Paris','Paris',"Provins",['Chris Brainerd','Riju']])
data_list.append([datetime.datetime(2019, 4, 20),3,"Porte St Jouy",'Provins',"France",'Paris','Paris',"Provins",['Chris Brainerd','Riju']])
data_list.append([datetime.datetime(2019, 4, 20),226,"Chateau de Fontainebleau",'Fontainebleau',"France",'Paris','Paris',"Palace and Park of Fontainebleau",['Chris Brainerd','Riju']])
data_list.append([datetime.datetime(2019, 4, 20),24,"Chateau de Fontainebleau Gardens",'Fontainebleau',"France",'Paris','Paris',"Palace and Park of Fontainebleau",['Chris Brainerd','Riju']])
data_list.append([datetime.datetime(2019, 4, 20),2,"Tour St Jacques",'Paris',"France",'Paris','Paris',"Routes of Santiago de Compostela",['Chris Brainerd','Riju']])
data_list.append([datetime.datetime(2019, 4, 20),1,"Place du Chatelet",'Paris',"France",'Paris','Paris',"Paris, Banks of the Seine",['Chris Brainerd','Riju']])
data_list.append([datetime.datetime(2019, 4, 20),1,"Conciergerie",'Paris',"France",'Paris','Paris',"Paris, Banks of the Seine",['Chris Brainerd','Riju']])
data_list.append([datetime.datetime(2019, 4, 20),9,"Notre-Dame",'Paris',"France",'Paris','Paris',"Paris, Banks of the Seine",['Chris Brainerd','Riju']])
data_list.append([datetime.datetime(2019, 4, 20),1,"Sainte Chapelle",'Paris',"France",'Paris','Paris',"Paris, Banks of the Seine",['Chris Brainerd','Riju']])
data_list.append([datetime.datetime(2019, 4, 20),6,"Pont Neuf",'Paris',"France",'Paris','Paris',"Paris, Banks of the Seine",['Chris Brainerd','Riju']])
data_list.append([datetime.datetime(2019, 4, 20),1,"Fontaine St Michel",'Paris',"France",'Paris','Paris',"",['Chris Brainerd','Riju']])
data_list.append([datetime.datetime(2019, 4, 20),18,"Louvre",'Paris',"France",'Paris','Paris',"Paris, Banks of the Seine",['Chris Brainerd','Riju']])
data_list.append([datetime.datetime(2019, 4, 20),4,"Hotel de Monnaie",'Paris',"France",'Paris','Paris',"Paris, Banks of the Seine",['Chris Brainerd','Riju']])
data_list.append([datetime.datetime(2019, 4, 20),3,"Institut de France",'Paris',"France",'Paris','Paris',"Paris, Banks of the Seine",['Chris Brainerd','Riju']])
data_list.append([datetime.datetime(2019, 4, 20),2,"Saint-Germain-l'Auxerrois",'Paris',"France",'Paris','Paris',"Paris, Banks of the Seine",['Chris Brainerd','Riju']])
data_list.append([datetime.datetime(2019, 4, 20),4,"Arc du Carrousel",'Paris',"France",'Paris','Paris',"Paris, Banks of the Seine",['Chris Brainerd','Riju']])
data_list.append([datetime.datetime(2019, 4, 20),16,"Tour Eiffel",'Paris',"France",'Paris','Paris',"Paris, Banks of the Seine",['Chris Brainerd','Riju']])
data_list.append([datetime.datetime(2019, 4, 20),12,"Tour Eiffel Observatory",'Paris',"France",'Paris','Paris',"",['Chris Brainerd','Riju']])
data_list.append([datetime.datetime(2019, 4, 20),1,"Hotel d'Invalides",'Paris',"France",'Paris','Paris',"Paris, Banks of the Seine",['Chris Brainerd','Riju']])
data_list.append([datetime.datetime(2019, 4, 20),1,"Ecole Militaire",'Paris',"France",'Paris','Paris',"Paris, Banks of the Seine",['Chris Brainerd','Riju']])
data_list.append([datetime.datetime(2019, 4, 20),1,"Palais de Chaillot",'Paris',"France",'Paris','Paris',"Paris, Banks of the Seine",['Chris Brainerd','Riju']])
data_list.append([datetime.datetime(2019, 4, 21),2,"Tour Eiffel",'Paris',"France",'Paris','Paris',"Paris, Banks of the Seine",['Chris Brainerd','Riju']])
data_list.append([datetime.datetime(2019, 4, 21),91,"Palais Jacques-Coeur",'Bourges',"France",'Paris','Paris',"",[]])
data_list.append([datetime.datetime(2019, 4, 21),195,"Cathedral",'Bourges',"France",'Paris','Paris',"Bourges Cathedral",[]])
data_list.append([datetime.datetime(2019, 4, 21),5,"Hotel des Echevins",'Bourges',"France",'Paris','Paris',"Bourges Cathedral",[]])
data_list.append([datetime.datetime(2019, 4, 21),14,"Cathedral Tower View",'Bourges',"France",'Paris','Paris',"Bourges Cathedral",[]])
data_list.append([datetime.datetime(2019, 4, 21),3,"Palais Duc Jean Berry",'Bourges',"France",'Paris','Paris',"",[]])
data_list.append([datetime.datetime(2019, 4, 21),25,"Hotel Lallemant",'Bourges',"France",'Paris','Paris',"",[]])
data_list.append([datetime.datetime(2019, 4, 22),2,"Gare St Lazare",'Paris',"France",'Paris','Geneva',"",['Chris Brainerd','Riju']])
data_list.append([datetime.datetime(2019, 4, 22),5,"Gare du Havre",'Le Havre',"France",'Paris','Geneva',"",['Chris Brainerd','Riju']])
#together with Hotel de Ville
data_list.append([datetime.datetime(2019, 4, 22),4,"Place Hotel de Ville",'Le Havre',"France",'Paris','Geneva',"Le Havre",['Chris Brainerd','Riju']])
data_list.append([datetime.datetime(2019, 4, 22),32,"St Joseph",'Le Havre',"France",'Paris','Geneva',"Le Havre",['Chris Brainerd','Riju']])
data_list.append([datetime.datetime(2019, 4, 22),9,"Le Volcan & Bibliotheque Oscar Niemeyer",'Le Havre',"France",'Paris','Geneva',"Le Havre",['Chris Brainerd','Riju']])
data_list.append([datetime.datetime(2019, 4, 22),4,"Gare de Lyon",'Paris',"France",'Paris','Geneva',"",['Chris Brainerd','Riju']])
#london & oxford done
data_list.append([datetime.datetime(2019,4,13),2,"London St Pancras","London","United Kingdom","London","London","",[]])
data_list.append([datetime.datetime(2019,4,13),3,"London King's Cross","London","United Kingdom","London","London","",[]])
data_list.append([datetime.datetime(2019,4,13),2,"Downing College","Cambridge","United Kingdom","London","London","",[]])
data_list.append([datetime.datetime(2019,4,13),2,"St Andrews Street Baptist Church","Cambridge","United Kingdom","London","London","",[]])
data_list.append([datetime.datetime(2019,4,13),5,"Great St Mary's","Cambridge","United Kingdom","London","London","",[]])
data_list.append([datetime.datetime(2019,4,13),51,"King's College","Cambridge","United Kingdom","London","London","",[]])
data_list.append([datetime.datetime(2019,4,13),23,"St John's College","Cambridge","United Kingdom","London","London","",[]])
data_list.append([datetime.datetime(2019,4,13),63,"Cathedral","Peterborough","United Kingdom","London","London","",[]])
data_list.append([datetime.datetime(2019,4,13),3,"Guildhall","Peterborough","United Kingdom","London","London","",[]])
data_list.append([datetime.datetime(2019,4,13),77,"Cathedral","Ely","United Kingdom","London","London","",[]])
data_list.append([datetime.datetime(2019,4,14),73,"Old Royal Naval College","London","United Kingdom","London","Oxford","Maritime Greenwich",[]])
data_list.append([datetime.datetime(2019, 4, 14),31,"Queen's House",'London',"United Kingdom",'London','Oxford',"Maritime Greenwich",[]])
data_list.append([datetime.datetime(2019, 4, 14),3,"Greenwich Observatory",'London',"United Kingdom",'London','Oxford',"Maritime Greenwich",[]])
data_list.append([datetime.datetime(2019, 4, 14),27,"Kenwood House",'London',"United Kingdom",'London','Oxford',"",[]])
data_list.append([datetime.datetime(2019, 4, 14),3,"Kenwood House Gardens",'London',"United Kingdom",'London','Oxford',"",[]])
data_list.append([datetime.datetime(2019, 4, 14),93,"British Museum",'London',"United Kingdom",'London','Oxford',"",[]])
data_list.append([datetime.datetime(2019, 4, 14),1,"Radcliffe Camera",'Oxford',"United Kingdom",'London','Oxford',"",[]])
data_list.append([datetime.datetime(2019, 4, 14),1,"Balliol College",'Oxford',"United Kingdom",'London','Oxford',"",[]])
data_list.append([datetime.datetime(2019, 4, 15),2,"Blackfriars Church",'Oxford',"United Kingdom",'Oxford','Oxford',"",[]])
data_list.append([datetime.datetime(2019, 4, 15),1,"St Aloysius Church",'Oxford',"United Kingdom",'Oxford','Oxford',"",[]])
data_list.append([datetime.datetime(2019, 4, 16),2,"St Mary Magdalen",'Oxford',"United Kingdom",'Oxford','Oxford',"",[]])
data_list.append([datetime.datetime(2019, 4, 16),6,"St Anne's College",'Oxford',"United Kingdom",'Oxford','Oxford',"",[]])
data_list.append([datetime.datetime(2019, 4, 16),18,"Brasenose College",'Oxford',"United Kingdom",'Oxford','Oxford',"",[]])
data_list.append([datetime.datetime(2019, 4, 16),2,"Radcliffe Camera",'Oxford',"United Kingdom",'Oxford','Oxford',"",[]])
data_list.append([datetime.datetime(2019, 4, 17),3,"St Anne's College",'Oxford',"United Kingdom",'Oxford','Oxford',"",[]])
data_list.append([datetime.datetime(2019, 4, 17),5,"Wadham College",'Oxford',"United Kingdom",'Oxford','Oxford',"",[]])
data_list.append([datetime.datetime(2019, 4, 17),5,"Bodleian Library",'Oxford',"United Kingdom",'Oxford','Oxford',"",[]])
data_list.append([datetime.datetime(2019, 4, 17),1,"Radcliffe Camera",'Oxford',"United Kingdom",'Oxford','Oxford',"",[]])
data_list.append([datetime.datetime(2019, 4, 17),1,"Brasenose College",'Oxford',"United Kingdom",'Oxford','Oxford',"",[]])
data_list.append([datetime.datetime(2019, 4, 17),8,"Balliol College",'Oxford',"United Kingdom",'Oxford','Oxford',"",[]])

# %%
#liechtenstein done
data_list.append([datetime.datetime(2019, 5, 26),3,"Burg Gutenberg",'Balzers',"Liechtenstein",'Geneva','Geneva',"",['Riju']])
data_list.append([datetime.datetime(2019, 5, 26),13,"Schloss Vaduz",'Vaduz',"Liechtenstein",'Geneva','Geneva',"",['Riju']])
data_list.append([datetime.datetime(2019, 5, 26),2,"Rathaus",'Vaduz',"Liechtenstein",'Geneva','Geneva',"",['Riju']])
data_list.append([datetime.datetime(2019, 5, 26),3,"Rotes Haus",'Vaduz',"Liechtenstein",'Geneva','Geneva',"",['Riju']])
data_list.append([datetime.datetime(2019, 5, 26),12,"St Florin's Cathedral",'Vaduz',"Liechtenstein",'Geneva','Geneva',"",['Riju']])
data_list.append([datetime.datetime(2019, 5, 26),3,"Kunsthaus",'Zurich',"Switzerland",'Geneva','Geneva',"",['Riju']])
#hannover done
data_list.append([datetime.datetime(2019,5,30),3,"Welfenschloss","Hannover","Germany","Geneva","Hannover","",['Grace']])
data_list.append([datetime.datetime(2019,5,30),3,"Nord LB Headquarters","Hannover","Germany","Geneva","Hannover","",['Grace']])
data_list.append([datetime.datetime(2019,5,30),10,"City Hall","Hannover","Germany","Geneva","Hannover","",['Grace']])
data_list.append([datetime.datetime(2019,5,30),2,"Leineschloss","Hannover","Germany","Geneva","Hannover","",['Grace']])
data_list.append([datetime.datetime(2019,5,30),4,"Holzmarkt","Hannover","Germany","Geneva","Hannover","",['Grace']])
data_list.append([datetime.datetime(2019,5,30),7,"Marktkirche","Hannover","Germany","Geneva","Hannover","",['Grace']])
data_list.append([datetime.datetime(2019,5,30),55,"Schloss","Oldenburg","Germany","Geneva","Hannover","",['Grace']])
data_list.append([datetime.datetime(2019,5,31),104,"Corvey Monastery","Hoexter","Germany","Hannover","Hannover","Corvey Monastery",['Grace']])
data_list.append([datetime.datetime(2019,5,31),13,"Fagus Factory","Alfeld","Germany","Hannover","Hannover","Fagus Factory",['Grace']])
data_list.append([datetime.datetime(2019,5,31),36,"Dom","Hildesheim","Germany","Hannover","Hannover","Dom & Michaeliskirche Hildesheim",['Grace']])
data_list.append([datetime.datetime(2019,5,31),46,"Dommuseum","Hildesheim","Germany","Hannover","Hannover","Dom & Michaeliskirche Hildesheim",['Grace']])
data_list.append([datetime.datetime(2019,5,31),42,"Michaeliskirche","Hildesheim","Germany","Hannover","Hannover","Dom & Michaeliskirche Hildesheim",['Grace']])
data_list.append([datetime.datetime(2019,5,31),5,"Marktplatz","Hildesheim","Germany","Hannover","Hannover","",['Grace']])
data_list.append([datetime.datetime(2019,5,31),3,"Schloss","Braunschweig","Germany","Hannover","Hannover","",['Grace']])
data_list.append([datetime.datetime(2019,5,31),5,"Dom","Braunschweig","Germany","Hannover","Hannover","",['Grace']])
data_list.append([datetime.datetime(2019,5,31),2,"Braunschweiger Loewe","Braunschweig","Germany","Hannover","Hannover","",['Grace']])
data_list.append([datetime.datetime(2019,5,31),8,"Altstadtmarkt","Braunschweig","Germany","Hannover","Hannover","",['Grace']])
data_list.append([datetime.datetime(2019,6,1),58,"Dom","Bremen","Germany","Hannover","Hannover","",['Grace']])
data_list.append([datetime.datetime(2019,6,1),4,"Frauenkirche","Bremen","Germany","Hannover","Hannover","",['Grace']])
data_list.append([datetime.datetime(2019,6,1),78,"Rathaus","Bremen","Germany","Hannover","Hannover","Rathaus & Roland Bremen",['Grace']])
data_list.append([datetime.datetime(2019,6,1),78,"Roland","Bremen","Germany","Hannover","Hannover","Rathaus & Roland Bremen",['Grace']])
data_list.append([datetime.datetime(2019,6,1),4,"Marktplatz","Bremen","Germany","Hannover","Hannover","",['Grace']])
data_list.append([datetime.datetime(2019,6,1),3,"Hauptbahnhof","Bremen","Germany","Hannover","Hannover","Rathaus & Roland Bremen",['Grace']])
data_list.append([datetime.datetime(2019,6,1),7,"Boettcherstrasse","Bremen","Germany","Hannover","Hannover","Rathaus & Roland Bremen",['Grace']])
data_list.append([datetime.datetime(2019,6,1),2,"Schweinehirt und seine Herde","Bremen","Germany","Hannover","Hannover","Rathaus & Roland Bremen",['Grace']])
data_list.append([datetime.datetime(2019,6,1),2,"Bremer Stadtmusikanten","Bremen","Germany","Hannover","Hannover","Rathaus & Roland Bremen",['Grace']])
data_list.append([datetime.datetime(2019,6,2),40,"Rammelsberg Mine","Goslar","Germany","Hannover","Hannover","Goslar & Rammelsberg",['Grace']])
data_list.append([datetime.datetime(2019,6,2),33,"Imperial Palace","Goslar","Germany","Hannover","Hannover","Goslar & Rammelsberg",['Grace']])
data_list.append([datetime.datetime(2019,6,2),14,"Marktkirche","Goslar","Germany","Hannover","Hannover","Goslar & Rammelsberg",['Grace']])
data_list.append([datetime.datetime(2019,6,2),4,"Marktplatz","Goslar","Germany","Hannover","Hannover","Goslar & Rammelsberg",['Grace']])
data_list.append([datetime.datetime(2019,6,2),5,"Domvorhalle","Goslar","Germany","Hannover","Hannover","Goslar & Rammelsberg",['Grace']])
data_list.append([datetime.datetime(2019,6,2),6,"Schloss Herrenhausen","Hannover","Germany","Geneva","Hannover","",['Grace']])
data_list.append([datetime.datetime(2019,6,2),66,"Galeriegebaeude Herrenhausen","Hannover","Germany","Geneva","Hannover","",['Grace']])
data_list.append([datetime.datetime(2019,6,2),48,"Herrenhaeuser Gaerten","Hannover","Germany","Geneva","Hannover","",['Grace']])
data_list.append([datetime.datetime(2019,6,2),21,"Grotte Herrenhaeuser Gaerten","Hannover","Germany","Geneva","Hannover","",['Grace']])
data_list.append([datetime.datetime(2019,6,2),27,"Berggarten","Hannover","Germany","Geneva","Hannover","",['Grace']])
data_list.append([datetime.datetime(2019,6,2),4,"Marktkirche","Hannover","Germany","Geneva","Hannover","",['Grace']])
data_list.append([datetime.datetime(2019,6,16),8,"Kapellbruecke","Lucerne","Switzerland","Geneva","Geneva","",['Riju','Chris Brainerd','Rachel']])
data_list.append([datetime.datetime(2019,6,16),16,"Jesuitenkirche","Lucerne","Switzerland","Geneva","Geneva","",['Riju','Chris Brainerd','Rachel']])
data_list.append([datetime.datetime(2019,6,16),14,"Spreuerbruecke","Lucerne","Switzerland","Geneva","Geneva","",['Riju','Chris Brainerd','Rachel']])
data_list.append([datetime.datetime(2019,6,16),4,"Weinmarkt","Lucerne","Switzerland","Geneva","Geneva","",['Riju','Chris Brainerd','Rachel']])
data_list.append([datetime.datetime(2019,6,16),7,"Museggmauer","Lucerne","Switzerland","Geneva","Geneva","",['Riju','Chris Brainerd','Rachel']])
data_list.append([datetime.datetime(2019,6,16),2,"Loewendenkmal","Lucerne","Switzerland","Geneva","Geneva","",['Riju','Chris Brainerd','Rachel']])
data_list.append([datetime.datetime(2019,6,16),9,"Rigi","Lucerne","Switzerland","Geneva","Geneva","",['Riju','Chris Brainerd','Rachel']])
data_list.append([datetime.datetime(2019,6,16),10,"Pilatus","Lucerne","Switzerland","Geneva","Geneva","",['Riju','Chris Brainerd','Rachel']])
data_list.append([datetime.datetime(2019,6,16),26,"Rigi View Point","Lucerne","Switzerland","Geneva","Geneva","",['Riju','Chris Brainerd','Rachel']])
#vallorbe/fete de la musique
data_list.append([datetime.datetime(2019,6,22),119,"Grottes de Vallorbe","Vallorbe","Switzerland","Geneva","Geneva","",['Christian','Anne-Kathrin']])
data_list.append([datetime.datetime(2019,6,22),1,"Jet d'Eau","Geneva","Switzerland","Geneva","Geneva","",[]])
data_list.append([datetime.datetime(2019,6,22),1,"Grand Theatre","Geneva","Switzerland","Geneva","Geneva","",[]])
data_list.append([datetime.datetime(2019,7,8),1,"CMS","Cessy","France","Geneva","Geneva","",['Andres','Jens']])
data_list.append([datetime.datetime(2019,7,28),73,"Aletschgletscher","Fieschertal","Switzerland","Geneva","Geneva","Swiss Alps Jungfrau-Aletsch",['Francesca','Jose','Chris Brainerd','Ulrike','Ivan']])
data_list.append([datetime.datetime(2019,7,28),2,"Ewigschneefeld","Fieschertal","Switzerland","Geneva","Geneva","Swiss Alps Jungfrau-Aletsch",['Francesca','Jose','Chris Brainerd','Ulrike','Ivan']])
data_list.append([datetime.datetime(2019,7,28),1,"Mittelaletschgletscher","Fieschertal","Switzerland","Geneva","Geneva","Swiss Alps Jungfrau-Aletsch",['Francesca','Jose','Chris Brainerd','Ulrike','Ivan']])
data_list.append([datetime.datetime(2019,8,25),9,"Bisgletscher",'Randa',"Switzerland",'Geneva','Geneva',"",['Chris Brainerd','Janina','Sam','Grace',"Christine",'Andres']])
data_list.append([datetime.datetime(2019,8,25),11,"Dent Blanche, Obergabel-, Zinalroth- & Weisshorn group",'Zermatt',"Switzerland",'Geneva','Geneva',"",['Chris Brainerd','Janina','Sam','Grace',"Christine",'Andres']])
data_list.append([datetime.datetime(2019,8,25),3,"Kleinmatterhorn with Kleinmatterhorn- & Theodulgletschern",'Zermatt',"Switzerland",'Geneva','Geneva',"",['Chris Brainerd','Janina','Sam','Grace',"Christine",'Andres']])
data_list.append([datetime.datetime(2019,8,25),12,"Findelgetscher",'Zermatt',"Switzerland",'Geneva','Geneva',"",['Chris Brainerd','Janina','Sam','Grace',"Christine",'Andres']])
data_list.append([datetime.datetime(2019,8,25),2,"Mischabel group",'Zermatt',"Switzerland",'Geneva','Geneva',"",['Chris Brainerd','Janina','Sam','Grace',"Christine",'Andres']])
data_list.append([datetime.datetime(2019,8,25),20,"Matterhorn including Zmuttgletscher",'Zermatt',"Switzerland",'Geneva','Geneva',"",['Chris Brainerd','Janina','Sam','Grace',"Christine",'Andres']])
data_list.append([datetime.datetime(2019,8,25),1,"Breithorn",'Zermatt',"Switzerland",'Geneva','Geneva',"",['Chris Brainerd','Janina','Sam','Grace',"Christine",'Andres']])
data_list.append([datetime.datetime(2019,8,25),7,"Stellisee",'Zermatt',"Switzerland",'Geneva','Geneva',"",['Chris Brainerd','Janina','Sam','Grace',"Christine",'Andres']])
data_list.append([datetime.datetime(2019,8,25),5,"Grindjisee",'Zermatt',"Switzerland",'Geneva','Geneva',"",['Chris Brainerd','Janina','Sam','Grace',"Christine",'Andres']])
data_list.append([datetime.datetime(2019,8,31),1,"Glacier de Bossons",'Chamonix',"France",'Geneva','Geneva',"",['Chris Brainerd','Sasha','Yaroslava','Andres']])
data_list.append([datetime.datetime(2019,8,31),1,"Mont Brevent",'Chamonix',"France",'Geneva','Geneva',"",['Chris Brainerd','Sasha','Yaroslava','Andres']])
data_list.append([datetime.datetime(2019,8,31),3,"Porta Praetoria",'Aosta',"Italy",'Geneva','Geneva',"",['Chris Brainerd','Sasha','Yaroslava','Andres']])
data_list.append([datetime.datetime(2019,8,31),19,"Cathedral",'Aosta',"Italy",'Geneva','Geneva',"",['Chris Brainerd','Sasha','Yaroslava','Andres']])
data_list.append([datetime.datetime(2019,8,31),2,"Teatro Romano",'Aosta',"Italy",'Geneva','Geneva',"",['Chris Brainerd','Sasha','Yaroslava','Andres']])
data_list.append([datetime.datetime(2019,8,31),29,"Lillaz Waterfall",'Lillaz',"Italy",'Geneva','Geneva',"",['Chris Brainerd','Sasha','Yaroslava','Andres']])
data_list.append([datetime.datetime(2019,8,31),14,"Cascate del Rutor",'La Thuile',"Italy",'Geneva','Geneva',"",['Chris Brainerd','Sasha','Yaroslava','Andres']])
data_list.append([datetime.datetime(2019,9,15),41,"Langgletscher",'Blatten',"Switzerland",'Geneva','Geneva',"Swiss Alps Jungfrau-Aletsch",['Janina']])
data_list.append([datetime.datetime(2019,9,15),2,"Loinbachgletscher",'Blatten',"Switzerland",'Geneva','Geneva',"Swiss Alps Jungfrau-Aletsch",['Janina']])
data_list.append([datetime.datetime(2019,9,15),20,"Grosshorn & Jegigletscher",'Blatten',"Switzerland",'Geneva','Geneva',"Swiss Alps Jungfrau-Aletsch",['Janina']])
data_list.append([datetime.datetime(2019,9,15),5,"Dischliggletscher",'Blatten',"Switzerland",'Geneva','Geneva',"Swiss Alps Jungfrau-Aletsch",['Janina']])
data_list.append([datetime.datetime(2019,9,15),5,"Grundsee",'Blatten',"Switzerland",'Geneva','Geneva',"Swiss Alps Jungfrau-Aletsch",['Janina']])

# %%
#paris II 2019
data_list.append([datetime.datetime(2019, 9, 20),3,"Place de la Nation",'Paris',"France",'Geneva','Paris',"",['Michael',"Nhi",'Vivan','Sam']])
data_list.append([datetime.datetime(2019, 9, 21),1,"Place de la Nation",'Paris',"France",'Geneva','Paris',"",['Michael',"Nhi",'Vivan','Sam']])
data_list.append([datetime.datetime(2019, 9, 21),87,"Palais Royal",'Paris',"France",'Paris','Paris',"",['Michael',"Nhi",'Vivan','Sam']])
data_list.append([datetime.datetime(2019, 9, 21),4,"Louvre",'Paris',"France",'Paris','Paris',"Paris, Banks of the Seine",['Michael',"Nhi",'Vivan','Sam']])
data_list.append([datetime.datetime(2019, 9, 21),1,"Opera Garnier",'Paris',"France",'Paris','Paris',"",['Michael',"Nhi",'Vivan','Sam']])
data_list.append([datetime.datetime(2019, 9, 21),52,"Banque de France",'Paris',"France",'Paris','Paris',"",['Michael',"Nhi",'Vivan','Sam']])
data_list.append([datetime.datetime(2019, 9, 21),60,"Hotel de Ville",'Paris',"France",'Paris','Paris',"Paris, Banks of the Seine",['Michael',"Nhi",'Vivan','Sam']])
data_list.append([datetime.datetime(2019, 9, 21),1,"Notre Dame",'Paris',"France",'Paris','Paris',"Paris, Banks of the Seine",['Michael',"Nhi",'Vivan','Sam']])
data_list.append([datetime.datetime(2019, 9, 21),1,"Place du Chatelet",'Paris',"France",'Paris','Paris',"Paris, Banks of the Seine",['Michael',"Nhi",'Vivan','Sam']])
data_list.append([datetime.datetime(2019, 9, 21),1,"Palais du Justice",'Paris',"France",'Paris','Paris',"Paris, Banks of the Seine",['Michael',"Nhi",'Vivan','Sam']])
data_list.append([datetime.datetime(2019, 9, 21),4,"Conciergerie",'Paris',"France",'Paris','Paris',"Paris, Banks of the Seine",['Michael',"Nhi",'Vivan','Sam']])
data_list.append([datetime.datetime(2019, 9, 21),31,"Sainte Chapelle",'Paris',"France",'Paris','Paris',"Paris, Banks of the Seine",['Michael',"Nhi",'Vivan','Sam']])
data_list.append([datetime.datetime(2019, 9, 21),3,"Hotel de Monnaie",'Paris',"France",'Paris','Paris',"Paris, Banks of the Seine",['Michael',"Nhi",'Vivan','Sam']])
data_list.append([datetime.datetime(2019, 9, 21),18,"Hotel d'Avaray",'Paris',"France",'Paris','Paris',"",['Michael',"Nhi",'Vivan','Sam']])
data_list.append([datetime.datetime(2019, 9, 21),35,"Hotel de Matignon'",'Paris',"France",'Paris','Paris',"",['Michael',"Nhi",'Vivan','Sam']])
data_list.append([datetime.datetime(2019, 9, 21),27,"Hotel de Soubise'",'Paris',"France",'Paris','Paris',"",['Michael',"Nhi",'Vivan','Sam']])
data_list.append([datetime.datetime(2019, 9, 21),2,"Hotel d'Invalides",'Paris',"France",'Paris','Paris',"",['Michael',"Nhi",'Vivan','Sam']])
data_list.append([datetime.datetime(2019, 9, 21),3,"Tour Eiffel",'Paris',"France",'Paris','Paris',"Paris, Banks of the Seine",['Michael',"Nhi",'Vivan','Sam']])
data_list.append([datetime.datetime(2019, 9, 21),8,"Tour Eiffel Observatory",'Paris',"France",'Paris','Paris',"Paris, Banks of the Seine",['Michael',"Nhi",'Vivan','Sam']])
data_list.append([datetime.datetime(2019, 9, 21),1,"Ecole Militaire",'Paris',"France",'Paris','Paris',"Paris, Banks of the Seine",['Michael',"Nhi",'Vivan','Sam']])
data_list.append([datetime.datetime(2019, 9, 21),1,"Grand Palais",'Paris',"France",'Paris','Paris',"Paris, Banks of the Seine",['Michael',"Nhi",'Vivan','Sam']])
data_list.append([datetime.datetime(2019, 9, 21),1,"Palais des Chaillot",'Paris',"France",'Paris','Paris',"Paris, Banks of the Seine",['Michael',"Nhi",'Vivan','Sam']])
data_list.append([datetime.datetime(2019, 9, 22),95,"Palais du Luxembourg",'Paris',"France",'Paris','Geneva',"",['Michael',"Nhi",'Vivan','Sam']])
data_list.append([datetime.datetime(2019, 9, 22),28,"Petit Luxembourg",'Paris',"France",'Paris','Geneva',"",['Michael',"Nhi",'Vivan','Sam']])
data_list.append([datetime.datetime(2019, 9, 22),6,"Jardin du Luxembourg",'Paris',"France",'Paris','Geneva',"",['Michael',"Nhi",'Vivan','Sam']])
data_list.append([datetime.datetime(2019, 9, 22),1,"Lions' Fountain",'Paris',"France",'Paris','Geneva',"",['Michael',"Nhi",'Vivan','Sam']])
data_list.append([datetime.datetime(2019, 9, 22),3,"St Sulpice",'Paris',"France",'Paris','Geneva',"",['Michael',"Nhi",'Vivan','Sam']])
data_list.append([datetime.datetime(2019, 9, 22),35,"Hotel de Lassay",'Paris',"France",'Paris','Geneva',"Paris, Banks of the Seine",['Michael',"Nhi",'Vivan','Sam']])
data_list.append([datetime.datetime(2019, 9, 22),36,"Palais Bourbon",'Paris',"France",'Paris','Geneva',"Paris, Banks of the Seine",['Michael',"Nhi",'Vivan','Sam']])
data_list.append([datetime.datetime(2019, 9, 22),10,"Hotel de Monnaie",'Paris',"France",'Paris','Geneva',"Paris, Banks of the Seine",[]])
data_list.append([datetime.datetime(2019, 9, 22),34,"Ecole Nationale Superieure des Beaux-Arts",'Paris',"France",'Paris','Geneva',"Paris, Banks of the Seine",[]])
data_list.append([datetime.datetime(2019, 9, 22),12,"Louvre",'Paris',"France",'Paris','Paris',"Geneva, Banks of the Seine",[]])
data_list.append([datetime.datetime(2019, 9, 22),7,"Jardin des Tuileries",'Paris',"France",'Paris','Geneva',"Paris, Banks of the Seine",[]])
data_list.append([datetime.datetime(2019, 9, 22),4,"Jardin des Tuileries",'Paris',"France",'Paris','Geneva',"Paris, Banks of the Seine",['Michael',"Nhi",'Vivan','Sam']])
data_list.append([datetime.datetime(2019, 9, 22),1,"Musee d'Orsay",'Paris',"France",'Paris','Paris',"Paris, Banks of the Seine",['Michael',"Nhi",'Vivan','Sam']])
data_list.append([datetime.datetime(2019, 9, 22),1,"Tour Eiffel",'Paris',"France",'Paris','Geneva',"Pari, Banks of the Seine",['Michael',"Nhi",'Vivan','Sam']])
data_list.append([datetime.datetime(2019, 9, 22),1,"Grand Palais",'Paris',"France",'Paris','Geneva',"Paris, Banks of the Seine",['Michael',"Nhi",'Vivan','Sam']])
data_list.append([datetime.datetime(2019, 9, 22),6,"Place de la Concorde",'Paris',"France",'Paris','Geneva',"Paris, Banks of the Seine",['Michael',"Nhi",'Vivan','Sam']])
data_list.append([datetime.datetime(2019, 9, 22),31,"Orangerie",'Paris',"France",'Paris','Paris',"Geneva, Banks of the Seine",['Michael',"Nhi",'Vivan','Sam']])

# %%
#gruyeres
data_list.append([datetime.datetime(2019,10,6),4,"Maison du Gruyere","Gruyeres","Switzerland","Geneva","Geneva","",['Will','Andrew','Xuan']])
data_list.append([datetime.datetime(2019,10,6),2,"Giger Bar","Gruyeres","Switzerland","Geneva","Geneva","",['Will','Andrew','Xuan']])
data_list.append([datetime.datetime(2019,10,6),1,"Maison Cailler","Broc","Switzerland","Geneva","Geneva","",['Will','Andrew','Xuan']])
data_list.append([datetime.datetime(2019,10,6),7,"Villa le Lac de Corbusier","Corseaux","Switzerland","Geneva","Geneva","The Architectural Work of Le Corbusier",['Will','Andrew','Xuan']])
data_list.append([datetime.datetime(2019,10,13),42,"Gorges du Fier","Lovagny","France","Geneva","Geneva","",['Andrew']])
data_list.append([datetime.datetime(2019,10,13),33,"Mer de Rochers","Lovagny","France","Geneva","Geneva","",['Andrew']])
data_list.append([datetime.datetime(2019,10,13),24,"Pertes de la Valserine","Bellegarde-sur-Valserine","France","Geneva","Geneva","",['Andrew']])
data_list.append([datetime.datetime(2019,10,20),15,"Villa Batholoni","Geneva","Switzerland","Geneva","Geneva","",[]])
data_list.append([datetime.datetime(2019,10,26),4,"Trorrent de Lona Waterfalls","Grimentz","Switzerland","Geneva","Geneva","",['Sasha','Juno','Tema','Elga']])
data_list.append([datetime.datetime(2019,10,26),11,"Lac de Moiry & Dam","Grimentz","Switzerland","Geneva","Geneva","",['Sasha','Juno','Tema','Elga']])
data_list.append([datetime.datetime(2019,10,26),46,"Glacier de Moiry","Grimentz","Switzerland","Geneva","Geneva","",['Sasha','Juno','Tema','Elga']])
data_list.append([datetime.datetime(2019,10,26),5,"Lac de Chateaupre","Grimentz","Switzerland","Geneva","Geneva","",['Sasha','Juno','Tema','Elga']])
data_list.append([datetime.datetime(2019,10,27),104,"Gorge de l'Areuse","Boudry","Switzerland","Geneva","Geneva","",['Sam','Grace','Christine','Dylan','Vivan','Will']])
data_list.append([datetime.datetime(2019,10,27),5,"Eiger, Moench, Jungfrau","Grindelwald","Switzerland","Geneva","Geneva","Swiss Alps Jungfrau-Aletsch",['Sam','Grace','Christine','Dylan','Vivan','Will']])
data_list.append([datetime.datetime(2019,11,17),1,"Liebfrauenkirche","Waldshut","Germany","Lauchringen","Lauchringen","",['Anne-Kathrin','Mathilda','Christian']])
data_list.append([datetime.datetime(2019,11,29),2,"Jet d'Eau","Geneva","Switzerland","Geneva","Geneva","",[]])
data_list.append([datetime.datetime(2019,12,29),46,"Voelkerschlachtdenkmal","Leipzig","Germany","Lauchringen","Dresden","",['Artur']])
data_list.append([datetime.datetime(2019,12,29),5,"Neues Rathaus","Leipzig","Germany","Lauchringen","Dresden","",['Artur']])
data_list.append([datetime.datetime(2019,12,29),2,"Universitaet","Leipzig","Germany","Lauchringen","Dresden","",['Artur']])
data_list.append([datetime.datetime(2019,12,29),1,"Mendebrunnen","Leipzig","Germany","Lauchringen","Dresden","",['Artur']])
data_list.append([datetime.datetime(2019,12,29),17,"Nikolaikirche","Leipzig","Germany","Lauchringen","Dresden","",['Artur']])
data_list.append([datetime.datetime(2019,12,29),5,"Altes Rathaus","Leipzig","Germany","Lauchringen","Dresden","",['Artur']])
data_list.append([datetime.datetime(2019,12,29),21,"Thomaskirche","Leipzig","Germany","Lauchringen","Dresden","",['Artur']])
data_list.append([datetime.datetime(2019,12,29),1,"Johann-Sebastian-Bach-Denkmal","Leipzig","Germany","Lauchringen","Dresden","",['Artur']])
data_list.append([datetime.datetime(2019,12,29),1,"Bundesverwaltungsgericht","Leipzig","Germany","Lauchringen","Dresden","",['Artur']])
data_list.append([datetime.datetime(2019,12,29),1,"Semperoper","Dresden","Germany","Lauchringen","Dresden","",['Artur']])
data_list.append([datetime.datetime(2019,12,29),1,"Kunsthochschule","Dresden","Germany","Lauchringen","Dresden","",['Artur']])
data_list.append([datetime.datetime(2019,12,29),3,"Hofkirche","Dresden","Germany","Lauchringen","Dresden","",['Artur']])
data_list.append([datetime.datetime(2019,12,29),5,"Residenzschloss","Dresden","Germany","Lauchringen","Dresden","",['Artur']])
data_list.append([datetime.datetime(2019,12,29),2,"Neumarkt","Dresden","Germany","Lauchringen","Dresden","",['Artur']])
data_list.append([datetime.datetime(2019,12,30),60,"Semperoper","Dresden","Germany","Dresden","Dresden","",['Artur']])
data_list.append([datetime.datetime(2019,12,30),6,"Hofkirche","Dresden","Germany","Dresden","Dresden","",['Artur']])
data_list.append([datetime.datetime(2019,12,30),5,"Oberlandesgericht","Dresden","Germany","Dresden","Dresden","",['Artur']])
data_list.append([datetime.datetime(2019,12,30),8,"Residenzschloss","Dresden","Germany","Dresden","Dresden","",['Artur']])
data_list.append([datetime.datetime(2019,12,30),33,"Frauenkirche","Dresden","Germany","Dresden","Dresden","",['Artur']])
data_list.append([datetime.datetime(2019,12,30),34,"Zwinger","Dresden","Germany","Dresden","Dresden","",['Artur']])
data_list.append([datetime.datetime(2019,12,30),4,"Kunsthochschule","Dresden","Germany","Dresden","Dresden","",['Artur']])
data_list.append([datetime.datetime(2019,12,30),3,"Altmarkt","Dresden","Germany","Dresden","Dresden","",['Artur']])
data_list.append([datetime.datetime(2019,12,30),2,"Neumarkt","Dresden","Germany","Dresden","Dresden","",['Artur']])
data_list.append([datetime.datetime(2019,12,30),4,"Goldener Reiter","Dresden","Germany","Dresden","Dresden","",['Artur']])
data_list.append([datetime.datetime(2019,12,30),41,"Bastei","Lohmen","Germany","Dresden","Dresden","",['Artur']])
data_list.append([datetime.datetime(2019,12,30),7,"Basteibruecke","Lohmen","Germany","Dresden","Dresden","",['Artur']])
data_list.append([datetime.datetime(2019,12,30),15,"Felsenburg Neurathen","Lohmen","Germany","Dresden","Dresden","",['Artur']])
data_list.append([datetime.datetime(2019,12,30),6,"Elbsandsteingebirge","Lohmen","Germany","Dresden","Dresden","",['Artur']])
data_list.append([datetime.datetime(2019,12,31),237,"Residenzschloss","Dresden","Germany","Dresden","Dresden","",['Artur']])
data_list.append([datetime.datetime(2019,12,31),17,"Hofkirche","Dresden","Germany","Dresden","Dresden","",['Artur']])
data_list.append([datetime.datetime(2019,12,31),2,"Oberlandesgericht","Dresden","Germany","Dresden","Dresden","",['Artur']])
data_list.append([datetime.datetime(2019,12,31),116,"Zwinger","Dresden","Germany","Dresden","Dresden","",['Artur']])
data_list.append([datetime.datetime(2019,12,31),1,"Hauptbahnhof","Dresden","Germany","Dresden","Dresden","",['Artur']])
data_list.append([datetime.datetime(2019,12,31),1,"Altmarkt","Dresden","Germany","Dresden","Dresden","",['Artur']])
data_list.append([datetime.datetime(2019,12,31),1,"Kunsthochschule","Dresden","Germany","Dresden","Dresden","",['Artur']])

# %%
#2020 complete
data_list.append([datetime.datetime(2020,1,1),22,"Fuerst-Pueckler-Park",'Bad Muskau',"Germany",'Dresden','Wroclaw',"Muskauer Park/Park Muzakowski",['Artur']])
data_list.append([datetime.datetime(2020,1,1),25,"Fuerst-Pueckler-Park","Leknica","Poland",'Dresden','Wroclaw',"Muskauer Park/Park Muzakowski",['Artur']])
data_list.append([datetime.datetime(2020,1,1),59,"Church of Peace","Swidnica","Poland",'Dresden','Wroclaw',"Churches of Peace in Jawor and Swidnicai",['Artur']])
data_list.append([datetime.datetime(2020,1,1),14,"Cathedral","Swidnica","Poland",'Dresden','Wroclaw',"",['Artur']])
data_list.append([datetime.datetime(2020,1,1),1,"Central Station","Wroclaw","Poland",'Dresden','Wroclaw',"",['Artur']])
data_list.append([datetime.datetime(2020,1,1),1,"Kosciuszki Square","Wroclaw","Poland",'Dresden','Wroclaw',"",['Artur']])
data_list.append([datetime.datetime(2020,1,1),2,"Oper","Wroclaw","Poland",'Dresden','Wroclaw',"",['Artur']])
data_list.append([datetime.datetime(2020,1,1),6,"Rathaus","Wroclaw","Poland",'Dresden','Wroclaw',"",['Artur']])
data_list.append([datetime.datetime(2020,1,2),2,"Central Station","Wroclaw","Poland",'Wroclaw','Wroclaw',"",['Artur']])
data_list.append([datetime.datetime(2020,1,2),97,"Wieliczka Royal Salt Mine","Wieliczka","Poland",'Wroclaw','Wroclaw',"Wieliczka and Bochnia Royal Salt Mines",['Artur']])
data_list.append([datetime.datetime(2020,1,2),2,"Central Station","Krakow","Poland",'Wroclaw','Wroclaw',"",['Artur']])
data_list.append([datetime.datetime(2020,1,2),3,"St Florian's Gate",'Krakow',"Poland",'Wroclaw','Wroclaw',"Historic Centre of Krakow",["Artur"]])
data_list.append([datetime.datetime(2020,1,2),1,"Barbakan",'Krakow',"Poland",'Wroclaw','Wroclaw',"Historic Centre of Krakow",["Artur"]])
data_list.append([datetime.datetime(2020,1,2),6,"Cloth Hall",'Krakow',"Poland",'Wroclaw','Wroclaw',"Historic Centre of Krakow",["Artur"]])
data_list.append([datetime.datetime(2020,1,2),55,"St Mary's Basilica",'Krakow',"Poland",'Wroclaw','Wroclaw',"Historic Centre of Krakow",["Artur"]])
data_list.append([datetime.datetime(2020,1,2),4,"St Barbara",'Krakow',"Poland",'Wroclaw','Wroclaw',"Historic Centre of Krakow",["Artur"]])
data_list.append([datetime.datetime(2020,1,2),3,"Town Hall Tower",'Krakow',"Poland",'Wroclaw','Wroclaw',"Historic Centre of Krakow",["Artur"]])
data_list.append([datetime.datetime(2020,1,2),4,"St Andrew's",'Krakow',"Poland",'Wroclaw','Wroclaw',"Historic Centre of Krakow",["Artur"]])
data_list.append([datetime.datetime(2020,1,2),15,"St Peter & Paul",'Krakow',"Poland",'Wroclaw','Wroclaw',"Historic Centre of Krakow",["Artur"]])
data_list.append([datetime.datetime(2020,1,2),12,"Wawel Castle",'Krakow',"Poland",'Wroclaw','Wroclaw',"Historic Centre of Krakow",["Artur"]])
data_list.append([datetime.datetime(2020,1,2),43,"Wawel Cathedral",'Krakow',"Poland",'Wroclaw','Wroclaw',"Historic Centre of Krakow",["Artur"]])
data_list.append([datetime.datetime(2020,1,2),15,"St Anna",'Krakow',"Poland",'Warsaw','Wroclaw',"Historic Centre of Krakow",["Artur"]])
data_list.append([datetime.datetime(2020,1,2),3,"Juliusz Slowacki Theatre",'Krakow',"Poland",'Wroclaw','Wroclaw',"Historic Centre of Krakow",["Artur"]])
data_list.append([datetime.datetime(2020,1,3),12,"Centennial Hall",'Wroclaw',"Poland",'Wroclaw','Wroclaw',"Centennial Hall in Wroclaw",["Artur"]])
data_list.append([datetime.datetime(2020,1,3),81,"Dom",'Wroclaw',"Poland",'Wroclaw','Wroclaw',"",["Artur"]])
data_list.append([datetime.datetime(2020,1,3),3,"Kreuzkirche",'Wroclaw',"Poland",'Wroclaw','Wroclaw',"",["Artur"]])
data_list.append([datetime.datetime(2020,1,3),5,"Sandkirche",'Wroclaw',"Poland",'Wroclaw','Wroclaw',"",["Artur"]])
data_list.append([datetime.datetime(2020,1,3),3,"St Cyril and Methodius",'Wroclaw',"Poland",'Wroclaw','Wroclaw',"",["Artur"]])
data_list.append([datetime.datetime(2020,1,3),19,"University Church",'Wroclaw',"Poland",'Wroclaw','Wroclaw',"",["Artur"]])
data_list.append([datetime.datetime(2020,1,3),68,"University",'Wroclaw',"Poland",'Wroclaw','Wroclaw',"",["Artur"]])
data_list.append([datetime.datetime(2020,1,3),4,"Matthaeuskirche",'Wroclaw',"Poland",'Wroclaw','Wroclaw',"",["Artur"]])
data_list.append([datetime.datetime(2020,1,3),6,"Magdalenenkirche",'Wroclaw',"Poland",'Wroclaw','Wroclaw',"",["Artur"]])
data_list.append([datetime.datetime(2020,1,3),2,"Rathaus","Wroclaw","Poland",'Wroclaw','Wroclaw',"",['Artur']])
data_list.append([datetime.datetime(2020,1,3),42,"Koenigsschloss","Wroclaw","Poland",'Wroclaw','Wroclaw',"",['Artur']])
data_list.append([datetime.datetime(2020,1,3),5,"Synagoge zum Weissen Storch","Wroclaw","Poland",'Wroclaw','Wroclaw',"",['Artur']])
data_list.append([datetime.datetime(2020,1,3),2,"Oper","Wroclaw","Poland",'Wroclaw','Wroclaw',"",['Artur']])
data_list.append([datetime.datetime(2020,1,3),1,"Central Station","Wroclaw","Poland",'Wroclaw','Wroclaw',"",['Artur']])
data_list.append([datetime.datetime(2020,1,4),88,"Schloss Fuerstenstein","Walbrzych","Poland",'Wroclaw','Bayreuth',"",['Artur']])
data_list.append([datetime.datetime(2020,1,5),2,"Burg Zwernitz","Wonsees","Germany",'Bayreuth','Lauchringen',"",['Artur']])
data_list.append([datetime.datetime(2020,1,5),60,"Felsengarten Sanspareil","Wonsees","Germany",'Bayreuth','Lauchringen',"",['Artur']])
data_list.append([datetime.datetime(2020,1,11),30,"Gorges de la Langouette",'Les Planches-en-Montagne',"France",'Geneva','Geneva',"",['Sasha','Juno']])
data_list.append([datetime.datetime(2020,1,11),55,"Pertes de l'Ain",'Bourg-de-Sirod',"France",'Geneva','Geneva',"",['Sasha','Juno']])
data_list.append([datetime.datetime(2020,1,11),120,"Royal Monastery of Brou",'Bourg-en-Bresse',"France",'Geneva','Geneva',"",['Sasha','Juno']])
#st Gallen & Reichenau 2020
data_list.append([datetime.datetime(2020,2,8),3,"Abbey",'St Gallen',"Switzerland",'Geneva','Geneva',"Abbey of St Gall",['Dylan','Sam','Grace','Vivan']])
data_list.append([datetime.datetime(2020,2,8),38,"Abbey Cathedral",'St Gallen',"Switzerland",'Geneva','Geneva',"Abbey of St Gall",['Dylan','Sam','Grace','Vivan']])
data_list.append([datetime.datetime(2020,2,8),1,"Gallusplatz",'St Gallen',"Switzerland",'Geneva','Geneva',"",['Dylan','Sam','Grace','Vivan']])
data_list.append([datetime.datetime(2020,2,8),25,"St Georg",'Reichenau',"Germany",'Geneva','Geneva',"Monastic Island of Reichenau",['Dylan','Sam','Grace','Vivan']])
data_list.append([datetime.datetime(2020,2,8),24,"Monastery",'Reichenau',"Germany",'Geneva','Geneva',"Monastic Island of Reichenau",['Dylan','Sam','Grace','Vivan']])
data_list.append([datetime.datetime(2020,2,8),19,"St Peter & Paul",'Reichenau',"Germany",'Geneva','Geneva',"Monastic Island of Reichenau",['Dylan','Sam','Grace','Vivan']])
data_list.append([datetime.datetime(2020,2,8),46,"Minster",'Konstanz',"Germany",'Geneva','Geneva',"",['Dylan','Sam','Grace','Vivan']])
#rome 2020 
#no church in main focus
data_list.append([datetime.datetime(2020,2,20),1,"Piazza Santa Maria Maggiore",'Rome',"Italy",'Geneva','Rome',"Rome",[]])
data_list.append([datetime.datetime(2020,2,20),10,"Santa Maria Maggiore",'Rome',"Vatican",'Geneva','Rome',"Rome",[]])
data_list.append([datetime.datetime(2020,2,20),3,"Sant'Alfonso De Liguori",'Rome',"Italy",'Geneva','Rome',"Rome",[]])
data_list.append([datetime.datetime(2020,2,20),16,"Santa Prassede",'Rome',"Italy",'Geneva','Rome',"Rome",[]])
data_list.append([datetime.datetime(2020,2,20),1,"Piazza dell'Esquilino",'Rome',"Vatican",'Geneva','Rome',"Rome",[]])
data_list.append([datetime.datetime(2020,2,20),4,"San Paolo entra le Mura",'Rome',"Italy",'Geneva','Rome',"Rome",[]])
#with all 4 fountains
data_list.append([datetime.datetime(2020,2,20),9,"San Carlo alle Quattro Fontane",'Rome',"Italy",'Geneva','Rome',"Rome",[]])
data_list.append([datetime.datetime(2020,2,20),1,"Moses Fountain",'Rome',"Italy",'Rome','Geneva',"Rome",[]])
data_list.append([datetime.datetime(2020,2,20),14,"Santa Maria della Vittoria",'Rome',"Italy",'Geneva','Rome',"Rome",[]])
data_list.append([datetime.datetime(2020,2,20),1,"Baths of Diocletian",'Rome',"Italy",'Rome','Geneva',"Rome",[]])
data_list.append([datetime.datetime(2020,2,20),8,"Santa Maria degli Angeli",'Rome',"Italy",'Geneva','Rome',"Rome",[]])
data_list.append([datetime.datetime(2020,2,20),68,"Palazzo Massimo alla Terme",'Rome',"Italy",'Geneva','Rome',"Rome",[]])
data_list.append([datetime.datetime(2020,2,20),8,"San Patrizio Fountain",'Orvieto',"Italy",'Geneva','Rome',"",[]])
data_list.append([datetime.datetime(2020,2,20),3,"Fortezza Albronoz",'Orvieto',"Italy",'Geneva','Rome',"",[]])
data_list.append([datetime.datetime(2020,2,20),2,"Santa Maria dei Servi",'Orvieto',"Italy",'Geneva','Rome',"",[]])
data_list.append([datetime.datetime(2020,2,20),1,"Sant'Angelo",'Orvieto',"Italy",'Geneva','Rome',"",[]])
data_list.append([datetime.datetime(2020,2,20),94,"Duomo",'Orvieto',"Italy",'Geneva','Rome',"",[]])
data_list.append([datetime.datetime(2020,2,20),3,"Palazzo Soliano",'Orvieto',"Italy",'Geneva','Rome',"",[]])
data_list.append([datetime.datetime(2020,2,20),16,"Cathedral Museum",'Orvieto',"Italy",'Geneva','Rome',"",[]])
data_list.append([datetime.datetime(2020,2,20),1,"San Bernardino",'Orvieto',"Italy",'Geneva','Rome',"",[]])
data_list.append([datetime.datetime(2020,2,20),2,"Collegiata dei Santi Andrea e Bartolomeo",'Orvieto',"Italy",'Geneva','Rome',"",[]])
data_list.append([datetime.datetime(2020,2,20),3,"San Giovenale",'Orvieto',"Italy",'Geneva','Rome',"",[]])
data_list.append([datetime.datetime(2020,2,20),8,"Orvieto Underground",'Orvieto',"Italy",'Geneva','Rome',"",[]])
data_list.append([datetime.datetime(2020,2,20),2,"Roma Termini",'Rome',"Italy",'Geneva','Rome',"Rome",[]])
data_list.append([datetime.datetime(2020,2,21),1,"Porta Santa Lucia",'Urbino',"Italy",'Rome','Rome',"Historic Centre of Urbino",[]])
data_list.append([datetime.datetime(2020,2,21),4,"Santo Spirito",'Urbino',"Italy",'Rome','Rome',"Historic Centre of Urbino",[]])
data_list.append([datetime.datetime(2020,2,21),25,"Oratorio di San Giuseppe",'Urbino',"Italy",'Rome','Rome',"Historic Centre of Urbino",[]])
data_list.append([datetime.datetime(2020,2,21),11,"Oratorio di San Giovanni Battista",'Urbino',"Italy",'Rome','Rome',"Historic Centre of Urbino",[]])
data_list.append([datetime.datetime(2020,2,21),4,"Duomo",'Urbino',"Italy",'Rome','Rome',"Historic Centre of Urbino",[]])
data_list.append([datetime.datetime(2020,2,21),79,"Palazzo Ducale",'Urbino',"Italy",'Rome','Rome',"Historic Centre of Urbino",[]])
data_list.append([datetime.datetime(2020,2,21),2,"Fortezza Albornoz",'Urbino',"Italy",'Rome','Rome',"Historic Centre of Urbino",[]])
data_list.append([datetime.datetime(2020,2,21),1,"Piazza della Repubblica",'Urbino',"Italy",'Rome','Rome',"Historic Centre of Urbino",[]])
data_list.append([datetime.datetime(2020,2,21),2,"San Domenico",'Urbino',"Italy",'Rome','Rome',"Historic Centre of Urbino",[]])
data_list.append([datetime.datetime(2020,2,21),2,"Oratorio della Santa Croce",'Urbino',"Italy",'Rome','Rome',"Historic Centre of Urbino",[]])
data_list.append([datetime.datetime(2020,2,21),2,"Santa Chiara",'Urbino',"Italy",'Rome','Rome',"Historic Centre of Urbino",[]])
data_list.append([datetime.datetime(2020,2,21),2,"Santa Caterina",'Urbino',"Italy",'Rome','Rome',"Historic Centre of Urbino",[]])
data_list.append([datetime.datetime(2020,2,21),2,"San Francesco",'Urbino',"Italy",'Rome','Rome',"Historic Centre of Urbino",[]])
data_list.append([datetime.datetime(2020,2,21),5,"Duomo",'Pesaro',"Italy",'Rome','Rome',"",[]])
data_list.append([datetime.datetime(2020,2,21),2,"Piazza del Popolo",'Pesaro',"Italy",'Rome','Rome',"",[]])
data_list.append([datetime.datetime(2020,2,22),6,"Lago Albano",'Castel Gandolfo',"Italy",'Rome','Rome',"",[]])
data_list.append([datetime.datetime(2020,2,22),6,"San Tommaso da Villanova",'Castel Gandolfo',"Italy",'Rome','Rome',"",[]])
data_list.append([datetime.datetime(2020,2,22),61,"Palazzo Pontifico",'Castel Gandolfo',"Vatican",'Rome','Rome',"",[]])
data_list.append([datetime.datetime(2020,2,22),78,"Villa Barberini",'Castel Gandolfo',"Vatican",'Rome','Rome',"",[]])
data_list.append([datetime.datetime(2020,2,22),2,"Sacro Cuore di Gesu",'Ciampino',"Italy",'Rome','Rome',"",[]])
data_list.append([datetime.datetime(2020,2,22),1,"Porta Cecere",'Anagni',"Italy",'Rome','Rome',"",[]])
data_list.append([datetime.datetime(2020,2,22),1,"Madonna di Loreto",'Anagni',"Italy",'Rome','Rome',"",[]])
data_list.append([datetime.datetime(2020,2,22),2,"Piazza Cavour",'Anagni',"Italy",'Rome','Rome',"",[]])
data_list.append([datetime.datetime(2020,2,22),92,"Duomo",'Anagni',"Italy",'Rome','Rome',"",[]])
data_list.append([datetime.datetime(2020,2,22),9,"Palazzo di Bonifacio VIII",'Anagni',"Italy",'Rome','Rome',"",[]])
data_list.append([datetime.datetime(2020,2,22),2,"San Giovanni De Duce",'Anagni',"Italy",'Rome','Rome',"",[]])
data_list.append([datetime.datetime(2020,2,23),2,"Roman Amphitheatre",'Terni',"Italy",'Rome','Rome',"",[]])
data_list.append([datetime.datetime(2020,2,23),4,"San Francesco",'Terni',"Italy",'Rome','Rome',"",[]])
data_list.append([datetime.datetime(2020,2,23),2,"Duomo",'Terni',"Italy",'Rome','Rome',"",[]])
data_list.append([datetime.datetime(2020,2,23),2,"Piazza della Repubblica",'Terni',"Italy",'Rome','Rome',"",[]])
data_list.append([datetime.datetime(2020,2,23),116,"Cascata della Marmore",'Marmore',"Italy",'Rome','Rome',"",[]])
data_list.append([datetime.datetime(2020,2,23),8,"Piazza del Popolo",'Rome',"Italy",'Rome','Rome',"Rome",[]])
data_list.append([datetime.datetime(2020,2,23),4,"Santa Maria dei Miracoli",'Rome',"Italy",'Rome','Rome',"Rome",[]])
data_list.append([datetime.datetime(2020,2,23),2,"Porta del Popolo",'Rome',"Italy",'Rome','Rome',"Rome",[]])
data_list.append([datetime.datetime(2020,2,23),1,"Santa Maria del Popolo",'Rome',"Italy",'Rome','Rome',"Rome",[]])
data_list.append([datetime.datetime(2020,2,23),2,"Pincio",'Rome',"Italy",'Rome','Rome',"Rome",[]])
data_list.append([datetime.datetime(2020,2,23),1,"Villa Borghese",'Rome',"Italy",'Rome','Rome',"",[]])
data_list.append([datetime.datetime(2020,2,23),1,"Fontana delle Conche",'Rome',"Italy",'Rome','Rome',"",[]])
data_list.append([datetime.datetime(2020,2,23),3,"Sant'Eugenio",'Rome',"Italy",'Rome','Rome',"",[]])
data_list.append([datetime.datetime(2020,2,23),78,"Villa Giulia",'Rome',"Italy",'Rome','Rome',"",[]])
#including spanish stairs
data_list.append([datetime.datetime(2020,2,23),3,"Piazza di Spagna",'Rome',"Italy",'Geneva','Rome',"Rome",[]])
#mit mariensaeule
data_list.append([datetime.datetime(2020,2,23),3,"Piazza Mignanelli",'Rome',"Italy",'Geneva','Rome',"Rome",[]])
data_list.append([datetime.datetime(2020,2,23),1,"Palazzo Barberini",'Rome',"Italy",'Rome','Rome',"Rome",[]])
data_list.append([datetime.datetime(2020,2,23),3,"San Carlo alle Quattro Fontane",'Rome',"Italy",'Rome','Rome',"Rome",[]])
data_list.append([datetime.datetime(2020,2,23),3,"Piazza Santa Maria Maggiore",'Rome',"Italy",'Rome','Rome',"Rome",[]])
data_list.append([datetime.datetime(2020,2,23),6,"Santa Maria Maggiore",'Rome',"Vatican",'Rome','Rome',"Rome",[]])
data_list.append([datetime.datetime(2020,2,24),17,"Palazzo Piccolomini",'Pienza',"Italy",'Rome','Rome',"Pienza",[]])
data_list.append([datetime.datetime(2020,2,24),17,"Duomo",'Pienza',"Italy",'Rome','Rome',"Pienza",[]])
data_list.append([datetime.datetime(2020,2,24),5,"Pieve di Corsignano",'Pienza',"Italy",'Rome','Rome',"Pienza",[]])
data_list.append([datetime.datetime(2020,2,24),8,"San Francesco",'Pienza',"Italy",'Rome','Rome',"Pienza",[]])
data_list.append([datetime.datetime(2020,2,25),2,"Porta Camollia",'Siena',"Italy",'Rome','Rome',"Siena",[]])
data_list.append([datetime.datetime(2020,2,25),3,"San Pietro Alla Magione",'Siena',"Italy",'Rome','Rome',"Siena",[]])
data_list.append([datetime.datetime(2020,2,25),4,"Santa Maria in Portico a Fontegiusta",'Siena',"Italy",'Rome','Rome',"Siena",[]])
data_list.append([datetime.datetime(2020,2,25),4,"Sant'Andrea",'Siena',"Italy",'Rome','Rome',"Siena",[]])
data_list.append([datetime.datetime(2020,2,25),1,"Piazza Salimbeni",'Siena',"Italy",'Rome','Rome',"Siena",[]])
data_list.append([datetime.datetime(2020,2,25),1,"Piazza Tolomei",'Siena',"Italy",'Rome','Rome',"Siena",[]])
data_list.append([datetime.datetime(2020,2,25),2,"Loggia della Mercanzia",'Siena',"Italy",'Rome','Rome',"Siena",[]])
data_list.append([datetime.datetime(2020,2,25),1,"Sant Cristoforo",'Siena',"Italy",'Rome','Rome',"Siena",[]])
data_list.append([datetime.datetime(2020,2,25),1,"Piazza del Campo",'Siena',"Italy",'Rome','Rome',"Siena",[]])
data_list.append([datetime.datetime(2020,2,25),34,"Palazzo Pubblico",'Siena',"Italy",'Rome','Rome',"Siena",[]])
data_list.append([datetime.datetime(2020,2,25),3,"Santa Maria della Scala",'Siena',"Italy",'Rome','Rome',"Siena",[]])
data_list.append([datetime.datetime(2020,2,25),164,"Duomo",'Siena',"Italy",'Rome','Rome',"Siena",[]])
data_list.append([datetime.datetime(2020,2,25),14,"Museo dell'Opera del Duomo",'Siena',"Italy",'Rome','Rome',"Siena",[]])
data_list.append([datetime.datetime(2020,2,25),5,"San Niccolo in Sasso",'Siena',"Italy",'Rome','Rome',"Siena",[]])
data_list.append([datetime.datetime(2020,2,25),4,"San Domenico",'Siena',"Italy",'Rome','Rome',"Siena",[]])
data_list.append([datetime.datetime(2020,2,25),2,"Oratorio della Camera",'Siena',"Italy",'Rome','Rome',"Siena",[]])
data_list.append([datetime.datetime(2020,2,25),6,"Oratorio della Cucina",'Siena',"Italy",'Rome','Rome',"Siena",[]])
data_list.append([datetime.datetime(2020,2,25),2,"Chiesa del Crocifisso",'Siena',"Italy",'Rome','Rome',"Siena",[]])
data_list.append([datetime.datetime(2020,2,25),24,"Baptistery",'Siena',"Italy",'Rome','Rome',"Siena",[]])
data_list.append([datetime.datetime(2020,2,25),15,"Duomo Crypt",'Siena',"Italy",'Rome','Rome',"Siena",[]])
data_list.append([datetime.datetime(2020,2,25),6,"Palazzo Comunale",'San Gimignano',"Italy",'Rome','Rome',"San Gimignano",[]])
data_list.append([datetime.datetime(2020,2,25),33,"Torre Grossa",'San Gimignano',"Italy",'Rome','Rome',"San Gimignano",[]])
data_list.append([datetime.datetime(2020,2,25),49,"Duomo",'San Gimignano',"Italy",'Rome','Rome',"San Gimignano",[]])
data_list.append([datetime.datetime(2020,2,25),9,"Museum of Sacred Art",'San Gimignano',"Italy",'Rome','Rome',"San Gimignano",[]])
data_list.append([datetime.datetime(2020,2,25),3,"Piazza della Cisterna",'San Gimignano',"Italy",'Rome','Rome',"San Gimignano",[]])
data_list.append([datetime.datetime(2020,2,25),5,"Town Walls",'San Gimignano',"Italy",'Rome','Rome',"San Gimignano",[]])
data_list.append([datetime.datetime(2020,2,25),6,"San Lorenzo in Ponte",'San Gimignano',"Italy",'Rome','Rome',"San Gimignano",[]])
data_list.append([datetime.datetime(2020,2,25),5,"Museum of Arts",'San Gimignano',"Italy",'Rome','Rome',"San Gimignano",[]])
data_list.append([datetime.datetime(2020, 2, 26),38,"San Lorenzo",'Florence',"Italy",'Rome','Rome',"Florence",[]])
data_list.append([datetime.datetime(2020, 2, 26),32,"Baptistery",'Florence',"Italy",'Rome','Rome',"Florence",[]])
data_list.append([datetime.datetime(2020, 2, 26),81,"Duomo",'Florence',"Italy",'Rome','Rome',"Florence",[]])
data_list.append([datetime.datetime(2020, 2, 26),95,"Palazzo Vecchio",'Florence',"Italy",'Rome','Rome',"Florence",[]])
data_list.append([datetime.datetime(2020, 2, 26),87,"Uffizi",'Florence',"Italy",'Rome','Rome',"Florence",[]])
data_list.append([datetime.datetime(2020, 2, 26),53,"Santa Croce",'Florence',"Italy",'Rome','Rome',"Florence",[]])
data_list.append([datetime.datetime(2020, 2, 26),5,"Ponte Vecchio",'Florence',"Italy",'Rome','Rome',"Florence",[]])
data_list.append([datetime.datetime(2020, 2, 26),70,"Boboli Gardens",'Florence',"Italy",'Rome','Rome',"Florence",[]])
data_list.append([datetime.datetime(2020, 2, 26),133,"Palazzo Pitti",'Florence',"Italy",'Rome','Rome',"Florence",[]])
data_list.append([datetime.datetime(2020, 2, 26),63,"Santa Maria Novella",'Florence',"Italy",'Rome','Rome',"Florence",[]])
data_list.append([datetime.datetime(2020, 2, 26),3,"Santa Maria Maggiore",'Florence',"Italy",'Rome','Rome',"Florence",[]])
data_list.append([datetime.datetime(2020, 2, 26),2,"Palazzo Bargello",'Florence',"Italy",'Rome','Rome',"Florence",[]])
data_list.append([datetime.datetime(2020, 2, 26),5,"Neptune Fountain",'Florence',"Italy",'Rome','Rome',"Florence",[]])
data_list.append([datetime.datetime(2020, 2, 26),1,"Loggia dei Lanzi",'Florence',"Italy",'Rome','Rome',"Florence",[]])
data_list.append([datetime.datetime(2020, 2, 26),1,"San Filippo Neri",'Florence',"Italy",'Rome','Rome',"Florence",[]])
data_list.append([datetime.datetime(2020, 2, 26),29,"Capelle Medicee",'Florence',"Italy",'Rome','Rome',"Florence",[]])
data_list.append([datetime.datetime(2020, 2, 26),15,"Biblioteca Medicea Laurenziana",'Florence',"Italy",'Rome','Rome',"Florence",[]])
data_list.append([datetime.datetime(2020, 2, 26),1,"San Miniato al Monte",'Florence',"Italy",'Rome','Rome',"Florence",[]])
data_list.append([datetime.datetime(2020, 2, 26),15,"Santissima Annunziata",'Florence',"Italy",'Rome','Rome',"Florence",[]])
data_list.append([datetime.datetime(2020, 2, 26),1,"Stazione Santa Maria Novella",'Florence',"Italy",'Rome','Rome',"Florence",[]])
data_list.append([datetime.datetime(2020, 2, 26),1,"San Michele Arcangelo Visdomini",'Florence',"Italy",'Rome','Rome',"Florence",[]])
data_list.append([datetime.datetime(2020, 2, 26),1,"Santa Felicita",'Florence',"Italy",'Rome','Rome',"Florence",[]])
data_list.append([datetime.datetime(2020, 2, 26),32,"Cathedral Museum",'Florence',"Italy",'Rome','Rome',"Florence",[]])
data_list.append([datetime.datetime(2020, 2, 27),2,"Porta Asinaria",'Rome',"Italy",'Rome','Rome',"Rome",['Bryan']])
data_list.append([datetime.datetime(2020, 2, 27),1,"Porta San Giovanni",'Rome',"Italy",'Rome','Rome',"Rome",['Bryan']])
#including treasury and cloister
data_list.append([datetime.datetime(2020, 2, 27),81,"Basilica di San Giovanni in Laterano",'Rome',"Vatican",'Rome','Rome',"Rome",['Bryan']])
data_list.append([datetime.datetime(2020, 2, 27),2,"Triclinium Leoninum",'Rome',"Vatican",'Rome','Rome',"Rome",['Bryan']])
data_list.append([datetime.datetime(2020, 2, 27),30,"Sancta Sanctorum",'Rome',"Vatican",'Rome','Rome',"Rome",['Bryan']])
data_list.append([datetime.datetime(2020, 2, 27),2,"Piazza di Laterano",'Rome',"Vatican",'Rome','Rome',"Rome",['Bryan']])
data_list.append([datetime.datetime(2020, 2, 27),12,"Battistero Lateranense",'Rome',"Vatican",'Rome','Rome',"Rome",['Bryan']])
data_list.append([datetime.datetime(2020, 2, 27),25,"Villa dei Quintili",'Rome',"Italy",'Rome','Rome',"",['Bryan']])
data_list.append([datetime.datetime(2020, 2, 27),17,"Via Appia Antica",'Rome',"Italy",'Rome','Rome',"",['Bryan']])
data_list.append([datetime.datetime(2020, 2, 27),12,"Cecilia Metella Mausoleum",'Rome',"Italy",'Rome','Rome',"",['Bryan']])
data_list.append([datetime.datetime(2020, 2, 27),3,"Villa of Maxentius",'Rome',"Italy",'Rome','Rome',"",['Bryan']])
data_list.append([datetime.datetime(2020, 2, 27),9,"San Sebastiano fuori le Mura",'Rome',"Italy",'Rome','Rome',"",['Bryan']])
data_list.append([datetime.datetime(2020, 2, 27),9,"Villa Torlonia Park",'Rome',"Italy",'Rome','Rome',"",['Bryan']])
data_list.append([datetime.datetime(2020, 2, 27),22,"Villa Torlonia Casino Nobile",'Rome',"Italy",'Rome','Rome',"",['Bryan']])
data_list.append([datetime.datetime(2020, 2, 27),28,"Villa Torlonia Casina delle Civette",'Rome',"Italy",'Rome','Rome',"",['Bryan']])
data_list.append([datetime.datetime(2020, 2, 27),12,"Santa Constanza",'Rome',"Italy",'Rome','Rome',"",['Bryan']])
data_list.append([datetime.datetime(2020, 2, 27),6,"Sant'Agnese fuori le Mura",'Rome',"Italy",'Rome','Rome',"",['Bryan']])
data_list.append([datetime.datetime(2020, 2, 27),1,"Baths of Diocletian",'Rome',"Italy",'Rome','Rome',"Rome",['Bryan']])
data_list.append([datetime.datetime(2020, 2, 27),2,"Santa Maria degli Angeli",'Rome',"Italy",'Rome','Rome',"Rome",['Bryan']])
data_list.append([datetime.datetime(2020, 2, 27),3,"St Peter's Basilica",'Rome',"Vatican",'Rome','Rome',"Vactican",['Bryan']])
data_list.append([datetime.datetime(2020, 2, 27),2,"Castel Sant'Angelo",'Rome',"Italy",'Rome','Rome',"",['Bryan']])
#includes Sistine's Chapel & Stanze di Raffaelo
data_list.append([datetime.datetime(2020, 2, 28),197,"Vatican Museums",'Rome',"Vatican",'Rome','Rome',"Vatican",['Bryan']])
data_list.append([datetime.datetime(2020, 2, 28),7,"Vatican Gardens",'Rome',"Vatican",'Rome','Rome',"Vatican",['Bryan']])
#includes the collonades
data_list.append([datetime.datetime(2020, 2, 28),157,"St Peter's Basilica",'Rome',"Vatican",'Rome','Rome',"Vactican",['Bryan']])
data_list.append([datetime.datetime(2020, 2, 28),4,"Apostolic Palace",'Rome',"Vatican",'Rome','Rome',"Vatican",['Bryan']])
data_list.append([datetime.datetime(2020, 2, 28),4,"Santa Maria in Traspontina",'Rome',"Italy",'Rome','Rome',"",['Bryan']])
data_list.append([datetime.datetime(2020, 2, 28),43,"Castel Sant'Angelo",'Rome',"Italy",'Rome','Rome',"",['Bryan']])
data_list.append([datetime.datetime(2020, 2, 28),5,"San Giovanni Battista dei Fiorentini",'Rome',"Italy",'Rome','Rome',"",['Bryan']])
data_list.append([datetime.datetime(2020, 2, 28),13,"Santa Maria della Pace",'Rome',"Italy",'Rome','Rome',"Rome",['Bryan']])
data_list.append([datetime.datetime(2020, 2, 28),5,"Piazza Navona",'Rome',"Italy",'Rome','Rome',"Rome",['Bryan']])
data_list.append([datetime.datetime(2020, 2, 28),16,"San Luigi dei Francesi.",'Rome',"Italy",'Rome','Rome',"Rome",['Bryan']])
data_list.append([datetime.datetime(2020, 2, 28),16,"Pantheon",'Rome',"Italy",'Rome','Rome',"Rome",['Bryan']])
data_list.append([datetime.datetime(2020, 2, 28),2,"Piazza della Rotonda",'Rome',"Italy",'Rome','Rome',"Rome",['Bryan']])
data_list.append([datetime.datetime(2020, 2, 28),3,"Maria Sopra Minerva",'Rome',"Italy",'Rome','Rome',"Rome",['Bryan']])
data_list.append([datetime.datetime(2020, 2, 28),2,"Piazza della Minerva",'Rome',"Italy",'Rome','Rome',"Rome",['Bryan']])
data_list.append([datetime.datetime(2020, 2, 28),4,"Santa Marta al Collegio Romano",'Rome',"Italy",'Rome','Rome',"Rome",['Bryan']])
data_list.append([datetime.datetime(2020, 2, 28),19,"Sant'Ignazio'",'Rome',"Italy",'Rome','Rome',"Rome",['Bryan']])
data_list.append([datetime.datetime(2020, 2, 28),1,"Piazza di Sant'Ignazio'",'Rome',"Italy",'Rome','Rome',"Rome",['Bryan']])
data_list.append([datetime.datetime(2020, 2, 28),1,"Hadrian's Temple",'Rome',"Italy",'Rome','Rome',"Rome",['Bryan']])
data_list.append([datetime.datetime(2020, 2, 28),1,"Santa Maria della Concezione in Campo Marzio",'Rome',"Italy",'Rome','Rome',"Rome",['Bryan']])
data_list.append([datetime.datetime(2020, 2, 28),5,"Column of Marcus Aurelius",'Rome',"Italy",'Rome','Rome',"Rome",['Bryan']])
data_list.append([datetime.datetime(2020, 2, 28),1,"Palazzo Montecitorio",'Rome',"Italy",'Rome','Rome',"Rome",['Bryan']])
data_list.append([datetime.datetime(2020, 2, 28),1,"Palazzo Chigi",'Rome',"Italy",'Rome','Rome',"Rome",['Bryan']])
data_list.append([datetime.datetime(2020, 2, 28),7,"Santi Ambrogio e Carlo al Corso",'Rome',"Italy",'Rome','Rome',"Rome",['Bryan']])
data_list.append([datetime.datetime(2020, 2, 28),1,"Piazza del Popolo",'Rome',"Italy",'Rome','Rome',"Rome",['Bryan']])
data_list.append([datetime.datetime(2020,2,28),1,"Santa Maria dei Miracoli",'Rome',"Italy",'Rome','Rome',"Rome",['Bryan']])
data_list.append([datetime.datetime(2020,2,28),65,"Villa Borghese Casino Nobile",'Rome',"Italy",'Rome','Rome',"",['Bryan']])
data_list.append([datetime.datetime(2020,2,28),1,"Porta Pinciana",'Rome',"Italy",'Rome','Rome',"Rome",['Bryan']])
data_list.append([datetime.datetime(2020,2,28),2,"Oratorio del Santissimo Sacramento al Tritone",'Rome',"Italy",'Rome','Rome',"Rome",['Bryan']])
data_list.append([datetime.datetime(2020,2,28),14,"Trevi Fountain",'Rome',"Italy",'Rome','Rome',"Rome",['Bryan']])
data_list.append([datetime.datetime(2020,2,28),1,"Santa Vincenzo e Anastasio a Fontana di Trevi",'Rome',"Italy",'Rome','Rome',"Rome",['Bryan']])
data_list.append([datetime.datetime(2020,2,28),2,"Santa Maria in Trivio",'Rome',"Italy",'Geneva','Rome',"Rome",['Bryan']])
data_list.append([datetime.datetime(2020,2,29),1,"Piazza Beniamino Gigli",'Rome',"Italy",'Geneva','Rome',"Rome",['Bryan']])
data_list.append([datetime.datetime(2020,2,29),54,"Forum Romanum",'Rome',"Italy",'Rome','Rome',"Rome",['Bryan']])
data_list.append([datetime.datetime(2020,2,29),8,"Palatine Gardens",'Rome',"Italy",'Rome','Rome',"Rome",['Bryan']])
data_list.append([datetime.datetime(2020,2,29),7,"Colosseum",'Rome',"Italy",'Rome','Rome',"Rome",['Bryan']])
#backside
data_list.append([datetime.datetime(2020,2,29),3,"Capitol",'Rome',"Italy",'Rome','Rome',"Rome",['Bryan']])
#domus transitoria in imperial palace
data_list.append([datetime.datetime(2020,2,29),71,"Imperial Palace on Palatine Hill",'Rome',"Italy",'Rome','Rome',"Rome",['Bryan']])
data_list.append([datetime.datetime(2020,2,29),35,"Imperial Palace on Palatine Hill Casa di Augusto",'Rome',"Italy",'Rome','Rome',"Rome",['Bryan']])
data_list.append([datetime.datetime(2020,2,29),33,"Imperial Palace on Palatine Hill Casa di Livia",'Rome',"Italy",'Rome','Rome',"Rome",['Bryan']])
data_list.append([datetime.datetime(2020,2,29),13,"Palatine Museum",'Rome',"Italy",'Rome','Rome',"Rome",['Bryan']])
data_list.append([datetime.datetime(2020,2,29),12,"Santa Francesca Romana",'Rome',"Italy",'Rome','Rome',"Rome",['HBryan']])
data_list.append([datetime.datetime(2020,2,29),1,"Santi Luca e Martino",'Rome',"Italy",'Rome','Rome',"Rome",[]])
data_list.append([datetime.datetime(2020,2,29),2,"Circus Maximus",'Rome',"Italy",'Rome','Rome',"Rome",['Bryan']])
data_list.append([datetime.datetime(2020,2,29),107,"Palazzo Quirinale",'Rome',"Italy",'Rome','Rome',"Rome",[]])
data_list.append([datetime.datetime(2020,2,29),1,"Santi Andrea e Gregorio al Celio",'Rome',"Italy",'Rome','Rome',"Rome",['Bryan']])
data_list.append([datetime.datetime(2020,2,29),1,"Temple of Venus and Roma",'Rome',"Italy",'Rome','Rome',"Rome",['Bryan']])
data_list.append([datetime.datetime(2020,2,29),3,"Santi Domenico e Sisto",'Rome',"Italy",'Rome','Rome',"Rome",[]])
data_list.append([datetime.datetime(2020,2,29),11,"Imperial Forums",'Rome',"Italy",'Rome','Rome',"Rome",[]])
data_list.append([datetime.datetime(2020,2,29),1,"Column of Trajan",'Rome',"Italy",'Rome','Rome',"Rome",[]])
data_list.append([datetime.datetime(2020,2,29),2,"Santa Maria al Foro Traiano",'Rome',"Italy",'Rome','Rome',"Rome",[]])
data_list.append([datetime.datetime(2020,2,29),2,"Colosseum",'Rome',"Italy",'Rome','Rome',"Rome",[]])
data_list.append([datetime.datetime(2020,2,29),8,"San Pietro in Vincoli",'Rome',"Italy",'Rome','Rome',"Rome",['Bryan']])
data_list.append([datetime.datetime(2020,2,29),2,"Santa Maria ai Monti",'Rome',"Italy",'Rome','Rome',"Rome",['Bryan']])
data_list.append([datetime.datetime(2020,2,29),5,"Military Cathedral Santa Caterina da Siena in Magnanapoli",'Rome',"Italy",'Rome','Rome',"Rome",['Bryan']])
data_list.append([datetime.datetime(2020,2,29),15,"Column of Trajan",'Rome',"Italy",'Rome','Rome',"Rome",['Bryan']])
data_list.append([datetime.datetime(2020,2,29),6,"Santa Maria di Loreto",'Rome',"Italy",'Rome','Rome',"Rome",['Bryan']])
data_list.append([datetime.datetime(2020,2,29),6,"Monumento Nazionale a Vittorio Emanuele II",'Rome',"Italy",'Rome','Rome',"Rome",['Bryan']])
data_list.append([datetime.datetime(2020,2,29),15,"Santi Apostoli",'Rome',"Italy",'Rome','Rome',"Rome",['Bryan']])
data_list.append([datetime.datetime(2020,2,29),5,"Santa Maria in Via Lata",'Rome',"Italy",'Rome','Rome',"Rome",['Bryan']])
data_list.append([datetime.datetime(2020,2,29),26,"Il Gesu",'Rome',"Italy",'Rome','Rome',"Rome",['Bryan']])
data_list.append([datetime.datetime(2020,2,29),2,"Santissimo Sudario all'Argentina",'Rome',"Italy",'Rome','Rome',"Rome",['Bryan']])
data_list.append([datetime.datetime(2020,2,29),1,"Santissime Stimmate di San Francesco",'Rome',"Italy",'Rome','Rome',"Rome",['Bryan']])
data_list.append([datetime.datetime(2020,2,29),17,"Sant'Andrea della Valle",'Rome',"Italy",'Rome','Rome',"Rome",['Bryan']])
data_list.append([datetime.datetime(2020,2,29),4,"Largo di Torre Argentina",'Rome',"Italy",'Rome','Rome',"Rome",['Bryan']])
data_list.append([datetime.datetime(2020,2,29),30,"Palazzo Venezia",'Rome',"Italy",'Rome','Rome',"Rome",['Bryan']])
data_list.append([datetime.datetime(2020,2,29),1,"Teatro Marcello",'Rome',"Italy",'Rome','Rome',"Rome",['Bryan']])
#facade capitoline museums, inside for museum
data_list.append([datetime.datetime(2020,2,29),12,"Piazza del Campidoglio",'Rome',"Italy",'Rome','Rome',"Rome",['Bryan']])
data_list.append([datetime.datetime(2020,2,29),3,"Imperial Forums",'Rome',"Italy",'Rome','Rome',"Rome",['Bryan']])
data_list.append([datetime.datetime(2020,2,29),1,"Santi Domenico e Sisto",'Rome',"Italy",'Rome','Rome',"Rome",['Bryan']])
data_list.append([datetime.datetime(2020,2,29),1,"Santa Maria Maggiore",'Rome',"Italy",'Rome','Rome',"Rome",['Bryan']])
#tivoli and last day
data_list.append([datetime.datetime(2020,3,1),1,'Santa Maria Maggiore','Tivoli',"Italy",'Rome','Rome',"",['Bryan']])
data_list.append([datetime.datetime(2020,3,1),2,'Rocca Pia','Tivoli',"Italy",'Rome','Rome',"",['Bryan']])
data_list.append([datetime.datetime(2020,3,1),94,"Villa Adriana",'Tivoli',"Italy",'Rome','Rome',"Villa Adriana",['Bryan']])
data_list.append([datetime.datetime(2020,3,1),163,"Villa d'Este",'Tivoli',"Italy",'Rome','Rome',"Villa d'Este",['Bryan']])
data_list.append([datetime.datetime(2020,3,1),44,"Villa Gregoriana",'Tivoli',"Italy",'Rome','Rome',"",['Bryan']])
data_list.append([datetime.datetime(2020,3,1),2,"Vesta Temple",'Tivoli',"Italy",'Rome','Rome',"",['Bryan']])
data_list.append([datetime.datetime(2020,3,1),2,"Tiburnus Temple",'Tivoli',"Italy",'Rome','Rome',"",['Bryan']])
data_list.append([datetime.datetime(2020,3,1),2,"Piazza Navona",'Rome',"Italy",'Rome','Rome',"Rome",[]])
data_list.append([datetime.datetime(2020,3,1),1,"Pantheon",'Rome',"Italy",'Rome','Rome',"Rome",[]])
data_list.append([datetime.datetime(2020,3,1),1,"Santa Chiara",'Rome',"Italy",'Rome','Rome',"Rome",['Bryan']])
data_list.append([datetime.datetime(2020,3,1),3,"Palazzo Santa Chiara",'Rome',"Italy",'Rome','Rome',"Rome",['Bryan']])
data_list.append([datetime.datetime(2020,3,2),32,"San Paolo fuori le Mura",'Rome',"Vatican",'Rome','Rome',"Rome",['Bryan']])
data_list.append([datetime.datetime(2020,3,2),3,"Cestius Pyramide",'Rome',"Vatican",'Rome','Rome',"Rome",['Bryan']])
data_list.append([datetime.datetime(2020,3,2),2,"Porta San Paolo",'Rome',"Vatican",'Rome','Rome',"Rome",['Bryan']])
data_list.append([datetime.datetime(2020,3,2),2,"Aurelian Walls",'Rome',"Italy",'Rome','Rome',"Rome",['Bryan']])
data_list.append([datetime.datetime(2020,3,2),35,"Baths of Caracalla",'Rome',"Italy",'Rome','Rome',"Rome",['Bryan']])
data_list.append([datetime.datetime(2020,3,2),6,"Santi Andrea e Gregorio al Celio",'Rome',"Italy",'Rome','Rome',"Rome",['Bryan']])
data_list.append([datetime.datetime(2020,3,2),23,"Roman Houses on Celio",'Rome',"Italy",'Rome','Rome',"Rome",['Bryan']])
data_list.append([datetime.datetime(2020,3,2),5,"Santi Giovanni e Paolo",'Rome',"Italy",'Rome','Rome',"Rome",['Bryan']])
data_list.append([datetime.datetime(2020,3,2),2,"Circus Maximus",'Rome',"Italy",'Rome','Rome',"Rome",['Bryan']])
data_list.append([datetime.datetime(2020,3,2),2,"Imperial Palace on Palatine Hill",'Rome',"Italy",'Rome','Rome',"Rome",['Bryan']])
data_list.append([datetime.datetime(2020,3,2),14,"Santa Maria in Trastevere",'Rome',"Italy",'Rome','Rome',"Rome",['Bryan']])
data_list.append([datetime.datetime(2020,3,2),36,"Villa Farnesina",'Rome',"Italy",'Rome','Rome',"Rome",['Bryan']])
data_list.append([datetime.datetime(2020,3,2),1,"San Giuseppe alla Lungara",'Rome',"Italy",'Rome','Rome',"Rome",['Bryan']])
data_list.append([datetime.datetime(2020,3,2),1,"San Giovanni Battista dei Fiorentini",'Rome',"Italy",'Rome','Rome',"Rome",['Bryan']])
data_list.append([datetime.datetime(2020,3,2),1,"Porta Santo Spirito",'Rome',"Italy",'Rome','Rome',"Rome",['Bryan']])
data_list.append([datetime.datetime(2020,3,2),1,"Leonine Walls",'Rome',"Italy",'Rome','Rome',"Rome",['Bryan']])
data_list.append([datetime.datetime(2020,3,2),25,"St Peter's Basilica",'Rome',"Vatican",'Rome','Rome',"Vactican",['Bryan']])
data_list.append([datetime.datetime(2020,3,2),1,"Apostolic Palace",'Rome',"Vatican",'Rome','Rome',"Vatican",['Bryan']])
data_list.append([datetime.datetime(2020,3,2),6,"Santa Maria in Vallicella",'Rome',"Italy",'Rome','Rome',"Rome",['Bryan']])
data_list.append([datetime.datetime(2020,3,2),1,"Santa Pudenzia",'Rome',"Italy",'Rome','Rome',"Rome",['Bryan']])
data_list.append([datetime.datetime(2020,3,2),11,"Santa Maria Maggiore",'Rome',"Vatican",'Rome','Rome',"Vatican",['Bryan']])
data_list.append([datetime.datetime(2020,3,2),6,"Santa Prassede",'Rome',"Italy",'Rome','Rome',"Rome",['Bryan']])

# %%
data_list.append([datetime.datetime(2020,5,17),5,"Cascade du Ramacle","Chateau d'Oex","Switzerland",'Geneva','Geneva',"",['Juno']])
data_list.append([datetime.datetime(2020,5,17),11,"Gummfluh","Chateau d'Oex","Switzerland",'Geneva','Geneva',"",['Juno']])
data_list.append([datetime.datetime(2020,5,17),3,"Le Rubli","Rougemont","Switzerland",'Geneva','Geneva',"",['Juno']])
data_list.append([datetime.datetime(2020,5,24),6,"Park de la Grange","Geneva","Switzerland",'Geneva','Geneva',"",['Juno']])
data_list.append([datetime.datetime(2020,5,31),7,"Ebenalp","Wasserauen","Switzerland",'Geneva','Geneva',"",['Juno']])
data_list.append([datetime.datetime(2020,5,31),4,"Berggasthaus Aescher","Wasserauen","Switzerland",'Geneva','Geneva',"",['Juno']])
data_list.append([datetime.datetime(2020,5,31),11,"Hoher Kasten","Wasserauen","Switzerland",'Geneva','Geneva',"",['Juno']])
data_list.append([datetime.datetime(2020,5,31),35,"Alpstein","Wasserauen","Switzerland",'Geneva','Geneva',"",['Juno']])
data_list.append([datetime.datetime(2020,5,31),1,"Seealpsee","Wasserauen","Switzerland",'Geneva','Geneva',"",['Juno']])
data_list.append([datetime.datetime(2020,5,31),8,"Wildkirchlihoehle","Wasserauen","Switzerland",'Geneva','Geneva',"",['Juno']])
data_list.append([datetime.datetime(2020,5,31),2,"Wildkirchli","Wasserauen","Switzerland",'Geneva','Geneva',"",['Juno']])
data_list.append([datetime.datetime(2020,6,1),2,"Hoher Kasten","Wasserauen","Switzerland",'Wasserauen','Murg',"",['Juno']])
data_list.append([datetime.datetime(2020,6,1),43,"Alpstein","Wasserauen","Switzerland",'Wasserauen','Murg',"",['Juno']])
data_list.append([datetime.datetime(2020,6,1),14,"Saentis","Wasserauen","Switzerland",'Wasserauen','Murg',"",['Juno']])
data_list.append([datetime.datetime(2020,6,1),13,"Seealpsee","Wasserauen","Switzerland",'Wasserauen','Murg',"",['Juno']])
data_list.append([datetime.datetime(2020,6,1),2,"Murgbachwasserfall","Murg","Switzerland",'Wasserauen','Murg',"",['Juno']])
data_list.append([datetime.datetime(2020,6,1),17,"Walensee mit Churfirsten","Murg","Switzerland",'Wasserauen','Murg',"",['Juno']])
data_list.append([datetime.datetime(2020,6,2),23,"Walensee mit Churfirsten","Murg","Switzerland",'Murg','Geneva',"",['Juno']])
data_list.append([datetime.datetime(2020,6,2),3,"Kapelle","Quinten","Switzerland",'Murg','Geneva',"",['Juno']])
data_list.append([datetime.datetime(2020,6,2),5,"Ringquelle","Betlis","Switzerland",'Murg','Geneva',"",['Juno']])
data_list.append([datetime.datetime(2020,6,2),3,"Kapelle","Betlis","Switzerland",'Murg','Geneva',"",['Juno']])
data_list.append([datetime.datetime(2020,6,2),1,"Burgruine Strahlegg","Betlis","Switzerland",'Murg','Geneva',"",['Juno']])
data_list.append([datetime.datetime(2020,6,20),64,"Minster",'Strasbourg',"France",'Lauchringen','Lauchringen',"",['Artur']])
data_list.append([datetime.datetime(2020,6,20),2,"Palais Rohan",'Strasbourg',"France",'Lauchringen','Lauchringen',"",['Artur']])
data_list.append([datetime.datetime(2020,6,20),2,"Palais du Rhin",'Strasbourg',"France",'Lauchringen','Lauchringen',"",['Artur']])
data_list.append([datetime.datetime(2020,6,20),2,"Place de la Republique",'Strasbourg',"France",'Lauchringen','Lauchringen',"",['Artur']])
data_list.append([datetime.datetime(2020,6,20),4,"Canal du Faux-Rempart",'Strasbourg',"France",'Lauchringen','Lauchringen',"",['Artur']])
data_list.append([datetime.datetime(2020,6,20),2,"Ponts Couverts",'Strasbourg',"France",'Lauchringen','Lauchringen',"",['Artur']])
data_list.append([datetime.datetime(2020,6,20),4,"Petite France",'Strasbourg',"France",'Lauchringen','Lauchringen',"",['Artur']])
data_list.append([datetime.datetime(2020,6,20),3,"Kammerzellhaus",'Strasbourg',"France",'Lauchringen','Lauchringen',"",['Artur']])
data_list.append([datetime.datetime(2020,6,20),5,"Trinkhalle",'Baden-Baden',"Germany",'Lauchringen','Lauchringen',"The Great Spas of Europe",['Anne-Kathrin',"Mathilda",'Christian','Artur']])
data_list.append([datetime.datetime(2020,6,20),2,"Kurhaus",'Baden-Baden',"Germany",'Lauchringen','Lauchringen',"The Great Spas of Europe",['Anne-Kathrin',"Mathilda",'Christian','Artur']])
data_list.append([datetime.datetime(2020,6,21),1,"Kirche",'Untermettingen',"Germany",'Lauchringen','Lauchringen',"",[]])
data_list.append([datetime.datetime(2020,7,4),74,"Grottes du Cerdon",'Labalme',"France",'Geneva','Geneva',"",["Tema",'Sasha']])
data_list.append([datetime.datetime(2020,7,4),113,"Grottes de La Balme",'La Balme-les-Grottes',"France",'Geneva','Geneva',"",["Tema",'Sasha']])
data_list.append([datetime.datetime(2020,7,4),15,"Gorges de Thurignin",'Belmont-Luthezieu',"France",'Geneva','Geneva',"",['Sasha']])
data_list.append([datetime.datetime(2020,7,4),13,"Vieu",'Source de Groin',"France",'Geneva','Geneva',"",['Sasha']])
data_list.append([datetime.datetime(2020,7,4),10,"Pain de Sucre",'Champagne-en-Valromey',"France",'Geneva','Geneva',"",['Sasha']])
data_list.append([datetime.datetime(2020,7,4),4,"Pits des Tines",'Champagne-en-Valromey',"France",'Geneva','Geneva',"",['Sasha']])
data_list.append([datetime.datetime(2020,7,4),6,"Pain de Sucre",'Surjoux',"France",'Geneva','Geneva',"",['Sasha']])
data_list.append([datetime.datetime(2020,7,5),13,"Roman Road Trail St Cergue-Nyon",'St Cergue',"Switzerland",'Geneva','Geneva',"",['Janina','Kevin','Sam','Grace','Dylan']])
data_list.append([datetime.datetime(2020,7,5),5,"Mont Blanc",'Chamonix',"France",'Geneva','Geneva',"",['Janina','Kevin','Sam','Grace','Dylan']])
data_list.append([datetime.datetime(2020,7,12),21,"Musee d'Art et Histoire",'Geneva',"Switzerland",'Geneva','Geneva',"",['Vivan']])
data_list.append([datetime.datetime(2020,7,18),1,"Mont Blanc",'Chamonix',"France",'Geneva','Geneva',"",['Janina','Kevin','Sam','Grace','Dylan']])
data_list.append([datetime.datetime(2020,7,18),21,"Glacier du Nant Blanc",'Chamonix',"France",'Geneva','Geneva',"",['Juno','Andriy','Sasha','Tema']])
data_list.append([datetime.datetime(2020,7,18),3,"Aigilles Rouge",'Chamonix',"France",'Geneva','Geneva',"",['Juno','Andriy','Sasha','Tema']])
data_list.append([datetime.datetime(2020,7,18),1,"Aigille and Glacier du Plan",'Chamonix',"France",'Geneva','Geneva',"",['Juno','Andriy','Sasha','Tema']])
data_list.append([datetime.datetime(2020,7,18),21,"Mont Blanc",'Chamonix',"France",'Geneva','Geneva',"",['Juno','Andriy','Sasha','Tema']])
data_list.append([datetime.datetime(2020,7,18),21,"Mont Brevent",'Chamonix',"France",'Geneva','Geneva',"",['Juno','Andriy','Sasha','Tema']])
data_list.append([datetime.datetime(2020,7,18),77,"Mer de Glace",'Chamonix',"France",'Geneva','Geneva',"",['Juno','Andriy','Sasha','Tema']])
data_list.append([datetime.datetime(2020,7,18),5,"Glacier des Periades",'Chamonix',"France",'Geneva','Geneva',"",['Juno','Andriy','Sasha','Tema']])
data_list.append([datetime.datetime(2020,7,18),4,"Dent du Geant",'Chamonix',"France",'Geneva','Geneva',"",['Juno','Andriy','Sasha','Tema']])
data_list.append([datetime.datetime(2020,7,18),10,"Glacier des Bossons",'Chamonix',"France",'Geneva','Geneva',"",['Juno','Andriy','Sasha','Tema']])
data_list.append([datetime.datetime(2020,7,18),5,"Les Drus",'Chamonix',"France",'Geneva','Geneva',"",['Juno','Andriy','Sasha','Tema']])
data_list.append([datetime.datetime(2020,7,18),3,"Glacier du Nant Blanc",'Chamonix',"France",'Geneva','Geneva',"",['Juno','Andriy','Sasha','Tema']])
data_list.append([datetime.datetime(2020,7,18),2,"Grandes Jorasses",'Chamonix',"France",'Geneva','Geneva',"",['Juno','Andriy','Sasha','Tema']])
data_list.append([datetime.datetime(2020,7,18),3,"Grand Charmoz",'Chamonix',"France",'Geneva','Geneva',"",['Juno','Andriy','Sasha','Tema']])
data_list.append([datetime.datetime(2020,7,18),2,"Glacier des Leschaux",'Chamonix',"France",'Geneva','Geneva',"",['Juno','Andriy','Sasha','Tema']])
data_list.append([datetime.datetime(2020,8,1),2,"Mischabel group",'Saas Fee',"Switzerland",'Geneva','Geneva',"",['Sam']])
data_list.append([datetime.datetime(2020,8,1),1,"Weishorn",'Zermatt',"Switzerland",'Geneva','Geneva',"",['Sam']])
data_list.append([datetime.datetime(2020,8,1),3,"Unterbaechhorn",'Belalp',"Switzerland",'Geneva','Geneva',"",['Sam']])
data_list.append([datetime.datetime(2020,8,1),14,"Oberaletschgletscher","Riederalp","Switzerland","Geneva","Geneva","Swiss Alps Jungfrau-Aletsch",['Sam']])
data_list.append([datetime.datetime(2020,8,1),14,"Aletschgletscher","Fieschertal","Switzerland","Geneva","Geneva","Swiss Alps Jungfrau-Aletsch",['Sam']])
data_list.append([datetime.datetime(2020,8,1),2,"Oberaletschschlucht","Riederalp","Switzerland","Geneva","Geneva","Swiss Alps Jungfrau-Aletsch",['Sam']])
data_list.append([datetime.datetime(2020,8,1),3,"Aletschhorn","Fieschertal","Switzerland","Geneva","Geneva","Swiss Alps Jungfrau-Aletsch",['Sam']])
data_list.append([datetime.datetime(2020,8,1),15,"Sacro Monte di Domodossola","Domodossola","Italy","Geneva","Geneva","Sacro Monte di Piemonte",['Sam']])
data_list.append([datetime.datetime(2020,8,9),5,"Lauterbrunner Tal","Lauterbrunnen","Switzerland","Geneva","Geneva","",['Tema']])
data_list.append([datetime.datetime(2020,8,9),5,"Eiger, Moench, Jungfrau","Grindelwald","Switzerland","Geneva","Fieschertal","Swiss Alps Jungfrau-Aletsch",['Tema']])
data_list.append([datetime.datetime(2020,8,9),3,"Eigergletscher","Grindelwald","Switzerland","Geneva","Fieschertal","Swiss Alps Jungfrau-Aletsch",['Tema']])
data_list.append([datetime.datetime(2020,8,9),6,"Guggigletscher","Grindelwald","Switzerland","Geneva","Fieschertal","Swiss Alps Jungfrau-Aletsch",['Tema']])
data_list.append([datetime.datetime(2020,8,9),3,"Jungfrau","Grindelwald","Switzerland","Geneva","Fieschertal","Swiss Alps Jungfrau-Aletsch",['Tema']])
data_list.append([datetime.datetime(2020,8,9),1,"Silberhorn und Silberhorngletscher","Grindelwald","Switzerland","Geneva","Fieschertal","Swiss Alps Jungfrau-Aletsch",['Tema']])
data_list.append([datetime.datetime(2020,8,9),2,"Moench","Grindelwald","Switzerland","Geneva","Fieschertal","Swiss Alps Jungfrau-Aletsch",['Tema']])
data_list.append([datetime.datetime(2020,8,9),10,"Grindelwald-Fieschergletscher","Grindelwald","Switzerland","Geneva","Fieschertal","Swiss Alps Jungfrau-Aletsch",['Tema']])
data_list.append([datetime.datetime(2020,8,9),14,"Jungfraufirn","Fieschertal","Switzerland","Geneva","Fieschertal","Swiss Alps Jungfrau-Aletsch",['Tema']])
data_list.append([datetime.datetime(2020,8,9),3,"Aletschgletscher","Fieschertal","Switzerland","Geneva","Fieschertal","Swiss Alps Jungfrau-Aletsch",['Tema']])
data_list.append([datetime.datetime(2020,8,9),3,"Aletschhorn","Fieschertal","Switzerland","Geneva","Fieschertal","Swiss Alps Jungfrau-Aletsch",['Tema','Sasha','Juno']])
data_list.append([datetime.datetime(2020,8,9),12,"Aletschfirn","Fieschertal","Switzerland","Geneva","Fieschertal","Swiss Alps Jungfrau-Aletsch",['Tema','Sasha','Juno']])
data_list.append([datetime.datetime(2020,8,9),65,"Jungfraufirn","Fieschertal","Switzerland","Geneva","Fieschertal","Swiss Alps Jungfrau-Aletsch",['Tema','Sasha','Juno']])
data_list.append([datetime.datetime(2020,8,9),16,"Aletschgletscher","Fieschertal","Switzerland","Geneva","Fieschertal","Swiss Alps Jungfrau-Aletsch",['Tema','Sasha','Juno']])
data_list.append([datetime.datetime(2020,8,9),1,"Sphinx","Fieschertal","Switzerland","Geneva","Fieschertal","Swiss Alps Jungfrau-Aletsch",['Tema','Sasha','Juno']])
data_list.append([datetime.datetime(2019,8,9),65,"Ewigschneefeld","Fieschertal","Switzerland","Geneva","Fieschertal","Swiss Alps Jungfrau-Aletsch",['Tema','Sasha','Juno']])
data_list.append([datetime.datetime(2020,8,9),3,"Jungfrau","Grindelwald","Switzerland","Geneva","Fieschertal","Swiss Alps Jungfrau-Aletsch",['Tema']])
data_list.append([datetime.datetime(2020,8,9),4,"Grueneggfirn","Grindelwald","Switzerland","Geneva","Fieschertal","Swiss Alps Jungfrau-Aletsch",['Tema']])
data_list.append([datetime.datetime(2020,8,10),38,"Aletschgletscher","Fieschertal","Switzerland","Fieschertal","Geneva","Swiss Alps Jungfrau-Aletsch",['Tema','Sasha','Juno']])
data_list.append([datetime.datetime(2020,8,10),5,"Grueneggfirn","Grindelwald","Switzerland","Fieschertal","Geneva","Swiss Alps Jungfrau-Aletsch",['Tema']])
data_list.append([datetime.datetime(2020,8,10),8,"Jungfraufirn","Fieschertal","Switzerland","Fieschertal","Geneva","Swiss Alps Jungfrau-Aletsch",['Tema','Sasha','Juno']])
data_list.append([datetime.datetime(2019,8,10),2,"Ewigschneefeld","Fieschertal","Switzerland","Fieschertal","Geneva","Swiss Alps Jungfrau-Aletsch",['Tema','Sasha','Juno']])
data_list.append([datetime.datetime(2020,8,10),9,"Aletschfirn","Fieschertal","Switzerland","Fieschertal","Geneva","Swiss Alps Jungfrau-Aletsch",['Tema','Sasha','Juno']])
data_list.append([datetime.datetime(2020,8,10),2,"Aletschhorn","Fieschertal","Switzerland","Fieschertal","Geneva","Swiss Alps Jungfrau-Aletsch",['Tema','Sasha','Juno']])
data_list.append([datetime.datetime(2020,8,10),2,"Jungfraufirn","Fieschertal","Switzerland","Fieschertal","Geneva","Swiss Alps Jungfrau-Aletsch",['Tema','Sasha','Juno']])
data_list.append([datetime.datetime(2020,8,10),1,"Fieschergletscher","Fieschertal","Switzerland","Fieschertal","Geneva","Swiss Alps Jungfrau-Aletsch",['Tema','Sasha','Juno']])
data_list.append([datetime.datetime(2020,8,19),3,"Jet d'Eau",'Geneva',"Switzerland",'Geneva','Geneva',"",[]])
data_list.append([datetime.datetime(2020,8,22),17,"Mont Forchat",'Lullin',"France",'Geneva','Geneva',"",['Sasha']])
data_list.append([datetime.datetime(2020,8,23),1,"Parc de Bastions and Reformation Monument",'Geneva',"Switzerland",'Geneva','Geneva',"",[]])
data_list.append([datetime.datetime(2020,8,29),3,"Church",'Brugg',"Switzerland",'Geneva','Geneva',"",['Artur']])
data_list.append([datetime.datetime(2020,9,5),11,"Kloster Rheinau",'Rheinau',"Switzerland",'Lauchringen','Lauchringen',"",['Artur']])
data_list.append([datetime.datetime(2020,9,5),3,"Kraftwerk Rheinau",'Rheinau',"Switzerland",'Lauchringen','Lauchringen',"",['Artur']])
data_list.append([datetime.datetime(2020,9,5),2,"Schloss Woerth",'Neuhausen am Rheinfall',"Switzerland",'Lauchringen','Lauchringen',"",['Artur']])
data_list.append([datetime.datetime(2020,9,5),10,"Schloss Laufen",'Laufen',"Switzerland",'Lauchringen','Lauchringen',"",['Artur']])
data_list.append([datetime.datetime(2020,9,5),75,"Rheinfall",'Neuhausen am Rheinfall',"Switzerland",'Lauchringen','Lauchringen',"",['Artur']])
data_list.append([datetime.datetime(2020,9,6),10,"Kuessaburg",'Bechtersbohl',"Germany",'Lauchringen','Lauchringen',"",['Artur','Felicitas','Julius','Jan-Marc','Franziska']])
data_list.append([datetime.datetime(2020,9,14),2,"Burgruine Stein","Baden","Switzerland","Lauchringen","Lauchringen","",[]])
data_list.append([datetime.datetime(2020,9,20),7,"St Hippolyt und Verena","Oehningen","Germany","Lauchringen","Lauchringen","",['Artur']])
data_list.append([datetime.datetime(2020,9,20),13,"Klingenbachschlucht","Oehningen","Germany","Lauchringen","Lauchringen","",['Artur']])
data_list.append([datetime.datetime(2020,9,20),1,"Chorherrenkapelle","Oehningen","Germany","Lauchringen","Lauchringen","",['Artur']])
data_list.append([datetime.datetime(2020,9,20),2,"Petruskirche","Kattenhorn","Germany","Lauchringen","Lauchringen","",['Artur']])
data_list.append([datetime.datetime(2020,10,3),23,"Steinaschlucht","Lauchringen","Germany","Lauchringen","Lauchringen","",['Artur']])
data_list.append([datetime.datetime(2020,10,4),98,"Schloss und Kloster Salem","Salem","Germany","Lauchringen","Lauchringen","",['Artur']])
data_list.append([datetime.datetime(2020,10,4),6,"Georgskirche","Bermatingen","Germany","Lauchringen","Lauchringen","",['Artur']])
data_list.append([datetime.datetime(2020,10,4),15,"Nikolausmuenster","Ueberlingen","Germany","Lauchringen","Lauchringen","",['Artur']])
data_list.append([datetime.datetime(2020,10,4),5,"Franziskanerkirche","Ueberlingen","Germany","Lauchringen","Lauchringen","",['Artur']])
data_list.append([datetime.datetime(2020,10,4),1,"Franziskanertor","Ueberlingen","Germany","Lauchringen","Lauchringen","",['Artur']])
data_list.append([datetime.datetime(2020,10,9),5,"Stadtkirche","Baden","Switzerland","Lauchringen","Lauchringen","",[]])
data_list.append([datetime.datetime(2020,10,9),3,"Burgruine Stein","Baden","Switzerland","Lauchringen","Lauchringen","",[]])
data_list.append([datetime.datetime(2020,10,10),21,"Steinaschlucht","Lauchringen","Germany","Lauchringen","Lauchringen","",[]])
data_list.append([datetime.datetime(2020,10,11),43,"Hoellgrotten","Baar","Switzerland","Lauchringen","Lauchringen","",['Namrata']])
data_list.append([datetime.datetime(2020,10,11),8,"Schwarzenbachfall","Baar","Switzerland","Lauchringen","Lauchringen","",['Namrata']])
data_list.append([datetime.datetime(2020,10,11),3,"Bugruine Wildenburg","Baar","Switzerland","Lauchringen","Lauchringen","",['Namrata']])
data_list.append([datetime.datetime(2020,10,25),22,"Vitibuckaussichtsturmm","Tiengen","Germany","Lauchringen","Lauchringen","",['Artur']])
data_list.append([datetime.datetime(2020,11,6),3,"Steinaschlucht","Lauchringen","Germany","Lauchringen","Lauchringen","",[]])
data_list.append([datetime.datetime(2020,11,8),2,"Seltenbachschlucht","Waldshut","Germany","Lauchringen","Lauchringen","",['Artur']])
data_list.append([datetime.datetime(2020,11,8),2,"Stadttore","Waldshut","Germany","Lauchringen","Lauchringen","",['Artur']])
data_list.append([datetime.datetime(2020,11,8),5,"Liebfrauenkirche","Waldshut","Germany","Lauchringen","Lauchringen","",['Artur']])
data_list.append([datetime.datetime(2020,11,8),2,"Rathaus","Waldshut","Germany","Lauchringen","Lauchringen","",['Artur']])
data_list.append([datetime.datetime(2020,11,8),2,"Spitalkapelle","Waldshut","Germany","Lauchringen","Lauchringen","",['Artur']])
data_list.append([datetime.datetime(2020,11,8),6,"Schloss",'Tiengen',"Germany",'Lauchringen','Lauchringen',"",['Artur']])
data_list.append([datetime.datetime(2020,11,8),13,"Maria Himmelfahrt",'Tiengen',"Germany",'Lauchringen','Lauchringen',"",['Artur']])
data_list.append([datetime.datetime(2020,11,8),2,"Storchenturm",'Tiengen',"Germany",'Lauchringen','Lauchringen',"",['Artur']])
data_list.append([datetime.datetime(2020,11,9),1,"Herz-Jesu-Kirche","Lauchringen","Germany","Lauchringen","Lauchringen","",[]])
data_list.append([datetime.datetime(2020,11,14),2,"Storchenturm","Tiengen","Germany","Lauchringen","Lauchringen","",[]])
data_list.append([datetime.datetime(2020,11,14),3,"Langenstein","Tiengen","Germany","Lauchringen","Lauchringen","",[]])
data_list.append([datetime.datetime(2020,11,15),15,"Steinaschlucht","Lauchringen","Germany","Lauchringen","Lauchringen","",[]])
data_list.append([datetime.datetime(2020,11,22),22,"Todtmooser Wasserfall","Todtmoos","Germany","Lauchringen","Lauchringen","",['Artur']])
data_list.append([datetime.datetime(2020,11,22),28,"Kloster","St Blasien","Germany","Lauchringen","Lauchringen","",['Artur']])

# %%
#2021 complete
data_list.append([datetime.datetime(2021, 1, 10),8,"Holzbruecke",'Bad Saeckingen',"Germany",'Lauchringen','Lauchringen',"",['Artur']])
data_list.append([datetime.datetime(2021, 1, 10),2,"Gallusturm",'Bad Saeckingen',"Germany",'Lauchringen','Lauchringen',"",['Artur']])
data_list.append([datetime.datetime(2021, 1, 10),3,"Rheinkraftwerk",'Bad Saeckingen',"Germany",'Lauchringen','Lauchringen',"",['Artur']])
data_list.append([datetime.datetime(2021, 1, 10),28,"Fridolinsmuenster",'Bad Saeckingen',"Germany",'Lauchringen','Lauchringen',"",['Artur']])
data_list.append([datetime.datetime(2021, 1, 10),2,"Trompeterschloss",'Bad Saeckingen',"Germany",'Lauchringen','Lauchringen',"",['Artur']])
data_list.append([datetime.datetime(2021, 1, 10),2,"Heilig-Geist-Kirche",'Laufenburg',"Germany",'Lauchringen','Lauchringen',"",['Artur']])
data_list.append([datetime.datetime(2021, 1, 22),11,"Lauffen-Wasserfall",'Lauchringen',"Germany",'Lauchringen','Lauchringen',"",[]])
data_list.append([datetime.datetime(2021, 1, 26),5,"Steinaschlucht",'Lauchringen',"Germany",'Lauchringen','Lauchringen',"",[]])
data_list.append([datetime.datetime(2021, 1, 29),9,"Lauffen-Wasserfall",'Lauchringen',"Germany",'Lauchringen','Lauchringen',"",[]])
data_list.append([datetime.datetime(2021, 2, 4),7,"Aachtopf",'Aach',"Germany",'Lauchringen','Lauchringen',"",['Artur']])
data_list.append([datetime.datetime(2021,2,4),9,"St Georg",'Reichenau',"Germany",'Lauchringen','Lauchringen',"Monastic Island of Reichenau",['Artur']])
data_list.append([datetime.datetime(2021,2,4),6,"Monastery",'Reichenau',"Germany",'Lauchringen','Lauchringen',"Monastic Island of Reichenau",['Artur']])
data_list.append([datetime.datetime(2021,2,4),6,"St Peter & Paul",'Reichenau',"Germany",'Lauchringen','Lauchringen',"Monastic Island of Reichenau",['Artur']])
data_list.append([datetime.datetime(2021,2,6),15,"Wallfahrtskirche Birnau",'Birnau',"Germany",'Lauchringen','Lauchringen',"",['Artur']])
data_list.append([datetime.datetime(2021,2,6),14,"Muenster",'Lindau',"Germany",'Lauchringen','Lauchringen',"",['Artur']])
data_list.append([datetime.datetime(2021,2,6),4,"Altes Rathaus",'Lindau',"Germany",'Lauchringen','Lauchringen',"",['Artur']])
data_list.append([datetime.datetime(2021,2,6),6,"Neuer Leuchtturm",'Lindau',"Germany",'Lauchringen','Lauchringen',"",['Artur']])
data_list.append([datetime.datetime(2021,2,6),2,"Mangturm",'Lindau',"Germany",'Lauchringen','Lauchringen',"",['Artur']])
data_list.append([datetime.datetime(2021,2,6),9,"Peterskirche",'Lindau',"Germany",'Lauchringen','Lauchringen',"",['Artur']])
data_list.append([datetime.datetime(2021,2,6),40,"Abtei",'Weingarten',"Germany",'Lauchringen','Lauchringen',"",['Artur']])
data_list.append([datetime.datetime(2021,2,6),4,"Schloss",'Friedrichshafen',"Germany",'Lauchringen','Lauchringen',"",['Artur']])
data_list.append([datetime.datetime(2021,2,6),2,"Burg Meersburg",'Meersburg',"Germany",'Lauchringen','Lauchringen',"",['Artur']])
data_list.append([datetime.datetime(2021,2,6),1,"Stadtkirche",'Meersburg',"Germany",'Lauchringen','Lauchringen',"",['Artur']])
data_list.append([datetime.datetime(2021,2,6),8,"Neues Schloss",'Meersburg',"Germany",'Lauchringen','Lauchringen',"",['Artur']])
data_list.append([datetime.datetime(2021,2,6),2,"Magische Saeule",'Meersburg',"Germany",'Lauchringen','Lauchringen',"",['Artur']])
data_list.append([datetime.datetime(2021,2,7),12,"Lauffen-Wasserfall",'Lauchringen',"Germany",'Lauchringen','Lauchringen',"",['Artur']])
data_list.append([datetime.datetime(2021,2,7),1,"Storchenturm",'Tiengen',"Germany",'Lauchringen','Lauchringen',"",['Artur']])
data_list.append([datetime.datetime(2021,2,7),1,"Schloss",'Tiengen',"Germany",'Lauchringen','Lauchringen',"",['Artur']])
data_list.append([datetime.datetime(2021,2,7),1,"Maria Himmelfahrt",'Tiengen',"Germany",'Lauchringen','Lauchringen',"",['Artur']])
data_list.append([datetime.datetime(2021,2,7),1,"Kriegerdenkmal",'Lauchringen',"Germany",'Lauchringen','Lauchringen',"",['Artur']])
data_list.append([datetime.datetime(2021,2,13),9,"Steinaschlucht",'Lauchringen',"Germany",'Lauchringen','Lauchringen',"",[]])
data_list.append([datetime.datetime(2021,2,14),5,"Haselbachfall",'Indlekofen',"Germany",'Lauchringen','Lauchringen',"",['Artur']])
data_list.append([datetime.datetime(2021,2,15),8,"Lauffen-Wasserfall",'Lauchringen',"Germany",'Lauchringen','Lauchringen',"",[]])
data_list.append([datetime.datetime(2021, 2, 19),15,"Schluechtsee",'Grafenhausen',"Germany",'Lauchringen','Lauchringen',"",['Artur']])
data_list.append([datetime.datetime(2021,2,21),19,"Erzabtei",'Beuron',"Germany",'Lauchringen','Lauchringen',"",['Artur']])
data_list.append([datetime.datetime(2021,2,21),58,"Donaudurchbruch",'Beuron',"Germany",'Lauchringen','Lauchringen',"",['Artur']])
data_list.append([datetime.datetime(2021,2,21),2,"Mauruskapelle",'Beuron',"Germany",'Lauchringen','Lauchringen',"",['Artur']])
data_list.append([datetime.datetime(2021,2,21),7,"Schloss",'Sigmaringen',"Germany",'Lauchringen','Lauchringen',"",['Artur']])
data_list.append([datetime.datetime(2021,2,21),5,"St Johann",'Sigmaringen',"Germany",'Lauchringen','Lauchringen',"",['Artur']])
data_list.append([datetime.datetime(2021,2,23),4,"Burg Steinegg",'Bonndorf',"Germany",'Lauchringen','Lauchringen',"",['Artur']])
data_list.append([datetime.datetime(2021,2,23),6,"Burg Roggenbach",'Bonndorf',"Germany",'Lauchringen','Lauchringen',"",['Artur']])
data_list.append([datetime.datetime(2021,2,26),24,"Menzenschwander Albschlucht",'Menzenschwand',"Germany",'Lauchringen','Lauchringen',"",['Artur']])
data_list.append([datetime.datetime(2021,2,26),5,"Menzenschwander Wasserfall",'Menzenschwand',"Germany",'Lauchringen','Lauchringen',"",['Artur']])
data_list.append([datetime.datetime(2021,2,26),43,"Todtnauer Wasserfall",'Todtnau',"Germany",'Lauchringen','Lauchringen',"",['Artur']])
data_list.append([datetime.datetime(2021,2,27),4,"Ravennaviadukt","Breitnau","Germany","Lauchringen","Lauchringen","",['Artur']])
data_list.append([datetime.datetime(2021,2,27),41,"Ravennaschlucht","Breitnau","Germany","Lauchringen","Lauchringen","",['Artur']])
data_list.append([datetime.datetime(2021,2,27),1,"Rathaus","Freiburg","Germany","Lauchringen","Lauchringen","",['Artur']])
data_list.append([datetime.datetime(2021,2,27),40,"Minster","Freiburg","Germany","Lauchringen","Lauchringen","",['Artur']])
data_list.append([datetime.datetime(2021,2,27),2,"Martinstor","Freiburg","Germany","Lauchringen","Lauchringen","",['Artur']])
data_list.append([datetime.datetime(2021,2,27),1,"Georg's Fountain","Freiburg","Germany","Lauchringen","Lauchringen","",['Artur']])
data_list.append([datetime.datetime(2021,2,27),2,"Schwabentor","Freiburg","Germany","Lauchringen","Lauchringen","",['Artur']])
data_list.append([datetime.datetime(2021,2,27),19,"Kloster","St Peter","Germany","Lauchringen","Lauchringen","",['Artur']])
data_list.append([datetime.datetime(2021,2,27),9,"Kloster","St Maergen","Germany","Lauchringen","Lauchringen","",['Artur']])
data_list.append([datetime.datetime(2021,2,27),6,"Titisee","Titisee","Germany","Lauchringen","Lauchringen","",['Artur']])
data_list.append([datetime.datetime(2021,2,27),5,"Windgfaellweiher","Lenzkirch","Germany","Lauchringen","Lauchringen","",['Artur']])
data_list.append([datetime.datetime(2021,2,27),2,"Schluchsee Staumauer","Schluchsee","Germany","Lauchringen","Lauchringen","",['Artur']])
data_list.append([datetime.datetime(2021,2,27),3,"Schluchsee","Schluchsee","Germany","Lauchringen","Lauchringen","",['Artur']])
data_list.append([datetime.datetime(2021,2,28),9,"Burgruine Wieladingen","Rickenbach","Germany","Lauchringen","Lauchringen","",['Artur']])
data_list.append([datetime.datetime(2021,2,28),5,"Strahlbrusch Wasserfall","Rickenbach","Germany","Lauchringen","Lauchringen","",['Artur']])
data_list.append([datetime.datetime(2021,3,2),5,"Aybach Wasserfall","Goerwihl","Germany","Lauchringen","Lauchringen","",['Artur']])
data_list.append([datetime.datetime(2021,3,2),4,"Kleiner Hoellbach Wasserfall","Goerwihl","Germany","Lauchringen","Lauchringen","",['Artur']])
data_list.append([datetime.datetime(2021,3,2),10,"Grosser Hoellbach Wasserfall","Goerwihl","Germany","Lauchringen","Lauchringen","",['Artur']])
data_list.append([datetime.datetime(2021,3,2),3,"Unterer Hoellbach Wasserfall","Goerwihl","Germany","Lauchringen","Lauchringen","",['Artur']])
data_list.append([datetime.datetime(2021,3,6),9,"Stephanskirche",'Konstanz',"Germany",'Lauchringen','Lauchringen',"",['Artur']])
data_list.append([datetime.datetime(2021,3,6),3,"Christuskirche",'Konstanz',"Germany",'Lauchringen','Lauchringen',"",['Artur']])
data_list.append([datetime.datetime(2021,3,6),1,"Rheintorturm",'Konstanz',"Germany",'Lauchringen','Lauchringen',"",['Artur']])
data_list.append([datetime.datetime(2021,3,6),8,"Dreifaltigkeitskirche",'Konstanz',"Germany",'Lauchringen','Lauchringen',"",['Artur']])
data_list.append([datetime.datetime(2021,3,6),1,"Rathaus",'Konstanz',"Germany",'Lauchringen','Lauchringen',"",['Artur']])
data_list.append([datetime.datetime(2021,3,6),2,"Imperia",'Konstanz',"Germany",'Lauchringen','Lauchringen',"",['Artur']])
data_list.append([datetime.datetime(2021,3,6),1,"Konzilgebaeude",'Konstanz',"Germany",'Lauchringen','Lauchringen',"",['Artur']])
data_list.append([datetime.datetime(2021,3,6),45,"Minster",'Konstanz',"Germany",'Lauchringen','Lauchringen',"",['Artur']])
data_list.append([datetime.datetime(2021,3,6),11,"Hohenkraehen",'Hilzingen',"Germany",'Lauchringen','Lauchringen',"",['Artur']])
data_list.append([datetime.datetime(2021,3,6),2,"Hohentwiel",'Singen',"Germany",'Lauchringen','Lauchringen',"",['Artur']])
data_list.append([datetime.datetime(2021,3,6),13,"Maegdeberg",'Muehlhausen',"Germany",'Lauchringen','Lauchringen',"",['Artur']])
data_list.append([datetime.datetime(2021,3,6),2,"Stadttor",'Tengen',"Germany",'Lauchringen','Lauchringen',"",['Artur']])
data_list.append([datetime.datetime(2021,3,6),2,"Hinterburg",'Tengen',"Germany",'Lauchringen','Lauchringen',"",['Artur']])
data_list.append([datetime.datetime(2021,3,6),21,"Muehlbachschlucht",'Tengen',"Germany",'Lauchringen','Lauchringen',"",['Artur']])
data_list.append([datetime.datetime(2021,3,10),1,"Schloss",'Tiengen',"Germany",'Lauchringen','Lauchringen',"",[]])
data_list.append([datetime.datetime(2021,3,10),2,"Storchenturm",'Tiengen',"Germany",'Lauchringen','Lauchringen',"",[]])
data_list.append([datetime.datetime(2021, 3, 11),1,"Bahnhof",'Lindau',"Germany",'Lauchringen','Lauchringen',"",['Artur']])
data_list.append([datetime.datetime(2021, 3, 11),1,"Hauptbahnhof",'Munich',"Germany",'Lauchringen','Lauchringen',"",[]])
data_list.append([datetime.datetime(2021, 3, 11),2,"Hauptbahnhof",'Salzburg',"Austria",'Lauchringen','Lauchringen',"",[]])
data_list.append([datetime.datetime(2021, 3, 11),3,"Hauptbahnhof",'Vienna',"Austria",'Lauchringen','Lauchringen',"",[]])
data_list.append([datetime.datetime(2021,3,25),34,"Triberger Wasserfaelle",'Triberg',"Germany",'Lauchringen','Lauchringen',"",['Artur']])
data_list.append([datetime.datetime(2021,3,25),3,"Bergsee",'Triberg',"Germany",'Lauchringen','Lauchringen',"",['Artur']])
data_list.append([datetime.datetime(2021,3,25),15,"Maria in der Tanne",'Triberg',"Germany",'Lauchringen','Lauchringen',"",['Artur']])
data_list.append([datetime.datetime(2021,3,25),5,"Schonachwasserfall",'Triberg',"Germany",'Lauchringen','Lauchringen',"",['Artur']])
data_list.append([datetime.datetime(2021,3,25),1,"Erste weltgroesste Kuckucksuhr",'Schonach',"Germany",'Lauchringen','Lauchringen',"",['Artur']])
data_list.append([datetime.datetime(2021,3,25),2,"Johanniterkirche",'Villingen',"Germany",'Lauchringen','Lauchringen',"",['Artur']])
data_list.append([datetime.datetime(2021,3,25),23,"Muenster",'Villingen',"Germany",'Lauchringen','Lauchringen',"",['Artur']])
data_list.append([datetime.datetime(2021,3,25),4,"Stadtmauer mit Stadttoren",'Villingen',"Germany",'Lauchringen','Lauchringen',"",['Artur']])
data_list.append([datetime.datetime(2021,3,28),5,"Teufelskueche",'Dachsberg',"Germany",'Lauchringen','Lauchringen',"",['Artur']])
data_list.append([datetime.datetime(2021,3,28),3,"Krai-Woog-Gumpen",'Goerwihl',"Germany",'Lauchringen','Lauchringen',"",['Artur']])
data_list.append([datetime.datetime(2021,3,28),11,"Teufelskessel",'Gutenburg',"Germany",'Lauchringen','Lauchringen',"",['Artur']])
data_list.append([datetime.datetime(2021,3,30),12,"Schleifenbachwasserfaelle",'Blumberg',"Germany",'Lauchringen','Lauchringen',"",['Artur']])
data_list.append([datetime.datetime(2021,3,30),3,"Mundelfinger Wasserfall",'Mundelfingen',"Germany",'Lauchringen','Lauchringen',"",['Artur']])
data_list.append([datetime.datetime(2021,3,30),4,"Kirche",'Mundelfingen',"Germany",'Lauchringen','Lauchringen',"",['Artur']])
data_list.append([datetime.datetime(2021,3,30),2,"Donauversickerung",'Immendingen',"Germany",'Lauchringen','Lauchringen',"",['Artur']])
data_list.append([datetime.datetime(2021,3,30),10,"Hoewenegg",'Mundelfingen',"Germany",'Lauchringen','Lauchringen',"",['Artur']])
data_list.append([datetime.datetime(2021,4,11),5,"Stadtkirche",'Stuehlingen',"Germany",'Lauchringen','Lauchringen',"",['Artur']])
data_list.append([datetime.datetime(2021,4,11),8,"Kapuzinerkloster",'Stuehlingen',"Germany",'Lauchringen','Lauchringen',"",['Artur']])
data_list.append([datetime.datetime(2021,4,11),15,"Dampfkessel",'Grimmelshofen',"Germany",'Lauchringen','Lauchringen',"",['Artur']])
data_list.append([datetime.datetime(2021,4,11),3,"Schloss Hohenlupfen",'Stuehlingen',"Germany",'Lauchringen','Lauchringen',"",['Artur']])
data_list.append([datetime.datetime(2021,4,13),4,"Lauffen-Wasserfall",'Lauchringen',"Germany",'Lauchringen','Lauchringen',"",['Artur']])
data_list.append([datetime.datetime(2021,4,16),1,"Stadttore",'Waldshut',"Germany",'Lauchringen','Lauchringen',"",['Artur']])
data_list.append([datetime.datetime(2021,4,16),1,"Schaeferbrunnen",'Waldshut',"Germany",'Lauchringen','Lauchringen',"",['Artur']])
data_list.append([datetime.datetime(2021,4,16),3,"Seltenbachschlucht",'Waldshut',"Germany",'Lauchringen','Lauchringen',"",['Artur']])
data_list.append([datetime.datetime(2021,4,16),12,"Wildgehege",'Waldshut',"Germany",'Lauchringen','Lauchringen',"",['Artur']])
data_list.append([datetime.datetime(2021,4,16),2,"Antoniuskapelle",'Hohentengen',"Germany",'Lauchringen','Lauchringen',"",['Artur']])
data_list.append([datetime.datetime(2021,4,16),3,"Burg Rotwasserstelz",'Hohentengen',"Germany",'Lauchringen','Lauchringen',"",['Artur']])
data_list.append([datetime.datetime(2021,4,16),5,"Rheinbunker",'Kaiserstuhl',"Switzerland",'Lauchringen','Lauchringen',"",['Artur']])
data_list.append([datetime.datetime(2021,4,16),4,"Burg Weisswasserstelz",'Hohentengen',"Germany",'Lauchringen','Lauchringen',"",['Artur']])
data_list.append([datetime.datetime(2021,4,24),14,"Loesshohlwege",'Bickensohl',"Germany",'Lauchringen','Lauchringen',"",['Artur']])
data_list.append([datetime.datetime(2021,4,24),2,"Rheintor",'Breisach',"Germany",'Lauchringen','Lauchringen',"",['Artur']])
data_list.append([datetime.datetime(2021,4,24),20,"Stephansmuenster",'Breisach',"Germany",'Lauchringen','Lauchringen',"",['Artur']])
data_list.append([datetime.datetime(2021,4,24),2,"Stadtmauer",'Breisach',"Germany",'Lauchringen','Lauchringen',"",['Artur']])
data_list.append([datetime.datetime(2021,5,4),80,"Stephansdom",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,5,4),19,"Peterskirche",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,5,4),7,"Pestsaeule",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,5,4),15,"Jesuitenkirche",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,5,4),1,"Dominikanerkirche",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,5,4),1,"Akademie der Wissenschaften",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,5,4),1,"Griechenkathedrale",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,5,4),16,"Hofburg",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,5,4),1,"Michaelerkirche",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,5,4),1,"Kunsthistorisches Museum",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,5,5),1,"Donauturm",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,5,6),8,"Stephansdom",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,5,6),39,"Kapuzinergruft",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,5,6),6,"Kapuzinerkirche",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,5,6),1,"Reformierte Stadtkirche",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,5,6),1,"Lutherische Stadtkirche",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,5,6),14,"Michaelerkirche",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,5,6),12,"Hofburg",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,5,6),7,"Augustinerkirche",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,5,6),32,"Hofbibliothek",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,5,6),1,"Bundeskanzleramt",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,5,6),7,"Minoritenkirche",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,5,6),2,"Stadtpalais Liechtenstein",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,5,6),2,"Stadtpalais Liechtenstein",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,5,6),5,"Burgtheater",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,5,6),2,"Rathaus",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,5,6),2,"Universitaet",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,5,6),23,"Votivkirche",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,5,6),7,"Schottenkirche",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,5,6),11,"Palais Daun-Kinsky",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,5,6),9,"Kirche am Hof",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,5,6),11,"Maria am Gestade",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,5,6),13,"Altes Rathaus",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,5,6),2,"Vermaehlungsbrunnen",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,5,6),1,"Ankeruhr",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,5,6),3,"Deutschordenskirche",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,5,6),14,"Franziskanerkirche",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,5,7),100,"Schloss Schoenbrunn",'Vienna',"Austria",'Vienna','Vienna',"Schoenbrunn Palace",[]])
data_list.append([datetime.datetime(2021,5,7),38,"Schlosspark Schoenbrunn",'Vienna',"Austria",'Vienna','Vienna',"Schoenbrunn Palace",[]])
data_list.append([datetime.datetime(2021,5,7),1,"Hofburg",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,5,7),1,"Stallburg",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,5,7),61,"Kaiserliche Schatzkammer",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,5,7),2,"Albertina",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,5,8),60,"Hofburg",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,5,8),1,"Mozartdenkmal",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,5,8),10,"Secession",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,5,8),1,"Staatsoper",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,5,8),30,"Karlskirche",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,5,8),1,"Musikverein",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,5,8),1,"Kuenstlerhaus - Albertina Modern",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,5,8),2,"Stephansdom",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,5,8),1,"Palais Schwarzenberg",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,5,8),1,"Hochstrahlbrunnen",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,5,8),1,"Rote Armee Denkmal",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,5,8),4,"Oberes Belvedere",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,5,8),2,"Unteres Belvedere",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,5,8),15,"Belvederegarten",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,5,8),1,"Salesianerinnenkirche",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,5,8),1,"Gardekirche",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,5,9),67,"Nationalpark Donau-Auen",'Vienna',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021,5,9),114,"Albertina",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,5,9),1,"Staatsoper",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,5,9),2,"Burggarten",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,5,9),2,"Schmetterlingshaus",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,5,9),3,"Hofburg Palmenhaus",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,5,10),3,"Dorotheum",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,5,10),33,"Palais Lobkowitz",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,5,10),3,"Hofburg",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,5,10),49,"Weltmuseum",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,5,10),5,"Ruestkammer",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,5,10),1,"Winterpalais Prinz Eugen",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,5,10),3,"Kursalon",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,5,10),10,"Stadtpark",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,5,10),5,"Hundertwasserhaus",'Vienna',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021,5,10),1,"Kunst Haus Wien Museum Hundertwasser",'Vienna',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021,5,10),3,"Johann-Nepomuk-Kirche",'Vienna',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021,5,11),5,"Hofburg",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,5,11),10,"Palais Mollard",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,5,11),3,"Ephesusmuseum",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,5,11),34,"Weltmuseum",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,5,11),1,"Naturhistorisches Museum",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,5,11),91,"Kunsthistorisches Museum",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,5,11),5,"Schloss Schoenbrunn",'Vienna',"Austria",'Vienna','Vienna',"Schoenbrunn Palace",[]])
data_list.append([datetime.datetime(2021,5,11),23,"Schlosspark Schoenbrunn",'Vienna',"Austria",'Vienna','Vienna',"Schoenbrunn Palace",[]])
data_list.append([datetime.datetime(2021,5,11),26,"Schlosspark Schoenbrunn Palmenhaus",'Vienna',"Austria",'Vienna','Vienna',"Schoenbrunn Palace",[]])
data_list.append([datetime.datetime(2021,5,11),12,"Schlosspark Schoenbrunn Wuestenhaus",'Vienna',"Austria",'Vienna','Vienna',"Schoenbrunn Palace",[]])
data_list.append([datetime.datetime(2021,5,11),4,"Schlosspark Schoenbrunn Gloriette",'Vienna',"Austria",'Vienna','Vienna',"Schoenbrunn Palace",[]])
data_list.append([datetime.datetime(2021,5,12),75,"Oberes Belvedere",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,5,12),4,"Belvederegarten",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,5,12),4,"Botanischer Garten",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,5,12),8,"Belvedere 21",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,5,12),19,"Kuenstlerhaus - Albertina Modern",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,5,12),14,"Dommuseum",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,5,12),1,"Stephansdom",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,5,13),2,"Schloss Schoenbrunn",'Vienna',"Austria",'Vienna','Vienna',"Schoenbrunn Palace",[]])
data_list.append([datetime.datetime(2021,5,13),33,"Schloss Schoenbrunn Kaiserliche Wagenburg",'Vienna',"Austria",'Vienna','Vienna',"Schoenbrunn Palace",[]])
data_list.append([datetime.datetime(2021,5,13),36,"Moebelmuseum",'Vienna',"Austria",'Vienna','Vienna',"Schoenbrunn Palace",[]])
data_list.append([datetime.datetime(2021,5,13),45,"Naturhistorisches Museum",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,5,14),10,"Franz von Assisi Kirche",'Vienna',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021,5,14),2,"Kagran Georgskirche",'Vienna',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021,5,15),9,"Schloss Niederweiden",'Engelhartstetten',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021,5,15),48,"Schloss Hof",'Engelhartstetten',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021,5,15),42,"Schloss Hof Garten",'Engelhartstetten',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021,5,15),16,"Schloss Hof Gutshof",'Engelhartstetten',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021,5,15),7,"Schloss Schoenbrunn",'Vienna',"Austria",'Vienna','Vienna',"Schoenbrunn Palace",[]])
data_list.append([datetime.datetime(2021,5,15),27,"Schlosspark Schoenbrunn",'Vienna',"Austria",'Vienna','Vienna',"Schoenbrunn Palace",[]])
data_list.append([datetime.datetime(2021,5,15),11,"Schlosspark Schoenbrunn Gloriette",'Vienna',"Austria",'Vienna','Vienna',"Schoenbrunn Palace",[]])
data_list.append([datetime.datetime(2021,5,16),100,"Tiergarten Schoenbrunn",'Vienna',"Austria",'Vienna','Vienna',"Schoenbrunn Palace",[]])
data_list.append([datetime.datetime(2021,5,16),2,"Schlosspark Schoenbrunn",'Vienna',"Austria",'Vienna','Vienna',"Schoenbrunn Palace",[]])
#golling & salzburg I 2021
data_list.append([datetime.datetime(2021, 5, 22),19,"Golling Falls",'Golling an der Salzach',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021, 5, 22),75,"Festung Hohensalzburg",'Salzburg',"Austria",'Vienna','Vienna',"Salzburg",[]])
data_list.append([datetime.datetime(2021, 5, 22),26,"Schloss Hellbrunn",'Salzburg',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021, 5, 22),72,"Schlosspark Hellbrunn",'Salzburg',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021, 5, 22),11,"Neue Residenz",'Salzburg',"Austria",'Vienna','Vienna',"Salzburg",[]])
data_list.append([datetime.datetime(2021, 5, 22),74,"Alte Residenz",'Salzburg',"Austria",'Vienna','Vienna',"Salzburg",[]])
data_list.append([datetime.datetime(2021, 5, 22),65,"Dom",'Salzburg',"Austria",'Vienna','Vienna',"Salzburg",[]])
data_list.append([datetime.datetime(2021, 5, 22),3,"Michaelskirche",'Salzburg',"Austria",'Vienna','Vienna',"Salzburg",[]])
data_list.append([datetime.datetime(2021, 5, 22),11,"Kollegienkirche",'Salzburg',"Austria",'Vienna','Vienna',"Salzburg",[]])
data_list.append([datetime.datetime(2021, 5, 22),22,"Franziskanerkirche",'Salzburg',"Austria",'Vienna','Vienna',"Salzburg",[]])
data_list.append([datetime.datetime(2021, 5, 22),21,"Erzabtei St Peter",'Salzburg',"Austria",'Vienna','Vienna',"Salzburg",[]])
data_list.append([datetime.datetime(2021, 5, 22),10,"Dommuseum",'Salzburg',"Austria",'Vienna','Vienna',"Salzburg",[]])
data_list.append([datetime.datetime(2021, 5, 22),10,"Schloss Mirabell",'Salzburg',"Austria",'Vienna','Vienna',"Salzburg",[]])
data_list.append([datetime.datetime(2021, 5, 22),4,"Margarethenkapelle",'Salzburg',"Austria",'Vienna','Vienna',"Salzburg",[]])
data_list.append([datetime.datetime(2021, 5, 22),1,"Kreuzkapelle",'Salzburg',"Austria",'Vienna','Vienna',"Salzburg",[]])
data_list.append([datetime.datetime(2021, 5, 22),6,"Petersfriedhof",'Salzburg',"Austria",'Vienna','Vienna',"Salzburg",[]])
data_list.append([datetime.datetime(2021, 5, 22),2,"St Johannes am Imberg",'Salzburg',"Austria",'Vienna','Vienna',"Salzburg",[]])
data_list.append([datetime.datetime(2021, 5, 22),6,"Dreifaltigkeitskirche",'Salzburg',"Austria",'Vienna','Vienna',"Salzburg",[]])
data_list.append([datetime.datetime(2021, 5, 22),2,"Kapuzinerkirche",'Salzburg',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021, 5, 22),1,"Kapitelschwemme","Salzburg","Austria","Vienna","Vienna","Salzburg",[]])
data_list.append([datetime.datetime(2021, 5, 22),2,"Residenzbrunnen","Salzburg","Austria","Vienna","Vienna","Salzburg",[]])
data_list.append([datetime.datetime(2021, 5, 22),2,"Florianibrunnen","Salzburg","Austria","Vienna","Vienna","Salzburg",[]])
data_list.append([datetime.datetime(2021, 5, 22),1,"Mariensaeule","Salzburg","Austria","Vienna","Vienna","Salzburg",[]])
data_list.append([datetime.datetime(2021,5,23),56,"Staatsoper",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,5,23),7,"Annakirche",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,5,23),3,"Malteserkirche",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,5,23),38,"Hofburg",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,5,23),1,"Peterskirche",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,5,23),3,"Stephansdom",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,5,23),5,"Stallburg",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,5,23),34,"Salzbergwerk",'Hallstatt',"Austria",'Vienna','Vienna',"Hallstatt-Dachstein/Salzkammergut Cultural Landscape",[]])
data_list.append([datetime.datetime(2021,5,23),37,"Hallstaetter See",'Hallstatt',"Austria",'Vienna','Vienna',"Hallstatt-Dachstein/Salzkammergut Cultural Landscape",[]])
data_list.append([datetime.datetime(2021,5,23),18,"Muehlbachfall",'Hallstatt',"Austria",'Vienna','Vienna',"Hallstatt-Dachstein/Salzkammergut Cultural Landscape",[]])
data_list.append([datetime.datetime(2021,5,23),13,"Kirche Maria Himmelfahrt",'Hallstatt',"Austria",'Vienna','Vienna',"Hallstatt-Dachstein/Salzkammergut Cultural Landscape",[]])
data_list.append([datetime.datetime(2021,5,23),2,"Evangelische Pfarrkirche",'Hallstatt',"Austria",'Vienna','Vienna',"Hallstatt-Dachstein/Salzkammergut Cultural Landscape",[]])
data_list.append([datetime.datetime(2021,5,23),4,"Marktplatz",'Hallstatt',"Austria",'Vienna','Vienna',"Hallstatt-Dachstein/Salzkammergut Cultural Landscape",[]])
data_list.append([datetime.datetime(2021,5,23),4,"Schleierfall",'Hallstatt',"Austria",'Vienna','Vienna',"Hallstatt-Dachstein/Salzkammergut Cultural Landscape",[]])
data_list.append([datetime.datetime(2021,5,23),4,"Echerntal",'Hallstatt',"Austria",'Vienna','Vienna',"Hallstatt-Dachstein/Salzkammergut Cultural Landscape",[]])
data_list.append([datetime.datetime(2021,5,23),11,"Waldbachstrub",'Hallstatt',"Austria",'Vienna','Vienna',"Hallstatt-Dachstein/Salzkammergut Cultural Landscape",[]])
data_list.append([datetime.datetime(2021,5,23),28,"Welterbemuseum Hallstatt",'Hallstatt',"Austria",'Vienna','Vienna',"Hallstatt-Dachstein/Salzkammergut Cultural Landscape",[]])
data_list.append([datetime.datetime(2021,5,28),5,"Reformierte Stadtkirche",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,5,28),5,"Lutherische Stadtkirche",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,5,28),15,"Karlskirche",'Vienna',"Austria",'Vienna','Vienna',"Vienna",["Bob"]])
data_list.append([datetime.datetime(2021,5,28),5,"Franziskanerkirche",'Vienna',"Austria",'Vienna','Vienna',"Vienna",["Bob"]])
data_list.append([datetime.datetime(2021,5,28),21,"Jesuitenkirche",'Vienna',"Austria",'Vienna','Vienna',"Vienna",["Bob"]])
data_list.append([datetime.datetime(2021,5,28),10,"Bernardikapelle",'Vienna',"Austria",'Vienna','Vienna',"Vienna",["Bob"]])
data_list.append([datetime.datetime(2021,5,28),18,"Stephansdom",'Vienna',"Austria",'Vienna','Vienna',"Vienna",["Bob"]])
data_list.append([datetime.datetime(2021,5,28),5,"Pestsaeule",'Vienna',"Austria",'Vienna','Vienna',"Vienna",["Bob"]])
data_list.append([datetime.datetime(2021,5,28),7,"Schottenkirche",'Vienna',"Austria",'Vienna','Vienna',"Vienna",["Bob"]])
data_list.append([datetime.datetime(2021,5,28),4,"Michaelskirche",'Vienna',"Austria",'Vienna','Vienna',"Vienna",["Bob"]])
data_list.append([datetime.datetime(2021,5,28),6,"Hofburg",'Vienna',"Austria",'Vienna','Vienna',"Vienna",["Bob"]])
data_list.append([datetime.datetime(2021,5,28),1,"Staatsoper",'Vienna',"Austria",'Vienna','Vienna',"Vienna",["Bob"]])
data_list.append([datetime.datetime(2021,5,29),26,"Schottenkirche",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,5,29),1,"Peterskirche",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,5,29),1,"Josefsbrunnen",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,5,29),32,"Schottenstift",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,5,30),176,"Klosterneuburg Abbey",'Klosterneuburg',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021,5,30),37,"Klosterneuburg Abbey Church",'Klosterneuburg',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021,5,30),51,"Klosterneuburg Abbey Treasury",'Klosterneuburg',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021,5,30),4,"Muellverbrennungsanlage Spittelau",'Vienna',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021,6,3),62,"Burg Hochosterwitz",'Launsdorf',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021,6,3),4,"Maria Himmelfahrt",'Launsdorf',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021,6,3),1,"Fleischmann-Viadukt",'Semmering',"Austria",'Vienna','Vienna',"Semmering Railway",[]])
data_list.append([datetime.datetime(2021,6,3),1,"Kalte-Rinne-Viadukt",'Breitenstein',"Austria",'Vienna','Vienna',"Semmering Railway",[]])
data_list.append([datetime.datetime(2021,6,3),1,"Burgruine Klamm",'Breitenstein',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021,6,5),4,"Praterstern",'Vienna',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021,6,5),15,"Wurstelprater",'Vienna',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021,6,5),1,"Ernst-Happel-Stadion",'Vienna',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021,6,5),29,"Prater Auenwald",'Vienna',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021,6,6),2,"Lainzer Tiergarten",'Vienna',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021,6,6),53,"Hermesvilla",'Vienna',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021,6,6),3,"Maria Hietzing",'Vienna',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021,6,6),3,"Belvederegarten",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,6,6),23,"Schlosspark Schoenbrunn",'Vienna',"Austria",'Vienna','Vienna',"Schoenbrunn Palace",[]])
data_list.append([datetime.datetime(2021,6,6),1,"Schlosspark Schoenbrunn Palmenhaus",'Vienna',"Austria",'Vienna','Vienna',"Schoenbrunn Palace",[]])
data_list.append([datetime.datetime(2021,6,6),27,"Arsenal",'Vienna',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021,6,12),68,"Stift Lilienfeld",'Lilienfeld',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021,6,12),72,"Stift Herzogenburg",'Herzogenburg',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021,6,12),7,"Franziskanerkirche",'St Poelten',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021,6,12),5,"Rathausplatz",'St Poelten',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021,6,12),4,"Prandtauerkirche",'St Poelten',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021,6,12),35,"Dom",'St Poelten',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021,6,13),60,"Myrafaelle",'Muggendorf',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021,6,13),12,"Hausstein",'Muggendorf',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021,6,13),48,"Steinwandklamm",'Furth an der Triesting',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021,6,13),9,"Burg",'Wiener Neustadt',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021,6,13),13,"Stift Neukloster",'Wiener Neustadt',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021,6,13),2,"Hauptplatz",'Wiener Neustadt',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021,6,13),20,"Dom",'Wiener Neustadt',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021,6,13),1,"Stadtmauer",'Wiener Neustadt',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021,6,19),4,"Stift Melk","Melk","Austria","Vienna","Vienna","Wachau Cultural Landscape",[]])
data_list.append([datetime.datetime(2021,6,19),3,"Marktkapelle","Emmersdorf an der Donau","Austria","Vienna","Vienna","Wachau Cultural Landscape",[]])
data_list.append([datetime.datetime(2021,6,19),3,"Nikolauskirche","Emmersdorf an der Donau","Austria","Vienna","Vienna","Wachau Cultural Landscape",[]])
data_list.append([datetime.datetime(2021,6,19),3,"Mauritiuskirche","Spitz an der Donau","Austria","Vienna","Vienna","Wachau Cultural Landscape",[]])
data_list.append([datetime.datetime(2021,6,19),4,"Burgruine Hinterhaus","Spitz an der Donau","Austria","Vienna","Vienna","Wachau Cultural Landscape",[]])
data_list.append([datetime.datetime(2021,6,19),1,"Johanneskapelle","Spitz an der Donau","Austria","Vienna","Vienna","Wachau Cultural Landscape",[]])
data_list.append([datetime.datetime(2021,6,19),4,"Stadtmauer","Duernstein","Austria","Vienna","Vienna","Wachau Cultural Landscape",[]])
data_list.append([datetime.datetime(2021,6,19),13,"Burgruine Duernstein","Duernstein","Austria","Vienna","Vienna","Wachau Cultural Landscape",[]])
data_list.append([datetime.datetime(2021,6,19),87,"Stift Duernstein","Duernstein","Austria","Vienna","Vienna","Wachau Cultural Landscape",[]])
data_list.append([datetime.datetime(2021,6,19),3,"Stift Goettweig","Furth bei Goettweig","Austria","Vienna","Vienna","Wachau Cultural Landscape",[]])
data_list.append([datetime.datetime(2021,6,19),18,"Veitskirche","Krems an der Donau","Austria","Vienna","Vienna","Wachau Cultural Landscape",[]])
data_list.append([datetime.datetime(2021,6,19),10,"Piaristenkirche","Krems an der Donau","Austria","Vienna","Vienna","Wachau Cultural Landscape",[]])
data_list.append([datetime.datetime(2021,6,19),10,"Dominikanerkloster","Krems an der Donau","Austria","Vienna","Vienna","Wachau Cultural Landscape",[]])
data_list.append([datetime.datetime(2021,6,19),1,"Buergerspitalkirche","Krems an der Donau","Austria","Vienna","Vienna","Wachau Cultural Landscape",[]])
data_list.append([datetime.datetime(2021,6,19),19,"Steinertor","Krems an der Donau","Austria","Vienna","Vienna","Wachau Cultural Landscape",[]])
data_list.append([datetime.datetime(2021,6,20),2,"Hauptplatz","Baden bei Wien","Austria","Vienna","Vienna","The Great Spas of Europe",[]])
data_list.append([datetime.datetime(2021,6,20),5,"Stephanskirche","Baden bei Wien","Austria","Vienna","Vienna","The Great Spas of Europe",[]])
data_list.append([datetime.datetime(2021,6,20),9,"Kurhaus mit Kurpark","Baden bei Wien","Austria","Vienna","Vienna","The Great Spas of Europe",[]])
data_list.append([datetime.datetime(2021,6,20),5,"Beethovenhaus","Baden bei Wien","Austria","Vienna","Vienna","The Great Spas of Europe",[]])
data_list.append([datetime.datetime(2021,6,20),2,"Josefsbad","Baden bei Wien","Austria","Vienna","Vienna","The Great Spas of Europe",[]])
data_list.append([datetime.datetime(2021,6,20),25,"Frauenbad","Baden bei Wien","Austria","Vienna","Vienna","The Great Spas of Europe",[]])
data_list.append([datetime.datetime(2021,6,20),1,"Franzensbad","Baden bei Wien","Austria","Vienna","Vienna","The Great Spas of Europe",[]])
data_list.append([datetime.datetime(2021,6,20),2,"Engelsbad","Baden bei Wien","Austria","Vienna","Vienna","The Great Spas of Europe",[]])
data_list.append([datetime.datetime(2021,6,20),97,"Stift Heiligenkreuz","Heiligenkreuz im Wienerwald","Austria","Vienna","Vienna","",[]])
data_list.append([datetime.datetime(2021,6,20),8,"Kalvarienberg","Heiligenkreuz im Wienerwald","Austria","Vienna","Vienna","",[]])
data_list.append([datetime.datetime(2021,6,22),1,"Griechenkirche St Georg",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,6,22),2,"Stadttempel",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,6,22),1,"Griechenkathedrale",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,6,22),2,"Griechisch-Katholische Barbarakirche",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,6,25),2,"Volkstheater",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,6,25),2,"Palais Trautson",'Vienna',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021,6,25),1,"Palais Auersperg",'Vienna',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021,6,25),3,"Ulrichskirche",'Vienna',"Austria",'Vienna','Vienna',"",[]])
#mit Kirche
data_list.append([datetime.datetime(2021,6,25),3,"Stiftskaserne",'Vienna',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021,6,25),9,"Kirche Mariahilf",'Vienna',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021,6,25),4,"Museumsquartier",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,6,26),63,"Stift Seitenstetten",'Seitenstetten',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021,6,26),17,"Hofgarten Stift Seitenstetten",'Vienna',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021,6,26),164,"Stift St Florian",'St Florian bei Linz',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021,6,26),9,"Mariendom",'Linz',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021,6,26),1,"Alter Dom",'Linz',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021,6,26),5,"Ursulinnenkirche",'Linz',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021,6,26),1,"Karmelitenkirche",'Linz',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021,6,26),1,"Kirche der Barmherzigen Brueder",'Linz',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021,7,2),37,"Schmetterlingshaus",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,7,2),18,"Hofburg",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,7,2),17,"Stephansdom",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,7,2),1,"Franziskanerkirche",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,7,2),1,"Rathaus",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,7,2),1,"Karlskirche",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,7,3),12,"Hallstaetter See",'Hallstatt',"Austria",'Vienna','Vienna',"Hallstatt-Dachstein/Salzkammergut Cultural Landscape",[]])
data_list.append([datetime.datetime(2021,7,3),21,"Koppenbruellerhoehle",'Obertraun',"Austria",'Vienna','Vienna',"Hallstatt-Dachstein/Salzkammergut Cultural Landscape",[]])
data_list.append([datetime.datetime(2021,7,3),8,"Koppenwinkelsee",'Obertraun',"Austria",'Vienna','Vienna',"Hallstatt-Dachstein/Salzkammergut Cultural Landscape",[]])
data_list.append([datetime.datetime(2021,7,3),58,"Dachstein Rieseneishoehle",'Obertraun',"Austria",'Vienna','Vienna',"Hallstatt-Dachstein/Salzkammergut Cultural Landscape",[]])
data_list.append([datetime.datetime(2021,7,3),42,"Mammuthoehle",'Obertraun',"Austria",'Vienna','Vienna',"Hallstatt-Dachstein/Salzkammergut Cultural Landscape",[]])
data_list.append([datetime.datetime(2021,7,3),10,"Hallstaetter Gletscher",'Obertraun',"Austria",'Vienna','Vienna',"Hallstatt-Dachstein/Salzkammergut Cultural Landscape",[]])
data_list.append([datetime.datetime(2021,7,3),6,"Krippenstein 5 Fingers",'Obertraun',"Austria",'Vienna','Vienna',"Hallstatt-Dachstein/Salzkammergut Cultural Landscape",[]])
data_list.append([datetime.datetime(2021,7,4),6,"Otto-Wagner Pavillon Karlsplatz",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,7,4),1,"Karlskirche",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,7,4),2,"Hofburg",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,7,4),7,"Neidhart Festsaal",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,7,4),1,"Vermaehlungsbrunnen",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,7,4),7,"Roemermuseum",'Vienna',"Austria",'Vienna','Vienna',"Frontiers of the Roman Empire",[]])
data_list.append([datetime.datetime(2021,7,4),7,"Virgilkapelle",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,7,4),18,"Otto-Wagner Hofpavillon Hietzing",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,7,4),9,"Wotrubakirche",'Vienna',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021,7,4),80,"Zweite Otto-Wagner-Villa (Ernst Fuchs Museum)",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,7,4),4,"Stephansdom",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,7,4),1,"Votivkirche",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,7,4),6,"Jesuitenkirche",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,7,4),2,"Staatsoper",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,7,4),35,"Zentralfriedhof",'Vienna',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021,7,9),3,"mumok",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,7,10),84,"Kitzlochklamm",'Taxenbach',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021,7,10),102,"Liechtensteinklamm",'St Johann im Pongau',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021,7,10),5,"Gainfeldwasserfall",'Bischofshofen',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021,7,10),2,"Sprungschanze Bischofshofen",'Bischofshofen',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021,7,10),6,"Tennengebirge",'Bischofshofen',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021,7,10),2,"Burgruine Bachfall",'Bischofshofen',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021,7,17),65,"Gasteiner Wasserfall",'Bad Gastein',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021,7,17),3,"Pfarrkirche Primus und Felizian",'Bad Gastein',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021,7,17),27,"Landhaus",'Klagenfurt',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021,7,17),2,"Alter Platz",'Klagenfurt',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021,7,17),6,"Stadthauptpfarrkirche St Egid",'Klagenfurt',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021,7,17),1,"Heuplatz",'Klagenfurt',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021,7,17),2,"Kapuzinerkirche",'Klagenfurt',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021,7,17),4,"Heiligengeistkirche",'Klagenfurt',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021,7,17),2,"Lindwurmbrunnen",'Klagenfurt',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021,7,17),20,"Dom",'Klagenfurt',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021,7,17),2,"Klagenfurt Hauptbahnhof",'Klagenfurt',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021,7,18),40,"MAK",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,7,23),1,"Festung Kufstein",'Kufstein',"Austria",'Vienna','Innsbruck',"",[]])
data_list.append([datetime.datetime(2021,7,23),1,"Triumphpforte",'Innsbruck',"Austria",'Vienna','Innsbruck',"",[]])
data_list.append([datetime.datetime(2021,7,23),1,"Servitenkirche",'Innsbruck',"Austria",'Vienna','Innsbruck',"",[]])
data_list.append([datetime.datetime(2021,7,23),1,"Taxispalais",'Innsbruck',"Austria",'Vienna','Innsbruck',"",[]])
data_list.append([datetime.datetime(2021,7,23),2,"Annasaeule",'Innsbruck',"Austria",'Vienna','Innsbruck',"",[]])
data_list.append([datetime.datetime(2021,7,23),5,"Goldenes Dachl",'Innsbruck',"Austria",'Vienna','Innsbruck',"",[]])
data_list.append([datetime.datetime(2021,7,23),21,"Dom",'Innsbruck',"Austria",'Vienna','Innsbruck',"",[]])
data_list.append([datetime.datetime(2021,7,23),2,"Rathaus",'Innsbruck',"Austria",'Vienna','Innsbruck',"",[]])
data_list.append([datetime.datetime(2021,7,23),2,"Hofkirche",'Innsbruck',"Austria",'Vienna','Innsbruck',"",[]])
data_list.append([datetime.datetime(2021,7,23),4,"Hofburg",'Innsbruck',"Austria",'Vienna','Innsbruck',"",[]])
data_list.append([datetime.datetime(2021,7,23),1,"Leopoldbrunnen",'Innsbruck',"Austria",'Vienna','Innsbruck',"",[]])
data_list.append([datetime.datetime(2021,7,23),9,"Jesuitenkirche",'Innsbruck',"Austria",'Vienna','Innsbruck',"",[]])
data_list.append([datetime.datetime(2021,7,23),1,"Ottoburg",'Innsbruck',"Austria",'Vienna','Innsbruck',"",[]])
data_list.append([datetime.datetime(2021,7,23),1,"Nordkette",'Innsbruck',"Austria",'Vienna','Innsbruck',"",[]])
data_list.append([datetime.datetime(2021,7,23),1,"Spitalkirche",'Innsbruck',"Austria",'Vienna','Innsbruck',"",[]])
data_list.append([datetime.datetime(2021,7,23),1,"Nordkette",'Innsbruck',"Austria",'Vienna','Innsbruck',"",['Grace','Sam','Janina']])
data_list.append([datetime.datetime(2021,7,23),1,"Dom",'Innsbruck',"Austria",'Vienna','Innsbruck',"",['Grace','Sam','Janina']])
data_list.append([datetime.datetime(2021,7,23),1,"Hofburg",'Innsbruck',"Austria",'Vienna','Innsbruck',"",['Grace','Sam','Janina']])
data_list.append([datetime.datetime(2021,7,23),1,"Hofkirche",'Innsbruck',"Austria",'Vienna','Innsbruck',"",['Grace','Sam','Janina']])
data_list.append([datetime.datetime(2021,7,23),1,"Rathaus",'Innsbruck',"Austria",'Vienna','Innsbruck',"",['Grace','Sam','Janina']])
data_list.append([datetime.datetime(2021,7,23),2,"Goldenes Dachl",'Innsbruck',"Austria",'Vienna','Innsbruck',"",['Grace','Sam','Janina']])
data_list.append([datetime.datetime(2021,7,24),5,"Stausee Durlassboden",'Gerlos',"Austria",'Innsbruck','Innsbruck',"",['Grace','Sam','Janina']])
data_list.append([datetime.datetime(2021,7,24),46,"Krimmler Wasserfaelle",'Krimml',"Austria",'Innsbruck','Innsbruck',"",['Grace','Sam','Janina']])
data_list.append([datetime.datetime(2021,7,24),47,"Hofkirche",'Innsbruck',"Austria",'Innsbruck','Innsbruck',"",['Grace','Sam','Janina']])
data_list.append([datetime.datetime(2021,7,24),2,"Nordkette",'Innsbruck',"Austria",'Innsbruck','Innsbruck',"",['Grace','Sam','Janina']])
data_list.append([datetime.datetime(2021,7,24),17,"Hofburg",'Innsbruck',"Austria",'Innsbruck','Innsbruck',"",['Grace','Sam','Janina']])
data_list.append([datetime.datetime(2021,7,24),3,"Dom",'Innsbruck',"Austria",'Innsbruck','Innsbruck',"",['Grace','Sam','Janina']])
data_list.append([datetime.datetime(2021,7,24),9,"Basilika Wilten",'Innsbruck',"Austria",'Innsbruck','Innsbruck',"",['Grace','Sam','Janina']])
data_list.append([datetime.datetime(2021,7,24),53,"Stift Wilten",'Innsbruck',"Austria",'Innsbruck','Innsbruck',"",['Grace','Sam','Janina']])
data_list.append([datetime.datetime(2021,7,24),1,"Bergisel Sprungschanze",'Innsbruck',"Austria",'Innsbruck','Innsbruck',"",['Grace','Sam','Janina']])
data_list.append([datetime.datetime(2021,7,24),1,"Goldenes Dachl",'Innsbruck',"Austria",'Innsbruck','Innsbruck',"",['Grace','Sam','Janina']])
data_list.append([datetime.datetime(2021,7,25),13,"Nordkette",'Innsbruck',"Austria",'Innsbruck','Innsbruck',"",['Grace','Sam','Janina']])
data_list.append([datetime.datetime(2021,7,25),92,"Swarovski Kristallwelten",'Wattens',"Austria",'Innsbruck','Vienna',"",['Grace','Sam','Janina']])
data_list.append([datetime.datetime(2021,7,25),72,"Schloss Ambras",'Innsbruck',"Austria",'Innsbruck','Vienna',"",['Grace','Sam','Janina']])
data_list.append([datetime.datetime(2021,7,25),72,"Innsbruck Hauptbahnhof",'Innsbruck',"Austria",'Innsbruck','Vienna',"",['Grace','Sam','Janina']])
data_list.append([datetime.datetime(2021,7,31),22,"Universitaet",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,7,31),40,"Palais Epstein",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,7,31),1,"Justizpalast",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,7,31),1,"Palais Auersperg",'Vienna',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021,7,31),12,"Maria Treu",'Vienna',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021,7,31),14,"Palais Schoenborn",'Vienna',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021,7,31),1,"St Aegyd",'Vienna',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021,7,31),16,"Geymuellerschloessel",'Vienna',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021,8,1),4,"Heidentor",'Petronell-Carnuntum',"Austria",'Vienna','Vienna',"Frontiers of the Roman Empire",[]])
data_list.append([datetime.datetime(2021,8,1),8,"Amphitheater Zivilstadt",'Petronell-Carnuntum',"Austria",'Vienna','Vienna',"Frontiers of the Roman Empire",[]])
data_list.append([datetime.datetime(2021,8,1),16,"Roman Quarter",'Petronell-Carnuntum',"Austria",'Vienna','Vienna',"Frontiers of the Roman Empire",[]])
data_list.append([datetime.datetime(2021,8,1),4,"Schloss Petronell",'Petronell-Carnuntum',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021,8,1),11,"Nationalpark Donau-Auen",'Petronell-Carnuntum',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021,8,1),3,"Rundkapelle St Johannes d Taeufer",'Petronell-Carnuntum',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021,8,1),2,"Annakapelle",'Petronell-Carnuntum',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021,8,1),1,"Dreifaltigkeitssaeule",'Petronell-Carnuntum',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021,8,1),2,"St Petronilla",'Petronell-Carnuntum',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021,8,1),5,"Amphitheater Militaerstadt",'Bad Deutsch-Altenburg',"Austria",'Vienna','Vienna',"Frontiers of the Roman Empire",[]])
data_list.append([datetime.datetime(2021,8,1),8,"Maria Himmelfahrt",'Bad Deutsch-Altenburg',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021,8,1),14,"Museum Carnuntium",'Bad Deutsch-Altenburg',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021,8,1),13,"Schlosspark Eckartsau",'Eckartsau',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021,8,1),71,"Schloss Eckartsau",'Eckartsau',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021,8,1),2,"St Leonhard",'Eckartsau',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021,8,5),7,"Stephansdom",'Vienna',"Austria",'Vienna','Vienna',"Vienna",['Namrata']])
data_list.append([datetime.datetime(2021,8,7),29,"Steinbruch",'St Margarethen im Burgenland',"Austria",'Vienna','Vienna',"Fertoe/Neusiedlersee Cultural Landscape",[]])
data_list.append([datetime.datetime(2021,8,7),3,"Toleranzkirche",'Rust am See',"Austria",'Vienna','Vienna',"Fertoe/Neusiedlersee Cultural Landscape",[]])
data_list.append([datetime.datetime(2021,8,7),3,"Stadtmauer",'Rust am See',"Austria",'Vienna','Vienna',"Fertoe/Neusiedlersee Cultural Landscape",[]])
data_list.append([datetime.datetime(2021,8,7),3,"Rathausplatz",'Rust am See',"Austria",'Vienna','Vienna',"Fertoe/Neusiedlersee Cultural Landscape",[]])
data_list.append([datetime.datetime(2021,8,7),2,"Dreifaltigkeitskirche",'Rust am See',"Austria",'Vienna','Vienna',"Fertoe/Neusiedlersee Cultural Landscape",[]])
data_list.append([datetime.datetime(2021,8,7),3,"Stadthafen",'Rust am See',"Austria",'Vienna','Vienna',"Fertoe/Neusiedlersee Cultural Landscape",[]])
data_list.append([datetime.datetime(2021,8,7),4,"Hafen",'Rust am See',"Austria",'Vienna','Vienna',"Fertoe/Neusiedlersee Cultural Landscape",[]])
data_list.append([datetime.datetime(2021,8,7),4,"Dom Sankt Martin",'Eisenstadt',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021,8,7),3,"Rathaus",'Eisenstadt',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021,8,7),4,"Franziskanerkirche",'Eisenstadt',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021,8,7),71,"Schloss Esterhazy",'Eisenstadt',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021,8,7),2,"Antoniuskirche",'Eisenstadt',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021,8,7),10,"Bergkirche",'Eisenstadt',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021,8,7),22,"Kalvarienberg",'Eisenstadt',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021,8,8),5,"Kreuzschwesternkloster Laxenburg",'Laxenburg',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021,8,8),11,"Kirche",'Laxenburg',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021,8,8),9,"Blauer Hof",'Laxenburg',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021,8,8),4,"Altes Schloss",'Laxenburg',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021,8,8),49,"Schlosspark Laxenburg",'Laxenburg',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021,8,8),66,"Franzensburg",'Laxenburg',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021,8,14),9,"Schloss Rosenburg",'Rosenburg',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021,8,14),7,"Kampschlaufe",'Altenburg',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021,8,14),125,"Stift Altenburg",'Altenburg',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021,8,14),74,"Stift Goettweig","Furth bei Goettweig","Austria","Vienna","Vienna","Wachau Cultural Landscape",[]])
data_list.append([datetime.datetime(2021,8,15),5,"Krankenhaus der Barmherzigen Brueder",'Vienna',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021,8,15),2,"Karmeliterkirche St Josef",'Vienna',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021,8,15),3,"St Leopold",'Vienna',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021,8,15),5,"Augarten",'Vienna',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021,8,19),13,"Hofbibliothek",'Vienna',"Austria",'Vienna','Vienna',"Vienna",['Nicolae','Adrian']])
data_list.append([datetime.datetime(2021,8,21),2,"Kartnerkogel-Viadukt",'Semmering',"Austria",'Vienna','Vienna',"Semmering Railway",[]])
data_list.append([datetime.datetime(2021,8,21),12,"Adlitzgraben",'Breitenstein',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021,8,21),8,"20-Schillingblick",'Smmering',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021,8,21),5,"Krausel-Klause-Viadukt",'Breitenstein',"Austria",'Vienna','Vienna',"Semmering Railway",[]])
data_list.append([datetime.datetime(2021,8,21),9,"Kalte-Rinne-Viadukt",'Breitenstein',"Austria",'Vienna','Vienna',"Semmering Railway",[]])
data_list.append([datetime.datetime(2021,8,21),5,"Unterer-Adlitzgraben-Viadukt",'Semmering',"Austria",'Vienna','Vienna',"Semmering Railway",[]])
data_list.append([datetime.datetime(2021,8,21),3,"Rumplergragen-Viadukt",'Breitenstein',"Austria",'Vienna','Vienna',"Semmering Railway",[]])
data_list.append([datetime.datetime(2021,8,21),2,"Gamperlgraben-Viadukt",'Breitenstein',"Austria",'Vienna','Vienna',"Semmering Railway",[]])
data_list.append([datetime.datetime(2021,8,21),3,"Wagnergraben-Viadukt",'Breitenstein',"Austria",'Vienna','Vienna',"Semmering Railway",[]])
data_list.append([datetime.datetime(2021,8,21),3,"Burgruine Klamm",'Breitenstein',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021,8,21),1,"Pfarrkirche",'Payerbach',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021,8,21),1,"Payerbachgraben-Viadukt",'Payerbach',"Austria",'Vienna','Vienna',"Semmering Railway",[]])
data_list.append([datetime.datetime(2021,8,21),1,"Schwarza-Viadukt",'Payerbach',"Austria",'Vienna','Vienna',"Semmering Railway",[]])

# %%
#prague 2021 done
data_list.append([datetime.datetime(2021, 8, 27),2,"Powder Tower",'Prague',"Czechia",'Vienna','Prague',"Historic Centre of Prague",[]])
data_list.append([datetime.datetime(2021, 8, 27),1,"Municipal House",'Prague',"Czechia",'Vienna','Prague',"Historic Centre of Prague",[]])
data_list.append([datetime.datetime(2021, 8, 27),1,"St Nicholas (Old Town)",'Prague',"Czechia",'Prague','Prague',"Historic Centre of Prague",[]])
data_list.append([datetime.datetime(2021, 8, 27),3,"Old Town Hall",'Prague',"Czechia",'Vienna','Prague',"Historic Centre of Prague",[]])
data_list.append([datetime.datetime(2021, 8, 27),1,"Old Town Square",'Prague',"Czechia",'Vienna','Prague',"Historic Centre of Prague",[]])
data_list.append([datetime.datetime(2021, 8, 27),1,"Rudolfinum",'Prague',"Czechia",'Vienna','Prague',"Historic Centre of Prague",[]])
data_list.append([datetime.datetime(2021, 8, 27),1,"St Vitus Cathedral",'Prague',"Czechia",'Vienna','Prague',"Historic Centre of Prague",[]])
data_list.append([datetime.datetime(2021, 8, 28),2,"Powder Tower",'Prague',"Czechia",'Prague','Prague',"Historic Centre of Prague",[]])
data_list.append([datetime.datetime(2021, 8, 28),1,"Municipal House",'Prague',"Czechia",'Prague','Prague',"Historic Centre of Prague",[]])
data_list.append([datetime.datetime(2021, 8, 28),3,"Teyn Church",'Prague',"Czechia",'Prague','Prague',"Historic Centre of Prague",[]])
data_list.append([datetime.datetime(2021, 8, 28),9,"Old Town Square",'Prague',"Czechia",'Prague','Prague',"Historic Centre of Prague",[]])
data_list.append([datetime.datetime(2021, 8, 28),3,"Old Town Hall",'Prague',"Czechia",'Prague','Prague',"Historic Centre of Prague",[]])
data_list.append([datetime.datetime(2021, 8, 28),1,"St Nicholas (Old Town)",'Prague',"Czechia",'Prague','Prague',"Historic Centre of Prague",[]])
data_list.append([datetime.datetime(2021, 8, 28),3,"Small Old Town Square",'Prague',"Czechia",'Prague','Prague',"Historic Centre of Prague",[]])
data_list.append([datetime.datetime(2021, 8, 28),3,"Clementinum",'Prague',"Czechia",'Prague','Prague',"Historic Centre of Prague",[]])
#including the towers
data_list.append([datetime.datetime(2021, 8, 28),20,"Charles Bridge",'Prague',"Czechia",'Prague','Prague',"Historic Centre of Prague",[]])
data_list.append([datetime.datetime(2021, 8, 28),1,"Charles IV Monument",'Prague',"Czechia",'Prague','Prague',"Historic Centre of Prague",[]])
data_list.append([datetime.datetime(2021, 8, 28),3,"St Francis of Assisi",'Prague',"Czechia",'Prague','Prague',"Historic Centre of Prague",[]])
data_list.append([datetime.datetime(2021, 8, 28),2,"Clementinum St Salvator",'Prague',"Czechia",'Prague','Prague',"Historic Centre of Prague",[]])
data_list.append([datetime.datetime(2021, 8, 28),9,"St Nicholas (Lesser Side)",'Prague',"Czechia",'Prague','Prague',"Historic Centre of Prague",[]])
#quarter, not royal palace or vitus, or belvedere, but golden lane
data_list.append([datetime.datetime(2021, 8, 28),22,"Prague Castle",'Prague',"Czechia",'Prague','Prague',"Historic Centre of Prague",[]])
data_list.append([datetime.datetime(2021, 8, 28),93,"St Vitus Cathedral",'Prague',"Czechia",'Prague','Prague',"Historic Centre of Prague",[]])
data_list.append([datetime.datetime(2021, 8, 28),2,"Lesser Side Square",'Prague',"Czechia",'Prague','Prague',"Historic Centre of Prague",[]])
#also outside of new royal palace
data_list.append([datetime.datetime(2021, 8, 28),18,"Prague Castle State Apartments",'Prague',"Czechia",'Prague','Prague',"Historic Centre of Prague",[]])
data_list.append([datetime.datetime(2021, 8, 28),3,"Archbishop's Palace",'Prague',"Czechia",'Prague','Prague',"Historic Centre of Prague",[]])
data_list.append([datetime.datetime(2021, 8, 28),8,"Strahov Monastery",'Prague',"Czechia",'Prague','Prague',"Historic Centre of Prague",[]])
data_list.append([datetime.datetime(2021, 8, 28),1,"Toskana Palais",'Prague',"Czechia",'Prague','Prague',"Historic Centre of Prague",[]])
data_list.append([datetime.datetime(2021, 8, 28),2,"Schwarzenberg Palais",'Prague',"Czechia",'Prague','Prague',"Historic Centre of Prague",[]])
data_list.append([datetime.datetime(2021, 8, 28),32,"Prague Castle Old Royal Palace",'Prague',"Czechia",'Prague','Prague',"Historic Centre of Prague",[]])
data_list.append([datetime.datetime(2021, 8, 28),15,"Prague Castle St George",'Prague',"Czechia",'Prague','Prague',"Historic Centre of Prague",[]])
data_list.append([datetime.datetime(2021, 8, 28),1,"Wallenstein Palace",'Prague',"Czechia",'Prague','Prague',"Historic Centre of Prague",[]])
data_list.append([datetime.datetime(2021, 8, 28),4,"Prague Castle Gardens",'Prague',"Czechia",'Prague','Prague',"Historic Centre of Prague",[]])
data_list.append([datetime.datetime(2021, 8, 28),19,"Prague Castle Belvedere",'Prague',"Czechia",'Prague','Prague',"Historic Centre of Prague",[]])
data_list.append([datetime.datetime(2021, 8, 28),1,"St Benedict",'Prague',"Czechia",'Prague','Prague',"Historic Centre of Prague",[]])
data_list.append([datetime.datetime(2021, 8, 28),3,"Palais Czernin",'Prague',"Czechia",'Prague','Prague',"Historic Centre of Prague",[]])
data_list.append([datetime.datetime(2021, 8, 28),35,"Loreto",'Prague',"Czechia",'Prague','Prague',"Historic Centre of Prague",[]])
data_list.append([datetime.datetime(2021, 8, 28),1,"Capucin Church",'Prague',"Czechia",'Prague','Prague',"Historic Centre of Prague",[]])
data_list.append([datetime.datetime(2021, 8, 28),24,"Palais Sternberg",'Prague',"Czechia",'Prague','Prague',"Historic Centre of Prague",[]])
data_list.append([datetime.datetime(2021, 8, 28),1,"Prague Main Station",'Prague',"Czechia",'Prague','Prague',"Historic Centre of Prague",[]])
data_list.append([datetime.datetime(2021, 8, 28),34,"Karlstejn Castle",'Karlstejn',"Czechia",'Prague','Prague',"",[]])
data_list.append([datetime.datetime(2021, 8, 28),1,"Petrin Tower",'Prague',"Czechia",'Prague','Prague',"",[]])
data_list.append([datetime.datetime(2021, 8, 28),1,"National Museum",'Prague',"Czechia",'Prague','Prague',"Historic Centre of Prague",[]])
data_list.append([datetime.datetime(2021, 8, 28),1,"National Theatre",'Prague',"Czechia",'Prague','Prague',"Historic Centre of Prague",[]])
data_list.append([datetime.datetime(2021, 8, 28),1,"Rudolfinum",'Prague',"Czechia",'Prague','Prague',"Historic Centre of Prague",[]])
data_list.append([datetime.datetime(2021, 8, 28),1,"Town Hall",'Prague',"Czechia",'Prague','Prague',"Historic Centre of Prague",[]])
data_list.append([datetime.datetime(2021, 8, 28),1,"Jillich Church",'Prague',"Czechia",'Prague','Prague',"Historic Centre of Prague",[]])
data_list.append([datetime.datetime(2021, 8, 29),9,"Old Town Square",'Prague',"Czechia",'Prague','Vienna',"Historic Centre of Prague",[]])
data_list.append([datetime.datetime(2021, 8, 29),19,"Clementinum",'Prague',"Czechia",'Prague','Vienna',"Historic Centre of Prague",[]])
data_list.append([datetime.datetime(2021, 8, 29),4,"Charles Bridge",'Prague',"Czechia",'Prague','Vienna',"Historic Centre of Prague",[]])
data_list.append([datetime.datetime(2021, 8, 29),1,"Petrin Tower",'Prague',"Czechia",'Prague','Vienna',"",[]])
data_list.append([datetime.datetime(2021, 8, 29),1,"Schwarzenberg Palais",'Prague',"Czechia",'Prague','Vienna',"Historic Centre of Prague",[]])
data_list.append([datetime.datetime(2021, 8, 29),2,"St Vitus Cathedral",'Prague',"Czechia",'Prague','Vienna',"Historic Centre of Prague",[]])
data_list.append([datetime.datetime(2021, 8, 29),50,"Strahov Monastery",'Prague',"Czechia",'Prague','Vienna',"Historic Centre of Prague",[]])
data_list.append([datetime.datetime(2021, 8, 29),4,"St Francis of Assisi",'Prague',"Czechia",'Prague','Vienna',"Historic Centre of Prague",[]])
data_list.append([datetime.datetime(2021, 8, 29),4,"Clementinum St Clemens",'Prague',"Czechia",'Prague','Vienna',"Historic Centre of Prague",[]])
data_list.append([datetime.datetime(2021, 8, 29),15,"Teyn Church",'Prague',"Czechia",'Prague','Vienna',"Historic Centre of Prague",[]])
data_list.append([datetime.datetime(2021, 8, 29),1,"Jillich Church",'Prague',"Czechia",'Prague','Vienna',"Historic Centre of Prague",[]])
data_list.append([datetime.datetime(2021, 8, 29),4,"Prague Castle",'Prague',"Czechia",'Prague','Vienna',"Historic Centre of Prague",[]])
data_list.append([datetime.datetime(2021, 8, 29),47,"St Nicholas (Lesser Side)",'Prague',"Czechia",'Prague','Vienna',"Historic Centre of Prague",[]])
data_list.append([datetime.datetime(2021, 8, 29),1,"Clementinum St Salvator",'Prague',"Czechia",'Prague','Vienna',"Historic Centre of Prague",[]])
data_list.append([datetime.datetime(2021, 8, 29),7,"St Nicholas (Old Town)",'Prague',"Czechia",'Prague','Vienna',"Historic Centre of Prague",[]])
data_list.append([datetime.datetime(2021, 8, 29),30,"Old Town Hall",'Prague',"Czechia",'Prague','Vienna',"Historic Centre of Prague",[]])
data_list.append([datetime.datetime(2021, 8, 29),16,"Colloredo-Mansfeld Palais",'Prague',"Czechia",'Prague','Vienna',"Historic Centre of Prague",[]])
data_list.append([datetime.datetime(2021, 8, 29),61,"Troja Palace",'Prague',"Czechia",'Prague','Vienna',"",[]])
data_list.append([datetime.datetime(2021, 8, 29),14,"Wallenstein Palace",'Prague',"Czechia",'Prague','Vienna',"Historic Centre of Prague",[]])
data_list.append([datetime.datetime(2021, 8, 29),1,"Henry's Tower",'Prague',"Czechia",'Prague','Vienna',"Historic Centre of Prague",[]])
data_list.append([datetime.datetime(2021, 8, 29),7,"Jerusalem Synagogue",'Prague',"Czechia",'Prague','Vienna',"Historic Centre of Prague",[]])
data_list.append([datetime.datetime(2021, 8, 29),2,"Prague Main Station",'Prague',"Czechia",'Prague','Vienna',"Historic Centre of Prague",[]])

# %%
data_list.append([datetime.datetime(2021,9,2),2,"Dom","Passau","Germany","Vienna","Geiselwind","",[]])
data_list.append([datetime.datetime(2021,9,2),2,"Veste Oberhaus","Passau","Germany","Vienna","Geiselwind","",[]])
data_list.append([datetime.datetime(2021,9,2),2,"Jesuitenkolleg","Passau","Germany","Vienna","Geiselwind","",[]])
data_list.append([datetime.datetime(2021,9,3),1,"Marktplatz","Geiselwind","Germany","Geiselwind","Geiselwind","Town of Bamberg",['Hannsjoerg']])
data_list.append([datetime.datetime(2021,9,3),21,"Old Town Hall","Bamberg","Germany","Geiselwind","Geiselwind","Town of Bamberg",['Hannsjoerg']])
data_list.append([datetime.datetime(2021,9,3),8,"St Martin","Bamberg","Germany","Geiselwind","Geiselwind","Town of Bamberg",['Hannsjoerg']])
data_list.append([datetime.datetime(2021,9,3),20,"Dom","Bamberg","Germany","Geiselwind","Geiselwind","Town of Bamberg",['Hannsjoerg']])
data_list.append([datetime.datetime(2021,9,3),2,"Alte Hofhaltung","Bamberg","Germany","Geiselwind","Geiselwind","Town of Bamberg",['Hannsjoerg']])
data_list.append([datetime.datetime(2021,9,3),3,"Jakobskirche","Bamberg","Germany","Geiselwind","Geiselwind","Town of Bamberg",['Hannsjoerg']])
data_list.append([datetime.datetime(2021,9,3),1,"New Residence","Bamberg","Germany","Geiselwind","Geiselwind","Town of Bamberg",['Hannsjoerg']])
data_list.append([datetime.datetime(2021,9,3),1,"Michaelsberg Monastery","Bamberg","Germany","Geiselwind","Geiselwind","Town of Bamberg",['Hannsjoerg']])
data_list.append([datetime.datetime(2021,9,3),7,"Schloss Weissenstein","Pommmersfelden","Germany","Geiselwind","Geiselwind","",['Hannsjoerg']])
data_list.append([datetime.datetime(2021,9,4),8,"Residence","Wuerzburg","Germany","Geiselwind","Geiselwind","Wuerzburg Residence with the Court Gardens and Residence Square",['Hannsjoerg','Artur','Jan-Marc','Franziska','Marion','Julius','Felicitas']])
data_list.append([datetime.datetime(2021,9,4),15,"Residence Court Gardens","Wuerzburg","Germany","Geiselwind","Geiselwind","Wuerzburg Residence with the Court Gardens and Residence Square",['Hannsjoerg','Artur','Jan-Marc','Franziska','Marion','Julius','Felicitas','Christian','Anne-Kathrin','Mathilda']])
data_list.append([datetime.datetime(2021,9,4),14,"Dom","Wuerzburg","Germany","Geiselwind","Geiselwind","",['Hannsjoerg','Artur','Jan-Marc','Franziska','Marion','Julius','Felicitas']])
data_list.append([datetime.datetime(2021,9,4),15,"Neumuenster","Wuerzburg","Germany","Geiselwind","Geiselwind","",['Hannsjoerg','Artur','Jan-Marc','Franziska','Marion','Julius','Felicitas','Christian','Anne-Kathrin','Mathilda']])
data_list.append([datetime.datetime(2021,9,4),5,"Rathaus","Wuerzburg","Germany","Geiselwind","Geiselwind","",['Hannsjoerg','Artur','Jan-Marc','Franziska','Marion','Julius','Felicitas','Christian','Anne-Kathrin','Mathilda']])
data_list.append([datetime.datetime(2021,9,4),1,"Festung Marienberg","Wuerzburg","Germany","Geiselwind","Geiselwind","",['Hannsjoerg','Artur','Jan-Marc','Franziska','Marion','Julius','Felicitas','Christian','Anne-Kathrin','Mathilda']])
data_list.append([datetime.datetime(2021,9,4),5,"Alte Mainbruecke","Wuerzburg","Germany","Geiselwind","Geiselwind","",['Hannsjoerg','Artur','Jan-Marc','Franziska','Marion','Julius','Felicitas','Christian','Anne-Kathrin','Mathilda']])
data_list.append([datetime.datetime(2021,9,4),3,"Marienkapelle","Wuerzburg","Germany","Geiselwind","Geiselwind","",['Hannsjoerg','Artur','Jan-Marc','Franziska','Marion','Julius','Felicitas','Christian','Anne-Kathrin','Mathilda']])
data_list.append([datetime.datetime(2021,9,5),2,"Old Town Hall","Regensburg","Germany","Geiselwind","Vienna","Old town of Regensburg with Stadtamhof",[]])
data_list.append([datetime.datetime(2021,9,5),22,"Dom","Regensburg","Germany","Geiselwind","Vienna","Old town of Regensburg with Stadtamhof",[]])
data_list.append([datetime.datetime(2021,9,5),1,"St Johann","Regensburg","Germany","Geiselwind","Vienna","Old town of Regensburg with Stadtamhof",[]])
data_list.append([datetime.datetime(2021,9,5),3,"Karmelitenkirche","Regensburg","Germany","Geiselwind","Vienna","Old town of Regensburg with Stadtamhof",[]])
data_list.append([datetime.datetime(2021,9,5),2,"Kollegiatstift unserer Lieben Frau zur alten Kapelle","Regensburg","Germany","Geiselwind","Vienna","Old town of Regensburg with Stadtamhof",[]])
data_list.append([datetime.datetime(2021,9,5),3,"St Ulrich","Regensburg","Germany","Geiselwind","Vienna","Old town of Regensburg with Stadtamhof",[]])
data_list.append([datetime.datetime(2021,9,5),4,"Niedermuenster","Regensburg","Germany","Geiselwind","Vienna","Old town of Regensburg with Stadtamhof",[]])
data_list.append([datetime.datetime(2021,9,5),3,"Porta Praetoria","Regensburg","Germany","Geiselwind","Vienna","Old town of Regensburg with Stadtamhof",[]])
data_list.append([datetime.datetime(2021,9,5),1,"Haidplatz","Regensburg","Germany","Geiselwind","Vienna","Old town of Regensburg with Stadtamhof",[]])
data_list.append([datetime.datetime(2021,9,5),2,"Dreieinigkeitskirche","Regensburg","Germany","Geiselwind","Vienna","Old town of Regensburg with Stadtamhof",[]])
data_list.append([datetime.datetime(2021,9,5),17,"Kloster St Emmeram","Regensburg","Germany","Geiselwind","Vienna","Old town of Regensburg with Stadtamhof",[]])
data_list.append([datetime.datetime(2021,9,5),4,"Schottenkirche","Regensburg","Germany","Geiselwind","Vienna","Old town of Regensburg with Stadtamhof",[]])
data_list.append([datetime.datetime(2021,9,5),1,"Herz-Jesu-Kirche","Regensburg","Germany","Geiselwind","Vienna","Old town of Regensburg with Stadtamhof",[]])
data_list.append([datetime.datetime(2021,9,5),1,"Steinerne Bruecke","Regensburg","Germany","Geiselwind","Vienna","Old town of Regensburg with Stadtamhof",[]])
data_list.append([datetime.datetime(2021,9,5),4,"Spitalkirche St Katharina","Regensburg","Germany","Geiselwind","Vienna","Old town of Regensburg with Stadtamhof",[]])
data_list.append([datetime.datetime(2021,9,5),7,"St Mang","Regensburg","Germany","Geiselwind","Vienna","Old town of Regensburg with Stadtamhof",[]])
data_list.append([datetime.datetime(2021,9,5),16,"Domschatzkammer","Regensburg","Germany","Geiselwind","Vienna","Old town of Regensburg with Stadtamhof",[]])
data_list.append([datetime.datetime(2021,9,5),6,"St Kassian","Regensburg","Germany","Geiselwind","Vienna","Old town of Regensburg with Stadtamhof",[]])
data_list.append([datetime.datetime(2021,9,5),32,"Dom","Passau","Germany","Geiselwind","Vienna","",[]])
data_list.append([datetime.datetime(2021,9,5),1,"Veste Oberhaus","Passau","Germany","Geiselwind","Vienna","",[]])
data_list.append([datetime.datetime(2021,9,5),3,"Jesuitenkolleg","Passau","Germany","Geiselwind","Vienna","",[]])
data_list.append([datetime.datetime(2021,9,5),1,"Votivkirche","Passau","Germany","Geiselwind","Vienna","",[]])
data_list.append([datetime.datetime(2021,9,5),1,"Matthaeuskirche","Passau","Germany","Geiselwind","Vienna","",[]])
data_list.append([datetime.datetime(2021,9,5),3,"Alte Residenz","Passau","Germany","Geiselwind","Vienna","",[]])
data_list.append([datetime.datetime(2021,9,5),1,"Residenzplatz","Passau","Germany","Geiselwind","Vienna","",[]])
data_list.append([datetime.datetime(2021,9,5),1,"Neue Residenz","Passau","Germany","Geiselwind","Vienna","",[]])
data_list.append([datetime.datetime(2021,9,5),1,"Michaelskirche","Passau","Germany","Geiselwind","Vienna","",[]])
data_list.append([datetime.datetime(2021,9,5),1,"Klosterkirche Niedernburg","Passau","Germany","Geiselwind","Vienna","",[]])
data_list.append([datetime.datetime(2021,9,5),2,"Veste Niederhaus","Passau","Germany","Geiselwind","Vienna","",[]])
data_list.append([datetime.datetime(2021,9,5),1,"Rathaus","Passau","Germany","Geiselwind","Vienna","",[]])
data_list.append([datetime.datetime(2021,9,5),4,"Stadtpfarrkirche St Paul","Passau","Germany","Geiselwind","Vienna","",[]])
data_list.append([datetime.datetime(2021,9,5),4,"Kloster Mariahilf","Passau","Germany","Geiselwind","Vienna","",[]])
data_list.append([datetime.datetime(2021,9,5),3,"Wallfahrtsstiege","Passau","Germany","Geiselwind","Vienna","",[]])
data_list.append([datetime.datetime(2021,9,5),1,"St Gertraud","Passau","Germany","Geiselwind","Vienna","",[]])
data_list.append([datetime.datetime(2021,9,5),1,"Peichterturm","Passau","Germany","Geiselwind","Vienna","",[]])
data_list.append([datetime.datetime(2021,9,5),1,"Severinstor","Passau","Germany","Geiselwind","Vienna","",[]])
data_list.append([datetime.datetime(2021, 9, 18),3,"Stausee Wienerbruck",'Annaberg bei Mariazell',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021, 9, 18),19,"Lassinggraben",'Annaberg bei Mariazell',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021, 9, 18),5,"Kienbachfall",'Annaberg bei Mariazell',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021, 9, 18),7,"Lassingfall",'Annaberg bei Mariazell',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021, 9, 18),1,"Speicherkraftwerk Wienerbruck",'Annaberg bei Mariazell',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021, 9, 18),106,"Oetschergraeben",'Mitterbach am Erlaufsee,',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021, 9, 18),2,"Muehlbachfall",'Mitterbach am Erlaufsee,',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021, 9, 18),4,"Oetscherfall",'Mitterbach am Erlaufsee,',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021, 9, 18),9,"Mirafall",'Mitterbach am Erlaufsee,',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021, 9, 18),6,"Schleierfall",'Mitterbach am Erlaufsee,',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021, 9, 18),39,"Basilika Mariazell",'Mariazell,',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021, 9, 18),1,"Michaelskapelle",'Mariazell,',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021, 9, 18),2,"Kerzengrotte",'Mariazell,',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021, 9, 18),5,"Erlaufstausee",'Mitterbach am Erlaufsee,',"Austria",'Vienna','Vienna',"",[]])

# %%
#23/9 to france trip
data_list.append([datetime.datetime(2021,9,23),4,"Hofbibliothek",'Vienna',"Austria",'Vienna','Vienna',"Vienna",['Vivan','Michael']])
data_list.append([datetime.datetime(2021,9,23),1,"Maria Theresia Monument",'Vienna',"Austria",'Vienna','Vienna',"Vienna",['Vivan','Michael']])
data_list.append([datetime.datetime(2021,9,23),1,"Rathaus",'Vienna',"Austria",'Vienna','Vienna',"Vienna",['Vivan','Michael']])
data_list.append([datetime.datetime(2021,9,23),10,"Kunsthistorisches Museum",'Vienna',"Austria",'Vienna','Vienna',"Vienna",['Vivan','Michael']])
data_list.append([datetime.datetime(2021,9,24),3,"Staatsoper",'Vienna',"Austria",'Vienna','Vienna',"Vienna",['Vivan','Michael']])
data_list.append([datetime.datetime(2021,9,24),1,"Erzherzog Albrecht Reiterdenkmal",'Vienna',"Austria",'Vienna','Vienna',"Vienna",['Vivan','Michael']])
#salzburg II 2021
data_list.append([datetime.datetime(2021,9,25),14,"Festung Hohensalzburg",'Salzburg',"Austria",'Vienna','Vienna',"Salzburg",['Michael','Vivan']])
data_list.append([datetime.datetime(2021,9,25),10,"Dom",'Salzburg',"Austria",'Vienna','Vienna',"Salzburg",['Michael','Vivan']])
data_list.append([datetime.datetime(2021,9,25),6,"Alte Residenz",'Salzburg',"Austria",'Vienna','Vienna',"Salzburg",['Michael','Vivan']])
data_list.append([datetime.datetime(2021,9,25),7,"Schloss Mirabell",'Salzburg',"Austria",'Vienna','Vienna',"Salzburg",['Michael','Vivan']])
data_list.append([datetime.datetime(2021,9,26),21,"Haus der Industrie",'Vienna',"Austria",'Vienna','Vienna',"Vienna",['Vivan']])
data_list.append([datetime.datetime(2021,9,26),3,"Franziskanerkirche",'Vienna',"Austria",'Vienna','Vienna',"Vienna",['Vivan']])
data_list.append([datetime.datetime(2021,9,26),1,"Jesuitenkirche",'Vienna',"Austria",'Vienna','Vienna',"Vienna",['Vivan']])
data_list.append([datetime.datetime(2021,9,26),33,"Akademie der Wissenschaften",'Vienna',"Austria",'Vienna','Vienna',"Vienna",['Vivan']])
data_list.append([datetime.datetime(2021,9,26),32,"Franzoesische Botschaft",'Vienna',"Austria",'Vienna','Vienna',"Vienna",['Vivan']])
data_list.append([datetime.datetime(2021,9,26),7,"Hofburgkapelle",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,9,26),62,"Palais Niederoesterreich",'Vienna',"Austria",'Vienna','Vienna',"Vienna",["Vivan",'Michael']])
data_list.append([datetime.datetime(2021,10,2),69,"Burgtheater",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,10,2),61,"Stadtpalais Liechtenstein",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,10,2),2,"Volksgarten",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,10,2),20,"Leopold Museum",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,10,2),8,"Schatzkammer des Deutschen Ordens",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,10,2),2,"Mozarthaus",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,10,2),10,"Kunst Haus Wien Museum Hundertwasser",'Vienna',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2021,10,8),1,"Kaiserliche Schatzkammer",'Vienna',"Austria",'Vienna','Vienna',"Vienna",['Angelika']])
data_list.append([datetime.datetime(2021,10,9),2,"Schloss Schoenbrunn",'Vienna',"Austria",'Vienna','Vienna',"Schoenbrunn Palace",[]])
data_list.append([datetime.datetime(2021,10,9),32,"Schlosspark Schoenbrunn",'Vienna',"Austria",'Vienna','Vienna',"Schoenbrunn Palace",[]])

# %%
#train trip 2021 complete
data_list.append([datetime.datetime(2021,10,22),4,"Stadtmauer mit Tuermen","Nuernberg","Germany","Vienna","Nuernberg","",[]])
data_list.append([datetime.datetime(2021,10,22),3,"Lorenzkirche","Nuernberg","Germany","Vienna","Nuernberg","",[]])
data_list.append([datetime.datetime(2021,10,22),11,"Kaiserburg","Nuernberg","Germany","Vienna","Nuernberg","",[]])
data_list.append([datetime.datetime(2021,10,22),2,"Frauenkirche","Nuernberg","Germany","Vienna","Nuernberg","",[]])
data_list.append([datetime.datetime(2021,10,22),5,"Schoener Brunnen","Nuernberg","Germany","Vienna","Nuernberg","",[]])
data_list.append([datetime.datetime(2021,10,22),3,"Sebalduskirche","Nuernberg","Germany","Vienna","Nuernberg","",[]])
data_list.append([datetime.datetime(2021,10,22),1,"Albrecht Duerer Haus","Nuernberg","Germany","Vienna","Nuernberg","",[]])
data_list.append([datetime.datetime(2021,10,22),1,"Fembohaus","Nuernberg","Germany","Vienna","Nuernberg","",[]])
data_list.append([datetime.datetime(2021,10,22),2,"Rathaus","Nuernberg","Germany","Vienna","Nuernberg","",[]])
data_list.append([datetime.datetime(2021,10,22),1,"Zeughaus","Nuernberg","Germany","Vienna","Nuernberg","",[]])
data_list.append([datetime.datetime(2021,10,23),12,"Stadtmauer mit Tuermen","Nuernberg","Germany","Nuernberg","Trier","",[]])
data_list.append([datetime.datetime(2021,10,23),54,"Lorenzkirche","Nuernberg","Germany","Nuernberg","Trier","",[]])
data_list.append([datetime.datetime(2021,10,23),2,"St Klara","Nuernberg","Germany","Nuernberg","Trier","",[]])
data_list.append([datetime.datetime(2021,10,23),49,"Kaiserburg","Nuernberg","Germany","Nuernberg","Trier","",[]])
data_list.append([datetime.datetime(2021,10,23),1,"Tugendbrunnen","Nuernberg","Germany","Nuernberg","Trier","",[]])
data_list.append([datetime.datetime(2021,10,23),1,"Narrenschiff","Nuernberg","Germany","Nuernberg","Trier","",[]])
data_list.append([datetime.datetime(2021,10,23),16,"Schoener Brunnen","Nuernberg","Germany","Nuernberg","Trier","",[]])
data_list.append([datetime.datetime(2021,10,23),8,"Frauenkirche","Nuernberg","Germany","Nuernberg","Trier","",[]])
data_list.append([datetime.datetime(2021,10,23),3,"Rathaus","Nuernberg","Germany","Nuernberg","Trier","",[]])
data_list.append([datetime.datetime(2021,10,23),37,"Sebalduskirche","Nuernberg","Germany","Nuernberg","Trier","",[]])
data_list.append([datetime.datetime(2021,10,23),29,"Fembohaus","Nuernberg","Germany","Nuernberg","Trier","",[]])
data_list.append([datetime.datetime(2021,10,23),5,"Egidienkirche","Nuernberg","Germany","Nuernberg","Trier","",[]])
data_list.append([datetime.datetime(2021,10,23),1,"Tucherschloss","Nuernberg","Germany","Nuernberg","Trier","",[]])
data_list.append([datetime.datetime(2021,10,23),4,"Ehekarussell","Nuernberg","Germany","Nuernberg","Trier","",[]])
data_list.append([datetime.datetime(2021,10,23),6,"Elisabethkirche","Nuernberg","Germany","Nuernberg","Trier","",[]])
data_list.append([datetime.datetime(2021,10,23),1,"Weisser Turm","Nuernberg","Germany","Nuernberg","Trier","",[]])
data_list.append([datetime.datetime(2021,10,23),4,"Jakobskirche","Nuernberg","Germany","Nuernberg","Trier","",[]])
data_list.append([datetime.datetime(2021,10,23),3,"Justizpalast Nuernberg","Nuernberg","Germany","Nuernberg","Trier","",[]])
data_list.append([datetime.datetime(2021,10,23),30,"Germanisches Nationalmuseum","Nuernberg","Germany","Nuernberg","Trier","",[]])
data_list.append([datetime.datetime(2021,10,23),1,"Hauptbahnhof","Nuernberg","Germany","Nuernberg","Trier","",[]])
data_list.append([datetime.datetime(2021,10,23),5,"Porta Nigra","Trier","Germany","Nuernberg","Trier","Roman Monuments, Cathedral of St Peter and Church of Our Lady in Trier",[]])
data_list.append([datetime.datetime(2021,10,23),1,"Dom","Trier","Germany","Nuernberg","Trier","Roman Monuments, Cathedral of St Peter and Church of Our Lady in Trier",[]])
data_list.append([datetime.datetime(2021,10,24),24,"Porta Nigra","Trier","Germany","Trier","Trier","Roman Monuments, Cathedral of St Peter and Church of Our Lady in Trier",[]])
data_list.append([datetime.datetime(2021,10,24),7,"Gare du Luxemburg","Luxembourg","Luxembourg","Trier","Trier","",[]])
data_list.append([datetime.datetime(2021,10,24),21,"Cathedral Notre-Dame","Luxembourg","Luxembourg","Trier","Trier","City of Luxembourg: its Old Quarters and Fortifications",[]])
data_list.append([datetime.datetime(2021,10,24),5,"Grand Ducal Palais","Luxembourg","Luxembourg","Trier","Trier","City of Luxembourg: its Old Quarters and Fortifications",[]])
data_list.append([datetime.datetime(2021,10,24),6,"Three Towers Gate","Luxembourg","Luxembourg","Trier","Trier","City of Luxembourg: its Old Quarters and Fortifications",[]])
data_list.append([datetime.datetime(2021,10,24),3,"Vauban Towers","Luxembourg","Luxembourg","Trier","Trier","",[]])
data_list.append([datetime.datetime(2021,10,24),2,"Citadelle du St Esprit","Luxembourg","Luxembourg","Trier","Trier","City of Luxembourg: its Old Quarters and Fortifications",[]])
data_list.append([datetime.datetime(2021,10,24),6,"Bock Casemates","Luxembourg","Luxembourg","Trier","Trier","City of Luxembourg: its Old Quarters and Fortifications",[]])
data_list.append([datetime.datetime(2021,10,24),2,"Rham Bastion","Luxembourg","Luxembourg","Trier","Trier","City of Luxembourg: its Old Quarters and Fortifications",[]])
data_list.append([datetime.datetime(2021,10,24),2,"Palais du Justice","Luxembourg","Luxembourg","Trier","Trier","City of Luxembourg: its Old Quarters and Fortifications",[]])
data_list.append([datetime.datetime(2021,10,24),2,"Simeonstift","Trier","Germany","Trier","Trier","Roman Monuments, Cathedral of St Peter and Church of Our Lady in Trier",[]])
data_list.append([datetime.datetime(2021,10,24),2,"St Gangolf","Trier","Germany","Trier","Trier","",[]])
data_list.append([datetime.datetime(2021,10,24),70,"Dom","Trier","Germany","Trier","Trier","Roman Monuments, Cathedral of St Peter and Church of Our Lady in Trier",[]])
data_list.append([datetime.datetime(2021,10,24),6,"Hauptmarkt","Trier","Germany","Trier","Trier","Roman Monuments, Cathedral of St Peter and Church of Our Lady in Trier",[]])
data_list.append([datetime.datetime(2021,10,24),4,"Marktbrunnen","Trier","Germany","Trier","Trier","Roman Monuments, Cathedral of St Peter and Church of Our Lady in Trier",[]])
data_list.append([datetime.datetime(2021,10,24),16,"Liebfrauenkirche","Trier","Germany","Trier","Trier","Roman Monuments, Cathedral of St Peter and Church of Our Lady in Trier",[]])
data_list.append([datetime.datetime(2021,10,24),25,"Museum am Dom","Trier","Germany","Trier","Trier","",[]])
data_list.append([datetime.datetime(2021,10,24),7,"Konstantinbasilika","Trier","Germany","Trier","Trier","Roman Monuments, Cathedral of St Peter and Church of Our Lady in Trier",[]])
data_list.append([datetime.datetime(2021,10,24),15,"Kurfuerstliches Palais","Trier","Germany","Trier","Trier","Roman Monuments, Cathedral of St Peter and Church of Our Lady in Trier",[]])
data_list.append([datetime.datetime(2021,10,24),8,"Palastgarten","Trier","Germany","Trier","Trier","",[]])
data_list.append([datetime.datetime(2021,10,24),25,"Rheinisches Landesmuseum","Trier","Germany","Trier","Trier","",[]])
data_list.append([datetime.datetime(2021,10,24),10,"Kaiserthermen","Trier","Germany","Trier","Trier","Roman Monuments, Cathedral of St Peter and Church of Our Lady in Trier",[]])
data_list.append([datetime.datetime(2021,10,24),9,"Amphitheater","Trier","Germany","Trier","Trier","Roman Monuments, Cathedral of St Peter and Church of Our Lady in Trier",[]])
data_list.append([datetime.datetime(2021,10,24),6,"Thermen am Viehmarkt","Trier","Germany","Trier","Trier","Roman Monuments, Cathedral of St Peter and Church of Our Lady in Trier",[]])
data_list.append([datetime.datetime(2021,10,24),2,"Barbarathermen","Trier","Germany","Trier","Trier","Roman Monuments, Cathedral of St Peter and Church of Our Lady in Trier",[]])
data_list.append([datetime.datetime(2021,10,24),2,"Roemerbruecke","Trier","Germany","Trier","Trier","Roman Monuments, Cathedral of St Peter and Church of Our Lady in Trier",[]])
data_list.append([datetime.datetime(2021,10,24),20,"Benediktinerabtei St Matthias","Trier","Germany","Trier","Trier","",[]])
data_list.append([datetime.datetime(2021,10,24),2,"Handwerkerbrunnen","Trier","Germany","Trier","Trier","",[]])
#all up to after Trier or before Metz finished
data_list.append([datetime.datetime(2021,10,25),2,"Gare","Metz","France","Trier","Metz","",[]])
data_list.append([datetime.datetime(2021,10,25),1,"Porte Serpenoise","Metz","France","Trier","Metz","",[]])
data_list.append([datetime.datetime(2021,10,25),2,"Palais du Gouverneur","Metz","France","Trier","Metz","",[]])
data_list.append([datetime.datetime(2021,10,25),2,"Basilique Saint-Pierre-aux-Nonnains","Metz","France","Trier","Metz","",[]])
data_list.append([datetime.datetime(2021,10,25),80,"Cathedral","Metz","France","Trier","Metz","",[]])
data_list.append([datetime.datetime(2021,10,25),2,"Garnisonskirche","Metz","France","Trier","Metz","",[]])
data_list.append([datetime.datetime(2021,10,25),3,"Temple Neuf","Metz","France","Trier","Metz","",[]])
data_list.append([datetime.datetime(2021,10,25),2,"Place St Louis","Metz","France","Trier","Metz","",[]])
data_list.append([datetime.datetime(2021,10,25),2,"St-Eucaire","Metz","France","Trier","Metz","",[]])
data_list.append([datetime.datetime(2021,10,25),12,"Porte des Allemands","Metz","France","Trier","Metz","",[]])
data_list.append([datetime.datetime(2021,10,25),3,"Water Tower","Metz","France","Trier","Metz","",[]])
data_list.append([datetime.datetime(2021,10,25),23,"Place Stanislas","Nancy","France","Trier","Metz","Place Stanislas, Place de la Carriere and Place d'Alliance in Nancy",[]])
data_list.append([datetime.datetime(2021,10,25),1,"Porte Stanislas","Nancy","France","Trier","Metz","",[]])
data_list.append([datetime.datetime(2021,10,25),2,"Place Carnot","Nancy","France","Trier","Metz","",[]])
data_list.append([datetime.datetime(2021,10,25),22,"Cathedral","Nancy","France","Trier","Metz","",[]])
data_list.append([datetime.datetime(2021,10,25),18,"Place de la Carriere","Nancy","France","Trier","Metz","Place Stanislas, Place de la Carriere and Place d'Alliance in Nancy",[]])
data_list.append([datetime.datetime(2021,10,25),2,"Basilique St-Epvre","Nancy","France","Trier","Metz","",[]])
data_list.append([datetime.datetime(2021,10,25),5,"Palais Des Ducs De Lorraine","Nancy","France","Trier","Metz","",[]])
data_list.append([datetime.datetime(2021,10,25),4,"Porte de la Craffe","Nancy","France","Trier","Metz","",[]])
data_list.append([datetime.datetime(2021,10,25),2,"Porte de la Citaadelle","Nancy","France","Trier","Metz","",[]])
data_list.append([datetime.datetime(2021,10,25),2,"Hotel Ferrari","Nancy","France","Trier","Metz","",[]])
data_list.append([datetime.datetime(2021,10,25),2,"St Sebastien","Nancy","France","Trier","Metz","",[]])
data_list.append([datetime.datetime(2021,10,25),2,"Porte St-Nicolas","Nancy","France","Trier","Metz","",[]])
data_list.append([datetime.datetime(2021,10,25),3,"St-Pierre","Nancy","France","Trier","Metz","",[]])
data_list.append([datetime.datetime(2021,10,26),3,"Gare de l'Est","Paris","France","Metz","Paris","",[]])
data_list.append([datetime.datetime(2021,10,26),3,"St-Laurent","Paris","France","Metz","Paris","",[]])
data_list.append([datetime.datetime(2021,10,26),4,"Gare du Nord","Paris","France","Metz","Paris","",[]])
data_list.append([datetime.datetime(2021,10,26),1,"Place Napoleon III","Paris","France","Metz","Paris","",[]])
data_list.append([datetime.datetime(2021,10,26),15,"La Madelaine","Paris","France","Metz","Paris","Paris, Banks of the Seine",[]])
data_list.append([datetime.datetime(2021,10,26),2,"Palais Bourbon","Paris","France","Metz","Paris","Paris, Banks of the Seine",[]])
data_list.append([datetime.datetime(2021,10,26),1,"Hotel de la Marine","Paris","France","Metz","Paris","Paris, Banks of the Seine",[]])
data_list.append([datetime.datetime(2021,10,26),11,"Place de la Concorde","Paris","France","Metz","Paris","Paris, Banks of the Seine",[]])
data_list.append([datetime.datetime(2021,10,26),56,"Musee d'Orsay","Paris","France","Metz","Paris","Paris, Banks of the Seine",[]])
data_list.append([datetime.datetime(2021,10,26),6,"Tour Eiffel","Paris","France","Metz","Paris","Paris, Banks of the Seine",[]])
data_list.append([datetime.datetime(2021,10,26),2,"Hotel de Salm","Paris","France","Metz","Paris","",[]])
data_list.append([datetime.datetime(2021,10,26),22,"Hotel Biron","Paris","France","Metz","Paris","",[]])
data_list.append([datetime.datetime(2021,10,26),6,"Hotel Biron Gardens","Paris","France","Metz","Paris","",[]])
data_list.append([datetime.datetime(2021,10,26),71,"Hotel d'Invalides",'Paris',"France",'Metz','Paris',"Paris, Banks of the Seine",[]])
data_list.append([datetime.datetime(2021,10,26),3,"Grand Palais",'Paris',"France",'Metz','Paris',"Paris, Banks of the Seine",[]])
data_list.append([datetime.datetime(2021,10,26),10,"Pont Alexandre III",'Paris',"France",'Metz','Paris',"Paris, Banks of the Seine",[]])
data_list.append([datetime.datetime(2021,10,26),35,"Petit Palais",'Paris',"France",'Metz','Paris',"Paris, Banks of the Seine",[]])
data_list.append([datetime.datetime(2021,10,26),1,"Fontaine George Cuvier","Paris","France","Metz","Paris","",[]])
data_list.append([datetime.datetime(2021,10,26),1,"Place du Pantheon","Paris","France","Metz","Paris","",[]])
data_list.append([datetime.datetime(2021,10,26),23,"Pantheon","Paris","France","Metz","Paris","",[]])
data_list.append([datetime.datetime(2021,10,26),1,"Hotel de la Marine","Paris","France","Metz","Paris","",[]])
data_list.append([datetime.datetime(2021,10,26),51,"Opera Garnier","Paris","France","Metz","Paris","",[]])
data_list.append([datetime.datetime(2021,10,26),25,"Musee des Arts Decoratifs ",'Paris',"France",'Metz','Paris',"Paris, Banks of the Seine",[]])
data_list.append([datetime.datetime(2021,10,26),13,"Catacombs","Paris","France","Metz","Paris","",[]])
data_list.append([datetime.datetime(2021,10,26),6,"Arc de Triomphe",'Paris',"France",'Metz','Paris',"",[]])
data_list.append([datetime.datetime(2021,10,26),8,"Arc de Triomphe Terrace",'Paris',"France",'Metz','Paris',"",[]])
data_list.append([datetime.datetime(2021,10,27),235,"Louvre",'Paris',"France",'Paris','Paris',"",[]])
data_list.append([datetime.datetime(2021,10,27),3,"Arc du Carrousel",'Paris',"France",'Paris','Paris',"Paris, Banks of the Seine",[]])
data_list.append([datetime.datetime(2021,10,27),38,"Hotel Camondo",'Paris',"France",'Paris','Paris',"",[]])
data_list.append([datetime.datetime(2021,10,27),92,"Basilique de St Denis",'St Denis',"France",'Paris','Paris',"",[]])
data_list.append([datetime.datetime(2021,10,27),3,"Tour St Jacques",'Paris',"France",'Paris','Paris',"Routes of Santiago de Compostela",[]])
data_list.append([datetime.datetime(2021,10,27),1,"Place du Chatelet",'Paris',"France",'Paris','Paris',"Paris, Banks of the Seine",[]])
data_list.append([datetime.datetime(2021,10,27),73,"Sainte Chapelle",'Paris',"France",'Paris','Paris',"Paris, Banks of the Seine",[]])
data_list.append([datetime.datetime(2021,10,27),1,"Notre Dame",'Paris',"France",'Paris','Paris',"Paris, Banks of the Seine",[]])
data_list.append([datetime.datetime(2021,10,27),1,"Palais de Justice",'Paris',"France",'Paris','Paris',"Paris, Banks of the Seine",[]])
data_list.append([datetime.datetime(2021,10,27),1,"Fontaine St Michel",'Paris',"France",'Paris','Paris',"",[]])
data_list.append([datetime.datetime(2021,10,27),12,"St Germain des Pres",'Paris',"France",'Paris','Paris',"",[]])
data_list.append([datetime.datetime(2021,10,27),1,"Square Felix Desruelles",'Paris',"France",'Paris','Paris',"",[]])
data_list.append([datetime.datetime(2021,10,27),51,"Hotel de la Marine",'Paris',"France",'Paris','Paris',"",[]])
data_list.append([datetime.datetime(2021,10,27),1,"Grand Palais",'Paris',"France",'Paris','Paris',"Paris, Banks of the Seine",[]])
data_list.append([datetime.datetime(2021,10,27),2,"Jardin des Tuileries",'Paris',"France",'Paris','Paris',"Paris, Banks of the Seine",[]])
data_list.append([datetime.datetime(2021,10,27),2,"Place de la Concorde",'Paris',"France",'Paris','Paris',"Paris, Banks of the Seine",[]])
data_list.append([datetime.datetime(2021,10,27),3,"Saint-Germain-l'Auxerrois",'Paris',"France",'Paris','Paris',"Paris, Banks of the Seine",[]])
data_list.append([datetime.datetime(2021,10,27),7,"St Eustache",'Paris',"France",'Paris','Paris',"",[]])
data_list.append([datetime.datetime(2021,10,27),1,"Bourse de Commerce",'Paris',"France",'Paris','Paris',"",[]])
data_list.append([datetime.datetime(2021,10,27),11,"Centre Pompidou",'Paris',"France",'Paris','Paris',"",[]])
data_list.append([datetime.datetime(2021,10,27),4,"Tour Eiffel",'Paris',"France",'Paris','Paris',"Paris, Banks of the Seine",[]])
data_list.append([datetime.datetime(2021,10,27),1,"Hotel de Ville",'Paris',"France",'Paris','Paris',"Paris, Banks of the Seine",[]])
data_list.append([datetime.datetime(2021,10,28),3,"Gare Lille-Flanders",'Lille',"France",'Paris','Paris',"",[]])
data_list.append([datetime.datetime(2021,10,28),56,"Cathedral",'Tournai',"Belgium",'Paris','Paris',"Notre-Dame Cathedral in Tournai",[]])
data_list.append([datetime.datetime(2021,10,28),3,"Belfry",'Tournai',"Belgium",'Paris','Paris',"Belfries of Belgium and France",[]])
data_list.append([datetime.datetime(2021,10,28),4,"Grand Place",'Tournai',"Belgium",'Paris','Paris',"",[]])
data_list.append([datetime.datetime(2021,10,28),7,"Hotel de Ville",'Lille',"France",'Paris','Paris',"Belfries of Belgium and France",[]])
data_list.append([datetime.datetime(2021,10,28),2,"Porte de Paris",'Lille',"France",'Paris','Paris',"",[]])
data_list.append([datetime.datetime(2021,10,28),1,"Place Simon Vollant",'Lille',"France",'Paris','Paris',"",[]])
data_list.append([datetime.datetime(2021,10,28),1,"Place de la Gare",'Lille',"France",'Paris','Paris',"",[]])
data_list.append([datetime.datetime(2021,10,28),22,"Fosse No 9-9 bis",'Oignies',"France",'Paris','Paris',"Nord-Pas de Calais Mining Basin",[]])
data_list.append([datetime.datetime(2021,10,28),13,"Terrils",'Oignies',"France",'Paris','Paris',"Nord-Pas de Calais Mining Basin",[]])
data_list.append([datetime.datetime(2021,10,28),4,"St-Jean-Baptiste",'Arras',"France",'Paris','Paris',"",[]])
data_list.append([datetime.datetime(2021,10,28),6,"Place des Heros",'Arras',"France",'Paris','Paris',"",[]])
data_list.append([datetime.datetime(2021,10,28),2,"Grand Place",'Arras',"France",'Paris','Paris',"",[]])
data_list.append([datetime.datetime(2021,10,28),10,"Hotel de Ville",'Arras',"France",'Paris','Paris',"Belfries of Belgium and France",[]])
data_list.append([datetime.datetime(2021,10,28),4,"Cathedral",'Arras',"France",'Paris','Paris',"",[]])
data_list.append([datetime.datetime(2021,10,28),2,"Place Victor Hugo",'Arras',"France",'Paris','Paris',"",[]])
data_list.append([datetime.datetime(2021,10,28),31,"Citadel",'Arras',"France",'Paris','Paris',"Fortifications of Vauban",[]])
data_list.append([datetime.datetime(2021,10,28),1,"Gare du Nord",'Paris',"France",'Paris','Paris',"",[]])
data_list.append([datetime.datetime(2021,10,29),114,"Cathedral",'Aachen',"Germany",'Paris','Frankfurt',"Aachen Cathedral",[]])
data_list.append([datetime.datetime(2021,10,29),1,"St Foillan",'Aachen',"Germany",'Paris','Frankfurt',"",[]])
data_list.append([datetime.datetime(2021,10,29),21,"City Hall",'Aachen',"Germany",'Paris','Frankfurt',"",[]])
data_list.append([datetime.datetime(2021,10,29),30,"Cathedral Treasury",'Aachen',"Germany",'Paris','Frankfurt',"",[]])
data_list.append([datetime.datetime(2021,10,29),2,"Marschiertor",'Aachen',"Germany",'Paris','Frankfurt',"",[]])
data_list.append([datetime.datetime(2021,10,29),172,"Dom",'Cologne',"Germany",'Paris','Frankfurt',"Cologne Cathedral",[]])
data_list.append([datetime.datetime(2021,10,29),26,"Cathedral Treasury",'Cologne',"Germany",'Paris','Frankfurt',"Cologne Cathedral",[]])
data_list.append([datetime.datetime(2021,10,29),1,"Antoninerkirche",'Cologne',"Germany",'Paris','Frankfurt',"",[]])
data_list.append([datetime.datetime(2021,10,29),2,"Alt St Alban",'Cologne',"Germany",'Paris','Frankfurt',"",[]])
data_list.append([datetime.datetime(2021,10,29),2,"Guerzenich",'Cologne',"Germany",'Paris','Frankfurt',"",[]])
data_list.append([datetime.datetime(2021,10,29),1,"Roman Sewage Canal",'Cologne',"Germany",'Paris','Frankfurt',"Frontiers of the Roman Empire",[]])
data_list.append([datetime.datetime(2021,10,29),2,"Roman Northern Gate",'Cologne',"Germany",'Paris','Frankfurt',"",[]])
data_list.append([datetime.datetime(2021,10,29),1,"Gross St Martin",'Cologne',"Germany",'Paris','Frankfurt',"",[]])
data_list.append([datetime.datetime(2021,10,29),4,"Rathaus",'Cologne',"Germany",'Paris','Frankfurt',"",[]])
data_list.append([datetime.datetime(2021,10,29),2,"Hohenzollerndenkmal",'Cologne',"Germany",'Paris','Frankfurt',"",[]])
data_list.append([datetime.datetime(2021,10,29),5,"Hohenzollernbruecke",'Cologne',"Germany",'Paris','Frankfurt',"",[]])
data_list.append([datetime.datetime(2021,10,29),1,"Commerzbank Tower",'Frankfurt',"Germany",'Paris','Frankfurt',"",[]])
data_list.append([datetime.datetime(2021,10,30),1,"Hauptbahnhhof",'Mannheim',"Germany",'Frankfurt','Frankfurt',"",[]])
data_list.append([datetime.datetime(2021,10,30),68,"Dom",'Speyer',"Germany",'Frankfurt','Frankfurt',"Speyer Cathedral",[]])
data_list.append([datetime.datetime(2021,10,30),3,"Oelberg",'Speyer',"Germany",'Frankfurt','Frankfurt',"",[]])
data_list.append([datetime.datetime(2021,10,30),1,"Heidentuermchen",'Speyer',"Germany",'Frankfurt','Frankfurt',"",[]])
data_list.append([datetime.datetime(2021,10,30),19,"mittelalterlicher Judenhof",'Speyer',"Germany",'Frankfurt','Frankfurt',"ShUM Sites of Speyer, Worms and Mainz",[]])
data_list.append([datetime.datetime(2021,10,30),2,"Dreifaltigkeitskirche",'Speyer',"Germany",'Frankfurt','Frankfurt',"",[]])
data_list.append([datetime.datetime(2021,10,30),1,"Lutherdenkmal",'Worms',"Germany",'Frankfurt','Frankfurt',"",[]])
data_list.append([datetime.datetime(2021,10,30),44,"Cathedral",'Worms',"Germany",'Frankfurt','Frankfurt',"",[]])
data_list.append([datetime.datetime(2021,10,30),1,"Hauptbahnhof",'Worms',"Germany",'Frankfurt','Frankfurt',"",[]])
data_list.append([datetime.datetime(2021,10,30),4,"Hauptbahnhof",'Darmstadt',"Germany",'Frankfurt','Frankfurt',"",[]])
data_list.append([datetime.datetime(2021,10,30),8,"Residenzschloss",'Darmstadt',"Germany",'Frankfurt','Frankfurt',"",[]])
data_list.append([datetime.datetime(2021,10,30),31,"Mathildenhoehe",'Darmstadt',"Germany",'Frankfurt','Frankfurt',"",[]])
data_list.append([datetime.datetime(2021,10,30),16,"Hochzeitsturm",'Darmstadt',"Germany",'Frankfurt','Frankfurt',"Mathildenhoehe Darmstadt",[]])
data_list.append([datetime.datetime(2021,10,30),1,"Gutenberg-Denkmal",'Frankfurt',"Germany",'Frankfurt','Frankfurt',"",[]])
data_list.append([datetime.datetime(2021,10,30),1,"Hauptwache",'Frankfurt',"Germany",'Frankfurt','Frankfurt',"",[]])
data_list.append([datetime.datetime(2021,10,30),1,"Commerzbank Tower",'Frankfurt',"Germany",'Frankfurt','Frankfurt',"",[]])
data_list.append([datetime.datetime(2021,10,30),11,"Galeria Frankfurt Zeil Dachterrasse",'Frankfurt',"Germany",'Frankfurt','Frankfurt',"",[]])
data_list.append([datetime.datetime(2021,10,31),2,"Burg Pfalzgrafenstein",'Kaub',"Germany",'Frankfurt','Frankfurt',"Upper Middle Rhine Valley",[]])
data_list.append([datetime.datetime(2021,10,31),49,"Marksburg",'Braubach',"Germany",'Frankfurt','Frankfurt',"Upper Middle Rhine Valley",[]])
data_list.append([datetime.datetime(2021,10,31),4,"Schloss Philippsburg",'Braubach',"Germany",'Frankfurt','Frankfurt',"Upper Middle Rhine Valley",[]])
data_list.append([datetime.datetime(2021,10,31),1,"Marktplatz",'Braubach',"Germany",'Frankfurt','Frankfurt',"Upper Middle Rhine Valley",[]])
data_list.append([datetime.datetime(2021,10,31),15,"Muenster",'Essen',"Germany",'Frankfurt','Frankfurt',"",[]])
data_list.append([datetime.datetime(2021,10,31),27,"Cathedral Treasury",'Essen',"Germany",'Frankfurt','Frankfurt',"",[]])
data_list.append([datetime.datetime(2021,10,31),2,"Alte Synagoge",'Essen',"Germany",'Frankfurt','Frankfurt',"",[]])
data_list.append([datetime.datetime(2021,10,31),33,"Zeche Zollverein",'Essen',"Germany",'Frankfurt','Frankfurt',"Zeche Zollverein",[]])
data_list.append([datetime.datetime(2021,11,1),41,"Schlosspark Schoenbrunn",'Vienna',"Austria",'Vienna','Vienna',"Schoenbrunn Palace",[]])
data_list.append([datetime.datetime(2021,12,12),8,"Stephansdom",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,12,12),19,"Maria am Gestade",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,12,12),1,"Minoritenkirche",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,12,12),2,"Weltmuseum",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,12,12),1,"Museum fuer Musikinstrumente",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2021,12,31),3,"Lauffen-Wasserfall",'Lauchringen',"Germany",'Lauchringen','Lauchringen',"",['Hannsjoerg']])

# %%
data_list.append([datetime.datetime(2022,1,2),2,"Hohentwiel",'Singen',"Germany",'Lauchringen','Vienna',"",[]])
data_list.append([datetime.datetime(2022,1,30),41,"Unteres Belvedere",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2022,1,30),1,"Salesianerinnenkirche",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2022,1,30),1,"Gardekirche",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2022,1,30),18,"Kunsthistorisches Museum",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2022,1,30),3,"Kaiserliche Schatzkammer",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2022,1,30),3,"Stephansdom",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2022,2,13),1,"Votivkirche",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2022,2,13),8,"Dreifaltigkeitskirche Alser Vorstadt",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2022,2,13),3,"Rathaus",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2022,2,13),27,"Kunsthistorisches Museum",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2022,2,13),1,"Hofburg",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2022,2,13),2,"Stephansdom",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2022,2,18),6,"Ruprechtskirche",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2022,2,18),1,"Basiliskenhaus",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2022,2,18),1,"Dominikanerkirche",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2022,2,18),43,"Unteres Belvedere",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2022,2,18),5,"Oberes Belvedere",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2022,2,18),6,"Schloss Schoenbrunn",'Vienna',"Austria",'Vienna','Vienna',"Schoenbrunn Palace",[]])
data_list.append([datetime.datetime(2022,2,18),2,"Burgtheater",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2022,2,18),3,"Rathaus",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2022,2,18),3,"Nationalbank",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2022,2,18),1,"Universitaet",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2022,2,19),4,"Ankeruhr",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2022,2,19),2,"Vermaehlungsbrunnen",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2022,2,19),4,"Maria am Gestade",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2022,2,19),2,"Palais Daun-Kinsky",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2022,2,19),2,"Universitaet",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2022,2,19),27,"Votivkirche",'Vienna',"Austria",'Vienna','Vienna',"Vienna",[]])
data_list.append([datetime.datetime(2022,2,20),18,"Servitenkirche",'Vienna',"Austria",'Vienna','Vienna',"",[]])
data_list.append([datetime.datetime(2022,2,20),4,"Lazaristenkirche",'Vienna',"Austria",'Vienna','Vienna',"",[]])

# %%
#spain done
data_list.append([datetime.datetime(2022, 3, 19),1,"Airport",'Madrid',"Spain",'Vienna','Malaga',"",[]])
data_list.append([datetime.datetime(2022, 3, 19),1,"Hotel Mediodia",'Madrid',"Spain",'Vienna','Malaga',"Paseo del Prado and Buen Retiro, a landscape of Arts and Sciences",[]])
data_list.append([datetime.datetime(2022, 3, 19),2,"Palacio de Linares",'Madrid',"Spain",'Vienna','Malaga',"Paseo del Prado and Buen Retiro, a landscape of Arts and Sciences",[]])
data_list.append([datetime.datetime(2022, 3, 19),5,"Station Madrid Atocha",'Madrid',"Spain",'Vienna','Malaga',"Paseo del Prado and Buen Retiro, a landscape of Arts and Sciences",[]])
data_list.append([datetime.datetime(2022, 3, 19),48,"El Retiro Park",'Madrid',"Spain",'Vienna','Malaga',"Paseo del Prado and Buen Retiro, a landscape of Arts and Sciences",[]])
data_list.append([datetime.datetime(2022, 3, 19),2,"Neptune Fountain",'Madrid',"Spain",'Vienna','Malaga',"Paseo del Prado and Buen Retiro, a landscape of Arts and Sciences",[]])
data_list.append([datetime.datetime(2022, 3, 19),11,"San Jeronimo el Real",'Madrid',"Spain",'Vienna','Malaga',"Paseo del Prado and Buen Retiro, a landscape of Arts and Sciences",[]])
data_list.append([datetime.datetime(2022, 3, 19),4,"Palacio de Cibeles",'Madrid',"Spain",'Vienna','Malaga',"Paseo del Prado and Buen Retiro, a landscape of Arts and Sciences",[]])
data_list.append([datetime.datetime(2022, 3, 19),3,"Plaza de Cibeles with Cibeles Fountain",'Madrid',"Spain",'Vienna','Malaga',"Paseo del Prado and Buen Retiro, a landscape of Arts and Sciences",[]])
data_list.append([datetime.datetime(2022, 3, 19),1,"Puerta de Alcala",'Madrid',"Spain",'Vienna','Malaga',"Paseo del Prado and Buen Retiro, a landscape of Arts and Sciences",[]])
data_list.append([datetime.datetime(2022, 3, 19),3,"San Manuel & San Benito",'Madrid',"Spain",'Vienna','Malaga',"Paseo del Prado and Buen Retiro, a landscape of Arts and Sciences",[]])
data_list.append([datetime.datetime(2022, 3, 19),1,"Cason del Buen Retiro",'Madrid',"Spain",'Vienna','Malaga',"Paseo del Prado and Buen Retiro, a landscape of Arts and Sciences",[]])
data_list.append([datetime.datetime(2022, 3, 19),1,"Museo del Prado",'Madrid',"Spain",'Vienna','Malaga',"Paseo del Prado and Buen Retiro, a landscape of Arts and Sciences",[]])
data_list.append([datetime.datetime(2022, 3, 19),6,"Botanical Gardens",'Madrid',"Spain",'Vienna','Malaga',"Paseo del Prado and Buen Retiro, a landscape of Arts and Sciences",[]])
data_list.append([datetime.datetime(2022, 3, 19),9,"Cathedral",'Malaga',"Spain",'Vienna','Malaga',"",[]])
data_list.append([datetime.datetime(2022, 3, 19),6,"Alcazaba",'Malaga',"Spain",'Vienna','Malaga',"",[]])
data_list.append([datetime.datetime(2022, 3, 19),1,"Roman Theatre",'Malaga',"Spain",'Vienna','Malaga',"",[]])
data_list.append([datetime.datetime(2022, 3, 20),54,"Cathedral",'Malaga',"Spain",'Malaga','Malaga',"",[]])
data_list.append([datetime.datetime(2022, 3, 20),54,"Alcazaba",'Malaga',"Spain",'Malaga','Malaga',"",[]])
data_list.append([datetime.datetime(2022, 3, 20),5,"Roman Theatre",'Malaga',"Spain",'Malaga','Malaga',"",[]])
data_list.append([datetime.datetime(2022, 3, 20),23,"Picasso Museum",'Malaga',"Spain",'Malaga','Malaga',"",[]])
data_list.append([datetime.datetime(2022, 3, 20),52,"Malaga Museum",'Malaga',"Spain",'Malaga','Malaga',"",[]])
data_list.append([datetime.datetime(2022, 3, 20),10,"Sea Life Museum",'Malaga',"Spain",'Malaga','Malaga',"",[]])
data_list.append([datetime.datetime(2022, 3, 20),5,"Museo Carmen Thyssen",'Malaga',"Spain",'Malaga','Malaga',"",[]])
data_list.append([datetime.datetime(2022, 3, 21),1,"Eagle Aqueduct",'Maro',"Spain",'Malaga','Granada',"",[]])
data_list.append([datetime.datetime(2022, 3, 21),76,"Cueva de Nerja",'Maro',"Spain",'Malaga','Granada',"",[]])
data_list.append([datetime.datetime(2022, 3, 21),3,"Station Malaga Maria Zambrano",'Malaga',"Spain",'Malaga','Granada',"",[]])
data_list.append([datetime.datetime(2022, 3, 21),62,"San Juan de Dios",'Granada',"Spain",'Malaga','Granada',"",[]])
data_list.append([datetime.datetime(2022, 3, 21),4,"Sanctuary of Our Lady of Eternal Help",'Granada',"Spain",'Malaga','Granada',"",[]])
data_list.append([datetime.datetime(2022, 3, 21),1,"Monastery San Jeronimo",'Granada',"Spain",'Malaga','Granada',"",[]])
data_list.append([datetime.datetime(2022, 3, 21),1,"San Anton",'Granada',"Spain",'Malaga','Granada',"",[]])
data_list.append([datetime.datetime(2022, 3, 21),11,"Basilica of our Lady of Sorrows",'Granada',"Spain",'Malaga','Granada',"",[]])
data_list.append([datetime.datetime(2022, 3, 21),4,"Monastery San Gregorio Betico",'Granada',"Spain",'Malaga','Granada',"",[]])
data_list.append([datetime.datetime(2022, 3, 21),4,"San Nicolas",'Granada',"Spain",'Malaga','Granada',"Alhambra, Generalife and Albayzin, Granada",[]])
data_list.append([datetime.datetime(2022, 3, 21),1,"Generalife",'Granada',"Spain",'Malaga','Granada',"Alhambra, Generalife and Albayzin, Granada",[]])
data_list.append([datetime.datetime(2022, 3, 21),6,"Alhambra",'Granada',"Spain",'Malaga','Granada',"Alhambra, Generalife and Albayzin, Granada",[]])
data_list.append([datetime.datetime(2022, 3, 21),3,"City Walls and Gates",'Granada',"Spain",'Malaga','Granada',"Alhambra, Generalife and Albayzin, Granada",[]])
data_list.append([datetime.datetime(2022, 3, 21),5,"Cathedral",'Granada',"Spain",'Malaga','Granada',"",[]])
data_list.append([datetime.datetime(2022, 3, 21),10,"El Sagrario",'Granada',"Spain",'Malaga','Granada',"",[]])
data_list.append([datetime.datetime(2022, 3, 21),2,"Capilla Real",'Granada',"Spain",'Malaga','Granada',"",[]])
data_list.append([datetime.datetime(2022, 3, 21),1,"Palacio de la Madraza",'Granada',"Spain",'Malaga','Granada',"",[]])
data_list.append([datetime.datetime(2022, 3, 22),56,"Cathedral",'Granada',"Spain",'Granada','Granada',"",[]])
data_list.append([datetime.datetime(2022, 3, 22),8,"El Sagrario",'Granada',"Spain",'Granada','Granada',"",[]])
data_list.append([datetime.datetime(2022, 3, 22),10,"Capilla Real",'Granada',"Spain",'Granada','Granada',"",[]])
data_list.append([datetime.datetime(2022, 3, 22),8,"Palacio de la Madraza",'Granada',"Spain",'Granada','Granada',"",[]])
data_list.append([datetime.datetime(2022, 3, 22),8,"City Walls and Gates",'Granada',"Spain",'Granada','Granada',"Alhambra, Generalife and Albayzin, Granada",[]])
data_list.append([datetime.datetime(2022, 3, 22),1,"Heart of Jesus Church",'Granada',"Spain",'Granada','Granada',"",[]])
data_list.append([datetime.datetime(2022, 3, 22),1,"San Nicolas",'Granada',"Spain",'Granada','Granada',"Alhambra, Generalife and Albayzin, Granada",[]])
data_list.append([datetime.datetime(2022, 3, 22),34,"Generalife",'Granada',"Spain",'Granada','Granada',"Alhambra, Generalife and Albayzin, Granada",[]])
data_list.append([datetime.datetime(2022, 3, 22),178,"Alhambra",'Granada',"Spain",'Granada','Granada',"Alhambra, Generalife and Albayzin, Granada",[]])
data_list.append([datetime.datetime(2022, 3, 22),4,"San Pietro y San Pablo",'Granada',"Spain",'Granada','Granada',"Alhambra, Generalife and Albayzin, Granada",[]])
data_list.append([datetime.datetime(2022, 3, 22),2,"Casa de Castril",'Granada',"Spain",'Granada','Granada',"Alhambra, Generalife and Albayzin, Granada",[]])
data_list.append([datetime.datetime(2022, 3, 22),5,"Casa de Zafra",'Granada',"Spain",'Granada','Granada',"Alhambra, Generalife and Albayzin, Granada",[]])
data_list.append([datetime.datetime(2022, 3, 22),8,"El Banuelo",'Granada',"Spain",'Granada','Granada',"Alhambra, Generalife and Albayzin, Granada",[]])
data_list.append([datetime.datetime(2022, 3, 22),4,"Casa de Horno",'Granada',"Spain",'Granada','Granada',"Alhambra, Generalife and Albayzin, Granada",[]])
data_list.append([datetime.datetime(2022, 3, 22),4,"Casa del Chapiz",'Granada',"Spain",'Granada','Granada',"Alhambra, Generalife and Albayzin, Granada",[]])
data_list.append([datetime.datetime(2022, 3, 22),8,"Palacio Dar al-Horra",'Granada',"Spain",'Granada','Granada',"Alhambra, Generalife and Albayzin, Granada",[]])
data_list.append([datetime.datetime(2022, 3, 22),1,"San Juan de Dios",'Granada',"Spain",'Granada','Granada',"",[]])
data_list.append([datetime.datetime(2022, 3, 22),32,"Monastery San Jeronimo",'Granada',"Spain",'Granada','Granada',"",[]])
data_list.append([datetime.datetime(2022, 3, 22),2,"Corral del Carbon",'Granada',"Spain",'Granada','Granada',"",[]])
data_list.append([datetime.datetime(2022, 3, 22),50,"Cartuja de Granada",'Granada',"Spain",'Granada','Granada',"",[]])
data_list.append([datetime.datetime(2022, 3, 22),7,"Cuarto Real de Santo Domingo",'Granada',"Spain",'Granada','Granada',"",[]])
data_list.append([datetime.datetime(2022, 3, 23),89,"Cathedral",'Jaen',"Spain",'Granada','Granada',"",[]])
data_list.append([datetime.datetime(2022, 3, 23),7,"Hospital de Santiago",'Ubeda',"Spain",'Granada','Granada',"",[]])
data_list.append([datetime.datetime(2022, 3, 23),4,"San Isidoro",'Ubeda',"Spain",'Granada','Granada',"",[]])
data_list.append([datetime.datetime(2022, 3, 23),13,"San Pablo",'Ubeda',"Spain",'Granada','Granada',"",[]])
data_list.append([datetime.datetime(2022, 3, 23),10,"Sinagoga del Agua",'Ubeda',"Spain",'Granada','Granada',"",[]])
data_list.append([datetime.datetime(2022, 3, 23),22,"Monastery San Miguel",'Ubeda',"Spain",'Granada','Granada',"",[]])
data_list.append([datetime.datetime(2022, 3, 23),56,"Capilla San Salvador",'Ubeda',"Spain",'Granada','Granada',"Ubeda & Baeza",[]])
data_list.append([datetime.datetime(2022, 3, 23),32,"Basilica de Santa Maria de los Reales Alcazares",'Ubeda',"Spain",'Granada','Granada',"Ubeda & Baeza",[]])
data_list.append([datetime.datetime(2022, 3, 23),5,"City Walls and Gates",'Ubeda',"Spain",'Granada','Granada',"",[]])
data_list.append([datetime.datetime(2022, 3, 23),5,"San Lorenzo",'Ubeda',"Spain",'Granada','Granada',"",[]])
data_list.append([datetime.datetime(2022, 3, 23),12,"San Ildefonso",'Jaen',"Spain",'Granada','Granada',"",[]])
data_list.append([datetime.datetime(2022, 3, 23),3,"Santa Maria Magdalene",'Jaen',"Spain",'Granada','Granada',"",[]])
data_list.append([datetime.datetime(2022, 3, 23),1,"Monastery Santa Ursula",'Jaen',"Spain",'Granada','Granada',"",[]])
data_list.append([datetime.datetime(2022, 3, 23),6,"Arabic Baths",'Jaen',"Spain",'Granada','Granada',"",[]])
data_list.append([datetime.datetime(2022, 3, 24),7,"San Miguel",'Cordoba',"Spain",'Granada','Cordoba',"",[]])
data_list.append([datetime.datetime(2022, 3, 24),4,"San Nicolas de la Villa",'Cordoba',"Spain",'Granada','Cordoba',"",[]])
data_list.append([datetime.datetime(2022, 3, 24),166,"Mezqita Cathedral",'Cordoba',"Spain",'Granada','Cordoba',"Historic Centre of Cordoba",[]])
data_list.append([datetime.datetime(2022, 3, 24),5,"Column of St Rafael",'Cordoba',"Spain",'Granada','Cordoba',"Historic Centre of Cordoba",[]])
data_list.append([datetime.datetime(2022, 3, 24),2,"Puerta del Puente",'Cordoba',"Spain",'Granada','Cordoba',"Historic Centre of Cordoba",[]])
data_list.append([datetime.datetime(2022, 3, 24),11,"Roman Bridge",'Cordoba',"Spain",'Granada','Cordoba',"Historic Centre of Cordoba",[]])
data_list.append([datetime.datetime(2022, 3, 24),7,"Torre Calahorra",'Cordoba',"Spain",'Granada','Cordoba',"Historic Centre of Cordoba",[]])
data_list.append([datetime.datetime(2022, 3, 24),5,"Episcopal Palace",'Cordoba',"Spain",'Granada','Cordoba',"Historic Centre of Cordoba",[]])
data_list.append([datetime.datetime(2022, 3, 24),3,"Synagogue",'Cordoba',"Spain",'Granada','Cordoba',"Historic Centre of Cordoba",[]])
data_list.append([datetime.datetime(2022, 3, 24),5,"City Walls",'Cordoba',"Spain",'Granada','Cordoba',"Historic Centre of Cordoba",[]])
data_list.append([datetime.datetime(2022, 3, 24),29,"Medina Azahara",'Cordoba',"Spain",'Granada','Cordoba',"Caliphate City of Medina Azahara",[]])
data_list.append([datetime.datetime(2022, 3, 24),6,"Capilla Mujedar de San Bartolome",'Cordoba',"Spain",'Granada','Cordoba',"Historic Centre of Cordoba",[]])
data_list.append([datetime.datetime(2022, 3, 24),9,"Banos Califales",'Cordoba',"Spain",'Granada','Cordoba',"Historic Centre of Cordoba",[]])
data_list.append([datetime.datetime(2022, 3, 24),32,"Alcazar de los Reyes Cristianos",'Cordoba',"Spain",'Granada','Cordoba',"Historic Centre of Cordoba",[]])
data_list.append([datetime.datetime(2022, 3, 24),3,"Roman Temple",'Cordoba',"Spain",'Granada','Cordoba',"",[]])
data_list.append([datetime.datetime(2022, 3, 24),3,"Monastery Santa Cruz",'Cordoba',"Spain",'Granada','Cordoba',"",[]])
data_list.append([datetime.datetime(2022, 3, 24),7,"Archaeological Museum",'Cordoba',"Spain",'Granada','Cordoba',"Historic Centre of Cordoba",[]])
data_list.append([datetime.datetime(2022, 3, 24),1,"San Juan & Todos Los Santos",'Cordoba',"Spain",'Granada','Cordoba',"Historic Centre of Cordoba",[]])
data_list.append([datetime.datetime(2015, 3, 24),1,"Palacio de Viana",'Cordoba',"Spain",'Granada','Cordoba',"",[]])
data_list.append([datetime.datetime(2022, 3, 25),2,"Canos de Carmona Aqueduct",'Sevilla',"Spain",'Cordoba','Sevilla',"",[]])
data_list.append([datetime.datetime(2022, 3, 25),217,"Cathedral",'Sevilla',"Spain",'Cordoba','Sevilla',"Cathedral, Alcazar and Archivo de Indias in Seville",['Manuel']])
data_list.append([datetime.datetime(2022, 3, 25),199,"Alcazar",'Sevilla',"Spain",'Cordoba','Sevilla',"Cathedral, Alcazar and Archivo de Indias in Seville",['Manuel']])
data_list.append([datetime.datetime(2022, 3, 25),4,"Archivo General de Indias",'Sevilla',"Spain",'Cordoba','Sevilla',"Cathedral, Alcazar and Archivo de Indias in Seville",['Manuel']])
data_list.append([datetime.datetime(2022, 3, 25),25,"Plaza de Espana",'Sevilla',"Spain",'Cordoba','Sevilla',"",[]])
data_list.append([datetime.datetime(2022, 3, 25),21,"San Salvador",'Sevilla',"Spain",'Cordoba','Sevilla',"",[]])
data_list.append([datetime.datetime(2022, 3, 25),3,"City Hall",'Sevilla',"Spain",'Cordoba','Sevilla',"",[]])
data_list.append([datetime.datetime(2022, 3, 25),25,"Hospital de los Venerables",'Sevilla',"Spain",'Cordoba','Sevilla',"",[]])
data_list.append([datetime.datetime(2015, 3, 25),4,"Palacio San Telmo",'Sevilla',"Spain",'Cordoba','Sevilla',"",[]])
data_list.append([datetime.datetime(2022, 3, 25),17,"Hospital de la Caridad",'Sevilla',"Spain",'Cordoba','Sevilla',"",[]])
data_list.append([datetime.datetime(2022, 3, 25),2,"Roman Temple",'Sevilla',"Spain",'Cordoba','Sevilla',"",[]])
data_list.append([datetime.datetime(2022, 3, 25),4,"San Ildefonso",'Sevilla',"Spain",'Cordoba','Sevilla',"",[]])
data_list.append([datetime.datetime(2022, 3, 25),4,"Monastery San Leandro",'Sevilla',"Spain",'Cordoba','Sevilla',"",[]])
data_list.append([datetime.datetime(2022, 3, 25),2,"Casa de Pilatos",'Sevilla',"Spain",'Cordoba','Sevilla',"",[]])
data_list.append([datetime.datetime(2022, 3, 25),27,"San Luis de los Franceses",'Sevilla',"Spain",'Cordoba','Sevilla',"",[]])
data_list.append([datetime.datetime(2022, 3, 25),2,"Basilica de la Macarena",'Sevilla',"Spain",'Cordoba','Sevilla',"",[]])
data_list.append([datetime.datetime(2022, 3, 25),2,"City Walls",'Sevilla',"Spain",'Cordoba','Sevilla',"",[]])
data_list.append([datetime.datetime(2022, 3, 25),5,"Church of Third Order",'Sevilla',"Spain",'Cordoba','Sevilla',"",[]])
data_list.append([datetime.datetime(2022, 3, 25),1,"Plaza de la Encarnacion",'Sevilla',"Spain",'Cordoba','Sevilla',"",[]])
data_list.append([datetime.datetime(2022, 3, 25),3,"Santa Annunciata",'Sevilla',"Spain",'Cordoba','Sevilla',"",[]])
data_list.append([datetime.datetime(2022, 3, 25),2,"San Antonio Abad",'Sevilla',"Spain",'Cordoba','Sevilla',"",[]])
data_list.append([datetime.datetime(2022, 3, 25),14,"Museum of Fine Arts",'Sevilla',"Spain",'Cordoba','Sevilla',"",[]])
data_list.append([datetime.datetime(2022, 3, 25),6,"Santa Maria Magdalene",'Sevilla',"Spain",'Cordoba','Sevilla',"",[]])
data_list.append([datetime.datetime(2022, 3, 26),14,"San Francisco Javier",'Caceres',"Spain",'Sevilla','Sevilla',"Caceres",[]])
data_list.append([datetime.datetime(2022, 3, 26),27,"City Walls and Towers",'Caceres',"Spain",'Sevilla','Sevilla',"Caceres",[]])
data_list.append([datetime.datetime(2022, 3, 26),7,"Torre de los Pozos",'Caceres',"Spain",'Sevilla','Sevilla',"Caceres",[]])
data_list.append([datetime.datetime(2022, 3, 26),37,"Co-Cathedral",'Caceres',"Spain",'Sevilla','Sevilla',"Caceres",[]])
data_list.append([datetime.datetime(2022, 3, 26),3,"Plaza Mayor",'Caceres',"Spain",'Sevilla','Sevilla',"",[]])
data_list.append([datetime.datetime(2022, 3, 26),10,"Caceres Museum",'Caceres',"Spain",'Sevilla','Sevilla',"Caceres",[]])
data_list.append([datetime.datetime(2022, 3, 26),2,"Eremita de San Antonio",'Caceres',"Spain",'Sevilla','Sevilla',"Caceres",[]])
data_list.append([datetime.datetime(2022, 3, 26),1,"Plaza de la Encarnacion",'Sevilla',"Spain",'Sevilla','Sevilla',"",[]])
data_list.append([datetime.datetime(2022, 3, 27),5,"Puente Romano",'Merida',"Spain",'Sevilla','Sevilla',"Merida",[]])
data_list.append([datetime.datetime(2022, 3, 27),6,"Cathedral",'Merida',"Spain",'Sevilla','Sevilla',"",[]])
data_list.append([datetime.datetime(2022, 3, 27),18,"Alcazaba",'Merida',"Spain",'Sevilla','Sevilla',"Merida",[]])
data_list.append([datetime.datetime(2022, 3, 27),6,"Santa Clara - Visigoth Museum",'Merida',"Spain",'Sevilla','Sevilla',"Merida",[]])
data_list.append([datetime.datetime(2022, 3, 27),2,"Arco de Trajano",'Merida',"Spain",'Sevilla','Sevilla',"Merida",[]])
data_list.append([datetime.datetime(2022, 3, 27),10,"Temple of Diana",'Merida',"Spain",'Sevilla','Sevilla',"Merida",[]])
data_list.append([datetime.datetime(2022, 3, 27),3,"Roman Porticus",'Merida',"Spain",'Sevilla','Sevilla',"Merida",[]])
data_list.append([datetime.datetime(2022, 3, 27),60,"National Museum of Roman Art",'Merida',"Spain",'Sevilla','Sevilla',"Merida",[]])
data_list.append([datetime.datetime(2022, 3, 27),20,"Roman Theatre",'Merida',"Spain",'Sevilla','Sevilla',"Merida",[]])
data_list.append([datetime.datetime(2022, 3, 27),6,"Roman Amphitheatre",'Merida',"Spain",'Sevilla','Sevilla',"Merida",[]])
data_list.append([datetime.datetime(2022, 3, 27),2,"Roman Baths",'Merida',"Spain",'Sevilla','Sevilla',"Merida",[]])
data_list.append([datetime.datetime(2022, 3, 27),14,"Basilica de Santa Eulalia",'Merida',"Spain",'Sevilla','Sevilla',"Merida",[]])
data_list.append([datetime.datetime(2022, 3, 27),8,"Milagros Aqueduct",'Merida',"Spain",'Sevilla','Sevilla',"Merida",[]])
data_list.append([datetime.datetime(2022, 3, 27),5,"San Lazaro Aqueduct",'Merida',"Spain",'Sevilla','Sevilla',"Merida",[]])
data_list.append([datetime.datetime(2022, 3, 27),6,"Roman Circus",'Merida',"Spain",'Sevilla','Sevilla',"Merida",[]])
data_list.append([datetime.datetime(2022, 3, 27),12,"Casa del Anfiteatro",'Merida',"Spain",'Sevilla','Sevilla',"Merida",[]])
data_list.append([datetime.datetime(2022, 3, 27),9,"Casa del Mitreo",'Merida',"Spain",'Sevilla','Sevilla',"Merida",[]])
data_list.append([datetime.datetime(2022, 3, 27),3,"Colombarium",'Merida',"Spain",'Sevilla','Sevilla',"Merida",[]])
data_list.append([datetime.datetime(2022, 3, 28),20,"Museo Reina Sofia",'Madrid',"Spain",'Sevilla','Madrid',"Paseo del Prado and Buen Retiro, a landscape of Arts and Sciences",[]])
data_list.append([datetime.datetime(2022, 3, 28),2,"San Sebastian",'Madrid',"Spain",'Sevilla','Madrid',"",[]])
data_list.append([datetime.datetime(2022, 3, 28),2,"Santa Cruz",'Madrid',"Spain",'Sevilla','Madrid',"",[]])
data_list.append([datetime.datetime(2022, 3, 28),5,"Plaza Mayor",'Madrid',"Spain",'Sevilla','Madrid',"",[]])
data_list.append([datetime.datetime(2022, 3, 28),3,"Casa de Villa",'Madrid',"Spain",'Sevilla','Madrid',"",[]])
data_list.append([datetime.datetime(2022, 3, 28),6,"Army Cathedral",'Madrid',"Spain",'Sevilla','Madrid',"",[]])
data_list.append([datetime.datetime(2022, 3, 28),52,"Almudena Cathedral",'Madrid',"Spain",'Sevilla','Madrid',"",[]])
data_list.append([datetime.datetime(2022, 3, 28),9,"Palacio Real",'Madrid',"Spain",'Sevilla','Madrid',"",[]])
data_list.append([datetime.datetime(2022, 3, 28),5,"Palacio de Liria",'Madrid',"Spain",'Sevilla','Madrid',"",[]])
data_list.append([datetime.datetime(2022, 3, 28),1,"Santa Teresa & San Jose",'Madrid',"Spain",'Sevilla','Madrid',"",[]])
data_list.append([datetime.datetime(2022, 3, 28),2,"Temple of Debod",'Madrid',"Spain",'Sevilla','Madrid',"",[]])
data_list.append([datetime.datetime(2022, 3, 28),2,"Plaza de Espana",'Madrid',"Spain",'Sevilla','Madrid',"",[]])
data_list.append([datetime.datetime(2022, 3, 28),2,"Sabatini Gardens",'Madrid',"Spain",'Sevilla','Madrid',"",[]])
data_list.append([datetime.datetime(2022, 3, 28),9,"San Miguel",'Madrid',"Spain",'Sevilla','Madrid',"",[]])
data_list.append([datetime.datetime(2022, 3, 28),5,"Plaza Mayor",'Cuenca',"Spain",'Sevilla','Madrid',"Cuenca",[]])
data_list.append([datetime.datetime(2022, 3, 28),121,"Cathedral",'Cuenca',"Spain",'Sevilla','Madrid',"Cuenca",[]])
data_list.append([datetime.datetime(2022, 3, 28),20,"Cathedral Museum",'Cuenca',"Spain",'Sevilla','Madrid',"Cuenca",[]])
data_list.append([datetime.datetime(2022, 3, 28),9,"Cuenca Canyon",'Cuenca',"Spain",'Sevilla','Madrid',"",[]])
data_list.append([datetime.datetime(2022, 3, 28),5,"San Pedro",'Cuenca',"Spain",'Sevilla','Madrid',"Cuenca",[]])
data_list.append([datetime.datetime(2022, 3, 28),2,"Castillo",'Cuenca',"Spain",'Sevilla','Madrid',"Cuenca",[]])
data_list.append([datetime.datetime(2022, 3, 28),5,"Station Madrid Atocha",'Madrid',"Spain",'Sevilla','Madrid',"Paseo del Prado and Buen Retiro, a landscape of Arts and Sciences",[]])
data_list.append([datetime.datetime(2022, 3, 29),4,"Hotel Mediodia",'Madrid',"Spain",'Madrid','Madrid',"Paseo del Prado and Buen Retiro, a landscape of Arts and Sciences",[]])
data_list.append([datetime.datetime(2022, 3, 29),3,"Plaza Mayor",'Madrid',"Spain",'Madrid','Madrid',"",[]])
data_list.append([datetime.datetime(2022, 3, 29),13,"San Isidro",'Madrid',"Spain",'Madrid','Madrid',"",[]])
data_list.append([datetime.datetime(2022, 3, 29),11,"San Andres",'Madrid',"Spain",'Madrid','Madrid',"",[]])
data_list.append([datetime.datetime(2022, 3, 29),23,"Real Basilica de San Francisco el Grande",'Madrid',"Spain",'Madrid','Madrid',"",[]])
data_list.append([datetime.datetime(2022, 3, 29),2,"Plaza de Oriente",'Madrid',"Spain",'Madrid','Madrid',"",[]])
data_list.append([datetime.datetime(2022, 3, 29),1,"Almudena Cathedral",'Madrid',"Spain",'Madrid','Madrid',"",[]])
data_list.append([datetime.datetime(2022, 3, 29),1,"Teatro Real",'Madrid',"Spain",'Madrid','Madrid',"",[]])
data_list.append([datetime.datetime(2022, 3, 29),12,"San Antonio de los Alemanes",'Madrid',"Spain",'Madrid','Madrid',"",[]])
data_list.append([datetime.datetime(2022, 3, 29),2,"San Ildefonso",'Madrid',"Spain",'Madrid','Madrid',"",[]])
data_list.append([datetime.datetime(2022, 3, 29),1,"San Anton",'Madrid',"Spain",'Madrid','Madrid',"",[]])
data_list.append([datetime.datetime(2022, 3, 29),7,"Santa Barbara",'Madrid',"Spain",'Madrid','Madrid',"",[]])
data_list.append([datetime.datetime(2022, 3, 29),11,"San Jose",'Madrid',"Spain",'Madrid','Madrid',"",[]])
data_list.append([datetime.datetime(2022, 3, 29),2,"Church of the Order of Calatravas",'Madrid',"Spain",'Madrid','Madrid',"",[]])
data_list.append([datetime.datetime(2022, 3, 29),1,"Basilica of Jesus de Medinaceli",'Madrid',"Spain",'Madrid','Madrid',"",[]])
data_list.append([datetime.datetime(2022, 3, 29),1,"Palacio de las Cortes",'Madrid',"Spain",'Madrid','Madrid',"Paseo del Prado and Buen Retiro, a landscape of Arts and Sciences",[]])
data_list.append([datetime.datetime(2022, 3, 29),18,"Palacio de Laredo",'Alcala de Henares',"Spain",'Madrid','Madrid',"",[]])
data_list.append([datetime.datetime(2022, 3, 29),7,"Capilla de las Santas Formas",'Alcala de Henares',"Spain",'Madrid','Madrid',"Alcala de Henares",[]])
data_list.append([datetime.datetime(2022, 3, 29),7,"Colegio Mayor de San Ildefonso",'Alcala de Henares',"Spain",'Madrid','Madrid',"Alcala de Henares",[]])
data_list.append([datetime.datetime(2022, 3, 29),5,"Capilla del Oidor",'Alcala de Henares',"Spain",'Madrid','Madrid',"Alcala de Henares",[]])
data_list.append([datetime.datetime(2022, 3, 29),15,"Regional Archaeological Museum",'Alcala de Henares',"Spain",'Madrid','Madrid',"Alcala de Henares",[]])
data_list.append([datetime.datetime(2022, 3, 29),3,"City Walls and Gates",'Alcala de Henares',"Spain",'Madrid','Madrid',"Alcala de Henares",[]])
data_list.append([datetime.datetime(2022, 3, 29),4,"Cathedral",'Alcala de Henares',"Spain",'Madrid','Madrid',"Alcala de Henares",[]])
data_list.append([datetime.datetime(2022, 3, 29),7,"Excavations of Complutum",'Alcala de Henares',"Spain",'Madrid','Madrid',"",[]])
data_list.append([datetime.datetime(2022, 3, 29),1,"Santa Maria la Mayor",'Alcala de Henares',"Spain",'Madrid','Madrid',"Alcala de Henares",[]])
data_list.append([datetime.datetime(2022, 3, 29),1,"Museo del Prado",'Madrid',"Spain",'Madrid','Madrid',"Paseo del Prado and Buen Retiro, a landscape of Arts and Sciences",[]])
data_list.append([datetime.datetime(2022, 3, 30),1,"Station",'Toledo',"Spain",'Madrid','Madrid',"Toledo",[]])
data_list.append([datetime.datetime(2022, 3, 30),238,"Cathedral",'Toledo',"Spain",'Madrid','Madrid',"Toledo",[]])
data_list.append([datetime.datetime(2022, 3, 30),23,"Hospital de Santa Cruz",'Toledo',"Spain",'Madrid','Madrid',"Toledo",[]])
data_list.append([datetime.datetime(2022, 3, 30),6,"Cuevas de Hercule",'Toledo',"Spain",'Madrid','Madrid',"Toledo",[]])
data_list.append([datetime.datetime(2022, 3, 30),3,"Roman Baths",'Toledo',"Spain",'Madrid','Madrid',"Toledo",[]])
data_list.append([datetime.datetime(2022, 3, 30),21,"San Roman",'Toledo',"Spain",'Madrid','Madrid',"Toledo",[]])
data_list.append([datetime.datetime(2022, 3, 30),12,"Jesuit Church",'Toledo',"Spain",'Madrid','Madrid',"Toledo",[]])
data_list.append([datetime.datetime(2022, 3, 30),14,"Ermita Mezquita del Cristo de la Luz",'Toledo',"Spain",'Madrid','Madrid',"Toledo",[]])
data_list.append([datetime.datetime(2022, 3, 30),35,"City Walls and Gates",'Toledo',"Spain",'Madrid','Madrid',"Toledo",[]])
data_list.append([datetime.datetime(2022, 3, 30),38,"Hospital de Tavera",'Toledo',"Spain",'Madrid','Madrid',"Toledo",[]])
data_list.append([datetime.datetime(2022, 3, 30),5,"Alcazar",'Toledo',"Spain",'Madrid','Madrid',"Toledo",[]])
data_list.append([datetime.datetime(2022, 3, 30),1,"Episcopal Chapel",'Toledo',"Spain",'Madrid','Madrid',"Toledo",[]])
data_list.append([datetime.datetime(2022, 3, 30),9,"El Salvador",'Toledo',"Spain",'Madrid','Madrid',"Toledo",[]])
data_list.append([datetime.datetime(2022, 3, 30),10,"Synagogue del Transito",'Toledo',"Spain",'Madrid','Madrid',"Toledo",[]])
data_list.append([datetime.datetime(2022, 3, 30),5,"Tajo Canyon",'Toledo',"Spain",'Madrid','Madrid',"Toledo",[]])
data_list.append([datetime.datetime(2022, 3, 30),11,"Puente San Martin",'Toledo',"Spain",'Madrid','Madrid',"Toledo",[]])
data_list.append([datetime.datetime(2022, 3, 30),11,"Synagogue Santa Maria la Blanca",'Toledo',"Spain",'Madrid','Madrid',"Toledo",[]])
data_list.append([datetime.datetime(2022, 3, 30),40,"Monastery San Juan de los Reyes",'Toledo',"Spain",'Madrid','Madrid',"Toledo",[]])
data_list.append([datetime.datetime(2022, 3, 30),12,"Real Colegio Doncellas Nobles",'Toledo',"Spain",'Madrid','Madrid',"Toledo",[]])
data_list.append([datetime.datetime(2022, 3, 30),6,"Taller del Moro",'Toledo',"Spain",'Madrid','Madrid',"Toledo",[]])
data_list.append([datetime.datetime(2022, 3, 30),15,"El Greco Museum",'Toledo',"Spain",'Madrid','Madrid',"Toledo",[]])
data_list.append([datetime.datetime(2022, 3, 30),7,"Puente del Alcantara",'Toledo',"Spain",'Madrid','Madrid',"Toledo",[]])
data_list.append([datetime.datetime(2022, 3, 31),1,"Plaza Guzman",'Leon',"Spain",'Madrid','Madrid',"Routes of Santiago de Compostela",[]])
data_list.append([datetime.datetime(2022, 3, 31),1,"Casa Botines",'Leon',"Spain",'Madrid','Madrid',"Routes of Santiago de Compostela",[]])
data_list.append([datetime.datetime(2022, 3, 31),1,"Plaza de San Domingo",'Leon',"Spain",'Madrid','Madrid',"Routes of Santiago de Compostela",[]])
data_list.append([datetime.datetime(2022, 3, 31),2,"San Marcelo",'Leon',"Spain",'Madrid','Madrid',"Routes of Santiago de Compostela",[]])
data_list.append([datetime.datetime(2022, 3, 31),2,"Plaza Mayor",'Leon',"Spain",'Madrid','Madrid',"Routes of Santiago de Compostela",[]])
data_list.append([datetime.datetime(2022, 3, 31),111,"Cathedral",'Leon',"Spain",'Madrid','Madrid',"Routes of Santiago de Compostela",[]])
data_list.append([datetime.datetime(2022, 3, 31),17,"Basilica de San Isidro",'Leon',"Spain",'Madrid','Madrid',"Routes of Santiago de Compostela",[]])
data_list.append([datetime.datetime(2022, 3, 31),5,"Roman Walls",'Leon',"Spain",'Madrid','Madrid',"Routes of Santiago de Compostela",[]])
data_list.append([datetime.datetime(2022, 3, 31),17,"Monastery San Marcos",'Leon',"Spain",'Madrid','Madrid',"Routes of Santiago de Compostela",[]])
data_list.append([datetime.datetime(2022, 3, 31),6,"Monastery Church San Marcos",'Leon',"Spain",'Madrid','Madrid',"",[]])
data_list.append([datetime.datetime(2022, 3, 31),72,"Cathedral",'Astorga',"Spain",'Madrid','Madrid',"Routes of Santiago de Compostela",[]])
data_list.append([datetime.datetime(2022, 3, 31),61,"Episcopal Palace",'Astorga',"Spain",'Madrid','Madrid',"Routes of Santiago de Compostela",[]])
data_list.append([datetime.datetime(2022, 3, 31),3,"City Walls",'Astorga',"Spain",'Madrid','Madrid',"Routes of Santiago de Compostela",[]])
data_list.append([datetime.datetime(2022, 4, 1),14,"Roman Aqueduct",'Segovia',"Spain",'Madrid','Madrid',"Old Town of Segovia and its Aqueduct",[]])
data_list.append([datetime.datetime(2022, 4, 1),14,"City Walls",'Segovia',"Spain",'Madrid','Madrid',"Old Town of Segovia and its Aqueduct",[]])
data_list.append([datetime.datetime(2022, 4, 1),14,"San Millan",'Segovia',"Spain",'Madrid','Madrid',"",[]])
data_list.append([datetime.datetime(2022, 4, 1),18,"San Martin",'Segovia',"Spain",'Madrid','Madrid',"Old Town of Segovia and its Aqueduct",[]])
data_list.append([datetime.datetime(2022, 4, 1),3,"Plaza Mayor",'Segovia',"Spain",'Madrid','Madrid',"Old Town of Segovia and its Aqueduct",[]])
data_list.append([datetime.datetime(2022, 4, 1),1,"San Miguel",'Segovia',"Spain",'Madrid','Madrid',"Old Town of Segovia and its Aqueduct",[]])
data_list.append([datetime.datetime(2022, 4, 1),82,"Cathedral",'Segovia',"Spain",'Madrid','Madrid',"Old Town of Segovia and its Aqueduct",[]])
data_list.append([datetime.datetime(2022, 4, 1),3,"Puerta de San Andres",'Segovia',"Spain",'Madrid','Madrid',"Old Town of Segovia and its Aqueduct",[]])
data_list.append([datetime.datetime(2022, 4, 1),48,"Alcazar",'Segovia',"Spain",'Madrid','Madrid',"Old Town of Segovia and its Aqueduct",[]])
data_list.append([datetime.datetime(2022, 4, 1),14,"Santa Vera Cruz",'Segovia',"Spain",'Madrid','Madrid',"",[]])
data_list.append([datetime.datetime(2022, 4, 1),7,"Sanctuary of the Virgin of Fuencisla",'Segovia',"Spain",'Madrid','Madrid',"",[]])
data_list.append([datetime.datetime(2022, 4, 1),12,"San Juan y Pastor",'Segovia',"Spain",'Madrid','Madrid',"Old Town of Segovia and its Aqueduct",[]])
data_list.append([datetime.datetime(2022, 4, 1),2,"San Esteban",'Segovia',"Spain",'Madrid','Madrid',"Old Town of Segovia and its Aqueduct",[]])
data_list.append([datetime.datetime(2022, 4, 1),4,"Monastery San Juan de la Cruz",'Segovia',"Spain",'Madrid','Madrid',"",[]])
data_list.append([datetime.datetime(2022, 4, 1),12,"Palacio Real de La Granja de San Ildefenso",'La Granja',"Spain",'Madrid','Madrid',"",[]])
data_list.append([datetime.datetime(2022, 4, 1),59,"Palacio Real de La Granja de San Ildefenso Gardens",'La Granja',"Spain",'Madrid','Madrid',"",[]])
data_list.append([datetime.datetime(2022, 4, 1),2,"Plaza Medina del Campo",'Segovia',"Spain",'Madrid','Madrid',"Old Town of Segovia and its Aqueduct",[]])
data_list.append([datetime.datetime(2022, 4, 1),1,"Museo del Prado",'Madrid',"Spain",'Madrid','Madrid',"Paseo del Prado and Buen Retiro, a landscape of Arts and Sciences",[]])
data_list.append([datetime.datetime(2022, 4, 1),1,"San Jeronimo el Real",'Madrid',"Spain",'Madrid','Madrid',"Paseo del Prado and Buen Retiro, a landscape of Arts and Sciences",[]])
data_list.append([datetime.datetime(2022, 4, 1),5,"Neptune Fountain",'Madrid',"Spain",'Madrid','Madrid',"Paseo del Prado and Buen Retiro, a landscape of Arts and Sciences",[]])
data_list.append([datetime.datetime(2022, 4, 1),6,"Plaza de Cibeles with Cibeles Fountain",'Madrid',"Spain",'Madrid','Madrid',"Paseo del Prado and Buen Retiro, a landscape of Arts and Sciences",[]])
data_list.append([datetime.datetime(2022, 4, 1),1,"El Retiro Park",'Madrid',"Spain",'Madrid','Madrid',"Paseo del Prado and Buen Retiro, a landscape of Arts and Sciences",[]])
data_list.append([datetime.datetime(2022, 4, 1),2,"Palacio de Cibeles",'Madrid',"Spain",'Madrid','Madrid',"Paseo del Prado and Buen Retiro, a landscape of Arts and Sciences",[]])
data_list.append([datetime.datetime(2022, 4, 1),2,"Puerta de Alcala",'Madrid',"Spain",'Madrid','Madrid',"Paseo del Prado and Buen Retiro, a landscape of Arts and Sciences",[]])
data_list.append([datetime.datetime(2022, 4, 1),1,"Palacio de Linares",'Madrid',"Spain",'Madrid','Madrid',"Paseo del Prado and Buen Retiro, a landscape of Arts and Sciences",[]])
data_list.append([datetime.datetime(2022, 4, 2),1,"Station",'Aranjuez',"Spain",'Madrid','Madrid',"",[]])
data_list.append([datetime.datetime(2022, 4, 2),22,"Palacio Real",'Aranjuez',"Spain",'Madrid','Madrid',"Aranjuez",[]])
data_list.append([datetime.datetime(2022, 4, 2),41,"Palacio Real Gardens",'Aranjuez',"Spain",'Madrid','Madrid',"Aranjuez",[]])
data_list.append([datetime.datetime(2022, 4, 2),110,"Real Sitio de San Lorenzo de El Escorial",'El Escorial',"Spain",'Madrid','Madrid',"Real Sitio de San Lorenzo de El Escorial",[]])
data_list.append([datetime.datetime(2022, 4, 2),14,"Casita del Principe",'El Escorial',"Spain",'Madrid','Madrid',"Real Sitio de San Lorenzo de El Escorial",[]])


data_list.append([datetime.datetime(2022, 4, 3),3,"Plaza Mayor",'Madrid',"Spain",'Madrid','Vienna',"",[]])
data_list.append([datetime.datetime(2022, 4, 3),2,"Almudena Cathedral",'Madrid',"Spain",'Madrid','Vienna',"",[]])
data_list.append([datetime.datetime(2022, 4, 3),60,"Palacio Real",'Madrid',"Spain",'Madrid','Vienna',"",[]])
data_list.append([datetime.datetime(2022, 4, 3),57,"Casa Cerralbo",'Madrid',"Spain",'Madrid','Vienna',"",[]])
data_list.append([datetime.datetime(2022, 4, 3),2,"Plaza de Espana",'Madrid',"Spain",'Madrid','Vienna',"",[]])
data_list.append([datetime.datetime(2022, 4, 3),49,"Museo Thyssen-Bornemisza",'Madrid',"Spain",'Madrid','Vienna',"Paseo del Prado and Buen Retiro, a landscape of Arts and Sciences",[]])
data_list.append([datetime.datetime(2022, 4, 3),21,"Botanical Gardens",'Madrid',"Spain",'Madrid','Vienna',"Paseo del Prado and Buen Retiro, a landscape of Arts and Sciences",[]])

# %%
df = pd.DataFrame(data_list,columns=['Date', 'Pictures', 'Name','Place','Country','Day Start Place','Day End Place','UNESCO Site',"Co-Travellers"])
df.to_csv("../data/Attraction_VisitInfo.csv")
df
# Out:
#            Date  Pictures                      Name   Place         Country  \
# 0    1996-08-24         1            Somerset House  London  United Kingdom
# 1    1996-08-24         1            British Museum  London  United Kingdom
# 2    1996-08-25         1     Westminster Cathedral  London  United Kingdom
# 3    1996-08-25         1          National Gallery  London  United Kingdom
# 4    1996-08-25         1   St Martin in the Fields  London  United Kingdom
# ...         ...       ...                       ...     ...             ...
# 5463 2022-04-03        60              Palacio Real  Madrid           Spain
# 5464 2022-04-03        57             Casa Cerralbo  Madrid           Spain
# 5465 2022-04-03         2           Plaza de Espana  Madrid           Spain
# 5466 2022-04-03        49  Museo Thyssen-Bornemisza  Madrid           Spain
# 5467 2022-04-03        21         Botanical Gardens  Madrid           Spain
#
#      Day Start Place Day End Place  \
# ...

# %%
df["AttractionString"]=df["Country"]+df["Place"].values+df["Name"].values

# %%
#big places
#france: Paris, Lyon
#UK: London
#Germany: Berlin,Munich
#Spain: Barcelona, Madrid
#Portugal: Lisbon? Porto?
#Poland: Warsaw, Krakow
#Italy: Milan, Rome, Florence, Venice, Naples, Torino, Genoa, Bergamo, Palermo, Bologna
#Copenhagen, Stockholm, St Petersburg, Brussels, Vienna, Salzburg, Prague, Budapest, Athens
#Beijing, Nanjing, Macao, Seoul, Kyoto, Tokyo, Istanbul, Marrakesh, Amsterdam

# %%
df_attractionCities=df.groupby(["Place"]).agg(
    Number_Attractions=("AttractionString",'nunique'),
    Photos_Attractions=('Pictures','sum'),
    DaysVisited=("Date",'nunique')
                              ).sort_values(by=["Number_Attractions","Photos_Attractions"],
    ascending=False).reset_index()
df_attractionCities["Photos_per_Attraction"]=df_attractionCities["Photos_Attractions"]/df_attractionCities["Number_Attractions"]
df_attractionCities["Photos_per_Day"]=df_attractionCities["Photos_Attractions"]/df_attractionCities["DaysVisited"]
df_attractionCities["N_Attracions_per_Day"]=df_attractionCities["Number_Attractions"]/df_attractionCities["DaysVisited"]
df_attractionCities.head(50)
# Out:
#                         Place  Number_Attractions  Photos_Attractions  \
# 0                        Rome                 219                5414
# 1                      Vienna                 152                4550
# 2                       Paris                 135                4406
# 3                      London                  96                2075
# 4                      Berlin                  66                1175
# 5                      Venice                  64                1104
# 6                      Prague                  51                1152
# 7                      Madrid                  45                 566
# 8                      Munich                  42                 586
# 9                   Barcelona                  38                1071
# 10                   Florence                  37                1863
# 11                     Naples                  33                 886
# ...

# %%
#list_def=[32,32.50,70,10,69,15,11,20]
#list_def.remove(10)
#print((list_def))
#df_attractionCities.loc[~((df_attractionCities["Number_Attractions"].isin(list_def)) &
#                        (df_attractionCities["Place"].isin(["Kiev",'Seoul','Geneva','Dublin',"Noto"])))].head(50)

# %%
##list_def=[20,32.50,70,10,69,15,10]
#print(list_def)
#list_def.remove(10)
#list_def

# %%
df["year"]=df["Date"].dt.year
df_by_year_country=df.groupby(["year","Country"]).agg(
    Number_Attractions=("AttractionString",'nunique'),
    Number_Places=('Place','nunique'),
    Number_Countries=('Country','nunique'),
    Number_Days=('Date','nunique'),
    Photos_Attractions=('Pictures','sum')
    ).sort_values(by=["Number_Attractions","Photos_Attractions"],
    ascending=False).reset_index()
df_by_year_country["Attractions_per_Day"]=df_by_year_country["Number_Attractions"]/df_by_year_country["Number_Days"]
df_by_year_country["Photos_per_Attraction"]=df_by_year_country["Photos_Attractions"]/df_by_year_country["Number_Attractions"]
df_by_year_country["Photos_per_Place"]=df_by_year_country["Photos_Attractions"]/df_by_year_country["Number_Places"]
df_by_year_country["Photos_per_Day"]=df_by_year_country["Photos_Attractions"]/df_by_year_country["Number_Days"]
df_by_year_country.head(50)
# Out:
#     year         Country  Number_Attractions  Number_Places  Number_Countries  \
# 0   2021         Austria                 339             51                 1
# 1   2021         Germany                 241             65                 1
# 2   2022           Spain                 229             19                 1
# 3   2017           Italy                 217             17                 1
# 4   2020           Italy                 211             15                 1
# 5   2013           Italy                 197              4                 1
# 6   2016           Italy                 147             22                 1
# 7   2019           Italy                 124             26                 1
# 8   2018         Germany                 115             31                 1
# 9   2014  United Kingdom                 112             18                 1
# 10  2018          France                 107             19                 1
# ...

# %%
df["year"]=df["Date"].dt.year
df_by_year=df.groupby(["year"]).agg(
    Number_Attractions=("AttractionString",'nunique'),
    Number_Places=('Place','nunique'),
    Number_Countries=('Country','nunique'),
    Number_Days=('Date','nunique'),
    Photos_Attractions=('Pictures','sum')
    ).sort_values(by=["Number_Attractions","Photos_Attractions"],
    ascending=False).reset_index()
df_by_year["Photos_per_Attraction"]=df_by_year["Photos_Attractions"]/df_by_year["Number_Attractions"]
df_by_year["Photos_per_Place"]=df_by_year["Photos_Attractions"]/df_by_year["Number_Places"]
df_by_year["Photos_per_Day"]=df_by_year["Photos_Attractions"]/df_by_year["Number_Days"]
df_by_year["Attractions_per_Day"]=df_by_year["Number_Attractions"]/df_by_year["Number_Days"]
df_by_year.head(50)
# Out:
#     year  Number_Attractions  Number_Places  Number_Countries  Number_Days  \
# 0   2017                 721             91                20           84
# 1   2021                 718            128                 7          102
# 2   2018                 614            123                13           82
# 3   2020                 382             72                 6           53
# 4   2013                 380             39                 7           52
# 5   2019                 338             70                 6           49
# 6   2016                 330             47                 8           39
# 7   2014                 281             40                 7           42
# 8   2022                 254             21                 3           22
# 9   2015                 249             35                 7           32
# 10  2012                 161             10                 5           27
# ...

# %%
#for attractions need to splice out via places
#e.g. far too many Duomos otherwise
df.groupby(["Day Start Place"]).agg(
    PhotosFromPlace=('Pictures','sum'),
    AttractionsVisited=('AttractionString','nunique'),
    PlacesVisited=('Place','nunique'),
    DaysVisited=("Date",'nunique')
                              ).sort_values(by=["PhotosFromPlace"],
    ascending=False).reset_index().head(50)
# Out:
#    Day Start Place  PhotosFromPlace  AttractionsVisited  PlacesVisited  \
# 0           Geneva             8781                 573            125
# 1           Vienna             8341                 389             56
# 2            Paris             7975                 249             31
# 3             Rome             7448                 304             13
# 4           London             3208                 145             21
# 5           Madrid             2815                 145             14
# 6      Lauchringen             2511                 214             76
# 7           Berlin             2387                 121             10
# 8           Naples             1708                  66             13
# 9           Venice             1613                  91              7
# 10          Milano             1341                  78             10
# 11         Beijing             1293                  28              5
# ...

# %%
df_country=df.groupby(["Country",]).agg(
    Number_Attractions=('AttractionString','nunique'),
    Number_Places=('Place','nunique'),
    Photos_Attractions=('Pictures','sum'),
    DaysVisited=("Date",'nunique')
    ).sort_values(by=["Number_Attractions","Photos_Attractions"],
    ascending=False).reset_index()
df_country["Photos_per_Attraction"]=df_country["Photos_Attractions"]/df_country["Number_Attractions"]
df_country["Photos_per_Place"]=df_country["Photos_Attractions"]/df_country["Number_Places"]
df_country["Photos_per_Day"]=df_country["Photos_Attractions"]/df_country["DaysVisited"]
df_country["Attractions_per_Day"]=df_country["Number_Attractions"]/df_country["DaysVisited"]
df_country.head(50)
# Out:
#            Country  Number_Attractions  Number_Places  Photos_Attractions  \
# 0            Italy                 811             86               16740
# 1          Germany                 626            132               10828
# 2           France                 439             70               11278
# 3          Austria                 379             53                9089
# 4            Spain                 357             28                7650
# 5   United Kingdom                 224             44                4843
# 6      Switzerland                 196             59                2983
# 7            China                  99             13                2446
# 8              USA                  74             13                 968
# 9            Japan                  69             11                1113
# 10         Belgium                  63              8                1128
# 11          Poland                  62              7                1226
# ...

# %%
import re
#re.sub(r'\W+', '', your_string)

cotravellers=set()

#if I consider unique() just alone, then it would split everything directly into 

for expr in df['Co-Travellers'].values:
    for w in expr:
        name=re.sub(r"[^\w-]", ' ', w).strip()
        if name!="":
            cotravellers.add(name)
print(cotravellers)
df_list_co_travellers=[]
for ind_ct,ct in enumerate(cotravellers):
    cot_flag=np.zeros(len(df))
    for ind,expr in enumerate(df['Co-Travellers'].values):
        if ct in expr:
            cot_flag[ind]=1
    df["cot_flag"]=cot_flag
    
    print(ind_ct, ct,": total number of attractions",df.loc[df['cot_flag']==1,"AttractionString"].nunique(),
         "joined on",df.loc[(df['cot_flag']==1),"Date"].nunique(),"separate occasions")
    df_list_co_travellers.append([ct,
                                df.loc[(df['cot_flag']==1),"AttractionString"].nunique(),
                                df.loc[(df['cot_flag']==1),"Date"].nunique(),
                                df.loc[(df['cot_flag']==1),"Country"].nunique(),
                                df.loc[(df['cot_flag']==1),"Place"].nunique(),
                                df.loc[(df['cot_flag']==1),"Date"].min(),
                                df.loc[(df['cot_flag']==1),"Date"].max(),
                                df.loc[(df['cot_flag']==1),"Pictures"].sum()
                                 ])
    if df.loc[(df['cot_flag']==1),"Date"].nunique()>1:
        min_x=df.loc[(df['cot_flag']==1),"Date"].min()-np.timedelta64(2,"M")
        max_x=df.loc[(df['cot_flag']==1),"Date"].max()+np.timedelta64(2,"M")
        fig, ax = plt.subplots()
        max_y=1.25*df[(df['cot_flag']==1)].drop(columns=['Co-Travellers']).groupby(pd.Grouper(key="Date", freq="1D")).nunique()["AttractionString"].max()
        df[(df['cot_flag']==1)].drop(columns=['Co-Travellers']).groupby(pd.Grouper(key="Date", freq="1D")).nunique()["AttractionString"].plot(title="attractions visited",ylabel="N Attractions",xlim=(min_x,max_x),ylim=(0,max_y))
        plt.show()
# Out:
# {'Hannsjoerg', 'Kennedy', 'Nick', 'Christine', 'AJ', 'Bob', 'Bing', 'Siyi', 'Amin', 'Gianrico', 'Dylan', 'Pieter', 'Chris Lee', 'Mathilda', 'Paul', 'Graham', 'Francesca', 'YaoYao', 'MaryAnn', 'Will', 'Santona', 'Jose', 'Jan', 'HBryan', 'Susanne', 'Jesse', 'Rachel', 'Chris Clarke', 'Juno', 'Chris Brainerd', 'Andriy', 'Franziska', 'Cameron', 'Sasha', 'Sarah', 'Serena', 'Julius', 'Ulrike', 'Mohamed', 'Vivan', 'Janina', 'Angelika', 'Elga', 'Heidrun', 'Juliette', 'Andres', 'Xuan', 'Evan', 'Tema', 'Zhicheng', 'Reyer', 'Eve', 'Devin', 'Anne', 'Lingpao', 'Christian', 'Rosana', 'Nhi', 'Jan-Marc', 'Manuel', 'Aaron', 'Nicolae', 'Juliana', 'Nate', 'Riju', 'Anne-Kathrin', 'David', 'Eva', 'Kevin', 'Adrian', 'Chris Martin', 'Jacob', 'Jens', 'Steffen', 'Laser', 'Andrew', 'Bryan', 'Indara', 'Yaroslava', 'Rickard', 'Artur', 'Stephanie', 'Can', 'Eric', 'Namrata', 'Ivan', 'Grace', 'Simon', 'Sigi', 'Michael', 'Felicitas', 'Tony', 'Sam', 'Marion'}
# ...

# %%
df_coTrav = pd.DataFrame(df_list_co_travellers,columns=['Co-Traveller', 'N_Attractions','Days',"N_Countries","N_Places","FirstTripDate",'LastTripDate',"N_Photos"])
df_coTrav=df_coTrav.sort_values(by=["N_Attractions",'N_Photos'],ascending=False).reset_index().drop(columns='index')
df_coTrav.to_csv("../data/AttractionStats_cotravellers.csv")
df_coTrav.head(50)
# Out:
#       Co-Traveller  N_Attractions  Days  N_Countries  N_Places FirstTripDate  \
# 0            Artur            842   136           10       184    1996-08-24
# 1          Heidrun            806   105           10       119    1996-08-24
# 2             Riju            413    51           15        51    2015-07-18
# 3       Hannsjoerg            338    84            8        61    1996-08-24
# 4            Reyer            198    28            9        48    2017-07-08
# 5   Chris Brainerd            178    21            4        41    2018-08-11
# 6             Amin            163    13            4        16    2016-05-14
# 7             Eric            109    15            4        16    2012-09-28
# 8            Bryan            106     5            2         2    2020-02-27
# 9     Anne-Kathrin            104    23            5        17    1996-08-24
# 10          Andrew             96    12            3        16    2010-07-31
# ...

# %%
min_x=df["Date"].min()-np.timedelta64(2,"M")
max_x=df["Date"].max()+np.timedelta64(2,"M")
fig, ax = plt.subplots(figsize=(20,5))
max_y=1.25*df.drop(columns=['Co-Travellers']).groupby(pd.Grouper(key="Date", freq="1D")).nunique()["AttractionString"].max()
df.drop(columns=['Co-Travellers']).groupby(pd.Grouper(key="Date", freq="1D")).nunique()["AttractionString"].plot(title="attractions visited",ylabel="N Attractions",xlim=(min_x,max_x),ylim=(0,max_y))
plt.show()

# %%
min_x=df["Date"].min()-np.timedelta64(2,"M")
max_x=df["Date"].max()+np.timedelta64(2,"M")
fig, ax = plt.subplots(figsize=(20,5))
max_y=1.25*df.drop(columns=['Co-Travellers']).groupby(pd.Grouper(key="Date", freq="1W")).nunique()["AttractionString"].max()
df.drop(columns=['Co-Travellers']).groupby(pd.Grouper(key="Date", freq="1W")).nunique()["AttractionString"].plot(title="attractions visited",ylabel="N Attractions",xlim=(min_x,max_x),ylim=(0,max_y))
plt.show()

# %%
min_x=df["Date"].min()-np.timedelta64(2,"M")
max_x=df["Date"].max()+np.timedelta64(2,"M")
fig, ax = plt.subplots(figsize=(20,5))
max_y=1.25*df.drop(columns=['Co-Travellers']).groupby(pd.Grouper(key="Date", freq="2W")).nunique()["AttractionString"].max()
df.drop(columns=['Co-Travellers']).groupby(pd.Grouper(key="Date", freq="2W")).nunique()["AttractionString"].plot(title="attractions visited",ylabel="N Attractions",xlim=(min_x,max_x),ylim=(0,max_y))
plt.show()

# %%
min_x=df["Date"].min()-np.timedelta64(2,"M")
max_x=df["Date"].max()+np.timedelta64(2,"M")
fig, ax = plt.subplots(figsize=(20,5))
max_y=1.25*df.drop(columns=['Co-Travellers']).groupby(pd.Grouper(key="Date", freq="M")).nunique()["AttractionString"].max()
df.drop(columns=['Co-Travellers']).groupby(pd.Grouper(key="Date", freq="M")).nunique()["AttractionString"].plot(title="attractions visited",ylabel="N Attractions",xlim=(min_x,max_x),ylim=(0,max_y))
plt.show()
